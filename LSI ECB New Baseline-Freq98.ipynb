# %%
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['Press']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(4394 unique tokens: ['able', 'acceptable', 'accompanied', 'according', 'account']...)

# %%
# filter words that occur in more than 90% of documents
id2word.filter_extremes(no_above = 0.980)
print(id2word)
# Out:
# Dictionary(1966 unique tokens: ['able', 'accompanied', 'according', 'account', 'achievement']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.283*"inflation" + 0.180*"term" + 0.180*"medium" + 0.177*"annual" + '
#   '0.160*"remain" + 0.155*"analysis" + 0.132*"financial" + 0.130*"fiscal" + '
#   '0.128*"continue" + 0.124*"expected"')]
# [(0,
#   '0.283*"inflation" + 0.180*"term" + 0.180*"medium" + 0.177*"annual" + '
#   '0.160*"remain" + 0.155*"analysis" + 0.132*"financial" + 0.130*"fiscal" + '
#   '0.128*"continue" + 0.124*"expected"'),
#  (1,
#   '-0.210*"loan" + -0.179*"inflation" + 0.173*"first" + 0.157*"recent" + '
#   '-0.151*"measure" + 0.144*"level" + 0.133*"strong" + 0.126*"wage" + '
#   '0.124*"central" + 0.119*"would"'),
#  (2,
#   '0.206*"medium" + 0.189*"upside" + 0.184*"strong" + -0.164*"bank" + '
#   '-0.148*"operation" + -0.136*"central" + 0.128*"term" + -0.125*"january" + '
#   '0.122*"remain" + -0.122*"national"'),
#  (3,
#   '0.228*"oil" + -0.197*"financial" + -0.174*"pressure" + 0.172*"projection" + '
#   '-0.161*"bank" + 0.157*"reform" + 0.138*"quarter" + -0.130*"may" + '
#   '-0.129*"remain" + 0.123*"recovery"'),
#  (4,
#   '-0.287*"financial" + 0.211*"term" + 0.206*"remain" + 0.197*"recovery" + '
#   '-0.137*"underlying" + -0.134*"upside" + -0.127*"projection" + 0.126*"low" + '
#   '-0.122*"impact" + -0.121*"credit"')]
# [(0,
#   '0.283*"inflation" + 0.180*"term" + 0.180*"medium" + 0.177*"annual" + '
#   '0.160*"remain" + 0.155*"analysis" + 0.132*"financial" + 0.130*"fiscal" + '
#   '0.128*"continue" + 0.124*"expected"'),
#  (1,
#   '-0.210*"loan" + -0.179*"inflation" + 0.173*"first" + 0.157*"recent" + '
#   '-0.151*"measure" + 0.144*"level" + 0.133*"strong" + 0.126*"wage" + '
#   '0.124*"central" + 0.119*"would"'),
#  (2,
#   '-0.206*"medium" + -0.189*"upside" + -0.184*"strong" + 0.164*"bank" + '
#   '0.148*"operation" + 0.136*"central" + -0.128*"term" + 0.125*"january" + '
#   '-0.122*"remain" + 0.122*"national"'),
#  (3,
#   '-0.228*"oil" + 0.197*"financial" + 0.174*"pressure" + -0.172*"projection" + '
#   '0.161*"bank" + -0.157*"reform" + -0.138*"quarter" + 0.130*"may" + '
#   '0.129*"remain" + -0.123*"recovery"'),
#  (4,
#   '0.287*"financial" + -0.210*"term" + -0.206*"remain" + -0.197*"recovery" + '
#   '0.137*"underlying" + 0.134*"upside" + 0.127*"projection" + -0.126*"low" + '
#   '0.122*"impact" + 0.121*"credit"'),
#  (5,
#   '0.183*"remains" + 0.146*"underlying" + -0.145*"effect" + -0.137*"inflation" '
#   '+ -0.127*"financial" + 0.119*"essential" + 0.119*"liquidity" + '
#   '0.114*"pressure" + 0.112*"ample" + -0.109*"recovery"'),
#  (6,
#   '-0.233*"credit" + -0.215*"medium" + 0.204*"pressure" + 0.197*"inflation" + '
#   '0.187*"recent" + 0.157*"measure" + 0.151*"inflationary" + -0.148*"subdued" '
#   '+ -0.144*"bank" + -0.143*"money"'),
#  (7,
#   '0.342*"projection" + 0.247*"staff" + 0.164*"measure" + -0.155*"financial" + '
#   '0.155*"range" + 0.147*"macroeconomic" + 0.136*"eurosystem" + '
#   '0.130*"operation" + -0.124*"demand" + -0.121*"reform"'),
#  (8,
#   '0.268*"measure" + -0.235*"projection" + 0.149*"environment" + '
#   '0.140*"purchase" + -0.132*"staff" + -0.124*"may" + -0.123*"expected" + '
#   '0.121*"financial" + -0.113*"subdued" + -0.108*"eurosystem"'),
#  (9,
#   '-0.224*"financial" + 0.154*"may" + 0.132*"energy" + 0.130*"food" + '
#   '0.127*"contribute" + 0.124*"recent" + 0.121*"continued" + 0.117*"recovery" '
#   '+ -0.112*"activity" + -0.110*"projection"')]
# [(0,
#   '0.283*"inflation" + 0.180*"term" + 0.180*"medium" + 0.177*"annual" + '
#   '0.160*"remain" + 0.155*"analysis" + 0.132*"financial" + 0.130*"fiscal" + '
#   '0.128*"continue" + 0.124*"expected"'),
#  (1,
#   '-0.210*"loan" + -0.179*"inflation" + 0.173*"first" + 0.157*"recent" + '
#   '-0.151*"measure" + 0.144*"level" + 0.133*"strong" + 0.126*"wage" + '
#   '0.124*"central" + 0.119*"would"'),
#  (2,
#   '-0.206*"medium" + -0.189*"upside" + -0.184*"strong" + 0.164*"bank" + '
#   '0.148*"operation" + 0.136*"central" + -0.128*"term" + 0.125*"january" + '
#   '-0.122*"remain" + 0.122*"national"'),
#  (3,
#   '0.229*"oil" + -0.197*"financial" + -0.174*"pressure" + 0.172*"projection" + '
#   '-0.161*"bank" + 0.157*"reform" + 0.138*"quarter" + -0.130*"may" + '
#   '-0.129*"remain" + 0.123*"recovery"'),
#  (4,
#   '-0.287*"financial" + 0.211*"term" + 0.206*"remain" + 0.197*"recovery" + '
#   '-0.137*"underlying" + -0.134*"upside" + -0.127*"projection" + 0.126*"low" + '
#   '-0.122*"impact" + -0.121*"credit"'),
#  (5,
#   '-0.183*"remains" + -0.146*"underlying" + 0.145*"effect" + 0.137*"inflation" '
#   '+ 0.127*"financial" + -0.119*"essential" + -0.119*"liquidity" + '
#   '-0.114*"pressure" + -0.112*"ample" + 0.109*"recovery"'),
#  (6,
#   '0.233*"credit" + 0.215*"medium" + -0.204*"pressure" + -0.197*"inflation" + '
#   '-0.187*"recent" + -0.157*"measure" + -0.151*"inflationary" + '
#   '0.148*"subdued" + 0.144*"bank" + 0.143*"money"'),
#  (7,
#   '0.342*"projection" + 0.247*"staff" + 0.164*"measure" + -0.155*"financial" + '
#   '0.155*"range" + 0.147*"macroeconomic" + 0.136*"eurosystem" + '
#   '0.130*"operation" + -0.124*"demand" + -0.122*"reform"'),
#  (8,
#   '0.268*"measure" + -0.234*"projection" + 0.149*"environment" + '
#   '0.140*"purchase" + -0.133*"staff" + -0.124*"may" + -0.123*"expected" + '
#   '0.121*"financial" + -0.113*"subdued" + -0.108*"eurosystem"'),
#  (9,
#   '-0.224*"financial" + 0.154*"may" + 0.132*"energy" + 0.130*"food" + '
#   '0.127*"contribute" + 0.124*"recent" + 0.121*"continued" + 0.117*"recovery" '
#   '+ -0.112*"activity" + -0.110*"projection"'),
#  (10,
#   '0.205*"projection" + -0.202*"operation" + -0.156*"month" + 0.150*"escb" + '
#   '-0.144*"economy" + -0.141*"period" + -0.140*"refinancing" + 0.139*"staff" + '
#   '0.135*"analysis" + 0.126*"central"'),
#  (11,
#   '0.199*"level" + -0.176*"financial" + 0.157*"activity" + 0.143*"inflation" + '
#   '0.131*"january" + 0.126*"continue" + -0.124*"moderate" + -0.117*"gdp" + '
#   '-0.116*"month" + -0.116*"uncertainty"'),
#  (12,
#   '-0.202*"recent" + -0.192*"financial" + -0.192*"may" + -0.163*"volatility" + '
#   '0.161*"level" + 0.158*"effect" + -0.142*"credit" + 0.140*"wage" + '
#   '-0.129*"data" + 0.124*"moderate"'),
#  (13,
#   '0.301*"december" + 0.277*"january" + -0.211*"june" + 0.166*"november" + '
#   '-0.163*"july" + -0.128*"quarter" + -0.126*"recent" + -0.121*"may" + '
#   '0.120*"medium" + 0.117*"term"'),
#  (14,
#   '0.209*"inflation" + -0.157*"quarter" + -0.152*"activity" + 0.138*"medium" + '
#   '-0.136*"low" + 0.125*"still" + 0.124*"mediumterm" + -0.122*"january" + '
#   '-0.120*"ongoing" + -0.120*"latest"'),
#  (15,
#   '0.145*"quarter" + -0.138*"month" + -0.135*"key" + 0.135*"september" + '
#   '0.135*"july" + 0.133*"continue" + 0.128*"operation" + -0.119*"inflation" + '
#   '0.118*"august" + 0.117*"remain"'),
#  (16,
#   '-0.245*"march" + 0.195*"inflation" + 0.193*"september" + 0.161*"october" + '
#   '-0.141*"april" + -0.135*"domestic" + -0.134*"economy" + 0.128*"august" + '
#   '-0.121*"looking" + -0.117*"february"'),
#  (17,
#   '-0.205*"oil" + -0.142*"measure" + 0.134*"recovery" + -0.131*"need" + '
#   '0.129*"condition" + -0.129*"remain" + 0.122*"operation" + -0.117*"activity" '
#   '+ -0.116*"quarter" + -0.113*"november"'),
#  (18,
#   '-0.143*"level" + -0.140*"year" + 0.123*"information" + 0.120*"remain" + '
#   '0.119*"effect" + 0.116*"first" + -0.115*"momentum" + 0.113*"changeover" + '
#   '-0.110*"private" + 0.103*"since"'),
#  (19,
#   '-0.173*"activity" + -0.166*"january" + -0.156*"recovery" + -0.143*"annual" '
#   '+ 0.135*"domestic" + -0.131*"year" + -0.127*"expected" + 0.123*"economy" + '
#   '0.116*"oil" + 0.115*"operation"')]
# [(0,
#   '-0.283*"inflation" + -0.180*"term" + -0.180*"medium" + -0.177*"annual" + '
#   '-0.160*"remain" + -0.155*"analysis" + -0.132*"financial" + -0.130*"fiscal" '
#   '+ -0.128*"continue" + -0.124*"expected"'),
#  (1,
#   '0.210*"loan" + 0.179*"inflation" + -0.173*"first" + -0.157*"recent" + '
#   '0.151*"measure" + -0.144*"level" + -0.133*"strong" + -0.126*"wage" + '
#   '-0.124*"central" + -0.119*"would"'),
#  (2,
#   '-0.206*"medium" + -0.189*"upside" + -0.184*"strong" + 0.164*"bank" + '
#   '0.148*"operation" + 0.136*"central" + -0.128*"term" + 0.125*"january" + '
#   '-0.122*"remain" + 0.122*"national"'),
#  (3,
#   '0.229*"oil" + -0.197*"financial" + -0.174*"pressure" + 0.172*"projection" + '
#   '-0.161*"bank" + 0.157*"reform" + 0.138*"quarter" + -0.130*"may" + '
#   '-0.129*"remain" + 0.123*"recovery"'),
#  (4,
#   '-0.287*"financial" + 0.211*"term" + 0.206*"remain" + 0.197*"recovery" + '
#   '-0.137*"underlying" + -0.134*"upside" + -0.127*"projection" + 0.126*"low" + '
#   '-0.122*"impact" + -0.121*"credit"'),
#  (5,
#   '-0.183*"remains" + -0.146*"underlying" + 0.145*"effect" + 0.137*"inflation" '
#   '+ 0.127*"financial" + -0.119*"essential" + -0.119*"liquidity" + '
#   '-0.114*"pressure" + -0.112*"ample" + 0.109*"recovery"'),
#  (6,
#   '-0.233*"credit" + -0.215*"medium" + 0.204*"pressure" + 0.197*"inflation" + '
#   '0.187*"recent" + 0.157*"measure" + 0.151*"inflationary" + -0.148*"subdued" '
#   '+ -0.144*"bank" + -0.143*"money"'),
#  (7,
#   '0.342*"projection" + 0.247*"staff" + 0.164*"measure" + -0.156*"financial" + '
#   '0.155*"range" + 0.147*"macroeconomic" + 0.136*"eurosystem" + '
#   '0.130*"operation" + -0.124*"demand" + -0.121*"reform"'),
#  (8,
#   '0.268*"measure" + -0.235*"projection" + 0.149*"environment" + '
#   '0.140*"purchase" + -0.133*"staff" + -0.124*"may" + -0.123*"expected" + '
#   '0.121*"financial" + -0.113*"subdued" + -0.108*"eurosystem"'),
#  (9,
#   '0.224*"financial" + -0.154*"may" + -0.132*"energy" + -0.130*"food" + '
#   '-0.127*"contribute" + -0.124*"recent" + -0.121*"continued" + '
#   '-0.117*"recovery" + 0.112*"activity" + 0.110*"projection"'),
#  (10,
#   '-0.205*"projection" + 0.202*"operation" + 0.156*"month" + -0.150*"escb" + '
#   '0.144*"economy" + 0.141*"period" + 0.140*"refinancing" + -0.139*"staff" + '
#   '-0.135*"analysis" + -0.126*"central"'),
#  (11,
#   '0.199*"level" + -0.176*"financial" + 0.157*"activity" + 0.143*"inflation" + '
#   '0.131*"january" + 0.125*"continue" + -0.124*"moderate" + -0.116*"gdp" + '
#   '-0.116*"month" + -0.116*"uncertainty"'),
#  (12,
#   '0.202*"recent" + 0.192*"financial" + 0.192*"may" + 0.163*"volatility" + '
#   '-0.161*"level" + -0.158*"effect" + 0.142*"credit" + -0.140*"wage" + '
#   '0.128*"data" + -0.124*"moderate"'),
#  (13,
#   '-0.301*"december" + -0.277*"january" + 0.211*"june" + -0.166*"november" + '
#   '0.163*"july" + 0.128*"quarter" + 0.126*"recent" + 0.121*"may" + '
#   '-0.120*"medium" + -0.117*"term"'),
#  (14,
#   '-0.209*"inflation" + 0.157*"quarter" + 0.152*"activity" + -0.138*"medium" + '
#   '0.136*"low" + -0.125*"still" + -0.124*"mediumterm" + 0.122*"january" + '
#   '0.120*"ongoing" + 0.119*"latest"'),
#  (15,
#   '-0.145*"quarter" + 0.138*"month" + 0.136*"key" + -0.135*"september" + '
#   '-0.135*"july" + -0.133*"continue" + -0.128*"operation" + 0.119*"inflation" '
#   '+ -0.118*"august" + -0.116*"remain"'),
#  (16,
#   '-0.245*"march" + 0.195*"inflation" + 0.193*"september" + 0.160*"october" + '
#   '-0.141*"april" + -0.135*"domestic" + -0.134*"economy" + 0.127*"august" + '
#   '-0.120*"looking" + -0.117*"february"'),
#  (17,
#   '0.205*"oil" + 0.142*"measure" + -0.135*"recovery" + 0.131*"need" + '
#   '-0.129*"condition" + 0.129*"remain" + -0.122*"operation" + 0.117*"activity" '
#   '+ 0.116*"quarter" + 0.115*"november"'),
#  (18,
#   '0.142*"level" + 0.139*"year" + -0.123*"information" + -0.120*"remain" + '
#   '-0.119*"effect" + -0.116*"first" + 0.115*"momentum" + -0.113*"changeover" + '
#   '0.111*"private" + -0.102*"since"'),
#  (19,
#   '0.173*"activity" + 0.166*"january" + 0.156*"recovery" + 0.143*"annual" + '
#   '-0.134*"domestic" + 0.132*"year" + 0.126*"expected" + -0.123*"economy" + '
#   '-0.116*"oil" + -0.115*"operation"'),
#  (20,
#   '0.241*"year" + 0.218*"bank" + 0.213*"country" + -0.186*"strategy" + '
#   '-0.173*"economy" + 0.142*"eurosystem" + 0.140*"activity" + -0.138*"january" '
#   '+ 0.126*"central" + 0.126*"support"'),
#  (21,
#   '0.192*"june" + -0.125*"sector" + 0.125*"expect" + 0.124*"may" + '
#   '-0.123*"reference" + -0.122*"value" + 0.119*"facility" + -0.116*"strategy" '
#   '+ -0.115*"activity" + -0.112*"account"'),
#  (22,
#   '-0.185*"oil" + -0.157*"high" + -0.155*"expected" + -0.133*"remains" + '
#   '-0.128*"wage" + 0.120*"volatility" + 0.115*"decision" + 0.113*"medium" + '
#   '0.110*"assessment" + 0.109*"reform"'),
#  (23,
#   '0.203*"oil" + -0.167*"level" + 0.160*"particular" + 0.154*"money" + '
#   '0.152*"term" + -0.145*"sector" + 0.140*"medium" + -0.130*"economy" + '
#   '0.120*"demand" + 0.116*"higher"'),
#  (24,
#   '-0.190*"term" + -0.187*"exchange" + 0.148*"country" + -0.144*"medium" + '
#   '-0.139*"well" + 0.130*"first" + 0.128*"new" + 0.122*"fiscal" + '
#   '-0.119*"outlook" + -0.110*"financial"'),
#  (25,
#   '-0.135*"september" + 0.128*"activity" + 0.127*"december" + -0.127*"regard" '
#   '+ 0.125*"effect" + -0.125*"country" + 0.122*"year" + 0.122*"assessment" + '
#   '0.114*"impact" + -0.110*"current"'),
#  (26,
#   '-0.196*"banknote" + 0.128*"oil" + -0.127*"reform" + 0.115*"trend" + '
#   '-0.114*"information" + 0.113*"balance" + 0.111*"decision" + -0.109*"recent" '
#   '+ 0.107*"quarter" + 0.107*"reference"'),
#  (27,
#   '-0.207*"recent" + 0.182*"regard" + 0.169*"quarter" + -0.147*"remain" + '
#   '-0.127*"oil" + -0.122*"impact" + 0.118*"underlying" + -0.110*"january" + '
#   '0.109*"structural" + 0.107*"side"'),
#  (28,
#   '0.204*"first" + -0.177*"remain" + 0.170*"may" + 0.144*"quarter" + '
#   '0.141*"activity" + -0.131*"operation" + 0.112*"information" + '
#   '0.108*"projection" + -0.106*"inflation" + -0.104*"strong"'),
#  (29,
#   '-0.303*"year" + 0.181*"fiscal" + 0.178*"activity" + 0.153*"pressure" + '
#   '-0.146*"recent" + -0.132*"february" + 0.130*"would" + -0.126*"underlying" + '
#   '-0.118*"ahead" + -0.114*"medium"'),
#  (30,
#   '0.195*"continue" + 0.178*"inflation" + 0.142*"financial" + 0.142*"first" + '
#   '-0.117*"remain" + 0.112*"second" + -0.110*"data" + -0.110*"overall" + '
#   '-0.109*"recent" + 0.109*"recovery"'),
#  (31,
#   '0.207*"quarter" + -0.188*"information" + 0.174*"country" + '
#   '-0.164*"particular" + 0.138*"inflation" + -0.134*"need" + -0.131*"july" + '
#   '-0.112*"sector" + -0.106*"june" + -0.100*"potential"'),
#  (32,
#   '-0.205*"decision" + 0.128*"available" + -0.122*"programme" + 0.121*"strong" '
#   '+ 0.118*"oil" + 0.112*"fiscal" + -0.111*"point" + -0.109*"particular" + '
#   '0.108*"bank" + -0.108*"remain"'),
#  (33,
#   '0.203*"continued" + -0.158*"march" + -0.140*"country" + 0.135*"june" + '
#   '0.135*"point" + -0.130*"remains" + -0.120*"data" + 0.116*"strong" + '
#   '-0.116*"level" + -0.115*"continue"'),
#  (34,
#   '-0.147*"european" + -0.143*"april" + -0.132*"level" + 0.119*"december" + '
#   '-0.118*"account" + -0.117*"shortterm" + -0.114*"would" + '
#   '0.112*"consolidation" + -0.109*"continued" + -0.104*"union"'),
#  (35,
#   '-0.156*"country" + 0.154*"would" + 0.149*"banknote" + -0.149*"august" + '
#   '0.125*"day" + -0.122*"demand" + -0.117*"reform" + 0.114*"therefore" + '
#   '-0.110*"month" + 0.109*"remains"'),
#  (36,
#   '0.174*"expected" + 0.163*"recent" + 0.148*"first" + -0.142*"oil" + '
#   '-0.118*"hicp" + 0.114*"outlook" + -0.113*"recovery" + -0.112*"upward" + '
#   '0.108*"particular" + -0.105*"february"'),
#  (37,
#   '0.169*"recent" + -0.162*"impact" + 0.146*"expansion" + 0.133*"current" + '
#   '-0.126*"first" + 0.122*"shortterm" + -0.118*"employment" + 0.118*"june" + '
#   '0.112*"continued" + -0.108*"march"'),
#  (38,
#   '0.216*"quarter" + -0.202*"time" + 0.164*"july" + 0.139*"impact" + '
#   '0.135*"expected" + 0.129*"continue" + 0.123*"available" + 0.122*"data" + '
#   '-0.118*"first" + -0.115*"value"'),
#  (39,
#   '0.188*"country" + 0.157*"line" + -0.150*"domestic" + -0.145*"demand" + '
#   '-0.135*"banknote" + 0.125*"oil" + 0.109*"recent" + 0.108*"would" + '
#   '0.106*"assessment" + 0.102*"period"'),
#  (40,
#   '-0.167*"support" + 0.159*"july" + -0.157*"moderate" + 0.152*"first" + '
#   '-0.150*"level" + 0.132*"outlook" + -0.126*"current" + -0.117*"reference" + '
#   '-0.117*"expectation" + 0.116*"country"'),
#  (41,
#   '-0.175*"inflation" + -0.131*"support" + 0.127*"particularly" + '
#   '0.122*"continue" + -0.106*"remain" + 0.105*"ongoing" + 0.105*"oil" + '
#   '-0.102*"treaty" + 0.100*"high" + 0.100*"line"'),
#  (42,
#   '0.136*"outlook" + -0.121*"quarter" + 0.118*"mainly" + -0.116*"course" + '
#   '-0.106*"past" + 0.103*"support" + -0.100*"private" + 0.100*"operation" + '
#   '-0.092*"could" + 0.092*"subdued"'),
#  (43,
#   '-0.233*"remains" + 0.196*"overall" + -0.153*"european" + 0.130*"time" + '
#   '-0.121*"outlook" + 0.116*"confidence" + -0.112*"regard" + 0.110*"march" + '
#   '0.099*"monitoring" + -0.097*"supporting"'),
#  (44,
#   '-0.175*"time" + 0.145*"energy" + -0.139*"country" + 0.135*"remain" + '
#   '0.121*"high" + -0.118*"money" + 0.114*"available" + -0.113*"trend" + '
#   '-0.104*"wage" + -0.103*"asset"'),
#  (45,
#   '0.161*"term" + -0.138*"particular" + -0.135*"low" + 0.134*"support" + '
#   '0.119*"oil" + -0.112*"around" + -0.111*"reflecting" + -0.109*"half" + '
#   '-0.108*"loan" + -0.108*"mediumterm"'),
#  (46,
#   '0.149*"quarter" + -0.139*"remain" + -0.139*"month" + -0.132*"april" + '
#   '0.130*"would" + -0.118*"implementation" + -0.111*"point" + '
#   '0.109*"inflation" + 0.107*"available" + 0.105*"july"'),
#  (47,
#   '-0.177*"would" + 0.164*"outlook" + -0.149*"condition" + 0.145*"pressure" + '
#   '0.141*"purchase" + 0.115*"available" + 0.111*"information" + '
#   '-0.104*"sector" + -0.104*"service" + 0.103*"banknote"'),
#  (48,
#   '-0.224*"continued" + -0.143*"august" + -0.128*"thus" + 0.126*"april" + '
#   '-0.115*"july" + 0.112*"eurosystem" + 0.111*"overall" + -0.109*"range" + '
#   '0.105*"looking" + -0.098*"day"'),
#  (49,
#   '-0.140*"economy" + -0.131*"overall" + 0.126*"reform" + -0.123*"factor" + '
#   '0.121*"information" + 0.118*"current" + 0.116*"continued" + 0.113*"time" + '
#   '0.110*"term" + 0.108*"decline"')]
# [(0,
#   '-0.283*"inflation" + -0.180*"term" + -0.180*"medium" + -0.177*"annual" + '
#   '-0.160*"remain" + -0.155*"analysis" + -0.132*"financial" + -0.130*"fiscal" '
#   '+ -0.128*"continue" + -0.124*"expected"'),
#  (1,
#   '-0.210*"loan" + -0.179*"inflation" + 0.173*"first" + 0.157*"recent" + '
#   '-0.151*"measure" + 0.144*"level" + 0.133*"strong" + 0.126*"wage" + '
#   '0.124*"central" + 0.119*"would"'),
#  (2,
#   '0.206*"medium" + 0.189*"upside" + 0.184*"strong" + -0.164*"bank" + '
#   '-0.148*"operation" + -0.136*"central" + 0.128*"term" + -0.125*"january" + '
#   '0.122*"remain" + -0.122*"national"'),
#  (3,
#   '0.229*"oil" + -0.197*"financial" + -0.174*"pressure" + 0.172*"projection" + '
#   '-0.161*"bank" + 0.157*"reform" + 0.138*"quarter" + -0.130*"may" + '
#   '-0.129*"remain" + 0.123*"recovery"'),
#  (4,
#   '-0.287*"financial" + 0.211*"term" + 0.206*"remain" + 0.197*"recovery" + '
#   '-0.137*"underlying" + -0.134*"upside" + -0.127*"projection" + 0.126*"low" + '
#   '-0.122*"impact" + -0.121*"credit"'),
#  (5,
#   '0.183*"remains" + 0.146*"underlying" + -0.145*"effect" + -0.137*"inflation" '
#   '+ -0.127*"financial" + 0.119*"essential" + 0.119*"liquidity" + '
#   '0.114*"pressure" + 0.112*"ample" + -0.109*"recovery"'),
#  (6,
#   '-0.233*"credit" + -0.215*"medium" + 0.204*"pressure" + 0.197*"inflation" + '
#   '0.187*"recent" + 0.157*"measure" + 0.151*"inflationary" + -0.148*"subdued" '
#   '+ -0.144*"bank" + -0.143*"money"'),
#  (7,
#   '-0.342*"projection" + -0.247*"staff" + -0.164*"measure" + 0.156*"financial" '
#   '+ -0.155*"range" + -0.147*"macroeconomic" + -0.136*"eurosystem" + '
#   '-0.130*"operation" + 0.124*"demand" + 0.121*"reform"'),
#  (8,
#   '-0.268*"measure" + 0.235*"projection" + -0.149*"environment" + '
#   '-0.140*"purchase" + 0.133*"staff" + 0.124*"may" + 0.123*"expected" + '
#   '-0.121*"financial" + 0.113*"subdued" + 0.108*"eurosystem"'),
#  (9,
#   '0.224*"financial" + -0.154*"may" + -0.132*"energy" + -0.130*"food" + '
#   '-0.127*"contribute" + -0.124*"recent" + -0.121*"continued" + '
#   '-0.117*"recovery" + 0.112*"activity" + 0.110*"projection"'),
#  (10,
#   '0.205*"projection" + -0.202*"operation" + -0.156*"month" + 0.150*"escb" + '
#   '-0.144*"economy" + -0.141*"period" + -0.140*"refinancing" + 0.139*"staff" + '
#   '0.135*"analysis" + 0.126*"central"'),
#  (11,
#   '-0.199*"level" + 0.176*"financial" + -0.157*"activity" + -0.143*"inflation" '
#   '+ -0.131*"january" + -0.125*"continue" + 0.124*"moderate" + 0.116*"gdp" + '
#   '0.116*"month" + 0.116*"uncertainty"'),
#  (12,
#   '-0.202*"recent" + -0.192*"financial" + -0.192*"may" + -0.163*"volatility" + '
#   '0.161*"level" + 0.158*"effect" + -0.142*"credit" + 0.140*"wage" + '
#   '-0.128*"data" + 0.124*"moderate"'),
#  (13,
#   '-0.301*"december" + -0.277*"january" + 0.211*"june" + -0.166*"november" + '
#   '0.163*"july" + 0.128*"quarter" + 0.126*"recent" + 0.121*"may" + '
#   '-0.120*"medium" + -0.117*"term"'),
#  (14,
#   '0.209*"inflation" + -0.157*"quarter" + -0.152*"activity" + 0.138*"medium" + '
#   '-0.136*"low" + 0.125*"still" + 0.124*"mediumterm" + -0.122*"january" + '
#   '-0.120*"ongoing" + -0.119*"latest"'),
#  (15,
#   '-0.145*"quarter" + 0.138*"month" + 0.136*"key" + -0.135*"september" + '
#   '-0.135*"july" + -0.133*"continue" + -0.128*"operation" + 0.119*"inflation" '
#   '+ -0.118*"august" + -0.116*"remain"'),
#  (16,
#   '0.245*"march" + -0.195*"inflation" + -0.193*"september" + -0.160*"october" '
#   '+ 0.141*"april" + 0.135*"domestic" + 0.134*"economy" + -0.127*"august" + '
#   '0.120*"looking" + 0.117*"february"'),
#  (17,
#   '-0.205*"oil" + -0.142*"measure" + 0.135*"recovery" + -0.131*"need" + '
#   '0.130*"condition" + -0.129*"remain" + 0.122*"operation" + -0.117*"activity" '
#   '+ -0.116*"quarter" + -0.115*"november"'),
#  (18,
#   '0.142*"level" + 0.139*"year" + -0.123*"information" + -0.120*"remain" + '
#   '-0.119*"effect" + -0.116*"first" + 0.115*"momentum" + -0.113*"changeover" + '
#   '0.111*"private" + -0.102*"since"'),
#  (19,
#   '0.173*"activity" + 0.165*"january" + 0.157*"recovery" + 0.143*"annual" + '
#   '-0.135*"domestic" + 0.132*"year" + 0.126*"expected" + -0.123*"economy" + '
#   '-0.116*"oil" + -0.115*"operation"'),
#  (20,
#   '-0.241*"year" + -0.218*"bank" + -0.214*"country" + 0.186*"strategy" + '
#   '0.173*"economy" + -0.142*"eurosystem" + -0.140*"activity" + 0.138*"january" '
#   '+ -0.126*"central" + -0.126*"support"'),
#  (21,
#   '-0.192*"june" + 0.125*"sector" + -0.125*"expect" + -0.124*"may" + '
#   '0.123*"reference" + 0.122*"value" + -0.120*"facility" + 0.116*"strategy" + '
#   '0.114*"activity" + 0.112*"account"'),
#  (22,
#   '0.185*"oil" + 0.157*"high" + 0.155*"expected" + 0.133*"remains" + '
#   '0.128*"wage" + -0.120*"volatility" + -0.115*"decision" + -0.113*"medium" + '
#   '-0.110*"assessment" + -0.109*"reform"'),
#  (23,
#   '0.203*"oil" + -0.167*"level" + 0.160*"particular" + 0.154*"money" + '
#   '0.152*"term" + -0.145*"sector" + 0.140*"medium" + -0.130*"economy" + '
#   '0.120*"demand" + 0.116*"higher"'),
#  (24,
#   '-0.190*"term" + -0.186*"exchange" + 0.148*"country" + -0.144*"medium" + '
#   '-0.139*"well" + 0.130*"first" + 0.128*"new" + 0.122*"fiscal" + '
#   '-0.119*"outlook" + -0.110*"financial"'),
#  (25,
#   '-0.135*"september" + 0.128*"activity" + 0.127*"december" + -0.127*"regard" '
#   '+ 0.125*"effect" + -0.125*"country" + 0.122*"year" + 0.122*"assessment" + '
#   '0.114*"impact" + -0.110*"current"'),
#  (26,
#   '0.196*"banknote" + -0.128*"oil" + 0.127*"reform" + -0.115*"trend" + '
#   '0.114*"information" + -0.113*"balance" + -0.110*"decision" + 0.109*"recent" '
#   '+ -0.107*"quarter" + -0.107*"reference"'),
#  (27,
#   '-0.207*"recent" + 0.182*"regard" + 0.169*"quarter" + -0.147*"remain" + '
#   '-0.127*"oil" + -0.121*"impact" + 0.118*"underlying" + -0.110*"january" + '
#   '0.109*"structural" + 0.107*"side"'),
#  (28,
#   '-0.205*"first" + 0.178*"remain" + -0.170*"may" + -0.144*"quarter" + '
#   '-0.142*"activity" + 0.131*"operation" + -0.112*"information" + '
#   '-0.108*"projection" + 0.106*"inflation" + 0.105*"strong"'),
#  (29,
#   '0.302*"year" + -0.181*"fiscal" + -0.178*"activity" + -0.153*"pressure" + '
#   '0.146*"recent" + 0.132*"february" + -0.130*"would" + 0.127*"underlying" + '
#   '0.118*"ahead" + 0.114*"medium"'),
#  (30,
#   '0.195*"continue" + 0.178*"inflation" + 0.142*"financial" + 0.142*"first" + '
#   '-0.117*"remain" + 0.112*"second" + -0.110*"data" + -0.109*"recent" + '
#   '-0.109*"overall" + 0.109*"recovery"'),
#  (31,
#   '0.206*"quarter" + -0.187*"information" + 0.175*"country" + '
#   '-0.165*"particular" + 0.138*"inflation" + -0.134*"need" + -0.130*"july" + '
#   '-0.112*"sector" + -0.106*"june" + -0.101*"potential"'),
#  (32,
#   '-0.204*"decision" + 0.129*"available" + -0.122*"programme" + 0.120*"strong" '
#   '+ 0.118*"oil" + 0.111*"fiscal" + -0.111*"point" + -0.108*"remain" + '
#   '-0.108*"particular" + 0.108*"bank"'),
#  (33,
#   '0.204*"continued" + -0.158*"march" + -0.141*"country" + 0.135*"june" + '
#   '0.133*"point" + -0.130*"remains" + -0.119*"data" + 0.118*"strong" + '
#   '-0.117*"level" + -0.115*"continue"'),
#  (34,
#   '0.146*"european" + 0.142*"april" + 0.132*"level" + -0.118*"december" + '
#   '0.118*"account" + 0.117*"shortterm" + 0.114*"would" + '
#   '-0.113*"consolidation" + 0.108*"continued" + 0.104*"union"'),
#  (35,
#   '-0.155*"country" + 0.155*"would" + 0.150*"banknote" + -0.149*"august" + '
#   '0.125*"day" + -0.121*"demand" + -0.117*"reform" + 0.115*"therefore" + '
#   '-0.110*"month" + 0.110*"remains"'),
#  (36,
#   '0.174*"expected" + 0.163*"recent" + 0.150*"first" + -0.141*"oil" + '
#   '-0.119*"hicp" + 0.114*"outlook" + -0.113*"upward" + -0.112*"recovery" + '
#   '0.107*"particular" + -0.105*"february"'),
#  (37,
#   '0.170*"recent" + -0.162*"impact" + 0.146*"expansion" + 0.133*"current" + '
#   '-0.126*"first" + 0.122*"shortterm" + -0.118*"employment" + 0.117*"june" + '
#   '0.113*"continued" + -0.109*"march"'),
#  (38,
#   '-0.216*"quarter" + 0.203*"time" + -0.163*"july" + -0.138*"impact" + '
#   '-0.134*"expected" + -0.130*"continue" + -0.124*"data" + -0.124*"available" '
#   '+ 0.117*"first" + 0.115*"value"'),
#  (39,
#   '0.189*"country" + 0.156*"line" + -0.150*"domestic" + -0.143*"demand" + '
#   '-0.136*"banknote" + 0.125*"oil" + 0.109*"recent" + 0.108*"would" + '
#   '0.106*"assessment" + 0.103*"period"'),
#  (40,
#   '0.168*"support" + -0.158*"july" + 0.156*"moderate" + -0.152*"first" + '
#   '0.148*"level" + -0.132*"outlook" + 0.126*"current" + 0.118*"reference" + '
#   '0.117*"expectation" + 0.116*"value"'),
#  (41,
#   '0.175*"inflation" + 0.130*"support" + -0.128*"particularly" + '
#   '-0.123*"continue" + 0.107*"remain" + -0.105*"ongoing" + -0.105*"oil" + '
#   '0.101*"treaty" + -0.100*"high" + -0.100*"line"'),
#  (42,
#   '0.136*"outlook" + -0.121*"quarter" + 0.117*"mainly" + -0.117*"course" + '
#   '-0.107*"past" + 0.103*"support" + -0.101*"private" + 0.100*"operation" + '
#   '0.093*"subdued" + -0.091*"could"'),
#  (43,
#   '0.232*"remains" + -0.195*"overall" + 0.153*"european" + -0.129*"time" + '
#   '0.120*"outlook" + -0.116*"confidence" + 0.112*"regard" + -0.109*"march" + '
#   '-0.100*"monitoring" + 0.097*"supporting"'),
#  (44,
#   '-0.174*"time" + 0.144*"energy" + -0.138*"country" + 0.134*"remain" + '
#   '0.121*"high" + -0.118*"money" + 0.113*"available" + -0.113*"trend" + '
#   '-0.103*"wage" + -0.102*"asset"'),
#  (45,
#   '0.161*"term" + -0.139*"particular" + -0.136*"low" + 0.133*"support" + '
#   '0.121*"oil" + -0.112*"around" + -0.112*"reflecting" + -0.111*"loan" + '
#   '-0.110*"half" + -0.108*"mediumterm"'),
#  (46,
#   '0.147*"quarter" + -0.139*"remain" + -0.138*"month" + -0.132*"april" + '
#   '0.129*"would" + -0.118*"implementation" + -0.110*"point" + '
#   '0.108*"inflation" + 0.107*"available" + 0.106*"july"'),
#  (47,
#   '-0.178*"would" + 0.164*"outlook" + 0.148*"pressure" + -0.147*"condition" + '
#   '0.141*"purchase" + 0.113*"available" + 0.110*"information" + '
#   '-0.104*"service" + -0.102*"impact" + -0.102*"higher"'),
#  (48,
#   '0.224*"continued" + 0.145*"august" + 0.126*"thus" + -0.126*"april" + '
#   '0.115*"july" + -0.112*"eurosystem" + -0.109*"overall" + 0.108*"range" + '
#   '-0.103*"looking" + 0.098*"day"'),
#  (49,
#   '0.141*"economy" + 0.130*"overall" + 0.125*"factor" + -0.124*"reform" + '
#   '-0.121*"information" + -0.118*"continued" + -0.117*"current" + '
#   '-0.113*"time" + -0.111*"term" + 0.107*"country"'),
#  (50,
#   '0.164*"continue" + 0.152*"deficit" + -0.128*"employment" + -0.125*"global" '
#   '+ -0.122*"impact" + -0.106*"may" + 0.103*"implementation" + '
#   '0.103*"expectation" + -0.100*"prospect" + 0.098*"moderate"'),
#  (51,
#   '0.187*"expected" + 0.170*"country" + 0.133*"particular" + 0.131*"global" + '
#   '0.128*"december" + 0.125*"recovery" + -0.122*"october" + -0.116*"unchanged" '
#   '+ -0.114*"continue" + -0.107*"support"'),
#  (52,
#   '-0.166*"level" + -0.151*"assessment" + -0.137*"strong" + 0.127*"purchase" + '
#   '-0.124*"macroeconomic" + -0.117*"order" + 0.106*"positive" + 0.103*"effect" '
#   '+ 0.102*"view" + -0.099*"therefore"'),
#  (53,
#   '0.176*"regard" + -0.157*"need" + -0.154*"continued" + 0.143*"impact" + '
#   '0.129*"expansion" + -0.128*"particular" + 0.115*"would" + 0.103*"past" + '
#   '-0.101*"confidence" + -0.099*"activity"'),
#  (54,
#   '0.161*"strong" + 0.136*"december" + 0.134*"inflation" + 0.126*"month" + '
#   '-0.122*"factor" + -0.114*"remains" + -0.110*"expected" + -0.107*"give" + '
#   '0.104*"particularly" + -0.102*"since"'),
#  (55,
#   '-0.148*"remains" + -0.129*"january" + -0.122*"outlook" + 0.115*"economy" + '
#   '0.115*"recent" + -0.113*"trend" + 0.111*"information" + -0.111*"second" + '
#   '-0.104*"inflation" + -0.104*"activity"'),
#  (56,
#   '0.197*"purchase" + 0.126*"still" + 0.126*"high" + 0.112*"sector" + '
#   '-0.110*"well" + -0.098*"line" + -0.097*"credit" + 0.091*"economy" + '
#   '-0.089*"pact" + 0.089*"continue"'),
#  (57,
#   '-0.120*"decision" + -0.118*"wage" + -0.114*"continue" + 0.110*"new" + '
#   '-0.106*"account" + -0.100*"regard" + 0.100*"end" + 0.097*"assessment" + '
#   '-0.096*"pressure" + 0.095*"supporting"'),
#  (58,
#   '-0.186*"quarter" + -0.164*"decline" + 0.140*"current" + -0.131*"term" + '
#   '0.122*"continue" + 0.121*"consumer" + 0.116*"assessment" + -0.116*"data" + '
#   '-0.115*"recent" + -0.114*"support"'),
#  (59,
#   '-0.142*"data" + 0.139*"country" + 0.121*"financial" + -0.119*"ahead" + '
#   '-0.111*"gdp" + 0.107*"particular" + 0.106*"environment" + 0.106*"operation" '
#   '+ -0.102*"continue" + -0.101*"expectation"'),
#  (60,
#   '0.166*"would" + -0.127*"month" + 0.124*"line" + 0.124*"effect" + '
#   '0.119*"condition" + -0.114*"june" + -0.113*"oil" + -0.106*"higher" + '
#   '0.099*"august" + 0.095*"prospect"'),
#  (61,
#   '0.133*"continue" + -0.118*"point" + 0.116*"information" + '
#   '-0.114*"continues" + 0.112*"december" + -0.108*"european" + 0.102*"effect" '
#   '+ -0.102*"assessment" + 0.100*"level" + 0.100*"remain"'),
#  (62,
#   '0.136*"recovery" + -0.118*"ongoing" + -0.118*"improvement" + '
#   '-0.115*"commodity" + 0.109*"september" + -0.108*"unemployment" + '
#   '0.102*"economy" + -0.101*"pressure" + 0.101*"condition" + -0.099*"balance"'),
#  (63,
#   '-0.134*"activity" + -0.123*"outlook" + -0.122*"inflation" + '
#   '-0.114*"account" + -0.112*"still" + -0.108*"march" + 0.107*"well" + '
#   '0.103*"line" + 0.098*"may" + -0.098*"dynamic"'),
#  (64,
#   '-0.130*"reform" + 0.122*"hicp" + -0.118*"outlook" + 0.115*"slightly" + '
#   '-0.114*"key" + 0.108*"march" + 0.106*"year" + 0.105*"fiscal" + '
#   '-0.104*"annual" + 0.104*"service"'),
#  (65,
#   '-0.143*"may" + 0.124*"overall" + 0.124*"february" + -0.122*"state" + '
#   '0.116*"shortterm" + 0.113*"quarter" + 0.111*"banknote" + -0.101*"member" + '
#   '0.097*"factor" + -0.095*"european"'),
#  (66,
#   '-0.134*"however" + 0.129*"broadly" + -0.117*"measure" + -0.112*"low" + '
#   '0.111*"may" + 0.111*"activity" + -0.103*"expected" + -0.101*"confidence" + '
#   '0.098*"remained" + 0.096*"related"'),
#  (67,
#   '0.155*"regard" + -0.141*"adjustment" + 0.123*"continue" + 0.103*"taken" + '
#   '-0.102*"may" + -0.095*"country" + -0.092*"quarter" + 0.092*"somewhat" + '
#   '0.091*"treaty" + -0.088*"september"'),
#  (68,
#   '0.226*"still" + 0.153*"uncertainty" + 0.131*"economy" + 0.121*"range" + '
#   '-0.119*"fiscal" + 0.119*"measure" + -0.106*"decline" + 0.105*"remained" + '
#   '-0.097*"government" + -0.097*"due"'),
#  (69,
#   '-0.156*"continue" + 0.128*"high" + -0.121*"april" + 0.116*"remain" + '
#   '0.115*"purchase" + 0.107*"february" + 0.107*"well" + -0.106*"november" + '
#   '-0.099*"need" + 0.098*"mediumterm"'),
#  (70,
#   '-0.142*"outlook" + -0.139*"fiscal" + -0.125*"current" + -0.120*"decline" + '
#   '-0.118*"reflects" + -0.114*"march" + 0.101*"time" + -0.101*"high" + '
#   '0.096*"ensure" + -0.092*"towards"'),
#  (71,
#   '0.165*"broadly" + -0.139*"reflecting" + -0.136*"improvement" + '
#   '0.114*"reform" + 0.114*"government" + 0.111*"ahead" + -0.108*"global" + '
#   '0.108*"therefore" + 0.107*"activity" + -0.102*"effect"'),
#  (72,
#   '0.152*"higher" + -0.146*"range" + 0.136*"treaty" + -0.129*"opportunity" + '
#   '0.118*"still" + 0.112*"support" + 0.108*"state" + -0.105*"balance" + '
#   '-0.102*"would" + -0.095*"unchanged"'),
#  (73,
#   '-0.144*"may" + -0.134*"period" + 0.134*"level" + -0.113*"line" + '
#   '-0.112*"time" + -0.111*"ensure" + 0.109*"adjustment" + -0.109*"current" + '
#   '-0.100*"data" + 0.094*"still"'),
#  (74,
#   '0.152*"moderate" + -0.144*"european" + 0.123*"quarter" + 0.113*"somewhat" + '
#   '-0.112*"contribute" + -0.108*"stance" + 0.107*"consistent" + '
#   '-0.104*"continued" + 0.102*"hicp" + -0.099*"latest"'),
#  (75,
#   '-0.144*"decline" + -0.132*"progress" + 0.125*"remained" + 0.109*"unchanged" '
#   '+ -0.107*"environment" + 0.104*"recovery" + 0.103*"programme" + '
#   '0.103*"several" + -0.099*"well" + 0.098*"uncertainty"'),
#  (76,
#   '0.164*"fiscal" + -0.151*"continued" + -0.143*"available" + -0.142*"remains" '
#   '+ -0.125*"high" + -0.115*"loan" + 0.112*"expected" + 0.109*"economy" + '
#   '-0.101*"expectation" + -0.100*"hicp"'),
#  (77,
#   '0.179*"labour" + -0.154*"positive" + -0.148*"particular" + 0.116*"sector" + '
#   '-0.107*"slightly" + -0.106*"coming" + -0.105*"range" + 0.104*"context" + '
#   '0.101*"service" + -0.094*"reform"'),
#  (78,
#   '0.133*"energy" + -0.127*"range" + 0.126*"employment" + 0.108*"particular" + '
#   '0.104*"month" + -0.102*"rise" + 0.102*"continue" + -0.101*"effort" + '
#   '0.100*"adjustment" + -0.093*"improve"'),
#  (79,
#   '-0.117*"support" + -0.114*"april" + -0.112*"information" + '
#   '-0.109*"confirmed" + -0.108*"uncertainty" + 0.106*"decision" + '
#   '-0.103*"upward" + 0.102*"credit" + 0.099*"food" + 0.099*"low"'),
#  (80,
#   '-0.128*"employment" + -0.124*"let" + 0.114*"could" + -0.104*"current" + '
#   '0.099*"impact" + -0.092*"august" + 0.091*"part" + -0.090*"looking" + '
#   '0.085*"condition" + 0.085*"month"'),
#  (81,
#   '-0.173*"unchanged" + -0.148*"however" + 0.115*"december" + '
#   '0.115*"expansion" + -0.113*"higher" + -0.110*"likely" + -0.109*"november" + '
#   '-0.098*"june" + 0.098*"sector" + 0.097*"recent"'),
#  (82,
#   '0.126*"previous" + 0.126*"increased" + -0.119*"balance" + -0.113*"bank" + '
#   '0.109*"line" + -0.104*"remained" + 0.102*"annual" + 0.101*"appropriate" + '
#   '0.099*"labour" + 0.092*"improvement"'),
#  (83,
#   '0.131*"necessary" + 0.113*"current" + 0.112*"however" + -0.110*"essential" '
#   '+ 0.109*"adjustment" + -0.105*"country" + 0.102*"labour" + -0.101*"union" + '
#   '-0.100*"european" + 0.099*"energy"'),
#  (84,
#   '-0.145*"new" + -0.130*"activity" + -0.120*"february" + 0.108*"sector" + '
#   '0.106*"liquidity" + 0.100*"longterm" + 0.099*"bank" + -0.098*"expansion" + '
#   '-0.093*"rise" + 0.089*"reflects"'),
#  (85,
#   '0.123*"broadly" + 0.114*"measure" + 0.106*"confirm" + 0.102*"become" + '
#   '-0.102*"new" + -0.101*"hicp" + -0.100*"global" + 0.100*"lower" + '
#   '-0.099*"may" + 0.097*"favourable"'),
#  (86,
#   '-0.165*"overall" + -0.113*"change" + 0.107*"sector" + 0.105*"new" + '
#   '0.102*"employment" + 0.101*"public" + 0.096*"shortterm" + -0.094*"month" + '
#   '-0.092*"positive" + -0.092*"improve"'),
#  (87,
#   '0.130*"still" + 0.129*"course" + 0.119*"would" + -0.113*"early" + '
#   '-0.102*"pressure" + -0.100*"treaty" + -0.099*"close" + 0.098*"economy" + '
#   '-0.096*"tender" + 0.095*"ongoing"'),
#  (88,
#   '-0.164*"current" + 0.111*"february" + -0.109*"august" + -0.106*"recently" + '
#   '0.104*"need" + -0.104*"continued" + 0.099*"consumer" + 0.091*"stronger" + '
#   '-0.090*"assessment" + 0.090*"fact"'),
#  (89,
#   '-0.157*"moreover" + -0.136*"basis" + 0.123*"energy" + 0.111*"available" + '
#   '-0.107*"improvement" + 0.104*"april" + 0.102*"country" + -0.100*"situation" '
#   '+ -0.099*"context" + 0.094*"fully"'),
#  (90,
#   '-0.153*"public" + 0.113*"january" + -0.111*"second" + -0.100*"outlook" + '
#   '0.100*"measure" + -0.095*"ahead" + -0.094*"confidence" + -0.091*"process" + '
#   '-0.091*"recent" + -0.091*"consistent"'),
#  (91,
#   '0.138*"range" + -0.132*"october" + -0.110*"ongoing" + -0.105*"regard" + '
#   '0.100*"decision" + 0.099*"continue" + 0.096*"need" + 0.096*"supporting" + '
#   '-0.093*"energy" + 0.090*"strong"'),
#  (92,
#   '0.114*"remain" + -0.110*"service" + -0.108*"within" + -0.104*"information" '
#   '+ -0.103*"already" + -0.102*"confirmed" + 0.101*"therefore" + '
#   '0.100*"fiscal" + -0.097*"would" + -0.096*"underlying"'),
#  (93,
#   '-0.120*"let" + -0.103*"objective" + 0.103*"low" + 0.100*"outlook" + '
#   '-0.098*"context" + 0.096*"current" + -0.091*"deficit" + -0.090*"wage" + '
#   '0.086*"level" + 0.084*"first"'),
#  (94,
#   '-0.138*"july" + -0.114*"cost" + 0.108*"particularly" + 0.107*"improvement" '
#   '+ 0.106*"objective" + -0.104*"private" + 0.100*"coming" + 0.093*"june" + '
#   '-0.092*"april" + -0.092*"pace"'),
#  (95,
#   '-0.139*"strengthening" + -0.127*"september" + 0.105*"given" + '
#   '-0.102*"course" + 0.102*"stronger" + 0.101*"remains" + 0.100*"longterm" + '
#   '-0.099*"owing" + -0.095*"ongoing" + -0.094*"labour"'),
#  (96,
#   '0.121*"remains" + -0.113*"labour" + 0.112*"fiscal" + 0.105*"strengthened" + '
#   '0.098*"fully" + 0.097*"february" + -0.096*"due" + -0.095*"strengthen" + '
#   '0.089*"would" + 0.088*"purchase"'),
#  (97,
#   '-0.118*"opportunity" + 0.117*"gradual" + -0.110*"employment" + 0.109*"hicp" '
#   '+ 0.102*"remain" + 0.100*"give" + -0.099*"remaining" + 0.098*"reform" + '
#   '0.098*"strengthening" + -0.092*"support"'),
#  (98,
#   '-0.113*"remained" + 0.107*"sector" + 0.104*"survey" + -0.102*"continues" + '
#   '0.101*"november" + -0.098*"moderation" + 0.098*"level" + -0.096*"mainly" + '
#   '-0.095*"august" + -0.087*"line"'),
#  (99,
#   '0.124*"broadly" + 0.118*"commitment" + -0.113*"consistent" + '
#   '-0.104*"information" + -0.100*"consolidation" + 0.097*"increased" + '
#   '0.096*"high" + -0.093*"european" + 0.092*"forecast" + -0.091*"quarter"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lsi5 = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi5 = coherence_model_lsi5.get_coherence()
print('\nCoherence Score5: ', coherence_lsi5)

# Compute Coherence Score
coherence_model_lsi10 = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi10 = coherence_model_lsi10.get_coherence()
print('\nCoherence Score10: ', coherence_lsi10)

# Compute Coherence Score
coherence_model_lsi20 = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi20 = coherence_model_lsi20.get_coherence()
print('\nCoherence Score20: ', coherence_lsi20)

# Compute Coherence Score
coherence_model_lsi50 = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi50 = coherence_model_lsi50.get_coherence()
print('\nCoherence Score50: ', coherence_lsi50)

# Compute Coherence Score
coherence_model_lsi100 = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi100 = coherence_model_lsi100.get_coherence()
print('\nCoherence Score100: ', coherence_lsi100)


# Compute Coherence Score
coherence_model_lsi5 = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi5 = coherence_model_lsi5.get_coherence()
print('\nCoherence Score5: ', coherence_lsi5)

# Compute Coherence Score
coherence_model_lsi10 = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi10 = coherence_model_lsi10.get_coherence()
print('\nCoherence Score10: ', coherence_lsi10)

# Compute Coherence Score
coherence_model_lsi20 = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi20 = coherence_model_lsi20.get_coherence()
print('\nCoherence Score20: ', coherence_lsi20)

# Compute Coherence Score
coherence_model_lsi50 = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi50 = coherence_model_lsi50.get_coherence()
print('\nCoherence Score50: ', coherence_lsi50)

# Compute Coherence Score
coherence_model_lsi100 = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi100 = coherence_model_lsi100.get_coherence()
print('\nCoherence Score100: ', coherence_lsi100)
# Out:
# Coherence Score5:  0.33282851753563475
#
# Coherence Score10:  0.34415802352928115
#
# Coherence Score20:  0.2964199191499416
#
# Coherence Score50:  0.2696232113077477
#
# Coherence Score100:  0.23662844028604
#
# Coherence Score5:  -0.37045853925561384
#
# Coherence Score10:  -0.613951499448281
#
# Coherence Score20:  -0.5669801066257735
#
# Coherence Score50:  -0.87436912439999
#
# Coherence Score100:  -0.7753050028796862
