# %% [markdown]
# # load packages

# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess, lemmatize
from gensim.models import CoherenceModel
from gensim.models import LdaModel, LdaMulticore
import gensim.downloader as api
from gensim.models import LsiModel

nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools 
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
#import logging
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
#logging.root.setLevel(level=logging.INFO)
#import warnings
#warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_csv('C:/Users/Kornelius/Desktop/Data 2/nips-papers/papers.csv', header = 0, sep = ';', error_bad_lines=False)
# Drop the columns not needed
df = df.drop(columns=['id', 'event_type', 'pdf_name'], axis=1)

# %%
# Drop a row by condition
df = df[df.abstract != 'Abstract Missing']

# %%
data = df.abstract.values.tolist()

# %% [markdown]
# # Pre-processing (Baseline)

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(data):
    stop_free = " ".join([i for i in data.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(data).split() for data in data]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(16129 unique tokens: ['activity', 'also', 'analysis', 'applied', 'assume']...)

# %%
# less than 10 documents,
id2word = corpora.Dictionary(data)
id2word.filter_extremes(no_below = 50)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# # LSI

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.382*"model" + 0.314*"algorithm" + 0.261*"learning" + 0.236*"method" + '
#   '0.228*"problem" + 0.223*"data" + 0.160*"show" + 0.137*"approach" + '
#   '0.131*"function" + 0.123*"network"')]
# [(0,
#   '0.382*"model" + 0.314*"algorithm" + 0.261*"learning" + 0.236*"method" + '
#   '0.228*"problem" + 0.223*"data" + 0.160*"show" + 0.137*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.732*"model" + 0.435*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.115*"learning" + -0.107*"network" + -0.102*"image" + 0.089*"bound" + '
#   '-0.086*"neural" + 0.080*"method"'),
#  (2,
#   '0.528*"algorithm" + 0.388*"model" + -0.336*"learning" + -0.324*"network" + '
#   '-0.302*"method" + -0.163*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.124*"deep" + -0.122*"neural"'),
#  (3,
#   '0.576*"method" + -0.456*"learning" + -0.356*"network" + -0.285*"algorithm" '
#   '+ 0.247*"data" + 0.122*"matrix" + 0.107*"problem" + -0.099*"deep" + '
#   '-0.098*"neural" + -0.090*"task"'),
#  (4,
#   '-0.601*"network" + 0.570*"learning" + 0.278*"data" + -0.220*"neural" + '
#   '-0.105*"algorithm" + -0.099*"method" + -0.082*"deep" + -0.081*"image" + '
#   '0.077*"task" + 0.075*"approach"')]
# [(0,
#   '0.382*"model" + 0.314*"algorithm" + 0.261*"learning" + 0.236*"method" + '
#   '0.228*"problem" + 0.223*"data" + 0.160*"show" + 0.137*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.732*"model" + 0.435*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.115*"learning" + -0.107*"network" + -0.102*"image" + 0.089*"bound" + '
#   '-0.086*"neural" + 0.080*"method"'),
#  (2,
#   '0.528*"algorithm" + 0.388*"model" + -0.336*"learning" + -0.324*"network" + '
#   '-0.302*"method" + -0.163*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.124*"deep" + -0.122*"neural"'),
#  (3,
#   '-0.576*"method" + 0.456*"learning" + 0.356*"network" + 0.285*"algorithm" + '
#   '-0.247*"data" + -0.122*"matrix" + -0.107*"problem" + 0.099*"deep" + '
#   '0.098*"neural" + 0.090*"task"'),
#  (4,
#   '-0.601*"network" + 0.570*"learning" + 0.278*"data" + -0.220*"neural" + '
#   '-0.105*"algorithm" + -0.099*"method" + -0.083*"deep" + -0.081*"image" + '
#   '0.077*"task" + 0.074*"approach"'),
#  (5,
#   '0.687*"data" + -0.315*"function" + 0.260*"algorithm" + -0.202*"model" + '
#   '-0.200*"problem" + -0.187*"learning" + -0.158*"method" + 0.150*"network" + '
#   '-0.114*"optimization" + 0.110*"feature"'),
#  (6,
#   '-0.506*"image" + 0.326*"data" + 0.289*"function" + -0.264*"algorithm" + '
#   '-0.251*"method" + 0.246*"network" + -0.237*"feature" + -0.226*"object" + '
#   '0.193*"distribution" + 0.128*"bound"'),
#  (7,
#   '-0.471*"method" + 0.435*"problem" + 0.326*"image" + -0.302*"algorithm" + '
#   '-0.229*"learning" + 0.142*"object" + -0.125*"gradient" + -0.124*"inference" '
#   '+ 0.122*"matrix" + -0.116*"network"'),
#  (8,
#   '-0.564*"problem" + 0.537*"function" + 0.218*"image" + 0.201*"feature" + '
#   '-0.182*"matrix" + -0.173*"learning" + 0.164*"distribution" + '
#   '-0.147*"network" + 0.125*"bound" + 0.096*"loss"'),
#  (9,
#   '-0.500*"function" + 0.372*"distribution" + 0.278*"bound" + -0.256*"data" + '
#   '-0.249*"problem" + 0.200*"sample" + 0.192*"matrix" + -0.127*"optimization" '
#   '+ -0.107*"model" + 0.105*"show"')]
# [(0,
#   '0.382*"model" + 0.314*"algorithm" + 0.261*"learning" + 0.236*"method" + '
#   '0.228*"problem" + 0.223*"data" + 0.160*"show" + 0.137*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.732*"model" + 0.435*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.115*"learning" + -0.107*"network" + -0.102*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.080*"method"'),
#  (2,
#   '0.528*"algorithm" + 0.388*"model" + -0.336*"learning" + -0.324*"network" + '
#   '-0.302*"method" + -0.163*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.122*"neural"'),
#  (3,
#   '0.576*"method" + -0.456*"learning" + -0.356*"network" + -0.285*"algorithm" '
#   '+ 0.247*"data" + 0.122*"matrix" + 0.107*"problem" + -0.099*"deep" + '
#   '-0.098*"neural" + -0.090*"task"'),
#  (4,
#   '0.601*"network" + -0.570*"learning" + -0.278*"data" + 0.221*"neural" + '
#   '0.105*"algorithm" + 0.099*"method" + 0.082*"deep" + 0.081*"image" + '
#   '-0.077*"task" + -0.074*"approach"'),
#  (5,
#   '0.687*"data" + -0.316*"function" + 0.260*"algorithm" + -0.202*"model" + '
#   '-0.200*"problem" + -0.188*"learning" + -0.158*"method" + 0.150*"network" + '
#   '-0.114*"optimization" + 0.110*"feature"'),
#  (6,
#   '-0.505*"image" + 0.325*"data" + 0.290*"function" + -0.265*"algorithm" + '
#   '-0.251*"method" + 0.246*"network" + -0.236*"feature" + -0.226*"object" + '
#   '0.194*"distribution" + 0.128*"bound"'),
#  (7,
#   '-0.471*"method" + 0.436*"problem" + 0.327*"image" + -0.302*"algorithm" + '
#   '-0.229*"learning" + 0.142*"object" + -0.125*"gradient" + -0.125*"inference" '
#   '+ 0.121*"matrix" + -0.117*"network"'),
#  (8,
#   '0.566*"problem" + -0.538*"function" + -0.219*"image" + -0.200*"feature" + '
#   '0.181*"matrix" + 0.173*"learning" + -0.164*"distribution" + 0.147*"network" '
#   '+ -0.126*"bound" + -0.097*"loss"'),
#  (9,
#   '-0.501*"function" + 0.371*"distribution" + 0.277*"bound" + -0.255*"data" + '
#   '-0.249*"problem" + 0.199*"sample" + 0.192*"matrix" + -0.130*"optimization" '
#   '+ 0.108*"complexity" + -0.107*"model"'),
#  (10,
#   '-0.458*"feature" + -0.386*"matrix" + 0.358*"distribution" + '
#   '0.283*"approach" + 0.244*"inference" + 0.215*"image" + -0.188*"kernel" + '
#   '0.128*"problem" + -0.126*"model" + -0.104*"sparse"'),
#  (11,
#   '0.414*"feature" + 0.316*"kernel" + 0.304*"approach" + -0.282*"bound" + '
#   '-0.238*"image" + 0.238*"inference" + 0.203*"distribution" + -0.181*"data" + '
#   '-0.160*"loss" + -0.138*"method"'),
#  (12,
#   '-0.293*"graph" + -0.289*"image" + 0.270*"task" + -0.259*"matrix" + '
#   '-0.225*"distribution" + 0.207*"time" + 0.196*"feature" + -0.187*"kernel" + '
#   '0.186*"policy" + 0.168*"information"'),
#  (13,
#   '-0.494*"matrix" + 0.387*"feature" + -0.325*"approach" + 0.225*"graph" + '
#   '0.197*"distribution" + 0.175*"problem" + 0.151*"method" + 0.150*"bound" + '
#   '-0.121*"image" + -0.117*"neural"'),
#  (14,
#   '-0.527*"graph" + 0.361*"distribution" + 0.266*"feature" + -0.233*"approach" '
#   '+ -0.183*"bound" + 0.179*"matrix" + -0.176*"kernel" + 0.157*"problem" + '
#   '-0.157*"clustering" + 0.154*"gradient"'),
#  (15,
#   '0.400*"bound" + 0.315*"approach" + -0.312*"task" + -0.271*"distribution" + '
#   '-0.261*"graph" + 0.217*"kernel" + 0.189*"inference" + 0.158*"feature" + '
#   '-0.144*"function" + -0.143*"clustering"'),
#  (16,
#   '-0.440*"kernel" + 0.285*"approach" + 0.259*"matrix" + 0.236*"task" + '
#   '-0.200*"gradient" + -0.184*"image" + -0.174*"rate" + 0.158*"function" + '
#   '0.157*"inference" + 0.146*"bound"'),
#  (17,
#   '-0.295*"task" + -0.270*"gradient" + 0.230*"inference" + -0.220*"approach" + '
#   '0.206*"bound" + 0.198*"image" + -0.190*"training" + 0.187*"method" + '
#   '0.154*"time" + 0.150*"state"'),
#  (18,
#   '-0.503*"kernel" + -0.356*"task" + 0.298*"approach" + 0.221*"graph" + '
#   '0.198*"feature" + -0.178*"classification" + -0.148*"loss" + '
#   '-0.138*"inference" + 0.132*"sparse" + 0.131*"policy"'),
#  (19,
#   '0.324*"gradient" + -0.244*"approach" + 0.240*"stochastic" + 0.224*"matrix" '
#   '+ -0.202*"neural" + -0.198*"linear" + 0.196*"task" + 0.186*"inference" + '
#   '-0.182*"loss" + 0.165*"process"')]
# [(0,
#   '0.382*"model" + 0.314*"algorithm" + 0.261*"learning" + 0.236*"method" + '
#   '0.228*"problem" + 0.223*"data" + 0.160*"show" + 0.137*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.732*"model" + 0.435*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.115*"learning" + -0.107*"network" + -0.102*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.080*"method"'),
#  (2,
#   '-0.528*"algorithm" + -0.388*"model" + 0.336*"learning" + 0.324*"network" + '
#   '0.302*"method" + 0.163*"image" + 0.155*"task" + 0.143*"feature" + '
#   '0.124*"deep" + 0.122*"neural"'),
#  (3,
#   '0.576*"method" + -0.456*"learning" + -0.356*"network" + -0.285*"algorithm" '
#   '+ 0.247*"data" + 0.122*"matrix" + 0.107*"problem" + -0.099*"deep" + '
#   '-0.098*"neural" + -0.090*"task"'),
#  (4,
#   '-0.601*"network" + 0.570*"learning" + 0.278*"data" + -0.220*"neural" + '
#   '-0.105*"algorithm" + -0.099*"method" + -0.083*"deep" + -0.081*"image" + '
#   '0.077*"task" + 0.074*"approach"'),
#  (5,
#   '0.687*"data" + -0.315*"function" + 0.260*"algorithm" + -0.202*"model" + '
#   '-0.200*"problem" + -0.187*"learning" + -0.158*"method" + 0.150*"network" + '
#   '-0.114*"optimization" + 0.111*"feature"'),
#  (6,
#   '-0.505*"image" + 0.325*"data" + 0.289*"function" + -0.265*"algorithm" + '
#   '-0.251*"method" + 0.246*"network" + -0.236*"feature" + -0.226*"object" + '
#   '0.194*"distribution" + 0.128*"bound"'),
#  (7,
#   '0.471*"method" + -0.436*"problem" + -0.326*"image" + 0.302*"algorithm" + '
#   '0.229*"learning" + -0.142*"object" + 0.126*"gradient" + 0.125*"inference" + '
#   '-0.121*"matrix" + 0.116*"network"'),
#  (8,
#   '-0.565*"problem" + 0.538*"function" + 0.219*"image" + 0.201*"feature" + '
#   '-0.181*"matrix" + -0.173*"learning" + 0.165*"distribution" + '
#   '-0.147*"network" + 0.126*"bound" + 0.096*"loss"'),
#  (9,
#   '-0.499*"function" + 0.371*"distribution" + 0.278*"bound" + -0.256*"data" + '
#   '-0.248*"problem" + 0.202*"sample" + 0.192*"matrix" + -0.129*"optimization" '
#   '+ -0.107*"model" + 0.106*"show"'),
#  (10,
#   '-0.457*"feature" + -0.387*"matrix" + 0.359*"distribution" + '
#   '0.282*"approach" + 0.242*"inference" + 0.215*"image" + -0.189*"kernel" + '
#   '0.129*"problem" + -0.126*"model" + -0.106*"sparse"'),
#  (11,
#   '-0.413*"feature" + -0.318*"kernel" + -0.305*"approach" + 0.281*"bound" + '
#   '-0.241*"inference" + 0.237*"image" + -0.200*"distribution" + 0.181*"data" + '
#   '0.163*"loss" + 0.139*"method"'),
#  (12,
#   '-0.295*"graph" + -0.290*"image" + 0.272*"task" + -0.260*"matrix" + '
#   '-0.221*"distribution" + 0.207*"time" + 0.200*"feature" + -0.190*"kernel" + '
#   '0.188*"policy" + 0.166*"information"'),
#  (13,
#   '-0.490*"matrix" + 0.392*"feature" + -0.330*"approach" + 0.218*"graph" + '
#   '0.208*"distribution" + 0.179*"problem" + 0.150*"method" + 0.144*"bound" + '
#   '-0.120*"image" + -0.117*"neural"'),
#  (14,
#   '0.526*"graph" + -0.362*"distribution" + -0.257*"feature" + 0.229*"approach" '
#   '+ -0.193*"matrix" + 0.188*"bound" + 0.175*"kernel" + 0.156*"clustering" + '
#   '-0.156*"problem" + -0.150*"gradient"'),
#  (15,
#   '-0.395*"bound" + 0.320*"task" + -0.306*"approach" + 0.272*"distribution" + '
#   '0.263*"graph" + -0.220*"kernel" + -0.187*"inference" + -0.161*"feature" + '
#   '0.149*"function" + 0.147*"clustering"'),
#  (16,
#   '0.439*"kernel" + -0.293*"approach" + -0.259*"matrix" + -0.232*"task" + '
#   '0.193*"gradient" + 0.186*"image" + 0.167*"rate" + -0.162*"inference" + '
#   '-0.153*"function" + -0.151*"bound"'),
#  (17,
#   '0.286*"task" + 0.264*"gradient" + -0.227*"inference" + 0.221*"approach" + '
#   '-0.206*"bound" + -0.196*"image" + 0.190*"training" + -0.189*"method" + '
#   '-0.153*"time" + 0.149*"convergence"'),
#  (18,
#   '-0.506*"kernel" + -0.364*"task" + 0.299*"approach" + 0.222*"graph" + '
#   '0.197*"feature" + -0.176*"classification" + -0.142*"loss" + '
#   '-0.139*"inference" + 0.131*"sparse" + 0.128*"learning"'),
#  (19,
#   '-0.331*"gradient" + -0.236*"stochastic" + 0.232*"approach" + '
#   '-0.226*"matrix" + 0.203*"neural" + 0.202*"linear" + -0.194*"task" + '
#   '0.193*"loss" + -0.176*"inference" + -0.160*"process"'),
#  (20,
#   '-0.476*"inference" + 0.253*"policy" + 0.220*"approach" + 0.216*"kernel" + '
#   '-0.192*"loss" + -0.187*"show" + 0.166*"distribution" + -0.156*"graph" + '
#   '0.139*"model" + 0.138*"network"'),
#  (21,
#   '-0.393*"task" + -0.335*"bound" + 0.331*"time" + 0.230*"show" + '
#   '0.227*"label" + 0.199*"training" + 0.187*"loss" + -0.156*"structure" + '
#   '0.138*"classification" + 0.132*"class"'),
#  (22,
#   '-0.372*"clustering" + 0.287*"time" + -0.211*"information" + 0.209*"sparse" '
#   '+ 0.195*"parameter" + 0.195*"task" + 0.170*"regression" + 0.167*"image" + '
#   '-0.160*"neural" + -0.151*"matrix"'),
#  (23,
#   '-0.425*"clustering" + 0.343*"graph" + -0.239*"show" + 0.185*"gradient" + '
#   '0.180*"loss" + 0.175*"information" + -0.162*"set" + -0.156*"cluster" + '
#   '-0.150*"object" + 0.147*"time"'),
#  (24,
#   '0.393*"result" + 0.298*"policy" + -0.281*"object" + -0.216*"number" + '
#   '0.210*"show" + -0.184*"sample" + 0.169*"new" + -0.166*"time" + '
#   '-0.157*"parameter" + -0.154*"task"'),
#  (25,
#   '0.382*"time" + 0.233*"loss" + -0.227*"show" + 0.219*"object" + '
#   '-0.195*"policy" + -0.188*"using" + -0.184*"training" + -0.179*"bound" + '
#   '0.176*"framework" + -0.169*"neural"'),
#  (26,
#   '-0.516*"object" + 0.313*"time" + 0.238*"clustering" + -0.205*"variable" + '
#   '-0.201*"show" + -0.195*"structure" + 0.182*"result" + 0.162*"image" + '
#   '-0.146*"latent" + -0.136*"space"'),
#  (27,
#   '-0.335*"show" + -0.334*"latent" + -0.241*"variable" + -0.236*"time" + '
#   '-0.174*"clustering" + -0.154*"topic" + 0.153*"estimator" + 0.151*"loss" + '
#   '-0.144*"structure" + -0.140*"word"'),
#  (28,
#   '-0.321*"information" + -0.297*"process" + 0.276*"object" + -0.245*"label" + '
#   '0.215*"show" + -0.180*"set" + -0.164*"parameter" + -0.157*"structure" + '
#   '0.142*"task" + 0.135*"result"'),
#  (29,
#   '0.478*"information" + -0.343*"loss" + -0.213*"state" + -0.209*"number" + '
#   '-0.177*"clustering" + -0.170*"task" + 0.153*"variable" + -0.145*"linear" + '
#   '0.144*"sample" + -0.131*"process"'),
#  (30,
#   '-0.459*"show" + 0.245*"result" + -0.228*"loss" + 0.226*"number" + '
#   '0.213*"class" + 0.200*"latent" + 0.145*"topic" + 0.142*"state" + '
#   '-0.140*"parameter" + -0.140*"image"'),
#  (31,
#   '-0.359*"sample" + -0.289*"variable" + -0.286*"training" + 0.274*"label" + '
#   '-0.237*"loss" + -0.206*"clustering" + -0.195*"latent" + '
#   '0.187*"distribution" + -0.176*"result" + 0.161*"sparse"'),
#  (32,
#   '-0.390*"using" + 0.385*"set" + 0.211*"label" + -0.197*"sparse" + '
#   '0.189*"class" + 0.158*"rate" + -0.149*"loss" + -0.143*"vector" + '
#   '-0.143*"representation" + -0.139*"number"'),
#  (33,
#   '-0.262*"set" + -0.240*"number" + 0.228*"process" + -0.223*"information" + '
#   '-0.219*"regret" + 0.202*"error" + 0.184*"classification" + 0.180*"based" + '
#   '0.175*"bound" + -0.167*"kernel"'),
#  (34,
#   '-0.320*"process" + -0.315*"set" + -0.275*"training" + -0.224*"optimization" '
#   '+ 0.183*"gradient" + 0.179*"estimator" + -0.162*"object" + 0.160*"state" + '
#   '0.154*"label" + 0.153*"analysis"'),
#  (35,
#   '-0.341*"performance" + 0.296*"using" + 0.242*"result" + -0.230*"variable" + '
#   '-0.220*"parameter" + 0.195*"space" + 0.177*"rate" + -0.175*"policy" + '
#   '0.173*"information" + 0.150*"sample"'),
#  (36,
#   '-0.361*"using" + 0.296*"process" + 0.267*"number" + -0.202*"parameter" + '
#   '0.197*"rate" + -0.196*"set" + -0.178*"gradient" + 0.176*"show" + '
#   '0.166*"domain" + 0.164*"sample"'),
#  (37,
#   '-0.538*"framework" + -0.240*"domain" + 0.220*"state" + 0.184*"loss" + '
#   '-0.183*"using" + 0.175*"information" + 0.163*"result" + 0.151*"performance" '
#   '+ -0.146*"label" + 0.123*"estimator"'),
#  (38,
#   '-0.305*"set" + 0.276*"class" + 0.200*"using" + -0.198*"domain" + '
#   '-0.180*"paper" + 0.176*"result" + 0.172*"rate" + -0.166*"state" + '
#   '-0.163*"loss" + 0.154*"prior"'),
#  (39,
#   '-0.315*"parameter" + 0.292*"structure" + -0.270*"state" + 0.236*"gradient" '
#   '+ -0.199*"optimization" + 0.196*"sample" + 0.177*"process" + '
#   '-0.172*"framework" + 0.171*"tree" + 0.165*"complexity"'),
#  (40,
#   '0.272*"structure" + -0.263*"variable" + -0.233*"linear" + 0.208*"tree" + '
#   '0.207*"neural" + -0.182*"latent" + -0.175*"policy" + 0.160*"new" + '
#   '-0.159*"using" + 0.157*"parameter"'),
#  (41,
#   '-0.277*"result" + 0.266*"space" + -0.253*"using" + -0.226*"number" + '
#   '0.199*"representation" + 0.199*"estimator" + -0.195*"variable" + '
#   '-0.171*"domain" + -0.150*"parameter" + 0.144*"sparse"'),
#  (42,
#   '-0.339*"analysis" + -0.264*"process" + 0.246*"sparse" + 0.187*"clustering" '
#   '+ 0.173*"optimal" + 0.172*"optimization" + -0.172*"new" + 0.144*"bayesian" '
#   '+ 0.143*"kernel" + -0.140*"parameter"'),
#  (43,
#   '0.322*"rate" + -0.287*"linear" + -0.261*"result" + -0.232*"framework" + '
#   '0.211*"using" + 0.167*"word" + -0.167*"information" + 0.162*"convergence" + '
#   '-0.153*"gradient" + -0.151*"regression"'),
#  (44,
#   '0.369*"domain" + -0.262*"sample" + 0.223*"information" + -0.184*"number" + '
#   '0.181*"time" + 0.176*"sparse" + 0.172*"parameter" + 0.152*"target" + '
#   '0.139*"structure" + 0.134*"process"'),
#  (45,
#   '0.290*"optimization" + 0.289*"class" + 0.230*"information" + 0.207*"policy" '
#   '+ 0.197*"state" + 0.187*"new" + 0.173*"using" + -0.165*"result" + '
#   '0.164*"convex" + -0.162*"human"'),
#  (46,
#   '-0.259*"tree" + -0.254*"new" + 0.238*"optimization" + 0.224*"parameter" + '
#   '0.196*"policy" + 0.185*"sample" + -0.172*"linear" + 0.162*"result" + '
#   '0.160*"label" + -0.156*"state"'),
#  (47,
#   '0.296*"state" + -0.235*"policy" + -0.207*"number" + 0.190*"class" + '
#   '-0.181*"metric" + -0.168*"linear" + -0.161*"structure" + -0.160*"local" + '
#   '-0.156*"new" + 0.155*"using"'),
#  (48,
#   '0.415*"new" + -0.267*"optimization" + -0.267*"domain" + 0.189*"sparse" + '
#   '0.174*"gradient" + -0.165*"random" + 0.149*"error" + -0.138*"performance" + '
#   '-0.136*"space" + -0.115*"process"'),
#  (49,
#   '-0.288*"linear" + -0.243*"human" + -0.238*"parameter" + 0.226*"performance" '
#   '+ -0.188*"class" + -0.183*"representation" + 0.179*"propose" + 0.175*"set" '
#   '+ -0.156*"decision" + 0.153*"sparse"')]
# [(0,
#   '0.382*"model" + 0.314*"algorithm" + 0.261*"learning" + 0.236*"method" + '
#   '0.228*"problem" + 0.223*"data" + 0.160*"show" + 0.137*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.732*"model" + 0.435*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.115*"learning" + -0.107*"network" + -0.102*"image" + 0.089*"bound" + '
#   '-0.086*"neural" + 0.080*"method"'),
#  (2,
#   '-0.528*"algorithm" + -0.388*"model" + 0.336*"learning" + 0.324*"network" + '
#   '0.302*"method" + 0.163*"image" + 0.155*"task" + 0.143*"feature" + '
#   '0.124*"deep" + 0.122*"neural"'),
#  (3,
#   '-0.576*"method" + 0.456*"learning" + 0.356*"network" + 0.285*"algorithm" + '
#   '-0.247*"data" + -0.122*"matrix" + -0.107*"problem" + 0.099*"deep" + '
#   '0.098*"neural" + 0.090*"task"'),
#  (4,
#   '-0.601*"network" + 0.570*"learning" + 0.278*"data" + -0.221*"neural" + '
#   '-0.105*"algorithm" + -0.099*"method" + -0.083*"deep" + -0.081*"image" + '
#   '0.077*"task" + 0.074*"approach"'),
#  (5,
#   '0.687*"data" + -0.315*"function" + 0.260*"algorithm" + -0.202*"model" + '
#   '-0.200*"problem" + -0.188*"learning" + -0.158*"method" + 0.150*"network" + '
#   '-0.114*"optimization" + 0.110*"feature"'),
#  (6,
#   '-0.505*"image" + 0.325*"data" + 0.290*"function" + -0.264*"algorithm" + '
#   '-0.251*"method" + 0.246*"network" + -0.236*"feature" + -0.226*"object" + '
#   '0.194*"distribution" + 0.129*"bound"'),
#  (7,
#   '0.471*"method" + -0.436*"problem" + -0.326*"image" + 0.302*"algorithm" + '
#   '0.229*"learning" + -0.142*"object" + 0.126*"gradient" + 0.125*"inference" + '
#   '-0.121*"matrix" + 0.116*"network"'),
#  (8,
#   '0.565*"problem" + -0.538*"function" + -0.219*"image" + -0.201*"feature" + '
#   '0.181*"matrix" + 0.173*"learning" + -0.165*"distribution" + 0.147*"network" '
#   '+ -0.126*"bound" + -0.097*"loss"'),
#  (9,
#   '0.500*"function" + -0.371*"distribution" + -0.277*"bound" + 0.256*"data" + '
#   '0.248*"problem" + -0.201*"sample" + -0.192*"matrix" + 0.129*"optimization" '
#   '+ 0.107*"model" + -0.106*"show"'),
#  (10,
#   '0.458*"feature" + 0.387*"matrix" + -0.358*"distribution" + '
#   '-0.282*"approach" + -0.243*"inference" + -0.215*"image" + 0.190*"kernel" + '
#   '-0.128*"problem" + 0.126*"model" + 0.106*"sparse"'),
#  (11,
#   '-0.412*"feature" + -0.318*"kernel" + -0.304*"approach" + 0.281*"bound" + '
#   '-0.241*"inference" + 0.237*"image" + -0.200*"distribution" + 0.181*"data" + '
#   '0.163*"loss" + 0.139*"method"'),
#  (12,
#   '0.294*"graph" + 0.290*"image" + -0.271*"task" + 0.260*"matrix" + '
#   '0.221*"distribution" + -0.207*"time" + -0.200*"feature" + 0.189*"kernel" + '
#   '-0.187*"policy" + -0.166*"information"'),
#  (13,
#   '0.490*"matrix" + -0.392*"feature" + 0.331*"approach" + -0.216*"graph" + '
#   '-0.209*"distribution" + -0.180*"problem" + -0.150*"method" + -0.144*"bound" '
#   '+ 0.120*"image" + 0.117*"neural"'),
#  (14,
#   '-0.528*"graph" + 0.360*"distribution" + 0.257*"feature" + -0.226*"approach" '
#   '+ 0.193*"matrix" + -0.187*"bound" + -0.173*"kernel" + -0.156*"clustering" + '
#   '0.155*"problem" + 0.152*"gradient"'),
#  (15,
#   '0.395*"bound" + -0.324*"task" + 0.304*"approach" + -0.272*"distribution" + '
#   '-0.261*"graph" + 0.226*"kernel" + 0.185*"inference" + 0.159*"feature" + '
#   '-0.151*"function" + -0.148*"clustering"'),
#  (16,
#   '0.436*"kernel" + -0.298*"approach" + -0.258*"matrix" + -0.229*"task" + '
#   '0.191*"gradient" + 0.186*"image" + 0.166*"rate" + -0.162*"inference" + '
#   '-0.155*"bound" + -0.152*"function"'),
#  (17,
#   '-0.287*"task" + -0.266*"gradient" + 0.230*"inference" + -0.224*"approach" + '
#   '0.204*"bound" + 0.197*"image" + -0.189*"training" + 0.188*"method" + '
#   '0.153*"time" + 0.148*"state"'),
#  (18,
#   '-0.507*"kernel" + -0.362*"task" + 0.298*"approach" + 0.222*"graph" + '
#   '0.197*"feature" + -0.177*"classification" + -0.145*"loss" + '
#   '-0.138*"inference" + 0.132*"sparse" + 0.128*"learning"'),
#  (19,
#   '0.329*"gradient" + 0.239*"stochastic" + -0.232*"approach" + 0.226*"matrix" '
#   '+ -0.202*"neural" + -0.201*"linear" + 0.195*"task" + -0.192*"loss" + '
#   '0.173*"inference" + 0.161*"process"'),
#  (20,
#   '0.476*"inference" + -0.253*"policy" + -0.221*"approach" + -0.217*"kernel" + '
#   '0.192*"loss" + 0.190*"show" + -0.166*"distribution" + 0.158*"graph" + '
#   '-0.138*"network" + -0.138*"model"'),
#  (21,
#   '-0.391*"task" + -0.335*"bound" + 0.329*"time" + 0.231*"show" + '
#   '0.228*"label" + 0.199*"training" + 0.189*"loss" + -0.154*"structure" + '
#   '0.140*"classification" + 0.133*"class"'),
#  (22,
#   '-0.373*"clustering" + 0.282*"time" + 0.211*"sparse" + -0.209*"information" '
#   '+ 0.195*"task" + 0.192*"parameter" + 0.170*"regression" + 0.169*"image" + '
#   '-0.162*"neural" + -0.152*"approach"'),
#  (23,
#   '-0.425*"clustering" + 0.342*"graph" + -0.237*"show" + 0.187*"gradient" + '
#   '0.180*"loss" + 0.180*"information" + -0.161*"set" + -0.160*"cluster" + '
#   '0.143*"time" + -0.142*"result"'),
#  (24,
#   '0.393*"result" + 0.300*"policy" + -0.277*"object" + -0.226*"number" + '
#   '0.204*"show" + -0.186*"sample" + 0.170*"new" + -0.167*"time" + '
#   '-0.157*"task" + -0.155*"parameter"'),
#  (25,
#   '0.391*"time" + -0.233*"show" + 0.231*"loss" + 0.210*"object" + '
#   '-0.200*"policy" + -0.193*"using" + -0.182*"training" + -0.179*"bound" + '
#   '0.177*"framework" + -0.172*"neural"'),
#  (26,
#   '0.511*"object" + -0.306*"time" + -0.224*"clustering" + 0.210*"variable" + '
#   '0.203*"show" + 0.202*"structure" + -0.178*"result" + 0.164*"latent" + '
#   '-0.161*"image" + 0.140*"space"'),
#  (27,
#   '-0.357*"show" + -0.314*"latent" + -0.252*"time" + -0.230*"variable" + '
#   '0.173*"loss" + -0.162*"clustering" + 0.153*"process" + 0.150*"estimator" + '
#   '0.150*"label" + -0.147*"topic"'),
#  (28,
#   '-0.324*"information" + 0.293*"object" + -0.280*"process" + -0.232*"label" + '
#   '-0.195*"set" + 0.178*"show" + -0.163*"structure" + -0.159*"clustering" + '
#   '-0.154*"parameter" + 0.148*"domain"'),
#  (29,
#   '0.482*"information" + -0.326*"loss" + -0.212*"number" + -0.211*"state" + '
#   '-0.172*"task" + -0.171*"clustering" + 0.166*"sample" + -0.157*"linear" + '
#   '0.144*"variable" + -0.123*"process"'),
#  (30,
#   '0.461*"show" + -0.256*"result" + 0.240*"loss" + -0.217*"number" + '
#   '-0.215*"class" + -0.198*"latent" + -0.145*"analysis" + -0.144*"topic" + '
#   '0.144*"image" + -0.143*"object"'),
#  (31,
#   '0.366*"sample" + 0.286*"training" + -0.275*"label" + 0.267*"variable" + '
#   '0.248*"loss" + 0.211*"clustering" + 0.195*"latent" + -0.183*"distribution" '
#   '+ 0.171*"result" + -0.158*"sparse"'),
#  (32,
#   '0.461*"set" + -0.329*"using" + 0.187*"class" + -0.171*"process" + '
#   '-0.171*"sparse" + -0.148*"bound" + -0.148*"performance" + 0.147*"kernel" + '
#   '0.144*"parameter" + -0.138*"vector"'),
#  (33,
#   '0.273*"number" + -0.246*"label" + 0.226*"information" + -0.204*"error" + '
#   '0.204*"regret" + -0.193*"rate" + 0.191*"using" + -0.176*"based" + '
#   '-0.174*"classification" + -0.163*"classifier"'),
#  (34,
#   '-0.316*"process" + -0.313*"set" + -0.278*"training" + -0.222*"optimization" '
#   '+ 0.181*"estimator" + 0.178*"gradient" + -0.168*"object" + 0.164*"state" + '
#   '0.158*"number" + 0.152*"label"'),
#  (35,
#   '-0.331*"performance" + 0.304*"using" + -0.251*"variable" + 0.234*"result" + '
#   '-0.213*"parameter" + 0.204*"space" + -0.198*"policy" + 0.169*"rate" + '
#   '0.154*"information" + 0.141*"set"'),
#  (36,
#   '-0.332*"using" + 0.316*"process" + 0.258*"number" + -0.228*"parameter" + '
#   '0.212*"rate" + -0.209*"set" + 0.180*"sample" + 0.177*"show" + '
#   '-0.175*"gradient" + 0.159*"latent"'),
#  (37,
#   '-0.534*"framework" + -0.251*"domain" + 0.200*"state" + -0.184*"using" + '
#   '0.182*"information" + 0.182*"result" + 0.174*"loss" + 0.149*"performance" + '
#   '-0.146*"label" + -0.123*"propose"'),
#  (38,
#   '0.282*"using" + -0.268*"set" + 0.259*"class" + -0.200*"state" + '
#   '-0.197*"domain" + 0.179*"result" + -0.174*"paper" + 0.159*"rate" + '
#   '-0.157*"loss" + -0.155*"proposed"'),
#  (39,
#   '0.343*"structure" + -0.298*"parameter" + -0.264*"state" + 0.225*"gradient" '
#   '+ 0.210*"tree" + -0.194*"optimization" + 0.183*"sample" + 0.170*"process" + '
#   '0.167*"complexity" + -0.162*"framework"'),
#  (40,
#   '0.266*"variable" + 0.256*"linear" + -0.247*"structure" + -0.214*"parameter" '
#   '+ -0.204*"neural" + -0.192*"tree" + 0.180*"policy" + -0.161*"class" + '
#   '0.155*"set" + -0.151*"new"'),
#  (41,
#   '-0.296*"result" + 0.270*"space" + -0.239*"using" + -0.231*"number" + '
#   '0.223*"representation" + 0.202*"estimator" + -0.187*"variable" + '
#   '-0.164*"parameter" + 0.163*"sparse" + -0.153*"domain"'),
#  (42,
#   '-0.341*"analysis" + -0.274*"process" + 0.238*"sparse" + '
#   '0.190*"optimization" + 0.177*"clustering" + 0.171*"optimal" + -0.153*"new" '
#   '+ 0.151*"kernel" + 0.142*"bayesian" + 0.141*"human"'),
#  (43,
#   '-0.306*"rate" + 0.276*"linear" + 0.253*"framework" + -0.250*"domain" + '
#   '0.191*"sample" + -0.166*"convergence" + -0.162*"structure" + 0.157*"result" '
#   '+ -0.153*"using" + 0.147*"optimization"'),
#  (44,
#   '0.291*"information" + 0.291*"domain" + -0.199*"sample" + 0.190*"result" + '
#   '0.168*"sparse" + -0.163*"using" + 0.161*"gradient" + 0.155*"time" + '
#   '0.145*"parameter" + 0.142*"object"'),
#  (45,
#   '-0.299*"optimization" + -0.290*"class" + -0.227*"information" + '
#   '-0.226*"policy" + -0.206*"new" + -0.192*"using" + 0.180*"result" + '
#   '-0.173*"time" + 0.159*"propose" + -0.154*"state"'),
#  (46,
#   '-0.258*"tree" + -0.232*"new" + 0.216*"parameter" + 0.213*"policy" + '
#   '-0.201*"state" + 0.201*"optimization" + -0.201*"linear" + 0.175*"sample" + '
#   '0.173*"label" + -0.172*"class"'),
#  (47,
#   '0.245*"state" + -0.221*"number" + -0.217*"metric" + -0.213*"policy" + '
#   '0.190*"class" + 0.179*"human" + -0.174*"structure" + 0.172*"representation" '
#   '+ -0.164*"linear" + -0.144*"local"'),
#  (48,
#   '-0.448*"new" + 0.317*"optimization" + 0.267*"domain" + -0.212*"sparse" + '
#   '-0.174*"gradient" + 0.156*"random" + -0.155*"set" + -0.137*"policy" + '
#   '0.131*"space" + -0.130*"rate"'),
#  (49,
#   '0.257*"performance" + -0.253*"parameter" + -0.237*"linear" + -0.220*"human" '
#   '+ -0.205*"representation" + -0.183*"class" + -0.170*"based" + '
#   '0.164*"estimator" + -0.145*"decision" + 0.142*"set"'),
#  (50,
#   '0.223*"framework" + -0.210*"new" + 0.203*"training" + 0.196*"system" + '
#   '-0.184*"metric" + 0.184*"linear" + 0.183*"convergence" + -0.177*"sparse" + '
#   '-0.166*"two" + 0.159*"structure"'),
#  (51,
#   '-0.428*"estimator" + 0.285*"performance" + 0.218*"state" + -0.196*"policy" '
#   '+ -0.195*"based" + 0.160*"regression" + 0.151*"parameter" + 0.150*"rate" + '
#   '0.133*"error" + -0.126*"point"'),
#  (52,
#   '-0.346*"label" + -0.300*"new" + 0.218*"training" + -0.217*"linear" + '
#   '0.204*"tree" + 0.189*"framework" + 0.179*"decision" + -0.176*"deep" + '
#   '-0.170*"performance" + 0.160*"class"'),
#  (53,
#   '0.252*"performance" + -0.215*"prediction" + -0.191*"representation" + '
#   '-0.184*"deep" + 0.182*"two" + -0.177*"decision" + -0.159*"space" + '
#   '0.157*"inference" + -0.156*"game" + -0.154*"parameter"'),
#  (54,
#   '0.306*"class" + -0.230*"bayesian" + 0.224*"propose" + -0.197*"regression" + '
#   '-0.184*"optimization" + 0.162*"point" + -0.159*"estimator" + '
#   '-0.157*"present" + -0.140*"analysis" + -0.140*"latent"'),
#  (55,
#   '0.306*"space" + -0.253*"linear" + 0.194*"new" + 0.172*"system" + '
#   '-0.169*"two" + -0.161*"state" + -0.159*"propose" + 0.155*"domain" + '
#   '-0.152*"analysis" + -0.150*"deep"'),
#  (56,
#   '0.221*"sparse" + -0.219*"representation" + 0.215*"training" + '
#   '-0.197*"regression" + -0.188*"set" + -0.181*"bayesian" + 0.164*"analysis" + '
#   '0.159*"inference" + 0.145*"prediction" + 0.138*"setting"'),
#  (57,
#   '0.312*"two" + -0.276*"analysis" + 0.268*"approximation" + '
#   '0.223*"regression" + -0.174*"estimator" + -0.167*"performance" + '
#   '-0.166*"set" + 0.152*"sparse" + 0.146*"also" + -0.143*"optimal"'),
#  (58,
#   '0.294*"structure" + -0.274*"tree" + 0.244*"error" + 0.241*"approximation" + '
#   '-0.180*"proposed" + -0.162*"decision" + -0.147*"vector" + '
#   '-0.146*"parameter" + 0.146*"point" + 0.141*"framework"'),
#  (59,
#   '0.294*"based" + 0.222*"random" + -0.178*"human" + 0.168*"error" + '
#   '-0.165*"prediction" + 0.151*"approximation" + 0.145*"sampling" + '
#   '0.142*"setting" + 0.139*"system" + -0.133*"two"'),
#  (60,
#   '0.254*"error" + -0.204*"training" + -0.198*"human" + 0.195*"input" + '
#   '0.187*"prediction" + -0.179*"based" + 0.174*"propose" + -0.173*"optimal" + '
#   '0.172*"classifier" + 0.168*"sampling"'),
#  (61,
#   '0.366*"sampling" + -0.249*"two" + 0.228*"training" + -0.201*"approximation" '
#   '+ -0.198*"large" + 0.173*"space" + 0.166*"new" + 0.165*"propose" + '
#   '-0.148*"tree" + 0.142*"regression"'),
#  (62,
#   '0.379*"two" + 0.250*"based" + 0.232*"space" + -0.182*"regression" + '
#   '-0.148*"online" + -0.138*"also" + -0.136*"propose" + 0.133*"input" + '
#   '-0.124*"setting" + -0.124*"topic"'),
#  (63,
#   '-0.252*"paper" + -0.242*"metric" + -0.240*"proposed" + 0.195*"propose" + '
#   '0.175*"test" + -0.164*"bayesian" + 0.161*"prediction" + '
#   '-0.156*"approximation" + -0.155*"solution" + -0.155*"also"'),
#  (64,
#   '0.367*"based" + -0.258*"random" + 0.231*"regression" + -0.163*"new" + '
#   '-0.160*"used" + -0.153*"framework" + 0.149*"analysis" + -0.147*"test" + '
#   '0.147*"prediction" + 0.142*"sampling"'),
#  (65,
#   '0.274*"game" + 0.246*"neural" + -0.184*"neuron" + -0.177*"representation" + '
#   '-0.175*"estimator" + 0.175*"regression" + -0.171*"present" + '
#   '-0.171*"linear" + -0.166*"sampling" + -0.162*"optimal"'),
#  (66,
#   '0.263*"prediction" + -0.240*"game" + 0.204*"point" + 0.204*"proposed" + '
#   '-0.179*"noise" + -0.169*"system" + 0.162*"neural" + -0.138*"tree" + '
#   '0.132*"class" + -0.129*"large"'),
#  (67,
#   '0.254*"random" + 0.234*"local" + -0.199*"application" + 0.195*"game" + '
#   '0.185*"large" + -0.154*"approximation" + -0.152*"number" + '
#   '-0.151*"submodular" + -0.148*"deep" + -0.147*"paper"'),
#  (68,
#   '0.280*"game" + 0.268*"test" + 0.187*"large" + -0.158*"metric" + '
#   '-0.149*"tree" + -0.145*"policy" + 0.140*"bayesian" + -0.138*"setting" + '
#   '-0.130*"query" + -0.129*"layer"'),
#  (69,
#   '0.266*"regression" + -0.236*"space" + -0.179*"online" + -0.171*"propose" + '
#   '-0.171*"tree" + -0.149*"latent" + -0.148*"test" + -0.147*"approximation" + '
#   '-0.132*"random" + 0.123*"optimal"'),
#  (70,
#   '0.247*"also" + -0.237*"proposed" + 0.223*"metric" + -0.213*"space" + '
#   '-0.210*"error" + -0.198*"regression" + 0.161*"based" + -0.156*"system" + '
#   '-0.154*"optimal" + -0.142*"class"'),
#  (71,
#   '-0.322*"point" + 0.311*"proposed" + -0.260*"optimal" + -0.189*"dynamic" + '
#   '-0.163*"system" + 0.153*"based" + 0.152*"approximation" + '
#   '-0.142*"prediction" + 0.135*"error" + -0.129*"sparse"'),
#  (72,
#   '-0.325*"test" + 0.240*"paper" + -0.229*"representation" + -0.226*"also" + '
#   '-0.196*"proposed" + 0.185*"human" + 0.175*"sampling" + -0.153*"analysis" + '
#   '0.146*"topic" + 0.144*"estimation"'),
#  (73,
#   '0.250*"efficient" + -0.219*"memory" + 0.204*"noise" + 0.193*"prediction" + '
#   '-0.177*"sparse" + -0.169*"classification" + -0.161*"setting" + '
#   '0.158*"random" + -0.157*"one" + -0.157*"machine"'),
#  (74,
#   '-0.223*"present" + -0.200*"also" + -0.193*"test" + -0.186*"representation" '
#   '+ -0.156*"error" + -0.151*"paper" + 0.147*"sample" + 0.146*"framework" + '
#   '-0.137*"point" + 0.137*"approximation"'),
#  (75,
#   '-0.245*"representation" + 0.225*"topic" + 0.198*"test" + -0.178*"training" '
#   '+ 0.173*"work" + 0.161*"sequence" + -0.157*"vector" + 0.140*"input" + '
#   '0.139*"game" + 0.135*"state"'),
#  (76,
#   '0.208*"sampling" + -0.186*"also" + 0.176*"neural" + -0.174*"input" + '
#   '-0.172*"point" + 0.169*"system" + 0.169*"metric" + -0.164*"performance" + '
#   '-0.162*"neuron" + 0.155*"sparse"'),
#  (77,
#   '-0.217*"game" + 0.217*"action" + -0.187*"deep" + -0.184*"one" + '
#   '0.182*"prior" + 0.173*"neural" + 0.155*"estimation" + -0.134*"study" + '
#   '0.133*"local" + -0.131*"also"'),
#  (78,
#   '0.297*"local" + -0.252*"also" + 0.210*"estimator" + 0.203*"dynamic" + '
#   '-0.200*"estimation" + 0.197*"study" + -0.192*"user" + 0.178*"case" + '
#   '0.162*"game" + -0.147*"online"'),
#  (79,
#   '0.227*"one" + 0.217*"different" + -0.202*"classifier" + 0.184*"input" + '
#   '-0.165*"signal" + -0.159*"probability" + 0.156*"bayesian" + 0.156*"class" + '
#   '-0.141*"classification" + 0.128*"local"'),
#  (80,
#   '-0.255*"test" + 0.195*"noise" + 0.194*"optimal" + 0.179*"random" + '
#   '-0.169*"sampling" + 0.169*"present" + 0.142*"classifier" + -0.136*"local" + '
#   '0.132*"experiment" + 0.132*"solution"'),
#  (81,
#   '-0.309*"norm" + 0.259*"paper" + -0.244*"prior" + -0.213*"work" + '
#   '0.190*"prediction" + 0.171*"also" + -0.168*"convex" + -0.164*"measure" + '
#   '0.161*"gaussian" + -0.159*"tensor"'),
#  (82,
#   '0.202*"present" + 0.196*"prior" + -0.174*"norm" + -0.173*"optimal" + '
#   '-0.163*"propose" + -0.161*"game" + 0.157*"local" + 0.154*"user" + '
#   '-0.153*"human" + 0.149*"point"'),
#  (83,
#   '0.308*"also" + -0.239*"signal" + 0.165*"layer" + -0.159*"novel" + '
#   '-0.153*"representation" + -0.151*"point" + -0.149*"metric" + 0.140*"regret" '
#   '+ -0.138*"component" + -0.135*"bayesian"'),
#  (84,
#   '0.251*"online" + -0.220*"also" + 0.202*"paper" + -0.196*"sampling" + '
#   '-0.177*"decision" + -0.159*"vector" + 0.150*"constraint" + '
#   '-0.146*"optimization" + 0.142*"based" + 0.141*"large"'),
#  (85,
#   '-0.247*"variable" + 0.244*"latent" + -0.238*"error" + 0.199*"online" + '
#   '0.188*"probability" + 0.184*"point" + -0.176*"metric" + 0.176*"value" + '
#   '0.159*"proposed" + 0.149*"sampling"'),
#  (86,
#   '0.223*"case" + -0.207*"action" + 0.186*"large" + -0.165*"classification" + '
#   '-0.158*"application" + -0.154*"point" + 0.138*"noise" + -0.137*"first" + '
#   '0.132*"local" + 0.128*"input"'),
#  (87,
#   '0.196*"used" + 0.189*"experiment" + -0.186*"machine" + -0.182*"bayesian" + '
#   '0.179*"work" + -0.172*"also" + 0.172*"number" + -0.172*"propose" + '
#   '0.166*"space" + 0.164*"classification"'),
#  (88,
#   '0.193*"stochastic" + 0.189*"large" + 0.187*"memory" + -0.174*"optimal" + '
#   '-0.170*"study" + 0.161*"point" + -0.160*"component" + 0.155*"norm" + '
#   '-0.151*"efficient" + 0.150*"neuron"'),
#  (89,
#   '-0.253*"estimation" + -0.246*"deep" + 0.196*"estimator" + 0.190*"propose" + '
#   '-0.148*"point" + 0.146*"regularization" + -0.143*"sampling" + '
#   '0.141*"random" + -0.141*"response" + 0.140*"datasets"'),
#  (90,
#   '-0.257*"technique" + 0.230*"provide" + 0.208*"experiment" + -0.189*"tree" + '
#   '-0.165*"one" + -0.160*"point" + -0.159*"case" + 0.152*"decision" + '
#   '-0.149*"prior" + -0.147*"ranking"'),
#  (91,
#   '0.251*"used" + 0.219*"sampling" + 0.196*"noise" + -0.194*"system" + '
#   '0.187*"setting" + -0.181*"present" + -0.180*"probability" + 0.168*"signal" '
#   '+ -0.167*"visual" + -0.157*"random"'),
#  (92,
#   '0.187*"stochastic" + -0.169*"datasets" + 0.169*"noise" + -0.168*"optimal" + '
#   '0.166*"used" + 0.152*"value" + -0.152*"classifier" + 0.149*"similarity" + '
#   '0.131*"deep" + -0.131*"sampling"'),
#  (93,
#   '-0.317*"probability" + 0.254*"vector" + -0.203*"also" + 0.186*"query" + '
#   '0.167*"provide" + -0.162*"topic" + 0.157*"online" + -0.150*"used" + '
#   '-0.140*"signal" + 0.133*"visual"'),
#  (94,
#   '0.204*"human" + -0.203*"memory" + -0.179*"setting" + -0.165*"random" + '
#   '0.159*"present" + -0.158*"dynamic" + 0.146*"vector" + -0.146*"prior" + '
#   '0.143*"online" + -0.142*"computational"'),
#  (95,
#   '-0.237*"component" + -0.223*"local" + 0.208*"point" + 0.166*"objective" + '
#   '-0.166*"probability" + 0.160*"work" + 0.141*"random" + 0.131*"error" + '
#   '-0.126*"mixture" + 0.124*"regularization"'),
#  (96,
#   '-0.319*"signal" + 0.192*"constraint" + -0.157*"value" + -0.157*"optimal" + '
#   '-0.157*"provide" + 0.154*"probability" + -0.141*"rule" + 0.140*"work" + '
#   '0.137*"noise" + -0.131*"classification"'),
#  (97,
#   '-0.223*"dynamic" + -0.203*"one" + 0.189*"setting" + 0.173*"system" + '
#   '0.153*"constraint" + 0.150*"solution" + 0.137*"different" + '
#   '-0.129*"experiment" + -0.126*"work" + 0.124*"technique"'),
#  (98,
#   '0.192*"memory" + 0.179*"different" + -0.174*"novel" + -0.165*"study" + '
#   '0.152*"component" + -0.149*"layer" + -0.144*"neuron" + 0.142*"one" + '
#   '0.142*"noise" + -0.132*"probability"'),
#  (99,
#   '-0.224*"well" + 0.194*"use" + 0.187*"efficient" + -0.172*"novel" + '
#   '0.171*"one" + 0.170*"cost" + -0.157*"setting" + 0.142*"study" + '
#   '-0.138*"paper" + 0.129*"estimation"')]

# %% [markdown]
# # Evaluation

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.



coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)


coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='u_mass')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)
# Out:
# Coherence Score:  0.2627923251812317
#
# Coherence Score5:  0.3482224798180873
#
# Coherence Score10:  0.31993069741287766
#
# Coherence Score20:  0.3133235869765766
#
# Coherence Score50:  0.261074520396635
#
# Coherence Score100:  0.22833037626657962
#
# Coherence Score:  -1.3206663098063114
#
# Coherence Score5:  -2.071951618345915
#
# Coherence Score10:  -2.1520287893407994
#
# Coherence Score20:  -2.1447225417776052
#
# Coherence Score50:  -2.258188455342615
#
# Coherence Score100:  -2.423550537834102
