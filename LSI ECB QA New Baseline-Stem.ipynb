# %%
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['qa']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
ps = PorterStemmer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(ps.stem(word) for word in punc_free.split())
    return normalized

data = [clean(df).split() for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(5942 unique tokens: ['absenc', 'accept', 'achiev', 'activ', 'add']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.237*"would" + 0.201*"say" + 0.184*"rate" + 0.182*"said" + '
#   '0.169*"question" + 0.162*"price" + 0.159*"govern" + 0.152*"also" + '
#   '0.150*"market" + 0.147*"bank"')]
# [(0,
#   '0.237*"would" + 0.201*"say" + 0.184*"rate" + 0.182*"said" + '
#   '0.169*"question" + 0.162*"price" + 0.159*"govern" + 0.152*"also" + '
#   '0.150*"market" + 0.147*"bank"'),
#  (1,
#   '-0.226*"regard" + 0.189*"bank" + 0.180*"polici" + -0.170*"stabil" + '
#   '0.158*"one" + 0.157*"think" + 0.136*"actual" + -0.128*"observ" + '
#   '0.127*"answer" + -0.122*"level"'),
#  (2,
#   '0.405*"govern" + -0.258*"rate" + -0.257*"price" + 0.211*"decis" + '
#   '-0.198*"inflat" + 0.190*"countri" + 0.164*"bank" + 0.138*"measur" + '
#   '0.125*"question" + -0.118*"would"'),
#  (3,
#   '0.336*"euro" + -0.242*"market" + 0.214*"growth" + -0.208*"bank" + '
#   '0.173*"area" + -0.136*"risk" + 0.136*"develop" + -0.133*"inflat" + '
#   '0.132*"year" + 0.122*"say"'),
#  (4,
#   '-0.512*"rate" + -0.251*"decis" + 0.170*"risk" + -0.166*"inflat" + '
#   '-0.165*"measur" + 0.142*"think" + -0.141*"polici" + -0.137*"today" + '
#   '-0.137*"interest" + 0.137*"would"')]
# [(0,
#   '0.237*"would" + 0.201*"say" + 0.184*"rate" + 0.182*"said" + '
#   '0.169*"question" + 0.162*"price" + 0.159*"govern" + 0.152*"also" + '
#   '0.150*"market" + 0.147*"bank"'),
#  (1,
#   '0.226*"regard" + -0.189*"bank" + -0.180*"polici" + 0.170*"stabil" + '
#   '-0.158*"one" + -0.157*"think" + -0.136*"actual" + 0.128*"observ" + '
#   '-0.127*"answer" + 0.122*"level"'),
#  (2,
#   '0.405*"govern" + -0.258*"rate" + -0.257*"price" + 0.211*"decis" + '
#   '-0.198*"inflat" + 0.190*"countri" + 0.164*"bank" + 0.138*"measur" + '
#   '0.125*"question" + -0.118*"would"'),
#  (3,
#   '-0.336*"euro" + 0.242*"market" + -0.214*"growth" + 0.208*"bank" + '
#   '-0.173*"area" + 0.136*"risk" + -0.136*"develop" + 0.133*"inflat" + '
#   '-0.132*"year" + -0.122*"say"'),
#  (4,
#   '0.512*"rate" + 0.251*"decis" + -0.170*"risk" + 0.166*"inflat" + '
#   '0.165*"measur" + -0.142*"think" + 0.141*"polici" + 0.137*"today" + '
#   '0.137*"interest" + -0.137*"would"'),
#  (5,
#   '-0.359*"rate" + -0.296*"bank" + 0.295*"polici" + 0.248*"inflat" + '
#   '0.218*"monetari" + 0.165*"programm" + -0.147*"market" + 0.146*"that" + '
#   '0.131*"govern" + -0.123*"euro"'),
#  (6,
#   '0.295*"would" + -0.287*"area" + -0.273*"euro" + 0.263*"council" + '
#   '-0.252*"countri" + -0.236*"price" + -0.148*"stabil" + 0.148*"govern" + '
#   '-0.125*"deliv" + -0.123*"year"'),
#  (7,
#   '-0.314*"govern" + 0.233*"bank" + 0.232*"polici" + -0.228*"council" + '
#   '0.211*"say" + 0.205*"would" + -0.200*"time" + -0.145*"look" + '
#   '0.133*"growth" + -0.126*"chang"'),
#  (8,
#   '0.340*"price" + 0.258*"market" + 0.247*"stabil" + -0.185*"economi" + '
#   '-0.138*"see" + -0.132*"import" + -0.128*"time" + 0.119*"risk" + '
#   '0.118*"govern" + -0.117*"measur"'),
#  (9,
#   '-0.270*"monetari" + 0.231*"would" + -0.214*"risk" + -0.207*"polici" + '
#   '0.174*"rate" + 0.173*"inflat" + 0.168*"say" + 0.155*"confid" + '
#   '-0.138*"decis" + 0.136*"respons"')]
# [(0,
#   '0.237*"would" + 0.201*"say" + 0.184*"rate" + 0.182*"said" + '
#   '0.169*"question" + 0.162*"price" + 0.159*"govern" + 0.152*"also" + '
#   '0.150*"market" + 0.147*"bank"'),
#  (1,
#   '-0.226*"regard" + 0.189*"bank" + 0.180*"polici" + -0.170*"stabil" + '
#   '0.158*"one" + 0.157*"think" + 0.136*"actual" + -0.128*"observ" + '
#   '0.127*"answer" + -0.122*"level"'),
#  (2,
#   '-0.405*"govern" + 0.258*"rate" + 0.257*"price" + -0.211*"decis" + '
#   '0.198*"inflat" + -0.190*"countri" + -0.164*"bank" + -0.138*"measur" + '
#   '-0.125*"question" + 0.118*"would"'),
#  (3,
#   '0.336*"euro" + -0.242*"market" + 0.214*"growth" + -0.208*"bank" + '
#   '0.173*"area" + -0.136*"risk" + 0.136*"develop" + -0.133*"inflat" + '
#   '0.132*"year" + 0.122*"say"'),
#  (4,
#   '0.512*"rate" + 0.251*"decis" + -0.170*"risk" + 0.166*"inflat" + '
#   '0.165*"measur" + -0.142*"think" + 0.141*"polici" + 0.137*"interest" + '
#   '0.137*"today" + -0.137*"would"'),
#  (5,
#   '-0.359*"rate" + -0.296*"bank" + 0.295*"polici" + 0.248*"inflat" + '
#   '0.218*"monetari" + 0.165*"programm" + -0.147*"market" + 0.146*"that" + '
#   '0.131*"govern" + -0.123*"euro"'),
#  (6,
#   '0.295*"would" + -0.287*"area" + -0.273*"euro" + 0.263*"council" + '
#   '-0.252*"countri" + -0.236*"price" + -0.148*"stabil" + 0.148*"govern" + '
#   '-0.125*"deliv" + -0.123*"year"'),
#  (7,
#   '0.314*"govern" + -0.232*"bank" + -0.232*"polici" + 0.228*"council" + '
#   '-0.212*"say" + -0.205*"would" + 0.200*"time" + 0.145*"look" + '
#   '-0.133*"growth" + 0.126*"chang"'),
#  (8,
#   '0.340*"price" + 0.258*"market" + 0.247*"stabil" + -0.185*"economi" + '
#   '-0.138*"see" + -0.132*"import" + -0.128*"time" + 0.119*"risk" + '
#   '0.118*"govern" + -0.117*"measur"'),
#  (9,
#   '0.271*"monetari" + -0.231*"would" + 0.214*"risk" + 0.207*"polici" + '
#   '-0.174*"rate" + -0.173*"inflat" + -0.168*"say" + -0.154*"confid" + '
#   '0.137*"decis" + -0.136*"respons"'),
#  (10,
#   '-0.467*"market" + 0.397*"bank" + 0.173*"stabil" + 0.159*"price" + '
#   '-0.110*"would" + -0.108*"money" + -0.107*"observ" + -0.105*"function" + '
#   '-0.102*"polici" + -0.101*"continu"'),
#  (11,
#   '0.285*"rate" + 0.277*"risk" + -0.178*"take" + 0.176*"area" + '
#   '-0.175*"develop" + -0.141*"situat" + 0.140*"regard" + 0.138*"measur" + '
#   '-0.137*"confid" + -0.129*"us"'),
#  (12,
#   '0.224*"said" + -0.213*"would" + 0.195*"polici" + -0.184*"it" + 0.167*"rate" '
#   '+ -0.153*"decis" + -0.147*"price" + 0.140*"monetari" + 0.129*"financi" + '
#   '0.117*"situat"'),
#  (13,
#   '-0.255*"bank" + -0.211*"govern" + -0.209*"economi" + 0.175*"decis" + '
#   '0.158*"confid" + -0.151*"council" + 0.145*"would" + 0.130*"ecb" + '
#   '-0.127*"last" + 0.126*"think"'),
#  (14,
#   '-0.260*"market" + 0.235*"question" + -0.204*"that" + 0.194*"say" + '
#   '0.182*"see" + 0.165*"would" + -0.151*"situat" + -0.151*"euro" + '
#   '-0.125*"chang" + -0.121*"area"'),
#  (15,
#   '-0.285*"question" + -0.223*"observ" + -0.182*"second" + 0.175*"say" + '
#   '-0.136*"effect" + 0.134*"risk" + 0.131*"decis" + -0.131*"project" + '
#   '-0.125*"said" + 0.125*"global"'),
#  (16,
#   '0.271*"risk" + 0.253*"inflat" + -0.186*"growth" + -0.166*"that" + '
#   '0.160*"euro" + -0.155*"rate" + 0.143*"discuss" + -0.132*"see" + '
#   '0.131*"also" + 0.115*"would"'),
#  (17,
#   '0.239*"time" + 0.160*"it" + -0.154*"effect" + -0.143*"say" + '
#   '0.136*"increas" + -0.127*"reason" + 0.125*"that" + 0.116*"first" + '
#   '-0.116*"think" + -0.113*"council"'),
#  (18,
#   '-0.197*"greec" + -0.194*"say" + -0.190*"greek" + -0.172*"liquid" + '
#   '-0.159*"said" + 0.147*"council" + 0.126*"also" + 0.124*"european" + '
#   '-0.124*"month" + 0.120*"level"'),
#  (19,
#   '-0.316*"economi" + -0.187*"effect" + 0.155*"chang" + 0.125*"one" + '
#   '-0.119*"european" + -0.118*"basi" + 0.113*"regard" + -0.113*"ecb" + '
#   '-0.113*"point" + 0.112*"year"')]
# [(0,
#   '-0.237*"would" + -0.201*"say" + -0.184*"rate" + -0.182*"said" + '
#   '-0.169*"question" + -0.162*"price" + -0.159*"govern" + -0.152*"also" + '
#   '-0.150*"market" + -0.147*"bank"'),
#  (1,
#   '-0.226*"regard" + 0.189*"bank" + 0.180*"polici" + -0.170*"stabil" + '
#   '0.158*"one" + 0.157*"think" + 0.136*"actual" + -0.128*"observ" + '
#   '0.127*"answer" + -0.122*"level"'),
#  (2,
#   '0.405*"govern" + -0.258*"rate" + -0.257*"price" + 0.211*"decis" + '
#   '-0.198*"inflat" + 0.190*"countri" + 0.164*"bank" + 0.138*"measur" + '
#   '0.125*"question" + -0.118*"would"'),
#  (3,
#   '-0.336*"euro" + 0.242*"market" + -0.214*"growth" + 0.208*"bank" + '
#   '-0.173*"area" + 0.136*"risk" + -0.136*"develop" + 0.133*"inflat" + '
#   '-0.132*"year" + -0.122*"say"'),
#  (4,
#   '0.512*"rate" + 0.251*"decis" + -0.170*"risk" + 0.166*"inflat" + '
#   '0.165*"measur" + -0.142*"think" + 0.141*"polici" + 0.137*"interest" + '
#   '0.137*"today" + -0.137*"would"'),
#  (5,
#   '-0.359*"rate" + -0.296*"bank" + 0.295*"polici" + 0.248*"inflat" + '
#   '0.218*"monetari" + 0.165*"programm" + -0.147*"market" + 0.146*"that" + '
#   '0.131*"govern" + -0.123*"euro"'),
#  (6,
#   '0.295*"would" + -0.287*"area" + -0.273*"euro" + 0.263*"council" + '
#   '-0.252*"countri" + -0.236*"price" + -0.148*"stabil" + 0.148*"govern" + '
#   '-0.125*"deliv" + -0.123*"year"'),
#  (7,
#   '-0.314*"govern" + 0.232*"bank" + 0.232*"polici" + -0.228*"council" + '
#   '0.212*"say" + 0.205*"would" + -0.200*"time" + -0.145*"look" + '
#   '0.133*"growth" + -0.126*"chang"'),
#  (8,
#   '0.340*"price" + 0.258*"market" + 0.247*"stabil" + -0.185*"economi" + '
#   '-0.138*"see" + -0.132*"import" + -0.128*"time" + 0.119*"risk" + '
#   '0.118*"govern" + -0.117*"measur"'),
#  (9,
#   '0.271*"monetari" + -0.232*"would" + 0.214*"risk" + 0.207*"polici" + '
#   '-0.174*"rate" + -0.173*"inflat" + -0.168*"say" + -0.154*"confid" + '
#   '0.137*"decis" + -0.136*"respons"'),
#  (10,
#   '-0.467*"market" + 0.397*"bank" + 0.173*"stabil" + 0.159*"price" + '
#   '-0.110*"would" + -0.109*"money" + -0.107*"observ" + -0.105*"function" + '
#   '-0.102*"polici" + -0.100*"continu"'),
#  (11,
#   '-0.285*"rate" + -0.277*"risk" + 0.178*"take" + -0.176*"area" + '
#   '0.175*"develop" + 0.141*"situat" + -0.140*"regard" + -0.139*"measur" + '
#   '0.136*"confid" + 0.129*"us"'),
#  (12,
#   '-0.224*"said" + 0.213*"would" + -0.195*"polici" + 0.184*"it" + '
#   '-0.167*"rate" + 0.153*"decis" + 0.147*"price" + -0.140*"monetari" + '
#   '-0.128*"financi" + -0.116*"situat"'),
#  (13,
#   '0.255*"bank" + 0.211*"govern" + 0.209*"economi" + -0.175*"decis" + '
#   '-0.157*"confid" + 0.152*"council" + -0.146*"would" + -0.130*"ecb" + '
#   '0.126*"last" + -0.126*"think"'),
#  (14,
#   '0.260*"market" + -0.235*"question" + 0.205*"that" + -0.194*"say" + '
#   '-0.181*"see" + -0.165*"would" + 0.152*"euro" + 0.152*"situat" + '
#   '0.126*"chang" + 0.120*"area"'),
#  (15,
#   '-0.286*"question" + -0.224*"observ" + -0.182*"second" + 0.176*"say" + '
#   '-0.137*"effect" + 0.134*"risk" + 0.131*"decis" + -0.131*"project" + '
#   '-0.125*"said" + 0.124*"global"'),
#  (16,
#   '0.271*"risk" + 0.253*"inflat" + -0.186*"growth" + -0.166*"that" + '
#   '0.160*"euro" + -0.155*"rate" + 0.143*"discuss" + -0.131*"see" + '
#   '0.131*"also" + 0.115*"would"'),
#  (17,
#   '0.238*"time" + 0.161*"it" + -0.153*"effect" + -0.144*"say" + '
#   '0.135*"increas" + -0.127*"reason" + 0.125*"that" + -0.116*"think" + '
#   '0.115*"first" + -0.114*"council"'),
#  (18,
#   '0.197*"greec" + 0.196*"say" + 0.191*"greek" + 0.171*"liquid" + 0.157*"said" '
#   '+ -0.146*"council" + -0.126*"also" + -0.125*"european" + 0.124*"month" + '
#   '-0.120*"level"'),
#  (19,
#   '-0.316*"economi" + -0.187*"effect" + 0.154*"chang" + 0.126*"one" + '
#   '-0.119*"european" + -0.117*"basi" + -0.115*"ecb" + 0.114*"regard" + '
#   '-0.112*"euro" + 0.111*"year"'),
#  (20,
#   '0.271*"countri" + -0.155*"stabil" + -0.149*"discuss" + -0.137*"instrument" '
#   '+ -0.129*"inflat" + -0.127*"point" + 0.126*"measur" + 0.124*"monetari" + '
#   '-0.124*"growth" + 0.120*"interest"'),
#  (21,
#   '0.204*"economi" + 0.193*"measur" + -0.187*"confid" + -0.162*"project" + '
#   '0.153*"point" + -0.143*"level" + -0.133*"growth" + -0.132*"decis" + '
#   '-0.123*"also" + 0.123*"that"'),
#  (22,
#   '0.222*"say" + -0.220*"would" + 0.214*"effect" + 0.160*"time" + '
#   '-0.158*"polici" + -0.157*"stabil" + 0.155*"inflat" + 0.155*"question" + '
#   '-0.142*"year" + -0.114*"price"'),
#  (23,
#   '-0.219*"growth" + -0.199*"economi" + 0.199*"said" + -0.177*"look" + '
#   '0.161*"level" + -0.137*"one" + 0.135*"today" + 0.135*"us" + 0.130*"effect" '
#   '+ -0.130*"basi"'),
#  (24,
#   '0.243*"measur" + 0.236*"said" + 0.157*"regard" + -0.155*"observ" + '
#   '0.147*"fiscal" + 0.144*"risk" + -0.141*"one" + -0.132*"certainli" + '
#   '-0.126*"monetari" + 0.118*"ecb"'),
#  (25,
#   '0.218*"measur" + -0.185*"interest" + -0.178*"question" + 0.156*"today" + '
#   '-0.147*"expect" + 0.143*"say" + 0.133*"look" + 0.130*"project" + '
#   '-0.121*"risk" + -0.118*"sustain"'),
#  (26,
#   '-0.185*"risk" + -0.168*"year" + 0.147*"regard" + -0.145*"price" + '
#   '0.141*"that" + 0.138*"said" + 0.134*"growth" + -0.127*"think" + '
#   '0.126*"polici" + -0.120*"go"'),
#  (27,
#   '-0.240*"chang" + -0.171*"time" + 0.162*"point" + 0.162*"countri" + '
#   '0.157*"first" + -0.156*"financi" + -0.151*"stabil" + 0.149*"said" + '
#   '-0.140*"ecb" + 0.133*"figur"'),
#  (28,
#   '0.231*"it" + -0.223*"that" + -0.184*"term" + -0.169*"think" + '
#   '-0.164*"interest" + 0.159*"effect" + -0.156*"council" + 0.130*"take" + '
#   '0.129*"central" + 0.122*"exchang"'),
#  (29,
#   '0.321*"countri" + -0.203*"see" + -0.162*"figur" + -0.138*"economi" + '
#   '-0.136*"confid" + 0.133*"question" + -0.132*"think" + 0.128*"chang" + '
#   '0.125*"number" + -0.121*"year"'),
#  (30,
#   '0.274*"think" + 0.188*"would" + -0.157*"meet" + 0.152*"financi" + '
#   '0.140*"decis" + -0.137*"discuss" + -0.132*"confid" + -0.130*"bond" + '
#   '-0.121*"ecb" + -0.113*"level"'),
#  (31,
#   '0.214*"year" + -0.149*"structur" + -0.142*"see" + -0.140*"central" + '
#   '0.133*"clear" + -0.132*"would" + 0.129*"present" + -0.128*"reform" + '
#   '-0.126*"well" + -0.123*"alreadi"'),
#  (32,
#   '-0.185*"observ" + 0.183*"see" + -0.160*"expect" + 0.149*"countri" + '
#   '-0.148*"increas" + 0.116*"said" + -0.116*"take" + 0.114*"exchang" + '
#   '-0.111*"call" + -0.108*"fiscal"'),
#  (33,
#   '-0.187*"growth" + -0.172*"programm" + 0.165*"level" + 0.151*"increas" + '
#   '0.134*"situat" + -0.125*"said" + 0.120*"financi" + -0.118*"stabil" + '
#   '0.114*"clear" + -0.113*"observ"'),
#  (34,
#   '0.250*"that" + -0.223*"decis" + 0.150*"also" + -0.146*"time" + 0.142*"look" '
#   '+ 0.139*"countri" + 0.131*"risk" + 0.123*"say" + -0.119*"one" + '
#   '0.117*"credit"'),
#  (35,
#   '-0.179*"year" + 0.166*"us" + -0.142*"import" + -0.133*"level" + '
#   '0.124*"know" + 0.124*"growth" + 0.115*"situat" + 0.112*"decis" + '
#   '0.109*"work" + -0.108*"note"'),
#  (36,
#   '0.181*"regard" + 0.167*"ecb" + -0.155*"mention" + 0.142*"consid" + '
#   '-0.142*"said" + 0.142*"exchang" + -0.133*"clear" + 0.131*"know" + '
#   '0.118*"us" + -0.118*"see"'),
#  (37,
#   '0.228*"situat" + -0.153*"inform" + -0.140*"us" + -0.135*"first" + '
#   '-0.134*"part" + 0.129*"council" + 0.127*"expect" + -0.123*"decid" + '
#   '0.120*"liquid" + -0.120*"respons"'),
#  (38,
#   '0.176*"observ" + 0.154*"project" + 0.152*"european" + 0.136*"data" + '
#   '-0.116*"figur" + -0.116*"level" + -0.114*"discuss" + 0.108*"council" + '
#   '0.105*"think" + 0.105*"expect"'),
#  (39,
#   '-0.157*"work" + 0.157*"mandat" + 0.152*"would" + -0.144*"interest" + '
#   '-0.143*"respons" + -0.138*"decis" + -0.138*"taken" + -0.126*"economi" + '
#   '-0.124*"certainli" + -0.110*"say"'),
#  (40,
#   '-0.174*"central" + -0.164*"differ" + 0.137*"increas" + 0.136*"meet" + '
#   '0.131*"regard" + 0.123*"recoveri" + -0.120*"see" + -0.119*"growth" + '
#   '-0.118*"know" + 0.114*"messag"'),
#  (41,
#   '0.190*"observ" + -0.171*"expect" + 0.140*"level" + 0.139*"well" + '
#   '-0.130*"know" + 0.125*"assess" + -0.123*"european" + 0.119*"economi" + '
#   '0.111*"differ" + 0.108*"exchang"'),
#  (42,
#   '0.179*"certainli" + 0.142*"time" + -0.139*"commun" + -0.133*"ecb" + '
#   '0.130*"meet" + -0.129*"clear" + 0.120*"new" + -0.114*"remain" + '
#   '-0.110*"take" + 0.103*"one"'),
#  (43,
#   '-0.158*"one" + 0.137*"clear" + 0.135*"new" + -0.134*"project" + '
#   '-0.132*"respons" + 0.123*"fiscal" + 0.121*"first" + -0.111*"case" + '
#   '0.110*"would" + -0.110*"monetari"'),
#  (44,
#   '-0.219*"import" + 0.166*"chang" + -0.142*"mention" + 0.141*"function" + '
#   '-0.129*"decid" + -0.124*"respect" + 0.122*"global" + 0.121*"would" + '
#   '0.114*"respons" + 0.113*"meet"'),
#  (45,
#   '0.219*"also" + -0.121*"project" + 0.118*"today" + -0.116*"say" + '
#   '0.114*"reason" + 0.111*"first" + -0.110*"expect" + 0.103*"liquid" + '
#   '-0.100*"world" + -0.098*"ecb"'),
#  (46,
#   '-0.158*"credibl" + -0.149*"ecb" + 0.141*"regard" + 0.121*"think" + '
#   '0.118*"point" + 0.114*"question" + -0.109*"see" + 0.109*"import" + '
#   '0.106*"month" + -0.104*"today"'),
#  (47,
#   '0.167*"alreadi" + 0.154*"it" + -0.140*"discuss" + 0.131*"confid" + '
#   '-0.124*"come" + -0.121*"see" + 0.114*"stanc" + -0.110*"figur" + '
#   '0.110*"import" + -0.108*"case"'),
#  (48,
#   '0.188*"ecb" + 0.142*"bond" + 0.129*"reason" + -0.126*"again" + 0.121*"that" '
#   '+ 0.114*"observ" + -0.113*"reform" + -0.108*"messag" + 0.108*"central" + '
#   '-0.106*"currenc"'),
#  (49,
#   '-0.203*"cours" + 0.165*"meet" + 0.163*"ecb" + 0.122*"situat" + '
#   '0.121*"messag" + -0.114*"develop" + -0.112*"confid" + -0.110*"appropri" + '
#   '-0.107*"effect" + 0.103*"monetari"')]
# [(0,
#   '-0.237*"would" + -0.201*"say" + -0.184*"rate" + -0.182*"said" + '
#   '-0.169*"question" + -0.162*"price" + -0.159*"govern" + -0.152*"also" + '
#   '-0.150*"market" + -0.147*"bank"'),
#  (1,
#   '0.226*"regard" + -0.189*"bank" + -0.180*"polici" + 0.170*"stabil" + '
#   '-0.158*"one" + -0.157*"think" + -0.136*"actual" + 0.128*"observ" + '
#   '-0.127*"answer" + 0.122*"level"'),
#  (2,
#   '-0.405*"govern" + 0.258*"rate" + 0.257*"price" + -0.211*"decis" + '
#   '0.198*"inflat" + -0.190*"countri" + -0.164*"bank" + -0.138*"measur" + '
#   '-0.125*"question" + 0.118*"would"'),
#  (3,
#   '-0.336*"euro" + 0.242*"market" + -0.214*"growth" + 0.208*"bank" + '
#   '-0.173*"area" + -0.136*"develop" + 0.136*"risk" + 0.133*"inflat" + '
#   '-0.132*"year" + -0.122*"say"'),
#  (4,
#   '-0.512*"rate" + -0.251*"decis" + 0.170*"risk" + -0.166*"inflat" + '
#   '-0.165*"measur" + 0.142*"think" + -0.141*"polici" + -0.137*"interest" + '
#   '-0.137*"today" + 0.137*"would"'),
#  (5,
#   '0.359*"rate" + 0.296*"bank" + -0.295*"polici" + -0.248*"inflat" + '
#   '-0.218*"monetari" + -0.165*"programm" + 0.147*"market" + -0.146*"that" + '
#   '-0.131*"govern" + 0.123*"euro"'),
#  (6,
#   '-0.295*"would" + 0.287*"area" + 0.273*"euro" + -0.263*"council" + '
#   '0.252*"countri" + 0.236*"price" + 0.148*"stabil" + -0.148*"govern" + '
#   '0.125*"deliv" + 0.123*"year"'),
#  (7,
#   '-0.314*"govern" + 0.232*"bank" + 0.232*"polici" + -0.228*"council" + '
#   '0.212*"say" + 0.205*"would" + -0.200*"time" + -0.145*"look" + '
#   '0.133*"growth" + -0.126*"chang"'),
#  (8,
#   '0.340*"price" + 0.258*"market" + 0.247*"stabil" + -0.185*"economi" + '
#   '-0.138*"see" + -0.132*"import" + -0.128*"time" + 0.119*"risk" + '
#   '0.118*"govern" + -0.117*"measur"'),
#  (9,
#   '0.271*"monetari" + -0.232*"would" + 0.214*"risk" + 0.207*"polici" + '
#   '-0.174*"rate" + -0.173*"inflat" + -0.168*"say" + -0.154*"confid" + '
#   '0.138*"decis" + -0.136*"respons"'),
#  (10,
#   '-0.467*"market" + 0.397*"bank" + 0.173*"stabil" + 0.159*"price" + '
#   '-0.110*"would" + -0.109*"money" + -0.107*"observ" + -0.106*"function" + '
#   '-0.102*"polici" + -0.100*"continu"'),
#  (11,
#   '-0.285*"rate" + -0.277*"risk" + 0.178*"take" + -0.176*"area" + '
#   '0.175*"develop" + 0.141*"situat" + -0.140*"regard" + -0.139*"measur" + '
#   '0.136*"confid" + 0.129*"us"'),
#  (12,
#   '-0.224*"said" + 0.213*"would" + -0.195*"polici" + 0.184*"it" + '
#   '-0.167*"rate" + 0.153*"decis" + 0.147*"price" + -0.140*"monetari" + '
#   '-0.128*"financi" + -0.116*"situat"'),
#  (13,
#   '0.255*"bank" + 0.211*"govern" + 0.209*"economi" + -0.175*"decis" + '
#   '-0.157*"confid" + 0.152*"council" + -0.146*"would" + -0.130*"ecb" + '
#   '0.126*"last" + -0.126*"think"'),
#  (14,
#   '-0.260*"market" + 0.235*"question" + -0.205*"that" + 0.194*"say" + '
#   '0.181*"see" + 0.165*"would" + -0.152*"euro" + -0.151*"situat" + '
#   '-0.126*"chang" + -0.120*"area"'),
#  (15,
#   '0.285*"question" + 0.224*"observ" + 0.182*"second" + -0.176*"say" + '
#   '0.137*"effect" + -0.134*"risk" + 0.131*"project" + -0.131*"decis" + '
#   '0.125*"said" + -0.124*"global"'),
#  (16,
#   '0.271*"risk" + 0.253*"inflat" + -0.186*"growth" + -0.166*"that" + '
#   '0.160*"euro" + -0.155*"rate" + 0.143*"discuss" + -0.131*"see" + '
#   '0.130*"also" + 0.115*"would"'),
#  (17,
#   '-0.239*"time" + -0.160*"it" + 0.153*"effect" + 0.144*"say" + '
#   '-0.135*"increas" + 0.127*"reason" + -0.125*"that" + 0.116*"think" + '
#   '-0.116*"first" + 0.114*"council"'),
#  (18,
#   '-0.198*"greec" + -0.195*"say" + -0.190*"greek" + -0.171*"liquid" + '
#   '-0.157*"said" + 0.146*"council" + 0.127*"also" + 0.125*"european" + '
#   '-0.124*"month" + 0.120*"level"'),
#  (19,
#   '-0.316*"economi" + -0.187*"effect" + 0.154*"chang" + 0.126*"one" + '
#   '-0.119*"european" + -0.117*"basi" + -0.115*"ecb" + 0.114*"regard" + '
#   '-0.112*"euro" + 0.112*"year"'),
#  (20,
#   '0.271*"countri" + -0.155*"stabil" + -0.149*"discuss" + -0.137*"instrument" '
#   '+ -0.129*"inflat" + -0.127*"point" + 0.126*"measur" + 0.124*"monetari" + '
#   '-0.124*"growth" + 0.120*"interest"'),
#  (21,
#   '0.205*"economi" + 0.192*"measur" + -0.187*"confid" + -0.162*"project" + '
#   '0.153*"point" + -0.143*"level" + -0.133*"growth" + -0.132*"decis" + '
#   '-0.123*"also" + 0.123*"that"'),
#  (22,
#   '0.222*"say" + -0.219*"would" + 0.214*"effect" + 0.160*"time" + '
#   '-0.158*"polici" + -0.157*"stabil" + 0.155*"inflat" + 0.154*"question" + '
#   '-0.141*"year" + -0.114*"price"'),
#  (23,
#   '0.220*"growth" + 0.199*"economi" + -0.198*"said" + 0.177*"look" + '
#   '-0.161*"level" + 0.137*"one" + -0.136*"today" + -0.135*"us" + '
#   '-0.131*"effect" + 0.129*"basi"'),
#  (24,
#   '-0.245*"measur" + -0.237*"said" + -0.155*"regard" + 0.154*"observ" + '
#   '-0.146*"fiscal" + -0.143*"risk" + 0.141*"one" + 0.132*"certainli" + '
#   '0.126*"monetari" + -0.118*"ecb"'),
#  (25,
#   '0.217*"measur" + -0.184*"interest" + -0.178*"question" + 0.156*"today" + '
#   '-0.147*"expect" + 0.144*"say" + 0.133*"look" + 0.130*"project" + '
#   '-0.122*"risk" + -0.118*"sustain"'),
#  (26,
#   '0.185*"risk" + 0.167*"year" + -0.147*"regard" + 0.145*"price" + '
#   '-0.141*"that" + -0.138*"said" + -0.134*"growth" + 0.126*"think" + '
#   '-0.125*"polici" + 0.120*"go"'),
#  (27,
#   '0.241*"chang" + 0.170*"time" + -0.162*"countri" + -0.162*"point" + '
#   '0.157*"financi" + -0.156*"first" + 0.151*"stabil" + -0.150*"said" + '
#   '0.140*"ecb" + -0.133*"figur"'),
#  (28,
#   '0.232*"it" + -0.224*"that" + -0.183*"term" + -0.169*"think" + '
#   '-0.164*"interest" + 0.160*"effect" + -0.157*"council" + 0.131*"take" + '
#   '0.128*"central" + 0.123*"exchang"'),
#  (29,
#   '0.321*"countri" + -0.202*"see" + -0.162*"figur" + -0.138*"economi" + '
#   '-0.136*"confid" + -0.133*"think" + 0.133*"question" + 0.126*"chang" + '
#   '0.124*"number" + -0.120*"year"'),
#  (30,
#   '0.273*"think" + 0.187*"would" + -0.157*"meet" + 0.153*"financi" + '
#   '0.140*"decis" + -0.137*"discuss" + -0.133*"confid" + -0.130*"bond" + '
#   '-0.120*"ecb" + -0.113*"level"'),
#  (31,
#   '0.215*"year" + -0.148*"structur" + -0.142*"see" + -0.141*"central" + '
#   '0.134*"clear" + -0.132*"would" + 0.130*"present" + -0.129*"reform" + '
#   '-0.126*"well" + -0.123*"alreadi"'),
#  (32,
#   '0.184*"observ" + -0.183*"see" + 0.159*"expect" + -0.148*"countri" + '
#   '0.148*"increas" + 0.117*"take" + -0.116*"said" + -0.115*"exchang" + '
#   '0.109*"call" + 0.108*"fiscal"'),
#  (33,
#   '0.186*"growth" + 0.173*"programm" + -0.164*"level" + -0.149*"increas" + '
#   '-0.134*"situat" + 0.123*"said" + -0.119*"financi" + 0.119*"stabil" + '
#   '0.115*"observ" + -0.114*"clear"'),
#  (34,
#   '0.251*"that" + -0.225*"decis" + 0.148*"also" + -0.146*"time" + 0.141*"look" '
#   '+ 0.137*"countri" + 0.130*"risk" + 0.123*"say" + -0.119*"one" + '
#   '0.117*"credit"'),
#  (35,
#   '-0.179*"year" + 0.166*"us" + -0.140*"import" + -0.134*"level" + '
#   '0.125*"growth" + 0.124*"know" + 0.114*"situat" + 0.112*"decis" + '
#   '0.108*"countri" + 0.108*"work"'),
#  (36,
#   '0.181*"regard" + 0.167*"ecb" + -0.155*"mention" + 0.143*"exchang" + '
#   '-0.143*"said" + 0.142*"consid" + -0.134*"clear" + 0.130*"know" + '
#   '-0.118*"see" + 0.117*"us"'),
#  (37,
#   '0.227*"situat" + -0.153*"inform" + -0.141*"us" + -0.135*"first" + '
#   '-0.134*"part" + 0.128*"council" + 0.127*"expect" + -0.123*"decid" + '
#   '0.120*"liquid" + -0.119*"respons"'),
#  (38,
#   '-0.175*"observ" + -0.155*"project" + -0.152*"european" + -0.136*"data" + '
#   '0.117*"level" + 0.117*"figur" + 0.113*"discuss" + -0.105*"council" + '
#   '-0.105*"expect" + 0.103*"economi"'),
#  (39,
#   '0.157*"mandat" + -0.157*"work" + 0.152*"would" + -0.144*"interest" + '
#   '-0.143*"respons" + -0.138*"decis" + -0.138*"taken" + -0.126*"economi" + '
#   '-0.125*"certainli" + -0.110*"say"'),
#  (40,
#   '-0.174*"central" + -0.163*"differ" + 0.136*"increas" + 0.134*"meet" + '
#   '0.132*"regard" + 0.123*"recoveri" + -0.119*"growth" + -0.119*"see" + '
#   '-0.119*"know" + 0.114*"messag"'),
#  (41,
#   '-0.189*"observ" + 0.170*"expect" + -0.140*"level" + -0.137*"well" + '
#   '0.130*"know" + 0.125*"european" + -0.124*"assess" + -0.120*"economi" + '
#   '-0.108*"regard" + -0.108*"differ"'),
#  (42,
#   '0.179*"certainli" + 0.142*"time" + -0.138*"commun" + -0.131*"ecb" + '
#   '0.128*"meet" + -0.125*"clear" + 0.123*"new" + -0.112*"remain" + '
#   '-0.110*"take" + 0.105*"one"'),
#  (43,
#   '-0.161*"one" + 0.135*"clear" + -0.133*"project" + 0.131*"new" + '
#   '-0.128*"respons" + 0.122*"first" + 0.122*"fiscal" + 0.115*"would" + '
#   '-0.111*"monetari" + -0.108*"case"'),
#  (44,
#   '-0.216*"import" + 0.166*"chang" + 0.143*"function" + -0.140*"mention" + '
#   '-0.128*"decid" + -0.126*"respect" + 0.120*"global" + 0.119*"respons" + '
#   '0.117*"would" + -0.113*"new"'),
#  (45,
#   '-0.219*"also" + 0.120*"project" + 0.116*"say" + -0.114*"today" + '
#   '0.112*"expect" + -0.112*"reason" + -0.111*"first" + -0.107*"liquid" + '
#   '0.099*"world" + -0.098*"differ"'),
#  (46,
#   '0.157*"credibl" + 0.152*"ecb" + -0.144*"regard" + -0.120*"think" + '
#   '-0.118*"point" + -0.114*"question" + -0.110*"import" + 0.108*"see" + '
#   '-0.104*"month" + 0.101*"deliv"'),
#  (47,
#   '-0.169*"alreadi" + -0.154*"it" + 0.140*"discuss" + -0.129*"confid" + '
#   '0.128*"come" + 0.121*"see" + -0.114*"stanc" + -0.113*"import" + '
#   '0.111*"figur" + 0.111*"case"'),
#  (48,
#   '-0.189*"ecb" + -0.144*"bond" + -0.129*"reason" + 0.127*"again" + '
#   '-0.124*"that" + 0.113*"reform" + -0.112*"observ" + -0.109*"central" + '
#   '0.106*"messag" + 0.106*"also"'),
#  (49,
#   '-0.201*"cours" + 0.163*"meet" + 0.160*"ecb" + 0.125*"messag" + '
#   '0.124*"situat" + -0.118*"develop" + -0.115*"appropri" + -0.112*"confid" + '
#   '-0.106*"effect" + 0.102*"monetari"'),
#  (50,
#   '0.142*"possibl" + 0.136*"year" + -0.127*"discuss" + 0.124*"inflat" + '
#   '-0.117*"polici" + 0.114*"today" + 0.112*"way" + -0.108*"level" + '
#   '0.107*"issu" + -0.105*"credit"'),
#  (51,
#   '-0.168*"meet" + -0.151*"cours" + 0.141*"also" + -0.113*"figur" + '
#   '-0.113*"medium" + 0.110*"europ" + 0.110*"point" + -0.108*"import" + '
#   '0.106*"one" + -0.099*"thing"'),
#  (52,
#   '-0.193*"today" + 0.185*"differ" + -0.150*"area" + -0.122*"that" + '
#   '0.119*"measur" + 0.111*"call" + -0.110*"basi" + 0.110*"interest" + '
#   '-0.106*"appropri" + 0.103*"financi"'),
#  (53,
#   '0.156*"would" + 0.154*"economi" + 0.138*"interest" + 0.133*"financ" + '
#   '-0.131*"european" + -0.123*"respons" + -0.122*"say" + -0.110*"institut" + '
#   '-0.103*"statement" + -0.102*"assess"'),
#  (54,
#   '0.147*"mandat" + -0.144*"expect" + -0.130*"continu" + -0.128*"balanc" + '
#   '-0.126*"decid" + -0.126*"also" + -0.115*"meet" + -0.109*"respons" + '
#   '-0.107*"mention" + 0.106*"inflat"'),
#  (55,
#   '0.187*"global" + -0.155*"increas" + -0.153*"appropri" + -0.134*"year" + '
#   '0.126*"project" + 0.120*"import" + 0.120*"first" + -0.119*"also" + '
#   '-0.115*"implement" + 0.109*"staff"'),
#  (56,
#   '0.138*"level" + -0.137*"comment" + 0.134*"chang" + 0.127*"statement" + '
#   '0.117*"inflat" + -0.116*"rule" + -0.116*"gener" + -0.115*"quarter" + '
#   '-0.111*"also" + 0.110*"ask"'),
#  (57,
#   '-0.195*"mention" + -0.147*"time" + -0.133*"move" + -0.116*"also" + '
#   '0.106*"basi" + 0.105*"noth" + 0.101*"point" + -0.101*"import" + '
#   '-0.098*"vigil" + 0.097*"us"'),
#  (58,
#   '0.134*"know" + -0.129*"think" + 0.126*"consid" + -0.126*"mandat" + '
#   '-0.116*"continu" + 0.116*"year" + -0.113*"area" + 0.112*"so" + 0.109*"go" + '
#   '0.108*"financi"'),
#  (59,
#   '0.178*"decid" + -0.141*"look" + -0.131*"let" + 0.131*"much" + 0.119*"go" + '
#   '-0.119*"expect" + -0.114*"new" + -0.110*"one" + 0.110*"regard" + '
#   '-0.109*"differ"'),
#  (60,
#   '0.149*"present" + -0.148*"last" + -0.136*"indic" + -0.127*"one" + '
#   '-0.121*"confid" + 0.121*"take" + -0.113*"explain" + 0.109*"assess" + '
#   '0.107*"state" + -0.107*"interest"'),
#  (61,
#   '0.136*"council" + 0.127*"polici" + 0.125*"new" + -0.116*"judgement" + '
#   '-0.111*"balanc" + -0.110*"us" + 0.106*"figur" + 0.106*"system" + '
#   '-0.103*"oil" + -0.101*"situat"'),
#  (62,
#   '-0.147*"financi" + -0.131*"differ" + 0.128*"judgement" + -0.125*"term" + '
#   '0.122*"condit" + 0.121*"done" + 0.117*"mention" + 0.114*"alreadi" + '
#   '-0.112*"analysi" + -0.112*"answer"'),
#  (63,
#   '0.133*"statement" + -0.128*"european" + -0.124*"need" + '
#   '-0.114*"uncertainti" + -0.114*"programm" + -0.114*"first" + -0.102*"call" + '
#   '0.102*"econom" + -0.101*"make" + 0.100*"question"'),
#  (64,
#   '-0.142*"come" + 0.120*"factor" + 0.118*"develop" + -0.118*"work" + '
#   '-0.115*"economi" + 0.108*"figur" + 0.106*"fiscal" + 0.105*"number" + '
#   '0.105*"respons" + 0.101*"ecb"'),
#  (65,
#   '-0.165*"regard" + -0.145*"recoveri" + 0.138*"issu" + 0.135*"remain" + '
#   '0.127*"nonstandard" + -0.122*"observ" + -0.120*"posit" + 0.116*"effect" + '
#   '0.115*"number" + -0.108*"differ"'),
#  (66,
#   '-0.171*"improv" + 0.138*"fact" + -0.127*"rule" + 0.113*"necessari" + '
#   '0.110*"stabil" + -0.103*"question" + -0.096*"tender" + -0.096*"omt" + '
#   '-0.093*"much" + 0.090*"stress"'),
#  (67,
#   '0.134*"bond" + -0.125*"appropri" + -0.124*"growth" + -0.120*"author" + '
#   '-0.109*"discuss" + -0.109*"ltro" + -0.107*"comment" + -0.105*"global" + '
#   '-0.104*"respons" + 0.102*"stabil"'),
#  (68,
#   '-0.148*"mention" + 0.143*"credit" + -0.138*"want" + -0.120*"financ" + '
#   '-0.110*"fact" + -0.110*"work" + -0.108*"come" + 0.107*"certainli" + '
#   '0.101*"alway" + 0.100*"account"'),
#  (69,
#   '-0.152*"billion" + 0.128*"could" + 0.124*"need" + -0.122*"direct" + '
#   '-0.119*"end" + 0.114*"level" + -0.101*"fact" + -0.099*"problem" + '
#   '-0.093*"import" + -0.090*"govern"'),
#  (70,
#   '0.145*"work" + -0.130*"comment" + 0.124*"know" + 0.108*"greec" + '
#   '-0.107*"let" + -0.106*"good" + -0.105*"next" + 0.104*"central" + '
#   '-0.096*"demand" + -0.096*"differ"'),
#  (71,
#   '-0.139*"close" + -0.129*"first" + 0.123*"term" + -0.119*"respons" + '
#   '0.113*"work" + -0.107*"continu" + -0.106*"committe" + 0.103*"state" + '
#   '-0.101*"us" + 0.093*"fact"'),
#  (72,
#   '0.134*"could" + -0.130*"last" + 0.123*"increas" + 0.117*"euro" + '
#   '-0.114*"know" + -0.112*"assess" + 0.110*"stress" + -0.103*"currenc" + '
#   '-0.099*"sector" + 0.097*"place"'),
#  (73,
#   '-0.138*"ecb" + 0.131*"exchang" + -0.127*"state" + -0.125*"unit" + '
#   '0.121*"number" + -0.120*"differ" + -0.113*"sinc" + -0.112*"reform" + '
#   '0.107*"comment" + 0.102*"guidanc"'),
#  (74,
#   '0.156*"programm" + -0.126*"issu" + 0.111*"import" + -0.106*"regard" + '
#   '0.105*"see" + -0.103*"point" + 0.102*"increas" + -0.100*"public" + '
#   '-0.099*"consid" + 0.097*"nonstandard"'),
#  (75,
#   '0.120*"level" + -0.118*"place" + -0.107*"differ" + -0.107*"euro" + '
#   '0.102*"collater" + 0.098*"press" + 0.096*"fund" + 0.094*"european" + '
#   '0.094*"note" + 0.093*"way"'),
#  (76,
#   '-0.171*"central" + -0.120*"point" + 0.115*"good" + 0.113*"it" + '
#   '0.105*"financi" + -0.104*"certainli" + 0.101*"low" + 0.097*"oper" + '
#   '0.090*"govern" + 0.090*"analysi"'),
#  (77,
#   '0.159*"balanc" + 0.117*"high" + 0.114*"make" + -0.108*"account" + '
#   '0.108*"whole" + 0.107*"interest" + -0.103*"today" + -0.101*"alreadi" + '
#   '0.098*"bond" + -0.095*"problem"'),
#  (78,
#   '-0.134*"recoveri" + -0.115*"oper" + -0.112*"analysi" + 0.112*"strong" + '
#   '0.111*"reason" + 0.106*"today" + 0.098*"thing" + -0.097*"alway" + '
#   '0.096*"credibl" + 0.095*"year"'),
#  (79,
#   '-0.130*"work" + -0.128*"import" + 0.124*"financi" + 0.107*"account" + '
#   '-0.106*"consid" + 0.104*"situat" + -0.103*"low" + 0.096*"take" + '
#   '-0.094*"us" + -0.092*"quit"'),
#  (80,
#   '-0.157*"still" + -0.112*"close" + 0.108*"may" + 0.107*"respect" + '
#   '-0.105*"figur" + 0.101*"month" + -0.097*"one" + -0.095*"posit" + '
#   '-0.093*"much" + -0.087*"view"'),
#  (81,
#   '-0.139*"alreadi" + 0.126*"time" + -0.109*"so" + -0.103*"could" + '
#   '-0.099*"structur" + 0.093*"mani" + -0.092*"concern" + -0.091*"extent" + '
#   '-0.091*"discuss" + 0.091*"growth"'),
#  (82,
#   '-0.168*"make" + 0.115*"basi" + -0.113*"statement" + 0.111*"implement" + '
#   '0.111*"expect" + -0.108*"programm" + 0.104*"absolut" + 0.103*"liquid" + '
#   '0.102*"exchang" + 0.095*"member"'),
#  (83,
#   '0.136*"currenc" + 0.129*"statement" + -0.116*"real" + -0.107*"growth" + '
#   '0.104*"made" + -0.089*"monetari" + -0.085*"think" + 0.084*"use" + '
#   '-0.084*"alert" + 0.083*"anchor"'),
#  (84,
#   '0.137*"could" + 0.124*"sector" + 0.114*"line" + 0.111*"discuss" + '
#   '-0.109*"crisi" + -0.104*"today" + -0.097*"comment" + -0.097*"remain" + '
#   '-0.094*"figur" + 0.093*"develop"'),
#  (85,
#   '0.131*"messag" + -0.117*"judgement" + -0.116*"new" + -0.110*"effect" + '
#   '0.106*"well" + 0.103*"differ" + 0.102*"press" + -0.097*"overal" + '
#   '0.094*"confirm" + 0.091*"come"'),
#  (86,
#   '-0.130*"alreadi" + -0.126*"nonstandard" + -0.118*"econom" + '
#   '0.107*"understand" + -0.106*"move" + -0.106*"world" + -0.105*"also" + '
#   '-0.104*"month" + 0.104*"again" + -0.098*"us"'),
#  (87,
#   '-0.111*"measur" + -0.108*"again" + 0.107*"unit" + 0.101*"qe" + '
#   '0.098*"invest" + -0.096*"transpar" + 0.095*"part" + 0.092*"way" + '
#   '0.090*"certainli" + -0.090*"mention"'),
#  (88,
#   '0.124*"uncertainti" + 0.122*"well" + 0.111*"now" + 0.101*"care" + '
#   '0.097*"help" + -0.096*"today" + -0.096*"treati" + 0.096*"respons" + '
#   '0.095*"make" + -0.093*"real"'),
#  (89,
#   '-0.130*"decid" + 0.113*"level" + -0.108*"assess" + 0.105*"use" + '
#   '0.103*"deliv" + -0.101*"look" + -0.100*"again" + -0.100*"give" + '
#   '-0.100*"realli" + 0.091*"econom"'),
#  (90,
#   '0.113*"close" + -0.108*"second" + 0.106*"analysi" + -0.106*"us" + '
#   '-0.104*"new" + -0.099*"nonstandard" + 0.099*"mention" + 0.098*"credit" + '
#   '-0.096*"clear" + -0.096*"place"'),
#  (91,
#   '-0.116*"uncertainti" + -0.108*"european" + 0.098*"factor" + 0.097*"someth" '
#   '+ -0.095*"look" + 0.094*"account" + 0.094*"unit" + -0.091*"whole" + '
#   '0.091*"is" + 0.090*"gener"'),
#  (92,
#   '0.153*"today" + -0.119*"chang" + 0.114*"recoveri" + -0.111*"second" + '
#   '0.109*"contribut" + -0.104*"european" + -0.098*"help" + 0.093*"first" + '
#   '-0.090*"even" + 0.089*"state"'),
#  (93,
#   '-0.126*"global" + -0.126*"differ" + 0.120*"make" + -0.116*"singl" + '
#   '0.111*"mandat" + 0.105*"meet" + -0.096*"credibl" + 0.096*"greec" + '
#   '0.095*"high" + -0.093*"posit"'),
#  (94,
#   '0.130*"continu" + -0.113*"press" + 0.112*"ask" + -0.099*"take" + '
#   '0.098*"financi" + -0.097*"econom" + -0.095*"move" + -0.094*"expect" + '
#   '0.094*"come" + 0.092*"countri"'),
#  (95,
#   '0.133*"publish" + -0.119*"today" + 0.112*"account" + -0.109*"financ" + '
#   '-0.105*"much" + -0.102*"basi" + -0.102*"presid" + 0.097*"economi" + '
#   '-0.096*"strong" + 0.093*"confid"'),
#  (96,
#   '0.124*"fiscal" + 0.122*"econom" + 0.121*"posit" + 0.119*"figur" + '
#   '0.112*"happen" + -0.104*"again" + -0.102*"increas" + 0.100*"expect" + '
#   '0.093*"point" + 0.088*"gener"'),
#  (97,
#   '-0.151*"come" + 0.135*"concern" + 0.103*"particular" + 0.100*"money" + '
#   '-0.098*"credibl" + 0.098*"let" + -0.092*"financi" + -0.090*"econom" + '
#   '0.090*"figur" + -0.088*"cypru"'),
#  (98,
#   '-0.112*"money" + 0.110*"continu" + 0.109*"countri" + 0.101*"function" + '
#   '-0.101*"today" + 0.097*"start" + 0.093*"inform" + 0.092*"decis" + '
#   '0.088*"number" + 0.084*"labour"'),
#  (99,
#   '0.119*"european" + 0.116*"commun" + 0.110*"so" + -0.107*"particular" + '
#   '0.107*"comment" + -0.104*"know" + 0.098*"respect" + 0.095*"consid" + '
#   '-0.091*"revis" + 0.088*"no"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.



coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)


coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='u_mass')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)
# Out:
# Coherence Score:  0.23931973060457498
#
# Coherence Score5:  0.3038024617431102
#
# Coherence Score10:  0.31881994946950865
#
# Coherence Score20:  0.28206499176276767
#
# Coherence Score50:  0.25332115388860443
#
# Coherence Score100:  0.23670646308958657
#
# Coherence Score:  -0.03100727216097961
#
# Coherence Score5:  -0.2063867675970989
#
# Coherence Score10:  -0.2710258478686366
#
# Coherence Score20:  -0.2873307660876176
#
# Coherence Score50:  -0.6969270414667078
#
# Coherence Score100:  -0.5946345010740851
