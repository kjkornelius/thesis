# %%
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['qa']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(8371 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# filter words that occur in more than 90% of documents
id2word.filter_extremes(no_above = 0.900)
print(id2word)
# Out:
# Dictionary(3434 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.179*"regard" + 0.169*"risk" + 0.169*"important" + 0.167*"country" + '
#   '0.165*"economy" + 0.126*"situation" + 0.124*"ecb" + 0.118*"term" + '
#   '0.113*"government" + 0.101*"certainly"')]
# [(0,
#   '0.179*"regard" + 0.169*"risk" + 0.169*"important" + 0.167*"country" + '
#   '0.165*"economy" + 0.126*"situation" + 0.124*"ecb" + 0.118*"term" + '
#   '0.113*"government" + 0.101*"certainly"'),
#  (1,
#   '0.280*"regard" + -0.171*"actually" + -0.152*"answer" + -0.137*"ecb" + '
#   '0.132*"appropriate" + 0.127*"particular" + -0.120*"thing" + 0.120*"number" '
#   '+ 0.116*"again" + -0.114*"country"'),
#  (2,
#   '0.367*"government" + 0.285*"country" + 0.230*"measure" + -0.225*"risk" + '
#   '0.153*"programme" + -0.151*"analysis" + 0.125*"nonstandard" + '
#   '-0.119*"information" + -0.116*"certainly" + -0.116*"oil"'),
#  (3,
#   '0.218*"development" + 0.196*"european" + -0.182*"risk" + 0.182*"exchange" + '
#   '-0.144*"measure" + 0.136*"may" + 0.134*"central" + -0.134*"credit" + '
#   '0.130*"cannot" + 0.127*"europe"'),
#  (4,
#   '0.287*"risk" + -0.185*"thats" + -0.169*"programme" + 0.161*"money" + '
#   '-0.160*"economy" + -0.152*"reform" + 0.148*"ecb" + 0.146*"operation" + '
#   '-0.137*"expectation" + -0.136*"structural"')]
# [(0,
#   '0.179*"regard" + 0.169*"risk" + 0.169*"important" + 0.167*"country" + '
#   '0.165*"economy" + 0.126*"situation" + 0.124*"ecb" + 0.118*"term" + '
#   '0.113*"government" + 0.101*"certainly"'),
#  (1,
#   '0.280*"regard" + -0.171*"actually" + -0.152*"answer" + -0.137*"ecb" + '
#   '0.132*"appropriate" + 0.127*"particular" + -0.120*"thing" + 0.120*"number" '
#   '+ 0.116*"again" + -0.114*"country"'),
#  (2,
#   '0.367*"government" + 0.285*"country" + 0.230*"measure" + -0.225*"risk" + '
#   '0.153*"programme" + -0.151*"analysis" + 0.125*"nonstandard" + '
#   '-0.119*"information" + -0.116*"certainly" + -0.116*"oil"'),
#  (3,
#   '0.218*"development" + 0.196*"european" + -0.182*"risk" + 0.181*"exchange" + '
#   '-0.144*"measure" + 0.136*"may" + 0.134*"central" + -0.134*"credit" + '
#   '0.130*"cannot" + 0.127*"europe"'),
#  (4,
#   '0.287*"risk" + -0.186*"thats" + -0.169*"programme" + 0.161*"money" + '
#   '-0.160*"economy" + -0.153*"reform" + 0.148*"ecb" + 0.146*"operation" + '
#   '-0.137*"expectation" + -0.136*"structural"'),
#  (5,
#   '-0.246*"measure" + 0.179*"risk" + 0.164*"reform" + 0.163*"country" + '
#   '0.156*"ecb" + -0.122*"effect" + 0.115*"job" + 0.115*"responsibility" + '
#   '0.113*"analysis" + -0.113*"appropriate"'),
#  (6,
#   '0.305*"country" + -0.249*"it" + 0.226*"economy" + -0.216*"risk" + '
#   '-0.207*"programme" + -0.157*"greek" + -0.151*"bond" + -0.142*"greece" + '
#   '-0.133*"government" + 0.124*"situation"'),
#  (7,
#   '0.190*"situation" + -0.189*"country" + 0.170*"important" + 0.163*"change" + '
#   '0.156*"confidence" + -0.152*"regard" + -0.151*"medium" + -0.150*"deliver" + '
#   '0.146*"month" + 0.135*"analysis"'),
#  (8,
#   '0.192*"risk" + 0.189*"country" + -0.183*"confidence" + -0.180*"ecb" + '
#   '-0.174*"financial" + 0.169*"change" + -0.150*"central" + 0.146*"government" '
#   '+ -0.144*"european" + 0.143*"information"'),
#  (9,
#   '0.288*"economy" + -0.216*"it" + 0.201*"risk" + -0.167*"confidence" + '
#   '0.148*"financial" + -0.138*"medium" + -0.129*"term" + 0.118*"central" + '
#   '-0.116*"balance" + 0.113*"global"')]
# [(0,
#   '0.179*"regard" + 0.169*"risk" + 0.169*"important" + 0.167*"country" + '
#   '0.165*"economy" + 0.126*"situation" + 0.124*"ecb" + 0.118*"term" + '
#   '0.113*"government" + 0.101*"certainly"'),
#  (1,
#   '0.280*"regard" + -0.171*"actually" + -0.152*"answer" + -0.137*"ecb" + '
#   '0.132*"appropriate" + 0.127*"particular" + -0.120*"thing" + 0.120*"number" '
#   '+ 0.116*"again" + -0.114*"country"'),
#  (2,
#   '0.367*"government" + 0.285*"country" + 0.230*"measure" + -0.225*"risk" + '
#   '0.153*"programme" + -0.151*"analysis" + 0.125*"nonstandard" + '
#   '-0.119*"information" + -0.116*"certainly" + -0.116*"oil"'),
#  (3,
#   '-0.218*"development" + -0.196*"european" + 0.182*"risk" + -0.181*"exchange" '
#   '+ 0.144*"measure" + -0.136*"may" + -0.134*"central" + 0.134*"credit" + '
#   '-0.131*"cannot" + -0.127*"europe"'),
#  (4,
#   '-0.288*"risk" + 0.185*"thats" + 0.169*"programme" + -0.161*"money" + '
#   '0.160*"economy" + 0.153*"reform" + -0.148*"ecb" + -0.145*"operation" + '
#   '0.137*"expectation" + 0.136*"structural"'),
#  (5,
#   '-0.246*"measure" + 0.179*"risk" + 0.164*"reform" + 0.163*"country" + '
#   '0.156*"ecb" + -0.122*"effect" + 0.115*"job" + 0.115*"responsibility" + '
#   '-0.113*"appropriate" + 0.113*"analysis"'),
#  (6,
#   '0.304*"country" + -0.249*"it" + 0.226*"economy" + -0.216*"risk" + '
#   '-0.207*"programme" + -0.157*"greek" + -0.151*"bond" + -0.142*"greece" + '
#   '-0.133*"government" + 0.125*"situation"'),
#  (7,
#   '-0.191*"situation" + 0.188*"country" + -0.170*"important" + -0.163*"change" '
#   '+ -0.156*"confidence" + 0.151*"regard" + 0.151*"medium" + 0.149*"deliver" + '
#   '-0.147*"month" + -0.137*"analysis"'),
#  (8,
#   '-0.192*"risk" + -0.191*"country" + 0.186*"confidence" + 0.181*"ecb" + '
#   '0.172*"financial" + -0.168*"change" + 0.150*"central" + -0.145*"government" '
#   '+ 0.143*"european" + -0.140*"information"'),
#  (9,
#   '0.289*"economy" + -0.216*"it" + 0.200*"risk" + -0.167*"confidence" + '
#   '0.147*"financial" + -0.138*"medium" + -0.129*"term" + 0.119*"central" + '
#   '-0.116*"balance" + 0.114*"global"'),
#  (10,
#   '-0.303*"measure" + 0.253*"greece" + 0.228*"greek" + -0.214*"risk" + '
#   '0.178*"economy" + 0.149*"ela" + 0.142*"liquidity" + 0.130*"government" + '
#   '-0.123*"nonstandard" + -0.122*"fiscal"'),
#  (11,
#   '0.218*"government" + 0.214*"risk" + -0.185*"measure" + 0.171*"financial" + '
#   '-0.168*"country" + -0.158*"economy" + -0.150*"ecb" + 0.143*"confidence" + '
#   '-0.139*"oil" + -0.112*"projection"'),
#  (12,
#   '0.217*"measure" + 0.166*"european" + -0.160*"fiscal" + -0.148*"reform" + '
#   '0.143*"look" + 0.141*"economy" + 0.127*"mandate" + -0.127*"money" + '
#   '0.127*"ecb" + 0.113*"nonstandard"'),
#  (13,
#   '-0.195*"projection" + 0.168*"money" + 0.165*"economy" + -0.154*"situation" '
#   '+ -0.135*"objective" + -0.127*"answer" + -0.126*"oil" + 0.118*"ab" + '
#   '-0.118*"effect" + -0.115*"government"'),
#  (14,
#   '-0.226*"it" + 0.175*"increase" + 0.168*"operation" + 0.144*"term" + '
#   '0.137*"billion" + 0.131*"negative" + 0.124*"greek" + 0.119*"go" + '
#   '0.114*"reason" + -0.111*"government"'),
#  (15,
#   '-0.268*"economy" + 0.262*"country" + 0.136*"account" + -0.134*"structural" '
#   '+ 0.130*"certainly" + -0.128*"reason" + -0.122*"reform" + 0.118*"central" + '
#   '0.112*"basis" + 0.111*"period"'),
#  (16,
#   '0.290*"situation" + 0.165*"it" + -0.154*"regard" + 0.147*"number" + '
#   '0.142*"effect" + 0.141*"month" + 0.140*"balance" + -0.133*"guidance" + '
#   '0.132*"european" + -0.124*"government"'),
#  (17,
#   '0.217*"central" + 0.137*"position" + -0.136*"projection" + -0.130*"done" + '
#   '0.125*"situation" + -0.120*"fiscal" + -0.118*"appropriate" + '
#   '-0.115*"figure" + 0.114*"country" + 0.114*"term"'),
#  (18,
#   '-0.228*"economy" + -0.177*"meeting" + -0.175*"basis" + 0.155*"operation" + '
#   '-0.151*"analysis" + 0.146*"regard" + -0.128*"balance" + -0.125*"government" '
#   '+ -0.110*"global" + -0.102*"term"'),
#  (19,
#   '-0.213*"figure" + -0.168*"bond" + -0.166*"look" + 0.141*"month" + '
#   '-0.140*"risk" + -0.140*"confidence" + -0.135*"projection" + '
#   '-0.122*"country" + 0.114*"made" + 0.105*"state"')]
# [(0,
#   '-0.179*"regard" + -0.169*"risk" + -0.169*"important" + -0.167*"country" + '
#   '-0.165*"economy" + -0.126*"situation" + -0.124*"ecb" + -0.118*"term" + '
#   '-0.113*"government" + -0.101*"certainly"'),
#  (1,
#   '0.280*"regard" + -0.171*"actually" + -0.152*"answer" + -0.137*"ecb" + '
#   '0.132*"appropriate" + 0.127*"particular" + -0.120*"thing" + 0.120*"number" '
#   '+ 0.116*"again" + -0.114*"country"'),
#  (2,
#   '-0.367*"government" + -0.285*"country" + -0.230*"measure" + 0.225*"risk" + '
#   '-0.153*"programme" + 0.151*"analysis" + -0.125*"nonstandard" + '
#   '0.119*"information" + 0.116*"certainly" + 0.116*"oil"'),
#  (3,
#   '-0.218*"development" + -0.196*"european" + 0.182*"risk" + -0.181*"exchange" '
#   '+ 0.144*"measure" + -0.136*"may" + -0.134*"central" + 0.134*"credit" + '
#   '-0.131*"cannot" + -0.127*"europe"'),
#  (4,
#   '-0.288*"risk" + 0.185*"thats" + 0.169*"programme" + -0.161*"money" + '
#   '0.160*"economy" + 0.152*"reform" + -0.148*"ecb" + -0.145*"operation" + '
#   '0.137*"expectation" + 0.136*"structural"'),
#  (5,
#   '-0.246*"measure" + 0.179*"risk" + 0.164*"reform" + 0.163*"country" + '
#   '0.156*"ecb" + -0.122*"effect" + 0.115*"job" + 0.115*"responsibility" + '
#   '-0.113*"appropriate" + 0.113*"analysis"'),
#  (6,
#   '-0.304*"country" + 0.249*"it" + -0.226*"economy" + 0.216*"risk" + '
#   '0.207*"programme" + 0.157*"greek" + 0.151*"bond" + 0.142*"greece" + '
#   '0.133*"government" + -0.124*"situation"'),
#  (7,
#   '0.190*"situation" + -0.188*"country" + 0.171*"important" + 0.162*"change" + '
#   '0.156*"confidence" + -0.152*"regard" + -0.151*"medium" + -0.150*"deliver" + '
#   '0.147*"month" + 0.136*"analysis"'),
#  (8,
#   '0.192*"risk" + 0.190*"country" + -0.185*"confidence" + -0.180*"ecb" + '
#   '-0.173*"financial" + 0.168*"change" + -0.152*"central" + 0.145*"government" '
#   '+ -0.143*"european" + 0.141*"information"'),
#  (9,
#   '0.289*"economy" + -0.216*"it" + 0.200*"risk" + -0.167*"confidence" + '
#   '0.149*"financial" + -0.138*"medium" + -0.129*"term" + 0.119*"central" + '
#   '-0.117*"balance" + 0.114*"global"'),
#  (10,
#   '0.303*"measure" + -0.253*"greece" + -0.228*"greek" + 0.214*"risk" + '
#   '-0.178*"economy" + -0.150*"ela" + -0.142*"liquidity" + -0.129*"government" '
#   '+ 0.123*"nonstandard" + 0.122*"fiscal"'),
#  (11,
#   '0.219*"government" + 0.214*"risk" + -0.186*"measure" + 0.172*"financial" + '
#   '-0.168*"country" + -0.159*"economy" + -0.150*"ecb" + 0.144*"confidence" + '
#   '-0.138*"oil" + -0.111*"projection"'),
#  (12,
#   '-0.217*"measure" + -0.166*"european" + 0.161*"fiscal" + 0.149*"reform" + '
#   '-0.143*"look" + -0.140*"economy" + 0.128*"money" + -0.127*"mandate" + '
#   '-0.126*"ecb" + -0.113*"discussion"'),
#  (13,
#   '0.193*"projection" + -0.167*"money" + -0.165*"economy" + 0.154*"situation" '
#   '+ 0.135*"objective" + 0.127*"oil" + 0.127*"answer" + -0.119*"ab" + '
#   '0.118*"effect" + -0.115*"it"'),
#  (14,
#   '-0.225*"it" + 0.173*"increase" + 0.168*"operation" + 0.146*"term" + '
#   '0.135*"billion" + 0.131*"negative" + 0.125*"greek" + 0.120*"go" + '
#   '0.112*"reason" + -0.112*"government"'),
#  (15,
#   '0.265*"economy" + -0.262*"country" + -0.138*"account" + 0.135*"structural" '
#   '+ -0.132*"certainly" + 0.130*"reason" + 0.125*"reform" + -0.116*"central" + '
#   '-0.113*"basis" + -0.110*"taken"'),
#  (16,
#   '0.295*"situation" + 0.165*"it" + -0.155*"regard" + 0.147*"effect" + '
#   '0.144*"balance" + 0.142*"number" + 0.142*"month" + -0.131*"guidance" + '
#   '0.128*"european" + 0.124*"message"'),
#  (17,
#   '-0.218*"central" + -0.136*"position" + 0.133*"projection" + 0.127*"done" + '
#   '0.120*"fiscal" + -0.117*"country" + -0.117*"situation" + '
#   '-0.116*"responsibility" + 0.116*"appropriate" + -0.115*"clear"'),
#  (18,
#   '-0.230*"economy" + -0.179*"meeting" + -0.175*"basis" + 0.156*"operation" + '
#   '-0.150*"analysis" + 0.141*"regard" + -0.130*"government" + -0.127*"balance" '
#   '+ -0.111*"global" + -0.107*"term"'),
#  (19,
#   '-0.216*"figure" + -0.167*"bond" + -0.164*"look" + 0.142*"month" + '
#   '-0.142*"risk" + -0.141*"confidence" + -0.136*"projection" + '
#   '-0.123*"country" + 0.114*"made" + 0.105*"state"'),
#  (20,
#   '0.211*"programme" + -0.185*"government" + 0.153*"effect" + 0.143*"fiscal" + '
#   '0.140*"consider" + 0.133*"ecb" + -0.127*"thing" + -0.127*"instrument" + '
#   '-0.127*"different" + 0.119*"country"'),
#  (21,
#   '-0.166*"reason" + -0.166*"important" + 0.154*"condition" + 0.149*"it" + '
#   '0.142*"change" + -0.125*"certainly" + -0.123*"effect" + 0.123*"credit" + '
#   '-0.114*"state" + -0.113*"responsibility"'),
#  (22,
#   '-0.166*"lending" + 0.152*"liquidity" + -0.149*"certainly" + -0.147*"new" + '
#   '0.140*"central" + -0.139*"credit" + 0.129*"banking" + 0.126*"it" + '
#   '-0.122*"europe" + -0.119*"expectation"'),
#  (23,
#   '0.201*"confidence" + -0.187*"figure" + 0.177*"measure" + 0.166*"important" '
#   '+ -0.148*"reform" + -0.130*"programme" + -0.120*"certainly" + '
#   '-0.117*"economy" + -0.108*"actually" + 0.102*"treaty"'),
#  (24,
#   '0.228*"exchange" + 0.144*"reason" + 0.130*"regard" + 0.124*"meeting" + '
#   '0.124*"country" + 0.123*"structural" + -0.119*"expectation" + '
#   '0.116*"instrument" + -0.114*"fiscal" + 0.113*"effect"'),
#  (25,
#   '-0.232*"important" + 0.162*"clear" + 0.160*"fiscal" + 0.152*"recovery" + '
#   '0.118*"nonstandard" + 0.116*"different" + 0.116*"basis" + '
#   '0.113*"appropriate" + -0.111*"staff" + -0.107*"government"'),
#  (26,
#   '0.197*"term" + -0.181*"economy" + -0.150*"clear" + -0.139*"information" + '
#   '0.127*"european" + 0.120*"situation" + -0.109*"appropriate" + '
#   '-0.106*"condition" + 0.104*"important" + -0.103*"again"'),
#  (27,
#   '-0.167*"figure" + -0.166*"information" + 0.164*"nonstandard" + '
#   '0.151*"country" + 0.145*"financial" + 0.131*"risk" + -0.130*"different" + '
#   '-0.120*"fiscal" + -0.118*"consider" + 0.117*"expectation"'),
#  (28,
#   '-0.185*"certainly" + -0.156*"analysis" + 0.151*"situation" + '
#   '-0.147*"liquidity" + -0.130*"regard" + -0.126*"central" + 0.123*"ecb" + '
#   '-0.122*"functioning" + -0.122*"problem" + -0.118*"system"'),
#  (29,
#   '-0.211*"central" + 0.170*"message" + -0.159*"again" + -0.155*"basis" + '
#   '0.136*"global" + 0.127*"strong" + 0.127*"next" + 0.127*"meeting" + '
#   '0.127*"regard" + -0.124*"number"'),
#  (30,
#   '0.171*"message" + -0.145*"situation" + 0.142*"money" + -0.135*"longterm" + '
#   '-0.133*"regard" + -0.131*"exchange" + 0.131*"european" + 0.123*"change" + '
#   '0.118*"fiscal" + -0.111*"quarter"'),
#  (31,
#   '0.241*"global" + -0.135*"particular" + -0.133*"increase" + 0.126*"mandate" '
#   '+ 0.124*"ecb" + -0.123*"meeting" + -0.122*"present" + 0.121*"financial" + '
#   '-0.119*"expectation" + -0.115*"economic"'),
#  (32,
#   '0.210*"effect" + -0.141*"important" + -0.126*"ab" + 0.123*"european" + '
#   '0.121*"may" + -0.120*"development" + 0.120*"change" + -0.119*"thats" + '
#   '-0.116*"make" + -0.114*"collateral"'),
#  (33,
#   '-0.184*"programme" + 0.155*"job" + 0.137*"figure" + -0.122*"term" + '
#   '-0.121*"financial" + 0.119*"mandate" + 0.115*"risk" + '
#   '-0.115*"responsibility" + -0.112*"global" + 0.108*"creation"'),
#  (34,
#   '0.156*"ecb" + -0.125*"change" + 0.125*"information" + 0.123*"balance" + '
#   '-0.120*"again" + 0.120*"state" + -0.109*"credit" + -0.107*"effect" + '
#   '-0.101*"perhaps" + 0.100*"development"'),
#  (35,
#   '-0.155*"recovery" + 0.153*"month" + 0.153*"financial" + -0.131*"exchange" + '
#   '-0.127*"programme" + -0.126*"again" + 0.126*"world" + -0.119*"comment" + '
#   '0.113*"problem" + 0.113*"next"'),
#  (36,
#   '0.159*"expectation" + -0.143*"effect" + -0.140*"appropriate" + -0.133*"new" '
#   '+ -0.121*"comment" + -0.120*"confidence" + 0.119*"recovery" + '
#   '0.118*"european" + -0.118*"treaty" + -0.111*"taken"'),
#  (37,
#   '0.166*"ecb" + -0.146*"appropriate" + -0.141*"important" + -0.126*"action" + '
#   '0.124*"central" + -0.113*"clear" + 0.111*"liquidity" + -0.108*"recovery" + '
#   '0.107*"better" + -0.104*"two"'),
#  (38,
#   '0.173*"new" + 0.148*"rule" + 0.119*"bond" + -0.116*"two" + -0.116*"going" + '
#   '0.115*"private" + 0.112*"figure" + -0.103*"le" + 0.103*"made" + '
#   '-0.100*"real"'),
#  (39,
#   '-0.178*"clear" + -0.126*"move" + 0.120*"situation" + -0.119*"decided" + '
#   '0.113*"message" + -0.112*"athens" + 0.112*"eurogroup" + 0.111*"change" + '
#   '0.106*"president" + -0.100*"confidence"'),
#  (40,
#   '-0.153*"meeting" + -0.144*"information" + 0.138*"change" + '
#   '-0.132*"confidence" + -0.118*"mentioned" + 0.111*"state" + '
#   '-0.111*"secondround" + -0.109*"decided" + -0.104*"always" + '
#   '0.099*"appropriate"'),
#  (41,
#   '0.159*"central" + -0.150*"clear" + -0.140*"ecb" + -0.137*"actually" + '
#   '-0.136*"stance" + 0.128*"financial" + -0.122*"exchange" + -0.112*"quite" + '
#   '0.110*"want" + 0.105*"still"'),
#  (42,
#   '-0.155*"two" + 0.129*"information" + -0.129*"judgement" + -0.128*"let" + '
#   '-0.122*"since" + 0.118*"central" + 0.117*"mandate" + -0.116*"treaty" + '
#   '-0.110*"development" + -0.100*"fiscal"'),
#  (43,
#   '0.186*"quarter" + -0.144*"projection" + 0.127*"look" + 0.123*"number" + '
#   '-0.122*"recovery" + -0.119*"mentioned" + 0.117*"development" + '
#   '-0.101*"economic" + 0.097*"issue" + 0.095*"cyprus"'),
#  (44,
#   '-0.176*"let" + -0.128*"quarter" + 0.128*"view" + -0.126*"statement" + '
#   '-0.120*"financial" + -0.114*"position" + -0.111*"again" + -0.109*"actually" '
#   '+ -0.106*"projection" + 0.099*"mentioned"'),
#  (45,
#   '0.126*"note" + -0.122*"development" + 0.116*"nonstandard" + 0.113*"since" + '
#   '-0.110*"always" + 0.103*"let" + 0.094*"money" + -0.094*"government" + '
#   '0.093*"low" + 0.092*"go"'),
#  (46,
#   '0.168*"european" + 0.134*"let" + 0.126*"balance" + -0.123*"may" + '
#   '-0.123*"thing" + -0.123*"present" + 0.118*"impact" + 0.115*"billion" + '
#   '0.114*"uncertainty" + -0.098*"going"'),
#  (47,
#   '0.177*"ecb" + -0.141*"global" + -0.135*"present" + -0.133*"mandate" + '
#   '0.119*"period" + 0.115*"look" + -0.100*"projection" + 0.095*"sector" + '
#   '0.095*"and" + -0.091*"part"'),
#  (48,
#   '0.151*"figure" + -0.120*"reason" + -0.114*"something" + 0.110*"account" + '
#   '-0.107*"pact" + 0.105*"financial" + -0.102*"may" + 0.100*"remain" + '
#   '0.100*"whole" + -0.095*"term"'),
#  (49,
#   '0.150*"continue" + 0.145*"consider" + -0.130*"programme" + '
#   '0.129*"responsibility" + -0.112*"need" + 0.111*"new" + -0.110*"european" + '
#   '-0.108*"public" + -0.107*"analysis" + -0.102*"good"')]
# [(0,
#   '-0.179*"regard" + -0.169*"risk" + -0.169*"important" + -0.167*"country" + '
#   '-0.165*"economy" + -0.126*"situation" + -0.124*"ecb" + -0.118*"term" + '
#   '-0.113*"government" + -0.101*"certainly"'),
#  (1,
#   '0.280*"regard" + -0.171*"actually" + -0.152*"answer" + -0.137*"ecb" + '
#   '0.132*"appropriate" + 0.127*"particular" + -0.120*"thing" + 0.120*"number" '
#   '+ 0.116*"again" + -0.114*"country"'),
#  (2,
#   '-0.367*"government" + -0.285*"country" + -0.230*"measure" + 0.225*"risk" + '
#   '-0.153*"programme" + 0.151*"analysis" + -0.125*"nonstandard" + '
#   '0.119*"information" + 0.116*"certainly" + 0.116*"oil"'),
#  (3,
#   '0.218*"development" + 0.196*"european" + -0.182*"risk" + 0.181*"exchange" + '
#   '-0.144*"measure" + 0.136*"may" + 0.134*"central" + -0.134*"credit" + '
#   '0.131*"cannot" + 0.127*"europe"'),
#  (4,
#   '-0.287*"risk" + 0.185*"thats" + 0.169*"programme" + -0.161*"money" + '
#   '0.160*"economy" + 0.152*"reform" + -0.148*"ecb" + -0.145*"operation" + '
#   '0.137*"expectation" + 0.136*"structural"'),
#  (5,
#   '0.246*"measure" + -0.179*"risk" + -0.164*"reform" + -0.163*"country" + '
#   '-0.156*"ecb" + 0.122*"effect" + -0.115*"job" + -0.115*"responsibility" + '
#   '0.113*"appropriate" + -0.113*"analysis"'),
#  (6,
#   '-0.304*"country" + 0.249*"it" + -0.226*"economy" + 0.216*"risk" + '
#   '0.207*"programme" + 0.157*"greek" + 0.151*"bond" + 0.142*"greece" + '
#   '0.133*"government" + -0.124*"situation"'),
#  (7,
#   '-0.191*"situation" + 0.188*"country" + -0.170*"important" + -0.163*"change" '
#   '+ -0.156*"confidence" + 0.152*"regard" + 0.151*"medium" + 0.150*"deliver" + '
#   '-0.147*"month" + -0.137*"analysis"'),
#  (8,
#   '0.192*"risk" + 0.190*"country" + -0.185*"confidence" + -0.180*"ecb" + '
#   '-0.173*"financial" + 0.169*"change" + -0.152*"central" + 0.145*"government" '
#   '+ -0.144*"european" + 0.141*"information"'),
#  (9,
#   '0.289*"economy" + -0.216*"it" + 0.200*"risk" + -0.167*"confidence" + '
#   '0.148*"financial" + -0.138*"medium" + -0.129*"term" + 0.119*"central" + '
#   '-0.117*"balance" + 0.114*"global"'),
#  (10,
#   '0.303*"measure" + -0.253*"greece" + -0.228*"greek" + 0.214*"risk" + '
#   '-0.178*"economy" + -0.150*"ela" + -0.142*"liquidity" + -0.129*"government" '
#   '+ 0.124*"nonstandard" + 0.123*"fiscal"'),
#  (11,
#   '0.219*"government" + 0.214*"risk" + -0.186*"measure" + 0.172*"financial" + '
#   '-0.168*"country" + -0.158*"economy" + -0.150*"ecb" + 0.144*"confidence" + '
#   '-0.138*"oil" + -0.112*"projection"'),
#  (12,
#   '-0.217*"measure" + -0.166*"european" + 0.161*"fiscal" + 0.149*"reform" + '
#   '-0.143*"look" + -0.140*"economy" + 0.128*"money" + -0.128*"mandate" + '
#   '-0.126*"ecb" + -0.113*"discussion"'),
#  (13,
#   '-0.194*"projection" + 0.167*"money" + 0.165*"economy" + -0.154*"situation" '
#   '+ -0.135*"objective" + -0.127*"oil" + -0.126*"answer" + 0.119*"ab" + '
#   '-0.118*"effect" + 0.114*"it"'),
#  (14,
#   '-0.225*"it" + 0.173*"increase" + 0.169*"operation" + 0.146*"term" + '
#   '0.135*"billion" + 0.131*"negative" + 0.124*"greek" + 0.120*"go" + '
#   '0.112*"reason" + -0.112*"government"'),
#  (15,
#   '0.265*"economy" + -0.262*"country" + -0.138*"account" + 0.135*"structural" '
#   '+ -0.132*"certainly" + 0.130*"reason" + 0.124*"reform" + -0.115*"central" + '
#   '-0.113*"basis" + -0.111*"period"'),
#  (16,
#   '0.294*"situation" + 0.165*"it" + -0.155*"regard" + 0.146*"effect" + '
#   '0.143*"number" + 0.143*"balance" + 0.141*"month" + -0.131*"guidance" + '
#   '0.129*"european" + 0.123*"message"'),
#  (17,
#   '-0.218*"central" + -0.136*"position" + 0.133*"projection" + 0.128*"done" + '
#   '0.121*"fiscal" + -0.119*"situation" + -0.117*"country" + '
#   '0.116*"appropriate" + -0.116*"responsibility" + -0.115*"clear"'),
#  (18,
#   '-0.230*"economy" + -0.179*"meeting" + -0.175*"basis" + 0.156*"operation" + '
#   '-0.150*"analysis" + 0.142*"regard" + -0.130*"government" + -0.128*"balance" '
#   '+ -0.111*"global" + -0.106*"term"'),
#  (19,
#   '0.216*"figure" + 0.167*"bond" + 0.165*"look" + -0.143*"month" + '
#   '0.141*"confidence" + 0.141*"risk" + 0.136*"projection" + 0.123*"country" + '
#   '-0.115*"made" + -0.106*"state"'),
#  (20,
#   '0.211*"programme" + -0.184*"government" + 0.153*"effect" + 0.143*"fiscal" + '
#   '0.140*"consider" + 0.133*"ecb" + -0.127*"different" + -0.126*"thing" + '
#   '-0.126*"instrument" + 0.119*"country"'),
#  (21,
#   '-0.166*"reason" + -0.166*"important" + 0.154*"condition" + 0.149*"it" + '
#   '0.142*"change" + -0.126*"certainly" + -0.124*"effect" + 0.123*"credit" + '
#   '-0.114*"state" + -0.114*"responsibility"'),
#  (22,
#   '-0.166*"lending" + 0.152*"liquidity" + -0.148*"certainly" + -0.147*"new" + '
#   '0.141*"central" + -0.140*"credit" + 0.129*"banking" + 0.125*"it" + '
#   '-0.122*"europe" + -0.120*"expectation"'),
#  (23,
#   '0.201*"confidence" + -0.187*"figure" + 0.176*"measure" + 0.170*"important" '
#   '+ -0.147*"reform" + -0.130*"programme" + -0.119*"certainly" + '
#   '-0.118*"economy" + -0.109*"actually" + 0.103*"treaty"'),
#  (24,
#   '-0.231*"exchange" + -0.144*"reason" + -0.131*"regard" + -0.124*"country" + '
#   '-0.123*"meeting" + -0.123*"structural" + 0.120*"expectation" + '
#   '0.117*"fiscal" + -0.114*"instrument" + -0.113*"effect"'),
#  (25,
#   '0.231*"important" + -0.162*"clear" + -0.161*"fiscal" + -0.151*"recovery" + '
#   '-0.117*"nonstandard" + -0.116*"different" + -0.115*"basis" + '
#   '-0.113*"appropriate" + 0.110*"staff" + 0.108*"government"'),
#  (26,
#   '0.198*"term" + -0.181*"economy" + -0.151*"clear" + -0.140*"information" + '
#   '0.128*"european" + 0.119*"situation" + -0.109*"appropriate" + '
#   '-0.108*"condition" + 0.104*"important" + -0.103*"bond"'),
#  (27,
#   '-0.166*"figure" + -0.166*"information" + 0.164*"nonstandard" + '
#   '0.151*"country" + 0.144*"financial" + 0.132*"risk" + -0.129*"different" + '
#   '-0.121*"fiscal" + -0.118*"consider" + 0.118*"expectation"'),
#  (28,
#   '-0.184*"certainly" + -0.156*"analysis" + 0.154*"situation" + '
#   '-0.146*"liquidity" + -0.130*"central" + -0.128*"regard" + '
#   '-0.123*"functioning" + 0.122*"ecb" + -0.120*"problem" + -0.117*"system"'),
#  (29,
#   '-0.209*"central" + 0.172*"message" + -0.160*"again" + -0.154*"basis" + '
#   '0.136*"global" + 0.129*"regard" + 0.126*"next" + 0.126*"meeting" + '
#   '0.126*"strong" + -0.124*"number"'),
#  (30,
#   '-0.171*"message" + 0.144*"situation" + -0.141*"money" + 0.134*"longterm" + '
#   '0.133*"regard" + -0.131*"european" + 0.130*"exchange" + -0.123*"change" + '
#   '-0.119*"fiscal" + 0.111*"quarter"'),
#  (31,
#   '0.241*"global" + -0.135*"particular" + -0.133*"increase" + 0.126*"mandate" '
#   '+ 0.125*"ecb" + -0.123*"meeting" + -0.122*"present" + 0.120*"financial" + '
#   '-0.118*"expectation" + -0.116*"economic"'),
#  (32,
#   '-0.209*"effect" + 0.138*"important" + 0.128*"ab" + -0.122*"may" + '
#   '-0.122*"european" + -0.118*"change" + 0.117*"development" + 0.117*"make" + '
#   '0.116*"thats" + 0.115*"projection"'),
#  (33,
#   '0.180*"programme" + -0.156*"job" + -0.137*"figure" + 0.123*"financial" + '
#   '0.123*"term" + -0.119*"mandate" + -0.118*"risk" + 0.114*"global" + '
#   '0.114*"responsibility" + -0.109*"creation"'),
#  (34,
#   '-0.156*"ecb" + 0.126*"change" + -0.126*"information" + -0.123*"balance" + '
#   '0.122*"again" + -0.121*"state" + 0.111*"credit" + 0.107*"effect" + '
#   '-0.101*"development" + 0.100*"perhaps"'),
#  (35,
#   '-0.157*"recovery" + 0.153*"month" + 0.152*"financial" + -0.130*"exchange" + '
#   '-0.126*"programme" + 0.126*"world" + -0.126*"again" + -0.119*"comment" + '
#   '0.115*"problem" + 0.112*"next"'),
#  (36,
#   '-0.157*"expectation" + 0.141*"effect" + 0.139*"appropriate" + 0.132*"new" + '
#   '0.119*"confidence" + 0.119*"comment" + 0.118*"treaty" + -0.118*"recovery" + '
#   '-0.117*"european" + 0.114*"taken"'),
#  (37,
#   '-0.157*"ecb" + 0.147*"appropriate" + 0.139*"important" + -0.130*"central" + '
#   '0.127*"action" + 0.113*"recovery" + -0.111*"liquidity" + 0.110*"two" + '
#   '-0.108*"better" + 0.108*"clear"'),
#  (38,
#   '-0.170*"new" + -0.148*"rule" + -0.119*"bond" + 0.116*"going" + '
#   '-0.112*"private" + -0.112*"figure" + 0.111*"two" + -0.103*"made" + '
#   '0.101*"real" + 0.101*"le"'),
#  (39,
#   '0.184*"clear" + 0.125*"move" + -0.119*"situation" + -0.116*"message" + '
#   '-0.116*"change" + 0.115*"decided" + 0.114*"athens" + -0.113*"eurogroup" + '
#   '-0.105*"president" + 0.101*"confidence"'),
#  (40,
#   '0.152*"meeting" + 0.144*"information" + -0.139*"change" + '
#   '0.131*"confidence" + 0.117*"mentioned" + -0.111*"state" + '
#   '0.109*"secondround" + 0.109*"decided" + 0.106*"always" + '
#   '-0.099*"appropriate"'),
#  (41,
#   '-0.160*"central" + 0.149*"clear" + 0.141*"ecb" + 0.139*"actually" + '
#   '0.135*"stance" + -0.127*"financial" + 0.125*"exchange" + 0.111*"quite" + '
#   '-0.110*"want" + -0.107*"still"'),
#  (42,
#   '0.155*"two" + 0.130*"let" + 0.129*"judgement" + -0.128*"information" + '
#   '0.120*"since" + -0.120*"central" + -0.119*"mandate" + 0.118*"treaty" + '
#   '0.110*"development" + 0.099*"fiscal"'),
#  (43,
#   '-0.188*"quarter" + 0.144*"projection" + -0.129*"look" + -0.122*"number" + '
#   '0.121*"recovery" + -0.119*"development" + 0.118*"mentioned" + '
#   '0.099*"economic" + -0.096*"issue" + -0.095*"problem"'),
#  (44,
#   '0.172*"let" + 0.128*"statement" + 0.125*"quarter" + -0.125*"view" + '
#   '0.119*"financial" + 0.114*"again" + 0.110*"actually" + 0.108*"position" + '
#   '0.104*"projection" + 0.102*"staff"'),
#  (45,
#   '-0.125*"note" + 0.125*"development" + -0.115*"nonstandard" + -0.113*"since" '
#   '+ -0.109*"let" + 0.106*"always" + 0.097*"government" + -0.096*"money" + '
#   '-0.096*"low" + 0.093*"different"'),
#  (46,
#   '0.160*"european" + 0.132*"let" + -0.128*"present" + -0.128*"may" + '
#   '0.122*"balance" + -0.120*"thing" + 0.118*"impact" + 0.116*"uncertainty" + '
#   '0.116*"billion" + 0.095*"taken"'),
#  (47,
#   '-0.181*"ecb" + 0.136*"global" + 0.131*"mandate" + -0.124*"period" + '
#   '0.124*"present" + -0.117*"look" + 0.097*"projection" + -0.096*"sector" + '
#   '-0.094*"and" + 0.093*"conclusion"'),
#  (48,
#   '0.151*"figure" + -0.122*"reason" + -0.113*"something" + -0.111*"pact" + '
#   '0.110*"account" + 0.106*"financial" + -0.103*"may" + 0.096*"whole" + '
#   '0.096*"remain" + -0.095*"term"'),
#  (49,
#   '0.153*"continue" + 0.152*"consider" + -0.130*"programme" + '
#   '0.129*"responsibility" + 0.114*"new" + -0.114*"european" + -0.108*"need" + '
#   '-0.106*"public" + 0.106*"answer" + -0.105*"analysis"'),
#  (50,
#   '0.120*"make" + 0.117*"important" + 0.116*"european" + -0.113*"note" + '
#   '-0.105*"confidence" + 0.104*"information" + 0.101*"new" + 0.100*"period" + '
#   '-0.100*"whether" + 0.100*"scenario"'),
#  (51,
#   '-0.157*"new" + 0.155*"credit" + 0.128*"judgement" + -0.116*"necessary" + '
#   '-0.113*"absolutely" + 0.112*"particular" + -0.111*"operation" + '
#   '0.104*"factor" + -0.100*"expectation" + 0.098*"right"'),
#  (52,
#   '-0.201*"come" + 0.144*"number" + 0.113*"billion" + -0.110*"measure" + '
#   '0.102*"pact" + 0.101*"problem" + -0.098*"believe" + -0.094*"make" + '
#   '-0.093*"functioning" + -0.092*"month"'),
#  (53,
#   '0.146*"exchange" + 0.126*"nonstandard" + -0.123*"european" + '
#   '-0.099*"authority" + -0.098*"scenario" + 0.093*"good" + -0.093*"ab" + '
#   '-0.093*"national" + -0.092*"central" + 0.088*"again"'),
#  (54,
#   '0.135*"look" + 0.134*"different" + -0.131*"issue" + 0.130*"financial" + '
#   '-0.111*"definition" + 0.110*"programme" + 0.109*"figure" + -0.107*"basis" + '
#   '-0.105*"consider" + -0.104*"good"'),
#  (55,
#   '0.181*"look" + 0.138*"sense" + -0.129*"figure" + 0.127*"month" + '
#   '0.112*"operation" + 0.105*"loan" + 0.094*"mentioned" + 0.090*"concerned" + '
#   '0.088*"billion" + -0.086*"people"'),
#  (56,
#   '-0.158*"let" + 0.127*"account" + 0.123*"discussion" + 0.108*"committee" + '
#   '0.102*"credit" + 0.096*"matter" + -0.093*"particular" + -0.092*"europe" + '
#   '-0.092*"period" + 0.091*"reform"'),
#  (57,
#   '-0.159*"basis" + -0.130*"present" + -0.121*"again" + -0.115*"account" + '
#   '0.115*"possible" + 0.102*"sector" + -0.098*"bond" + -0.097*"financial" + '
#   '0.095*"overall" + 0.094*"want"'),
#  (58,
#   '-0.141*"certainly" + 0.135*"analysis" + -0.129*"month" + 0.127*"answer" + '
#   '0.125*"effect" + -0.118*"may" + -0.118*"go" + 0.102*"institution" + '
#   '-0.101*"high" + -0.099*"nonstandard"'),
#  (59,
#   '0.130*"meeting" + 0.120*"far" + -0.120*"actually" + -0.120*"confidence" + '
#   '-0.115*"sector" + -0.114*"staff" + -0.110*"many" + -0.105*"fully" + '
#   '0.100*"condition" + -0.098*"economy"'),
#  (60,
#   '0.146*"number" + -0.137*"mentioned" + -0.132*"necessary" + -0.131*"mandate" '
#   '+ -0.122*"may" + 0.119*"new" + 0.118*"discussion" + 0.098*"high" + '
#   '0.094*"ltro" + -0.093*"information"'),
#  (61,
#   '0.115*"cost" + 0.101*"volatility" + 0.101*"statement" + -0.097*"stance" + '
#   '0.096*"week" + 0.094*"development" + 0.094*"private" + -0.094*"assessment" '
#   '+ 0.092*"balance" + -0.091*"problem"'),
#  (62,
#   '-0.126*"oil" + 0.114*"note" + -0.105*"two" + -0.103*"whether" + '
#   '-0.103*"responsibility" + -0.097*"dynamic" + -0.097*"tender" + '
#   '0.092*"assumption" + 0.091*"capital" + -0.089*"country"'),
#  (63,
#   '-0.144*"full" + 0.128*"money" + -0.121*"appropriate" + 0.119*"help" + '
#   '-0.114*"liquidity" + 0.110*"again" + -0.105*"large" + 0.105*"close" + '
#   '0.103*"exchange" + -0.101*"bond"'),
#  (64,
#   '0.163*"work" + -0.134*"comment" + 0.132*"answer" + 0.125*"regard" + '
#   '0.109*"again" + -0.108*"account" + 0.108*"europe" + -0.103*"eurogroup" + '
#   '-0.100*"responsibility" + -0.098*"message"'),
#  (65,
#   '-0.137*"exactly" + 0.110*"different" + 0.107*"it" + 0.099*"future" + '
#   '-0.098*"statement" + -0.098*"let" + 0.098*"assessment" + 0.097*"line" + '
#   '0.093*"financial" + -0.091*"condition"'),
#  (66,
#   '-0.136*"good" + 0.130*"issue" + -0.125*"economic" + 0.122*"month" + '
#   '-0.121*"discussion" + -0.117*"thing" + -0.114*"analysis" + '
#   '-0.109*"currency" + 0.094*"public" + 0.094*"balance"'),
#  (67,
#   '-0.108*"close" + -0.106*"europe" + -0.106*"meeting" + -0.100*"element" + '
#   '-0.093*"case" + -0.092*"assessment" + -0.088*"make" + -0.085*"something" + '
#   '0.084*"rule" + -0.083*"might"'),
#  (68,
#   '0.153*"fully" + 0.116*"note" + -0.114*"statement" + -0.108*"projection" + '
#   '0.100*"period" + 0.096*"line" + 0.094*"dynamic" + -0.092*"important" + '
#   '-0.090*"data" + -0.089*"mentioned"'),
#  (69,
#   '-0.186*"case" + 0.132*"structural" + -0.116*"present" + 0.112*"various" + '
#   '0.099*"confidence" + 0.098*"operation" + -0.094*"central" + '
#   '-0.089*"forward" + 0.085*"scenario" + -0.084*"responsibility"'),
#  (70,
#   '0.137*"recovery" + 0.134*"new" + 0.119*"still" + -0.109*"month" + '
#   '-0.106*"objective" + -0.103*"view" + -0.101*"europe" + 0.094*"certainly" + '
#   '0.094*"respect" + 0.093*"fiscal"'),
#  (71,
#   '0.126*"rule" + 0.113*"want" + -0.112*"make" + -0.108*"responsibility" + '
#   '-0.104*"statement" + 0.103*"asset" + 0.094*"currency" + -0.093*"press" + '
#   '0.092*"europe" + 0.092*"system"'),
#  (72,
#   '0.128*"case" + -0.119*"uncertainty" + -0.116*"still" + -0.110*"it" + '
#   '0.109*"no" + 0.105*"expectation" + 0.104*"taken" + 0.097*"message" + '
#   '0.093*"factor" + -0.093*"european"'),
#  (73,
#   '0.112*"account" + -0.109*"concerned" + -0.106*"made" + 0.099*"factor" + '
#   '-0.098*"comment" + -0.096*"basis" + -0.093*"balance" + -0.091*"we" + '
#   '0.089*"sure" + 0.088*"clear"'),
#  (74,
#   '-0.136*"institution" + 0.114*"going" + -0.113*"different" + -0.108*"ecb" + '
#   '0.101*"factor" + 0.097*"call" + 0.091*"seen" + -0.089*"within" + '
#   '-0.088*"remain" + 0.085*"again"'),
#  (75,
#   '0.123*"message" + -0.105*"many" + 0.100*"taken" + 0.096*"namely" + '
#   '-0.095*"world" + 0.093*"continue" + -0.092*"credibility" + 0.090*"backstop" '
#   '+ -0.090*"instrument" + -0.088*"economic"'),
#  (76,
#   '-0.137*"right" + 0.111*"public" + -0.109*"central" + 0.104*"since" + '
#   '-0.101*"currency" + 0.101*"member" + 0.096*"different" + '
#   '-0.095*"institution" + -0.090*"account" + -0.089*"review"'),
#  (77,
#   '-0.156*"basis" + 0.110*"reform" + 0.105*"exactly" + -0.105*"comment" + '
#   '-0.104*"mentioned" + 0.103*"real" + 0.103*"projection" + '
#   '-0.094*"institution" + -0.090*"taken" + 0.089*"credibility"'),
#  (78,
#   '0.139*"month" + 0.135*"decided" + -0.131*"liquidity" + 0.117*"stance" + '
#   '0.115*"place" + -0.106*"clear" + 0.101*"make" + 0.099*"medium" + '
#   '-0.094*"never" + -0.090*"operation"'),
#  (79,
#   '0.115*"factor" + 0.111*"all" + -0.098*"right" + -0.098*"line" + '
#   '-0.095*"consider" + 0.094*"kind" + 0.094*"close" + 0.093*"sense" + '
#   '-0.089*"before" + 0.083*"still"'),
#  (80,
#   '-0.147*"european" + 0.110*"greece" + 0.105*"work" + 0.103*"expectation" + '
#   '0.098*"le" + -0.089*"observe" + -0.088*"different" + 0.088*"make" + '
#   '-0.088*"banking" + 0.087*"message"'),
#  (81,
#   '0.134*"economic" + -0.108*"particular" + -0.105*"problem" + 0.103*"account" '
#   '+ 0.101*"appropriate" + 0.101*"central" + -0.095*"continue" + '
#   '0.095*"analysis" + 0.084*"review" + 0.080*"actually"'),
#  (82,
#   '-0.120*"mediumterm" + -0.112*"plan" + 0.105*"significant" + 0.102*"still" + '
#   '-0.096*"result" + -0.094*"credit" + 0.091*"quarter" + -0.089*"comment" + '
#   '-0.089*"answer" + -0.087*"really"'),
#  (83,
#   '0.147*"comment" + 0.146*"no" + -0.128*"development" + 0.124*"always" + '
#   '-0.112*"future" + 0.106*"intervention" + -0.092*"issue" + 0.089*"statement" '
#   '+ 0.083*"use" + -0.083*"data"'),
#  (84,
#   '0.135*"economic" + -0.122*"respect" + -0.109*"and" + -0.107*"basis" + '
#   '0.104*"meeting" + 0.097*"people" + -0.093*"necessary" + 0.090*"line" + '
#   '-0.087*"again" + 0.086*"low"'),
#  (85,
#   '-0.138*"case" + -0.136*"real" + 0.113*"analysis" + -0.103*"mean" + '
#   '-0.102*"treaty" + 0.100*"current" + -0.091*"come" + 0.090*"ago" + '
#   '0.089*"deliver" + -0.086*"even"'),
#  (86,
#   '0.125*"credible" + 0.100*"single" + 0.099*"work" + 0.099*"action" + '
#   '0.096*"seen" + 0.089*"lot" + -0.089*"factor" + 0.088*"period" + '
#   '0.087*"side" + -0.087*"overall"'),
#  (87,
#   '0.125*"term" + 0.111*"present" + -0.103*"period" + 0.096*"upside" + '
#   '0.091*"lending" + 0.091*"favourable" + 0.079*"job" + 0.075*"banking" + '
#   '0.075*"moment" + 0.074*"overall"'),
#  (88,
#   '0.109*"exchange" + -0.108*"objective" + 0.100*"inflationary" + '
#   '-0.095*"made" + -0.094*"uncertainty" + 0.091*"certainly" + 0.090*"increase" '
#   '+ 0.089*"liquidity" + -0.089*"message" + 0.088*"state"'),
#  (89,
#   '-0.148*"make" + 0.122*"increase" + 0.101*"situation" + -0.097*"economic" + '
#   '0.097*"favourable" + -0.096*"different" + -0.096*"banking" + '
#   '0.092*"assumption" + -0.091*"institution" + 0.091*"esm"'),
#  (90,
#   '-0.122*"problem" + 0.111*"better" + -0.100*"global" + 0.098*"present" + '
#   '0.097*"new" + -0.091*"come" + -0.090*"stance" + -0.086*"right" + '
#   '-0.086*"sentiment" + -0.085*"international"'),
#  (91,
#   '0.132*"three" + -0.118*"absolutely" + -0.104*"mentioned" + -0.104*"quite" + '
#   '0.104*"appropriate" + -0.103*"environment" + 0.100*"issue" + '
#   '0.094*"position" + -0.093*"smp" + 0.091*"figure"'),
#  (92,
#   '-0.137*"development" + -0.122*"now" + -0.105*"past" + 0.104*"process" + '
#   '-0.097*"account" + -0.095*"increase" + -0.095*"really" + 0.093*"figure" + '
#   '-0.092*"judgement" + -0.092*"oil"'),
#  (93,
#   '0.125*"effect" + -0.123*"close" + -0.112*"european" + 0.097*"finance" + '
#   '-0.097*"confidence" + -0.096*"exactly" + -0.095*"expectation" + '
#   '-0.093*"line" + -0.091*"world" + 0.088*"functioning"'),
#  (94,
#   '0.113*"authority" + 0.111*"public" + 0.108*"labour" + 0.107*"various" + '
#   '-0.106*"position" + -0.104*"currency" + -0.104*"message" + -0.101*"central" '
#   '+ -0.096*"phenomenon" + 0.095*"mandate"'),
#  (95,
#   '0.101*"commitment" + -0.098*"far" + 0.097*"exchange" + -0.088*"give" + '
#   '-0.085*"better" + 0.084*"esm" + 0.083*"outlook" + 0.082*"basically" + '
#   '-0.082*"institution" + 0.081*"stage"'),
#  (96,
#   '-0.118*"deliver" + -0.113*"answer" + 0.098*"want" + -0.094*"make" + '
#   '0.089*"again" + -0.088*"figure" + 0.086*"future" + -0.086*"part" + '
#   '0.083*"something" + -0.080*"definition"'),
#  (97,
#   '-0.129*"let" + -0.106*"believe" + -0.103*"dynamic" + 0.098*"functioning" + '
#   '-0.098*"financial" + -0.097*"investment" + 0.093*"world" + -0.084*"part" + '
#   '0.082*"mediumterm" + -0.081*"direction"'),
#  (98,
#   '-0.117*"took" + 0.113*"financing" + -0.104*"large" + -0.104*"respect" + '
#   '0.101*"treaty" + 0.096*"rule" + 0.094*"currency" + -0.091*"system" + '
#   '0.089*"and" + -0.088*"ecb"'),
#  (99,
#   '0.102*"reason" + 0.100*"need" + 0.100*"lower" + -0.094*"future" + '
#   '-0.089*"really" + 0.086*"significant" + -0.082*"back" + -0.082*"low" + '
#   '-0.082*"central" + 0.079*"account"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.



coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)


coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='u_mass')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)
# Out:
# Coherence Score:  0.2128903154906919
#
# Coherence Score5:  0.3759388500810462
#
# Coherence Score10:  0.32719985741082713
#
# Coherence Score20:  0.2800624977068745
#
# Coherence Score50:  0.24957313332036946
#
# Coherence Score100:  0.22032990866530588
#
# Coherence Score:  -0.17175956004941648
#
# Coherence Score5:  -0.44211754621083543
#
# Coherence Score10:  -0.49993015969761545
#
# Coherence Score20:  -0.496530766836369
#
# Coherence Score50:  -0.8846288656400034
#
# Coherence Score100:  -0.7986485979264569
