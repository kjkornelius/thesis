# %%
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['qa']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(8371 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# less than 10 documents,
id2word = corpora.Dictionary(data)
id2word.filter_extremes(no_below = 4)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.162*"programme" + 0.150*"actually" + 0.133*"condition" + 0.123*"bond" + '
#   '0.110*"money" + 0.094*"recovery" + 0.093*"several" + 0.092*"lower" + '
#   '0.092*"don" + 0.091*"action"')]
# [(0,
#   '0.162*"programme" + 0.150*"actually" + 0.133*"condition" + 0.123*"bond" + '
#   '0.110*"money" + 0.094*"recovery" + 0.093*"several" + 0.092*"lower" + '
#   '0.092*"don" + 0.091*"action"'),
#  (1,
#   '-0.240*"actually" + 0.171*"deliver" + -0.160*"programme" + '
#   '-0.149*"condition" + 0.132*"currency" + -0.129*"basically" + -0.128*"thats" '
#   '+ -0.118*"sense" + -0.117*"bond" + 0.113*"observed"'),
#  (2,
#   '-0.338*"programme" + -0.254*"greece" + -0.250*"operation" + -0.214*"greek" '
#   '+ -0.209*"bond" + -0.181*"nonstandard" + -0.172*"billion" + '
#   '-0.147*"collateral" + -0.107*"functioning" + -0.104*"ela"'),
#  (3,
#   '-0.297*"programme" + -0.260*"thats" + 0.255*"money" + 0.179*"operation" + '
#   '-0.159*"condition" + -0.155*"weve" + -0.148*"greece" + -0.130*"recovery" + '
#   '0.129*"balance" + 0.128*"don"'),
#  (4,
#   '0.213*"thats" + 0.165*"weve" + 0.163*"negative" + 0.145*"purchase" + '
#   '-0.144*"treaty" + 0.133*"lower" + 0.129*"loan" + -0.127*"greece" + '
#   '-0.110*"week" + 0.110*"lending"')]
# [(0,
#   '0.162*"programme" + 0.150*"actually" + 0.133*"condition" + 0.123*"bond" + '
#   '0.110*"money" + 0.094*"recovery" + 0.093*"several" + 0.092*"lower" + '
#   '0.092*"don" + 0.091*"action"'),
#  (1,
#   '-0.240*"actually" + 0.171*"deliver" + -0.160*"programme" + '
#   '-0.149*"condition" + 0.132*"currency" + -0.129*"basically" + -0.128*"thats" '
#   '+ -0.118*"sense" + -0.117*"bond" + 0.113*"observed"'),
#  (2,
#   '-0.338*"programme" + -0.254*"greece" + -0.251*"operation" + -0.213*"greek" '
#   '+ -0.209*"bond" + -0.181*"nonstandard" + -0.172*"billion" + '
#   '-0.147*"collateral" + -0.107*"functioning" + -0.104*"ela"'),
#  (3,
#   '0.298*"programme" + 0.259*"thats" + -0.256*"money" + -0.178*"operation" + '
#   '0.160*"condition" + 0.155*"weve" + 0.147*"greece" + 0.131*"recovery" + '
#   '-0.129*"balance" + -0.129*"don"'),
#  (4,
#   '0.213*"thats" + 0.166*"weve" + 0.163*"negative" + 0.146*"purchase" + '
#   '-0.144*"treaty" + 0.132*"lower" + 0.130*"loan" + -0.127*"greece" + '
#   '-0.110*"week" + 0.109*"lending"'),
#  (5,
#   '-0.225*"money" + -0.221*"operation" + 0.162*"deliver" + 0.156*"programme" + '
#   '-0.125*"forecast" + -0.120*"billion" + -0.112*"week" + -0.110*"conclusion" '
#   '+ 0.108*"crisis" + -0.104*"negative"'),
#  (6,
#   '-0.253*"greek" + 0.239*"nonstandard" + -0.216*"greece" + -0.211*"bond" + '
#   '-0.154*"collateral" + -0.153*"ela" + 0.144*"recovery" + 0.141*"help" + '
#   '-0.116*"condition" + -0.114*"capital"'),
#  (7,
#   '0.237*"greece" + -0.202*"balance" + 0.200*"forward" + -0.194*"bond" + '
#   '0.170*"guidance" + -0.152*"sheet" + -0.148*"condition" + 0.129*"recovery" + '
#   '-0.114*"don" + -0.108*"creation"'),
#  (8,
#   '0.218*"ab" + 0.218*"programme" + -0.217*"condition" + -0.211*"negative" + '
#   '0.167*"we" + 0.160*"ve" + -0.149*"objective" + -0.134*"funding" + '
#   '-0.129*"financing" + 0.126*"qe"'),
#  (9,
#   '-0.198*"guidance" + -0.173*"forward" + -0.164*"asset" + 0.162*"labour" + '
#   '0.161*"quarter" + -0.148*"currency" + 0.115*"deliver" + -0.113*"bond" + '
#   '-0.113*"environment" + 0.111*"unemployment"')]
# [(0,
#   '0.162*"programme" + 0.150*"actually" + 0.133*"condition" + 0.123*"bond" + '
#   '0.110*"money" + 0.094*"recovery" + 0.093*"several" + 0.092*"lower" + '
#   '0.092*"don" + 0.091*"action"'),
#  (1,
#   '-0.240*"actually" + 0.171*"deliver" + -0.160*"programme" + '
#   '-0.149*"condition" + 0.132*"currency" + -0.129*"basically" + -0.128*"thats" '
#   '+ -0.118*"sense" + -0.117*"bond" + 0.113*"observed"'),
#  (2,
#   '-0.338*"programme" + -0.254*"greece" + -0.251*"operation" + -0.213*"greek" '
#   '+ -0.209*"bond" + -0.181*"nonstandard" + -0.172*"billion" + '
#   '-0.147*"collateral" + -0.107*"functioning" + -0.104*"ela"'),
#  (3,
#   '0.298*"programme" + 0.259*"thats" + -0.256*"money" + -0.179*"operation" + '
#   '0.160*"condition" + 0.155*"weve" + 0.147*"greece" + 0.130*"recovery" + '
#   '-0.129*"balance" + -0.129*"don"'),
#  (4,
#   '-0.214*"thats" + -0.165*"weve" + -0.163*"negative" + -0.146*"purchase" + '
#   '0.143*"treaty" + -0.132*"lower" + -0.129*"loan" + 0.127*"greece" + '
#   '0.110*"week" + -0.110*"lending"'),
#  (5,
#   '0.225*"money" + 0.221*"operation" + -0.163*"deliver" + -0.157*"programme" + '
#   '0.125*"forecast" + 0.120*"billion" + 0.113*"week" + 0.110*"conclusion" + '
#   '-0.108*"crisis" + 0.104*"negative"'),
#  (6,
#   '0.253*"greek" + -0.238*"nonstandard" + 0.215*"greece" + 0.211*"bond" + '
#   '0.154*"collateral" + 0.152*"ela" + -0.143*"recovery" + -0.141*"help" + '
#   '0.116*"condition" + 0.114*"capital"'),
#  (7,
#   '0.235*"greece" + -0.203*"balance" + 0.202*"forward" + -0.195*"bond" + '
#   '0.170*"guidance" + -0.151*"sheet" + -0.148*"condition" + 0.128*"recovery" + '
#   '-0.115*"don" + -0.109*"creation"'),
#  (8,
#   '-0.218*"condition" + 0.218*"programme" + 0.217*"ab" + -0.212*"negative" + '
#   '0.168*"we" + 0.161*"ve" + -0.149*"objective" + -0.134*"funding" + '
#   '-0.129*"financing" + 0.126*"qe"'),
#  (9,
#   '0.197*"guidance" + 0.173*"forward" + 0.164*"asset" + -0.161*"labour" + '
#   '-0.158*"quarter" + 0.146*"currency" + -0.116*"deliver" + '
#   '0.112*"environment" + 0.111*"bond" + -0.111*"unemployment"'),
#  (10,
#   '-0.195*"deliver" + 0.188*"recovery" + 0.178*"data" + -0.176*"objective" + '
#   '-0.146*"secondround" + 0.128*"pact" + 0.128*"balance" + 0.124*"negative" + '
#   '-0.105*"guidance" + 0.104*"positive"'),
#  (11,
#   '-0.313*"money" + 0.199*"staff" + -0.191*"recovery" + 0.190*"nonstandard" + '
#   '0.153*"eurosystem" + -0.132*"instrument" + 0.119*"framework" + '
#   '-0.116*"treaty" + 0.116*"ab" + 0.115*"abs"'),
#  (12,
#   '-0.178*"pact" + 0.178*"operation" + -0.162*"collateral" + 0.145*"programme" '
#   '+ -0.128*"framework" + -0.125*"currency" + 0.125*"test" + 0.117*"stress" + '
#   '0.112*"scenario" + 0.110*"billion"'),
#  (13,
#   '0.199*"balance" + -0.174*"loan" + -0.173*"programme" + 0.164*"nonstandard" '
#   '+ 0.158*"recovery" + 0.146*"instrument" + 0.141*"uncertainty" + '
#   '0.118*"staff" + -0.115*"purchase" + 0.115*"scenario"'),
#  (14,
#   '-0.151*"forward" + -0.147*"labour" + -0.138*"recovery" + 0.133*"committee" '
#   '+ -0.132*"bond" + 0.128*"ab" + -0.128*"condition" + 0.123*"pact" + '
#   '0.114*"concept" + 0.111*"loan"'),
#  (15,
#   '-0.161*"programme" + 0.151*"capital" + 0.146*"ela" + 0.146*"billion" + '
#   '0.145*"currency" + -0.138*"conditionality" + -0.137*"staff" + '
#   '-0.134*"recovery" + -0.129*"objective" + 0.124*"lower"'),
#  (16,
#   '0.237*"lending" + -0.197*"banking" + -0.150*"asset" + -0.142*"we" + '
#   '0.137*"balance" + 0.125*"thats" + 0.119*"every" + -0.111*"vigilance" + '
#   '-0.105*"crisis" + 0.104*"treaty"'),
#  (17,
#   '-0.215*"recovery" + 0.199*"condition" + -0.176*"balance" + -0.134*"thats" + '
#   '0.134*"deliver" + 0.130*"negative" + -0.118*"demand" + 0.110*"data" + '
#   '0.110*"guidance" + -0.096*"lending"'),
#  (18,
#   '-0.243*"balance" + 0.187*"actually" + 0.161*"operation" + -0.156*"sheet" + '
#   '0.147*"currency" + 0.124*"recovery" + -0.123*"condition" + -0.117*"treaty" '
#   '+ -0.111*"move" + -0.108*"lending"'),
#  (19,
#   '0.211*"bond" + 0.170*"scenario" + -0.146*"balance" + 0.143*"lending" + '
#   '0.136*"quarter" + 0.130*"functioning" + -0.123*"money" + -0.113*"labour" + '
#   '0.109*"uncertainty" + -0.107*"objective"')]
# [(0,
#   '-0.162*"programme" + -0.150*"actually" + -0.133*"condition" + -0.123*"bond" '
#   '+ -0.110*"money" + -0.094*"recovery" + -0.093*"several" + -0.092*"lower" + '
#   '-0.092*"don" + -0.091*"action"'),
#  (1,
#   '-0.240*"actually" + 0.171*"deliver" + -0.160*"programme" + '
#   '-0.149*"condition" + 0.132*"currency" + -0.129*"basically" + -0.128*"thats" '
#   '+ -0.118*"sense" + -0.117*"bond" + 0.113*"observed"'),
#  (2,
#   '0.338*"programme" + 0.254*"greece" + 0.251*"operation" + 0.214*"greek" + '
#   '0.209*"bond" + 0.181*"nonstandard" + 0.172*"billion" + 0.147*"collateral" + '
#   '0.107*"functioning" + 0.104*"ela"'),
#  (3,
#   '-0.298*"programme" + -0.259*"thats" + 0.256*"money" + 0.179*"operation" + '
#   '-0.159*"condition" + -0.155*"weve" + -0.147*"greece" + -0.130*"recovery" + '
#   '0.129*"balance" + 0.129*"don"'),
#  (4,
#   '0.213*"thats" + 0.165*"weve" + 0.163*"negative" + 0.146*"purchase" + '
#   '-0.143*"treaty" + 0.132*"lower" + 0.130*"loan" + -0.126*"greece" + '
#   '-0.110*"week" + 0.110*"lending"'),
#  (5,
#   '-0.225*"money" + -0.221*"operation" + 0.163*"deliver" + 0.156*"programme" + '
#   '-0.125*"forecast" + -0.120*"billion" + -0.113*"week" + -0.110*"conclusion" '
#   '+ 0.108*"crisis" + -0.104*"negative"'),
#  (6,
#   '-0.253*"greek" + 0.238*"nonstandard" + -0.216*"greece" + -0.212*"bond" + '
#   '-0.154*"collateral" + -0.153*"ela" + 0.143*"recovery" + 0.141*"help" + '
#   '-0.116*"condition" + -0.114*"capital"'),
#  (7,
#   '-0.235*"greece" + 0.203*"balance" + -0.201*"forward" + 0.194*"bond" + '
#   '-0.170*"guidance" + 0.152*"sheet" + 0.146*"condition" + -0.128*"recovery" + '
#   '0.115*"don" + 0.109*"creation"'),
#  (8,
#   '0.219*"condition" + -0.219*"programme" + -0.218*"ab" + 0.212*"negative" + '
#   '-0.167*"we" + -0.161*"ve" + 0.149*"objective" + 0.135*"funding" + '
#   '0.128*"financing" + -0.125*"qe"'),
#  (9,
#   '-0.197*"guidance" + -0.172*"forward" + -0.164*"asset" + 0.162*"labour" + '
#   '0.159*"quarter" + -0.147*"currency" + 0.116*"deliver" + '
#   '-0.113*"environment" + -0.112*"bond" + 0.110*"unemployment"'),
#  (10,
#   '0.196*"deliver" + -0.189*"recovery" + -0.179*"data" + 0.176*"objective" + '
#   '0.148*"secondround" + -0.127*"balance" + -0.127*"pact" + -0.125*"negative" '
#   '+ 0.105*"guidance" + -0.103*"positive"'),
#  (11,
#   '-0.312*"money" + 0.199*"staff" + -0.191*"recovery" + 0.189*"nonstandard" + '
#   '0.151*"eurosystem" + -0.133*"instrument" + 0.119*"framework" + '
#   '-0.117*"treaty" + 0.116*"ab" + 0.115*"abs"'),
#  (12,
#   '-0.179*"pact" + 0.177*"operation" + -0.167*"collateral" + 0.157*"programme" '
#   '+ -0.127*"framework" + 0.125*"test" + -0.121*"currency" + 0.116*"stress" + '
#   '-0.113*"instrument" + 0.110*"quarter"'),
#  (13,
#   '-0.195*"balance" + 0.178*"loan" + -0.167*"nonstandard" + 0.165*"programme" '
#   '+ -0.152*"recovery" + -0.145*"uncertainty" + -0.137*"instrument" + '
#   '-0.120*"scenario" + -0.119*"actually" + 0.114*"purchase"'),
#  (14,
#   '0.149*"forward" + 0.147*"labour" + 0.141*"recovery" + 0.135*"bond" + '
#   '-0.131*"committee" + -0.129*"ab" + 0.129*"condition" + -0.127*"pact" + '
#   '-0.114*"concept" + -0.109*"loan"'),
#  (15,
#   '-0.157*"programme" + 0.153*"capital" + 0.147*"ela" + 0.146*"billion" + '
#   '0.145*"currency" + -0.139*"conditionality" + -0.135*"staff" + '
#   '-0.134*"recovery" + -0.130*"objective" + 0.125*"lower"'),
#  (16,
#   '0.238*"lending" + -0.197*"banking" + -0.151*"asset" + -0.144*"we" + '
#   '0.139*"balance" + 0.126*"thats" + 0.121*"every" + -0.110*"vigilance" + '
#   '-0.106*"crisis" + 0.105*"treaty"'),
#  (17,
#   '-0.219*"recovery" + 0.202*"condition" + -0.170*"balance" + -0.134*"thats" + '
#   '0.133*"deliver" + 0.129*"negative" + -0.118*"demand" + 0.111*"data" + '
#   '0.108*"guidance" + 0.099*"financing"'),
#  (18,
#   '-0.245*"balance" + 0.188*"actually" + 0.161*"operation" + -0.156*"sheet" + '
#   '0.142*"currency" + -0.119*"condition" + 0.118*"recovery" + -0.115*"treaty" '
#   '+ -0.113*"move" + -0.112*"lending"'),
#  (19,
#   '0.210*"bond" + 0.167*"scenario" + -0.145*"balance" + 0.141*"lending" + '
#   '0.131*"quarter" + 0.131*"functioning" + -0.124*"money" + -0.114*"labour" + '
#   '-0.109*"guidance" + 0.109*"uncertainty"'),
#  (20,
#   '-0.226*"quarter" + -0.144*"negative" + -0.126*"competitiveness" + '
#   '0.116*"functioning" + 0.114*"single" + -0.113*"greece" + 0.113*"currency" + '
#   '-0.105*"loan" + -0.100*"actually" + -0.099*"athens"'),
#  (21,
#   '-0.183*"quarter" + 0.165*"operation" + 0.157*"labour" + -0.147*"lower" + '
#   '0.138*"condition" + 0.137*"staff" + 0.136*"instrument" + 0.109*"ab" + '
#   '0.106*"progress" + 0.100*"we"'),
#  (22,
#   '0.279*"instrument" + 0.158*"bond" + 0.121*"germany" + 0.112*"don" + '
#   '-0.109*"we" + 0.106*"target" + -0.103*"condition" + 0.100*"note" + '
#   '0.099*"average" + 0.098*"framework"'),
#  (23,
#   '0.136*"move" + -0.135*"currency" + 0.135*"tender" + 0.131*"fixed" + '
#   '0.117*"bond" + 0.117*"pact" + -0.099*"president" + -0.097*"staff" + '
#   '0.096*"observed" + -0.096*"several"'),
#  (24,
#   '0.146*"pact" + 0.137*"cost" + -0.128*"credible" + 0.122*"observed" + '
#   '0.119*"quarter" + -0.116*"credibility" + -0.113*"took" + -0.107*"recovery" '
#   '+ -0.107*"crisis" + 0.105*"lower"'),
#  (25,
#   '0.179*"treaty" + 0.136*"labour" + 0.128*"eurosystem" + -0.124*"committee" + '
#   '-0.118*"action" + 0.117*"functioning" + 0.116*"consolidation" + '
#   '-0.113*"balance" + 0.111*"lower" + -0.109*"note"'),
#  (26,
#   '-0.222*"currency" + 0.142*"collateral" + -0.134*"instrument" + 0.119*"don" '
#   '+ 0.115*"eurogroup" + -0.101*"carefully" + 0.101*"finance" + 0.096*"ab" + '
#   '-0.094*"bond" + -0.094*"committee"'),
#  (27,
#   '0.129*"ready" + -0.126*"condition" + -0.118*"lending" + -0.108*"mediumterm" '
#   '+ -0.108*"thats" + 0.107*"negative" + 0.102*"several" + 0.097*"president" + '
#   '-0.096*"don" + -0.092*"communication"'),
#  (28,
#   '-0.151*"objective" + 0.140*"staff" + 0.137*"uncertainty" + '
#   '-0.130*"operation" + 0.123*"actually" + 0.122*"environment" + 0.115*"asset" '
#   '+ -0.106*"treaty" + -0.100*"basically" + 0.100*"currency"'),
#  (29,
#   '0.137*"labour" + -0.128*"quarter" + -0.124*"participant" + 0.112*"scenario" '
#   '+ 0.111*"help" + -0.108*"tender" + -0.102*"stress" + -0.099*"test" + '
#   '0.098*"cost" + 0.096*"single"'),
#  (30,
#   '0.168*"note" + -0.144*"nonstandard" + 0.132*"mediumterm" + -0.115*"deposit" '
#   '+ 0.109*"week" + 0.109*"staff" + -0.105*"indicator" + 0.104*"irish" + '
#   '0.101*"plan" + 0.098*"sign"'),
#  (31,
#   '0.154*"concept" + -0.122*"scenario" + 0.112*"every" + 0.110*"functioning" + '
#   '-0.096*"especially" + 0.094*"bond" + -0.093*"eurogroup" + -0.093*"currency" '
#   '+ 0.092*"capital" + 0.087*"episode"'),
#  (32,
#   '-0.148*"programme" + -0.134*"favourable" + 0.120*"banking" + '
#   '-0.115*"vigilance" + 0.110*"thats" + -0.110*"environment" + '
#   '-0.109*"lending" + -0.104*"deflation" + 0.098*"citizen" + 0.097*"actually"'),
#  (33,
#   '-0.176*"treaty" + -0.147*"single" + -0.137*"programme" + 0.113*"security" + '
#   '0.109*"condition" + 0.105*"transmission" + -0.105*"decrease" + 0.103*"fund" '
#   '+ 0.103*"observed" + -0.095*"recovery"'),
#  (34,
#   '-0.146*"action" + 0.118*"billion" + 0.112*"uncertainty" + 0.106*"dollar" + '
#   '-0.106*"tender" + -0.090*"conditionality" + 0.089*"forward" + '
#   '0.086*"partner" + 0.085*"stress" + 0.084*"eurogroup"'),
#  (35,
#   '0.193*"note" + -0.161*"data" + 0.158*"pillar" + 0.127*"channel" + '
#   '-0.100*"objective" + 0.097*"decrease" + -0.096*"decide" + -0.091*"sign" + '
#   '-0.090*"deficit" + 0.088*"creation"'),
#  (36,
#   '0.199*"treaty" + -0.133*"balance" + 0.128*"recovery" + -0.118*"volatility" '
#   '+ 0.110*"fragmentation" + -0.104*"scenario" + -0.104*"currency" + '
#   '-0.099*"abs" + 0.096*"deliver" + 0.095*"nonstandard"'),
#  (37,
#   '0.122*"quarter" + 0.120*"ab" + -0.116*"phenomenon" + -0.116*"survey" + '
#   '-0.108*"nonstandard" + 0.107*"tender" + 0.106*"able" + -0.092*"week" + '
#   '0.090*"objective" + 0.089*"currency"'),
#  (38,
#   '-0.163*"treaty" + -0.138*"observed" + 0.124*"loan" + -0.123*"inflationary" '
#   '+ -0.115*"action" + 0.114*"lower" + 0.111*"move" + -0.094*"commodity" + '
#   '-0.094*"help" + -0.092*"objective"'),
#  (39,
#   '-0.200*"quarter" + -0.131*"money" + 0.117*"qe" + -0.114*"ve" + '
#   '0.108*"secondround" + -0.106*"staff" + -0.105*"functioning" + -0.098*"note" '
#   '+ 0.097*"imf" + 0.093*"ltro"'),
#  (40,
#   '0.174*"uncertainty" + -0.115*"actually" + -0.115*"secondround" + '
#   '-0.114*"survey" + 0.107*"instrument" + 0.101*"unemployment" + '
#   '-0.096*"recovery" + 0.094*"week" + -0.085*"tension" + -0.084*"tender"'),
#  (41,
#   '0.151*"committee" + -0.143*"single" + 0.122*"deficit" + -0.119*"imf" + '
#   '-0.118*"data" + -0.117*"instrument" + 0.112*"credibility" + -0.111*"decide" '
#   '+ 0.104*"ex" + 0.102*"activity"'),
#  (42,
#   '-0.129*"tender" + 0.125*"however" + 0.124*"note" + -0.119*"banking" + '
#   '0.110*"credibility" + 0.103*"actually" + 0.099*"took" + 0.096*"million" + '
#   '-0.094*"communication" + 0.093*"refinancing"'),
#  (43,
#   '-0.121*"atlantic" + -0.108*"sense" + -0.107*"emerging" + 0.099*"range" + '
#   '0.098*"carefully" + 0.096*"uncertainty" + 0.095*"phenomenon" + 0.094*"qe" + '
#   '0.090*"read" + -0.090*"esm"'),
#  (44,
#   '-0.120*"creation" + -0.118*"matter" + -0.105*"average" + '
#   '-0.102*"unemployment" + -0.100*"sustainable" + -0.095*"greece" + '
#   '-0.094*"mr" + 0.091*"investment" + 0.090*"pillar" + 0.088*"financing"'),
#  (45,
#   '0.134*"tender" + 0.122*"deficit" + 0.118*"condition" + -0.111*"currency" + '
#   '-0.108*"recovery" + 0.101*"due" + 0.098*"conditionality" + '
#   '0.094*"uncertainty" + 0.090*"necessarily" + 0.089*"decide"'),
#  (46,
#   '0.129*"changed" + 0.128*"decrease" + -0.121*"basically" + '
#   '-0.118*"mediumterm" + 0.117*"deflation" + 0.112*"took" + -0.110*"upside" + '
#   '0.101*"don" + 0.096*"run" + -0.095*"methodology"'),
#  (47,
#   '0.148*"nonstandard" + 0.118*"phenomenon" + 0.107*"lower" + 0.102*"recovery" '
#   '+ 0.101*"dynamic" + -0.096*"expenditure" + 0.096*"cost" + -0.095*"esm" + '
#   '-0.094*"achieved" + 0.091*"lack"'),
#  (48,
#   '0.115*"credible" + 0.104*"greece" + -0.104*"carefully" + 0.103*"reserve" + '
#   '0.100*"credibility" + -0.089*"big" + -0.088*"tomorrow" + 0.088*"banking" + '
#   '-0.087*"default" + -0.087*"decide"'),
#  (49,
#   '0.127*"phenomenon" + -0.124*"staff" + 0.122*"upside" + -0.105*"imf" + '
#   '0.103*"conclusion" + 0.094*"trend" + 0.094*"benchmark" + '
#   '-0.092*"tightening" + -0.091*"week" + -0.090*"banking"')]
# [(0,
#   '-0.162*"programme" + -0.150*"actually" + -0.133*"condition" + -0.123*"bond" '
#   '+ -0.110*"money" + -0.094*"recovery" + -0.093*"several" + -0.092*"lower" + '
#   '-0.092*"don" + -0.091*"action"'),
#  (1,
#   '-0.240*"actually" + 0.171*"deliver" + -0.160*"programme" + '
#   '-0.149*"condition" + 0.132*"currency" + -0.129*"basically" + -0.128*"thats" '
#   '+ -0.118*"sense" + -0.117*"bond" + 0.113*"observed"'),
#  (2,
#   '-0.338*"programme" + -0.254*"greece" + -0.251*"operation" + -0.214*"greek" '
#   '+ -0.209*"bond" + -0.181*"nonstandard" + -0.172*"billion" + '
#   '-0.147*"collateral" + -0.107*"functioning" + -0.104*"ela"'),
#  (3,
#   '0.298*"programme" + 0.259*"thats" + -0.256*"money" + -0.179*"operation" + '
#   '0.159*"condition" + 0.155*"weve" + 0.147*"greece" + 0.130*"recovery" + '
#   '-0.129*"balance" + -0.129*"don"'),
#  (4,
#   '0.213*"thats" + 0.165*"weve" + 0.163*"negative" + 0.146*"purchase" + '
#   '-0.143*"treaty" + 0.132*"lower" + 0.129*"loan" + -0.126*"greece" + '
#   '-0.110*"week" + 0.110*"lending"'),
#  (5,
#   '-0.225*"money" + -0.221*"operation" + 0.163*"deliver" + 0.157*"programme" + '
#   '-0.125*"forecast" + -0.120*"billion" + -0.113*"week" + -0.110*"conclusion" '
#   '+ 0.108*"crisis" + -0.104*"negative"'),
#  (6,
#   '0.253*"greek" + -0.238*"nonstandard" + 0.216*"greece" + 0.212*"bond" + '
#   '0.154*"collateral" + 0.153*"ela" + -0.143*"recovery" + -0.141*"help" + '
#   '0.116*"condition" + 0.114*"capital"'),
#  (7,
#   '-0.235*"greece" + 0.203*"balance" + -0.201*"forward" + 0.195*"bond" + '
#   '-0.170*"guidance" + 0.151*"sheet" + 0.146*"condition" + -0.128*"recovery" + '
#   '0.115*"don" + 0.109*"creation"'),
#  (8,
#   '-0.219*"condition" + 0.219*"programme" + 0.218*"ab" + -0.212*"negative" + '
#   '0.167*"we" + 0.161*"ve" + -0.149*"objective" + -0.135*"funding" + '
#   '-0.128*"financing" + 0.125*"qe"'),
#  (9,
#   '0.197*"guidance" + 0.173*"forward" + 0.164*"asset" + -0.162*"labour" + '
#   '-0.159*"quarter" + 0.147*"currency" + -0.116*"deliver" + '
#   '0.113*"environment" + 0.112*"bond" + -0.111*"unemployment"'),
#  (10,
#   '-0.196*"deliver" + 0.189*"recovery" + 0.179*"data" + -0.176*"objective" + '
#   '-0.147*"secondround" + 0.128*"balance" + 0.127*"pact" + 0.125*"negative" + '
#   '-0.106*"guidance" + 0.103*"positive"'),
#  (11,
#   '-0.312*"money" + 0.199*"staff" + -0.192*"recovery" + 0.189*"nonstandard" + '
#   '0.151*"eurosystem" + -0.133*"instrument" + 0.119*"framework" + '
#   '-0.117*"treaty" + 0.115*"ab" + 0.115*"abs"'),
#  (12,
#   '-0.179*"pact" + 0.177*"operation" + -0.166*"collateral" + 0.156*"programme" '
#   '+ -0.127*"framework" + 0.125*"test" + -0.122*"currency" + 0.115*"stress" + '
#   '-0.113*"instrument" + 0.110*"quarter"'),
#  (13,
#   '0.196*"balance" + -0.178*"loan" + 0.168*"nonstandard" + -0.164*"programme" '
#   '+ 0.152*"recovery" + 0.145*"uncertainty" + 0.138*"instrument" + '
#   '0.120*"scenario" + 0.119*"actually" + -0.115*"purchase"'),
#  (14,
#   '0.149*"forward" + 0.147*"labour" + 0.140*"recovery" + 0.135*"bond" + '
#   '-0.131*"committee" + -0.130*"ab" + 0.130*"condition" + -0.127*"pact" + '
#   '-0.114*"concept" + -0.108*"loan"'),
#  (15,
#   '-0.158*"programme" + 0.152*"capital" + 0.147*"ela" + 0.146*"currency" + '
#   '0.145*"billion" + -0.139*"conditionality" + -0.136*"staff" + '
#   '-0.134*"recovery" + -0.130*"objective" + 0.125*"lower"'),
#  (16,
#   '-0.238*"lending" + 0.197*"banking" + 0.151*"asset" + 0.145*"we" + '
#   '-0.139*"balance" + -0.127*"thats" + -0.121*"every" + 0.109*"vigilance" + '
#   '0.106*"crisis" + -0.104*"treaty"'),
#  (17,
#   '0.218*"recovery" + -0.202*"condition" + 0.171*"balance" + 0.133*"thats" + '
#   '-0.133*"deliver" + -0.129*"negative" + 0.119*"demand" + -0.111*"data" + '
#   '-0.109*"guidance" + -0.097*"financing"'),
#  (18,
#   '-0.246*"balance" + 0.188*"actually" + 0.160*"operation" + -0.157*"sheet" + '
#   '0.143*"currency" + 0.120*"recovery" + -0.120*"condition" + -0.116*"treaty" '
#   '+ -0.113*"lending" + -0.112*"move"'),
#  (19,
#   '-0.211*"bond" + -0.168*"scenario" + 0.145*"balance" + -0.141*"lending" + '
#   '-0.131*"quarter" + -0.130*"functioning" + 0.123*"money" + 0.113*"labour" + '
#   '-0.109*"uncertainty" + 0.108*"guidance"'),
#  (20,
#   '-0.225*"quarter" + -0.144*"negative" + -0.126*"competitiveness" + '
#   '0.116*"functioning" + 0.114*"single" + 0.114*"currency" + -0.113*"greece" + '
#   '-0.105*"loan" + -0.100*"actually" + -0.100*"athens"'),
#  (21,
#   '-0.185*"quarter" + 0.165*"operation" + 0.157*"labour" + -0.147*"lower" + '
#   '0.139*"condition" + 0.137*"staff" + 0.136*"instrument" + 0.110*"ab" + '
#   '0.105*"progress" + 0.099*"we"'),
#  (22,
#   '0.280*"instrument" + 0.157*"bond" + 0.120*"germany" + 0.112*"don" + '
#   '-0.109*"we" + 0.106*"target" + -0.104*"condition" + 0.100*"note" + '
#   '0.099*"average" + -0.097*"ve"'),
#  (23,
#   '0.138*"move" + 0.135*"tender" + -0.135*"currency" + 0.132*"fixed" + '
#   '0.118*"bond" + 0.117*"pact" + -0.099*"president" + 0.098*"observed" + '
#   '-0.098*"staff" + -0.097*"several"'),
#  (24,
#   '0.147*"pact" + 0.138*"cost" + -0.128*"credible" + 0.122*"observed" + '
#   '0.120*"quarter" + -0.115*"credibility" + -0.112*"took" + -0.107*"recovery" '
#   '+ 0.107*"lower" + -0.106*"crisis"'),
#  (25,
#   '0.179*"treaty" + 0.135*"labour" + 0.127*"eurosystem" + -0.125*"committee" + '
#   '-0.119*"action" + 0.117*"functioning" + 0.116*"consolidation" + '
#   '-0.113*"balance" + 0.111*"lower" + -0.109*"note"'),
#  (26,
#   '-0.222*"currency" + 0.141*"collateral" + -0.131*"instrument" + 0.120*"don" '
#   '+ 0.115*"eurogroup" + -0.101*"carefully" + 0.101*"finance" + 0.096*"ab" + '
#   '-0.095*"bond" + -0.094*"committee"'),
#  (27,
#   '-0.130*"ready" + 0.125*"condition" + 0.117*"lending" + 0.112*"mediumterm" + '
#   '0.109*"thats" + -0.106*"negative" + -0.104*"several" + -0.099*"president" + '
#   '0.096*"don" + 0.091*"communication"'),
#  (28,
#   '0.151*"objective" + -0.143*"staff" + -0.138*"uncertainty" + '
#   '0.130*"operation" + -0.123*"actually" + -0.121*"environment" + '
#   '-0.116*"asset" + 0.107*"treaty" + 0.101*"basically" + -0.099*"currency"'),
#  (29,
#   '-0.137*"labour" + 0.126*"quarter" + 0.124*"participant" + -0.111*"scenario" '
#   '+ -0.110*"help" + 0.108*"tender" + 0.103*"stress" + -0.100*"cost" + '
#   '0.099*"test" + -0.096*"single"'),
#  (30,
#   '0.170*"note" + -0.146*"nonstandard" + 0.133*"mediumterm" + -0.116*"deposit" '
#   '+ 0.108*"staff" + 0.108*"week" + 0.105*"irish" + -0.102*"indicator" + '
#   '-0.100*"survey" + 0.099*"plan"'),
#  (31,
#   '0.155*"concept" + -0.122*"scenario" + 0.115*"every" + 0.111*"functioning" + '
#   '-0.096*"especially" + 0.095*"bond" + 0.093*"capital" + -0.093*"eurogroup" + '
#   '-0.092*"currency" + 0.087*"episode"'),
#  (32,
#   '-0.149*"programme" + -0.134*"favourable" + 0.119*"banking" + '
#   '-0.115*"vigilance" + -0.110*"environment" + 0.110*"thats" + '
#   '-0.109*"lending" + -0.103*"deflation" + 0.099*"indicator" + '
#   '0.098*"citizen"'),
#  (33,
#   '0.178*"treaty" + 0.147*"single" + 0.138*"programme" + -0.112*"security" + '
#   '-0.107*"condition" + -0.106*"transmission" + -0.105*"fund" + '
#   '-0.102*"observed" + 0.101*"decrease" + -0.094*"note"'),
#  (34,
#   '-0.147*"action" + 0.119*"billion" + 0.113*"uncertainty" + -0.107*"tender" + '
#   '0.106*"dollar" + -0.091*"conditionality" + 0.087*"forward" + '
#   '0.086*"partner" + 0.084*"stress" + -0.084*"credible"'),
#  (35,
#   '-0.185*"note" + 0.160*"data" + -0.157*"pillar" + -0.125*"channel" + '
#   '0.100*"decide" + 0.097*"objective" + -0.095*"currency" + -0.095*"decrease" '
#   '+ 0.093*"sign" + -0.090*"creation"'),
#  (36,
#   '0.204*"treaty" + 0.134*"recovery" + -0.134*"balance" + -0.127*"volatility" '
#   '+ 0.104*"fragmentation" + -0.101*"scenario" + 0.101*"note" + '
#   '-0.099*"commitment" + -0.099*"currency" + 0.097*"credible"'),
#  (37,
#   '0.122*"quarter" + 0.120*"ab" + -0.118*"survey" + -0.113*"phenomenon" + '
#   '-0.107*"nonstandard" + 0.106*"tender" + 0.105*"able" + 0.093*"objective" + '
#   '-0.093*"week" + 0.091*"staff"'),
#  (38,
#   '0.159*"treaty" + 0.139*"observed" + 0.123*"inflationary" + -0.123*"loan" + '
#   '-0.115*"move" + 0.115*"action" + -0.110*"lower" + 0.093*"help" + '
#   '0.092*"commodity" + 0.091*"deficit"'),
#  (39,
#   '-0.196*"quarter" + -0.133*"money" + 0.121*"qe" + -0.117*"ve" + '
#   '0.115*"secondround" + -0.112*"staff" + -0.101*"functioning" + 0.097*"imf" + '
#   '-0.095*"note" + 0.094*"ltro"'),
#  (40,
#   '-0.173*"uncertainty" + 0.120*"actually" + 0.115*"survey" + '
#   '0.112*"secondround" + -0.109*"instrument" + -0.103*"unemployment" + '
#   '0.094*"recovery" + -0.091*"week" + 0.087*"average" + 0.086*"tension"'),
#  (41,
#   '-0.151*"committee" + 0.139*"single" + -0.121*"deficit" + 0.120*"instrument" '
#   '+ 0.120*"imf" + 0.117*"decide" + 0.117*"data" + -0.110*"credibility" + '
#   '-0.102*"ex" + -0.101*"activity"'),
#  (42,
#   '-0.128*"however" + 0.128*"tender" + -0.122*"note" + 0.117*"banking" + '
#   '-0.112*"credibility" + -0.103*"took" + -0.101*"actually" + -0.098*"million" '
#   '+ 0.095*"communication" + -0.094*"refinancing"'),
#  (43,
#   '0.119*"atlantic" + 0.113*"sense" + 0.105*"emerging" + -0.099*"range" + '
#   '-0.097*"qe" + -0.097*"carefully" + -0.096*"uncertainty" + 0.093*"esm" + '
#   '-0.092*"phenomenon" + -0.091*"read"'),
#  (44,
#   '-0.120*"creation" + -0.118*"matter" + -0.105*"sustainable" + -0.103*"mr" + '
#   '-0.102*"unemployment" + -0.098*"average" + -0.098*"greece" + '
#   '0.090*"financing" + 0.089*"investment" + 0.089*"series"'),
#  (45,
#   '0.139*"tender" + 0.122*"deficit" + 0.117*"condition" + -0.112*"currency" + '
#   '-0.112*"recovery" + 0.103*"uncertainty" + 0.100*"due" + '
#   '0.097*"conditionality" + -0.096*"used" + -0.093*"progress"'),
#  (46,
#   '0.131*"decrease" + 0.129*"changed" + -0.114*"basically" + '
#   '-0.112*"mediumterm" + 0.111*"deflation" + 0.108*"took" + 0.106*"don" + '
#   '-0.102*"upside" + 0.096*"run" + 0.094*"read"'),
#  (47,
#   '0.142*"nonstandard" + 0.116*"phenomenon" + 0.105*"lower" + 0.101*"recovery" '
#   '+ 0.099*"dynamic" + -0.096*"expenditure" + -0.095*"esm" + 0.093*"cost" + '
#   '0.091*"lack" + 0.090*"able"'),
#  (48,
#   '-0.117*"credible" + -0.116*"reserve" + -0.104*"greece" + 0.100*"carefully" '
#   '+ 0.095*"default" + -0.095*"credibility" + 0.091*"tomorrow" + 0.091*"big" + '
#   '0.086*"decide" + 0.086*"doctrine"'),
#  (49,
#   '-0.123*"staff" + 0.123*"phenomenon" + 0.123*"upside" + 0.104*"conclusion" + '
#   '-0.103*"imf" + 0.097*"benchmark" + -0.096*"tightening" + -0.095*"banking" + '
#   '-0.091*"week" + 0.090*"trend"'),
#  (50,
#   '-0.124*"demand" + -0.113*"collateral" + -0.109*"competitiveness" + '
#   '-0.109*"tender" + -0.103*"germany" + 0.099*"omt" + -0.088*"use" + '
#   '-0.083*"fixed" + -0.083*"domestic" + 0.083*"head"'),
#  (51,
#   '0.160*"functioning" + -0.160*"banking" + -0.102*"concept" + 0.093*"sense" + '
#   '0.092*"instrument" + -0.091*"governor" + 0.091*"phenomenon" + -0.088*"test" '
#   '+ 0.087*"creation" + 0.086*"sign"'),
#  (52,
#   '0.115*"currency" + -0.109*"eurogroup" + 0.106*"banking" + -0.096*"test" + '
#   '-0.093*"team" + -0.092*"partner" + 0.091*"help" + -0.091*"consensus" + '
#   '-0.090*"executive" + -0.087*"competition"'),
#  (53,
#   '-0.137*"operation" + 0.131*"note" + 0.130*"draw" + -0.118*"functioning" + '
#   '-0.108*"sentiment" + 0.106*"potential" + 0.103*"volatility" + '
#   '0.096*"opinion" + -0.096*"international" + 0.095*"mediumterm"'),
#  (54,
#   '0.130*"trust" + -0.127*"stress" + -0.123*"test" + -0.114*"fragmentation" + '
#   '0.112*"supervisor" + 0.097*"action" + 0.094*"intervention" + 0.089*"option" '
#   '+ -0.086*"ab" + -0.086*"remember"'),
#  (55,
#   '-0.124*"default" + -0.113*"doctrine" + 0.109*"example" + 0.090*"we" + '
#   '0.089*"shock" + 0.089*"opinion" + 0.087*"executive" + -0.086*"credible" + '
#   '-0.085*"decide" + -0.084*"atlantic"'),
#  (56,
#   '-0.117*"security" + 0.111*"action" + 0.109*"upside" + 0.103*"uncertainty" + '
#   '0.094*"irish" + -0.092*"ask" + -0.087*"them" + -0.087*"athens" + '
#   '-0.083*"banknote" + 0.083*"observing"'),
#  (57,
#   '-0.108*"decide" + -0.107*"sign" + -0.105*"plan" + 0.104*"irish" + '
#   '-0.102*"note" + 0.101*"proposal" + -0.099*"use" + -0.097*"investment" + '
#   '0.096*"dynamic" + 0.088*"necessarily"'),
#  (58,
#   '0.148*"quarter" + 0.105*"condition" + 0.102*"forecast" + 0.091*"however" + '
#   '-0.090*"deficit" + 0.089*"thats" + -0.089*"yield" + 0.088*"money" + '
#   '-0.086*"observing" + 0.080*"function"'),
#  (59,
#   '-0.128*"functioning" + 0.124*"favourable" + 0.110*"sense" + 0.094*"upside" '
#   '+ -0.092*"eurogroup" + -0.091*"fragmentation" + 0.088*"plan" + '
#   '-0.088*"phenomenon" + -0.087*"evidence" + -0.086*"condition"'),
#  (60,
#   '-0.141*"intervention" + 0.131*"lower" + 0.121*"operation" + 0.104*"opinion" '
#   '+ 0.102*"especially" + -0.095*"assumption" + -0.093*"mediumterm" + '
#   '0.093*"dynamic" + 0.090*"essential" + -0.084*"difference"'),
#  (61,
#   '0.158*"mr" + -0.120*"review" + 0.120*"capital" + 0.114*"day" + '
#   '0.099*"implemented" + 0.094*"report" + -0.094*"ela" + -0.093*"environment" '
#   '+ -0.090*"remark" + -0.089*"within"'),
#  (62,
#   '0.119*"germany" + 0.114*"loan" + 0.113*"objective" + 0.098*"option" + '
#   '0.096*"upside" + -0.096*"negative" + 0.093*"consensus" + 0.091*"december" + '
#   '0.089*"eurogroup" + -0.086*"specific"'),
#  (63,
#   '0.103*"phenomenon" + 0.103*"bond" + 0.099*"able" + -0.087*"financing" + '
#   '-0.084*"legislation" + 0.084*"proposal" + -0.082*"creation" + '
#   '-0.082*"germany" + -0.077*"treaty" + -0.077*"unemployment"'),
#  (64,
#   '-0.107*"review" + -0.098*"remark" + 0.097*"considered" + 0.089*"following" '
#   '+ -0.088*"extremely" + 0.086*"fragmentation" + 0.084*"fundamental" + '
#   '-0.083*"series" + 0.082*"improvement" + 0.081*"billion"'),
#  (65,
#   '0.121*"week" + -0.100*"progressively" + 0.096*"occasion" + 0.092*"several" '
#   '+ 0.092*"move" + -0.091*"note" + -0.090*"normal" + -0.087*"judge" + '
#   '0.084*"basically" + -0.084*"banking"'),
#  (66,
#   '0.119*"action" + -0.112*"objective" + 0.109*"quarter" + -0.101*"percentage" '
#   '+ -0.097*"positive" + -0.096*"cyprus" + -0.092*"several" + 0.088*"trust" + '
#   '-0.084*"extremely" + 0.083*"sustainable"'),
#  (67,
#   '0.119*"able" + 0.110*"consensus" + 0.102*"tax" + -0.098*"potential" + '
#   '-0.096*"functioning" + -0.096*"ab" + -0.095*"purchase" + -0.093*"facility" '
#   '+ 0.090*"benefit" + -0.090*"everybody"'),
#  (68,
#   '0.129*"move" + 0.116*"extremely" + 0.112*"ensure" + 0.109*"every" + '
#   '0.106*"political" + -0.098*"environment" + -0.088*"reserve" + '
#   '-0.088*"assumption" + 0.086*"totally" + -0.086*"july"'),
#  (69,
#   '-0.112*"loan" + -0.112*"meet" + 0.103*"phenomenon" + 0.097*"sign" + '
#   '-0.097*"cyprus" + -0.094*"esm" + 0.092*"progress" + 0.089*"president" + '
#   '-0.088*"reserve" + 0.088*"lower"'),
#  (70,
#   '-0.128*"supply" + 0.126*"purchase" + -0.087*"president" + -0.084*"opinion" '
#   '+ -0.083*"occasion" + 0.079*"germany" + -0.077*"read" + -0.076*"potential" '
#   '+ 0.076*"return" + -0.076*"stressed"'),
#  (71,
#   '0.111*"observed" + -0.101*"forecast" + -0.093*"data" + -0.091*"ltro" + '
#   '-0.087*"option" + 0.086*"treaty" + 0.085*"several" + 0.083*"funding" + '
#   '-0.082*"march" + 0.081*"loan"'),
#  (72,
#   '-0.121*"banking" + -0.117*"environment" + -0.115*"president" + '
#   '0.105*"agreement" + -0.104*"independence" + -0.101*"observing" + '
#   '0.094*"single" + 0.093*"money" + 0.092*"debt" + -0.089*"creation"'),
#  (73,
#   '0.123*"eurogroup" + -0.099*"uncertainty" + -0.096*"remember" + '
#   '0.093*"indicator" + 0.086*"whatever" + 0.084*"crisis" + -0.084*"qe" + '
#   '0.082*"available" + -0.082*"march" + -0.081*"keep"'),
#  (74,
#   '-0.134*"conclusion" + 0.109*"credibility" + 0.107*"sentiment" + '
#   '0.097*"improvement" + -0.096*"decide" + 0.092*"single" + -0.089*"judge" + '
#   '0.087*"finance" + -0.083*"data" + -0.083*"around"'),
#  (75,
#   '0.097*"unanimous" + 0.097*"discus" + 0.095*"eurosystem" + 0.091*"upside" + '
#   '-0.087*"uncertainty" + -0.086*"signal" + -0.085*"survey" + -0.085*"deliver" '
#   '+ 0.082*"refinancing" + -0.081*"international"'),
#  (76,
#   '-0.137*"parliament" + -0.119*"imf" + -0.112*"opinion" + -0.111*"standard" + '
#   '-0.098*"intervention" + -0.095*"upon" + -0.091*"conditionality" + '
#   '0.090*"single" + -0.082*"understanding" + 0.081*"additional"'),
#  (77,
#   '0.106*"conditionality" + -0.098*"upon" + -0.094*"recovery" + '
#   '-0.092*"operation" + 0.087*"hard" + 0.082*"procedure" + -0.082*"banknote" + '
#   '0.080*"essential" + -0.080*"loss" + 0.079*"yield"'),
#  (78,
#   '-0.132*"consensus" + -0.111*"uncertainty" + -0.098*"observing" + '
#   '0.096*"considered" + -0.089*"forecast" + 0.086*"loss" + -0.080*"ensure" + '
#   '-0.080*"responsible" + 0.080*"tax" + 0.080*"conclusion"'),
#  (79,
#   '0.106*"agreement" + 0.089*"commitment" + 0.089*"investment" + -0.083*"debt" '
#   '+ 0.083*"strategy" + -0.083*"banknote" + -0.082*"household" + 0.080*"trust" '
#   '+ 0.076*"emerging" + 0.076*"upon"'),
#  (80,
#   '0.108*"tender" + -0.101*"team" + 0.094*"example" + -0.092*"intervention" + '
#   '0.091*"fixed" + 0.086*"dynamic" + 0.083*"early" + -0.082*"labour" + '
#   '-0.082*"movement" + -0.081*"average"'),
#  (81,
#   '0.111*"day" + 0.097*"smp" + 0.096*"episode" + -0.093*"dollar" + '
#   '0.088*"diagnosis" + 0.084*"finance" + -0.080*"capacity" + '
#   '-0.079*"conclusion" + -0.076*"default" + 0.074*"governor"'),
#  (82,
#   '-0.120*"week" + 0.109*"normal" + 0.091*"crisis" + 0.087*"carefully" + '
#   '-0.086*"conditionality" + -0.083*"china" + -0.083*"imf" + '
#   '-0.081*"independence" + -0.080*"supervisor" + -0.079*"environment"'),
#  (83,
#   '-0.138*"day" + -0.133*"action" + 0.111*"secondround" + 0.095*"ii" + '
#   '0.095*"uncertainty" + -0.093*"greece" + 0.092*"credible" + 0.090*"finance" '
#   '+ -0.090*"money" + -0.088*"decrease"'),
#  (84,
#   '0.105*"president" + -0.103*"very" + 0.101*"decide" + -0.101*"transmission" '
#   '+ -0.087*"qe" + 0.084*"concern" + -0.083*"shock" + -0.080*"day" + '
#   '-0.078*"credible" + -0.078*"investment"'),
#  (85,
#   '-0.095*"deliver" + -0.094*"partner" + 0.092*"labour" + -0.092*"especially" '
#   '+ 0.090*"day" + 0.087*"exceptional" + 0.086*"independence" + '
#   '-0.084*"looking" + 0.078*"complex" + -0.078*"help"'),
#  (86,
#   '-0.143*"credibility" + -0.099*"hard" + 0.087*"ltro" + -0.083*"amount" + '
#   '0.081*"nonstandard" + -0.081*"basically" + 0.080*"esm" + 0.080*"irish" + '
#   '-0.079*"atlantic" + -0.078*"anchor"'),
#  (87,
#   '0.098*"germany" + -0.093*"advance" + 0.092*"within" + -0.090*"volatility" + '
#   '-0.086*"purchase" + 0.085*"weak" + -0.085*"vigilant" + -0.085*"thought" + '
#   '-0.084*"forecast" + 0.083*"consolidation"'),
#  (88,
#   '-0.134*"value" + -0.104*"environment" + 0.101*"evidence" + '
#   '-0.095*"forecast" + -0.090*"remember" + 0.089*"refinancing" + '
#   '0.089*"several" + 0.087*"inflationary" + 0.086*"use" + 0.084*"reserve"'),
#  (89,
#   '-0.139*"independence" + -0.106*"open" + 0.099*"criterion" + -0.091*"don" + '
#   '-0.090*"run" + 0.088*"review" + 0.087*"unemployment" + -0.086*"speaking" + '
#   '0.082*"smp" + 0.081*"head"'),
#  (90,
#   '0.110*"effective" + -0.100*"judge" + 0.100*"conference" + -0.095*"amount" + '
#   '0.089*"here" + 0.089*"implemented" + 0.088*"share" + -0.087*"crisis" + '
#   '0.085*"smp" + -0.085*"pressure"'),
#  (91,
#   '0.116*"every" + -0.109*"proposal" + -0.098*"single" + -0.098*"option" + '
#   '0.090*"signal" + -0.089*"sustained" + 0.088*"intervention" + '
#   '-0.084*"favourable" + 0.082*"agreement" + 0.080*"independence"'),
#  (92,
#   '0.107*"value" + -0.099*"money" + 0.099*"principle" + -0.093*"intervention" '
#   '+ -0.090*"complex" + 0.088*"war" + 0.085*"methodology" + 0.084*"domestic" + '
#   '-0.083*"goal" + 0.082*"billion"'),
#  (93,
#   '0.099*"loss" + 0.096*"extremely" + 0.093*"conclusion" + 0.088*"president" + '
#   '0.087*"alert" + -0.084*"difficulty" + -0.081*"help" + 0.080*"indicator" + '
#   '0.079*"standard" + -0.078*"body"'),
#  (94,
#   '0.107*"intervention" + 0.100*"plan" + 0.081*"intention" + '
#   '0.080*"additional" + -0.080*"deal" + -0.077*"nonstandard" + -0.075*"amount" '
#   '+ 0.074*"judge" + -0.074*"observation" + -0.074*"day"'),
#  (95,
#   '-0.093*"sustainable" + -0.090*"loan" + 0.087*"phenomenon" + '
#   '0.079*"cooperation" + 0.078*"observer" + -0.078*"supervision" + '
#   '-0.077*"extremely" + -0.076*"eurosystem" + -0.076*"agreed" + -0.073*"week"'),
#  (96,
#   '0.139*"deliver" + -0.113*"convergence" + 0.097*"intervention" + '
#   '0.095*"response" + -0.092*"financing" + -0.087*"tender" + 0.082*"essence" + '
#   '-0.081*"unemployment" + -0.079*"stand" + 0.079*"mediumterm"'),
#  (97,
#   '-0.104*"intervention" + 0.100*"week" + 0.100*"commodity" + -0.097*"simple" '
#   '+ 0.090*"investor" + 0.085*"data" + 0.080*"challenge" + 0.079*"confirm" + '
#   '0.079*"opinion" + -0.078*"loss"'),
#  (98,
#   '0.102*"sentiment" + -0.097*"sign" + -0.096*"proposal" + '
#   '-0.091*"inflationary" + 0.090*"crisis" + 0.089*"every" + -0.085*"precisely" '
#   '+ -0.085*"parliament" + -0.084*"region" + -0.082*"committee"'),
#  (99,
#   '0.101*"used" + -0.098*"crisis" + 0.085*"tax" + -0.085*"vigilance" + '
#   '0.083*"mr" + 0.081*"cautious" + -0.080*"imf" + 0.079*"investment" + '
#   '-0.079*"functioning" + 0.078*"loss"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.



coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)


coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='u_mass')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)
# Out:
# Coherence Score:  0.36947416716256093
#
# Coherence Score5:  0.3814036597460726
#
# Coherence Score10:  0.33680708090984746
#
# Coherence Score20:  0.2741303957399451
#
# Coherence Score50:  0.24507132043422925
#
# Coherence Score100:  0.2185240758775431
#
# Coherence Score:  -0.6375017967841166
#
# Coherence Score5:  -0.8213122217456782
#
# Coherence Score10:  -0.9804211270309408
#
# Coherence Score20:  -1.1087980628879115
#
# Coherence Score50:  -1.5491138808040759
#
# Coherence Score100:  -1.485996842658067
