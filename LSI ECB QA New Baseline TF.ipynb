# %%
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['qa']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(8371 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
id2word.filter_n_most_frequent(10)
print((id2word))
# Out:
# Dictionary(8361 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.204*"price" + 0.192*"market" + 0.174*"time" + 0.161*"bank" + '
#   '0.158*"stability" + 0.153*"policy" + 0.146*"inflation" + 0.144*"see" + '
#   '0.138*"decision" + 0.137*"monetary"')]
# [(0,
#   '0.204*"price" + 0.192*"market" + 0.174*"time" + 0.161*"bank" + '
#   '0.158*"stability" + 0.153*"policy" + 0.146*"inflation" + 0.144*"see" + '
#   '0.138*"decision" + 0.137*"monetary"'),
#  (1,
#   '0.240*"regard" + -0.207*"policy" + 0.185*"stability" + -0.174*"think" + '
#   '-0.172*"bank" + -0.140*"actually" + 0.131*"level" + -0.126*"answer" + '
#   '-0.126*"monetary" + -0.111*"second"'),
#  (2,
#   '0.315*"price" + -0.296*"government" + 0.270*"inflation" + -0.259*"decision" '
#   '+ -0.211*"country" + -0.187*"bank" + -0.171*"measure" + 0.128*"risk" + '
#   '0.118*"growth" + -0.111*"taken"'),
#  (3,
#   '0.307*"market" + 0.240*"bank" + -0.230*"policy" + -0.219*"growth" + '
#   '0.186*"risk" + -0.186*"monetary" + -0.153*"year" + 0.140*"money" + '
#   '0.124*"credit" + -0.115*"council"'),
#  (4,
#   '0.324*"inflation" + 0.292*"policy" + 0.208*"measure" + 0.201*"decision" + '
#   '0.181*"programme" + -0.175*"think" + -0.160*"area" + -0.138*"so" + '
#   '0.134*"monetary" + 0.125*"expectation"')]
# [(0,
#   '0.204*"price" + 0.192*"market" + 0.174*"time" + 0.161*"bank" + '
#   '0.158*"stability" + 0.153*"policy" + 0.146*"inflation" + 0.144*"see" + '
#   '0.138*"decision" + 0.137*"monetary"'),
#  (1,
#   '0.240*"regard" + -0.207*"policy" + 0.185*"stability" + -0.174*"think" + '
#   '-0.172*"bank" + -0.140*"actually" + 0.131*"level" + -0.126*"answer" + '
#   '-0.126*"monetary" + -0.111*"second"'),
#  (2,
#   '0.315*"price" + -0.296*"government" + 0.270*"inflation" + -0.258*"decision" '
#   '+ -0.211*"country" + -0.187*"bank" + -0.171*"measure" + 0.128*"risk" + '
#   '0.118*"growth" + -0.111*"taken"'),
#  (3,
#   '-0.307*"market" + -0.240*"bank" + 0.230*"policy" + 0.219*"growth" + '
#   '-0.186*"risk" + 0.186*"monetary" + 0.154*"year" + -0.140*"money" + '
#   '-0.124*"credit" + 0.115*"council"'),
#  (4,
#   '0.324*"inflation" + 0.292*"policy" + 0.208*"measure" + 0.201*"decision" + '
#   '0.181*"programme" + -0.175*"think" + -0.160*"area" + -0.138*"so" + '
#   '0.134*"monetary" + 0.125*"expectation"'),
#  (5,
#   '0.279*"country" + 0.248*"area" + -0.235*"council" + -0.206*"governing" + '
#   '-0.179*"bank" + -0.176*"central" + 0.168*"stability" + 0.155*"price" + '
#   '0.154*"government" + -0.130*"market"'),
#  (6,
#   '-0.370*"council" + -0.338*"governing" + 0.187*"bank" + -0.172*"risk" + '
#   '-0.160*"ecb" + 0.147*"year" + -0.124*"clear" + 0.109*"level" + '
#   '0.104*"growth" + 0.103*"economy"'),
#  (7,
#   '-0.282*"market" + -0.248*"policy" + -0.237*"stability" + 0.229*"time" + '
#   '0.225*"inflation" + -0.216*"price" + -0.196*"monetary" + 0.168*"decision" + '
#   '-0.151*"bank" + 0.136*"economy"'),
#  (8,
#   '0.269*"market" + -0.226*"monetary" + -0.223*"risk" + 0.217*"price" + '
#   '0.212*"inflation" + -0.180*"bank" + -0.150*"analysis" + -0.142*"policy" + '
#   '-0.128*"important" + -0.118*"growth"'),
#  (9,
#   '0.371*"bank" + -0.278*"risk" + -0.212*"area" + -0.191*"monetary" + '
#   '-0.172*"decision" + -0.153*"market" + 0.150*"confidence" + 0.149*"economy" '
#   '+ 0.123*"central" + -0.122*"regard"')]
# [(0,
#   '0.204*"price" + 0.192*"market" + 0.174*"time" + 0.161*"bank" + '
#   '0.158*"stability" + 0.153*"policy" + 0.146*"inflation" + 0.144*"see" + '
#   '0.138*"decision" + 0.137*"monetary"'),
#  (1,
#   '0.240*"regard" + -0.207*"policy" + 0.185*"stability" + -0.174*"think" + '
#   '-0.172*"bank" + -0.140*"actually" + 0.131*"level" + -0.126*"answer" + '
#   '-0.126*"monetary" + -0.111*"second"'),
#  (2,
#   '-0.315*"price" + 0.296*"government" + -0.270*"inflation" + 0.258*"decision" '
#   '+ 0.211*"country" + 0.187*"bank" + 0.171*"measure" + -0.128*"risk" + '
#   '-0.118*"growth" + 0.111*"taken"'),
#  (3,
#   '-0.307*"market" + -0.240*"bank" + 0.230*"policy" + 0.219*"growth" + '
#   '0.186*"monetary" + -0.186*"risk" + 0.154*"year" + -0.140*"money" + '
#   '-0.124*"credit" + 0.115*"council"'),
#  (4,
#   '0.324*"inflation" + 0.292*"policy" + 0.207*"measure" + 0.201*"decision" + '
#   '0.181*"programme" + -0.175*"think" + -0.160*"area" + -0.138*"so" + '
#   '0.134*"monetary" + 0.125*"expectation"'),
#  (5,
#   '-0.279*"country" + -0.248*"area" + 0.235*"council" + 0.206*"governing" + '
#   '0.179*"bank" + 0.176*"central" + -0.167*"stability" + -0.155*"price" + '
#   '-0.155*"government" + 0.131*"market"'),
#  (6,
#   '-0.370*"council" + -0.338*"governing" + 0.186*"bank" + -0.172*"risk" + '
#   '-0.160*"ecb" + 0.147*"year" + -0.124*"clear" + 0.109*"level" + '
#   '0.104*"growth" + -0.104*"it"'),
#  (7,
#   '0.282*"market" + 0.248*"policy" + 0.236*"stability" + -0.229*"time" + '
#   '-0.225*"inflation" + 0.216*"price" + 0.195*"monetary" + -0.168*"decision" + '
#   '0.151*"bank" + -0.135*"economy"'),
#  (8,
#   '0.270*"market" + -0.225*"monetary" + -0.223*"risk" + 0.217*"price" + '
#   '0.212*"inflation" + -0.180*"bank" + -0.150*"analysis" + -0.142*"policy" + '
#   '-0.127*"important" + -0.117*"growth"'),
#  (9,
#   '-0.372*"bank" + 0.278*"risk" + 0.212*"area" + 0.191*"monetary" + '
#   '0.171*"decision" + 0.153*"market" + -0.149*"confidence" + -0.148*"economy" '
#   '+ -0.123*"central" + 0.122*"regard"'),
#  (10,
#   '0.393*"market" + -0.327*"price" + -0.210*"bank" + -0.179*"stability" + '
#   '-0.159*"decision" + 0.156*"policy" + 0.145*"financial" + 0.141*"reform" + '
#   '0.129*"economy" + -0.110*"today"'),
#  (11,
#   '-0.259*"growth" + 0.170*"situation" + 0.166*"analysis" + -0.162*"market" + '
#   '0.160*"confidence" + 0.158*"policy" + 0.157*"stability" + 0.155*"so" + '
#   '0.144*"monetary" + -0.120*"regard"'),
#  (12,
#   '0.220*"it" + -0.211*"governing" + -0.208*"council" + -0.187*"country" + '
#   '0.185*"confidence" + -0.145*"economy" + 0.136*"bond" + 0.135*"market" + '
#   '0.135*"greek" + 0.129*"know"'),
#  (13,
#   '0.313*"risk" + 0.223*"inflation" + -0.191*"decision" + 0.171*"bank" + '
#   '0.163*"area" + -0.156*"think" + -0.125*"level" + -0.121*"certainly" + '
#   '0.120*"interest" + -0.115*"financial"'),
#  (14,
#   '0.283*"measure" + -0.220*"government" + -0.194*"time" + -0.162*"bank" + '
#   '-0.157*"stability" + 0.145*"ecb" + 0.140*"regard" + 0.138*"fiscal" + '
#   '-0.130*"greece" + 0.129*"nonstandard"'),
#  (15,
#   '0.222*"situation" + 0.181*"economy" + -0.177*"level" + -0.163*"interest" + '
#   '-0.162*"time" + 0.160*"change" + 0.148*"month" + -0.140*"central" + '
#   '0.126*"liquidity" + -0.121*"confidence"'),
#  (16,
#   '0.282*"economy" + 0.225*"measure" + 0.180*"european" + 0.173*"point" + '
#   '0.150*"interest" + -0.145*"month" + -0.135*"country" + -0.135*"situation" + '
#   '0.134*"ecb" + 0.116*"basis"'),
#  (17,
#   '0.286*"it" + -0.209*"growth" + 0.169*"time" + -0.145*"inflation" + '
#   '0.141*"measure" + 0.136*"ab" + -0.119*"term" + -0.117*"think" + 0.115*"ve" '
#   '+ 0.113*"take"'),
#  (18,
#   '0.310*"country" + -0.226*"year" + 0.178*"monetary" + -0.158*"stability" + '
#   '-0.153*"government" + -0.134*"think" + -0.132*"risk" + -0.130*"measure" + '
#   '0.127*"interest" + 0.118*"economy"'),
#  (19,
#   '0.279*"economy" + 0.208*"risk" + -0.158*"year" + -0.141*"level" + '
#   '-0.128*"time" + 0.124*"exchange" + 0.120*"money" + -0.111*"projection" + '
#   '-0.105*"last" + -0.104*"interest"')]
# [(0,
#   '-0.204*"price" + -0.192*"market" + -0.174*"time" + -0.161*"bank" + '
#   '-0.158*"stability" + -0.153*"policy" + -0.146*"inflation" + -0.144*"see" + '
#   '-0.138*"decision" + -0.137*"monetary"'),
#  (1,
#   '0.240*"regard" + -0.207*"policy" + 0.185*"stability" + -0.174*"think" + '
#   '-0.172*"bank" + -0.140*"actually" + 0.131*"level" + -0.126*"answer" + '
#   '-0.126*"monetary" + -0.111*"second"'),
#  (2,
#   '0.315*"price" + -0.296*"government" + 0.270*"inflation" + -0.258*"decision" '
#   '+ -0.211*"country" + -0.187*"bank" + -0.171*"measure" + 0.128*"risk" + '
#   '0.118*"growth" + -0.111*"taken"'),
#  (3,
#   '-0.307*"market" + -0.240*"bank" + 0.230*"policy" + 0.219*"growth" + '
#   '-0.186*"risk" + 0.186*"monetary" + 0.154*"year" + -0.140*"money" + '
#   '-0.124*"credit" + 0.115*"council"'),
#  (4,
#   '-0.324*"inflation" + -0.292*"policy" + -0.208*"measure" + -0.201*"decision" '
#   '+ -0.181*"programme" + 0.175*"think" + 0.160*"area" + 0.138*"so" + '
#   '-0.134*"monetary" + -0.125*"expectation"'),
#  (5,
#   '0.279*"country" + 0.248*"area" + -0.235*"council" + -0.206*"governing" + '
#   '-0.180*"bank" + -0.177*"central" + 0.168*"stability" + 0.155*"price" + '
#   '0.155*"government" + -0.131*"market"'),
#  (6,
#   '0.370*"council" + 0.338*"governing" + -0.187*"bank" + 0.172*"risk" + '
#   '0.160*"ecb" + -0.147*"year" + 0.124*"clear" + -0.109*"level" + '
#   '-0.104*"growth" + 0.103*"it"'),
#  (7,
#   '-0.282*"market" + -0.248*"policy" + -0.237*"stability" + 0.229*"time" + '
#   '0.225*"inflation" + -0.216*"price" + -0.195*"monetary" + 0.168*"decision" + '
#   '-0.151*"bank" + 0.135*"economy"'),
#  (8,
#   '-0.269*"market" + 0.225*"monetary" + 0.223*"risk" + -0.217*"price" + '
#   '-0.212*"inflation" + 0.180*"bank" + 0.150*"analysis" + 0.142*"policy" + '
#   '0.127*"important" + 0.117*"growth"'),
#  (9,
#   '0.372*"bank" + -0.278*"risk" + -0.212*"area" + -0.191*"monetary" + '
#   '-0.172*"decision" + -0.153*"market" + 0.149*"confidence" + 0.148*"economy" '
#   '+ 0.123*"central" + -0.121*"regard"'),
#  (10,
#   '0.393*"market" + -0.327*"price" + -0.210*"bank" + -0.179*"stability" + '
#   '-0.159*"decision" + 0.157*"policy" + 0.145*"financial" + 0.141*"reform" + '
#   '0.129*"economy" + -0.110*"today"'),
#  (11,
#   '-0.259*"growth" + 0.170*"situation" + 0.166*"analysis" + -0.162*"market" + '
#   '0.161*"confidence" + 0.158*"policy" + 0.157*"stability" + 0.155*"so" + '
#   '0.144*"monetary" + -0.121*"effect"'),
#  (12,
#   '-0.220*"it" + 0.212*"governing" + 0.207*"council" + 0.187*"country" + '
#   '-0.184*"confidence" + 0.145*"economy" + -0.137*"bond" + -0.135*"greek" + '
#   '-0.135*"market" + -0.128*"know"'),
#  (13,
#   '-0.313*"risk" + -0.224*"inflation" + 0.191*"decision" + -0.170*"bank" + '
#   '-0.163*"area" + 0.155*"think" + 0.125*"level" + 0.122*"certainly" + '
#   '-0.120*"interest" + 0.115*"financial"'),
#  (14,
#   '0.283*"measure" + -0.220*"government" + -0.195*"time" + -0.162*"bank" + '
#   '-0.157*"stability" + 0.145*"ecb" + 0.142*"regard" + 0.138*"fiscal" + '
#   '-0.131*"greece" + 0.129*"nonstandard"'),
#  (15,
#   '-0.223*"situation" + -0.181*"economy" + 0.177*"level" + 0.164*"interest" + '
#   '0.161*"time" + -0.159*"change" + -0.148*"month" + 0.139*"central" + '
#   '-0.126*"liquidity" + 0.120*"confidence"'),
#  (16,
#   '-0.282*"economy" + -0.226*"measure" + -0.180*"european" + -0.173*"point" + '
#   '-0.148*"interest" + 0.145*"month" + 0.137*"country" + 0.136*"situation" + '
#   '-0.133*"ecb" + -0.116*"basis"'),
#  (17,
#   '-0.286*"it" + 0.210*"growth" + -0.170*"time" + 0.145*"inflation" + '
#   '-0.140*"measure" + -0.137*"ab" + 0.120*"term" + 0.120*"think" + '
#   '-0.115*"take" + -0.114*"ve"'),
#  (18,
#   '0.309*"country" + -0.227*"year" + 0.180*"monetary" + -0.157*"stability" + '
#   '-0.154*"government" + -0.133*"think" + -0.132*"risk" + -0.131*"measure" + '
#   '0.127*"interest" + 0.120*"economy"'),
#  (19,
#   '-0.279*"economy" + -0.208*"risk" + 0.157*"year" + 0.142*"level" + '
#   '0.128*"time" + -0.123*"exchange" + -0.119*"money" + 0.112*"projection" + '
#   '0.106*"interest" + 0.106*"last"'),
#  (20,
#   '-0.217*"regard" + 0.200*"point" + 0.153*"area" + 0.151*"market" + '
#   '0.141*"today" + -0.134*"ecb" + 0.129*"think" + -0.122*"so" + '
#   '-0.119*"second" + 0.115*"country"'),
#  (21,
#   '0.190*"effect" + 0.176*"projection" + 0.174*"decision" + -0.154*"stability" '
#   '+ -0.150*"programme" + 0.143*"oil" + 0.121*"central" + -0.120*"interest" + '
#   '0.116*"today" + 0.115*"financial"'),
#  (22,
#   '-0.291*"level" + 0.201*"decision" + 0.177*"growth" + 0.173*"see" + '
#   '-0.170*"area" + -0.146*"inflation" + -0.134*"year" + 0.134*"month" + '
#   '0.126*"economy" + 0.120*"time"'),
#  (23,
#   '0.177*"risk" + -0.176*"instrument" + 0.169*"think" + -0.162*"policy" + '
#   '-0.144*"point" + -0.133*"stability" + 0.133*"well" + -0.129*"growth" + '
#   '0.122*"ecb" + -0.121*"pact"'),
#  (24,
#   '-0.172*"think" + 0.155*"change" + -0.153*"information" + 0.141*"year" + '
#   '-0.139*"always" + 0.137*"credit" + -0.128*"number" + -0.123*"state" + '
#   '0.116*"price" + 0.114*"economy"'),
#  (25,
#   '0.239*"see" + 0.213*"figure" + -0.200*"measure" + 0.173*"point" + '
#   '0.159*"look" + -0.155*"important" + -0.149*"today" + -0.139*"year" + '
#   '-0.133*"month" + 0.126*"second"'),
#  (26,
#   '0.186*"year" + -0.168*"reform" + 0.166*"confidence" + -0.151*"already" + '
#   '0.144*"think" + -0.139*"number" + 0.135*"figure" + -0.131*"area" + '
#   '0.130*"bond" + 0.117*"information"'),
#  (27,
#   '-0.193*"country" + 0.187*"economy" + 0.183*"area" + 0.181*"think" + '
#   '0.153*"figure" + -0.129*"fiscal" + -0.119*"meeting" + 0.117*"interest" + '
#   '0.112*"so" + -0.112*"treaty"'),
#  (28,
#   '0.185*"country" + -0.157*"increase" + -0.142*"it" + 0.141*"ecb" + '
#   '0.139*"important" + -0.138*"economy" + 0.138*"programme" + '
#   '-0.128*"situation" + -0.127*"condition" + -0.123*"term"'),
#  (29,
#   '0.314*"see" + 0.169*"reason" + 0.164*"effect" + -0.159*"fiscal" + '
#   '0.116*"european" + -0.111*"basis" + -0.110*"past" + 0.108*"year" + '
#   '0.106*"certainly" + 0.098*"europe"'),
#  (30,
#   '0.188*"exchange" + 0.160*"last" + 0.155*"regard" + -0.145*"interest" + '
#   '-0.140*"year" + -0.135*"change" + 0.132*"well" + -0.125*"fiscal" + '
#   '-0.124*"clear" + -0.110*"basis"'),
#  (31,
#   '0.187*"exchange" + -0.140*"financial" + 0.128*"programme" + 0.119*"year" + '
#   '-0.119*"nonstandard" + 0.117*"bond" + -0.117*"expectation" + '
#   '0.115*"central" + 0.114*"important" + -0.107*"development"'),
#  (32,
#   '-0.247*"situation" + 0.180*"time" + -0.179*"growth" + 0.158*"government" + '
#   '-0.129*"decision" + -0.122*"way" + 0.115*"course" + 0.111*"money" + '
#   '-0.111*"it" + -0.105*"risk"'),
#  (33,
#   '0.194*"area" + -0.169*"important" + 0.153*"time" + 0.148*"month" + '
#   '-0.136*"reason" + -0.113*"economy" + 0.111*"fiscal" + -0.109*"quite" + '
#   '0.109*"information" + -0.102*"good"'),
#  (34,
#   '-0.231*"meeting" + -0.146*"regard" + -0.144*"level" + -0.130*"time" + '
#   '-0.117*"reform" + 0.116*"so" + -0.114*"government" + -0.112*"exchange" + '
#   '-0.108*"look" + -0.106*"certainly"'),
#  (35,
#   '-0.170*"financial" + -0.146*"european" + 0.138*"situation" + 0.137*"second" '
#   '+ -0.135*"inflation" + 0.123*"government" + 0.123*"part" + -0.116*"area" + '
#   '0.111*"quarter" + 0.106*"well"'),
#  (36,
#   '0.156*"message" + 0.146*"new" + -0.138*"central" + 0.134*"already" + '
#   '-0.131*"exchange" + -0.118*"part" + 0.107*"development" + 0.107*"area" + '
#   '0.105*"second" + 0.101*"expectation"'),
#  (37,
#   '-0.157*"mandate" + 0.142*"responsibility" + -0.139*"country" + -0.134*"it" '
#   '+ 0.111*"decision" + -0.110*"important" + -0.108*"give" + -0.101*"mean" + '
#   '-0.098*"people" + -0.095*"recovery"'),
#  (38,
#   '0.225*"certainly" + -0.202*"think" + 0.131*"government" + 0.127*"analysis" '
#   '+ 0.122*"answer" + -0.122*"central" + 0.098*"thing" + -0.098*"projection" + '
#   '0.096*"past" + 0.094*"actually"'),
#  (39,
#   '-0.191*"clear" + -0.150*"information" + -0.135*"appropriate" + '
#   '0.132*"expectation" + -0.132*"effect" + -0.130*"recovery" + '
#   '0.120*"monetary" + 0.118*"think" + -0.117*"ecb" + 0.114*"point"'),
#  (40,
#   '-0.171*"global" + 0.157*"projection" + -0.131*"financial" + 0.129*"thing" + '
#   '0.126*"new" + 0.124*"again" + -0.122*"ecb" + -0.112*"term" + -0.108*"price" '
#   '+ -0.106*"may"'),
#  (41,
#   '-0.174*"loan" + 0.154*"liquidity" + -0.152*"government" + -0.144*"interest" '
#   '+ 0.130*"change" + -0.128*"point" + 0.127*"functioning" + 0.125*"time" + '
#   '0.119*"global" + -0.114*"increase"'),
#  (42,
#   '0.186*"change" + -0.163*"ecb" + 0.144*"effect" + -0.125*"year" + '
#   '0.124*"level" + 0.124*"programme" + -0.123*"way" + 0.118*"course" + '
#   '-0.118*"two" + 0.109*"case"'),
#  (43,
#   '-0.178*"new" + 0.153*"last" + -0.149*"figure" + -0.139*"today" + '
#   '0.131*"ecb" + -0.121*"europe" + 0.107*"period" + 0.104*"interest" + '
#   '0.100*"balance" + 0.099*"thing"'),
#  (44,
#   '-0.169*"appropriate" + 0.138*"european" + 0.137*"credit" + 0.124*"decision" '
#   '+ -0.117*"course" + -0.117*"basis" + 0.112*"know" + -0.102*"we" + '
#   '-0.102*"far" + 0.100*"take"'),
#  (45,
#   '0.156*"know" + -0.129*"global" + 0.128*"course" + -0.123*"today" + '
#   '-0.119*"possible" + 0.116*"take" + 0.116*"reform" + -0.109*"stance" + '
#   '0.108*"figure" + -0.104*"since"'),
#  (46,
#   '-0.190*"important" + 0.134*"regard" + -0.134*"confidence" + '
#   '0.126*"responsibility" + 0.123*"present" + -0.122*"credit" + '
#   '0.112*"recovery" + 0.105*"negative" + -0.103*"statement" + 0.098*"well"'),
#  (47,
#   '0.158*"regard" + 0.132*"europe" + 0.130*"look" + 0.128*"interest" + '
#   '0.106*"bond" + 0.103*"account" + -0.102*"today" + -0.101*"liquidity" + '
#   '0.100*"take" + -0.098*"area"'),
#  (48,
#   '-0.160*"programme" + 0.149*"mandate" + -0.131*"clear" + 0.113*"credit" + '
#   '0.112*"change" + 0.110*"effect" + 0.108*"system" + 0.104*"number" + '
#   '-0.104*"rule" + -0.102*"know"'),
#  (49,
#   '0.161*"meeting" + 0.160*"ecb" + 0.127*"figure" + -0.124*"today" + '
#   '-0.111*"case" + -0.108*"believe" + -0.099*"far" + -0.099*"development" + '
#   '0.096*"better" + -0.095*"action"')]
# [(0,
#   '-0.204*"price" + -0.192*"market" + -0.174*"time" + -0.161*"bank" + '
#   '-0.158*"stability" + -0.153*"policy" + -0.146*"inflation" + -0.144*"see" + '
#   '-0.138*"decision" + -0.137*"monetary"'),
#  (1,
#   '0.240*"regard" + -0.207*"policy" + 0.185*"stability" + -0.174*"think" + '
#   '-0.172*"bank" + -0.140*"actually" + 0.131*"level" + -0.126*"answer" + '
#   '-0.126*"monetary" + -0.111*"second"'),
#  (2,
#   '-0.315*"price" + 0.296*"government" + -0.270*"inflation" + 0.258*"decision" '
#   '+ 0.211*"country" + 0.187*"bank" + 0.171*"measure" + -0.128*"risk" + '
#   '-0.118*"growth" + 0.111*"taken"'),
#  (3,
#   '0.307*"market" + 0.240*"bank" + -0.230*"policy" + -0.219*"growth" + '
#   '0.186*"risk" + -0.186*"monetary" + -0.154*"year" + 0.140*"money" + '
#   '0.124*"credit" + -0.115*"council"'),
#  (4,
#   '-0.324*"inflation" + -0.292*"policy" + -0.207*"measure" + -0.201*"decision" '
#   '+ -0.181*"programme" + 0.175*"think" + 0.160*"area" + 0.138*"so" + '
#   '-0.134*"monetary" + -0.125*"expectation"'),
#  (5,
#   '0.279*"country" + 0.248*"area" + -0.235*"council" + -0.206*"governing" + '
#   '-0.179*"bank" + -0.177*"central" + 0.168*"stability" + 0.155*"price" + '
#   '0.155*"government" + -0.131*"market"'),
#  (6,
#   '-0.370*"council" + -0.338*"governing" + 0.187*"bank" + -0.172*"risk" + '
#   '-0.160*"ecb" + 0.147*"year" + -0.124*"clear" + 0.109*"level" + '
#   '0.104*"growth" + -0.103*"it"'),
#  (7,
#   '-0.282*"market" + -0.248*"policy" + -0.237*"stability" + 0.229*"time" + '
#   '0.225*"inflation" + -0.216*"price" + -0.195*"monetary" + 0.168*"decision" + '
#   '-0.151*"bank" + 0.135*"economy"'),
#  (8,
#   '0.269*"market" + -0.225*"monetary" + -0.223*"risk" + 0.217*"price" + '
#   '0.212*"inflation" + -0.180*"bank" + -0.150*"analysis" + -0.142*"policy" + '
#   '-0.127*"important" + -0.117*"growth"'),
#  (9,
#   '0.372*"bank" + -0.278*"risk" + -0.212*"area" + -0.191*"monetary" + '
#   '-0.172*"decision" + -0.153*"market" + 0.149*"confidence" + 0.148*"economy" '
#   '+ 0.122*"central" + -0.122*"regard"'),
#  (10,
#   '-0.393*"market" + 0.327*"price" + 0.210*"bank" + 0.179*"stability" + '
#   '0.159*"decision" + -0.157*"policy" + -0.145*"financial" + -0.141*"reform" + '
#   '-0.129*"economy" + 0.110*"today"'),
#  (11,
#   '0.259*"growth" + -0.170*"situation" + -0.165*"analysis" + 0.162*"market" + '
#   '-0.160*"confidence" + -0.158*"policy" + -0.157*"stability" + -0.155*"so" + '
#   '-0.144*"monetary" + 0.120*"regard"'),
#  (12,
#   '0.220*"it" + -0.211*"governing" + -0.207*"council" + -0.187*"country" + '
#   '0.184*"confidence" + -0.145*"economy" + 0.137*"bond" + 0.135*"greek" + '
#   '0.135*"market" + 0.128*"know"'),
#  (13,
#   '-0.313*"risk" + -0.224*"inflation" + 0.191*"decision" + -0.170*"bank" + '
#   '-0.163*"area" + 0.156*"think" + 0.125*"level" + 0.122*"certainly" + '
#   '-0.120*"interest" + 0.115*"financial"'),
#  (14,
#   '0.284*"measure" + -0.220*"government" + -0.195*"time" + -0.162*"bank" + '
#   '-0.157*"stability" + 0.145*"ecb" + 0.141*"regard" + 0.138*"fiscal" + '
#   '-0.131*"greece" + 0.129*"nonstandard"'),
#  (15,
#   '0.223*"situation" + 0.181*"economy" + -0.177*"level" + -0.163*"interest" + '
#   '-0.161*"time" + 0.160*"change" + 0.148*"month" + -0.139*"central" + '
#   '0.126*"liquidity" + -0.121*"confidence"'),
#  (16,
#   '0.282*"economy" + 0.225*"measure" + 0.181*"european" + 0.173*"point" + '
#   '0.149*"interest" + -0.145*"month" + -0.136*"country" + -0.136*"situation" + '
#   '0.133*"ecb" + 0.115*"basis"'),
#  (17,
#   '0.286*"it" + -0.210*"growth" + 0.169*"time" + -0.145*"inflation" + '
#   '0.140*"measure" + 0.137*"ab" + -0.121*"term" + -0.120*"think" + '
#   '0.115*"take" + 0.115*"ve"'),
#  (18,
#   '-0.309*"country" + 0.227*"year" + -0.180*"monetary" + 0.157*"stability" + '
#   '0.154*"government" + 0.133*"think" + 0.132*"risk" + 0.131*"measure" + '
#   '-0.127*"interest" + -0.120*"economy"'),
#  (19,
#   '0.279*"economy" + 0.208*"risk" + -0.157*"year" + -0.143*"level" + '
#   '-0.128*"time" + 0.123*"exchange" + 0.119*"money" + -0.111*"projection" + '
#   '-0.106*"interest" + -0.106*"last"'),
#  (20,
#   '-0.217*"regard" + 0.200*"point" + 0.153*"area" + 0.151*"market" + '
#   '0.141*"today" + -0.134*"ecb" + 0.129*"think" + -0.122*"so" + '
#   '-0.119*"second" + 0.115*"country"'),
#  (21,
#   '0.190*"effect" + 0.176*"projection" + 0.174*"decision" + -0.153*"stability" '
#   '+ -0.151*"programme" + 0.144*"oil" + -0.122*"interest" + 0.120*"central" + '
#   '0.117*"today" + 0.115*"financial"'),
#  (22,
#   '0.291*"level" + -0.200*"decision" + -0.178*"growth" + -0.173*"see" + '
#   '0.170*"area" + 0.147*"inflation" + 0.134*"year" + -0.134*"month" + '
#   '-0.126*"economy" + -0.120*"time"'),
#  (23,
#   '0.178*"risk" + -0.177*"instrument" + 0.169*"think" + -0.163*"policy" + '
#   '-0.144*"point" + -0.134*"stability" + 0.133*"well" + -0.128*"growth" + '
#   '0.121*"ecb" + -0.120*"pact"'),
#  (24,
#   '0.172*"think" + -0.155*"change" + 0.153*"information" + -0.141*"year" + '
#   '0.139*"always" + -0.138*"credit" + 0.127*"number" + 0.123*"state" + '
#   '-0.116*"price" + -0.114*"economy"'),
#  (25,
#   '-0.238*"see" + -0.213*"figure" + 0.200*"measure" + -0.173*"point" + '
#   '-0.160*"look" + 0.156*"important" + 0.148*"today" + 0.138*"year" + '
#   '0.133*"month" + -0.126*"government"'),
#  (26,
#   '-0.185*"year" + 0.168*"reform" + -0.167*"confidence" + 0.150*"already" + '
#   '-0.144*"think" + 0.138*"number" + -0.135*"figure" + 0.132*"area" + '
#   '-0.130*"bond" + -0.117*"information"'),
#  (27,
#   '0.193*"country" + -0.188*"economy" + -0.183*"area" + -0.181*"think" + '
#   '-0.152*"figure" + 0.130*"fiscal" + 0.119*"meeting" + -0.117*"interest" + '
#   '-0.112*"so" + -0.111*"certainly"'),
#  (28,
#   '-0.187*"country" + 0.157*"increase" + 0.142*"it" + -0.140*"ecb" + '
#   '-0.138*"important" + 0.138*"economy" + -0.138*"programme" + '
#   '0.128*"situation" + 0.127*"condition" + 0.124*"term"'),
#  (29,
#   '0.314*"see" + 0.170*"reason" + 0.165*"effect" + -0.159*"fiscal" + '
#   '0.117*"european" + -0.111*"past" + -0.111*"basis" + 0.107*"year" + '
#   '0.104*"certainly" + 0.097*"europe"'),
#  (30,
#   '-0.193*"exchange" + -0.161*"last" + -0.154*"regard" + 0.146*"interest" + '
#   '0.136*"year" + 0.135*"change" + -0.132*"well" + 0.126*"fiscal" + '
#   '0.124*"clear" + -0.111*"staff"'),
#  (31,
#   '0.181*"exchange" + -0.141*"financial" + 0.126*"programme" + 0.123*"year" + '
#   '-0.120*"nonstandard" + -0.118*"expectation" + 0.116*"bond" + '
#   '0.116*"important" + 0.116*"central" + -0.108*"development"'),
#  (32,
#   '0.246*"situation" + -0.180*"time" + 0.178*"growth" + -0.158*"government" + '
#   '0.129*"decision" + 0.123*"way" + -0.116*"course" + -0.111*"money" + '
#   '0.111*"it" + 0.107*"risk"'),
#  (33,
#   '-0.192*"area" + 0.171*"important" + -0.162*"time" + -0.151*"month" + '
#   '0.139*"reason" + 0.112*"quite" + -0.109*"fiscal" + -0.109*"information" + '
#   '0.108*"economy" + 0.103*"good"'),
#  (34,
#   '0.226*"meeting" + 0.146*"level" + 0.144*"regard" + 0.124*"time" + '
#   '0.121*"reform" + -0.119*"so" + 0.117*"government" + 0.111*"look" + '
#   '0.110*"exchange" + -0.103*"number"'),
#  (35,
#   '0.171*"financial" + 0.149*"european" + -0.136*"situation" + -0.134*"second" '
#   '+ 0.134*"inflation" + -0.126*"part" + -0.124*"government" + 0.122*"area" + '
#   '-0.112*"quarter" + -0.108*"level"'),
#  (36,
#   '-0.155*"message" + -0.144*"new" + 0.137*"central" + -0.135*"already" + '
#   '0.130*"exchange" + 0.113*"part" + -0.108*"second" + -0.106*"development" + '
#   '-0.105*"area" + -0.099*"expectation"'),
#  (37,
#   '0.156*"mandate" + -0.144*"responsibility" + 0.138*"country" + 0.133*"it" + '
#   '0.111*"important" + -0.111*"decision" + 0.111*"give" + 0.102*"mean" + '
#   '0.097*"people" + -0.097*"central"'),
#  (38,
#   '0.229*"certainly" + -0.205*"think" + 0.128*"analysis" + 0.126*"government" '
#   '+ 0.119*"answer" + -0.118*"central" + -0.102*"projection" + '
#   '0.099*"actually" + 0.095*"thing" + 0.094*"global"'),
#  (39,
#   '-0.195*"clear" + -0.152*"information" + -0.134*"appropriate" + '
#   '0.134*"expectation" + -0.132*"recovery" + -0.130*"effect" + -0.120*"ecb" + '
#   '0.118*"monetary" + -0.114*"decision" + 0.113*"think"'),
#  (40,
#   '-0.173*"global" + 0.153*"projection" + -0.133*"financial" + 0.132*"new" + '
#   '0.126*"thing" + 0.125*"again" + -0.123*"ecb" + -0.115*"term" + '
#   '-0.108*"price" + -0.107*"may"'),
#  (41,
#   '0.173*"loan" + -0.153*"liquidity" + 0.153*"government" + 0.145*"interest" + '
#   '0.129*"point" + -0.127*"change" + -0.127*"functioning" + -0.123*"time" + '
#   '-0.121*"global" + 0.116*"increase"'),
#  (42,
#   '-0.185*"change" + 0.162*"ecb" + -0.144*"effect" + -0.125*"level" + '
#   '-0.124*"programme" + 0.123*"year" + 0.120*"two" + 0.119*"way" + '
#   '-0.118*"course" + -0.109*"case"'),
#  (43,
#   '0.181*"new" + -0.152*"last" + 0.149*"figure" + 0.138*"today" + -0.129*"ecb" '
#   '+ 0.121*"europe" + -0.109*"period" + -0.105*"interest" + -0.102*"balance" + '
#   '-0.102*"thing"'),
#  (44,
#   '0.169*"appropriate" + -0.141*"credit" + -0.139*"european" + '
#   '-0.123*"decision" + 0.120*"course" + 0.113*"basis" + -0.108*"know" + '
#   '0.102*"we" + -0.101*"part" + 0.100*"far"'),
#  (45,
#   '-0.158*"know" + 0.130*"global" + 0.125*"today" + -0.124*"course" + '
#   '0.118*"possible" + -0.117*"take" + -0.115*"reform" + 0.110*"stance" + '
#   '-0.109*"figure" + -0.105*"level"'),
#  (46,
#   '0.195*"important" + -0.142*"regard" + 0.141*"confidence" + '
#   '-0.122*"responsibility" + 0.120*"credit" + -0.119*"present" + '
#   '-0.108*"recovery" + -0.107*"negative" + 0.103*"statement" + -0.098*"well"'),
#  (47,
#   '0.142*"regard" + 0.135*"look" + 0.130*"europe" + 0.129*"interest" + '
#   '0.113*"bond" + -0.107*"today" + 0.104*"account" + -0.098*"basis" + '
#   '-0.096*"message" + -0.095*"area"'),
#  (48,
#   '-0.158*"programme" + 0.153*"mandate" + -0.129*"clear" + 0.115*"change" + '
#   '0.113*"credit" + 0.108*"system" + 0.108*"effect" + -0.106*"recovery" + '
#   '-0.103*"know" + 0.102*"number"'),
#  (49,
#   '-0.166*"ecb" + -0.161*"meeting" + -0.127*"figure" + 0.124*"today" + '
#   '0.109*"case" + 0.105*"believe" + 0.101*"far" + -0.099*"better" + '
#   '0.097*"action" + 0.092*"development"'),
#  (50,
#   '0.153*"global" + -0.132*"year" + 0.122*"two" + -0.114*"statement" + '
#   '0.114*"way" + -0.111*"let" + 0.108*"treaty" + -0.104*"quarter" + '
#   '-0.103*"again" + 0.100*"staff"'),
#  (51,
#   '-0.161*"money" + -0.133*"balance" + -0.119*"european" + -0.106*"liquidity" '
#   '+ -0.102*"again" + 0.099*"going" + -0.094*"may" + 0.092*"strong" + '
#   '0.090*"want" + -0.089*"effect"'),
#  (52,
#   '-0.148*"projection" + -0.127*"regard" + -0.124*"mandate" + 0.122*"think" + '
#   '0.121*"development" + -0.116*"note" + -0.100*"state" + 0.099*"period" + '
#   '0.097*"asset" + -0.097*"strong"'),
#  (53,
#   '0.151*"financial" + 0.139*"answer" + -0.129*"european" + 0.128*"could" + '
#   '-0.127*"policy" + 0.105*"new" + -0.103*"operation" + 0.101*"look" + '
#   '0.101*"ecb" + 0.096*"rule"'),
#  (54,
#   '0.198*"last" + -0.164*"appropriate" + 0.141*"policy" + 0.130*"confidence" + '
#   '-0.123*"monetary" + 0.113*"element" + -0.101*"future" + -0.101*"present" + '
#   '-0.101*"year" + -0.097*"well"'),
#  (55,
#   '0.147*"analysis" + 0.133*"figure" + -0.120*"appropriate" + -0.118*"today" + '
#   '0.117*"development" + 0.113*"full" + 0.103*"quite" + -0.100*"point" + '
#   '-0.094*"new" + -0.094*"like"'),
#  (56,
#   '-0.132*"impact" + 0.131*"much" + 0.120*"continue" + -0.117*"know" + '
#   '-0.113*"new" + -0.106*"respect" + -0.105*"assessment" + -0.104*"public" + '
#   '-0.102*"condition" + -0.100*"nothing"'),
#  (57,
#   '-0.184*"condition" + -0.169*"certainly" + 0.119*"fact" + -0.115*"period" + '
#   '-0.113*"factor" + -0.113*"consider" + 0.110*"different" + 0.104*"bank" + '
#   '0.100*"meeting" + 0.099*"way"'),
#  (58,
#   '-0.168*"important" + -0.127*"stability" + -0.120*"billion" + -0.118*"fact" '
#   '+ 0.116*"measure" + 0.114*"again" + 0.106*"think" + 0.105*"come" + '
#   '-0.105*"time" + -0.101*"problem"'),
#  (59,
#   '0.156*"let" + -0.146*"term" + -0.131*"institution" + -0.114*"need" + '
#   '0.113*"statement" + 0.105*"mentioned" + 0.099*"global" + -0.098*"really" + '
#   '-0.097*"may" + 0.093*"continue"'),
#  (60,
#   '0.148*"actually" + -0.132*"european" + 0.129*"sector" + 0.123*"discussion" '
#   '+ 0.118*"no" + 0.113*"going" + 0.112*"account" + 0.099*"currency" + '
#   '0.097*"basis" + -0.096*"programme"'),
#  (61,
#   '-0.136*"lower" + -0.124*"term" + 0.100*"ab" + 0.096*"level" + '
#   '0.093*"second" + -0.090*"monetary" + 0.090*"scenario" + 0.089*"need" + '
#   '-0.086*"before" + 0.085*"liquidity"'),
#  (62,
#   '-0.139*"judgement" + -0.131*"take" + 0.127*"consider" + -0.118*"particular" '
#   '+ -0.113*"objective" + -0.111*"regard" + -0.102*"account" + -0.096*"second" '
#   '+ 0.093*"always" + -0.090*"basis"'),
#  (63,
#   '0.129*"regard" + 0.128*"different" + -0.127*"look" + -0.110*"effect" + '
#   '0.105*"important" + -0.100*"possible" + 0.099*"may" + 0.098*"actually" + '
#   '-0.096*"economic" + 0.096*"expectation"'),
#  (64,
#   '-0.151*"year" + -0.134*"information" + -0.126*"account" + '
#   '0.119*"confidence" + -0.116*"possible" + -0.114*"comment" + 0.108*"better" '
#   '+ -0.105*"situation" + 0.103*"lower" + -0.098*"medium"'),
#  (65,
#   '0.150*"know" + 0.147*"work" + 0.135*"tender" + -0.116*"policy" + '
#   '-0.114*"various" + 0.105*"programme" + -0.098*"continue" + '
#   '-0.096*"phenomenon" + -0.095*"responsibility" + -0.091*"period"'),
#  (66,
#   '0.117*"done" + -0.117*"treaty" + -0.112*"full" + -0.111*"way" + '
#   '-0.107*"certainly" + -0.102*"increase" + 0.101*"come" + -0.100*"sector" + '
#   '0.096*"capital" + 0.089*"take"'),
#  (67,
#   '-0.138*"regard" + 0.135*"credit" + -0.117*"treaty" + 0.114*"growth" + '
#   '-0.109*"mandate" + -0.104*"figure" + -0.103*"central" + -0.103*"fact" + '
#   '0.101*"level" + -0.101*"observing"'),
#  (68,
#   '0.141*"much" + -0.139*"comment" + -0.138*"could" + -0.134*"number" + '
#   '-0.130*"good" + 0.123*"work" + 0.113*"call" + -0.103*"thing" + '
#   '-0.094*"next" + 0.090*"know"'),
#  (69,
#   '0.177*"could" + 0.128*"year" + -0.115*"responsibility" + 0.107*"want" + '
#   '-0.106*"know" + 0.099*"need" + -0.098*"we" + -0.098*"ve" + -0.091*"fact" + '
#   '-0.089*"particular"'),
#  (70,
#   '0.127*"believe" + -0.101*"ab" + 0.094*"risksharing" + 0.094*"survey" + '
#   '-0.093*"security" + -0.090*"again" + 0.089*"today" + 0.088*"actually" + '
#   '-0.088*"increase" + 0.087*"staff"'),
#  (71,
#   '-0.107*"note" + 0.107*"structural" + 0.106*"month" + 0.105*"balance" + '
#   '0.094*"competitiveness" + 0.094*"already" + 0.094*"impact" + '
#   '0.094*"measure" + 0.093*"medium" + 0.091*"issue"'),
#  (72,
#   '-0.137*"account" + 0.129*"second" + -0.114*"state" + 0.111*"exchange" + '
#   '-0.110*"look" + 0.108*"projection" + 0.103*"week" + 0.101*"take" + '
#   '-0.096*"risk" + -0.095*"ecb"'),
#  (73,
#   '-0.118*"exchange" + -0.110*"nonstandard" + 0.109*"assessment" + '
#   '0.109*"whether" + 0.108*"mediumterm" + -0.099*"again" + -0.098*"done" + '
#   '0.090*"thing" + -0.089*"always" + 0.088*"report"'),
#  (74,
#   '0.170*"already" + -0.125*"rule" + 0.120*"account" + -0.111*"fully" + '
#   '0.110*"might" + 0.100*"taken" + 0.099*"recovery" + -0.097*"course" + '
#   '-0.088*"basis" + 0.087*"oil"'),
#  (75,
#   '-0.124*"much" + -0.120*"fully" + 0.115*"fiscal" + 0.107*"central" + '
#   '-0.097*"really" + -0.094*"line" + -0.085*"assessment" + -0.083*"it" + '
#   '0.081*"quite" + 0.080*"case"'),
#  (76,
#   '-0.115*"economic" + -0.115*"area" + -0.104*"discussion" + '
#   '-0.104*"intervention" + -0.103*"recovery" + 0.095*"regard" + -0.094*"fact" '
#   '+ 0.091*"possible" + 0.089*"last" + 0.088*"money"'),
#  (77,
#   '0.133*"interest" + -0.128*"figure" + -0.118*"currency" + 0.112*"may" + '
#   '-0.105*"present" + -0.105*"statement" + -0.102*"no" + -0.102*"institution" '
#   '+ -0.093*"close" + 0.092*"take"'),
#  (78,
#   '-0.126*"fact" + -0.114*"fiscal" + -0.100*"message" + 0.097*"growth" + '
#   '-0.096*"way" + -0.094*"already" + 0.093*"again" + 0.093*"much" + '
#   '0.091*"mentioned" + 0.086*"phenomenon"'),
#  (79,
#   '-0.123*"still" + -0.123*"therefore" + -0.105*"judgement" + 0.102*"message" '
#   '+ 0.098*"public" + 0.097*"balance" + 0.096*"really" + 0.091*"move" + '
#   '-0.091*"it" + 0.088*"liquidity"'),
#  (80,
#   '-0.111*"month" + 0.105*"basis" + 0.098*"responsibility" + '
#   '-0.095*"discussion" + 0.093*"information" + -0.091*"credibility" + '
#   '-0.091*"thing" + -0.090*"projection" + 0.090*"press" + -0.087*"done"'),
#  (81,
#   '-0.110*"judgement" + -0.105*"central" + 0.096*"increase" + 0.095*"since" + '
#   '-0.093*"take" + -0.088*"answer" + 0.086*"good" + -0.086*"took" + '
#   '0.083*"today" + 0.081*"regard"'),
#  (82,
#   '0.130*"currency" + 0.128*"could" + -0.110*"real" + 0.108*"low" + '
#   '0.105*"well" + -0.103*"treaty" + -0.096*"national" + -0.096*"operation" + '
#   '0.094*"responsibility" + 0.085*"judgement"'),
#  (83,
#   '0.148*"message" + -0.125*"today" + 0.107*"position" + 0.106*"again" + '
#   '0.100*"past" + 0.090*"something" + 0.089*"matter" + -0.088*"basis" + '
#   '-0.088*"economic" + -0.087*"even"'),
#  (84,
#   '0.155*"month" + -0.137*"member" + -0.110*"uncertainty" + -0.110*"comment" + '
#   '0.096*"real" + -0.093*"come" + -0.093*"basis" + 0.088*"nonstandard" + '
#   '-0.087*"responsibility" + 0.084*"private"'),
#  (85,
#   '-0.107*"europe" + 0.105*"monetary" + -0.105*"united" + 0.100*"present" + '
#   '0.096*"job" + -0.096*"liquidity" + 0.092*"see" + -0.090*"growth" + '
#   '0.089*"banking" + -0.087*"including"'),
#  (86,
#   '0.118*"statement" + -0.105*"economic" + -0.101*"development" + 0.094*"now" '
#   '+ -0.092*"know" + 0.087*"important" + -0.086*"account" + -0.085*"think" + '
#   '-0.083*"assessment" + 0.083*"respect"'),
#  (87,
#   '-0.117*"come" + -0.113*"different" + -0.105*"bond" + -0.101*"financial" + '
#   '0.097*"overall" + 0.095*"future" + -0.091*"make" + 0.091*"good" + '
#   '-0.088*"month" + 0.085*"negative"'),
#  (88,
#   '-0.171*"always" + -0.106*"made" + 0.099*"new" + 0.099*"different" + '
#   '0.093*"number" + -0.088*"npls" + 0.087*"government" + 0.086*"future" + '
#   '-0.085*"president" + -0.084*"press"'),
#  (89,
#   '-0.158*"european" + 0.121*"really" + -0.110*"country" + 0.102*"expectation" '
#   '+ 0.099*"greece" + -0.093*"economic" + -0.090*"confidence" + -0.088*"made" '
#   '+ 0.087*"tell" + 0.086*"something"'),
#  (90,
#   '0.128*"expectation" + 0.122*"much" + 0.111*"even" + 0.103*"economic" + '
#   '-0.098*"today" + -0.093*"credit" + -0.091*"statement" + '
#   '0.091*"responsibility" + -0.089*"again" + -0.088*"term"'),
#  (91,
#   '-0.113*"different" + -0.103*"banking" + 0.102*"financial" + 0.102*"mandate" '
#   '+ -0.101*"measure" + 0.096*"regard" + -0.094*"let" + 0.092*"is" + '
#   '-0.089*"necessary" + -0.088*"particular"'),
#  (92,
#   '-0.109*"period" + 0.105*"risksharing" + 0.104*"answer" + 0.101*"investment" '
#   '+ -0.098*"direction" + -0.097*"expectation" + 0.092*"continue" + '
#   '0.089*"factor" + 0.087*"global" + -0.085*"lot"'),
#  (93,
#   '-0.126*"particular" + 0.111*"new" + -0.103*"exchange" + 0.102*"term" + '
#   '0.100*"want" + -0.100*"sign" + 0.099*"real" + 0.095*"pillar" + '
#   '0.093*"absolutely" + -0.092*"basis"'),
#  (94,
#   '0.114*"credible" + -0.110*"exchange" + 0.107*"situation" + -0.103*"greece" '
#   '+ -0.096*"operation" + -0.094*"everything" + 0.080*"today" + -0.079*"data" '
#   '+ -0.078*"again" + 0.077*"justified"'),
#  (95,
#   '0.135*"message" + -0.113*"operation" + -0.106*"certainly" + 0.088*"case" + '
#   '0.082*"and" + -0.081*"high" + 0.081*"exactly" + 0.081*"data" + 0.081*"ecb" '
#   '+ 0.078*"intervention"'),
#  (96,
#   '-0.110*"message" + -0.100*"assessment" + -0.094*"real" + 0.094*"year" + '
#   '-0.092*"possible" + 0.091*"problem" + 0.088*"liquidity" + -0.088*"future" + '
#   '-0.085*"responsibility" + -0.085*"important"'),
#  (97,
#   '-0.119*"time" + 0.106*"process" + 0.104*"going" + -0.096*"real" + '
#   '-0.095*"account" + 0.093*"period" + -0.093*"factor" + 0.091*"basis" + '
#   '0.090*"analysis" + 0.090*"central"'),
#  (98,
#   '-0.164*"position" + 0.099*"reason" + -0.096*"whole" + 0.093*"functioning" + '
#   '0.088*"made" + 0.085*"increase" + -0.083*"trust" + 0.079*"ab" + '
#   '0.076*"situation" + -0.073*"central"'),
#  (99,
#   '0.127*"authority" + -0.117*"issue" + -0.115*"currency" + -0.114*"second" + '
#   '0.105*"institution" + 0.097*"looking" + -0.095*"europe" + -0.090*"are" + '
#   '0.090*"no" + 0.086*"confidence"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.



coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)


coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='u_mass')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)
# Out:
# Coherence Score:  0.24490787387368007
#
# Coherence Score5:  0.33427669379496805
#
# Coherence Score10:  0.3153977783678778
#
# Coherence Score20:  0.2742349086291714
#
# Coherence Score50:  0.24909077245875202
#
# Coherence Score100:  0.22699921472361012
#
# Coherence Score:  -0.08781761317778826
#
# Coherence Score5:  -0.3433445781923909
#
# Coherence Score10:  -0.3585959448409332
#
# Coherence Score20:  -0.3869504990308481
#
# Coherence Score50:  -0.7177095911237139
#
# Coherence Score100:  -0.6539861472041555
