# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['qa']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
ps = PorterStemmer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(ps.stem(word) for word in punc_free.split())
    return normalized

data = [clean(df).split() for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(5942 unique tokens: ['absenc', 'accept', 'achiev', 'activ', 'add']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=1, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
lda_model5 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model10 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model20 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model50 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=50, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model100 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=100, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\models\ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
# Print the Keyword in the 1 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.010*"would" + 0.010*"question" + 0.009*"say" + 0.008*"bank" + '
#   '0.008*"rate" + 0.008*"polici" + 0.008*"that" + 0.008*"said" + 0.007*"first" '
#   '+ 0.007*"also"')]

# %%
# Print the Keyword in the 5 topics
pprint(lda_model5.print_topics())
doc_lda = lda_model5[corpus]

# Print the Keyword in the 10 topics
pprint(lda_model10.print_topics())
doc_lda = lda_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lda_model20.print_topics())
doc_lda = lda_model20[corpus]

# Print the Keyword in the 50 topics
pprint(lda_model50.print_topics())
doc_lda = lda_model50[corpus]

# Print the Keyword in the 100 topics
pprint(lda_model100.print_topics())
doc_lda = lda_model100[corpus]
# Out:
# [(0,
#   '0.014*"govern" + 0.012*"decis" + 0.010*"regard" + 0.010*"question" + '
#   '0.009*"market" + 0.009*"say" + 0.009*"bank" + 0.008*"would" + 0.008*"said" '
#   '+ 0.007*"first"'),
#  (1,
#   '0.012*"question" + 0.012*"polici" + 0.011*"bank" + 0.011*"that" + '
#   '0.009*"say" + 0.009*"monetari" + 0.009*"first" + 0.009*"inflat" + '
#   '0.009*"would" + 0.008*"rate"'),
#  (2,
#   '0.010*"rate" + 0.009*"time" + 0.008*"inflat" + 0.008*"would" + '
#   '0.007*"think" + 0.007*"one" + 0.006*"actual" + 0.006*"point" + 0.006*"area" '
#   '+ 0.006*"so"'),
#  (3,
#   '0.014*"euro" + 0.013*"rate" + 0.009*"one" + 0.008*"would" + 0.008*"bank" + '
#   '0.007*"think" + 0.007*"area" + 0.007*"develop" + 0.007*"well" + '
#   '0.007*"question"'),
#  (4,
#   '0.014*"would" + 0.011*"said" + 0.011*"price" + 0.011*"say" + 0.009*"rate" + '
#   '0.008*"stabil" + 0.008*"growth" + 0.007*"market" + 0.007*"also" + '
#   '0.007*"regard"')]
# [(0,
#   '0.008*"abss" + 0.004*"recurr" + 0.003*"coupon" + 0.003*"markdown" + '
#   '0.003*"unsecur" + 0.002*"biennial" + 0.002*"sltro" + 0.002*"pittsburgh" + '
#   '0.002*"strongdollar" + 0.002*"gothenburg"'),
#  (1,
#   '0.013*"polici" + 0.013*"bank" + 0.012*"question" + 0.011*"that" + '
#   '0.010*"would" + 0.010*"monetari" + 0.009*"say" + 0.009*"inflat" + '
#   '0.009*"first" + 0.009*"rate"'),
#  (2,
#   '0.007*"balanc" + 0.006*"north" + 0.005*"chang" + 0.005*"massiv" + '
#   '0.005*"recoveri" + 0.005*"month" + 0.005*"magnet" + 0.004*"comprehens" + '
#   '0.004*"explain" + 0.004*"gradual"'),
#  (3,
#   '0.008*"undervalu" + 0.005*"fdi" + 0.003*"interview" + 0.002*"fabiu" + '
#   '0.002*"techniqu" + 0.002*"overst" + 0.002*"cruis" + 0.002*"altitud" + '
#   '0.002*"style" + 0.002*"instil"'),
#  (4,
#   '0.013*"rate" + 0.012*"would" + 0.010*"euro" + 0.008*"say" + 0.007*"one" + '
#   '0.007*"time" + 0.007*"price" + 0.007*"also" + 0.006*"question" + '
#   '0.006*"said"'),
#  (5,
#   '0.012*"market" + 0.010*"question" + 0.009*"first" + 0.009*"that" + '
#   '0.009*"also" + 0.008*"second" + 0.008*"time" + 0.008*"polici" + '
#   '0.008*"govern" + 0.008*"reform"'),
#  (6,
#   '0.008*"merkel" + 0.007*"athen" + 0.007*"sticki" + 0.006*"kanzlerin" + '
#   '0.005*"residu" + 0.005*"harmonis" + 0.003*"stormi" + 0.003*"metaphor" + '
#   '0.003*"baltic" + 0.003*"wim"'),
#  (7,
#   '0.012*"would" + 0.012*"said" + 0.011*"regard" + 0.011*"say" + '
#   '0.010*"govern" + 0.010*"price" + 0.010*"stabil" + 0.009*"market" + '
#   '0.008*"decis" + 0.008*"import"'),
#  (8,
#   '0.000*"say" + 0.000*"would" + 0.000*"bank" + 0.000*"rate" + 0.000*"growth" '
#   '+ 0.000*"govern" + 0.000*"time" + 0.000*"price" + 0.000*"first" + '
#   '0.000*"euro"'),
#  (9,
#   '0.000*"would" + 0.000*"say" + 0.000*"first" + 0.000*"that" + 0.000*"rate" + '
#   '0.000*"question" + 0.000*"price" + 0.000*"euro" + 0.000*"time" + '
#   '0.000*"said"')]
# [(0,
#   '0.000*"would" + 0.000*"also" + 0.000*"import" + 0.000*"said" + 0.000*"say" '
#   '+ 0.000*"price" + 0.000*"know" + 0.000*"market" + 0.000*"growth" + '
#   '0.000*"govern"'),
#  (1,
#   '0.015*"market" + 0.013*"reform" + 0.011*"question" + 0.009*"also" + '
#   '0.009*"that" + 0.008*"inflat" + 0.008*"first" + 0.008*"govern" + '
#   '0.008*"say" + 0.008*"effect"'),
#  (2,
#   '0.013*"balanc" + 0.012*"black" + 0.011*"magnet" + 0.011*"north" + '
#   '0.009*"comprehens" + 0.007*"explain" + 0.007*"chang" + 0.006*"incorpor" + '
#   '0.005*"tirelessli" + 0.004*"fault"'),
#  (3,
#   '0.005*"cruis" + 0.005*"altitud" + 0.003*"causal" + 0.002*"vodaphon" + '
#   '0.000*"andthey" + 0.000*"would" + 0.000*"said" + 0.000*"rate" + '
#   '0.000*"price" + 0.000*"euro"'),
#  (4,
#   '0.013*"govern" + 0.011*"would" + 0.009*"market" + 0.009*"say" + '
#   '0.009*"council" + 0.008*"decis" + 0.008*"said" + 0.007*"question" + '
#   '0.007*"rate" + 0.007*"time"'),
#  (5,
#   '0.013*"polici" + 0.012*"bank" + 0.012*"that" + 0.011*"question" + '
#   '0.010*"one" + 0.009*"first" + 0.009*"discuss" + 0.009*"monetari" + '
#   '0.008*"time" + 0.008*"inflat"'),
#  (6,
#   '0.010*"residu" + 0.003*"shareholders" + 0.003*"nondistribut" + '
#   '0.003*"catchingup" + 0.002*"article" + 0.002*"escbrel" + 0.002*"direttorio" '
#   '+ 0.002*"strategy" + 0.002*"superiore" + 0.002*"deputi"'),
#  (7,
#   '0.027*"decis" + 0.021*"regard" + 0.020*"oper" + 0.016*"taken" + '
#   '0.016*"appropri" + 0.015*"govern" + 0.015*"consid" + 0.013*"level" + '
#   '0.012*"measur" + 0.010*"market"'),
#  (8,
#   '0.000*"say" + 0.000*"would" + 0.000*"growth" + 0.000*"rate" + 0.000*"level" '
#   '+ 0.000*"stabil" + 0.000*"govern" + 0.000*"price" + 0.000*"euro" + '
#   '0.000*"time"'),
#  (9,
#   '0.000*"would" + 0.000*"say" + 0.000*"rate" + 0.000*"that" + 0.000*"price" + '
#   '0.000*"first" + 0.000*"euro" + 0.000*"stabil" + 0.000*"said" + '
#   '0.000*"question"'),
#  (10,
#   '0.015*"would" + 0.013*"price" + 0.013*"said" + 0.013*"say" + 0.012*"stabil" '
#   '+ 0.010*"regard" + 0.009*"growth" + 0.009*"import" + 0.008*"level" + '
#   '0.008*"economi"'),
#  (11,
#   '0.000*"would" + 0.000*"rate" + 0.000*"said" + 0.000*"price" + 0.000*"say" + '
#   '0.000*"govern" + 0.000*"year" + 0.000*"know" + 0.000*"growth" + '
#   '0.000*"euro"'),
#  (12,
#   '0.000*"would" + 0.000*"rate" + 0.000*"say" + 0.000*"price" + 0.000*"regard" '
#   '+ 0.000*"euro" + 0.000*"said" + 0.000*"level" + 0.000*"market" + '
#   '0.000*"stabil"'),
#  (13,
#   '0.000*"would" + 0.000*"question" + 0.000*"rate" + 0.000*"say" + '
#   '0.000*"euro" + 0.000*"also" + 0.000*"bank" + 0.000*"price" + 0.000*"govern" '
#   '+ 0.000*"time"'),
#  (14,
#   '0.016*"bank" + 0.013*"would" + 0.013*"rate" + 0.012*"question" + '
#   '0.012*"say" + 0.011*"see" + 0.010*"also" + 0.010*"reform" + 0.009*"central" '
#   '+ 0.009*"structur"'),
#  (15,
#   '0.025*"rate" + 0.024*"interest" + 0.020*"polici" + 0.018*"that" + '
#   '0.017*"monetari" + 0.016*"think" + 0.016*"inflat" + 0.016*"let" + '
#   '0.014*"say" + 0.014*"effect"'),
#  (16,
#   '0.000*"time" + 0.000*"stabil" + 0.000*"euro" + 0.000*"say" + '
#   '0.000*"question" + 0.000*"would" + 0.000*"rate" + 0.000*"price" + '
#   '0.000*"said" + 0.000*"govern"'),
#  (17,
#   '0.020*"rate" + 0.017*"euro" + 0.011*"would" + 0.010*"area" + '
#   '0.009*"develop" + 0.009*"one" + 0.008*"may" + 0.008*"year" + '
#   '0.008*"exchang" + 0.007*"well"'),
#  (18,
#   '0.000*"rate" + 0.000*"would" + 0.000*"say" + 0.000*"govern" + 0.000*"also" '
#   '+ 0.000*"euro" + 0.000*"growth" + 0.000*"time" + 0.000*"council" + '
#   '0.000*"question"'),
#  (19,
#   '0.016*"undervalu" + 0.007*"lamfalussi" + 0.004*"peter" + '
#   '0.003*"gratifyingli" + 0.003*"intuit" + 0.003*"bath" + 0.003*"transgress" + '
#   '0.003*"britain" + 0.003*"resent" + 0.003*"bestperform"')]
# [(8,
#   '0.000*"say" + 0.000*"growth" + 0.000*"would" + 0.000*"rate" + 0.000*"level" '
#   '+ 0.000*"stabil" + 0.000*"market" + 0.000*"price" + 0.000*"govern" + '
#   '0.000*"euro"'),
#  (40,
#   '0.000*"price" + 0.000*"would" + 0.000*"said" + 0.000*"rate" + '
#   '0.000*"stabil" + 0.000*"area" + 0.000*"euro" + 0.000*"say" + 0.000*"that" + '
#   '0.000*"market"'),
#  (34,
#   '0.000*"rate" + 0.000*"say" + 0.000*"would" + 0.000*"said" + 0.000*"price" + '
#   '0.000*"that" + 0.000*"one" + 0.000*"growth" + 0.000*"euro" + 0.000*"also"'),
#  (12,
#   '0.000*"would" + 0.000*"say" + 0.000*"rate" + 0.000*"regard" + 0.000*"price" '
#   '+ 0.000*"level" + 0.000*"said" + 0.000*"stabil" + 0.000*"govern" + '
#   '0.000*"market"'),
#  (32,
#   '0.000*"would" + 0.000*"euro" + 0.000*"rate" + 0.000*"time" + 0.000*"growth" '
#   '+ 0.000*"price" + 0.000*"area" + 0.000*"govern" + 0.000*"year" + '
#   '0.000*"say"'),
#  (43,
#   '0.000*"rate" + 0.000*"would" + 0.000*"price" + 0.000*"euro" + 0.000*"say" + '
#   '0.000*"bank" + 0.000*"one" + 0.000*"govern" + 0.000*"that" + 0.000*"also"'),
#  (11,
#   '0.000*"would" + 0.000*"rate" + 0.000*"said" + 0.000*"say" + 0.000*"price" + '
#   '0.000*"govern" + 0.000*"year" + 0.000*"growth" + 0.000*"know" + '
#   '0.000*"level"'),
#  (9,
#   '0.000*"would" + 0.000*"say" + 0.000*"rate" + 0.000*"that" + 0.000*"first" + '
#   '0.000*"euro" + 0.000*"price" + 0.000*"stabil" + 0.000*"question" + '
#   '0.000*"said"'),
#  (35,
#   '0.000*"would" + 0.000*"said" + 0.000*"say" + 0.000*"price" + 0.000*"regard" '
#   '+ 0.000*"stabil" + 0.000*"time" + 0.000*"market" + 0.000*"question" + '
#   '0.000*"also"'),
#  (25,
#   '0.000*"would" + 0.000*"euro" + 0.000*"that" + 0.000*"rate" + 0.000*"say" + '
#   '0.000*"polici" + 0.000*"also" + 0.000*"growth" + 0.000*"price" + '
#   '0.000*"question"'),
#  (38,
#   '0.093*"interview" + 0.085*"school" + 0.085*"freedom" + 0.082*"entrench" + '
#   '0.082*"ladi" + 0.014*"fdi" + 0.010*"expir" + 0.007*"chose" + '
#   '0.005*"toolbox" + 0.005*"begun"'),
#  (33,
#   '0.099*"uptick" + 0.029*"constancio" + 0.026*"undervalu" + 0.016*"realis" + '
#   '0.015*"portugues" + 0.014*"blame" + 0.012*"mr" + 0.010*"properti" + '
#   '0.010*"unif" + 0.009*"foot"'),
#  (1,
#   '0.046*"interest" + 0.046*"rate" + 0.029*"polici" + 0.028*"let" + '
#   '0.028*"that" + 0.027*"think" + 0.027*"monetari" + 0.023*"expect" + '
#   '0.018*"reflect" + 0.018*"inflat"'),
#  (45,
#   '0.018*"rate" + 0.012*"take" + 0.012*"decis" + 0.011*"new" + 0.011*"money" + '
#   '0.011*"today" + 0.010*"market" + 0.008*"us" + 0.008*"euro" + '
#   '0.008*"develop"'),
#  (4,
#   '0.017*"price" + 0.016*"would" + 0.015*"market" + 0.013*"said" + '
#   '0.012*"stabil" + 0.011*"regard" + 0.011*"risk" + 0.010*"say" + '
#   '0.009*"observ" + 0.009*"level"'),
#  (5,
#   '0.017*"euro" + 0.015*"one" + 0.013*"think" + 0.011*"develop" + 0.011*"may" '
#   '+ 0.010*"area" + 0.010*"rate" + 0.010*"cannot" + 0.010*"so" + 0.009*"ecb"'),
#  (20,
#   '0.012*"regard" + 0.011*"said" + 0.011*"decis" + 0.009*"would" + '
#   '0.009*"take" + 0.009*"govern" + 0.008*"level" + 0.008*"price" + '
#   '0.008*"question" + 0.008*"rate"'),
#  (14,
#   '0.017*"bank" + 0.015*"rate" + 0.014*"would" + 0.014*"question" + '
#   '0.013*"say" + 0.012*"see" + 0.012*"central" + 0.011*"reform" + 0.010*"also" '
#   '+ 0.010*"effect"'),
#  (36,
#   '0.014*"would" + 0.013*"say" + 0.011*"govern" + 0.010*"euro" + 0.009*"rate" '
#   '+ 0.008*"said" + 0.008*"also" + 0.007*"area" + 0.007*"question" + '
#   '0.007*"council"'),
#  (49,
#   '0.012*"polici" + 0.011*"that" + 0.011*"question" + 0.010*"bank" + '
#   '0.010*"first" + 0.009*"inflat" + 0.009*"monetari" + 0.009*"time" + '
#   '0.009*"one" + 0.008*"market"')]
# [(48,
#   '0.000*"would" + 0.000*"said" + 0.000*"price" + 0.000*"say" + 0.000*"take" + '
#   '0.000*"account" + 0.000*"import" + 0.000*"rate" + 0.000*"regard" + '
#   '0.000*"inflat"'),
#  (76,
#   '0.000*"area" + 0.000*"said" + 0.000*"level" + 0.000*"question" + '
#   '0.000*"euro" + 0.000*"growth" + 0.000*"say" + 0.000*"first" + '
#   '0.000*"govern" + 0.000*"council"'),
#  (87,
#   '0.000*"govern" + 0.000*"would" + 0.000*"council" + 0.000*"say" + '
#   '0.000*"regard" + 0.000*"market" + 0.000*"rate" + 0.000*"growth" + '
#   '0.000*"level" + 0.000*"stabil"'),
#  (67,
#   '0.000*"say" + 0.000*"rate" + 0.000*"year" + 0.000*"would" + 0.000*"govern" '
#   '+ 0.000*"question" + 0.000*"polici" + 0.000*"council" + 0.000*"one" + '
#   '0.000*"time"'),
#  (84,
#   '0.000*"rate" + 0.000*"would" + 0.000*"euro" + 0.000*"say" + 0.000*"level" + '
#   '0.000*"see" + 0.000*"time" + 0.000*"area" + 0.000*"take" + 0.000*"also"'),
#  (8,
#   '0.000*"growth" + 0.000*"stabil" + 0.000*"euro" + 0.000*"rate" + '
#   '0.000*"govern" + 0.000*"would" + 0.000*"first" + 0.000*"increas" + '
#   '0.000*"polici" + 0.000*"market"'),
#  (34,
#   '0.000*"say" + 0.000*"would" + 0.000*"said" + 0.000*"rate" + 0.000*"price" + '
#   '0.000*"european" + 0.000*"economi" + 0.000*"question" + 0.000*"one" + '
#   '0.000*"stabil"'),
#  (32,
#   '0.000*"would" + 0.000*"time" + 0.000*"govern" + 0.000*"rate" + 0.000*"euro" '
#   '+ 0.000*"council" + 0.000*"say" + 0.000*"first" + 0.000*"year" + '
#   '0.000*"said"'),
#  (40,
#   '0.000*"price" + 0.000*"would" + 0.000*"stabil" + 0.000*"rate" + '
#   '0.000*"market" + 0.000*"area" + 0.000*"said" + 0.000*"euro" + 0.000*"know" '
#   '+ 0.000*"level"'),
#  (43,
#   '0.000*"rate" + 0.000*"bank" + 0.000*"would" + 0.000*"polici" + 0.000*"one" '
#   '+ 0.000*"price" + 0.000*"today" + 0.000*"euro" + 0.000*"exchang" + '
#   '0.000*"first"'),
#  (33,
#   '0.050*"repay" + 0.034*"mr" + 0.022*"valu" + 0.021*"provision" + '
#   '0.021*"constancio" + 0.020*"market" + 0.020*"concern" + 0.020*"wors" + '
#   '0.017*"merger" + 0.017*"mere"'),
#  (14,
#   '0.162*"reaffirm" + 0.068*"birthday" + 0.029*"abrupt" + 0.028*"war" + '
#   '0.022*"portug" + 0.022*"usd" + 0.020*"intens" + 0.019*"de" + 0.019*"evolv" '
#   '+ 0.019*"detriment"'),
#  (88,
#   '0.082*"test" + 0.055*"confus" + 0.051*"bottom" + 0.051*"protract" + '
#   '0.051*"conflict" + 0.039*"uptick" + 0.039*"coverag" + 0.039*"ladi" + '
#   '0.037*"school" + 0.016*"slovenia"'),
#  (20,
#   '0.014*"regard" + 0.014*"price" + 0.013*"said" + 0.013*"would" + '
#   '0.012*"stabil" + 0.010*"decis" + 0.009*"say" + 0.009*"market" + '
#   '0.009*"observ" + 0.009*"level"'),
#  (79,
#   '0.022*"govern" + 0.017*"euro" + 0.013*"council" + 0.012*"area" + '
#   '0.012*"say" + 0.010*"decis" + 0.010*"would" + 0.009*"countri" + '
#   '0.009*"question" + 0.008*"first"'),
#  (68,
#   '0.039*"rate" + 0.018*"develop" + 0.017*"exchang" + 0.013*"may" + '
#   '0.013*"euro" + 0.011*"well" + 0.011*"still" + 0.010*"time" + 0.010*"would" '
#   '+ 0.010*"growth"'),
#  (36,
#   '0.013*"question" + 0.013*"reform" + 0.011*"rate" + 0.011*"bank" + '
#   '0.011*"say" + 0.011*"also" + 0.010*"see" + 0.010*"market" + 0.009*"effect" '
#   '+ 0.009*"countri"'),
#  (96,
#   '0.022*"bank" + 0.015*"one" + 0.012*"year" + 0.011*"question" + '
#   '0.011*"would" + 0.009*"also" + 0.009*"time" + 0.009*"think" + '
#   '0.008*"polici" + 0.008*"say"'),
#  (51,
#   '0.020*"weve" + 0.017*"would" + 0.012*"say" + 0.010*"said" + 0.010*"also" + '
#   '0.010*"import" + 0.010*"market" + 0.009*"growth" + 0.008*"see" + '
#   '0.008*"economi"'),
#  (49,
#   '0.019*"that" + 0.018*"polici" + 0.013*"monetari" + 0.013*"inflat" + '
#   '0.012*"question" + 0.012*"expect" + 0.012*"first" + 0.012*"discuss" + '
#   '0.011*"rate" + 0.009*"second"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity5: ', lda_model5.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity10: ', lda_model10.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity20: ', lda_model20.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity50: ', lda_model50.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity100: ', lda_model100.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100: ', coherence_lda)


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence ScoreUMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100UMass: ', coherence_lda)
# Out:
# Perplexity:  -7.081471977679179
#
# Perplexity5:  -6.942471621490896
#
# Perplexity10:  -6.958168600223194
#
# Perplexity20:  -6.995606961564716
#
# Perplexity50:  -7.019245339515959
#
# Perplexity100:  -9.232825984578295
#
# Coherence Score:  0.2541921365753451
#
# Coherence Score5:  0.25786142884316876
#
# Coherence Score10:  0.3452195541499844
#
# Coherence Score20:  0.28830954507885354
#
# Coherence Score50:  0.32949143671513814
#
# Coherence Score100:  0.30062781824841384
#
# Coherence ScoreUMass:  -0.030202041057444548
#
# Coherence Score5UMass:  -0.07959115898703124
#
# Coherence Score10UMass:  -5.073950764378482
#
# Coherence Score20UMass:  -1.0829243727430822
#
# Coherence Score50UMass:  -3.0176490426140448
#
# Coherence Score100UMass:  -1.6088174495951657
