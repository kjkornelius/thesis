# %% [markdown]
# # Set up imports

# %%
# setting up our imports
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.models import LdaModel, LdaMulticore
import gensim.downloader as api
from gensim.models import LsiModel
from gensim.models import ldaseqmodel
from gensim.corpora import Dictionary, bleicorpus
from gensim.matutils import hellinger

nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools 
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
#import logging
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
#logging.root.setLevel(level=logging.INFO)
#import warnings
#warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # load dataset

# %%
# Load dataset
df = pd.read_csv('C:/Users/Kornelius/Desktop/Data 2/nips-papers/papers.csv', header = 0, sep = ';', error_bad_lines=False)
# Drop the columns not needed
df = df.drop(columns=['id', 'event_type', 'pdf_name'], axis=1)

# %%
# Drop a row by condition
df = df[df.abstract != 'Abstract Missing']

# %%
df['word_count'] = df['abstract'].apply(lambda x: len(str(x).split(" ")))
df[['abstract','word_count']].head()
df.word_count.describe()
# Out:
# count    3924.000000
# mean      148.390928
# std        45.605755
# min        19.000000
# 25%       116.000000
# 50%       143.000000
# 75%       177.000000
# max       317.000000
# Name: word_count, dtype: float64

# %%
# sort by year
df = df.sort_values(by=['year'])
df
# Out:
#       year                                              title  \
# 6389  1997        A Neural Network Based Head Tracking System
# 5909  1997  Learning Generative Models with the Up Propaga...
# 4884  2000   Algorithms for Non-negative Matrix Factorization
# 5281  2001  Characterizing Neural Gain Control using Spike...
# 4471  2007  Learning Horizontal Connections in a Sparse Co...
# 4477  2007                 Predictive Matrix-Variate t Models
# 4480  2007                        Competition Adds Complexity
# 6095  2007  Progressive mixture rules are deviation subopt...
# 6085  2007  Adaptive Embedded Subgraph Algorithms using Wa...
# 3564  2007  Estimating disparity with confidence from ener...
# 3430  2007          Discriminative Batch Mode Active Learning
# 6000  2007   Random Sampling of States in Dynamic Programming
# 4515  2007        Mining Internet-Scale Software Repositories
# 3434  2007                Computing Robust Counter-Strategies
# 5958  2007           The Infinite Gamma-Poisson Feature Model
# 4607  2007  Linear programming analysis of loopy belief pr...
# 6031  2007  Fitted Q-iteration in continuous action-space ...
# 6202  2007  Efficient Convex Relaxation for Transductive S...
# 4439  2007  An online Hebbian learning rule that performs ...
# 4385  2007  On Ranking in Survival Analysis: Bounds on the...
# 6255  2007  The Noisy-Logical Distribution and its Applica...
# 4363  2007  Support Vector Machine Classification with Ind...
# 3565  2007  Modelling motion primitives and their timing i...
# 6271  2007  Modeling image patches with a directed hierarc...
# 4276  2007  Gaussian Process Models for Link Analysis and ...
# 4226  2007                Spatial Latent Dirichlet Allocation
# 6405  2007  Regulator Discovery from Gene Expression Time ...
# 6479  2007                            Supervised Topic Models
# 3578  2007  EEG-Based Brain-Computer Interaction: Improved...
# 6549  2007  A General Boosting Method and its Application ...
# ...    ...                                                ...
# 5371  2017         Independence clustering (without a matrix)
# 5370  2017  Interpretable and Globally Optimal Prediction ...
# 5383  2017  From Parity to Preference-based Notions of Fai...
# 5368  2017  On Tensor Train Rank Minimization : Statistica...
# 5358  2017  Gradients of Generative Models for Improved Di...
# 5357  2017  Dual-Agent GANs for Photorealistic and Identit...
# 5351  2017  Query Complexity of Clustering with Side Infor...
# 3484  2017                       Welfare Guarantees from Data
# 5337  2017  Subset Selection and Summarization in Sequenti...
# 5327  2017  Clustering Billions of Reads for DNA Data Storage
# 5360  2017  Expectation Propagation with Stochastic Kineti...
# 5521  2017     Model evidence from nonequilibrium simulations
# 5401  2017                Collecting Telemetry Data Privately
# 5421  2017  Learning Combinatorial Optimization Algorithms...
# 5506  2017  k-Support and Ordered Weighted Sparsity for Ov...
# 5501  2017     From Bayesian Sparsity to Gated Recurrent Nets
# 5498  2017  Minimax Estimation of Bandable Precision Matrices
# 5492  2017  Lower bounds on the robustness to adversarial ...
# 5488  2017  Union of Intersections (UoI) for Interpretable...
# 5484  2017  Uprooting and Rerooting Higher-Order Graphical...
# 5411  2017  When Cyclic Coordinate Descent Outperforms Ran...
# 5465  2017  InfoGAIL: Interpretable Imitation Learning fro...
# 5450  2017  The Expressive Power of Neural Networks: A Vie...
# 5446  2017       Improving the Expected Improvement Algorithm
# 5444  2017  Clustering Stable Instances of Euclidean k-means.
# 5440  2017  Deliberation Networks: Sequence Generation Bey...
# 5436  2017  On the Model Shrinkage Effect of Gamma Process...
# 5434  2017      Regret Analysis for Continuous Dueling Bandit
# 5459  2017  Identification of Gaussian Process State Space...
# 5278  2017                    Hierarchical Methods of Moments
#
#                                                abstract  \
# 6389  We have constructed an inexpensive video based...
# 5909  Up-propagation is an algorithm for inverting a...
# 4884  Non-negative matrix factorization (NMF) has pr...
# 5281  Spike-triggered averaging techniques are effec...
# 4471  It has been shown that adapting a dictionary o...
# 4477  It is becoming increasingly important to learn...
# 4480  It is known that determinining whether a DEC-P...
# 6095  We consider the learning task consisting in pr...
# 6085  We consider the estimation problem in Gaussian...
# 3564  Binocular fusion takes place over a limited re...
# 3430  Active learning sequentially selects unlabeled...
# 6000  We combine two threads of research on approxim...
# 4515  Large repositories of source code create new c...
# 3434  Adaptation to other initially unknown agents o...
# 5958  We address the problem of factorial learning w...
# 4607  Loopy belief propagation has been employed in ...
# 6031  We consider continuous state, continuous actio...
# 6202  We consider the problem of Support Vector Mach...
# 4439  Independent component analysis (ICA) is a powe...
# 4385  In this paper, we show that classical survival...
# 6255  We describe a novel noisy-logical distribution...
# 4363  In this paper, we propose a method for support...
# 3565  Biological movement is built up of sub-blocks ...
# 6271  We describe an efficient learning procedure fo...
# 4276  In this paper we develop a Gaussian process (G...
# 4226  In recent years, the language model Latent Dir...
# 6405  We introduce a hierarchical Bayesian model for...
# 6479  We introduce supervised latent Dirichlet alloc...
# 3578  Brain-computer interfaces (BCIs), as any other...
# 6549  We present a general boosting method extending...
# ...                                                 ...
# 5371  The  independence clustering problem is consid...
# 5370  Textual grounding is an important but challeng...
# 5383  The adoption of automated, data-driven decisio...
# 5368  Tensor train (TT) decomposition provides a spa...
# 5358  Tandem mass spectrometry (MS/MS) is a high-thr...
# 5357  Synthesizing realistic profile faces is promis...
# 5351  Suppose, we are given a set of $n$ elements to...
# 3484  Analysis of efficiency of outcomes in game the...
# 5337  Subset selection, which is the task of finding...
# 5327  Storing data in synthetic DNA offers the possi...
# 5360  Technological breakthroughs allow us to collec...
# 5521  The marginal likelihood, or model evidence, is...
# 5401  The collection and analysis of telemetry data ...
# 5421  The design of good heuristics or approximation...
# 5506  The k-support and OWL norms generalize the l1 ...
# 5501  The iterations of many first-order algorithms,...
# 5498  The inverse covariance matrix provides conside...
# 5492  The input-output mappings learned by state-of-...
# 5488  The increasing size and complexity of scientif...
# 5484  The idea of uprooting and rerooting graphical ...
# 5411  The coordinate descent (CD) method is a classi...
# 5465  The goal of imitation learning is to mimic exp...
# 5450  The expressive power of neural networks is imp...
# 5446  The expected improvement (EI) algorithm is a p...
# 5444  The Euclidean k-means problem is arguably the ...
# 5440  The encoder-decoder framework has achieved pro...
# 5436  The edge partition model (EPM) is a fundamenta...
# 5434  The dueling bandit is a learning framework whe...
# 5459  The Gaussian process state space model (GPSSM)...
# 5278  Spectral methods of moments provide a powerful...
#
#                                              paper_text  word_count
# 6389  A Neural Network Based\nHead Tracking System\n...         112
# 5909  Learning Generative Models with the\nUp-Propag...          70
# 4884  Algorithms for Non-negative Matrix\nFactorizat...         107
# 5281  Characterizing neural gain control using\nspik...          81
# 4471  Learning Horizontal Connections in a Sparse Co...         143
# 4477  Predictive Matrix-Variate t Models\nShenghuo Z...         126
# 4480  Competition adds complexity\n\nJudy Goldsmith\...          67
# 6095  Progressive mixture rules are deviation subopt...         141
# 6085  Adaptive Embedded Subgraph Algorithms using\nW...         123
# 3564  Estimating disparity with confidence from ener...         185
# 3430  Discriminative Batch Mode Active Learning\nYuh...         178
# 6000  Random Sampling of States in Dynamic\nProgramm...          91
# 4515  Mining Internet-Scale Software Repositories\n\...         190
# 3434  Computing Robust Counter-Strategies\n\nMichael...         174
# 5958  The Infinite Gamma-Poisson Feature Model\nMich...         134
# 4607  Linear Programming Analysis of Loopy Belief\nP...         125
# 6031  Fitted Q-iteration in continuous action-space ...          87
# 6202  Efficient Convex Relaxation for\nTransductive ...         127
# 4439  An online Hebbian learning rule that performs\...         103
# 4385  On Ranking in Survival Analysis: Bounds on the...         125
# 6255  The Noisy-Logical Distribution and its Applica...         129
# 4363  Support Vector Machine Classification\nwith In...         103
# 3565  Modelling motion primitives and their timing\n...         169
# 6271  Modeling image patches with a directed hierarc...         118
# 4276  Gaussian Process Models for\nLink Analysis and...          99
# 4226  Spatial Latent Dirichlet Allocation\n\nXiaogan...         186
# 6405  Regulator Discovery from Gene Expression Time\...         106
# 6479  Supervised topic models\n\nJon D. McAuliffe\nD...          99
# 3578  EEG-Based Brain-Computer Interaction: Improved...         290
# 6549  A General Boosting Method and its Application ...         123
# ...                                                 ...         ...
# 5371  Independence clustering (without a matrix)\n\n...         141
# 5370  Interpretable and Globally Optimal Prediction ...         134
# 5383  From Parity to Preference-based Notions\nof Fa...         170
# 5368  On Tensor Train Rank Minimization: Statistical...         107
# 5358  Gradients of Generative Models for Improved\nD...         170
# 5357  Dual-Agent GANs for Photorealistic and Identit...         237
# 5351  Query Complexity of Clustering with\nSide Info...         302
# 3484  Welfare Guarantees from Data\nDarrell Hoy\nUni...         157
# 5337  Subset Selection and Summarization\nin Sequent...         215
# 5327  Clustering Billions of Reads for DNA Data Stor...         198
# 5360  Expectation Propagation with Stochastic Kineti...         148
# 5521  Model evidence from nonequilibrium simulations...         130
# 5401  Collecting Telemetry Data Privately\n\nBolin D...         189
# 5421  Learning Combinatorial Optimization Algorithms...         165
# 5506  k-Support and Ordered Weighted Sparsity for\nO...         139
# 5501  From Bayesian Sparsity to Gated Recurrent Nets...         210
# 5498  Minimax Estimation of Bandable Precision Matri...         179
# 5492  Lower bounds on the robustness to adversarial\...         109
# 5488  Union of Intersections (UoI) for Interpretable...         191
# 5484  Uprooting and Rerooting Higher-Order Graphical...         125
# 5411  When Cyclic Coordinate Descent Outperforms\nRa...         165
# 5465  InfoGAIL: Interpretable Imitation Learning fro...         145
# 5450  The Expressive Power of Neural Networks: A Vie...         246
# 5446  Improving the Expected Improvement Algorithm\n...         156
# 5444  Clustering Stable Instances of Euclidean k-mea...         194
# 5440  Deliberation Networks: Sequence Generation\nBe...         184
# 5436  On the Model Shrinkage Effect of\nGamma Proces...         196
# 5434  Regret Analysis for Continuous Dueling Bandit\...         128
# 5459  Identification of Gaussian Process State Space...         168
# 5278  Hierarchical Methods of Moments\nMatteo Ruffin...          94
#
# [3924 rows x 5 columns]

# %%
df.year.value_counts()
# Out:
# 2017    679
# 2016    569
# 2014    411
# 2015    403
# 2013    360
# 2012    342
# 2011    290
# 2010    288
# 2009    257
# 2008    222
# 2007     99
# 1997      2
# 2001      1
# 2000      1
# Name: year, dtype: int64

# %%
data = df.abstract.values.tolist()

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(data):
    stop_free = " ".join([i for i in data.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(data).split() for data in data]

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
ps = PorterStemmer()
def clean(data):
    stop_free = " ".join([i for i in data.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(ps.stem(word) for word in punc_free.split())
    return normalized

data = [clean(data).split() for data in data]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
from nltk.probability import FreqDist
result = str(data_words).strip('[]')
freq = pd.Series(''.join(result).split()).value_counts()[:50]
freq
# turn series into df
df = freq.to_frame().reset_index()
df.columns = ['words','counts']
# draw graph
ax = df.plot.bar(x='words', y='counts', rot=0, figsize=(50,30))


plt.xticks(size = 50)
plt.xticks(rotation=90)
plt.yticks(size = 40)
# Out:
# (array([   0., 1000., 2000., 3000., 4000., 5000., 6000.]),
#  <a list of 7 Text yticklabel objects>)

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(12827 unique tokens: ['adapt', 'adjust', 'allow', 'also', 'auxiliari']...)

# %%
# less than 10 documents,
id2word = corpora.Dictionary(data)
id2word.filter_extremes(no_above = 0.90)
print((id2word))
# Out:
# Dictionary(4415 unique tokens: ['adaptation', 'adjusts', 'allows', 'also', 'auxiliary']...)

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %%
from gensim.models import ldaseqmodel
import numpy
from gensim.matutils import hellinger

# %%
time_slice = [4 , 11, 13, 9, 11, 11, 11, 11, 12, 12, 12, 12, 12, 12, 12, 12, 12, 8, 8]
