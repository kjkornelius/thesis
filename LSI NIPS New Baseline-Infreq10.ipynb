# %% [markdown]
# # load packages

# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess, lemmatize
from gensim.models import CoherenceModel
from gensim.models import LdaModel, LdaMulticore
import gensim.downloader as api
from gensim.models import LsiModel

nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools 
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
#import logging
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
#logging.root.setLevel(level=logging.INFO)
#import warnings
#warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_csv('C:/Users/Kornelius/Desktop/Data 2/nips-papers/papers.csv', header = 0, sep = ';', error_bad_lines=False)
# Drop the columns not needed
df = df.drop(columns=['id', 'event_type', 'pdf_name'], axis=1)

# %%
# Drop a row by condition
df = df[df.abstract != 'Abstract Missing']

# %%
data = df.abstract.values.tolist()

# %% [markdown]
# # Pre-processing (Baseline)

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(data):
    stop_free = " ".join([i for i in data.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(data).split() for data in data]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(16129 unique tokens: ['activity', 'also', 'analysis', 'applied', 'assume']...)

# %%
# less than 10 documents,
id2word = corpora.Dictionary(data)
id2word.filter_extremes(no_below = 10)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# # LSI

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.103*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '0.520*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.327*"network" + '
#   '-0.296*"method" + -0.165*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.124*"neural"'),
#  (3,
#   '0.574*"method" + -0.442*"learning" + -0.359*"network" + -0.292*"algorithm" '
#   '+ 0.253*"data" + 0.121*"matrix" + 0.104*"problem" + -0.100*"neural" + '
#   '-0.100*"deep" + -0.087*"task"'),
#  (4,
#   '-0.590*"network" + 0.578*"learning" + 0.267*"data" + -0.219*"neural" + '
#   '-0.104*"algorithm" + -0.103*"method" + 0.081*"task" + -0.079*"deep" + '
#   '0.075*"approach" + -0.075*"image"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '0.728*"model" + -0.434*"algorithm" + -0.240*"problem" + -0.134*"function" + '
#   '-0.114*"learning" + 0.108*"network" + 0.103*"image" + -0.090*"bound" + '
#   '0.086*"neural" + -0.079*"method"'),
#  (2,
#   '-0.520*"algorithm" + -0.391*"model" + 0.334*"learning" + 0.327*"network" + '
#   '0.296*"method" + 0.165*"image" + 0.155*"task" + 0.143*"feature" + '
#   '0.125*"deep" + 0.124*"neural"'),
#  (3,
#   '-0.574*"method" + 0.442*"learning" + 0.359*"network" + 0.292*"algorithm" + '
#   '-0.253*"data" + -0.121*"matrix" + -0.104*"problem" + 0.099*"neural" + '
#   '0.099*"deep" + 0.087*"task"'),
#  (4,
#   '0.590*"network" + -0.578*"learning" + -0.267*"data" + 0.217*"neural" + '
#   '0.104*"algorithm" + 0.103*"method" + -0.080*"task" + 0.080*"deep" + '
#   '-0.075*"approach" + 0.075*"image"'),
#  (5,
#   '-0.682*"data" + 0.316*"function" + -0.262*"algorithm" + 0.202*"model" + '
#   '0.197*"problem" + 0.185*"learning" + 0.162*"method" + -0.139*"network" + '
#   '0.114*"optimization" + -0.112*"feature"'),
#  (6,
#   '-0.522*"image" + 0.327*"data" + 0.272*"function" + 0.251*"network" + '
#   '-0.245*"algorithm" + -0.236*"feature" + -0.235*"object" + -0.221*"method" + '
#   '0.186*"distribution" + 0.120*"bound"'),
#  (7,
#   '0.483*"method" + -0.424*"problem" + 0.319*"algorithm" + -0.292*"image" + '
#   '0.225*"learning" + -0.127*"object" + 0.125*"gradient" + 0.124*"inference" + '
#   '-0.120*"matrix" + -0.113*"distribution"'),
#  (8,
#   '-0.569*"problem" + 0.531*"function" + 0.212*"image" + 0.191*"feature" + '
#   '-0.185*"matrix" + -0.170*"learning" + 0.166*"distribution" + '
#   '-0.145*"network" + 0.127*"bound" + 0.096*"loss"'),
#  (9,
#   '-0.499*"function" + 0.349*"distribution" + 0.271*"bound" + -0.258*"data" + '
#   '-0.251*"problem" + 0.209*"matrix" + 0.194*"sample" + -0.129*"optimization" '
#   '+ 0.105*"show" + 0.103*"complexity"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '0.728*"model" + -0.434*"algorithm" + -0.240*"problem" + -0.134*"function" + '
#   '-0.114*"learning" + 0.108*"network" + 0.103*"image" + -0.090*"bound" + '
#   '0.086*"neural" + -0.079*"method"'),
#  (2,
#   '0.520*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.327*"network" + '
#   '-0.296*"method" + -0.165*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.123*"neural"'),
#  (3,
#   '0.574*"method" + -0.442*"learning" + -0.359*"network" + -0.292*"algorithm" '
#   '+ 0.253*"data" + 0.121*"matrix" + 0.104*"problem" + -0.100*"neural" + '
#   '-0.099*"deep" + -0.087*"task"'),
#  (4,
#   '0.590*"network" + -0.578*"learning" + -0.267*"data" + 0.218*"neural" + '
#   '0.104*"algorithm" + 0.103*"method" + -0.080*"task" + 0.079*"deep" + '
#   '-0.075*"approach" + 0.075*"image"'),
#  (5,
#   '0.682*"data" + -0.316*"function" + 0.262*"algorithm" + -0.201*"model" + '
#   '-0.197*"problem" + -0.184*"learning" + -0.162*"method" + 0.140*"network" + '
#   '-0.114*"optimization" + 0.112*"feature"'),
#  (6,
#   '-0.523*"image" + 0.328*"data" + 0.272*"function" + 0.251*"network" + '
#   '-0.245*"algorithm" + -0.236*"feature" + -0.234*"object" + -0.221*"method" + '
#   '0.185*"distribution" + 0.120*"bound"'),
#  (7,
#   '0.482*"method" + -0.424*"problem" + 0.319*"algorithm" + -0.292*"image" + '
#   '0.225*"learning" + -0.126*"object" + 0.125*"inference" + 0.123*"gradient" + '
#   '-0.121*"matrix" + -0.112*"distribution"'),
#  (8,
#   '-0.568*"problem" + 0.531*"function" + 0.211*"image" + 0.192*"feature" + '
#   '-0.184*"matrix" + -0.170*"learning" + 0.167*"distribution" + '
#   '-0.145*"network" + 0.128*"bound" + 0.095*"loss"'),
#  (9,
#   '0.498*"function" + -0.349*"distribution" + -0.271*"bound" + 0.258*"data" + '
#   '0.251*"problem" + -0.206*"matrix" + -0.195*"sample" + 0.131*"optimization" '
#   '+ -0.105*"complexity" + -0.104*"show"'),
#  (10,
#   '0.449*"feature" + 0.381*"matrix" + -0.370*"distribution" + '
#   '-0.275*"approach" + -0.245*"inference" + -0.203*"image" + 0.187*"kernel" + '
#   '0.131*"model" + -0.125*"problem" + 0.111*"function"'),
#  (11,
#   '-0.403*"feature" + -0.324*"kernel" + -0.300*"approach" + 0.272*"bound" + '
#   '-0.242*"inference" + 0.222*"image" + -0.202*"distribution" + 0.183*"data" + '
#   '0.163*"loss" + -0.141*"graph"'),
#  (12,
#   '-0.283*"graph" + -0.278*"image" + 0.259*"task" + -0.229*"distribution" + '
#   '-0.226*"matrix" + 0.209*"time" + 0.189*"policy" + 0.179*"feature" + '
#   '0.169*"information" + -0.165*"kernel"'),
#  (13,
#   '-0.507*"matrix" + 0.387*"feature" + -0.282*"approach" + 0.237*"graph" + '
#   '0.168*"bound" + 0.158*"problem" + -0.156*"image" + 0.147*"method" + '
#   '0.145*"distribution" + -0.121*"neural"'),
#  (14,
#   '-0.513*"graph" + 0.364*"distribution" + 0.306*"feature" + -0.230*"approach" '
#   '+ 0.178*"problem" + -0.165*"kernel" + -0.163*"bound" + -0.157*"clustering" '
#   '+ 0.147*"gradient" + -0.142*"time"'),
#  (15,
#   '0.402*"bound" + 0.396*"approach" + -0.281*"distribution" + -0.280*"graph" + '
#   '0.217*"inference" + -0.168*"task" + 0.157*"feature" + -0.145*"clustering" + '
#   '-0.116*"method" + -0.112*"information"'),
#  (16,
#   '0.462*"kernel" + -0.356*"task" + -0.277*"matrix" + 0.199*"image" + '
#   '0.194*"gradient" + -0.189*"function" + 0.177*"rate" + -0.166*"approach" + '
#   '0.143*"stochastic" + 0.128*"convergence"'),
#  (17,
#   '0.340*"task" + 0.267*"gradient" + -0.232*"bound" + -0.221*"inference" + '
#   '0.191*"training" + -0.189*"image" + -0.187*"method" + -0.150*"learning" + '
#   '0.148*"convergence" + 0.147*"performance"'),
#  (18,
#   '-0.510*"kernel" + 0.353*"approach" + -0.310*"task" + 0.215*"graph" + '
#   '0.193*"feature" + 0.153*"sparse" + -0.148*"classification" + '
#   '-0.130*"inference" + 0.128*"gradient" + -0.124*"process"'),
#  (19,
#   '-0.297*"gradient" + 0.252*"loss" + -0.230*"matrix" + -0.225*"policy" + '
#   '0.210*"neural" + -0.198*"stochastic" + 0.176*"classification" + '
#   '0.171*"approach" + 0.169*"linear" + -0.165*"time"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.103*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '-0.520*"algorithm" + -0.391*"model" + 0.334*"learning" + 0.327*"network" + '
#   '0.296*"method" + 0.165*"image" + 0.155*"task" + 0.143*"feature" + '
#   '0.125*"deep" + 0.123*"neural"'),
#  (3,
#   '-0.574*"method" + 0.442*"learning" + 0.359*"network" + 0.292*"algorithm" + '
#   '-0.253*"data" + -0.121*"matrix" + -0.104*"problem" + 0.100*"neural" + '
#   '0.099*"deep" + 0.087*"task"'),
#  (4,
#   '-0.590*"network" + 0.578*"learning" + 0.267*"data" + -0.218*"neural" + '
#   '-0.104*"algorithm" + -0.103*"method" + 0.081*"task" + -0.079*"deep" + '
#   '0.075*"approach" + -0.075*"image"'),
#  (5,
#   '-0.682*"data" + 0.316*"function" + -0.262*"algorithm" + 0.201*"model" + '
#   '0.197*"problem" + 0.185*"learning" + 0.162*"method" + -0.140*"network" + '
#   '0.114*"optimization" + -0.112*"feature"'),
#  (6,
#   '0.522*"image" + -0.328*"data" + -0.272*"function" + -0.251*"network" + '
#   '0.244*"algorithm" + 0.236*"feature" + 0.233*"object" + 0.221*"method" + '
#   '-0.185*"distribution" + -0.120*"bound"'),
#  (7,
#   '0.483*"method" + -0.424*"problem" + 0.319*"algorithm" + -0.293*"image" + '
#   '0.225*"learning" + -0.126*"object" + 0.124*"inference" + 0.123*"gradient" + '
#   '-0.121*"matrix" + -0.113*"distribution"'),
#  (8,
#   '0.569*"problem" + -0.531*"function" + -0.212*"image" + -0.191*"feature" + '
#   '0.184*"matrix" + 0.170*"learning" + -0.166*"distribution" + 0.145*"network" '
#   '+ -0.127*"bound" + -0.096*"loss"'),
#  (9,
#   '-0.499*"function" + 0.349*"distribution" + 0.272*"bound" + -0.258*"data" + '
#   '-0.251*"problem" + 0.206*"matrix" + 0.195*"sample" + -0.130*"optimization" '
#   '+ 0.105*"show" + 0.105*"complexity"'),
#  (10,
#   '-0.449*"feature" + -0.380*"matrix" + 0.370*"distribution" + '
#   '0.276*"approach" + 0.243*"inference" + 0.203*"image" + -0.186*"kernel" + '
#   '-0.131*"model" + 0.124*"problem" + -0.112*"function"'),
#  (11,
#   '0.404*"feature" + 0.323*"kernel" + 0.300*"approach" + -0.275*"bound" + '
#   '0.240*"inference" + -0.224*"image" + 0.196*"distribution" + -0.182*"data" + '
#   '-0.162*"loss" + 0.138*"graph"'),
#  (12,
#   '0.284*"graph" + 0.275*"image" + -0.260*"task" + 0.230*"distribution" + '
#   '0.225*"matrix" + -0.210*"time" + -0.190*"policy" + -0.176*"feature" + '
#   '-0.172*"information" + 0.170*"kernel"'),
#  (13,
#   '-0.508*"matrix" + 0.388*"feature" + -0.284*"approach" + 0.237*"graph" + '
#   '0.169*"bound" + 0.159*"problem" + -0.155*"image" + 0.147*"method" + '
#   '0.145*"distribution" + -0.121*"neural"'),
#  (14,
#   '-0.512*"graph" + 0.368*"distribution" + 0.306*"feature" + -0.232*"approach" '
#   '+ 0.178*"problem" + -0.167*"kernel" + -0.163*"bound" + -0.156*"clustering" '
#   '+ 0.148*"gradient" + -0.143*"time"'),
#  (15,
#   '-0.399*"bound" + -0.393*"approach" + 0.281*"distribution" + 0.281*"graph" + '
#   '-0.214*"inference" + 0.189*"task" + -0.159*"feature" + 0.147*"clustering" + '
#   '0.122*"method" + -0.120*"kernel"'),
#  (16,
#   '0.459*"kernel" + -0.345*"task" + -0.278*"matrix" + 0.202*"image" + '
#   '0.193*"gradient" + -0.186*"function" + -0.184*"approach" + 0.176*"rate" + '
#   '0.143*"stochastic" + 0.127*"convergence"'),
#  (17,
#   '0.332*"task" + 0.271*"gradient" + -0.235*"bound" + -0.226*"inference" + '
#   '0.193*"training" + -0.192*"image" + -0.188*"method" + 0.151*"approach" + '
#   '-0.148*"learning" + 0.146*"stochastic"'),
#  (18,
#   '-0.508*"kernel" + 0.353*"approach" + -0.326*"task" + 0.208*"graph" + '
#   '0.191*"feature" + 0.148*"sparse" + -0.145*"classification" + '
#   '-0.143*"inference" + -0.121*"process" + 0.111*"learning"'),
#  (19,
#   '0.294*"gradient" + -0.255*"loss" + 0.234*"matrix" + 0.229*"policy" + '
#   '-0.213*"neural" + 0.203*"stochastic" + -0.174*"linear" + -0.173*"approach" '
#   '+ -0.169*"classification" + 0.162*"process"'),
#  (20,
#   '0.501*"inference" + -0.272*"approach" + -0.213*"policy" + -0.204*"kernel" + '
#   '0.183*"graph" + 0.166*"show" + -0.163*"distribution" + 0.140*"variational" '
#   '+ 0.136*"task" + 0.136*"loss"'),
#  (21,
#   '0.401*"task" + 0.345*"bound" + -0.328*"time" + -0.230*"show" + '
#   '-0.227*"label" + -0.188*"training" + -0.188*"loss" + 0.144*"structure" + '
#   '-0.139*"classification" + -0.130*"class"'),
#  (22,
#   '-0.347*"clustering" + 0.256*"time" + 0.225*"sparse" + -0.224*"information" '
#   '+ 0.185*"parameter" + 0.182*"task" + 0.173*"regression" + 0.170*"image" + '
#   '-0.167*"matrix" + -0.162*"approach"'),
#  (23,
#   '0.443*"clustering" + -0.333*"graph" + 0.239*"show" + -0.177*"gradient" + '
#   '-0.171*"information" + 0.171*"cluster" + -0.162*"loss" + -0.158*"time" + '
#   '0.152*"result" + 0.142*"set"'),
#  (24,
#   '-0.365*"result" + -0.288*"policy" + 0.282*"object" + 0.216*"number" + '
#   '0.199*"time" + -0.194*"show" + 0.193*"sample" + 0.176*"task" + '
#   '0.173*"parameter" + -0.161*"new"'),
#  (25,
#   '0.336*"time" + 0.240*"object" + 0.236*"loss" + -0.203*"show" + '
#   '-0.200*"training" + -0.186*"neural" + -0.182*"policy" + -0.179*"using" + '
#   '-0.178*"bound" + 0.169*"framework"'),
#  (26,
#   '-0.474*"object" + 0.363*"time" + 0.221*"clustering" + -0.206*"show" + '
#   '-0.202*"variable" + 0.194*"result" + -0.178*"structure" + 0.151*"image" + '
#   '-0.148*"latent" + -0.136*"space"'),
#  (27,
#   '-0.323*"latent" + -0.239*"variable" + -0.225*"information" + -0.200*"show" '
#   '+ 0.195*"graph" + -0.190*"structure" + -0.188*"clustering" + 0.175*"object" '
#   '+ -0.170*"time" + -0.163*"topic"'),
#  (28,
#   '0.343*"show" + -0.309*"information" + -0.307*"process" + -0.271*"label" + '
#   '0.236*"object" + 0.167*"time" + -0.157*"bayesian" + -0.143*"parameter" + '
#   '-0.136*"gaussian" + -0.129*"loss"'),
#  (29,
#   '0.468*"information" + -0.315*"loss" + -0.211*"state" + -0.211*"clustering" '
#   '+ -0.197*"number" + -0.159*"process" + -0.146*"task" + 0.136*"sample" + '
#   '-0.134*"gradient" + -0.123*"linear"'),
#  (30,
#   '0.462*"show" + -0.252*"result" + 0.242*"loss" + -0.199*"class" + '
#   '-0.192*"number" + -0.190*"latent" + -0.148*"analysis" + -0.146*"topic" + '
#   '-0.141*"object" + 0.141*"parameter"'),
#  (31,
#   '0.365*"sample" + 0.277*"variable" + 0.259*"training" + -0.215*"number" + '
#   '-0.201*"label" + 0.196*"latent" + 0.195*"clustering" + '
#   '-0.183*"distribution" + -0.175*"sparse" + 0.164*"loss"'),
#  (32,
#   '-0.452*"set" + 0.264*"using" + 0.200*"process" + 0.174*"bound" + '
#   '-0.170*"kernel" + -0.167*"class" + -0.164*"result" + 0.161*"sparse" + '
#   '0.157*"performance" + -0.153*"parameter"'),
#  (33,
#   '0.301*"label" + -0.262*"using" + -0.252*"number" + -0.237*"loss" + '
#   '0.174*"error" + -0.171*"training" + -0.164*"information" + 0.161*"show" + '
#   '0.160*"classification" + 0.156*"rate"'),
#  (34,
#   '0.267*"process" + 0.256*"training" + 0.237*"set" + -0.223*"state" + '
#   '0.202*"performance" + -0.191*"information" + -0.178*"estimator" + '
#   '-0.178*"label" + 0.176*"optimization" + -0.154*"space"'),
#  (35,
#   '0.315*"using" + 0.291*"set" + -0.265*"variable" + 0.242*"result" + '
#   '-0.226*"performance" + -0.219*"policy" + -0.177*"parameter" + 0.172*"space" '
#   '+ 0.157*"rate" + -0.142*"loss"'),
#  (36,
#   '0.317*"process" + 0.261*"rate" + -0.241*"parameter" + -0.238*"using" + '
#   '0.215*"number" + -0.194*"gradient" + -0.188*"set" + 0.178*"sample" + '
#   '0.170*"show" + 0.156*"domain"'),
#  (37,
#   '0.470*"framework" + 0.279*"using" + -0.268*"state" + 0.186*"domain" + '
#   '-0.181*"performance" + 0.179*"structure" + -0.176*"information" + '
#   '0.172*"label" + -0.164*"loss" + -0.140*"estimator"'),
#  (38,
#   '-0.276*"using" + 0.218*"set" + -0.213*"class" + -0.188*"estimator" + '
#   '0.186*"loss" + -0.182*"parameter" + 0.172*"domain" + -0.166*"rate" + '
#   '-0.163*"performance" + 0.159*"paper"'),
#  (39,
#   '-0.298*"parameter" + -0.248*"framework" + -0.244*"state" + '
#   '0.230*"structure" + 0.228*"result" + 0.192*"gradient" + -0.182*"based" + '
#   '-0.173*"optimization" + 0.170*"tree" + -0.158*"domain"'),
#  (40,
#   '-0.307*"structure" + 0.291*"variable" + 0.247*"linear" + -0.207*"neural" + '
#   '-0.202*"tree" + -0.193*"parameter" + -0.178*"class" + 0.169*"set" + '
#   '0.161*"latent" + 0.154*"policy"'),
#  (41,
#   '-0.285*"using" + 0.266*"space" + -0.262*"result" + -0.254*"number" + '
#   '0.214*"representation" + -0.187*"variable" + 0.181*"estimator" + '
#   '0.171*"sparse" + -0.157*"new" + 0.137*"neural"'),
#  (42,
#   '-0.319*"analysis" + -0.307*"process" + 0.252*"sparse" + 0.177*"clustering" '
#   '+ 0.171*"rate" + 0.158*"optimization" + 0.157*"optimal" + -0.146*"set" + '
#   '0.145*"kernel" + 0.139*"bayesian"'),
#  (43,
#   '-0.340*"information" + -0.255*"domain" + -0.212*"time" + -0.186*"sparse" + '
#   '0.183*"sample" + -0.159*"object" + 0.152*"human" + -0.130*"result" + '
#   '-0.127*"bound" + -0.124*"gradient"'),
#  (44,
#   '-0.271*"domain" + 0.269*"framework" + 0.253*"linear" + -0.249*"rate" + '
#   '0.211*"sample" + 0.191*"optimization" + -0.163*"two" + 0.151*"state" + '
#   '-0.145*"structure" + 0.138*"system"'),
#  (45,
#   '0.295*"optimization" + 0.254*"policy" + -0.244*"result" + 0.229*"class" + '
#   '0.219*"using" + 0.171*"new" + -0.162*"gradient" + 0.152*"loss" + '
#   '-0.147*"proposed" + 0.147*"convex"'),
#  (46,
#   '-0.254*"tree" + -0.249*"new" + 0.235*"result" + -0.225*"class" + '
#   '0.204*"parameter" + -0.203*"state" + 0.191*"label" + 0.185*"policy" + '
#   '-0.178*"linear" + -0.142*"rate"'),
#  (47,
#   '-0.215*"number" + 0.213*"representation" + 0.209*"state" + 0.207*"class" + '
#   '-0.203*"policy" + -0.198*"metric" + 0.176*"human" + 0.160*"estimator" + '
#   '-0.157*"space" + -0.151*"structure"'),
#  (48,
#   '0.407*"new" + -0.287*"optimization" + -0.219*"domain" + -0.209*"random" + '
#   '-0.167*"space" + 0.165*"based" + -0.154*"performance" + 0.133*"gradient" + '
#   '0.130*"error" + 0.128*"policy"'),
#  (49,
#   '0.303*"parameter" + 0.300*"linear" + -0.223*"new" + -0.205*"estimator" + '
#   '-0.196*"set" + -0.192*"sparse" + 0.188*"human" + 0.152*"representation" + '
#   '0.148*"optimization" + -0.147*"propose"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.103*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '0.520*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.327*"network" + '
#   '-0.296*"method" + -0.165*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.123*"neural"'),
#  (3,
#   '0.574*"method" + -0.442*"learning" + -0.359*"network" + -0.292*"algorithm" '
#   '+ 0.253*"data" + 0.121*"matrix" + 0.104*"problem" + -0.100*"neural" + '
#   '-0.099*"deep" + -0.087*"task"'),
#  (4,
#   '-0.590*"network" + 0.578*"learning" + 0.268*"data" + -0.218*"neural" + '
#   '-0.104*"algorithm" + -0.103*"method" + 0.081*"task" + -0.079*"deep" + '
#   '0.075*"approach" + -0.075*"image"'),
#  (5,
#   '0.682*"data" + -0.316*"function" + 0.262*"algorithm" + -0.202*"model" + '
#   '-0.196*"problem" + -0.185*"learning" + -0.162*"method" + 0.140*"network" + '
#   '-0.114*"optimization" + 0.112*"feature"'),
#  (6,
#   '0.522*"image" + -0.328*"data" + -0.272*"function" + -0.251*"network" + '
#   '0.245*"algorithm" + 0.236*"feature" + 0.233*"object" + 0.221*"method" + '
#   '-0.185*"distribution" + -0.120*"bound"'),
#  (7,
#   '0.483*"method" + -0.424*"problem" + 0.319*"algorithm" + -0.292*"image" + '
#   '0.225*"learning" + -0.126*"object" + 0.124*"inference" + 0.123*"gradient" + '
#   '-0.121*"matrix" + -0.113*"distribution"'),
#  (8,
#   '0.568*"problem" + -0.531*"function" + -0.212*"image" + -0.191*"feature" + '
#   '0.184*"matrix" + 0.170*"learning" + -0.166*"distribution" + 0.145*"network" '
#   '+ -0.126*"bound" + -0.095*"loss"'),
#  (9,
#   '0.499*"function" + -0.349*"distribution" + -0.272*"bound" + 0.258*"data" + '
#   '0.252*"problem" + -0.206*"matrix" + -0.196*"sample" + 0.130*"optimization" '
#   '+ -0.105*"show" + -0.105*"complexity"'),
#  (10,
#   '-0.449*"feature" + -0.380*"matrix" + 0.370*"distribution" + '
#   '0.276*"approach" + 0.244*"inference" + 0.203*"image" + -0.186*"kernel" + '
#   '-0.131*"model" + 0.124*"problem" + -0.112*"function"'),
#  (11,
#   '0.404*"feature" + 0.323*"kernel" + 0.300*"approach" + -0.275*"bound" + '
#   '0.240*"inference" + -0.224*"image" + 0.198*"distribution" + -0.182*"data" + '
#   '-0.163*"loss" + 0.139*"graph"'),
#  (12,
#   '-0.283*"graph" + -0.276*"image" + 0.260*"task" + -0.231*"distribution" + '
#   '-0.225*"matrix" + 0.210*"time" + 0.190*"policy" + 0.175*"feature" + '
#   '0.172*"information" + -0.169*"kernel"'),
#  (13,
#   '-0.507*"matrix" + 0.387*"feature" + -0.284*"approach" + 0.237*"graph" + '
#   '0.170*"bound" + 0.159*"problem" + -0.155*"image" + 0.147*"method" + '
#   '0.146*"distribution" + -0.122*"neural"'),
#  (14,
#   '0.513*"graph" + -0.367*"distribution" + -0.306*"feature" + 0.230*"approach" '
#   '+ -0.178*"problem" + 0.168*"kernel" + 0.163*"bound" + 0.156*"clustering" + '
#   '-0.149*"gradient" + 0.143*"time"'),
#  (15,
#   '-0.398*"bound" + -0.393*"approach" + 0.282*"distribution" + 0.280*"graph" + '
#   '-0.213*"inference" + 0.187*"task" + -0.158*"feature" + 0.146*"clustering" + '
#   '0.122*"method" + -0.121*"kernel"'),
#  (16,
#   '0.458*"kernel" + -0.346*"task" + -0.278*"matrix" + 0.201*"image" + '
#   '0.194*"gradient" + -0.186*"function" + -0.184*"approach" + 0.175*"rate" + '
#   '0.143*"stochastic" + 0.124*"convergence"'),
#  (17,
#   '-0.337*"task" + -0.271*"gradient" + 0.236*"bound" + 0.229*"inference" + '
#   '-0.193*"training" + 0.192*"image" + 0.187*"method" + 0.149*"learning" + '
#   '-0.148*"approach" + -0.145*"stochastic"'),
#  (18,
#   '-0.511*"kernel" + 0.350*"approach" + -0.323*"task" + 0.213*"graph" + '
#   '0.193*"feature" + 0.153*"sparse" + -0.143*"classification" + '
#   '-0.139*"inference" + -0.118*"process" + 0.116*"gradient"'),
#  (19,
#   '0.295*"gradient" + -0.254*"loss" + 0.234*"matrix" + 0.229*"policy" + '
#   '-0.212*"neural" + 0.203*"stochastic" + -0.175*"linear" + -0.175*"approach" '
#   '+ -0.168*"classification" + 0.164*"process"'),
#  (20,
#   '0.503*"inference" + -0.275*"approach" + -0.214*"policy" + -0.198*"kernel" + '
#   '0.180*"graph" + 0.169*"show" + -0.161*"distribution" + 0.139*"variational" '
#   '+ 0.139*"task" + 0.139*"loss"'),
#  (21,
#   '0.401*"task" + 0.343*"bound" + -0.328*"time" + -0.229*"show" + '
#   '-0.223*"label" + -0.186*"loss" + -0.185*"training" + 0.148*"structure" + '
#   '-0.136*"classification" + -0.131*"class"'),
#  (22,
#   '-0.345*"clustering" + 0.259*"time" + -0.229*"information" + 0.224*"sparse" '
#   '+ 0.184*"task" + 0.184*"parameter" + 0.176*"regression" + 0.170*"image" + '
#   '-0.166*"matrix" + -0.165*"approach"'),
#  (23,
#   '-0.450*"clustering" + 0.331*"graph" + -0.233*"show" + 0.178*"gradient" + '
#   '0.172*"information" + 0.165*"time" + -0.163*"cluster" + 0.162*"loss" + '
#   '-0.152*"result" + -0.149*"set"'),
#  (24,
#   '0.370*"result" + 0.289*"policy" + -0.279*"object" + -0.220*"number" + '
#   '-0.197*"sample" + -0.197*"time" + 0.191*"show" + -0.176*"task" + '
#   '-0.172*"parameter" + 0.163*"new"'),
#  (25,
#   '0.327*"time" + 0.255*"object" + 0.235*"loss" + -0.200*"show" + '
#   '-0.194*"training" + -0.187*"neural" + -0.180*"bound" + -0.180*"using" + '
#   '-0.179*"policy" + 0.171*"framework"'),
#  (26,
#   '-0.470*"object" + 0.363*"time" + 0.221*"clustering" + -0.220*"show" + '
#   '-0.209*"variable" + 0.190*"result" + -0.177*"structure" + 0.151*"image" + '
#   '-0.147*"latent" + -0.135*"space"'),
#  (27,
#   '-0.331*"latent" + -0.245*"variable" + -0.241*"show" + -0.199*"time" + '
#   '-0.185*"clustering" + 0.184*"graph" + -0.179*"structure" + '
#   '-0.176*"information" + -0.169*"topic" + 0.156*"inference"'),
#  (28,
#   '0.355*"information" + 0.304*"process" + -0.298*"show" + 0.263*"label" + '
#   '-0.254*"object" + 0.157*"parameter" + 0.151*"set" + 0.150*"bayesian" + '
#   '-0.146*"time" + 0.133*"gaussian"'),
#  (29,
#   '0.456*"information" + -0.302*"loss" + -0.227*"state" + -0.219*"number" + '
#   '-0.200*"clustering" + -0.157*"process" + -0.148*"task" + 0.145*"sample" + '
#   '-0.135*"gradient" + -0.133*"linear"'),
#  (30,
#   '-0.466*"show" + -0.264*"loss" + 0.244*"result" + 0.197*"class" + '
#   '0.182*"latent" + 0.176*"number" + 0.151*"analysis" + -0.149*"parameter" + '
#   '0.145*"topic" + -0.144*"regret"'),
#  (31,
#   '-0.369*"sample" + -0.288*"variable" + -0.266*"training" + 0.226*"label" + '
#   '-0.204*"clustering" + -0.196*"latent" + -0.195*"loss" + 0.192*"number" + '
#   '0.185*"distribution" + 0.174*"sparse"'),
#  (32,
#   '0.448*"set" + -0.310*"using" + 0.188*"class" + -0.180*"process" + '
#   '-0.167*"sparse" + -0.163*"bound" + 0.157*"kernel" + 0.155*"result" + '
#   '-0.148*"performance" + 0.143*"parameter"'),
#  (33,
#   '0.278*"label" + -0.265*"number" + -0.220*"using" + -0.212*"loss" + '
#   '0.198*"error" + -0.175*"information" + 0.171*"classification" + '
#   '0.168*"based" + -0.166*"regret" + 0.165*"show"'),
#  (34,
#   '-0.287*"process" + -0.282*"training" + -0.254*"set" + 0.227*"state" + '
#   '-0.188*"optimization" + 0.177*"estimator" + 0.176*"information" + '
#   '-0.172*"performance" + 0.164*"label" + -0.151*"object"'),
#  (35,
#   '0.309*"using" + -0.278*"performance" + -0.264*"variable" + 0.247*"result" + '
#   '0.235*"set" + -0.213*"policy" + -0.196*"parameter" + 0.183*"space" + '
#   '0.174*"rate" + -0.149*"loss"'),
#  (36,
#   '0.316*"process" + -0.275*"using" + 0.251*"rate" + 0.241*"number" + '
#   '-0.227*"parameter" + -0.218*"set" + -0.189*"gradient" + -0.169*"structure" '
#   '+ 0.167*"show" + 0.163*"sample"'),
#  (37,
#   '-0.507*"framework" + -0.229*"domain" + 0.204*"state" + -0.190*"using" + '
#   '-0.169*"label" + 0.169*"information" + 0.168*"result" + 0.167*"performance" '
#   '+ 0.166*"loss" + -0.164*"structure"'),
#  (38,
#   '0.282*"using" + -0.250*"set" + 0.247*"class" + -0.192*"loss" + '
#   '0.187*"estimator" + -0.181*"domain" + 0.168*"parameter" + -0.154*"paper" + '
#   '0.148*"result" + 0.147*"rate"'),
#  (39,
#   '-0.295*"structure" + 0.287*"parameter" + 0.263*"state" + -0.208*"gradient" '
#   '+ -0.196*"result" + 0.193*"framework" + -0.191*"tree" + '
#   '0.184*"optimization" + 0.173*"based" + -0.160*"sample"'),
#  (40,
#   '-0.278*"variable" + -0.250*"linear" + 0.243*"structure" + 0.215*"parameter" '
#   '+ -0.197*"using" + 0.193*"neural" + 0.192*"tree" + -0.161*"policy" + '
#   '0.160*"show" + -0.151*"latent"'),
#  (41,
#   '0.282*"result" + 0.266*"number" + -0.266*"space" + 0.260*"using" + '
#   '-0.210*"representation" + -0.191*"estimator" + 0.182*"variable" + '
#   '-0.157*"sparse" + 0.150*"new" + 0.141*"parameter"'),
#  (42,
#   '0.333*"analysis" + 0.300*"process" + -0.228*"sparse" + -0.176*"optimal" + '
#   '-0.170*"clustering" + -0.166*"optimization" + -0.162*"rate" + '
#   '-0.146*"bayesian" + -0.144*"human" + -0.140*"kernel"'),
#  (43,
#   '0.290*"information" + -0.276*"rate" + 0.258*"linear" + 0.213*"result" + '
#   '0.181*"object" + 0.174*"framework" + 0.162*"state" + 0.158*"gradient" + '
#   '-0.147*"word" + -0.147*"analysis"'),
#  (44,
#   '0.359*"domain" + -0.260*"sample" + 0.189*"time" + -0.184*"framework" + '
#   '0.174*"information" + 0.173*"structure" + 0.159*"rate" + -0.159*"linear" + '
#   '-0.155*"number" + -0.153*"system"'),
#  (45,
#   '0.320*"optimization" + 0.272*"class" + 0.225*"policy" + -0.220*"result" + '
#   '0.215*"using" + 0.211*"new" + 0.157*"loss" + 0.155*"convex" + '
#   '-0.142*"proposed" + -0.135*"parameter"'),
#  (46,
#   '0.285*"tree" + 0.216*"linear" + 0.211*"new" + -0.190*"result" + '
#   '-0.185*"policy" + -0.184*"label" + -0.176*"parameter" + 0.166*"state" + '
#   '-0.164*"sample" + -0.158*"set"'),
#  (47,
#   '-0.258*"state" + -0.246*"class" + 0.203*"policy" + 0.201*"number" + '
#   '-0.174*"representation" + -0.172*"human" + 0.168*"metric" + 0.166*"space" + '
#   '-0.159*"system" + 0.148*"structure"'),
#  (48,
#   '0.459*"new" + -0.326*"optimization" + -0.246*"domain" + -0.185*"random" + '
#   '0.154*"policy" + 0.153*"gradient" + 0.139*"rate" + 0.135*"sparse" + '
#   '0.127*"error" + 0.119*"based"'),
#  (49,
#   '-0.289*"parameter" + -0.278*"linear" + 0.225*"estimator" + '
#   '0.205*"performance" + -0.191*"human" + -0.178*"representation" + '
#   '0.165*"set" + -0.162*"class" + -0.153*"decision" + 0.139*"propose"'),
#  (50,
#   '0.250*"based" + -0.234*"framework" + 0.225*"new" + 0.214*"estimator" + '
#   '-0.180*"rate" + -0.178*"convergence" + -0.174*"performance" + '
#   '0.172*"optimization" + -0.166*"parameter" + -0.165*"structure"'),
#  (51,
#   '0.353*"estimator" + -0.259*"performance" + -0.209*"state" + -0.185*"metric" '
#   '+ 0.180*"policy" + 0.151*"neural" + -0.145*"two" + -0.135*"sample" + '
#   '-0.132*"sparse" + -0.130*"regression"'),
#  (52,
#   '0.340*"label" + 0.299*"new" + -0.243*"training" + -0.207*"framework" + '
#   '-0.195*"tree" + 0.190*"linear" + 0.189*"deep" + -0.183*"decision" + '
#   '-0.165*"topic" + -0.141*"class"'),
#  (53,
#   '0.255*"performance" + -0.194*"prediction" + -0.192*"decision" + '
#   '-0.183*"deep" + -0.178*"representation" + 0.162*"linear" + 0.162*"system" + '
#   '-0.160*"game" + 0.148*"two" + 0.145*"domain"'),
#  (54,
#   '-0.288*"class" + 0.249*"bayesian" + 0.211*"regression" + 0.187*"two" + '
#   '-0.184*"propose" + -0.161*"point" + 0.154*"optimization" + 0.150*"state" + '
#   '-0.148*"parameter" + 0.138*"linear"'),
#  (55,
#   '0.284*"space" + -0.242*"linear" + 0.215*"new" + -0.194*"propose" + '
#   '0.173*"representation" + 0.167*"domain" + -0.160*"analysis" + '
#   '0.158*"system" + -0.132*"training" + -0.127*"state"'),
#  (56,
#   '0.185*"regression" + -0.172*"training" + -0.171*"sparse" + '
#   '-0.170*"analysis" + 0.168*"set" + -0.158*"system" + -0.155*"prediction" + '
#   '0.151*"human" + 0.150*"representation" + -0.146*"inference"'),
#  (57,
#   '-0.298*"two" + 0.269*"analysis" + -0.261*"approximation" + -0.197*"sparse" '
#   '+ 0.179*"set" + -0.172*"regression" + 0.170*"estimator" + '
#   '0.164*"performance" + -0.160*"also" + -0.142*"study"'),
#  (58,
#   '0.238*"tree" + 0.233*"based" + -0.208*"training" + -0.207*"prediction" + '
#   '-0.207*"space" + 0.204*"random" + 0.162*"performance" + -0.154*"metric" + '
#   '-0.153*"human" + -0.147*"framework"'),
#  (59,
#   '-0.290*"error" + -0.277*"approximation" + -0.268*"structure" + '
#   '0.161*"proposed" + 0.138*"prediction" + -0.135*"sampling" + '
#   '0.133*"parameter" + -0.132*"based" + 0.130*"vector" + '
#   '-0.129*"representation"'),
#  (60,
#   '-0.374*"sampling" + 0.338*"two" + -0.192*"propose" + -0.186*"regression" + '
#   '0.168*"game" + -0.155*"training" + -0.155*"new" + 0.141*"framework" + '
#   '-0.138*"topic" + 0.127*"approximation"'),
#  (61,
#   '0.253*"error" + 0.199*"prediction" + -0.198*"training" + 0.190*"input" + '
#   '-0.183*"human" + 0.174*"sampling" + 0.144*"two" + -0.142*"optimal" + '
#   '0.140*"sample" + 0.137*"classifier"'),
#  (62,
#   '-0.258*"space" + -0.221*"sampling" + 0.177*"online" + -0.172*"two" + '
#   '-0.171*"training" + 0.170*"regression" + -0.164*"signal" + '
#   '-0.162*"bayesian" + 0.153*"large" + -0.146*"based"'),
#  (63,
#   '0.271*"random" + 0.183*"structure" + -0.183*"metric" + -0.169*"game" + '
#   '0.168*"test" + -0.159*"proposed" + -0.149*"based" + 0.142*"framework" + '
#   '-0.140*"sampling" + -0.138*"approximation"'),
#  (64,
#   '-0.256*"based" + 0.246*"game" + -0.230*"two" + -0.211*"representation" + '
#   '0.197*"used" + 0.191*"also" + 0.168*"neural" + 0.159*"paper" + '
#   '0.153*"bayesian" + 0.150*"classifier"'),
#  (65,
#   '-0.364*"based" + -0.265*"regression" + -0.213*"game" + 0.200*"optimal" + '
#   '0.178*"proposed" + -0.174*"space" + 0.174*"new" + 0.150*"estimator" + '
#   '-0.149*"neural" + 0.147*"approximation"'),
#  (66,
#   '0.290*"prediction" + 0.194*"neural" + -0.185*"noise" + 0.179*"point" + '
#   '0.175*"class" + -0.169*"user" + 0.166*"proposed" + 0.156*"sequence" + '
#   '-0.134*"tree" + -0.131*"system"'),
#  (67,
#   '-0.260*"random" + -0.258*"game" + -0.206*"large" + 0.173*"deep" + '
#   '-0.170*"local" + 0.160*"number" + 0.147*"propose" + 0.144*"prediction" + '
#   '-0.139*"label" + -0.138*"sampling"'),
#  (68,
#   '-0.235*"test" + -0.232*"application" + 0.184*"local" + -0.179*"many" + '
#   '-0.163*"game" + -0.150*"based" + -0.142*"bayesian" + 0.139*"proposed" + '
#   '0.136*"error" + 0.135*"query"'),
#  (69,
#   '0.276*"also" + -0.234*"regression" + -0.204*"optimal" + 0.179*"dynamic" + '
#   '-0.164*"paper" + -0.162*"complexity" + 0.151*"propose" + 0.148*"tree" + '
#   '0.139*"prior" + 0.131*"bayesian"'),
#  (70,
#   '-0.276*"space" + 0.262*"metric" + 0.199*"based" + 0.175*"sampling" + '
#   '-0.175*"propose" + -0.163*"test" + -0.151*"class" + -0.147*"system" + '
#   '0.138*"classification" + -0.137*"component"'),
#  (71,
#   '0.352*"proposed" + -0.259*"point" + -0.239*"optimal" + '
#   '0.215*"approximation" + 0.174*"error" + -0.168*"prediction" + '
#   '0.151*"signal" + -0.144*"sparse" + 0.143*"memory" + -0.137*"one"'),
#  (72,
#   '-0.301*"test" + -0.254*"representation" + -0.226*"also" + '
#   '-0.195*"regression" + 0.170*"space" + 0.167*"paper" + 0.163*"human" + '
#   '0.151*"latent" + 0.150*"sparse" + -0.142*"structure"'),
#  (73,
#   '-0.233*"memory" + 0.219*"efficient" + 0.198*"prediction" + 0.195*"random" + '
#   '-0.180*"setting" + -0.179*"one" + 0.174*"prior" + -0.162*"classification" + '
#   '-0.141*"machine" + 0.139*"noise"'),
#  (74,
#   '0.185*"test" + -0.183*"action" + 0.178*"present" + 0.171*"sampling" + '
#   '0.155*"probability" + 0.151*"latent" + 0.150*"representation" + '
#   '-0.146*"sample" + 0.145*"stochastic" + -0.144*"framework"'),
#  (75,
#   '-0.212*"input" + -0.205*"noise" + -0.173*"norm" + 0.151*"large" + '
#   '-0.149*"action" + -0.141*"local" + -0.138*"convex" + 0.137*"item" + '
#   '-0.136*"present" + 0.135*"prediction"'),
#  (76,
#   '-0.195*"point" + 0.193*"deep" + 0.190*"case" + 0.177*"metric" + '
#   '0.173*"dynamic" + -0.168*"representation" + -0.159*"rule" + -0.146*"signal" '
#   '+ -0.144*"also" + 0.126*"system"'),
#  (77,
#   '0.237*"game" + -0.197*"neural" + -0.178*"action" + -0.159*"test" + '
#   '-0.157*"analysis" + 0.151*"estimator" + -0.148*"system" + 0.148*"dynamic" + '
#   '-0.139*"estimation" + 0.139*"study"'),
#  (78,
#   '-0.248*"dynamic" + -0.221*"local" + -0.206*"vector" + 0.191*"test" + '
#   '0.185*"also" + -0.165*"norm" + -0.147*"study" + 0.143*"online" + '
#   '-0.142*"two" + 0.142*"user"'),
#  (79,
#   '-0.253*"signal" + -0.203*"prediction" + 0.181*"norm" + 0.170*"one" + '
#   '0.158*"also" + 0.155*"class" + 0.142*"estimation" + 0.138*"different" + '
#   '-0.137*"classifier" + -0.134*"noise"'),
#  (80,
#   '0.253*"local" + -0.253*"optimal" + -0.217*"propose" + 0.171*"paper" + '
#   '0.166*"test" + -0.160*"norm" + -0.151*"estimate" + -0.145*"large" + '
#   '-0.143*"analysis" + 0.129*"error"'),
#  (81,
#   '-0.257*"metric" + 0.209*"present" + 0.181*"classifier" + -0.170*"error" + '
#   '-0.158*"norm" + 0.153*"prior" + -0.133*"tree" + 0.133*"random" + '
#   '0.131*"datasets" + -0.127*"sampling"'),
#  (82,
#   '0.200*"representation" + -0.187*"also" + 0.179*"bayesian" + 0.160*"signal" '
#   '+ -0.158*"decision" + 0.156*"paper" + -0.151*"estimator" + 0.149*"one" + '
#   '0.144*"estimation" + 0.135*"novel"'),
#  (83,
#   '-0.301*"prior" + 0.280*"also" + 0.237*"paper" + -0.235*"work" + '
#   '-0.175*"norm" + 0.169*"estimation" + -0.161*"point" + 0.147*"gaussian" + '
#   '-0.136*"test" + 0.125*"random"'),
#  (84,
#   '0.238*"variable" + -0.228*"latent" + -0.206*"probability" + '
#   '-0.175*"sampling" + -0.171*"different" + 0.164*"error" + -0.159*"point" + '
#   '0.153*"regret" + 0.151*"test" + -0.139*"proposed"'),
#  (85,
#   '-0.224*"online" + -0.174*"paper" + -0.159*"sequence" + 0.150*"prediction" + '
#   '-0.148*"input" + 0.147*"novel" + 0.147*"decision" + -0.147*"complexity" + '
#   '-0.146*"test" + -0.142*"different"'),
#  (86,
#   '0.202*"also" + -0.197*"setting" + 0.166*"case" + -0.163*"first" + '
#   '-0.162*"online" + -0.154*"memory" + -0.152*"constraint" + '
#   '-0.149*"efficient" + 0.143*"regret" + 0.139*"space"'),
#  (87,
#   '-0.267*"large" + 0.239*"used" + -0.197*"memory" + -0.179*"visual" + '
#   '0.178*"number" + 0.139*"online" + 0.132*"optimal" + 0.126*"classification" '
#   '+ 0.125*"technique" + 0.121*"different"'),
#  (88,
#   '0.206*"work" + -0.187*"efficient" + -0.171*"vector" + 0.160*"space" + '
#   '-0.159*"bayesian" + 0.153*"test" + -0.148*"cost" + 0.146*"deep" + '
#   '-0.144*"computational" + 0.142*"variational"'),
#  (89,
#   '0.206*"estimate" + 0.197*"visual" + 0.187*"deep" + 0.169*"natural" + '
#   '-0.158*"action" + -0.154*"solution" + 0.149*"estimation" + 0.146*"response" '
#   '+ -0.144*"estimator" + -0.134*"regularization"'),
#  (90,
#   '-0.288*"point" + 0.184*"propose" + -0.182*"also" + 0.167*"decision" + '
#   '-0.161*"tree" + 0.153*"noise" + -0.146*"technique" + '
#   '-0.137*"classification" + -0.134*"one" + -0.131*"selection"'),
#  (91,
#   '-0.232*"sampling" + 0.230*"random" + -0.224*"setting" + -0.172*"used" + '
#   '0.161*"complexity" + -0.132*"test" + 0.126*"present" + -0.121*"signal" + '
#   '-0.121*"vector" + 0.119*"also"'),
#  (92,
#   '-0.274*"probability" + 0.206*"point" + 0.205*"noise" + 0.202*"visual" + '
#   '0.189*"online" + -0.147*"memory" + -0.135*"prior" + 0.129*"state" + '
#   '0.115*"value" + 0.115*"experiment"'),
#  (93,
#   '0.220*"signal" + 0.219*"used" + 0.201*"also" + -0.195*"proposed" + '
#   '-0.169*"query" + 0.146*"complexity" + -0.140*"classifier" + -0.129*"norm" + '
#   '0.126*"noise" + -0.120*"field"'),
#  (94,
#   '-0.202*"provide" + 0.193*"large" + -0.172*"local" + 0.156*"natural" + '
#   '0.155*"classifier" + -0.149*"setting" + -0.142*"similarity" + '
#   '-0.138*"search" + 0.138*"selection" + 0.134*"human"'),
#  (95,
#   '0.244*"system" + 0.219*"provide" + -0.202*"dynamic" + 0.182*"approximation" '
#   '+ 0.143*"present" + -0.138*"ranking" + 0.130*"experiment" + -0.128*"latent" '
#   '+ -0.127*"sampling" + -0.127*"one"'),
#  (96,
#   '-0.255*"component" + 0.223*"random" + -0.197*"human" + -0.160*"present" + '
#   '-0.154*"probability" + 0.145*"optimal" + 0.137*"memory" + -0.130*"learn" + '
#   '0.126*"objective" + 0.114*"using"'),
#  (97,
#   '0.252*"signal" + -0.199*"noise" + -0.174*"constraint" + -0.170*"solution" + '
#   '-0.168*"used" + 0.157*"optimal" + -0.144*"visual" + -0.137*"convergence" + '
#   '0.136*"one" + -0.130*"regularization"'),
#  (98,
#   '0.190*"vector" + -0.187*"experiment" + 0.165*"paper" + -0.150*"stochastic" '
#   '+ 0.142*"memory" + -0.136*"point" + -0.135*"estimation" + 0.132*"online" + '
#   '-0.130*"linear" + 0.130*"novel"'),
#  (99,
#   '0.248*"one" + 0.175*"different" + 0.174*"case" + -0.169*"machine" + '
#   '-0.163*"work" + -0.155*"example" + -0.144*"sequence" + 0.142*"component" + '
#   '-0.141*"brain" + 0.139*"classification"')]

# %% [markdown]
# # Evaluation

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.



coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)


coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='u_mass')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)
# Out:
# Coherence Score:  0.8272689835812015
#
# Coherence Score5:  0.4150147884719485
#
# Coherence Score10:  0.34793001153492564
#
# Coherence Score20:  0.3299190683998402
#
# Coherence Score50:  0.264131192118135
#
# Coherence Score100:  0.23139146045818534
#
# Coherence Score:  -20.754273019198575
#
# Coherence Score5:  -1.9918806938044882
#
# Coherence Score10:  -2.1609728979672216
#
# Coherence Score20:  -2.1586240466793947
#
# Coherence Score50:  -2.352320512322162
#
# Coherence Score100:  -2.4737777918466635
