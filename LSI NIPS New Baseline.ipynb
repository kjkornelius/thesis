# %% [markdown]
# # load packages

# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess, lemmatize
from gensim.models import CoherenceModel
from gensim.models import LdaModel, LdaMulticore
import gensim.downloader as api
from gensim.models import LsiModel

nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools 
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
#import logging
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
#logging.root.setLevel(level=logging.INFO)
#import warnings
#warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_csv('C:/Users/Kornelius/Desktop/Data 2/nips-papers/papers.csv', header = 0, sep = ';', error_bad_lines=False)
# Drop the columns not needed
df = df.drop(columns=['id', 'event_type', 'pdf_name'], axis=1)

# %%
# Drop a row by condition
df = df[df.abstract != 'Abstract Missing']

# %%
data = df.abstract.values.tolist()

# %% [markdown]
# # Pre-processing (Baseline)

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(data):
    stop_free = " ".join([i for i in data.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(data).split() for data in data]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(16129 unique tokens: ['activity', 'also', 'analysis', 'applied', 'assume']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# # LSI

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.234*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.234*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.102*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '-0.519*"algorithm" + -0.391*"model" + 0.334*"learning" + 0.327*"network" + '
#   '0.296*"method" + 0.165*"image" + 0.155*"task" + 0.143*"feature" + '
#   '0.125*"deep" + 0.124*"neural"'),
#  (3,
#   '0.573*"method" + -0.439*"learning" + -0.360*"network" + -0.292*"algorithm" '
#   '+ 0.254*"data" + 0.121*"matrix" + 0.103*"problem" + -0.100*"neural" + '
#   '-0.098*"deep" + -0.087*"task"'),
#  (4,
#   '-0.587*"network" + 0.579*"learning" + 0.267*"data" + -0.218*"neural" + '
#   '-0.104*"method" + -0.103*"algorithm" + 0.081*"task" + -0.079*"deep" + '
#   '0.076*"approach" + -0.074*"image"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.234*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '0.728*"model" + -0.434*"algorithm" + -0.240*"problem" + -0.134*"function" + '
#   '-0.114*"learning" + 0.108*"network" + 0.102*"image" + -0.090*"bound" + '
#   '0.086*"neural" + -0.079*"method"'),
#  (2,
#   '0.519*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.327*"network" + '
#   '-0.296*"method" + -0.165*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.123*"neural"'),
#  (3,
#   '-0.574*"method" + 0.439*"learning" + 0.360*"network" + 0.292*"algorithm" + '
#   '-0.254*"data" + -0.121*"matrix" + -0.104*"problem" + 0.100*"neural" + '
#   '0.099*"deep" + 0.087*"task"'),
#  (4,
#   '-0.587*"network" + 0.579*"learning" + 0.267*"data" + -0.218*"neural" + '
#   '-0.104*"method" + -0.103*"algorithm" + 0.081*"task" + -0.078*"deep" + '
#   '0.075*"approach" + -0.074*"image"'),
#  (5,
#   '-0.681*"data" + 0.315*"function" + -0.261*"algorithm" + 0.201*"model" + '
#   '0.195*"problem" + 0.184*"learning" + 0.162*"method" + -0.139*"network" + '
#   '0.112*"optimization" + -0.112*"feature"'),
#  (6,
#   '-0.523*"image" + 0.326*"data" + 0.270*"function" + 0.251*"network" + '
#   '-0.243*"algorithm" + -0.236*"feature" + -0.234*"object" + -0.219*"method" + '
#   '0.184*"distribution" + 0.118*"bound"'),
#  (7,
#   '0.482*"method" + -0.423*"problem" + 0.320*"algorithm" + -0.290*"image" + '
#   '0.224*"learning" + -0.125*"object" + 0.125*"inference" + 0.123*"gradient" + '
#   '-0.121*"matrix" + -0.113*"distribution"'),
#  (8,
#   '-0.567*"problem" + 0.529*"function" + 0.211*"image" + 0.190*"feature" + '
#   '-0.185*"matrix" + -0.170*"learning" + 0.167*"distribution" + '
#   '-0.145*"network" + 0.127*"bound" + 0.096*"loss"'),
#  (9,
#   '-0.500*"function" + 0.346*"distribution" + 0.271*"bound" + -0.258*"data" + '
#   '-0.250*"problem" + 0.206*"matrix" + 0.194*"sample" + -0.130*"optimization" '
#   '+ 0.104*"show" + 0.102*"complexity"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.234*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.102*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '-0.519*"algorithm" + -0.391*"model" + 0.334*"learning" + 0.327*"network" + '
#   '0.296*"method" + 0.165*"image" + 0.155*"task" + 0.143*"feature" + '
#   '0.125*"deep" + 0.124*"neural"'),
#  (3,
#   '-0.574*"method" + 0.439*"learning" + 0.360*"network" + 0.292*"algorithm" + '
#   '-0.254*"data" + -0.121*"matrix" + -0.103*"problem" + 0.100*"neural" + '
#   '0.099*"deep" + 0.087*"task"'),
#  (4,
#   '0.587*"network" + -0.579*"learning" + -0.266*"data" + 0.218*"neural" + '
#   '0.104*"method" + 0.103*"algorithm" + -0.081*"task" + 0.079*"deep" + '
#   '-0.076*"approach" + 0.075*"image"'),
#  (5,
#   '-0.681*"data" + 0.316*"function" + -0.262*"algorithm" + 0.201*"model" + '
#   '0.196*"problem" + 0.184*"learning" + 0.162*"method" + -0.139*"network" + '
#   '0.114*"optimization" + -0.111*"feature"'),
#  (6,
#   '-0.522*"image" + 0.326*"data" + 0.271*"function" + 0.251*"network" + '
#   '-0.243*"algorithm" + -0.236*"feature" + -0.233*"object" + -0.219*"method" + '
#   '0.184*"distribution" + 0.120*"bound"'),
#  (7,
#   '0.482*"method" + -0.424*"problem" + 0.320*"algorithm" + -0.290*"image" + '
#   '0.224*"learning" + -0.125*"object" + 0.125*"inference" + 0.124*"gradient" + '
#   '-0.120*"matrix" + -0.113*"distribution"'),
#  (8,
#   '0.568*"problem" + -0.529*"function" + -0.212*"image" + -0.190*"feature" + '
#   '0.184*"matrix" + 0.170*"learning" + -0.166*"distribution" + 0.144*"network" '
#   '+ -0.126*"bound" + -0.096*"loss"'),
#  (9,
#   '-0.500*"function" + 0.349*"distribution" + 0.270*"bound" + -0.257*"data" + '
#   '-0.251*"problem" + 0.205*"matrix" + 0.196*"sample" + -0.128*"optimization" '
#   '+ 0.106*"show" + 0.104*"complexity"'),
#  (10,
#   '0.446*"feature" + 0.379*"matrix" + -0.369*"distribution" + '
#   '-0.276*"approach" + -0.245*"inference" + -0.201*"image" + 0.185*"kernel" + '
#   '0.131*"model" + -0.125*"problem" + 0.109*"function"'),
#  (11,
#   '0.405*"feature" + 0.325*"kernel" + 0.296*"approach" + -0.272*"bound" + '
#   '0.242*"inference" + -0.222*"image" + 0.195*"distribution" + -0.183*"data" + '
#   '-0.158*"loss" + 0.139*"graph"'),
#  (12,
#   '-0.282*"graph" + -0.274*"image" + 0.259*"task" + -0.231*"distribution" + '
#   '-0.220*"matrix" + 0.212*"time" + 0.191*"policy" + 0.174*"information" + '
#   '-0.168*"kernel" + 0.167*"feature"'),
#  (13,
#   '0.508*"matrix" + -0.384*"feature" + 0.277*"approach" + -0.237*"graph" + '
#   '-0.177*"bound" + 0.158*"image" + -0.156*"problem" + -0.147*"method" + '
#   '-0.134*"distribution" + 0.123*"neural"'),
#  (14,
#   '0.511*"graph" + -0.366*"distribution" + -0.311*"feature" + 0.236*"approach" '
#   '+ -0.181*"problem" + 0.168*"kernel" + 0.157*"bound" + 0.152*"clustering" + '
#   '-0.149*"gradient" + 0.143*"time"'),
#  (15,
#   '-0.408*"approach" + -0.390*"bound" + 0.279*"distribution" + 0.279*"graph" + '
#   '-0.210*"inference" + -0.157*"feature" + 0.152*"task" + 0.140*"clustering" + '
#   '0.125*"method" + 0.119*"neuron"'),
#  (16,
#   '-0.453*"kernel" + 0.372*"task" + 0.271*"matrix" + -0.199*"image" + '
#   '-0.192*"gradient" + 0.186*"function" + -0.178*"rate" + 0.156*"approach" + '
#   '-0.141*"stochastic" + -0.126*"convergence"'),
#  (17,
#   '-0.345*"task" + -0.269*"gradient" + 0.239*"bound" + 0.224*"inference" + '
#   '-0.196*"training" + 0.190*"image" + 0.182*"method" + -0.164*"kernel" + '
#   '0.151*"learning" + -0.146*"performance"'),
#  (18,
#   '-0.505*"kernel" + 0.360*"approach" + -0.311*"task" + 0.202*"graph" + '
#   '0.183*"feature" + 0.161*"sparse" + -0.145*"inference" + '
#   '-0.139*"classification" + -0.132*"process" + 0.113*"gradient"'),
#  (19,
#   '0.298*"gradient" + -0.272*"loss" + 0.236*"policy" + 0.227*"matrix" + '
#   '-0.209*"neural" + 0.208*"stochastic" + -0.176*"classification" + '
#   '-0.162*"linear" + 0.159*"time" + -0.155*"approach"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.234*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '0.728*"model" + -0.434*"algorithm" + -0.240*"problem" + -0.134*"function" + '
#   '-0.114*"learning" + 0.108*"network" + 0.102*"image" + -0.090*"bound" + '
#   '0.086*"neural" + -0.079*"method"'),
#  (2,
#   '0.519*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.327*"network" + '
#   '-0.296*"method" + -0.165*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.123*"neural"'),
#  (3,
#   '0.574*"method" + -0.439*"learning" + -0.360*"network" + -0.292*"algorithm" '
#   '+ 0.254*"data" + 0.121*"matrix" + 0.103*"problem" + -0.100*"neural" + '
#   '-0.099*"deep" + -0.087*"task"'),
#  (4,
#   '0.587*"network" + -0.579*"learning" + -0.267*"data" + 0.218*"neural" + '
#   '0.104*"method" + 0.103*"algorithm" + -0.081*"task" + 0.079*"deep" + '
#   '-0.075*"approach" + 0.074*"image"'),
#  (5,
#   '-0.681*"data" + 0.315*"function" + -0.262*"algorithm" + 0.201*"model" + '
#   '0.196*"problem" + 0.184*"learning" + 0.162*"method" + -0.140*"network" + '
#   '0.114*"optimization" + -0.112*"feature"'),
#  (6,
#   '-0.522*"image" + 0.326*"data" + 0.270*"function" + 0.251*"network" + '
#   '-0.243*"algorithm" + -0.236*"feature" + -0.233*"object" + -0.219*"method" + '
#   '0.184*"distribution" + 0.119*"bound"'),
#  (7,
#   '-0.482*"method" + 0.423*"problem" + -0.320*"algorithm" + 0.290*"image" + '
#   '-0.225*"learning" + 0.125*"object" + -0.124*"inference" + -0.123*"gradient" '
#   '+ 0.121*"matrix" + 0.113*"distribution"'),
#  (8,
#   '-0.568*"problem" + 0.529*"function" + 0.211*"image" + 0.190*"feature" + '
#   '-0.184*"matrix" + -0.170*"learning" + 0.167*"distribution" + '
#   '-0.145*"network" + 0.126*"bound" + 0.095*"loss"'),
#  (9,
#   '-0.500*"function" + 0.350*"distribution" + 0.270*"bound" + -0.257*"data" + '
#   '-0.250*"problem" + 0.205*"matrix" + 0.195*"sample" + -0.128*"optimization" '
#   '+ 0.104*"show" + 0.103*"complexity"'),
#  (10,
#   '-0.447*"feature" + -0.379*"matrix" + 0.368*"distribution" + '
#   '0.276*"approach" + 0.244*"inference" + 0.202*"image" + -0.185*"kernel" + '
#   '-0.131*"model" + 0.126*"problem" + -0.110*"function"'),
#  (11,
#   '0.404*"feature" + 0.322*"kernel" + 0.298*"approach" + -0.273*"bound" + '
#   '0.239*"inference" + -0.222*"image" + 0.196*"distribution" + -0.183*"data" + '
#   '-0.163*"loss" + 0.141*"graph"'),
#  (12,
#   '0.282*"graph" + 0.273*"image" + -0.258*"task" + 0.229*"distribution" + '
#   '0.222*"matrix" + -0.210*"time" + -0.191*"policy" + -0.172*"information" + '
#   '-0.171*"feature" + 0.165*"kernel"'),
#  (13,
#   '0.508*"matrix" + -0.385*"feature" + 0.277*"approach" + -0.242*"graph" + '
#   '-0.174*"bound" + 0.159*"image" + -0.155*"problem" + -0.146*"method" + '
#   '-0.135*"distribution" + 0.123*"neural"'),
#  (14,
#   '-0.507*"graph" + 0.367*"distribution" + 0.313*"feature" + -0.234*"approach" '
#   '+ 0.182*"problem" + -0.168*"kernel" + -0.160*"bound" + -0.154*"clustering" '
#   '+ 0.148*"gradient" + -0.144*"time"'),
#  (15,
#   '0.403*"approach" + 0.396*"bound" + -0.282*"graph" + -0.277*"distribution" + '
#   '0.215*"inference" + -0.159*"task" + 0.159*"feature" + -0.147*"clustering" + '
#   '-0.120*"method" + -0.117*"neuron"'),
#  (16,
#   '0.456*"kernel" + -0.366*"task" + -0.277*"matrix" + 0.199*"image" + '
#   '0.197*"gradient" + -0.191*"function" + 0.175*"rate" + -0.155*"approach" + '
#   '0.146*"stochastic" + 0.125*"convergence"'),
#  (17,
#   '-0.341*"task" + -0.275*"gradient" + 0.234*"bound" + 0.226*"inference" + '
#   '-0.190*"training" + 0.188*"image" + 0.187*"method" + 0.149*"learning" + '
#   '-0.143*"convergence" + -0.142*"stochastic"'),
#  (18,
#   '-0.512*"kernel" + 0.354*"approach" + -0.315*"task" + 0.209*"graph" + '
#   '0.194*"feature" + 0.152*"sparse" + -0.138*"inference" + '
#   '-0.136*"classification" + -0.122*"process" + 0.112*"gradient"'),
#  (19,
#   '0.290*"gradient" + -0.251*"loss" + 0.235*"policy" + 0.233*"matrix" + '
#   '-0.206*"neural" + 0.200*"stochastic" + -0.175*"approach" + '
#   '-0.173*"classification" + -0.173*"linear" + 0.167*"time"'),
#  (20,
#   '0.502*"inference" + -0.277*"approach" + -0.212*"policy" + -0.198*"kernel" + '
#   '0.178*"graph" + 0.163*"show" + -0.161*"distribution" + 0.143*"task" + '
#   '0.138*"variational" + 0.135*"loss"'),
#  (21,
#   '-0.397*"task" + -0.343*"bound" + 0.321*"time" + 0.231*"show" + '
#   '0.224*"label" + 0.193*"loss" + 0.185*"training" + -0.150*"structure" + '
#   '0.135*"classification" + 0.128*"class"'),
#  (22,
#   '-0.362*"clustering" + 0.262*"time" + 0.223*"sparse" + -0.222*"information" '
#   '+ 0.177*"task" + 0.175*"parameter" + 0.173*"image" + 0.173*"regression" + '
#   '-0.162*"approach" + -0.161*"matrix"'),
#  (23,
#   '0.427*"clustering" + -0.328*"graph" + 0.253*"show" + -0.184*"information" + '
#   '-0.183*"gradient" + -0.176*"time" + 0.163*"result" + 0.159*"cluster" + '
#   '-0.155*"loss" + 0.147*"set"'),
#  (24,
#   '-0.357*"result" + 0.275*"object" + -0.273*"policy" + 0.226*"number" + '
#   '0.201*"time" + 0.193*"sample" + -0.183*"show" + 0.177*"task" + '
#   '0.173*"parameter" + -0.154*"new"'),
#  (25,
#   '-0.308*"time" + -0.271*"object" + -0.231*"loss" + 0.199*"training" + '
#   '0.191*"neural" + 0.186*"show" + 0.179*"bound" + 0.178*"using" + '
#   '-0.172*"framework" + 0.172*"policy"'),
#  (26,
#   '-0.474*"object" + 0.374*"time" + 0.239*"clustering" + -0.210*"show" + '
#   '0.199*"result" + -0.197*"variable" + -0.155*"structure" + 0.153*"image" + '
#   '-0.134*"policy" + -0.120*"latent"'),
#  (27,
#   '-0.340*"show" + -0.317*"latent" + -0.237*"variable" + -0.223*"time" + '
#   '0.179*"loss" + -0.157*"topic" + 0.154*"process" + -0.149*"word" + '
#   '0.147*"label" + 0.144*"state"'),
#  (28,
#   '-0.407*"information" + -0.263*"process" + 0.261*"object" + -0.218*"label" + '
#   '-0.171*"set" + 0.164*"show" + 0.157*"task" + 0.149*"result" + '
#   '0.148*"domain" + 0.147*"graph"'),
#  (29,
#   '0.445*"information" + -0.282*"loss" + -0.243*"state" + -0.226*"number" + '
#   '-0.191*"clustering" + -0.157*"process" + 0.148*"sample" + -0.140*"gradient" '
#   '+ -0.139*"task" + -0.128*"latent"'),
#  (30,
#   '-0.448*"show" + -0.285*"loss" + 0.255*"result" + 0.190*"class" + '
#   '0.166*"latent" + 0.161*"number" + 0.155*"analysis" + -0.154*"parameter" + '
#   '-0.150*"regret" + 0.145*"topic"'),
#  (31,
#   '-0.364*"sample" + -0.287*"variable" + -0.275*"training" + 0.247*"label" + '
#   '-0.201*"loss" + 0.190*"distribution" + -0.188*"clustering" + '
#   '-0.185*"latent" + 0.177*"sparse" + -0.165*"result"'),
#  (32,
#   '0.440*"set" + -0.271*"using" + -0.198*"process" + -0.181*"bound" + '
#   '0.178*"kernel" + 0.170*"class" + 0.153*"parameter" + 0.144*"setting" + '
#   '0.135*"result" + -0.129*"performance"'),
#  (33,
#   '-0.270*"number" + -0.262*"using" + 0.253*"label" + -0.202*"loss" + '
#   '0.183*"error" + 0.169*"show" + -0.168*"information" + 0.162*"rate" + '
#   '0.155*"classifier" + 0.145*"classification"'),
#  (34,
#   '0.334*"process" + 0.289*"training" + 0.237*"set" + -0.225*"state" + '
#   '0.177*"optimization" + -0.172*"estimator" + -0.170*"gradient" + '
#   '-0.164*"label" + 0.162*"object" + -0.143*"information"'),
#  (35,
#   '-0.337*"using" + 0.300*"performance" + 0.255*"variable" + -0.213*"result" + '
#   '-0.209*"set" + -0.199*"space" + 0.191*"policy" + 0.178*"parameter" + '
#   '-0.166*"rate" + 0.155*"loss"'),
#  (36,
#   '0.264*"process" + 0.262*"number" + 0.245*"rate" + -0.241*"using" + '
#   '-0.241*"parameter" + -0.233*"set" + 0.189*"sample" + 0.171*"show" + '
#   '-0.160*"gradient" + 0.149*"information"'),
#  (37,
#   '-0.495*"framework" + -0.222*"domain" + 0.216*"state" + 0.192*"result" + '
#   '0.187*"information" + -0.176*"using" + -0.165*"label" + -0.157*"structure" '
#   '+ 0.138*"loss" + 0.136*"estimator"'),
#  (38,
#   '0.263*"using" + -0.259*"set" + 0.238*"class" + -0.188*"loss" + '
#   '0.170*"estimator" + -0.160*"representation" + 0.159*"parameter" + '
#   '0.159*"result" + -0.153*"domain" + -0.146*"paper"'),
#  (39,
#   '0.324*"structure" + -0.275*"parameter" + -0.252*"state" + 0.211*"gradient" '
#   '+ -0.195*"framework" + 0.190*"result" + 0.190*"tree" + '
#   '-0.177*"optimization" + 0.177*"sample" + -0.156*"based"'),
#  (40,
#   '-0.279*"variable" + -0.255*"linear" + 0.226*"parameter" + 0.222*"structure" '
#   '+ 0.176*"tree" + -0.173*"policy" + 0.170*"neural" + -0.170*"using" + '
#   '0.158*"new" + 0.158*"show"'),
#  (41,
#   '0.294*"result" + 0.263*"number" + -0.249*"space" + 0.248*"using" + '
#   '-0.221*"representation" + -0.216*"estimator" + 0.205*"variable" + '
#   '-0.136*"neural" + 0.130*"based" + -0.128*"sparse"'),
#  (42,
#   '0.318*"analysis" + 0.300*"process" + -0.236*"sparse" + -0.211*"rate" + '
#   '-0.197*"optimal" + -0.171*"clustering" + -0.148*"optimization" + '
#   '-0.140*"kernel" + -0.134*"bayesian" + 0.133*"gaussian"'),
#  (43,
#   '0.286*"rate" + -0.274*"linear" + -0.227*"framework" + 0.209*"using" + '
#   '-0.201*"result" + -0.185*"information" + 0.173*"analysis" + 0.161*"word" + '
#   '-0.152*"state" + 0.150*"two"'),
#  (44,
#   '0.365*"domain" + -0.279*"sample" + 0.246*"information" + 0.191*"time" + '
#   '0.166*"structure" + 0.165*"target" + 0.157*"parameter" + 0.152*"sparse" + '
#   '-0.146*"system" + 0.143*"bound"'),
#  (45,
#   '0.309*"class" + 0.289*"optimization" + 0.246*"new" + -0.229*"result" + '
#   '0.217*"policy" + 0.195*"using" + 0.161*"information" + -0.157*"propose" + '
#   '-0.143*"label" + -0.140*"proposed"'),
#  (46,
#   '0.291*"tree" + 0.236*"linear" + 0.210*"metric" + -0.185*"set" + 0.178*"new" '
#   '+ -0.176*"parameter" + -0.163*"representation" + -0.163*"label" + '
#   '0.160*"number" + -0.151*"policy"'),
#  (47,
#   '0.283*"state" + 0.262*"class" + -0.232*"policy" + -0.208*"optimization" + '
#   '-0.171*"space" + -0.155*"number" + 0.151*"system" + 0.142*"estimator" + '
#   '-0.136*"metric" + 0.135*"using"'),
#  (48,
#   '0.390*"new" + -0.263*"optimization" + -0.213*"random" + -0.190*"domain" + '
#   '0.180*"based" + 0.162*"error" + -0.160*"performance" + 0.155*"policy" + '
#   '0.141*"optimal" + -0.140*"space"'),
#  (49,
#   '0.276*"parameter" + 0.245*"linear" + -0.203*"set" + 0.202*"human" + '
#   '-0.198*"estimator" + -0.191*"new" + 0.175*"class" + 0.174*"representation" '
#   '+ 0.169*"optimization" + -0.156*"propose"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.234*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '0.728*"model" + -0.434*"algorithm" + -0.240*"problem" + -0.134*"function" + '
#   '-0.114*"learning" + 0.108*"network" + 0.102*"image" + -0.090*"bound" + '
#   '0.086*"neural" + -0.079*"method"'),
#  (2,
#   '0.519*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.327*"network" + '
#   '-0.296*"method" + -0.165*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.123*"neural"'),
#  (3,
#   '0.574*"method" + -0.439*"learning" + -0.360*"network" + -0.292*"algorithm" '
#   '+ 0.254*"data" + 0.121*"matrix" + 0.103*"problem" + -0.100*"neural" + '
#   '-0.099*"deep" + -0.087*"task"'),
#  (4,
#   '0.587*"network" + -0.579*"learning" + -0.267*"data" + 0.218*"neural" + '
#   '0.104*"method" + 0.103*"algorithm" + -0.081*"task" + 0.079*"deep" + '
#   '-0.075*"approach" + 0.074*"image"'),
#  (5,
#   '0.681*"data" + -0.315*"function" + 0.262*"algorithm" + -0.201*"model" + '
#   '-0.196*"problem" + -0.184*"learning" + -0.162*"method" + 0.139*"network" + '
#   '-0.114*"optimization" + 0.111*"feature"'),
#  (6,
#   '0.522*"image" + -0.326*"data" + -0.270*"function" + -0.251*"network" + '
#   '0.243*"algorithm" + 0.236*"feature" + 0.233*"object" + 0.219*"method" + '
#   '-0.184*"distribution" + -0.119*"bound"'),
#  (7,
#   '-0.482*"method" + 0.423*"problem" + -0.320*"algorithm" + 0.290*"image" + '
#   '-0.225*"learning" + 0.125*"object" + -0.125*"inference" + -0.123*"gradient" '
#   '+ 0.121*"matrix" + 0.113*"distribution"'),
#  (8,
#   '0.568*"problem" + -0.529*"function" + -0.211*"image" + -0.190*"feature" + '
#   '0.184*"matrix" + 0.170*"learning" + -0.167*"distribution" + 0.144*"network" '
#   '+ -0.126*"bound" + -0.095*"loss"'),
#  (9,
#   '0.499*"function" + -0.349*"distribution" + -0.270*"bound" + 0.258*"data" + '
#   '0.250*"problem" + -0.205*"matrix" + -0.195*"sample" + 0.130*"optimization" '
#   '+ -0.105*"show" + -0.104*"complexity"'),
#  (10,
#   '-0.446*"feature" + -0.379*"matrix" + 0.369*"distribution" + '
#   '0.276*"approach" + 0.244*"inference" + 0.201*"image" + -0.184*"kernel" + '
#   '-0.131*"model" + 0.125*"problem" + -0.110*"function"'),
#  (11,
#   '-0.404*"feature" + -0.323*"kernel" + -0.298*"approach" + 0.274*"bound" + '
#   '-0.239*"inference" + 0.223*"image" + -0.197*"distribution" + 0.183*"data" + '
#   '0.162*"loss" + -0.141*"graph"'),
#  (12,
#   '0.281*"graph" + 0.273*"image" + -0.258*"task" + 0.230*"distribution" + '
#   '0.222*"matrix" + -0.210*"time" + -0.191*"policy" + -0.172*"information" + '
#   '-0.171*"feature" + 0.165*"kernel"'),
#  (13,
#   '-0.508*"matrix" + 0.385*"feature" + -0.278*"approach" + 0.239*"graph" + '
#   '0.173*"bound" + -0.159*"image" + 0.156*"problem" + 0.147*"method" + '
#   '0.138*"distribution" + -0.122*"neural"'),
#  (14,
#   '0.509*"graph" + -0.367*"distribution" + -0.311*"feature" + 0.233*"approach" '
#   '+ -0.181*"problem" + 0.167*"kernel" + 0.160*"bound" + 0.155*"clustering" + '
#   '-0.148*"gradient" + 0.144*"time"'),
#  (15,
#   '-0.405*"approach" + -0.395*"bound" + 0.283*"graph" + 0.278*"distribution" + '
#   '-0.217*"inference" + -0.160*"feature" + 0.159*"task" + 0.146*"clustering" + '
#   '0.119*"method" + 0.117*"information"'),
#  (16,
#   '0.459*"kernel" + -0.366*"task" + -0.277*"matrix" + 0.199*"image" + '
#   '0.195*"gradient" + -0.192*"function" + 0.176*"rate" + -0.153*"approach" + '
#   '0.146*"stochastic" + 0.122*"convergence"'),
#  (17,
#   '0.340*"task" + 0.273*"gradient" + -0.235*"bound" + -0.225*"inference" + '
#   '0.189*"training" + -0.188*"image" + -0.188*"method" + -0.149*"learning" + '
#   '0.147*"stochastic" + 0.143*"convergence"'),
#  (18,
#   '0.512*"kernel" + -0.356*"approach" + 0.317*"task" + -0.209*"graph" + '
#   '-0.190*"feature" + -0.155*"sparse" + 0.139*"inference" + '
#   '0.136*"classification" + 0.125*"process" + -0.110*"gradient"'),
#  (19,
#   '0.293*"gradient" + -0.256*"loss" + 0.235*"policy" + 0.232*"matrix" + '
#   '-0.212*"neural" + 0.201*"stochastic" + -0.174*"classification" + '
#   '-0.170*"linear" + -0.168*"approach" + 0.163*"time"'),
#  (20,
#   '0.502*"inference" + -0.277*"approach" + -0.212*"policy" + -0.197*"kernel" + '
#   '0.181*"graph" + 0.166*"show" + -0.158*"distribution" + 0.142*"task" + '
#   '0.139*"variational" + 0.133*"loss"'),
#  (21,
#   '-0.396*"task" + -0.345*"bound" + 0.324*"time" + 0.231*"show" + '
#   '0.224*"label" + 0.189*"loss" + 0.186*"training" + -0.149*"structure" + '
#   '0.137*"classification" + 0.130*"class"'),
#  (22,
#   '-0.344*"clustering" + 0.260*"time" + 0.224*"sparse" + -0.224*"information" '
#   '+ 0.180*"task" + 0.179*"parameter" + 0.174*"regression" + 0.171*"image" + '
#   '-0.169*"matrix" + -0.163*"approach"'),
#  (23,
#   '-0.445*"clustering" + 0.328*"graph" + -0.238*"show" + 0.179*"gradient" + '
#   '0.172*"information" + 0.172*"time" + 0.162*"loss" + -0.161*"cluster" + '
#   '-0.158*"result" + -0.149*"set"'),
#  (24,
#   '0.360*"result" + 0.281*"policy" + -0.271*"object" + -0.219*"number" + '
#   '-0.203*"time" + -0.194*"sample" + 0.189*"show" + -0.179*"task" + '
#   '-0.173*"parameter" + 0.157*"new"'),
#  (25,
#   '-0.327*"time" + -0.254*"object" + -0.231*"loss" + 0.198*"training" + '
#   '0.192*"show" + 0.185*"neural" + 0.181*"bound" + 0.179*"using" + '
#   '0.177*"policy" + -0.170*"framework"'),
#  (26,
#   '-0.469*"object" + 0.360*"time" + 0.222*"clustering" + -0.217*"show" + '
#   '-0.205*"variable" + 0.199*"result" + -0.171*"structure" + 0.152*"image" + '
#   '-0.141*"latent" + -0.131*"space"'),
#  (27,
#   '-0.328*"latent" + -0.303*"show" + -0.239*"variable" + -0.215*"time" + '
#   '-0.168*"topic" + -0.167*"clustering" + 0.166*"loss" + -0.160*"structure" + '
#   '0.160*"graph" + -0.152*"word"'),
#  (28,
#   '-0.379*"information" + -0.291*"process" + 0.279*"object" + -0.247*"label" + '
#   '0.242*"show" + -0.163*"set" + -0.156*"parameter" + 0.143*"task" + '
#   '-0.134*"bayesian" + 0.132*"result"'),
#  (29,
#   '0.464*"information" + -0.296*"loss" + -0.229*"state" + -0.209*"number" + '
#   '-0.198*"clustering" + -0.158*"process" + -0.148*"task" + 0.139*"sample" + '
#   '-0.130*"gradient" + -0.124*"linear"'),
#  (30,
#   '0.460*"show" + 0.267*"loss" + -0.246*"result" + -0.193*"class" + '
#   '-0.183*"latent" + -0.180*"number" + -0.151*"analysis" + 0.150*"regret" + '
#   '0.146*"parameter" + -0.146*"topic"'),
#  (31,
#   '-0.376*"sample" + -0.277*"variable" + -0.275*"training" + 0.238*"label" + '
#   '-0.199*"clustering" + -0.196*"latent" + -0.194*"loss" + '
#   '0.183*"distribution" + 0.181*"number" + 0.165*"sparse"'),
#  (32,
#   '-0.424*"set" + 0.225*"using" + 0.216*"process" + 0.196*"bound" + '
#   '-0.184*"kernel" + -0.174*"result" + -0.163*"parameter" + -0.151*"class" + '
#   '-0.149*"setting" + 0.142*"based"'),
#  (33,
#   '-0.315*"using" + 0.278*"label" + -0.247*"number" + -0.223*"loss" + '
#   '0.178*"rate" + 0.166*"show" + 0.161*"error" + -0.153*"sparse" + '
#   '-0.143*"regret" + -0.141*"information"'),
#  (34,
#   '0.276*"process" + 0.257*"training" + -0.238*"state" + 0.236*"set" + '
#   '0.194*"performance" + 0.184*"optimization" + -0.182*"estimator" + '
#   '-0.181*"information" + -0.158*"label" + -0.147*"space"'),
#  (35,
#   '-0.312*"using" + 0.264*"performance" + -0.253*"set" + 0.252*"variable" + '
#   '-0.245*"result" + 0.210*"policy" + 0.196*"parameter" + -0.173*"rate" + '
#   '-0.163*"space" + 0.155*"loss"'),
#  (36,
#   '-0.312*"process" + 0.267*"using" + -0.245*"rate" + -0.242*"number" + '
#   '0.226*"parameter" + 0.224*"set" + 0.190*"gradient" + 0.170*"structure" + '
#   '-0.163*"show" + -0.159*"sample"'),
#  (37,
#   '-0.488*"framework" + -0.219*"domain" + 0.213*"state" + -0.187*"using" + '
#   '0.180*"information" + -0.179*"structure" + -0.174*"label" + '
#   '0.167*"performance" + 0.161*"loss" + 0.156*"result"'),
#  (38,
#   '0.277*"using" + -0.238*"set" + 0.229*"class" + -0.190*"loss" + '
#   '0.189*"parameter" + 0.183*"estimator" + -0.159*"domain" + -0.153*"paper" + '
#   '0.149*"rate" + 0.149*"result"'),
#  (39,
#   '0.294*"structure" + -0.280*"parameter" + -0.251*"state" + '
#   '-0.213*"framework" + 0.208*"result" + 0.195*"gradient" + 0.190*"tree" + '
#   '-0.169*"based" + -0.167*"optimization" + -0.165*"domain"'),
#  (40,
#   '0.280*"variable" + 0.268*"linear" + -0.223*"structure" + -0.217*"parameter" '
#   '+ -0.187*"neural" + 0.179*"using" + -0.173*"tree" + 0.160*"policy" + '
#   '-0.155*"show" + -0.151*"class"'),
#  (41,
#   '0.293*"result" + 0.267*"number" + -0.256*"space" + 0.246*"using" + '
#   '-0.199*"representation" + 0.189*"variable" + -0.184*"estimator" + '
#   '-0.142*"neural" + -0.139*"set" + 0.138*"parameter"'),
#  (42,
#   '0.324*"analysis" + 0.307*"process" + -0.230*"sparse" + -0.178*"clustering" '
#   '+ -0.177*"optimization" + -0.176*"rate" + -0.167*"optimal" + '
#   '-0.138*"bayesian" + 0.133*"new" + -0.128*"human"'),
#  (43,
#   '0.292*"rate" + -0.273*"information" + -0.238*"linear" + -0.206*"result" + '
#   '-0.185*"framework" + -0.174*"object" + -0.166*"state" + 0.166*"using" + '
#   '-0.161*"gradient" + 0.149*"word"'),
#  (44,
#   '-0.371*"domain" + 0.256*"sample" + -0.185*"time" + 0.174*"framework" + '
#   '-0.173*"information" + -0.166*"structure" + 0.164*"number" + 0.164*"system" '
#   '+ -0.146*"sparse" + -0.146*"rate"'),
#  (45,
#   '-0.300*"optimization" + -0.260*"class" + -0.229*"policy" + -0.228*"using" + '
#   '0.223*"result" + -0.219*"new" + -0.158*"loss" + -0.152*"convex" + '
#   '0.140*"proposed" + 0.139*"estimator"'),
#  (46,
#   '-0.251*"tree" + 0.240*"policy" + -0.228*"state" + -0.199*"new" + '
#   '-0.188*"class" + 0.183*"sample" + 0.182*"parameter" + 0.178*"result" + '
#   '0.176*"optimization" + -0.164*"linear"'),
#  (47,
#   '-0.224*"number" + -0.218*"metric" + 0.216*"class" + 0.202*"state" + '
#   '0.200*"representation" + -0.175*"structure" + 0.173*"human" + '
#   '-0.168*"space" + -0.150*"linear" + -0.148*"policy"'),
#  (48,
#   '-0.460*"new" + 0.328*"optimization" + 0.241*"domain" + 0.181*"random" + '
#   '-0.160*"sparse" + -0.159*"gradient" + -0.143*"policy" + -0.140*"rate" + '
#   '-0.132*"error" + 0.121*"process"'),
#  (49,
#   '0.289*"linear" + 0.283*"parameter" + -0.210*"estimator" + '
#   '-0.191*"performance" + 0.191*"human" + -0.177*"set" + '
#   '0.174*"representation" + 0.164*"class" + 0.145*"decision" + '
#   '-0.135*"propose"'),
#  (50,
#   '-0.225*"framework" + 0.211*"based" + 0.202*"new" + -0.191*"structure" + '
#   '-0.180*"convergence" + 0.174*"metric" + -0.169*"rate" + '
#   '0.166*"optimization" + 0.158*"one" + -0.156*"system"'),
#  (51,
#   '-0.410*"estimator" + 0.255*"performance" + 0.218*"state" + -0.207*"policy" '
#   '+ 0.145*"analysis" + 0.143*"regression" + 0.143*"metric" + 0.126*"sample" + '
#   '0.122*"error" + -0.118*"neural"'),
#  (52,
#   '0.345*"label" + 0.302*"new" + -0.232*"training" + -0.222*"framework" + '
#   '-0.212*"tree" + 0.199*"deep" + -0.175*"decision" + -0.169*"topic" + '
#   '-0.160*"word" + 0.153*"linear"'),
#  (53,
#   '0.307*"performance" + -0.189*"decision" + 0.179*"linear" + '
#   '-0.178*"prediction" + 0.162*"inference" + 0.162*"domain" + -0.160*"deep" + '
#   '-0.160*"game" + -0.160*"representation" + -0.158*"random"'),
#  (54,
#   '-0.280*"class" + -0.238*"propose" + 0.219*"bayesian" + 0.207*"regression" + '
#   '-0.172*"point" + 0.169*"optimization" + 0.157*"estimator" + 0.157*"present" '
#   '+ -0.147*"proposed" + 0.139*"two"'),
#  (55,
#   '-0.273*"space" + 0.252*"linear" + -0.189*"new" + -0.189*"representation" + '
#   '0.186*"training" + 0.165*"state" + 0.163*"analysis" + -0.151*"system" + '
#   '0.146*"two" + -0.145*"parameter"'),
#  (56,
#   '0.223*"two" + -0.183*"sparse" + -0.181*"analysis" + 0.177*"regression" + '
#   '0.171*"representation" + -0.163*"system" + -0.152*"training" + '
#   '0.151*"human" + -0.148*"input" + -0.142*"error"'),
#  (57,
#   '0.267*"two" + -0.250*"analysis" + -0.217*"set" + 0.192*"approximation" + '
#   '-0.174*"deep" + 0.173*"sparse" + 0.158*"regression" + -0.155*"error" + '
#   '0.154*"label" + -0.153*"optimal"'),
#  (58,
#   '-0.245*"tree" + 0.199*"space" + 0.188*"training" + -0.182*"random" + '
#   '0.170*"metric" + -0.169*"based" + 0.165*"framework" + 0.160*"large" + '
#   '0.143*"prediction" + -0.140*"vector"'),
#  (59,
#   '-0.283*"approximation" + -0.267*"error" + -0.246*"structure" + '
#   '0.166*"analysis" + -0.158*"based" + 0.150*"proposed" + -0.147*"sampling" + '
#   '-0.136*"topic" + -0.124*"random" + 0.124*"human"'),
#  (60,
#   '-0.373*"two" + 0.223*"training" + -0.199*"error" + -0.197*"game" + '
#   '0.175*"new" + 0.172*"study" + 0.170*"sampling" + -0.160*"large" + '
#   '-0.155*"prediction" + 0.144*"random"'),
#  (61,
#   '0.364*"sampling" + 0.240*"propose" + 0.199*"input" + -0.169*"optimal" + '
#   '0.169*"regression" + -0.149*"latent" + 0.144*"prediction" + 0.143*"linear" '
#   '+ -0.143*"based" + 0.135*"classifier"'),
#  (62,
#   '-0.278*"space" + -0.210*"two" + 0.193*"online" + -0.176*"training" + '
#   '0.172*"domain" + -0.170*"sampling" + -0.162*"signal" + 0.154*"large" + '
#   '-0.150*"bayesian" + -0.148*"based"'),
#  (63,
#   '-0.225*"game" + -0.209*"metric" + -0.192*"bayesian" + -0.184*"paper" + '
#   '0.167*"test" + 0.164*"random" + -0.161*"also" + 0.158*"structure" + '
#   '-0.156*"proposed" + -0.155*"prior"'),
#  (64,
#   '-0.247*"game" + 0.240*"representation" + -0.202*"neural" + 0.197*"sampling" '
#   '+ 0.193*"estimator" + -0.192*"used" + -0.173*"random" + '
#   '0.166*"approximation" + 0.153*"based" + 0.149*"neuron"'),
#  (65,
#   '-0.433*"based" + -0.288*"regression" + 0.195*"new" + -0.169*"game" + '
#   '0.160*"proposed" + -0.145*"prediction" + -0.140*"space" + 0.139*"optimal" + '
#   '0.133*"framework" + -0.128*"domain"'),
#  (66,
#   '0.288*"prediction" + 0.180*"proposed" + -0.178*"user" + -0.171*"noise" + '
#   '0.169*"neural" + -0.161*"system" + 0.159*"sequence" + 0.158*"class" + '
#   '-0.145*"game" + 0.144*"point"'),
#  (67,
#   '0.277*"game" + 0.232*"random" + 0.214*"large" + -0.189*"propose" + '
#   '-0.158*"deep" + 0.150*"test" + 0.141*"vector" + -0.140*"number" + '
#   '0.126*"sampling" + 0.125*"new"'),
#  (68,
#   '-0.252*"test" + 0.235*"local" + -0.214*"application" + -0.169*"many" + '
#   '-0.164*"bayesian" + 0.145*"point" + -0.140*"prediction" + 0.140*"online" + '
#   '0.126*"metric" + 0.126*"sampling"'),
#  (69,
#   '-0.236*"propose" + -0.216*"also" + -0.199*"tree" + -0.180*"test" + '
#   '-0.178*"dynamic" + -0.175*"space" + 0.174*"probability" + '
#   '0.161*"regression" + 0.147*"complexity" + -0.133*"online"'),
#  (70,
#   '0.244*"metric" + -0.239*"proposed" + -0.217*"space" + -0.202*"regression" + '
#   '0.188*"sparse" + 0.186*"based" + 0.159*"number" + -0.157*"optimal" + '
#   '0.154*"also" + -0.147*"error"'),
#  (71,
#   '0.231*"test" + 0.212*"representation" + -0.209*"space" + 0.208*"regression" '
#   '+ 0.202*"point" + -0.172*"human" + -0.169*"paper" + 0.161*"also" + '
#   '-0.148*"approximation" + -0.129*"latent"'),
#  (72,
#   '-0.337*"proposed" + 0.259*"point" + 0.213*"paper" + 0.197*"optimal" + '
#   '-0.166*"signal" + 0.166*"sparse" + -0.163*"approximation" + 0.143*"one" + '
#   '-0.132*"based" + 0.129*"neuron"'),
#  (73,
#   '-0.245*"memory" + -0.201*"one" + 0.199*"efficient" + 0.194*"random" + '
#   '0.185*"prior" + -0.162*"sparse" + 0.147*"noise" + -0.142*"setting" + '
#   '-0.140*"machine" + -0.140*"classification"'),
#  (74,
#   '-0.191*"action" + 0.183*"present" + 0.175*"test" + 0.160*"memory" + '
#   '-0.160*"one" + -0.154*"framework" + -0.149*"label" + 0.147*"probability" + '
#   '0.140*"experiment" + 0.139*"neural"'),
#  (75,
#   '-0.226*"input" + 0.204*"dynamic" + 0.201*"large" + 0.174*"probability" + '
#   '0.162*"vector" + -0.159*"topic" + 0.130*"study" + -0.129*"game" + '
#   '-0.128*"gradient" + -0.123*"state"'),
#  (76,
#   '0.195*"also" + -0.166*"metric" + -0.159*"deep" + 0.155*"point" + '
#   '-0.149*"case" + 0.149*"signal" + 0.147*"performance" + '
#   '0.146*"representation" + -0.144*"optimal" + 0.137*"rule"'),
#  (77,
#   '-0.229*"neural" + 0.209*"game" + 0.166*"also" + 0.162*"one" + 0.159*"deep" '
#   '+ -0.156*"action" + -0.155*"paper" + -0.155*"prior" + 0.145*"layer" + '
#   '0.136*"online"'),
#  (78,
#   '0.238*"test" + 0.229*"user" + -0.227*"dynamic" + -0.185*"norm" + '
#   '0.180*"also" + -0.178*"local" + -0.172*"classifier" + -0.164*"case" + '
#   '-0.139*"study" + -0.129*"first"'),
#  (79,
#   '0.212*"present" + -0.211*"signal" + 0.187*"estimation" + 0.176*"also" + '
#   '-0.165*"probability" + 0.152*"different" + 0.148*"class" + 0.141*"one" + '
#   '0.136*"based" + 0.136*"paper"'),
#  (80,
#   '0.235*"also" + 0.233*"optimal" + -0.232*"local" + 0.186*"solution" + '
#   '-0.173*"metric" + 0.169*"classifier" + -0.166*"error" + 0.163*"propose" + '
#   '-0.151*"test" + -0.141*"study"'),
#  (81,
#   '0.247*"norm" + 0.227*"metric" + -0.213*"latent" + 0.184*"variable" + '
#   '-0.182*"local" + 0.170*"error" + 0.168*"one" + -0.157*"different" + '
#   '0.153*"label" + 0.153*"estimation"'),
#  (82,
#   '-0.259*"prior" + 0.201*"prediction" + -0.193*"test" + 0.171*"signal" + '
#   '-0.171*"norm" + -0.158*"large" + -0.155*"online" + 0.154*"also" + '
#   '0.151*"estimation" + -0.147*"work"'),
#  (83,
#   '-0.203*"point" + 0.169*"decision" + -0.168*"prior" + -0.168*"novel" + '
#   '-0.161*"prediction" + 0.145*"statistical" + 0.144*"analysis" + '
#   '-0.142*"topic" + 0.142*"human" + -0.138*"one"'),
#  (84,
#   '-0.247*"paper" + -0.227*"online" + 0.215*"also" + 0.202*"decision" + '
#   '-0.187*"representation" + 0.152*"accuracy" + -0.141*"input" + '
#   '0.130*"vector" + 0.122*"convex" + 0.120*"prior"'),
#  (85,
#   '-0.209*"point" + 0.196*"present" + -0.179*"value" + 0.172*"regret" + '
#   '-0.170*"probability" + -0.169*"setting" + -0.154*"memory" + '
#   '-0.151*"sampling" + -0.148*"human" + -0.147*"latent"'),
#  (86,
#   '0.273*"case" + 0.236*"also" + -0.165*"efficient" + -0.160*"setting" + '
#   '0.160*"large" + 0.153*"paper" + -0.141*"application" + 0.141*"tree" + '
#   '-0.130*"response" + 0.123*"space"'),
#  (87,
#   '-0.229*"work" + 0.213*"memory" + 0.207*"bayesian" + -0.204*"number" + '
#   '-0.203*"sampling" + -0.178*"used" + 0.177*"large" + -0.169*"estimation" + '
#   '-0.167*"proposed" + -0.163*"estimate"'),
#  (88,
#   '0.216*"solution" + 0.164*"action" + -0.159*"visual" + 0.156*"stochastic" + '
#   '-0.154*"vector" + -0.154*"response" + -0.149*"natural" + '
#   '-0.147*"estimation" + -0.143*"convex" + 0.140*"random"'),
#  (89,
#   '-0.259*"deep" + 0.214*"propose" + -0.183*"test" + 0.155*"different" + '
#   '-0.149*"paper" + -0.149*"topic" + 0.144*"component" + 0.134*"user" + '
#   '-0.130*"dynamic" + 0.127*"complexity"'),
#  (90,
#   '0.271*"noise" + -0.190*"point" + -0.176*"technique" + -0.148*"also" + '
#   '-0.146*"classification" + -0.146*"complexity" + 0.145*"decision" + '
#   '-0.134*"measure" + 0.125*"experiment" + -0.125*"system"'),
#  (91,
#   '0.232*"signal" + 0.227*"used" + -0.224*"visual" + -0.163*"classifier" + '
#   '0.159*"memory" + -0.135*"query" + 0.134*"optimal" + -0.126*"present" + '
#   '-0.126*"case" + 0.125*"also"'),
#  (92,
#   '-0.202*"sampling" + -0.155*"vector" + 0.145*"regression" + 0.137*"value" + '
#   '0.136*"propose" + 0.135*"similarity" + 0.134*"stochastic" + '
#   '0.133*"complexity" + 0.131*"sequence" + 0.130*"dynamic"'),
#  (93,
#   '-0.226*"probability" + 0.168*"local" + -0.157*"large" + -0.151*"well" + '
#   '0.151*"prediction" + -0.146*"input" + 0.140*"setting" + -0.138*"first" + '
#   '0.137*"vector" + 0.135*"used"'),
#  (94,
#   '-0.248*"point" + -0.182*"online" + -0.178*"present" + 0.171*"local" + '
#   '0.150*"prior" + 0.149*"ranking" + -0.141*"noise" + 0.131*"setting" + '
#   '0.129*"component" + 0.126*"propose"'),
#  (95,
#   '0.235*"one" + 0.232*"noise" + -0.226*"provide" + -0.201*"system" + '
#   '0.168*"point" + 0.146*"human" + 0.142*"dynamic" + 0.141*"sampling" + '
#   '-0.126*"neuron" + 0.121*"rate"'),
#  (96,
#   '-0.258*"stochastic" + 0.235*"online" + 0.188*"signal" + -0.171*"different" '
#   '+ -0.152*"tree" + -0.140*"natural" + 0.134*"classifier" + -0.134*"noise" + '
#   '0.132*"provide" + -0.129*"prior"'),
#  (97,
#   '-0.206*"memory" + -0.180*"latent" + 0.178*"different" + -0.161*"work" + '
#   '0.156*"estimate" + 0.144*"component" + 0.137*"constraint" + '
#   '-0.133*"optimal" + 0.133*"provide" + -0.125*"objective"'),
#  (98,
#   '0.240*"memory" + 0.200*"component" + 0.188*"regression" + 0.147*"vector" + '
#   '0.144*"case" + -0.125*"different" + 0.123*"mixture" + -0.120*"one" + '
#   '-0.118*"proposed" + -0.116*"bayesian"'),
#  (99,
#   '-0.180*"random" + 0.167*"brain" + -0.166*"used" + -0.153*"system" + '
#   '-0.145*"objective" + 0.141*"present" + 0.137*"value" + 0.129*"experiment" + '
#   '0.129*"first" + 0.122*"dynamic"')]

# %% [markdown]
# # Evaluation

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.



coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)


coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='u_mass')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)
# Out:
# Coherence Score:  0.2627923251812317
#
# Coherence Score5:  0.41480293196448115
#
# Coherence Score10:  0.37498113642947334
#
# Coherence Score20:  0.3209857333066504
#
# Coherence Score50:  0.2672642078610385
#
# Coherence Score100:  0.23165813319711667
#
# Coherence Score:  -1.3206663098063114
#
# Coherence Score5:  -1.9876046086710013
#
# Coherence Score10:  -1.986057481541275
#
# Coherence Score20:  -2.088764253334657
#
# Coherence Score50:  -2.2989521616352087
#
# Coherence Score100:  -2.442079457287028
