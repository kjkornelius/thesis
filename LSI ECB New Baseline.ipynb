# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['Press']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(4394 unique tokens: ['able', 'acceptable', 'accompanied', 'according', 'account']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build the LSI Model
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.295*"price" + 0.292*"euro" + 0.283*"growth" + 0.274*"area" + 0.238*"rate" '
#   '+ 0.210*"monetary" + 0.208*"economic" + 0.168*"inflation" + '
#   '0.146*"development" + 0.138*"council"')]
# [(0,
#   '0.295*"price" + 0.292*"euro" + 0.283*"growth" + 0.274*"area" + 0.238*"rate" '
#   '+ 0.210*"monetary" + 0.208*"economic" + 0.168*"inflation" + '
#   '0.146*"development" + 0.138*"council"'),
#  (1,
#   '-0.345*"council" + -0.313*"governing" + -0.218*"euro" + 0.203*"inflation" + '
#   '-0.179*"ecb" + 0.151*"medium" + 0.138*"risk" + 0.138*"remain" + '
#   '0.136*"economic" + 0.133*"analysis"'),
#  (2,
#   '-0.427*"price" + -0.244*"stability" + -0.214*"growth" + 0.195*"loan" + '
#   '0.164*"inflation" + 0.158*"measure" + 0.154*"policy" + -0.143*"development" '
#   '+ -0.142*"strong" + -0.135*"risk"'),
#  (3,
#   '0.210*"monetary" + 0.205*"policy" + -0.185*"council" + -0.182*"medium" + '
#   '-0.180*"governing" + 0.166*"area" + -0.163*"remain" + -0.157*"term" + '
#   '-0.152*"financial" + -0.147*"pressure"'),
#  (4,
#   '-0.430*"euro" + -0.371*"area" + 0.237*"policy" + 0.196*"rate" + '
#   '0.185*"monetary" + 0.139*"recovery" + -0.138*"market" + 0.113*"measure" + '
#   '0.109*"governing" + -0.109*"underlying"')]
# [(0,
#   '0.295*"price" + 0.292*"euro" + 0.283*"growth" + 0.274*"area" + 0.238*"rate" '
#   '+ 0.210*"monetary" + 0.208*"economic" + 0.168*"inflation" + '
#   '0.146*"development" + 0.138*"council"'),
#  (1,
#   '0.345*"council" + 0.313*"governing" + 0.218*"euro" + -0.203*"inflation" + '
#   '0.179*"ecb" + -0.151*"medium" + -0.138*"risk" + -0.138*"remain" + '
#   '-0.136*"economic" + -0.133*"analysis"'),
#  (2,
#   '-0.427*"price" + -0.244*"stability" + -0.214*"growth" + 0.195*"loan" + '
#   '0.164*"inflation" + 0.158*"measure" + 0.154*"policy" + -0.143*"development" '
#   '+ -0.142*"strong" + -0.135*"risk"'),
#  (3,
#   '0.210*"monetary" + 0.205*"policy" + -0.185*"council" + -0.182*"medium" + '
#   '-0.180*"governing" + 0.166*"area" + -0.163*"remain" + -0.157*"term" + '
#   '-0.152*"financial" + -0.147*"pressure"'),
#  (4,
#   '0.430*"euro" + 0.371*"area" + -0.237*"policy" + -0.196*"rate" + '
#   '-0.185*"monetary" + -0.139*"recovery" + 0.138*"market" + -0.113*"measure" + '
#   '-0.109*"governing" + 0.109*"underlying"'),
#  (5,
#   '0.281*"market" + 0.274*"monetary" + 0.268*"financial" + -0.259*"rate" + '
#   '0.241*"risk" + -0.154*"growth" + 0.140*"policy" + 0.133*"credit" + '
#   '0.130*"money" + -0.130*"recovery"'),
#  (6,
#   '-0.457*"rate" + -0.192*"operation" + 0.169*"policy" + -0.159*"projection" + '
#   '0.141*"economic" + -0.136*"refinancing" + -0.134*"risk" + 0.119*"stability" '
#   '+ -0.117*"increase" + -0.116*"staff"'),
#  (7,
#   '-0.351*"monetary" + 0.200*"inflation" + 0.194*"projection" + '
#   '0.172*"financial" + 0.156*"effect" + -0.146*"remain" + -0.119*"ample" + '
#   '0.118*"staff" + 0.112*"hicp" + -0.111*"increase"'),
#  (8,
#   '-0.312*"economic" + 0.294*"growth" + -0.235*"rate" + 0.186*"projection" + '
#   '0.159*"medium" + -0.148*"recent" + -0.138*"activity" + 0.135*"gdp" + '
#   '0.129*"governing" + 0.129*"staff"'),
#  (9,
#   '-0.219*"pressure" + -0.207*"projection" + 0.197*"credit" + 0.170*"medium" + '
#   '-0.167*"measure" + -0.161*"recent" + 0.157*"rate" + 0.157*"subdued" + '
#   '0.153*"condition" + -0.147*"staff"')]
# [(0,
#   '0.295*"price" + 0.292*"euro" + 0.283*"growth" + 0.274*"area" + 0.238*"rate" '
#   '+ 0.210*"monetary" + 0.208*"economic" + 0.168*"inflation" + '
#   '0.146*"development" + 0.138*"council"'),
#  (1,
#   '0.345*"council" + 0.313*"governing" + 0.218*"euro" + -0.203*"inflation" + '
#   '0.179*"ecb" + -0.151*"medium" + -0.138*"risk" + -0.138*"remain" + '
#   '-0.136*"economic" + -0.133*"analysis"'),
#  (2,
#   '0.427*"price" + 0.244*"stability" + 0.214*"growth" + -0.195*"loan" + '
#   '-0.164*"inflation" + -0.158*"measure" + -0.154*"policy" + '
#   '0.143*"development" + 0.142*"strong" + 0.135*"risk"'),
#  (3,
#   '0.210*"monetary" + 0.205*"policy" + -0.185*"council" + -0.182*"medium" + '
#   '-0.180*"governing" + 0.166*"area" + -0.163*"remain" + -0.157*"term" + '
#   '-0.152*"financial" + -0.147*"pressure"'),
#  (4,
#   '-0.430*"euro" + -0.371*"area" + 0.237*"policy" + 0.196*"rate" + '
#   '0.185*"monetary" + 0.139*"recovery" + -0.138*"market" + 0.113*"measure" + '
#   '0.109*"governing" + -0.109*"underlying"'),
#  (5,
#   '0.281*"market" + 0.274*"monetary" + 0.268*"financial" + -0.259*"rate" + '
#   '0.241*"risk" + -0.154*"growth" + 0.140*"policy" + 0.133*"credit" + '
#   '0.130*"money" + -0.130*"recovery"'),
#  (6,
#   '-0.457*"rate" + -0.192*"operation" + 0.169*"policy" + -0.159*"projection" + '
#   '0.141*"economic" + -0.136*"refinancing" + -0.134*"risk" + 0.119*"stability" '
#   '+ -0.117*"increase" + -0.116*"staff"'),
#  (7,
#   '-0.351*"monetary" + 0.200*"inflation" + 0.194*"projection" + '
#   '0.172*"financial" + 0.156*"effect" + -0.146*"remain" + -0.119*"ample" + '
#   '0.118*"staff" + 0.112*"hicp" + -0.111*"increase"'),
#  (8,
#   '-0.312*"economic" + 0.294*"growth" + -0.235*"rate" + 0.186*"projection" + '
#   '0.159*"medium" + -0.148*"recent" + -0.138*"activity" + 0.135*"gdp" + '
#   '0.129*"governing" + 0.129*"staff"'),
#  (9,
#   '0.219*"pressure" + 0.207*"projection" + -0.197*"credit" + -0.170*"medium" + '
#   '0.166*"measure" + 0.161*"recent" + -0.157*"subdued" + -0.157*"rate" + '
#   '-0.153*"condition" + 0.148*"staff"'),
#  (10,
#   '-0.317*"price" + 0.316*"growth" + 0.253*"market" + 0.215*"financial" + '
#   '-0.194*"projection" + -0.131*"ecb" + -0.126*"euro" + 0.119*"uncertainty" + '
#   '-0.119*"staff" + 0.112*"month"'),
#  (11,
#   '0.232*"projection" + -0.175*"growth" + 0.158*"staff" + 0.147*"economic" + '
#   '-0.144*"price" + -0.136*"loan" + -0.130*"food" + -0.130*"energy" + '
#   '-0.123*"may" + 0.112*"market"'),
#  (12,
#   '0.205*"measure" + 0.195*"euro" + 0.173*"area" + 0.160*"stability" + '
#   '-0.159*"market" + -0.144*"development" + -0.137*"projection" + '
#   '-0.133*"recent" + -0.133*"remain" + -0.129*"ecb"'),
#  (13,
#   '-0.245*"development" + -0.208*"price" + 0.181*"bank" + 0.171*"level" + '
#   '-0.170*"increase" + 0.151*"interest" + 0.133*"risk" + 0.130*"january" + '
#   '0.130*"central" + 0.129*"economic"'),
#  (14,
#   '-0.218*"economic" + 0.185*"oil" + 0.174*"december" + 0.159*"january" + '
#   '0.152*"development" + 0.145*"november" + 0.136*"price" + -0.131*"effect" + '
#   '-0.130*"expected" + -0.128*"may"'),
#  (15,
#   '-0.187*"may" + 0.169*"growth" + 0.166*"september" + -0.152*"march" + '
#   '-0.149*"euro" + 0.139*"october" + -0.136*"recent" + 0.136*"july" + '
#   '0.134*"price" + 0.131*"august"'),
#  (16,
#   '-0.264*"inflation" + 0.176*"also" + 0.176*"operation" + 0.166*"economic" + '
#   '-0.166*"ecb" + -0.158*"rate" + 0.136*"recovery" + 0.136*"march" + '
#   '0.130*"council" + -0.124*"expectation"'),
#  (17,
#   '-0.201*"market" + -0.194*"oil" + 0.192*"council" + 0.162*"governing" + '
#   '-0.151*"national" + -0.144*"remain" + -0.130*"policy" + -0.126*"quarter" + '
#   '-0.122*"need" + 0.121*"economic"'),
#  (18,
#   '-0.228*"economic" + 0.200*"risk" + 0.128*"low" + 0.127*"quarter" + '
#   '0.124*"analysis" + -0.123*"staff" + -0.120*"annual" + 0.119*"ongoing" + '
#   '-0.114*"financial" + -0.114*"activity"'),
#  (19,
#   '-0.203*"activity" + 0.155*"period" + 0.141*"continue" + 0.140*"market" + '
#   '-0.131*"december" + 0.130*"also" + -0.122*"january" + 0.117*"fixed" + '
#   '-0.114*"november" + -0.111*"balance"')]
# [(0,
#   '-0.295*"price" + -0.292*"euro" + -0.283*"growth" + -0.274*"area" + '
#   '-0.238*"rate" + -0.210*"monetary" + -0.208*"economic" + -0.168*"inflation" '
#   '+ -0.146*"development" + -0.138*"council"'),
#  (1,
#   '0.345*"council" + 0.313*"governing" + 0.218*"euro" + -0.203*"inflation" + '
#   '0.179*"ecb" + -0.151*"medium" + -0.138*"risk" + -0.138*"remain" + '
#   '-0.136*"economic" + -0.133*"analysis"'),
#  (2,
#   '-0.427*"price" + -0.244*"stability" + -0.214*"growth" + 0.195*"loan" + '
#   '0.164*"inflation" + 0.158*"measure" + 0.154*"policy" + -0.143*"development" '
#   '+ -0.142*"strong" + -0.135*"risk"'),
#  (3,
#   '-0.210*"monetary" + -0.205*"policy" + 0.185*"council" + 0.182*"medium" + '
#   '0.180*"governing" + -0.166*"area" + 0.163*"remain" + 0.157*"term" + '
#   '0.152*"financial" + 0.147*"pressure"'),
#  (4,
#   '0.430*"euro" + 0.371*"area" + -0.237*"policy" + -0.196*"rate" + '
#   '-0.185*"monetary" + -0.139*"recovery" + 0.138*"market" + -0.113*"measure" + '
#   '-0.109*"governing" + 0.109*"underlying"'),
#  (5,
#   '0.281*"market" + 0.274*"monetary" + 0.268*"financial" + -0.259*"rate" + '
#   '0.241*"risk" + -0.154*"growth" + 0.140*"policy" + 0.133*"credit" + '
#   '0.130*"money" + -0.130*"recovery"'),
#  (6,
#   '0.457*"rate" + 0.192*"operation" + -0.169*"policy" + 0.159*"projection" + '
#   '-0.141*"economic" + 0.136*"refinancing" + 0.134*"risk" + -0.119*"stability" '
#   '+ 0.117*"increase" + 0.116*"staff"'),
#  (7,
#   '-0.351*"monetary" + 0.200*"inflation" + 0.194*"projection" + '
#   '0.172*"financial" + 0.156*"effect" + -0.146*"remain" + -0.119*"ample" + '
#   '0.118*"staff" + 0.112*"hicp" + -0.111*"increase"'),
#  (8,
#   '-0.312*"economic" + 0.294*"growth" + -0.235*"rate" + 0.186*"projection" + '
#   '0.159*"medium" + -0.148*"recent" + -0.138*"activity" + 0.135*"gdp" + '
#   '0.129*"governing" + 0.129*"staff"'),
#  (9,
#   '0.219*"pressure" + 0.207*"projection" + -0.197*"credit" + -0.170*"medium" + '
#   '0.166*"measure" + 0.161*"recent" + -0.157*"subdued" + -0.157*"rate" + '
#   '-0.153*"condition" + 0.148*"staff"'),
#  (10,
#   '0.317*"price" + -0.316*"growth" + -0.253*"market" + -0.215*"financial" + '
#   '0.193*"projection" + 0.131*"ecb" + 0.126*"euro" + -0.119*"uncertainty" + '
#   '0.119*"staff" + -0.112*"month"'),
#  (11,
#   '-0.232*"projection" + 0.175*"growth" + -0.158*"staff" + -0.147*"economic" + '
#   '0.145*"price" + 0.136*"loan" + 0.130*"food" + 0.130*"energy" + 0.123*"may" '
#   '+ -0.112*"market"'),
#  (12,
#   '-0.205*"measure" + -0.195*"euro" + -0.173*"area" + -0.160*"stability" + '
#   '0.159*"market" + 0.144*"development" + 0.137*"projection" + 0.133*"recent" '
#   '+ 0.133*"remain" + 0.129*"ecb"'),
#  (13,
#   '-0.245*"development" + -0.208*"price" + 0.181*"bank" + 0.171*"level" + '
#   '-0.170*"increase" + 0.151*"interest" + 0.133*"risk" + 0.131*"january" + '
#   '0.130*"central" + 0.129*"economic"'),
#  (14,
#   '-0.218*"economic" + 0.185*"oil" + 0.174*"december" + 0.159*"january" + '
#   '0.152*"development" + 0.145*"november" + 0.136*"price" + -0.131*"effect" + '
#   '-0.130*"expected" + -0.128*"may"'),
#  (15,
#   '-0.187*"may" + 0.169*"growth" + 0.166*"september" + -0.151*"march" + '
#   '-0.149*"euro" + 0.139*"october" + -0.136*"recent" + 0.136*"july" + '
#   '0.134*"price" + 0.131*"august"'),
#  (16,
#   '-0.264*"inflation" + 0.176*"also" + 0.176*"operation" + 0.166*"economic" + '
#   '-0.165*"ecb" + -0.158*"rate" + 0.137*"recovery" + 0.136*"march" + '
#   '0.130*"council" + -0.125*"expectation"'),
#  (17,
#   '-0.201*"market" + -0.193*"oil" + 0.192*"council" + 0.162*"governing" + '
#   '-0.151*"national" + -0.144*"remain" + -0.130*"policy" + -0.126*"quarter" + '
#   '-0.121*"need" + -0.121*"measure"'),
#  (18,
#   '0.229*"economic" + -0.200*"risk" + -0.129*"low" + -0.127*"quarter" + '
#   '-0.124*"analysis" + 0.123*"staff" + 0.120*"annual" + -0.119*"ongoing" + '
#   '0.114*"financial" + 0.113*"activity"'),
#  (19,
#   '0.202*"activity" + -0.154*"period" + -0.141*"continue" + -0.140*"market" + '
#   '-0.131*"also" + 0.130*"december" + 0.121*"january" + -0.117*"fixed" + '
#   '0.115*"november" + 0.111*"balance"'),
#  (20,
#   '-0.150*"information" + -0.136*"expected" + -0.134*"oil" + 0.133*"data" + '
#   '-0.128*"inflation" + 0.124*"interest" + 0.122*"development" + '
#   '-0.122*"upward" + 0.117*"economy" + -0.116*"effect"'),
#  (21,
#   '0.202*"bank" + 0.194*"year" + 0.178*"activity" + -0.152*"stability" + '
#   '-0.128*"market" + -0.122*"pillar" + 0.121*"national" + 0.117*"september" + '
#   '0.117*"central" + 0.108*"also"'),
#  (22,
#   '-0.194*"growth" + -0.176*"quarter" + -0.146*"since" + 0.129*"price" + '
#   '0.125*"oil" + 0.121*"year" + 0.120*"recent" + 0.119*"remains" + '
#   '0.117*"operation" + 0.112*"particular"'),
#  (23,
#   '-0.169*"operation" + -0.163*"medium" + 0.155*"expected" + -0.153*"term" + '
#   '-0.146*"eurosystem" + 0.140*"high" + -0.132*"decision" + 0.131*"annual" + '
#   '0.124*"january" + 0.120*"inflation"'),
#  (24,
#   '-0.247*"year" + -0.215*"country" + 0.159*"also" + 0.156*"economy" + '
#   '0.134*"term" + 0.132*"decision" + -0.122*"european" + 0.112*"medium" + '
#   '0.108*"point" + -0.105*"annual"'),
#  (25,
#   '-0.169*"money" + 0.160*"march" + 0.140*"increase" + -0.130*"new" + '
#   '-0.129*"measure" + -0.127*"first" + -0.125*"growth" + -0.120*"credit" + '
#   '-0.119*"banknote" + 0.118*"policy"'),
#  (26,
#   '0.184*"economic" + 0.159*"oil" + -0.146*"regard" + 0.137*"june" + '
#   '-0.136*"recent" + 0.127*"market" + -0.115*"quarter" + 0.106*"moderate" + '
#   '0.106*"council" + -0.101*"monetary"'),
#  (27,
#   '-0.200*"level" + 0.170*"also" + 0.151*"oil" + 0.130*"rate" + '
#   '-0.117*"stability" + 0.113*"pressure" + -0.110*"development" + '
#   '-0.107*"interest" + -0.106*"economic" + -0.105*"projection"'),
#  (28,
#   '0.205*"development" + 0.178*"december" + 0.166*"policy" + -0.163*"increase" '
#   '+ 0.143*"year" + 0.137*"wage" + 0.134*"november" + -0.129*"september" + '
#   '-0.124*"economic" + -0.122*"recovery"'),
#  (29,
#   '0.173*"term" + 0.142*"risk" + 0.142*"medium" + -0.136*"strategy" + '
#   '0.133*"previous" + -0.128*"continued" + -0.122*"activity" + 0.121*"also" + '
#   '0.119*"particular" + -0.119*"strong"'),
#  (30,
#   '-0.159*"first" + -0.140*"recent" + -0.129*"ecb" + -0.125*"key" + '
#   '0.118*"would" + 0.117*"main" + -0.116*"may" + -0.113*"mediumterm" + '
#   '-0.111*"information" + -0.111*"however"'),
#  (31,
#   '-0.190*"year" + -0.149*"inflation" + -0.145*"reflecting" + 0.141*"area" + '
#   '0.139*"shortterm" + 0.132*"support" + -0.125*"also" + 0.116*"time" + '
#   '0.114*"mediumterm" + 0.114*"recovery"'),
#  (32,
#   '0.150*"recovery" + 0.131*"available" + -0.126*"march" + 0.122*"first" + '
#   '-0.122*"environment" + 0.119*"line" + -0.117*"remain" + 0.116*"financial" + '
#   '-0.111*"increase" + -0.109*"structural"'),
#  (33,
#   '0.243*"also" + 0.140*"remain" + 0.128*"still" + -0.120*"domestic" + '
#   '0.117*"fiscal" + 0.114*"available" + -0.113*"demand" + 0.112*"period" + '
#   '0.109*"january" + 0.108*"economy"'),
#  (34,
#   '-0.175*"july" + -0.143*"monetary" + -0.140*"economy" + -0.134*"need" + '
#   '-0.133*"continued" + 0.128*"first" + -0.127*"eurosystem" + 0.121*"price" + '
#   '0.118*"march" + 0.111*"inflation"'),
#  (35,
#   '-0.178*"increase" + -0.171*"year" + 0.153*"august" + 0.149*"economic" + '
#   '-0.130*"european" + -0.126*"therefore" + 0.123*"country" + 0.116*"first" + '
#   '0.114*"current" + -0.112*"april"'),
#  (36,
#   '0.202*"would" + 0.160*"first" + -0.146*"inflation" + 0.146*"policy" + '
#   '0.128*"may" + -0.123*"recent" + 0.118*"pressure" + -0.115*"economic" + '
#   '0.112*"employment" + 0.112*"market"'),
#  (37,
#   '0.195*"monetary" + 0.193*"remain" + 0.176*"recent" + -0.170*"fiscal" + '
#   '-0.143*"loan" + -0.125*"price" + 0.116*"country" + 0.113*"impact" + '
#   '-0.111*"looking" + -0.108*"june"'),
#  (38,
#   '-0.146*"remains" + -0.142*"continue" + 0.129*"year" + -0.124*"month" + '
#   '0.116*"recent" + -0.115*"expected" + -0.115*"april" + -0.114*"monetary" + '
#   '0.109*"annual" + -0.108*"analysis"'),
#  (39,
#   '-0.246*"level" + 0.170*"country" + 0.143*"reform" + -0.139*"october" + '
#   '-0.133*"market" + 0.114*"data" + 0.110*"january" + -0.105*"external" + '
#   '-0.103*"annual" + 0.101*"additional"'),
#  (40,
#   '0.154*"recent" + 0.151*"continued" + -0.142*"data" + -0.141*"september" + '
#   '-0.123*"demand" + 0.119*"ahead" + -0.117*"banknote" + 0.112*"first" + '
#   '-0.111*"information" + -0.106*"production"'),
#  (41,
#   '0.196*"may" + -0.162*"march" + 0.149*"remain" + 0.133*"outlook" + '
#   '-0.133*"development" + -0.132*"february" + 0.128*"today" + '
#   '-0.128*"continue" + -0.123*"market" + -0.120*"time"'),
#  (42,
#   '-0.197*"also" + 0.161*"continue" + -0.153*"first" + 0.152*"expected" + '
#   '0.129*"assessment" + 0.116*"support" + 0.111*"available" + '
#   '-0.108*"inflation" + 0.104*"impact" + 0.103*"particular"'),
#  (43,
#   '-0.156*"monetary" + -0.142*"oil" + 0.140*"ecb" + -0.131*"time" + '
#   '-0.129*"significant" + 0.125*"continued" + 0.112*"price" + 0.112*"past" + '
#   '-0.111*"would" + -0.111*"uncertainty"'),
#  (44,
#   '0.151*"recent" + -0.148*"point" + -0.146*"development" + 0.134*"outlook" + '
#   '-0.132*"basis" + -0.127*"expected" + 0.121*"high" + 0.111*"unchanged" + '
#   '0.111*"oil" + 0.107*"reform"'),
#  (45,
#   '-0.256*"quarter" + -0.167*"remains" + 0.134*"mainly" + 0.126*"time" + '
#   '0.120*"structural" + 0.114*"ongoing" + 0.112*"potential" + '
#   '-0.112*"expected" + 0.107*"pressure" + 0.104*"public"'),
#  (46,
#   '0.171*"overall" + -0.148*"moderate" + 0.144*"line" + -0.134*"support" + '
#   '0.132*"risk" + 0.121*"account" + -0.120*"increase" + -0.111*"january" + '
#   '0.111*"country" + 0.106*"real"'),
#  (47,
#   '-0.190*"quarter" + 0.138*"month" + 0.126*"mediumterm" + -0.126*"oil" + '
#   '-0.126*"inflation" + 0.122*"particular" + 0.121*"analysis" + -0.120*"year" '
#   '+ 0.118*"continued" + -0.115*"rise"'),
#  (48,
#   '0.163*"july" + -0.136*"current" + -0.134*"year" + -0.127*"month" + '
#   '0.125*"country" + -0.124*"confirmed" + 0.124*"growth" + -0.123*"october" + '
#   '0.109*"subdued" + -0.109*"march"'),
#  (49,
#   '-0.171*"overall" + 0.162*"would" + 0.137*"time" + 0.128*"area" + '
#   '-0.125*"also" + 0.125*"continued" + 0.116*"outlook" + -0.107*"factor" + '
#   '-0.101*"economy" + -0.100*"support"')]
# [(0,
#   '-0.295*"price" + -0.292*"euro" + -0.283*"growth" + -0.274*"area" + '
#   '-0.238*"rate" + -0.210*"monetary" + -0.208*"economic" + -0.168*"inflation" '
#   '+ -0.146*"development" + -0.138*"council"'),
#  (1,
#   '0.345*"council" + 0.313*"governing" + 0.218*"euro" + -0.203*"inflation" + '
#   '0.179*"ecb" + -0.151*"medium" + -0.138*"risk" + -0.138*"remain" + '
#   '-0.136*"economic" + -0.133*"analysis"'),
#  (2,
#   '-0.427*"price" + -0.244*"stability" + -0.214*"growth" + 0.195*"loan" + '
#   '0.164*"inflation" + 0.158*"measure" + 0.154*"policy" + -0.143*"development" '
#   '+ -0.142*"strong" + -0.135*"risk"'),
#  (3,
#   '-0.210*"monetary" + -0.205*"policy" + 0.185*"council" + 0.182*"medium" + '
#   '0.180*"governing" + -0.166*"area" + 0.163*"remain" + 0.157*"term" + '
#   '0.152*"financial" + 0.147*"pressure"'),
#  (4,
#   '-0.430*"euro" + -0.371*"area" + 0.237*"policy" + 0.196*"rate" + '
#   '0.185*"monetary" + 0.139*"recovery" + -0.138*"market" + 0.113*"measure" + '
#   '0.109*"governing" + -0.109*"underlying"'),
#  (5,
#   '-0.281*"market" + -0.274*"monetary" + -0.268*"financial" + 0.259*"rate" + '
#   '-0.241*"risk" + 0.154*"growth" + -0.140*"policy" + -0.133*"credit" + '
#   '-0.130*"money" + 0.130*"recovery"'),
#  (6,
#   '-0.457*"rate" + -0.192*"operation" + 0.169*"policy" + -0.159*"projection" + '
#   '0.141*"economic" + -0.136*"refinancing" + -0.134*"risk" + 0.119*"stability" '
#   '+ -0.117*"increase" + -0.116*"staff"'),
#  (7,
#   '0.351*"monetary" + -0.200*"inflation" + -0.194*"projection" + '
#   '-0.172*"financial" + -0.156*"effect" + 0.146*"remain" + 0.119*"ample" + '
#   '-0.118*"staff" + -0.112*"hicp" + 0.111*"increase"'),
#  (8,
#   '-0.312*"economic" + 0.294*"growth" + -0.235*"rate" + 0.186*"projection" + '
#   '0.159*"medium" + -0.148*"recent" + -0.138*"activity" + 0.135*"gdp" + '
#   '0.129*"governing" + 0.129*"staff"'),
#  (9,
#   '0.219*"pressure" + 0.207*"projection" + -0.197*"credit" + -0.170*"medium" + '
#   '0.166*"measure" + 0.161*"recent" + -0.157*"subdued" + -0.157*"rate" + '
#   '-0.153*"condition" + 0.148*"staff"'),
#  (10,
#   '-0.317*"price" + 0.316*"growth" + 0.253*"market" + 0.215*"financial" + '
#   '-0.194*"projection" + -0.131*"ecb" + -0.126*"euro" + 0.119*"uncertainty" + '
#   '-0.119*"staff" + 0.112*"month"'),
#  (11,
#   '-0.232*"projection" + 0.175*"growth" + -0.158*"staff" + -0.147*"economic" + '
#   '0.145*"price" + 0.136*"loan" + 0.130*"food" + 0.130*"energy" + 0.123*"may" '
#   '+ -0.112*"market"'),
#  (12,
#   '0.205*"measure" + 0.195*"euro" + 0.173*"area" + 0.160*"stability" + '
#   '-0.159*"market" + -0.144*"development" + -0.137*"projection" + '
#   '-0.133*"recent" + -0.133*"remain" + -0.129*"ecb"'),
#  (13,
#   '-0.245*"development" + -0.208*"price" + 0.181*"bank" + 0.171*"level" + '
#   '-0.170*"increase" + 0.151*"interest" + 0.133*"risk" + 0.131*"january" + '
#   '0.130*"central" + 0.129*"economic"'),
#  (14,
#   '-0.218*"economic" + 0.185*"oil" + 0.174*"december" + 0.159*"january" + '
#   '0.152*"development" + 0.145*"november" + 0.136*"price" + -0.131*"effect" + '
#   '-0.130*"expected" + -0.128*"may"'),
#  (15,
#   '-0.187*"may" + 0.169*"growth" + 0.166*"september" + -0.151*"march" + '
#   '-0.149*"euro" + 0.139*"october" + -0.136*"recent" + 0.136*"july" + '
#   '0.134*"price" + 0.131*"august"'),
#  (16,
#   '0.264*"inflation" + -0.176*"also" + -0.176*"operation" + -0.166*"economic" '
#   '+ 0.166*"ecb" + 0.158*"rate" + -0.137*"recovery" + -0.135*"march" + '
#   '-0.130*"council" + 0.125*"expectation"'),
#  (17,
#   '0.201*"market" + 0.193*"oil" + -0.192*"council" + -0.162*"governing" + '
#   '0.151*"national" + 0.144*"remain" + 0.130*"policy" + 0.126*"quarter" + '
#   '0.122*"need" + 0.121*"measure"'),
#  (18,
#   '-0.229*"economic" + 0.200*"risk" + 0.128*"low" + 0.127*"quarter" + '
#   '0.124*"analysis" + -0.123*"staff" + -0.120*"annual" + 0.118*"ongoing" + '
#   '-0.114*"financial" + -0.113*"activity"'),
#  (19,
#   '-0.202*"activity" + 0.154*"period" + 0.141*"continue" + 0.140*"market" + '
#   '0.130*"also" + -0.130*"december" + -0.121*"january" + 0.117*"fixed" + '
#   '-0.115*"november" + -0.111*"balance"'),
#  (20,
#   '-0.150*"information" + -0.136*"expected" + -0.134*"oil" + 0.133*"data" + '
#   '-0.128*"inflation" + 0.124*"interest" + 0.122*"development" + '
#   '-0.122*"upward" + 0.117*"economy" + -0.116*"effect"'),
#  (21,
#   '-0.202*"bank" + -0.194*"year" + -0.178*"activity" + 0.152*"stability" + '
#   '0.128*"market" + 0.122*"pillar" + -0.121*"national" + -0.117*"central" + '
#   '-0.117*"september" + -0.108*"also"'),
#  (22,
#   '0.194*"growth" + 0.176*"quarter" + 0.146*"since" + -0.128*"price" + '
#   '-0.124*"oil" + -0.121*"year" + -0.121*"recent" + -0.119*"remains" + '
#   '-0.117*"operation" + -0.112*"particular"'),
#  (23,
#   '-0.169*"operation" + -0.163*"medium" + 0.155*"expected" + -0.153*"term" + '
#   '-0.147*"eurosystem" + 0.140*"high" + -0.132*"decision" + 0.131*"annual" + '
#   '0.124*"january" + 0.120*"inflation"'),
#  (24,
#   '0.247*"year" + 0.215*"country" + -0.159*"also" + -0.156*"economy" + '
#   '-0.133*"term" + -0.132*"decision" + 0.122*"european" + -0.112*"medium" + '
#   '-0.108*"point" + 0.105*"annual"'),
#  (25,
#   '-0.170*"money" + 0.160*"march" + 0.140*"increase" + -0.130*"new" + '
#   '-0.129*"measure" + -0.128*"first" + -0.125*"growth" + -0.120*"credit" + '
#   '-0.119*"banknote" + 0.118*"policy"'),
#  (26,
#   '-0.184*"economic" + -0.159*"oil" + 0.146*"regard" + -0.137*"june" + '
#   '0.136*"recent" + -0.127*"market" + 0.115*"quarter" + -0.106*"council" + '
#   '-0.106*"moderate" + 0.101*"monetary"'),
#  (27,
#   '0.199*"level" + -0.170*"also" + -0.150*"oil" + -0.130*"rate" + '
#   '0.117*"stability" + -0.113*"pressure" + 0.109*"development" + '
#   '0.108*"interest" + 0.106*"economic" + 0.105*"projection"'),
#  (28,
#   '0.206*"development" + 0.177*"december" + 0.166*"policy" + -0.163*"increase" '
#   '+ 0.143*"year" + 0.137*"wage" + 0.135*"november" + -0.129*"september" + '
#   '-0.124*"economic" + -0.122*"recovery"'),
#  (29,
#   '0.173*"term" + 0.142*"risk" + 0.142*"medium" + -0.136*"strategy" + '
#   '0.133*"previous" + -0.128*"continued" + -0.122*"activity" + 0.121*"also" + '
#   '-0.119*"strong" + 0.119*"particular"'),
#  (30,
#   '-0.159*"first" + -0.140*"recent" + -0.129*"ecb" + -0.125*"key" + '
#   '0.118*"would" + 0.117*"main" + -0.116*"may" + -0.113*"mediumterm" + '
#   '-0.111*"however" + -0.111*"information"'),
#  (31,
#   '0.191*"year" + 0.149*"inflation" + 0.145*"reflecting" + -0.141*"area" + '
#   '-0.140*"shortterm" + -0.132*"support" + 0.125*"also" + -0.116*"time" + '
#   '-0.114*"mediumterm" + -0.114*"recovery"'),
#  (32,
#   '-0.150*"recovery" + -0.132*"available" + 0.127*"march" + -0.122*"first" + '
#   '0.122*"environment" + -0.119*"line" + 0.118*"remain" + -0.115*"financial" + '
#   '0.111*"increase" + 0.109*"structural"'),
#  (33,
#   '-0.244*"also" + -0.141*"remain" + -0.129*"still" + 0.120*"domestic" + '
#   '-0.117*"fiscal" + -0.114*"available" + 0.113*"demand" + -0.112*"period" + '
#   '-0.108*"january" + -0.107*"economy"'),
#  (34,
#   '-0.174*"july" + -0.144*"monetary" + -0.139*"economy" + -0.133*"continued" + '
#   '-0.133*"need" + 0.128*"first" + -0.127*"eurosystem" + 0.120*"price" + '
#   '0.119*"march" + 0.112*"inflation"'),
#  (35,
#   '-0.178*"increase" + -0.171*"year" + 0.153*"august" + 0.149*"economic" + '
#   '-0.130*"european" + -0.126*"therefore" + 0.123*"country" + 0.115*"first" + '
#   '-0.114*"april" + 0.113*"current"'),
#  (36,
#   '0.203*"would" + 0.159*"first" + 0.146*"policy" + -0.146*"inflation" + '
#   '0.128*"may" + -0.124*"recent" + 0.118*"pressure" + -0.115*"economic" + '
#   '0.114*"employment" + 0.111*"market"'),
#  (37,
#   '-0.195*"monetary" + -0.193*"remain" + -0.175*"recent" + 0.170*"fiscal" + '
#   '0.143*"loan" + 0.125*"price" + -0.116*"country" + -0.113*"impact" + '
#   '0.110*"looking" + -0.108*"level"'),
#  (38,
#   '-0.147*"remains" + -0.143*"continue" + 0.128*"year" + -0.125*"month" + '
#   '0.116*"recent" + -0.115*"expected" + -0.114*"april" + -0.113*"monetary" + '
#   '0.109*"annual" + -0.108*"analysis"'),
#  (39,
#   '0.247*"level" + -0.170*"country" + -0.143*"reform" + 0.140*"october" + '
#   '0.133*"market" + -0.114*"data" + -0.111*"january" + 0.105*"external" + '
#   '0.103*"annual" + -0.100*"additional"'),
#  (40,
#   '0.155*"recent" + 0.150*"continued" + -0.143*"data" + -0.141*"september" + '
#   '-0.124*"demand" + 0.118*"ahead" + -0.117*"banknote" + 0.111*"first" + '
#   '-0.110*"information" + -0.106*"production"'),
#  (41,
#   '-0.197*"may" + 0.162*"march" + -0.149*"remain" + -0.134*"outlook" + '
#   '0.134*"development" + 0.131*"february" + -0.129*"today" + 0.128*"continue" '
#   '+ 0.124*"market" + 0.121*"time"'),
#  (42,
#   '0.197*"also" + -0.161*"continue" + 0.153*"first" + -0.151*"expected" + '
#   '-0.130*"assessment" + -0.117*"support" + -0.112*"available" + '
#   '0.108*"inflation" + -0.104*"particular" + -0.104*"impact"'),
#  (43,
#   '0.157*"monetary" + 0.141*"oil" + -0.140*"ecb" + 0.132*"time" + '
#   '0.130*"significant" + -0.127*"continued" + -0.114*"past" + -0.112*"price" + '
#   '-0.111*"programme" + 0.111*"uncertainty"'),
#  (44,
#   '0.150*"recent" + -0.148*"point" + -0.145*"development" + 0.134*"outlook" + '
#   '-0.132*"basis" + -0.126*"expected" + 0.121*"high" + 0.113*"unchanged" + '
#   '0.111*"oil" + 0.106*"reform"'),
#  (45,
#   '0.253*"quarter" + 0.165*"remains" + -0.135*"mainly" + -0.122*"time" + '
#   '-0.120*"structural" + -0.114*"ongoing" + 0.111*"expected" + '
#   '-0.111*"potential" + -0.108*"pressure" + -0.104*"public"'),
#  (46,
#   '0.172*"overall" + -0.146*"moderate" + 0.144*"line" + -0.134*"support" + '
#   '0.132*"risk" + 0.121*"account" + -0.120*"increase" + -0.111*"january" + '
#   '0.111*"country" + 0.105*"real"'),
#  (47,
#   '-0.182*"quarter" + 0.144*"month" + -0.130*"oil" + 0.128*"mediumterm" + '
#   '-0.127*"inflation" + 0.123*"particular" + 0.119*"analysis" + -0.118*"rise" '
#   '+ -0.114*"year" + 0.113*"continued"'),
#  (48,
#   '-0.159*"july" + 0.139*"current" + 0.139*"year" + -0.126*"country" + '
#   '0.124*"october" + -0.123*"growth" + 0.120*"confirmed" + 0.119*"month" + '
#   '0.114*"high" + -0.112*"subdued"'),
#  (49,
#   '0.172*"overall" + -0.163*"would" + -0.140*"time" + -0.129*"area" + '
#   '-0.129*"continued" + 0.126*"also" + -0.117*"outlook" + 0.107*"factor" + '
#   '0.101*"economy" + -0.097*"medium"'),
#  (50,
#   '0.152*"remains" + -0.142*"january" + -0.131*"february" + 0.128*"april" + '
#   '0.126*"strong" + -0.123*"would" + 0.121*"labour" + -0.114*"inflation" + '
#   '-0.113*"early" + -0.106*"higher"'),
#  (51,
#   '-0.149*"support" + -0.145*"also" + -0.142*"available" + 0.131*"new" + '
#   '-0.115*"european" + 0.114*"condition" + 0.111*"market" + 0.109*"expected" + '
#   '0.108*"december" + -0.106*"october"'),
#  (52,
#   '0.169*"also" + 0.142*"risk" + 0.141*"impact" + 0.138*"may" + -0.125*"first" '
#   '+ -0.115*"continue" + 0.109*"point" + -0.103*"january" + -0.102*"remain" + '
#   '0.100*"still"'),
#  (53,
#   '0.178*"outlook" + 0.149*"well" + 0.144*"global" + -0.136*"economic" + '
#   '-0.127*"continued" + 0.118*"purchase" + -0.112*"assessment" + '
#   '-0.108*"previous" + -0.108*"quarter" + -0.108*"would"'),
#  (54,
#   '-0.134*"past" + 0.133*"particular" + 0.130*"effect" + -0.127*"term" + '
#   '0.126*"economy" + -0.124*"range" + 0.123*"account" + 0.122*"continue" + '
#   '0.121*"also" + -0.115*"reform"'),
#  (55,
#   '-0.163*"country" + -0.150*"risk" + -0.123*"also" + 0.114*"cost" + '
#   '-0.111*"expected" + 0.110*"trend" + 0.101*"credit" + -0.100*"purchase" + '
#   '0.094*"liquidity" + -0.094*"particular"'),
#  (56,
#   '0.220*"strong" + -0.127*"factor" + 0.124*"assessment" + -0.124*"policy" + '
#   '0.114*"country" + -0.113*"expected" + 0.104*"broadly" + 0.104*"structural" '
#   '+ 0.104*"continued" + 0.100*"following"'),
#  (57,
#   '-0.127*"purchase" + 0.126*"remains" + 0.120*"development" + 0.112*"year" + '
#   '-0.111*"gradual" + 0.110*"since" + 0.106*"stance" + 0.106*"line" + '
#   '-0.104*"continue" + -0.101*"given"'),
#  (58,
#   '0.153*"risk" + 0.150*"expected" + -0.144*"need" + -0.132*"decline" + '
#   '-0.125*"market" + -0.118*"overall" + 0.117*"past" + -0.116*"energy" + '
#   '0.115*"development" + -0.108*"low"'),
#  (59,
#   '-0.191*"continue" + -0.161*"increase" + 0.136*"line" + 0.131*"employment" + '
#   '-0.127*"fiscal" + -0.127*"information" + 0.118*"ensure" + -0.113*"loan" + '
#   '-0.111*"year" + 0.107*"overall"'),
#  (60,
#   '0.172*"recent" + -0.133*"time" + -0.128*"risk" + -0.122*"may" + '
#   '-0.112*"january" + 0.107*"treaty" + -0.105*"value" + 0.104*"global" + '
#   '0.097*"previous" + -0.095*"increase"'),
#  (61,
#   '0.138*"december" + -0.131*"assessment" + 0.121*"remain" + 0.119*"policy" + '
#   '0.116*"would" + 0.115*"quarter" + -0.106*"activity" + 0.106*"strong" + '
#   '-0.105*"previous" + -0.104*"past"'),
#  (62,
#   '0.147*"available" + 0.108*"december" + -0.105*"expected" + -0.104*"however" '
#   '+ 0.103*"development" + 0.096*"information" + -0.096*"ongoing" + '
#   '0.095*"programme" + 0.092*"interest" + -0.091*"region"'),
#  (63,
#   '-0.167*"would" + -0.149*"impact" + 0.138*"june" + -0.137*"march" + '
#   '0.112*"development" + -0.109*"data" + 0.108*"therefore" + -0.107*"somewhat" '
#   '+ 0.105*"continued" + -0.100*"looking"'),
#  (64,
#   '0.129*"remain" + -0.120*"treaty" + 0.120*"effect" + -0.114*"development" + '
#   '0.108*"inflation" + 0.108*"level" + -0.107*"government" + 0.104*"upward" + '
#   '-0.104*"term" + 0.100*"take"'),
#  (65,
#   '-0.158*"may" + -0.157*"risk" + 0.115*"second" + -0.113*"policy" + '
#   '0.112*"regard" + 0.110*"point" + -0.106*"period" + 0.104*"underlying" + '
#   '0.104*"outlook" + -0.097*"country"'),
#  (66,
#   '-0.132*"level" + -0.132*"consumer" + -0.127*"given" + 0.124*"recovery" + '
#   '0.116*"september" + 0.104*"recent" + 0.099*"support" + -0.097*"particular" '
#   '+ 0.094*"gdp" + 0.094*"moderate"'),
#  (67,
#   '0.132*"assessment" + -0.131*"annual" + -0.124*"credit" + -0.121*"reform" + '
#   '0.111*"regard" + 0.109*"february" + 0.098*"economy" + -0.097*"today" + '
#   '-0.095*"meeting" + 0.091*"year"'),
#  (68,
#   '-0.143*"outlook" + 0.131*"november" + 0.124*"growth" + -0.119*"impact" + '
#   '0.103*"banknote" + -0.098*"course" + 0.097*"continue" + 0.094*"subdued" + '
#   '-0.094*"remains" + 0.090*"increase"'),
#  (69,
#   '-0.128*"quarter" + 0.122*"credit" + -0.116*"july" + 0.113*"expectation" + '
#   '-0.112*"hicp" + 0.106*"confidence" + 0.094*"hand" + -0.094*"high" + '
#   '-0.092*"last" + 0.092*"stance"'),
#  (70,
#   '0.142*"effect" + -0.116*"implementation" + -0.116*"stability" + '
#   '-0.116*"ongoing" + 0.110*"monetary" + -0.102*"support" + 0.101*"next" + '
#   '0.098*"reflecting" + -0.096*"still" + -0.094*"regard"'),
#  (71,
#   '0.178*"improvement" + 0.124*"pressure" + 0.119*"asset" + 0.113*"purchase" + '
#   '0.101*"remained" + 0.100*"range" + 0.099*"level" + 0.094*"demand" + '
#   '0.093*"regard" + -0.090*"reform"'),
#  (72,
#   '-0.206*"still" + 0.124*"service" + -0.119*"reform" + -0.117*"private" + '
#   '-0.117*"following" + -0.113*"key" + -0.110*"purchase" + 0.106*"fiscal" + '
#   '0.104*"government" + -0.091*"uncertainty"'),
#  (73,
#   '0.182*"continue" + 0.132*"higher" + -0.125*"quarter" + -0.116*"adjustment" '
#   '+ -0.115*"hicp" + 0.109*"significantly" + -0.100*"remains" + -0.096*"tax" + '
#   '0.095*"environment" + 0.089*"june"'),
#  (74,
#   '0.166*"decline" + 0.127*"contribute" + -0.123*"uncertainty" + -0.105*"may" '
#   '+ -0.100*"economy" + 0.099*"level" + -0.096*"still" + 0.096*"end" + '
#   '0.093*"fiscal" + -0.092*"economic"'),
#  (75,
#   '0.141*"april" + 0.127*"rise" + 0.122*"continue" + 0.111*"expected" + '
#   '0.109*"economy" + -0.106*"sector" + -0.105*"continued" + 0.102*"need" + '
#   '-0.101*"ongoing" + -0.099*"treaty"'),
#  (76,
#   '-0.159*"moderate" + 0.149*"however" + 0.135*"september" + 0.126*"overall" + '
#   '0.118*"latest" + -0.109*"recovery" + -0.101*"outlook" + 0.098*"contribute" '
#   '+ 0.097*"adjustment" + 0.097*"second"'),
#  (77,
#   '0.170*"range" + 0.127*"month" + -0.123*"may" + -0.110*"sector" + '
#   '-0.101*"imbalance" + 0.097*"oil" + 0.094*"looking" + -0.093*"currently" + '
#   '-0.092*"adjustment" + 0.090*"overall"'),
#  (78,
#   '-0.141*"february" + -0.132*"factor" + -0.116*"asset" + -0.115*"high" + '
#   '0.113*"trend" + -0.113*"march" + 0.111*"economy" + -0.098*"outlook" + '
#   '-0.098*"analysis" + -0.098*"decline"'),
#  (79,
#   '0.126*"oil" + 0.124*"let" + -0.124*"increase" + 0.111*"need" + 0.104*"may" '
#   '+ -0.098*"deficit" + -0.096*"positive" + 0.094*"state" + -0.094*"line" + '
#   '0.091*"real"'),
#  (80,
#   '-0.159*"demand" + -0.147*"particular" + -0.120*"fiscal" + -0.112*"energy" + '
#   '0.110*"credit" + 0.109*"pressure" + -0.099*"continued" + -0.099*"may" + '
#   '0.097*"treaty" + 0.095*"appropriate"'),
#  (81,
#   '0.126*"month" + -0.111*"situation" + -0.110*"current" + -0.106*"outlook" + '
#   '-0.101*"ensure" + -0.097*"let" + -0.093*"improvement" + -0.093*"reflects" + '
#   '-0.092*"increased" + 0.090*"factor"'),
#  (82,
#   '0.137*"remains" + -0.135*"bank" + 0.117*"appropriate" + -0.112*"process" + '
#   '-0.099*"towards" + 0.099*"line" + -0.099*"however" + -0.097*"adjustment" + '
#   '0.093*"country" + 0.092*"available"'),
#  (83,
#   '0.139*"broadly" + -0.127*"uncertainty" + 0.108*"however" + 0.108*"continue" '
#   '+ -0.104*"information" + 0.098*"inflationary" + 0.094*"regard" + '
#   '-0.089*"shortterm" + -0.086*"upward" + -0.081*"april"'),
#  (84,
#   '-0.139*"however" + -0.134*"february" + 0.128*"moreover" + 0.110*"addition" '
#   '+ 0.107*"recent" + 0.105*"estimate" + -0.104*"labour" + 0.098*"european" + '
#   '0.091*"decline" + 0.091*"august"'),
#  (85,
#   '0.164*"country" + -0.134*"remained" + 0.131*"annual" + 0.124*"somewhat" + '
#   '0.111*"outlook" + -0.101*"employment" + -0.098*"perspective" + '
#   '-0.093*"still" + -0.089*"published" + 0.088*"time"'),
#  (86,
#   '-0.157*"unchanged" + 0.123*"confirmed" + -0.118*"mediumterm" + '
#   '0.106*"particular" + -0.104*"decision" + -0.100*"high" + 0.099*"fiscal" + '
#   '-0.097*"somewhat" + 0.096*"necessary" + 0.094*"august"'),
#  (87,
#   '-0.108*"sector" + 0.105*"expected" + 0.105*"country" + 0.100*"fully" + '
#   '0.097*"commodity" + -0.096*"outlook" + -0.096*"upward" + '
#   '-0.095*"particular" + 0.093*"november" + 0.092*"likely"'),
#  (88,
#   '-0.126*"current" + -0.125*"measure" + -0.119*"overall" + 0.107*"new" + '
#   '0.105*"continued" + -0.102*"energy" + -0.096*"owing" + -0.095*"stemming" + '
#   '0.091*"prevailing" + 0.091*"basis"'),
#  (89,
#   '0.124*"positive" + -0.112*"expected" + -0.108*"continues" + 0.100*"remain" '
#   '+ 0.094*"month" + 0.093*"treaty" + 0.089*"liquidity" + 0.088*"development" '
#   '+ 0.088*"outlook" + -0.087*"taking"'),
#  (90,
#   '-0.160*"continued" + -0.121*"decision" + -0.120*"august" + -0.102*"current" '
#   '+ 0.102*"increased" + -0.099*"remains" + -0.096*"upside" + 0.095*"october" '
#   '+ -0.095*"recently" + 0.092*"stability"'),
#  (91,
#   '-0.146*"available" + 0.123*"improvement" + -0.122*"continue" + 0.108*"data" '
#   '+ -0.105*"stronger" + 0.102*"sector" + 0.097*"important" + 0.094*"latest" + '
#   '0.093*"stability" + -0.085*"treaty"'),
#  (92,
#   '0.123*"would" + -0.114*"may" + 0.113*"cost" + -0.106*"close" + '
#   '-0.101*"important" + 0.098*"ecbs" + -0.092*"turning" + 0.091*"likely" + '
#   '-0.089*"effort" + -0.089*"budgetary"'),
#  (93,
#   '-0.123*"april" + 0.110*"expected" + 0.095*"therefore" + -0.095*"wage" + '
#   '0.093*"reflects" + -0.091*"employment" + 0.086*"recent" + 0.084*"time" + '
#   '-0.083*"activity" + -0.082*"regard"'),
#  (94,
#   '-0.124*"current" + 0.117*"government" + 0.114*"moreover" + -0.114*"april" + '
#   '0.106*"july" + 0.101*"october" + -0.101*"support" + 0.100*"measure" + '
#   '-0.095*"energy" + 0.093*"essential"'),
#  (95,
#   '-0.154*"level" + -0.114*"current" + 0.108*"remained" + -0.102*"information" '
#   '+ -0.099*"several" + -0.098*"sector" + -0.097*"december" + 0.095*"longterm" '
#   '+ -0.095*"may" + 0.093*"march"'),
#  (96,
#   '-0.140*"month" + 0.128*"measure" + -0.125*"policy" + 0.100*"service" + '
#   '0.091*"contribute" + 0.088*"objective" + -0.083*"low" + -0.082*"owing" + '
#   '0.082*"loan" + -0.082*"public"'),
#  (97,
#   '-0.115*"earlier" + 0.110*"tender" + -0.108*"year" + 0.103*"however" + '
#   '-0.096*"could" + 0.095*"particular" + 0.090*"june" + -0.088*"important" + '
#   '0.087*"strengthened" + -0.086*"last"'),
#  (98,
#   '-0.126*"february" + -0.125*"ongoing" + 0.116*"december" + -0.116*"october" '
#   '+ -0.096*"recovery" + 0.095*"stance" + -0.093*"week" + -0.091*"ahead" + '
#   '0.089*"may" + 0.088*"demand"'),
#  (99,
#   '-0.127*"strengthening" + -0.122*"september" + 0.121*"remains" + '
#   '0.110*"implementation" + -0.098*"owing" + 0.098*"activity" + '
#   '0.093*"potential" + 0.092*"effort" + 0.090*"adjustment" + '
#   '-0.088*"regarding"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lsi5 = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi5 = coherence_model_lsi5.get_coherence()
print('\nCoherence Score5: ', coherence_lsi5)

# Compute Coherence Score
coherence_model_lsi10 = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi10 = coherence_model_lsi10.get_coherence()
print('\nCoherence Score10: ', coherence_lsi10)

# Compute Coherence Score
coherence_model_lsi20 = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi20 = coherence_model_lsi20.get_coherence()
print('\nCoherence Score20: ', coherence_lsi20)

# Compute Coherence Score
coherence_model_lsi50 = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi50 = coherence_model_lsi50.get_coherence()
print('\nCoherence Score50: ', coherence_lsi50)

# Compute Coherence Score
coherence_model_lsi100 = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi100 = coherence_model_lsi100.get_coherence()
print('\nCoherence Score100: ', coherence_lsi100)


# Compute Coherence Score
coherence_model_lsi5 = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi5 = coherence_model_lsi5.get_coherence()
print('\nCoherence Score5: ', coherence_lsi5)

# Compute Coherence Score
coherence_model_lsi10 = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi10 = coherence_model_lsi10.get_coherence()
print('\nCoherence Score10: ', coherence_lsi10)

# Compute Coherence Score
coherence_model_lsi20 = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi20 = coherence_model_lsi20.get_coherence()
print('\nCoherence Score20: ', coherence_lsi20)

# Compute Coherence Score
coherence_model_lsi50 = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi50 = coherence_model_lsi50.get_coherence()
print('\nCoherence Score50: ', coherence_lsi50)

# Compute Coherence Score
coherence_model_lsi100 = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi100 = coherence_model_lsi100.get_coherence()
print('\nCoherence Score100: ', coherence_lsi100)
# Out:
# Coherence Score5:  0.3691233118088902
#
# Coherence Score10:  0.3555174860499063
#
# Coherence Score20:  0.32575777684930585
#
# Coherence Score50:  0.28429565008054136
#
# Coherence Score100:  0.24192668567307493
#
# Coherence Score5:  -0.19777492561186288
#
# Coherence Score10:  -0.33689213931847484
#
# Coherence Score20:  -0.40970656842580705
#
# Coherence Score50:  -0.8026707863601348
#
# Coherence Score100:  -0.6933009564878162
