# %% [markdown]
# # Set up imports

# %%
# setting up our imports
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.models import LdaModel, LdaMulticore
import gensim.downloader as api
from gensim.models import LsiModel
from gensim.models import ldaseqmodel
from gensim.corpora import Dictionary, bleicorpus
from gensim.matutils import hellinger

nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools 
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
#import logging
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
#logging.root.setLevel(level=logging.INFO)
#import warnings
#warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # load dataset

# %%
# Load dataset
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
# Drop the columns not needed
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\defusedxml\ElementTree.py:68: DeprecationWarning: The html argument of XMLParser() is deprecated
#   _XMLParser.__init__(self, html, target, encoding)
# C:\Users\Kornelius\Anaconda3\lib\site-packages\defusedxml\ElementTree.py:68: DeprecationWarning: The html argument of XMLParser() is deprecated
#   _XMLParser.__init__(self, html, target, encoding)
# C:\Users\Kornelius\Anaconda3\lib\site-packages\defusedxml\ElementTree.py:68: DeprecationWarning: The html argument of XMLParser() is deprecated
#   _XMLParser.__init__(self, html, target, encoding)
# C:\Users\Kornelius\Anaconda3\lib\site-packages\defusedxml\ElementTree.py:68: DeprecationWarning: The html argument of XMLParser() is deprecated
#   _XMLParser.__init__(self, html, target, encoding)
# C:\Users\Kornelius\Anaconda3\lib\site-packages\defusedxml\ElementTree.py:68: DeprecationWarning: The html argument of XMLParser() is deprecated
#   _XMLParser.__init__(self, html, target, encoding)
# C:\Users\Kornelius\Anaconda3\lib\site-packages\defusedxml\ElementTree.py:68: DeprecationWarning: The html argument of XMLParser() is deprecated
#   _XMLParser.__init__(self, html, target, encoding)

# %%
df['word_count'] = df['qa'].apply(lambda x: len(str(x).split(" ")))
df[['qa','word_count']].head()
df.word_count.describe()
# Out:
# count     205.000000
# mean     3022.404878
# std      1041.743884
# min       656.000000
# 25%      2182.000000
# 50%      3210.000000
# 75%      3800.000000
# max      5269.000000
# Name: word_count, dtype: float64

# %%
# sort by year
df = df.sort_values(by=['Date'])
df
# Out:
#      Date                                              Press  \
# 0    1998  Ladies and gentlemen, in line with our stated ...
# 1    1998  Ladies and gentlemen, as in previous months, t...
# 2    1998  Ladies and gentlemen, the Vice-President and I...
# 3    1998  Ladies and gentlemen, the Vice-President and I...
# 14   1999  Ladies and gentlemen, the Vice-President and I...
# 13   1999  Ladies and gentlemen,\nthe Vice-President and ...
# 12   1999  Ladies and gentlemen,\nthe Vice-President and ...
# 11   1999  Ladies and gentlemen, the Vice-President and I...
# 9    1999  Ladies and gentlemen, the Vice-President and I...
# 10   1999  Ladies and gentlemen, the Vice-President and I...
# 7    1999  Ladies and gentlemen, the Vice-President and I...
# 6    1999  Ladies and gentlemen, the Vice-President and I...
# 5    1999  Ladies and gentlemen, the Vice-President and I...
# 4    1999  Ladies and gentlemen, the Vice-President and I...
# 8    1999  Ladies and gentlemen, the Vice-President and I...
# 22   2000  Ladies and gentlemen, the Vice-President and I...
# 27   2000  Ladies and gentlemen, the Vice-President and I...
# 25   2000  Ladies and gentlemen,\nToday, the Governing Co...
# 24   2000  Ladies and gentlemen, the Vice-President and I...
# 23   2000  Ladies and gentlemen, the Vice-President and I...
# 21   2000  Ladies and gentlemen, the Vice-President and I...
# 26   2000  Ladies and gentlemen, the Vice-President and I...
# 19   2000  Ladies and gentlemen, the Vice-President and I...
# 18   2000  Ladies and gentlemen, today, the Governing Cou...
# 17   2000  Ladies and gentlemen, the Vice-President and I...
# 16   2000  Ladies and gentlemen,\nthe Vice-President and ...
# ..                                                 ...         ...
# 165  The decision was unanimous. And I can spend so...        3746
# 170  At today’s meeting, we had an ample discussion...        4683
# 188  On the first question, you see, you are in a v...        3818
# 186  First of all, all the details, almost all the ...        3659
# 185  The answer to the first question is no. It was...        3772
# 184  Indeed, the TLTROs will enhance our monetary p...        4398
# 183   Really, I don't think I ever made an explicit...        4463
# 187  I’ll answer both questions by reading the stat...        2847
# 181  Yes. On the first question, the too prolonged ...        2844
# 180  I think you have rightly pointed to the key se...        4213
# 179  The reasons for today’s Governing Council deci...        4190
# 178  The discussion today was a broad discussion. I...        4365
# 177  Yes, you are right. We have used firmer words ...        3906
# 182  On the first question, I would say that for al...        3193
# 196  Let me tell you how we came to take the decisi...        3470
# 195  On the first issue, I'm really commenting only...        3756
# 194  We may see negative numbers of inflation in th...        3226
# 193  The decision to raise ELA today is symmetrical...        4271
# 191   I think the answer to your question is entire...        4393
# 190   The sustained improvement, it just says what ...        2963
# 189  The answer to the first question, yes we will ...        3536
# 192  On your first question, the answer is no, beca...        3304
# 203  The answer to the second question is no, there...        2311
# 197  I will ask Mr Constâncio to answer the second ...        3593
# 198  On the TLTRO I just can give you a brief overv...        4225
# 199  You'll get all the details of the corporate pr...        3383
# 200  To the first question I'll answer, basically, ...        3424
# 201  As I said before, we discussed the general eco...        4733
# 202  We tasked the relevant committees to work, as ...        2026
# 204  Yes, the two options that have been presented ...        3279
#
# [205 rows x 4 columns]

# %%
df.Date.value_counts()
# Out:
# 2000    13
# 2007    12
# 2014    12
# 2013    12
# 2012    12
# 2011    12
# 2010    12
# 2009    12
# 2008    12
# 2006    12
# 1999    11
# 2005    11
# 2004    11
# 2003    11
# 2002    11
# 2001     9
# 2016     8
# 2015     8
# 1998     4
# Name: Date, dtype: int64

# %%
# sort by year
data = df['qa']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(data):
    stop_free = " ".join([i for i in data.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(data).split() for data in data]

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
ps = PorterStemmer()
def clean(data):
    stop_free = " ".join([i for i in data.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(ps.stem(word) for word in punc_free.split())
    return normalized

data = [clean(data).split() for data in data]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
from nltk.probability import FreqDist
result = str(data_words).strip('[]')
freq = pd.Series(''.join(result).split()).value_counts()[:50]
freq
# turn series into df
df = freq.to_frame().reset_index()
df.columns = ['words','counts']
# draw graph
ax = df.plot.bar(x='words', y='counts', rot=0, figsize=(50,30))


plt.xticks(size = 50)
plt.xticks(rotation=90)
plt.yticks(size = 40)
# Out:
# (array([   0.,  500., 1000., 1500., 2000., 2500., 3000., 3500.]),
#  <a list of 8 Text yticklabel objects>)

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(8371 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# less than 10 documents,
id2word = corpora.Dictionary(data)
id2word.filter_extremes(no_above = 0.90)
print((id2word))
# Out:
# Dictionary(3434 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
dir(id2word)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_adapt_by_suffix',
#  '_load_specials',
#  '_save_specials',
#  '_smart_save',
#  'add_documents',
#  'compactify',
#  'dfs',
#  'doc2bow',
#  'doc2idx',
#  'filter_extremes',
#  'filter_n_most_frequent',
#  'filter_tokens',
#  'from_corpus',
#  'from_documents',
#  'get',
#  'id2token',
#  'items',
#  'iteritems',
#  'iterkeys',
#  'itervalues',
#  'keys',
#  'load',
#  'load_from_text',
#  'merge_with',
#  'num_docs',
#  'num_nnz',
#  'num_pos',
#  'save',
#  'save_as_text',
#  'token2id',
#  'values']

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]
# Out:
# Dictionary(8371 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
from gensim.models import ldaseqmodel
import numpy
from gensim.matutils import hellinger

# %%
time_slice = [4 , 11, 13, 9, 11, 11, 11, 11, 12, 12, 12, 12, 12, 12, 12, 12, 12, 8, 8]
