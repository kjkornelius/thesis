# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['Press']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(4394 unique tokens: ['able', 'acceptable', 'accompanied', 'according', 'account']...)

# %%
# filter words that occur in more than 90% of documents
id2word.filter_extremes(no_above = 0.990)
print(id2word)
# Out:
# Dictionary(1972 unique tokens: ['able', 'accompanied', 'according', 'account', 'achievement']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=1, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
lda_model5 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model10 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model20 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model50 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=50, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model100 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=100, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\models\ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
# Print the Keyword in the 1 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.015*"inflation" + 0.010*"annual" + 0.008*"risk" + 0.007*"loan" + '
#   '0.007*"also" + 0.007*"analysis" + 0.007*"measure" + 0.007*"continue" + '
#   '0.007*"stability" + 0.007*"quarter"')]

# %%
# Print the Keyword in the 5 topics
pprint(lda_model5.print_topics())
doc_lda = lda_model5[corpus]

# Print the Keyword in the 10 topics
pprint(lda_model10.print_topics())
doc_lda = lda_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lda_model20.print_topics())
doc_lda = lda_model20[corpus]

# Print the Keyword in the 50 topics
pprint(lda_model50.print_topics())
doc_lda = lda_model50[corpus]

# Print the Keyword in the 100 topics
pprint(lda_model100.print_topics())
doc_lda = lda_model100[corpus]
# Out:
# [(0,
#   '0.014*"inflation" + 0.013*"risk" + 0.011*"medium" + 0.010*"term" + '
#   '0.010*"stability" + 0.009*"remain" + 0.009*"analysis" + 0.007*"annual" + '
#   '0.007*"fiscal" + 0.006*"financial"'),
#  (1,
#   '0.015*"loan" + 0.012*"subdued" + 0.012*"annual" + 0.012*"inflation" + '
#   '0.010*"financial" + 0.010*"operation" + 0.009*"expected" + '
#   '0.008*"nonfinancial" + 0.008*"sheet" + 0.008*"bank"'),
#  (2,
#   '0.018*"inflation" + 0.014*"annual" + 0.012*"loan" + 0.012*"recovery" + '
#   '0.012*"measure" + 0.010*"quarter" + 0.010*"structural" + 0.010*"reform" + '
#   '0.009*"continue" + 0.008*"also"'),
#  (3,
#   '0.011*"stability" + 0.009*"also" + 0.008*"ecb" + 0.008*"recent" + '
#   '0.007*"year" + 0.007*"increase" + 0.006*"level" + 0.006*"first" + '
#   '0.005*"oil" + 0.005*"risk"'),
#  (4,
#   '0.020*"inflation" + 0.017*"purchase" + 0.015*"annual" + 0.010*"measure" + '
#   '0.009*"recovery" + 0.009*"outlook" + 0.009*"reform" + 0.009*"structural" + '
#   '0.009*"also" + 0.008*"september"')]
# [(0,
#   '0.016*"inflation" + 0.010*"annual" + 0.010*"loan" + 0.010*"financial" + '
#   '0.009*"risk" + 0.009*"analysis" + 0.008*"term" + 0.008*"remain" + '
#   '0.008*"fiscal" + 0.007*"continue"'),
#  (1,
#   '0.001*"inflation" + 0.001*"stability" + 0.001*"term" + 0.001*"risk" + '
#   '0.001*"annual" + 0.001*"remain" + 0.001*"year" + 0.001*"expected" + '
#   '0.001*"analysis" + 0.001*"medium"'),
#  (2,
#   '0.001*"inflation" + 0.001*"risk" + 0.001*"reform" + 0.001*"annual" + '
#   '0.001*"also" + 0.001*"continue" + 0.001*"stability" + 0.001*"real" + '
#   '0.001*"level" + 0.001*"medium"'),
#  (3,
#   '0.015*"medium" + 0.012*"inflation" + 0.012*"remain" + 0.012*"term" + '
#   '0.011*"stability" + 0.010*"risk" + 0.009*"analysis" + 0.008*"expected" + '
#   '0.008*"annual" + 0.008*"credit"'),
#  (4,
#   '0.018*"inflation" + 0.014*"annual" + 0.012*"recovery" + 0.011*"measure" + '
#   '0.011*"loan" + 0.010*"quarter" + 0.010*"structural" + 0.010*"reform" + '
#   '0.009*"also" + 0.008*"continue"'),
#  (5,
#   '0.001*"ecb" + 0.001*"also" + 0.001*"recent" + 0.001*"stability" + '
#   '0.001*"strategy" + 0.001*"year" + 0.001*"risk" + 0.001*"first" + '
#   '0.001*"state" + 0.001*"inflation"'),
#  (6,
#   '0.008*"actively" + 0.001*"cash" + 0.001*"changeover" + 0.001*"noticeable" + '
#   '0.001*"coin" + 0.001*"fuel" + 0.001*"trading" + 0.001*"organised" + '
#   '0.001*"calendar" + 0.001*"campaign"'),
#  (7,
#   '0.070*"projection" + 0.055*"staff" + 0.053*"july" + 0.044*"june" + '
#   '0.026*"macroeconomic" + 0.022*"gdp" + 0.016*"real" + 0.015*"rise" + '
#   '0.015*"annual" + 0.015*"slightly"'),
#  (8,
#   '0.013*"ecb" + 0.009*"first" + 0.008*"also" + 0.008*"stability" + '
#   '0.007*"bank" + 0.007*"increase" + 0.007*"decision" + 0.007*"central" + '
#   '0.006*"january" + 0.006*"year"'),
#  (9,
#   '0.015*"stability" + 0.012*"risk" + 0.011*"inflation" + 0.009*"recent" + '
#   '0.009*"also" + 0.008*"level" + 0.008*"term" + 0.008*"oil" + 0.007*"fiscal" '
#   '+ 0.007*"medium"')]
# [(0,
#   '0.016*"inflation" + 0.011*"financial" + 0.010*"annual" + 0.010*"risk" + '
#   '0.009*"medium" + 0.009*"analysis" + 0.009*"remain" + 0.008*"term" + '
#   '0.008*"loan" + 0.008*"expected"'),
#  (1,
#   '0.001*"stability" + 0.001*"inflation" + 0.001*"risk" + 0.001*"year" + '
#   '0.001*"also" + 0.001*"level" + 0.001*"oil" + 0.001*"term" + 0.001*"recent" '
#   '+ 0.001*"fiscal"'),
#  (2,
#   '0.001*"stability" + 0.001*"risk" + 0.001*"inflation" + 0.001*"also" + '
#   '0.001*"increase" + 0.001*"level" + 0.001*"medium" + 0.001*"reform" + '
#   '0.001*"oil" + 0.001*"year"'),
#  (3,
#   '0.017*"stability" + 0.014*"risk" + 0.011*"inflation" + 0.009*"medium" + '
#   '0.008*"increase" + 0.008*"term" + 0.008*"level" + 0.008*"also" + '
#   '0.008*"strong" + 0.007*"recent"'),
#  (4,
#   '0.031*"smoothing" + 0.000*"indexed" + 0.000*"stability" + 0.000*"risk" + '
#   '0.000*"alter" + 0.000*"ecb" + 0.000*"recent" + 0.000*"also" + '
#   '0.000*"consumer" + 0.000*"first"'),
#  (5,
#   '0.001*"also" + 0.001*"stability" + 0.001*"ecb" + 0.001*"year" + '
#   '0.001*"risk" + 0.001*"recent" + 0.001*"inflation" + 0.001*"first" + '
#   '0.001*"level" + 0.001*"term"'),
#  (6,
#   '0.001*"stability" + 0.001*"also" + 0.001*"year" + 0.001*"ecb" + '
#   '0.001*"inflation" + 0.001*"recent" + 0.001*"first" + 0.001*"risk" + '
#   '0.001*"increase" + 0.001*"month"'),
#  (7,
#   '0.001*"stability" + 0.001*"also" + 0.001*"inflation" + 0.001*"risk" + '
#   '0.001*"year" + 0.001*"medium" + 0.001*"reform" + 0.001*"annual" + '
#   '0.001*"level" + 0.001*"term"'),
#  (8,
#   '0.001*"stability" + 0.001*"risk" + 0.001*"also" + 0.001*"recent" + '
#   '0.001*"term" + 0.001*"ecb" + 0.001*"level" + 0.001*"increase" + '
#   '0.001*"inflation" + 0.001*"first"'),
#  (9,
#   '0.001*"stability" + 0.001*"inflation" + 0.001*"term" + 0.001*"risk" + '
#   '0.001*"medium" + 0.001*"also" + 0.001*"increase" + 0.001*"annual" + '
#   '0.001*"year" + 0.001*"fiscal"'),
#  (10,
#   '0.001*"projection" + 0.001*"inflation" + 0.001*"risk" + 0.001*"annual" + '
#   '0.001*"also" + 0.001*"term" + 0.001*"stability" + 0.001*"reform" + '
#   '0.001*"ecb" + 0.001*"continue"'),
#  (11,
#   '0.021*"loan" + 0.014*"recovery" + 0.014*"inflation" + 0.012*"measure" + '
#   '0.011*"march" + 0.011*"annual" + 0.011*"quarter" + 0.011*"april" + '
#   '0.010*"reform" + 0.010*"structural"'),
#  (12,
#   '0.017*"term" + 0.014*"remain" + 0.013*"medium" + 0.012*"pressure" + '
#   '0.012*"recovery" + 0.010*"inflationary" + 0.009*"inflation" + '
#   '0.008*"analysis" + 0.008*"low" + 0.008*"also"'),
#  (13,
#   '0.001*"stability" + 0.001*"year" + 0.001*"risk" + 0.001*"also" + '
#   '0.001*"term" + 0.001*"fiscal" + 0.001*"inflation" + 0.001*"analysis" + '
#   '0.001*"ecb" + 0.001*"medium"'),
#  (14,
#   '0.001*"stability" + 0.001*"year" + 0.001*"recent" + 0.001*"term" + '
#   '0.001*"ecb" + 0.001*"increase" + 0.001*"inflation" + 0.001*"also" + '
#   '0.001*"annual" + 0.001*"oil"'),
#  (15,
#   '0.001*"recent" + 0.001*"stability" + 0.001*"reform" + 0.001*"member" + '
#   '0.001*"inflation" + 0.001*"also" + 0.001*"annual" + 0.001*"satisfactory" + '
#   '0.001*"outlook" + 0.001*"risk"'),
#  (16,
#   '0.013*"ecb" + 0.009*"first" + 0.009*"also" + 0.007*"year" + '
#   '0.007*"stability" + 0.007*"decision" + 0.007*"recent" + 0.007*"financial" + '
#   '0.006*"bank" + 0.006*"january"'),
#  (17,
#   '0.001*"stability" + 0.001*"inflation" + 0.001*"medium" + 0.001*"risk" + '
#   '0.001*"level" + 0.001*"also" + 0.001*"increase" + 0.001*"term" + '
#   '0.001*"economy" + 0.001*"financial"'),
#  (18,
#   '0.001*"stability" + 0.001*"inflation" + 0.001*"risk" + 0.001*"also" + '
#   '0.001*"term" + 0.001*"increase" + 0.001*"annual" + 0.001*"medium" + '
#   '0.001*"level" + 0.001*"remain"'),
#  (19,
#   '0.020*"inflation" + 0.015*"annual" + 0.011*"measure" + 0.011*"recovery" + '
#   '0.010*"purchase" + 0.010*"structural" + 0.010*"quarter" + 0.010*"reform" + '
#   '0.009*"also" + 0.008*"continue"')]
# [(24,
#   '0.001*"stability" + 0.001*"risk" + 0.001*"also" + 0.001*"ecb" + '
#   '0.001*"annual" + 0.001*"year" + 0.001*"country" + 0.001*"medium" + '
#   '0.001*"increase" + 0.001*"first"'),
#  (5,
#   '0.001*"ecb" + 0.001*"also" + 0.001*"risk" + 0.001*"first" + 0.001*"year" + '
#   '0.001*"stability" + 0.001*"recent" + 0.001*"term" + 0.001*"inflation" + '
#   '0.001*"level"'),
#  (6,
#   '0.001*"stability" + 0.001*"year" + 0.001*"also" + 0.001*"ecb" + '
#   '0.001*"recent" + 0.001*"first" + 0.001*"risk" + 0.001*"data" + '
#   '0.001*"increase" + 0.001*"month"'),
#  (35,
#   '0.001*"stability" + 0.001*"ecb" + 0.001*"also" + 0.001*"first" + '
#   '0.001*"medium" + 0.001*"level" + 0.001*"year" + 0.001*"increase" + '
#   '0.001*"economy" + 0.001*"bank"'),
#  (40,
#   '0.001*"stability" + 0.001*"risk" + 0.001*"inflation" + 0.001*"country" + '
#   '0.001*"also" + 0.001*"medium" + 0.001*"remain" + 0.001*"term" + 0.001*"oil" '
#   '+ 0.001*"recent"'),
#  (1,
#   '0.001*"stability" + 0.001*"inflation" + 0.001*"risk" + 0.001*"also" + '
#   '0.001*"term" + 0.001*"oil" + 0.001*"level" + 0.001*"year" + 0.001*"country" '
#   '+ 0.001*"remain"'),
#  (13,
#   '0.001*"year" + 0.001*"also" + 0.001*"risk" + 0.001*"stability" + '
#   '0.001*"however" + 0.001*"term" + 0.001*"ecb" + 0.001*"fiscal" + '
#   '0.001*"analysis" + 0.001*"inflation"'),
#  (2,
#   '0.001*"stability" + 0.001*"risk" + 0.001*"also" + 0.001*"increase" + '
#   '0.001*"inflation" + 0.001*"medium" + 0.001*"term" + 0.001*"outlook" + '
#   '0.001*"level" + 0.001*"oil"'),
#  (33,
#   '0.001*"stability" + 0.001*"also" + 0.001*"risk" + 0.001*"oil" + '
#   '0.001*"term" + 0.001*"inflation" + 0.001*"increase" + 0.001*"year" + '
#   '0.001*"ecb" + 0.001*"level"'),
#  (8,
#   '0.001*"stability" + 0.001*"also" + 0.001*"risk" + 0.001*"ecb" + '
#   '0.001*"term" + 0.001*"level" + 0.001*"recent" + 0.001*"year" + '
#   '0.001*"increase" + 0.001*"inflation"'),
#  (4,
#   '0.107*"mfis" + 0.065*"referred" + 0.000*"stability" + 0.000*"risk" + '
#   '0.000*"ecb" + 0.000*"also" + 0.000*"inflation" + 0.000*"financial" + '
#   '0.000*"increase" + 0.000*"ncbs"'),
#  (36,
#   '0.070*"alter" + 0.060*"reallocation" + 0.017*"examined" + 0.002*"spending" '
#   '+ 0.001*"efficiently" + 0.000*"pillar" + 0.000*"occurred" + '
#   '0.000*"portfolio" + 0.000*"concluded" + 0.000*"moderation"'),
#  (39,
#   '0.082*"value" + 0.070*"reference" + 0.050*"waning" + 0.047*"continuously" + '
#   '0.047*"ecbs" + 0.039*"accession" + 0.034*"paper" + 0.033*"course" + '
#   '0.026*"entail" + 0.025*"official"'),
#  (20,
#   '0.077*"banknote" + 0.077*"uneven" + 0.072*"changeover" + 0.055*"coin" + '
#   '0.053*"cash" + 0.050*"information" + 0.043*"treaty" + 0.038*"pillar" + '
#   '0.032*"process" + 0.027*"campaign"'),
#  (30,
#   '0.064*"below" + 0.063*"securitisation" + 0.055*"funding" + 0.052*"banks" + '
#   '0.050*"transmission" + 0.036*"intensification" + 0.036*"mros" + '
#   '0.031*"rehn" + 0.030*"sovereign" + 0.030*"fragmentation"'),
#  (25,
#   '0.022*"stability" + 0.018*"recent" + 0.017*"oil" + 0.016*"consumer" + '
#   '0.012*"first" + 0.012*"also" + 0.011*"ecb" + 0.011*"however" + '
#   '0.011*"pillar" + 0.011*"wage"'),
#  (41,
#   '0.508*"infrastructure" + 0.100*"corresponding" + 0.030*"specify" + '
#   '0.023*"suffer" + 0.022*"act" + 0.021*"transfer" + 0.017*"calendar" + '
#   '0.017*"find" + 0.014*"issuance" + 0.014*"journal"'),
#  (23,
#   '0.013*"ecb" + 0.013*"operation" + 0.013*"bank" + 0.009*"financial" + '
#   '0.009*"january" + 0.008*"refinancing" + 0.008*"decision" + 0.008*"also" + '
#   '0.008*"first" + 0.008*"decided"'),
#  (0,
#   '0.014*"risk" + 0.013*"medium" + 0.012*"term" + 0.012*"inflation" + '
#   '0.011*"stability" + 0.010*"remain" + 0.008*"analysis" + 0.007*"expected" + '
#   '0.007*"financial" + 0.007*"expectation"'),
#  (48,
#   '0.019*"inflation" + 0.015*"annual" + 0.012*"loan" + 0.012*"measure" + '
#   '0.011*"recovery" + 0.010*"quarter" + 0.010*"structural" + 0.010*"reform" + '
#   '0.009*"continue" + 0.008*"also"')]
# [(30,
#   '0.001*"essential" + 0.001*"extend" + 0.001*"detrimental" + 0.001*"dominant" '
#   '+ 0.001*"effectively" + 0.001*"emergence" + 0.001*"cut" + '
#   '0.001*"eventually" + 0.001*"fundamental" + 0.001*"flexible"'),
#  (24,
#   '0.001*"risk" + 0.001*"oil" + 0.001*"stability" + 0.001*"medium" + '
#   '0.001*"particular" + 0.001*"year" + 0.001*"quarter" + 0.001*"annual" + '
#   '0.001*"projection" + 0.001*"also"'),
#  (40,
#   '0.001*"risk" + 0.001*"oil" + 0.001*"inflation" + 0.001*"stability" + '
#   '0.001*"also" + 0.001*"remain" + 0.001*"medium" + 0.001*"month" + '
#   '0.001*"term" + 0.001*"quarter"'),
#  (80,
#   '0.001*"ecb" + 0.001*"stability" + 0.001*"central" + 0.001*"ncbs" + '
#   '0.001*"year" + 0.001*"risk" + 0.001*"escb" + 0.001*"reference" + '
#   '0.001*"financial" + 0.001*"outlook"'),
#  (5,
#   '0.001*"ecb" + 0.001*"first" + 0.001*"also" + 0.001*"january" + 0.001*"bank" '
#   '+ 0.001*"national" + 0.001*"decision" + 0.001*"stability" + 0.001*"value" + '
#   '0.001*"data"'),
#  (57,
#   '0.001*"stability" + 0.001*"also" + 0.001*"term" + 0.001*"ecb" + '
#   '0.001*"risk" + 0.001*"increase" + 0.001*"first" + 0.001*"credit" + '
#   '0.001*"oil" + 0.001*"would"'),
#  (35,
#   '0.001*"stability" + 0.001*"ecb" + 0.001*"fiscal" + 0.001*"recent" + '
#   '0.001*"first" + 0.001*"economy" + 0.001*"value" + 0.001*"also" + '
#   '0.001*"reference" + 0.001*"bank"'),
#  (83,
#   '0.001*"ecb" + 0.001*"stability" + 0.001*"year" + 0.001*"bank" + '
#   '0.001*"regard" + 0.001*"banknote" + 0.001*"information" + 0.001*"central" + '
#   '0.001*"also" + 0.001*"month"'),
#  (1,
#   '0.001*"bank" + 0.001*"ecb" + 0.001*"stability" + 0.001*"central" + '
#   '0.001*"national" + 0.001*"also" + 0.001*"information" + 0.001*"banknote" + '
#   '0.001*"year" + 0.001*"inflation"'),
#  (84,
#   '0.001*"increase" + 0.001*"february" + 0.001*"stability" + 0.001*"country" + '
#   '0.001*"recent" + 0.001*"trend" + 0.001*"month" + 0.001*"oil" + '
#   '0.001*"decision" + 0.001*"strong"'),
#  (41,
#   '0.051*"day" + 0.047*"published" + 0.042*"ecb" + 0.040*"decision" + '
#   '0.038*"press" + 0.038*"trend" + 0.035*"changeover" + 0.034*"value" + '
#   '0.033*"official" + 0.031*"legal"'),
#  (76,
#   '0.221*"operation" + 0.158*"refinancing" + 0.127*"fixed" + 0.082*"tender" + '
#   '0.080*"allotment" + 0.037*"sale" + 0.034*"threemonth" + 0.031*"settled" + '
#   '0.026*"counterparties" + 0.025*"stabilised"'),
#  (52,
#   '0.209*"turned" + 0.052*"exert" + 0.048*"inter" + 0.048*"alia" + '
#   '0.047*"plausible" + 0.045*"returning" + 0.041*"believe" + 0.040*"prudent" + '
#   '0.039*"windfall" + 0.032*"update"'),
#  (69,
#   '0.101*"financial" + 0.065*"tension" + 0.050*"turmoil" + 0.040*"uncertainty" '
#   '+ 0.024*"course" + 0.023*"shortterm" + 0.023*"world" + 0.023*"decision" + '
#   '0.019*"globally" + 0.018*"commodity"'),
#  (56,
#   '0.036*"stability" + 0.030*"pillar" + 0.026*"strategy" + 0.023*"second" + '
#   '0.019*"exchange" + 0.019*"first" + 0.018*"however" + 0.017*"wage" + '
#   '0.017*"year" + 0.016*"member"'),
#  (23,
#   '0.020*"january" + 0.019*"bank" + 0.018*"ecb" + 0.018*"main" + '
#   '0.015*"increase" + 0.015*"eurosystem" + 0.015*"first" + 0.015*"facility" + '
#   '0.015*"point" + 0.014*"consumer"'),
#  (66,
#   '0.013*"term" + 0.013*"medium" + 0.012*"remain" + 0.011*"inflation" + '
#   '0.010*"expected" + 0.009*"expectation" + 0.009*"financial" + 0.009*"line" + '
#   '0.009*"pressure" + 0.008*"may"'),
#  (0,
#   '0.019*"stability" + 0.018*"risk" + 0.011*"medium" + 0.010*"term" + '
#   '0.009*"strong" + 0.009*"upside" + 0.008*"inflation" + 0.008*"increase" + '
#   '0.007*"level" + 0.007*"analysis"'),
#  (68,
#   '0.018*"purchase" + 0.017*"loan" + 0.014*"measure" + 0.011*"annual" + '
#   '0.011*"inflation" + 0.011*"recovery" + 0.009*"structural" + 0.009*"also" + '
#   '0.009*"european" + 0.008*"quarter"'),
#  (48,
#   '0.022*"inflation" + 0.016*"annual" + 0.011*"reform" + 0.011*"recovery" + '
#   '0.011*"quarter" + 0.010*"measure" + 0.010*"continue" + 0.009*"loan" + '
#   '0.009*"fiscal" + 0.009*"structural"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity5: ', lda_model5.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity10: ', lda_model10.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity20: ', lda_model20.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity50: ', lda_model50.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity100: ', lda_model100.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100: ', coherence_lda)


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence ScoreUMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100UMass: ', coherence_lda)
# Out:
# Perplexity:  -6.839069437234599
#
# Perplexity5:  -6.68660869506805
#
# Perplexity10:  -6.675181517048252
#
# Perplexity20:  -6.70542787467583
#
# Perplexity50:  -6.757871417227102
#
# Perplexity100:  -7.933531916727498
#
# Coherence Score:  0.268065660953906
#
# Coherence Score5:  0.3197504680865236
#
# Coherence Score10:  0.34150272531858233
#
# Coherence Score20:  0.3201173308584792
#
# Coherence Score50:  0.31424110847849457
#
# Coherence Score100:  0.31389739533303407
#
# Coherence ScoreUMass:  -0.07043186383127625
#
# Coherence Score5UMass:  -0.2264144030038649
#
# Coherence Score10UMass:  -0.545523681471587
#
# Coherence Score20UMass:  -0.16984216150610293
#
# Coherence Score50UMass:  -0.5495517362866322
#
# Coherence Score100UMass:  -0.5471532010508304
