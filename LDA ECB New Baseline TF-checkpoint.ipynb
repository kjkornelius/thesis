# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx')

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['Press']

# %%
#Explore
#Fetch wordcount for each abstract
#df['word_count'] = df.apply(lambda x: len(str(x).split(" ")))
#df[['Press','word_count']].head()

#df.word_count.describe()

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data)) #list

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(4394 unique tokens: ['able', 'acceptable', 'accompanied', 'according', 'account']...)

# %%
id2word.filter_n_most_frequent(10)
print((id2word))
# Out:
# Dictionary(4384 unique tokens: ['able', 'acceptable', 'accompanied', 'according', 'account']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
lda_model5 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model10 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model20 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model50 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=50, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model100 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=100, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\models\ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
# Print the Keyword in the 5 topics
pprint(lda_model5.print_topics())
doc_lda = lda_model5[corpus]

# Print the Keyword in the 10 topics
pprint(lda_model10.print_topics())
doc_lda = lda_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lda_model20.print_topics())
doc_lda = lda_model20[corpus]

# Print the Keyword in the 50 topics
pprint(lda_model50.print_topics())
doc_lda = lda_model50[corpus]

# Print the Keyword in the 100 topics
pprint(lda_model100.print_topics())
doc_lda = lda_model100[corpus]
# Out:
# [(0,
#   '0.003*"sharing" + 0.002*"lithuania" + 0.002*"reconsider" + '
#   '0.001*"nineteenth" + 0.001*"lietuvos" + 0.001*"rotation" + 0.001*"bankas" + '
#   '0.001*"endseptember" + 0.001*"voting" + 0.001*"retains"'),
#  (1,
#   '0.020*"policy" + 0.017*"inflation" + 0.013*"annual" + 0.011*"recovery" + '
#   '0.010*"measure" + 0.010*"loan" + 0.009*"quarter" + 0.009*"reform" + '
#   '0.009*"structural" + 0.008*"also"'),
#  (2,
#   '0.014*"inflation" + 0.009*"annual" + 0.009*"term" + 0.009*"medium" + '
#   '0.009*"remain" + 0.009*"financial" + 0.008*"market" + 0.008*"loan" + '
#   '0.008*"analysis" + 0.008*"governing"'),
#  (3,
#   '0.015*"risk" + 0.014*"stability" + 0.011*"inflation" + 0.010*"medium" + '
#   '0.009*"market" + 0.008*"term" + 0.008*"analysis" + 0.008*"increase" + '
#   '0.007*"remain" + 0.007*"upside"'),
#  (4,
#   '0.013*"governing" + 0.009*"stability" + 0.008*"policy" + 0.008*"ecb" + '
#   '0.008*"also" + 0.007*"interest" + 0.006*"recent" + 0.006*"year" + '
#   '0.006*"today" + 0.006*"first"')]
# [(0,
#   '0.000*"inflation" + 0.000*"risk" + 0.000*"governing" + 0.000*"stability" + '
#   '0.000*"policy" + 0.000*"market" + 0.000*"also" + 0.000*"interest" + '
#   '0.000*"term" + 0.000*"annual"'),
#  (1,
#   '0.006*"upswing" + 0.006*"transparency" + 0.005*"guideline" + '
#   '0.005*"statistic" + 0.004*"payment" + 0.004*"vigilant" + 0.004*"witnessed" '
#   '+ 0.004*"copy" + 0.003*"published" + 0.003*"item"'),
#  (2,
#   '0.007*"conditionality" + 0.005*"extensively" + 0.004*"boosted" + '
#   '0.004*"van" + 0.003*"guideline" + 0.003*"reversibility" + '
#   '0.003*"fulfilment" + 0.003*"activate" + 0.003*"tenth" + 0.003*"integrity"'),
#  (3,
#   '0.007*"strategy" + 0.006*"say" + 0.006*"governing" + 0.005*"phase" + '
#   '0.005*"eu" + 0.004*"consumer" + 0.004*"eurosystem" + 0.004*"settlement" + '
#   '0.004*"state" + 0.004*"fact"'),
#  (4,
#   '0.033*"governing" + 0.015*"central" + 0.015*"ecb" + 0.014*"banknote" + '
#   '0.012*"national" + 0.012*"first" + 0.011*"bank" + 0.011*"today" + '
#   '0.009*"january" + 0.008*"facility"'),
#  (5,
#   '0.020*"inflation" + 0.015*"annual" + 0.014*"policy" + 0.012*"loan" + '
#   '0.010*"measure" + 0.010*"governing" + 0.009*"analysis" + 0.008*"purchase" + '
#   '0.008*"outlook" + 0.008*"financial"'),
#  (6,
#   '0.021*"policy" + 0.017*"inflation" + 0.013*"annual" + 0.011*"recovery" + '
#   '0.011*"loan" + 0.011*"measure" + 0.010*"quarter" + 0.009*"reform" + '
#   '0.009*"structural" + 0.008*"continue"'),
#  (7,
#   '0.014*"treaty" + 0.010*"maastricht" + 0.007*"campaign" + 0.003*"imf" + '
#   '0.003*"practice" + 0.003*"actively" + 0.003*"underpinnings" + '
#   '0.003*"successfully" + 0.003*"forum" + 0.002*"counteracting"'),
#  (8,
#   '0.010*"policy" + 0.009*"governing" + 0.008*"interest" + 0.008*"recent" + '
#   '0.008*"year" + 0.007*"ecb" + 0.007*"also" + 0.006*"market" + '
#   '0.006*"stability" + 0.006*"outlook"'),
#  (9,
#   '0.012*"risk" + 0.011*"inflation" + 0.011*"stability" + 0.010*"medium" + '
#   '0.010*"market" + 0.009*"term" + 0.008*"remain" + 0.007*"analysis" + '
#   '0.006*"governing" + 0.006*"increase"')]
# [(0,
#   '0.000*"governing" + 0.000*"risk" + 0.000*"stability" + 0.000*"inflation" + '
#   '0.000*"interest" + 0.000*"also" + 0.000*"policy" + 0.000*"term" + '
#   '0.000*"market" + 0.000*"increase"'),
#  (1,
#   '0.000*"stability" + 0.000*"inflation" + 0.000*"governing" + 0.000*"also" + '
#   '0.000*"risk" + 0.000*"policy" + 0.000*"ecb" + 0.000*"term" + '
#   '0.000*"increase" + 0.000*"level"'),
#  (2,
#   '0.000*"inflation" + 0.000*"governing" + 0.000*"stability" + 0.000*"risk" + '
#   '0.000*"also" + 0.000*"level" + 0.000*"ecb" + 0.000*"annual" + '
#   '0.000*"market" + 0.000*"interest"'),
#  (3,
#   '0.003*"crosschecked" + 0.002*"manufactured" + 0.002*"internationally" + '
#   '0.002*"comfort" + 0.002*"lifted" + 0.002*"traded" + 0.002*"triple" + '
#   '0.000*"treatment" + 0.000*"prioritised" + 0.000*"precisely"'),
#  (4,
#   '0.011*"fraud" + 0.011*"antifraud" + 0.007*"noting" + 0.007*"worth" + '
#   '0.005*"link" + 0.004*"satisfaction" + 0.004*"adapt" + 0.004*"isolation" + '
#   '0.004*"audit" + 0.004*"olaf"'),
#  (5,
#   '0.020*"purchase" + 0.017*"inflation" + 0.016*"policy" + 0.013*"annual" + '
#   '0.011*"governing" + 0.010*"outlook" + 0.009*"september" + 0.009*"also" + '
#   '0.009*"asset" + 0.009*"sustained"'),
#  (6,
#   '0.013*"contracting" + 0.010*"guiding" + 0.008*"forcefully" + '
#   '0.005*"incorporation" + 0.005*"welldefined" + 0.002*"sake" + '
#   '0.002*"transformation" + 0.002*"alone" + 0.002*"entrance" + '
#   '0.002*"reabsorb"'),
#  (7,
#   '0.024*"maastricht" + 0.022*"treaty" + 0.005*"placed" + '
#   '0.005*"wellestablished" + 0.005*"chairing" + 0.004*"city" + '
#   '0.004*"tangible" + 0.004*"proof" + 0.004*"history" + 0.002*"abiding"'),
#  (8,
#   '0.032*"governing" + 0.020*"ecb" + 0.015*"first" + 0.014*"today" + '
#   '0.013*"policy" + 0.013*"interest" + 0.011*"central" + 0.011*"banknote" + '
#   '0.010*"bank" + 0.009*"value"'),
#  (9,
#   '0.007*"method" + 0.006*"brought" + 0.005*"closetobalance" + 0.005*"bolster" '
#   '+ 0.005*"disaster" + 0.005*"flood" + 0.005*"incomplete" + '
#   '0.005*"cornerstone" + 0.005*"undesirable" + 0.005*"exists"'),
#  (10,
#   '0.010*"risk" + 0.010*"stability" + 0.010*"market" + 0.010*"inflation" + '
#   '0.009*"medium" + 0.009*"term" + 0.007*"governing" + 0.007*"remain" + '
#   '0.007*"financial" + 0.006*"increase"'),
#  (11,
#   '0.025*"campaign" + 0.012*"raised" + 0.007*"imf" + 0.007*"depreciation" + '
#   '0.006*"forum" + 0.005*"section" + 0.004*"printed" + 0.004*"introductory" + '
#   '0.004*"supervision" + 0.004*"iraq"'),
#  (12,
#   '0.000*"policy" + 0.000*"also" + 0.000*"stability" + 0.000*"inflation" + '
#   '0.000*"governing" + 0.000*"year" + 0.000*"market" + 0.000*"medium" + '
#   '0.000*"ecb" + 0.000*"interest"'),
#  (13,
#   '0.010*"community" + 0.009*"strategy" + 0.009*"transparency" + '
#   '0.007*"reached" + 0.007*"counterfeit" + 0.006*"cannot" + 0.006*"agree" + '
#   '0.006*"eba" + 0.006*"clearing" + 0.006*"understood"'),
#  (14,
#   '0.004*"turmoil" + 0.002*"confront" + 0.002*"family" + 0.002*"barroso" + '
#   '0.002*"restructure" + 0.000*"intensification" + 0.000*"risk" + '
#   '0.000*"inflation" + 0.000*"stability" + 0.000*"term"'),
#  (15,
#   '0.004*"nationale" + 0.004*"recording" + 0.002*"motif" + 0.002*"underway" + '
#   '0.002*"dropped" + 0.002*"valid" + 0.002*"recognises" + 0.002*"warn" + '
#   '0.002*"error" + 0.002*"cautiously"'),
#  (16,
#   '0.000*"stability" + 0.000*"governing" + 0.000*"also" + 0.000*"market" + '
#   '0.000*"risk" + 0.000*"outlook" + 0.000*"increase" + 0.000*"medium" + '
#   '0.000*"term" + 0.000*"inflation"'),
#  (17,
#   '0.021*"policy" + 0.018*"inflation" + 0.014*"annual" + 0.013*"loan" + '
#   '0.011*"measure" + 0.011*"recovery" + 0.010*"quarter" + 0.009*"reform" + '
#   '0.009*"structural" + 0.009*"continue"'),
#  (18,
#   '0.000*"stability" + 0.000*"governing" + 0.000*"inflation" + 0.000*"also" + '
#   '0.000*"market" + 0.000*"year" + 0.000*"ecb" + 0.000*"increase" + '
#   '0.000*"interest" + 0.000*"policy"'),
#  (19,
#   '0.016*"oil" + 0.012*"level" + 0.012*"recent" + 0.012*"also" + '
#   '0.012*"reform" + 0.011*"stability" + 0.011*"inflation" + 0.010*"recovery" + '
#   '0.009*"term" + 0.009*"would"')]
# [(48,
#   '0.000*"governing" + 0.000*"year" + 0.000*"policy" + 0.000*"interest" + '
#   '0.000*"today" + 0.000*"stability" + 0.000*"month" + 0.000*"recent" + '
#   '0.000*"ecb" + 0.000*"regard"'),
#  (34,
#   '0.000*"also" + 0.000*"stability" + 0.000*"inflation" + 0.000*"governing" + '
#   '0.000*"first" + 0.000*"level" + 0.000*"interest" + 0.000*"risk" + '
#   '0.000*"increase" + 0.000*"outlook"'),
#  (46,
#   '0.000*"inflation" + 0.000*"also" + 0.000*"year" + 0.000*"policy" + '
#   '0.000*"stability" + 0.000*"governing" + 0.000*"recent" + 0.000*"remain" + '
#   '0.000*"risk" + 0.000*"continue"'),
#  (40,
#   '0.000*"governing" + 0.000*"stability" + 0.000*"policy" + 0.000*"year" + '
#   '0.000*"inflation" + 0.000*"level" + 0.000*"risk" + 0.000*"medium" + '
#   '0.000*"recent" + 0.000*"annual"'),
#  (20,
#   '0.000*"governing" + 0.000*"stability" + 0.000*"risk" + 0.000*"inflation" + '
#   '0.000*"year" + 0.000*"level" + 0.000*"also" + 0.000*"term" + 0.000*"policy" '
#   '+ 0.000*"oil"'),
#  (0,
#   '0.000*"governing" + 0.000*"interest" + 0.000*"also" + 0.000*"stability" + '
#   '0.000*"inflation" + 0.000*"policy" + 0.000*"risk" + 0.000*"market" + '
#   '0.000*"increase" + 0.000*"term"'),
#  (35,
#   '0.000*"governing" + 0.000*"also" + 0.000*"stability" + 0.000*"policy" + '
#   '0.000*"increase" + 0.000*"market" + 0.000*"interest" + 0.000*"inflation" + '
#   '0.000*"level" + 0.000*"regard"'),
#  (44,
#   '0.000*"governing" + 0.000*"interest" + 0.000*"stability" + 0.000*"also" + '
#   '0.000*"level" + 0.000*"regard" + 0.000*"ecb" + 0.000*"year" + 0.000*"today" '
#   '+ 0.000*"recent"'),
#  (21,
#   '0.000*"stability" + 0.000*"also" + 0.000*"inflation" + 0.000*"risk" + '
#   '0.000*"market" + 0.000*"level" + 0.000*"governing" + 0.000*"medium" + '
#   '0.000*"country" + 0.000*"ecb"'),
#  (7,
#   '0.000*"governing" + 0.000*"stability" + 0.000*"inflation" + 0.000*"also" + '
#   '0.000*"market" + 0.000*"level" + 0.000*"term" + 0.000*"year" + '
#   '0.000*"interest" + 0.000*"policy"'),
#  (38,
#   '0.027*"mostly" + 0.022*"disaster" + 0.016*"peer" + 0.011*"responding" + '
#   '0.010*"naturally" + 0.010*"thing" + 0.009*"seminar" + 0.008*"midterm" + '
#   '0.008*"debate" + 0.008*"restructure"'),
#  (8,
#   '0.069*"banknote" + 0.036*"changeover" + 0.029*"coin" + 0.026*"pillar" + '
#   '0.022*"cash" + 0.019*"day" + 0.018*"participating" + 0.017*"issue" + '
#   '0.016*"official" + 0.016*"member"'),
#  (29,
#   '0.016*"carefully" + 0.016*"appreciation" + 0.014*"spending" + 0.014*"would" '
#   '+ 0.013*"confidence" + 0.012*"urge" + 0.012*"middle" + 0.011*"eurostats" + '
#   '0.011*"portfolio" + 0.011*"liquidity"'),
#  (5,
#   '0.052*"guidance" + 0.021*"tender" + 0.018*"fixed" + 0.016*"operation" + '
#   '0.014*"date" + 0.013*"money" + 0.012*"word" + 0.012*"procedure" + '
#   '0.011*"incorporates" + 0.010*"depreciation"'),
#  (24,
#   '0.017*"oil" + 0.017*"risk" + 0.012*"inflation" + 0.011*"analysis" + '
#   '0.011*"recent" + 0.011*"reform" + 0.010*"stability" + 0.010*"fiscal" + '
#   '0.009*"projection" + 0.008*"contained"'),
#  (22,
#   '0.020*"stability" + 0.020*"underpins" + 0.017*"inflation" + 0.016*"effect" '
#   '+ 0.014*"turmoil" + 0.013*"financial" + 0.013*"risk" + 0.012*"high" + '
#   '0.012*"secondround" + 0.012*"impact"'),
#  (45,
#   '0.034*"governing" + 0.017*"ecb" + 0.017*"today" + 0.017*"operation" + '
#   '0.013*"january" + 0.013*"bank" + 0.012*"decision" + 0.012*"interest" + '
#   '0.011*"central" + 0.011*"december"'),
#  (23,
#   '0.016*"medium" + 0.014*"term" + 0.014*"risk" + 0.013*"inflation" + '
#   '0.012*"remain" + 0.011*"market" + 0.010*"analysis" + 0.010*"stability" + '
#   '0.009*"expected" + 0.008*"pressure"'),
#  (10,
#   '0.010*"stability" + 0.010*"governing" + 0.009*"market" + 0.008*"policy" + '
#   '0.008*"recent" + 0.007*"increase" + 0.007*"financial" + 0.007*"also" + '
#   '0.006*"year" + 0.006*"interest"'),
#  (17,
#   '0.020*"policy" + 0.018*"inflation" + 0.014*"annual" + 0.012*"loan" + '
#   '0.011*"measure" + 0.011*"recovery" + 0.010*"quarter" + 0.009*"structural" + '
#   '0.009*"reform" + 0.008*"continue"')]
# [(34,
#   '0.000*"stability" + 0.000*"governing" + 0.000*"outlook" + 0.000*"first" + '
#   '0.000*"also" + 0.000*"market" + 0.000*"financial" + 0.000*"inflation" + '
#   '0.000*"fiscal" + 0.000*"recent"'),
#  (48,
#   '0.000*"governing" + 0.000*"year" + 0.000*"interest" + 0.000*"today" + '
#   '0.000*"indicator" + 0.000*"march" + 0.000*"policy" + 0.000*"month" + '
#   '0.000*"stability" + 0.000*"increase"'),
#  (46,
#   '0.000*"also" + 0.000*"recent" + 0.000*"policy" + 0.000*"stability" + '
#   '0.000*"interest" + 0.000*"year" + 0.000*"governing" + 0.000*"first" + '
#   '0.000*"continued" + 0.000*"risk"'),
#  (20,
#   '0.000*"risk" + 0.000*"stability" + 0.000*"analysis" + 0.000*"inflation" + '
#   '0.000*"reform" + 0.000*"increase" + 0.000*"oil" + 0.000*"governing" + '
#   '0.000*"policy" + 0.000*"term"'),
#  (69,
#   '0.000*"interest" + 0.000*"level" + 0.000*"activity" + 0.000*"recent" + '
#   '0.000*"inflation" + 0.000*"governing" + 0.000*"ecb" + 0.000*"stability" + '
#   '0.000*"time" + 0.000*"annual"'),
#  (85,
#   '0.000*"governing" + 0.000*"stability" + 0.000*"also" + 0.000*"ecb" + '
#   '0.000*"policy" + 0.000*"risk" + 0.000*"interest" + 0.000*"bank" + '
#   '0.000*"first" + 0.000*"regard"'),
#  (0,
#   '0.000*"risk" + 0.000*"governing" + 0.000*"stability" + 0.000*"oil" + '
#   '0.000*"also" + 0.000*"interest" + 0.000*"policy" + 0.000*"increase" + '
#   '0.000*"inflation" + 0.000*"market"'),
#  (84,
#   '0.000*"oil" + 0.000*"governing" + 0.000*"increase" + 0.000*"market" + '
#   '0.000*"ecb" + 0.000*"stability" + 0.000*"economy" + 0.000*"fiscal" + '
#   '0.000*"policy" + 0.000*"also"'),
#  (40,
#   '0.000*"governing" + 0.000*"stability" + 0.000*"policy" + 0.000*"market" + '
#   '0.000*"year" + 0.000*"risk" + 0.000*"medium" + 0.000*"also" + 0.000*"level" '
#   '+ 0.000*"particular"'),
#  (35,
#   '0.000*"also" + 0.000*"governing" + 0.000*"policy" + 0.000*"interest" + '
#   '0.000*"stability" + 0.000*"level" + 0.000*"increase" + 0.000*"market" + '
#   '0.000*"recent" + 0.000*"ecb"'),
#  (5,
#   '0.047*"operation" + 0.036*"governing" + 0.028*"refinancing" + 0.021*"fixed" '
#   '+ 0.018*"ecb" + 0.017*"bank" + 0.016*"allotment" + 0.015*"today" + '
#   '0.015*"first" + 0.015*"tender"'),
#  (24,
#   '0.605*"extension" + 0.017*"convey" + 0.012*"stimulating" + 0.009*"left" + '
#   '0.007*"cornerstone" + 0.007*"undesirable" + 0.006*"unwelcome" + '
#   '0.005*"conclusive" + 0.005*"benign" + 0.005*"widespread"'),
#  (27,
#   '0.488*"undue" + 0.016*"ncbs" + 0.014*"ccbm" + 0.014*"consolidated" + '
#   '0.014*"documentation" + 0.014*"weekly" + 0.010*"pay" + 0.007*"escbs" + '
#   '0.007*"legally" + 0.007*"commit"'),
#  (82,
#   '0.047*"channel" + 0.037*"distribution" + 0.034*"inconsistent" + '
#   '0.021*"globally" + 0.020*"interest" + 0.017*"central" + 0.012*"proposal" + '
#   '0.012*"urge" + 0.011*"might" + 0.011*"participant"'),
#  (10,
#   '0.018*"governing" + 0.011*"ecb" + 0.010*"year" + 0.009*"interest" + '
#   '0.009*"recent" + 0.009*"stability" + 0.008*"today" + 0.008*"exchange" + '
#   '0.007*"month" + 0.007*"policy"'),
#  (58,
#   '0.025*"stability" + 0.019*"market" + 0.019*"risk" + 0.016*"financial" + '
#   '0.011*"increase" + 0.011*"effect" + 0.010*"strong" + 0.010*"medium" + '
#   '0.009*"data" + 0.009*"governing"'),
#  (83,
#   '0.012*"risk" + 0.012*"medium" + 0.011*"term" + 0.011*"inflation" + '
#   '0.010*"remain" + 0.010*"stability" + 0.009*"market" + 0.008*"analysis" + '
#   '0.007*"expected" + 0.007*"pressure"'),
#  (45,
#   '0.025*"policy" + 0.024*"purchase" + 0.014*"governing" + 0.013*"annual" + '
#   '0.012*"also" + 0.011*"asset" + 0.010*"sustained" + 0.010*"outlook" + '
#   '0.010*"increase" + 0.009*"ecb"'),
#  (17,
#   '0.022*"policy" + 0.021*"inflation" + 0.016*"annual" + 0.014*"measure" + '
#   '0.014*"loan" + 0.014*"financial" + 0.010*"economy" + 0.010*"governing" + '
#   '0.009*"pace" + 0.008*"nonfinancial"'),
#  (90,
#   '0.021*"inflation" + 0.018*"policy" + 0.015*"loan" + 0.014*"annual" + '
#   '0.014*"recovery" + 0.013*"quarter" + 0.012*"reform" + 0.012*"continue" + '
#   '0.011*"analysis" + 0.010*"structural"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
# Compute Perplexity

print('\nPerplexity5: ', lda_model5.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity10: ', lda_model10.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity20: ', lda_model20.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity50: ', lda_model50.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity100: ', lda_model100.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100: ', coherence_lda)




coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100UMass: ', coherence_lda)
# Out:
# Perplexity5:  -6.8569603612781425
#
# Perplexity10:  -6.900159709345189
#
# Perplexity20:  -6.923304929817173
#
# Perplexity50:  -6.959535309359142
#
# Perplexity100:  -8.676129491110965
#
# Coherence Score5:  0.3030549170052087
#
# Coherence Score10:  0.3536339552659188
#
# Coherence Score20:  0.3504924277044077
#
# Coherence Score50:  0.34476116664872025
#
# Coherence Score100:  0.3381198225980991
#
# Coherence Score5UMass:  -1.436235173229044
#
# Coherence Score10UMass:  -3.846763156685705
#
# Coherence Score20UMass:  -4.009463919407289
#
# Coherence Score50UMass:  -2.043570762492506
#
# Coherence Score100UMass:  -1.8604558329497747
