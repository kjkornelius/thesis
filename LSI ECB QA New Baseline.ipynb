# %%
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['qa']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(8371 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.252*"would" + 0.194*"say" + 0.194*"said" + 0.192*"rate" + '
#   '0.179*"question" + 0.169*"price" + 0.162*"also" + 0.159*"market" + '
#   '0.147*"first" + 0.146*"time"')]
# [(0,
#   '0.252*"would" + 0.194*"say" + 0.194*"said" + 0.192*"rate" + '
#   '0.179*"question" + 0.169*"price" + 0.162*"also" + 0.159*"market" + '
#   '0.147*"first" + 0.146*"time"'),
#  (1,
#   '0.232*"regard" + -0.193*"policy" + 0.182*"stability" + -0.166*"one" + '
#   '-0.162*"bank" + -0.161*"think" + -0.133*"actually" + 0.130*"level" + '
#   '-0.122*"answer" + -0.115*"monetary"'),
#  (2,
#   '0.315*"rate" + -0.297*"government" + 0.258*"price" + 0.243*"inflation" + '
#   '-0.220*"country" + -0.215*"decision" + -0.149*"euro" + -0.146*"measure" + '
#   '-0.143*"bank" + -0.138*"question"'),
#  (3,
#   '-0.350*"euro" + 0.226*"market" + -0.214*"growth" + -0.202*"rate" + '
#   '-0.176*"area" + 0.150*"bank" + 0.149*"inflation" + 0.144*"risk" + '
#   '-0.134*"year" + -0.130*"exchange"'),
#  (4,
#   '0.592*"rate" + 0.244*"decision" + 0.147*"measure" + -0.143*"said" + '
#   '0.141*"interest" + -0.139*"would" + -0.131*"risk" + 0.128*"bank" + '
#   '0.122*"appropriate" + 0.116*"today"')]
# [(0,
#   '0.252*"would" + 0.194*"say" + 0.194*"said" + 0.192*"rate" + '
#   '0.179*"question" + 0.169*"price" + 0.162*"also" + 0.159*"market" + '
#   '0.147*"first" + 0.146*"time"'),
#  (1,
#   '0.232*"regard" + -0.193*"policy" + 0.182*"stability" + -0.166*"one" + '
#   '-0.162*"bank" + -0.161*"think" + -0.133*"actually" + 0.130*"level" + '
#   '-0.122*"answer" + -0.115*"monetary"'),
#  (2,
#   '-0.315*"rate" + 0.297*"government" + -0.258*"price" + -0.243*"inflation" + '
#   '0.220*"country" + 0.215*"decision" + 0.149*"euro" + 0.146*"measure" + '
#   '0.143*"bank" + 0.138*"question"'),
#  (3,
#   '0.350*"euro" + -0.226*"market" + 0.214*"growth" + 0.202*"rate" + '
#   '0.176*"area" + -0.150*"bank" + -0.149*"inflation" + -0.143*"risk" + '
#   '0.134*"year" + 0.130*"exchange"'),
#  (4,
#   '-0.592*"rate" + -0.244*"decision" + -0.147*"measure" + 0.143*"said" + '
#   '-0.141*"interest" + 0.139*"would" + 0.131*"risk" + -0.128*"bank" + '
#   '-0.122*"appropriate" + -0.117*"today"'),
#  (5,
#   '-0.371*"policy" + -0.265*"inflation" + -0.239*"monetary" + 0.239*"bank" + '
#   '0.193*"market" + -0.170*"programme" + 0.164*"think" + -0.135*"measure" + '
#   '0.130*"so" + -0.129*"decision"'),
#  (6,
#   '-0.303*"council" + 0.285*"price" + -0.276*"would" + 0.270*"area" + '
#   '-0.255*"governing" + 0.239*"euro" + 0.217*"country" + 0.161*"stability" + '
#   '0.148*"inflation" + -0.131*"say"'),
#  (7,
#   '-0.269*"market" + -0.245*"bank" + -0.244*"policy" + 0.228*"time" + '
#   '0.223*"inflation" + -0.188*"monetary" + -0.167*"price" + -0.165*"stability" '
#   '+ -0.151*"question" + 0.144*"decision"'),
#  (8,
#   '-0.282*"council" + -0.267*"governing" + -0.256*"price" + 0.200*"would" + '
#   '0.196*"economy" + 0.193*"say" + 0.193*"bank" + -0.179*"market" + '
#   '0.156*"growth" + 0.156*"important"'),
#  (9,
#   '0.277*"risk" + -0.277*"would" + 0.235*"monetary" + -0.190*"say" + '
#   '-0.160*"confidence" + -0.144*"europe" + 0.143*"decision" + -0.143*"market" '
#   '+ 0.142*"area" + 0.132*"analysis"')]
# [(0,
#   '0.252*"would" + 0.194*"say" + 0.194*"said" + 0.192*"rate" + '
#   '0.179*"question" + 0.169*"price" + 0.162*"also" + 0.159*"market" + '
#   '0.147*"first" + 0.146*"time"'),
#  (1,
#   '0.232*"regard" + -0.193*"policy" + 0.182*"stability" + -0.166*"one" + '
#   '-0.162*"bank" + -0.161*"think" + -0.133*"actually" + 0.130*"level" + '
#   '-0.122*"answer" + -0.116*"monetary"'),
#  (2,
#   '-0.315*"rate" + 0.297*"government" + -0.258*"price" + -0.243*"inflation" + '
#   '0.220*"country" + 0.215*"decision" + 0.149*"euro" + 0.146*"measure" + '
#   '0.143*"bank" + 0.138*"question"'),
#  (3,
#   '0.350*"euro" + -0.226*"market" + 0.214*"growth" + 0.202*"rate" + '
#   '0.176*"area" + -0.150*"bank" + -0.149*"inflation" + -0.143*"risk" + '
#   '0.134*"year" + 0.130*"exchange"'),
#  (4,
#   '-0.592*"rate" + -0.244*"decision" + -0.147*"measure" + 0.143*"said" + '
#   '-0.141*"interest" + 0.139*"would" + 0.131*"risk" + -0.128*"bank" + '
#   '-0.122*"appropriate" + -0.117*"today"'),
#  (5,
#   '0.371*"policy" + 0.265*"inflation" + -0.239*"bank" + 0.239*"monetary" + '
#   '-0.193*"market" + 0.170*"programme" + -0.164*"think" + 0.135*"measure" + '
#   '-0.130*"so" + 0.129*"decision"'),
#  (6,
#   '-0.303*"council" + 0.285*"price" + -0.276*"would" + 0.270*"area" + '
#   '-0.255*"governing" + 0.239*"euro" + 0.217*"country" + 0.161*"stability" + '
#   '0.147*"inflation" + -0.131*"say"'),
#  (7,
#   '0.269*"market" + 0.245*"bank" + 0.244*"policy" + -0.228*"time" + '
#   '-0.223*"inflation" + 0.188*"monetary" + 0.167*"price" + 0.165*"stability" + '
#   '0.151*"question" + -0.144*"decision"'),
#  (8,
#   '0.282*"council" + 0.267*"governing" + 0.257*"price" + -0.201*"would" + '
#   '-0.196*"economy" + -0.193*"bank" + -0.192*"say" + 0.179*"market" + '
#   '-0.156*"growth" + -0.156*"important"'),
#  (9,
#   '0.277*"risk" + -0.277*"would" + 0.236*"monetary" + -0.190*"say" + '
#   '-0.159*"confidence" + -0.144*"europe" + 0.143*"decision" + -0.143*"market" '
#   '+ 0.142*"area" + 0.132*"analysis"'),
#  (10,
#   '0.445*"market" + -0.371*"bank" + -0.251*"price" + -0.191*"stability" + '
#   '0.160*"policy" + 0.135*"monetary" + 0.107*"risk" + 0.105*"euro" + '
#   '0.099*"money" + -0.096*"central"'),
#  (11,
#   '0.271*"would" + -0.227*"said" + 0.206*"it" + -0.185*"situation" + '
#   '-0.148*"policy" + 0.143*"decision" + -0.132*"financial" + 0.129*"regard" + '
#   '0.128*"operation" + 0.124*"bond"'),
#  (12,
#   '0.259*"rate" + 0.247*"risk" + -0.195*"economy" + -0.173*"market" + '
#   '0.164*"would" + 0.163*"interest" + 0.156*"monetary" + 0.152*"analysis" + '
#   '-0.138*"one" + -0.126*"governing"'),
#  (13,
#   '0.235*"governing" + 0.222*"council" + -0.204*"decision" + '
#   '-0.186*"confidence" + -0.180*"that" + 0.166*"rate" + 0.148*"area" + '
#   '0.148*"risk" + -0.145*"month" + -0.142*"take"'),
#  (14,
#   '-0.340*"question" + 0.187*"bank" + -0.184*"see" + 0.156*"market" + '
#   '0.151*"that" + 0.146*"euro" + -0.144*"first" + -0.143*"year" + '
#   '-0.141*"second" + -0.127*"would"'),
#  (15,
#   '-0.251*"say" + 0.210*"measure" + -0.194*"decision" + -0.190*"time" + '
#   '-0.176*"stability" + 0.137*"question" + -0.132*"government" + 0.131*"also" '
#   '+ 0.126*"situation" + 0.124*"figure"'),
#  (16,
#   '0.234*"risk" + -0.231*"growth" + 0.191*"inflation" + -0.181*"rate" + '
#   '-0.181*"said" + -0.167*"market" + 0.157*"bank" + 0.154*"would" + '
#   '0.138*"central" + -0.135*"programme"'),
#  (17,
#   '-0.218*"government" + -0.176*"risk" + -0.167*"greece" + -0.155*"question" + '
#   '0.155*"country" + 0.148*"fiscal" + -0.141*"inflation" + 0.135*"that" + '
#   '-0.134*"greek" + 0.131*"policy"'),
#  (18,
#   '0.219*"said" + 0.196*"economy" + -0.177*"first" + 0.174*"say" + '
#   '-0.164*"level" + -0.162*"time" + -0.154*"question" + 0.123*"policy" + '
#   '0.121*"so" + 0.118*"measure"'),
#  (19,
#   '0.246*"country" + 0.173*"it" + -0.172*"inflation" + -0.165*"think" + '
#   '0.151*"time" + 0.135*"united" + 0.133*"measure" + 0.128*"monetary" + '
#   '-0.123*"euro" + -0.120*"confidence"')]
# [(0,
#   '-0.252*"would" + -0.194*"say" + -0.194*"said" + -0.192*"rate" + '
#   '-0.179*"question" + -0.169*"price" + -0.162*"also" + -0.159*"market" + '
#   '-0.147*"first" + -0.146*"time"'),
#  (1,
#   '0.232*"regard" + -0.193*"policy" + 0.182*"stability" + -0.166*"one" + '
#   '-0.162*"bank" + -0.161*"think" + -0.133*"actually" + 0.130*"level" + '
#   '-0.122*"answer" + -0.115*"monetary"'),
#  (2,
#   '0.315*"rate" + -0.297*"government" + 0.258*"price" + 0.243*"inflation" + '
#   '-0.220*"country" + -0.215*"decision" + -0.149*"euro" + -0.146*"measure" + '
#   '-0.143*"bank" + -0.138*"question"'),
#  (3,
#   '-0.350*"euro" + 0.226*"market" + -0.214*"growth" + -0.202*"rate" + '
#   '-0.176*"area" + 0.150*"bank" + 0.149*"inflation" + 0.144*"risk" + '
#   '-0.134*"year" + -0.130*"exchange"'),
#  (4,
#   '-0.592*"rate" + -0.244*"decision" + -0.147*"measure" + 0.143*"said" + '
#   '-0.141*"interest" + 0.139*"would" + 0.130*"risk" + -0.128*"bank" + '
#   '-0.122*"appropriate" + -0.117*"today"'),
#  (5,
#   '0.371*"policy" + 0.265*"inflation" + -0.239*"bank" + 0.239*"monetary" + '
#   '-0.193*"market" + 0.170*"programme" + -0.164*"think" + 0.135*"measure" + '
#   '-0.130*"so" + 0.129*"decision"'),
#  (6,
#   '0.303*"council" + -0.285*"price" + 0.276*"would" + -0.270*"area" + '
#   '0.255*"governing" + -0.239*"euro" + -0.217*"country" + -0.161*"stability" + '
#   '-0.147*"inflation" + 0.131*"say"'),
#  (7,
#   '0.269*"market" + 0.245*"bank" + 0.244*"policy" + -0.228*"time" + '
#   '-0.223*"inflation" + 0.188*"monetary" + 0.167*"price" + 0.165*"stability" + '
#   '0.151*"question" + -0.144*"decision"'),
#  (8,
#   '-0.282*"council" + -0.267*"governing" + -0.257*"price" + 0.201*"would" + '
#   '0.196*"economy" + 0.193*"say" + 0.192*"bank" + -0.179*"market" + '
#   '0.156*"growth" + 0.156*"important"'),
#  (9,
#   '0.277*"risk" + -0.277*"would" + 0.235*"monetary" + -0.190*"say" + '
#   '-0.159*"confidence" + -0.144*"europe" + 0.143*"decision" + -0.143*"market" '
#   '+ 0.142*"area" + 0.132*"analysis"'),
#  (10,
#   '0.445*"market" + -0.372*"bank" + -0.252*"price" + -0.191*"stability" + '
#   '0.160*"policy" + 0.136*"monetary" + 0.107*"risk" + 0.105*"euro" + '
#   '0.099*"money" + -0.096*"central"'),
#  (11,
#   '-0.271*"would" + 0.227*"said" + -0.206*"it" + 0.185*"situation" + '
#   '0.148*"policy" + -0.143*"decision" + 0.132*"financial" + -0.129*"operation" '
#   '+ -0.129*"regard" + -0.123*"bond"'),
#  (12,
#   '0.259*"rate" + 0.247*"risk" + -0.195*"economy" + -0.173*"market" + '
#   '0.164*"would" + 0.164*"interest" + 0.156*"monetary" + 0.152*"analysis" + '
#   '-0.138*"one" + -0.126*"governing"'),
#  (13,
#   '0.235*"governing" + 0.222*"council" + -0.204*"decision" + '
#   '-0.187*"confidence" + -0.180*"that" + 0.166*"rate" + 0.149*"area" + '
#   '0.148*"risk" + -0.144*"month" + -0.142*"take"'),
#  (14,
#   '-0.339*"question" + 0.186*"bank" + -0.185*"see" + 0.157*"market" + '
#   '0.150*"that" + 0.146*"euro" + -0.145*"first" + -0.143*"year" + '
#   '-0.141*"second" + -0.126*"would"'),
#  (15,
#   '0.251*"say" + -0.210*"measure" + 0.194*"decision" + 0.191*"time" + '
#   '0.176*"stability" + -0.137*"question" + 0.132*"government" + -0.132*"also" '
#   '+ -0.126*"situation" + -0.124*"figure"'),
#  (16,
#   '0.237*"risk" + -0.231*"growth" + 0.194*"inflation" + -0.181*"rate" + '
#   '-0.180*"said" + -0.166*"market" + 0.159*"bank" + 0.154*"would" + '
#   '0.137*"central" + -0.133*"programme"'),
#  (17,
#   '-0.219*"government" + -0.173*"risk" + -0.168*"greece" + 0.155*"country" + '
#   '-0.154*"question" + 0.147*"fiscal" + -0.137*"inflation" + -0.137*"greek" + '
#   '0.133*"policy" + 0.133*"that"'),
#  (18,
#   '-0.219*"said" + -0.197*"economy" + 0.177*"first" + -0.174*"say" + '
#   '0.165*"level" + 0.162*"time" + 0.153*"question" + -0.123*"policy" + '
#   '-0.120*"so" + -0.119*"measure"'),
#  (19,
#   '0.247*"country" + 0.174*"it" + -0.170*"inflation" + -0.163*"think" + '
#   '0.152*"time" + 0.135*"united" + 0.131*"measure" + 0.126*"monetary" + '
#   '-0.125*"euro" + -0.120*"confidence"'),
#  (20,
#   '0.330*"economy" + -0.197*"regard" + 0.168*"european" + 0.166*"point" + '
#   '0.161*"basis" + -0.155*"growth" + -0.146*"say" + -0.121*"month" + '
#   '0.113*"could" + 0.112*"financial"'),
#  (21,
#   '0.218*"economy" + -0.193*"level" + 0.172*"measure" + 0.170*"one" + '
#   '0.158*"stability" + -0.138*"country" + 0.135*"risk" + 0.128*"point" + '
#   '0.122*"exchange" + -0.119*"also"'),
#  (22,
#   '-0.241*"said" + -0.211*"it" + -0.173*"question" + -0.168*"central" + '
#   '0.151*"point" + -0.148*"effect" + 0.142*"would" + 0.142*"policy" + '
#   '0.140*"one" + -0.139*"that"'),
#  (23,
#   '0.189*"year" + 0.179*"measure" + 0.174*"financial" + 0.157*"ecb" + '
#   '-0.148*"two" + -0.148*"first" + 0.132*"time" + 0.130*"projection" + '
#   '-0.125*"programme" + -0.124*"one"'),
#  (24,
#   '-0.208*"think" + -0.207*"measure" + -0.164*"say" + 0.142*"one" + '
#   '-0.139*"said" + -0.138*"today" + 0.131*"risk" + -0.127*"operation" + '
#   '-0.125*"euro" + 0.116*"reform"'),
#  (25,
#   '-0.175*"stability" + 0.170*"effect" + -0.167*"would" + -0.165*"level" + '
#   '-0.164*"said" + 0.158*"decision" + 0.153*"say" + 0.151*"country" + '
#   '0.144*"know" + 0.136*"information"'),
#  (26,
#   '-0.177*"programme" + -0.170*"well" + -0.166*"risk" + -0.154*"think" + '
#   '0.150*"instrument" + -0.145*"year" + -0.142*"also" + -0.139*"price" + '
#   '0.136*"look" + 0.131*"so"'),
#  (27,
#   '-0.217*"growth" + 0.173*"say" + -0.168*"fiscal" + 0.163*"change" + '
#   '-0.160*"think" + 0.141*"effect" + -0.140*"said" + 0.139*"question" + '
#   '-0.124*"term" + 0.120*"it"'),
#  (28,
#   '0.210*"said" + -0.182*"year" + 0.164*"government" + 0.164*"would" + '
#   '0.152*"central" + 0.147*"decision" + -0.132*"ecb" + -0.131*"interest" + '
#   '0.128*"country" + -0.121*"month"'),
#  (29,
#   '-0.246*"country" + 0.241*"see" + 0.185*"economy" + -0.138*"question" + '
#   '0.137*"think" + 0.126*"figure" + -0.125*"growth" + -0.120*"market" + '
#   '-0.111*"stability" + -0.105*"operation"'),
#  (30,
#   '0.190*"bond" + 0.189*"year" + 0.149*"confidence" + 0.138*"say" + '
#   '0.125*"level" + -0.125*"area" + -0.123*"financial" + 0.122*"could" + '
#   '-0.117*"decision" + 0.115*"credit"'),
#  (31,
#   '-0.184*"said" + 0.166*"think" + -0.164*"see" + -0.147*"already" + '
#   '-0.145*"exchange" + 0.141*"it" + -0.127*"meeting" + 0.116*"problem" + '
#   '-0.112*"low" + -0.111*"time"'),
#  (32,
#   '0.172*"programme" + 0.161*"figure" + -0.148*"increase" + -0.144*"term" + '
#   '0.137*"growth" + -0.121*"structural" + -0.118*"labour" + 0.117*"said" + '
#   '-0.114*"high" + -0.110*"nonstandard"'),
#  (33,
#   '0.193*"that" + -0.187*"one" + 0.184*"growth" + 0.182*"see" + '
#   '-0.141*"government" + -0.132*"level" + 0.129*"country" + -0.128*"analysis" '
#   '+ -0.122*"economy" + -0.120*"reform"'),
#  (34,
#   '0.201*"regard" + 0.170*"exchange" + 0.163*"important" + -0.163*"economy" + '
#   '-0.134*"today" + -0.120*"negative" + 0.108*"projection" + -0.107*"time" + '
#   '-0.106*"no" + 0.106*"think"'),
#  (35,
#   '0.207*"also" + 0.162*"last" + -0.155*"clear" + -0.144*"level" + '
#   '-0.137*"effect" + -0.120*"see" + -0.111*"want" + 0.111*"know" + '
#   '0.110*"take" + -0.110*"strong"'),
#  (36,
#   '-0.181*"decision" + 0.173*"government" + 0.151*"basis" + -0.145*"situation" '
#   '+ 0.142*"year" + 0.141*"time" + 0.132*"important" + -0.128*"confidence" + '
#   '0.123*"central" + 0.115*"money"'),
#  (37,
#   '-0.140*"situation" + -0.139*"it" + -0.136*"liquidity" + 0.128*"first" + '
#   '-0.111*"guidance" + 0.108*"certainly" + 0.104*"government" + -0.102*"mean" '
#   '+ 0.097*"part" + 0.096*"private"'),
#  (38,
#   '0.159*"country" + 0.154*"look" + -0.139*"decision" + 0.131*"level" + '
#   '0.126*"well" + -0.123*"month" + 0.110*"government" + 0.109*"risk" + '
#   '-0.105*"would" + -0.104*"european"'),
#  (39,
#   '0.174*"also" + 0.151*"said" + -0.133*"inflation" + -0.126*"way" + '
#   '-0.121*"part" + -0.117*"ecb" + 0.116*"recovery" + 0.114*"change" + '
#   '-0.110*"central" + 0.110*"country"'),
#  (40,
#   '-0.148*"interest" + -0.132*"development" + 0.128*"something" + '
#   '0.128*"mandate" + -0.123*"make" + -0.121*"first" + -0.117*"increase" + '
#   '0.113*"would" + 0.112*"fully" + -0.109*"thats"'),
#  (41,
#   '-0.189*"clear" + -0.158*"recovery" + 0.149*"expectation" + '
#   '0.133*"certainly" + 0.132*"message" + -0.127*"central" + 0.124*"government" '
#   '+ -0.123*"ecb" + -0.113*"part" + 0.106*"growth"'),
#  (42,
#   '0.166*"that" + 0.159*"reason" + 0.132*"global" + -0.131*"fiscal" + '
#   '-0.126*"information" + 0.123*"one" + 0.109*"today" + -0.106*"reform" + '
#   '0.102*"responsibility" + -0.102*"survey"'),
#  (43,
#   '-0.185*"said" + -0.132*"see" + 0.127*"economy" + -0.111*"know" + '
#   '0.110*"particular" + 0.110*"assessment" + 0.106*"data" + -0.104*"mandate" + '
#   '0.100*"think" + -0.100*"union"'),
#  (44,
#   '0.164*"number" + 0.162*"state" + 0.153*"ecb" + -0.134*"liquidity" + '
#   '0.125*"loan" + 0.122*"also" + -0.121*"time" + 0.119*"already" + '
#   '0.118*"european" + 0.115*"important"'),
#  (45,
#   '-0.185*"also" + -0.180*"today" + -0.142*"liquidity" + 0.135*"point" + '
#   '-0.126*"again" + -0.115*"functioning" + 0.114*"financial" + '
#   '-0.112*"certainly" + 0.107*"question" + -0.106*"quarter"'),
#  (46,
#   '-0.175*"global" + 0.154*"monetary" + -0.137*"ecb" + 0.137*"think" + '
#   '0.118*"well" + -0.113*"that" + -0.110*"last" + -0.108*"balance" + '
#   '-0.101*"may" + 0.101*"made"'),
#  (47,
#   '-0.155*"level" + -0.134*"credit" + -0.132*"know" + 0.128*"clear" + '
#   '0.125*"appropriate" + 0.110*"that" + 0.107*"new" + 0.104*"negative" + '
#   '0.103*"year" + 0.102*"comment"'),
#  (48,
#   '0.158*"new" + -0.148*"projection" + 0.145*"bond" + -0.138*"last" + '
#   '0.131*"rule" + -0.125*"one" + -0.124*"interest" + 0.114*"see" + '
#   '-0.114*"staff" + -0.113*"think"'),
#  (49,
#   '0.134*"year" + -0.130*"projection" + 0.113*"recovery" + 0.112*"way" + '
#   '-0.108*"time" + 0.102*"know" + 0.097*"first" + 0.096*"exchange" + '
#   '-0.093*"effect" + -0.093*"well"')]
# [(0,
#   '-0.252*"would" + -0.194*"say" + -0.194*"said" + -0.192*"rate" + '
#   '-0.179*"question" + -0.169*"price" + -0.162*"also" + -0.159*"market" + '
#   '-0.147*"first" + -0.146*"time"'),
#  (1,
#   '0.232*"regard" + -0.193*"policy" + 0.182*"stability" + -0.166*"one" + '
#   '-0.162*"bank" + -0.161*"think" + -0.133*"actually" + 0.130*"level" + '
#   '-0.122*"answer" + -0.116*"monetary"'),
#  (2,
#   '0.315*"rate" + -0.297*"government" + 0.258*"price" + 0.243*"inflation" + '
#   '-0.220*"country" + -0.215*"decision" + -0.149*"euro" + -0.146*"measure" + '
#   '-0.143*"bank" + -0.138*"question"'),
#  (3,
#   '-0.350*"euro" + 0.226*"market" + -0.214*"growth" + -0.202*"rate" + '
#   '-0.176*"area" + 0.150*"bank" + 0.149*"inflation" + 0.144*"risk" + '
#   '-0.134*"year" + -0.130*"exchange"'),
#  (4,
#   '-0.592*"rate" + -0.244*"decision" + -0.147*"measure" + 0.143*"said" + '
#   '-0.141*"interest" + 0.139*"would" + 0.130*"risk" + -0.128*"bank" + '
#   '-0.122*"appropriate" + -0.117*"today"'),
#  (5,
#   '0.371*"policy" + 0.265*"inflation" + -0.239*"bank" + 0.239*"monetary" + '
#   '-0.193*"market" + 0.170*"programme" + -0.164*"think" + 0.135*"measure" + '
#   '-0.130*"so" + 0.129*"decision"'),
#  (6,
#   '-0.303*"council" + 0.285*"price" + -0.276*"would" + 0.270*"area" + '
#   '-0.255*"governing" + 0.239*"euro" + 0.217*"country" + 0.161*"stability" + '
#   '0.148*"inflation" + -0.131*"say"'),
#  (7,
#   '-0.269*"market" + -0.245*"bank" + -0.244*"policy" + 0.228*"time" + '
#   '0.223*"inflation" + -0.188*"monetary" + -0.167*"price" + -0.165*"stability" '
#   '+ -0.151*"question" + 0.144*"decision"'),
#  (8,
#   '-0.282*"council" + -0.267*"governing" + -0.257*"price" + 0.201*"would" + '
#   '0.195*"economy" + 0.193*"say" + 0.192*"bank" + -0.179*"market" + '
#   '0.156*"growth" + 0.156*"important"'),
#  (9,
#   '-0.277*"risk" + 0.277*"would" + -0.235*"monetary" + 0.190*"say" + '
#   '0.159*"confidence" + 0.144*"europe" + -0.143*"decision" + 0.143*"market" + '
#   '-0.142*"area" + -0.132*"analysis"'),
#  (10,
#   '0.445*"market" + -0.372*"bank" + -0.252*"price" + -0.191*"stability" + '
#   '0.160*"policy" + 0.136*"monetary" + 0.107*"risk" + 0.105*"euro" + '
#   '0.099*"money" + -0.096*"central"'),
#  (11,
#   '0.271*"would" + -0.227*"said" + 0.206*"it" + -0.185*"situation" + '
#   '-0.148*"policy" + 0.143*"decision" + -0.132*"financial" + 0.129*"regard" + '
#   '0.129*"operation" + 0.123*"bond"'),
#  (12,
#   '-0.259*"rate" + -0.247*"risk" + 0.195*"economy" + 0.173*"market" + '
#   '-0.164*"would" + -0.164*"interest" + -0.156*"monetary" + -0.152*"analysis" '
#   '+ 0.137*"one" + 0.126*"governing"'),
#  (13,
#   '0.235*"governing" + 0.222*"council" + -0.204*"decision" + '
#   '-0.187*"confidence" + -0.180*"that" + 0.166*"rate" + 0.149*"area" + '
#   '0.148*"risk" + -0.145*"month" + -0.142*"take"'),
#  (14,
#   '-0.339*"question" + 0.186*"bank" + -0.185*"see" + 0.157*"market" + '
#   '0.150*"that" + 0.146*"euro" + -0.145*"first" + -0.143*"year" + '
#   '-0.141*"second" + -0.127*"would"'),
#  (15,
#   '-0.251*"say" + 0.210*"measure" + -0.193*"decision" + -0.191*"time" + '
#   '-0.176*"stability" + 0.137*"question" + -0.132*"government" + 0.131*"also" '
#   '+ 0.126*"situation" + 0.125*"figure"'),
#  (16,
#   '-0.237*"risk" + 0.231*"growth" + -0.194*"inflation" + 0.181*"rate" + '
#   '0.180*"said" + 0.167*"market" + -0.158*"bank" + -0.154*"would" + '
#   '-0.137*"central" + 0.133*"programme"'),
#  (17,
#   '0.219*"government" + 0.173*"risk" + 0.168*"greece" + -0.155*"country" + '
#   '0.154*"question" + -0.147*"fiscal" + 0.138*"inflation" + 0.137*"greek" + '
#   '-0.133*"policy" + -0.133*"that"'),
#  (18,
#   '0.219*"said" + 0.197*"economy" + -0.177*"first" + 0.174*"say" + '
#   '-0.165*"level" + -0.161*"time" + -0.153*"question" + 0.123*"policy" + '
#   '0.121*"so" + 0.119*"measure"'),
#  (19,
#   '-0.247*"country" + -0.174*"it" + 0.169*"inflation" + 0.163*"think" + '
#   '-0.152*"time" + -0.135*"united" + -0.131*"measure" + -0.126*"monetary" + '
#   '0.126*"euro" + 0.120*"confidence"'),
#  (20,
#   '-0.331*"economy" + 0.197*"regard" + -0.168*"european" + -0.166*"point" + '
#   '-0.161*"basis" + 0.155*"growth" + 0.146*"say" + 0.121*"month" + '
#   '-0.113*"could" + -0.111*"financial"'),
#  (21,
#   '0.219*"economy" + -0.193*"level" + 0.171*"measure" + 0.170*"one" + '
#   '0.158*"stability" + -0.138*"country" + 0.135*"risk" + 0.128*"point" + '
#   '0.122*"exchange" + -0.119*"also"'),
#  (22,
#   '0.241*"said" + 0.211*"it" + 0.173*"question" + 0.168*"central" + '
#   '-0.151*"point" + 0.147*"effect" + -0.142*"policy" + -0.142*"would" + '
#   '-0.140*"one" + 0.139*"that"'),
#  (23,
#   '0.185*"year" + 0.174*"financial" + 0.172*"measure" + 0.160*"ecb" + '
#   '-0.149*"two" + -0.148*"first" + 0.129*"time" + 0.127*"projection" + '
#   '0.127*"risk" + -0.126*"programme"'),
#  (24,
#   '-0.213*"measure" + -0.209*"think" + -0.161*"say" + 0.146*"one" + '
#   '-0.140*"today" + -0.138*"said" + 0.127*"risk" + -0.124*"operation" + '
#   '-0.123*"euro" + 0.117*"reform"'),
#  (25,
#   '-0.176*"stability" + 0.170*"effect" + -0.167*"would" + -0.164*"said" + '
#   '-0.164*"level" + 0.157*"decision" + 0.154*"say" + 0.151*"country" + '
#   '0.144*"know" + 0.136*"information"'),
#  (26,
#   '-0.176*"programme" + -0.169*"well" + -0.166*"risk" + -0.154*"think" + '
#   '0.149*"instrument" + -0.145*"year" + -0.143*"also" + -0.140*"price" + '
#   '0.137*"look" + 0.132*"so"'),
#  (27,
#   '0.217*"growth" + -0.173*"say" + 0.169*"fiscal" + -0.164*"change" + '
#   '0.161*"think" + -0.141*"effect" + 0.140*"said" + -0.139*"question" + '
#   '0.123*"term" + 0.119*"measure"'),
#  (28,
#   '0.210*"said" + -0.181*"year" + 0.165*"government" + 0.165*"would" + '
#   '0.151*"central" + 0.147*"decision" + -0.132*"ecb" + -0.131*"interest" + '
#   '0.128*"country" + -0.121*"month"'),
#  (29,
#   '0.247*"country" + -0.241*"see" + -0.186*"economy" + 0.138*"question" + '
#   '-0.137*"think" + -0.126*"figure" + 0.125*"growth" + 0.120*"market" + '
#   '0.111*"stability" + 0.106*"operation"'),
#  (30,
#   '-0.191*"bond" + -0.189*"year" + -0.147*"confidence" + -0.138*"say" + '
#   '-0.126*"level" + 0.125*"area" + 0.123*"financial" + -0.122*"could" + '
#   '0.117*"decision" + 0.115*"that"'),
#  (31,
#   '0.184*"said" + -0.167*"think" + 0.164*"see" + 0.146*"exchange" + '
#   '0.146*"already" + -0.142*"it" + 0.127*"meeting" + -0.116*"problem" + '
#   '0.113*"low" + 0.111*"structural"'),
#  (32,
#   '-0.171*"programme" + -0.160*"figure" + 0.149*"increase" + 0.144*"term" + '
#   '-0.138*"growth" + 0.121*"structural" + 0.118*"labour" + -0.117*"said" + '
#   '0.114*"high" + 0.111*"nonstandard"'),
#  (33,
#   '-0.192*"that" + 0.187*"one" + -0.183*"growth" + -0.182*"see" + '
#   '0.141*"government" + 0.131*"level" + -0.130*"country" + 0.127*"analysis" + '
#   '0.123*"economy" + 0.119*"reform"'),
#  (34,
#   '0.200*"regard" + 0.171*"exchange" + 0.162*"important" + -0.160*"economy" + '
#   '-0.129*"today" + -0.119*"negative" + -0.108*"time" + -0.107*"no" + '
#   '0.107*"thats" + 0.106*"think"'),
#  (35,
#   '-0.208*"also" + -0.163*"last" + 0.156*"clear" + 0.144*"level" + '
#   '0.138*"effect" + 0.118*"see" + 0.113*"strong" + 0.112*"want" + '
#   '-0.110*"take" + -0.110*"know"'),
#  (36,
#   '-0.182*"decision" + 0.174*"government" + 0.152*"basis" + -0.145*"situation" '
#   '+ 0.143*"time" + 0.142*"year" + 0.134*"important" + -0.127*"confidence" + '
#   '0.123*"central" + 0.114*"money"'),
#  (37,
#   '-0.141*"situation" + -0.139*"it" + -0.135*"liquidity" + 0.130*"first" + '
#   '-0.111*"guidance" + 0.108*"certainly" + -0.104*"mean" + 0.103*"government" '
#   '+ 0.097*"private" + 0.097*"part"'),
#  (38,
#   '0.158*"country" + 0.153*"look" + -0.138*"decision" + 0.131*"level" + '
#   '0.127*"well" + -0.123*"month" + 0.110*"government" + 0.109*"risk" + '
#   '-0.106*"would" + 0.103*"particular"'),
#  (39,
#   '-0.173*"also" + -0.149*"said" + 0.135*"inflation" + 0.127*"way" + '
#   '0.120*"part" + 0.119*"ecb" + -0.117*"recovery" + -0.112*"change" + '
#   '0.111*"central" + -0.110*"country"'),
#  (40,
#   '-0.147*"interest" + -0.136*"development" + 0.133*"mandate" + '
#   '0.127*"something" + -0.124*"make" + -0.122*"first" + -0.117*"increase" + '
#   '0.111*"fully" + -0.111*"thats" + 0.110*"would"'),
#  (41,
#   '0.192*"clear" + 0.160*"recovery" + -0.148*"expectation" + '
#   '-0.133*"certainly" + -0.129*"message" + 0.126*"central" + '
#   '-0.125*"government" + 0.121*"ecb" + 0.114*"part" + -0.106*"growth"'),
#  (42,
#   '0.167*"that" + 0.156*"reason" + 0.133*"global" + -0.131*"fiscal" + '
#   '-0.127*"information" + 0.121*"one" + 0.107*"today" + -0.104*"survey" + '
#   '-0.103*"reform" + 0.102*"responsibility"'),
#  (43,
#   '0.187*"said" + 0.133*"see" + -0.125*"economy" + -0.110*"particular" + '
#   '0.109*"know" + -0.108*"assessment" + -0.106*"data" + 0.104*"mandate" + '
#   '-0.102*"think" + 0.101*"union"'),
#  (44,
#   '0.163*"number" + 0.158*"state" + 0.153*"ecb" + -0.145*"liquidity" + '
#   '0.130*"loan" + 0.128*"already" + -0.118*"time" + 0.118*"also" + '
#   '0.116*"important" + 0.114*"european"'),
#  (45,
#   '0.192*"also" + 0.180*"today" + 0.138*"liquidity" + -0.134*"point" + '
#   '0.123*"again" + -0.115*"financial" + 0.112*"functioning" + '
#   '0.111*"certainly" + 0.109*"quarter" + -0.109*"question"'),
#  (46,
#   '0.175*"global" + -0.154*"monetary" + 0.138*"ecb" + -0.136*"think" + '
#   '-0.120*"well" + 0.112*"that" + 0.108*"last" + 0.108*"balance" + '
#   '-0.101*"made" + 0.101*"period"'),
#  (47,
#   '-0.151*"level" + -0.136*"credit" + -0.135*"know" + 0.135*"appropriate" + '
#   '0.132*"clear" + 0.110*"that" + 0.109*"new" + 0.103*"negative" + '
#   '0.100*"would" + 0.098*"comment"'),
#  (48,
#   '0.158*"new" + -0.146*"projection" + 0.146*"bond" + -0.139*"last" + '
#   '0.132*"rule" + -0.126*"one" + -0.124*"interest" + 0.113*"see" + '
#   '-0.112*"staff" + -0.110*"think"'),
#  (49,
#   '-0.134*"year" + 0.128*"projection" + -0.113*"recovery" + -0.111*"way" + '
#   '0.107*"time" + -0.097*"know" + -0.097*"first" + 0.096*"effect" + '
#   '-0.095*"exchange" + -0.094*"going"'),
#  (50,
#   '-0.173*"also" + -0.168*"appropriate" + 0.168*"important" + 0.148*"ecb" + '
#   '-0.129*"fully" + 0.127*"credit" + -0.122*"asset" + -0.112*"regard" + '
#   '0.106*"projection" + 0.104*"lending"'),
#  (51,
#   '0.196*"course" + 0.164*"effect" + 0.159*"important" + -0.138*"possible" + '
#   '0.136*"confidence" + -0.131*"ecb" + 0.106*"need" + -0.102*"expectation" + '
#   '-0.098*"one" + -0.097*"regard"'),
#  (52,
#   '0.159*"interest" + -0.156*"today" + 0.123*"different" + -0.121*"let" + '
#   '-0.112*"something" + -0.110*"expectation" + -0.105*"again" + 0.105*"taken" '
#   '+ 0.102*"figure" + -0.102*"commission"'),
#  (53,
#   '0.167*"global" + -0.141*"information" + -0.137*"know" + -0.115*"stability" '
#   '+ 0.110*"made" + 0.108*"europe" + 0.107*"judgement" + -0.102*"see" + '
#   '0.101*"credit" + 0.101*"assessment"'),
#  (54,
#   '0.124*"regard" + 0.122*"mandate" + -0.122*"staff" + 0.114*"government" + '
#   '-0.111*"ecb" + -0.106*"it" + -0.106*"country" + -0.106*"new" + '
#   '0.101*"thing" + 0.101*"job"'),
#  (55,
#   '0.156*"financial" + 0.146*"let" + 0.144*"meeting" + 0.132*"banking" + '
#   '0.122*"already" + -0.104*"way" + 0.104*"year" + -0.101*"view" + '
#   '0.098*"quarter" + -0.096*"two"'),
#  (56,
#   '-0.171*"important" + 0.127*"certainly" + 0.124*"ecb" + 0.108*"figure" + '
#   '0.103*"european" + 0.103*"recovery" + -0.101*"framework" + '
#   '-0.100*"absolutely" + -0.096*"action" + -0.092*"first"'),
#  (57,
#   '0.157*"appropriate" + -0.156*"point" + 0.127*"much" + -0.117*"that" + '
#   '0.109*"line" + -0.107*"condition" + -0.107*"message" + -0.105*"place" + '
#   '-0.104*"policy" + 0.101*"account"'),
#  (58,
#   '-0.196*"analysis" + -0.135*"development" + 0.114*"one" + 0.104*"policy" + '
#   '-0.098*"quarter" + 0.097*"move" + -0.096*"financial" + -0.095*"number" + '
#   '-0.094*"term" + -0.094*"meeting"'),
#  (59,
#   '0.141*"one" + -0.134*"global" + -0.118*"responsibility" + 0.112*"stability" '
#   '+ -0.098*"particular" + 0.094*"situation" + -0.092*"mandate" + '
#   '-0.088*"think" + 0.086*"agreement" + 0.086*"rule"'),
#  (60,
#   '0.150*"time" + -0.125*"mandate" + -0.123*"level" + -0.123*"inflation" + '
#   '-0.122*"let" + -0.114*"change" + -0.112*"so" + 0.108*"decided" + '
#   '0.107*"important" + 0.104*"mentioned"'),
#  (61,
#   '0.154*"first" + 0.132*"take" + -0.125*"sector" + -0.120*"term" + '
#   '0.110*"present" + 0.103*"condition" + -0.095*"good" + -0.095*"way" + '
#   '-0.094*"judgement" + -0.093*"look"'),
#  (62,
#   '0.187*"know" + 0.132*"think" + -0.124*"mandate" + 0.111*"always" + '
#   '-0.110*"mentioned" + -0.104*"go" + 0.103*"new" + -0.102*"month" + '
#   '-0.098*"statement" + -0.097*"way"'),
#  (63,
#   '0.142*"going" + -0.132*"european" + 0.104*"fact" + -0.103*"balance" + '
#   '-0.101*"think" + -0.100*"area" + 0.097*"fiscal" + 0.097*"increase" + '
#   '-0.096*"make" + -0.096*"need"'),
#  (64,
#   '-0.149*"factor" + -0.147*"credit" + -0.137*"condition" + 0.130*"european" + '
#   '0.119*"comment" + -0.113*"question" + -0.111*"measure" + -0.096*"area" + '
#   '-0.094*"basis" + 0.092*"private"'),
#  (65,
#   '0.132*"may" + -0.132*"look" + -0.125*"continue" + 0.121*"need" + '
#   '0.102*"objective" + 0.099*"regard" + 0.097*"fully" + -0.094*"lower" + '
#   '-0.094*"billion" + 0.092*"strong"'),
#  (66,
#   '0.128*"one" + -0.109*"assessment" + -0.103*"rule" + 0.103*"may" + '
#   '-0.101*"good" + 0.101*"term" + -0.100*"take" + 0.098*"stability" + '
#   '-0.096*"state" + -0.096*"know"'),
#  (67,
#   '-0.185*"figure" + 0.132*"year" + -0.127*"that" + -0.125*"measure" + '
#   '0.124*"much" + -0.123*"fact" + -0.106*"say" + 0.099*"billion" + '
#   '0.099*"could" + -0.095*"one"'),
#  (68,
#   '0.144*"first" + -0.123*"regard" + 0.121*"issue" + 0.118*"sector" + '
#   '0.116*"present" + -0.111*"low" + -0.104*"european" + -0.103*"phenomenon" + '
#   '0.103*"projection" + 0.101*"possible"'),
#  (69,
#   '0.154*"could" + -0.127*"policy" + -0.121*"important" + -0.118*"part" + '
#   '-0.114*"liquidity" + 0.109*"level" + -0.103*"expectation" + 0.103*"look" + '
#   '0.103*"state" + -0.100*"euro"'),
#  (70,
#   '-0.159*"information" + -0.156*"situation" + 0.145*"know" + -0.113*"growth" '
#   '+ -0.108*"comment" + -0.107*"possible" + 0.104*"mentioned" + 0.104*"work" + '
#   '-0.103*"scenario" + 0.096*"position"'),
#  (71,
#   '0.144*"central" + 0.130*"work" + 0.126*"recovery" + -0.126*"course" + '
#   '0.110*"balance" + -0.106*"credit" + 0.099*"committee" + -0.099*"account" + '
#   '0.095*"programme" + 0.094*"already"'),
#  (72,
#   '0.154*"treaty" + -0.117*"done" + -0.110*"take" + -0.110*"come" + '
#   '-0.106*"good" + -0.105*"analysis" + 0.102*"certainly" + -0.102*"capital" + '
#   '0.094*"number" + 0.094*"european"'),
#  (73,
#   '-0.167*"last" + 0.138*"could" + -0.128*"answer" + 0.120*"certainly" + '
#   '-0.111*"inflationary" + -0.110*"balance" + 0.106*"euro" + 0.103*"change" + '
#   '-0.100*"sheet" + 0.097*"place"'),
#  (74,
#   '-0.112*"see" + 0.112*"taken" + -0.109*"ecb" + -0.105*"committee" + '
#   '-0.102*"level" + 0.098*"world" + 0.097*"take" + 0.090*"whether" + '
#   '0.088*"global" + -0.086*"line"'),
#  (75,
#   '-0.151*"case" + 0.129*"analysis" + 0.104*"various" + -0.103*"account" + '
#   '-0.099*"risk" + 0.097*"good" + 0.094*"side" + -0.089*"believe" + '
#   '-0.084*"made" + 0.084*"week"'),
#  (76,
#   '-0.156*"regard" + 0.136*"one" + -0.127*"want" + 0.110*"always" + '
#   '-0.108*"line" + 0.101*"growth" + 0.099*"again" + 0.098*"institution" + '
#   '-0.097*"already" + 0.093*"programme"'),
#  (77,
#   '0.135*"case" + 0.125*"responsibility" + -0.118*"fully" + -0.109*"issue" + '
#   '0.099*"whether" + -0.098*"come" + -0.095*"reform" + -0.095*"period" + '
#   '0.094*"difference" + 0.092*"recovery"'),
#  (78,
#   '-0.141*"point" + 0.128*"it" + 0.112*"assessment" + 0.110*"structural" + '
#   '-0.109*"mentioned" + 0.107*"number" + -0.102*"exactly" + 0.095*"already" + '
#   '0.094*"good" + -0.093*"objective"'),
#  (79,
#   '0.158*"already" + 0.127*"no" + -0.124*"interest" + 0.107*"money" + '
#   '-0.101*"may" + 0.092*"institution" + -0.092*"don" + 0.091*"last" + '
#   '0.091*"account" + 0.090*"different"'),
#  (80,
#   '-0.146*"month" + -0.125*"increase" + 0.101*"note" + 0.099*"fiscal" + '
#   '-0.094*"meeting" + 0.092*"judgement" + 0.089*"answer" + 0.088*"money" + '
#   '0.084*"let" + 0.083*"recovery"'),
#  (81,
#   '0.168*"currency" + -0.118*"consider" + 0.111*"message" + -0.103*"like" + '
#   '-0.101*"operation" + 0.100*"judgement" + 0.095*"particular" + '
#   '-0.093*"again" + 0.090*"second" + 0.090*"ltro"'),
#  (82,
#   '-0.109*"message" + -0.099*"recovery" + 0.094*"year" + -0.093*"bond" + '
#   '-0.093*"intervention" + -0.092*"liquidity" + -0.091*"area" + -0.089*"fact" '
#   '+ 0.088*"european" + -0.085*"comment"'),
#  (83,
#   '-0.153*"currency" + 0.110*"mentioned" + -0.098*"single" + '
#   '0.098*"credibility" + -0.092*"figure" + 0.085*"done" + 0.083*"proposal" + '
#   '0.083*"world" + -0.082*"data" + 0.081*"past"'),
#  (84,
#   '-0.116*"exactly" + -0.113*"press" + -0.104*"past" + 0.101*"thing" + '
#   '-0.100*"well" + -0.095*"change" + 0.095*"projection" + '
#   '-0.092*"responsibility" + -0.092*"close" + -0.091*"first"'),
#  (85,
#   '-0.142*"economic" + 0.118*"message" + -0.115*"today" + 0.101*"again" + '
#   '0.098*"term" + 0.095*"statement" + -0.093*"greece" + 0.093*"commission" + '
#   '-0.089*"europe" + -0.088*"remain"'),
#  (86,
#   '-0.215*"month" + 0.134*"still" + -0.127*"projection" + -0.100*"present" + '
#   '0.099*"responsibility" + -0.097*"real" + 0.085*"position" + '
#   '-0.084*"banking" + -0.084*"may" + -0.082*"see"'),
#  (87,
#   '0.138*"united" + 0.110*"state" + 0.104*"europe" + 0.092*"part" + '
#   '0.091*"mandate" + 0.089*"certainly" + -0.089*"week" + -0.088*"respect" + '
#   '-0.086*"concerned" + 0.084*"real"'),
#  (88,
#   '0.114*"today" + -0.111*"make" + 0.102*"level" + 0.101*"risk" + '
#   '0.092*"liquidity" + 0.091*"future" + 0.090*"repeat" + 0.088*"we" + '
#   '0.087*"particular" + -0.083*"work"'),
#  (89,
#   '-0.142*"expectation" + 0.132*"uncertainty" + -0.106*"really" + '
#   '0.103*"analysis" + -0.098*"and" + -0.090*"something" + 0.089*"comment" + '
#   '0.089*"situation" + -0.084*"mind" + -0.077*"period"'),
#  (90,
#   '0.124*"much" + 0.112*"even" + -0.102*"statement" + 0.099*"different" + '
#   '-0.094*"comment" + -0.092*"european" + -0.088*"give" + 0.086*"interest" + '
#   '-0.085*"important" + -0.085*"said"'),
#  (91,
#   '-0.141*"today" + 0.103*"actually" + 0.099*"government" + -0.096*"press" + '
#   '-0.095*"npls" + 0.095*"conclusion" + 0.093*"uncertainty" + 0.090*"new" + '
#   '0.083*"economic" + -0.081*"president"'),
#  (92,
#   '0.121*"always" + -0.121*"continue" + 0.120*"much" + 0.119*"economic" + '
#   '0.118*"made" + -0.095*"different" + -0.094*"recovery" + 0.092*"expectation" '
#   '+ -0.088*"credit" + 0.086*"so"'),
#  (93,
#   '-0.105*"let" + 0.101*"capital" + -0.099*"today" + -0.096*"way" + '
#   '0.095*"know" + 0.091*"line" + 0.088*"investment" + -0.087*"actually" + '
#   '0.087*"member" + 0.083*"recent"'),
#  (94,
#   '0.123*"term" + -0.115*"responsibility" + 0.094*"take" + 0.092*"again" + '
#   '-0.089*"real" + -0.088*"thing" + 0.086*"data" + 0.085*"no" + -0.084*"point" '
#   '+ 0.080*"different"'),
#  (95,
#   '0.145*"basis" + -0.109*"authority" + 0.093*"operation" + 0.089*"make" + '
#   '0.088*"everything" + -0.087*"capital" + 0.085*"financial" + '
#   '0.081*"exchange" + 0.081*"objective" + -0.081*"real"'),
#  (96,
#   '0.101*"european" + 0.100*"want" + -0.097*"factor" + -0.095*"particular" + '
#   '-0.094*"situation" + 0.092*"high" + -0.089*"risksharing" + 0.087*"part" + '
#   '0.086*"monetary" + -0.086*"perhaps"'),
#  (97,
#   '-0.118*"functioning" + 0.116*"basis" + -0.111*"message" + '
#   '-0.109*"information" + -0.109*"possible" + 0.101*"let" + 0.094*"position" + '
#   '0.092*"good" + 0.092*"expectation" + -0.092*"real"'),
#  (98,
#   '-0.099*"statement" + -0.098*"operation" + 0.095*"process" + 0.093*"central" '
#   '+ 0.090*"regard" + -0.089*"know" + -0.088*"large" + 0.087*"global" + '
#   '0.086*"single" + -0.086*"time"'),
#  (99,
#   '0.097*"institution" + 0.092*"european" + -0.091*"present" + -0.085*"price" '
#   '+ -0.084*"say" + 0.082*"comment" + 0.080*"global" + 0.080*"secondround" + '
#   '0.079*"cost" + -0.078*"credible"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.



coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)


coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='u_mass')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)
# Out:
# Coherence Score:  0.2557228304347493
#
# Coherence Score5:  0.34166206714252395
#
# Coherence Score10:  0.3050823323585386
#
# Coherence Score20:  0.27815279478346033
#
# Coherence Score50:  0.24787326310743485
#
# Coherence Score100:  0.23150942130445532
#
# Coherence Score:  -0.030953575948142256
#
# Coherence Score5:  -0.30216810482773016
#
# Coherence Score10:  -0.2991464124606581
#
# Coherence Score20:  -0.36878209606153034
#
# Coherence Score50:  -0.7149723007993952
#
# Coherence Score100:  -0.6274030680867986
