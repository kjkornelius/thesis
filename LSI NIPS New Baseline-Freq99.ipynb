# %% [markdown]
# # load packages

# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess, lemmatize
from gensim.models import CoherenceModel
from gensim.models import LdaModel, LdaMulticore
import gensim.downloader as api
from gensim.models import LsiModel

nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools 
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
#import logging
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
#logging.root.setLevel(level=logging.INFO)
#import warnings
#warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_csv('C:/Users/Kornelius/Desktop/Data 2/nips-papers/papers.csv', header = 0, sep = ';', error_bad_lines=False)
# Drop the columns not needed
df = df.drop(columns=['id', 'event_type', 'pdf_name'], axis=1)

# %%
# Drop a row by condition
df = df[df.abstract != 'Abstract Missing']

# %%
data = df.abstract.values.tolist()

# %% [markdown]
# # Pre-processing (Baseline)

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(data):
    stop_free = " ".join([i for i in data.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(data).split() for data in data]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(16129 unique tokens: ['activity', 'also', 'analysis', 'applied', 'assume']...)

# %%
# filter words that occur in more than 98% of documents
id2word.filter_extremes(no_above = 0.990)
print(id2word)
# Out:
# Dictionary(4415 unique tokens: ['activity', 'also', 'analysis', 'applied', 'assume']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# # LSI

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.103*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '0.519*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.327*"network" + '
#   '-0.296*"method" + -0.165*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.123*"neural"'),
#  (3,
#   '-0.574*"method" + 0.440*"learning" + 0.359*"network" + 0.292*"algorithm" + '
#   '-0.254*"data" + -0.121*"matrix" + -0.104*"problem" + 0.100*"neural" + '
#   '0.099*"deep" + 0.087*"task"'),
#  (4,
#   '-0.588*"network" + 0.579*"learning" + 0.267*"data" + -0.218*"neural" + '
#   '-0.104*"algorithm" + -0.104*"method" + 0.081*"task" + -0.080*"deep" + '
#   '0.075*"approach" + -0.075*"image"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.103*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '0.519*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.327*"network" + '
#   '-0.296*"method" + -0.165*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.123*"neural"'),
#  (3,
#   '0.574*"method" + -0.440*"learning" + -0.359*"network" + -0.292*"algorithm" '
#   '+ 0.254*"data" + 0.121*"matrix" + 0.104*"problem" + -0.100*"neural" + '
#   '-0.099*"deep" + -0.087*"task"'),
#  (4,
#   '-0.589*"network" + 0.579*"learning" + 0.267*"data" + -0.218*"neural" + '
#   '-0.104*"method" + -0.104*"algorithm" + 0.081*"task" + -0.079*"deep" + '
#   '0.075*"approach" + -0.075*"image"'),
#  (5,
#   '0.681*"data" + -0.316*"function" + 0.262*"algorithm" + -0.201*"model" + '
#   '-0.196*"problem" + -0.184*"learning" + -0.162*"method" + 0.139*"network" + '
#   '-0.114*"optimization" + 0.112*"feature"'),
#  (6,
#   '0.523*"image" + -0.327*"data" + -0.271*"function" + -0.251*"network" + '
#   '0.243*"algorithm" + 0.236*"feature" + 0.233*"object" + 0.219*"method" + '
#   '-0.185*"distribution" + -0.120*"bound"'),
#  (7,
#   '0.483*"method" + -0.424*"problem" + 0.320*"algorithm" + -0.289*"image" + '
#   '0.225*"learning" + -0.126*"object" + 0.124*"inference" + 0.123*"gradient" + '
#   '-0.121*"matrix" + -0.113*"distribution"'),
#  (8,
#   '-0.568*"problem" + 0.530*"function" + 0.212*"image" + 0.191*"feature" + '
#   '-0.183*"matrix" + -0.170*"learning" + 0.168*"distribution" + '
#   '-0.145*"network" + 0.127*"bound" + 0.095*"loss"'),
#  (9,
#   '0.501*"function" + -0.351*"distribution" + -0.270*"bound" + 0.258*"data" + '
#   '0.249*"problem" + -0.204*"matrix" + -0.194*"sample" + 0.132*"optimization" '
#   '+ -0.106*"show" + -0.104*"complexity"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.103*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '-0.519*"algorithm" + -0.391*"model" + 0.334*"learning" + 0.327*"network" + '
#   '0.296*"method" + 0.165*"image" + 0.155*"task" + 0.143*"feature" + '
#   '0.125*"deep" + 0.124*"neural"'),
#  (3,
#   '0.574*"method" + -0.440*"learning" + -0.359*"network" + -0.292*"algorithm" '
#   '+ 0.254*"data" + 0.121*"matrix" + 0.104*"problem" + -0.100*"neural" + '
#   '-0.098*"deep" + -0.087*"task"'),
#  (4,
#   '-0.589*"network" + 0.579*"learning" + 0.267*"data" + -0.218*"neural" + '
#   '-0.104*"algorithm" + -0.104*"method" + 0.081*"task" + -0.079*"deep" + '
#   '0.075*"approach" + -0.075*"image"'),
#  (5,
#   '0.681*"data" + -0.316*"function" + 0.262*"algorithm" + -0.201*"model" + '
#   '-0.196*"problem" + -0.185*"learning" + -0.162*"method" + 0.139*"network" + '
#   '-0.114*"optimization" + 0.112*"feature"'),
#  (6,
#   '-0.522*"image" + 0.327*"data" + 0.271*"function" + 0.251*"network" + '
#   '-0.243*"algorithm" + -0.236*"feature" + -0.233*"object" + -0.219*"method" + '
#   '0.185*"distribution" + 0.119*"bound"'),
#  (7,
#   '0.483*"method" + -0.424*"problem" + 0.320*"algorithm" + -0.290*"image" + '
#   '0.224*"learning" + -0.125*"object" + 0.124*"inference" + 0.122*"gradient" + '
#   '-0.121*"matrix" + -0.113*"distribution"'),
#  (8,
#   '-0.569*"problem" + 0.529*"function" + 0.211*"image" + 0.191*"feature" + '
#   '-0.184*"matrix" + -0.170*"learning" + 0.167*"distribution" + '
#   '-0.145*"network" + 0.126*"bound" + 0.096*"loss"'),
#  (9,
#   '0.500*"function" + -0.351*"distribution" + -0.269*"bound" + 0.258*"data" + '
#   '0.250*"problem" + -0.205*"matrix" + -0.195*"sample" + 0.128*"optimization" '
#   '+ -0.106*"complexity" + -0.104*"show"'),
#  (10,
#   '-0.448*"feature" + -0.380*"matrix" + 0.368*"distribution" + '
#   '0.277*"approach" + 0.244*"inference" + 0.202*"image" + -0.186*"kernel" + '
#   '-0.131*"model" + 0.125*"problem" + -0.109*"function"'),
#  (11,
#   '0.404*"feature" + 0.322*"kernel" + 0.298*"approach" + -0.275*"bound" + '
#   '0.242*"inference" + -0.224*"image" + 0.194*"distribution" + -0.182*"data" + '
#   '-0.164*"loss" + 0.140*"graph"'),
#  (12,
#   '-0.285*"graph" + -0.274*"image" + 0.258*"task" + -0.230*"distribution" + '
#   '-0.221*"matrix" + 0.208*"time" + 0.191*"policy" + 0.174*"information" + '
#   '0.170*"feature" + -0.169*"kernel"'),
#  (13,
#   '-0.509*"matrix" + 0.384*"feature" + -0.277*"approach" + 0.238*"graph" + '
#   '0.172*"bound" + -0.159*"image" + 0.156*"problem" + 0.147*"method" + '
#   '0.139*"distribution" + -0.123*"neural"'),
#  (14,
#   '-0.510*"graph" + 0.369*"distribution" + 0.311*"feature" + -0.230*"approach" '
#   '+ 0.180*"problem" + -0.167*"kernel" + -0.161*"bound" + -0.156*"clustering" '
#   '+ 0.146*"gradient" + -0.146*"time"'),
#  (15,
#   '-0.401*"approach" + -0.398*"bound" + 0.285*"graph" + 0.281*"distribution" + '
#   '-0.217*"inference" + 0.167*"task" + -0.160*"feature" + 0.142*"clustering" + '
#   '0.118*"method" + 0.118*"information"'),
#  (16,
#   '0.463*"kernel" + -0.358*"task" + -0.277*"matrix" + 0.201*"image" + '
#   '0.189*"gradient" + -0.188*"function" + 0.179*"rate" + -0.161*"approach" + '
#   '0.151*"stochastic" + 0.121*"convergence"'),
#  (17,
#   '-0.343*"task" + -0.279*"gradient" + 0.230*"bound" + 0.222*"inference" + '
#   '-0.191*"training" + 0.190*"method" + 0.188*"image" + -0.150*"stochastic" + '
#   '0.149*"learning" + -0.148*"kernel"'),
#  (18,
#   '0.501*"kernel" + -0.354*"approach" + 0.315*"task" + -0.213*"graph" + '
#   '-0.191*"feature" + -0.154*"sparse" + 0.145*"inference" + '
#   '0.138*"classification" + -0.125*"gradient" + 0.117*"process"'),
#  (19,
#   '0.287*"gradient" + -0.253*"loss" + 0.236*"matrix" + 0.227*"policy" + '
#   '-0.216*"neural" + 0.197*"stochastic" + -0.178*"approach" + -0.176*"linear" '
#   '+ -0.167*"classification" + 0.165*"time"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.103*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '0.519*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.327*"network" + '
#   '-0.296*"method" + -0.165*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.123*"neural"'),
#  (3,
#   '-0.574*"method" + 0.440*"learning" + 0.359*"network" + 0.292*"algorithm" + '
#   '-0.254*"data" + -0.121*"matrix" + -0.104*"problem" + 0.100*"neural" + '
#   '0.099*"deep" + 0.087*"task"'),
#  (4,
#   '0.588*"network" + -0.579*"learning" + -0.267*"data" + 0.218*"neural" + '
#   '0.104*"method" + 0.104*"algorithm" + -0.081*"task" + 0.079*"deep" + '
#   '-0.075*"approach" + 0.075*"image"'),
#  (5,
#   '-0.681*"data" + 0.316*"function" + -0.262*"algorithm" + 0.201*"model" + '
#   '0.196*"problem" + 0.184*"learning" + 0.162*"method" + -0.139*"network" + '
#   '0.114*"optimization" + -0.112*"feature"'),
#  (6,
#   '-0.523*"image" + 0.327*"data" + 0.271*"function" + 0.251*"network" + '
#   '-0.243*"algorithm" + -0.236*"feature" + -0.233*"object" + -0.219*"method" + '
#   '0.185*"distribution" + 0.119*"bound"'),
#  (7,
#   '0.483*"method" + -0.424*"problem" + 0.320*"algorithm" + -0.290*"image" + '
#   '0.225*"learning" + -0.125*"object" + 0.124*"inference" + 0.123*"gradient" + '
#   '-0.121*"matrix" + -0.113*"distribution"'),
#  (8,
#   '-0.568*"problem" + 0.530*"function" + 0.212*"image" + 0.191*"feature" + '
#   '-0.184*"matrix" + -0.170*"learning" + 0.167*"distribution" + '
#   '-0.145*"network" + 0.127*"bound" + 0.095*"loss"'),
#  (9,
#   '-0.500*"function" + 0.350*"distribution" + 0.271*"bound" + -0.258*"data" + '
#   '-0.250*"problem" + 0.206*"matrix" + 0.195*"sample" + -0.131*"optimization" '
#   '+ 0.105*"show" + 0.103*"complexity"'),
#  (10,
#   '-0.448*"feature" + -0.380*"matrix" + 0.368*"distribution" + '
#   '0.277*"approach" + 0.244*"inference" + 0.202*"image" + -0.185*"kernel" + '
#   '-0.131*"model" + 0.125*"problem" + -0.110*"function"'),
#  (11,
#   '0.402*"feature" + 0.324*"kernel" + 0.298*"approach" + -0.275*"bound" + '
#   '0.240*"inference" + -0.223*"image" + 0.197*"distribution" + -0.183*"data" + '
#   '-0.162*"loss" + 0.140*"graph"'),
#  (12,
#   '-0.282*"graph" + -0.276*"image" + 0.259*"task" + -0.229*"distribution" + '
#   '-0.222*"matrix" + 0.210*"time" + 0.191*"policy" + 0.174*"feature" + '
#   '0.172*"information" + -0.166*"kernel"'),
#  (13,
#   '-0.508*"matrix" + 0.388*"feature" + -0.281*"approach" + 0.235*"graph" + '
#   '0.170*"bound" + 0.158*"problem" + -0.157*"image" + 0.146*"method" + '
#   '0.144*"distribution" + -0.122*"neural"'),
#  (14,
#   '-0.512*"graph" + 0.367*"distribution" + 0.307*"feature" + -0.232*"approach" '
#   '+ 0.179*"problem" + -0.166*"kernel" + -0.163*"bound" + -0.156*"clustering" '
#   '+ 0.147*"gradient" + -0.144*"time"'),
#  (15,
#   '0.398*"approach" + 0.397*"bound" + -0.282*"graph" + -0.280*"distribution" + '
#   '0.214*"inference" + -0.172*"task" + 0.160*"feature" + -0.147*"clustering" + '
#   '-0.121*"method" + -0.117*"information"'),
#  (16,
#   '-0.461*"kernel" + 0.357*"task" + 0.279*"matrix" + -0.200*"image" + '
#   '-0.192*"gradient" + 0.189*"function" + -0.175*"rate" + 0.169*"approach" + '
#   '-0.143*"stochastic" + -0.123*"convergence"'),
#  (17,
#   '-0.339*"task" + -0.273*"gradient" + 0.234*"bound" + 0.228*"inference" + '
#   '-0.191*"training" + 0.188*"method" + 0.187*"image" + 0.149*"learning" + '
#   '-0.146*"stochastic" + -0.139*"kernel"'),
#  (18,
#   '0.509*"kernel" + -0.356*"approach" + 0.321*"task" + -0.211*"graph" + '
#   '-0.192*"feature" + -0.153*"sparse" + 0.144*"inference" + '
#   '0.141*"classification" + 0.124*"process" + -0.117*"gradient"'),
#  (19,
#   '0.292*"gradient" + -0.257*"loss" + 0.233*"matrix" + 0.230*"policy" + '
#   '-0.209*"neural" + 0.200*"stochastic" + -0.174*"classification" + '
#   '-0.173*"linear" + -0.170*"approach" + 0.164*"time"'),
#  (20,
#   '-0.500*"inference" + 0.278*"approach" + 0.211*"policy" + 0.199*"kernel" + '
#   '-0.182*"graph" + -0.167*"show" + 0.163*"distribution" + -0.144*"task" + '
#   '-0.139*"variational" + -0.133*"gradient"'),
#  (21,
#   '-0.398*"task" + -0.344*"bound" + 0.321*"time" + 0.233*"show" + '
#   '0.226*"label" + 0.187*"training" + 0.187*"loss" + -0.146*"structure" + '
#   '0.135*"classification" + 0.127*"prediction"'),
#  (22,
#   '-0.344*"clustering" + 0.262*"time" + -0.227*"information" + 0.225*"sparse" '
#   '+ 0.178*"parameter" + 0.177*"task" + 0.177*"regression" + 0.169*"image" + '
#   '-0.168*"matrix" + -0.163*"approach"'),
#  (23,
#   '0.448*"clustering" + -0.331*"graph" + 0.235*"show" + -0.181*"gradient" + '
#   '-0.170*"time" + -0.166*"information" + -0.165*"loss" + 0.157*"cluster" + '
#   '0.153*"result" + 0.146*"set"'),
#  (24,
#   '0.372*"result" + -0.286*"object" + 0.283*"policy" + -0.221*"number" + '
#   '-0.198*"sample" + -0.197*"time" + 0.190*"show" + -0.178*"task" + '
#   '-0.174*"parameter" + 0.159*"new"'),
#  (25,
#   '-0.325*"time" + -0.248*"object" + -0.236*"loss" + 0.198*"training" + '
#   '0.191*"show" + 0.185*"neural" + 0.180*"bound" + 0.178*"using" + '
#   '0.171*"policy" + -0.163*"framework"'),
#  (26,
#   '0.467*"object" + -0.361*"time" + 0.226*"show" + -0.226*"clustering" + '
#   '0.209*"variable" + -0.184*"result" + 0.175*"structure" + -0.152*"image" + '
#   '0.147*"latent" + 0.133*"space"'),
#  (27,
#   '-0.354*"information" + -0.299*"process" + 0.287*"show" + -0.260*"label" + '
#   '0.249*"object" + -0.160*"parameter" + 0.155*"time" + -0.148*"bayesian" + '
#   '-0.148*"set" + 0.130*"task"'),
#  (28,
#   '0.319*"latent" + 0.242*"variable" + 0.237*"show" + 0.194*"time" + '
#   '0.189*"clustering" + -0.185*"graph" + 0.177*"structure" + 0.171*"topic" + '
#   '0.170*"information" + -0.159*"inference"'),
#  (29,
#   '0.456*"information" + -0.306*"loss" + -0.235*"state" + -0.225*"number" + '
#   '-0.198*"clustering" + -0.157*"process" + -0.144*"task" + 0.141*"sample" + '
#   '-0.132*"linear" + -0.127*"gradient"'),
#  (30,
#   '0.463*"show" + 0.274*"loss" + -0.233*"result" + -0.199*"class" + '
#   '-0.180*"number" + -0.173*"latent" + -0.150*"analysis" + 0.147*"parameter" + '
#   '-0.142*"topic" + -0.139*"variable"'),
#  (31,
#   '-0.354*"sample" + -0.306*"variable" + -0.274*"training" + '
#   '-0.209*"clustering" + -0.206*"latent" + 0.205*"label" + '
#   '0.190*"distribution" + 0.183*"sparse" + 0.180*"number" + -0.172*"loss"'),
#  (32,
#   '-0.377*"set" + 0.230*"process" + 0.206*"bound" + -0.191*"kernel" + '
#   '0.185*"error" + 0.177*"based" + -0.169*"parameter" + -0.169*"regret" + '
#   '0.163*"classification" + -0.161*"result"'),
#  (33,
#   '-0.364*"using" + 0.289*"label" + 0.240*"set" + -0.210*"loss" + '
#   '-0.205*"number" + 0.176*"show" + 0.167*"rate" + 0.166*"class" + '
#   '-0.161*"sparse" + -0.147*"object"'),
#  (34,
#   '0.309*"process" + 0.280*"training" + 0.231*"set" + -0.227*"state" + '
#   '0.193*"optimization" + 0.176*"performance" + -0.173*"estimator" + '
#   '-0.169*"information" + -0.160*"gradient" + -0.154*"label"'),
#  (35,
#   '0.304*"using" + -0.267*"performance" + 0.262*"set" + -0.250*"variable" + '
#   '0.245*"result" + -0.207*"policy" + -0.179*"parameter" + 0.173*"space" + '
#   '0.171*"rate" + 0.149*"based"'),
#  (36,
#   '-0.303*"using" + 0.289*"process" + 0.259*"number" + -0.253*"parameter" + '
#   '0.232*"rate" + -0.206*"set" + 0.176*"information" + 0.175*"sample" + '
#   '0.171*"show" + -0.171*"structure"'),
#  (37,
#   '0.470*"framework" + 0.261*"domain" + -0.200*"result" + -0.195*"performance" '
#   '+ 0.179*"sample" + -0.170*"state" + 0.168*"label" + -0.149*"information" + '
#   '-0.148*"estimator" + 0.146*"complexity"'),
#  (38,
#   '0.308*"using" + 0.278*"class" + -0.257*"set" + -0.184*"loss" + '
#   '-0.182*"state" + -0.160*"domain" + 0.157*"result" + 0.156*"rate" + '
#   '-0.153*"paper" + 0.144*"estimator"'),
#  (39,
#   '0.308*"structure" + -0.298*"parameter" + -0.243*"state" + 0.229*"gradient" '
#   '+ -0.218*"framework" + -0.190*"optimization" + 0.189*"tree" + '
#   '0.184*"sample" + 0.173*"result" + 0.159*"complexity"'),
#  (40,
#   '-0.282*"variable" + 0.255*"structure" + -0.252*"linear" + 0.209*"neural" + '
#   '0.198*"class" + 0.198*"tree" + 0.184*"parameter" + -0.164*"using" + '
#   '-0.156*"latent" + 0.150*"show"'),
#  (41,
#   '-0.278*"space" + 0.253*"result" + 0.253*"using" + 0.231*"number" + '
#   '-0.224*"representation" + -0.209*"estimator" + -0.174*"sparse" + '
#   '0.171*"new" + 0.165*"parameter" + 0.139*"based"'),
#  (42,
#   '0.355*"analysis" + 0.288*"process" + -0.227*"sparse" + '
#   '-0.218*"optimization" + -0.164*"clustering" + -0.153*"bayesian" + '
#   '-0.146*"kernel" + -0.143*"optimal" + 0.142*"set" + -0.134*"rate"'),
#  (43,
#   '-0.308*"rate" + 0.268*"linear" + 0.252*"information" + 0.216*"result" + '
#   '0.203*"framework" + -0.166*"word" + 0.164*"object" + 0.164*"state" + '
#   '0.159*"gradient" + -0.152*"topic"'),
#  (44,
#   '-0.368*"domain" + 0.252*"sample" + -0.201*"information" + -0.195*"time" + '
#   '0.185*"number" + -0.166*"sparse" + -0.163*"structure" + 0.162*"system" + '
#   '0.162*"framework" + 0.140*"linear"'),
#  (45,
#   '-0.280*"new" + -0.272*"optimization" + -0.259*"class" + 0.234*"result" + '
#   '-0.213*"policy" + -0.203*"using" + -0.155*"loss" + 0.145*"proposed" + '
#   '0.143*"label" + 0.142*"estimator"'),
#  (46,
#   '0.242*"policy" + -0.241*"tree" + 0.230*"optimization" + -0.222*"new" + '
#   '-0.218*"linear" + -0.196*"class" + -0.193*"state" + 0.189*"result" + '
#   '0.180*"label" + 0.153*"sample"'),
#  (47,
#   '0.216*"state" + 0.209*"representation" + 0.207*"class" + -0.201*"number" + '
#   '-0.195*"metric" + -0.186*"structure" + -0.168*"space" + 0.168*"human" + '
#   '-0.153*"tree" + 0.143*"sparse"'),
#  (48,
#   '0.428*"new" + -0.329*"optimization" + -0.238*"domain" + 0.188*"sparse" + '
#   '0.169*"gradient" + -0.154*"random" + 0.145*"set" + 0.139*"policy" + '
#   '0.130*"rate" + -0.124*"work"'),
#  (49,
#   '-0.316*"parameter" + -0.286*"linear" + 0.259*"performance" + 0.194*"state" '
#   '+ -0.162*"representation" + -0.160*"system" + 0.151*"using" + '
#   '0.150*"variable" + -0.143*"policy" + 0.142*"random"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '0.728*"model" + -0.434*"algorithm" + -0.240*"problem" + -0.134*"function" + '
#   '-0.114*"learning" + 0.108*"network" + 0.103*"image" + -0.090*"bound" + '
#   '0.086*"neural" + -0.079*"method"'),
#  (2,
#   '-0.519*"algorithm" + -0.391*"model" + 0.334*"learning" + 0.327*"network" + '
#   '0.296*"method" + 0.165*"image" + 0.155*"task" + 0.143*"feature" + '
#   '0.125*"deep" + 0.123*"neural"'),
#  (3,
#   '0.574*"method" + -0.440*"learning" + -0.359*"network" + -0.292*"algorithm" '
#   '+ 0.254*"data" + 0.121*"matrix" + 0.104*"problem" + -0.100*"neural" + '
#   '-0.098*"deep" + -0.087*"task"'),
#  (4,
#   '-0.588*"network" + 0.579*"learning" + 0.267*"data" + -0.218*"neural" + '
#   '-0.104*"algorithm" + -0.104*"method" + 0.081*"task" + -0.079*"deep" + '
#   '0.075*"approach" + -0.075*"image"'),
#  (5,
#   '0.681*"data" + -0.316*"function" + 0.262*"algorithm" + -0.201*"model" + '
#   '-0.196*"problem" + -0.184*"learning" + -0.162*"method" + 0.139*"network" + '
#   '-0.114*"optimization" + 0.112*"feature"'),
#  (6,
#   '-0.523*"image" + 0.327*"data" + 0.271*"function" + 0.251*"network" + '
#   '-0.243*"algorithm" + -0.236*"feature" + -0.233*"object" + -0.219*"method" + '
#   '0.185*"distribution" + 0.119*"bound"'),
#  (7,
#   '-0.483*"method" + 0.424*"problem" + -0.320*"algorithm" + 0.290*"image" + '
#   '-0.225*"learning" + 0.125*"object" + -0.124*"inference" + -0.123*"gradient" '
#   '+ 0.121*"matrix" + 0.113*"distribution"'),
#  (8,
#   '-0.568*"problem" + 0.530*"function" + 0.211*"image" + 0.191*"feature" + '
#   '-0.184*"matrix" + -0.170*"learning" + 0.167*"distribution" + '
#   '-0.145*"network" + 0.127*"bound" + 0.095*"loss"'),
#  (9,
#   '-0.500*"function" + 0.349*"distribution" + 0.271*"bound" + -0.258*"data" + '
#   '-0.250*"problem" + 0.206*"matrix" + 0.195*"sample" + -0.130*"optimization" '
#   '+ 0.105*"complexity" + 0.104*"show"'),
#  (10,
#   '0.448*"feature" + 0.379*"matrix" + -0.369*"distribution" + '
#   '-0.277*"approach" + -0.244*"inference" + -0.202*"image" + 0.186*"kernel" + '
#   '0.131*"model" + -0.125*"problem" + 0.111*"function"'),
#  (11,
#   '0.403*"feature" + 0.323*"kernel" + 0.299*"approach" + -0.275*"bound" + '
#   '0.240*"inference" + -0.222*"image" + 0.197*"distribution" + -0.183*"data" + '
#   '-0.162*"loss" + 0.140*"graph"'),
#  (12,
#   '-0.283*"graph" + -0.275*"image" + 0.259*"task" + -0.229*"distribution" + '
#   '-0.222*"matrix" + 0.210*"time" + 0.190*"policy" + 0.174*"feature" + '
#   '0.173*"information" + -0.166*"kernel"'),
#  (13,
#   '-0.508*"matrix" + 0.388*"feature" + -0.281*"approach" + 0.237*"graph" + '
#   '0.171*"bound" + 0.158*"problem" + -0.158*"image" + 0.147*"method" + '
#   '0.142*"distribution" + -0.121*"neural"'),
#  (14,
#   '0.511*"graph" + -0.367*"distribution" + -0.308*"feature" + 0.232*"approach" '
#   '+ -0.180*"problem" + 0.167*"kernel" + 0.162*"bound" + 0.155*"clustering" + '
#   '-0.148*"gradient" + 0.144*"time"'),
#  (15,
#   '-0.403*"approach" + -0.397*"bound" + 0.283*"graph" + 0.279*"distribution" + '
#   '-0.216*"inference" + 0.165*"task" + -0.160*"feature" + 0.146*"clustering" + '
#   '0.119*"method" + 0.116*"information"'),
#  (16,
#   '-0.460*"kernel" + 0.363*"task" + 0.278*"matrix" + -0.200*"image" + '
#   '-0.194*"gradient" + 0.191*"function" + -0.174*"rate" + 0.161*"approach" + '
#   '-0.144*"stochastic" + -0.124*"convergence"'),
#  (17,
#   '-0.339*"task" + -0.271*"gradient" + 0.236*"bound" + 0.229*"inference" + '
#   '-0.191*"training" + 0.188*"image" + 0.187*"method" + 0.149*"learning" + '
#   '-0.145*"stochastic" + -0.142*"convergence"'),
#  (18,
#   '0.511*"kernel" + -0.356*"approach" + 0.318*"task" + -0.212*"graph" + '
#   '-0.192*"feature" + -0.153*"sparse" + 0.141*"inference" + '
#   '0.139*"classification" + 0.123*"process" + -0.115*"gradient"'),
#  (19,
#   '0.295*"gradient" + -0.256*"loss" + 0.233*"matrix" + 0.232*"policy" + '
#   '-0.212*"neural" + 0.202*"stochastic" + -0.173*"approach" + -0.173*"linear" '
#   '+ -0.172*"classification" + 0.163*"process"'),
#  (20,
#   '0.501*"inference" + -0.277*"approach" + -0.212*"policy" + -0.198*"kernel" + '
#   '0.181*"graph" + 0.168*"show" + -0.160*"distribution" + 0.143*"task" + '
#   '0.141*"variational" + 0.135*"loss"'),
#  (21,
#   '0.398*"task" + 0.346*"bound" + -0.324*"time" + -0.230*"show" + '
#   '-0.226*"label" + -0.188*"loss" + -0.186*"training" + 0.149*"structure" + '
#   '-0.137*"classification" + -0.132*"class"'),
#  (22,
#   '-0.348*"clustering" + 0.261*"time" + -0.226*"information" + 0.225*"sparse" '
#   '+ 0.181*"parameter" + 0.179*"task" + 0.174*"regression" + 0.171*"image" + '
#   '-0.169*"matrix" + -0.164*"approach"'),
#  (23,
#   '-0.444*"clustering" + 0.331*"graph" + -0.239*"show" + 0.181*"gradient" + '
#   '0.172*"information" + 0.169*"time" + 0.162*"loss" + -0.162*"cluster" + '
#   '-0.154*"result" + -0.147*"set"'),
#  (24,
#   '0.366*"result" + 0.283*"policy" + -0.275*"object" + -0.223*"number" + '
#   '-0.196*"sample" + -0.194*"time" + 0.191*"show" + -0.178*"task" + '
#   '-0.171*"parameter" + 0.161*"new"'),
#  (25,
#   '-0.328*"time" + -0.256*"object" + -0.234*"loss" + 0.200*"show" + '
#   '0.197*"training" + 0.185*"neural" + 0.179*"bound" + 0.178*"policy" + '
#   '0.177*"using" + -0.169*"framework"'),
#  (26,
#   '0.470*"object" + -0.363*"time" + -0.221*"clustering" + 0.218*"show" + '
#   '0.210*"variable" + -0.191*"result" + 0.176*"structure" + -0.152*"image" + '
#   '0.146*"latent" + 0.134*"space"'),
#  (27,
#   '-0.331*"latent" + -0.267*"show" + -0.242*"variable" + -0.209*"time" + '
#   '-0.179*"clustering" + 0.175*"graph" + -0.173*"structure" + -0.167*"topic" + '
#   '0.155*"inference" + -0.151*"word"'),
#  (28,
#   '-0.363*"information" + -0.299*"process" + 0.273*"show" + 0.266*"object" + '
#   '-0.261*"label" + -0.157*"parameter" + -0.153*"set" + -0.145*"bayesian" + '
#   '0.137*"task" + 0.137*"time"'),
#  (29,
#   '-0.462*"information" + 0.301*"loss" + 0.227*"state" + 0.213*"number" + '
#   '0.198*"clustering" + 0.157*"process" + 0.150*"task" + -0.142*"sample" + '
#   '0.133*"linear" + 0.131*"gradient"'),
#  (30,
#   '-0.464*"show" + -0.263*"loss" + 0.249*"result" + 0.196*"class" + '
#   '0.183*"latent" + 0.180*"number" + -0.148*"parameter" + 0.147*"topic" + '
#   '0.146*"analysis" + -0.142*"regret"'),
#  (31,
#   '0.374*"sample" + 0.285*"variable" + 0.266*"training" + -0.220*"label" + '
#   '0.203*"clustering" + 0.199*"latent" + 0.192*"loss" + -0.186*"number" + '
#   '-0.184*"distribution" + -0.174*"sparse"'),
#  (32,
#   '-0.388*"set" + 0.230*"process" + 0.204*"bound" + -0.189*"kernel" + '
#   '-0.175*"parameter" + 0.171*"error" + -0.163*"result" + 0.163*"based" + '
#   '-0.161*"regret" + -0.156*"setting"'),
#  (33,
#   '-0.353*"using" + 0.276*"label" + -0.225*"number" + -0.220*"loss" + '
#   '0.219*"set" + -0.173*"sparse" + 0.172*"class" + 0.167*"show" + 0.166*"rate" '
#   '+ -0.149*"object"'),
#  (34,
#   '-0.294*"process" + -0.269*"training" + -0.246*"set" + 0.228*"state" + '
#   '-0.193*"performance" + -0.182*"optimization" + 0.178*"estimator" + '
#   '0.178*"information" + 0.157*"label" + -0.144*"object"'),
#  (35,
#   '0.331*"using" + -0.264*"performance" + 0.263*"set" + -0.259*"variable" + '
#   '0.250*"result" + -0.209*"policy" + 0.172*"space" + -0.170*"parameter" + '
#   '0.156*"rate" + -0.155*"loss"'),
#  (36,
#   '-0.308*"process" + -0.263*"rate" + 0.235*"using" + 0.234*"parameter" + '
#   '-0.233*"number" + 0.209*"set" + 0.198*"gradient" + -0.174*"sample" + '
#   '-0.169*"show" + 0.155*"structure"'),
#  (37,
#   '-0.495*"framework" + 0.220*"state" + -0.220*"domain" + -0.206*"using" + '
#   '-0.179*"structure" + 0.179*"information" + -0.169*"label" + 0.162*"result" '
#   '+ 0.162*"loss" + 0.155*"performance"'),
#  (38,
#   '0.280*"using" + -0.238*"set" + 0.235*"class" + 0.189*"estimator" + '
#   '-0.185*"loss" + 0.183*"parameter" + -0.169*"domain" + 0.150*"performance" + '
#   '-0.149*"paper" + -0.147*"sample"'),
#  (39,
#   '-0.290*"parameter" + 0.285*"structure" + -0.257*"state" + '
#   '-0.206*"framework" + 0.205*"gradient" + 0.203*"result" + 0.179*"tree" + '
#   '-0.179*"optimization" + -0.167*"based" + -0.160*"domain"'),
#  (40,
#   '-0.292*"variable" + -0.243*"linear" + 0.243*"structure" + 0.199*"neural" + '
#   '0.198*"parameter" + 0.195*"tree" + -0.188*"using" + 0.174*"class" + '
#   '0.152*"show" + -0.147*"latent"'),
#  (41,
#   '0.285*"result" + 0.267*"number" + -0.259*"space" + 0.255*"using" + '
#   '-0.201*"representation" + 0.181*"variable" + -0.180*"estimator" + '
#   '-0.141*"set" + 0.140*"parameter" + 0.139*"new"'),
#  (42,
#   '-0.317*"analysis" + -0.300*"process" + 0.236*"sparse" + 0.181*"rate" + '
#   '0.180*"clustering" + 0.175*"optimal" + 0.160*"human" + 0.154*"optimization" '
#   '+ 0.143*"bayesian" + -0.134*"new"'),
#  (43,
#   '0.282*"rate" + -0.269*"information" + -0.258*"linear" + -0.225*"result" + '
#   '-0.182*"framework" + -0.171*"state" + 0.164*"word" + -0.164*"object" + '
#   '0.163*"analysis" + -0.155*"optimization"'),
#  (44,
#   '-0.371*"domain" + 0.262*"sample" + -0.185*"information" + -0.185*"time" + '
#   '0.181*"framework" + -0.174*"structure" + 0.167*"number" + -0.155*"sparse" + '
#   '0.149*"system" + -0.147*"target"'),
#  (45,
#   '-0.315*"optimization" + -0.240*"policy" + -0.237*"class" + -0.231*"using" + '
#   '0.212*"result" + -0.200*"new" + -0.170*"loss" + -0.162*"convex" + '
#   '0.158*"proposed" + 0.148*"gradient"'),
#  (46,
#   '0.286*"tree" + 0.214*"new" + 0.203*"linear" + -0.194*"policy" + '
#   '-0.179*"sample" + -0.178*"result" + -0.175*"label" + -0.174*"parameter" + '
#   '0.162*"state" + -0.159*"optimization"'),
#  (47,
#   '0.272*"class" + 0.250*"state" + -0.213*"number" + -0.193*"policy" + '
#   '-0.180*"metric" + 0.167*"representation" + -0.165*"space" + 0.165*"human" + '
#   '-0.161*"structure" + 0.153*"system"'),
#  (48,
#   '-0.460*"new" + 0.316*"optimization" + 0.244*"domain" + 0.197*"random" + '
#   '-0.154*"gradient" + -0.142*"rate" + -0.136*"error" + -0.136*"sparse" + '
#   '-0.136*"policy" + -0.131*"based"'),
#  (49,
#   '-0.295*"parameter" + -0.287*"linear" + 0.226*"estimator" + -0.194*"human" + '
#   '0.191*"performance" + 0.185*"set" + -0.169*"representation" + '
#   '-0.162*"class" + 0.143*"propose" + -0.139*"decision"'),
#  (50,
#   '0.211*"framework" + -0.193*"new" + -0.189*"metric" + 0.187*"structure" + '
#   '0.182*"system" + 0.176*"convergence" + -0.170*"based" + 0.155*"training" + '
#   '-0.155*"sparse" + -0.154*"one"'),
#  (51,
#   '-0.413*"estimator" + 0.299*"performance" + 0.235*"state" + -0.209*"policy" '
#   '+ -0.203*"based" + 0.159*"analysis" + 0.125*"sample" + 0.121*"regression" + '
#   '-0.118*"number" + 0.116*"parameter"'),
#  (52,
#   '0.322*"label" + 0.262*"new" + -0.230*"tree" + -0.217*"framework" + '
#   '0.210*"linear" + -0.207*"decision" + -0.201*"training" + '
#   '0.197*"performance" + 0.177*"structure" + 0.159*"deep"'),
#  (53,
#   '-0.238*"performance" + 0.211*"deep" + 0.197*"prediction" + 0.195*"new" + '
#   '0.195*"representation" + 0.163*"label" + 0.160*"game" + 0.151*"decision" + '
#   '-0.147*"class" + -0.142*"inference"'),
#  (54,
#   '0.274*"class" + -0.225*"bayesian" + 0.214*"propose" + -0.204*"regression" + '
#   '-0.174*"two" + -0.166*"optimization" + 0.165*"point" + -0.152*"topic" + '
#   '0.142*"parameter" + 0.141*"process"'),
#  (55,
#   '-0.268*"space" + 0.227*"linear" + -0.201*"new" + -0.186*"representation" + '
#   '-0.185*"domain" + 0.177*"training" + 0.171*"propose" + -0.166*"system" + '
#   '0.157*"two" + 0.157*"state"'),
#  (56,
#   '0.216*"training" + -0.193*"two" + 0.187*"sparse" + -0.166*"set" + '
#   '0.165*"analysis" + -0.149*"representation" + -0.148*"bayesian" + '
#   '-0.148*"regression" + 0.147*"input" + -0.145*"human"'),
#  (57,
#   '0.301*"two" + -0.274*"analysis" + 0.247*"approximation" + 0.194*"sparse" + '
#   '0.185*"regression" + -0.174*"set" + -0.172*"estimator" + 0.162*"also" + '
#   '-0.156*"performance" + -0.134*"number"'),
#  (58,
#   '0.245*"tree" + -0.213*"space" + -0.197*"training" + -0.176*"metric" + '
#   '-0.171*"framework" + 0.157*"decision" + -0.155*"approximation" + '
#   '-0.152*"human" + 0.148*"performance" + 0.147*"based"'),
#  (59,
#   '0.318*"error" + 0.265*"approximation" + 0.253*"structure" + '
#   '-0.171*"prediction" + 0.161*"based" + 0.155*"sampling" + -0.140*"space" + '
#   '-0.132*"parameter" + -0.125*"label" + 0.117*"representation"'),
#  (60,
#   '0.363*"two" + -0.346*"sampling" + -0.233*"regression" + -0.184*"propose" + '
#   '-0.169*"topic" + -0.161*"new" + 0.141*"framework" + 0.137*"game" + '
#   '0.133*"large" + -0.131*"study"'),
#  (61,
#   '-0.254*"prediction" + 0.215*"based" + 0.214*"training" + -0.213*"error" + '
#   '-0.204*"propose" + 0.180*"optimal" + -0.162*"input" + -0.157*"online" + '
#   '0.151*"random" + 0.143*"human"'),
#  (62,
#   '0.316*"sampling" + 0.226*"two" + 0.215*"space" + 0.204*"input" + '
#   '-0.168*"domain" + -0.152*"tree" + 0.144*"signal" + 0.142*"structure" + '
#   '-0.133*"approximation" + -0.132*"regression"'),
#  (63,
#   '-0.231*"random" + -0.211*"test" + 0.202*"metric" + 0.196*"bayesian" + '
#   '0.194*"game" + 0.170*"paper" + 0.163*"sampling" + 0.161*"prior" + '
#   '0.160*"also" + -0.157*"structure"'),
#  (64,
#   '0.258*"game" + -0.245*"representation" + -0.193*"estimator" + '
#   '-0.190*"based" + 0.190*"used" + -0.189*"approximation" + -0.176*"sampling" '
#   '+ -0.166*"present" + 0.163*"neural" + 0.147*"random"'),
#  (65,
#   '-0.401*"based" + -0.253*"regression" + 0.190*"new" + -0.172*"prediction" + '
#   '0.161*"optimal" + 0.154*"proposed" + -0.151*"space" + -0.138*"propose" + '
#   '-0.136*"neural" + -0.126*"game"'),
#  (66,
#   '0.283*"prediction" + -0.214*"game" + 0.202*"proposed" + 0.198*"neural" + '
#   '-0.164*"user" + 0.158*"point" + -0.156*"noise" + 0.147*"sequence" + '
#   '-0.142*"large" + 0.136*"class"'),
#  (67,
#   '-0.240*"random" + -0.237*"game" + 0.198*"deep" + -0.195*"large" + '
#   '-0.189*"local" + 0.153*"propose" + 0.153*"number" + -0.145*"vector" + '
#   '0.138*"decision" + -0.131*"present"'),
#  (68,
#   '-0.269*"test" + -0.188*"bayesian" + -0.182*"application" + -0.176*"game" + '
#   '0.170*"local" + 0.164*"metric" + 0.164*"point" + 0.159*"user" + '
#   '0.149*"query" + -0.139*"many"'),
#  (69,
#   '0.231*"also" + 0.228*"dynamic" + 0.213*"tree" + 0.211*"propose" + '
#   '-0.197*"regression" + -0.144*"proposed" + 0.138*"online" + '
#   '-0.136*"complexity" + -0.133*"paper" + -0.132*"large"'),
#  (70,
#   '0.240*"based" + 0.234*"metric" + -0.230*"space" + -0.205*"proposed" + '
#   '-0.175*"system" + -0.168*"error" + 0.166*"number" + 0.153*"sampling" + '
#   '-0.148*"class" + 0.147*"sparse"'),
#  (71,
#   '0.247*"test" + 0.222*"regression" + -0.216*"space" + 0.184*"representation" '
#   '+ -0.177*"error" + -0.169*"human" + -0.159*"latent" + 0.148*"structure" + '
#   '0.143*"point" + -0.142*"paper"'),
#  (72,
#   '-0.338*"proposed" + 0.256*"paper" + 0.234*"point" + 0.213*"optimal" + '
#   '-0.179*"memory" + -0.178*"approximation" + 0.153*"user" + 0.152*"topic" + '
#   '-0.139*"signal" + 0.139*"neuron"'),
#  (73,
#   '-0.264*"memory" + 0.203*"prior" + 0.194*"efficient" + -0.192*"one" + '
#   '-0.186*"sparse" + 0.186*"random" + 0.175*"prediction" + -0.166*"setting" + '
#   '-0.164*"experiment" + -0.150*"classification"'),
#  (74,
#   '-0.218*"present" + -0.176*"test" + 0.170*"sample" + -0.167*"complexity" + '
#   '-0.164*"noise" + 0.161*"one" + -0.161*"error" + -0.155*"latent" + '
#   '0.149*"label" + -0.143*"game"'),
#  (75,
#   '-0.216*"metric" + 0.203*"representation" + 0.175*"point" + 0.168*"also" + '
#   '-0.164*"different" + 0.162*"paper" + -0.157*"work" + -0.151*"case" + '
#   '0.139*"signal" + -0.131*"topic"'),
#  (76,
#   '-0.210*"action" + -0.185*"input" + -0.176*"neuron" + 0.168*"sparse" + '
#   '0.162*"probability" + 0.159*"dynamic" + 0.159*"stochastic" + 0.155*"neural" '
#   '+ -0.141*"norm" + 0.140*"prediction"'),
#  (77,
#   '0.234*"neural" + -0.232*"dynamic" + -0.226*"game" + 0.169*"estimation" + '
#   '-0.167*"deep" + 0.157*"analysis" + -0.156*"estimator" + -0.149*"one" + '
#   '0.136*"action" + -0.135*"layer"'),
#  (78,
#   '-0.250*"local" + -0.196*"dynamic" + 0.182*"test" + -0.179*"norm" + '
#   '0.166*"also" + -0.158*"vector" + 0.144*"linear" + 0.136*"signal" + '
#   '0.136*"user" + 0.130*"prediction"'),
#  (79,
#   '0.299*"also" + 0.182*"present" + -0.174*"tree" + -0.168*"signal" + '
#   '0.167*"class" + -0.166*"probability" + 0.163*"estimation" + 0.152*"one" + '
#   '-0.138*"case" + 0.137*"experiment"'),
#  (80,
#   '0.259*"optimal" + -0.246*"test" + -0.236*"local" + 0.192*"norm" + '
#   '0.183*"propose" + 0.162*"estimation" + 0.147*"analysis" + '
#   '-0.144*"different" + 0.141*"also" + -0.130*"prior"'),
#  (81,
#   '0.280*"norm" + -0.250*"paper" + -0.179*"noise" + 0.168*"sampling" + '
#   '-0.162*"classifier" + 0.161*"used" + -0.153*"prediction" + -0.153*"present" '
#   '+ 0.147*"measure" + -0.146*"random"'),
#  (82,
#   '0.280*"also" + 0.202*"action" + 0.159*"neuron" + 0.154*"human" + '
#   '-0.153*"point" + 0.150*"decision" + 0.142*"layer" + -0.135*"bayesian" + '
#   '0.132*"classification" + -0.122*"online"'),
#  (83,
#   '0.231*"metric" + -0.215*"online" + 0.165*"representation" + 0.162*"one" + '
#   '0.161*"error" + -0.153*"prior" + 0.151*"estimation" + -0.145*"classifier" + '
#   '0.137*"prediction" + -0.135*"based"'),
#  (84,
#   '-0.252*"online" + 0.209*"decision" + -0.205*"paper" + -0.187*"test" + '
#   '0.177*"noise" + 0.154*"work" + 0.150*"vector" + -0.148*"representation" + '
#   '0.146*"accuracy" + 0.145*"also"'),
#  (85,
#   '0.215*"probability" + -0.214*"test" + 0.207*"point" + -0.169*"case" + '
#   '-0.169*"regret" + -0.156*"variable" + 0.155*"human" + -0.152*"error" + '
#   '0.144*"setting" + 0.143*"neuron"'),
#  (86,
#   '-0.210*"sampling" + -0.185*"also" + -0.169*"tree" + -0.164*"latent" + '
#   '0.158*"novel" + 0.148*"variable" + 0.145*"prior" + -0.137*"gaussian" + '
#   '-0.133*"different" + 0.129*"first"'),
#  (87,
#   '0.257*"large" + -0.208*"number" + -0.199*"work" + -0.176*"proposed" + '
#   '-0.168*"experiment" + 0.164*"memory" + 0.163*"bayesian" + -0.160*"used" + '
#   '0.150*"propose" + 0.147*"search"'),
#  (88,
#   '0.239*"efficient" + -0.175*"deep" + -0.166*"large" + -0.158*"case" + '
#   '-0.157*"paper" + 0.156*"application" + -0.153*"space" + 0.143*"natural" + '
#   '-0.141*"work" + 0.137*"cost"'),
#  (89,
#   '-0.209*"also" + -0.198*"technique" + -0.191*"point" + 0.161*"visual" + '
#   '-0.151*"one" + 0.150*"estimate" + -0.132*"brain" + 0.132*"noise" + '
#   '-0.131*"tree" + -0.128*"complexity"'),
#  (90,
#   '-0.203*"present" + -0.203*"deep" + -0.193*"estimation" + 0.186*"noise" + '
#   '-0.178*"point" + -0.171*"estimate" + 0.160*"regularization" + '
#   '0.158*"estimator" + 0.147*"representation" + 0.144*"propose"'),
#  (91,
#   '0.248*"sampling" + 0.223*"setting" + 0.216*"signal" + -0.184*"classifier" + '
#   '-0.167*"visual" + -0.163*"random" + 0.158*"used" + 0.155*"dynamic" + '
#   '-0.148*"probability" + -0.147*"system"'),
#  (92,
#   '0.259*"noise" + 0.214*"point" + -0.173*"prior" + 0.172*"experiment" + '
#   '-0.169*"local" + 0.154*"used" + -0.137*"memory" + -0.134*"ranking" + '
#   '0.129*"human" + 0.127*"error"'),
#  (93,
#   '-0.254*"probability" + -0.201*"layer" + 0.173*"visual" + 0.167*"value" + '
#   '-0.160*"large" + 0.146*"work" + -0.123*"space" + 0.119*"similarity" + '
#   '0.116*"hashing" + -0.115*"topic"'),
#  (94,
#   '-0.224*"used" + 0.190*"online" + -0.173*"probability" + 0.166*"classifier" '
#   '+ -0.166*"complexity" + -0.164*"ranking" + -0.161*"propose" + '
#   '0.152*"vector" + -0.144*"stochastic" + 0.136*"convex"'),
#  (95,
#   '-0.226*"system" + -0.214*"provide" + 0.198*"large" + 0.178*"one" + '
#   '0.177*"action" + -0.135*"brain" + 0.135*"assumption" + 0.132*"application" '
#   '+ -0.132*"efficient" + 0.121*"dynamic"'),
#  (96,
#   '0.247*"random" + 0.206*"memory" + -0.169*"component" + 0.164*"metric" + '
#   '-0.159*"search" + -0.154*"human" + -0.151*"vector" + -0.140*"technique" + '
#   '-0.138*"example" + 0.134*"decision"'),
#  (97,
#   '0.238*"different" + -0.187*"work" + -0.179*"neuron" + 0.163*"visual" + '
#   '-0.160*"latent" + -0.152*"sequence" + -0.143*"first" + -0.138*"study" + '
#   '0.137*"one" + -0.128*"property"'),
#  (98,
#   '-0.259*"memory" + -0.164*"noise" + 0.160*"setting" + -0.154*"regret" + '
#   '0.154*"signal" + 0.150*"well" + -0.149*"action" + 0.148*"large" + '
#   '-0.147*"solution" + -0.146*"constraint"'),
#  (99,
#   '-0.225*"memory" + -0.198*"used" + 0.185*"dynamic" + 0.173*"decision" + '
#   '0.160*"input" + -0.152*"natural" + -0.147*"stimulus" + -0.134*"objective" + '
#   '-0.133*"case" + -0.128*"prediction"')]

# %% [markdown]
# # Evaluation

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.



coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)


coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='u_mass')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)
# Out:
# Coherence Score:  0.2627923251812317
#
# Coherence Score5:  0.3620284739603875
#
# Coherence Score10:  0.3526826700378628
#
# Coherence Score20:  0.3240496900367122
#
# Coherence Score50:  0.26334669917140496
#
# Coherence Score100:  0.2270120309008927
#
# Coherence Score:  -1.3206663098063114
#
# Coherence Score5:  -2.1946623320221645
#
# Coherence Score10:  -2.0607295472613947
#
# Coherence Score20:  -2.129263481369372
#
# Coherence Score50:  -2.312126370315815
#
# Coherence Score100:  -2.471284018793788
