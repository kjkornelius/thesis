# %% [markdown]
# # load packages

# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess, lemmatize
from gensim.models import CoherenceModel
from gensim.models import LdaModel, LdaMulticore
import gensim.downloader as api
from gensim.models import LsiModel

nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools 
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
#import logging
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
#logging.root.setLevel(level=logging.INFO)
#import warnings
#warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_csv('C:/Users/Kornelius/Desktop/Data 2/nips-papers/papers.csv', header = 0, sep = ';', error_bad_lines=False)
# Drop the columns not needed
df = df.drop(columns=['id', 'event_type', 'pdf_name'], axis=1)

# %%
# Drop a row by condition
df = df[df.abstract != 'Abstract Missing']

# %%
data = df.abstract.values.tolist()

# %% [markdown]
# # Pre-processing (Baseline)

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(data):
    stop_free = " ".join([i for i in data.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(data).split() for data in data]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(16129 unique tokens: ['activity', 'also', 'analysis', 'applied', 'assume']...)

# %%
# filter words that occur in more than 98% of documents
id2word.filter_extremes(no_above = 0.980)
print(id2word)
# Out:
# Dictionary(4415 unique tokens: ['activity', 'also', 'analysis', 'applied', 'assume']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# # LSI

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '0.728*"model" + -0.434*"algorithm" + -0.240*"problem" + -0.134*"function" + '
#   '-0.114*"learning" + 0.108*"network" + 0.103*"image" + -0.090*"bound" + '
#   '0.086*"neural" + -0.079*"method"'),
#  (2,
#   '-0.519*"algorithm" + -0.391*"model" + 0.334*"learning" + 0.327*"network" + '
#   '0.296*"method" + 0.165*"image" + 0.155*"task" + 0.143*"feature" + '
#   '0.125*"deep" + 0.124*"neural"'),
#  (3,
#   '0.574*"method" + -0.440*"learning" + -0.359*"network" + -0.292*"algorithm" '
#   '+ 0.254*"data" + 0.121*"matrix" + 0.104*"problem" + -0.100*"neural" + '
#   '-0.099*"deep" + -0.087*"task"'),
#  (4,
#   '-0.588*"network" + 0.579*"learning" + 0.267*"data" + -0.219*"neural" + '
#   '-0.103*"method" + -0.103*"algorithm" + 0.081*"task" + -0.079*"deep" + '
#   '0.076*"approach" + -0.075*"image"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.103*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '-0.519*"algorithm" + -0.391*"model" + 0.334*"learning" + 0.327*"network" + '
#   '0.296*"method" + 0.165*"image" + 0.155*"task" + 0.143*"feature" + '
#   '0.125*"deep" + 0.124*"neural"'),
#  (3,
#   '-0.574*"method" + 0.440*"learning" + 0.359*"network" + 0.292*"algorithm" + '
#   '-0.254*"data" + -0.121*"matrix" + -0.104*"problem" + 0.100*"neural" + '
#   '0.099*"deep" + 0.087*"task"'),
#  (4,
#   '-0.589*"network" + 0.579*"learning" + 0.267*"data" + -0.218*"neural" + '
#   '-0.104*"algorithm" + -0.104*"method" + 0.081*"task" + -0.079*"deep" + '
#   '0.075*"approach" + -0.075*"image"'),
#  (5,
#   '0.681*"data" + -0.316*"function" + 0.262*"algorithm" + -0.201*"model" + '
#   '-0.196*"problem" + -0.184*"learning" + -0.162*"method" + 0.139*"network" + '
#   '-0.114*"optimization" + 0.112*"feature"'),
#  (6,
#   '-0.523*"image" + 0.327*"data" + 0.271*"function" + 0.251*"network" + '
#   '-0.244*"algorithm" + -0.236*"feature" + -0.233*"object" + -0.219*"method" + '
#   '0.185*"distribution" + 0.120*"bound"'),
#  (7,
#   '0.483*"method" + -0.424*"problem" + 0.320*"algorithm" + -0.290*"image" + '
#   '0.225*"learning" + -0.126*"object" + 0.125*"inference" + 0.123*"gradient" + '
#   '-0.121*"matrix" + -0.113*"distribution"'),
#  (8,
#   '0.567*"problem" + -0.530*"function" + -0.212*"image" + -0.190*"feature" + '
#   '0.184*"matrix" + 0.169*"learning" + -0.168*"distribution" + 0.144*"network" '
#   '+ -0.127*"bound" + -0.095*"loss"'),
#  (9,
#   '0.500*"function" + -0.353*"distribution" + -0.272*"bound" + 0.258*"data" + '
#   '0.249*"problem" + -0.204*"matrix" + -0.195*"sample" + 0.130*"optimization" '
#   '+ -0.106*"show" + -0.103*"complexity"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '0.728*"model" + -0.434*"algorithm" + -0.240*"problem" + -0.134*"function" + '
#   '-0.114*"learning" + 0.108*"network" + 0.103*"image" + -0.090*"bound" + '
#   '0.086*"neural" + -0.079*"method"'),
#  (2,
#   '-0.519*"algorithm" + -0.391*"model" + 0.334*"learning" + 0.327*"network" + '
#   '0.296*"method" + 0.165*"image" + 0.155*"task" + 0.143*"feature" + '
#   '0.125*"deep" + 0.123*"neural"'),
#  (3,
#   '-0.574*"method" + 0.440*"learning" + 0.359*"network" + 0.292*"algorithm" + '
#   '-0.254*"data" + -0.121*"matrix" + -0.103*"problem" + 0.100*"neural" + '
#   '0.099*"deep" + 0.087*"task"'),
#  (4,
#   '-0.588*"network" + 0.579*"learning" + 0.267*"data" + -0.218*"neural" + '
#   '-0.104*"method" + -0.104*"algorithm" + 0.081*"task" + -0.079*"deep" + '
#   '0.075*"approach" + -0.075*"image"'),
#  (5,
#   '-0.681*"data" + 0.316*"function" + -0.262*"algorithm" + 0.201*"model" + '
#   '0.196*"problem" + 0.184*"learning" + 0.162*"method" + -0.139*"network" + '
#   '0.114*"optimization" + -0.112*"feature"'),
#  (6,
#   '-0.522*"image" + 0.327*"data" + 0.271*"function" + 0.251*"network" + '
#   '-0.244*"algorithm" + -0.236*"feature" + -0.233*"object" + -0.219*"method" + '
#   '0.185*"distribution" + 0.119*"bound"'),
#  (7,
#   '-0.483*"method" + 0.424*"problem" + -0.320*"algorithm" + 0.290*"image" + '
#   '-0.225*"learning" + 0.125*"object" + -0.125*"inference" + -0.124*"gradient" '
#   '+ 0.121*"matrix" + 0.114*"distribution"'),
#  (8,
#   '-0.568*"problem" + 0.529*"function" + 0.212*"image" + 0.191*"feature" + '
#   '-0.184*"matrix" + -0.170*"learning" + 0.168*"distribution" + '
#   '-0.145*"network" + 0.126*"bound" + 0.095*"loss"'),
#  (9,
#   '0.500*"function" + -0.347*"distribution" + -0.271*"bound" + 0.258*"data" + '
#   '0.250*"problem" + -0.207*"matrix" + -0.195*"sample" + 0.130*"optimization" '
#   '+ -0.107*"show" + -0.104*"complexity"'),
#  (10,
#   '-0.448*"feature" + -0.379*"matrix" + 0.370*"distribution" + '
#   '0.277*"approach" + 0.242*"inference" + 0.202*"image" + -0.186*"kernel" + '
#   '-0.131*"model" + 0.125*"problem" + -0.112*"function"'),
#  (11,
#   '-0.402*"feature" + -0.323*"kernel" + -0.299*"approach" + 0.276*"bound" + '
#   '-0.239*"inference" + 0.224*"image" + -0.198*"distribution" + 0.183*"data" + '
#   '0.161*"loss" + -0.139*"graph"'),
#  (12,
#   '0.283*"graph" + 0.274*"image" + -0.260*"task" + 0.230*"distribution" + '
#   '0.220*"matrix" + -0.211*"time" + -0.189*"policy" + -0.172*"feature" + '
#   '-0.172*"information" + 0.166*"kernel"'),
#  (13,
#   '-0.509*"matrix" + 0.386*"feature" + -0.281*"approach" + 0.237*"graph" + '
#   '0.171*"bound" + -0.158*"image" + 0.157*"problem" + 0.147*"method" + '
#   '0.143*"distribution" + -0.121*"neural"'),
#  (14,
#   '0.511*"graph" + -0.365*"distribution" + -0.308*"feature" + 0.234*"approach" '
#   '+ -0.182*"problem" + 0.164*"kernel" + 0.161*"bound" + 0.155*"clustering" + '
#   '-0.148*"gradient" + 0.141*"time"'),
#  (15,
#   '-0.405*"approach" + -0.390*"bound" + 0.280*"graph" + 0.279*"distribution" + '
#   '-0.210*"inference" + 0.160*"task" + -0.156*"feature" + 0.145*"clustering" + '
#   '0.124*"method" + 0.120*"information"'),
#  (16,
#   '0.461*"kernel" + -0.359*"task" + -0.282*"matrix" + 0.198*"image" + '
#   '-0.189*"function" + 0.188*"gradient" + 0.177*"rate" + -0.165*"approach" + '
#   '0.144*"stochastic" + 0.122*"convergence"'),
#  (17,
#   '0.352*"task" + 0.273*"gradient" + -0.240*"bound" + -0.228*"inference" + '
#   '-0.184*"image" + -0.184*"method" + 0.182*"training" + -0.149*"learning" + '
#   '0.146*"stochastic" + 0.143*"kernel"'),
#  (18,
#   '-0.505*"kernel" + 0.361*"approach" + -0.317*"task" + 0.209*"graph" + '
#   '0.189*"feature" + 0.153*"sparse" + -0.143*"inference" + '
#   '-0.138*"classification" + -0.124*"process" + 0.112*"gradient"'),
#  (19,
#   '-0.284*"gradient" + 0.253*"loss" + -0.242*"policy" + -0.231*"matrix" + '
#   '0.208*"neural" + -0.201*"stochastic" + 0.182*"classification" + '
#   '0.171*"linear" + 0.167*"approach" + -0.161*"process"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '0.728*"model" + -0.434*"algorithm" + -0.240*"problem" + -0.134*"function" + '
#   '-0.114*"learning" + 0.108*"network" + 0.103*"image" + -0.090*"bound" + '
#   '0.086*"neural" + -0.079*"method"'),
#  (2,
#   '-0.519*"algorithm" + -0.391*"model" + 0.334*"learning" + 0.327*"network" + '
#   '0.296*"method" + 0.165*"image" + 0.155*"task" + 0.143*"feature" + '
#   '0.125*"deep" + 0.124*"neural"'),
#  (3,
#   '-0.574*"method" + 0.440*"learning" + 0.359*"network" + 0.292*"algorithm" + '
#   '-0.254*"data" + -0.121*"matrix" + -0.104*"problem" + 0.100*"neural" + '
#   '0.099*"deep" + 0.087*"task"'),
#  (4,
#   '-0.588*"network" + 0.579*"learning" + 0.267*"data" + -0.218*"neural" + '
#   '-0.104*"method" + -0.104*"algorithm" + 0.081*"task" + -0.079*"deep" + '
#   '0.075*"approach" + -0.075*"image"'),
#  (5,
#   '-0.681*"data" + 0.316*"function" + -0.262*"algorithm" + 0.201*"model" + '
#   '0.196*"problem" + 0.184*"learning" + 0.162*"method" + -0.139*"network" + '
#   '0.114*"optimization" + -0.112*"feature"'),
#  (6,
#   '0.523*"image" + -0.327*"data" + -0.271*"function" + -0.251*"network" + '
#   '0.244*"algorithm" + 0.236*"feature" + 0.234*"object" + 0.219*"method" + '
#   '-0.185*"distribution" + -0.120*"bound"'),
#  (7,
#   '-0.483*"method" + 0.424*"problem" + -0.320*"algorithm" + 0.290*"image" + '
#   '-0.225*"learning" + 0.126*"object" + -0.124*"inference" + -0.123*"gradient" '
#   '+ 0.121*"matrix" + 0.114*"distribution"'),
#  (8,
#   '0.568*"problem" + -0.530*"function" + -0.211*"image" + -0.190*"feature" + '
#   '0.184*"matrix" + 0.170*"learning" + -0.168*"distribution" + 0.145*"network" '
#   '+ -0.127*"bound" + -0.095*"loss"'),
#  (9,
#   '-0.500*"function" + 0.349*"distribution" + 0.271*"bound" + -0.258*"data" + '
#   '-0.250*"problem" + 0.206*"matrix" + 0.195*"sample" + -0.130*"optimization" '
#   '+ 0.105*"show" + 0.105*"complexity"'),
#  (10,
#   '-0.447*"feature" + -0.379*"matrix" + 0.370*"distribution" + '
#   '0.277*"approach" + 0.245*"inference" + 0.202*"image" + -0.185*"kernel" + '
#   '-0.131*"model" + 0.124*"problem" + -0.111*"function"'),
#  (11,
#   '-0.403*"feature" + -0.324*"kernel" + -0.298*"approach" + 0.275*"bound" + '
#   '-0.242*"inference" + 0.222*"image" + -0.197*"distribution" + 0.182*"data" + '
#   '0.162*"loss" + -0.140*"graph"'),
#  (12,
#   '0.282*"graph" + 0.276*"image" + -0.259*"task" + 0.230*"distribution" + '
#   '0.222*"matrix" + -0.212*"time" + -0.191*"policy" + -0.174*"feature" + '
#   '-0.172*"information" + 0.165*"kernel"'),
#  (13,
#   '0.508*"matrix" + -0.388*"feature" + 0.282*"approach" + -0.236*"graph" + '
#   '-0.171*"bound" + -0.159*"problem" + 0.157*"image" + -0.146*"method" + '
#   '-0.145*"distribution" + 0.122*"neural"'),
#  (14,
#   '-0.512*"graph" + 0.367*"distribution" + 0.306*"feature" + -0.231*"approach" '
#   '+ 0.179*"problem" + -0.167*"kernel" + -0.164*"bound" + -0.155*"clustering" '
#   '+ 0.148*"gradient" + -0.143*"time"'),
#  (15,
#   '0.403*"approach" + 0.396*"bound" + -0.283*"graph" + -0.277*"distribution" + '
#   '0.216*"inference" + 0.160*"feature" + -0.159*"task" + -0.142*"clustering" + '
#   '-0.119*"method" + -0.118*"information"'),
#  (16,
#   '-0.462*"kernel" + 0.361*"task" + 0.278*"matrix" + -0.199*"image" + '
#   '-0.197*"gradient" + 0.191*"function" + -0.174*"rate" + 0.157*"approach" + '
#   '-0.148*"stochastic" + -0.124*"convergence"'),
#  (17,
#   '-0.342*"task" + -0.266*"gradient" + 0.238*"bound" + 0.227*"inference" + '
#   '-0.193*"training" + 0.188*"image" + 0.187*"method" + 0.150*"learning" + '
#   '-0.147*"stochastic" + -0.141*"convergence"'),
#  (18,
#   '-0.509*"kernel" + 0.355*"approach" + -0.315*"task" + 0.210*"graph" + '
#   '0.192*"feature" + 0.151*"sparse" + -0.144*"inference" + '
#   '-0.140*"classification" + 0.122*"gradient" + -0.119*"process"'),
#  (19,
#   '0.291*"gradient" + -0.255*"loss" + 0.232*"matrix" + 0.231*"policy" + '
#   '-0.217*"neural" + 0.203*"stochastic" + -0.177*"approach" + -0.174*"linear" '
#   '+ -0.169*"classification" + 0.164*"process"'),
#  (20,
#   '0.501*"inference" + -0.276*"approach" + -0.214*"policy" + -0.202*"kernel" + '
#   '0.179*"graph" + 0.168*"show" + -0.161*"distribution" + 0.139*"variational" '
#   '+ 0.138*"task" + 0.136*"loss"'),
#  (21,
#   '-0.401*"task" + -0.340*"bound" + 0.320*"time" + 0.232*"show" + '
#   '0.225*"label" + 0.185*"loss" + 0.184*"training" + -0.146*"structure" + '
#   '0.141*"classification" + 0.127*"class"'),
#  (22,
#   '0.346*"clustering" + -0.263*"time" + 0.230*"information" + -0.224*"sparse" '
#   '+ -0.181*"parameter" + -0.178*"task" + -0.175*"regression" + -0.169*"image" '
#   '+ 0.166*"matrix" + 0.164*"approach"'),
#  (23,
#   '0.443*"clustering" + -0.327*"graph" + 0.241*"show" + -0.182*"gradient" + '
#   '-0.178*"time" + -0.173*"information" + 0.167*"result" + 0.160*"cluster" + '
#   '-0.158*"loss" + 0.141*"set"'),
#  (24,
#   '0.360*"result" + 0.285*"policy" + -0.280*"object" + -0.224*"number" + '
#   '-0.192*"sample" + -0.188*"time" + 0.182*"show" + -0.178*"task" + '
#   '-0.175*"parameter" + 0.159*"new"'),
#  (25,
#   '-0.327*"time" + -0.257*"object" + -0.228*"loss" + 0.201*"show" + '
#   '0.195*"training" + 0.188*"neural" + 0.184*"policy" + 0.177*"using" + '
#   '0.176*"bound" + -0.170*"framework"'),
#  (26,
#   '-0.462*"object" + 0.364*"time" + -0.220*"variable" + 0.220*"clustering" + '
#   '-0.211*"show" + 0.190*"result" + -0.182*"structure" + 0.152*"image" + '
#   '-0.147*"latent" + -0.137*"space"'),
#  (27,
#   '-0.321*"latent" + -0.234*"variable" + -0.232*"show" + -0.187*"information" '
#   '+ -0.187*"clustering" + -0.186*"time" + 0.184*"graph" + -0.178*"structure" '
#   '+ -0.169*"topic" + 0.162*"inference"'),
#  (28,
#   '-0.343*"information" + 0.315*"show" + -0.305*"process" + -0.264*"label" + '
#   '0.246*"object" + -0.156*"bayesian" + 0.149*"time" + -0.148*"parameter" + '
#   '-0.145*"set" + -0.137*"gaussian"'),
#  (29,
#   '-0.450*"information" + 0.259*"loss" + 0.239*"number" + 0.233*"state" + '
#   '0.170*"clustering" + -0.165*"sample" + 0.145*"linear" + 0.143*"process" + '
#   '0.141*"task" + 0.133*"gradient"'),
#  (30,
#   '0.446*"show" + 0.302*"loss" + -0.240*"result" + -0.177*"class" + '
#   '-0.176*"latent" + 0.163*"regret" + -0.159*"analysis" + -0.158*"number" + '
#   '0.158*"parameter" + -0.147*"topic"'),
#  (31,
#   '0.346*"sample" + 0.297*"variable" + 0.281*"training" + -0.214*"label" + '
#   '0.209*"clustering" + 0.205*"latent" + -0.189*"sparse" + '
#   '-0.185*"distribution" + 0.179*"loss" + -0.171*"number"'),
#  (32,
#   '0.397*"using" + -0.354*"set" + -0.234*"label" + 0.209*"loss" + '
#   '-0.208*"class" + 0.176*"sparse" + -0.142*"rate" + 0.135*"object" + '
#   '0.134*"number" + 0.134*"representation"'),
#  (33,
#   '0.257*"set" + -0.223*"process" + 0.215*"number" + -0.205*"error" + '
#   '-0.200*"bound" + -0.197*"based" + 0.180*"kernel" + 0.173*"regret" + '
#   '-0.172*"classification" + 0.169*"information"'),
#  (34,
#   '0.274*"set" + 0.264*"training" + 0.259*"process" + -0.217*"state" + '
#   '0.212*"optimization" + -0.182*"estimator" + -0.168*"information" + '
#   '-0.160*"label" + 0.159*"performance" + 0.148*"object"'),
#  (35,
#   '-0.305*"performance" + 0.278*"using" + 0.263*"result" + -0.238*"variable" + '
#   '0.210*"rate" + -0.205*"parameter" + 0.196*"space" + -0.185*"policy" + '
#   '0.184*"set" + -0.153*"loss"'),
#  (36,
#   '0.316*"process" + -0.291*"using" + 0.247*"number" + 0.247*"rate" + '
#   '-0.227*"set" + -0.205*"structure" + -0.203*"gradient" + -0.202*"parameter" '
#   '+ 0.191*"latent" + 0.159*"variable"'),
#  (37,
#   '0.500*"framework" + -0.222*"state" + 0.202*"domain" + 0.183*"using" + '
#   '-0.183*"loss" + -0.172*"information" + 0.159*"label" + -0.157*"performance" '
#   '+ 0.153*"sample" + 0.148*"structure"'),
#  (38,
#   '0.264*"using" + -0.239*"set" + 0.230*"class" + 0.210*"parameter" + '
#   '-0.195*"domain" + 0.182*"estimator" + -0.175*"loss" + 0.174*"performance" + '
#   '-0.167*"sample" + 0.154*"result"'),
#  (39,
#   '-0.277*"structure" + 0.266*"parameter" + 0.265*"state" + 0.213*"framework" '
#   '+ -0.191*"tree" + -0.189*"gradient" + -0.189*"result" + -0.177*"process" + '
#   '0.174*"based" + 0.174*"optimization"'),
#  (40,
#   '0.271*"variable" + 0.251*"linear" + -0.233*"structure" + 0.204*"using" + '
#   '-0.196*"parameter" + -0.189*"neural" + -0.180*"tree" + 0.164*"policy" + '
#   '-0.155*"show" + 0.145*"latent"'),
#  (41,
#   '-0.279*"result" + 0.274*"space" + -0.260*"number" + -0.246*"using" + '
#   '0.213*"representation" + 0.185*"estimator" + -0.177*"new" + 0.174*"sparse" '
#   '+ -0.173*"variable" + -0.142*"based"'),
#  (42,
#   '-0.324*"analysis" + -0.285*"process" + 0.219*"sparse" + 0.179*"optimal" + '
#   '0.173*"rate" + 0.172*"clustering" + -0.154*"new" + 0.152*"kernel" + '
#   '-0.149*"set" + 0.147*"human"'),
#  (43,
#   '-0.304*"information" + 0.243*"rate" + -0.225*"linear" + -0.197*"result" + '
#   '-0.173*"optimization" + -0.167*"object" + 0.157*"analysis" + -0.154*"state" '
#   '+ -0.144*"time" + 0.138*"using"'),
#  (44,
#   '0.332*"domain" + -0.230*"sample" + -0.211*"linear" + -0.179*"framework" + '
#   '0.173*"parameter" + -0.170*"number" + -0.163*"system" + 0.152*"time" + '
#   '-0.139*"metric" + 0.139*"target"'),
#  (45,
#   '-0.319*"optimization" + -0.256*"policy" + -0.237*"class" + 0.215*"result" + '
#   '-0.202*"new" + -0.191*"using" + -0.159*"loss" + 0.155*"gradient" + '
#   '-0.154*"convex" + 0.143*"propose"'),
#  (46,
#   '0.259*"tree" + 0.238*"state" + 0.220*"class" + 0.220*"new" + '
#   '-0.201*"policy" + -0.195*"result" + -0.192*"parameter" + -0.188*"sample" + '
#   '0.181*"linear" + -0.157*"optimization"'),
#  (47,
#   '-0.245*"class" + 0.217*"number" + -0.208*"representation" + -0.205*"state" '
#   '+ -0.186*"human" + 0.178*"structure" + -0.165*"sparse" + 0.164*"linear" + '
#   '0.155*"policy" + 0.155*"space"'),
#  (48,
#   '-0.368*"new" + 0.308*"optimization" + 0.241*"domain" + -0.201*"set" + '
#   '-0.191*"sparse" + -0.190*"gradient" + 0.184*"parameter" + 0.172*"linear" + '
#   '0.127*"human" + 0.124*"decision"'),
#  (49,
#   '0.242*"parameter" + 0.231*"linear" + -0.210*"estimator" + '
#   '-0.202*"performance" + -0.186*"random" + 0.166*"new" + '
#   '-0.150*"optimization" + 0.146*"system" + 0.145*"based" + -0.145*"domain"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.103*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '0.519*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.327*"network" + '
#   '-0.296*"method" + -0.165*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.123*"neural"'),
#  (3,
#   '-0.574*"method" + 0.440*"learning" + 0.359*"network" + 0.292*"algorithm" + '
#   '-0.254*"data" + -0.121*"matrix" + -0.104*"problem" + 0.100*"neural" + '
#   '0.099*"deep" + 0.087*"task"'),
#  (4,
#   '0.588*"network" + -0.579*"learning" + -0.267*"data" + 0.218*"neural" + '
#   '0.104*"method" + 0.104*"algorithm" + -0.081*"task" + 0.079*"deep" + '
#   '-0.075*"approach" + 0.075*"image"'),
#  (5,
#   '-0.681*"data" + 0.316*"function" + -0.262*"algorithm" + 0.201*"model" + '
#   '0.196*"problem" + 0.184*"learning" + 0.162*"method" + -0.139*"network" + '
#   '0.114*"optimization" + -0.112*"feature"'),
#  (6,
#   '0.523*"image" + -0.327*"data" + -0.271*"function" + -0.251*"network" + '
#   '0.244*"algorithm" + 0.236*"feature" + 0.233*"object" + 0.219*"method" + '
#   '-0.185*"distribution" + -0.119*"bound"'),
#  (7,
#   '-0.483*"method" + 0.424*"problem" + -0.320*"algorithm" + 0.290*"image" + '
#   '-0.225*"learning" + 0.125*"object" + -0.124*"inference" + -0.123*"gradient" '
#   '+ 0.121*"matrix" + 0.113*"distribution"'),
#  (8,
#   '0.568*"problem" + -0.530*"function" + -0.212*"image" + -0.191*"feature" + '
#   '0.184*"matrix" + 0.170*"learning" + -0.167*"distribution" + 0.145*"network" '
#   '+ -0.127*"bound" + -0.095*"loss"'),
#  (9,
#   '-0.500*"function" + 0.349*"distribution" + 0.271*"bound" + -0.258*"data" + '
#   '-0.250*"problem" + 0.206*"matrix" + 0.195*"sample" + -0.130*"optimization" '
#   '+ 0.105*"show" + 0.104*"complexity"'),
#  (10,
#   '-0.448*"feature" + -0.380*"matrix" + 0.369*"distribution" + '
#   '0.276*"approach" + 0.244*"inference" + 0.202*"image" + -0.186*"kernel" + '
#   '-0.131*"model" + 0.125*"problem" + -0.111*"function"'),
#  (11,
#   '0.403*"feature" + 0.324*"kernel" + 0.299*"approach" + -0.275*"bound" + '
#   '0.241*"inference" + -0.223*"image" + 0.197*"distribution" + -0.183*"data" + '
#   '-0.162*"loss" + 0.140*"graph"'),
#  (12,
#   '-0.282*"graph" + -0.275*"image" + 0.259*"task" + -0.229*"distribution" + '
#   '-0.222*"matrix" + 0.210*"time" + 0.191*"policy" + 0.174*"feature" + '
#   '0.173*"information" + -0.166*"kernel"'),
#  (13,
#   '-0.508*"matrix" + 0.388*"feature" + -0.281*"approach" + 0.238*"graph" + '
#   '0.171*"bound" + -0.158*"image" + 0.158*"problem" + 0.147*"method" + '
#   '0.142*"distribution" + -0.122*"neural"'),
#  (14,
#   '-0.510*"graph" + 0.367*"distribution" + 0.308*"feature" + -0.232*"approach" '
#   '+ 0.180*"problem" + -0.167*"kernel" + -0.162*"bound" + -0.155*"clustering" '
#   '+ 0.148*"gradient" + -0.143*"time"'),
#  (15,
#   '-0.400*"approach" + -0.398*"bound" + 0.283*"graph" + 0.279*"distribution" + '
#   '-0.215*"inference" + 0.168*"task" + -0.159*"feature" + 0.146*"clustering" + '
#   '0.120*"method" + 0.117*"information"'),
#  (16,
#   '-0.460*"kernel" + 0.360*"task" + 0.278*"matrix" + -0.200*"image" + '
#   '-0.193*"gradient" + 0.190*"function" + -0.176*"rate" + 0.165*"approach" + '
#   '-0.145*"stochastic" + -0.122*"convergence"'),
#  (17,
#   '-0.340*"task" + -0.270*"gradient" + 0.236*"bound" + 0.229*"inference" + '
#   '-0.190*"training" + 0.188*"image" + 0.186*"method" + 0.149*"learning" + '
#   '-0.146*"stochastic" + -0.141*"approach"'),
#  (18,
#   '0.509*"kernel" + -0.354*"approach" + 0.318*"task" + -0.212*"graph" + '
#   '-0.193*"feature" + -0.153*"sparse" + 0.141*"inference" + '
#   '0.138*"classification" + 0.120*"process" + -0.118*"gradient"'),
#  (19,
#   '-0.293*"gradient" + 0.255*"loss" + -0.233*"matrix" + -0.233*"policy" + '
#   '0.211*"neural" + -0.202*"stochastic" + 0.174*"approach" + 0.172*"linear" + '
#   '0.172*"classification" + -0.165*"process"'),
#  (20,
#   '0.500*"inference" + -0.276*"approach" + -0.211*"policy" + -0.198*"kernel" + '
#   '0.181*"graph" + 0.169*"show" + -0.161*"distribution" + 0.143*"task" + '
#   '0.140*"variational" + 0.133*"loss"'),
#  (21,
#   '-0.398*"task" + -0.344*"bound" + 0.324*"time" + 0.229*"show" + '
#   '0.224*"label" + 0.189*"loss" + 0.183*"training" + -0.148*"structure" + '
#   '0.134*"classification" + 0.130*"class"'),
#  (22,
#   '-0.346*"clustering" + 0.259*"time" + -0.227*"information" + 0.226*"sparse" '
#   '+ 0.181*"parameter" + 0.179*"task" + 0.176*"regression" + 0.171*"image" + '
#   '-0.168*"matrix" + -0.164*"approach"'),
#  (23,
#   '0.449*"clustering" + -0.331*"graph" + 0.235*"show" + -0.178*"gradient" + '
#   '-0.170*"information" + -0.170*"time" + -0.164*"loss" + 0.160*"cluster" + '
#   '0.153*"result" + 0.145*"set"'),
#  (24,
#   '-0.366*"result" + -0.282*"policy" + 0.274*"object" + 0.222*"number" + '
#   '0.197*"time" + 0.197*"sample" + -0.192*"show" + 0.179*"task" + '
#   '0.172*"parameter" + -0.162*"new"'),
#  (25,
#   '0.328*"time" + 0.255*"object" + 0.231*"loss" + -0.197*"training" + '
#   '-0.197*"show" + -0.184*"neural" + -0.181*"using" + -0.180*"bound" + '
#   '-0.179*"policy" + 0.169*"framework"'),
#  (26,
#   '0.472*"object" + -0.362*"time" + -0.226*"clustering" + 0.218*"show" + '
#   '0.207*"variable" + -0.193*"result" + 0.174*"structure" + -0.152*"image" + '
#   '0.148*"latent" + 0.132*"space"'),
#  (27,
#   '0.331*"latent" + 0.310*"show" + 0.238*"variable" + 0.224*"time" + '
#   '-0.171*"loss" + 0.166*"topic" + 0.162*"clustering" + -0.154*"graph" + '
#   '0.152*"structure" + 0.152*"word"'),
#  (28,
#   '0.380*"information" + 0.290*"process" + -0.282*"object" + 0.244*"label" + '
#   '-0.226*"show" + 0.170*"set" + 0.154*"parameter" + -0.144*"task" + '
#   '-0.136*"domain" + 0.132*"bayesian"'),
#  (29,
#   '0.460*"information" + -0.311*"loss" + -0.224*"state" + -0.207*"number" + '
#   '-0.198*"clustering" + -0.156*"process" + -0.151*"task" + 0.136*"sample" + '
#   '-0.132*"gradient" + -0.128*"linear"'),
#  (30,
#   '0.466*"show" + 0.255*"loss" + -0.242*"result" + -0.199*"class" + '
#   '-0.191*"latent" + -0.187*"number" + -0.149*"analysis" + 0.145*"parameter" + '
#   '-0.142*"topic" + 0.139*"regret"'),
#  (31,
#   '-0.377*"sample" + -0.286*"variable" + -0.263*"training" + 0.227*"label" + '
#   '-0.209*"clustering" + -0.201*"loss" + -0.194*"latent" + '
#   '0.186*"distribution" + 0.182*"number" + 0.169*"sparse"'),
#  (32,
#   '0.391*"set" + -0.233*"process" + -0.200*"bound" + 0.193*"kernel" + '
#   '0.174*"parameter" + 0.171*"result" + -0.170*"error" + -0.164*"based" + '
#   '-0.160*"classification" + 0.156*"setting"'),
#  (33,
#   '-0.352*"using" + 0.270*"label" + -0.226*"number" + 0.220*"set" + '
#   '-0.210*"loss" + -0.172*"sparse" + 0.170*"rate" + 0.167*"show" + '
#   '0.167*"class" + -0.141*"object"'),
#  (34,
#   '0.290*"process" + 0.262*"training" + 0.241*"set" + -0.222*"state" + '
#   '0.203*"performance" + 0.186*"optimization" + -0.181*"information" + '
#   '-0.177*"estimator" + -0.170*"label" + 0.151*"object"'),
#  (35,
#   '0.292*"using" + -0.257*"performance" + 0.255*"set" + -0.246*"variable" + '
#   '0.245*"result" + -0.216*"policy" + -0.204*"parameter" + 0.177*"rate" + '
#   '0.171*"space" + -0.149*"analysis"'),
#  (36,
#   '-0.300*"process" + 0.273*"using" + -0.258*"number" + -0.255*"rate" + '
#   '0.240*"set" + 0.200*"parameter" + 0.196*"gradient" + -0.170*"show" + '
#   '0.170*"structure" + -0.154*"sample"'),
#  (37,
#   '-0.497*"framework" + -0.228*"domain" + 0.206*"state" + -0.187*"using" + '
#   '0.179*"performance" + 0.172*"information" + -0.169*"label" + '
#   '-0.168*"structure" + 0.159*"loss" + 0.159*"result"'),
#  (38,
#   '0.308*"using" + -0.224*"set" + 0.223*"class" + -0.195*"loss" + '
#   '0.184*"estimator" + 0.183*"parameter" + -0.160*"domain" + -0.150*"paper" + '
#   '0.148*"result" + -0.142*"sample"'),
#  (39,
#   '0.299*"structure" + -0.285*"parameter" + -0.249*"state" + '
#   '-0.204*"framework" + 0.201*"result" + 0.197*"tree" + 0.196*"gradient" + '
#   '-0.170*"based" + 0.160*"sample" + -0.160*"optimization"'),
#  (40,
#   '0.293*"variable" + 0.248*"linear" + -0.230*"structure" + -0.225*"parameter" '
#   '+ -0.200*"neural" + -0.189*"tree" + 0.181*"using" + -0.160*"class" + '
#   '0.154*"policy" + -0.149*"show"'),
#  (41,
#   '-0.290*"result" + 0.269*"space" + -0.252*"using" + -0.242*"number" + '
#   '0.217*"representation" + 0.192*"estimator" + 0.173*"sparse" + '
#   '-0.160*"parameter" + -0.159*"new" + -0.155*"variable"'),
#  (42,
#   '0.323*"analysis" + 0.303*"process" + -0.212*"sparse" + -0.170*"clustering" '
#   '+ -0.168*"rate" + -0.161*"optimization" + -0.158*"optimal" + -0.154*"human" '
#   '+ -0.152*"kernel" + 0.150*"set"'),
#  (43,
#   '0.298*"information" + -0.250*"rate" + 0.239*"linear" + 0.219*"result" + '
#   '0.174*"object" + -0.164*"analysis" + 0.164*"framework" + 0.156*"gradient" + '
#   '0.155*"state" + -0.153*"using"'),
#  (44,
#   '-0.344*"domain" + 0.241*"sample" + 0.193*"framework" + 0.188*"linear" + '
#   '0.183*"number" + -0.178*"rate" + -0.175*"time" + 0.171*"system" + '
#   '-0.151*"structure" + -0.145*"information"'),
#  (45,
#   '0.313*"optimization" + 0.274*"class" + 0.224*"new" + -0.220*"result" + '
#   '0.220*"policy" + 0.208*"using" + 0.164*"convex" + 0.155*"loss" + '
#   '-0.143*"propose" + -0.140*"proposed"'),
#  (46,
#   '-0.256*"tree" + 0.236*"policy" + -0.205*"state" + -0.202*"new" + '
#   '0.185*"optimization" + 0.181*"parameter" + 0.180*"sample" + 0.180*"result" '
#   '+ -0.179*"class" + -0.179*"linear"'),
#  (47,
#   '0.226*"state" + 0.221*"class" + -0.218*"number" + -0.191*"metric" + '
#   '-0.183*"structure" + 0.180*"representation" + 0.178*"human" + '
#   '-0.175*"policy" + -0.161*"space" + 0.143*"system"'),
#  (48,
#   '0.413*"new" + -0.288*"optimization" + -0.217*"domain" + -0.213*"random" + '
#   '0.159*"based" + -0.156*"performance" + 0.140*"policy" + 0.138*"gradient" + '
#   '-0.133*"space" + 0.128*"error"'),
#  (49,
#   '0.294*"parameter" + 0.256*"linear" + -0.201*"new" + -0.198*"estimator" + '
#   '-0.196*"set" + 0.195*"human" + 0.180*"representation" + '
#   '0.179*"optimization" + -0.170*"sparse" + 0.166*"class"'),
#  (50,
#   '-0.201*"framework" + 0.198*"metric" + -0.193*"convergence" + 0.189*"new" + '
#   '-0.177*"system" + 0.176*"based" + -0.174*"structure" + -0.166*"rate" + '
#   '0.160*"optimization" + 0.154*"one"'),
#  (51,
#   '-0.415*"estimator" + 0.291*"performance" + 0.240*"state" + -0.199*"policy" '
#   '+ -0.180*"based" + 0.154*"regression" + 0.147*"analysis" + 0.128*"setting" '
#   '+ 0.116*"error" + 0.115*"sample"'),
#  (52,
#   '-0.347*"label" + -0.318*"new" + 0.246*"training" + -0.213*"deep" + '
#   '0.211*"framework" + 0.197*"tree" + 0.172*"topic" + 0.162*"decision" + '
#   '0.154*"word" + -0.148*"linear"'),
#  (53,
#   '-0.272*"performance" + 0.202*"representation" + -0.202*"linear" + '
#   '0.196*"decision" + -0.187*"two" + 0.181*"prediction" + -0.171*"inference" + '
#   '-0.163*"structure" + -0.161*"system" + 0.151*"tree"'),
#  (54,
#   '-0.300*"class" + 0.227*"regression" + 0.218*"bayesian" + -0.190*"propose" + '
#   '0.173*"optimization" + 0.159*"estimator" + -0.158*"point" + 0.154*"two" + '
#   '0.150*"prediction" + -0.138*"proposed"'),
#  (55,
#   '-0.267*"space" + 0.242*"linear" + 0.196*"analysis" + -0.193*"new" + '
#   '-0.172*"representation" + 0.163*"propose" + 0.163*"training" + '
#   '-0.161*"domain" + 0.159*"state" + -0.157*"system"'),
#  (56,
#   '-0.209*"training" + -0.192*"sparse" + 0.184*"set" + -0.178*"prediction" + '
#   '0.173*"two" + 0.162*"bayesian" + 0.161*"representation" + -0.156*"analysis" '
#   '+ -0.148*"input" + -0.141*"clustering"'),
#  (57,
#   '-0.326*"two" + 0.264*"analysis" + -0.248*"approximation" + '
#   '-0.186*"regression" + 0.175*"set" + 0.172*"estimator" + 0.168*"performance" '
#   '+ -0.168*"sparse" + -0.141*"also" + -0.130*"label"'),
#  (58,
#   '-0.282*"tree" + 0.215*"space" + 0.209*"training" + -0.179*"based" + '
#   '0.157*"framework" + 0.152*"human" + -0.148*"random" + -0.147*"performance" '
#   '+ -0.146*"decision" + 0.142*"metric"'),
#  (59,
#   '0.319*"error" + 0.268*"structure" + 0.261*"approximation" + 0.191*"based" + '
#   '0.138*"system" + -0.138*"proposed" + 0.134*"sampling" + 0.125*"domain" + '
#   '0.125*"topic" + -0.119*"complexity"'),
#  (60,
#   '0.379*"two" + -0.302*"sampling" + -0.216*"regression" + -0.166*"propose" + '
#   '-0.161*"new" + 0.159*"large" + 0.153*"error" + -0.150*"training" + '
#   '0.144*"framework" + -0.140*"study"'),
#  (61,
#   '0.242*"prediction" + 0.198*"input" + 0.197*"sampling" + -0.172*"based" + '
#   '-0.169*"human" + 0.169*"propose" + -0.166*"training" + -0.160*"optimal" + '
#   '0.159*"regression" + 0.143*"sample"'),
#  (62,
#   '0.240*"space" + 0.221*"sampling" + 0.220*"two" + 0.177*"input" + '
#   '0.171*"based" + -0.170*"approximation" + -0.165*"online" + -0.161*"domain" '
#   '+ -0.152*"proposed" + -0.150*"metric"'),
#  (63,
#   '-0.239*"sampling" + 0.235*"random" + 0.211*"test" + -0.179*"based" + '
#   '-0.163*"bayesian" + -0.161*"metric" + 0.159*"propose" + -0.145*"present" + '
#   '-0.145*"optimal" + -0.142*"paper"'),
#  (64,
#   '0.316*"game" + -0.253*"representation" + 0.221*"neural" + 0.206*"bayesian" '
#   '+ 0.189*"used" + -0.180*"estimator" + -0.145*"two" + -0.142*"approximation" '
#   '+ 0.142*"prior" + 0.141*"also"'),
#  (65,
#   '-0.434*"based" + -0.244*"regression" + 0.211*"new" + -0.196*"prediction" + '
#   '-0.155*"domain" + 0.134*"optimal" + -0.132*"neural" + 0.130*"noise" + '
#   '0.129*"proposed" + 0.123*"constraint"'),
#  (66,
#   '-0.261*"prediction" + -0.205*"proposed" + 0.187*"user" + -0.158*"class" + '
#   '0.155*"noise" + 0.151*"game" + -0.150*"sequence" + 0.150*"system" + '
#   '-0.149*"point" + -0.148*"neural"'),
#  (67,
#   '-0.280*"game" + -0.276*"random" + -0.188*"large" + 0.181*"number" + '
#   '-0.169*"local" + 0.156*"prediction" + -0.144*"new" + 0.138*"decision" + '
#   '0.134*"propose" + 0.131*"application"'),
#  (68,
#   '-0.280*"test" + -0.189*"game" + -0.173*"application" + 0.173*"local" + '
#   '-0.169*"bayesian" + 0.158*"metric" + -0.155*"many" + 0.152*"point" + '
#   '0.132*"query" + 0.130*"policy"'),
#  (69,
#   '-0.239*"propose" + -0.213*"dynamic" + -0.212*"tree" + -0.192*"also" + '
#   '0.178*"regression" + 0.156*"probability" + 0.149*"based" + -0.145*"space" + '
#   '0.144*"complexity" + -0.143*"online"'),
#  (70,
#   '-0.228*"optimal" + 0.221*"metric" + -0.205*"regression" + 0.202*"also" + '
#   '-0.192*"space" + -0.190*"system" + 0.188*"based" + 0.163*"number" + '
#   '-0.159*"class" + 0.151*"classification"'),
#  (71,
#   '0.351*"proposed" + -0.278*"point" + 0.216*"approximation" + 0.207*"error" + '
#   '-0.196*"optimal" + -0.195*"prediction" + 0.178*"memory" + 0.163*"space" + '
#   '0.149*"signal" + -0.131*"sparse"'),
#  (72,
#   '-0.258*"test" + 0.233*"paper" + -0.213*"regression" + -0.201*"also" + '
#   '-0.181*"representation" + 0.164*"human" + 0.162*"latent" + -0.154*"input" + '
#   '0.150*"space" + 0.146*"random"'),
#  (73,
#   '0.241*"memory" + 0.222*"sparse" + -0.195*"efficient" + -0.188*"prediction" '
#   '+ -0.181*"representation" + -0.164*"proposed" + 0.163*"one" + '
#   '-0.160*"signal" + 0.156*"experiment" + -0.155*"prior"'),
#  (74,
#   '-0.231*"norm" + -0.174*"point" + -0.167*"noise" + -0.165*"complexity" + '
#   '0.151*"deep" + -0.138*"input" + -0.137*"latent" + 0.136*"variable" + '
#   '-0.136*"tensor" + -0.133*"present"'),
#  (75,
#   '-0.228*"action" + 0.212*"representation" + 0.191*"probability" + '
#   '-0.162*"topic" + -0.160*"neuron" + 0.159*"neural" + 0.150*"test" + '
#   '0.149*"study" + -0.144*"work" + -0.142*"input"'),
#  (76,
#   '-0.195*"deep" + 0.163*"decision" + -0.156*"state" + -0.155*"multiple" + '
#   '0.151*"representation" + -0.149*"metric" + -0.144*"case" + -0.141*"test" + '
#   '-0.131*"topic" + -0.126*"prediction"'),
#  (77,
#   '0.323*"test" + -0.279*"dynamic" + -0.208*"vector" + -0.189*"norm" + '
#   '-0.157*"one" + 0.151*"user" + 0.135*"neural" + -0.127*"based" + '
#   '-0.122*"local" + 0.117*"signal"'),
#  (78,
#   '-0.306*"also" + 0.210*"case" + 0.181*"neural" + -0.170*"one" + '
#   '-0.162*"user" + -0.156*"neuron" + -0.154*"item" + 0.147*"system" + '
#   '0.143*"tree" + 0.138*"dynamic"'),
#  (79,
#   '0.192*"game" + 0.182*"classifier" + 0.179*"signal" + -0.179*"different" + '
#   '0.172*"propose" + -0.165*"bayesian" + -0.158*"multiple" + -0.150*"local" + '
#   '0.150*"probability" + -0.142*"present"'),
#  (80,
#   '-0.280*"optimal" + 0.196*"local" + -0.194*"norm" + 0.174*"signal" + '
#   '0.166*"estimator" + -0.162*"datasets" + -0.161*"online" + -0.156*"large" + '
#   '-0.151*"estimation" + -0.131*"also"'),
#  (81,
#   '0.185*"norm" + -0.181*"present" + -0.172*"local" + 0.161*"metric" + '
#   '0.160*"human" + 0.153*"analysis" + -0.152*"noise" + 0.146*"representation" '
#   '+ -0.145*"prior" + -0.139*"brain"'),
#  (82,
#   '0.270*"prior" + -0.245*"paper" + -0.223*"estimation" + 0.217*"work" + '
#   '-0.155*"representation" + -0.154*"also" + -0.151*"experiment" + '
#   '0.148*"probability" + 0.133*"sampling" + 0.130*"system"'),
#  (83,
#   '-0.211*"metric" + -0.207*"one" + -0.184*"novel" + 0.171*"latent" + '
#   '0.146*"online" + -0.143*"memory" + 0.142*"different" + '
#   '0.139*"classification" + 0.136*"layer" + 0.134*"efficient"'),
#  (84,
#   '-0.293*"also" + -0.225*"decision" + 0.216*"online" + 0.180*"input" + '
#   '0.156*"representation" + 0.145*"point" + 0.143*"memory" + 0.141*"different" '
#   '+ -0.139*"accuracy" + -0.138*"vector"'),
#  (85,
#   '0.256*"sampling" + -0.188*"variable" + 0.176*"work" + 0.175*"estimate" + '
#   '0.172*"proposed" + 0.158*"latent" + -0.148*"bayesian" + -0.144*"test" + '
#   '0.143*"estimation" + -0.142*"error"'),
#  (86,
#   '-0.215*"case" + -0.194*"paper" + -0.194*"visual" + -0.145*"local" + '
#   '0.140*"first" + 0.139*"setting" + -0.136*"large" + 0.134*"random" + '
#   '0.124*"proposed" + -0.123*"regret"'),
#  (87,
#   '0.309*"used" + -0.230*"large" + -0.174*"memory" + 0.171*"number" + '
#   '0.154*"error" + -0.145*"classifier" + -0.140*"visual" + -0.136*"search" + '
#   '-0.134*"setting" + -0.132*"probability"'),
#  (88,
#   '-0.195*"work" + -0.189*"space" + 0.181*"technique" + -0.178*"paper" + '
#   '-0.155*"test" + 0.152*"application" + -0.147*"noise" + 0.145*"machine" + '
#   '-0.142*"experiment" + 0.142*"many"'),
#  (89,
#   '0.188*"convex" + 0.184*"response" + 0.166*"estimate" + 0.161*"estimation" + '
#   '0.158*"visual" + 0.149*"natural" + -0.145*"stochastic" + -0.139*"estimator" '
#   '+ -0.131*"search" + 0.129*"present"'),
#  (90,
#   '-0.231*"point" + 0.210*"noise" + 0.197*"propose" + -0.187*"estimation" + '
#   '-0.167*"tree" + 0.166*"provide" + -0.151*"deep" + -0.141*"classification" + '
#   '0.140*"decision" + 0.133*"datasets"'),
#  (91,
#   '0.260*"signal" + 0.201*"used" + -0.150*"novel" + -0.148*"query" + '
#   '-0.137*"visual" + -0.134*"classifier" + -0.125*"neuron" + -0.124*"case" + '
#   '0.123*"measurement" + 0.121*"sampling"'),
#  (92,
#   '-0.255*"probability" + -0.242*"also" + 0.219*"vector" + -0.190*"component" '
#   '+ 0.181*"point" + 0.174*"online" + -0.146*"ranking" + -0.141*"mixture" + '
#   '0.124*"sampling" + 0.119*"setting"'),
#  (93,
#   '-0.222*"constraint" + 0.198*"present" + 0.192*"experiment" + 0.160*"value" '
#   '+ 0.146*"point" + 0.139*"deep" + -0.127*"memory" + 0.126*"signal" + '
#   '-0.124*"setting" + -0.120*"cost"'),
#  (94,
#   '-0.240*"local" + -0.176*"search" + 0.175*"classifier" + 0.164*"multiple" + '
#   '-0.164*"setting" + -0.149*"dynamic" + -0.137*"propose" + -0.136*"ranking" + '
#   '-0.132*"complexity" + 0.130*"system"'),
#  (95,
#   '-0.276*"provide" + -0.172*"system" + -0.154*"use" + 0.150*"large" + '
#   '0.147*"objective" + 0.144*"error" + 0.140*"work" + -0.139*"local" + '
#   '0.137*"response" + 0.136*"natural"'),
#  (96,
#   '-0.260*"one" + -0.234*"component" + 0.173*"sequence" + -0.166*"human" + '
#   '-0.160*"signal" + -0.160*"online" + 0.148*"work" + 0.145*"latent" + '
#   '-0.139*"sampling" + 0.133*"brain"'),
#  (97,
#   '0.277*"random" + 0.192*"signal" + -0.192*"noise" + -0.172*"probability" + '
#   '-0.161*"used" + -0.161*"component" + -0.150*"constraint" + 0.140*"optimal" '
#   '+ -0.138*"layer" + -0.131*"search"'),
#  (98,
#   '0.322*"memory" + -0.283*"different" + -0.245*"stochastic" + '
#   '0.147*"gradient" + -0.129*"prior" + 0.128*"optimal" + 0.122*"regression" + '
#   '0.120*"neuron" + 0.116*"general" + 0.113*"representation"'),
#  (99,
#   '-0.232*"first" + -0.195*"paper" + -0.181*"vector" + 0.175*"use" + '
#   '0.150*"one" + 0.144*"bayesian" + -0.139*"known" + -0.138*"stimulus" + '
#   '0.138*"dynamic" + 0.134*"estimation"')]

# %% [markdown]
# # Evaluation

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.



coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)


coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='u_mass')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)
# Out:
# Coherence Score:  0.2627923251812317
#
# Coherence Score5:  0.3489944503110062
#
# Coherence Score10:  0.3969500531232323
#
# Coherence Score20:  0.3276653913061901
#
# Coherence Score50:  0.2567656138703637
#
# Coherence Score100:  0.22808982451681342
#
# Coherence Score:  -1.3206663098063114
#
# Coherence Score5:  -2.078625243547764
#
# Coherence Score10:  -2.074168979233075
#
# Coherence Score20:  -2.1635301046763895
#
# Coherence Score50:  -2.287281237543763
#
# Coherence Score100:  -2.4619836528401597
