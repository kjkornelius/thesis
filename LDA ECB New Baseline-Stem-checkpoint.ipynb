# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['Press']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
ps = PorterStemmer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(ps.stem(word) for word in punc_free.split())
    return normalized

data = [clean(df).split() for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(3061 unique tokens: ['abl', 'accept', 'accompani', 'accord', 'account']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=1, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
lda_model5 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model10 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model20 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model50 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=50, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model100 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=100, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\models\ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
# Print the Keyword in the 1 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.017*"area" + 0.017*"euro" + 0.015*"growth" + 0.015*"monetary" + '
#   '0.014*"rate" + 0.013*"economic" + 0.012*"price" + 0.012*"inflation" + '
#   '0.012*"policy" + 0.008*"annual"')]

# %%
# Print the Keyword in the 5 topics
pprint(lda_model5.print_topics())
doc_lda = lda_model5[corpus]

# Print the Keyword in the 10 topics
pprint(lda_model10.print_topics())
doc_lda = lda_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lda_model20.print_topics())
doc_lda = lda_model20[corpus]

# Print the Keyword in the 50 topics
pprint(lda_model50.print_topics())
doc_lda = lda_model50[corpus]

# Print the Keyword in the 100 topics
pprint(lda_model100.print_topics())
doc_lda = lda_model100[corpus]
# Out:
# [(0,
#   '0.018*"area" + 0.017*"euro" + 0.014*"rate" + 0.013*"inflation" + '
#   '0.012*"monetary" + 0.011*"loan" + 0.010*"annual" + 0.010*"financial" + '
#   '0.008*"governing" + 0.008*"council"'),
#  (1,
#   '0.023*"euro" + 0.014*"area" + 0.012*"growth" + 0.011*"council" + '
#   '0.011*"price" + 0.010*"governing" + 0.008*"economic" + 0.007*"stability" + '
#   '0.007*"development" + 0.007*"rate"'),
#  (2,
#   '0.018*"rate" + 0.017*"council" + 0.016*"euro" + 0.015*"governing" + '
#   '0.014*"price" + 0.013*"monetary" + 0.012*"area" + 0.011*"growth" + '
#   '0.010*"development" + 0.008*"ecb"'),
#  (3,
#   '0.023*"price" + 0.020*"growth" + 0.015*"euro" + 0.015*"economic" + '
#   '0.015*"area" + 0.013*"rate" + 0.011*"development" + 0.011*"monetary" + '
#   '0.011*"risk" + 0.011*"inflation"'),
#  (4,
#   '0.020*"monetary" + 0.019*"area" + 0.018*"policy" + 0.017*"euro" + '
#   '0.015*"inflation" + 0.015*"economic" + 0.015*"growth" + 0.014*"rate" + '
#   '0.012*"annual" + 0.010*"recovery"')]
# [(0,
#   '0.046*"fixed" + 0.034*"tender" + 0.027*"mros" + 0.021*"specialterm" + '
#   '0.018*"allotment" + 0.017*"life" + 0.013*"procedure" + 0.012*"ltro" + '
#   '0.012*"operation" + 0.011*"mro"'),
#  (1,
#   '0.000*"euro" + 0.000*"area" + 0.000*"price" + 0.000*"growth" + '
#   '0.000*"economic" + 0.000*"rate" + 0.000*"governing" + 0.000*"development" + '
#   '0.000*"monetary" + 0.000*"council"'),
#  (2,
#   '0.029*"council" + 0.027*"governing" + 0.018*"monetary" + 0.016*"ecb" + '
#   '0.013*"euro" + 0.013*"rate" + 0.011*"bank" + 0.011*"policy" + '
#   '0.011*"central" + 0.009*"today"'),
#  (3,
#   '0.016*"area" + 0.015*"euro" + 0.015*"rate" + 0.014*"inflation" + '
#   '0.010*"monetary" + 0.010*"economic" + 0.010*"growth" + 0.009*"medium" + '
#   '0.009*"term" + 0.009*"remain"'),
#  (4,
#   '0.021*"area" + 0.019*"euro" + 0.017*"risk" + 0.017*"monetary" + '
#   '0.017*"inflation" + 0.016*"growth" + 0.014*"economic" + 0.012*"financial" + '
#   '0.012*"market" + 0.011*"price"'),
#  (5,
#   '0.020*"monetary" + 0.019*"area" + 0.018*"policy" + 0.017*"euro" + '
#   '0.015*"inflation" + 0.014*"economic" + 0.014*"growth" + 0.014*"rate" + '
#   '0.012*"annual" + 0.010*"recovery"'),
#  (6,
#   '0.005*"facto" + 0.005*"broadlybased" + 0.005*"agree" + 0.004*"ulc" + '
#   '0.004*"core" + 0.004*"explicit" + 0.004*"coordinated" + 0.004*"yearonyear" '
#   '+ 0.004*"distinction" + 0.004*"never"'),
#  (7,
#   '0.002*"machine" + 0.002*"highranking" + 0.001*"entry" + 0.001*"winner" + '
#   '0.001*"debit" + 0.001*"award" + 0.001*"fraction" + 0.001*"absorbing" + '
#   '0.001*"shortrun" + 0.001*"eve"'),
#  (8,
#   '0.022*"price" + 0.020*"euro" + 0.019*"growth" + 0.016*"area" + 0.015*"rate" '
#   '+ 0.013*"economic" + 0.012*"development" + 0.010*"stability" + '
#   '0.008*"council" + 0.008*"monetary"'),
#  (9,
#   '0.028*"price" + 0.023*"growth" + 0.014*"area" + 0.014*"risk" + '
#   '0.014*"economic" + 0.013*"euro" + 0.013*"stability" + 0.012*"rate" + '
#   '0.012*"monetary" + 0.011*"development"')]
# [(0,
#   '0.000*"price" + 0.000*"area" + 0.000*"growth" + 0.000*"rate" + '
#   '0.000*"economic" + 0.000*"stability" + 0.000*"euro" + 0.000*"council" + '
#   '0.000*"monetary" + 0.000*"inflation"'),
#  (1,
#   '0.000*"euro" + 0.000*"area" + 0.000*"price" + 0.000*"growth" + '
#   '0.000*"governing" + 0.000*"economic" + 0.000*"rate" + 0.000*"development" + '
#   '0.000*"council" + 0.000*"monetary"'),
#  (2,
#   '0.000*"growth" + 0.000*"price" + 0.000*"development" + 0.000*"rate" + '
#   '0.000*"area" + 0.000*"euro" + 0.000*"monetary" + 0.000*"council" + '
#   '0.000*"governing" + 0.000*"stability"'),
#  (3,
#   '0.017*"cash" + 0.015*"treaty" + 0.014*"maastricht" + 0.009*"changeover" + '
#   '0.006*"attained" + 0.005*"erratic" + 0.005*"reimbursement" + 0.003*"city" + '
#   '0.003*"tangible" + 0.003*"attempt"'),
#  (4,
#   '0.007*"copy" + 0.006*"intensity" + 0.006*"prolong" + 0.004*"worrisome" + '
#   '0.004*"refrain" + 0.004*"transformed" + 0.004*"renew" + 0.003*"fairly" + '
#   '0.003*"interim" + 0.002*"crosschecked"'),
#  (5,
#   '0.013*"campaign" + 0.010*"antifraud" + 0.010*"fraud" + 0.008*"imf" + '
#   '0.007*"century" + 0.006*"accession" + 0.005*"coin" + 0.005*"link" + '
#   '0.005*"forum" + 0.003*"isolation"'),
#  (6,
#   '0.000*"price" + 0.000*"euro" + 0.000*"governing" + 0.000*"rate" + '
#   '0.000*"area" + 0.000*"economic" + 0.000*"growth" + 0.000*"monetary" + '
#   '0.000*"development" + 0.000*"stability"'),
#  (7,
#   '0.000*"price" + 0.000*"growth" + 0.000*"euro" + 0.000*"area" + 0.000*"rate" '
#   '+ 0.000*"governing" + 0.000*"council" + 0.000*"economic" + '
#   '0.000*"stability" + 0.000*"development"'),
#  (8,
#   '0.008*"arrangement" + 0.007*"participating" + 0.007*"cbas" + '
#   '0.006*"weekend" + 0.004*"statute" + 0.004*"approval" + 0.004*"proven" + '
#   '0.004*"migration" + 0.004*"cba" + 0.004*"strategic"'),
#  (9,
#   '0.033*"day" + 0.024*"banknote" + 0.019*"target" + 0.012*"crossborder" + '
#   '0.012*"printing" + 0.007*"frontloading" + 0.006*"operating" + '
#   '0.006*"successfully" + 0.005*"calendar" + 0.005*"disappear"'),
#  (10,
#   '0.000*"price" + 0.000*"growth" + 0.000*"euro" + 0.000*"area" + '
#   '0.000*"development" + 0.000*"economic" + 0.000*"rate" + 0.000*"stability" + '
#   '0.000*"monetary" + 0.000*"council"'),
#  (11,
#   '0.021*"price" + 0.019*"growth" + 0.018*"euro" + 0.014*"rate" + 0.014*"area" '
#   '+ 0.011*"stability" + 0.011*"development" + 0.011*"council" + '
#   '0.011*"economic" + 0.010*"monetary"'),
#  (12,
#   '0.025*"price" + 0.019*"growth" + 0.018*"euro" + 0.018*"economic" + '
#   '0.018*"area" + 0.015*"monetary" + 0.013*"rate" + 0.013*"risk" + '
#   '0.011*"development" + 0.010*"inflation"'),
#  (13,
#   '0.000*"growth" + 0.000*"euro" + 0.000*"price" + 0.000*"area" + 0.000*"rate" '
#   '+ 0.000*"economic" + 0.000*"monetary" + 0.000*"development" + '
#   '0.000*"governing" + 0.000*"council"'),
#  (14,
#   '0.017*"area" + 0.017*"inflation" + 0.014*"euro" + 0.013*"rate" + '
#   '0.013*"financial" + 0.012*"loan" + 0.012*"medium" + 0.011*"remain" + '
#   '0.011*"annual" + 0.010*"market"'),
#  (15,
#   '0.000*"price" + 0.000*"euro" + 0.000*"growth" + 0.000*"economic" + '
#   '0.000*"stability" + 0.000*"area" + 0.000*"monetary" + 0.000*"rate" + '
#   '0.000*"inflation" + 0.000*"policy"'),
#  (16,
#   '0.000*"euro" + 0.000*"economic" + 0.000*"price" + 0.000*"rate" + '
#   '0.000*"growth" + 0.000*"area" + 0.000*"council" + 0.000*"monetary" + '
#   '0.000*"market" + 0.000*"governing"'),
#  (17,
#   '0.020*"monetary" + 0.019*"area" + 0.018*"policy" + 0.017*"euro" + '
#   '0.015*"inflation" + 0.014*"economic" + 0.014*"growth" + 0.014*"rate" + '
#   '0.012*"annual" + 0.010*"recovery"'),
#  (18,
#   '0.000*"euro" + 0.000*"growth" + 0.000*"area" + 0.000*"price" + 0.000*"rate" '
#   '+ 0.000*"monetary" + 0.000*"council" + 0.000*"development" + '
#   '0.000*"economic" + 0.000*"governing"'),
#  (19,
#   '0.000*"price" + 0.000*"growth" + 0.000*"rate" + 0.000*"economic" + '
#   '0.000*"euro" + 0.000*"area" + 0.000*"monetary" + 0.000*"stability" + '
#   '0.000*"council" + 0.000*"development"')]
# [(16,
#   '0.000*"euro" + 0.000*"economic" + 0.000*"area" + 0.000*"price" + '
#   '0.000*"council" + 0.000*"rate" + 0.000*"monetary" + 0.000*"growth" + '
#   '0.000*"policy" + 0.000*"market"'),
#  (24,
#   '0.000*"price" + 0.000*"euro" + 0.000*"rate" + 0.000*"monetary" + '
#   '0.000*"governing" + 0.000*"council" + 0.000*"growth" + 0.000*"area" + '
#   '0.000*"economic" + 0.000*"ecb"'),
#  (25,
#   '0.000*"euro" + 0.000*"rate" + 0.000*"growth" + 0.000*"price" + '
#   '0.000*"governing" + 0.000*"council" + 0.000*"area" + 0.000*"monetary" + '
#   '0.000*"first" + 0.000*"policy"'),
#  (19,
#   '0.000*"growth" + 0.000*"price" + 0.000*"rate" + 0.000*"euro" + '
#   '0.000*"economic" + 0.000*"area" + 0.000*"stability" + 0.000*"monetary" + '
#   '0.000*"development" + 0.000*"council"'),
#  (18,
#   '0.000*"euro" + 0.000*"price" + 0.000*"area" + 0.000*"growth" + 0.000*"rate" '
#   '+ 0.000*"council" + 0.000*"monetary" + 0.000*"market" + 0.000*"development" '
#   '+ 0.000*"governing"'),
#  (23,
#   '0.000*"rate" + 0.000*"euro" + 0.000*"council" + 0.000*"monetary" + '
#   '0.000*"governing" + 0.000*"area" + 0.000*"price" + 0.000*"policy" + '
#   '0.000*"growth" + 0.000*"also"'),
#  (47,
#   '0.000*"growth" + 0.000*"euro" + 0.000*"price" + 0.000*"rate" + 0.000*"area" '
#   '+ 0.000*"also" + 0.000*"development" + 0.000*"risk" + 0.000*"economic" + '
#   '0.000*"stability"'),
#  (1,
#   '0.000*"euro" + 0.000*"area" + 0.000*"price" + 0.000*"governing" + '
#   '0.000*"growth" + 0.000*"rate" + 0.000*"council" + 0.000*"development" + '
#   '0.000*"economic" + 0.000*"monetary"'),
#  (7,
#   '0.000*"price" + 0.000*"euro" + 0.000*"growth" + 0.000*"area" + '
#   '0.000*"governing" + 0.000*"rate" + 0.000*"council" + 0.000*"market" + '
#   '0.000*"monetary" + 0.000*"development"'),
#  (48,
#   '0.000*"price" + 0.000*"area" + 0.000*"growth" + 0.000*"euro" + 0.000*"rate" '
#   '+ 0.000*"stability" + 0.000*"economic" + 0.000*"development" + '
#   '0.000*"monetary" + 0.000*"term"'),
#  (38,
#   '0.022*"web" + 0.022*"site" + 0.022*"standardised" + 0.017*"deduction" + '
#   '0.009*"such" + 0.005*"iv" + 0.005*"niinisto" + 0.005*"aforementioned" + '
#   '0.005*"derivative" + 0.005*"presenting"'),
#  (14,
#   '0.023*"property" + 0.018*"withdraw" + 0.013*"skilled" + 0.009*"border" + '
#   '0.009*"valuable" + 0.009*"user" + 0.009*"helpful" + 0.005*"accelerates" + '
#   '0.005*"vat" + 0.005*"nontechnical"'),
#  (27,
#   '0.018*"counterfeit" + 0.015*"clearing" + 0.015*"eba" + 0.014*"statistic" + '
#   '0.014*"definition" + 0.013*"centre" + 0.012*"regularly" + 0.012*"guide" + '
#   '0.012*"so" + 0.012*"dollar"'),
#  (34,
#   '0.025*"visible" + 0.017*"property" + 0.016*"attack" + 0.016*"terrorist" + '
#   '0.015*"judge" + 0.012*"delivering" + 0.012*"flexibly" + 0.012*"convinced" + '
#   '0.011*"excess" + 0.011*"persistently"'),
#  (49,
#   '0.038*"council" + 0.034*"governing" + 0.029*"euro" + 0.021*"monetary" + '
#   '0.020*"ecb" + 0.014*"central" + 0.013*"bank" + 0.013*"area" + '
#   '0.013*"banknote" + 0.012*"policy"'),
#  (33,
#   '0.066*"may" + 0.041*"uncertainty" + 0.034*"april" + 0.026*"loan" + '
#   '0.024*"referendum" + 0.024*"path" + 0.024*"uk" + 0.022*"prevailing" + '
#   '0.020*"growth" + 0.017*"recovery"'),
#  (12,
#   '0.026*"price" + 0.019*"growth" + 0.017*"economic" + 0.016*"area" + '
#   '0.016*"euro" + 0.016*"risk" + 0.012*"medium" + 0.012*"development" + '
#   '0.012*"monetary" + 0.011*"inflation"'),
#  (28,
#   '0.025*"price" + 0.021*"growth" + 0.019*"euro" + 0.015*"rate" + 0.015*"area" '
#   '+ 0.014*"development" + 0.013*"economic" + 0.011*"stability" + '
#   '0.008*"recent" + 0.007*"year"'),
#  (11,
#   '0.019*"rate" + 0.013*"council" + 0.013*"financial" + 0.012*"governing" + '
#   '0.012*"growth" + 0.011*"euro" + 0.011*"area" + 0.010*"inflation" + '
#   '0.008*"term" + 0.008*"pressure"'),
#  (17,
#   '0.021*"monetary" + 0.020*"area" + 0.018*"euro" + 0.018*"policy" + '
#   '0.016*"inflation" + 0.015*"economic" + 0.014*"growth" + 0.014*"rate" + '
#   '0.012*"annual" + 0.009*"loan"')]
# [(78,
#   '0.000*"price" + 0.000*"growth" + 0.000*"area" + 0.000*"euro" + '
#   '0.000*"monetary" + 0.000*"stability" + 0.000*"economic" + 0.000*"also" + '
#   '0.000*"development" + 0.000*"term"'),
#  (57,
#   '0.000*"price" + 0.000*"euro" + 0.000*"growth" + 0.000*"stability" + '
#   '0.000*"area" + 0.000*"rate" + 0.000*"governing" + 0.000*"economic" + '
#   '0.000*"monetary" + 0.000*"council"'),
#  (79,
#   '0.000*"euro" + 0.000*"rate" + 0.000*"growth" + 0.000*"monetary" + '
#   '0.000*"policy" + 0.000*"council" + 0.000*"area" + 0.000*"governing" + '
#   '0.000*"development" + 0.000*"stability"'),
#  (24,
#   '0.000*"price" + 0.000*"euro" + 0.000*"economic" + 0.000*"area" + '
#   '0.000*"rate" + 0.000*"growth" + 0.000*"stability" + 0.000*"inflation" + '
#   '0.000*"market" + 0.000*"council"'),
#  (93,
#   '0.000*"council" + 0.000*"monetary" + 0.000*"price" + 0.000*"governing" + '
#   '0.000*"euro" + 0.000*"policy" + 0.000*"growth" + 0.000*"rate" + '
#   '0.000*"area" + 0.000*"ecb"'),
#  (16,
#   '0.000*"economic" + 0.000*"euro" + 0.000*"rate" + 0.000*"growth" + '
#   '0.000*"area" + 0.000*"market" + 0.000*"council" + 0.000*"price" + '
#   '0.000*"policy" + 0.000*"uncertainty"'),
#  (90,
#   '0.000*"price" + 0.000*"euro" + 0.000*"growth" + 0.000*"economic" + '
#   '0.000*"area" + 0.000*"stability" + 0.000*"rate" + 0.000*"also" + '
#   '0.000*"development" + 0.000*"term"'),
#  (87,
#   '0.000*"rate" + 0.000*"euro" + 0.000*"stability" + 0.000*"price" + '
#   '0.000*"monetary" + 0.000*"area" + 0.000*"growth" + 0.000*"council" + '
#   '0.000*"development" + 0.000*"governing"'),
#  (82,
#   '0.000*"price" + 0.000*"growth" + 0.000*"economic" + 0.000*"euro" + '
#   '0.000*"stability" + 0.000*"analysis" + 0.000*"monetary" + 0.000*"risk" + '
#   '0.000*"area" + 0.000*"rate"'),
#  (47,
#   '0.000*"growth" + 0.000*"price" + 0.000*"euro" + 0.000*"rate" + 0.000*"area" '
#   '+ 0.000*"annual" + 0.000*"monetary" + 0.000*"economic" + '
#   '0.000*"development" + 0.000*"council"'),
#  (68,
#   '0.263*"british" + 0.019*"england" + 0.013*"miss" + 0.013*"deep" + '
#   '0.013*"true" + 0.011*"convey" + 0.006*"weighed" + 0.006*"dreadful" + '
#   '0.006*"relief" + 0.006*"rigour"'),
#  (33,
#   '0.176*"wagesetting" + 0.029*"elaborate" + 0.026*"pillar" + '
#   '0.022*"terrorist" + 0.022*"attack" + 0.021*"perceived" + '
#   '0.017*"strengthens" + 0.013*"argument" + 0.013*"prevailed" + '
#   '0.013*"counteracting"'),
#  (55,
#   '0.068*"membership" + 0.068*"facilitated" + 0.036*"facility" + '
#   '0.022*"interest" + 0.020*"forthcoming" + 0.019*"upward" + 0.016*"corridor" '
#   '+ 0.016*"central" + 0.014*"internal" + 0.014*"rate"'),
#  (49,
#   '0.039*"council" + 0.034*"governing" + 0.032*"euro" + 0.029*"ecb" + '
#   '0.020*"monetary" + 0.018*"first" + 0.018*"central" + 0.015*"banknote" + '
#   '0.015*"national" + 0.014*"value"'),
#  (12,
#   '0.021*"remain" + 0.021*"price" + 0.017*"pressure" + 0.017*"economic" + '
#   '0.016*"term" + 0.015*"area" + 0.015*"analysis" + 0.015*"euro" + '
#   '0.014*"medium" + 0.014*"inflation"'),
#  (95,
#   '0.033*"rate" + 0.026*"euro" + 0.020*"price" + 0.018*"operation" + '
#   '0.018*"area" + 0.017*"governing" + 0.017*"council" + 0.016*"development" + '
#   '0.015*"growth" + 0.013*"january"'),
#  (28,
#   '0.029*"price" + 0.022*"growth" + 0.016*"economic" + 0.016*"euro" + '
#   '0.014*"area" + 0.014*"stability" + 0.014*"development" + 0.012*"rate" + '
#   '0.011*"medium" + 0.010*"risk"'),
#  (11,
#   '0.018*"financial" + 0.016*"rate" + 0.015*"euro" + 0.014*"area" + '
#   '0.013*"council" + 0.013*"growth" + 0.011*"governing" + 0.010*"market" + '
#   '0.010*"monetary" + 0.008*"price"'),
#  (64,
#   '0.031*"projection" + 0.025*"risk" + 0.024*"growth" + 0.021*"price" + '
#   '0.019*"staff" + 0.017*"area" + 0.017*"extension" + 0.016*"inflation" + '
#   '0.016*"real" + 0.015*"euro"'),
#  (17,
#   '0.021*"monetary" + 0.020*"area" + 0.019*"policy" + 0.018*"euro" + '
#   '0.016*"inflation" + 0.015*"economic" + 0.015*"rate" + 0.014*"growth" + '
#   '0.013*"annual" + 0.011*"loan"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity5: ', lda_model5.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity10: ', lda_model10.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity20: ', lda_model20.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity50: ', lda_model50.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity100: ', lda_model100.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100: ', coherence_lda)


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence ScoreUMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100UMass: ', coherence_lda)
# Out:
# Perplexity:  -6.810429290435311
#
# Perplexity5:  -6.668818141274436
#
# Perplexity10:  -6.675104875914391
#
# Perplexity20:  -6.703291763505939
#
# Perplexity50:  -6.734850800251881
#
# Perplexity100:  -8.235186195107358
#
# Coherence Score:  0.34222072113657215
#
# Coherence Score5:  0.32759122947271646
#
# Coherence Score10:  0.4430949254944457
#
# Coherence Score20:  0.39167694994279423
#
# Coherence Score50:  0.3774032344154049
#
# Coherence Score100:  0.37003982230372523
#
# Coherence ScoreUMass:  -0.06974359114911222
#
# Coherence Score5UMass:  -0.15523415957694758
#
# Coherence Score10UMass:  -2.096190568277719
#
# Coherence Score20UMass:  -2.751158010509788
#
# Coherence Score50UMass:  -1.0770247508388353
#
# Coherence Score100UMass:  -1.0511648857473421
