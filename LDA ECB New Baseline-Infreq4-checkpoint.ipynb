# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['Press']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(4394 unique tokens: ['able', 'acceptable', 'accompanied', 'according', 'account']...)

# %%
texts = data
# less than 10 documents,
id2word = corpora.Dictionary(texts)
id2word.filter_extremes(no_below = 4)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=1, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
lda_model5 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model10 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model20 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model50 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=50, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model100 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=100, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\models\ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
# Print the Keyword in the 1 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.009*"projection" + 0.009*"staff" + 0.009*"purchase" + 0.007*"june" + '
#   '0.007*"march" + 0.006*"asset" + 0.005*"sustained" + 0.005*"accommodative" + '
#   '0.005*"contribute" + 0.005*"september"')]

# %%
# Print the Keyword in the 5 topics
pprint(lda_model5.print_topics())
doc_lda = lda_model5[corpus]

# Print the Keyword in the 10 topics
pprint(lda_model10.print_topics())
doc_lda = lda_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lda_model20.print_topics())
doc_lda = lda_model20[corpus]

# Print the Keyword in the 50 topics
pprint(lda_model50.print_topics())
doc_lda = lda_model50[corpus]

# Print the Keyword in the 100 topics
pprint(lda_model100.print_topics())
doc_lda = lda_model100[corpus]
# Out:
# [(0,
#   '0.006*"projection" + 0.005*"sound" + 0.005*"longer" + 0.005*"finance" + '
#   '0.005*"volatility" + 0.004*"fully" + 0.004*"thus" + 0.004*"background" + '
#   '0.004*"deficit" + 0.004*"accordingly"'),
#  (1,
#   '0.019*"purchase" + 0.015*"staff" + 0.014*"june" + 0.014*"projection" + '
#   '0.012*"march" + 0.011*"asset" + 0.011*"sustained" + 0.011*"path" + '
#   '0.010*"across" + 0.010*"contribute"'),
#  (2,
#   '0.012*"operation" + 0.011*"subdued" + 0.009*"aim" + 0.009*"weak" + '
#   '0.009*"to" + 0.009*"below" + 0.008*"tension" + 0.008*"projection" + '
#   '0.008*"refinancing" + 0.008*"adjusted"'),
#  (3,
#   '0.028*"october" + 0.018*"december" + 0.017*"september" + 0.017*"security" + '
#   '0.012*"maturity" + 0.012*"to" + 0.012*"below" + 0.011*"november" + '
#   '0.011*"negative" + 0.010*"extent"'),
#  (4,
#   '0.008*"exchange" + 0.008*"consumer" + 0.007*"january" + 0.007*"central" + '
#   '0.007*"pillar" + 0.006*"banknote" + 0.006*"value" + 0.005*"national" + '
#   '0.005*"member" + 0.005*"reference"')]
# [(0,
#   '0.001*"pillar" + 0.001*"treaty" + 0.001*"banknote" + 0.001*"challenge" + '
#   '0.001*"two" + 0.001*"concluded" + 0.001*"member" + 0.001*"somewhat" + '
#   '0.001*"exchange" + 0.001*"offered"'),
#  (1,
#   '0.012*"projection" + 0.010*"longer" + 0.008*"staff" + 0.007*"robust" + '
#   '0.007*"volatility" + 0.006*"ample" + 0.006*"projected" + 0.006*"thus" + '
#   '0.006*"firm" + 0.005*"productivity"'),
#  (2,
#   '0.013*"operation" + 0.012*"tension" + 0.011*"commodity" + 0.010*"aim" + '
#   '0.010*"refinancing" + 0.009*"process" + 0.009*"to" + 0.009*"deposit" + '
#   '0.008*"below" + 0.008*"range"'),
#  (3,
#   '0.019*"subdued" + 0.010*"weak" + 0.010*"projection" + 0.009*"below" + '
#   '0.009*"to" + 0.008*"gradual" + 0.008*"october" + 0.008*"securitisation" + '
#   '0.008*"negative" + 0.008*"aim"'),
#  (4,
#   '0.008*"consumer" + 0.006*"exchange" + 0.006*"pillar" + 0.006*"trend" + '
#   '0.005*"course" + 0.005*"member" + 0.005*"world" + 0.005*"average" + '
#   '0.005*"state" + 0.004*"banknote"'),
#  (5,
#   '0.016*"commodity" + 0.013*"food" + 0.012*"turmoil" + 0.010*"power" + '
#   '0.009*"stemming" + 0.009*"secondround" + 0.008*"objective" + '
#   '0.008*"significantly" + 0.008*"behaviour" + 0.008*"sound"'),
#  (6,
#   '0.032*"operation" + 0.025*"january" + 0.019*"facility" + 0.016*"reserve" + '
#   '0.016*"central" + 0.015*"refinancing" + 0.015*"escb" + 0.014*"three" + '
#   '0.013*"stage" + 0.013*"december"'),
#  (7,
#   '0.001*"consumer" + 0.001*"exchange" + 0.001*"affect" + 0.001*"erm" + '
#   '0.001*"forecast" + 0.001*"projection" + 0.001*"august" + 0.001*"help" + '
#   '0.001*"trend" + 0.001*"world"'),
#  (8,
#   '0.001*"december" + 0.001*"january" + 0.001*"apparent" + 0.001*"good" + '
#   '0.001*"range" + 0.001*"deadline" + 0.001*"situation" + 0.001*"november" + '
#   '0.001*"september" + 0.001*"projection"'),
#  (9,
#   '0.019*"purchase" + 0.014*"staff" + 0.014*"projection" + 0.013*"june" + '
#   '0.012*"march" + 0.011*"asset" + 0.011*"sustained" + 0.011*"path" + '
#   '0.010*"across" + 0.009*"contribute"')]
# [(0,
#   '0.001*"framework" + 0.001*"member" + 0.001*"projection" + 0.001*"pillar" + '
#   '0.001*"challenge" + 0.001*"exchange" + 0.001*"consumer" + 0.001*"banknote" '
#   '+ 0.001*"process" + 0.001*"two"'),
#  (1,
#   '0.001*"january" + 0.001*"firm" + 0.001*"confirmed" + 0.001*"trend" + '
#   '0.001*"across" + 0.001*"purchase" + 0.001*"longer" + 0.001*"warranted" + '
#   '0.001*"consumer" + 0.001*"gradual"'),
#  (2,
#   '0.140*"wagesetting" + 0.050*"flat" + 0.014*"materialised" + '
#   '0.014*"reflection" + 0.011*"weakness" + 0.011*"otherwise" + '
#   '0.011*"overnight" + 0.010*"deposit" + 0.010*"from" + 0.009*"consecutive"'),
#  (3,
#   '0.018*"subdued" + 0.014*"to" + 0.014*"below" + 0.014*"aim" + 0.013*"weak" + '
#   '0.013*"negative" + 0.009*"adjusted" + 0.008*"deposit" + 0.008*"december" + '
#   '0.008*"march"'),
#  (4,
#   '0.022*"positively" + 0.019*"april" + 0.016*"including" + 0.015*"across" + '
#   '0.013*"neutral" + 0.012*"prevailing" + 0.011*"framework" + 0.011*"keep" + '
#   '0.011*"robust" + 0.010*"lending"'),
#  (5,
#   '0.078*"weaker" + 0.044*"incoming" + 0.043*"improving" + 0.041*"weakness" + '
#   '0.039*"summer" + 0.036*"broadbased" + 0.035*"gradual" + 0.023*"geared" + '
#   '0.021*"negatively" + 0.021*"slow"'),
#  (6,
#   '0.041*"central" + 0.031*"national" + 0.023*"system" + 0.023*"escb" + '
#   '0.023*"january" + 0.021*"three" + 0.020*"reserve" + 0.019*"stage" + '
#   '0.018*"legal" + 0.016*"changeover"'),
#  (7,
#   '0.001*"statistic" + 0.001*"exchange" + 0.001*"consumer" + 0.001*"forecast" '
#   '+ 0.001*"industrial" + 0.001*"upswing" + 0.001*"course" + 0.001*"due" + '
#   '0.001*"value" + 0.001*"field"'),
#  (8,
#   '0.001*"january" + 0.001*"taxation" + 0.001*"december" + 0.001*"lower" + '
#   '0.001*"good" + 0.001*"consumer" + 0.001*"projection" + 0.001*"november" + '
#   '0.001*"availability" + 0.001*"situation"'),
#  (9,
#   '0.027*"march" + 0.022*"contribute" + 0.022*"staff" + 0.019*"extension" + '
#   '0.017*"projection" + 0.016*"sluggish" + 0.015*"tilted" + 0.013*"corporate" '
#   '+ 0.013*"sustained" + 0.012*"strongly"'),
#  (10,
#   '0.110*"operation" + 0.072*"refinancing" + 0.054*"fixed" + 0.038*"tender" + '
#   '0.033*"procedure" + 0.029*"maintenance" + 0.022*"mros" + 0.020*"threemonth" '
#   '+ 0.018*"end" + 0.017*"conducted"'),
#  (11,
#   '0.091*"projection" + 0.078*"july" + 0.074*"staff" + 0.066*"june" + '
#   '0.039*"steady" + 0.024*"foresee" + 0.022*"slightly" + 0.019*"revised" + '
#   '0.015*"august" + 0.013*"reflected"'),
#  (12,
#   '0.016*"consumer" + 0.011*"banknote" + 0.011*"exchange" + 0.010*"value" + '
#   '0.009*"two" + 0.009*"pillar" + 0.008*"bond" + 0.008*"give" + '
#   '0.008*"facility" + 0.008*"reference"'),
#  (13,
#   '0.008*"commodity" + 0.008*"longer" + 0.007*"range" + 0.007*"anchoring" + '
#   '0.006*"volatility" + 0.006*"policyrelevant" + 0.006*"firm" + '
#   '0.006*"projection" + 0.005*"projected" + 0.005*"deficit"'),
#  (14,
#   '0.020*"mfis" + 0.001*"successfully" + 0.001*"worth" + 0.001*"noting" + '
#   '0.001*"january" + 0.001*"news" + 0.001*"frontloading" + 0.001*"eur" + '
#   '0.001*"november" + 0.001*"so"'),
#  (15,
#   '0.001*"projection" + 0.001*"banknote" + 0.001*"staff" + 0.001*"consumer" + '
#   '0.001*"national" + 0.001*"central" + 0.001*"system" + 0.001*"forecast" + '
#   '0.001*"member" + 0.001*"average"'),
#  (16,
#   '0.008*"food" + 0.007*"course" + 0.006*"world" + 0.006*"consumer" + '
#   '0.006*"trend" + 0.006*"turmoil" + 0.005*"significantly" + '
#   '0.005*"fundamental" + 0.005*"moderation" + 0.005*"evidence"'),
#  (17,
#   '0.001*"consumer" + 0.001*"pillar" + 0.001*"moderation" + 0.001*"early" + '
#   '0.001*"position" + 0.001*"national" + 0.001*"january" + 0.001*"member" + '
#   '0.001*"service" + 0.001*"gradual"'),
#  (18,
#   '0.029*"purchase" + 0.015*"asset" + 0.013*"path" + 0.012*"sustained" + '
#   '0.010*"accommodative" + 0.010*"september" + 0.010*"full" + 0.009*"staff" + '
#   '0.009*"march" + 0.009*"below"'),
#  (19,
#   '0.001*"projection" + 0.001*"staff" + 0.001*"consumer" + 0.001*"average" + '
#   '0.001*"ample" + 0.001*"projected" + 0.001*"observed" + 0.001*"around" + '
#   '0.001*"thus" + 0.001*"background"')]
# [(17,
#   '0.001*"consumer" + 0.001*"service" + 0.001*"banknote" + 0.001*"national" + '
#   '0.001*"july" + 0.001*"lower" + 0.001*"february" + 0.001*"somewhat" + '
#   '0.001*"already" + 0.001*"january"'),
#  (15,
#   '0.001*"banknote" + 0.001*"already" + 0.001*"national" + 0.001*"escb" + '
#   '0.001*"projection" + 0.001*"staff" + 0.001*"longer" + 0.001*"service" + '
#   '0.001*"forecast" + 0.001*"confirmed"'),
#  (19,
#   '0.001*"projection" + 0.001*"staff" + 0.001*"projected" + 0.001*"side" + '
#   '0.001*"average" + 0.001*"productivity" + 0.001*"programme" + 0.001*"robust" '
#   '+ 0.001*"ample" + 0.001*"respect"'),
#  (0,
#   '0.001*"banknote" + 0.001*"pillar" + 0.001*"challenge" + 0.001*"framework" + '
#   '0.001*"two" + 0.001*"treaty" + 0.001*"member" + 0.001*"exchange" + '
#   '0.001*"somewhat" + 0.001*"national"'),
#  (22,
#   '0.001*"around" + 0.001*"position" + 0.001*"thus" + 0.001*"improve" + '
#   '0.001*"ample" + 0.001*"july" + 0.001*"consumer" + 0.001*"pillar" + '
#   '0.001*"trend" + 0.001*"average"'),
#  (28,
#   '0.001*"target" + 0.001*"state" + 0.001*"three" + 0.001*"central" + '
#   '0.001*"world" + 0.001*"member" + 0.001*"system" + 0.001*"reference" + '
#   '0.001*"position" + 0.001*"background"'),
#  (7,
#   '0.001*"banknote" + 0.001*"exchange" + 0.001*"trend" + 0.001*"national" + '
#   '0.001*"consumer" + 0.001*"pillar" + 0.001*"forecast" + 0.001*"average" + '
#   '0.001*"central" + 0.001*"issue"'),
#  (26,
#   '0.001*"january" + 0.001*"central" + 0.001*"operation" + 0.001*"facility" + '
#   '0.001*"consumer" + 0.001*"national" + 0.001*"value" + 0.001*"stage" + '
#   '0.001*"earlier" + 0.001*"banknote"'),
#  (1,
#   '0.001*"longer" + 0.001*"ample" + 0.001*"confirmed" + 0.001*"across" + '
#   '0.001*"scenario" + 0.001*"deficit" + 0.001*"side" + 0.001*"vigilance" + '
#   '0.001*"warranted" + 0.001*"trend"'),
#  (8,
#   '0.001*"january" + 0.001*"december" + 0.001*"facility" + 0.001*"situation" + '
#   '0.001*"trend" + 0.001*"consumer" + 0.001*"september" + 0.001*"average" + '
#   '0.001*"contribute" + 0.001*"good"'),
#  (31,
#   '0.036*"february" + 0.032*"made" + 0.023*"weakness" + 0.022*"bond" + '
#   '0.022*"movement" + 0.021*"picture" + 0.021*"seen" + 0.020*"sale" + '
#   '0.020*"signal" + 0.020*"percentage"'),
#  (5,
#   '0.196*"incoming" + 0.161*"subdued" + 0.090*"channel" + '
#   '0.090*"securitisation" + 0.072*"adjusted" + 0.042*"weaker" + 0.031*"said" + '
#   '0.027*"funding" + 0.021*"weighing" + 0.021*"stabilise"'),
#  (24,
#   '0.031*"projection" + 0.022*"staff" + 0.013*"range" + 0.013*"projected" + '
#   '0.011*"robust" + 0.011*"secondround" + 0.011*"ample" + 0.011*"longer" + '
#   '0.010*"trend" + 0.010*"timely"'),
#  (18,
#   '0.051*"operation" + 0.031*"refinancing" + 0.020*"fixed" + 0.020*"january" + '
#   '0.018*"facility" + 0.017*"maintenance" + 0.016*"tender" + 0.015*"december" '
#   '+ 0.014*"conducted" + 0.014*"threemonth"'),
#  (32,
#   '0.368*"mandate" + 0.344*"positively" + 0.073*"couple" + 0.073*"upcoming" + '
#   '0.002*"counteracting" + 0.000*"nonperforming" + 0.000*"contraction" + '
#   '0.000*"lagged" + 0.000*"august" + 0.000*"upturn"'),
#  (38,
#   '0.017*"owing" + 0.015*"power" + 0.013*"anchoring" + 0.012*"possibility" + '
#   '0.012*"longer" + 0.012*"purchasing" + 0.011*"protectionist" + '
#   '0.011*"volatility" + 0.011*"disorderly" + 0.011*"balanced"'),
#  (43,
#   '0.017*"commodity" + 0.013*"weak" + 0.013*"aim" + 0.011*"stepped" + '
#   '0.011*"negative" + 0.010*"to" + 0.010*"below" + 0.009*"keeping" + '
#   '0.008*"subdued" + 0.008*"contained"'),
#  (4,
#   '0.028*"infrastructure" + 0.024*"enterprise" + 0.017*"central" + '
#   '0.016*"neutral" + 0.011*"national" + 0.011*"differ" + 0.010*"system" + '
#   '0.008*"eu" + 0.008*"fund" + 0.008*"website"'),
#  (21,
#   '0.009*"steady" + 0.006*"consumer" + 0.006*"food" + 0.005*"underpins" + '
#   '0.005*"course" + 0.005*"early" + 0.005*"contribute" + 0.005*"trend" + '
#   '0.005*"evidence" + 0.004*"world"'),
#  (46,
#   '0.019*"purchase" + 0.015*"staff" + 0.015*"june" + 0.015*"projection" + '
#   '0.013*"march" + 0.012*"asset" + 0.011*"path" + 0.011*"sustained" + '
#   '0.010*"accommodative" + 0.010*"across"')]
# [(22,
#   '0.001*"framework" + 0.001*"system" + 0.001*"ncbs" + 0.001*"escb" + '
#   '0.001*"central" + 0.001*"union" + 0.001*"contained" + 0.001*"value" + '
#   '0.001*"stage" + 0.001*"reference"'),
#  (17,
#   '0.001*"banknote" + 0.001*"consumer" + 0.001*"central" + 0.001*"moderation" '
#   '+ 0.001*"pillar" + 0.001*"perspective" + 0.001*"early" + 0.001*"cash" + '
#   '0.001*"average" + 0.001*"present"'),
#  (99,
#   '0.001*"december" + 0.001*"exchange" + 0.001*"earlier" + 0.001*"gradually" + '
#   '0.001*"job" + 0.001*"world" + 0.001*"confirmed" + 0.001*"october" + '
#   '0.001*"already" + 0.001*"service"'),
#  (64,
#   '0.001*"december" + 0.001*"world" + 0.001*"production" + 0.001*"procedure" + '
#   '0.001*"trend" + 0.001*"deficit" + 0.001*"around" + 0.001*"projection" + '
#   '0.001*"january" + 0.001*"gradual"'),
#  (15,
#   '0.001*"service" + 0.001*"december" + 0.001*"already" + 0.001*"longer" + '
#   '0.001*"vigilance" + 0.001*"robust" + 0.001*"reduction" + 0.001*"even" + '
#   '0.001*"announced" + 0.001*"projection"'),
#  (44,
#   '0.001*"geopolitical" + 0.001*"december" + 0.001*"january" + '
#   '0.001*"consumer" + 0.001*"appreciation" + 0.001*"subdued" + 0.001*"weak" + '
#   '0.001*"average" + 0.001*"suggest" + 0.001*"respect"'),
#  (23,
#   '0.001*"longer" + 0.001*"plan" + 0.001*"treaty" + 0.001*"projection" + '
#   '0.001*"maastricht" + 0.001*"effort" + 0.001*"good" + 0.001*"robust" + '
#   '0.001*"programme" + 0.001*"gradual"'),
#  (97,
#   '0.001*"challenge" + 0.001*"value" + 0.001*"reference" + 0.001*"two" + '
#   '0.001*"october" + 0.001*"somewhat" + 0.001*"pillar" + 0.001*"seen" + '
#   '0.001*"general" + 0.001*"process"'),
#  (77,
#   '0.001*"central" + 0.001*"banknote" + 0.001*"target" + 0.001*"value" + '
#   '0.001*"system" + 0.001*"institution" + 0.001*"consumer" + 0.001*"national" '
#   '+ 0.001*"issue" + 0.001*"legal"'),
#  (57,
#   '0.001*"budgetary" + 0.001*"sustainability" + 0.001*"effort" + '
#   '0.001*"gradual" + 0.001*"like" + 0.001*"reduce" + 0.001*"world" + '
#   '0.001*"early" + 0.001*"half" + 0.001*"respect"'),
#  (13,
#   '0.023*"ample" + 0.018*"job" + 0.016*"momentum" + 0.015*"creation" + '
#   '0.015*"contribution" + 0.015*"anchoring" + 0.014*"elevated" + '
#   '0.012*"warranted" + 0.010*"volatility" + 0.010*"competitiveness"'),
#  (34,
#   '0.148*"projection" + 0.119*"staff" + 0.057*"july" + 0.054*"september" + '
#   '0.053*"june" + 0.043*"foresee" + 0.037*"reflected" + 0.024*"range" + '
#   '0.023*"october" + 0.022*"substantial"'),
#  (62,
#   '0.166*"extension" + 0.132*"tilted" + 0.090*"pick" + 0.083*"underpins" + '
#   '0.059*"recommendation" + 0.045*"projection" + 0.041*"staff" + '
#   '0.034*"productivity" + 0.030*"published" + 0.029*"regulatory"'),
#  (63,
#   '0.129*"steady" + 0.047*"far" + 0.036*"channel" + 0.034*"meanwhile" + '
#   '0.028*"good" + 0.027*"upcoming" + 0.027*"objective" + 0.025*"mandate" + '
#   '0.024*"already" + 0.020*"achieving"'),
#  (72,
#   '0.014*"january" + 0.012*"december" + 0.011*"exchange" + 0.010*"november" + '
#   '0.009*"lending" + 0.008*"made" + 0.008*"deposit" + 0.008*"operation" + '
#   '0.007*"facility" + 0.007*"banking"'),
#  (90,
#   '0.008*"commodity" + 0.008*"sound" + 0.007*"negative" + 0.006*"accordingly" '
#   '+ 0.006*"finance" + 0.006*"forecast" + 0.006*"commitment" + 0.006*"fall" + '
#   '0.006*"stemming" + 0.006*"policyrelevant"'),
#  (46,
#   '0.046*"march" + 0.038*"april" + 0.036*"june" + 0.022*"staff" + '
#   '0.022*"accommodative" + 0.018*"projection" + 0.018*"enhancement" + '
#   '0.017*"intended" + 0.017*"to" + 0.016*"aim"'),
#  (56,
#   '0.044*"purchase" + 0.033*"asset" + 0.023*"boost" + 0.023*"net" + '
#   '0.020*"subdued" + 0.018*"programme" + 0.018*"sustained" + 0.017*"cycle" + '
#   '0.016*"adjusted" + 0.016*"union"'),
#  (4,
#   '0.034*"aim" + 0.030*"infrastructure" + 0.029*"amount" + 0.020*"national" + '
#   '0.019*"to" + 0.018*"security" + 0.016*"october" + 0.016*"maturity" + '
#   '0.014*"provision" + 0.013*"adopted"'),
#  (21,
#   '0.018*"contribute" + 0.015*"across" + 0.013*"purchase" + 0.013*"sustained" '
#   '+ 0.012*"august" + 0.012*"accommodative" + 0.012*"full" + 0.011*"including" '
#   '+ 0.010*"billion" + 0.010*"benefiting"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity5: ', lda_model5.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity10: ', lda_model10.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity20: ', lda_model20.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity50: ', lda_model50.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity100: ', lda_model100.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100: ', coherence_lda)


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence ScoreUMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100UMass: ', coherence_lda)
# Out:
# Perplexity:  -7.261608988518162
#
# Perplexity5:  -7.017346822062788
#
# Perplexity10:  -6.998400563261789
#
# Perplexity20:  -7.098213072261679
#
# Perplexity50:  -7.158355188746964
#
# Perplexity100:  -10.010688507976342
#
# Coherence Score:  0.32373654645368644
#
# Coherence Score5:  0.32136031643201834
#
# Coherence Score10:  0.38606329400919925
#
# Coherence Score20:  0.36636863586078633
#
# Coherence Score50:  0.3206748740989115
#
# Coherence Score100:  0.31146124427344624
#
# Coherence ScoreUMass:  -0.7498682561370543
#
# Coherence Score5UMass:  -0.8135063631190249
#
# Coherence Score10UMass:  -1.0245313601546204
#
# Coherence Score20UMass:  -1.2796103810137414
#
# Coherence Score50UMass:  -1.823027647263738
#
# Coherence Score100UMass:  -1.7804100603388338
