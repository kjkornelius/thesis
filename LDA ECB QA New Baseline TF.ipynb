# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['qa']

# %%
    #Explore 

#Fetch wordcount for each abstract
#df['word_count'] = df.apply(lambda x: len(str(x).split(" ")))
#df[['QA','word_count']].head()

#df.word_count.describe()

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
# most frequent words before id2word
#result = str(data_words).strip('[]')
#result
#freq = pd.Series(''.join(result).split()).value_counts()[:-20]
#freq

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(8371 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
id2word.filter_n_most_frequent(10)
print((id2word))
# Out:
# Dictionary(8361 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=1, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
lda_model5 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model10 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model20 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model50 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=50, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model100 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=100, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\models\ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
# Print the Keyword in the 1 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.009*"policy" + 0.008*"bank" + 0.007*"monetary" + 0.007*"time" + '
#   '0.007*"inflation" + 0.007*"market" + 0.007*"price" + 0.006*"second" + '
#   '0.006*"see" + 0.006*"think"')]

# %%
# Print the Keyword in the 5 topics
pprint(lda_model5.print_topics())
doc_lda = lda_model5[corpus]

# Print the Keyword in the 10 topics
pprint(lda_model10.print_topics())
doc_lda = lda_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lda_model20.print_topics())
doc_lda = lda_model20[corpus]

# Print the Keyword in the 50 topics
pprint(lda_model50.print_topics())
doc_lda = lda_model50[corpus]

# Print the Keyword in the 100 topics
pprint(lda_model100.print_topics())
doc_lda = lda_model100[corpus]
# Out:
# [(0,
#   '0.000*"underassessment" + 0.000*"null" + 0.000*"forgetting" + '
#   '0.000*"underassessing" + 0.000*"anonymously" + 0.000*"void" + '
#   '0.000*"sangfroid" + 0.000*"composure" + 0.000*"brief" + '
#   '0.000*"normalising"'),
#  (1,
#   '0.007*"policy" + 0.007*"well" + 0.007*"time" + 0.007*"year" + '
#   '0.007*"development" + 0.006*"monetary" + 0.006*"exchange" + 0.006*"area" + '
#   '0.006*"price" + 0.006*"think"'),
#  (2,
#   '0.009*"decision" + 0.009*"bank" + 0.008*"market" + 0.008*"country" + '
#   '0.007*"area" + 0.007*"government" + 0.006*"measure" + 0.006*"time" + '
#   '0.006*"second" + 0.006*"see"'),
#  (3,
#   '0.012*"price" + 0.010*"stability" + 0.009*"regard" + 0.008*"market" + '
#   '0.008*"growth" + 0.008*"level" + 0.007*"council" + 0.007*"know" + '
#   '0.007*"important" + 0.006*"risk"'),
#  (4,
#   '0.013*"policy" + 0.010*"monetary" + 0.010*"inflation" + 0.010*"bank" + '
#   '0.008*"time" + 0.007*"second" + 0.007*"market" + 0.007*"think" + '
#   '0.006*"thats" + 0.006*"see"')]
# [(0,
#   '0.000*"stability" + 0.000*"know" + 0.000*"level" + 0.000*"price" + '
#   '0.000*"time" + 0.000*"market" + 0.000*"council" + 0.000*"year" + '
#   '0.000*"economy" + 0.000*"risk"'),
#  (1,
#   '0.008*"development" + 0.007*"mr" + 0.004*"inclined" + 0.004*"assure" + '
#   '0.003*"well" + 0.003*"couple" + 0.003*"noyer" + 0.003*"cannot" + '
#   '0.003*"realise" + 0.003*"hope"'),
#  (2,
#   '0.016*"measure" + 0.013*"bank" + 0.011*"government" + 0.009*"second" + '
#   '0.008*"programme" + 0.008*"country" + 0.008*"think" + 0.008*"policy" + '
#   '0.007*"fiscal" + 0.006*"ecb"'),
#  (3,
#   '0.012*"regard" + 0.012*"price" + 0.012*"stability" + 0.010*"market" + '
#   '0.009*"important" + 0.008*"level" + 0.008*"economy" + 0.007*"know" + '
#   '0.007*"council" + 0.007*"growth"'),
#  (4,
#   '0.015*"bank" + 0.013*"policy" + 0.010*"year" + 0.009*"time" + 0.008*"npls" '
#   '+ 0.008*"monetary" + 0.007*"inflation" + 0.007*"think" + 0.007*"important" '
#   '+ 0.007*"certainly"'),
#  (5,
#   '0.010*"time" + 0.009*"think" + 0.009*"country" + 0.008*"ecb" + 0.008*"area" '
#   '+ 0.008*"point" + 0.007*"market" + 0.007*"so" + 0.007*"policy" + '
#   '0.006*"second"'),
#  (6,
#   '0.004*"distortion" + 0.003*"usd" + 0.003*"irrespective" + 0.003*"clean" + '
#   '0.002*"undermined" + 0.002*"easter" + 0.002*"protest" + 0.002*"refinement" '
#   '+ 0.002*"resident" + 0.002*"kosovo"'),
#  (7,
#   '0.013*"policy" + 0.011*"monetary" + 0.011*"inflation" + 0.008*"second" + '
#   '0.008*"time" + 0.008*"see" + 0.007*"market" + 0.007*"bank" + 0.007*"reform" '
#   '+ 0.007*"interest"'),
#  (8,
#   '0.007*"price" + 0.007*"decision" + 0.007*"market" + 0.007*"year" + '
#   '0.006*"time" + 0.006*"growth" + 0.006*"bank" + 0.006*"area" + '
#   '0.006*"council" + 0.006*"policy"'),
#  (9,
#   '0.011*"symmetric" + 0.005*"cause" + 0.005*"rich" + 0.004*"policy" + '
#   '0.004*"expects" + 0.004*"recovery" + 0.003*"diverging" + 0.003*"change" + '
#   '0.003*"development" + 0.003*"russia"')]
# [(0,
#   '0.000*"know" + 0.000*"level" + 0.000*"stability" + 0.000*"price" + '
#   '0.000*"year" + 0.000*"economy" + 0.000*"time" + 0.000*"course" + '
#   '0.000*"council" + 0.000*"risk"'),
#  (1,
#   '0.001*"fortnightly" + 0.001*"basle" + 0.001*"augustseptember" + '
#   '0.001*"kuhbacher" + 0.001*"outbreak" + 0.001*"distinct" + 0.000*"disease" + '
#   '0.000*"dutchman" + 0.000*"heighten" + 0.000*"depreciating"'),
#  (2,
#   '0.002*"barring" + 0.002*"perceive" + 0.001*"doubtful" + 0.001*"panicky" + '
#   '0.001*"strikingly" + 0.001*"unwise" + 0.001*"concert" + 0.001*"variation" + '
#   '0.001*"hickups" + 0.001*"inexplicable"'),
#  (3,
#   '0.003*"formulating" + 0.002*"taylor" + 0.001*"turnabout" + 0.001*"wear" + '
#   '0.001*"crowd" + 0.001*"buoyantly" + 0.001*"stubborn" + 0.001*"afghanistan" '
#   '+ 0.001*"interrelated" + 0.001*"bimonthly"'),
#  (4,
#   '0.004*"departure" + 0.003*"respectable" + 0.002*"wife" + 0.002*"retire" + '
#   '0.002*"vacancy" + 0.001*"imaginable" + 0.001*"abstention" + '
#   '0.001*"midnight" + 0.001*"earlywarning" + 0.001*"collegiate"'),
#  (5,
#   '0.006*"physically" + 0.002*"rhythm" + 0.001*"ou" + 0.001*"magnificent" + '
#   '0.001*"destabilising" + 0.001*"diversities" + 0.001*"boombust" + '
#   '0.001*"que" + 0.001*"gagne" + 0.001*"overdue"'),
#  (6,
#   '0.000*"price" + 0.000*"know" + 0.000*"stability" + 0.000*"market" + '
#   '0.000*"level" + 0.000*"time" + 0.000*"course" + 0.000*"governing" + '
#   '0.000*"area" + 0.000*"growth"'),
#  (7,
#   '0.006*"maastricht" + 0.006*"undervalued" + 0.005*"legalistic" + '
#   '0.005*"holder" + 0.005*"imperfection" + 0.005*"undervaluation" + '
#   '0.004*"resort" + 0.004*"divergent" + 0.004*"nonetheless" + '
#   '0.004*"interrupt"'),
#  (8,
#   '0.012*"irish" + 0.011*"campaign" + 0.009*"supervision" + 0.008*"bid" + '
#   '0.005*"italia" + 0.005*"banca" + 0.005*"conducting" + 0.005*"denmark" + '
#   '0.005*"danish" + 0.005*"central"'),
#  (9,
#   '0.005*"velocity" + 0.004*"dependence" + 0.004*"compulsory" + '
#   '0.004*"pertain" + 0.003*"determinant" + 0.003*"expires" + 0.002*"adhering" '
#   '+ 0.002*"dmark" + 0.002*"maximised" + 0.002*"utterance"'),
#  (10,
#   '0.005*"lamfalussy" + 0.004*"changeover" + 0.002*"bath" + 0.002*"britain" + '
#   '0.002*"resentment" + 0.002*"acceptance" + 0.001*"copenhagen" + '
#   '0.001*"coffee" + 0.001*"risen" + 0.001*"transpose"'),
#  (11,
#   '0.013*"policy" + 0.011*"monetary" + 0.011*"inflation" + 0.008*"second" + '
#   '0.008*"see" + 0.008*"bank" + 0.007*"time" + 0.007*"programme" + '
#   '0.007*"reform" + 0.007*"interest"'),
#  (12,
#   '0.009*"area" + 0.008*"time" + 0.008*"think" + 0.008*"country" + '
#   '0.007*"policy" + 0.007*"well" + 0.007*"exchange" + 0.007*"so" + '
#   '0.007*"year" + 0.007*"may"'),
#  (13,
#   '0.007*"fdi" + 0.007*"registered" + 0.006*"seventeen" + 0.004*"flowing" + '
#   '0.003*"steel" + 0.003*"finalise" + 0.003*"envisaging" + 0.002*"plural" + '
#   '0.002*"condolence" + 0.002*"dutchman"'),
#  (14,
#   '0.000*"price" + 0.000*"see" + 0.000*"council" + 0.000*"market" + '
#   '0.000*"stability" + 0.000*"growth" + 0.000*"time" + 0.000*"policy" + '
#   '0.000*"know" + 0.000*"important"'),
#  (15,
#   '0.004*"recurrent" + 0.002*"passingthrough" + 0.001*"twodigit" + '
#   '0.001*"oilconsuming" + 0.001*"discovers" + 0.001*"generalisation" + '
#   '0.001*"reiteration" + 0.001*"hasard" + 0.000*"price" + 0.000*"receipt"'),
#  (16,
#   '0.000*"level" + 0.000*"price" + 0.000*"market" + 0.000*"stability" + '
#   '0.000*"well" + 0.000*"growth" + 0.000*"regard" + 0.000*"monetary" + '
#   '0.000*"year" + 0.000*"time"'),
#  (17,
#   '0.015*"bank" + 0.012*"policy" + 0.010*"time" + 0.009*"year" + '
#   '0.008*"market" + 0.007*"think" + 0.007*"certainly" + 0.007*"important" + '
#   '0.007*"monetary" + 0.006*"fiscal"'),
#  (18,
#   '0.010*"price" + 0.009*"market" + 0.009*"stability" + 0.008*"regard" + '
#   '0.007*"decision" + 0.007*"council" + 0.007*"level" + 0.006*"growth" + '
#   '0.006*"see" + 0.006*"governing"'),
#  (19,
#   '0.014*"contraction" + 0.008*"usd" + 0.005*"disaster" + 0.004*"mitigating" + '
#   '0.004*"emerged" + 0.004*"snail" + 0.004*"dispel" + 0.004*"protest" + '
#   '0.003*"convention" + 0.003*"nonresident"')]
# [(0,
#   '0.000*"know" + 0.000*"level" + 0.000*"stability" + 0.000*"price" + '
#   '0.000*"time" + 0.000*"risk" + 0.000*"council" + 0.000*"economy" + '
#   '0.000*"year" + 0.000*"course"'),
#  (34,
#   '0.000*"growth" + 0.000*"council" + 0.000*"european" + 0.000*"market" + '
#   '0.000*"price" + 0.000*"stability" + 0.000*"year" + 0.000*"time" + '
#   '0.000*"governing" + 0.000*"monetary"'),
#  (31,
#   '0.000*"time" + 0.000*"know" + 0.000*"price" + 0.000*"market" + '
#   '0.000*"governing" + 0.000*"growth" + 0.000*"council" + 0.000*"level" + '
#   '0.000*"risk" + 0.000*"regard"'),
#  (20,
#   '0.000*"price" + 0.000*"know" + 0.000*"level" + 0.000*"growth" + '
#   '0.000*"monetary" + 0.000*"council" + 0.000*"course" + 0.000*"market" + '
#   '0.000*"regard" + 0.000*"time"'),
#  (14,
#   '0.000*"price" + 0.000*"see" + 0.000*"council" + 0.000*"market" + '
#   '0.000*"growth" + 0.000*"stability" + 0.000*"time" + 0.000*"important" + '
#   '0.000*"know" + 0.000*"regard"'),
#  (16,
#   '0.000*"price" + 0.000*"level" + 0.000*"stability" + 0.000*"well" + '
#   '0.000*"market" + 0.000*"year" + 0.000*"regard" + 0.000*"growth" + '
#   '0.000*"council" + 0.000*"monetary"'),
#  (25,
#   '0.000*"market" + 0.000*"growth" + 0.000*"stability" + 0.000*"price" + '
#   '0.000*"risk" + 0.000*"monetary" + 0.000*"time" + 0.000*"council" + '
#   '0.000*"level" + 0.000*"inflation"'),
#  (26,
#   '0.000*"time" + 0.000*"price" + 0.000*"level" + 0.000*"stability" + '
#   '0.000*"council" + 0.000*"see" + 0.000*"growth" + 0.000*"year" + '
#   '0.000*"regard" + 0.000*"take"'),
#  (45,
#   '0.000*"price" + 0.000*"stability" + 0.000*"growth" + 0.000*"area" + '
#   '0.000*"know" + 0.000*"year" + 0.000*"time" + 0.000*"level" + 0.000*"see" + '
#   '0.000*"economy"'),
#  (10,
#   '0.000*"time" + 0.000*"council" + 0.000*"growth" + 0.000*"price" + '
#   '0.000*"area" + 0.000*"decision" + 0.000*"stability" + 0.000*"know" + '
#   '0.000*"course" + 0.000*"inflation"'),
#  (12,
#   '0.080*"abstain" + 0.072*"sluggish" + 0.012*"distortion" + 0.011*"tied" + '
#   '0.009*"picked" + 0.009*"undermining" + 0.009*"clean" + 0.009*"reinstate" + '
#   '0.009*"undervaluation" + 0.009*"overwhelmingly"'),
#  (46,
#   '0.173*"stabilising" + 0.078*"employer" + 0.010*"weakest" + 0.007*"unduly" + '
#   '0.007*"louvre" + 0.005*"denmark" + 0.005*"pilot" + 0.005*"accommodate" + '
#   '0.005*"futile" + 0.005*"touching"'),
#  (35,
#   '0.023*"think" + 0.022*"funding" + 0.022*"ab" + 0.019*"fragmentation" + '
#   '0.014*"ltro" + 0.012*"omt" + 0.011*"ltros" + 0.010*"ela" + 0.008*"backstop" '
#   '+ 0.008*"qe"'),
#  (33,
#   '0.013*"regard" + 0.012*"price" + 0.011*"stability" + 0.011*"market" + '
#   '0.010*"level" + 0.008*"economy" + 0.008*"decision" + 0.008*"risk" + '
#   '0.008*"see" + 0.008*"important"'),
#  (37,
#   '0.014*"development" + 0.012*"area" + 0.009*"well" + 0.009*"price" + '
#   '0.009*"monetary" + 0.009*"exchange" + 0.009*"cannot" + 0.008*"year" + '
#   '0.008*"policy" + 0.008*"growth"'),
#  (18,
#   '0.011*"council" + 0.008*"governing" + 0.008*"stability" + 0.008*"decision" '
#   '+ 0.007*"time" + 0.007*"area" + 0.007*"know" + 0.006*"situation" + '
#   '0.006*"european" + 0.006*"growth"'),
#  (44,
#   '0.051*"ive" + 0.020*"maturity" + 0.017*"vulnerability" + 0.013*"revise" + '
#   '0.013*"administration" + 0.013*"easing" + 0.011*"systemic" + 0.011*"whats" '
#   '+ 0.010*"rebalancing" + 0.010*"pm"'),
#  (32,
#   '0.015*"market" + 0.012*"reform" + 0.010*"inflation" + 0.009*"second" + '
#   '0.009*"time" + 0.009*"policy" + 0.008*"monetary" + 0.008*"programme" + '
#   '0.008*"price" + 0.007*"thats"'),
#  (11,
#   '0.018*"policy" + 0.014*"monetary" + 0.013*"inflation" + 0.012*"thats" + '
#   '0.011*"expectation" + 0.010*"think" + 0.008*"time" + 0.008*"second" + '
#   '0.008*"bank" + 0.007*"answer"'),
#  (43,
#   '0.016*"bank" + 0.009*"policy" + 0.008*"time" + 0.008*"country" + '
#   '0.008*"measure" + 0.008*"ecb" + 0.007*"year" + 0.007*"second" + '
#   '0.007*"think" + 0.007*"central"')]
# [(35,
#   '0.000*"growth" + 0.000*"monetary" + 0.000*"today" + 0.000*"policy" + '
#   '0.000*"want" + 0.000*"decision" + 0.000*"development" + 0.000*"come" + '
#   '0.000*"month" + 0.000*"interest"'),
#  (61,
#   '0.000*"today" + 0.000*"time" + 0.000*"bank" + 0.000*"see" + '
#   '0.000*"exchange" + 0.000*"decision" + 0.000*"policy" + 0.000*"interest" + '
#   '0.000*"growth" + 0.000*"market"'),
#  (77,
#   '0.000*"price" + 0.000*"time" + 0.000*"governing" + 0.000*"council" + '
#   '0.000*"risk" + 0.000*"market" + 0.000*"stability" + 0.000*"important" + '
#   '0.000*"regard" + 0.000*"clear"'),
#  (25,
#   '0.000*"growth" + 0.000*"monetary" + 0.000*"price" + 0.000*"market" + '
#   '0.000*"stability" + 0.000*"time" + 0.000*"inflation" + 0.000*"risk" + '
#   '0.000*"level" + 0.000*"know"'),
#  (34,
#   '0.000*"growth" + 0.000*"council" + 0.000*"stability" + 0.000*"european" + '
#   '0.000*"market" + 0.000*"year" + 0.000*"governing" + 0.000*"time" + '
#   '0.000*"price" + 0.000*"regard"'),
#  (0,
#   '0.000*"level" + 0.000*"know" + 0.000*"stability" + 0.000*"price" + '
#   '0.000*"year" + 0.000*"time" + 0.000*"economy" + 0.000*"course" + '
#   '0.000*"risk" + 0.000*"account"'),
#  (20,
#   '0.000*"price" + 0.000*"monetary" + 0.000*"know" + 0.000*"level" + '
#   '0.000*"growth" + 0.000*"decision" + 0.000*"council" + 0.000*"time" + '
#   '0.000*"regard" + 0.000*"course"'),
#  (97,
#   '0.000*"price" + 0.000*"stability" + 0.000*"level" + 0.000*"growth" + '
#   '0.000*"time" + 0.000*"economy" + 0.000*"important" + 0.000*"know" + '
#   '0.000*"regard" + 0.000*"course"'),
#  (78,
#   '0.000*"market" + 0.000*"price" + 0.000*"stability" + 0.000*"european" + '
#   '0.000*"growth" + 0.000*"regard" + 0.000*"decision" + 0.000*"europe" + '
#   '0.000*"council" + 0.000*"governing"'),
#  (81,
#   '0.000*"price" + 0.000*"growth" + 0.000*"time" + 0.000*"market" + '
#   '0.000*"monetary" + 0.000*"stability" + 0.000*"see" + 0.000*"area" + '
#   '0.000*"economy" + 0.000*"year"'),
#  (11,
#   '0.262*"while" + 0.015*"modified" + 0.015*"occurs" + 0.011*"suffering" + '
#   '0.009*"intensifying" + 0.009*"lame" + 0.007*"enabled" + 0.007*"urged" + '
#   '0.007*"unacceptably" + 0.007*"travel"'),
#  (12,
#   '0.068*"midst" + 0.057*"naturally" + 0.052*"protracted" + 0.043*"focused" + '
#   '0.042*"conflict" + 0.038*"forming" + 0.037*"aid" + 0.037*"recovering" + '
#   '0.035*"impetus" + 0.035*"sluggish"'),
#  (71,
#   '0.018*"decision" + 0.014*"market" + 0.011*"level" + 0.011*"money" + '
#   '0.010*"operation" + 0.009*"regard" + 0.009*"price" + 0.009*"appropriate" + '
#   '0.008*"taking" + 0.008*"confidence"'),
#  (37,
#   '0.038*"bond" + 0.024*"greece" + 0.023*"collateral" + 0.019*"whats" + '
#   '0.019*"return" + 0.017*"asset" + 0.016*"inflation" + 0.015*"apply" + '
#   '0.014*"people" + 0.014*"guidance"'),
#  (33,
#   '0.013*"regard" + 0.013*"stability" + 0.012*"price" + 0.010*"market" + '
#   '0.010*"council" + 0.009*"level" + 0.008*"important" + 0.008*"decision" + '
#   '0.008*"governing" + 0.008*"know"'),
#  (50,
#   '0.027*"market" + 0.025*"reform" + 0.016*"ive" + 0.015*"thats" + '
#   '0.014*"extent" + 0.014*"effect" + 0.014*"billion" + 0.013*"return" + '
#   '0.012*"sustained" + 0.011*"change"'),
#  (44,
#   '0.013*"year" + 0.011*"country" + 0.011*"area" + 0.010*"bank" + '
#   '0.009*"development" + 0.009*"last" + 0.009*"may" + 0.009*"european" + '
#   '0.007*"so" + 0.007*"government"'),
#  (56,
#   '0.009*"area" + 0.008*"time" + 0.008*"think" + 0.007*"country" + 0.007*"so" '
#   '+ 0.007*"way" + 0.006*"council" + 0.006*"it" + 0.006*"well" + '
#   '0.006*"policy"'),
#  (70,
#   '0.014*"bank" + 0.011*"reform" + 0.011*"central" + 0.010*"structural" + '
#   '0.010*"see" + 0.009*"inflation" + 0.009*"price" + 0.009*"policy" + '
#   '0.009*"interest" + 0.009*"effect"'),
#  (43,
#   '0.017*"policy" + 0.012*"monetary" + 0.011*"bank" + 0.010*"inflation" + '
#   '0.010*"time" + 0.010*"second" + 0.009*"think" + 0.008*"programme" + '
#   '0.007*"expectation" + 0.007*"answer"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity5: ', lda_model5.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity10: ', lda_model10.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity20: ', lda_model20.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity50: ', lda_model50.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity100: ', lda_model100.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100: ', coherence_lda)


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence ScoreUMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100UMass: ', coherence_lda)
# Out:
# Perplexity:  -7.509812041225364
#
# Perplexity5:  -7.349701362735932
#
# Perplexity10:  -7.381437512631336
#
# Perplexity20:  -7.394949957071151
#
# Perplexity50:  -7.444264520767226
#
# Perplexity100:  -10.673588240079093
#
# Coherence Score:  0.2417641768712322
#
# Coherence Score5:  0.276130081412178
#
# Coherence Score10:  0.32777832339450125
#
# Coherence Score20:  0.3664278190267954
#
# Coherence Score50:  0.326467306565349
#
# Coherence Score100:  0.32936614465810554
#
# Coherence ScoreUMass:  -0.06293912675565376
#
# Coherence Score5UMass:  -0.17940030703329551
#
# Coherence Score10UMass:  -2.3673405057267005
#
# Coherence Score20UMass:  -5.839187528228761
#
# Coherence Score50UMass:  -2.8566633664233114
#
# Coherence Score100UMass:  -2.84712236412666
