# %%
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['Press']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(4394 unique tokens: ['able', 'acceptable', 'accompanied', 'according', 'account']...)

# %%
# filter words that occur in more than 90% of documents
id2word.filter_extremes(no_above = 0.990)
print(id2word)
# Out:
# Dictionary(1972 unique tokens: ['able', 'accompanied', 'according', 'account', 'achievement']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.262*"inflation" + 0.199*"risk" + 0.186*"stability" + 0.168*"term" + '
#   '0.168*"medium" + 0.164*"annual" + 0.149*"remain" + 0.144*"analysis" + '
#   '0.136*"also" + 0.123*"financial"')]
# [(0,
#   '0.262*"inflation" + 0.199*"risk" + 0.186*"stability" + 0.168*"term" + '
#   '0.168*"medium" + 0.164*"annual" + 0.149*"remain" + 0.144*"analysis" + '
#   '0.136*"also" + 0.123*"financial"'),
#  (1,
#   '0.296*"stability" + -0.215*"loan" + -0.197*"inflation" + -0.157*"measure" + '
#   '0.140*"ecb" + 0.135*"first" + 0.134*"strong" + 0.132*"also" + '
#   '-0.130*"annual" + 0.126*"recent"'),
#  (2,
#   '-0.256*"ecb" + 0.222*"risk" + 0.172*"upside" + -0.169*"bank" + '
#   '0.168*"medium" + 0.158*"stability" + -0.153*"central" + 0.151*"strong" + '
#   '-0.134*"national" + -0.133*"operation"'),
#  (3,
#   '0.190*"oil" + 0.182*"projection" + -0.180*"pressure" + -0.170*"financial" + '
#   '-0.152*"medium" + -0.150*"remain" + 0.146*"quarter" + 0.145*"reform" + '
#   '-0.136*"term" + -0.132*"bank"'),
#  (4,
#   '0.282*"risk" + 0.267*"financial" + -0.209*"recovery" + -0.192*"term" + '
#   '-0.169*"remain" + 0.157*"underlying" + -0.157*"oil" + 0.120*"tension" + '
#   '0.120*"bank" + 0.119*"upside"')]
# [(0,
#   '0.262*"inflation" + 0.199*"risk" + 0.186*"stability" + 0.168*"term" + '
#   '0.168*"medium" + 0.164*"annual" + 0.149*"remain" + 0.144*"analysis" + '
#   '0.136*"also" + 0.123*"financial"'),
#  (1,
#   '0.296*"stability" + -0.215*"loan" + -0.197*"inflation" + -0.157*"measure" + '
#   '0.140*"ecb" + 0.135*"first" + 0.134*"strong" + 0.132*"also" + '
#   '-0.130*"annual" + 0.126*"recent"'),
#  (2,
#   '0.256*"ecb" + -0.222*"risk" + -0.172*"upside" + 0.169*"bank" + '
#   '-0.168*"medium" + -0.158*"stability" + 0.153*"central" + -0.151*"strong" + '
#   '0.134*"national" + 0.133*"operation"'),
#  (3,
#   '0.190*"oil" + 0.182*"projection" + -0.180*"pressure" + -0.170*"financial" + '
#   '-0.152*"medium" + -0.150*"remain" + 0.146*"quarter" + 0.145*"reform" + '
#   '-0.136*"term" + -0.132*"bank"'),
#  (4,
#   '0.282*"risk" + 0.267*"financial" + -0.209*"recovery" + -0.192*"term" + '
#   '-0.169*"remain" + 0.157*"underlying" + -0.157*"oil" + 0.120*"tension" + '
#   '0.120*"bank" + 0.119*"upside"'),
#  (5,
#   '-0.197*"increase" + 0.194*"financial" + -0.165*"remains" + '
#   '0.161*"inflation" + 0.154*"effect" + -0.131*"liquidity" + 0.117*"stability" '
#   '+ 0.116*"turmoil" + -0.110*"ample" + -0.108*"pressure"'),
#  (6,
#   '0.331*"projection" + 0.231*"staff" + 0.187*"measure" + -0.176*"subdued" + '
#   '-0.161*"credit" + 0.158*"pressure" + -0.152*"loan" + 0.152*"inflation" + '
#   '-0.139*"country" + -0.139*"condition"'),
#  (7,
#   '0.219*"projection" + 0.194*"medium" + -0.182*"recent" + 0.159*"staff" + '
#   '-0.151*"inflation" + -0.147*"financial" + -0.146*"pressure" + 0.144*"ecb" + '
#   '-0.137*"reform" + -0.134*"fiscal"'),
#  (8,
#   '0.267*"measure" + -0.177*"projection" + -0.173*"may" + 0.166*"environment" '
#   '+ 0.145*"financial" + -0.139*"recent" + 0.135*"stability" + -0.115*"upward" '
#   '+ 0.111*"purchase" + 0.110*"fiscal"'),
#  (9,
#   '0.208*"projection" + 0.166*"financial" + -0.152*"purchase" + '
#   '-0.142*"measure" + 0.128*"staff" + 0.127*"subdued" + -0.125*"increase" + '
#   '-0.122*"contribute" + -0.121*"may" + 0.114*"confidence"')]
# [(0,
#   '0.262*"inflation" + 0.199*"risk" + 0.186*"stability" + 0.168*"term" + '
#   '0.168*"medium" + 0.164*"annual" + 0.149*"remain" + 0.144*"analysis" + '
#   '0.136*"also" + 0.123*"financial"'),
#  (1,
#   '-0.296*"stability" + 0.215*"loan" + 0.197*"inflation" + 0.157*"measure" + '
#   '-0.140*"ecb" + -0.135*"first" + -0.134*"strong" + -0.132*"also" + '
#   '0.130*"annual" + -0.126*"recent"'),
#  (2,
#   '-0.256*"ecb" + 0.222*"risk" + 0.172*"upside" + -0.169*"bank" + '
#   '0.168*"medium" + 0.158*"stability" + -0.153*"central" + 0.151*"strong" + '
#   '-0.134*"national" + -0.133*"operation"'),
#  (3,
#   '0.190*"oil" + 0.182*"projection" + -0.180*"pressure" + -0.170*"financial" + '
#   '-0.152*"medium" + -0.150*"remain" + 0.146*"quarter" + 0.145*"reform" + '
#   '-0.136*"term" + -0.132*"bank"'),
#  (4,
#   '-0.282*"risk" + -0.267*"financial" + 0.209*"recovery" + 0.192*"term" + '
#   '0.169*"remain" + -0.157*"underlying" + 0.157*"oil" + -0.120*"tension" + '
#   '-0.120*"bank" + -0.119*"upside"'),
#  (5,
#   '-0.197*"increase" + 0.194*"financial" + -0.165*"remains" + '
#   '0.161*"inflation" + 0.154*"effect" + -0.131*"liquidity" + 0.117*"stability" '
#   '+ 0.116*"turmoil" + -0.110*"ample" + -0.108*"pressure"'),
#  (6,
#   '-0.331*"projection" + -0.231*"staff" + -0.187*"measure" + 0.176*"subdued" + '
#   '0.161*"credit" + -0.159*"pressure" + 0.152*"loan" + -0.152*"inflation" + '
#   '0.139*"country" + 0.139*"condition"'),
#  (7,
#   '-0.219*"projection" + -0.194*"medium" + 0.182*"recent" + -0.159*"staff" + '
#   '0.151*"inflation" + 0.147*"financial" + 0.146*"pressure" + -0.144*"ecb" + '
#   '0.137*"reform" + 0.134*"fiscal"'),
#  (8,
#   '-0.267*"measure" + 0.177*"projection" + 0.173*"may" + -0.166*"environment" '
#   '+ -0.145*"financial" + 0.139*"recent" + -0.135*"stability" + 0.115*"upward" '
#   '+ -0.111*"purchase" + -0.110*"fiscal"'),
#  (9,
#   '0.208*"projection" + 0.166*"financial" + -0.152*"purchase" + '
#   '-0.142*"measure" + 0.127*"staff" + 0.127*"subdued" + -0.125*"increase" + '
#   '-0.122*"contribute" + -0.122*"may" + 0.115*"confidence"'),
#  (10,
#   '0.216*"operation" + -0.180*"ecb" + 0.152*"refinancing" + 0.144*"period" + '
#   '-0.140*"bank" + 0.137*"economy" + 0.137*"month" + -0.133*"escb" + '
#   '0.128*"outlook" + 0.124*"eurosystem"'),
#  (11,
#   '0.222*"financial" + -0.198*"level" + -0.169*"inflation" + -0.149*"activity" '
#   '+ -0.132*"january" + 0.126*"uncertainty" + 0.118*"also" + 0.118*"moderate" '
#   '+ -0.117*"continue" + 0.110*"year"'),
#  (12,
#   '-0.207*"financial" + -0.188*"recent" + -0.163*"volatility" + -0.162*"may" + '
#   '0.154*"effect" + 0.145*"wage" + 0.140*"level" + -0.138*"credit" + '
#   '0.136*"moderate" + -0.134*"data"'),
#  (13,
#   '0.303*"december" + 0.289*"january" + -0.213*"june" + -0.172*"july" + '
#   '0.155*"november" + 0.118*"latest" + 0.116*"continued" + -0.113*"august" + '
#   '-0.113*"recent" + 0.112*"term"'),
#  (14,
#   '0.220*"inflation" + -0.205*"quarter" + -0.179*"also" + 0.175*"ecb" + '
#   '0.147*"country" + -0.144*"recovery" + -0.139*"risk" + -0.137*"operation" + '
#   '-0.131*"remain" + -0.124*"level"'),
#  (15,
#   '0.201*"stability" + -0.169*"bank" + -0.157*"month" + 0.131*"september" + '
#   '-0.130*"ongoing" + 0.129*"july" + -0.119*"however" + 0.116*"continue" + '
#   '0.111*"second" + 0.111*"period"'),
#  (16,
#   '0.201*"oil" + 0.192*"increase" + -0.152*"also" + -0.150*"condition" + '
#   '-0.148*"continue" + 0.137*"measure" + -0.135*"period" + 0.132*"need" + '
#   '0.130*"risk" + 0.126*"activity"'),
#  (17,
#   '-0.272*"march" + 0.230*"september" + 0.182*"october" + -0.161*"february" + '
#   '0.156*"august" + -0.151*"april" + -0.134*"looking" + 0.134*"inflation" + '
#   '-0.132*"stability" + -0.130*"economy"'),
#  (18,
#   '0.183*"risk" + -0.172*"expected" + -0.147*"increase" + -0.143*"annual" + '
#   '0.139*"operation" + -0.121*"pace" + -0.118*"activity" + -0.118*"bank" + '
#   '0.117*"lending" + 0.113*"term"'),
#  (19,
#   '-0.231*"year" + -0.177*"activity" + -0.150*"recovery" + 0.142*"information" '
#   '+ 0.129*"first" + 0.126*"reform" + 0.122*"continued" + -0.119*"level" + '
#   '-0.118*"particular" + -0.116*"would"')]
# [(0,
#   '-0.262*"inflation" + -0.199*"risk" + -0.186*"stability" + -0.168*"term" + '
#   '-0.168*"medium" + -0.164*"annual" + -0.149*"remain" + -0.144*"analysis" + '
#   '-0.136*"also" + -0.123*"financial"'),
#  (1,
#   '0.296*"stability" + -0.215*"loan" + -0.197*"inflation" + -0.157*"measure" + '
#   '0.140*"ecb" + 0.135*"first" + 0.134*"strong" + 0.132*"also" + '
#   '-0.130*"annual" + 0.126*"recent"'),
#  (2,
#   '0.256*"ecb" + -0.222*"risk" + -0.172*"upside" + 0.169*"bank" + '
#   '-0.168*"medium" + -0.158*"stability" + 0.153*"central" + -0.151*"strong" + '
#   '0.134*"national" + 0.133*"operation"'),
#  (3,
#   '0.190*"oil" + 0.182*"projection" + -0.180*"pressure" + -0.170*"financial" + '
#   '-0.152*"medium" + -0.150*"remain" + 0.146*"quarter" + 0.145*"reform" + '
#   '-0.136*"term" + -0.132*"bank"'),
#  (4,
#   '-0.282*"risk" + -0.267*"financial" + 0.209*"recovery" + 0.192*"term" + '
#   '0.169*"remain" + -0.157*"underlying" + 0.157*"oil" + -0.120*"tension" + '
#   '-0.120*"bank" + -0.119*"upside"'),
#  (5,
#   '-0.197*"increase" + 0.194*"financial" + -0.165*"remains" + '
#   '0.161*"inflation" + 0.154*"effect" + -0.131*"liquidity" + 0.117*"stability" '
#   '+ 0.116*"turmoil" + -0.110*"ample" + -0.108*"pressure"'),
#  (6,
#   '0.331*"projection" + 0.231*"staff" + 0.187*"measure" + -0.176*"subdued" + '
#   '-0.161*"credit" + 0.159*"pressure" + -0.152*"loan" + 0.152*"inflation" + '
#   '-0.139*"country" + -0.139*"condition"'),
#  (7,
#   '-0.219*"projection" + -0.194*"medium" + 0.182*"recent" + -0.159*"staff" + '
#   '0.151*"inflation" + 0.147*"financial" + 0.146*"pressure" + -0.144*"ecb" + '
#   '0.137*"reform" + 0.134*"fiscal"'),
#  (8,
#   '0.267*"measure" + -0.177*"projection" + -0.173*"may" + 0.165*"environment" '
#   '+ 0.145*"financial" + -0.139*"recent" + 0.135*"stability" + -0.116*"upward" '
#   '+ 0.111*"purchase" + 0.110*"fiscal"'),
#  (9,
#   '0.208*"projection" + 0.166*"financial" + -0.152*"purchase" + '
#   '-0.142*"measure" + 0.127*"staff" + 0.127*"subdued" + -0.125*"increase" + '
#   '-0.122*"contribute" + -0.122*"may" + 0.115*"confidence"'),
#  (10,
#   '0.216*"operation" + -0.180*"ecb" + 0.152*"refinancing" + 0.144*"period" + '
#   '-0.140*"bank" + 0.137*"economy" + 0.137*"month" + -0.133*"escb" + '
#   '0.128*"outlook" + 0.124*"eurosystem"'),
#  (11,
#   '0.222*"financial" + -0.198*"level" + -0.169*"inflation" + -0.149*"activity" '
#   '+ -0.132*"january" + 0.126*"uncertainty" + 0.118*"also" + 0.118*"moderate" '
#   '+ -0.117*"continue" + 0.110*"year"'),
#  (12,
#   '0.207*"financial" + 0.188*"recent" + 0.163*"volatility" + 0.162*"may" + '
#   '-0.154*"effect" + -0.145*"wage" + -0.140*"level" + 0.138*"credit" + '
#   '-0.136*"moderate" + 0.134*"data"'),
#  (13,
#   '-0.303*"december" + -0.289*"january" + 0.213*"june" + 0.172*"july" + '
#   '-0.155*"november" + -0.119*"latest" + -0.116*"continued" + 0.113*"august" + '
#   '0.113*"recent" + -0.112*"term"'),
#  (14,
#   '-0.221*"inflation" + 0.205*"quarter" + 0.180*"also" + -0.175*"ecb" + '
#   '-0.147*"country" + 0.144*"recovery" + 0.139*"risk" + 0.137*"operation" + '
#   '0.131*"remain" + 0.124*"level"'),
#  (15,
#   '-0.201*"stability" + 0.169*"bank" + 0.158*"month" + -0.130*"september" + '
#   '0.129*"ongoing" + -0.128*"july" + 0.119*"however" + -0.116*"continue" + '
#   '-0.111*"second" + -0.111*"period"'),
#  (16,
#   '-0.201*"oil" + -0.192*"increase" + 0.153*"also" + 0.151*"condition" + '
#   '0.148*"continue" + -0.137*"measure" + 0.136*"period" + -0.132*"need" + '
#   '-0.130*"risk" + -0.126*"activity"'),
#  (17,
#   '0.272*"march" + -0.231*"september" + -0.182*"october" + 0.161*"february" + '
#   '-0.157*"august" + 0.152*"april" + 0.135*"looking" + -0.134*"inflation" + '
#   '0.132*"stability" + 0.130*"economy"'),
#  (18,
#   '-0.184*"risk" + 0.172*"expected" + 0.147*"increase" + 0.143*"annual" + '
#   '-0.140*"operation" + 0.122*"pace" + 0.119*"activity" + 0.118*"bank" + '
#   '-0.117*"lending" + -0.114*"term"'),
#  (19,
#   '0.230*"year" + 0.177*"activity" + 0.150*"recovery" + -0.142*"information" + '
#   '-0.129*"first" + -0.127*"reform" + -0.122*"continued" + 0.119*"level" + '
#   '0.117*"particular" + 0.117*"would"'),
#  (20,
#   '-0.200*"january" + 0.180*"country" + 0.176*"domestic" + 0.176*"year" + '
#   '0.173*"bank" + -0.165*"strategy" + 0.154*"eurosystem" + -0.139*"stability" '
#   '+ 0.116*"central" + -0.110*"outlook"'),
#  (21,
#   '0.167*"activity" + -0.146*"june" + -0.138*"economy" + -0.125*"term" + '
#   '0.119*"sector" + -0.112*"also" + 0.110*"demand" + 0.106*"recent" + '
#   '-0.104*"inflation" + -0.103*"expect"'),
#  (22,
#   '0.197*"economy" + 0.152*"oil" + 0.130*"expected" + 0.128*"increase" + '
#   '-0.119*"country" + -0.113*"first" + -0.109*"june" + -0.109*"support" + '
#   '-0.107*"reform" + -0.103*"positive"'),
#  (23,
#   '0.234*"oil" + -0.183*"level" + 0.170*"particular" + 0.151*"money" + '
#   '0.121*"domestic" + -0.116*"past" + 0.116*"need" + 0.114*"demand" + '
#   '-0.112*"sector" + 0.108*"higher"'),
#  (24,
#   '-0.218*"term" + -0.210*"also" + -0.175*"decision" + -0.170*"medium" + '
#   '0.143*"month" + 0.143*"new" + 0.138*"year" + -0.122*"exchange" + '
#   '-0.122*"financial" + 0.104*"fiscal"'),
#  (25,
#   '0.131*"regard" + -0.130*"effect" + 0.120*"september" + -0.120*"assessment" '
#   '+ 0.114*"country" + -0.111*"impact" + -0.106*"december" + 0.106*"need" + '
#   '-0.104*"value" + -0.104*"activity"'),
#  (26,
#   '-0.161*"quarter" + 0.158*"banknote" + -0.139*"trend" + 0.135*"stability" + '
#   '-0.135*"also" + 0.121*"important" + 0.120*"national" + -0.120*"decision" + '
#   '-0.117*"first" + -0.117*"reference"'),
#  (27,
#   '-0.196*"regard" + 0.166*"recent" + -0.142*"quarter" + -0.139*"structural" + '
#   '0.118*"impact" + 0.115*"remain" + 0.115*"first" + 0.113*"oil" + '
#   '-0.112*"underlying" + 0.108*"june"'),
#  (28,
#   '0.171*"activity" + -0.162*"remain" + 0.139*"may" + 0.131*"information" + '
#   '-0.127*"operation" + -0.123*"strong" + 0.122*"overall" + -0.122*"inflation" '
#   '+ 0.109*"well" + -0.109*"would"'),
#  (29,
#   '0.222*"year" + -0.183*"activity" + 0.169*"also" + 0.140*"risk" + '
#   '0.128*"february" + -0.121*"oil" + -0.114*"may" + -0.112*"quarter" + '
#   '0.108*"inflation" + 0.108*"january"'),
#  (30,
#   '0.253*"also" + -0.195*"stability" + -0.158*"increase" + -0.140*"recovery" + '
#   '-0.114*"ncbs" + 0.111*"reflecting" + 0.109*"banknote" + 0.107*"new" + '
#   '-0.103*"three" + -0.103*"shortterm"'),
#  (31,
#   '-0.218*"year" + -0.207*"recent" + 0.170*"also" + 0.155*"continue" + '
#   '-0.153*"remain" + 0.148*"first" + 0.118*"would" + 0.113*"fiscal" + '
#   '-0.112*"oil" + -0.106*"continued"'),
#  (32,
#   '-0.210*"quarter" + -0.189*"inflation" + -0.179*"first" + '
#   '0.150*"macroeconomic" + 0.139*"fiscal" + 0.137*"july" + 0.133*"particular" '
#   '+ 0.116*"august" + -0.115*"year" + -0.106*"financial"'),
#  (33,
#   '-0.187*"increase" + -0.185*"decision" + 0.163*"strong" + 0.133*"fiscal" + '
#   '0.127*"activity" + 0.119*"available" + 0.113*"rise" + 0.109*"credit" + '
#   '0.108*"expansion" + -0.107*"analysis"'),
#  (34,
#   '-0.155*"continued" + -0.151*"june" + -0.141*"point" + 0.136*"country" + '
#   '0.135*"remains" + -0.119*"particular" + 0.117*"level" + -0.114*"pressure" + '
#   '0.109*"march" + 0.109*"continue"'),
#  (35,
#   '0.170*"august" + 0.132*"data" + 0.129*"country" + -0.122*"therefore" + '
#   '-0.118*"factor" + -0.116*"increase" + -0.116*"oil" + -0.116*"may" + '
#   '0.114*"pressure" + -0.106*"april"'),
#  (36,
#   '0.160*"particular" + 0.155*"outlook" + 0.133*"would" + -0.121*"increase" + '
#   '0.118*"level" + 0.117*"october" + 0.114*"month" + 0.113*"time" + '
#   '-0.112*"country" + 0.107*"external"'),
#  (37,
#   '0.196*"recent" + -0.164*"february" + -0.159*"march" + 0.143*"remain" + '
#   '0.140*"continued" + 0.127*"expansion" + -0.125*"impact" + 0.123*"inflation" '
#   '+ -0.123*"sector" + 0.114*"december"'),
#  (38,
#   '-0.227*"also" + 0.188*"current" + -0.147*"country" + 0.127*"assessment" + '
#   '0.125*"expected" + 0.118*"june" + -0.117*"august" + 0.113*"continue" + '
#   '0.108*"low" + -0.095*"demand"'),
#  (39,
#   '-0.213*"recent" + -0.169*"first" + 0.165*"quarter" + -0.150*"time" + '
#   '0.146*"banknote" + 0.141*"year" + 0.128*"overall" + -0.124*"value" + '
#   '0.112*"data" + 0.110*"july"'),
#  (40,
#   '-0.187*"expected" + -0.137*"impact" + 0.136*"april" + 0.132*"continues" + '
#   '-0.131*"support" + 0.121*"time" + 0.109*"day" + -0.103*"continue" + '
#   '0.101*"ongoing" + -0.100*"quarter"'),
#  (41,
#   '-0.182*"quarter" + 0.175*"inflation" + 0.144*"stability" + -0.131*"decline" '
#   '+ -0.130*"current" + -0.124*"continue" + -0.110*"level" + 0.107*"mainly" + '
#   '0.107*"energy" + -0.102*"unchanged"'),
#  (42,
#   '-0.190*"july" + 0.176*"support" + 0.169*"october" + -0.157*"country" + '
#   '-0.156*"line" + 0.150*"moderate" + -0.149*"outlook" + 0.145*"level" + '
#   '-0.127*"mainly" + 0.116*"annual"'),
#  (43,
#   '-0.175*"overall" + 0.133*"remains" + 0.129*"september" + -0.124*"risk" + '
#   '0.120*"term" + 0.116*"medium" + 0.115*"european" + -0.114*"low" + '
#   '-0.106*"higher" + 0.105*"effect"'),
#  (44,
#   '0.232*"time" + 0.144*"money" + 0.126*"asset" + -0.123*"economy" + '
#   '0.117*"march" + -0.117*"energy" + 0.117*"purchase" + 0.113*"country" + '
#   '-0.100*"high" + -0.099*"available"'),
#  (45,
#   '0.154*"remains" + -0.149*"public" + -0.137*"high" + 0.133*"particular" + '
#   '0.119*"outlook" + -0.116*"overall" + -0.109*"term" + 0.108*"trend" + '
#   '0.105*"process" + -0.103*"oil"'),
#  (46,
#   '-0.144*"would" + 0.135*"april" + 0.133*"strong" + 0.119*"remain" + '
#   '0.118*"month" + -0.118*"european" + -0.117*"quarter" + 0.116*"continued" + '
#   '-0.114*"inflation" + 0.109*"exchange"'),
#  (47,
#   '-0.199*"available" + 0.142*"impact" + 0.140*"risk" + 0.136*"may" + '
#   '-0.129*"information" + -0.127*"potential" + -0.123*"continued" + '
#   '0.116*"expected" + 0.102*"still" + -0.097*"deficit"'),
#  (48,
#   '-0.158*"continued" + -0.155*"also" + 0.149*"remains" + -0.126*"july" + '
#   '0.122*"april" + 0.109*"term" + 0.104*"point" + -0.102*"thus" + '
#   '-0.100*"august" + 0.099*"eurosystem"'),
#  (49,
#   '0.149*"would" + 0.141*"condition" + -0.136*"oil" + -0.135*"unchanged" + '
#   '0.130*"demand" + -0.123*"outlook" + 0.122*"continued" + 0.120*"loan" + '
#   '-0.112*"line" + 0.108*"reform"')]
# [(0,
#   '-0.262*"inflation" + -0.199*"risk" + -0.186*"stability" + -0.168*"term" + '
#   '-0.168*"medium" + -0.164*"annual" + -0.149*"remain" + -0.144*"analysis" + '
#   '-0.136*"also" + -0.123*"financial"'),
#  (1,
#   '0.296*"stability" + -0.215*"loan" + -0.197*"inflation" + -0.157*"measure" + '
#   '0.140*"ecb" + 0.135*"first" + 0.134*"strong" + 0.132*"also" + '
#   '-0.130*"annual" + 0.126*"recent"'),
#  (2,
#   '0.256*"ecb" + -0.222*"risk" + -0.172*"upside" + 0.169*"bank" + '
#   '-0.168*"medium" + -0.158*"stability" + 0.153*"central" + -0.151*"strong" + '
#   '0.134*"national" + 0.133*"operation"'),
#  (3,
#   '0.190*"oil" + 0.182*"projection" + -0.180*"pressure" + -0.170*"financial" + '
#   '-0.152*"medium" + -0.150*"remain" + 0.146*"quarter" + 0.145*"reform" + '
#   '-0.136*"term" + -0.132*"bank"'),
#  (4,
#   '-0.282*"risk" + -0.267*"financial" + 0.209*"recovery" + 0.192*"term" + '
#   '0.169*"remain" + -0.157*"underlying" + 0.157*"oil" + -0.120*"tension" + '
#   '-0.120*"bank" + -0.119*"upside"'),
#  (5,
#   '-0.197*"increase" + 0.194*"financial" + -0.165*"remains" + '
#   '0.161*"inflation" + 0.154*"effect" + -0.131*"liquidity" + 0.117*"stability" '
#   '+ 0.116*"turmoil" + -0.110*"ample" + -0.108*"pressure"'),
#  (6,
#   '-0.331*"projection" + -0.231*"staff" + -0.187*"measure" + 0.176*"subdued" + '
#   '0.161*"credit" + -0.159*"pressure" + 0.152*"loan" + -0.152*"inflation" + '
#   '0.139*"country" + 0.139*"condition"'),
#  (7,
#   '0.219*"projection" + 0.194*"medium" + -0.182*"recent" + 0.159*"staff" + '
#   '-0.151*"inflation" + -0.147*"financial" + -0.146*"pressure" + 0.144*"ecb" + '
#   '-0.137*"reform" + -0.134*"fiscal"'),
#  (8,
#   '-0.267*"measure" + 0.177*"projection" + 0.173*"may" + -0.165*"environment" '
#   '+ -0.145*"financial" + 0.139*"recent" + -0.135*"stability" + 0.116*"upward" '
#   '+ -0.111*"purchase" + -0.110*"fiscal"'),
#  (9,
#   '-0.208*"projection" + -0.166*"financial" + 0.152*"purchase" + '
#   '0.142*"measure" + -0.127*"staff" + -0.127*"subdued" + 0.125*"increase" + '
#   '0.122*"contribute" + 0.122*"may" + -0.115*"confidence"'),
#  (10,
#   '-0.216*"operation" + 0.180*"ecb" + -0.152*"refinancing" + -0.144*"period" + '
#   '0.140*"bank" + -0.137*"economy" + -0.137*"month" + 0.133*"escb" + '
#   '-0.128*"outlook" + -0.124*"eurosystem"'),
#  (11,
#   '0.222*"financial" + -0.198*"level" + -0.169*"inflation" + -0.149*"activity" '
#   '+ -0.132*"january" + 0.126*"uncertainty" + 0.118*"also" + 0.118*"moderate" '
#   '+ -0.117*"continue" + 0.110*"year"'),
#  (12,
#   '-0.207*"financial" + -0.188*"recent" + -0.163*"volatility" + -0.162*"may" + '
#   '0.154*"effect" + 0.145*"wage" + 0.140*"level" + -0.138*"credit" + '
#   '0.136*"moderate" + -0.134*"data"'),
#  (13,
#   '0.303*"december" + 0.289*"january" + -0.213*"june" + -0.172*"july" + '
#   '0.155*"november" + 0.119*"latest" + 0.116*"continued" + -0.113*"august" + '
#   '-0.113*"recent" + 0.112*"term"'),
#  (14,
#   '0.221*"inflation" + -0.205*"quarter" + -0.179*"also" + 0.175*"ecb" + '
#   '0.147*"country" + -0.144*"recovery" + -0.139*"risk" + -0.137*"operation" + '
#   '-0.131*"remain" + -0.124*"level"'),
#  (15,
#   '0.201*"stability" + -0.169*"bank" + -0.158*"month" + 0.131*"september" + '
#   '-0.129*"ongoing" + 0.128*"july" + -0.119*"however" + 0.116*"continue" + '
#   '0.111*"second" + 0.111*"period"'),
#  (16,
#   '-0.201*"oil" + -0.192*"increase" + 0.153*"also" + 0.151*"condition" + '
#   '0.148*"continue" + -0.137*"measure" + 0.136*"period" + -0.132*"need" + '
#   '-0.130*"risk" + -0.126*"activity"'),
#  (17,
#   '-0.271*"march" + 0.231*"september" + 0.182*"october" + -0.161*"february" + '
#   '0.157*"august" + -0.152*"april" + -0.134*"looking" + 0.134*"inflation" + '
#   '-0.132*"stability" + -0.130*"economy"'),
#  (18,
#   '0.184*"risk" + -0.172*"expected" + -0.147*"increase" + -0.143*"annual" + '
#   '0.140*"operation" + -0.121*"pace" + -0.118*"activity" + -0.118*"bank" + '
#   '0.117*"lending" + 0.114*"term"'),
#  (19,
#   '0.230*"year" + 0.177*"activity" + 0.151*"recovery" + -0.142*"information" + '
#   '-0.129*"first" + -0.127*"reform" + -0.122*"continued" + 0.119*"level" + '
#   '0.117*"particular" + 0.116*"would"'),
#  (20,
#   '0.199*"january" + -0.180*"country" + -0.176*"domestic" + -0.176*"year" + '
#   '-0.173*"bank" + 0.165*"strategy" + -0.154*"eurosystem" + 0.139*"stability" '
#   '+ -0.116*"central" + 0.109*"outlook"'),
#  (21,
#   '0.167*"activity" + -0.146*"june" + -0.138*"economy" + -0.125*"term" + '
#   '0.119*"sector" + -0.112*"also" + 0.111*"demand" + 0.106*"recent" + '
#   '-0.104*"inflation" + -0.103*"expect"'),
#  (22,
#   '-0.197*"economy" + -0.152*"oil" + -0.130*"expected" + -0.129*"increase" + '
#   '0.118*"country" + 0.113*"first" + 0.109*"june" + 0.109*"support" + '
#   '0.107*"reform" + 0.102*"positive"'),
#  (23,
#   '-0.234*"oil" + 0.182*"level" + -0.170*"particular" + -0.151*"money" + '
#   '-0.121*"domestic" + 0.117*"past" + -0.116*"need" + -0.114*"demand" + '
#   '0.112*"sector" + -0.108*"higher"'),
#  (24,
#   '-0.218*"term" + -0.210*"also" + -0.175*"decision" + -0.170*"medium" + '
#   '0.143*"month" + 0.143*"new" + 0.137*"year" + -0.122*"exchange" + '
#   '-0.122*"financial" + 0.104*"fiscal"'),
#  (25,
#   '-0.131*"regard" + 0.130*"effect" + 0.120*"assessment" + -0.120*"september" '
#   '+ -0.114*"country" + 0.110*"impact" + 0.106*"december" + -0.106*"need" + '
#   '0.104*"activity" + 0.104*"value"'),
#  (26,
#   '-0.161*"quarter" + 0.158*"banknote" + -0.139*"trend" + 0.135*"stability" + '
#   '-0.135*"also" + 0.122*"important" + 0.121*"national" + -0.120*"decision" + '
#   '-0.117*"reference" + -0.117*"first"'),
#  (27,
#   '-0.197*"regard" + 0.166*"recent" + -0.142*"quarter" + -0.139*"structural" + '
#   '0.117*"impact" + 0.115*"remain" + 0.115*"first" + 0.113*"oil" + '
#   '-0.112*"underlying" + 0.108*"june"'),
#  (28,
#   '0.171*"activity" + -0.162*"remain" + 0.139*"may" + 0.131*"information" + '
#   '-0.126*"operation" + -0.123*"strong" + 0.122*"overall" + -0.122*"inflation" '
#   '+ 0.109*"well" + -0.109*"would"'),
#  (29,
#   '-0.223*"year" + 0.184*"activity" + -0.169*"also" + -0.140*"risk" + '
#   '-0.127*"february" + 0.121*"oil" + 0.114*"may" + 0.113*"quarter" + '
#   '-0.108*"january" + -0.108*"inflation"'),
#  (30,
#   '0.253*"also" + -0.195*"stability" + -0.158*"increase" + -0.139*"recovery" + '
#   '-0.114*"ncbs" + 0.111*"reflecting" + 0.109*"banknote" + 0.107*"new" + '
#   '-0.103*"three" + -0.103*"shortterm"'),
#  (31,
#   '0.218*"year" + 0.208*"recent" + -0.171*"also" + -0.155*"continue" + '
#   '0.153*"remain" + -0.147*"first" + -0.118*"would" + -0.113*"fiscal" + '
#   '0.112*"oil" + 0.106*"continued"'),
#  (32,
#   '0.211*"quarter" + 0.189*"inflation" + 0.180*"first" + '
#   '-0.150*"macroeconomic" + -0.138*"fiscal" + -0.138*"july" + '
#   '-0.132*"particular" + -0.116*"august" + 0.115*"year" + 0.106*"financial"'),
#  (33,
#   '-0.187*"increase" + -0.184*"decision" + 0.164*"strong" + 0.133*"fiscal" + '
#   '0.127*"activity" + 0.119*"available" + 0.113*"rise" + 0.110*"credit" + '
#   '0.108*"expansion" + -0.107*"analysis"'),
#  (34,
#   '-0.154*"continued" + -0.150*"june" + -0.141*"point" + 0.135*"country" + '
#   '0.135*"remains" + -0.119*"particular" + 0.116*"level" + -0.115*"pressure" + '
#   '0.109*"march" + 0.108*"continue"'),
#  (35,
#   '0.169*"august" + 0.133*"data" + 0.130*"country" + -0.122*"therefore" + '
#   '-0.118*"factor" + -0.117*"may" + -0.116*"oil" + -0.116*"increase" + '
#   '0.113*"pressure" + -0.106*"april"'),
#  (36,
#   '0.160*"particular" + 0.155*"outlook" + 0.133*"would" + -0.121*"increase" + '
#   '0.119*"level" + 0.117*"october" + 0.114*"month" + 0.113*"time" + '
#   '-0.112*"country" + 0.107*"external"'),
#  (37,
#   '0.196*"recent" + -0.163*"february" + -0.160*"march" + 0.142*"remain" + '
#   '0.140*"continued" + 0.127*"expansion" + -0.125*"impact" + -0.123*"sector" + '
#   '0.122*"inflation" + 0.115*"december"'),
#  (38,
#   '0.227*"also" + -0.189*"current" + 0.147*"country" + -0.127*"assessment" + '
#   '-0.125*"expected" + -0.118*"june" + 0.117*"august" + -0.112*"continue" + '
#   '-0.108*"low" + 0.095*"demand"'),
#  (39,
#   '0.212*"recent" + 0.169*"first" + -0.165*"quarter" + 0.150*"time" + '
#   '-0.144*"banknote" + -0.141*"year" + -0.128*"overall" + 0.124*"value" + '
#   '-0.112*"data" + -0.110*"july"'),
#  (40,
#   '-0.188*"expected" + -0.136*"impact" + 0.135*"april" + 0.132*"continues" + '
#   '-0.131*"support" + 0.120*"time" + 0.110*"day" + -0.103*"continue" + '
#   '0.101*"ongoing" + -0.099*"quarter"'),
#  (41,
#   '0.182*"quarter" + -0.174*"inflation" + -0.144*"stability" + 0.131*"decline" '
#   '+ 0.131*"current" + 0.124*"continue" + 0.110*"level" + -0.107*"mainly" + '
#   '-0.107*"energy" + 0.103*"unchanged"'),
#  (42,
#   '-0.190*"july" + 0.177*"support" + 0.170*"october" + -0.158*"country" + '
#   '-0.155*"line" + 0.150*"moderate" + -0.149*"outlook" + 0.145*"level" + '
#   '-0.127*"mainly" + 0.117*"annual"'),
#  (43,
#   '-0.176*"overall" + 0.133*"remains" + 0.130*"september" + -0.125*"risk" + '
#   '0.121*"term" + 0.117*"medium" + 0.115*"european" + -0.112*"low" + '
#   '-0.107*"higher" + 0.105*"effect"'),
#  (44,
#   '0.234*"time" + 0.142*"money" + 0.126*"asset" + -0.123*"economy" + '
#   '0.118*"purchase" + 0.117*"march" + -0.117*"energy" + 0.113*"country" + '
#   '-0.102*"high" + -0.099*"available"'),
#  (45,
#   '0.154*"remains" + -0.149*"public" + -0.138*"high" + 0.132*"particular" + '
#   '0.117*"outlook" + -0.116*"overall" + -0.109*"term" + 0.108*"trend" + '
#   '0.105*"process" + -0.103*"oil"'),
#  (46,
#   '-0.142*"would" + 0.135*"april" + 0.132*"strong" + 0.120*"remain" + '
#   '-0.118*"quarter" + -0.118*"european" + 0.117*"month" + 0.114*"continued" + '
#   '-0.114*"inflation" + 0.108*"exchange"'),
#  (47,
#   '-0.198*"available" + 0.141*"risk" + 0.141*"impact" + 0.135*"may" + '
#   '-0.129*"information" + -0.127*"potential" + -0.125*"continued" + '
#   '0.118*"expected" + 0.100*"still" + -0.096*"forecast"'),
#  (48,
#   '0.157*"continued" + 0.157*"also" + -0.151*"remains" + 0.126*"july" + '
#   '-0.123*"april" + -0.109*"term" + -0.104*"point" + 0.101*"thus" + '
#   '0.101*"august" + -0.099*"eurosystem"'),
#  (49,
#   '-0.151*"would" + -0.140*"condition" + 0.137*"oil" + 0.135*"unchanged" + '
#   '-0.130*"demand" + 0.124*"outlook" + -0.123*"continued" + -0.121*"loan" + '
#   '0.110*"line" + -0.107*"reform"'),
#  (50,
#   '-0.144*"outlook" + -0.140*"global" + 0.139*"overall" + 0.135*"quarter" + '
#   '-0.132*"risk" + 0.123*"deficit" + 0.115*"implementation" + '
#   '0.114*"challenge" + 0.105*"effect" + -0.104*"purchase"'),
#  (51,
#   '0.173*"support" + -0.146*"first" + -0.127*"january" + 0.127*"also" + '
#   '-0.122*"expected" + -0.120*"expectation" + -0.115*"august" + 0.112*"recent" '
#   '+ -0.111*"rise" + -0.108*"december"'),
#  (52,
#   '-0.174*"purchase" + -0.151*"also" + -0.143*"november" + 0.132*"impact" + '
#   '0.131*"line" + 0.117*"macroeconomic" + -0.108*"continue" + '
#   '0.104*"favourable" + -0.099*"programme" + -0.097*"still"'),
#  (53,
#   '0.209*"country" + 0.182*"level" + 0.132*"particular" + 0.119*"therefore" + '
#   '0.111*"assessment" + -0.110*"annual" + 0.110*"order" + -0.110*"past" + '
#   '-0.103*"demand" + -0.102*"employment"'),
#  (54,
#   '0.166*"particular" + -0.141*"regard" + 0.134*"need" + 0.127*"continued" + '
#   '0.122*"employment" + -0.114*"expansion" + -0.109*"pressure" + '
#   '-0.102*"close" + 0.101*"overall" + -0.101*"impact"'),
#  (55,
#   '0.164*"strong" + -0.136*"expected" + -0.128*"remains" + 0.126*"month" + '
#   '0.120*"inflation" + -0.119*"factor" + 0.113*"december" + 0.108*"available" '
#   '+ -0.106*"loan" + -0.106*"real"'),
#  (56,
#   '0.155*"continue" + -0.142*"hicp" + -0.123*"march" + -0.121*"would" + '
#   '-0.115*"expected" + 0.115*"outlook" + -0.114*"information" + '
#   '-0.114*"annual" + -0.114*"expansion" + 0.105*"january"'),
#  (57,
#   '-0.145*"continue" + 0.137*"inflation" + -0.119*"important" + '
#   '0.115*"country" + -0.107*"remain" + 0.104*"remains" + -0.104*"increase" + '
#   '0.100*"activity" + 0.100*"average" + -0.099*"year"'),
#  (58,
#   '-0.195*"would" + -0.123*"sector" + -0.123*"recent" + 0.118*"month" + '
#   '-0.117*"purchase" + -0.115*"august" + -0.109*"condition" + 0.107*"money" + '
#   '-0.102*"data" + 0.099*"june"'),
#  (59,
#   '0.145*"wage" + -0.123*"assessment" + -0.121*"impact" + -0.119*"government" '
#   '+ 0.110*"support" + 0.106*"recent" + -0.106*"first" + -0.106*"programme" + '
#   '0.102*"horizon" + 0.101*"pressure"'),
#  (60,
#   '0.172*"decline" + 0.140*"data" + 0.133*"term" + -0.124*"effect" + '
#   '-0.123*"current" + 0.112*"quarter" + 0.107*"however" + 0.102*"challenge" + '
#   '-0.100*"particular" + 0.099*"first"'),
#  (61,
#   '-0.148*"may" + 0.141*"credit" + 0.122*"consumer" + -0.122*"risk" + '
#   '0.121*"also" + -0.121*"high" + 0.101*"underlying" + 0.097*"second" + '
#   '0.096*"condition" + 0.096*"looking"'),
#  (62,
#   '0.158*"september" + 0.146*"european" + -0.123*"effect" + 0.118*"risk" + '
#   '-0.115*"labour" + 0.109*"thereby" + 0.109*"line" + -0.108*"level" + '
#   '-0.108*"financial" + -0.104*"still"'),
#  (63,
#   '0.191*"risk" + -0.156*"previous" + 0.144*"fiscal" + 0.124*"activity" + '
#   '0.122*"effect" + -0.106*"global" + 0.104*"april" + -0.103*"recent" + '
#   '-0.102*"main" + 0.101*"data"'),
#  (64,
#   '0.138*"recovery" + -0.125*"ongoing" + 0.123*"contribute" + 0.121*"continue" '
#   '+ -0.114*"improvement" + 0.112*"decision" + -0.110*"pressure" + '
#   '0.101*"information" + 0.099*"economy" + -0.098*"commodity"'),
#  (65,
#   '0.133*"assessment" + 0.128*"somewhat" + 0.120*"activity" + 0.119*"outlook" '
#   '+ -0.115*"confidence" + -0.113*"help" + -0.111*"line" + '
#   '-0.111*"particularly" + 0.110*"regard" + 0.110*"hicp"'),
#  (66,
#   '0.157*"slightly" + 0.137*"first" + 0.134*"hicp" + -0.132*"credit" + '
#   '0.108*"overall" + 0.107*"february" + -0.106*"necessary" + 0.105*"march" + '
#   '-0.104*"global" + -0.101*"annual"'),
#  (67,
#   '0.150*"measure" + 0.127*"december" + 0.124*"however" + -0.119*"private" + '
#   '-0.107*"condition" + 0.106*"april" + 0.103*"stance" + -0.101*"related" + '
#   '-0.095*"february" + -0.092*"reform"'),
#  (68,
#   '-0.147*"adjustment" + 0.140*"decline" + -0.132*"hicp" + 0.125*"outlook" + '
#   '0.120*"bank" + -0.120*"need" + -0.114*"may" + 0.104*"overall" + '
#   '0.103*"high" + 0.102*"march"'),
#  (69,
#   '-0.175*"improvement" + -0.138*"remained" + -0.114*"ongoing" + '
#   '-0.113*"november" + 0.105*"continues" + -0.104*"regard" + -0.104*"range" + '
#   '0.104*"available" + -0.104*"upward" + 0.103*"indirect"'),
#  (70,
#   '0.157*"broadly" + 0.141*"continue" + -0.120*"february" + -0.119*"quarter" + '
#   '-0.119*"high" + -0.117*"well" + 0.114*"april" + -0.110*"next" + '
#   '0.100*"past" + -0.097*"impact"'),
#  (71,
#   '0.269*"still" + 0.116*"measure" + 0.115*"reform" + -0.114*"consolidation" + '
#   '-0.110*"effect" + 0.104*"progress" + -0.102*"june" + 0.100*"economy" + '
#   '-0.098*"fiscal" + -0.089*"data"'),
#  (72,
#   '0.132*"level" + 0.130*"purchase" + 0.128*"however" + 0.125*"looking" + '
#   '0.109*"pressure" + 0.102*"remain" + -0.101*"november" + -0.101*"early" + '
#   '-0.101*"analysis" + 0.101*"september"'),
#  (73,
#   '-0.142*"economy" + -0.123*"commodity" + 0.118*"reflects" + 0.117*"previous" '
#   '+ -0.106*"environment" + 0.105*"fiscal" + 0.103*"unchanged" + '
#   '-0.101*"reflecting" + 0.100*"organisation" + -0.099*"october"'),
#  (74,
#   '-0.154*"may" + 0.144*"range" + -0.136*"higher" + -0.115*"treaty" + '
#   '0.114*"month" + 0.108*"past" + 0.107*"opportunity" + -0.104*"sector" + '
#   '-0.101*"data" + 0.100*"upward"'),
#  (75,
#   '-0.134*"ensure" + -0.117*"may" + -0.114*"time" + -0.114*"ongoing" + '
#   '0.111*"adjustment" + 0.107*"programme" + -0.105*"current" + -0.105*"range" '
#   '+ 0.100*"underlying" + 0.098*"level"'),
#  (76,
#   '-0.190*"continued" + 0.140*"fiscal" + -0.139*"remains" + -0.129*"latest" + '
#   '0.126*"moderate" + 0.120*"quarter" + 0.108*"outlook" + -0.106*"second" + '
#   '-0.103*"loan" + -0.100*"reform"'),
#  (77,
#   '0.142*"well" + 0.135*"decline" + -0.129*"decided" + -0.126*"high" + '
#   '-0.124*"unchanged" + 0.114*"labour" + -0.110*"range" + -0.108*"mediumterm" '
#   '+ -0.098*"would" + 0.094*"progress"'),
#  (78,
#   '-0.180*"positive" + -0.168*"particular" + -0.124*"demand" + 0.121*"view" + '
#   '0.114*"pillar" + 0.097*"sector" + -0.095*"macroeconomic" + -0.094*"decline" '
#   '+ 0.093*"july" + -0.093*"coming"'),
#  (79,
#   '0.128*"let" + -0.127*"increase" + -0.116*"increased" + -0.108*"economy" + '
#   '0.105*"available" + -0.102*"furthermore" + -0.100*"recovery" + '
#   '0.098*"press" + -0.096*"labour" + -0.095*"first"'),
#  (80,
#   '0.133*"month" + -0.128*"food" + 0.121*"upward" + -0.116*"let" + '
#   '-0.113*"inflationary" + 0.103*"particular" + -0.103*"august" + '
#   '0.102*"uncertainty" + 0.102*"factor" + 0.102*"real"'),
#  (81,
#   '0.195*"country" + 0.118*"information" + 0.117*"and" + 0.109*"november" + '
#   '0.104*"expectation" + -0.100*"particular" + 0.100*"general" + 0.099*"taken" '
#   '+ -0.099*"continue" + 0.099*"change"'),
#  (82,
#   '0.144*"unchanged" + 0.130*"however" + -0.120*"april" + 0.116*"likely" + '
#   '-0.108*"january" + 0.108*"credit" + -0.104*"confirmed" + 0.101*"remain" + '
#   '0.098*"pace" + 0.097*"low"'),
#  (83,
#   '0.152*"however" + 0.133*"current" + -0.127*"essential" + '
#   '-0.120*"government" + -0.110*"impact" + 0.109*"necessary" + '
#   '0.104*"employment" + 0.102*"indicator" + -0.102*"service" + -0.100*"part"'),
#  (84,
#   '-0.150*"bank" + 0.138*"appropriate" + 0.104*"new" + 0.104*"february" + '
#   '0.102*"increased" + 0.101*"ecb" + -0.099*"period" + -0.098*"expected" + '
#   '0.097*"expansion" + -0.093*"ahead"'),
#  (85,
#   '0.138*"employment" + 0.116*"increase" + -0.113*"moderation" + '
#   '-0.113*"condition" + -0.104*"fiscal" + 0.103*"european" + 0.092*"high" + '
#   '0.091*"sector" + 0.091*"moreover" + -0.090*"progress"'),
#  (86,
#   '-0.150*"broadly" + 0.132*"necessary" + 0.113*"global" + -0.105*"sector" + '
#   '0.104*"available" + 0.099*"year" + -0.097*"particular" + -0.092*"already" + '
#   '-0.091*"continued" + -0.086*"firmly"'),
#  (87,
#   '0.120*"confirm" + 0.114*"lower" + 0.113*"owing" + 0.108*"overall" + '
#   '0.107*"favourable" + -0.105*"basis" + -0.101*"reflect" + -0.100*"continued" '
#   '+ 0.098*"still" + -0.098*"budgetary"'),
#  (88,
#   '0.139*"public" + -0.128*"current" + 0.118*"stability" + -0.116*"measure" + '
#   '0.116*"recent" + 0.106*"allow" + -0.106*"reflecting" + -0.098*"treaty" + '
#   '-0.096*"january" + 0.096*"expected"'),
#  (89,
#   '0.118*"current" + 0.114*"economy" + -0.111*"range" + -0.111*"upward" + '
#   '0.104*"month" + 0.101*"would" + -0.097*"negative" + -0.095*"stronger" + '
#   '0.095*"thus" + 0.087*"recently"'),
#  (90,
#   '-0.124*"moreover" + 0.123*"energy" + -0.118*"october" + 0.111*"decision" + '
#   '-0.103*"data" + 0.101*"slightly" + 0.100*"august" + -0.099*"february" + '
#   '-0.099*"context" + -0.097*"basis"'),
#  (91,
#   '-0.109*"would" + -0.105*"two" + 0.101*"energy" + -0.099*"treaty" + '
#   '-0.098*"supporting" + -0.097*"situation" + -0.091*"within" + -0.091*"since" '
#   '+ 0.091*"general" + -0.091*"cost"'),
#  (92,
#   '0.125*"confirmed" + 0.106*"february" + 0.105*"service" + -0.094*"remain" + '
#   '0.094*"within" + 0.093*"information" + 0.091*"last" + 0.091*"september" + '
#   '-0.090*"therefore" + 0.090*"already"'),
#  (93,
#   '-0.117*"outlook" + -0.111*"treaty" + 0.104*"objective" + 0.098*"purchase" + '
#   '0.097*"upward" + 0.097*"eurosystem" + 0.091*"confirmed" + 0.085*"shortterm" '
#   '+ -0.085*"eu" + 0.082*"economy"'),
#  (94,
#   '0.137*"remains" + 0.137*"july" + -0.134*"remained" + 0.124*"energy" + '
#   '-0.116*"range" + 0.114*"warranted" + -0.107*"inflationary" + '
#   '-0.103*"service" + -0.102*"balance" + 0.094*"fiscal"'),
#  (95,
#   '0.112*"adjustment" + -0.111*"strengthening" + 0.107*"regard" + 0.105*"june" '
#   '+ 0.103*"improvement" + 0.093*"current" + 0.093*"however" + '
#   '-0.093*"private" + -0.089*"concern" + -0.088*"number"'),
#  (96,
#   '0.137*"owing" + -0.133*"april" + 0.117*"improvement" + 0.111*"latest" + '
#   '0.110*"ongoing" + -0.109*"due" + 0.107*"fiscal" + 0.104*"production" + '
#   '-0.103*"gradual" + -0.096*"longterm"'),
#  (97,
#   '0.107*"employment" + -0.105*"remain" + 0.104*"important" + -0.102*"hicp" + '
#   '-0.098*"reform" + -0.093*"fiscal" + 0.093*"year" + 0.088*"remaining" + '
#   '0.086*"line" + 0.086*"low"'),
#  (98,
#   '-0.117*"august" + -0.116*"fiscal" + -0.112*"assessment" + 0.103*"outlook" + '
#   '-0.101*"continues" + -0.098*"budgetary" + -0.096*"credit" + '
#   '0.094*"required" + -0.094*"tender" + 0.092*"expectation"'),
#  (99,
#   '-0.119*"level" + -0.107*"range" + 0.095*"confidence" + '
#   '0.091*"macroeconomic" + -0.090*"press" + 0.089*"external" + '
#   '0.088*"continuing" + -0.088*"may" + 0.086*"recovery" + -0.085*"release"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lsi5 = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi5 = coherence_model_lsi5.get_coherence()
print('\nCoherence Score5: ', coherence_lsi5)

# Compute Coherence Score
coherence_model_lsi10 = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi10 = coherence_model_lsi10.get_coherence()
print('\nCoherence Score10: ', coherence_lsi10)

# Compute Coherence Score
coherence_model_lsi20 = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi20 = coherence_model_lsi20.get_coherence()
print('\nCoherence Score20: ', coherence_lsi20)

# Compute Coherence Score
coherence_model_lsi50 = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi50 = coherence_model_lsi50.get_coherence()
print('\nCoherence Score50: ', coherence_lsi50)

# Compute Coherence Score
coherence_model_lsi100 = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi100 = coherence_model_lsi100.get_coherence()
print('\nCoherence Score100: ', coherence_lsi100)


# Compute Coherence Score
coherence_model_lsi5 = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi5 = coherence_model_lsi5.get_coherence()
print('\nCoherence Score5: ', coherence_lsi5)

# Compute Coherence Score
coherence_model_lsi10 = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi10 = coherence_model_lsi10.get_coherence()
print('\nCoherence Score10: ', coherence_lsi10)

# Compute Coherence Score
coherence_model_lsi20 = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi20 = coherence_model_lsi20.get_coherence()
print('\nCoherence Score20: ', coherence_lsi20)

# Compute Coherence Score
coherence_model_lsi50 = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi50 = coherence_model_lsi50.get_coherence()
print('\nCoherence Score50: ', coherence_lsi50)

# Compute Coherence Score
coherence_model_lsi100 = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi100 = coherence_model_lsi100.get_coherence()
print('\nCoherence Score100: ', coherence_lsi100)
# Out:
# Coherence Score5:  0.3374990195783618
#
# Coherence Score10:  0.34327654931081064
#
# Coherence Score20:  0.3164215249272169
#
# Coherence Score50:  0.2649262748108422
#
# Coherence Score100:  0.24083944199044688
#
# Coherence Score5:  -0.3576728439863296
#
# Coherence Score10:  -0.5574565522623385
#
# Coherence Score20:  -0.4212649068160929
#
# Coherence Score50:  -0.8819792172340655
#
# Coherence Score100:  -0.7320785123616754
