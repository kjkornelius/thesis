# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['qa']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(8371 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# filter words that occur in more than 90% of documents
id2word.filter_extremes(no_above = 0.980)
print(id2word)
# Out:
# Dictionary(3462 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=1, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
lda_model5 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model10 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model20 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model50 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=50, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model100 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=100, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\models\ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
# Print the Keyword in the 1 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.008*"bank" + 0.008*"inflation" + 0.008*"market" + 0.007*"price" + '
#   '0.006*"second" + 0.006*"see" + 0.006*"think" + 0.005*"year" + '
#   '0.005*"growth" + 0.005*"country"')]

# %%
# Print the Keyword in the 5 topics
pprint(lda_model5.print_topics())
doc_lda = lda_model5[corpus]

# Print the Keyword in the 10 topics
pprint(lda_model10.print_topics())
doc_lda = lda_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lda_model20.print_topics())
doc_lda = lda_model20[corpus]

# Print the Keyword in the 50 topics
pprint(lda_model50.print_topics())
doc_lda = lda_model50[corpus]

# Print the Keyword in the 100 topics
pprint(lda_model100.print_topics())
doc_lda = lda_model100[corpus]
# Out:
# [(0,
#   '0.010*"growth" + 0.009*"development" + 0.009*"year" + 0.007*"price" + '
#   '0.007*"central" + 0.006*"exchange" + 0.006*"may" + 0.006*"course" + '
#   '0.006*"today" + 0.006*"bank"'),
#  (1,
#   '0.010*"price" + 0.010*"regard" + 0.010*"stability" + 0.010*"market" + '
#   '0.008*"decision" + 0.008*"level" + 0.007*"council" + 0.007*"important" + '
#   '0.007*"growth" + 0.007*"see"'),
#  (2,
#   '0.010*"area" + 0.008*"think" + 0.008*"country" + 0.007*"so" + 0.007*"point" '
#   '+ 0.007*"ecb" + 0.007*"government" + 0.006*"market" + 0.006*"bank" + '
#   '0.006*"decision"'),
#  (3,
#   '0.016*"bank" + 0.011*"reform" + 0.010*"central" + 0.010*"see" + '
#   '0.009*"structural" + 0.009*"inflation" + 0.008*"effect" + 0.008*"country" + '
#   '0.008*"ecb" + 0.008*"price"'),
#  (4,
#   '0.011*"inflation" + 0.009*"bank" + 0.009*"second" + 0.009*"market" + '
#   '0.008*"thats" + 0.008*"think" + 0.007*"programme" + 0.007*"answer" + '
#   '0.007*"expectation" + 0.006*"certainly"')]
# [(0,
#   '0.009*"development" + 0.009*"growth" + 0.008*"year" + 0.008*"price" + '
#   '0.007*"exchange" + 0.007*"area" + 0.006*"may" + 0.006*"today" + '
#   '0.006*"course" + 0.006*"european"'),
#  (1,
#   '0.011*"price" + 0.010*"stability" + 0.010*"regard" + 0.010*"market" + '
#   '0.008*"level" + 0.008*"important" + 0.007*"council" + 0.007*"growth" + '
#   '0.007*"economy" + 0.007*"see"'),
#  (2,
#   '0.018*"decision" + 0.017*"government" + 0.017*"measure" + 0.011*"country" + '
#   '0.009*"operation" + 0.009*"nonstandard" + 0.008*"bank" + 0.008*"programme" '
#   '+ 0.007*"decided" + 0.007*"case"'),
#  (3,
#   '0.011*"bank" + 0.011*"think" + 0.009*"country" + 0.008*"area" + '
#   '0.008*"second" + 0.008*"ecb" + 0.008*"market" + 0.008*"point" + '
#   '0.007*"actually" + 0.006*"so"'),
#  (4,
#   '0.000*"price" + 0.000*"market" + 0.000*"bank" + 0.000*"year" + '
#   '0.000*"council" + 0.000*"inflation" + 0.000*"governing" + 0.000*"risk" + '
#   '0.000*"area" + 0.000*"course"'),
#  (5,
#   '0.033*"tender" + 0.010*"fixed" + 0.009*"minimum" + 0.006*"bid" + '
#   '0.006*"variable" + 0.004*"connection" + 0.003*"player" + 0.003*"loose" + '
#   '0.003*"extra" + 0.003*"allocation"'),
#  (6,
#   '0.000*"council" + 0.000*"growth" + 0.000*"governing" + 0.000*"decision" + '
#   '0.000*"market" + 0.000*"price" + 0.000*"know" + 0.000*"economy" + '
#   '0.000*"see" + 0.000*"regard"'),
#  (7,
#   '0.011*"inflation" + 0.011*"bank" + 0.008*"second" + 0.008*"market" + '
#   '0.007*"think" + 0.007*"thats" + 0.006*"see" + 0.006*"answer" + '
#   '0.006*"price" + 0.006*"programme"'),
#  (8,
#   '0.008*"burden" + 0.004*"income" + 0.004*"habit" + 0.004*"eur" + '
#   '0.003*"loss" + 0.003*"luxembourg" + 0.001*"apparent" + 0.001*"threaten" + '
#   '0.001*"avoided" + 0.001*"eventual"'),
#  (9,
#   '0.026*"valuation" + 0.010*"suitable" + 0.004*"unusual" + 0.003*"refrain" + '
#   '0.002*"differing" + 0.002*"justifies" + 0.002*"affair" + 0.001*"closest" + '
#   '0.001*"definite" + 0.001*"guideline"')]
# [(0,
#   '0.019*"bank" + 0.014*"central" + 0.012*"reform" + 0.011*"structural" + '
#   '0.010*"see" + 0.010*"effect" + 0.009*"ecb" + 0.009*"interest" + '
#   '0.008*"country" + 0.008*"price"'),
#  (1,
#   '0.016*"price" + 0.013*"stability" + 0.012*"regard" + 0.011*"level" + '
#   '0.010*"market" + 0.010*"decision" + 0.009*"economy" + 0.009*"important" + '
#   '0.008*"inflation" + 0.007*"growth"'),
#  (2,
#   '0.043*"error" + 0.021*"merely" + 0.020*"lively" + 0.016*"double" + '
#   '0.007*"human" + 0.006*"processed" + 0.006*"neglect" + 0.004*"handle" + '
#   '0.003*"enormously" + 0.003*"benign"'),
#  (3,
#   '0.018*"bank" + 0.015*"country" + 0.014*"think" + 0.014*"credit" + '
#   '0.013*"area" + 0.012*"so" + 0.012*"actually" + 0.010*"ecb" + '
#   '0.009*"government" + 0.009*"see"'),
#  (4,
#   '0.000*"price" + 0.000*"market" + 0.000*"year" + 0.000*"council" + '
#   '0.000*"growth" + 0.000*"course" + 0.000*"risk" + 0.000*"regard" + '
#   '0.000*"know" + 0.000*"inflation"'),
#  (5,
#   '0.000*"price" + 0.000*"bank" + 0.000*"see" + 0.000*"area" + '
#   '0.000*"inflation" + 0.000*"growth" + 0.000*"market" + 0.000*"risk" + '
#   '0.000*"year" + 0.000*"ive"'),
#  (6,
#   '0.000*"growth" + 0.000*"council" + 0.000*"price" + 0.000*"know" + '
#   '0.000*"market" + 0.000*"governing" + 0.000*"stability" + 0.000*"regard" + '
#   '0.000*"year" + 0.000*"economy"'),
#  (7,
#   '0.015*"bank" + 0.010*"inflation" + 0.009*"think" + 0.009*"expectation" + '
#   '0.008*"thats" + 0.007*"second" + 0.007*"year" + 0.007*"certainly" + '
#   '0.007*"answer" + 0.006*"market"'),
#  (8,
#   '0.000*"market" + 0.000*"price" + 0.000*"stability" + 0.000*"regard" + '
#   '0.000*"today" + 0.000*"area" + 0.000*"year" + 0.000*"growth" + '
#   '0.000*"country" + 0.000*"already"'),
#  (9,
#   '0.029*"weekly" + 0.000*"market" + 0.000*"bank" + 0.000*"year" + '
#   '0.000*"area" + 0.000*"price" + 0.000*"attractive" + 0.000*"think" + '
#   '0.000*"stability" + 0.000*"point"'),
#  (10,
#   '0.000*"price" + 0.000*"stability" + 0.000*"growth" + 0.000*"market" + '
#   '0.000*"area" + 0.000*"know" + 0.000*"take" + 0.000*"council" + '
#   '0.000*"level" + 0.000*"see"'),
#  (11,
#   '0.000*"level" + 0.000*"bank" + 0.000*"price" + 0.000*"market" + '
#   '0.000*"council" + 0.000*"growth" + 0.000*"decision" + 0.000*"governing" + '
#   '0.000*"think" + 0.000*"course"'),
#  (12,
#   '0.000*"growth" + 0.000*"decision" + 0.000*"area" + 0.000*"stability" + '
#   '0.000*"council" + 0.000*"see" + 0.000*"price" + 0.000*"take" + 0.000*"year" '
#   '+ 0.000*"governing"'),
#  (13,
#   '0.000*"price" + 0.000*"year" + 0.000*"growth" + 0.000*"governing" + '
#   '0.000*"know" + 0.000*"stability" + 0.000*"council" + 0.000*"area" + '
#   '0.000*"see" + 0.000*"level"'),
#  (14,
#   '0.012*"inflation" + 0.012*"market" + 0.011*"second" + 0.011*"programme" + '
#   '0.009*"interest" + 0.009*"reform" + 0.009*"see" + 0.008*"governing" + '
#   '0.007*"council" + 0.007*"thats"'),
#  (15,
#   '0.000*"price" + 0.000*"stability" + 0.000*"council" + 0.000*"growth" + '
#   '0.000*"area" + 0.000*"governing" + 0.000*"know" + 0.000*"market" + '
#   '0.000*"see" + 0.000*"level"'),
#  (16,
#   '0.000*"growth" + 0.000*"price" + 0.000*"market" + 0.000*"know" + '
#   '0.000*"regard" + 0.000*"stability" + 0.000*"area" + 0.000*"course" + '
#   '0.000*"year" + 0.000*"level"'),
#  (17,
#   '0.010*"council" + 0.009*"market" + 0.009*"regard" + 0.009*"governing" + '
#   '0.008*"stability" + 0.007*"price" + 0.007*"decision" + 0.007*"risk" + '
#   '0.007*"see" + 0.006*"know"'),
#  (18,
#   '0.000*"price" + 0.000*"see" + 0.000*"decision" + 0.000*"regard" + '
#   '0.000*"level" + 0.000*"central" + 0.000*"area" + 0.000*"bank" + '
#   '0.000*"stability" + 0.000*"council"'),
#  (19,
#   '0.008*"year" + 0.008*"development" + 0.008*"exchange" + 0.007*"price" + '
#   '0.007*"think" + 0.007*"area" + 0.007*"may" + 0.006*"growth" + 0.006*"today" '
#   '+ 0.006*"country"')]
# [(16,
#   '0.000*"growth" + 0.000*"price" + 0.000*"market" + 0.000*"know" + '
#   '0.000*"area" + 0.000*"stability" + 0.000*"course" + 0.000*"regard" + '
#   '0.000*"year" + 0.000*"central"'),
#  (39,
#   '0.000*"growth" + 0.000*"year" + 0.000*"see" + 0.000*"price" + '
#   '0.000*"development" + 0.000*"area" + 0.000*"level" + 0.000*"course" + '
#   '0.000*"take" + 0.000*"stability"'),
#  (30,
#   '0.000*"year" + 0.000*"growth" + 0.000*"area" + 0.000*"price" + '
#   '0.000*"market" + 0.000*"development" + 0.000*"governing" + 0.000*"council" '
#   '+ 0.000*"see" + 0.000*"course"'),
#  (13,
#   '0.000*"growth" + 0.000*"price" + 0.000*"governing" + 0.000*"know" + '
#   '0.000*"year" + 0.000*"stability" + 0.000*"council" + 0.000*"risk" + '
#   '0.000*"area" + 0.000*"level"'),
#  (23,
#   '0.000*"growth" + 0.000*"know" + 0.000*"stability" + 0.000*"price" + '
#   '0.000*"level" + 0.000*"area" + 0.000*"risk" + 0.000*"market" + '
#   '0.000*"governing" + 0.000*"regard"'),
#  (10,
#   '0.000*"price" + 0.000*"stability" + 0.000*"growth" + 0.000*"market" + '
#   '0.000*"take" + 0.000*"area" + 0.000*"council" + 0.000*"know" + '
#   '0.000*"decision" + 0.000*"already"'),
#  (36,
#   '0.000*"price" + 0.000*"growth" + 0.000*"know" + 0.000*"economy" + '
#   '0.000*"market" + 0.000*"level" + 0.000*"stability" + 0.000*"regard" + '
#   '0.000*"council" + 0.000*"area"'),
#  (31,
#   '0.000*"growth" + 0.000*"stability" + 0.000*"council" + 0.000*"price" + '
#   '0.000*"see" + 0.000*"regard" + 0.000*"area" + 0.000*"governing" + '
#   '0.000*"bank" + 0.000*"level"'),
#  (42,
#   '0.000*"growth" + 0.000*"area" + 0.000*"price" + 0.000*"council" + '
#   '0.000*"know" + 0.000*"year" + 0.000*"stability" + 0.000*"market" + '
#   '0.000*"important" + 0.000*"see"'),
#  (21,
#   '0.000*"level" + 0.000*"stability" + 0.000*"growth" + 0.000*"price" + '
#   '0.000*"see" + 0.000*"course" + 0.000*"inflation" + 0.000*"important" + '
#   '0.000*"know" + 0.000*"already"'),
#  (38,
#   '0.483*"eligible" + 0.000*"modality" + 0.000*"governing" + 0.000*"council" + '
#   '0.000*"market" + 0.000*"area" + 0.000*"bank" + 0.000*"decision" + '
#   '0.000*"stability" + 0.000*"point"'),
#  (0,
#   '0.384*"weve" + 0.096*"sustainability" + 0.052*"revise" + 0.049*"reaffirmed" '
#   '+ 0.047*"delay" + 0.044*"mass" + 0.027*"implied" + 0.026*"harmonised" + '
#   '0.023*"vulnerable" + 0.023*"detailed"'),
#  (1,
#   '0.016*"regard" + 0.015*"stability" + 0.014*"price" + 0.013*"market" + '
#   '0.012*"important" + 0.011*"level" + 0.011*"economy" + 0.009*"know" + '
#   '0.008*"again" + 0.008*"appropriate"'),
#  (37,
#   '0.300*"ive" + 0.168*"thats" + 0.164*"im" + 0.129*"whats" + 0.045*"systemic" '
#   '+ 0.030*"reading" + 0.024*"reveal" + 0.019*"nine" + 0.010*"smooth" + '
#   '0.006*"payment"'),
#  (44,
#   '0.014*"area" + 0.013*"think" + 0.013*"development" + 0.013*"may" + '
#   '0.012*"so" + 0.011*"country" + 0.011*"statement" + 0.010*"it" + '
#   '0.009*"exchange" + 0.009*"cannot"'),
#  (17,
#   '0.014*"european" + 0.013*"country" + 0.013*"government" + 0.011*"year" + '
#   '0.011*"council" + 0.009*"area" + 0.008*"central" + 0.008*"bank" + '
#   '0.008*"decision" + 0.008*"measure"'),
#  (28,
#   '0.010*"price" + 0.010*"risk" + 0.008*"decision" + 0.008*"market" + '
#   '0.008*"see" + 0.007*"level" + 0.007*"area" + 0.007*"stability" + '
#   '0.007*"growth" + 0.006*"regard"'),
#  (7,
#   '0.018*"bank" + 0.012*"year" + 0.008*"problem" + 0.008*"thats" + '
#   '0.008*"important" + 0.008*"think" + 0.008*"certainly" + 0.008*"inflation" + '
#   '0.007*"come" + 0.007*"lending"'),
#  (14,
#   '0.012*"bank" + 0.010*"inflation" + 0.010*"see" + 0.009*"second" + '
#   '0.008*"central" + 0.007*"reform" + 0.007*"ecb" + 0.007*"expectation" + '
#   '0.007*"growth" + 0.006*"structural"'),
#  (22,
#   '0.012*"inflation" + 0.011*"market" + 0.011*"second" + 0.009*"think" + '
#   '0.008*"interest" + 0.008*"programme" + 0.007*"price" + 0.007*"see" + '
#   '0.007*"reform" + 0.007*"bank"')]
# [(59,
#   '0.000*"development" + 0.000*"year" + 0.000*"exchange" + 0.000*"course" + '
#   '0.000*"uncertainty" + 0.000*"still" + 0.000*"price" + 0.000*"inflation" + '
#   '0.000*"area" + 0.000*"bank"'),
#  (30,
#   '0.000*"year" + 0.000*"market" + 0.000*"growth" + 0.000*"price" + '
#   '0.000*"area" + 0.000*"governing" + 0.000*"see" + 0.000*"council" + '
#   '0.000*"development" + 0.000*"risk"'),
#  (55,
#   '0.000*"european" + 0.000*"council" + 0.000*"governing" + 0.000*"stability" '
#   '+ 0.000*"risk" + 0.000*"ecb" + 0.000*"price" + 0.000*"bank" + '
#   '0.000*"growth" + 0.000*"decision"'),
#  (68,
#   '0.000*"growth" + 0.000*"country" + 0.000*"year" + 0.000*"council" + '
#   '0.000*"future" + 0.000*"course" + 0.000*"development" + 0.000*"much" + '
#   '0.000*"think" + 0.000*"cannot"'),
#  (39,
#   '0.000*"development" + 0.000*"year" + 0.000*"area" + 0.000*"take" + '
#   '0.000*"new" + 0.000*"price" + 0.000*"course" + 0.000*"see" + 0.000*"growth" '
#   '+ 0.000*"last"'),
#  (10,
#   '0.000*"growth" + 0.000*"market" + 0.000*"area" + 0.000*"price" + '
#   '0.000*"stability" + 0.000*"central" + 0.000*"decision" + 0.000*"bank" + '
#   '0.000*"council" + 0.000*"take"'),
#  (71,
#   '0.000*"growth" + 0.000*"governing" + 0.000*"price" + 0.000*"know" + '
#   '0.000*"council" + 0.000*"stability" + 0.000*"year" + 0.000*"area" + '
#   '0.000*"level" + 0.000*"important"'),
#  (95,
#   '0.000*"council" + 0.000*"growth" + 0.000*"decision" + 0.000*"see" + '
#   '0.000*"stability" + 0.000*"area" + 0.000*"governing" + 0.000*"market" + '
#   '0.000*"price" + 0.000*"last"'),
#  (70,
#   '0.000*"know" + 0.000*"price" + 0.000*"see" + 0.000*"growth" + 0.000*"year" '
#   '+ 0.000*"market" + 0.000*"last" + 0.000*"economy" + 0.000*"area" + '
#   '0.000*"stability"'),
#  (82,
#   '0.000*"level" + 0.000*"growth" + 0.000*"council" + 0.000*"area" + '
#   '0.000*"stability" + 0.000*"know" + 0.000*"today" + 0.000*"market" + '
#   '0.000*"situation" + 0.000*"governing"'),
#  (28,
#   '0.012*"risk" + 0.012*"price" + 0.010*"market" + 0.009*"level" + 0.008*"see" '
#   '+ 0.008*"area" + 0.008*"stability" + 0.008*"regard" + 0.008*"last" + '
#   '0.007*"decision"'),
#  (14,
#   '0.027*"bank" + 0.026*"decided" + 0.021*"measure" + 0.020*"central" + '
#   '0.016*"national" + 0.016*"ecb" + 0.015*"programme" + 0.014*"decision" + '
#   '0.013*"second" + 0.012*"see"'),
#  (66,
#   '0.025*"development" + 0.012*"year" + 0.011*"test" + 0.011*"statement" + '
#   '0.011*"economic" + 0.010*"impact" + 0.010*"come" + 0.009*"future" + '
#   '0.009*"today" + 0.009*"it"'),
#  (93,
#   '0.057*"thats" + 0.037*"inflation" + 0.034*"weve" + 0.024*"programme" + '
#   '0.015*"im" + 0.015*"expectation" + 0.015*"lending" + 0.014*"answer" + '
#   '0.014*"ive" + 0.014*"purchase"'),
#  (50,
#   '0.013*"area" + 0.011*"ecb" + 0.010*"so" + 0.009*"country" + 0.009*"cannot" '
#   '+ 0.009*"european" + 0.008*"council" + 0.008*"and" + 0.008*"exchange" + '
#   '0.008*"think"'),
#  (77,
#   '0.015*"point" + 0.015*"answer" + 0.012*"second" + 0.011*"market" + '
#   '0.011*"place" + 0.011*"outlook" + 0.011*"actually" + 0.011*"sense" + '
#   '0.010*"discussed" + 0.010*"committee"'),
#  (84,
#   '0.017*"bank" + 0.014*"reform" + 0.014*"structural" + 0.012*"effect" + '
#   '0.012*"central" + 0.012*"country" + 0.011*"see" + 0.011*"price" + '
#   '0.011*"inflation" + 0.010*"interest"'),
#  (67,
#   '0.024*"bank" + 0.014*"year" + 0.011*"think" + 0.009*"problem" + '
#   '0.009*"important" + 0.008*"measure" + 0.008*"especially" + 0.008*"come" + '
#   '0.008*"recovery" + 0.007*"certainly"'),
#  (57,
#   '0.018*"think" + 0.017*"expectation" + 0.015*"interest" + 0.014*"let" + '
#   '0.012*"bank" + 0.012*"second" + 0.010*"governing" + 0.010*"large" + '
#   '0.010*"inflation" + 0.010*"council"'),
#  (22,
#   '0.017*"market" + 0.010*"second" + 0.010*"financial" + 0.010*"price" + '
#   '0.009*"country" + 0.008*"reform" + 0.008*"certainly" + 0.007*"inflation" + '
#   '0.007*"important" + 0.007*"know"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity5: ', lda_model5.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity10: ', lda_model10.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity20: ', lda_model20.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity50: ', lda_model50.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity100: ', lda_model100.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100: ', coherence_lda)


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence ScoreUMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100UMass: ', coherence_lda)
# Out:
# Perplexity:  -7.262292074299817
#
# Perplexity5:  -7.11388539148857
#
# Perplexity10:  -7.100493830073871
#
# Perplexity20:  -7.150284974314493
#
# Perplexity50:  -7.200846268935287
#
# Perplexity100:  -8.946627742533568
#
# Coherence Score:  0.24515066809007338
#
# Coherence Score5:  0.25417422041382465
#
# Coherence Score10:  0.35496120855019503
#
# Coherence Score20:  0.2836756065057183
#
# Coherence Score50:  0.2630562011141103
#
# Coherence Score100:  0.2652568470522732
#
# Coherence ScoreUMass:  -0.10007388897901281
#
# Coherence Score5UMass:  -0.1712659905074953
#
# Coherence Score10UMass:  -2.3594292824869596
#
# Coherence Score20UMass:  -0.7516272793416002
#
# Coherence Score50UMass:  -0.31571633242354885
#
# Coherence Score100UMass:  -0.3251036416057549
