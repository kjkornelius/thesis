# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['qa']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(8371 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# filter words that occur in more than 90% of documents
id2word.filter_extremes(no_above = 0.990)
print(id2word)
# Out:
# Dictionary(3465 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=1, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
lda_model5 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model10 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model20 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model50 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=50, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model100 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=100, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\models\ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
# Print the Keyword in the 1 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.010*"policy" + 0.008*"bank" + 0.008*"monetary" + 0.008*"inflation" + '
#   '0.008*"market" + 0.007*"price" + 0.006*"second" + 0.006*"see" + '
#   '0.006*"think" + 0.005*"year"')]

# %%
# Print the Keyword in the 5 topics
pprint(lda_model5.print_topics())
doc_lda = lda_model5[corpus]

# Print the Keyword in the 10 topics
pprint(lda_model10.print_topics())
doc_lda = lda_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lda_model20.print_topics())
doc_lda = lda_model20[corpus]

# Print the Keyword in the 50 topics
pprint(lda_model50.print_topics())
doc_lda = lda_model50[corpus]

# Print the Keyword in the 100 topics
pprint(lda_model100.print_topics())
doc_lda = lda_model100[corpus]
# Out:
# [(0,
#   '0.011*"price" + 0.010*"regard" + 0.010*"stability" + 0.009*"market" + '
#   '0.008*"decision" + 0.008*"level" + 0.008*"council" + 0.007*"growth" + '
#   '0.007*"important" + 0.007*"economy"'),
#  (1,
#   '0.011*"bank" + 0.008*"think" + 0.008*"policy" + 0.008*"country" + '
#   '0.008*"market" + 0.008*"second" + 0.007*"measure" + 0.007*"area" + '
#   '0.007*"point" + 0.006*"ecb"'),
#  (2,
#   '0.014*"policy" + 0.011*"monetary" + 0.010*"inflation" + 0.010*"bank" + '
#   '0.008*"second" + 0.007*"market" + 0.007*"thats" + 0.007*"think" + '
#   '0.006*"see" + 0.006*"answer"'),
#  (3,
#   '0.008*"year" + 0.007*"well" + 0.007*"growth" + 0.007*"development" + '
#   '0.007*"policy" + 0.007*"price" + 0.007*"monetary" + 0.006*"exchange" + '
#   '0.006*"area" + 0.005*"course"'),
#  (4,
#   '0.007*"tender" + 0.003*"interview" + 0.003*"variable" + 0.002*"openness" + '
#   '0.002*"fixed" + 0.002*"error" + 0.002*"minimum" + 0.002*"instruction" + '
#   '0.002*"signalling" + 0.001*"inflow"')]
# [(0,
#   '0.011*"price" + 0.010*"regard" + 0.010*"stability" + 0.010*"market" + '
#   '0.008*"level" + 0.008*"decision" + 0.007*"council" + 0.007*"important" + '
#   '0.007*"economy" + 0.007*"see"'),
#  (1,
#   '0.035*"operation" + 0.034*"measure" + 0.023*"nonstandard" + 0.017*"billion" '
#   '+ 0.017*"collateral" + 0.016*"liquidity" + 0.016*"bank" + 0.016*"money" + '
#   '0.015*"decision" + 0.015*"credit"'),
#  (2,
#   '0.014*"policy" + 0.014*"bank" + 0.012*"monetary" + 0.011*"inflation" + '
#   '0.011*"interest" + 0.010*"think" + 0.009*"see" + 0.008*"second" + '
#   '0.007*"price" + 0.007*"reform"'),
#  (3,
#   '0.019*"supervisor" + 0.013*"council" + 0.013*"banca" + 0.013*"draft" + '
#   '0.013*"italia" + 0.011*"move" + 0.010*"governing" + 0.009*"law" + '
#   '0.008*"dialogue" + 0.008*"article"'),
#  (4,
#   '0.018*"error" + 0.012*"indepth" + 0.010*"rotation" + 0.009*"enabling" + '
#   '0.008*"seventeen" + 0.007*"alternative" + 0.006*"arrive" + '
#   '0.005*"performed" + 0.005*"projected" + 0.005*"registered"'),
#  (5,
#   '0.000*"price" + 0.000*"market" + 0.000*"bank" + 0.000*"growth" + '
#   '0.000*"level" + 0.000*"know" + 0.000*"policy" + 0.000*"council" + '
#   '0.000*"well" + 0.000*"inflation"'),
#  (6,
#   '0.013*"development" + 0.011*"year" + 0.010*"well" + 0.009*"exchange" + '
#   '0.008*"area" + 0.008*"price" + 0.008*"monetary" + 0.008*"growth" + '
#   '0.008*"today" + 0.007*"may"'),
#  (7,
#   '0.013*"policy" + 0.010*"monetary" + 0.010*"market" + 0.010*"inflation" + '
#   '0.008*"bank" + 0.008*"second" + 0.007*"thats" + 0.007*"answer" + '
#   '0.007*"certainly" + 0.006*"programme"'),
#  (8,
#   '0.013*"country" + 0.010*"government" + 0.010*"ecb" + 0.009*"area" + '
#   '0.009*"think" + 0.008*"so" + 0.008*"bank" + 0.007*"european" + '
#   '0.006*"point" + 0.006*"decision"'),
#  (9,
#   '0.008*"intense" + 0.005*"subprime" + 0.004*"translation" + 0.001*"swiss" + '
#   '0.000*"hundred" + 0.000*"justifies" + 0.000*"liberalisation" + '
#   '0.000*"intensification" + 0.000*"nonstandard" + 0.000*"suitable"')]
# [(0,
#   '0.017*"confidence" + 0.016*"growth" + 0.015*"know" + 0.013*"europe" + '
#   '0.012*"responsibility" + 0.012*"currency" + 0.010*"stability" + '
#   '0.009*"important" + 0.009*"market" + 0.008*"course"'),
#  (1,
#   '0.000*"price" + 0.000*"year" + 0.000*"level" + 0.000*"stability" + '
#   '0.000*"area" + 0.000*"growth" + 0.000*"policy" + 0.000*"decision" + '
#   '0.000*"today" + 0.000*"risk"'),
#  (2,
#   '0.012*"policy" + 0.011*"inflation" + 0.010*"monetary" + 0.010*"reform" + '
#   '0.009*"interest" + 0.009*"bank" + 0.008*"market" + 0.008*"see" + '
#   '0.008*"second" + 0.008*"programme"'),
#  (3,
#   '0.000*"price" + 0.000*"growth" + 0.000*"council" + 0.000*"market" + '
#   '0.000*"policy" + 0.000*"year" + 0.000*"stability" + 0.000*"country" + '
#   '0.000*"see" + 0.000*"take"'),
#  (4,
#   '0.000*"growth" + 0.000*"price" + 0.000*"stability" + 0.000*"monetary" + '
#   '0.000*"regard" + 0.000*"council" + 0.000*"market" + 0.000*"see" + '
#   '0.000*"important" + 0.000*"level"'),
#  (5,
#   '0.000*"price" + 0.000*"growth" + 0.000*"market" + 0.000*"level" + '
#   '0.000*"know" + 0.000*"well" + 0.000*"council" + 0.000*"policy" + '
#   '0.000*"stability" + 0.000*"year"'),
#  (6,
#   '0.000*"policy" + 0.000*"transmission" + 0.000*"decision" + 0.000*"price" + '
#   '0.000*"year" + 0.000*"take" + 0.000*"market" + 0.000*"course" + 0.000*"see" '
#   '+ 0.000*"area"'),
#  (7,
#   '0.015*"bank" + 0.013*"think" + 0.011*"ecb" + 0.011*"country" + 0.010*"area" '
#   '+ 0.010*"point" + 0.009*"policy" + 0.009*"actually" + 0.009*"second" + '
#   '0.008*"so"'),
#  (8,
#   '0.000*"market" + 0.000*"stability" + 0.000*"growth" + 0.000*"decision" + '
#   '0.000*"price" + 0.000*"regard" + 0.000*"economy" + 0.000*"know" + '
#   '0.000*"think" + 0.000*"bank"'),
#  (9,
#   '0.000*"price" + 0.000*"growth" + 0.000*"know" + 0.000*"see" + '
#   '0.000*"market" + 0.000*"level" + 0.000*"stability" + 0.000*"regard" + '
#   '0.000*"council" + 0.000*"economy"'),
#  (10,
#   '0.000*"stability" + 0.000*"growth" + 0.000*"price" + 0.000*"know" + '
#   '0.000*"regard" + 0.000*"see" + 0.000*"decision" + 0.000*"market" + '
#   '0.000*"think" + 0.000*"level"'),
#  (11,
#   '0.011*"price" + 0.010*"regard" + 0.010*"stability" + 0.010*"market" + '
#   '0.008*"decision" + 0.008*"level" + 0.008*"council" + 0.007*"important" + '
#   '0.007*"see" + 0.007*"economy"'),
#  (12,
#   '0.000*"growth" + 0.000*"level" + 0.000*"council" + 0.000*"price" + '
#   '0.000*"area" + 0.000*"important" + 0.000*"market" + 0.000*"see" + '
#   '0.000*"regard" + 0.000*"course"'),
#  (13,
#   '0.000*"price" + 0.000*"stability" + 0.000*"bank" + 0.000*"country" + '
#   '0.000*"market" + 0.000*"area" + 0.000*"monetary" + 0.000*"regard" + '
#   '0.000*"think" + 0.000*"decision"'),
#  (14,
#   '0.015*"policy" + 0.012*"bank" + 0.010*"monetary" + 0.010*"inflation" + '
#   '0.008*"thats" + 0.008*"expectation" + 0.008*"second" + 0.007*"think" + '
#   '0.007*"answer" + 0.007*"year"'),
#  (15,
#   '0.009*"year" + 0.008*"price" + 0.007*"well" + 0.007*"growth" + 0.007*"area" '
#   '+ 0.007*"development" + 0.006*"exchange" + 0.006*"policy" + 0.006*"today" + '
#   '0.006*"country"'),
#  (16,
#   '0.040*"compact" + 0.026*"tax" + 0.023*"tender" + 0.019*"expenditure" + '
#   '0.018*"treaty" + 0.017*"similarity" + 0.014*"contraction" + 0.012*"efsf" + '
#   '0.012*"reserve" + 0.010*"infrastructure"'),
#  (17,
#   '0.038*"measure" + 0.036*"government" + 0.026*"ecb" + 0.025*"european" + '
#   '0.025*"decision" + 0.022*"nonstandard" + 0.021*"eonia" + 0.021*"greece" + '
#   '0.019*"programme" + 0.018*"head"'),
#  (18,
#   '0.000*"see" + 0.000*"council" + 0.000*"price" + 0.000*"know" + 0.000*"well" '
#   '+ 0.000*"area" + 0.000*"level" + 0.000*"stability" + 0.000*"ecb" + '
#   '0.000*"growth"'),
#  (19,
#   '0.000*"council" + 0.000*"governing" + 0.000*"market" + 0.000*"already" + '
#   '0.000*"level" + 0.000*"decision" + 0.000*"price" + 0.000*"course" + '
#   '0.000*"regard" + 0.000*"monetary"')]
# [(49,
#   '0.000*"see" + 0.000*"risk" + 0.000*"price" + 0.000*"country" + '
#   '0.000*"level" + 0.000*"growth" + 0.000*"year" + 0.000*"area" + '
#   '0.000*"regard" + 0.000*"economy"'),
#  (31,
#   '0.000*"see" + 0.000*"economy" + 0.000*"area" + 0.000*"country" + '
#   '0.000*"monetary" + 0.000*"price" + 0.000*"level" + 0.000*"risk" + '
#   '0.000*"stability" + 0.000*"know"'),
#  (47,
#   '0.000*"market" + 0.000*"price" + 0.000*"council" + 0.000*"important" + '
#   '0.000*"european" + 0.000*"stability" + 0.000*"governing" + 0.000*"know" + '
#   '0.000*"growth" + 0.000*"bank"'),
#  (21,
#   '0.000*"price" + 0.000*"know" + 0.000*"stability" + 0.000*"growth" + '
#   '0.000*"bank" + 0.000*"level" + 0.000*"governing" + 0.000*"central" + '
#   '0.000*"market" + 0.000*"monetary"'),
#  (26,
#   '0.000*"price" + 0.000*"growth" + 0.000*"know" + 0.000*"stability" + '
#   '0.000*"see" + 0.000*"monetary" + 0.000*"market" + 0.000*"area" + '
#   '0.000*"regard" + 0.000*"policy"'),
#  (30,
#   '0.000*"growth" + 0.000*"stability" + 0.000*"see" + 0.000*"know" + '
#   '0.000*"risk" + 0.000*"well" + 0.000*"country" + 0.000*"area" + '
#   '0.000*"market" + 0.000*"price"'),
#  (19,
#   '0.000*"council" + 0.000*"governing" + 0.000*"market" + 0.000*"level" + '
#   '0.000*"already" + 0.000*"price" + 0.000*"course" + 0.000*"monetary" + '
#   '0.000*"policy" + 0.000*"take"'),
#  (36,
#   '0.000*"stability" + 0.000*"price" + 0.000*"risk" + 0.000*"area" + '
#   '0.000*"know" + 0.000*"monetary" + 0.000*"level" + 0.000*"council" + '
#   '0.000*"take" + 0.000*"market"'),
#  (9,
#   '0.000*"price" + 0.000*"growth" + 0.000*"know" + 0.000*"level" + 0.000*"see" '
#   '+ 0.000*"market" + 0.000*"stability" + 0.000*"economy" + 0.000*"regard" + '
#   '0.000*"area"'),
#  (25,
#   '0.000*"growth" + 0.000*"stability" + 0.000*"price" + 0.000*"regard" + '
#   '0.000*"market" + 0.000*"year" + 0.000*"council" + 0.000*"see" + '
#   '0.000*"level" + 0.000*"inflation"'),
#  (32,
#   '0.126*"advanced" + 0.058*"vice" + 0.050*"indepth" + 0.045*"eventually" + '
#   '0.034*"versa" + 0.028*"strange" + 0.017*"coin" + 0.011*"adhere" + '
#   '0.010*"item" + 0.000*"enhanced"'),
#  (16,
#   '0.547*"package" + 0.098*"harmonised" + 0.000*"joined" + 0.000*"central" + '
#   '0.000*"price" + 0.000*"growth" + 0.000*"interest" + 0.000*"bank" + '
#   '0.000*"structural" + 0.000*"see"'),
#  (24,
#   '0.060*"country" + 0.044*"funding" + 0.043*"ab" + 0.038*"guidance" + '
#   '0.036*"consolidation" + 0.036*"forward" + 0.035*"so" + 0.028*"sign" + '
#   '0.027*"omt" + 0.023*"improvement"'),
#  (15,
#   '0.011*"area" + 0.010*"development" + 0.009*"european" + 0.009*"decision" + '
#   '0.009*"market" + 0.008*"government" + 0.008*"year" + 0.008*"exchange" + '
#   '0.007*"stability" + 0.007*"state"'),
#  (46,
#   '0.012*"regard" + 0.011*"stability" + 0.011*"price" + 0.010*"market" + '
#   '0.009*"level" + 0.008*"decision" + 0.008*"important" + 0.008*"council" + '
#   '0.008*"economy" + 0.007*"see"'),
#  (11,
#   '0.011*"area" + 0.009*"price" + 0.007*"monetary" + 0.007*"so" + '
#   '0.007*"council" + 0.006*"think" + 0.006*"ecb" + 0.006*"policy" + '
#   '0.006*"today" + 0.005*"risk"'),
#  (14,
#   '0.020*"policy" + 0.015*"monetary" + 0.014*"inflation" + 0.014*"expectation" '
#   '+ 0.011*"think" + 0.011*"second" + 0.009*"thats" + 0.009*"programme" + '
#   '0.009*"bond" + 0.009*"let"'),
#  (20,
#   '0.018*"market" + 0.013*"reform" + 0.011*"weve" + 0.010*"second" + '
#   '0.009*"programme" + 0.009*"inflation" + 0.009*"country" + 0.008*"policy" + '
#   '0.008*"monetary" + 0.008*"price"'),
#  (41,
#   '0.016*"bank" + 0.014*"policy" + 0.010*"year" + 0.009*"inflation" + '
#   '0.008*"monetary" + 0.008*"think" + 0.008*"certainly" + 0.007*"market" + '
#   '0.007*"important" + 0.007*"thats"'),
#  (39,
#   '0.018*"bank" + 0.011*"central" + 0.011*"policy" + 0.010*"see" + '
#   '0.009*"monetary" + 0.008*"structural" + 0.008*"reform" + 0.008*"ecb" + '
#   '0.008*"effect" + 0.008*"interest"')]
# [(73,
#   '0.000*"course" + 0.000*"well" + 0.000*"monetary" + 0.000*"council" + '
#   '0.000*"member" + 0.000*"still" + 0.000*"governing" + 0.000*"year" + '
#   '0.000*"way" + 0.000*"end"'),
#  (49,
#   '0.000*"see" + 0.000*"development" + 0.000*"policy" + 0.000*"country" + '
#   '0.000*"risk" + 0.000*"area" + 0.000*"level" + 0.000*"today" + 0.000*"year" '
#   '+ 0.000*"monetary"'),
#  (80,
#   '0.000*"year" + 0.000*"growth" + 0.000*"monetary" + 0.000*"figure" + '
#   '0.000*"country" + 0.000*"see" + 0.000*"it" + 0.000*"stability" + '
#   '0.000*"already" + 0.000*"next"'),
#  (82,
#   '0.000*"price" + 0.000*"level" + 0.000*"market" + 0.000*"stability" + '
#   '0.000*"course" + 0.000*"council" + 0.000*"growth" + 0.000*"know" + '
#   '0.000*"regard" + 0.000*"governing"'),
#  (31,
#   '0.000*"see" + 0.000*"economy" + 0.000*"level" + 0.000*"area" + '
#   '0.000*"country" + 0.000*"regard" + 0.000*"important" + 0.000*"price" + '
#   '0.000*"monetary" + 0.000*"stability"'),
#  (53,
#   '0.000*"growth" + 0.000*"price" + 0.000*"risk" + 0.000*"stability" + '
#   '0.000*"market" + 0.000*"see" + 0.000*"year" + 0.000*"important" + '
#   '0.000*"council" + 0.000*"governing"'),
#  (65,
#   '0.000*"policy" + 0.000*"year" + 0.000*"monetary" + 0.000*"take" + '
#   '0.000*"well" + 0.000*"price" + 0.000*"see" + 0.000*"growth" + '
#   '0.000*"inflation" + 0.000*"already"'),
#  (71,
#   '0.000*"growth" + 0.000*"stability" + 0.000*"know" + 0.000*"council" + '
#   '0.000*"policy" + 0.000*"confidence" + 0.000*"regard" + 0.000*"economy" + '
#   '0.000*"level" + 0.000*"governing"'),
#  (54,
#   '0.000*"economy" + 0.000*"growth" + 0.000*"price" + 0.000*"level" + '
#   '0.000*"important" + 0.000*"year" + 0.000*"regard" + 0.000*"stability" + '
#   '0.000*"risk" + 0.000*"analysis"'),
#  (47,
#   '0.000*"market" + 0.000*"price" + 0.000*"european" + 0.000*"year" + '
#   '0.000*"think" + 0.000*"area" + 0.000*"council" + 0.000*"important" + '
#   '0.000*"stability" + 0.000*"today"'),
#  (46,
#   '0.017*"regard" + 0.016*"price" + 0.015*"market" + 0.014*"stability" + '
#   '0.012*"situation" + 0.011*"risk" + 0.011*"important" + 0.009*"inflation" + '
#   '0.009*"term" + 0.009*"number"'),
#  (50,
#   '0.020*"development" + 0.019*"area" + 0.018*"cannot" + 0.017*"so" + '
#   '0.016*"exchange" + 0.015*"may" + 0.015*"today" + 0.014*"and" + '
#   '0.014*"statement" + 0.012*"assessment"'),
#  (63,
#   '0.011*"stability" + 0.011*"regard" + 0.010*"price" + 0.010*"growth" + '
#   '0.010*"decision" + 0.009*"level" + 0.009*"council" + 0.009*"area" + '
#   '0.009*"market" + 0.008*"economy"'),
#  (14,
#   '0.081*"ive" + 0.060*"transmission" + 0.047*"repo" + 0.029*"facility" + '
#   '0.029*"accommodation" + 0.023*"deposit" + 0.022*"becomes" + 0.022*"marked" '
#   '+ 0.020*"easing" + 0.020*"buy"'),
#  (62,
#   '0.019*"reform" + 0.018*"effect" + 0.014*"monetary" + 0.014*"policy" + '
#   '0.013*"inflation" + 0.013*"objective" + 0.013*"structural" + 0.012*"see" + '
#   '0.012*"bank" + 0.011*"price"'),
#  (57,
#   '0.010*"risk" + 0.009*"credit" + 0.009*"package" + 0.009*"price" + '
#   '0.009*"inflation" + 0.008*"market" + 0.008*"council" + 0.008*"area" + '
#   '0.007*"collateral" + 0.007*"bank"'),
#  (77,
#   '0.025*"policy" + 0.020*"inflation" + 0.019*"monetary" + 0.016*"think" + '
#   '0.016*"expectation" + 0.016*"thats" + 0.013*"let" + 0.012*"interest" + '
#   '0.011*"lending" + 0.011*"bank"'),
#  (96,
#   '0.017*"bank" + 0.013*"central" + 0.011*"ecb" + 0.010*"measure" + '
#   '0.009*"country" + 0.008*"see" + 0.008*"policy" + 0.008*"national" + '
#   '0.008*"structural" + 0.008*"european"'),
#  (20,
#   '0.014*"market" + 0.012*"policy" + 0.011*"second" + 0.011*"inflation" + '
#   '0.010*"monetary" + 0.009*"programme" + 0.009*"point" + 0.009*"thats" + '
#   '0.008*"answer" + 0.008*"reform"'),
#  (39,
#   '0.018*"bank" + 0.013*"year" + 0.011*"policy" + 0.009*"think" + 0.007*"come" '
#   '+ 0.007*"market" + 0.007*"certainly" + 0.007*"important" + 0.006*"problem" '
#   '+ 0.006*"measure"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity5: ', lda_model5.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity10: ', lda_model10.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity20: ', lda_model20.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity50: ', lda_model50.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity100: ', lda_model100.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100: ', coherence_lda)


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence ScoreUMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100UMass: ', coherence_lda)
# Out:
# Perplexity:  -7.245412794854428
#
# Perplexity5:  -7.073451451433048
#
# Perplexity10:  -7.118632663055676
#
# Perplexity20:  -7.127219241778509
#
# Perplexity50:  -7.1894188401074635
#
# Perplexity100:  -8.887823444966116
#
# Coherence Score:  0.24732239925239763
#
# Coherence Score5:  0.3074481075174464
#
# Coherence Score10:  0.37214270926987625
#
# Coherence Score20:  0.28097286475494543
#
# Coherence Score50:  0.2685907662961464
#
# Coherence Score100:  0.2731754041401247
#
# Coherence ScoreUMass:  -0.0740694102054709
#
# Coherence Score5UMass:  -1.379166591538656
#
# Coherence Score10UMass:  -1.943276838996237
#
# Coherence Score20UMass:  -0.5126775232873639
#
# Coherence Score50UMass:  -0.2759931790625079
#
# Coherence Score100UMass:  -0.40865386698938155
