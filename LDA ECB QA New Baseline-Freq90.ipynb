# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['qa']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(8371 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# filter words that occur in more than 90% of documents
id2word.filter_extremes(no_above = 0.900)
print(id2word)
# Out:
# Dictionary(3434 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=1, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
lda_model5 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model10 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model20 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model50 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=50, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model100 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=100, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\models\ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
# Print the Keyword in the 1 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.006*"country" + 0.005*"important" + 0.005*"risk" + 0.005*"expectation" + '
#   '0.005*"certainly" + 0.005*"ecb" + 0.005*"answer" + 0.005*"economy" + '
#   '0.004*"programme" + 0.004*"thats"')]

# %%
# Print the Keyword in the 5 topics
pprint(lda_model5.print_topics())
doc_lda = lda_model5[corpus]

# Print the Keyword in the 10 topics
pprint(lda_model10.print_topics())
doc_lda = lda_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lda_model20.print_topics())
doc_lda = lda_model20[corpus]

# Print the Keyword in the 50 topics
pprint(lda_model50.print_topics())
doc_lda = lda_model50[corpus]

# Print the Keyword in the 100 topics
pprint(lda_model100.print_topics())
doc_lda = lda_model100[corpus]
# Out:
# [(0,
#   '0.008*"development" + 0.007*"european" + 0.007*"exchange" + 0.006*"central" '
#   '+ 0.006*"may" + 0.006*"country" + 0.005*"answer" + 0.005*"cannot" + '
#   '0.005*"ecb" + 0.005*"economic"'),
#  (1,
#   '0.008*"thats" + 0.008*"programme" + 0.007*"answer" + 0.007*"reform" + '
#   '0.006*"expectation" + 0.006*"certainly" + 0.005*"country" + '
#   '0.005*"important" + 0.005*"financial" + 0.005*"ecb"'),
#  (2,
#   '0.009*"country" + 0.007*"ecb" + 0.006*"credit" + 0.006*"risk" + '
#   '0.006*"thing" + 0.006*"actually" + 0.005*"two" + 0.005*"it" + '
#   '0.005*"measure" + 0.005*"situation"'),
#  (3,
#   '0.012*"regard" + 0.008*"important" + 0.008*"economy" + 0.007*"risk" + '
#   '0.006*"situation" + 0.006*"appropriate" + 0.005*"term" + 0.005*"particular" '
#   '+ 0.005*"country" + 0.005*"number"'),
#  (4,
#   '0.010*"analysis" + 0.008*"important" + 0.008*"clear" + 0.007*"europe" + '
#   '0.007*"confidence" + 0.006*"responsibility" + 0.006*"month" + '
#   '0.006*"situation" + 0.006*"again" + 0.005*"mentioned"')]
# [(0,
#   '0.026*"government" + 0.017*"european" + 0.016*"ecb" + 0.013*"greece" + '
#   '0.010*"country" + 0.009*"pact" + 0.009*"position" + 0.008*"member" + '
#   '0.008*"opinion" + 0.008*"measure"'),
#  (1,
#   '0.009*"thats" + 0.008*"programme" + 0.008*"answer" + 0.008*"expectation" + '
#   '0.007*"certainly" + 0.006*"important" + 0.005*"financial" + 0.005*"let" + '
#   '0.005*"lending" + 0.005*"discussed"'),
#  (2,
#   '0.008*"development" + 0.007*"exchange" + 0.006*"country" + 0.006*"may" + '
#   '0.005*"cannot" + 0.005*"it" + 0.005*"and" + 0.005*"statement" + '
#   '0.004*"still" + 0.004*"month"'),
#  (3,
#   '0.013*"regard" + 0.009*"economy" + 0.009*"important" + 0.008*"risk" + '
#   '0.007*"situation" + 0.006*"appropriate" + 0.006*"term" + 0.006*"number" + '
#   '0.005*"present" + 0.005*"particular"'),
#  (4,
#   '0.012*"analysis" + 0.011*"important" + 0.010*"confidence" + 0.009*"clear" + '
#   '0.008*"europe" + 0.007*"responsibility" + 0.007*"month" + 0.007*"situation" '
#   '+ 0.007*"position" + 0.007*"mentioned"'),
#  (5,
#   '0.000*"compact" + 0.000*"european" + 0.000*"country" + 0.000*"answer" + '
#   '0.000*"central" + 0.000*"regard" + 0.000*"ecb" + 0.000*"development" + '
#   '0.000*"exchange" + 0.000*"economy"'),
#  (6,
#   '0.000*"conditionality" + 0.000*"equilibrium" + 0.000*"unfounded" + '
#   '0.000*"highlighted" + 0.000*"am" + 0.000*"managing" + 0.000*"squarely" + '
#   '0.000*"crunch" + 0.000*"break" + 0.000*"repair"'),
#  (7,
#   '0.011*"reform" + 0.011*"central" + 0.010*"ecb" + 0.010*"country" + '
#   '0.010*"structural" + 0.009*"measure" + 0.009*"effect" + 0.006*"national" + '
#   '0.006*"risk" + 0.006*"objective"'),
#  (8,
#   '0.001*"slovenia" + 0.001*"cutoff" + 0.001*"mix" + 0.001*"listed" + '
#   '0.001*"healthy" + 0.001*"skill" + 0.000*"supposed" + 0.000*"stabilise" + '
#   '0.000*"any" + 0.000*"link"'),
#  (9,
#   '0.013*"error" + 0.004*"human" + 0.003*"processed" + 0.002*"appeared" + '
#   '0.002*"payment" + 0.002*"water" + 0.002*"benign" + 0.002*"realtime" + '
#   '0.002*"behave" + 0.001*"gain"')]
# [(0,
#   '0.019*"practical" + 0.000*"ecb" + 0.000*"important" + 0.000*"european" + '
#   '0.000*"government" + 0.000*"term" + 0.000*"regard" + 0.000*"country" + '
#   '0.000*"and" + 0.000*"position"'),
#  (1,
#   '0.016*"weve" + 0.009*"important" + 0.009*"certainly" + 0.009*"problem" + '
#   '0.008*"thats" + 0.007*"come" + 0.007*"especially" + 0.007*"impact" + '
#   '0.007*"recovery" + 0.007*"lending"'),
#  (2,
#   '0.125*"ve" + 0.071*"ab" + 0.067*"we" + 0.052*"re" + 0.048*"ll" + '
#   '0.024*"tltros" + 0.015*"young" + 0.015*"diverging" + 0.015*"material" + '
#   '0.014*"producing"'),
#  (3,
#   '0.027*"reassure" + 0.017*"voted" + 0.000*"term" + 0.000*"regard" + '
#   '0.000*"risk" + 0.000*"global" + 0.000*"economy" + 0.000*"respect" + '
#   '0.000*"present" + 0.000*"medium"'),
#  (4,
#   '0.000*"important" + 0.000*"confidence" + 0.000*"risk" + 0.000*"economy" + '
#   '0.000*"regard" + 0.000*"situation" + 0.000*"analysis" + 0.000*"country" + '
#   '0.000*"term" + 0.000*"appropriate"'),
#  (5,
#   '0.000*"regard" + 0.000*"central" + 0.000*"european" + 0.000*"economy" + '
#   '0.000*"important" + 0.000*"confidence" + 0.000*"exchange" + '
#   '0.000*"development" + 0.000*"again" + 0.000*"europe"'),
#  (6,
#   '0.000*"ecb" + 0.000*"european" + 0.000*"regard" + 0.000*"important" + '
#   '0.000*"development" + 0.000*"central" + 0.000*"economy" + 0.000*"country" + '
#   '0.000*"answer" + 0.000*"make"'),
#  (7,
#   '0.009*"programme" + 0.009*"reform" + 0.007*"thats" + 0.007*"answer" + '
#   '0.007*"expectation" + 0.006*"effect" + 0.006*"country" + 0.006*"ecb" + '
#   '0.006*"let" + 0.005*"certainly"'),
#  (8,
#   '0.000*"regard" + 0.000*"economy" + 0.000*"important" + 0.000*"figure" + '
#   '0.000*"risk" + 0.000*"central" + 0.000*"country" + 0.000*"present" + '
#   '0.000*"again" + 0.000*"basis"'),
#  (9,
#   '0.000*"regard" + 0.000*"central" + 0.000*"important" + 0.000*"risk" + '
#   '0.000*"economy" + 0.000*"country" + 0.000*"figure" + 0.000*"european" + '
#   '0.000*"ecb" + 0.000*"exchange"'),
#  (10,
#   '0.012*"regard" + 0.009*"important" + 0.008*"economy" + 0.008*"risk" + '
#   '0.006*"situation" + 0.006*"appropriate" + 0.006*"clear" + '
#   '0.006*"particular" + 0.005*"present" + 0.005*"term"'),
#  (11,
#   '0.081*"compact" + 0.055*"contraction" + 0.052*"efsf" + 0.019*"legally" + '
#   '0.019*"preventive" + 0.016*"demonstration" + 0.013*"arm" + 0.006*"almunia" '
#   '+ 0.000*"treaty" + 0.000*"encouraged"'),
#  (12,
#   '0.000*"regard" + 0.000*"economy" + 0.000*"important" + 0.000*"european" + '
#   '0.000*"ecb" + 0.000*"clear" + 0.000*"risk" + 0.000*"country" + '
#   '0.000*"situation" + 0.000*"government"'),
#  (13,
#   '0.009*"country" + 0.007*"ecb" + 0.006*"exchange" + 0.006*"may" + '
#   '0.006*"development" + 0.005*"it" + 0.005*"european" + 0.005*"government" + '
#   '0.005*"two" + 0.005*"statement"'),
#  (14,
#   '0.000*"risk" + 0.000*"regard" + 0.000*"european" + 0.000*"important" + '
#   '0.000*"economy" + 0.000*"may" + 0.000*"development" + 0.000*"ecb" + '
#   '0.000*"present" + 0.000*"exchange"'),
#  (15,
#   '0.000*"regard" + 0.000*"important" + 0.000*"risk" + 0.000*"economy" + '
#   '0.000*"situation" + 0.000*"clear" + 0.000*"again" + 0.000*"number" + '
#   '0.000*"particular" + 0.000*"confidence"'),
#  (16,
#   '0.069*"doctrine" + 0.064*"default" + 0.037*"involvement" + '
#   '0.031*"selective" + 0.030*"advanced" + 0.013*"negotiated" + '
#   '0.012*"activated" + 0.009*"portuguese" + 0.002*"conditionality" + '
#   '0.001*"threshold"'),
#  (17,
#   '0.000*"economy" + 0.000*"figure" + 0.000*"risk" + 0.000*"central" + '
#   '0.000*"regard" + 0.000*"european" + 0.000*"development" + 0.000*"europe" + '
#   '0.000*"month" + 0.000*"situation"'),
#  (18,
#   '0.000*"risk" + 0.000*"regard" + 0.000*"number" + 0.000*"important" + '
#   '0.000*"economy" + 0.000*"information" + 0.000*"situation" + 0.000*"present" '
#   '+ 0.000*"central" + 0.000*"good"'),
#  (19,
#   '0.000*"regard" + 0.000*"risk" + 0.000*"economy" + 0.000*"projection" + '
#   '0.000*"analysis" + 0.000*"important" + 0.000*"present" + 0.000*"medium" + '
#   '0.000*"global" + 0.000*"clear"')]
# [(47,
#   '0.000*"economy" + 0.000*"risk" + 0.000*"analysis" + 0.000*"regard" + '
#   '0.000*"figure" + 0.000*"important" + 0.000*"clear" + 0.000*"term" + '
#   '0.000*"increase" + 0.000*"particular"'),
#  (6,
#   '0.000*"european" + 0.000*"ecb" + 0.000*"development" + 0.000*"central" + '
#   '0.000*"and" + 0.000*"europe" + 0.000*"may" + 0.000*"regard" + '
#   '0.000*"expect" + 0.000*"answer"'),
#  (8,
#   '0.000*"figure" + 0.000*"regard" + 0.000*"important" + 0.000*"economy" + '
#   '0.000*"risk" + 0.000*"central" + 0.000*"country" + 0.000*"projection" + '
#   '0.000*"basis" + 0.000*"present"'),
#  (34,
#   '0.000*"regard" + 0.000*"economy" + 0.000*"risk" + 0.000*"ecb" + '
#   '0.000*"central" + 0.000*"month" + 0.000*"clear" + 0.000*"country" + '
#   '0.000*"important" + 0.000*"figure"'),
#  (17,
#   '0.000*"figure" + 0.000*"economy" + 0.000*"risk" + 0.000*"european" + '
#   '0.000*"central" + 0.000*"regard" + 0.000*"development" + 0.000*"may" + '
#   '0.000*"europe" + 0.000*"still"'),
#  (23,
#   '0.000*"risk" + 0.000*"analysis" + 0.000*"economy" + 0.000*"figure" + '
#   '0.000*"situation" + 0.000*"clear" + 0.000*"development" + 0.000*"regard" + '
#   '0.000*"again" + 0.000*"present"'),
#  (28,
#   '0.000*"important" + 0.000*"regard" + 0.000*"clear" + 0.000*"economy" + '
#   '0.000*"central" + 0.000*"european" + 0.000*"again" + 0.000*"analysis" + '
#   '0.000*"situation" + 0.000*"present"'),
#  (45,
#   '0.000*"regard" + 0.000*"risk" + 0.000*"important" + 0.000*"again" + '
#   '0.000*"analysis" + 0.000*"economy" + 0.000*"central" + 0.000*"month" + '
#   '0.000*"country" + 0.000*"global"'),
#  (20,
#   '0.000*"regard" + 0.000*"exchange" + 0.000*"risk" + 0.000*"important" + '
#   '0.000*"central" + 0.000*"development" + 0.000*"economy" + 0.000*"future" + '
#   '0.000*"term" + 0.000*"confidence"'),
#  (29,
#   '0.000*"regard" + 0.000*"important" + 0.000*"risk" + 0.000*"term" + '
#   '0.000*"central" + 0.000*"meeting" + 0.000*"economy" + 0.000*"particular" + '
#   '0.000*"comment" + 0.000*"analysis"'),
#  (19,
#   '0.425*"ve" + 0.000*"ab" + 0.000*"economy" + 0.000*"risk" + 0.000*"regard" + '
#   '0.000*"important" + 0.000*"analysis" + 0.000*"europe" + 0.000*"country" + '
#   '0.000*"projection"'),
#  (24,
#   '0.149*"incoming" + 0.059*"evolve" + 0.000*"reviewing" + 0.000*"guidance" + '
#   '0.000*"drop" + 0.000*"economy" + 0.000*"risk" + 0.000*"country" + '
#   '0.000*"certainly" + 0.000*"ecb"'),
#  (42,
#   '0.207*"passing" + 0.065*"allowed" + 0.037*"interfere" + 0.036*"lifted" + '
#   '0.000*"ease" + 0.000*"evaluation" + 0.000*"stopped" + 0.000*"emergency" + '
#   '0.000*"loose" + 0.000*"replace"'),
#  (13,
#   '0.050*"liquidity" + 0.045*"operation" + 0.042*"driver" + 0.026*"week" + '
#   '0.024*"it" + 0.022*"discussion" + 0.022*"still" + 0.021*"four" + '
#   '0.021*"conflict" + 0.020*"then"'),
#  (10,
#   '0.032*"development" + 0.025*"commission" + 0.024*"future" + 0.024*"impact" '
#   '+ 0.019*"banking" + 0.018*"past" + 0.017*"come" + 0.017*"european" + '
#   '0.016*"note" + 0.015*"supervision"'),
#  (7,
#   '0.081*"package" + 0.052*"exchange" + 0.046*"extended" + 0.045*"expect" + '
#   '0.033*"undue" + 0.030*"still" + 0.027*"mr" + 0.023*"may" + 0.023*"factor" + '
#   '0.022*"agency"'),
#  (48,
#   '0.015*"regard" + 0.010*"important" + 0.008*"risk" + 0.008*"clear" + '
#   '0.006*"particular" + 0.006*"economy" + 0.006*"appropriate" + 0.006*"again" '
#   '+ 0.006*"responsibility" + 0.006*"number"'),
#  (22,
#   '0.018*"reform" + 0.016*"country" + 0.012*"billion" + 0.012*"government" + '
#   '0.011*"programme" + 0.010*"ecb" + 0.010*"change" + 0.009*"reason" + '
#   '0.009*"effect" + 0.008*"sense"'),
#  (21,
#   '0.008*"economy" + 0.007*"situation" + 0.006*"risk" + 0.006*"regard" + '
#   '0.005*"term" + 0.005*"and" + 0.005*"country" + 0.005*"look" + 0.004*"money" '
#   '+ 0.004*"figure"'),
#  (38,
#   '0.008*"thats" + 0.007*"answer" + 0.007*"expectation" + 0.006*"programme" + '
#   '0.006*"certainly" + 0.006*"let" + 0.006*"measure" + 0.005*"important" + '
#   '0.005*"ecb" + 0.005*"month"')]
# [(54,
#   '0.000*"risk" + 0.000*"regard" + 0.000*"basis" + 0.000*"important" + '
#   '0.000*"institution" + 0.000*"european" + 0.000*"again" + '
#   '0.000*"expectation" + 0.000*"economy" + 0.000*"member"'),
#  (93,
#   '0.000*"economy" + 0.000*"european" + 0.000*"certainly" + 0.000*"risk" + '
#   '0.000*"basis" + 0.000*"regard" + 0.000*"clear" + 0.000*"effect" + '
#   '0.000*"present" + 0.000*"reason"'),
#  (34,
#   '0.000*"reason" + 0.000*"month" + 0.000*"ecb" + 0.000*"figure" + '
#   '0.000*"regard" + 0.000*"particular" + 0.000*"always" + 0.000*"risk" + '
#   '0.000*"economy" + 0.000*"may"'),
#  (98,
#   '0.000*"economy" + 0.000*"present" + 0.000*"important" + 0.000*"regard" + '
#   '0.000*"ecb" + 0.000*"reason" + 0.000*"account" + 0.000*"mentioned" + '
#   '0.000*"again" + 0.000*"staff"'),
#  (61,
#   '0.000*"figure" + 0.000*"economy" + 0.000*"country" + 0.000*"regard" + '
#   '0.000*"situation" + 0.000*"present" + 0.000*"projection" + 0.000*"clear" + '
#   '0.000*"month" + 0.000*"particular"'),
#  (5,
#   '0.000*"european" + 0.000*"answer" + 0.000*"regard" + 0.000*"confidence" + '
#   '0.000*"risk" + 0.000*"increase" + 0.000*"past" + 0.000*"might" + '
#   '0.000*"economic" + 0.000*"look"'),
#  (52,
#   '0.000*"risk" + 0.000*"important" + 0.000*"ecb" + 0.000*"information" + '
#   '0.000*"analysis" + 0.000*"change" + 0.000*"mentioned" + 0.000*"again" + '
#   '0.000*"regard" + 0.000*"clear"'),
#  (72,
#   '0.000*"european" + 0.000*"ecb" + 0.000*"may" + 0.000*"central" + '
#   '0.000*"regard" + 0.000*"economy" + 0.000*"answer" + 0.000*"institution" + '
#   '0.000*"clear" + 0.000*"opinion"'),
#  (99,
#   '0.000*"regard" + 0.000*"economy" + 0.000*"number" + 0.000*"important" + '
#   '0.000*"global" + 0.000*"again" + 0.000*"account" + 0.000*"europe" + '
#   '0.000*"job" + 0.000*"financial"'),
#  (33,
#   '0.000*"risk" + 0.000*"economy" + 0.000*"and" + 0.000*"development" + '
#   '0.000*"come" + 0.000*"ecb" + 0.000*"impact" + 0.000*"central" + '
#   '0.000*"figure" + 0.000*"cannot"'),
#  (60,
#   '0.018*"clear" + 0.016*"change" + 0.016*"month" + 0.015*"balance" + '
#   '0.015*"welcomed" + 0.014*"world" + 0.014*"risk" + 0.014*"position" + '
#   '0.013*"information" + 0.013*"materialised"'),
#  (22,
#   '0.102*"figure" + 0.055*"next" + 0.054*"believe" + 0.052*"forecast" + '
#   '0.044*"pillar" + 0.041*"wage" + 0.039*"available" + 0.035*"average" + '
#   '0.031*"may" + 0.023*"performance"'),
#  (82,
#   '0.035*"message" + 0.035*"frankly" + 0.028*"forward" + 0.028*"uncertainty" + '
#   '0.027*"ability" + 0.027*"mostly" + 0.025*"impact" + 0.023*"supervision" + '
#   '0.022*"proper" + 0.021*"guidance"'),
#  (13,
#   '0.060*"liquidity" + 0.057*"operation" + 0.025*"refinancing" + '
#   '0.022*"naturally" + 0.019*"amount" + 0.018*"day" + 0.017*"result" + '
#   '0.016*"allotment" + 0.015*"money" + 0.015*"main"'),
#  (51,
#   '0.023*"country" + 0.015*"reform" + 0.015*"billion" + 0.013*"government" + '
#   '0.011*"look" + 0.011*"extent" + 0.010*"change" + 0.010*"thing" + '
#   '0.009*"two" + 0.009*"programme"'),
#  (48,
#   '0.010*"regard" + 0.009*"european" + 0.008*"government" + 0.008*"country" + '
#   '0.006*"confidence" + 0.006*"and" + 0.006*"particular" + 0.006*"ecb" + '
#   '0.006*"situation" + 0.006*"state"'),
#  (7,
#   '0.022*"central" + 0.017*"structural" + 0.016*"reform" + 0.015*"effect" + '
#   '0.013*"ecb" + 0.013*"country" + 0.012*"national" + 0.010*"exchange" + '
#   '0.009*"measure" + 0.009*"still"'),
#  (21,
#   '0.013*"regard" + 0.012*"economy" + 0.011*"important" + 0.010*"risk" + '
#   '0.008*"again" + 0.008*"number" + 0.007*"term" + 0.007*"account" + '
#   '0.006*"possible" + 0.006*"clear"'),
#  (58,
#   '0.016*"let" + 0.014*"expectation" + 0.010*"part" + 0.009*"ive" + '
#   '0.009*"credit" + 0.008*"full" + 0.008*"negative" + 0.008*"programme" + '
#   '0.008*"far" + 0.007*"large"'),
#  (38,
#   '0.011*"thats" + 0.010*"answer" + 0.008*"certainly" + 0.007*"financial" + '
#   '0.007*"important" + 0.007*"discussed" + 0.007*"objective" + '
#   '0.006*"programme" + 0.006*"actually" + 0.006*"expectation"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity5: ', lda_model5.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity10: ', lda_model10.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity20: ', lda_model20.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity50: ', lda_model50.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity100: ', lda_model100.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100: ', coherence_lda)


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence ScoreUMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100UMass: ', coherence_lda)
# Out:
# Perplexity:  -7.421148171267327
#
# Perplexity5:  -7.237018609375057
#
# Perplexity10:  -7.279134778437172
#
# Perplexity20:  -7.294476172388141
#
# Perplexity50:  -7.360900881047483
#
# Perplexity100:  -9.357204347648501
#
# Coherence Score:  0.23614531927091384
#
# Coherence Score5:  0.3421526888918609
#
# Coherence Score10:  0.3738814539883544
#
# Coherence Score20:  0.3138154024359969
#
# Coherence Score50:  0.2698617896272202
#
# Coherence Score100:  0.26617384109485637
#
# Coherence ScoreUMass:  -0.312369873463243
#
# Coherence Score5UMass:  -0.3130115299674082
#
# Coherence Score10UMass:  -1.248632882814217
#
# Coherence Score20UMass:  -0.9408682021078372
#
# Coherence Score50UMass:  -0.47144591151365234
#
# Coherence Score100UMass:  -0.47922138242943013
