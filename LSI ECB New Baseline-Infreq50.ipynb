# %%
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['Press']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(4394 unique tokens: ['able', 'acceptable', 'accompanied', 'according', 'account']...)

# %%
# less than 10 documents,
id2word = corpora.Dictionary(data)
id2word.filter_extremes(no_below = 50)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.240*"projection" + 0.183*"staff" + 0.144*"operation" + 0.129*"december" + '
#   '0.126*"commodity" + 0.117*"september" + 0.114*"january" + 0.112*"march" + '
#   '0.108*"to" + 0.107*"june"')]
# [(0,
#   '0.240*"projection" + 0.183*"staff" + 0.144*"operation" + 0.129*"december" + '
#   '0.126*"commodity" + 0.117*"september" + 0.114*"january" + 0.112*"march" + '
#   '0.108*"to" + 0.107*"june"'),
#  (1,
#   '-0.372*"projection" + -0.252*"staff" + 0.201*"consumer" + 0.174*"trend" + '
#   '0.171*"national" + -0.163*"below" + 0.159*"member" + -0.156*"june" + '
#   '-0.151*"to" + 0.149*"state"'),
#  (2,
#   '-0.327*"projection" + 0.292*"operation" + 0.217*"january" + -0.201*"staff" '
#   '+ 0.180*"refinancing" + 0.167*"national" + 0.165*"subdued" + 0.141*"system" '
#   '+ -0.134*"longer" + 0.130*"december"'),
#  (3,
#   '-0.424*"projection" + -0.281*"staff" + -0.214*"january" + 0.203*"commodity" '
#   '+ 0.163*"negative" + 0.161*"tension" + -0.155*"december" + '
#   '0.147*"policyrelevant" + -0.145*"national" + 0.141*"owing"'),
#  (4,
#   '-0.250*"commodity" + 0.222*"subdued" + -0.213*"december" + '
#   '-0.207*"projection" + 0.205*"june" + -0.200*"operation" + -0.185*"january" '
#   '+ 0.179*"gradual" + -0.157*"staff" + 0.140*"asset"')]
# [(0,
#   '0.240*"projection" + 0.183*"staff" + 0.144*"operation" + 0.129*"december" + '
#   '0.126*"commodity" + 0.117*"september" + 0.114*"january" + 0.112*"march" + '
#   '0.108*"to" + 0.107*"june"'),
#  (1,
#   '-0.372*"projection" + -0.252*"staff" + 0.201*"consumer" + 0.174*"trend" + '
#   '0.171*"national" + -0.163*"below" + 0.159*"member" + -0.156*"june" + '
#   '-0.151*"to" + 0.149*"state"'),
#  (2,
#   '-0.327*"projection" + 0.292*"operation" + 0.217*"january" + -0.201*"staff" '
#   '+ 0.180*"refinancing" + 0.167*"national" + 0.165*"subdued" + 0.141*"system" '
#   '+ -0.134*"longer" + 0.130*"december"'),
#  (3,
#   '0.424*"projection" + 0.281*"staff" + 0.214*"january" + -0.203*"commodity" + '
#   '-0.163*"negative" + -0.161*"tension" + 0.155*"december" + '
#   '-0.147*"policyrelevant" + 0.145*"national" + -0.141*"owing"'),
#  (4,
#   '-0.250*"commodity" + 0.222*"subdued" + -0.213*"december" + '
#   '-0.207*"projection" + 0.205*"june" + -0.200*"operation" + -0.185*"january" '
#   '+ 0.179*"gradual" + -0.157*"staff" + 0.140*"asset"'),
#  (5,
#   '-0.302*"march" + 0.242*"september" + -0.238*"february" + 0.219*"subdued" + '
#   '-0.203*"january" + -0.168*"ample" + -0.167*"accommodative" + '
#   '0.162*"projection" + -0.154*"april" + 0.152*"october"'),
#  (6,
#   '-0.315*"january" + 0.304*"operation" + -0.290*"december" + 0.264*"july" + '
#   '0.249*"june" + 0.217*"august" + -0.207*"subdued" + -0.200*"february" + '
#   '0.198*"september" + -0.182*"march"'),
#  (7,
#   '-0.248*"food" + -0.221*"tension" + 0.209*"longer" + -0.199*"october" + '
#   '-0.182*"september" + 0.181*"negative" + -0.174*"secondround" + '
#   '-0.161*"commodity" + -0.158*"november" + 0.156*"system"'),
#  (8,
#   '-0.255*"april" + -0.248*"march" + 0.245*"october" + -0.229*"food" + '
#   '0.226*"november" + 0.201*"december" + 0.171*"september" + 0.161*"ample" + '
#   '-0.155*"consumer" + 0.147*"job"'),
#  (9,
#   '-0.252*"national" + 0.229*"operation" + -0.206*"asset" + -0.194*"system" + '
#   '0.184*"consumer" + 0.178*"pillar" + 0.176*"refinancing" + -0.165*"january" '
#   '+ -0.161*"firm" + -0.158*"sustained"')]
# [(0,
#   '0.240*"projection" + 0.183*"staff" + 0.144*"operation" + 0.129*"december" + '
#   '0.126*"commodity" + 0.117*"september" + 0.114*"january" + 0.112*"march" + '
#   '0.108*"to" + 0.107*"june"'),
#  (1,
#   '-0.372*"projection" + -0.252*"staff" + 0.201*"consumer" + 0.174*"trend" + '
#   '0.171*"national" + -0.163*"below" + 0.159*"member" + -0.156*"june" + '
#   '-0.151*"to" + 0.149*"state"'),
#  (2,
#   '-0.327*"projection" + 0.292*"operation" + 0.217*"january" + -0.201*"staff" '
#   '+ 0.180*"refinancing" + 0.167*"national" + 0.165*"subdued" + 0.141*"system" '
#   '+ -0.134*"longer" + 0.130*"december"'),
#  (3,
#   '-0.424*"projection" + -0.281*"staff" + -0.214*"january" + 0.203*"commodity" '
#   '+ 0.163*"negative" + 0.161*"tension" + -0.155*"december" + '
#   '0.147*"policyrelevant" + -0.145*"national" + 0.141*"owing"'),
#  (4,
#   '0.250*"commodity" + -0.222*"subdued" + 0.213*"december" + '
#   '0.207*"projection" + -0.205*"june" + 0.200*"operation" + 0.185*"january" + '
#   '-0.179*"gradual" + 0.157*"staff" + -0.140*"asset"'),
#  (5,
#   '-0.302*"march" + 0.242*"september" + -0.238*"february" + 0.219*"subdued" + '
#   '-0.203*"january" + -0.168*"ample" + -0.167*"accommodative" + '
#   '0.162*"projection" + -0.155*"april" + 0.152*"october"'),
#  (6,
#   '-0.315*"january" + 0.304*"operation" + -0.290*"december" + 0.264*"july" + '
#   '0.249*"june" + 0.217*"august" + -0.207*"subdued" + -0.200*"february" + '
#   '0.198*"september" + -0.182*"march"'),
#  (7,
#   '-0.248*"food" + -0.221*"tension" + 0.209*"longer" + -0.199*"october" + '
#   '-0.182*"september" + 0.181*"negative" + -0.174*"secondround" + '
#   '-0.161*"commodity" + -0.158*"november" + 0.156*"system"'),
#  (8,
#   '-0.255*"april" + -0.248*"march" + 0.245*"october" + -0.229*"food" + '
#   '0.226*"november" + 0.201*"december" + 0.171*"september" + 0.161*"ample" + '
#   '-0.155*"consumer" + 0.147*"job"'),
#  (9,
#   '0.252*"national" + -0.229*"operation" + 0.206*"asset" + 0.194*"system" + '
#   '-0.185*"consumer" + -0.178*"pillar" + -0.176*"refinancing" + '
#   '0.165*"january" + 0.161*"firm" + 0.158*"sustained"'),
#  (10,
#   '0.225*"tension" + 0.224*"national" + -0.223*"negative" + 0.194*"subdued" + '
#   '0.182*"system" + -0.171*"october" + -0.169*"november" + -0.153*"pillar" + '
#   '-0.148*"september" + 0.141*"competitiveness"'),
#  (11,
#   '0.294*"operation" + -0.221*"tension" + 0.213*"volatility" + '
#   '0.192*"background" + 0.184*"refinancing" + -0.161*"process" + '
#   '-0.158*"pillar" + 0.149*"subdued" + 0.138*"capacity" + -0.136*"programme"'),
#  (12,
#   '0.348*"january" + 0.341*"july" + 0.323*"june" + -0.256*"april" + '
#   '-0.225*"october" + -0.215*"march" + -0.197*"system" + 0.157*"december" + '
#   '-0.152*"september" + 0.145*"consumer"'),
#  (13,
#   '-0.284*"fall" + 0.226*"process" + -0.168*"commodity" + 0.166*"food" + '
#   '-0.156*"possible" + -0.155*"reduction" + -0.151*"world" + '
#   '-0.148*"substantial" + 0.142*"deposit" + 0.134*"secondround"'),
#  (14,
#   '-0.323*"august" + -0.300*"february" + 0.273*"november" + -0.257*"september" '
#   '+ -0.228*"january" + 0.218*"june" + -0.214*"volatility" + 0.207*"december" '
#   '+ 0.138*"april" + -0.116*"commodity"'),
#  (15,
#   '0.297*"gradual" + -0.184*"policyrelevant" + 0.183*"deficit" + '
#   '0.168*"procedure" + 0.152*"long" + 0.147*"must" + 0.140*"respect" + '
#   '0.136*"accommodative" + -0.134*"trend" + 0.131*"world"'),
#  (16,
#   '0.240*"accommodative" + -0.216*"january" + 0.214*"commodity" + '
#   '0.165*"november" + 0.141*"december" + 0.140*"april" + -0.140*"tension" + '
#   '0.130*"base" + -0.129*"cost" + -0.128*"significantly"'),
#  (17,
#   '0.232*"march" + -0.181*"momentum" + -0.168*"lending" + 0.155*"asset" + '
#   '0.142*"operation" + -0.140*"anchoring" + -0.138*"april" + 0.138*"prospect" '
#   '+ 0.133*"banking" + 0.130*"objective"'),
#  (18,
#   '0.277*"volatility" + 0.232*"june" + -0.189*"lower" + 0.170*"additional" + '
#   '0.169*"confirmed" + 0.163*"strongly" + -0.163*"thus" + -0.154*"ample" + '
#   '0.146*"fully" + -0.144*"longer"'),
#  (19,
#   '-0.249*"national" + -0.212*"exchange" + -0.158*"service" + -0.158*"world" + '
#   '-0.156*"gradual" + -0.154*"contribution" + 0.152*"evidence" + 0.147*"trend" '
#   '+ -0.145*"creation" + 0.145*"momentum"')]
# [(0,
#   '-0.240*"projection" + -0.183*"staff" + -0.144*"operation" + '
#   '-0.129*"december" + -0.126*"commodity" + -0.117*"september" + '
#   '-0.114*"january" + -0.112*"march" + -0.108*"to" + -0.107*"june"'),
#  (1,
#   '-0.372*"projection" + -0.252*"staff" + 0.201*"consumer" + 0.174*"trend" + '
#   '0.171*"national" + -0.163*"below" + 0.159*"member" + -0.156*"june" + '
#   '-0.151*"to" + 0.149*"state"'),
#  (2,
#   '0.327*"projection" + -0.292*"operation" + -0.217*"january" + 0.201*"staff" '
#   '+ -0.180*"refinancing" + -0.167*"national" + -0.165*"subdued" + '
#   '-0.141*"system" + 0.134*"longer" + -0.130*"december"'),
#  (3,
#   '-0.424*"projection" + -0.281*"staff" + -0.214*"january" + 0.203*"commodity" '
#   '+ 0.163*"negative" + 0.161*"tension" + -0.155*"december" + '
#   '0.147*"policyrelevant" + -0.145*"national" + 0.141*"owing"'),
#  (4,
#   '0.250*"commodity" + -0.222*"subdued" + 0.213*"december" + '
#   '0.207*"projection" + -0.205*"june" + 0.200*"operation" + 0.185*"january" + '
#   '-0.179*"gradual" + 0.157*"staff" + -0.140*"asset"'),
#  (5,
#   '0.302*"march" + -0.242*"september" + 0.238*"february" + -0.219*"subdued" + '
#   '0.203*"january" + 0.168*"ample" + 0.167*"accommodative" + '
#   '-0.162*"projection" + 0.154*"april" + -0.152*"october"'),
#  (6,
#   '-0.315*"january" + 0.304*"operation" + -0.290*"december" + 0.264*"july" + '
#   '0.249*"june" + 0.217*"august" + -0.207*"subdued" + -0.200*"february" + '
#   '0.198*"september" + -0.182*"march"'),
#  (7,
#   '-0.248*"food" + -0.221*"tension" + 0.209*"longer" + -0.199*"october" + '
#   '-0.182*"september" + 0.181*"negative" + -0.174*"secondround" + '
#   '-0.161*"commodity" + -0.157*"november" + 0.156*"system"'),
#  (8,
#   '0.255*"april" + 0.248*"march" + -0.245*"october" + 0.229*"food" + '
#   '-0.226*"november" + -0.201*"december" + -0.171*"september" + -0.161*"ample" '
#   '+ 0.155*"consumer" + -0.147*"job"'),
#  (9,
#   '0.252*"national" + -0.229*"operation" + 0.206*"asset" + 0.194*"system" + '
#   '-0.185*"consumer" + -0.178*"pillar" + -0.176*"refinancing" + '
#   '0.165*"january" + 0.161*"firm" + 0.158*"sustained"'),
#  (10,
#   '0.225*"tension" + 0.224*"national" + -0.223*"negative" + 0.194*"subdued" + '
#   '0.182*"system" + -0.171*"october" + -0.169*"november" + -0.153*"pillar" + '
#   '-0.148*"september" + 0.141*"competitiveness"'),
#  (11,
#   '-0.295*"operation" + 0.221*"tension" + -0.213*"volatility" + '
#   '-0.192*"background" + -0.184*"refinancing" + 0.161*"process" + '
#   '0.158*"pillar" + -0.149*"subdued" + -0.138*"capacity" + 0.136*"programme"'),
#  (12,
#   '0.348*"january" + 0.341*"july" + 0.323*"june" + -0.256*"april" + '
#   '-0.225*"october" + -0.216*"march" + -0.197*"system" + 0.157*"december" + '
#   '-0.152*"september" + 0.145*"consumer"'),
#  (13,
#   '0.283*"fall" + -0.226*"process" + 0.168*"commodity" + -0.166*"food" + '
#   '0.156*"possible" + 0.155*"reduction" + 0.151*"world" + 0.148*"substantial" '
#   '+ -0.142*"deposit" + -0.134*"secondround"'),
#  (14,
#   '-0.323*"august" + -0.300*"february" + 0.273*"november" + -0.257*"september" '
#   '+ -0.228*"january" + 0.218*"june" + -0.214*"volatility" + 0.207*"december" '
#   '+ 0.138*"april" + -0.116*"commodity"'),
#  (15,
#   '0.297*"gradual" + -0.184*"policyrelevant" + 0.183*"deficit" + '
#   '0.168*"procedure" + 0.152*"long" + 0.147*"must" + 0.139*"respect" + '
#   '0.136*"accommodative" + -0.134*"trend" + 0.131*"world"'),
#  (16,
#   '-0.241*"accommodative" + 0.216*"january" + -0.214*"commodity" + '
#   '-0.165*"november" + -0.141*"december" + -0.140*"april" + 0.140*"tension" + '
#   '-0.130*"base" + 0.129*"cost" + 0.128*"significantly"'),
#  (17,
#   '0.232*"march" + -0.181*"momentum" + -0.168*"lending" + 0.155*"asset" + '
#   '0.142*"operation" + -0.140*"anchoring" + -0.138*"april" + 0.138*"prospect" '
#   '+ 0.134*"banking" + 0.130*"objective"'),
#  (18,
#   '0.277*"volatility" + 0.233*"june" + -0.189*"lower" + 0.170*"additional" + '
#   '0.169*"confirmed" + 0.164*"strongly" + -0.163*"thus" + -0.154*"ample" + '
#   '0.146*"fully" + -0.144*"longer"'),
#  (19,
#   '-0.249*"national" + -0.212*"exchange" + -0.158*"service" + -0.158*"world" + '
#   '-0.156*"gradual" + -0.154*"contribution" + 0.152*"evidence" + 0.148*"trend" '
#   '+ -0.145*"creation" + 0.145*"momentum"'),
#  (20,
#   '-0.272*"pillar" + -0.192*"trend" + 0.177*"consumer" + -0.151*"moderation" + '
#   '-0.141*"member" + 0.140*"course" + 0.137*"gradually" + 0.136*"lending" + '
#   '-0.133*"lower" + -0.129*"take"'),
#  (21,
#   '-0.214*"october" + 0.204*"december" + 0.204*"end" + 0.194*"several" + '
#   '-0.171*"contribute" + 0.168*"firm" + 0.156*"lead" + -0.153*"objective" + '
#   '0.152*"side" + -0.146*"weak"'),
#  (22,
#   '-0.269*"february" + 0.224*"april" + 0.213*"september" + 0.167*"january" + '
#   '-0.166*"programme" + 0.165*"union" + -0.159*"august" + -0.157*"negative" + '
#   '0.156*"reflected" + -0.140*"november"'),
#  (23,
#   '-0.187*"service" + -0.176*"deficit" + 0.155*"june" + -0.141*"somewhat" + '
#   '0.137*"owing" + 0.130*"give" + -0.128*"reduction" + 0.127*"next" + '
#   '-0.125*"gradually" + 0.125*"subdued"'),
#  (24,
#   '-0.249*"programme" + 0.217*"framework" + -0.208*"volatility" + '
#   '-0.204*"weak" + 0.170*"course" + -0.158*"lower" + 0.151*"general" + '
#   '0.150*"early" + 0.147*"gradual" + 0.144*"cost"'),
#  (25,
#   '0.272*"december" + 0.248*"august" + -0.192*"lower" + -0.157*"june" + '
#   '-0.156*"february" + -0.152*"november" + 0.150*"gradually" + '
#   '-0.148*"october" + 0.140*"lending" + -0.140*"exchange"'),
#  (26,
#   '0.293*"april" + 0.212*"take" + -0.196*"exchange" + 0.190*"august" + '
#   '-0.179*"february" + -0.154*"june" + 0.153*"programme" + 0.147*"gradual" + '
#   '-0.135*"one" + -0.134*"longer"'),
#  (27,
#   '-0.220*"commodity" + 0.213*"side" + 0.206*"february" + -0.171*"exchange" + '
#   '-0.170*"around" + 0.169*"related" + -0.153*"remaining" + 0.144*"already" + '
#   '0.138*"downward" + 0.130*"evidence"'),
#  (28,
#   '-0.232*"course" + -0.185*"observed" + -0.179*"weak" + 0.157*"budgetary" + '
#   '-0.153*"thus" + 0.147*"increasing" + -0.144*"deficit" + 0.142*"commodity" + '
#   '0.136*"opportunity" + -0.130*"world"'),
#  (29,
#   '-0.240*"longterm" + 0.215*"pillar" + -0.187*"short" + -0.167*"trend" + '
#   '-0.163*"service" + 0.158*"challenge" + 0.142*"improve" + 0.142*"framework" '
#   '+ 0.140*"like" + 0.138*"objective"'),
#  (30,
#   '-0.253*"trend" + 0.246*"volatility" + 0.167*"consumer" + 0.159*"objective" '
#   '+ 0.153*"prospect" + 0.144*"system" + -0.139*"secondround" + '
#   '-0.132*"evidence" + -0.132*"national" + 0.131*"significantly"'),
#  (31,
#   '0.232*"december" + -0.222*"union" + 0.215*"exchange" + -0.158*"service" + '
#   '0.152*"finance" + 0.142*"earlier" + -0.137*"process" + 0.135*"cost" + '
#   '-0.134*"prevailing" + 0.131*"possible"'),
#  (32,
#   '-0.209*"position" + 0.163*"programme" + -0.160*"increasing" + '
#   '0.153*"gradual" + 0.151*"fall" + -0.149*"deficit" + -0.149*"take" + '
#   '-0.145*"international" + 0.139*"november" + -0.138*"observed"'),
#  (33,
#   '0.189*"significantly" + -0.182*"production" + 0.173*"august" + '
#   '0.172*"position" + 0.170*"side" + -0.162*"next" + 0.160*"november" + '
#   '0.155*"short" + -0.141*"process" + 0.134*"state"'),
#  (34,
#   '-0.199*"firm" + 0.194*"take" + 0.171*"subdued" + -0.166*"prospect" + '
#   '0.162*"programme" + 0.159*"service" + -0.155*"downward" + -0.143*"gradual" '
#   '+ -0.142*"state" + 0.139*"tension"'),
#  (35,
#   '0.237*"asset" + -0.207*"situation" + -0.170*"firm" + -0.160*"exchange" + '
#   '-0.158*"gradually" + -0.156*"needed" + -0.152*"half" + 0.151*"early" + '
#   '0.149*"seen" + -0.143*"lead"'),
#  (36,
#   '0.231*"average" + 0.176*"lower" + 0.173*"service" + -0.166*"process" + '
#   '-0.163*"september" + 0.158*"deficit" + -0.134*"sound" + -0.133*"two" + '
#   '-0.132*"february" + 0.131*"reflects"'),
#  (37,
#   '-0.217*"confirmed" + -0.216*"prevailing" + 0.159*"july" + 0.149*"give" + '
#   '0.147*"national" + -0.141*"next" + 0.138*"needed" + 0.138*"volatility" + '
#   '0.136*"trend" + -0.131*"slightly"'),
#  (38,
#   '0.190*"course" + 0.175*"case" + 0.165*"asset" + 0.159*"challenge" + '
#   '0.150*"accordingly" + -0.146*"short" + 0.143*"foster" + 0.138*"confirmed" + '
#   '-0.138*"across" + -0.137*"plan"'),
#  (39,
#   '0.240*"strongly" + 0.203*"contribute" + 0.197*"trend" + 0.153*"service" + '
#   '-0.141*"end" + -0.135*"state" + -0.135*"assumption" + -0.135*"further" + '
#   '0.134*"forecast" + 0.132*"lower"'),
#  (40,
#   '-0.190*"slightly" + -0.166*"august" + -0.159*"framework" + 0.149*"february" '
#   '+ -0.148*"november" + -0.147*"already" + 0.141*"service" + '
#   '-0.141*"prevailing" + 0.139*"confirmed" + 0.132*"somewhat"'),
#  (41,
#   '0.200*"process" + 0.160*"although" + -0.159*"major" + 0.159*"within" + '
#   '0.156*"april" + 0.154*"observed" + -0.146*"seen" + -0.141*"needed" + '
#   '-0.141*"accommodative" + 0.135*"effective"'),
#  (42,
#   '-0.186*"reflects" + -0.181*"volatility" + -0.178*"consumer" + -0.172*"full" '
#   '+ -0.157*"cost" + 0.149*"background" + 0.148*"prospect" + -0.145*"fully" + '
#   '0.142*"reflected" + 0.140*"owing"'),
#  (43,
#   '-0.204*"framework" + 0.199*"cost" + 0.177*"third" + -0.162*"turn" + '
#   '0.148*"sign" + -0.143*"commission" + 0.141*"within" + -0.140*"foster" + '
#   '0.139*"longer" + -0.138*"consumer"'),
#  (44,
#   '-0.240*"release" + 0.195*"projected" + 0.169*"objective" + -0.163*"next" + '
#   '0.161*"declined" + -0.157*"momentum" + 0.152*"turn" + 0.151*"exchange" + '
#   '-0.139*"end" + -0.130*"world"'),
#  (45,
#   '0.189*"owing" + 0.187*"contribute" + 0.183*"far" + -0.178*"programme" + '
#   '0.171*"march" + -0.168*"background" + 0.159*"significantly" + -0.156*"must" '
#   '+ 0.152*"july" + -0.149*"weak"'),
#  (46,
#   '-0.192*"asset" + -0.161*"reduce" + 0.156*"owing" + -0.150*"next" + '
#   '-0.148*"help" + 0.140*"possible" + 0.139*"programme" + -0.138*"signal" + '
#   '0.135*"negative" + -0.129*"february"'),
#  (47,
#   '0.241*"good" + -0.213*"system" + 0.192*"slightly" + -0.182*"consumer" + '
#   '0.171*"start" + 0.165*"lending" + 0.163*"somewhat" + 0.150*"prospect" + '
#   '-0.138*"position" + -0.137*"moderation"'),
#  (48,
#   '0.231*"contribute" + 0.187*"early" + -0.185*"suggest" + 0.180*"end" + '
#   '0.161*"observed" + 0.155*"sign" + -0.144*"march" + -0.137*"production" + '
#   '-0.132*"take" + 0.132*"partly"'),
#  (49,
#   '-0.237*"forecast" + -0.176*"commitment" + 0.163*"early" + 0.163*"lower" + '
#   '-0.155*"end" + 0.153*"due" + -0.144*"international" + 0.137*"deficit" + '
#   '0.136*"earlier" + -0.132*"related"')]
# [(0,
#   '-0.240*"projection" + -0.183*"staff" + -0.144*"operation" + '
#   '-0.129*"december" + -0.126*"commodity" + -0.117*"september" + '
#   '-0.114*"january" + -0.112*"march" + -0.108*"to" + -0.107*"june"'),
#  (1,
#   '0.372*"projection" + 0.252*"staff" + -0.201*"consumer" + -0.174*"trend" + '
#   '-0.171*"national" + 0.163*"below" + -0.159*"member" + 0.156*"june" + '
#   '0.151*"to" + -0.149*"state"'),
#  (2,
#   '0.327*"projection" + -0.292*"operation" + -0.217*"january" + 0.201*"staff" '
#   '+ -0.180*"refinancing" + -0.167*"national" + -0.165*"subdued" + '
#   '-0.141*"system" + 0.134*"longer" + -0.130*"december"'),
#  (3,
#   '-0.424*"projection" + -0.281*"staff" + -0.214*"january" + 0.203*"commodity" '
#   '+ 0.163*"negative" + 0.161*"tension" + -0.155*"december" + '
#   '0.147*"policyrelevant" + -0.145*"national" + 0.141*"owing"'),
#  (4,
#   '0.250*"commodity" + -0.222*"subdued" + 0.213*"december" + '
#   '0.207*"projection" + -0.205*"june" + 0.200*"operation" + 0.185*"january" + '
#   '-0.179*"gradual" + 0.157*"staff" + -0.140*"asset"'),
#  (5,
#   '-0.302*"march" + 0.242*"september" + -0.238*"february" + 0.219*"subdued" + '
#   '-0.203*"january" + -0.168*"ample" + -0.167*"accommodative" + '
#   '0.162*"projection" + -0.154*"april" + 0.152*"october"'),
#  (6,
#   '0.315*"january" + -0.304*"operation" + 0.290*"december" + -0.264*"july" + '
#   '-0.249*"june" + -0.217*"august" + 0.207*"subdued" + 0.200*"february" + '
#   '-0.198*"september" + 0.182*"march"'),
#  (7,
#   '0.248*"food" + 0.221*"tension" + -0.209*"longer" + 0.199*"october" + '
#   '0.182*"september" + -0.181*"negative" + 0.174*"secondround" + '
#   '0.161*"commodity" + 0.157*"november" + -0.156*"system"'),
#  (8,
#   '0.255*"april" + 0.248*"march" + -0.245*"october" + 0.229*"food" + '
#   '-0.226*"november" + -0.201*"december" + -0.171*"september" + -0.161*"ample" '
#   '+ 0.155*"consumer" + -0.147*"job"'),
#  (9,
#   '-0.252*"national" + 0.229*"operation" + -0.206*"asset" + -0.194*"system" + '
#   '0.184*"consumer" + 0.178*"pillar" + 0.176*"refinancing" + -0.165*"january" '
#   '+ -0.161*"firm" + -0.158*"sustained"'),
#  (10,
#   '0.225*"tension" + 0.224*"national" + -0.223*"negative" + 0.194*"subdued" + '
#   '0.182*"system" + -0.171*"october" + -0.169*"november" + -0.153*"pillar" + '
#   '-0.148*"september" + 0.141*"competitiveness"'),
#  (11,
#   '0.295*"operation" + -0.221*"tension" + 0.213*"volatility" + '
#   '0.192*"background" + 0.184*"refinancing" + -0.161*"process" + '
#   '-0.158*"pillar" + 0.149*"subdued" + 0.138*"capacity" + -0.136*"programme"'),
#  (12,
#   '-0.348*"january" + -0.341*"july" + -0.323*"june" + 0.256*"april" + '
#   '0.225*"october" + 0.216*"march" + 0.197*"system" + -0.157*"december" + '
#   '0.152*"september" + -0.145*"consumer"'),
#  (13,
#   '0.283*"fall" + -0.226*"process" + 0.168*"commodity" + -0.166*"food" + '
#   '0.156*"possible" + 0.155*"reduction" + 0.151*"world" + 0.148*"substantial" '
#   '+ -0.142*"deposit" + -0.134*"secondround"'),
#  (14,
#   '0.323*"august" + 0.300*"february" + -0.273*"november" + 0.257*"september" + '
#   '0.228*"january" + -0.218*"june" + 0.214*"volatility" + -0.207*"december" + '
#   '-0.138*"april" + 0.116*"commodity"'),
#  (15,
#   '-0.297*"gradual" + 0.184*"policyrelevant" + -0.183*"deficit" + '
#   '-0.168*"procedure" + -0.152*"long" + -0.147*"must" + -0.139*"respect" + '
#   '-0.136*"accommodative" + 0.134*"trend" + -0.131*"world"'),
#  (16,
#   '-0.241*"accommodative" + 0.216*"january" + -0.214*"commodity" + '
#   '-0.165*"november" + -0.141*"december" + -0.140*"april" + 0.140*"tension" + '
#   '-0.130*"base" + 0.129*"cost" + 0.128*"significantly"'),
#  (17,
#   '0.232*"march" + -0.181*"momentum" + -0.168*"lending" + 0.155*"asset" + '
#   '0.142*"operation" + -0.140*"anchoring" + -0.138*"april" + 0.138*"prospect" '
#   '+ 0.134*"banking" + 0.130*"objective"'),
#  (18,
#   '0.277*"volatility" + 0.233*"june" + -0.189*"lower" + 0.170*"additional" + '
#   '0.169*"confirmed" + 0.164*"strongly" + -0.163*"thus" + -0.154*"ample" + '
#   '0.146*"fully" + -0.144*"longer"'),
#  (19,
#   '0.249*"national" + 0.212*"exchange" + 0.158*"service" + 0.158*"world" + '
#   '0.156*"gradual" + 0.154*"contribution" + -0.152*"evidence" + -0.148*"trend" '
#   '+ 0.145*"creation" + -0.145*"momentum"'),
#  (20,
#   '-0.272*"pillar" + -0.192*"trend" + 0.177*"consumer" + -0.151*"moderation" + '
#   '-0.141*"member" + 0.140*"course" + 0.137*"gradually" + 0.136*"lending" + '
#   '-0.133*"lower" + -0.129*"take"'),
#  (21,
#   '0.214*"october" + -0.204*"december" + -0.204*"end" + -0.194*"several" + '
#   '0.171*"contribute" + -0.168*"firm" + -0.156*"lead" + 0.153*"objective" + '
#   '-0.152*"side" + 0.146*"weak"'),
#  (22,
#   '0.269*"february" + -0.224*"april" + -0.213*"september" + -0.167*"january" + '
#   '0.166*"programme" + -0.165*"union" + 0.159*"august" + 0.157*"negative" + '
#   '-0.156*"reflected" + 0.140*"november"'),
#  (23,
#   '0.187*"service" + 0.176*"deficit" + -0.155*"june" + 0.141*"somewhat" + '
#   '-0.137*"owing" + -0.130*"give" + 0.128*"reduction" + -0.127*"next" + '
#   '0.125*"gradually" + -0.125*"subdued"'),
#  (24,
#   '-0.249*"programme" + 0.217*"framework" + -0.208*"volatility" + '
#   '-0.204*"weak" + 0.170*"course" + -0.158*"lower" + 0.151*"general" + '
#   '0.150*"early" + 0.147*"gradual" + 0.144*"cost"'),
#  (25,
#   '0.272*"december" + 0.248*"august" + -0.191*"lower" + -0.157*"june" + '
#   '-0.156*"february" + -0.152*"november" + 0.150*"gradually" + '
#   '-0.148*"october" + 0.140*"lending" + -0.140*"exchange"'),
#  (26,
#   '-0.293*"april" + -0.212*"take" + 0.196*"exchange" + -0.190*"august" + '
#   '0.179*"february" + 0.154*"june" + -0.153*"programme" + -0.147*"gradual" + '
#   '0.135*"one" + 0.134*"longer"'),
#  (27,
#   '0.220*"commodity" + -0.213*"side" + -0.206*"february" + 0.171*"exchange" + '
#   '0.170*"around" + -0.169*"related" + 0.153*"remaining" + -0.144*"already" + '
#   '-0.138*"downward" + -0.130*"evidence"'),
#  (28,
#   '0.232*"course" + 0.185*"observed" + 0.179*"weak" + -0.157*"budgetary" + '
#   '0.153*"thus" + -0.147*"increasing" + 0.144*"deficit" + -0.142*"commodity" + '
#   '-0.136*"opportunity" + 0.130*"world"'),
#  (29,
#   '0.240*"longterm" + -0.215*"pillar" + 0.187*"short" + 0.167*"trend" + '
#   '0.163*"service" + -0.158*"challenge" + -0.142*"improve" + '
#   '-0.142*"framework" + -0.140*"like" + -0.138*"objective"'),
#  (30,
#   '-0.253*"trend" + 0.246*"volatility" + 0.167*"consumer" + 0.159*"objective" '
#   '+ 0.153*"prospect" + 0.144*"system" + -0.139*"secondround" + '
#   '-0.132*"evidence" + -0.132*"national" + 0.131*"significantly"'),
#  (31,
#   '0.232*"december" + -0.222*"union" + 0.215*"exchange" + -0.158*"service" + '
#   '0.152*"finance" + 0.142*"earlier" + -0.137*"process" + 0.135*"cost" + '
#   '-0.134*"prevailing" + 0.130*"possible"'),
#  (32,
#   '-0.209*"position" + 0.163*"programme" + -0.160*"increasing" + '
#   '0.153*"gradual" + 0.151*"fall" + -0.149*"deficit" + -0.149*"take" + '
#   '-0.145*"international" + 0.139*"november" + -0.138*"observed"'),
#  (33,
#   '0.189*"significantly" + -0.182*"production" + 0.173*"august" + '
#   '0.172*"position" + 0.170*"side" + -0.162*"next" + 0.160*"november" + '
#   '0.154*"short" + -0.141*"process" + 0.134*"state"'),
#  (34,
#   '-0.199*"firm" + 0.195*"take" + 0.171*"subdued" + -0.166*"prospect" + '
#   '0.162*"programme" + 0.159*"service" + -0.155*"downward" + -0.143*"gradual" '
#   '+ -0.142*"state" + 0.139*"tension"'),
#  (35,
#   '0.237*"asset" + -0.207*"situation" + -0.170*"firm" + -0.160*"exchange" + '
#   '-0.158*"gradually" + -0.156*"needed" + -0.152*"half" + 0.151*"early" + '
#   '0.149*"seen" + -0.143*"lead"'),
#  (36,
#   '-0.231*"average" + -0.176*"lower" + -0.173*"service" + 0.166*"process" + '
#   '0.163*"september" + -0.158*"deficit" + 0.134*"sound" + 0.133*"two" + '
#   '0.132*"february" + -0.131*"reflects"'),
#  (37,
#   '0.217*"confirmed" + 0.216*"prevailing" + -0.159*"july" + -0.149*"give" + '
#   '-0.147*"national" + 0.141*"next" + -0.138*"needed" + -0.138*"volatility" + '
#   '-0.135*"trend" + 0.131*"slightly"'),
#  (38,
#   '-0.189*"course" + -0.175*"case" + -0.165*"asset" + -0.159*"challenge" + '
#   '-0.150*"accordingly" + 0.146*"short" + -0.143*"foster" + -0.138*"confirmed" '
#   '+ 0.138*"across" + 0.137*"plan"'),
#  (39,
#   '0.240*"strongly" + 0.203*"contribute" + 0.197*"trend" + 0.153*"service" + '
#   '-0.141*"end" + -0.135*"state" + -0.135*"further" + -0.134*"assumption" + '
#   '0.134*"forecast" + 0.132*"lower"'),
#  (40,
#   '0.190*"slightly" + 0.166*"august" + 0.159*"framework" + -0.149*"february" + '
#   '0.148*"november" + 0.147*"already" + -0.141*"service" + 0.141*"prevailing" '
#   '+ -0.139*"confirmed" + -0.132*"somewhat"'),
#  (41,
#   '0.200*"process" + 0.160*"although" + -0.159*"major" + 0.159*"within" + '
#   '0.156*"april" + 0.154*"observed" + -0.146*"seen" + -0.141*"needed" + '
#   '-0.141*"accommodative" + 0.135*"effective"'),
#  (42,
#   '-0.186*"reflects" + -0.181*"volatility" + -0.178*"consumer" + -0.172*"full" '
#   '+ -0.157*"cost" + 0.149*"background" + 0.148*"prospect" + -0.145*"fully" + '
#   '0.142*"reflected" + 0.140*"owing"'),
#  (43,
#   '-0.204*"framework" + 0.199*"cost" + 0.177*"third" + -0.162*"turn" + '
#   '0.148*"sign" + -0.143*"commission" + 0.141*"within" + -0.140*"foster" + '
#   '0.139*"longer" + 0.138*"november"'),
#  (44,
#   '-0.240*"release" + 0.195*"projected" + 0.169*"objective" + -0.162*"next" + '
#   '0.161*"declined" + -0.157*"momentum" + 0.152*"turn" + 0.152*"exchange" + '
#   '-0.139*"end" + -0.130*"world"'),
#  (45,
#   '0.189*"owing" + 0.186*"contribute" + 0.183*"far" + -0.178*"programme" + '
#   '0.171*"march" + -0.168*"background" + 0.159*"significantly" + -0.156*"must" '
#   '+ 0.151*"july" + -0.149*"weak"'),
#  (46,
#   '0.192*"asset" + 0.160*"reduce" + -0.156*"owing" + 0.150*"next" + '
#   '0.148*"help" + -0.140*"possible" + -0.138*"programme" + 0.138*"signal" + '
#   '-0.135*"negative" + 0.129*"february"'),
#  (47,
#   '0.241*"good" + -0.213*"system" + 0.192*"slightly" + -0.182*"consumer" + '
#   '0.171*"start" + 0.165*"lending" + 0.163*"somewhat" + 0.150*"prospect" + '
#   '-0.138*"position" + -0.138*"moderation"'),
#  (48,
#   '0.231*"contribute" + 0.187*"early" + -0.185*"suggest" + 0.180*"end" + '
#   '0.161*"observed" + 0.155*"sign" + -0.144*"march" + -0.137*"production" + '
#   '0.132*"partly" + -0.132*"take"'),
#  (49,
#   '-0.237*"forecast" + -0.176*"commitment" + 0.163*"early" + 0.163*"lower" + '
#   '-0.155*"end" + 0.153*"due" + -0.144*"international" + 0.137*"deficit" + '
#   '0.136*"earlier" + -0.132*"related"'),
#  (50,
#   '-0.177*"component" + 0.166*"sign" + -0.165*"owing" + 0.153*"like" + '
#   '-0.151*"cost" + 0.151*"budgetary" + 0.140*"remaining" + 0.133*"increasing" '
#   '+ 0.133*"productivity" + 0.123*"commodity"'),
#  (51,
#   '0.252*"background" + -0.206*"possible" + 0.162*"fourth" + 0.160*"deficit" + '
#   '0.156*"around" + 0.156*"pillar" + 0.145*"weaker" + 0.141*"evidence" + '
#   '0.139*"lower" + 0.139*"cost"'),
#  (52,
#   '0.180*"two" + 0.172*"framework" + -0.160*"process" + -0.160*"march" + '
#   '0.157*"challenge" + 0.148*"reflected" + -0.147*"deficit" + 0.144*"help" + '
#   '0.142*"commodity" + -0.140*"thus"'),
#  (53,
#   '-0.209*"reflects" + 0.194*"cost" + 0.157*"owing" + 0.157*"suggest" + '
#   '0.156*"next" + 0.142*"september" + -0.139*"declined" + -0.137*"around" + '
#   '-0.136*"needed" + -0.131*"effective"'),
#  (54,
#   '0.216*"productivity" + 0.188*"two" + -0.172*"due" + -0.163*"contribute" + '
#   '0.150*"assumption" + 0.148*"competition" + 0.143*"projected" + '
#   '-0.141*"slightly" + -0.132*"fact" + -0.131*"momentum"'),
#  (55,
#   '-0.209*"cost" + -0.196*"evidence" + -0.189*"commitment" + -0.184*"reflect" '
#   '+ 0.175*"somewhat" + -0.168*"lead" + -0.157*"challenge" + 0.148*"two" + '
#   '0.132*"firm" + -0.130*"respect"'),
#  (56,
#   '0.190*"confirmed" + -0.183*"relatively" + -0.158*"banking" + '
#   '-0.156*"slightly" + -0.156*"including" + 0.153*"end" + -0.150*"january" + '
#   '0.146*"moderation" + -0.139*"budget" + 0.137*"february"'),
#  (57,
#   '0.176*"consumer" + -0.165*"sustained" + 0.165*"system" + 0.155*"signal" + '
#   '-0.154*"end" + 0.151*"position" + -0.150*"made" + 0.147*"national" + '
#   '0.142*"firm" + -0.138*"cost"'),
#  (58,
#   '0.205*"one" + -0.204*"additional" + -0.195*"lead" + -0.195*"related" + '
#   '-0.170*"forecast" + -0.144*"union" + 0.134*"framework" + '
#   '-0.133*"perspective" + 0.132*"service" + -0.132*"eu"'),
#  (59,
#   '-0.176*"stemming" + -0.172*"reduce" + -0.159*"like" + 0.154*"food" + '
#   '-0.153*"sustained" + -0.153*"somewhat" + -0.145*"confirmed" + '
#   '0.143*"general" + 0.142*"projected" + 0.139*"commodity"'),
#  (60,
#   '-0.211*"additional" + -0.177*"exchange" + -0.173*"longterm" + '
#   '0.165*"effort" + 0.145*"continuing" + -0.143*"finance" + 0.142*"moderation" '
#   '+ -0.141*"debt" + -0.139*"owing" + -0.136*"gradual"'),
#  (61,
#   '-0.220*"effective" + -0.209*"july" + -0.163*"next" + 0.146*"june" + '
#   '0.145*"short" + -0.145*"further" + 0.144*"situation" + -0.137*"already" + '
#   '-0.135*"scenario" + 0.131*"stemming"'),
#  (62,
#   '0.228*"somewhat" + 0.171*"early" + -0.154*"objective" + 0.152*"clearly" + '
#   '0.147*"signal" + 0.146*"projected" + -0.140*"weak" + 0.137*"temporary" + '
#   '-0.134*"reduce" + -0.133*"improve"'),
#  (63,
#   '-0.167*"full" + -0.164*"prevailing" + -0.138*"end" + 0.138*"deposit" + '
#   '-0.134*"indicates" + -0.134*"lead" + 0.128*"finance" + -0.124*"furthermore" '
#   '+ -0.121*"prospect" + 0.121*"observed"'),
#  (64,
#   '-0.225*"world" + 0.179*"evidence" + -0.154*"balanced" + '
#   '-0.138*"competitiveness" + 0.136*"short" + -0.133*"respect" + '
#   '-0.131*"result" + 0.128*"national" + -0.125*"lower" + 0.125*"longterm"'),
#  (65,
#   '0.189*"projected" + 0.183*"pillar" + 0.181*"reduce" + 0.174*"trend" + '
#   '0.169*"cost" + 0.157*"accommodative" + -0.152*"special" + 0.135*"plan" + '
#   '0.131*"comprehensive" + 0.129*"furthermore"'),
#  (66,
#   '-0.182*"fully" + 0.173*"general" + -0.169*"must" + -0.160*"service" + '
#   '0.152*"challenge" + 0.150*"accordingly" + -0.141*"state" + -0.139*"two" + '
#   '0.136*"output" + -0.136*"framework"'),
#  (67,
#   '-0.196*"commodity" + 0.183*"two" + -0.148*"october" + -0.147*"commitment" + '
#   '0.144*"reduction" + 0.143*"long" + 0.142*"gradually" + 0.140*"accordingly" '
#   '+ -0.139*"suggest" + -0.136*"although"'),
#  (68,
#   '0.233*"reflected" + -0.206*"perspective" + -0.191*"continuing" + '
#   '0.187*"trend" + -0.169*"around" + -0.154*"needed" + 0.144*"lower" + '
#   '-0.130*"general" + 0.127*"production" + 0.124*"deposit"'),
#  (69,
#   '0.172*"increasing" + 0.166*"together" + 0.158*"robust" + -0.146*"sign" + '
#   '0.145*"signal" + -0.145*"general" + -0.132*"reflects" + -0.131*"firm" + '
#   '-0.129*"case" + -0.128*"seen"'),
#  (70,
#   '-0.201*"commission" + -0.174*"help" + 0.166*"already" + -0.154*"reflects" + '
#   '-0.147*"like" + 0.142*"shift" + 0.141*"october" + -0.140*"general" + '
#   '-0.139*"turn" + -0.132*"recently"'),
#  (71,
#   '0.161*"further" + 0.155*"robust" + -0.152*"enhance" + 0.149*"budgetary" + '
#   '0.147*"end" + -0.146*"early" + -0.135*"seen" + -0.135*"projected" + '
#   '-0.133*"accordingly" + 0.129*"partly"'),
#  (72,
#   '0.205*"help" + -0.183*"fact" + -0.163*"related" + -0.162*"turn" + '
#   '-0.159*"march" + 0.152*"shock" + -0.145*"take" + 0.136*"situation" + '
#   '0.134*"fully" + 0.133*"monitoring"'),
#  (73,
#   '0.209*"budgetary" + -0.186*"prevailing" + -0.161*"result" + '
#   '-0.160*"sustained" + -0.156*"contribution" + 0.148*"service" + '
#   '-0.144*"thus" + 0.142*"contribute" + 0.137*"provide" + -0.133*"increasing"'),
#  (74,
#   '-0.241*"recently" + -0.182*"strongly" + -0.161*"programme" + -0.160*"half" '
#   '+ -0.145*"budgetary" + -0.137*"subject" + 0.136*"fact" + -0.134*"fully" + '
#   '0.134*"side" + 0.133*"far"'),
#  (75,
#   '0.215*"slightly" + -0.177*"revised" + -0.162*"half" + 0.152*"food" + '
#   '-0.152*"moderation" + 0.149*"several" + 0.146*"projected" + '
#   '0.144*"perspective" + -0.140*"including" + -0.138*"see"'),
#  (76,
#   '0.192*"volatility" + -0.178*"remaining" + 0.153*"give" + '
#   '-0.153*"comprehensive" + -0.152*"opportunity" + -0.152*"around" + '
#   '-0.147*"already" + -0.134*"improve" + 0.125*"general" + -0.125*"together"'),
#  (77,
#   '-0.186*"budget" + -0.185*"substantial" + -0.165*"plan" + -0.158*"major" + '
#   '0.155*"early" + 0.149*"prevailing" + -0.138*"end" + 0.130*"present" + '
#   '0.125*"recently" + -0.123*"made"'),
#  (78,
#   '0.173*"april" + 0.169*"budgetary" + -0.164*"finance" + 0.147*"position" + '
#   '-0.147*"deposit" + -0.144*"including" + 0.143*"expenditure" + '
#   '0.133*"partly" + -0.132*"tension" + -0.130*"full"'),
#  (79,
#   '-0.201*"result" + 0.188*"fully" + 0.147*"banking" + -0.145*"union" + '
#   '0.143*"short" + 0.138*"relating" + -0.133*"next" + -0.130*"somewhat" + '
#   '-0.125*"fall" + 0.122*"prospect"'),
#  (80,
#   '-0.190*"confirmed" + 0.183*"september" + 0.168*"process" + -0.155*"pillar" '
#   '+ -0.152*"commission" + -0.142*"october" + 0.137*"gradual" + '
#   '-0.124*"budgetary" + -0.123*"production" + 0.117*"reduce"'),
#  (81,
#   '-0.176*"position" + 0.169*"result" + -0.168*"one" + 0.160*"base" + '
#   '0.157*"indicates" + -0.154*"adjusted" + 0.140*"strengthened" + '
#   '0.136*"start" + -0.130*"respect" + -0.129*"production"'),
#  (82,
#   '0.205*"far" + 0.172*"recently" + 0.159*"situation" + -0.156*"indicate" + '
#   '0.146*"half" + 0.146*"functioning" + -0.143*"subdued" + -0.133*"take" + '
#   '0.133*"action" + 0.124*"prevailing"'),
#  (83,
#   '0.176*"sustained" + -0.174*"effort" + -0.161*"result" + 0.157*"robust" + '
#   '-0.145*"generally" + -0.144*"prospect" + -0.143*"moderation" + '
#   '0.142*"ensuring" + 0.131*"conducted" + 0.128*"seen"'),
#  (84,
#   '-0.163*"process" + -0.156*"finance" + -0.151*"give" + -0.149*"effort" + '
#   '-0.144*"weaker" + 0.141*"stemming" + -0.138*"capacity" + '
#   '0.135*"contribution" + 0.134*"system" + 0.126*"finally"'),
#  (85,
#   '-0.259*"slightly" + 0.176*"due" + -0.159*"one" + 0.149*"sustained" + '
#   '-0.143*"shock" + 0.142*"comprehensive" + -0.131*"outside" + '
#   '-0.130*"strengthened" + -0.124*"lead" + -0.121*"manner"'),
#  (86,
#   '0.165*"clearly" + -0.161*"relating" + -0.150*"consumer" + -0.147*"monthly" '
#   '+ -0.146*"gradually" + -0.145*"renewed" + 0.141*"see" + 0.140*"situation" + '
#   '-0.138*"significantly" + -0.128*"already"'),
#  (87,
#   '-0.234*"situation" + -0.192*"shock" + -0.179*"enhance" + -0.157*"union" + '
#   '-0.151*"framework" + 0.141*"borrowing" + -0.130*"generally" + 0.130*"must" '
#   '+ 0.129*"fully" + 0.128*"negative"'),
#  (88,
#   '0.153*"cost" + -0.150*"revised" + 0.148*"borrowing" + -0.147*"improve" + '
#   '0.144*"position" + 0.140*"budgetary" + -0.138*"commitment" + 0.137*"union" '
#   '+ 0.137*"challenge" + 0.135*"prospect"'),
#  (89,
#   '0.164*"further" + 0.160*"union" + 0.131*"clearly" + -0.128*"functioning" + '
#   '-0.126*"temporary" + 0.120*"sign" + 0.118*"suggest" + -0.117*"output" + '
#   '-0.115*"substantial" + -0.112*"weak"'),
#  (90,
#   '-0.222*"continuing" + -0.211*"competitiveness" + -0.186*"union" + '
#   '0.182*"challenge" + 0.165*"yield" + 0.153*"turn" + 0.145*"moderation" + '
#   '0.137*"next" + -0.129*"lending" + -0.127*"within"'),
#  (91,
#   '-0.198*"allow" + 0.163*"anticipated" + 0.160*"made" + 0.150*"stemming" + '
#   '0.141*"union" + 0.140*"gradually" + 0.136*"including" + '
#   '-0.136*"organisation" + 0.134*"ensuring" + -0.132*"regarding"'),
#  (92,
#   '0.183*"anticipated" + 0.175*"job" + 0.153*"commodity" + 0.149*"within" + '
#   '-0.138*"evolution" + 0.134*"regarding" + 0.134*"several" + '
#   '-0.133*"exchange" + -0.130*"functioning" + -0.129*"recently"'),
#  (93,
#   '-0.223*"moderation" + -0.149*"improved" + -0.142*"efficiency" + '
#   '0.136*"course" + 0.129*"forecast" + -0.125*"balanced" + -0.124*"plan" + '
#   '-0.124*"august" + 0.118*"ratio" + 0.118*"observed"'),
#  (94,
#   '0.182*"significantly" + -0.176*"ratio" + 0.164*"capacity" + -0.161*"way" + '
#   '0.157*"manner" + 0.156*"timely" + 0.155*"picture" + 0.147*"partly" + '
#   '0.145*"le" + -0.143*"lead"'),
#  (95,
#   '0.157*"fully" + 0.155*"help" + 0.148*"accordingly" + 0.146*"production" + '
#   '0.141*"needed" + -0.140*"commission" + -0.137*"announced" + 0.129*"staff" + '
#   '0.129*"fact" + 0.128*"effort"'),
#  (96,
#   '-0.217*"situation" + -0.167*"owing" + 0.166*"sign" + 0.164*"accordingly" + '
#   '-0.144*"longterm" + -0.144*"effort" + 0.141*"subdued" + -0.139*"deposit" + '
#   '0.129*"although" + -0.127*"assumption"'),
#  (97,
#   '0.174*"scenario" + 0.167*"average" + 0.151*"gradual" + 0.138*"turn" + '
#   '0.137*"improved" + -0.136*"robust" + 0.135*"increasing" + -0.131*"suggest" '
#   '+ 0.130*"member" + 0.125*"reflected"'),
#  (98,
#   '0.186*"made" + -0.167*"effort" + -0.160*"budget" + 0.147*"outside" + '
#   '0.141*"present" + -0.138*"flow" + 0.133*"timely" + -0.129*"downward" + '
#   '0.127*"lower" + -0.126*"aggregate"'),
#  (99,
#   '-0.177*"challenge" + -0.165*"objective" + 0.160*"base" + 0.156*"effective" '
#   '+ -0.153*"lower" + 0.150*"maintain" + -0.138*"full" + -0.137*"fall" + '
#   '-0.135*"within" + 0.135*"across"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lsi5 = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi5 = coherence_model_lsi5.get_coherence()
print('\nCoherence Score5: ', coherence_lsi5)

# Compute Coherence Score
coherence_model_lsi10 = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi10 = coherence_model_lsi10.get_coherence()
print('\nCoherence Score10: ', coherence_lsi10)

# Compute Coherence Score
coherence_model_lsi20 = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi20 = coherence_model_lsi20.get_coherence()
print('\nCoherence Score20: ', coherence_lsi20)

# Compute Coherence Score
coherence_model_lsi50 = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi50 = coherence_model_lsi50.get_coherence()
print('\nCoherence Score50: ', coherence_lsi50)

# Compute Coherence Score
coherence_model_lsi100 = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi100 = coherence_model_lsi100.get_coherence()
print('\nCoherence Score100: ', coherence_lsi100)


# Compute Coherence Score
coherence_model_lsi5 = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi5 = coherence_model_lsi5.get_coherence()
print('\nCoherence Score5: ', coherence_lsi5)

# Compute Coherence Score
coherence_model_lsi10 = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi10 = coherence_model_lsi10.get_coherence()
print('\nCoherence Score10: ', coherence_lsi10)

# Compute Coherence Score
coherence_model_lsi20 = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi20 = coherence_model_lsi20.get_coherence()
print('\nCoherence Score20: ', coherence_lsi20)

# Compute Coherence Score
coherence_model_lsi50 = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi50 = coherence_model_lsi50.get_coherence()
print('\nCoherence Score50: ', coherence_lsi50)

# Compute Coherence Score
coherence_model_lsi100 = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi100 = coherence_model_lsi100.get_coherence()
print('\nCoherence Score100: ', coherence_lsi100)
# Out:
# Coherence Score5:  0.32322063484996993
#
# Coherence Score10:  0.30020098588668886
#
# Coherence Score20:  0.24625805104829385
#
# Coherence Score50:  0.20002243868209507
#
# Coherence Score100:  0.18365547422664047
#
# Coherence Score5:  -0.7715729839915296
#
# Coherence Score10:  -0.8579902824117237
#
# Coherence Score20:  -0.9045229406643511
#
# Coherence Score50:  -0.9645245978908008
#
# Coherence Score100:  -0.9880431201896213
