# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['Press']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(4394 unique tokens: ['able', 'acceptable', 'accompanied', 'according', 'account']...)

# %%
texts = data
# less than 10 documents,
id2word = corpora.Dictionary(texts)
id2word.filter_extremes(no_below = 50)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=1, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
lda_model5 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model10 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model20 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model50 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=50, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model100 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=100, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\models\ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
# Print the Keyword in the 1 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.018*"projection" + 0.016*"staff" + 0.014*"june" + 0.013*"march" + '
#   '0.011*"asset" + 0.010*"sustained" + 0.010*"accommodative" + '
#   '0.010*"contribute" + 0.009*"september" + 0.009*"across"')]

# %%
# Print the Keyword in the 5 topics
pprint(lda_model5.print_topics())
doc_lda = lda_model5[corpus]

# Print the Keyword in the 10 topics
pprint(lda_model10.print_topics())
doc_lda = lda_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lda_model20.print_topics())
doc_lda = lda_model20[corpus]

# Print the Keyword in the 50 topics
pprint(lda_model50.print_topics())
doc_lda = lda_model50[corpus]

# Print the Keyword in the 100 topics
pprint(lda_model100.print_topics())
doc_lda = lda_model100[corpus]
# Out:
# [(0,
#   '0.015*"consumer" + 0.012*"trend" + 0.011*"world" + 0.010*"january" + '
#   '0.009*"course" + 0.009*"average" + 0.009*"december" + 0.009*"food" + '
#   '0.009*"member" + 0.009*"state"'),
#  (1,
#   '0.025*"projection" + 0.025*"staff" + 0.023*"asset" + 0.023*"june" + '
#   '0.022*"sustained" + 0.020*"across" + 0.019*"accommodative" + '
#   '0.015*"objective" + 0.015*"september" + 0.015*"contribute"'),
#  (2,
#   '0.019*"subdued" + 0.017*"commodity" + 0.016*"below" + 0.015*"aim" + '
#   '0.015*"to" + 0.014*"weak" + 0.014*"tension" + 0.013*"negative" + '
#   '0.012*"operation" + 0.011*"owing"'),
#  (3,
#   '0.080*"march" + 0.065*"april" + 0.033*"operation" + 0.031*"sale" + '
#   '0.028*"adjusted" + 0.028*"securitisation" + 0.025*"june" + '
#   '0.023*"refinancing" + 0.021*"staff" + 0.021*"contribute"'),
#  (4,
#   '0.071*"projection" + 0.048*"staff" + 0.020*"projected" + 0.018*"firm" + '
#   '0.016*"longer" + 0.015*"revised" + 0.013*"ample" + 0.012*"assumption" + '
#   '0.012*"timely" + 0.012*"forecast"')]
# [(0,
#   '0.018*"consumer" + 0.016*"trend" + 0.011*"food" + 0.011*"world" + '
#   '0.010*"course" + 0.010*"average" + 0.010*"background" + 0.010*"exchange" + '
#   '0.010*"member" + 0.010*"evidence"'),
#  (1,
#   '0.004*"pillar" + 0.004*"production" + 0.004*"two" + 0.004*"moderation" + '
#   '0.004*"like" + 0.004*"trend" + 0.004*"national" + 0.004*"forecast" + '
#   '0.004*"consumer" + 0.004*"member"'),
#  (2,
#   '0.058*"subdued" + 0.032*"weak" + 0.026*"gradual" + 0.022*"negative" + '
#   '0.021*"weaker" + 0.020*"needed" + 0.019*"below" + 0.019*"picture" + '
#   '0.018*"to" + 0.017*"aim"'),
#  (3,
#   '0.059*"march" + 0.058*"april" + 0.046*"june" + 0.029*"adjusted" + '
#   '0.029*"sale" + 0.029*"securitisation" + 0.024*"operation" + '
#   '0.021*"including" + 0.021*"contribute" + 0.020*"to"'),
#  (4,
#   '0.147*"august" + 0.070*"july" + 0.054*"september" + 0.036*"negative" + '
#   '0.033*"deposit" + 0.032*"to" + 0.029*"adverse" + 0.028*"below" + '
#   '0.026*"third" + 0.023*"full"'),
#  (5,
#   '0.032*"asset" + 0.031*"sustained" + 0.024*"across" + 0.024*"accommodative" '
#   '+ 0.021*"objective" + 0.019*"improve" + 0.019*"programme" + 0.016*"gradual" '
#   '+ 0.016*"contribute" + 0.016*"staff"'),
#  (6,
#   '0.100*"projection" + 0.083*"staff" + 0.033*"march" + 0.029*"revised" + '
#   '0.023*"reflected" + 0.021*"across" + 0.020*"corporate" + 0.018*"sustained" '
#   '+ 0.017*"contribute" + 0.017*"lower"'),
#  (7,
#   '0.028*"commodity" + 0.021*"tension" + 0.018*"anchoring" + 0.016*"longer" + '
#   '0.014*"policyrelevant" + 0.014*"owing" + 0.013*"momentum" + 0.012*"firm" + '
#   '0.012*"competitiveness" + 0.012*"process"'),
#  (8,
#   '0.061*"december" + 0.058*"october" + 0.045*"january" + 0.044*"operation" + '
#   '0.037*"september" + 0.034*"november" + 0.028*"refinancing" + '
#   '0.021*"national" + 0.021*"conducted" + 0.021*"one"'),
#  (9,
#   '0.063*"june" + 0.058*"july" + 0.036*"staff" + 0.032*"projection" + '
#   '0.017*"september" + 0.017*"to" + 0.016*"substantial" + 0.016*"full" + '
#   '0.015*"below" + 0.015*"including"')]
# [(0,
#   '0.034*"commodity" + 0.024*"tension" + 0.020*"policyrelevant" + '
#   '0.017*"negative" + 0.015*"anchoring" + 0.015*"balanced" + 0.014*"take" + '
#   '0.014*"aim" + 0.014*"process" + 0.013*"owing"'),
#  (1,
#   '0.004*"trend" + 0.004*"pillar" + 0.004*"reflected" + 0.004*"relating" + '
#   '0.004*"opportunity" + 0.004*"moderation" + 0.004*"august" + 0.004*"course" '
#   '+ 0.004*"background" + 0.004*"consumer"'),
#  (2,
#   '0.004*"tension" + 0.004*"september" + 0.004*"august" + 0.004*"weaker" + '
#   '0.004*"reduce" + 0.004*"including" + 0.004*"pillar" + 0.004*"october" + '
#   '0.004*"adverse" + 0.004*"challenge"'),
#  (3,
#   '0.004*"april" + 0.004*"march" + 0.004*"course" + 0.004*"consumer" + '
#   '0.004*"union" + 0.004*"challenge" + 0.004*"somewhat" + 0.004*"finance" + '
#   '0.004*"exchange" + 0.004*"maintain"'),
#  (4,
#   '0.016*"ample" + 0.015*"forecast" + 0.012*"finance" + 0.012*"side" + '
#   '0.011*"longer" + 0.011*"deficit" + 0.011*"trend" + 0.010*"scenario" + '
#   '0.010*"contribution" + 0.010*"respect"'),
#  (5,
#   '0.004*"projection" + 0.004*"due" + 0.004*"staff" + 0.004*"average" + '
#   '0.004*"finance" + 0.004*"pillar" + 0.004*"robust" + 0.004*"trend" + '
#   '0.004*"scenario" + 0.004*"gradual"'),
#  (6,
#   '0.061*"march" + 0.052*"april" + 0.035*"staff" + 0.034*"june" + '
#   '0.031*"projection" + 0.024*"contribute" + 0.024*"across" + 0.016*"improved" '
#   '+ 0.014*"lower" + 0.014*"including"'),
#  (7,
#   '0.004*"ample" + 0.004*"longer" + 0.004*"projection" + 0.004*"already" + '
#   '0.004*"confirmed" + 0.004*"projected" + 0.004*"staff" + 0.004*"finance" + '
#   '0.004*"contribution" + 0.004*"scenario"'),
#  (8,
#   '0.007*"december" + 0.006*"november" + 0.005*"announced" + 0.005*"tension" + '
#   '0.004*"contribution" + 0.004*"october" + 0.004*"already" + 0.004*"include" '
#   '+ 0.004*"third" + 0.004*"operation"'),
#  (9,
#   '0.004*"projection" + 0.004*"consumer" + 0.004*"state" + '
#   '0.004*"policyrelevant" + 0.004*"reflects" + 0.004*"december" + '
#   '0.004*"november" + 0.004*"one" + 0.004*"side" + 0.004*"already"'),
#  (10,
#   '0.004*"consumer" + 0.004*"course" + 0.004*"revised" + 0.004*"due" + '
#   '0.004*"like" + 0.004*"ample" + 0.004*"exchange" + 0.004*"international" + '
#   '0.004*"trend" + 0.004*"position"'),
#  (11,
#   '0.026*"august" + 0.023*"including" + 0.022*"june" + 0.022*"accommodative" + '
#   '0.020*"across" + 0.018*"to" + 0.018*"july" + 0.017*"sustained" + '
#   '0.017*"full" + 0.017*"improve"'),
#  (12,
#   '0.004*"january" + 0.004*"consumer" + 0.004*"lower" + 0.004*"average" + '
#   '0.004*"pillar" + 0.004*"budgetary" + 0.004*"good" + 0.004*"exchange" + '
#   '0.004*"december" + 0.004*"world"'),
#  (13,
#   '0.127*"subdued" + 0.066*"weak" + 0.047*"gradual" + 0.040*"picture" + '
#   '0.036*"needed" + 0.036*"long" + 0.027*"effort" + 0.026*"recover" + '
#   '0.025*"resilience" + 0.023*"indicates"'),
#  (14,
#   '0.020*"food" + 0.020*"volatility" + 0.019*"secondround" + 0.017*"sound" + '
#   '0.016*"background" + 0.016*"firm" + 0.015*"thus" + 0.014*"competition" + '
#   '0.014*"objective" + 0.014*"significantly"'),
#  (15,
#   '0.034*"position" + 0.032*"ratio" + 0.031*"june" + 0.029*"way" + '
#   '0.028*"made" + 0.023*"exchange" + 0.022*"commitment" + 0.022*"debt" + '
#   '0.021*"early" + 0.021*"perspective"'),
#  (16,
#   '0.004*"august" + 0.004*"september" + 0.004*"july" + 0.004*"situation" + '
#   '0.004*"output" + 0.004*"decisive" + 0.004*"way" + 0.004*"made" + '
#   '0.004*"production" + 0.004*"adjusted"'),
#  (17,
#   '0.025*"january" + 0.021*"december" + 0.019*"consumer" + 0.018*"operation" + '
#   '0.015*"november" + 0.015*"system" + 0.014*"banking" + 0.014*"national" + '
#   '0.013*"average" + 0.013*"pillar"'),
#  (18,
#   '0.063*"projection" + 0.057*"staff" + 0.038*"september" + 0.027*"asset" + '
#   '0.026*"reflected" + 0.024*"sustained" + 0.023*"june" + 0.021*"programme" + '
#   '0.020*"july" + 0.018*"october"'),
#  (19,
#   '0.059*"to" + 0.048*"sale" + 0.044*"operation" + 0.035*"refinancing" + '
#   '0.033*"adjusted" + 0.029*"below" + 0.026*"aim" + 0.025*"securitisation" + '
#   '0.025*"accommodative" + 0.024*"flow"')]
# [(1,
#   '0.004*"pillar" + 0.004*"trend" + 0.004*"average" + 0.004*"moderation" + '
#   '0.004*"early" + 0.004*"reflected" + 0.004*"course" + 0.004*"food" + '
#   '0.004*"position" + 0.004*"opportunity"'),
#  (10,
#   '0.004*"consumer" + 0.004*"pillar" + 0.004*"related" + 0.004*"lower" + '
#   '0.004*"effort" + 0.004*"mr" + 0.004*"reflects" + 0.004*"trend" + '
#   '0.004*"contribute" + 0.004*"process"'),
#  (44,
#   '0.004*"september" + 0.004*"consumer" + 0.004*"contribute" + 0.004*"way" + '
#   '0.004*"help" + 0.004*"november" + 0.004*"december" + 0.004*"situation" + '
#   '0.004*"side" + 0.004*"ample"'),
#  (16,
#   '0.004*"operation" + 0.004*"december" + 0.004*"member" + 0.004*"september" + '
#   '0.004*"general" + 0.004*"november" + 0.004*"good" + 0.004*"trend" + '
#   '0.004*"contribute" + 0.004*"release"'),
#  (29,
#   '0.004*"national" + 0.004*"january" + 0.004*"system" + 0.004*"exchange" + '
#   '0.004*"member" + 0.004*"state" + 0.004*"one" + 0.004*"world" + '
#   '0.004*"average" + 0.004*"respect"'),
#  (2,
#   '0.004*"member" + 0.004*"pillar" + 0.004*"state" + 0.004*"position" + '
#   '0.004*"programme" + 0.004*"staff" + 0.004*"national" + 0.004*"situation" + '
#   '0.004*"shock" + 0.004*"background"'),
#  (9,
#   '0.004*"policyrelevant" + 0.004*"june" + 0.004*"union" + 0.004*"competition" '
#   '+ 0.004*"accommodative" + 0.004*"improve" + 0.004*"provision" + '
#   '0.004*"competitiveness" + 0.004*"reflected" + 0.004*"firm"'),
#  (48,
#   '0.004*"trend" + 0.004*"thus" + 0.004*"consumer" + 0.004*"within" + '
#   '0.004*"position" + 0.004*"july" + 0.004*"average" + 0.004*"framework" + '
#   '0.004*"cost" + 0.004*"result"'),
#  (5,
#   '0.004*"situation" + 0.004*"state" + 0.004*"november" + 0.004*"projection" + '
#   '0.004*"system" + 0.004*"member" + 0.004*"framework" + 0.004*"world" + '
#   '0.004*"average" + 0.004*"present"'),
#  (40,
#   '0.004*"world" + 0.004*"two" + 0.004*"moderation" + 0.004*"consumer" + '
#   '0.004*"exchange" + 0.004*"longer" + 0.004*"gradual" + 0.004*"effort" + '
#   '0.004*"sustained" + 0.004*"pillar"'),
#  (37,
#   '0.120*"february" + 0.076*"operation" + 0.063*"march" + 0.059*"refinancing" '
#   '+ 0.059*"exchange" + 0.045*"january" + 0.044*"lending" + 0.029*"emerging" + '
#   '0.026*"threemonth" + 0.026*"general"'),
#  (8,
#   '0.115*"october" + 0.080*"programme" + 0.077*"december" + 0.065*"sustained" '
#   '+ 0.062*"september" + 0.059*"remaining" + 0.042*"november" + 0.033*"result" '
#   '+ 0.031*"contribute" + 0.028*"fourth"'),
#  (30,
#   '0.092*"projection" + 0.059*"staff" + 0.030*"projected" + 0.027*"commodity" '
#   '+ 0.022*"firm" + 0.021*"sound" + 0.019*"secondround" + 0.017*"revised" + '
#   '0.016*"background" + 0.016*"forecast"'),
#  (27,
#   '0.059*"subdued" + 0.047*"tension" + 0.043*"weak" + 0.043*"aim" + '
#   '0.039*"negative" + 0.036*"below" + 0.030*"needed" + 0.027*"weaker" + '
#   '0.024*"long" + 0.022*"process"'),
#  (17,
#   '0.030*"system" + 0.026*"operation" + 0.025*"national" + 0.020*"one" + '
#   '0.019*"downward" + 0.019*"november" + 0.018*"banking" + 0.018*"deposit" + '
#   '0.016*"related" + 0.016*"release"'),
#  (22,
#   '0.029*"commodity" + 0.022*"policyrelevant" + 0.022*"balanced" + '
#   '0.020*"anchoring" + 0.019*"competitiveness" + 0.019*"longer" + 0.016*"job" '
#   '+ 0.015*"cost" + 0.015*"momentum" + 0.015*"volatility"'),
#  (39,
#   '0.022*"consumer" + 0.016*"food" + 0.016*"trend" + 0.012*"pillar" + '
#   '0.012*"moderation" + 0.011*"average" + 0.011*"position" + '
#   '0.011*"background" + 0.010*"course" + 0.010*"forecast"'),
#  (23,
#   '0.055*"projection" + 0.048*"staff" + 0.048*"july" + 0.042*"september" + '
#   '0.038*"august" + 0.035*"asset" + 0.029*"substantial" + 0.023*"june" + '
#   '0.022*"reflected" + 0.022*"end"'),
#  (19,
#   '0.056*"to" + 0.051*"cycle" + 0.050*"objective" + 0.049*"flow" + '
#   '0.048*"dampened" + 0.040*"union" + 0.031*"full" + 0.027*"large" + '
#   '0.026*"sale" + 0.024*"monthly"'),
#  (24,
#   '0.037*"march" + 0.035*"june" + 0.027*"accommodative" + 0.025*"april" + '
#   '0.024*"contribute" + 0.022*"staff" + 0.021*"across" + 0.019*"full" + '
#   '0.018*"projection" + 0.017*"creation"')]
# [(59,
#   '0.004*"september" + 0.004*"revised" + 0.004*"tension" + 0.004*"temporary" + '
#   '0.004*"sustained" + 0.004*"significantly" + 0.004*"service" + '
#   '0.004*"adjusted" + 0.004*"seen" + 0.004*"related"'),
#  (60,
#   '0.004*"september" + 0.004*"revised" + 0.004*"tension" + 0.004*"temporary" + '
#   '0.004*"sustained" + 0.004*"significantly" + 0.004*"service" + '
#   '0.004*"adjusted" + 0.004*"seen" + 0.004*"related"'),
#  (45,
#   '0.004*"september" + 0.004*"revised" + 0.004*"tension" + 0.004*"temporary" + '
#   '0.004*"sustained" + 0.004*"significantly" + 0.004*"service" + '
#   '0.004*"adjusted" + 0.004*"seen" + 0.004*"related"'),
#  (37,
#   '0.004*"march" + 0.004*"possible" + 0.004*"functioning" + 0.004*"february" + '
#   '0.004*"finance" + 0.004*"pillar" + 0.004*"production" + 0.004*"clearly" + '
#   '0.004*"scenario" + 0.004*"framework"'),
#  (44,
#   '0.004*"course" + 0.004*"moderation" + 0.004*"consumer" + 0.004*"pillar" + '
#   '0.004*"objective" + 0.004*"indicate" + 0.004*"average" + 0.004*"process" + '
#   '0.004*"confirmed" + 0.004*"base"'),
#  (51,
#   '0.004*"process" + 0.004*"observed" + 0.004*"consumer" + 0.004*"give" + '
#   '0.004*"two" + 0.004*"february" + 0.004*"required" + 0.004*"prospect" + '
#   '0.004*"help" + 0.004*"exchange"'),
#  (74,
#   '0.004*"projection" + 0.004*"staff" + 0.004*"situation" + 0.004*"eu" + '
#   '0.004*"member" + 0.004*"prevailing" + 0.004*"background" + '
#   '0.004*"programme" + 0.004*"present" + 0.004*"august"'),
#  (52,
#   '0.004*"foster" + 0.004*"fully" + 0.004*"course" + 0.004*"help" + '
#   '0.004*"world" + 0.004*"subject" + 0.004*"background" + 0.004*"finally" + '
#   '0.004*"consumer" + 0.004*"commission"'),
#  (91,
#   '0.004*"projection" + 0.004*"projected" + 0.004*"ample" + 0.004*"staff" + '
#   '0.004*"confirmed" + 0.004*"creation" + 0.004*"contribution" + '
#   '0.004*"longer" + 0.004*"background" + 0.004*"scenario"'),
#  (75,
#   '0.004*"september" + 0.004*"revised" + 0.004*"tension" + 0.004*"temporary" + '
#   '0.004*"sustained" + 0.004*"significantly" + 0.004*"service" + '
#   '0.004*"adjusted" + 0.004*"seen" + 0.004*"related"'),
#  (93,
#   '0.103*"september" + 0.095*"october" + 0.048*"projection" + 0.042*"staff" + '
#   '0.031*"december" + 0.029*"extent" + 0.027*"reflected" + 0.026*"asset" + '
#   '0.025*"monthly" + 0.023*"programme"'),
#  (23,
#   '0.223*"projection" + 0.192*"staff" + 0.089*"march" + 0.067*"revised" + '
#   '0.055*"slightly" + 0.035*"june" + 0.034*"gradually" + 0.025*"organisation" '
#   '+ 0.024*"adjusted" + 0.020*"secondround"'),
#  (82,
#   '0.037*"consumer" + 0.032*"trend" + 0.025*"pillar" + 0.025*"average" + '
#   '0.024*"exchange" + 0.024*"member" + 0.023*"state" + 0.021*"two" + '
#   '0.016*"course" + 0.016*"longterm"'),
#  (28,
#   '0.035*"food" + 0.024*"tension" + 0.020*"foster" + 0.019*"november" + '
#   '0.019*"help" + 0.019*"service" + 0.018*"further" + 0.017*"sound" + '
#   '0.017*"leave" + 0.017*"fully"'),
#  (62,
#   '0.081*"sale" + 0.059*"adjusted" + 0.036*"aim" + 0.033*"lending" + '
#   '0.032*"prevailing" + 0.031*"lower" + 0.029*"operation" + 0.029*"union" + '
#   '0.028*"signal" + 0.027*"subdued"'),
#  (61,
#   '0.044*"commodity" + 0.029*"longer" + 0.022*"projected" + '
#   '0.017*"policyrelevant" + 0.017*"competition" + 0.015*"sound" + '
#   '0.015*"robust" + 0.015*"anchoring" + 0.014*"firm" + 0.014*"accordingly"'),
#  (19,
#   '0.089*"january" + 0.078*"december" + 0.060*"february" + 0.044*"substantial" '
#   '+ 0.036*"deposit" + 0.033*"march" + 0.031*"aim" + 0.030*"flow" + '
#   '0.028*"special" + 0.028*"to"'),
#  (22,
#   '0.162*"june" + 0.069*"flow" + 0.056*"substantial" + 0.053*"including" + '
#   '0.043*"full" + 0.038*"next" + 0.034*"regarding" + 0.033*"owing" + '
#   '0.032*"capital" + 0.031*"plan"'),
#  (11,
#   '0.066*"accommodative" + 0.041*"instrument" + 0.040*"to" + 0.037*"across" + '
#   '0.034*"adequate" + 0.026*"cycle" + 0.026*"creation" + 0.022*"gradual" + '
#   '0.021*"reduce" + 0.020*"resilience"'),
#  (85,
#   '0.036*"sustained" + 0.032*"asset" + 0.032*"contribute" + 0.023*"objective" '
#   '+ 0.023*"staff" + 0.023*"programme" + 0.022*"across" + 0.021*"improve" + '
#   '0.020*"projection" + 0.020*"remaining"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity5: ', lda_model5.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity10: ', lda_model10.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity20: ', lda_model20.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity50: ', lda_model50.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity100: ', lda_model100.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100: ', coherence_lda)


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence ScoreUMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100UMass: ', coherence_lda)
# Out:
# Perplexity:  -5.7093063954437335
#
# Perplexity5:  -5.561633530851265
#
# Perplexity10:  -5.587293025279845
#
# Perplexity20:  -5.610446212628217
#
# Perplexity50:  -5.677062086296557
#
# Perplexity100:  -6.673953584407189
#
# Coherence Score:  0.2641719754583801
#
# Coherence Score5:  0.32778643666695534
#
# Coherence Score10:  0.30643764147365105
#
# Coherence Score20:  0.28816358711450885
#
# Coherence Score50:  0.24274101777402401
#
# Coherence Score100:  0.24343989367674124
#
# Coherence ScoreUMass:  -0.7685035992213708
#
# Coherence Score5UMass:  -0.782075421113865
#
# Coherence Score10UMass:  -0.7711093085498109
#
# Coherence Score20UMass:  -0.8679529319823869
#
# Coherence Score50UMass:  -0.8949063815171111
#
# Coherence Score100UMass:  -0.9137554911144803
