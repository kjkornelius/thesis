# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['qa']

# %%
    #Explore 

#Fetch wordcount for each abstract
df['word_count'] = df.apply(lambda x: len(str(x).split(" ")))
df[['QA','word_count']].head()

df.word_count.describe()
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\pandas\core\series.py:951: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]
# count     205.000000
# mean     3022.404878
# std      1041.743884
# min       656.000000
# 25%      2182.000000
# 50%      3210.000000
# 75%      3800.000000
# max      5269.000000
# Name: qa, dtype: float64

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(8371 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=1, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
lda_model5 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model10 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model20 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model50 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=50, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model100 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=100, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\models\ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
# Print the Keyword in the 1 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.010*"would" + 0.010*"question" + 0.008*"policy" + 0.008*"rate" + '
#   '0.008*"say" + 0.008*"said" + 0.007*"first" + 0.007*"also" + 0.007*"bank" + '
#   '0.007*"monetary"')]

# %%
# Print the Keyword in the 5 topics
pprint(lda_model5.print_topics())
doc_lda = lda_model5[corpus]

# Print the Keyword in the 10 topics
pprint(lda_model10.print_topics())
doc_lda = lda_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lda_model20.print_topics())
doc_lda = lda_model20[corpus]

# Print the Keyword in the 50 topics
pprint(lda_model50.print_topics())
doc_lda = lda_model50[corpus]

# Print the Keyword in the 100 topics
pprint(lda_model100.print_topics())
doc_lda = lda_model100[corpus]
# Out:
# [(0,
#   '0.012*"rate" + 0.010*"euro" + 0.010*"would" + 0.008*"say" + '
#   '0.007*"question" + 0.007*"one" + 0.006*"also" + 0.006*"year" + '
#   '0.006*"growth" + 0.006*"well"'),
#  (1,
#   '0.009*"bank" + 0.009*"would" + 0.008*"question" + 0.008*"first" + '
#   '0.008*"rate" + 0.008*"time" + 0.008*"one" + 0.008*"think" + 0.007*"policy" '
#   '+ 0.007*"said"'),
#  (2,
#   '0.012*"question" + 0.011*"policy" + 0.010*"bank" + 0.009*"would" + '
#   '0.009*"monetary" + 0.009*"inflation" + 0.008*"one" + 0.008*"first" + '
#   '0.008*"also" + 0.008*"rate"'),
#  (3,
#   '0.014*"policy" + 0.012*"expectation" + 0.011*"monetary" + 0.010*"question" '
#   '+ 0.010*"thats" + 0.010*"inflation" + 0.010*"first" + 0.009*"that" + '
#   '0.009*"second" + 0.009*"said"'),
#  (4,
#   '0.012*"would" + 0.010*"said" + 0.010*"say" + 0.009*"price" + 0.009*"regard" '
#   '+ 0.008*"stability" + 0.008*"market" + 0.007*"question" + 0.007*"rate" + '
#   '0.007*"also"')]
# [(0,
#   '0.014*"rate" + 0.011*"would" + 0.011*"euro" + 0.009*"say" + '
#   '0.008*"question" + 0.007*"one" + 0.007*"also" + 0.007*"growth" + '
#   '0.006*"that" + 0.006*"year"'),
#  (1,
#   '0.011*"bank" + 0.010*"think" + 0.009*"country" + 0.008*"first" + '
#   '0.008*"would" + 0.008*"euro" + 0.008*"area" + 0.007*"one" + 0.007*"said" + '
#   '0.007*"question"'),
#  (2,
#   '0.011*"policy" + 0.010*"question" + 0.010*"market" + 0.010*"inflation" + '
#   '0.009*"monetary" + 0.009*"first" + 0.009*"second" + 0.008*"time" + '
#   '0.008*"rate" + 0.008*"thats"'),
#  (3,
#   '0.002*"attenuate" + 0.002*"prohibits" + 0.002*"unsterilised" + '
#   '0.002*"mature" + 0.002*"lengthening" + 0.001*"noes" + 0.001*"embodies" + '
#   '0.001*"abuse" + 0.001*"aggravate" + 0.001*"circumvents"'),
#  (4,
#   '0.013*"would" + 0.011*"said" + 0.010*"say" + 0.010*"price" + 0.009*"regard" '
#   '+ 0.009*"stability" + 0.009*"market" + 0.007*"decision" + 0.007*"level" + '
#   '0.007*"also"'),
#  (5,
#   '0.002*"recurrent" + 0.001*"disappears" + 0.001*"longlasting" + '
#   '0.001*"passingthrough" + 0.001*"towers" + 0.001*"twodigit" + '
#   '0.001*"movements" + 0.001*"hasard" + 0.001*"reiteration" + '
#   '0.001*"generalisation"'),
#  (6,
#   '0.002*"temptation" + 0.002*"respectable" + 0.001*"departure" + '
#   '0.001*"resign" + 0.001*"vacancy" + 0.001*"retire" + 0.001*"wife" + '
#   '0.001*"solow" + 0.001*"developments" + 0.001*"spokesman"'),
#  (7,
#   '0.003*"europa" + 0.003*"portrait" + 0.002*"hologram" + 0.002*"film" + '
#   '0.002*"watermark" + 0.002*"gender" + 0.002*"antifraud" + 0.002*"upturn" + '
#   '0.002*"secured" + 0.002*"vase"'),
#  (8,
#   '0.013*"bank" + 0.013*"policy" + 0.013*"question" + 0.011*"would" + '
#   '0.009*"one" + 0.009*"monetary" + 0.009*"say" + 0.009*"inflation" + '
#   '0.008*"first" + 0.008*"rate"'),
#  (9,
#   '0.011*"inflation" + 0.010*"time" + 0.009*"rate" + 0.007*"would" + '
#   '0.006*"one" + 0.006*"ela" + 0.006*"lower" + 0.006*"period" + 0.006*"it" + '
#   '0.006*"forward"')]
# [(0,
#   '0.014*"would" + 0.012*"said" + 0.011*"regard" + 0.011*"say" + 0.011*"price" '
#   '+ 0.010*"stability" + 0.009*"market" + 0.008*"level" + 0.008*"decision" + '
#   '0.008*"council"'),
#  (1,
#   '0.002*"intrinsic" + 0.002*"amsterdam" + 0.001*"instil" + 0.001*"disturbing" '
#   '+ 0.001*"inhibiting" + 0.001*"mile" + 0.001*"gpd" + 0.001*"busy" + '
#   '0.001*"comite" + 0.001*"couched"'),
#  (2,
#   '0.013*"reserve" + 0.009*"exchange" + 0.007*"payment" + 0.007*"currency" + '
#   '0.006*"movement" + 0.006*"day" + 0.005*"gold" + 0.005*"usd" + '
#   '0.004*"emphasise" + 0.004*"resumption"'),
#  (3,
#   '0.000*"would" + 0.000*"said" + 0.000*"rate" + 0.000*"say" + 0.000*"know" + '
#   '0.000*"growth" + 0.000*"price" + 0.000*"question" + 0.000*"also" + '
#   '0.000*"stability"'),
#  (4,
#   '0.010*"vigilance" + 0.008*"vigilant" + 0.008*"saving" + 0.007*"arm" + '
#   '0.007*"provisional" + 0.007*"eurostat" + 0.006*"accounting" + '
#   '0.006*"guardian" + 0.005*"briefing" + 0.005*"weber"'),
#  (5,
#   '0.000*"would" + 0.000*"price" + 0.000*"say" + 0.000*"rate" + 0.000*"said" + '
#   '0.000*"euro" + 0.000*"stability" + 0.000*"area" + 0.000*"economy" + '
#   '0.000*"also"'),
#  (6,
#   '0.000*"would" + 0.000*"say" + 0.000*"said" + 0.000*"stability" + '
#   '0.000*"price" + 0.000*"council" + 0.000*"rate" + 0.000*"question" + '
#   '0.000*"also" + 0.000*"euro"'),
#  (7,
#   '0.000*"would" + 0.000*"also" + 0.000*"euro" + 0.000*"said" + '
#   '0.000*"question" + 0.000*"say" + 0.000*"rate" + 0.000*"growth" + '
#   '0.000*"stability" + 0.000*"year"'),
#  (8,
#   '0.005*"lamfalussy" + 0.004*"fraud" + 0.004*"antifraud" + 0.003*"seville" + '
#   '0.003*"respectable" + 0.003*"lame" + 0.003*"duck" + 0.003*"departure" + '
#   '0.002*"olaf" + 0.002*"demandled"'),
#  (9,
#   '0.005*"undervaluation" + 0.004*"jaime" + 0.003*"steel" + 0.002*"dutchman" + '
#   '0.002*"unprejudiced" + 0.002*"gratifyingly" + 0.002*"plural" + '
#   '0.002*"hampshire" + 0.002*"sea" + 0.001*"profession"'),
#  (10,
#   '0.000*"rate" + 0.000*"euro" + 0.000*"time" + 0.000*"would" + 0.000*"say" + '
#   '0.000*"price" + 0.000*"said" + 0.000*"area" + 0.000*"first" + 0.000*"one"'),
#  (11,
#   '0.000*"rate" + 0.000*"would" + 0.000*"said" + 0.000*"euro" + 0.000*"say" + '
#   '0.000*"also" + 0.000*"growth" + 0.000*"market" + 0.000*"time" + '
#   '0.000*"first"'),
#  (12,
#   '0.000*"would" + 0.000*"price" + 0.000*"rate" + 0.000*"euro" + 0.000*"also" '
#   '+ 0.000*"say" + 0.000*"growth" + 0.000*"stability" + 0.000*"time" + '
#   '0.000*"know"'),
#  (13,
#   '0.010*"rate" + 0.009*"would" + 0.008*"question" + 0.008*"euro" + '
#   '0.008*"one" + 0.008*"bank" + 0.007*"policy" + 0.007*"time" + 0.007*"also" + '
#   '0.007*"say"'),
#  (14,
#   '0.013*"campaign" + 0.005*"slogan" + 0.002*"shareholders" + 0.002*"printed" '
#   '+ 0.001*"inaction" + 0.001*"assign" + 0.001*"rift" + 0.001*"stockholm" + '
#   '0.001*"direttorio" + 0.001*"perturbed"'),
#  (15,
#   '0.000*"say" + 0.000*"would" + 0.000*"price" + 0.000*"said" + 0.000*"rate" + '
#   '0.000*"that" + 0.000*"market" + 0.000*"euro" + 0.000*"level" + '
#   '0.000*"growth"'),
#  (16,
#   '0.013*"policy" + 0.011*"question" + 0.010*"monetary" + 0.010*"inflation" + '
#   '0.010*"first" + 0.008*"one" + 0.008*"time" + 0.008*"thats" + 0.008*"bank" + '
#   '0.008*"second"'),
#  (17,
#   '0.000*"would" + 0.000*"price" + 0.000*"said" + 0.000*"market" + '
#   '0.000*"rate" + 0.000*"also" + 0.000*"stability" + 0.000*"say" + '
#   '0.000*"regard" + 0.000*"time"'),
#  (18,
#   '0.000*"would" + 0.000*"euro" + 0.000*"price" + 0.000*"council" + '
#   '0.000*"say" + 0.000*"question" + 0.000*"area" + 0.000*"see" + 0.000*"said" '
#   '+ 0.000*"also"'),
#  (19,
#   '0.014*"rate" + 0.013*"question" + 0.012*"bank" + 0.012*"would" + '
#   '0.011*"reform" + 0.010*"say" + 0.010*"also" + 0.009*"central" + '
#   '0.009*"policy" + 0.009*"structural"')]
# [(21,
#   '0.000*"would" + 0.000*"that" + 0.000*"regard" + 0.000*"rate" + 0.000*"euro" '
#   '+ 0.000*"price" + 0.000*"say" + 0.000*"also" + 0.000*"area" + '
#   '0.000*"growth"'),
#  (40,
#   '0.000*"say" + 0.000*"price" + 0.000*"would" + 0.000*"said" + 0.000*"also" + '
#   '0.000*"know" + 0.000*"rate" + 0.000*"level" + 0.000*"economy" + '
#   '0.000*"euro"'),
#  (5,
#   '0.000*"would" + 0.000*"price" + 0.000*"said" + 0.000*"say" + 0.000*"rate" + '
#   '0.000*"euro" + 0.000*"economy" + 0.000*"stability" + 0.000*"area" + '
#   '0.000*"also"'),
#  (11,
#   '0.000*"rate" + 0.000*"would" + 0.000*"said" + 0.000*"euro" + 0.000*"say" + '
#   '0.000*"also" + 0.000*"time" + 0.000*"market" + 0.000*"growth" + '
#   '0.000*"first"'),
#  (18,
#   '0.000*"would" + 0.000*"council" + 0.000*"price" + 0.000*"euro" + '
#   '0.000*"say" + 0.000*"question" + 0.000*"area" + 0.000*"see" + 0.000*"said" '
#   '+ 0.000*"also"'),
#  (17,
#   '0.000*"would" + 0.000*"said" + 0.000*"price" + 0.000*"rate" + 0.000*"also" '
#   '+ 0.000*"market" + 0.000*"say" + 0.000*"time" + 0.000*"that" + '
#   '0.000*"stability"'),
#  (35,
#   '0.000*"would" + 0.000*"question" + 0.000*"monetary" + 0.000*"rate" + '
#   '0.000*"said" + 0.000*"council" + 0.000*"say" + 0.000*"euro" + 0.000*"time" '
#   '+ 0.000*"growth"'),
#  (31,
#   '0.000*"would" + 0.000*"also" + 0.000*"euro" + 0.000*"question" + '
#   '0.000*"say" + 0.000*"said" + 0.000*"market" + 0.000*"rate" + '
#   '0.000*"stability" + 0.000*"price"'),
#  (33,
#   '0.000*"would" + 0.000*"say" + 0.000*"rate" + 0.000*"growth" + 0.000*"said" '
#   '+ 0.000*"question" + 0.000*"also" + 0.000*"price" + 0.000*"time" + '
#   '0.000*"euro"'),
#  (41,
#   '0.000*"would" + 0.000*"said" + 0.000*"know" + 0.000*"that" + 0.000*"say" + '
#   '0.000*"question" + 0.000*"growth" + 0.000*"also" + 0.000*"price" + '
#   '0.000*"level"'),
#  (38,
#   '0.030*"similarity" + 0.021*"stickiness" + 0.015*"team" + 0.012*"confident" '
#   '+ 0.012*"currency" + 0.011*"honour" + 0.011*"spontaneous" + 0.011*"wim" + '
#   '0.009*"deduce" + 0.009*"otto"'),
#  (24,
#   '0.045*"tender" + 0.021*"fixed" + 0.015*"optimise" + 0.014*"raton" + '
#   '0.012*"accession" + 0.012*"outset" + 0.009*"exceed" + '
#   '0.009*"professionally" + 0.008*"anywhere" + 0.008*"organisation"'),
#  (2,
#   '0.081*"birthday" + 0.010*"attribute" + 0.008*"harmony" + 0.008*"slippage" + '
#   '0.006*"kosovo" + 0.006*"southeast" + 0.006*"mishap" + 0.006*"euroland" + '
#   '0.006*"spokesman" + 0.005*"precision"'),
#  (27,
#   '0.204*"npls" + 0.059*"brexit" + 0.050*"wage" + 0.047*"ssm" + 0.035*"npl" + '
#   '0.034*"whats" + 0.019*"theyre" + 0.017*"nowotny" + 0.017*"firstquarter" + '
#   '0.017*"cspp"'),
#  (15,
#   '0.042*"funding" + 0.040*"ab" + 0.032*"fragmentation" + 0.027*"omt" + '
#   '0.023*"ltros" + 0.023*"ela" + 0.019*"conditionality" + 0.016*"lend" + '
#   '0.014*"hole" + 0.014*"jackson"'),
#  (16,
#   '0.043*"interest" + 0.039*"rate" + 0.038*"think" + 0.029*"let" + '
#   '0.023*"policy" + 0.022*"would" + 0.020*"reflect" + 0.020*"full" + '
#   '0.019*"bank" + 0.019*"ive"'),
#  (29,
#   '0.013*"would" + 0.011*"said" + 0.010*"say" + 0.010*"price" + '
#   '0.009*"stability" + 0.009*"regard" + 0.009*"market" + 0.008*"decision" + '
#   '0.008*"council" + 0.008*"level"'),
#  (19,
#   '0.013*"policy" + 0.011*"inflation" + 0.011*"question" + 0.011*"monetary" + '
#   '0.011*"first" + 0.010*"thats" + 0.010*"second" + 0.009*"programme" + '
#   '0.009*"market" + 0.008*"said"'),
#  (43,
#   '0.015*"bank" + 0.012*"policy" + 0.012*"one" + 0.012*"question" + '
#   '0.009*"would" + 0.009*"time" + 0.009*"first" + 0.008*"year" + 0.008*"think" '
#   '+ 0.008*"also"'),
#  (13,
#   '0.013*"rate" + 0.011*"would" + 0.011*"question" + 0.010*"bank" + '
#   '0.009*"also" + 0.009*"say" + 0.009*"country" + 0.009*"one" + 0.008*"policy" '
#   '+ 0.008*"euro"')]
# [(84,
#   '0.000*"would" + 0.000*"say" + 0.000*"know" + 0.000*"stability" + '
#   '0.000*"growth" + 0.000*"also" + 0.000*"currency" + 0.000*"regard" + '
#   '0.000*"rate" + 0.000*"time"'),
#  (15,
#   '0.000*"say" + 0.000*"would" + 0.000*"said" + 0.000*"price" + 0.000*"rate" + '
#   '0.000*"bank" + 0.000*"time" + 0.000*"level" + 0.000*"already" + '
#   '0.000*"central"'),
#  (21,
#   '0.000*"would" + 0.000*"regard" + 0.000*"said" + 0.000*"say" + 0.000*"that" '
#   '+ 0.000*"also" + 0.000*"council" + 0.000*"governing" + 0.000*"euro" + '
#   '0.000*"time"'),
#  (73,
#   '0.000*"price" + 0.000*"say" + 0.000*"would" + 0.000*"stability" + '
#   '0.000*"council" + 0.000*"growth" + 0.000*"said" + 0.000*"euro" + '
#   '0.000*"question" + 0.000*"rate"'),
#  (86,
#   '0.000*"ecb" + 0.000*"would" + 0.000*"rate" + 0.000*"year" + 0.000*"euro" + '
#   '0.000*"said" + 0.000*"say" + 0.000*"monetary" + 0.000*"first" + '
#   '0.000*"price"'),
#  (70,
#   '0.000*"would" + 0.000*"price" + 0.000*"question" + 0.000*"said" + '
#   '0.000*"stability" + 0.000*"growth" + 0.000*"risk" + 0.000*"also" + '
#   '0.000*"euro" + 0.000*"say"'),
#  (40,
#   '0.000*"say" + 0.000*"price" + 0.000*"said" + 0.000*"would" + 0.000*"also" + '
#   '0.000*"economy" + 0.000*"stability" + 0.000*"know" + 0.000*"level" + '
#   '0.000*"important"'),
#  (63,
#   '0.000*"rate" + 0.000*"would" + 0.000*"said" + 0.000*"price" + 0.000*"say" + '
#   '0.000*"growth" + 0.000*"stability" + 0.000*"market" + 0.000*"time" + '
#   '0.000*"course"'),
#  (88,
#   '0.000*"would" + 0.000*"price" + 0.000*"rate" + 0.000*"euro" + 0.000*"said" '
#   '+ 0.000*"see" + 0.000*"that" + 0.000*"stability" + 0.000*"policy" + '
#   '0.000*"well"'),
#  (3,
#   '0.000*"would" + 0.000*"said" + 0.000*"say" + 0.000*"rate" + 0.000*"know" + '
#   '0.000*"also" + 0.000*"price" + 0.000*"question" + 0.000*"first" + '
#   '0.000*"time"'),
#  (57,
#   '0.149*"headwind" + 0.029*"adoption" + 0.021*"restored" + 0.020*"visibility" '
#   '+ 0.017*"swiftly" + 0.016*"perform" + 0.012*"evidenced" + 0.012*"boosting" '
#   '+ 0.012*"hurt" + 0.011*"defence"'),
#  (83,
#   '0.159*"distort" + 0.082*"inconsistent" + 0.076*"intervention" + '
#   '0.056*"assure" + 0.037*"relevance" + 0.018*"issing" + 0.016*"hike" + '
#   '0.013*"surprise" + 0.012*"comply" + 0.010*"continuously"'),
#  (95,
#   '0.263*"marked" + 0.242*"execution" + 0.082*"birthday" + 0.010*"swift" + '
#   '0.006*"computer" + 0.004*"variation" + 0.004*"advisor" + 0.002*"disk" + '
#   '0.002*"backup" + 0.002*"motor"'),
#  (29,
#   '0.089*"complying" + 0.053*"offsetting" + 0.046*"stuck" + '
#   '0.045*"probability" + 0.015*"grave" + 0.014*"likely" + 0.013*"master" + '
#   '0.012*"pillar" + 0.011*"slowingdown" + 0.010*"solemnly"'),
#  (92,
#   '0.077*"test" + 0.053*"incidentally" + 0.032*"ecb" + 0.032*"european" + '
#   '0.027*"parliament" + 0.022*"planned" + 0.021*"july" + 0.019*"passing" + '
#   '0.018*"measuring" + 0.018*"commission"'),
#  (19,
#   '0.020*"reform" + 0.016*"rate" + 0.013*"price" + 0.012*"euro" + '
#   '0.012*"inflation" + 0.012*"return" + 0.011*"sustained" + 0.011*"interest" + '
#   '0.011*"extent" + 0.011*"know"'),
#  (55,
#   '0.015*"would" + 0.014*"price" + 0.014*"regard" + 0.012*"stability" + '
#   '0.012*"market" + 0.012*"say" + 0.011*"said" + 0.009*"level" + '
#   '0.008*"decision" + 0.008*"see"'),
#  (66,
#   '0.012*"would" + 0.011*"euro" + 0.010*"said" + 0.010*"rate" + 0.009*"say" + '
#   '0.009*"area" + 0.008*"that" + 0.007*"also" + 0.006*"price" + 0.006*"time"'),
#  (43,
#   '0.020*"policy" + 0.014*"monetary" + 0.014*"inflation" + 0.014*"question" + '
#   '0.013*"think" + 0.013*"expectation" + 0.013*"rate" + 0.012*"first" + '
#   '0.011*"would" + 0.011*"bank"'),
#  (13,
#   '0.013*"question" + 0.011*"policy" + 0.011*"bank" + 0.011*"one" + '
#   '0.009*"also" + 0.009*"market" + 0.009*"first" + 0.009*"time" + '
#   '0.008*"monetary" + 0.008*"would"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity5: ', lda_model5.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity10: ', lda_model10.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity20: ', lda_model20.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity50: ', lda_model50.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity100: ', lda_model100.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100: ', coherence_lda)


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence ScoreUMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100UMass: ', coherence_lda)
# Out:
# Perplexity:  -7.382675503613745
#
# Perplexity5:  -7.226193525752537
#
# Perplexity10:  -7.244013871797904
#
# Perplexity20:  -7.270344813133396
#
# Perplexity50:  -7.33055534449173
#
# Perplexity100:  -10.298308962580254
#
# Coherence Score:  0.25115093433407
#
# Coherence Score5:  0.27699321302235713
#
# Coherence Score10:  0.30991291524119174
#
# Coherence Score20:  0.32020332048987415
#
# Coherence Score50:  0.32243454458543247
#
# Coherence Score100:  0.30316133923261335
#
# Coherence ScoreUMass:  -0.0292208590194919
#
# Coherence Score5UMass:  -0.15411865143658704
#
# Coherence Score10UMass:  -1.9614064392473876
#
# Coherence Score20UMass:  -3.5771974354594827
#
# Coherence Score50UMass:  -3.080743188545706
#
# Coherence Score100UMass:  -1.8457559717070047
