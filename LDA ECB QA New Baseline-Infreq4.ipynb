# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['qa']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(8371 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
texts = data
# less than 10 documents,
id2word = corpora.Dictionary(texts)
id2word.filter_extremes(no_below = 4)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=1, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
lda_model5 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model10 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model20 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model50 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=50, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model100 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=100, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\models\ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
# Print the Keyword in the 1 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.007*"programme" + 0.007*"thats" + 0.005*"condition" + 0.005*"objective" + '
#   '0.004*"actually" + 0.004*"recovery" + 0.004*"weve" + 0.004*"lending" + '
#   '0.004*"sense" + 0.004*"bond"')]

# %%
# Print the Keyword in the 5 topics
pprint(lda_model5.print_topics())
doc_lda = lda_model5[corpus]

# Print the Keyword in the 10 topics
pprint(lda_model10.print_topics())
doc_lda = lda_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lda_model20.print_topics())
doc_lda = lda_model20[corpus]

# Print the Keyword in the 50 topics
pprint(lda_model50.print_topics())
doc_lda = lda_model50[corpus]

# Print the Keyword in the 100 topics
pprint(lda_model100.print_topics())
doc_lda = lda_model100[corpus]
# Out:
# [(0,
#   '0.012*"programme" + 0.011*"objective" + 0.009*"weve" + 0.009*"thats" + '
#   '0.009*"sense" + 0.008*"condition" + 0.007*"billion" + 0.006*"show" + '
#   '0.006*"basically" + 0.006*"matter"'),
#  (1,
#   '0.005*"deliver" + 0.004*"observed" + 0.004*"staff" + 0.004*"currency" + '
#   '0.004*"credible" + 0.004*"functioning" + 0.004*"quarter" + 0.003*"creation" '
#   '+ 0.003*"extremely" + 0.003*"carefully"'),
#  (2,
#   '0.009*"actually" + 0.006*"action" + 0.006*"don" + 0.005*"capital" + '
#   '0.005*"funding" + 0.005*"ab" + 0.005*"crisis" + 0.005*"forward" + '
#   '0.005*"asset" + 0.004*"within"'),
#  (3,
#   '0.006*"week" + 0.005*"money" + 0.004*"treaty" + 0.004*"forecast" + '
#   '0.004*"mr" + 0.004*"greek" + 0.004*"minister" + 0.004*"rather" + '
#   '0.003*"earlier" + 0.003*"day"'),
#  (4,
#   '0.015*"thats" + 0.012*"programme" + 0.010*"lending" + 0.009*"bond" + '
#   '0.007*"recovery" + 0.007*"condition" + 0.006*"several" + 0.006*"actually" + '
#   '0.006*"especially" + 0.006*"basically"')]
# [(0,
#   '0.008*"continuously" + 0.007*"supervision" + 0.005*"membership" + '
#   '0.005*"climate" + 0.005*"ripe" + 0.005*"contract" + 0.005*"trichet" + '
#   '0.005*"intervention" + 0.004*"mouth" + 0.004*"hopefully"'),
#  (1,
#   '0.031*"athens" + 0.025*"default" + 0.022*"doctrine" + 0.015*"selective" + '
#   '0.008*"informal" + 0.007*"dialogue" + 0.006*"portuguese" + 0.005*"italian" '
#   '+ 0.004*"attack" + 0.004*"discretion"'),
#  (2,
#   '0.009*"week" + 0.008*"rather" + 0.006*"forecast" + 0.006*"mr" + '
#   '0.006*"used" + 0.005*"indicator" + 0.005*"day" + 0.005*"movement" + '
#   '0.005*"concern" + 0.005*"become"'),
#  (3,
#   '0.016*"campaign" + 0.001*"material" + 0.001*"beforehand" + 0.000*"climate" '
#   '+ 0.000*"circulation" + 0.000*"forbidden" + 0.000*"openness" + '
#   '0.000*"hypothesis" + 0.000*"gratifying" + 0.000*"banknote"'),
#  (4,
#   '0.000*"dialogue" + 0.000*"spokesman" + 0.000*"minister" + '
#   '0.000*"circulating" + 0.000*"neighbourhood" + 0.000*"used" + '
#   '0.000*"exogenous" + 0.000*"banking" + 0.000*"sims" + 0.000*"concern"'),
#  (5,
#   '0.017*"thats" + 0.014*"programme" + 0.011*"condition" + 0.010*"sense" + '
#   '0.009*"purchase" + 0.009*"committee" + 0.009*"bond" + 0.008*"weve" + '
#   '0.008*"actually" + 0.008*"objective"'),
#  (6,
#   '0.010*"programme" + 0.008*"actually" + 0.007*"crisis" + 0.006*"bond" + '
#   '0.006*"action" + 0.006*"operation" + 0.005*"money" + 0.005*"decide" + '
#   '0.005*"condition" + 0.005*"collateral"'),
#  (7,
#   '0.005*"deliver" + 0.005*"currency" + 0.004*"staff" + 0.004*"observed" + '
#   '0.004*"credible" + 0.003*"extremely" + 0.003*"carefully" + 0.003*"treaty" + '
#   '0.003*"inflationary" + 0.003*"functioning"'),
#  (8,
#   '0.012*"thats" + 0.010*"programme" + 0.009*"recovery" + 0.008*"objective" + '
#   '0.008*"especially" + 0.008*"weve" + 0.008*"lending" + 0.007*"basically" + '
#   '0.006*"several" + 0.006*"act"'),
#  (9,
#   '0.016*"watching" + 0.010*"north" + 0.010*"equilibrium" + 0.008*"manager" + '
#   '0.008*"balance" + 0.007*"expertise" + 0.007*"budgetary" + 0.007*"disclose" '
#   '+ 0.006*"narrowly" + 0.005*"finetune"')]
# [(0,
#   '0.000*"slowdown" + 0.000*"misinterpreted" + 0.000*"duration" + '
#   '0.000*"eichel" + 0.000*"neighbourhood" + 0.000*"satisfied" + '
#   '0.000*"underestimate" + 0.000*"continuously" + 0.000*"tended" + '
#   '0.000*"near"'),
#  (1,
#   '0.088*"compact" + 0.028*"infrastructure" + 0.013*"expeditious" + '
#   '0.012*"attack" + 0.005*"centre" + 0.004*"consolidate" + 0.003*"deemed" + '
#   '0.000*"treaty" + 0.000*"both" + 0.000*"preannouncing"'),
#  (2,
#   '0.139*"guidance" + 0.119*"forward" + 0.094*"grain" + 0.030*"subdued" + '
#   '0.030*"abs" + 0.020*"deleveraging" + 0.016*"haircut" + 0.015*"extension" + '
#   '0.014*"activated" + 0.011*"threshold"'),
#  (3,
#   '0.012*"climate" + 0.010*"openness" + 0.005*"beforehand" + '
#   '0.005*"publishing" + 0.005*"forbidden" + 0.005*"preliminary" + '
#   '0.003*"circulation" + 0.002*"recollection" + 0.002*"evaluated" + '
#   '0.002*"yearend"'),
#  (4,
#   '0.000*"minister" + 0.000*"finance" + 0.000*"treaty" + 0.000*"inflationary" '
#   '+ 0.000*"conclusion" + 0.000*"reserve" + 0.000*"consensus" + '
#   '0.000*"creation" + 0.000*"uncertainty" + 0.000*"indeed"'),
#  (5,
#   '0.012*"pocket" + 0.000*"holding" + 0.000*"distortion" + 0.000*"fix" + '
#   '0.000*"derive" + 0.000*"transmission" + 0.000*"talking" + '
#   '0.000*"intervention" + 0.000*"quantify" + 0.000*"week"'),
#  (6,
#   '0.016*"programme" + 0.010*"bond" + 0.007*"act" + 0.007*"negative" + '
#   '0.007*"sense" + 0.006*"effective" + 0.006*"actually" + 0.006*"example" + '
#   '0.005*"objective" + 0.005*"lending"'),
#  (7,
#   '0.006*"deliver" + 0.006*"staff" + 0.005*"observed" + 0.005*"functioning" + '
#   '0.004*"observing" + 0.004*"quarter" + 0.004*"behalf" + 0.004*"carefully" + '
#   '0.004*"extremely" + 0.004*"credible"'),
#  (8,
#   '0.056*"thats" + 0.045*"weve" + 0.022*"ive" + 0.021*"committee" + '
#   '0.018*"evidence" + 0.016*"objective" + 0.014*"basically" + 0.013*"outlook" '
#   '+ 0.013*"purchase" + 0.013*"convergence"'),
#  (9,
#   '0.000*"balance" + 0.000*"finetune" + 0.000*"watching" + 0.000*"dollar" + '
#   '0.000*"conclusion" + 0.000*"computer" + 0.000*"north" + 0.000*"explain" + '
#   '0.000*"currency" + 0.000*"pact"'),
#  (10,
#   '0.077*"contraction" + 0.026*"efsf" + 0.024*"psi" + 0.018*"consolidation" + '
#   '0.016*"code" + 0.014*"valued" + 0.011*"orderly" + 0.006*"trick" + '
#   '0.004*"resumption" + 0.004*"rightly"'),
#  (11,
#   '0.023*"ab" + 0.016*"forecast" + 0.015*"slack" + 0.014*"rather" + '
#   '0.013*"movement" + 0.012*"become" + 0.011*"potential" + 0.010*"flow" + '
#   '0.010*"cause" + 0.010*"early"'),
#  (12,
#   '0.022*"conflict" + 0.017*"conclusion" + 0.011*"viewed" + 0.010*"flow" + '
#   '0.008*"complicated" + 0.008*"somewhat" + 0.008*"earlier" + '
#   '0.008*"declining" + 0.008*"used" + 0.007*"diversity"'),
#  (13,
#   '0.000*"eligible" + 0.000*"covered" + 0.000*"bond" + 0.000*"week" + '
#   '0.000*"treaty" + 0.000*"imf" + 0.000*"environment" + 0.000*"move" + '
#   '0.000*"money" + 0.000*"potential"'),
#  (14,
#   '0.008*"money" + 0.005*"operation" + 0.005*"week" + 0.004*"treaty" + '
#   '0.004*"day" + 0.004*"indicator" + 0.004*"within" + 0.004*"amount" + '
#   '0.003*"average" + 0.003*"deficit"'),
#  (15,
#   '0.043*"similarity" + 0.000*"changeover" + 0.000*"reserve" + 0.000*"mr" + '
#   '0.000*"currency" + 0.000*"happen" + 0.000*"decade" + 0.000*"military" + '
#   '0.000*"move" + 0.000*"day"'),
#  (16,
#   '0.000*"mr" + 0.000*"treaty" + 0.000*"potential" + 0.000*"conclusion" + '
#   '0.000*"opinion" + 0.000*"currency" + 0.000*"move" + 0.000*"phenomenon" + '
#   '0.000*"inflationary" + 0.000*"sentiment"'),
#  (17,
#   '0.025*"deliver" + 0.018*"currency" + 0.017*"citizen" + 0.014*"germany" + '
#   '0.014*"credible" + 0.014*"fellow" + 0.013*"million" + 0.013*"creation" + '
#   '0.010*"environment" + 0.008*"inflationary"'),
#  (18,
#   '0.001*"pocket" + 0.000*"disappear" + 0.000*"coin" + 0.000*"constructive" + '
#   '0.000*"beforehand" + 0.000*"eventually" + 0.000*"strange" + '
#   '0.000*"annualised" + 0.000*"resumption" + 0.000*"obstacle"'),
#  (19,
#   '0.012*"thats" + 0.010*"programme" + 0.009*"uncertainty" + 0.009*"actually" '
#   '+ 0.009*"condition" + 0.009*"lending" + 0.007*"objective" + 0.007*"several" '
#   '+ 0.007*"especially" + 0.007*"recovery"')]
# [(4,
#   '0.000*"opinion" + 0.000*"day" + 0.000*"date" + 0.000*"regime" + '
#   '0.000*"reserve" + 0.000*"community" + 0.000*"minister" + 0.000*"finance" + '
#   '0.000*"indeed" + 0.000*"within"'),
#  (48,
#   '0.000*"week" + 0.000*"rather" + 0.000*"remark" + 0.000*"deficit" + '
#   '0.000*"indeed" + 0.000*"deliver" + 0.000*"creation" + 0.000*"observed" + '
#   '0.000*"looking" + 0.000*"move"'),
#  (22,
#   '0.000*"week" + 0.000*"treaty" + 0.000*"concern" + 0.000*"money" + '
#   '0.000*"campaign" + 0.000*"uncertainty" + 0.000*"voting" + 0.000*"reserve" + '
#   '0.000*"minister" + 0.000*"rather"'),
#  (46,
#   '0.000*"vigilance" + 0.000*"staff" + 0.000*"inflationary" + 0.000*"scenario" '
#   '+ 0.000*"deliver" + 0.000*"partner" + 0.000*"sentiment" + '
#   '0.000*"environment" + 0.000*"essence" + 0.000*"trend"'),
#  (15,
#   '0.000*"sentiment" + 0.000*"mr" + 0.000*"phenomenon" + 0.000*"dynamic" + '
#   '0.000*"scenario" + 0.000*"environment" + 0.000*"inflationary" + '
#   '0.000*"move" + 0.000*"around" + 0.000*"pillar"'),
#  (35,
#   '0.000*"pact" + 0.000*"staff" + 0.000*"uncertainty" + 0.000*"mr" + '
#   '0.000*"reserve" + 0.000*"inflationary" + 0.000*"treaty" + 0.000*"consensus" '
#   '+ 0.000*"forecast" + 0.000*"day"'),
#  (24,
#   '0.000*"ve" + 0.000*"sentiment" + 0.000*"lending" + 0.000*"collateral" + '
#   '0.000*"dynamic" + 0.000*"currency" + 0.000*"credible" + 0.000*"creation" + '
#   '0.000*"move" + 0.000*"phenomenon"'),
#  (18,
#   '0.000*"forecast" + 0.000*"rather" + 0.000*"treaty" + 0.000*"conclusion" + '
#   '0.000*"phenomenon" + 0.000*"week" + 0.000*"every" + 0.000*"december" + '
#   '0.000*"staff" + 0.000*"recovery"'),
#  (0,
#   '0.000*"weve" + 0.000*"willingness" + 0.000*"mostly" + 0.000*"actually" + '
#   '0.000*"confusion" + 0.000*"several" + 0.000*"ab" + 0.000*"operation" + '
#   '0.000*"week" + 0.000*"president"'),
#  (16,
#   '0.000*"expeditious" + 0.000*"worse" + 0.000*"mr" + 0.000*"money" + '
#   '0.000*"conclusion" + 0.000*"opinion" + 0.000*"minister" + 0.000*"article" + '
#   '0.000*"currency" + 0.000*"day"'),
#  (43,
#   '0.307*"weve" + 0.076*"thats" + 0.058*"ill" + 0.054*"jurisdiction" + '
#   '0.037*"tltro" + 0.032*"prior" + 0.028*"evidence" + 0.026*"zero" + '
#   '0.025*"undertaken" + 0.024*"rebalancing"'),
#  (26,
#   '0.037*"grain" + 0.035*"protracted" + 0.026*"uncertainty" + 0.026*"powerful" '
#   '+ 0.024*"removed" + 0.024*"alternative" + 0.023*"dealt" + 0.022*"implicit" '
#   '+ 0.021*"eonia" + 0.021*"forming"'),
#  (34,
#   '0.012*"week" + 0.007*"treaty" + 0.007*"indicator" + 0.007*"used" + '
#   '0.007*"day" + 0.006*"sign" + 0.006*"money" + 0.006*"concern" + '
#   '0.006*"within" + 0.006*"deficit"'),
#  (19,
#   '0.040*"transmission" + 0.025*"fragmentation" + 0.025*"bubble" + '
#   '0.024*"capital" + 0.024*"instrument" + 0.023*"mostly" + 0.022*"actually" + '
#   '0.022*"funding" + 0.022*"money" + 0.020*"undertaken"'),
#  (44,
#   '0.038*"thats" + 0.031*"programme" + 0.024*"committee" + 0.021*"return" + '
#   '0.020*"ive" + 0.018*"bond" + 0.015*"reflect" + 0.014*"horizon" + '
#   '0.013*"financing" + 0.013*"negative"'),
#  (20,
#   '0.016*"objective" + 0.014*"ready" + 0.013*"implemented" + 0.013*"basically" '
#   '+ 0.013*"recovery" + 0.012*"crisis" + 0.012*"act" + 0.011*"target" + '
#   '0.011*"pretty" + 0.010*"shock"'),
#  (7,
#   '0.007*"deliver" + 0.005*"currency" + 0.005*"creation" + 0.005*"credible" + '
#   '0.005*"staff" + 0.005*"carefully" + 0.005*"inflationary" + '
#   '0.004*"functioning" + 0.004*"behalf" + 0.004*"sentiment"'),
#  (14,
#   '0.025*"billion" + 0.014*"deflation" + 0.013*"sustained" + 0.012*"matter" + '
#   '0.012*"show" + 0.012*"uncertainty" + 0.012*"security" + 0.011*"option" + '
#   '0.010*"trust" + 0.010*"condition"'),
#  (6,
#   '0.009*"quarter" + 0.007*"operation" + 0.006*"focus" + 0.006*"observed" + '
#   '0.005*"package" + 0.004*"remember" + 0.004*"don" + 0.004*"positive" + '
#   '0.004*"greece" + 0.004*"balance"'),
#  (30,
#   '0.012*"programme" + 0.012*"actually" + 0.011*"lending" + 0.010*"thats" + '
#   '0.010*"sense" + 0.010*"condition" + 0.009*"several" + 0.008*"especially" + '
#   '0.008*"lower" + 0.008*"recovery"')]
# [(57,
#   '0.000*"intervention" + 0.000*"mr" + 0.000*"value" + 0.000*"rumour" + '
#   '0.000*"trend" + 0.000*"communication" + 0.000*"forecast" + 0.000*"concept" '
#   '+ 0.000*"conference" + 0.000*"minister"'),
#  (94,
#   '0.000*"conference" + 0.000*"opinion" + 0.000*"note" + 0.000*"used" + '
#   '0.000*"community" + 0.000*"goal" + 0.000*"concern" + 0.000*"day" + '
#   '0.000*"indeed" + 0.000*"expected"'),
#  (71,
#   '0.000*"treaty" + 0.000*"be" + 0.000*"intervention" + 0.000*"seriously" + '
#   '0.000*"value" + 0.000*"forecast" + 0.000*"four" + 0.000*"changed" + '
#   '0.000*"moderate" + 0.000*"recovery"'),
#  (81,
#   '0.000*"tender" + 0.000*"average" + 0.000*"indeed" + 0.000*"fixed" + '
#   '0.000*"week" + 0.000*"move" + 0.000*"potential" + 0.000*"hope" + '
#   '0.000*"minimum" + 0.000*"thank"'),
#  (61,
#   '0.000*"pact" + 0.000*"treaty" + 0.000*"proposal" + 0.000*"explain" + '
#   '0.000*"currency" + 0.000*"very" + 0.000*"balance" + 0.000*"dollar" + '
#   '0.000*"team" + 0.000*"uncertainty"'),
#  (13,
#   '0.000*"mouth" + 0.000*"assistance" + 0.000*"bond" + 0.000*"banks" + '
#   '0.000*"mostly" + 0.000*"confusion" + 0.000*"greece" + 0.000*"instability" + '
#   '0.000*"compliance" + 0.000*"imf"'),
#  (25,
#   '0.000*"currency" + 0.000*"mr" + 0.000*"recovery" + 0.000*"favourable" + '
#   '0.000*"cut" + 0.000*"uncertainty" + 0.000*"pact" + 0.000*"vigilance" + '
#   '0.000*"proposal" + 0.000*"creation"'),
#  (36,
#   '0.000*"move" + 0.000*"dynamic" + 0.000*"every" + 0.000*"indicator" + '
#   '0.000*"pillar" + 0.000*"loss" + 0.000*"understanding" + 0.000*"observed" + '
#   '0.000*"sentiment" + 0.000*"million"'),
#  (24,
#   '0.000*"sentiment" + 0.000*"dynamic" + 0.000*"currency" + 0.000*"deliver" + '
#   '0.000*"move" + 0.000*"forecast" + 0.000*"inflationary" + 0.000*"creation" + '
#   '0.000*"credible" + 0.000*"upon"'),
#  (52,
#   '0.000*"sentiment" + 0.000*"credible" + 0.000*"inflationary" + '
#   '0.000*"scenario" + 0.000*"dynamic" + 0.000*"staff" + 0.000*"deliver" + '
#   '0.000*"data" + 0.000*"quarter" + 0.000*"single"'),
#  (8,
#   '0.052*"recovery" + 0.040*"stress" + 0.036*"balance" + 0.035*"especially" + '
#   '0.035*"instrument" + 0.029*"competition" + 0.025*"sheet" + 0.024*"out" + '
#   '0.023*"consumption" + 0.021*"tax"'),
#  (44,
#   '0.057*"thats" + 0.057*"ive" + 0.044*"effective" + 0.037*"horizon" + '
#   '0.031*"return" + 0.028*"path" + 0.025*"accommodative" + '
#   '0.024*"macroeconomic" + 0.019*"reflect" + 0.019*"committee"'),
#  (30,
#   '0.041*"repo" + 0.036*"convergence" + 0.035*"committee" + 0.031*"matter" + '
#   '0.028*"outlook" + 0.023*"political" + 0.023*"pressure" + 0.020*"meantime" + '
#   '0.020*"with" + 0.019*"condition"'),
#  (92,
#   '0.023*"several" + 0.022*"thats" + 0.021*"actually" + 0.020*"channel" + '
#   '0.019*"lower" + 0.017*"uncertainty" + 0.015*"spread" + 0.015*"generally" + '
#   '0.013*"forward" + 0.013*"basically"'),
#  (14,
#   '0.055*"billion" + 0.024*"sustained" + 0.020*"option" + 0.020*"undertaken" + '
#   '0.019*"though" + 0.017*"depend" + 0.016*"necessity" + 0.015*"sentence" + '
#   '0.015*"accommodation" + 0.015*"trust"'),
#  (7,
#   '0.007*"staff" + 0.007*"treaty" + 0.006*"carefully" + 0.005*"don" + '
#   '0.005*"package" + 0.005*"single" + 0.005*"observing" + 0.005*"pact" + '
#   '0.004*"every" + 0.004*"eurosystem"'),
#  (56,
#   '0.015*"survey" + 0.014*"ability" + 0.013*"observed" + '
#   '0.013*"implementation" + 0.011*"explain" + 0.010*"discus" + '
#   '0.010*"remember" + 0.010*"balance" + 0.010*"support" + 0.009*"quarter"'),
#  (74,
#   '0.026*"bond" + 0.018*"asset" + 0.016*"greece" + 0.013*"extraordinary" + '
#   '0.013*"sense" + 0.011*"apply" + 0.010*"perception" + 0.010*"worked" + '
#   '0.009*"data" + 0.009*"condition"'),
#  (80,
#   '0.052*"programme" + 0.026*"purchase" + 0.021*"lending" + 0.018*"sense" + '
#   '0.016*"actually" + 0.015*"financing" + 0.015*"condition" + 0.015*"show" + '
#   '0.014*"objective" + 0.012*"bond"'),
#  (87,
#   '0.010*"ready" + 0.008*"crisis" + 0.008*"however" + 0.008*"action" + '
#   '0.007*"address" + 0.007*"able" + 0.007*"nature" + 0.006*"maturity" + '
#   '0.006*"example" + 0.006*"focus"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity5: ', lda_model5.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity10: ', lda_model10.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity20: ', lda_model20.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity50: ', lda_model50.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity100: ', lda_model100.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100: ', coherence_lda)


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence ScoreUMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100UMass: ', coherence_lda)
# Out:
# Perplexity:  -7.8339286130366625
#
# Perplexity5:  -7.617438179877423
#
# Perplexity10:  -7.646420847161147
#
# Perplexity20:  -7.723255815057703
#
# Perplexity50:  -7.810849692982825
#
# Perplexity100:  -11.656510556310774
#
# Coherence Score:  0.5141230588077896
#
# Coherence Score5:  0.4670412146716477
#
# Coherence Score10:  0.47912782553870575
#
# Coherence Score20:  0.3805013376593985
#
# Coherence Score50:  0.3455542257296865
#
# Coherence Score100:  0.31698385806016377
#
# Coherence ScoreUMass:  -0.6436320867333867
#
# Coherence Score5UMass:  -0.8276593995589788
#
# Coherence Score10UMass:  -4.39781639273963
#
# Coherence Score20UMass:  -2.6449837402042933
#
# Coherence Score50UMass:  -2.257051239751864
#
# Coherence Score100UMass:  -1.6738289632296113
