# %%
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['Press']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(4394 unique tokens: ['able', 'acceptable', 'accompanied', 'according', 'account']...)

# %%
# less than 10 documents,
id2word = corpora.Dictionary(data)
id2word.filter_extremes(no_below = 10)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.205*"projection" + 0.158*"staff" + 0.130*"operation" + 0.116*"december" + '
#   '0.111*"commodity" + 0.106*"january" + 0.103*"september" + 0.097*"march" + '
#   '0.094*"to" + 0.093*"june"')]
# [(0,
#   '0.205*"projection" + 0.158*"staff" + 0.130*"operation" + 0.116*"december" + '
#   '0.111*"commodity" + 0.106*"january" + 0.103*"september" + 0.097*"march" + '
#   '0.094*"to" + 0.093*"june"'),
#  (1,
#   '0.258*"central" + 0.214*"national" + -0.213*"projection" + 0.193*"banknote" '
#   '+ 0.159*"three" + 0.155*"january" + 0.147*"reference" + 0.142*"system" + '
#   '0.141*"value" + -0.137*"staff"'),
#  (2,
#   '0.235*"operation" + 0.160*"subdued" + 0.156*"refinancing" + -0.133*"trend" '
#   '+ 0.128*"below" + 0.128*"to" + 0.118*"purchase" + -0.118*"longer" + '
#   '0.115*"january" + -0.114*"food"'),
#  (3,
#   '0.411*"projection" + 0.269*"staff" + -0.177*"commodity" + 0.161*"purchase" '
#   '+ -0.146*"keeping" + -0.141*"negative" + -0.137*"policyrelevant" + '
#   '-0.131*"tension" + -0.124*"aim" + -0.116*"deposit"'),
#  (4,
#   '-0.394*"projection" + -0.275*"staff" + -0.234*"range" + 0.189*"subdued" + '
#   '-0.160*"operation" + 0.155*"gradual" + 0.141*"purchase" + 0.113*"asset" + '
#   '-0.113*"commodity" + 0.099*"pillar"')]
# [(0,
#   '0.205*"projection" + 0.158*"staff" + 0.130*"operation" + 0.116*"december" + '
#   '0.111*"commodity" + 0.106*"january" + 0.103*"september" + 0.097*"march" + '
#   '0.094*"to" + 0.093*"june"'),
#  (1,
#   '0.258*"central" + 0.214*"national" + -0.213*"projection" + 0.193*"banknote" '
#   '+ 0.159*"three" + 0.155*"january" + 0.147*"reference" + 0.142*"system" + '
#   '0.141*"value" + -0.137*"staff"'),
#  (2,
#   '0.235*"operation" + 0.160*"subdued" + 0.156*"refinancing" + -0.133*"trend" '
#   '+ 0.128*"below" + 0.128*"to" + 0.118*"purchase" + -0.118*"longer" + '
#   '0.115*"january" + -0.114*"food"'),
#  (3,
#   '0.411*"projection" + 0.269*"staff" + -0.177*"commodity" + 0.161*"purchase" '
#   '+ -0.146*"keeping" + -0.141*"negative" + -0.137*"policyrelevant" + '
#   '-0.131*"tension" + -0.124*"aim" + -0.116*"deposit"'),
#  (4,
#   '-0.394*"projection" + -0.275*"staff" + -0.234*"range" + 0.189*"subdued" + '
#   '-0.160*"operation" + 0.155*"gradual" + 0.141*"purchase" + 0.113*"asset" + '
#   '-0.113*"commodity" + 0.099*"pillar"'),
#  (5,
#   '-0.245*"projection" + 0.202*"ample" + 0.171*"operation" + -0.168*"negative" '
#   '+ -0.167*"subdued" + 0.150*"job" + 0.143*"accommodative" + -0.141*"staff" + '
#   '0.135*"creation" + 0.135*"warranted"'),
#  (6,
#   '-0.227*"food" + -0.171*"operation" + -0.154*"commodity" + '
#   '-0.154*"secondround" + 0.153*"longer" + -0.150*"tension" + -0.128*"turmoil" '
#   '+ -0.126*"behaviour" + 0.123*"ample" + -0.112*"january"'),
#  (7,
#   '-0.265*"purchase" + 0.179*"december" + 0.169*"subdued" + -0.159*"june" + '
#   '-0.149*"asset" + -0.128*"firm" + -0.125*"national" + 0.122*"picture" + '
#   '0.119*"consumer" + 0.114*"november"'),
#  (8,
#   '-0.434*"january" + -0.292*"december" + 0.226*"july" + 0.195*"august" + '
#   '0.188*"june" + -0.172*"february" + 0.150*"september" + 0.148*"operation" + '
#   '-0.144*"march" + 0.127*"tension"'),
#  (9,
#   '-0.207*"consumer" + 0.202*"subdued" + -0.173*"pillar" + -0.151*"operation" '
#   '+ -0.151*"negative" + 0.123*"tension" + -0.123*"refinancing" + '
#   '0.123*"central" + 0.120*"national" + -0.116*"purchase"')]
# [(0,
#   '0.205*"projection" + 0.158*"staff" + 0.130*"operation" + 0.116*"december" + '
#   '0.111*"commodity" + 0.106*"january" + 0.103*"september" + 0.097*"march" + '
#   '0.094*"to" + 0.093*"june"'),
#  (1,
#   '-0.258*"central" + -0.214*"national" + 0.213*"projection" + '
#   '-0.193*"banknote" + -0.159*"three" + -0.155*"january" + -0.147*"reference" '
#   '+ -0.142*"system" + -0.141*"value" + 0.137*"staff"'),
#  (2,
#   '0.235*"operation" + 0.160*"subdued" + 0.156*"refinancing" + -0.133*"trend" '
#   '+ 0.128*"below" + 0.128*"to" + 0.118*"purchase" + -0.118*"longer" + '
#   '0.115*"january" + -0.114*"food"'),
#  (3,
#   '0.411*"projection" + 0.269*"staff" + -0.177*"commodity" + 0.161*"purchase" '
#   '+ -0.146*"keeping" + -0.141*"negative" + -0.137*"policyrelevant" + '
#   '-0.131*"tension" + -0.124*"aim" + -0.116*"deposit"'),
#  (4,
#   '0.394*"projection" + 0.275*"staff" + 0.234*"range" + -0.189*"subdued" + '
#   '0.160*"operation" + -0.155*"gradual" + -0.141*"purchase" + -0.113*"asset" + '
#   '0.113*"commodity" + -0.099*"pillar"'),
#  (5,
#   '-0.245*"projection" + 0.202*"ample" + 0.171*"operation" + -0.168*"negative" '
#   '+ -0.167*"subdued" + 0.150*"job" + 0.143*"accommodative" + -0.141*"staff" + '
#   '0.135*"creation" + 0.135*"warranted"'),
#  (6,
#   '-0.227*"food" + -0.171*"operation" + -0.154*"commodity" + '
#   '-0.154*"secondround" + 0.153*"longer" + -0.150*"tension" + -0.128*"turmoil" '
#   '+ -0.126*"behaviour" + 0.123*"ample" + -0.112*"january"'),
#  (7,
#   '0.265*"purchase" + -0.179*"december" + -0.169*"subdued" + 0.160*"june" + '
#   '0.149*"asset" + 0.127*"firm" + 0.125*"national" + -0.122*"picture" + '
#   '-0.119*"consumer" + -0.114*"november"'),
#  (8,
#   '0.434*"january" + 0.292*"december" + -0.226*"july" + -0.195*"august" + '
#   '-0.188*"june" + 0.172*"february" + -0.150*"september" + -0.148*"operation" '
#   '+ 0.144*"march" + -0.127*"tension"'),
#  (9,
#   '-0.207*"consumer" + 0.202*"subdued" + -0.173*"pillar" + -0.151*"operation" '
#   '+ -0.151*"negative" + 0.123*"tension" + -0.123*"refinancing" + '
#   '0.123*"central" + 0.120*"national" + -0.115*"purchase"'),
#  (10,
#   '-0.300*"october" + -0.297*"september" + 0.296*"march" + 0.260*"april" + '
#   '-0.221*"november" + -0.159*"purchase" + 0.141*"february" + '
#   '-0.140*"december" + 0.126*"subdued" + 0.125*"june"'),
#  (11,
#   '-0.250*"operation" + 0.181*"contained" + 0.163*"process" + '
#   '-0.153*"refinancing" + -0.145*"longer" + -0.142*"volatility" + '
#   '0.124*"february" + 0.124*"projection" + 0.123*"tension" + 0.116*"march"'),
#  (12,
#   '-0.183*"commodity" + -0.173*"fall" + -0.151*"turmoil" + -0.140*"march" + '
#   '0.132*"november" + -0.131*"tension" + -0.127*"diminishing" + '
#   '0.124*"october" + -0.122*"intensification" + -0.116*"february"'),
#  (13,
#   '0.226*"value" + 0.204*"reference" + -0.190*"july" + -0.165*"national" + '
#   '0.164*"march" + -0.156*"january" + -0.154*"facility" + -0.149*"central" + '
#   '-0.131*"june" + 0.126*"april"'),
#  (14,
#   '0.244*"july" + -0.175*"operation" + -0.168*"march" + 0.151*"june" + '
#   '-0.145*"asset" + -0.140*"central" + -0.137*"framework" + 0.132*"value" + '
#   '0.126*"consumer" + 0.119*"accommodative"'),
#  (15,
#   '0.231*"banknote" + 0.173*"national" + 0.152*"changeover" + 0.145*"exchange" '
#   '+ 0.140*"pillar" + -0.122*"system" + -0.116*"stage" + -0.116*"reserve" + '
#   '-0.115*"november" + -0.114*"deficit"'),
#  (16,
#   '-0.211*"gradual" + 0.174*"june" + -0.166*"september" + 0.154*"weak" + '
#   '-0.154*"accommodative" + 0.146*"tension" + -0.130*"volatility" + '
#   '-0.128*"long" + 0.126*"several" + -0.125*"commodity"'),
#  (17,
#   '0.175*"banking" + 0.157*"system" + -0.140*"june" + 0.132*"objective" + '
#   '-0.129*"firm" + -0.126*"lending" + 0.125*"banknote" + -0.124*"three" + '
#   '0.122*"end" + -0.122*"momentum"'),
#  (18,
#   '-0.182*"volatility" + 0.159*"pillar" + 0.147*"cash" + 0.136*"changeover" + '
#   '0.125*"moderation" + 0.123*"november" + -0.112*"august" + 0.107*"reference" '
#   '+ 0.104*"december" + -0.102*"industrial"'),
#  (19,
#   '0.173*"january" + 0.165*"august" + -0.148*"target" + -0.134*"day" + '
#   '-0.132*"november" + -0.132*"december" + -0.125*"contained" + 0.124*"early" '
#   '+ -0.122*"lending" + 0.114*"volatility"')]
# [(0,
#   '-0.205*"projection" + -0.158*"staff" + -0.130*"operation" + '
#   '-0.116*"december" + -0.111*"commodity" + -0.106*"january" + '
#   '-0.103*"september" + -0.097*"march" + -0.094*"to" + -0.093*"june"'),
#  (1,
#   '0.258*"central" + 0.214*"national" + -0.213*"projection" + 0.193*"banknote" '
#   '+ 0.159*"three" + 0.155*"january" + 0.147*"reference" + 0.142*"system" + '
#   '0.141*"value" + -0.137*"staff"'),
#  (2,
#   '0.235*"operation" + 0.160*"subdued" + 0.156*"refinancing" + -0.133*"trend" '
#   '+ 0.128*"below" + 0.128*"to" + 0.118*"purchase" + -0.118*"longer" + '
#   '0.115*"january" + -0.114*"food"'),
#  (3,
#   '-0.411*"projection" + -0.269*"staff" + 0.177*"commodity" + '
#   '-0.161*"purchase" + 0.146*"keeping" + 0.141*"negative" + '
#   '0.137*"policyrelevant" + 0.131*"tension" + 0.124*"aim" + 0.116*"deposit"'),
#  (4,
#   '0.394*"projection" + 0.275*"staff" + 0.234*"range" + -0.189*"subdued" + '
#   '0.160*"operation" + -0.155*"gradual" + -0.141*"purchase" + -0.113*"asset" + '
#   '0.113*"commodity" + -0.099*"pillar"'),
#  (5,
#   '-0.245*"projection" + 0.202*"ample" + 0.171*"operation" + -0.168*"negative" '
#   '+ -0.167*"subdued" + 0.150*"job" + 0.143*"accommodative" + -0.141*"staff" + '
#   '0.135*"creation" + 0.134*"warranted"'),
#  (6,
#   '0.227*"food" + 0.171*"operation" + 0.154*"commodity" + 0.154*"secondround" '
#   '+ -0.153*"longer" + 0.150*"tension" + 0.128*"turmoil" + 0.126*"behaviour" + '
#   '-0.123*"ample" + 0.112*"january"'),
#  (7,
#   '0.265*"purchase" + -0.179*"december" + -0.169*"subdued" + 0.159*"june" + '
#   '0.149*"asset" + 0.128*"firm" + 0.125*"national" + -0.122*"picture" + '
#   '-0.119*"consumer" + -0.114*"november"'),
#  (8,
#   '0.434*"january" + 0.292*"december" + -0.226*"july" + -0.195*"august" + '
#   '-0.188*"june" + 0.172*"february" + -0.150*"september" + -0.148*"operation" '
#   '+ 0.144*"march" + -0.127*"tension"'),
#  (9,
#   '0.207*"consumer" + -0.202*"subdued" + 0.173*"pillar" + 0.151*"operation" + '
#   '0.151*"negative" + -0.123*"tension" + 0.123*"refinancing" + '
#   '-0.123*"central" + -0.120*"national" + 0.115*"purchase"'),
#  (10,
#   '0.300*"october" + -0.296*"march" + 0.296*"september" + -0.260*"april" + '
#   '0.222*"november" + 0.159*"purchase" + -0.141*"february" + 0.140*"december" '
#   '+ -0.126*"subdued" + -0.125*"june"'),
#  (11,
#   '-0.250*"operation" + 0.181*"contained" + 0.163*"process" + '
#   '-0.152*"refinancing" + -0.145*"longer" + -0.142*"volatility" + '
#   '0.124*"february" + 0.124*"projection" + 0.123*"tension" + 0.116*"march"'),
#  (12,
#   '0.183*"commodity" + 0.173*"fall" + 0.151*"turmoil" + 0.140*"march" + '
#   '-0.132*"november" + 0.131*"tension" + 0.127*"diminishing" + '
#   '-0.124*"october" + 0.122*"intensification" + 0.116*"february"'),
#  (13,
#   '0.226*"value" + 0.204*"reference" + -0.190*"july" + -0.165*"national" + '
#   '0.164*"march" + -0.156*"january" + -0.154*"facility" + -0.149*"central" + '
#   '-0.131*"june" + 0.126*"april"'),
#  (14,
#   '-0.244*"july" + 0.175*"operation" + 0.168*"march" + -0.151*"june" + '
#   '0.145*"asset" + 0.139*"central" + 0.136*"framework" + -0.132*"value" + '
#   '-0.126*"consumer" + -0.119*"accommodative"'),
#  (15,
#   '0.231*"banknote" + 0.173*"national" + 0.153*"changeover" + 0.144*"exchange" '
#   '+ 0.140*"pillar" + -0.122*"system" + -0.116*"stage" + -0.116*"reserve" + '
#   '-0.115*"november" + -0.115*"deficit"'),
#  (16,
#   '-0.211*"gradual" + 0.173*"june" + -0.166*"september" + 0.154*"weak" + '
#   '-0.154*"accommodative" + 0.146*"tension" + -0.130*"volatility" + '
#   '-0.128*"long" + 0.126*"several" + -0.125*"commodity"'),
#  (17,
#   '0.176*"banking" + 0.157*"system" + -0.139*"june" + 0.133*"objective" + '
#   '-0.129*"firm" + -0.125*"lending" + -0.125*"three" + 0.124*"banknote" + '
#   '0.123*"end" + -0.122*"momentum"'),
#  (18,
#   '0.183*"volatility" + -0.159*"pillar" + -0.146*"cash" + -0.136*"changeover" '
#   '+ -0.126*"moderation" + -0.123*"november" + 0.112*"august" + '
#   '-0.108*"reference" + -0.105*"december" + 0.102*"industrial"'),
#  (19,
#   '-0.173*"january" + -0.165*"august" + 0.148*"target" + 0.134*"day" + '
#   '0.132*"december" + 0.132*"november" + 0.124*"contained" + -0.124*"early" + '
#   '0.122*"lending" + -0.114*"volatility"'),
#  (20,
#   '-0.198*"june" + 0.188*"banknote" + 0.152*"momentum" + 0.151*"increasing" + '
#   '-0.131*"december" + 0.123*"lending" + -0.119*"legal" + 0.114*"september" + '
#   '-0.113*"confirmed" + -0.109*"general"'),
#  (21,
#   '-0.157*"changeover" + -0.154*"volatility" + -0.146*"cash" + '
#   '0.145*"february" + -0.137*"june" + 0.123*"exchange" + -0.122*"weak" + '
#   '-0.120*"pillar" + -0.111*"trend" + 0.107*"december"'),
#  (22,
#   '-0.234*"banknote" + -0.192*"day" + -0.179*"december" + 0.164*"exchange" + '
#   '-0.150*"evidence" + -0.139*"production" + 0.128*"cost" + 0.118*"february" + '
#   '0.114*"march" + 0.103*"october"'),
#  (23,
#   '0.208*"april" + 0.194*"september" + -0.151*"february" + -0.134*"additional" '
#   '+ 0.131*"end" + 0.128*"october" + 0.127*"lead" + -0.122*"january" + '
#   '-0.117*"july" + 0.116*"reflected"'),
#  (24,
#   '-0.147*"lower" + -0.141*"january" + -0.140*"gradual" + -0.123*"target" + '
#   '0.119*"single" + 0.116*"secondround" + 0.110*"october" + 0.104*"programme" '
#   '+ 0.101*"march" + -0.098*"july"'),
#  (25,
#   '0.214*"april" + -0.154*"weak" + 0.153*"gradual" + 0.151*"october" + '
#   '-0.130*"range" + -0.129*"january" + 0.126*"march" + -0.117*"trend" + '
#   '0.113*"service" + -0.109*"reflects"'),
#  (26,
#   '0.187*"treaty" + -0.159*"trend" + 0.134*"framework" + 0.127*"thus" + '
#   '-0.123*"vigilance" + 0.123*"institution" + 0.120*"objective" + '
#   '0.120*"exchange" + 0.110*"single" + 0.108*"union"'),
#  (27,
#   '0.228*"june" + -0.192*"august" + -0.181*"february" + -0.177*"march" + '
#   '0.156*"december" + -0.139*"contained" + 0.137*"asset" + -0.129*"firm" + '
#   '0.114*"april" + 0.103*"lending"'),
#  (28,
#   '0.145*"reduction" + -0.131*"august" + 0.129*"pillar" + -0.127*"february" + '
#   '-0.125*"framework" + 0.120*"confirmed" + -0.120*"value" + 0.118*"position" '
#   '+ -0.109*"legal" + 0.101*"april"'),
#  (29,
#   '0.186*"course" + -0.166*"side" + 0.161*"confirmed" + 0.149*"scenario" + '
#   '-0.142*"november" + -0.130*"robust" + -0.130*"member" + 0.125*"deficit" + '
#   '0.121*"changeover" + 0.120*"gradually"'),
#  (30,
#   '0.217*"programme" + -0.172*"service" + 0.133*"gradual" + 0.129*"effort" + '
#   '0.128*"respect" + 0.113*"thus" + -0.110*"september" + -0.107*"full" + '
#   '0.103*"picture" + -0.102*"position"'),
#  (31,
#   '-0.141*"august" + 0.134*"pillar" + 0.133*"two" + -0.124*"reference" + '
#   '0.124*"day" + 0.115*"target" + -0.114*"course" + -0.109*"end" + '
#   '0.106*"october" + 0.106*"already"'),
#  (32,
#   '-0.157*"volatility" + -0.155*"significantly" + -0.128*"weak" + 0.117*"full" '
#   '+ -0.116*"subject" + 0.110*"next" + 0.103*"confirmed" + -0.100*"gradually" '
#   '+ 0.096*"evidence" + 0.095*"june"'),
#  (33,
#   '0.188*"august" + 0.162*"july" + -0.156*"volatility" + 0.145*"somewhat" + '
#   '-0.143*"october" + -0.132*"take" + -0.124*"half" + 0.116*"december" + '
#   '-0.112*"february" + 0.110*"turmoil"'),
#  (34,
#   '0.175*"december" + -0.156*"commodity" + -0.117*"lower" + 0.114*"capacity" + '
#   '-0.110*"process" + -0.108*"remaining" + 0.106*"september" + '
#   '0.102*"consumer" + 0.101*"competition" + -0.101*"firm"'),
#  (35,
#   '0.162*"november" + -0.135*"september" + 0.130*"firm" + -0.129*"february" + '
#   '0.121*"confirmed" + -0.121*"sign" + 0.120*"average" + -0.116*"volatility" + '
#   '-0.113*"around" + 0.108*"april"'),
#  (36,
#   '-0.129*"process" + -0.125*"significantly" + -0.119*"gradually" + '
#   '0.117*"take" + 0.115*"purchase" + -0.110*"subdued" + -0.108*"lead" + '
#   '-0.106*"firm" + -0.106*"clear" + 0.103*"additional"'),
#  (37,
#   '-0.194*"purchase" + -0.168*"programme" + 0.158*"prospect" + -0.145*"range" '
#   '+ -0.135*"longterm" + 0.130*"target" + -0.114*"treaty" + '
#   '-0.110*"prevailing" + 0.107*"forecast" + 0.104*"needed"'),
#  (38,
#   '0.152*"trend" + -0.150*"range" + -0.133*"gradual" + 0.132*"deficit" + '
#   '0.130*"treaty" + -0.128*"august" + 0.114*"food" + -0.113*"prospect" + '
#   '0.109*"excessive" + -0.108*"comprehensive"'),
#  (39,
#   '-0.139*"firm" + -0.134*"deficit" + -0.132*"exchange" + 0.129*"short" + '
#   '0.127*"service" + -0.125*"consumer" + -0.124*"several" + 0.123*"position" + '
#   '-0.110*"banknote" + 0.107*"take"'),
#  (40,
#   '0.153*"october" + -0.147*"december" + 0.134*"cost" + 0.128*"broadbased" + '
#   '-0.126*"half" + -0.113*"background" + -0.111*"base" + 0.107*"challenge" + '
#   '0.104*"june" + 0.102*"observed"'),
#  (41,
#   '-0.205*"range" + -0.158*"february" + 0.143*"trend" + -0.132*"asset" + '
#   '0.123*"cost" + -0.121*"early" + -0.118*"prospect" + 0.117*"reflect" + '
#   '0.114*"provide" + -0.103*"service"'),
#  (42,
#   '-0.152*"slightly" + 0.142*"issue" + -0.141*"contribute" + '
#   '-0.134*"significantly" + -0.124*"discussion" + 0.117*"full" + '
#   '-0.114*"range" + 0.103*"system" + 0.103*"related" + -0.103*"prospect"'),
#  (43,
#   '-0.153*"april" + 0.141*"february" + -0.130*"january" + -0.126*"subdued" + '
#   '-0.118*"pillar" + -0.118*"purchase" + 0.117*"good" + -0.114*"consumer" + '
#   '-0.113*"target" + -0.111*"firm"'),
#  (44,
#   '0.154*"several" + 0.151*"slightly" + 0.136*"objective" + '
#   '-0.127*"materialise" + -0.125*"longterm" + -0.122*"including" + '
#   '-0.122*"commodity" + 0.114*"average" + -0.112*"fully" + 0.104*"process"'),
#  (45,
#   '0.174*"lower" + 0.127*"owing" + -0.125*"february" + 0.116*"weakening" + '
#   '0.110*"august" + -0.108*"june" + 0.107*"april" + -0.105*"contained" + '
#   '0.103*"deficit" + -0.096*"accommodative"'),
#  (46,
#   '-0.156*"service" + 0.138*"commodity" + 0.128*"early" + -0.118*"contribute" '
#   '+ 0.107*"nature" + -0.107*"trend" + 0.106*"sustainability" + '
#   '0.100*"earlier" + -0.100*"cost" + -0.099*"fully"'),
#  (47,
#   '0.157*"november" + -0.144*"process" + 0.134*"june" + -0.134*"commission" + '
#   '-0.126*"september" + 0.122*"february" + -0.118*"state" + -0.114*"april" + '
#   '0.110*"increasingly" + 0.104*"owing"'),
#  (48,
#   '0.169*"contribute" + -0.160*"must" + 0.116*"tender" + -0.109*"bond" + '
#   '-0.108*"effective" + 0.106*"prevailing" + -0.104*"international" + '
#   '0.103*"consumer" + -0.102*"treaty" + 0.099*"lower"'),
#  (49,
#   '-0.152*"end" + -0.148*"fully" + 0.126*"take" + -0.124*"momentum" + '
#   '0.122*"range" + -0.121*"consumer" + -0.121*"treaty" + 0.119*"position" + '
#   '0.118*"two" + -0.112*"negative"')]
# [(0,
#   '-0.205*"projection" + -0.158*"staff" + -0.130*"operation" + '
#   '-0.116*"december" + -0.111*"commodity" + -0.106*"january" + '
#   '-0.103*"september" + -0.097*"march" + -0.094*"to" + -0.093*"june"'),
#  (1,
#   '0.258*"central" + 0.214*"national" + -0.213*"projection" + 0.193*"banknote" '
#   '+ 0.159*"three" + 0.155*"january" + 0.147*"reference" + 0.142*"system" + '
#   '0.141*"value" + -0.137*"staff"'),
#  (2,
#   '-0.235*"operation" + -0.160*"subdued" + -0.156*"refinancing" + '
#   '0.133*"trend" + -0.128*"below" + -0.128*"to" + -0.118*"purchase" + '
#   '0.118*"longer" + -0.115*"january" + 0.114*"food"'),
#  (3,
#   '-0.411*"projection" + -0.269*"staff" + 0.177*"commodity" + '
#   '-0.161*"purchase" + 0.146*"keeping" + 0.141*"negative" + '
#   '0.137*"policyrelevant" + 0.131*"tension" + 0.124*"aim" + 0.116*"deposit"'),
#  (4,
#   '0.394*"projection" + 0.275*"staff" + 0.234*"range" + -0.189*"subdued" + '
#   '0.160*"operation" + -0.155*"gradual" + -0.141*"purchase" + -0.113*"asset" + '
#   '0.113*"commodity" + -0.099*"pillar"'),
#  (5,
#   '0.245*"projection" + -0.202*"ample" + -0.171*"operation" + 0.168*"negative" '
#   '+ 0.167*"subdued" + -0.150*"job" + -0.143*"accommodative" + 0.141*"staff" + '
#   '-0.135*"creation" + -0.134*"warranted"'),
#  (6,
#   '0.227*"food" + 0.171*"operation" + 0.154*"commodity" + 0.154*"secondround" '
#   '+ -0.153*"longer" + 0.150*"tension" + 0.128*"turmoil" + 0.126*"behaviour" + '
#   '-0.123*"ample" + 0.112*"january"'),
#  (7,
#   '0.265*"purchase" + -0.179*"december" + -0.169*"subdued" + 0.159*"june" + '
#   '0.149*"asset" + 0.128*"firm" + 0.125*"national" + -0.122*"picture" + '
#   '-0.119*"consumer" + -0.114*"november"'),
#  (8,
#   '-0.434*"january" + -0.292*"december" + 0.226*"july" + 0.195*"august" + '
#   '0.188*"june" + -0.172*"february" + 0.150*"september" + 0.148*"operation" + '
#   '-0.144*"march" + 0.127*"tension"'),
#  (9,
#   '-0.207*"consumer" + 0.202*"subdued" + -0.173*"pillar" + -0.151*"operation" '
#   '+ -0.151*"negative" + 0.123*"tension" + -0.123*"refinancing" + '
#   '0.123*"central" + 0.120*"national" + -0.115*"purchase"'),
#  (10,
#   '-0.300*"october" + -0.296*"september" + 0.296*"march" + 0.260*"april" + '
#   '-0.221*"november" + -0.159*"purchase" + 0.141*"february" + '
#   '-0.140*"december" + 0.126*"subdued" + 0.125*"june"'),
#  (11,
#   '-0.250*"operation" + 0.181*"contained" + 0.163*"process" + '
#   '-0.152*"refinancing" + -0.145*"longer" + -0.142*"volatility" + '
#   '0.124*"february" + 0.124*"projection" + 0.123*"tension" + 0.116*"march"'),
#  (12,
#   '-0.183*"commodity" + -0.173*"fall" + -0.151*"turmoil" + -0.140*"march" + '
#   '0.132*"november" + -0.131*"tension" + -0.127*"diminishing" + '
#   '0.124*"october" + -0.122*"intensification" + -0.116*"february"'),
#  (13,
#   '0.226*"value" + 0.204*"reference" + -0.190*"july" + -0.165*"national" + '
#   '0.164*"march" + -0.156*"january" + -0.154*"facility" + -0.149*"central" + '
#   '-0.131*"june" + 0.126*"april"'),
#  (14,
#   '0.244*"july" + -0.175*"operation" + -0.168*"march" + 0.151*"june" + '
#   '-0.145*"asset" + -0.140*"central" + -0.136*"framework" + 0.132*"value" + '
#   '0.126*"consumer" + 0.119*"accommodative"'),
#  (15,
#   '0.231*"banknote" + 0.173*"national" + 0.153*"changeover" + 0.144*"exchange" '
#   '+ 0.140*"pillar" + -0.122*"system" + -0.116*"stage" + -0.116*"reserve" + '
#   '-0.115*"november" + -0.115*"deficit"'),
#  (16,
#   '0.211*"gradual" + -0.174*"june" + 0.166*"september" + -0.154*"weak" + '
#   '0.154*"accommodative" + -0.146*"tension" + 0.130*"volatility" + '
#   '0.128*"long" + -0.126*"several" + 0.125*"commodity"'),
#  (17,
#   '-0.175*"banking" + -0.157*"system" + 0.140*"june" + -0.133*"objective" + '
#   '0.129*"firm" + 0.125*"lending" + 0.125*"three" + -0.125*"banknote" + '
#   '-0.123*"end" + 0.122*"momentum"'),
#  (18,
#   '-0.183*"volatility" + 0.159*"pillar" + 0.146*"cash" + 0.136*"changeover" + '
#   '0.126*"moderation" + 0.123*"november" + -0.112*"august" + 0.108*"reference" '
#   '+ 0.105*"december" + -0.102*"industrial"'),
#  (19,
#   '0.173*"january" + 0.165*"august" + -0.148*"target" + -0.133*"day" + '
#   '-0.132*"november" + -0.132*"december" + -0.124*"contained" + 0.124*"early" '
#   '+ -0.122*"lending" + 0.114*"volatility"'),
#  (20,
#   '0.198*"june" + -0.188*"banknote" + -0.152*"momentum" + -0.152*"increasing" '
#   '+ 0.131*"december" + -0.123*"lending" + 0.119*"legal" + -0.114*"september" '
#   '+ 0.113*"confirmed" + 0.109*"general"'),
#  (21,
#   '-0.157*"changeover" + -0.154*"volatility" + -0.146*"cash" + '
#   '0.145*"february" + -0.137*"june" + 0.123*"exchange" + -0.122*"weak" + '
#   '-0.120*"pillar" + -0.111*"trend" + 0.108*"december"'),
#  (22,
#   '0.234*"banknote" + 0.192*"day" + 0.179*"december" + -0.165*"exchange" + '
#   '0.150*"evidence" + 0.139*"production" + -0.128*"cost" + -0.118*"february" + '
#   '-0.114*"march" + -0.103*"october"'),
#  (23,
#   '-0.208*"april" + -0.194*"september" + 0.151*"february" + 0.134*"additional" '
#   '+ -0.131*"end" + -0.128*"lead" + -0.127*"october" + 0.122*"january" + '
#   '0.117*"july" + -0.116*"reflected"'),
#  (24,
#   '0.147*"lower" + 0.141*"january" + 0.140*"gradual" + 0.123*"target" + '
#   '-0.119*"single" + -0.116*"secondround" + -0.110*"october" + '
#   '-0.103*"programme" + -0.101*"march" + 0.098*"july"'),
#  (25,
#   '0.214*"april" + -0.154*"weak" + 0.153*"gradual" + 0.151*"october" + '
#   '-0.130*"range" + -0.129*"january" + 0.126*"march" + -0.118*"trend" + '
#   '0.113*"service" + -0.109*"reflects"'),
#  (26,
#   '0.186*"treaty" + -0.159*"trend" + 0.134*"framework" + 0.126*"thus" + '
#   '-0.123*"vigilance" + 0.122*"institution" + 0.120*"objective" + '
#   '0.120*"exchange" + 0.110*"single" + 0.109*"union"'),
#  (27,
#   '0.227*"june" + -0.192*"august" + -0.181*"february" + -0.177*"march" + '
#   '0.156*"december" + -0.139*"contained" + 0.138*"asset" + -0.129*"firm" + '
#   '0.115*"april" + 0.103*"lending"'),
#  (28,
#   '-0.145*"reduction" + 0.132*"august" + -0.129*"pillar" + 0.127*"february" + '
#   '0.125*"framework" + -0.120*"confirmed" + 0.120*"value" + -0.118*"position" '
#   '+ 0.109*"legal" + -0.101*"april"'),
#  (29,
#   '0.186*"course" + -0.166*"side" + 0.161*"confirmed" + 0.149*"scenario" + '
#   '-0.142*"november" + -0.130*"member" + -0.130*"robust" + 0.125*"deficit" + '
#   '0.121*"changeover" + 0.120*"gradually"'),
#  (30,
#   '0.217*"programme" + -0.171*"service" + 0.132*"gradual" + 0.129*"effort" + '
#   '0.128*"respect" + 0.113*"thus" + -0.110*"september" + -0.107*"full" + '
#   '0.104*"picture" + -0.102*"position"'),
#  (31,
#   '0.143*"august" + -0.134*"pillar" + -0.133*"two" + 0.124*"reference" + '
#   '-0.123*"day" + -0.115*"target" + 0.113*"course" + 0.110*"end" + '
#   '-0.107*"already" + -0.105*"october"'),
#  (32,
#   '0.157*"volatility" + 0.155*"significantly" + 0.128*"weak" + 0.116*"subject" '
#   '+ -0.116*"full" + -0.110*"next" + -0.103*"confirmed" + 0.100*"gradually" + '
#   '-0.096*"evidence" + -0.095*"june"'),
#  (33,
#   '0.189*"august" + 0.162*"july" + -0.156*"volatility" + 0.145*"somewhat" + '
#   '-0.144*"october" + -0.131*"take" + -0.124*"half" + 0.117*"december" + '
#   '-0.112*"february" + 0.110*"turmoil"'),
#  (34,
#   '0.175*"december" + -0.156*"commodity" + -0.117*"lower" + 0.114*"capacity" + '
#   '-0.110*"process" + -0.108*"remaining" + 0.106*"september" + '
#   '0.102*"consumer" + 0.101*"competition" + -0.101*"firm"'),
#  (35,
#   '0.161*"november" + -0.135*"september" + 0.131*"firm" + -0.130*"february" + '
#   '0.121*"average" + 0.121*"confirmed" + -0.120*"sign" + -0.115*"volatility" + '
#   '-0.113*"around" + 0.108*"april"'),
#  (36,
#   '-0.128*"process" + -0.126*"significantly" + -0.119*"gradually" + '
#   '0.118*"take" + 0.112*"purchase" + -0.110*"subdued" + -0.109*"lead" + '
#   '-0.106*"clear" + -0.105*"firm" + 0.104*"target"'),
#  (37,
#   '0.195*"purchase" + 0.169*"programme" + -0.158*"prospect" + 0.145*"range" + '
#   '0.134*"longterm" + -0.128*"target" + 0.113*"treaty" + 0.109*"prevailing" + '
#   '-0.106*"forecast" + -0.104*"needed"'),
#  (38,
#   '0.152*"trend" + -0.151*"range" + -0.133*"gradual" + 0.131*"deficit" + '
#   '0.129*"treaty" + -0.128*"august" + 0.114*"food" + -0.114*"prospect" + '
#   '0.108*"excessive" + -0.107*"comprehensive"'),
#  (39,
#   '0.138*"firm" + 0.134*"deficit" + 0.131*"exchange" + -0.129*"short" + '
#   '-0.128*"service" + 0.125*"several" + 0.124*"consumer" + -0.122*"position" + '
#   '0.110*"banknote" + -0.107*"take"'),
#  (40,
#   '0.153*"october" + -0.148*"december" + 0.132*"cost" + -0.128*"half" + '
#   '0.127*"broadbased" + -0.114*"background" + -0.110*"base" + '
#   '0.108*"challenge" + 0.103*"june" + 0.102*"observed"'),
#  (41,
#   '0.204*"range" + 0.157*"february" + -0.144*"trend" + 0.131*"asset" + '
#   '-0.122*"cost" + 0.122*"early" + 0.118*"prospect" + -0.118*"reflect" + '
#   '-0.113*"provide" + 0.103*"service"'),
#  (42,
#   '-0.152*"slightly" + 0.142*"issue" + -0.142*"contribute" + '
#   '-0.134*"significantly" + -0.124*"discussion" + 0.116*"full" + '
#   '-0.116*"range" + -0.105*"prospect" + 0.104*"system" + -0.103*"start"'),
#  (43,
#   '-0.153*"april" + 0.140*"february" + -0.129*"january" + -0.125*"subdued" + '
#   '-0.118*"purchase" + -0.117*"pillar" + -0.116*"consumer" + 0.116*"good" + '
#   '-0.112*"target" + -0.110*"firm"'),
#  (44,
#   '-0.154*"several" + -0.150*"slightly" + -0.136*"objective" + '
#   '0.127*"materialise" + 0.126*"longterm" + 0.123*"commodity" + '
#   '0.121*"including" + -0.113*"average" + 0.111*"fully" + 0.104*"suggest"'),
#  (45,
#   '0.174*"lower" + 0.127*"owing" + -0.125*"february" + 0.116*"weakening" + '
#   '0.112*"august" + -0.110*"june" + 0.108*"april" + 0.104*"deficit" + '
#   '-0.103*"contained" + -0.098*"accommodative"'),
#  (46,
#   '0.155*"service" + -0.137*"commodity" + -0.129*"early" + 0.118*"contribute" '
#   '+ -0.108*"nature" + 0.107*"trend" + -0.105*"sustainability" + '
#   '-0.102*"earlier" + 0.099*"pillar" + 0.099*"cost"'),
#  (47,
#   '0.157*"november" + -0.144*"process" + 0.135*"june" + -0.133*"commission" + '
#   '-0.127*"september" + 0.120*"february" + -0.119*"state" + -0.116*"april" + '
#   '0.109*"increasingly" + 0.105*"owing"'),
#  (48,
#   '0.170*"contribute" + -0.160*"must" + 0.115*"tender" + -0.110*"effective" + '
#   '-0.108*"bond" + 0.107*"prevailing" + 0.104*"consumer" + '
#   '-0.103*"international" + -0.103*"treaty" + 0.100*"lower"'),
#  (49,
#   '-0.152*"end" + -0.147*"fully" + 0.127*"take" + -0.124*"treaty" + '
#   '-0.124*"momentum" + -0.122*"consumer" + 0.119*"range" + 0.119*"position" + '
#   '0.117*"two" + -0.112*"foster"'),
#  (50,
#   '0.140*"state" + -0.137*"trend" + 0.134*"challenge" + -0.133*"banknote" + '
#   '-0.128*"longer" + -0.122*"production" + 0.122*"day" + 0.120*"member" + '
#   '-0.118*"purchase" + 0.118*"cost"'),
#  (51,
#   '-0.175*"average" + 0.138*"september" + -0.130*"november" + '
#   '0.124*"background" + -0.118*"projected" + 0.116*"world" + -0.106*"exchange" '
#   '+ 0.105*"security" + 0.102*"additional" + 0.101*"set"'),
#  (52,
#   '0.171*"range" + -0.143*"reduce" + 0.138*"contribute" + -0.122*"projection" '
#   '+ -0.113*"full" + 0.110*"objective" + 0.103*"projected" + 0.102*"forecast" '
#   '+ 0.102*"commodity" + 0.097*"earlier"'),
#  (53,
#   '0.152*"february" + -0.128*"full" + 0.120*"short" + -0.114*"world" + '
#   '0.113*"asset" + -0.111*"owing" + 0.110*"due" + -0.104*"component" + '
#   '0.101*"earlier" + 0.096*"tension"'),
#  (54,
#   '-0.180*"cost" + 0.153*"system" + 0.135*"reflects" + 0.126*"increasing" + '
#   '0.118*"seen" + -0.110*"much" + 0.103*"around" + 0.097*"observed" + '
#   '-0.096*"finance" + -0.093*"warranted"'),
#  (55,
#   '-0.145*"general" + 0.117*"including" + -0.115*"tender" + 0.113*"robust" + '
#   '0.112*"reflected" + -0.108*"needed" + -0.107*"december" + -0.106*"improve" '
#   '+ -0.103*"somewhat" + -0.100*"august"'),
#  (56,
#   '-0.123*"full" + -0.120*"temporary" + 0.116*"around" + 0.115*"lower" + '
#   '0.110*"range" + 0.109*"confirmed" + 0.105*"commodity" + -0.098*"already" + '
#   '-0.094*"third" + -0.092*"base"'),
#  (57,
#   '-0.145*"challenge" + -0.142*"average" + 0.136*"treaty" + 0.129*"march" + '
#   '0.128*"next" + -0.117*"framework" + -0.116*"rather" + -0.112*"programme" + '
#   '-0.108*"confirmed" + -0.101*"increasing"'),
#  (58,
#   '0.157*"february" + -0.139*"momentum" + 0.138*"november" + 0.125*"early" + '
#   '-0.123*"banking" + -0.118*"course" + -0.115*"january" + -0.112*"increasing" '
#   '+ -0.104*"monitoring" + -0.099*"far"'),
#  (59,
#   '0.118*"contribute" + -0.106*"around" + 0.106*"somewhat" + -0.101*"effort" + '
#   '0.098*"debt" + 0.098*"end" + -0.098*"suggest" + 0.095*"needed" + '
#   '-0.092*"november" + 0.091*"confirmed"'),
#  (60,
#   '-0.156*"service" + -0.140*"april" + 0.128*"consumer" + -0.120*"somewhat" + '
#   '-0.120*"early" + -0.114*"stemming" + 0.113*"relatively" + -0.112*"relating" '
#   '+ 0.111*"eu" + 0.110*"course"'),
#  (61,
#   '0.138*"reflects" + -0.127*"prevailing" + -0.125*"july" + 0.124*"range" + '
#   '0.120*"food" + 0.109*"finance" + -0.105*"target" + -0.104*"november" + '
#   '-0.103*"improve" + -0.099*"like"'),
#  (62,
#   '-0.152*"recently" + 0.149*"somewhat" + 0.118*"longterm" + -0.116*"early" + '
#   '0.109*"programme" + 0.108*"international" + -0.105*"member" + '
#   '0.104*"finance" + 0.101*"job" + 0.099*"mid"'),
#  (63,
#   '-0.191*"range" + 0.184*"lower" + -0.142*"consumer" + 0.126*"shock" + '
#   '-0.125*"generally" + 0.125*"improve" + -0.125*"expenditure" + '
#   '0.106*"august" + -0.099*"central" + 0.098*"service"'),
#  (64,
#   '0.139*"budgetary" + 0.110*"plan" + -0.108*"subject" + -0.108*"suggest" + '
#   '0.106*"effective" + 0.104*"observed" + 0.103*"confirmed" + 0.095*"related" '
#   '+ 0.095*"slightly" + 0.092*"contribute"'),
#  (65,
#   '0.152*"somewhat" + -0.141*"improve" + -0.115*"commodity" + -0.108*"lead" + '
#   '0.107*"deficit" + -0.101*"prevailing" + 0.100*"continuing" + '
#   '0.095*"anticipated" + -0.094*"confirmed" + -0.094*"production"'),
#  (66,
#   '-0.142*"moderation" + 0.129*"trend" + 0.124*"foreign" + -0.116*"stemming" + '
#   '-0.113*"negative" + -0.104*"beyond" + 0.101*"contribute" + -0.098*"short" + '
#   '-0.097*"nature" + -0.088*"union"'),
#  (67,
#   '0.144*"perspective" + -0.126*"production" + -0.109*"clearly" + '
#   '0.107*"several" + -0.102*"review" + -0.099*"already" + -0.098*"help" + '
#   '0.095*"provide" + 0.094*"evidence" + 0.093*"september"'),
#  (68,
#   '-0.116*"continuing" + 0.115*"budgetary" + -0.111*"next" + 0.109*"national" '
#   '+ 0.105*"forecast" + -0.101*"two" + -0.101*"already" + -0.095*"cost" + '
#   '-0.093*"slightly" + -0.093*"half"'),
#  (69,
#   '-0.132*"owing" + -0.124*"improved" + -0.118*"related" + -0.112*"generally" '
#   '+ 0.107*"prevailing" + 0.105*"longterm" + 0.105*"might" + -0.100*"forecast" '
#   '+ 0.100*"due" + -0.097*"two"'),
#  (70,
#   '-0.143*"service" + 0.143*"prospect" + 0.112*"give" + 0.107*"reduce" + '
#   '0.107*"projected" + -0.103*"fact" + -0.099*"strongly" + 0.098*"member" + '
#   '0.096*"general" + 0.095*"prevailing"'),
#  (71,
#   '-0.136*"october" + -0.127*"sound" + -0.117*"weakening" + -0.110*"gradual" + '
#   '-0.108*"plan" + 0.105*"perspective" + 0.105*"take" + -0.103*"trend" + '
#   '0.102*"reflects" + 0.101*"july"'),
#  (72,
#   '0.137*"already" + 0.131*"commodity" + 0.120*"confirmed" + 0.116*"improved" '
#   '+ -0.113*"trend" + 0.105*"reflect" + 0.104*"one" + 0.103*"treaty" + '
#   '0.096*"modest" + 0.096*"component"'),
#  (73,
#   '-0.134*"already" + -0.134*"programme" + -0.128*"early" + 0.124*"longer" + '
#   '0.122*"revised" + 0.119*"grow" + 0.117*"bond" + 0.107*"situation" + '
#   '-0.104*"significantly" + -0.103*"declined"'),
#  (74,
#   '-0.136*"evidence" + 0.125*"further" + -0.116*"exchange" + 0.114*"weakening" '
#   '+ -0.112*"partner" + 0.111*"opportunity" + -0.109*"stemming" + '
#   '-0.103*"march" + 0.100*"deficit" + -0.100*"owing"'),
#  (75,
#   '-0.125*"heightened" + 0.123*"within" + 0.118*"start" + 0.116*"july" + '
#   '-0.109*"indicate" + 0.107*"suggest" + 0.104*"april" + 0.096*"although" + '
#   '0.095*"far" + -0.094*"many"'),
#  (76,
#   '0.160*"service" + 0.132*"help" + -0.129*"half" + -0.117*"treaty" + '
#   '0.109*"april" + -0.108*"indeed" + 0.101*"nature" + -0.098*"subdued" + '
#   '0.098*"august" + 0.097*"present"'),
#  (77,
#   '0.121*"contribute" + -0.119*"reflect" + -0.115*"role" + 0.111*"release" + '
#   '-0.105*"upwards" + 0.104*"made" + 0.103*"way" + 0.101*"situation" + '
#   '-0.100*"come" + -0.095*"negative"'),
#  (78,
#   '-0.138*"one" + -0.132*"range" + 0.130*"service" + -0.123*"two" + '
#   '0.109*"return" + 0.106*"october" + -0.101*"accordingly" + '
#   '0.100*"determined" + -0.097*"effective" + -0.097*"sustained"'),
#  (79,
#   '-0.190*"july" + 0.130*"september" + 0.126*"slightly" + -0.125*"cost" + '
#   '0.116*"case" + -0.111*"capital" + 0.109*"fall" + -0.102*"october" + '
#   '0.092*"movement" + -0.088*"union"'),
#  (80,
#   '-0.150*"strongly" + 0.149*"two" + 0.136*"respect" + -0.122*"especially" + '
#   '-0.120*"commodity" + 0.110*"pillar" + -0.110*"firm" + 0.102*"purchase" + '
#   '-0.100*"recently" + -0.099*"significantly"'),
#  (81,
#   '-0.143*"range" + 0.140*"reflected" + 0.112*"thus" + -0.112*"significantly" '
#   '+ 0.110*"purchase" + 0.106*"hand" + -0.101*"that" + -0.101*"somewhat" + '
#   '-0.100*"volatility" + 0.099*"population"'),
#  (82,
#   '-0.146*"position" + 0.134*"moderation" + 0.124*"august" + 0.114*"lead" + '
#   '-0.110*"programme" + 0.108*"projected" + 0.104*"october" + 0.104*"largely" '
#   '+ -0.103*"december" + -0.102*"sound"'),
#  (83,
#   '-0.127*"monthly" + -0.116*"give" + 0.112*"budget" + -0.105*"moderation" + '
#   '0.102*"even" + 0.099*"deposit" + 0.096*"several" + -0.094*"sustained" + '
#   '0.093*"banking" + 0.092*"evolution"'),
#  (84,
#   '-0.118*"remaining" + 0.110*"owing" + -0.107*"effort" + 0.101*"cost" + '
#   '-0.097*"treaty" + 0.096*"indicates" + -0.092*"return" + 0.091*"purchase" + '
#   '-0.090*"finance" + 0.087*"food"'),
#  (85,
#   '0.196*"thus" + -0.123*"significantly" + 0.121*"gradually" + -0.120*"week" + '
#   '-0.114*"evidence" + -0.107*"treaty" + 0.106*"increasing" + '
#   '-0.102*"resulting" + 0.099*"early" + 0.094*"consumer"'),
#  (86,
#   '-0.121*"further" + -0.120*"commission" + -0.114*"mr" + -0.111*"commitment" '
#   '+ 0.097*"determined" + -0.096*"debt" + 0.096*"industrial" + 0.094*"member" '
#   '+ 0.092*"revised" + 0.091*"prevailing"'),
#  (87,
#   '0.115*"ecbs" + -0.112*"must" + -0.104*"additional" + 0.104*"several" + '
#   '0.099*"help" + 0.098*"slightly" + 0.096*"like" + 0.094*"evidence" + '
#   '0.092*"yield" + 0.091*"including"'),
#  (88,
#   '0.143*"slightly" + 0.125*"case" + -0.124*"side" + 0.120*"recently" + '
#   '0.099*"end" + -0.096*"including" + 0.095*"continuing" + 0.093*"consequence" '
#   '+ 0.091*"contained" + 0.090*"longterm"'),
#  (89,
#   '0.146*"deficit" + 0.145*"next" + -0.124*"background" + -0.110*"around" + '
#   '-0.109*"sustained" + -0.107*"remaining" + 0.100*"fact" + -0.100*"mr" + '
#   '-0.098*"recently" + 0.091*"better"'),
#  (90,
#   '-0.127*"base" + -0.120*"lead" + -0.118*"budget" + -0.111*"plan" + '
#   '-0.099*"affect" + -0.097*"gain" + -0.096*"furthermore" + -0.096*"ago" + '
#   '0.095*"beyond" + -0.093*"allow"'),
#  (91,
#   '0.143*"better" + 0.117*"continuing" + 0.114*"sustained" + -0.106*"respect" '
#   '+ -0.100*"cost" + 0.092*"associated" + 0.089*"january" + -0.088*"within" + '
#   '-0.088*"perspective" + -0.085*"broader"'),
#  (92,
#   '-0.119*"reflects" + 0.110*"objective" + 0.104*"result" + -0.099*"shock" + '
#   '-0.095*"rising" + -0.094*"long" + -0.093*"nature" + -0.092*"longterm" + '
#   '-0.090*"importance" + 0.085*"framework"'),
#  (93,
#   '0.118*"trend" + 0.111*"generally" + -0.108*"whole" + 0.104*"process" + '
#   '0.103*"one" + 0.095*"take" + 0.093*"state" + -0.088*"base" + -0.087*"side" '
#   '+ -0.087*"downwards"'),
#  (94,
#   '0.127*"programme" + -0.119*"opportunity" + 0.119*"gradual" + 0.103*"reduce" '
#   '+ -0.098*"standard" + 0.097*"budgetary" + 0.096*"industrial" + '
#   '0.095*"competition" + 0.094*"sound" + 0.093*"rather"'),
#  (95,
#   '-0.123*"fully" + 0.116*"deficit" + -0.116*"august" + -0.102*"procedure" + '
#   '0.099*"competitiveness" + 0.098*"see" + -0.098*"signal" + '
#   '0.097*"continuing" + -0.095*"good" + -0.092*"productivity"'),
#  (96,
#   '0.126*"turn" + 0.110*"substantial" + 0.108*"consumer" + 0.107*"eu" + '
#   '-0.105*"output" + 0.105*"end" + 0.105*"commission" + -0.101*"budgetary" + '
#   '-0.100*"fourth" + 0.097*"commitment"'),
#  (97,
#   '-0.131*"partly" + -0.129*"comprehensive" + -0.126*"especially" + '
#   '-0.123*"result" + 0.121*"forecast" + -0.107*"mid" + -0.089*"fostering" + '
#   '-0.088*"system" + 0.085*"corporate" + 0.085*"create"'),
#  (98,
#   '0.130*"within" + -0.107*"published" + -0.105*"gradual" + -0.103*"remaining" '
#   '+ -0.102*"dampened" + 0.097*"seen" + 0.094*"situation" + -0.093*"next" + '
#   '0.092*"anticipated" + -0.090*"turn"'),
#  (99,
#   '0.137*"process" + -0.109*"third" + -0.109*"needed" + -0.103*"weak" + '
#   '0.102*"dampen" + 0.098*"indicates" + -0.098*"commission" + 0.096*"made" + '
#   '0.095*"october" + 0.088*"reduce"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lsi5 = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi5 = coherence_model_lsi5.get_coherence()
print('\nCoherence Score5: ', coherence_lsi5)

# Compute Coherence Score
coherence_model_lsi10 = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi10 = coherence_model_lsi10.get_coherence()
print('\nCoherence Score10: ', coherence_lsi10)

# Compute Coherence Score
coherence_model_lsi20 = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi20 = coherence_model_lsi20.get_coherence()
print('\nCoherence Score20: ', coherence_lsi20)

# Compute Coherence Score
coherence_model_lsi50 = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi50 = coherence_model_lsi50.get_coherence()
print('\nCoherence Score50: ', coherence_lsi50)

# Compute Coherence Score
coherence_model_lsi100 = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi100 = coherence_model_lsi100.get_coherence()
print('\nCoherence Score100: ', coherence_lsi100)


# Compute Coherence Score
coherence_model_lsi5 = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi5 = coherence_model_lsi5.get_coherence()
print('\nCoherence Score5: ', coherence_lsi5)

# Compute Coherence Score
coherence_model_lsi10 = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi10 = coherence_model_lsi10.get_coherence()
print('\nCoherence Score10: ', coherence_lsi10)

# Compute Coherence Score
coherence_model_lsi20 = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi20 = coherence_model_lsi20.get_coherence()
print('\nCoherence Score20: ', coherence_lsi20)

# Compute Coherence Score
coherence_model_lsi50 = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi50 = coherence_model_lsi50.get_coherence()
print('\nCoherence Score50: ', coherence_lsi50)

# Compute Coherence Score
coherence_model_lsi100 = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi100 = coherence_model_lsi100.get_coherence()
print('\nCoherence Score100: ', coherence_lsi100)
# Out:
# Coherence Score5:  0.41369110917198454
#
# Coherence Score10:  0.3581927976624296
#
# Coherence Score20:  0.2841529928522577
#
# Coherence Score50:  0.2487279786034231
#
# Coherence Score100:  0.20989481696189657
#
# Coherence Score5:  -0.8891173216723786
#
# Coherence Score10:  -0.955057976778986
#
# Coherence Score20:  -1.0911301723266216
#
# Coherence Score50:  -1.4181090064029491
#
# Coherence Score100:  -1.3470237909752054
