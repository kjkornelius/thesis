# %% [markdown]
# # load packages

# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess, lemmatize
from gensim.models import CoherenceModel
from gensim.models import LdaModel, LdaMulticore
import gensim.downloader as api
from gensim.models import LsiModel

nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools 
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
#import logging
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
#logging.root.setLevel(level=logging.INFO)
#import warnings
#warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_csv('C:/Users/Kornelius/Desktop/Data 2/nips-papers/papers.csv', header = 0, sep = ';', error_bad_lines=False)
# Drop the columns not needed
df = df.drop(columns=['id', 'event_type', 'pdf_name'], axis=1)

# %%
# Drop a row by condition
df = df[df.abstract != 'Abstract Missing']

# %%
data = df.abstract.values.tolist()

# %% [markdown]
# # Pre-processing (Baseline)

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(data):
    stop_free = " ".join([i for i in data.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(data).split() for data in data]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(16129 unique tokens: ['activity', 'also', 'analysis', 'applied', 'assume']...)

# %%
# less than 10 documents,
id2word = corpora.Dictionary(data)
id2word.filter_extremes(no_below = 4)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# # LSI

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.103*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '0.519*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.327*"network" + '
#   '-0.296*"method" + -0.165*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.123*"neural"'),
#  (3,
#   '-0.574*"method" + 0.440*"learning" + 0.360*"network" + 0.292*"algorithm" + '
#   '-0.254*"data" + -0.122*"matrix" + -0.104*"problem" + 0.100*"neural" + '
#   '0.098*"deep" + 0.087*"task"'),
#  (4,
#   '0.588*"network" + -0.579*"learning" + -0.267*"data" + 0.218*"neural" + '
#   '0.104*"method" + 0.103*"algorithm" + -0.081*"task" + 0.078*"deep" + '
#   '-0.075*"approach" + 0.075*"image"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.102*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '-0.519*"algorithm" + -0.391*"model" + 0.334*"learning" + 0.327*"network" + '
#   '0.296*"method" + 0.165*"image" + 0.155*"task" + 0.143*"feature" + '
#   '0.125*"deep" + 0.123*"neural"'),
#  (3,
#   '-0.574*"method" + 0.440*"learning" + 0.359*"network" + 0.292*"algorithm" + '
#   '-0.254*"data" + -0.121*"matrix" + -0.104*"problem" + 0.100*"neural" + '
#   '0.098*"deep" + 0.086*"task"'),
#  (4,
#   '-0.588*"network" + 0.579*"learning" + 0.267*"data" + -0.218*"neural" + '
#   '-0.104*"algorithm" + -0.104*"method" + 0.081*"task" + -0.079*"deep" + '
#   '0.075*"approach" + -0.074*"image"'),
#  (5,
#   '-0.681*"data" + 0.316*"function" + -0.262*"algorithm" + 0.201*"model" + '
#   '0.196*"problem" + 0.184*"learning" + 0.163*"method" + -0.140*"network" + '
#   '0.114*"optimization" + -0.112*"feature"'),
#  (6,
#   '-0.523*"image" + 0.326*"data" + 0.271*"function" + 0.251*"network" + '
#   '-0.243*"algorithm" + -0.236*"feature" + -0.232*"object" + -0.219*"method" + '
#   '0.185*"distribution" + 0.119*"bound"'),
#  (7,
#   '-0.483*"method" + 0.424*"problem" + -0.320*"algorithm" + 0.289*"image" + '
#   '-0.224*"learning" + 0.125*"object" + -0.124*"inference" + -0.124*"gradient" '
#   '+ 0.121*"matrix" + 0.113*"distribution"'),
#  (8,
#   '0.567*"problem" + -0.530*"function" + -0.211*"image" + -0.191*"feature" + '
#   '0.185*"matrix" + 0.170*"learning" + -0.167*"distribution" + 0.144*"network" '
#   '+ -0.126*"bound" + -0.095*"loss"'),
#  (9,
#   '0.499*"function" + -0.350*"distribution" + -0.271*"bound" + 0.259*"data" + '
#   '0.250*"problem" + -0.204*"matrix" + -0.197*"sample" + 0.132*"optimization" '
#   '+ -0.107*"complexity" + -0.104*"show"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '0.728*"model" + -0.434*"algorithm" + -0.240*"problem" + -0.134*"function" + '
#   '-0.114*"learning" + 0.108*"network" + 0.102*"image" + -0.090*"bound" + '
#   '0.086*"neural" + -0.079*"method"'),
#  (2,
#   '-0.519*"algorithm" + -0.391*"model" + 0.334*"learning" + 0.328*"network" + '
#   '0.296*"method" + 0.165*"image" + 0.155*"task" + 0.143*"feature" + '
#   '0.125*"deep" + 0.123*"neural"'),
#  (3,
#   '0.574*"method" + -0.440*"learning" + -0.359*"network" + -0.292*"algorithm" '
#   '+ 0.254*"data" + 0.121*"matrix" + 0.103*"problem" + -0.100*"neural" + '
#   '-0.098*"deep" + -0.087*"task"'),
#  (4,
#   '-0.588*"network" + 0.579*"learning" + 0.267*"data" + -0.218*"neural" + '
#   '-0.104*"method" + -0.104*"algorithm" + 0.081*"task" + -0.079*"deep" + '
#   '0.075*"approach" + -0.075*"image"'),
#  (5,
#   '-0.681*"data" + 0.315*"function" + -0.262*"algorithm" + 0.201*"model" + '
#   '0.196*"problem" + 0.184*"learning" + 0.163*"method" + -0.139*"network" + '
#   '0.114*"optimization" + -0.112*"feature"'),
#  (6,
#   '-0.522*"image" + 0.327*"data" + 0.271*"function" + 0.251*"network" + '
#   '-0.244*"algorithm" + -0.236*"feature" + -0.233*"object" + -0.219*"method" + '
#   '0.184*"distribution" + 0.120*"bound"'),
#  (7,
#   '0.483*"method" + -0.424*"problem" + 0.320*"algorithm" + -0.290*"image" + '
#   '0.225*"learning" + -0.126*"object" + 0.124*"inference" + 0.124*"gradient" + '
#   '-0.121*"matrix" + -0.113*"distribution"'),
#  (8,
#   '-0.568*"problem" + 0.530*"function" + 0.211*"image" + 0.190*"feature" + '
#   '-0.184*"matrix" + -0.170*"learning" + 0.167*"distribution" + '
#   '-0.145*"network" + 0.127*"bound" + 0.095*"loss"'),
#  (9,
#   '-0.499*"function" + 0.349*"distribution" + 0.272*"bound" + -0.258*"data" + '
#   '-0.250*"problem" + 0.204*"matrix" + 0.194*"sample" + -0.131*"optimization" '
#   '+ 0.104*"complexity" + 0.103*"show"'),
#  (10,
#   '0.447*"feature" + 0.379*"matrix" + -0.370*"distribution" + '
#   '-0.277*"approach" + -0.245*"inference" + -0.202*"image" + 0.186*"kernel" + '
#   '0.131*"model" + -0.125*"problem" + 0.110*"function"'),
#  (11,
#   '0.403*"feature" + 0.326*"kernel" + 0.298*"approach" + -0.274*"bound" + '
#   '0.238*"inference" + -0.220*"image" + 0.200*"distribution" + -0.182*"data" + '
#   '-0.163*"loss" + 0.142*"graph"'),
#  (12,
#   '-0.282*"graph" + -0.276*"image" + 0.260*"task" + -0.227*"distribution" + '
#   '-0.222*"matrix" + 0.211*"time" + 0.190*"policy" + 0.176*"feature" + '
#   '0.174*"information" + -0.161*"kernel"'),
#  (13,
#   '0.507*"matrix" + -0.385*"feature" + 0.280*"approach" + -0.242*"graph" + '
#   '-0.172*"bound" + 0.158*"image" + -0.155*"problem" + -0.148*"method" + '
#   '-0.136*"distribution" + 0.126*"neural"'),
#  (14,
#   '-0.509*"graph" + 0.365*"distribution" + 0.309*"feature" + -0.236*"approach" '
#   '+ 0.180*"problem" + -0.166*"kernel" + -0.160*"bound" + 0.154*"gradient" + '
#   '-0.153*"clustering" + -0.145*"time"'),
#  (15,
#   '-0.409*"approach" + -0.391*"bound" + 0.283*"graph" + 0.272*"distribution" + '
#   '-0.220*"inference" + -0.161*"feature" + 0.151*"task" + 0.145*"clustering" + '
#   '0.123*"information" + 0.115*"method"'),
#  (16,
#   '0.463*"kernel" + -0.371*"task" + -0.277*"matrix" + 0.198*"image" + '
#   '0.197*"gradient" + -0.192*"function" + 0.173*"rate" + -0.152*"approach" + '
#   '0.142*"stochastic" + 0.116*"convergence"'),
#  (17,
#   '0.327*"task" + 0.274*"gradient" + -0.241*"bound" + -0.225*"inference" + '
#   '-0.189*"method" + 0.186*"training" + -0.186*"image" + -0.144*"learning" + '
#   '0.144*"optimization" + 0.143*"approach"'),
#  (18,
#   '-0.509*"kernel" + 0.343*"approach" + -0.317*"task" + 0.215*"graph" + '
#   '0.193*"feature" + 0.159*"sparse" + -0.148*"classification" + '
#   '-0.139*"inference" + 0.121*"gradient" + -0.116*"process"'),
#  (19,
#   '0.286*"gradient" + -0.249*"loss" + 0.236*"matrix" + 0.225*"policy" + '
#   '-0.207*"neural" + 0.200*"stochastic" + -0.178*"approach" + 0.174*"time" + '
#   '-0.173*"linear" + -0.172*"neuron"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.103*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '0.519*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.327*"network" + '
#   '-0.296*"method" + -0.165*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.123*"neural"'),
#  (3,
#   '-0.574*"method" + 0.440*"learning" + 0.359*"network" + 0.292*"algorithm" + '
#   '-0.254*"data" + -0.121*"matrix" + -0.104*"problem" + 0.100*"neural" + '
#   '0.099*"deep" + 0.087*"task"'),
#  (4,
#   '0.588*"network" + -0.579*"learning" + -0.267*"data" + 0.218*"neural" + '
#   '0.104*"method" + 0.104*"algorithm" + -0.081*"task" + 0.079*"deep" + '
#   '-0.075*"approach" + 0.075*"image"'),
#  (5,
#   '-0.681*"data" + 0.315*"function" + -0.262*"algorithm" + 0.201*"model" + '
#   '0.196*"problem" + 0.184*"learning" + 0.163*"method" + -0.140*"network" + '
#   '0.114*"optimization" + -0.112*"feature"'),
#  (6,
#   '0.522*"image" + -0.327*"data" + -0.271*"function" + -0.251*"network" + '
#   '0.244*"algorithm" + 0.236*"feature" + 0.234*"object" + 0.219*"method" + '
#   '-0.185*"distribution" + -0.120*"bound"'),
#  (7,
#   '-0.483*"method" + 0.424*"problem" + -0.320*"algorithm" + 0.290*"image" + '
#   '-0.225*"learning" + 0.125*"object" + -0.125*"inference" + -0.123*"gradient" '
#   '+ 0.121*"matrix" + 0.113*"distribution"'),
#  (8,
#   '-0.568*"problem" + 0.530*"function" + 0.212*"image" + 0.190*"feature" + '
#   '-0.184*"matrix" + -0.170*"learning" + 0.167*"distribution" + '
#   '-0.145*"network" + 0.126*"bound" + 0.095*"loss"'),
#  (9,
#   '0.500*"function" + -0.349*"distribution" + -0.271*"bound" + 0.258*"data" + '
#   '0.251*"problem" + -0.206*"matrix" + -0.195*"sample" + 0.129*"optimization" '
#   '+ -0.104*"show" + -0.104*"complexity"'),
#  (10,
#   '0.447*"feature" + 0.380*"matrix" + -0.369*"distribution" + '
#   '-0.277*"approach" + -0.245*"inference" + -0.201*"image" + 0.186*"kernel" + '
#   '0.131*"model" + -0.125*"problem" + 0.111*"function"'),
#  (11,
#   '0.402*"feature" + 0.324*"kernel" + 0.299*"approach" + -0.275*"bound" + '
#   '0.239*"inference" + -0.223*"image" + 0.196*"distribution" + -0.183*"data" + '
#   '-0.164*"loss" + 0.140*"graph"'),
#  (12,
#   '-0.281*"graph" + -0.275*"image" + 0.259*"task" + -0.231*"distribution" + '
#   '-0.222*"matrix" + 0.210*"time" + 0.192*"policy" + 0.173*"feature" + '
#   '0.173*"information" + -0.166*"kernel"'),
#  (13,
#   '0.508*"matrix" + -0.388*"feature" + 0.282*"approach" + -0.237*"graph" + '
#   '-0.171*"bound" + 0.158*"image" + -0.158*"problem" + -0.147*"method" + '
#   '-0.141*"distribution" + 0.120*"neural"'),
#  (14,
#   '-0.510*"graph" + 0.366*"distribution" + 0.309*"feature" + -0.232*"approach" '
#   '+ 0.180*"problem" + -0.167*"kernel" + -0.162*"bound" + -0.155*"clustering" '
#   '+ 0.147*"gradient" + -0.143*"time"'),
#  (15,
#   '0.404*"approach" + 0.398*"bound" + -0.285*"graph" + -0.276*"distribution" + '
#   '0.218*"inference" + 0.161*"feature" + -0.158*"task" + -0.145*"clustering" + '
#   '-0.117*"method" + -0.116*"neuron"'),
#  (16,
#   '-0.460*"kernel" + 0.364*"task" + 0.276*"matrix" + -0.199*"gradient" + '
#   '-0.198*"image" + 0.193*"function" + -0.178*"rate" + 0.153*"approach" + '
#   '-0.143*"stochastic" + -0.122*"convergence"'),
#  (17,
#   '-0.341*"task" + -0.269*"gradient" + 0.234*"bound" + 0.228*"inference" + '
#   '-0.189*"training" + 0.188*"image" + 0.187*"method" + 0.149*"learning" + '
#   '-0.145*"stochastic" + -0.141*"approach"'),
#  (18,
#   '0.513*"kernel" + -0.355*"approach" + 0.318*"task" + -0.212*"graph" + '
#   '-0.192*"feature" + -0.159*"sparse" + 0.137*"classification" + '
#   '0.135*"inference" + 0.121*"process" + -0.116*"gradient"'),
#  (19,
#   '-0.294*"gradient" + 0.259*"loss" + -0.237*"policy" + -0.233*"matrix" + '
#   '0.213*"neural" + -0.203*"stochastic" + 0.171*"classification" + '
#   '0.171*"linear" + 0.167*"approach" + -0.163*"time"'),
#  (20,
#   '0.500*"inference" + -0.278*"approach" + -0.213*"policy" + -0.195*"kernel" + '
#   '0.180*"graph" + 0.167*"show" + -0.159*"distribution" + 0.146*"task" + '
#   '0.141*"variational" + 0.133*"loss"'),
#  (21,
#   '-0.398*"task" + -0.347*"bound" + 0.327*"time" + 0.231*"show" + '
#   '0.225*"label" + 0.189*"training" + 0.188*"loss" + -0.144*"structure" + '
#   '0.135*"classification" + 0.134*"class"'),
#  (22,
#   '-0.356*"clustering" + 0.261*"time" + -0.223*"information" + 0.223*"sparse" '
#   '+ 0.186*"task" + 0.178*"parameter" + 0.173*"regression" + 0.172*"image" + '
#   '-0.166*"matrix" + -0.160*"approach"'),
#  (23,
#   '-0.441*"clustering" + 0.328*"graph" + -0.243*"show" + 0.180*"gradient" + '
#   '0.179*"information" + 0.167*"loss" + -0.166*"result" + 0.164*"time" + '
#   '-0.156*"cluster" + -0.145*"set"'),
#  (24,
#   '-0.358*"result" + -0.285*"policy" + 0.271*"object" + 0.226*"number" + '
#   '0.205*"sample" + 0.199*"time" + -0.188*"show" + 0.173*"task" + '
#   '0.171*"parameter" + -0.158*"new"'),
#  (25,
#   '-0.326*"time" + -0.269*"object" + -0.229*"loss" + 0.197*"show" + '
#   '0.194*"training" + 0.188*"neural" + 0.181*"bound" + 0.175*"policy" + '
#   '0.173*"using" + -0.167*"framework"'),
#  (26,
#   '-0.474*"object" + 0.362*"time" + -0.220*"show" + 0.213*"clustering" + '
#   '-0.208*"variable" + 0.194*"result" + -0.176*"structure" + 0.155*"image" + '
#   '-0.148*"latent" + -0.126*"space"'),
#  (27,
#   '0.353*"show" + 0.303*"latent" + 0.241*"time" + 0.215*"variable" + '
#   '-0.171*"loss" + -0.164*"process" + 0.157*"topic" + 0.145*"word" + '
#   '-0.145*"state" + -0.145*"label"'),
#  (28,
#   '0.394*"information" + -0.297*"object" + 0.251*"process" + 0.218*"label" + '
#   '0.168*"set" + -0.155*"show" + -0.154*"domain" + -0.153*"graph" + '
#   '-0.148*"task" + 0.146*"parameter"'),
#  (29,
#   '-0.458*"information" + 0.272*"loss" + 0.245*"state" + 0.222*"number" + '
#   '0.193*"clustering" + 0.160*"process" + 0.140*"latent" + 0.134*"gradient" + '
#   '-0.133*"sample" + 0.133*"task"'),
#  (30,
#   '-0.446*"show" + -0.294*"loss" + 0.243*"result" + 0.180*"class" + '
#   '0.170*"latent" + 0.165*"number" + -0.163*"parameter" + 0.160*"analysis" + '
#   '-0.156*"regret" + 0.144*"performance"'),
#  (31,
#   '0.365*"sample" + 0.294*"variable" + 0.254*"training" + 0.209*"latent" + '
#   '-0.204*"label" + 0.196*"clustering" + -0.191*"number" + -0.191*"sparse" + '
#   '-0.187*"distribution" + 0.172*"loss"'),
#  (32,
#   '-0.446*"set" + 0.306*"using" + 0.188*"process" + -0.183*"class" + '
#   '0.168*"bound" + -0.158*"kernel" + -0.153*"result" + 0.152*"sparse" + '
#   '-0.135*"setting" + 0.134*"performance"'),
#  (33,
#   '0.303*"label" + -0.264*"number" + -0.223*"using" + 0.213*"error" + '
#   '-0.211*"loss" + 0.171*"classification" + 0.170*"show" + -0.167*"regret" + '
#   '0.167*"based" + -0.159*"training"'),
#  (34,
#   '-0.263*"set" + -0.259*"training" + 0.247*"state" + -0.244*"process" + '
#   '0.203*"information" + -0.197*"performance" + -0.182*"optimization" + '
#   '0.178*"estimator" + 0.153*"label" + 0.147*"space"'),
#  (35,
#   '0.308*"using" + -0.270*"performance" + -0.241*"variable" + 0.235*"set" + '
#   '0.233*"result" + -0.217*"parameter" + -0.216*"policy" + 0.177*"rate" + '
#   '0.158*"space" + -0.154*"loss"'),
#  (36,
#   '0.324*"process" + -0.258*"using" + 0.252*"rate" + -0.238*"set" + '
#   '0.227*"number" + -0.203*"gradient" + -0.194*"parameter" + 0.161*"latent" + '
#   '0.156*"show" + 0.154*"class"'),
#  (37,
#   '0.516*"framework" + 0.238*"domain" + 0.211*"using" + -0.193*"result" + '
#   '0.179*"label" + -0.176*"information" + -0.163*"state" + -0.157*"loss" + '
#   '-0.146*"performance" + 0.127*"propose"'),
#  (38,
#   '-0.303*"using" + -0.229*"class" + 0.215*"set" + -0.197*"estimator" + '
#   '-0.194*"parameter" + 0.191*"loss" + 0.185*"domain" + -0.152*"result" + '
#   '-0.151*"performance" + 0.145*"paper"'),
#  (39,
#   '0.299*"parameter" + -0.295*"structure" + 0.265*"state" + -0.212*"gradient" '
#   '+ -0.185*"tree" + -0.177*"result" + 0.170*"based" + -0.165*"sample" + '
#   '0.163*"optimization" + -0.145*"class"'),
#  (40,
#   '0.288*"variable" + -0.243*"structure" + -0.217*"parameter" + 0.210*"using" '
#   '+ 0.205*"linear" + -0.194*"tree" + -0.193*"neural" + 0.176*"latent" + '
#   '-0.155*"class" + -0.147*"show"'),
#  (41,
#   '-0.302*"result" + -0.290*"number" + 0.259*"space" + -0.219*"using" + '
#   '0.213*"representation" + 0.187*"estimator" + -0.170*"variable" + '
#   '-0.160*"new" + 0.150*"set" + -0.137*"parameter"'),
#  (42,
#   '0.342*"analysis" + 0.273*"process" + -0.271*"sparse" + -0.203*"clustering" '
#   '+ -0.183*"optimization" + -0.157*"optimal" + 0.148*"new" + 0.144*"set" + '
#   '0.137*"component" + -0.126*"bayesian"'),
#  (43,
#   '-0.301*"information" + 0.289*"rate" + -0.265*"linear" + -0.206*"result" + '
#   '-0.200*"framework" + -0.170*"object" + -0.163*"gradient" + 0.142*"using" + '
#   '-0.139*"state" + 0.136*"convergence"'),
#  (44,
#   '-0.339*"domain" + 0.260*"sample" + 0.191*"linear" + 0.186*"framework" + '
#   '-0.183*"time" + 0.178*"system" + -0.166*"information" + -0.155*"structure" '
#   '+ 0.138*"number" + -0.135*"parameter"'),
#  (45,
#   '0.285*"class" + 0.265*"optimization" + -0.248*"result" + 0.233*"new" + '
#   '0.199*"using" + 0.194*"policy" + -0.166*"proposed" + -0.152*"label" + '
#   '0.150*"loss" + 0.150*"state"'),
#  (46,
#   '0.244*"tree" + -0.240*"policy" + -0.209*"sample" + 0.181*"linear" + '
#   '0.180*"state" + -0.169*"set" + -0.162*"parameter" + 0.160*"class" + '
#   '-0.156*"optimization" + 0.155*"new"'),
#  (47,
#   '0.236*"state" + 0.227*"class" + -0.207*"number" + -0.190*"metric" + '
#   '-0.190*"policy" + 0.185*"representation" + 0.184*"human" + '
#   '-0.177*"structure" + -0.175*"linear" + 0.153*"sparse"'),
#  (48,
#   '-0.482*"new" + 0.324*"optimization" + 0.221*"domain" + -0.191*"sparse" + '
#   '-0.186*"gradient" + 0.140*"random" + 0.131*"parameter" + -0.125*"based" + '
#   '-0.116*"propose" + -0.115*"rate"'),
#  (49,
#   '0.271*"performance" + -0.256*"linear" + -0.210*"parameter" + -0.198*"human" '
#   '+ -0.184*"class" + -0.168*"based" + -0.167*"decision" + '
#   '-0.164*"representation" + 0.152*"estimator" + 0.137*"set"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.103*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '0.519*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.327*"network" + '
#   '-0.296*"method" + -0.165*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.123*"neural"'),
#  (3,
#   '0.574*"method" + -0.440*"learning" + -0.359*"network" + -0.292*"algorithm" '
#   '+ 0.254*"data" + 0.121*"matrix" + 0.104*"problem" + -0.100*"neural" + '
#   '-0.099*"deep" + -0.087*"task"'),
#  (4,
#   '0.588*"network" + -0.579*"learning" + -0.267*"data" + 0.218*"neural" + '
#   '0.104*"method" + 0.104*"algorithm" + -0.081*"task" + 0.079*"deep" + '
#   '-0.075*"approach" + 0.075*"image"'),
#  (5,
#   '-0.681*"data" + 0.315*"function" + -0.262*"algorithm" + 0.201*"model" + '
#   '0.196*"problem" + 0.184*"learning" + 0.163*"method" + -0.139*"network" + '
#   '0.114*"optimization" + -0.112*"feature"'),
#  (6,
#   '-0.523*"image" + 0.327*"data" + 0.271*"function" + 0.251*"network" + '
#   '-0.244*"algorithm" + -0.236*"feature" + -0.234*"object" + -0.219*"method" + '
#   '0.185*"distribution" + 0.119*"bound"'),
#  (7,
#   '0.483*"method" + -0.424*"problem" + 0.320*"algorithm" + -0.290*"image" + '
#   '0.225*"learning" + -0.125*"object" + 0.124*"inference" + 0.123*"gradient" + '
#   '-0.121*"matrix" + -0.113*"distribution"'),
#  (8,
#   '0.568*"problem" + -0.530*"function" + -0.211*"image" + -0.191*"feature" + '
#   '0.184*"matrix" + 0.170*"learning" + -0.167*"distribution" + 0.145*"network" '
#   '+ -0.127*"bound" + -0.095*"loss"'),
#  (9,
#   '0.500*"function" + -0.349*"distribution" + -0.271*"bound" + 0.258*"data" + '
#   '0.250*"problem" + -0.206*"matrix" + -0.195*"sample" + 0.130*"optimization" '
#   '+ -0.104*"show" + -0.104*"complexity"'),
#  (10,
#   '0.447*"feature" + 0.379*"matrix" + -0.370*"distribution" + '
#   '-0.277*"approach" + -0.245*"inference" + -0.201*"image" + 0.185*"kernel" + '
#   '0.131*"model" + -0.125*"problem" + 0.111*"function"'),
#  (11,
#   '0.403*"feature" + 0.324*"kernel" + 0.299*"approach" + -0.275*"bound" + '
#   '0.240*"inference" + -0.222*"image" + 0.197*"distribution" + -0.183*"data" + '
#   '-0.162*"loss" + 0.141*"graph"'),
#  (12,
#   '-0.282*"graph" + -0.275*"image" + 0.258*"task" + -0.229*"distribution" + '
#   '-0.222*"matrix" + 0.210*"time" + 0.190*"policy" + 0.173*"feature" + '
#   '0.172*"information" + -0.166*"kernel"'),
#  (13,
#   '-0.508*"matrix" + 0.387*"feature" + -0.280*"approach" + 0.237*"graph" + '
#   '0.172*"bound" + -0.159*"image" + 0.158*"problem" + 0.147*"method" + '
#   '0.141*"distribution" + -0.122*"neural"'),
#  (14,
#   '-0.510*"graph" + 0.367*"distribution" + 0.308*"feature" + -0.232*"approach" '
#   '+ 0.180*"problem" + -0.167*"kernel" + -0.162*"bound" + -0.155*"clustering" '
#   '+ 0.148*"gradient" + -0.144*"time"'),
#  (15,
#   '0.404*"approach" + 0.398*"bound" + -0.284*"graph" + -0.278*"distribution" + '
#   '0.217*"inference" + 0.160*"feature" + -0.158*"task" + -0.146*"clustering" + '
#   '-0.118*"method" + -0.117*"neuron"'),
#  (16,
#   '-0.461*"kernel" + 0.365*"task" + 0.277*"matrix" + -0.199*"image" + '
#   '-0.195*"gradient" + 0.192*"function" + -0.176*"rate" + 0.155*"approach" + '
#   '-0.145*"stochastic" + -0.124*"convergence"'),
#  (17,
#   '0.339*"task" + 0.271*"gradient" + -0.236*"bound" + -0.229*"inference" + '
#   '0.191*"training" + -0.189*"image" + -0.187*"method" + -0.149*"learning" + '
#   '0.147*"stochastic" + 0.142*"convergence"'),
#  (18,
#   '-0.510*"kernel" + 0.356*"approach" + -0.318*"task" + 0.210*"graph" + '
#   '0.191*"feature" + 0.156*"sparse" + -0.140*"inference" + '
#   '-0.139*"classification" + -0.121*"process" + 0.113*"gradient"'),
#  (19,
#   '0.293*"gradient" + -0.257*"loss" + 0.235*"policy" + 0.233*"matrix" + '
#   '-0.211*"neural" + 0.203*"stochastic" + -0.172*"classification" + '
#   '-0.171*"linear" + -0.170*"approach" + 0.163*"time"'),
#  (20,
#   '-0.502*"inference" + 0.278*"approach" + 0.213*"policy" + 0.198*"kernel" + '
#   '-0.181*"graph" + -0.167*"show" + 0.160*"distribution" + -0.144*"task" + '
#   '-0.140*"variational" + -0.134*"loss"'),
#  (21,
#   '-0.400*"task" + -0.346*"bound" + 0.326*"time" + 0.231*"show" + '
#   '0.224*"label" + 0.187*"loss" + 0.186*"training" + -0.145*"structure" + '
#   '0.137*"classification" + 0.129*"class"'),
#  (22,
#   '0.353*"clustering" + -0.260*"time" + -0.225*"sparse" + 0.222*"information" '
#   '+ -0.182*"task" + -0.181*"parameter" + -0.175*"regression" + -0.171*"image" '
#   '+ 0.166*"matrix" + 0.162*"approach"'),
#  (23,
#   '0.442*"clustering" + -0.331*"graph" + 0.236*"show" + -0.179*"gradient" + '
#   '-0.174*"information" + -0.167*"time" + -0.163*"loss" + 0.162*"cluster" + '
#   '0.154*"result" + 0.149*"set"'),
#  (24,
#   '0.365*"result" + 0.284*"policy" + -0.275*"object" + -0.221*"number" + '
#   '-0.200*"time" + -0.197*"sample" + 0.192*"show" + -0.178*"task" + '
#   '-0.171*"parameter" + 0.163*"new"'),
#  (25,
#   '0.329*"time" + 0.250*"object" + 0.234*"loss" + -0.201*"show" + '
#   '-0.196*"training" + -0.187*"neural" + -0.181*"using" + -0.180*"policy" + '
#   '-0.179*"bound" + 0.172*"framework"'),
#  (26,
#   '0.473*"object" + -0.359*"time" + -0.220*"clustering" + 0.215*"show" + '
#   '0.208*"variable" + -0.194*"result" + 0.176*"structure" + -0.152*"image" + '
#   '0.142*"latent" + 0.133*"space"'),
#  (27,
#   '0.331*"latent" + 0.270*"show" + 0.241*"variable" + 0.207*"time" + '
#   '0.178*"clustering" + -0.175*"graph" + 0.169*"structure" + 0.168*"topic" + '
#   '-0.155*"loss" + -0.151*"inference"'),
#  (28,
#   '0.370*"information" + 0.298*"process" + -0.273*"show" + -0.270*"object" + '
#   '0.256*"label" + 0.155*"parameter" + 0.155*"set" + 0.143*"bayesian" + '
#   '-0.137*"task" + -0.129*"time"'),
#  (29,
#   '-0.460*"information" + 0.307*"loss" + 0.222*"state" + 0.214*"number" + '
#   '0.199*"clustering" + 0.161*"process" + 0.149*"task" + -0.142*"sample" + '
#   '0.129*"gradient" + 0.129*"linear"'),
#  (30,
#   '0.465*"show" + 0.256*"loss" + -0.239*"result" + -0.195*"class" + '
#   '-0.186*"number" + -0.185*"latent" + -0.151*"analysis" + -0.150*"topic" + '
#   '0.148*"parameter" + 0.143*"regret"'),
#  (31,
#   '0.371*"sample" + 0.287*"variable" + 0.268*"training" + -0.226*"label" + '
#   '0.208*"clustering" + 0.197*"latent" + 0.194*"loss" + -0.184*"number" + '
#   '-0.184*"distribution" + -0.169*"sparse"'),
#  (32,
#   '0.422*"set" + -0.218*"process" + -0.205*"using" + -0.200*"bound" + '
#   '0.186*"kernel" + 0.172*"result" + 0.164*"parameter" + 0.156*"setting" + '
#   '-0.152*"error" + -0.146*"based"'),
#  (33,
#   '0.325*"using" + -0.286*"label" + 0.247*"number" + 0.224*"loss" + '
#   '-0.176*"rate" + -0.171*"show" + -0.157*"set" + 0.154*"sparse" + '
#   '-0.150*"error" + -0.146*"class"'),
#  (34,
#   '-0.293*"process" + -0.268*"training" + -0.248*"set" + 0.229*"state" + '
#   '0.181*"estimator" + -0.181*"optimization" + 0.180*"information" + '
#   '-0.179*"performance" + 0.163*"label" + -0.151*"object"'),
#  (35,
#   '0.316*"using" + -0.275*"performance" + 0.246*"result" + -0.244*"variable" + '
#   '0.240*"set" + -0.209*"policy" + -0.198*"parameter" + 0.178*"rate" + '
#   '0.172*"space" + -0.153*"loss"'),
#  (36,
#   '0.300*"process" + -0.265*"using" + 0.250*"number" + 0.243*"rate" + '
#   '-0.237*"set" + -0.207*"parameter" + -0.192*"gradient" + 0.164*"sample" + '
#   '0.163*"show" + -0.163*"structure"'),
#  (37,
#   '0.485*"framework" + 0.220*"domain" + -0.216*"state" + 0.204*"using" + '
#   '0.187*"structure" + -0.178*"information" + 0.176*"label" + '
#   '-0.169*"performance" + -0.158*"result" + -0.157*"loss"'),
#  (38,
#   '-0.289*"using" + 0.233*"set" + -0.232*"class" + 0.192*"loss" + '
#   '-0.187*"parameter" + -0.180*"estimator" + 0.164*"domain" + 0.156*"paper" + '
#   '-0.149*"performance" + 0.149*"sample"'),
#  (39,
#   '0.301*"parameter" + -0.276*"structure" + 0.253*"state" + 0.216*"framework" '
#   '+ -0.212*"result" + -0.202*"gradient" + 0.186*"optimization" + '
#   '-0.172*"tree" + 0.164*"based" + 0.161*"domain"'),
#  (40,
#   '0.293*"variable" + -0.249*"structure" + 0.239*"linear" + -0.200*"parameter" '
#   '+ -0.192*"neural" + -0.186*"tree" + 0.181*"using" + 0.167*"policy" + '
#   '-0.161*"class" + -0.156*"show"'),
#  (41,
#   '-0.299*"result" + -0.272*"number" + 0.246*"space" + -0.237*"using" + '
#   '0.197*"representation" + 0.187*"estimator" + -0.183*"variable" + '
#   '0.150*"set" + -0.148*"parameter" + 0.129*"neural"'),
#  (42,
#   '-0.326*"analysis" + -0.297*"process" + 0.233*"sparse" + 0.181*"clustering" '
#   '+ 0.178*"rate" + 0.173*"optimal" + 0.165*"optimization" + -0.139*"new" + '
#   '0.138*"human" + 0.136*"bayesian"'),
#  (43,
#   '0.283*"rate" + -0.272*"information" + -0.270*"linear" + -0.208*"result" + '
#   '-0.195*"framework" + -0.171*"object" + -0.170*"state" + 0.161*"analysis" + '
#   '-0.161*"gradient" + 0.157*"using"'),
#  (44,
#   '0.356*"domain" + -0.254*"sample" + 0.197*"time" + 0.185*"information" + '
#   '-0.180*"number" + -0.176*"framework" + 0.166*"structure" + 0.155*"sparse" + '
#   '-0.154*"system" + -0.149*"linear"'),
#  (45,
#   '0.302*"optimization" + 0.270*"class" + 0.231*"new" + 0.227*"policy" + '
#   '-0.222*"result" + 0.216*"using" + 0.156*"loss" + 0.152*"convex" + '
#   '-0.145*"proposed" + -0.140*"parameter"'),
#  (46,
#   '-0.268*"tree" + 0.214*"policy" + -0.195*"new" + -0.188*"state" + '
#   '-0.185*"linear" + 0.183*"sample" + 0.180*"result" + 0.176*"parameter" + '
#   '-0.166*"class" + 0.160*"label"'),
#  (47,
#   '0.235*"state" + 0.231*"class" + -0.208*"number" + -0.183*"policy" + '
#   '0.182*"human" + 0.180*"representation" + -0.179*"metric" + '
#   '-0.173*"structure" + 0.166*"system" + -0.163*"space"'),
#  (48,
#   '0.468*"new" + -0.312*"optimization" + -0.225*"domain" + -0.192*"random" + '
#   '0.154*"based" + 0.151*"gradient" + -0.145*"performance" + 0.136*"rate" + '
#   '0.135*"policy" + 0.130*"error"'),
#  (49,
#   '0.292*"parameter" + 0.281*"linear" + -0.205*"performance" + '
#   '-0.203*"estimator" + 0.201*"human" + -0.191*"set" + 0.174*"representation" '
#   '+ 0.171*"class" + -0.147*"propose" + -0.145*"sparse"'),
#  (50,
#   '0.220*"framework" + -0.209*"based" + 0.194*"convergence" + '
#   '0.187*"structure" + -0.173*"new" + -0.169*"metric" + 0.168*"system" + '
#   '-0.162*"one" + 0.160*"dynamic" + 0.156*"rate"'),
#  (51,
#   '-0.419*"estimator" + 0.257*"performance" + 0.236*"state" + -0.209*"policy" '
#   '+ -0.160*"based" + 0.153*"regression" + 0.149*"analysis" + '
#   '0.118*"classifier" + -0.117*"neural" + 0.116*"setting"'),
#  (52,
#   '0.304*"label" + 0.292*"new" + -0.241*"tree" + -0.234*"training" + '
#   '-0.232*"framework" + -0.212*"decision" + 0.197*"performance" + '
#   '0.192*"linear" + -0.156*"topic" + 0.155*"deep"'),
#  (53,
#   '0.237*"performance" + -0.216*"deep" + -0.205*"representation" + '
#   '-0.182*"prediction" + -0.179*"new" + 0.164*"training" + 0.157*"system" + '
#   '-0.156*"random" + 0.155*"class" + -0.154*"game"'),
#  (54,
#   '0.263*"class" + 0.230*"propose" + -0.224*"regression" + -0.220*"bayesian" + '
#   '-0.179*"optimization" + 0.176*"point" + -0.158*"two" + 0.153*"proposed" + '
#   '-0.152*"estimator" + 0.138*"using"'),
#  (55,
#   '-0.300*"space" + 0.273*"linear" + -0.194*"new" + 0.180*"propose" + '
#   '-0.159*"system" + 0.156*"two" + 0.156*"state" + -0.152*"domain" + '
#   '-0.146*"representation" + 0.142*"analysis"'),
#  (56,
#   '-0.270*"analysis" + 0.253*"two" + 0.222*"regression" + -0.169*"training" + '
#   '-0.155*"inference" + -0.141*"error" + -0.141*"clustering" + -0.137*"system" '
#   '+ -0.135*"regret" + 0.134*"prior"'),
#  (57,
#   '0.234*"approximation" + 0.233*"sparse" + 0.227*"two" + -0.224*"set" + '
#   '-0.182*"representation" + -0.178*"analysis" + -0.166*"estimator" + '
#   '0.157*"setting" + 0.154*"label" + -0.151*"performance"'),
#  (58,
#   '-0.246*"tree" + -0.206*"based" + 0.192*"space" + 0.192*"training" + '
#   '0.178*"framework" + 0.165*"prediction" + -0.152*"random" + 0.148*"human" + '
#   '-0.148*"performance" + 0.134*"large"'),
#  (59,
#   '-0.288*"error" + -0.281*"approximation" + -0.268*"structure" + '
#   '-0.172*"based" + -0.167*"sampling" + 0.151*"prediction" + 0.140*"proposed" '
#   '+ -0.132*"system" + 0.123*"label" + 0.118*"tree"'),
#  (60,
#   '-0.346*"two" + 0.223*"training" + -0.222*"error" + -0.207*"prediction" + '
#   '0.167*"human" + 0.158*"study" + -0.154*"large" + 0.148*"analysis" + '
#   '0.142*"new" + -0.140*"input"'),
#  (61,
#   '-0.318*"sampling" + -0.277*"propose" + 0.219*"two" + 0.209*"optimal" + '
#   '-0.201*"regression" + 0.174*"based" + -0.169*"input" + 0.138*"latent" + '
#   '-0.134*"topic" + 0.132*"framework"'),
#  (62,
#   '0.244*"space" + 0.224*"sampling" + -0.193*"domain" + 0.184*"signal" + '
#   '0.182*"bayesian" + -0.169*"online" + 0.159*"training" + -0.158*"large" + '
#   '-0.154*"approximation" + 0.152*"input"'),
#  (63,
#   '-0.284*"random" + 0.246*"based" + -0.217*"test" + 0.205*"regression" + '
#   '0.183*"metric" + -0.178*"framework" + -0.162*"structure" + 0.161*"game" + '
#   '0.149*"analysis" + 0.141*"also"'),
#  (64,
#   '0.245*"sampling" + -0.244*"game" + -0.228*"neural" + 0.213*"representation" '
#   '+ 0.211*"two" + -0.190*"used" + 0.174*"present" + 0.163*"estimator" + '
#   '-0.146*"bayesian" + -0.146*"also"'),
#  (65,
#   '-0.333*"based" + 0.203*"proposed" + 0.199*"new" + -0.192*"propose" + '
#   '-0.189*"space" + -0.188*"regression" + -0.176*"prediction" + 0.168*"metric" '
#   '+ 0.158*"optimal" + 0.157*"paper"'),
#  (66,
#   '-0.283*"prediction" + 0.277*"game" + -0.196*"proposed" + -0.190*"neural" + '
#   '0.186*"large" + 0.152*"noise" + -0.146*"class" + -0.144*"approximation" + '
#   '0.141*"classification" + -0.133*"output"'),
#  (67,
#   '-0.266*"game" + -0.212*"random" + 0.194*"deep" + 0.174*"decision" + '
#   '0.165*"propose" + 0.155*"user" + -0.154*"test" + -0.151*"vector" + '
#   '-0.150*"large" + -0.133*"present"'),
#  (68,
#   '-0.255*"test" + 0.220*"local" + -0.184*"application" + -0.183*"bayesian" + '
#   '0.174*"point" + -0.171*"based" + -0.157*"many" + 0.149*"online" + '
#   '0.132*"metric" + 0.126*"error"'),
#  (69,
#   '-0.273*"also" + 0.220*"regression" + -0.200*"propose" + -0.197*"tree" + '
#   '-0.187*"online" + 0.177*"optimal" + 0.167*"probability" + -0.162*"dynamic" '
#   '+ 0.153*"paper" + -0.135*"test"'),
#  (70,
#   '0.259*"metric" + 0.225*"based" + -0.222*"space" + -0.171*"optimal" + '
#   '0.163*"sparse" + 0.158*"number" + 0.157*"sampling" + -0.152*"system" + '
#   '-0.148*"proposed" + -0.148*"regression"'),
#  (71,
#   '-0.261*"point" + 0.225*"approximation" + 0.224*"proposed" + 0.215*"space" + '
#   '0.196*"signal" + -0.191*"optimal" + 0.190*"error" + -0.161*"test" + '
#   '-0.151*"bayesian" + -0.141*"dynamic"'),
#  (72,
#   '0.276*"proposed" + -0.222*"paper" + 0.210*"representation" + 0.191*"test" + '
#   '-0.184*"topic" + 0.157*"regression" + 0.157*"also" + -0.142*"prediction" + '
#   '0.142*"structure" + 0.139*"analysis"'),
#  (73,
#   '-0.248*"memory" + -0.207*"sparse" + 0.200*"efficient" + 0.188*"proposed" + '
#   '0.185*"prediction" + -0.178*"one" + -0.168*"classification" + '
#   '0.166*"random" + 0.155*"noise" + 0.155*"prior"'),
#  (74,
#   '0.200*"representation" + 0.179*"test" + 0.167*"error" + 0.162*"norm" + '
#   '0.162*"also" + 0.148*"present" + -0.147*"one" + -0.146*"sample" + '
#   '0.145*"latent" + 0.137*"paper"'),
#  (75,
#   '0.205*"input" + 0.172*"neuron" + -0.171*"large" + -0.164*"neural" + '
#   '0.162*"topic" + 0.159*"work" + -0.156*"probability" + -0.155*"vector" + '
#   '0.155*"sequence" + 0.142*"action"'),
#  (76,
#   '-0.205*"local" + -0.202*"norm" + 0.190*"sparse" + -0.187*"based" + '
#   '0.183*"test" + -0.162*"point" + -0.152*"representation" + -0.150*"action" + '
#   '0.143*"deep" + -0.139*"number"'),
#  (77,
#   '-0.243*"game" + 0.190*"action" + 0.190*"neural" + 0.187*"estimation" + '
#   '0.183*"human" + -0.169*"estimator" + -0.158*"dynamic" + 0.154*"analysis" + '
#   '-0.143*"study" + 0.127*"metric"'),
#  (78,
#   '-0.296*"also" + 0.261*"dynamic" + -0.211*"user" + 0.203*"case" + '
#   '0.161*"norm" + 0.150*"classifier" + 0.144*"complexity" + -0.143*"item" + '
#   '0.141*"tree" + 0.137*"local"'),
#  (79,
#   '-0.216*"present" + -0.193*"local" + -0.187*"one" + -0.180*"bayesian" + '
#   '-0.169*"different" + -0.161*"class" + -0.158*"layer" + -0.151*"multiple" + '
#   '-0.140*"random" + -0.134*"dynamic"'),
#  (80,
#   '0.239*"optimal" + -0.216*"test" + 0.205*"also" + 0.202*"estimation" + '
#   '-0.166*"sampling" + -0.155*"error" + -0.154*"local" + 0.154*"classifier" + '
#   '-0.147*"estimator" + 0.143*"random"'),
#  (81,
#   '-0.335*"prior" + -0.251*"work" + 0.172*"paper" + 0.145*"stochastic" + '
#   '-0.144*"point" + 0.144*"dynamic" + -0.140*"test" + 0.132*"visual" + '
#   '0.129*"human" + 0.127*"estimation"'),
#  (82,
#   '-0.258*"norm" + 0.207*"prediction" + 0.185*"signal" + -0.181*"online" + '
#   '0.175*"noise" + 0.174*"paper" + -0.161*"used" + 0.160*"novel" + '
#   '-0.154*"large" + -0.153*"measure"'),
#  (83,
#   '-0.240*"also" + -0.176*"classification" + -0.157*"layer" + 0.152*"signal" + '
#   '0.150*"point" + 0.138*"bayesian" + -0.136*"paper" + 0.135*"estimate" + '
#   '-0.134*"decision" + 0.134*"metric"'),
#  (84,
#   '0.210*"sampling" + -0.204*"online" + 0.192*"also" + -0.165*"paper" + '
#   '0.145*"noise" + 0.144*"vector" + 0.139*"prediction" + -0.138*"bayesian" + '
#   '0.138*"work" + -0.138*"application"'),
#  (85,
#   '-0.266*"error" + -0.255*"variable" + 0.217*"latent" + 0.210*"different" + '
#   '-0.174*"metric" + 0.172*"probability" + 0.163*"random" + 0.160*"point" + '
#   '-0.138*"norm" + 0.129*"online"'),
#  (86,
#   '-0.288*"memory" + 0.248*"used" + 0.178*"optimal" + -0.161*"large" + '
#   '-0.151*"point" + 0.147*"number" + -0.147*"classifier" + -0.138*"deep" + '
#   '-0.134*"stochastic" + -0.131*"first"'),
#  (87,
#   '0.247*"paper" + -0.187*"application" + 0.181*"case" + 0.171*"large" + '
#   '0.163*"test" + 0.159*"online" + -0.157*"machine" + -0.156*"technique" + '
#   '0.155*"space" + 0.154*"work"'),
#  (88,
#   '-0.214*"propose" + -0.180*"local" + 0.175*"topic" + 0.166*"dynamic" + '
#   '-0.159*"vector" + -0.158*"latent" + -0.150*"visual" + 0.141*"deep" + '
#   '0.137*"number" + -0.132*"case"'),
#  (89,
#   '-0.199*"signal" + -0.197*"estimation" + 0.193*"action" + -0.175*"deep" + '
#   '-0.160*"regret" + 0.155*"random" + -0.130*"also" + 0.130*"work" + '
#   '-0.127*"sampling" + -0.125*"study"'),
#  (90,
#   '0.199*"also" + 0.183*"case" + 0.182*"point" + 0.181*"one" + '
#   '0.172*"technique" + 0.148*"tree" + -0.146*"experiment" + -0.143*"setting" + '
#   '-0.138*"response" + 0.135*"error"'),
#  (91,
#   '-0.295*"noise" + -0.204*"used" + 0.183*"system" + 0.175*"probability" + '
#   '-0.159*"signal" + -0.149*"experiment" + 0.142*"ranking" + -0.141*"online" + '
#   '0.136*"case" + 0.131*"field"'),
#  (92,
#   '-0.266*"point" + -0.225*"visual" + -0.186*"present" + 0.179*"local" + '
#   '0.144*"constraint" + 0.144*"probability" + 0.134*"setting" + '
#   '0.132*"sampling" + 0.115*"also" + -0.115*"regret"'),
#  (93,
#   '0.173*"probability" + -0.166*"sampling" + -0.163*"query" + '
#   '-0.156*"estimation" + 0.152*"sequence" + 0.143*"experiment" + '
#   '0.140*"propose" + 0.134*"measure" + 0.133*"reward" + -0.127*"analysis"'),
#  (94,
#   '-0.212*"classifier" + 0.168*"constraint" + 0.164*"prior" + '
#   '0.158*"complexity" + 0.141*"used" + 0.141*"stochastic" + 0.133*"local" + '
#   '-0.131*"variational" + -0.128*"regularization" + -0.127*"online"'),
#  (95,
#   '-0.235*"human" + -0.234*"component" + -0.197*"present" + 0.179*"random" + '
#   '-0.156*"one" + -0.155*"use" + 0.139*"decision" + -0.134*"layer" + '
#   '-0.133*"probability" + -0.125*"case"'),
#  (96,
#   '0.246*"one" + -0.193*"stochastic" + 0.184*"dynamic" + -0.162*"tree" + '
#   '0.162*"online" + 0.150*"two" + -0.147*"vector" + 0.145*"signal" + '
#   '0.131*"structure" + 0.131*"random"'),
#  (97,
#   '-0.284*"provide" + 0.203*"constraint" + -0.197*"value" + -0.193*"signal" + '
#   '-0.174*"use" + 0.156*"visual" + 0.152*"noise" + -0.148*"local" + '
#   '-0.134*"classification" + 0.134*"machine"'),
#  (98,
#   '-0.245*"memory" + 0.201*"stochastic" + 0.190*"different" + -0.189*"online" '
#   '+ -0.150*"regret" + -0.135*"neuron" + -0.130*"brain" + -0.129*"machine" + '
#   '0.127*"setting" + -0.126*"gradient"'),
#  (99,
#   '0.343*"memory" + 0.191*"used" + 0.184*"efficient" + 0.151*"one" + '
#   '0.149*"prediction" + -0.143*"input" + -0.143*"novel" + -0.142*"decision" + '
#   '0.142*"classification" + -0.133*"dynamic"')]

# %% [markdown]
# # Evaluation

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.



coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)


coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='u_mass')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)
# Out:
# Coherence Score:  0.2627923251812317
#
# Coherence Score5:  0.4052500695756426
#
# Coherence Score10:  0.3227329434451162
#
# Coherence Score20:  0.32978395001874505
#
# Coherence Score50:  0.26423153175216396
#
# Coherence Score100:  0.23638106012127644
#
# Coherence Score:  -1.3206663098063114
#
# Coherence Score5:  -1.943964901627469
#
# Coherence Score10:  -2.1270621799675835
#
# Coherence Score20:  -2.1483660187754046
#
# Coherence Score50:  -2.260180135326383
#
# Coherence Score100:  -2.4729963021171226
