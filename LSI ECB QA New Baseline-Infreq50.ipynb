# %%
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['qa']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(8371 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# less than 10 documents,
id2word = corpora.Dictionary(data)
id2word.filter_extremes(no_below = 50)
print(id2word)
# Out:
# Dictionary(397 unique tokens: ['activity', 'agreement', 'ass', 'asset', 'aware']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.185*"programme" + 0.171*"actually" + 0.152*"condition" + 0.142*"bond" + '
#   '0.128*"money" + 0.109*"recovery" + 0.106*"don" + 0.106*"several" + '
#   '0.105*"lower" + 0.104*"action"')]
# [(0,
#   '0.185*"programme" + 0.171*"actually" + 0.152*"condition" + 0.142*"bond" + '
#   '0.128*"money" + 0.109*"recovery" + 0.106*"don" + 0.106*"several" + '
#   '0.105*"lower" + 0.104*"action"'),
#  (1,
#   '-0.288*"actually" + 0.203*"deliver" + -0.196*"programme" + '
#   '-0.180*"condition" + 0.160*"currency" + -0.156*"basically" + -0.150*"bond" '
#   '+ -0.142*"sense" + 0.132*"observed" + 0.126*"staff"'),
#  (2,
#   '0.405*"operation" + 0.324*"programme" + 0.286*"bond" + 0.227*"billion" + '
#   '0.220*"money" + 0.166*"collateral" + 0.149*"refinancing" + '
#   '0.145*"functioning" + 0.135*"purchase" + -0.122*"data"'),
#  (3,
#   '-0.563*"programme" + 0.362*"money" + 0.214*"operation" + -0.171*"condition" '
#   '+ -0.145*"currency" + -0.145*"recovery" + -0.114*"pact" + 0.108*"data" + '
#   '0.105*"refinancing" + 0.104*"balance"'),
#  (4,
#   '-0.244*"week" + -0.185*"forecast" + 0.184*"deliver" + -0.173*"mr" + '
#   '-0.162*"minister" + 0.147*"quarter" + -0.145*"rather" + -0.141*"treaty" + '
#   '-0.140*"day" + 0.133*"lower"')]
# [(0,
#   '0.185*"programme" + 0.171*"actually" + 0.152*"condition" + 0.142*"bond" + '
#   '0.128*"money" + 0.109*"recovery" + 0.106*"don" + 0.106*"several" + '
#   '0.105*"lower" + 0.104*"action"'),
#  (1,
#   '0.288*"actually" + -0.203*"deliver" + 0.196*"programme" + 0.180*"condition" '
#   '+ -0.160*"currency" + 0.156*"basically" + 0.150*"bond" + 0.142*"sense" + '
#   '-0.132*"observed" + -0.126*"staff"'),
#  (2,
#   '-0.405*"operation" + -0.324*"programme" + -0.286*"bond" + -0.227*"billion" '
#   '+ -0.220*"money" + -0.166*"collateral" + -0.149*"refinancing" + '
#   '-0.145*"functioning" + -0.135*"purchase" + 0.122*"data"'),
#  (3,
#   '0.563*"programme" + -0.362*"money" + -0.214*"operation" + 0.171*"condition" '
#   '+ 0.145*"currency" + 0.145*"recovery" + 0.114*"pact" + -0.108*"data" + '
#   '-0.105*"refinancing" + -0.104*"balance"'),
#  (4,
#   '0.244*"week" + 0.185*"forecast" + -0.184*"deliver" + 0.173*"mr" + '
#   '0.162*"minister" + -0.147*"quarter" + 0.145*"rather" + 0.141*"treaty" + '
#   '0.141*"day" + -0.133*"lower"'),
#  (5,
#   '0.298*"recovery" + -0.285*"bond" + -0.202*"balance" + -0.196*"creation" + '
#   '0.193*"negative" + -0.187*"collateral" + -0.172*"don" + 0.168*"loan" + '
#   '0.153*"programme" + -0.146*"actually"'),
#  (6,
#   '-0.377*"condition" + -0.217*"bond" + -0.210*"negative" + -0.180*"purchase" '
#   '+ 0.172*"functioning" + 0.165*"action" + 0.160*"balance" + 0.159*"crisis" + '
#   '0.155*"forward" + 0.143*"help"'),
#  (7,
#   '-0.309*"negative" + 0.306*"programme" + -0.271*"currency" + '
#   '-0.240*"recovery" + -0.225*"condition" + -0.149*"creation" + '
#   '-0.145*"environment" + -0.141*"financing" + 0.140*"don" + 0.134*"staff"'),
#  (8,
#   '0.289*"balance" + -0.274*"money" + 0.192*"data" + 0.189*"recovery" + '
#   '0.185*"quarter" + 0.173*"staff" + 0.168*"pact" + -0.155*"deliver" + '
#   '-0.154*"objective" + 0.148*"sheet"'),
#  (9,
#   '-0.366*"balance" + -0.232*"sheet" + -0.221*"money" + 0.215*"capital" + '
#   '0.213*"billion" + 0.192*"operation" + -0.187*"recovery" + 0.158*"data" + '
#   '0.155*"banking" + 0.141*"eurogroup"')]
# [(0,
#   '0.185*"programme" + 0.171*"actually" + 0.152*"condition" + 0.142*"bond" + '
#   '0.128*"money" + 0.109*"recovery" + 0.106*"don" + 0.106*"several" + '
#   '0.105*"lower" + 0.104*"action"'),
#  (1,
#   '0.288*"actually" + -0.203*"deliver" + 0.196*"programme" + 0.180*"condition" '
#   '+ -0.160*"currency" + 0.156*"basically" + 0.150*"bond" + 0.142*"sense" + '
#   '-0.132*"observed" + -0.126*"staff"'),
#  (2,
#   '-0.405*"operation" + -0.324*"programme" + -0.286*"bond" + -0.227*"billion" '
#   '+ -0.220*"money" + -0.166*"collateral" + -0.149*"refinancing" + '
#   '-0.145*"functioning" + -0.135*"purchase" + 0.122*"data"'),
#  (3,
#   '-0.563*"programme" + 0.362*"money" + 0.214*"operation" + -0.171*"condition" '
#   '+ -0.145*"currency" + -0.145*"recovery" + -0.114*"pact" + 0.108*"data" + '
#   '0.105*"refinancing" + 0.104*"balance"'),
#  (4,
#   '-0.244*"week" + -0.185*"forecast" + 0.183*"deliver" + -0.173*"mr" + '
#   '-0.162*"minister" + 0.147*"quarter" + -0.145*"rather" + -0.141*"treaty" + '
#   '-0.140*"day" + 0.133*"lower"'),
#  (5,
#   '-0.298*"recovery" + 0.285*"bond" + 0.202*"balance" + 0.196*"creation" + '
#   '-0.193*"negative" + 0.187*"collateral" + 0.172*"don" + -0.167*"loan" + '
#   '-0.153*"programme" + 0.146*"actually"'),
#  (6,
#   '0.377*"condition" + 0.217*"bond" + 0.211*"negative" + 0.180*"purchase" + '
#   '-0.172*"functioning" + -0.165*"action" + -0.160*"balance" + -0.159*"crisis" '
#   '+ -0.155*"forward" + -0.143*"help"'),
#  (7,
#   '0.309*"negative" + -0.306*"programme" + 0.271*"currency" + 0.239*"recovery" '
#   '+ 0.225*"condition" + 0.150*"creation" + 0.145*"environment" + '
#   '0.141*"financing" + -0.140*"don" + -0.134*"staff"'),
#  (8,
#   '0.289*"balance" + -0.275*"money" + 0.192*"data" + 0.189*"recovery" + '
#   '0.185*"quarter" + 0.172*"staff" + 0.169*"pact" + -0.156*"deliver" + '
#   '-0.155*"objective" + 0.148*"sheet"'),
#  (9,
#   '0.366*"balance" + 0.232*"sheet" + 0.221*"money" + -0.214*"capital" + '
#   '-0.212*"billion" + -0.192*"operation" + 0.187*"recovery" + -0.158*"data" + '
#   '-0.156*"banking" + -0.140*"eurogroup"'),
#  (10,
#   '0.241*"quarter" + 0.222*"deliver" + -0.204*"forward" + -0.194*"asset" + '
#   '-0.192*"balance" + -0.185*"lower" + 0.178*"crisis" + -0.177*"mediumterm" + '
#   '0.156*"capital" + 0.147*"labour"'),
#  (11,
#   '0.227*"money" + -0.226*"staff" + -0.225*"objective" + -0.210*"deliver" + '
#   '0.200*"bond" + 0.197*"labour" + 0.180*"treaty" + -0.175*"committee" + '
#   '-0.171*"collateral" + -0.159*"framework"'),
#  (12,
#   '0.224*"uncertainty" + 0.197*"treaty" + 0.193*"recovery" + 0.166*"actually" '
#   '+ -0.158*"currency" + -0.156*"loan" + -0.148*"asset" + 0.146*"operation" + '
#   '-0.136*"sign" + -0.134*"framework"'),
#  (13,
#   '0.279*"pact" + 0.212*"collateral" + 0.206*"instrument" + -0.170*"billion" + '
#   '-0.164*"currency" + -0.161*"quarter" + 0.161*"single" + -0.156*"lower" + '
#   '-0.142*"environment" + 0.142*"framework"'),
#  (14,
#   '0.369*"recovery" + -0.261*"lending" + -0.247*"treaty" + 0.165*"billion" + '
#   '-0.157*"committee" + 0.150*"labour" + -0.142*"loan" + -0.138*"financing" + '
#   '0.131*"banking" + -0.123*"concept"'),
#  (15,
#   '-0.281*"actually" + 0.208*"staff" + 0.168*"balance" + 0.160*"uncertainty" + '
#   '0.159*"condition" + -0.158*"pact" + -0.158*"operation" + -0.146*"sense" + '
#   '-0.137*"crisis" + 0.137*"lending"'),
#  (16,
#   '0.269*"quarter" + 0.203*"bond" + 0.197*"asset" + -0.187*"condition" + '
#   '0.157*"assumption" + -0.152*"operation" + 0.142*"banking" + 0.142*"essence" '
#   '+ -0.137*"deliver" + -0.137*"pact"'),
#  (17,
#   '-0.192*"deliver" + -0.182*"treaty" + 0.175*"action" + -0.174*"bond" + '
#   '0.165*"objective" + -0.152*"forecast" + 0.150*"several" + 0.149*"currency" '
#   '+ -0.141*"data" + 0.139*"unemployment"'),
#  (18,
#   '0.312*"instrument" + -0.212*"objective" + 0.161*"we" + 0.158*"currency" + '
#   '0.155*"staff" + -0.154*"note" + -0.153*"quarter" + -0.146*"money" + '
#   '0.143*"crisis" + 0.140*"credible"'),
#  (19,
#   '0.278*"functioning" + 0.263*"currency" + -0.214*"balance" + 0.172*"staff" + '
#   '-0.159*"negative" + -0.152*"move" + -0.138*"consensus" + 0.131*"we" + '
#   '0.128*"investment" + 0.126*"quarter"')]
# [(0,
#   '-0.185*"programme" + -0.171*"actually" + -0.152*"condition" + -0.142*"bond" '
#   '+ -0.128*"money" + -0.109*"recovery" + -0.106*"don" + -0.106*"several" + '
#   '-0.105*"lower" + -0.104*"action"'),
#  (1,
#   '0.288*"actually" + -0.203*"deliver" + 0.196*"programme" + 0.180*"condition" '
#   '+ -0.160*"currency" + 0.156*"basically" + 0.150*"bond" + 0.142*"sense" + '
#   '-0.132*"observed" + -0.126*"staff"'),
#  (2,
#   '0.405*"operation" + 0.324*"programme" + 0.286*"bond" + 0.227*"billion" + '
#   '0.220*"money" + 0.166*"collateral" + 0.149*"refinancing" + '
#   '0.145*"functioning" + 0.135*"purchase" + -0.122*"data"'),
#  (3,
#   '0.563*"programme" + -0.362*"money" + -0.214*"operation" + 0.171*"condition" '
#   '+ 0.145*"currency" + 0.145*"recovery" + 0.114*"pact" + -0.108*"data" + '
#   '-0.105*"refinancing" + -0.104*"balance"'),
#  (4,
#   '0.244*"week" + 0.185*"forecast" + -0.184*"deliver" + 0.173*"mr" + '
#   '0.162*"minister" + -0.147*"quarter" + 0.145*"rather" + 0.141*"treaty" + '
#   '0.141*"day" + -0.133*"lower"'),
#  (5,
#   '0.298*"recovery" + -0.285*"bond" + -0.202*"balance" + -0.196*"creation" + '
#   '0.193*"negative" + -0.187*"collateral" + -0.172*"don" + 0.167*"loan" + '
#   '0.153*"programme" + -0.145*"actually"'),
#  (6,
#   '0.377*"condition" + 0.217*"bond" + 0.210*"negative" + 0.180*"purchase" + '
#   '-0.172*"functioning" + -0.165*"action" + -0.160*"balance" + -0.159*"crisis" '
#   '+ -0.155*"forward" + -0.143*"help"'),
#  (7,
#   '-0.309*"negative" + 0.306*"programme" + -0.271*"currency" + '
#   '-0.240*"recovery" + -0.225*"condition" + -0.150*"creation" + '
#   '-0.145*"environment" + -0.141*"financing" + 0.140*"don" + 0.134*"staff"'),
#  (8,
#   '-0.289*"balance" + 0.275*"money" + -0.192*"data" + -0.189*"recovery" + '
#   '-0.185*"quarter" + -0.172*"staff" + -0.169*"pact" + 0.156*"deliver" + '
#   '0.155*"objective" + -0.148*"sheet"'),
#  (9,
#   '0.366*"balance" + 0.232*"sheet" + 0.221*"money" + -0.214*"capital" + '
#   '-0.212*"billion" + -0.192*"operation" + 0.188*"recovery" + -0.158*"data" + '
#   '-0.155*"banking" + -0.140*"eurogroup"'),
#  (10,
#   '-0.241*"quarter" + -0.222*"deliver" + 0.204*"forward" + 0.194*"asset" + '
#   '0.192*"balance" + 0.186*"lower" + -0.178*"crisis" + 0.177*"mediumterm" + '
#   '-0.156*"capital" + -0.147*"labour"'),
#  (11,
#   '-0.227*"money" + 0.226*"staff" + 0.225*"objective" + 0.210*"deliver" + '
#   '-0.200*"bond" + -0.197*"labour" + -0.180*"treaty" + 0.175*"committee" + '
#   '0.171*"collateral" + 0.159*"framework"'),
#  (12,
#   '-0.224*"uncertainty" + -0.197*"treaty" + -0.193*"recovery" + '
#   '-0.166*"actually" + 0.158*"currency" + 0.156*"loan" + 0.148*"asset" + '
#   '-0.147*"operation" + 0.136*"sign" + 0.135*"framework"'),
#  (13,
#   '-0.279*"pact" + -0.211*"collateral" + -0.206*"instrument" + 0.170*"billion" '
#   '+ 0.164*"currency" + -0.161*"single" + 0.160*"quarter" + 0.157*"lower" + '
#   '-0.143*"framework" + 0.142*"environment"'),
#  (14,
#   '-0.369*"recovery" + 0.262*"lending" + 0.247*"treaty" + -0.164*"billion" + '
#   '0.158*"committee" + -0.150*"labour" + 0.142*"loan" + 0.138*"financing" + '
#   '-0.131*"banking" + 0.123*"concept"'),
#  (15,
#   '0.281*"actually" + -0.208*"staff" + -0.168*"balance" + -0.161*"uncertainty" '
#   '+ -0.159*"condition" + 0.158*"pact" + 0.158*"operation" + 0.146*"sense" + '
#   '-0.137*"lending" + 0.137*"crisis"'),
#  (16,
#   '0.269*"quarter" + 0.203*"bond" + 0.198*"asset" + -0.187*"condition" + '
#   '0.157*"assumption" + -0.152*"operation" + 0.142*"essence" + 0.141*"banking" '
#   '+ -0.137*"deliver" + -0.136*"pact"'),
#  (17,
#   '0.192*"deliver" + 0.182*"treaty" + 0.175*"bond" + -0.174*"action" + '
#   '-0.165*"objective" + 0.152*"forecast" + -0.150*"several" + '
#   '-0.149*"currency" + 0.142*"data" + -0.140*"unemployment"'),
#  (18,
#   '0.312*"instrument" + -0.212*"objective" + 0.161*"we" + 0.159*"currency" + '
#   '0.155*"staff" + -0.154*"note" + -0.153*"quarter" + -0.146*"money" + '
#   '0.143*"crisis" + 0.140*"credible"'),
#  (19,
#   '-0.278*"functioning" + -0.263*"currency" + 0.214*"balance" + -0.172*"staff" '
#   '+ 0.159*"negative" + 0.152*"move" + 0.138*"consensus" + -0.131*"we" + '
#   '-0.128*"investment" + -0.126*"quarter"'),
#  (20,
#   '0.315*"lending" + -0.228*"condition" + -0.201*"we" + 0.198*"recovery" + '
#   '0.155*"loan" + -0.144*"asset" + -0.143*"deficit" + 0.133*"credible" + '
#   '-0.128*"mediumterm" + 0.125*"act"'),
#  (21,
#   '-0.228*"instrument" + 0.201*"crisis" + -0.198*"forward" + -0.188*"cost" + '
#   '-0.187*"labour" + -0.173*"quarter" + 0.163*"consensus" + 0.145*"concept" + '
#   '0.140*"we" + -0.132*"framework"'),
#  (22,
#   '-0.230*"note" + 0.190*"data" + 0.187*"actually" + -0.174*"capital" + '
#   '-0.173*"several" + 0.166*"loan" + -0.151*"lower" + -0.149*"germany" + '
#   '0.143*"progress" + 0.141*"survey"'),
#  (23,
#   '0.236*"collateral" + -0.231*"observed" + 0.195*"treaty" + -0.156*"survey" + '
#   '0.156*"negative" + -0.152*"uncertainty" + -0.147*"favourable" + '
#   '-0.133*"inflationary" + 0.132*"lower" + 0.127*"president"'),
#  (24,
#   '0.243*"treaty" + 0.216*"cost" + 0.208*"observed" + -0.188*"don" + '
#   '0.146*"labour" + 0.142*"president" + 0.140*"staff" + -0.124*"conclusion" + '
#   '-0.124*"committee" + 0.122*"progress"'),
#  (25,
#   '-0.179*"data" + 0.178*"condition" + -0.167*"investment" + 0.158*"lending" + '
#   '0.158*"mediumterm" + -0.149*"president" + -0.144*"single" + '
#   '-0.140*"purchase" + 0.139*"imf" + -0.124*"citizen"'),
#  (26,
#   '-0.218*"staff" + 0.218*"move" + 0.196*"observed" + -0.181*"uncertainty" + '
#   '-0.170*"money" + 0.148*"phenomenon" + -0.144*"labour" + -0.138*"note" + '
#   '0.135*"observation" + 0.131*"cautious"'),
#  (27,
#   '0.219*"objective" + 0.213*"functioning" + -0.196*"banking" + -0.168*"don" + '
#   '-0.156*"loan" + 0.151*"data" + 0.142*"instrument" + -0.138*"treaty" + '
#   '-0.136*"carefully" + 0.124*"quarter"'),
#  (28,
#   '0.205*"dynamic" + 0.175*"currency" + -0.170*"favourable" + 0.157*"loan" + '
#   '-0.148*"credibility" + -0.142*"don" + 0.133*"reserve" + 0.129*"banking" + '
#   '0.127*"actually" + -0.126*"money"'),
#  (29,
#   '-0.226*"quarter" + -0.209*"action" + 0.182*"volatility" + 0.165*"week" + '
#   '0.155*"imf" + -0.151*"money" + 0.149*"lower" + 0.124*"carefully" + '
#   '-0.124*"committee" + 0.123*"debt"'),
#  (30,
#   '0.169*"functioning" + -0.156*"we" + -0.150*"lending" + 0.145*"treaty" + '
#   '0.141*"bond" + 0.136*"operation" + -0.135*"uncertainty" + -0.126*"single" + '
#   '-0.124*"collateral" + 0.122*"progress"'),
#  (31,
#   '-0.226*"single" + -0.184*"negative" + 0.176*"uncertainty" + '
#   '0.145*"consensus" + -0.139*"inflationary" + 0.127*"capital" + '
#   '-0.122*"whatever" + -0.121*"amount" + -0.120*"commodity" + 0.118*"move"'),
#  (32,
#   '-0.175*"sign" + 0.174*"deficit" + -0.171*"note" + -0.154*"conference" + '
#   '0.153*"labour" + -0.151*"took" + -0.150*"eurogroup" + -0.132*"actually" + '
#   '0.131*"treaty" + 0.123*"uncertainty"'),
#  (33,
#   '0.269*"move" + -0.191*"uncertainty" + -0.184*"phenomenon" + -0.172*"curve" '
#   '+ 0.143*"money" + 0.135*"decide" + -0.134*"framework" + -0.133*"yield" + '
#   '-0.131*"observed" + 0.129*"december"'),
#  (34,
#   '0.208*"billion" + -0.186*"every" + -0.158*"committee" + 0.147*"dynamic" + '
#   '-0.144*"average" + -0.142*"negative" + -0.131*"banking" + 0.129*"creation" '
#   '+ 0.127*"shock" + 0.127*"sustainable"'),
#  (35,
#   '0.166*"deliver" + 0.163*"demand" + 0.156*"committee" + -0.147*"framework" + '
#   '0.145*"decide" + -0.145*"indicator" + -0.135*"functioning" + '
#   '0.134*"unemployment" + -0.134*"we" + 0.129*"lending"'),
#  (36,
#   '-0.241*"creation" + -0.226*"uncertainty" + 0.196*"note" + 0.160*"act" + '
#   '0.146*"concept" + -0.140*"sustainable" + 0.136*"took" + 0.129*"currency" + '
#   '0.123*"value" + -0.118*"sign"'),
#  (37,
#   '-0.263*"decide" + -0.168*"phenomenon" + 0.159*"collateral" + '
#   '0.152*"quarter" + -0.152*"investment" + 0.143*"difference" + '
#   '0.141*"opinion" + -0.139*"extremely" + 0.129*"currency" + -0.119*"channel"'),
#  (38,
#   '-0.238*"forecast" + 0.219*"uncertainty" + 0.183*"reserve" + '
#   '-0.151*"lending" + -0.140*"instrument" + 0.136*"credible" + 0.135*"bond" + '
#   '0.135*"pact" + -0.130*"citizen" + -0.115*"collateral"'),
#  (39,
#   '-0.184*"imf" + -0.167*"upside" + -0.160*"data" + -0.157*"money" + '
#   '0.154*"actually" + -0.144*"essential" + 0.143*"lending" + 0.142*"billion" + '
#   '0.137*"mr" + -0.124*"operation"'),
#  (40,
#   '-0.179*"credible" + 0.175*"move" + -0.162*"note" + -0.157*"credibility" + '
#   '-0.153*"lower" + 0.146*"partner" + -0.144*"dynamic" + -0.138*"investment" + '
#   '-0.137*"financing" + -0.133*"progress"'),
#  (41,
#   '-0.186*"decide" + -0.181*"note" + 0.146*"remark" + -0.137*"strategy" + '
#   '-0.130*"uncertainty" + -0.127*"action" + 0.126*"sentiment" + '
#   '-0.126*"parliament" + -0.126*"mediumterm" + 0.124*"lower"'),
#  (42,
#   '-0.180*"banking" + 0.162*"opinion" + 0.148*"however" + 0.142*"around" + '
#   '0.140*"collateral" + 0.136*"mediumterm" + 0.135*"survey" + 0.133*"currency" '
#   '+ -0.124*"domain" + 0.122*"conclusion"'),
#  (43,
#   '0.228*"functioning" + -0.171*"potential" + -0.168*"consensus" + '
#   '0.159*"collateral" + -0.154*"opinion" + 0.140*"germany" + 0.137*"normal" + '
#   '-0.136*"lower" + -0.133*"inflationary" + -0.127*"commodity"'),
#  (44,
#   '-0.221*"reserve" + -0.186*"use" + -0.157*"dollar" + -0.155*"extremely" + '
#   '0.151*"imf" + 0.146*"staff" + 0.140*"indicator" + -0.124*"germany" + '
#   '0.122*"supply" + 0.120*"president"'),
#  (45,
#   '0.177*"week" + -0.170*"spread" + -0.150*"channel" + -0.148*"forecast" + '
#   '0.129*"move" + -0.124*"banking" + -0.117*"stress" + 0.116*"adjustment" + '
#   '0.115*"capacity" + 0.114*"money"'),
#  (46,
#   '-0.191*"concept" + -0.164*"within" + 0.159*"debt" + 0.155*"sense" + '
#   '0.149*"effective" + -0.147*"forecast" + -0.140*"week" + 0.138*"president" + '
#   '0.134*"confirmed" + 0.132*"remember"'),
#  (47,
#   '0.216*"inflationary" + 0.190*"stress" + -0.187*"opinion" + -0.181*"action" '
#   '+ -0.155*"phenomenon" + 0.143*"happy" + 0.138*"committee" + 0.133*"act" + '
#   '-0.129*"additional" + 0.127*"crisis"'),
#  (48,
#   '0.181*"quarter" + -0.176*"objective" + 0.156*"conclusion" + '
#   '0.155*"eurosystem" + -0.152*"influence" + 0.140*"trust" + -0.139*"demand" + '
#   '0.138*"help" + 0.138*"concept" + -0.129*"observing"'),
#  (49,
#   '0.193*"investment" + 0.178*"mr" + 0.173*"day" + 0.170*"potential" + '
#   '0.155*"commodity" + 0.151*"communication" + -0.147*"difference" + '
#   '-0.139*"upside" + -0.137*"move" + 0.136*"opinion"')]
# [(0,
#   '-0.185*"programme" + -0.171*"actually" + -0.152*"condition" + -0.142*"bond" '
#   '+ -0.128*"money" + -0.109*"recovery" + -0.106*"don" + -0.106*"several" + '
#   '-0.105*"lower" + -0.104*"action"'),
#  (1,
#   '0.288*"actually" + -0.203*"deliver" + 0.196*"programme" + 0.180*"condition" '
#   '+ -0.160*"currency" + 0.156*"basically" + 0.150*"bond" + 0.142*"sense" + '
#   '-0.132*"observed" + -0.126*"staff"'),
#  (2,
#   '-0.405*"operation" + -0.324*"programme" + -0.286*"bond" + -0.227*"billion" '
#   '+ -0.220*"money" + -0.166*"collateral" + -0.149*"refinancing" + '
#   '-0.145*"functioning" + -0.135*"purchase" + 0.122*"data"'),
#  (3,
#   '0.563*"programme" + -0.362*"money" + -0.214*"operation" + 0.171*"condition" '
#   '+ 0.145*"currency" + 0.145*"recovery" + 0.114*"pact" + -0.108*"data" + '
#   '-0.105*"refinancing" + -0.104*"balance"'),
#  (4,
#   '0.244*"week" + 0.185*"forecast" + -0.184*"deliver" + 0.173*"mr" + '
#   '0.162*"minister" + -0.147*"quarter" + 0.145*"rather" + 0.141*"treaty" + '
#   '0.140*"day" + -0.133*"lower"'),
#  (5,
#   '0.298*"recovery" + -0.285*"bond" + -0.202*"balance" + -0.196*"creation" + '
#   '0.193*"negative" + -0.187*"collateral" + -0.172*"don" + 0.167*"loan" + '
#   '0.153*"programme" + -0.146*"actually"'),
#  (6,
#   '0.377*"condition" + 0.217*"bond" + 0.211*"negative" + 0.180*"purchase" + '
#   '-0.172*"functioning" + -0.165*"action" + -0.160*"balance" + -0.159*"crisis" '
#   '+ -0.155*"forward" + -0.143*"help"'),
#  (7,
#   '0.309*"negative" + -0.306*"programme" + 0.271*"currency" + 0.240*"recovery" '
#   '+ 0.225*"condition" + 0.150*"creation" + 0.145*"environment" + '
#   '0.141*"financing" + -0.140*"don" + -0.134*"staff"'),
#  (8,
#   '-0.289*"balance" + 0.275*"money" + -0.192*"data" + -0.189*"recovery" + '
#   '-0.185*"quarter" + -0.172*"staff" + -0.169*"pact" + 0.156*"deliver" + '
#   '0.155*"objective" + -0.148*"sheet"'),
#  (9,
#   '0.366*"balance" + 0.232*"sheet" + 0.221*"money" + -0.214*"capital" + '
#   '-0.212*"billion" + -0.192*"operation" + 0.188*"recovery" + -0.158*"data" + '
#   '-0.155*"banking" + -0.140*"eurogroup"'),
#  (10,
#   '0.241*"quarter" + 0.222*"deliver" + -0.204*"forward" + -0.194*"asset" + '
#   '-0.192*"balance" + -0.186*"lower" + 0.178*"crisis" + -0.177*"mediumterm" + '
#   '0.156*"capital" + 0.147*"labour"'),
#  (11,
#   '0.227*"money" + -0.226*"staff" + -0.225*"objective" + -0.210*"deliver" + '
#   '0.200*"bond" + 0.197*"labour" + 0.180*"treaty" + -0.175*"committee" + '
#   '-0.171*"collateral" + -0.159*"framework"'),
#  (12,
#   '-0.224*"uncertainty" + -0.197*"treaty" + -0.193*"recovery" + '
#   '-0.166*"actually" + 0.158*"currency" + 0.156*"loan" + 0.148*"asset" + '
#   '-0.147*"operation" + 0.136*"sign" + 0.135*"framework"'),
#  (13,
#   '0.279*"pact" + 0.211*"collateral" + 0.206*"instrument" + -0.170*"billion" + '
#   '-0.164*"currency" + 0.161*"single" + -0.160*"quarter" + -0.157*"lower" + '
#   '0.142*"framework" + -0.142*"environment"'),
#  (14,
#   '-0.369*"recovery" + 0.262*"lending" + 0.247*"treaty" + -0.164*"billion" + '
#   '0.158*"committee" + -0.150*"labour" + 0.142*"loan" + 0.138*"financing" + '
#   '-0.131*"banking" + 0.123*"concept"'),
#  (15,
#   '0.281*"actually" + -0.208*"staff" + -0.168*"balance" + -0.161*"uncertainty" '
#   '+ -0.159*"condition" + 0.158*"pact" + 0.158*"operation" + 0.146*"sense" + '
#   '-0.137*"lending" + 0.137*"crisis"'),
#  (16,
#   '0.269*"quarter" + 0.203*"bond" + 0.198*"asset" + -0.187*"condition" + '
#   '0.157*"assumption" + -0.152*"operation" + 0.142*"essence" + 0.141*"banking" '
#   '+ -0.136*"deliver" + -0.136*"pact"'),
#  (17,
#   '-0.192*"deliver" + -0.182*"treaty" + -0.175*"bond" + 0.174*"action" + '
#   '0.165*"objective" + -0.152*"forecast" + 0.150*"several" + 0.149*"currency" '
#   '+ -0.142*"data" + 0.140*"unemployment"'),
#  (18,
#   '-0.312*"instrument" + 0.212*"objective" + -0.161*"we" + -0.159*"currency" + '
#   '-0.155*"staff" + 0.154*"note" + 0.154*"quarter" + 0.146*"money" + '
#   '-0.143*"crisis" + -0.140*"credible"'),
#  (19,
#   '0.278*"functioning" + 0.263*"currency" + -0.214*"balance" + 0.172*"staff" + '
#   '-0.160*"negative" + -0.152*"move" + -0.138*"consensus" + 0.131*"we" + '
#   '0.128*"investment" + 0.126*"quarter"'),
#  (20,
#   '0.315*"lending" + -0.228*"condition" + -0.202*"we" + 0.198*"recovery" + '
#   '0.155*"loan" + -0.144*"asset" + -0.143*"deficit" + 0.133*"credible" + '
#   '-0.128*"mediumterm" + 0.124*"act"'),
#  (21,
#   '0.228*"instrument" + -0.201*"crisis" + 0.198*"forward" + 0.188*"cost" + '
#   '0.187*"labour" + 0.173*"quarter" + -0.163*"consensus" + -0.145*"concept" + '
#   '-0.140*"we" + 0.132*"framework"'),
#  (22,
#   '0.230*"note" + -0.190*"data" + -0.187*"actually" + 0.174*"capital" + '
#   '0.173*"several" + -0.166*"loan" + 0.151*"lower" + 0.149*"germany" + '
#   '-0.143*"progress" + -0.141*"survey"'),
#  (23,
#   '-0.236*"collateral" + 0.232*"observed" + -0.195*"treaty" + 0.156*"survey" + '
#   '-0.156*"negative" + 0.152*"uncertainty" + 0.147*"favourable" + '
#   '0.134*"inflationary" + -0.132*"lower" + -0.127*"president"'),
#  (24,
#   '0.243*"treaty" + 0.216*"cost" + 0.208*"observed" + -0.189*"don" + '
#   '0.146*"labour" + 0.142*"president" + 0.140*"staff" + -0.125*"conclusion" + '
#   '-0.124*"committee" + 0.122*"progress"'),
#  (25,
#   '-0.179*"data" + 0.178*"condition" + -0.167*"investment" + 0.158*"lending" + '
#   '0.158*"mediumterm" + -0.149*"president" + -0.144*"single" + '
#   '-0.140*"purchase" + 0.139*"imf" + -0.124*"citizen"'),
#  (26,
#   '-0.218*"staff" + 0.218*"move" + 0.197*"observed" + -0.181*"uncertainty" + '
#   '-0.170*"money" + 0.148*"phenomenon" + -0.144*"labour" + -0.138*"note" + '
#   '0.135*"observation" + 0.131*"cautious"'),
#  (27,
#   '-0.219*"objective" + -0.213*"functioning" + 0.196*"banking" + 0.168*"don" + '
#   '0.156*"loan" + -0.151*"data" + -0.142*"instrument" + 0.138*"treaty" + '
#   '0.135*"carefully" + -0.124*"quarter"'),
#  (28,
#   '-0.206*"dynamic" + -0.174*"currency" + 0.170*"favourable" + -0.158*"loan" + '
#   '0.148*"credibility" + 0.142*"don" + -0.133*"reserve" + -0.129*"banking" + '
#   '-0.127*"actually" + 0.126*"money"'),
#  (29,
#   '0.226*"quarter" + 0.208*"action" + -0.182*"volatility" + -0.165*"week" + '
#   '-0.155*"imf" + 0.151*"money" + -0.149*"lower" + -0.124*"carefully" + '
#   '0.124*"committee" + -0.123*"debt"'),
#  (30,
#   '0.169*"functioning" + -0.156*"we" + -0.151*"lending" + 0.145*"treaty" + '
#   '0.141*"bond" + 0.137*"operation" + -0.135*"uncertainty" + -0.126*"single" + '
#   '-0.124*"collateral" + 0.122*"progress"'),
#  (31,
#   '0.225*"single" + 0.184*"negative" + -0.176*"uncertainty" + '
#   '-0.145*"consensus" + 0.139*"inflationary" + -0.127*"capital" + '
#   '0.123*"whatever" + 0.121*"amount" + 0.121*"commodity" + -0.119*"move"'),
#  (32,
#   '0.175*"sign" + -0.174*"deficit" + 0.172*"note" + 0.154*"conference" + '
#   '-0.154*"labour" + 0.151*"took" + 0.149*"eurogroup" + 0.132*"actually" + '
#   '-0.132*"treaty" + -0.123*"uncertainty"'),
#  (33,
#   '0.269*"move" + -0.192*"uncertainty" + -0.184*"phenomenon" + -0.172*"curve" '
#   '+ 0.143*"money" + 0.135*"decide" + -0.134*"framework" + -0.133*"yield" + '
#   '-0.131*"observed" + 0.129*"december"'),
#  (34,
#   '0.208*"billion" + -0.186*"every" + -0.158*"committee" + 0.147*"dynamic" + '
#   '-0.145*"average" + -0.141*"negative" + -0.132*"banking" + 0.129*"creation" '
#   '+ 0.128*"shock" + 0.127*"sustainable"'),
#  (35,
#   '0.166*"deliver" + 0.163*"demand" + 0.156*"committee" + -0.147*"framework" + '
#   '0.145*"decide" + -0.145*"indicator" + -0.135*"functioning" + '
#   '0.134*"unemployment" + -0.134*"we" + 0.129*"lending"'),
#  (36,
#   '-0.241*"creation" + -0.226*"uncertainty" + 0.196*"note" + 0.159*"act" + '
#   '0.146*"concept" + -0.140*"sustainable" + 0.137*"took" + 0.130*"currency" + '
#   '0.123*"value" + -0.118*"sign"'),
#  (37,
#   '-0.264*"decide" + -0.169*"phenomenon" + 0.159*"collateral" + '
#   '0.152*"quarter" + -0.151*"investment" + 0.143*"difference" + '
#   '0.142*"opinion" + -0.139*"extremely" + 0.129*"currency" + -0.119*"channel"'),
#  (38,
#   '0.239*"forecast" + -0.219*"uncertainty" + -0.182*"reserve" + '
#   '0.151*"lending" + 0.140*"instrument" + -0.136*"credible" + -0.135*"pact" + '
#   '-0.135*"bond" + 0.130*"citizen" + 0.115*"collateral"'),
#  (39,
#   '0.184*"imf" + 0.167*"upside" + 0.160*"data" + 0.157*"money" + '
#   '-0.154*"actually" + 0.144*"essential" + -0.143*"lending" + -0.142*"billion" '
#   '+ -0.137*"mr" + 0.124*"operation"'),
#  (40,
#   '0.179*"credible" + -0.175*"move" + 0.162*"note" + 0.156*"credibility" + '
#   '0.153*"lower" + -0.146*"partner" + 0.144*"dynamic" + 0.138*"investment" + '
#   '0.137*"financing" + 0.134*"progress"'),
#  (41,
#   '0.186*"decide" + 0.180*"note" + -0.146*"remark" + 0.137*"strategy" + '
#   '0.130*"uncertainty" + 0.127*"action" + -0.126*"sentiment" + '
#   '0.126*"parliament" + 0.126*"mediumterm" + -0.124*"lower"'),
#  (42,
#   '-0.180*"banking" + 0.162*"opinion" + 0.147*"however" + 0.142*"around" + '
#   '0.140*"collateral" + 0.136*"mediumterm" + 0.135*"survey" + 0.133*"currency" '
#   '+ -0.125*"domain" + -0.122*"single"'),
#  (43,
#   '-0.228*"functioning" + 0.170*"potential" + 0.168*"consensus" + '
#   '-0.158*"collateral" + 0.154*"opinion" + -0.140*"germany" + -0.137*"normal" '
#   '+ 0.137*"lower" + 0.134*"inflationary" + 0.128*"commodity"'),
#  (44,
#   '-0.221*"reserve" + -0.185*"use" + -0.156*"dollar" + -0.155*"extremely" + '
#   '0.151*"imf" + 0.145*"staff" + 0.140*"indicator" + -0.123*"germany" + '
#   '0.121*"supply" + 0.120*"president"'),
#  (45,
#   '0.177*"week" + -0.170*"spread" + -0.150*"channel" + -0.148*"forecast" + '
#   '0.129*"move" + -0.123*"banking" + 0.116*"adjustment" + -0.116*"stress" + '
#   '0.115*"capacity" + -0.115*"amount"'),
#  (46,
#   '0.191*"concept" + 0.164*"within" + -0.159*"debt" + -0.155*"sense" + '
#   '-0.149*"effective" + 0.148*"forecast" + 0.140*"week" + -0.138*"president" + '
#   '-0.133*"confirmed" + -0.133*"remember"'),
#  (47,
#   '-0.216*"inflationary" + -0.190*"stress" + 0.186*"opinion" + 0.180*"action" '
#   '+ 0.156*"phenomenon" + -0.142*"happy" + -0.138*"committee" + -0.134*"act" + '
#   '0.130*"additional" + -0.128*"crisis"'),
#  (48,
#   '0.180*"quarter" + -0.176*"objective" + 0.156*"conclusion" + '
#   '0.155*"eurosystem" + -0.152*"influence" + 0.140*"trust" + -0.140*"demand" + '
#   '0.139*"help" + 0.137*"concept" + -0.129*"observing"'),
#  (49,
#   '-0.192*"investment" + -0.178*"mr" + -0.174*"day" + -0.170*"potential" + '
#   '-0.155*"commodity" + -0.151*"communication" + 0.147*"difference" + '
#   '0.140*"upside" + -0.137*"opinion" + 0.136*"move"'),
#  (50,
#   '0.176*"functioning" + -0.148*"opinion" + -0.147*"stress" + 0.145*"event" + '
#   '0.143*"reserve" + 0.136*"understanding" + 0.135*"judge" + 0.134*"sentiment" '
#   '+ -0.134*"extremely" + 0.133*"inflationary"'),
#  (51,
#   '0.167*"agreement" + -0.135*"observed" + -0.131*"dynamic" + 0.131*"cut" + '
#   '-0.131*"debt" + 0.127*"closely" + 0.127*"framework" + -0.124*"effective" + '
#   '0.120*"judge" + -0.116*"occasion"'),
#  (52,
#   '-0.178*"positive" + -0.160*"value" + 0.144*"used" + -0.142*"sense" + '
#   '0.140*"observing" + -0.131*"volatility" + -0.127*"credible" + '
#   '0.127*"unemployment" + 0.115*"carefully" + 0.115*"small"'),
#  (53,
#   '0.209*"extremely" + 0.160*"sign" + 0.149*"remark" + 0.140*"ensure" + '
#   '-0.137*"size" + -0.135*"took" + -0.134*"amount" + -0.130*"action" + '
#   '-0.129*"staff" + -0.128*"meet"'),
#  (54,
#   '0.176*"loan" + -0.161*"upon" + 0.148*"happens" + -0.140*"took" + '
#   '-0.134*"several" + 0.125*"conclusion" + 0.123*"every" + -0.121*"banking" + '
#   '-0.118*"extremely" + 0.118*"assumption"'),
#  (55,
#   '-0.178*"emerging" + -0.151*"behalf" + 0.142*"agreement" + 0.138*"mr" + '
#   '0.137*"board" + 0.134*"we" + -0.126*"occasion" + -0.124*"communication" + '
#   '-0.122*"don" + 0.119*"start"'),
#  (56,
#   '0.178*"phenomenon" + 0.156*"basically" + 0.155*"credibility" + '
#   '-0.145*"reserve" + -0.139*"took" + -0.135*"several" + 0.133*"consensus" + '
#   '-0.131*"hard" + -0.128*"move" + -0.123*"happy"'),
#  (57,
#   '-0.214*"conclusion" + 0.178*"survey" + 0.159*"move" + 0.143*"agreement" + '
#   '0.133*"consensus" + -0.121*"inflationary" + -0.115*"pact" + 0.112*"decide" '
#   '+ -0.111*"earlier" + -0.111*"draw"'),
#  (58,
#   '-0.187*"negative" + 0.180*"purchase" + 0.168*"mediumterm" + 0.142*"banking" '
#   '+ 0.134*"treaty" + -0.131*"stress" + 0.121*"independent" + -0.119*"supply" '
#   '+ -0.118*"eurogroup" + -0.117*"progress"'),
#  (59,
#   '-0.162*"normal" + 0.154*"standard" + -0.144*"shock" + -0.142*"observer" + '
#   '-0.138*"banking" + -0.137*"dollar" + 0.126*"volatility" + 0.125*"sense" + '
#   '-0.124*"judge" + -0.122*"needed"'),
#  (60,
#   '-0.162*"communication" + 0.150*"positive" + -0.137*"concern" + '
#   '0.132*"address" + 0.127*"finance" + 0.117*"progressively" + '
#   '0.116*"objective" + -0.115*"week" + 0.114*"early" + 0.110*"eurogroup"'),
#  (61,
#   '0.145*"parliament" + -0.141*"target" + -0.138*"december" + '
#   '-0.137*"forecast" + 0.136*"agreement" + -0.134*"everybody" + -0.132*"help" '
#   '+ 0.127*"indicator" + -0.124*"don" + 0.124*"eurogroup"'),
#  (62,
#   '0.163*"recovery" + 0.142*"eurogroup" + -0.133*"front" + -0.131*"carefully" '
#   '+ -0.130*"sentiment" + -0.128*"specific" + 0.128*"commodity" + '
#   '0.127*"outlook" + -0.119*"minister" + 0.113*"favourable"'),
#  (63,
#   '-0.183*"president" + 0.182*"welcome" + -0.155*"result" + -0.155*"objective" '
#   '+ 0.147*"regarding" + 0.139*"partner" + 0.133*"within" + 0.132*"action" + '
#   '-0.117*"longer" + -0.116*"additional"'),
#  (64,
#   '0.194*"several" + -0.155*"around" + -0.151*"took" + -0.148*"within" + '
#   '-0.123*"deposit" + 0.120*"opinion" + 0.115*"average" + -0.114*"matter" + '
#   '0.113*"crisis" + 0.111*"value"'),
#  (65,
#   '0.233*"improvement" + 0.207*"indicator" + -0.178*"wage" + 0.156*"president" '
#   '+ -0.130*"forecast" + 0.127*"up" + 0.126*"single" + -0.126*"reserve" + '
#   '0.123*"essential" + -0.120*"thought"'),
#  (66,
#   '-0.162*"deliver" + 0.153*"positive" + 0.139*"yield" + 0.137*"lower" + '
#   '-0.136*"sustainable" + 0.135*"mediumterm" + -0.129*"lending" + '
#   '0.128*"channel" + -0.127*"especially" + -0.124*"strategy"'),
#  (67,
#   '0.162*"extremely" + 0.146*"example" + -0.145*"signal" + -0.144*"deficit" + '
#   '-0.135*"especially" + -0.125*"changed" + 0.124*"implemented" + '
#   '-0.123*"currency" + 0.123*"committee" + 0.122*"here"'),
#  (68,
#   '-0.161*"commodity" + 0.159*"especially" + -0.152*"extremely" + '
#   '0.147*"progress" + 0.137*"goal" + 0.129*"benefit" + 0.120*"ahead" + '
#   '-0.119*"read" + 0.114*"demand" + -0.111*"standard"'),
#  (69,
#   '-0.215*"trust" + 0.183*"pact" + 0.157*"shortterm" + 0.142*"shock" + '
#   '-0.133*"however" + -0.129*"address" + 0.118*"progress" + 0.115*"eurogroup" '
#   '+ 0.113*"imf" + 0.107*"behalf"'),
#  (70,
#   '-0.175*"phenomenon" + 0.148*"trust" + 0.140*"shortterm" + '
#   '-0.137*"implemented" + 0.130*"banking" + 0.130*"germany" + '
#   '-0.129*"evolution" + 0.125*"potential" + -0.123*"indicator" + '
#   '0.121*"aware"'),
#  (71,
#   '0.191*"phenomenon" + -0.183*"share" + -0.161*"effective" + '
#   '0.161*"parliament" + 0.145*"value" + -0.128*"conference" + 0.126*"normal" + '
#   '-0.125*"survey" + 0.123*"reference" + 0.118*"took"'),
#  (72,
#   '0.165*"day" + 0.139*"move" + -0.136*"week" + -0.134*"benefit" + '
#   '0.123*"trust" + 0.121*"matter" + -0.117*"sustainable" + 0.114*"possibility" '
#   '+ -0.112*"finance" + -0.108*"conference"'),
#  (73,
#   '-0.171*"forecast" + -0.158*"trust" + -0.158*"observing" + '
#   '-0.149*"executive" + 0.141*"everybody" + 0.132*"forward" + 0.131*"cut" + '
#   '-0.126*"instrument" + -0.125*"probably" + 0.123*"obviously"'),
#  (74,
#   '0.196*"basically" + -0.165*"event" + -0.139*"demand" + -0.135*"available" + '
#   '-0.132*"we" + 0.130*"lower" + 0.121*"remains" + 0.116*"itself" + '
#   '0.115*"investment" + -0.114*"refinancing"'),
#  (75,
#   '0.160*"money" + 0.159*"deliver" + -0.147*"upon" + 0.133*"early" + '
#   '-0.130*"changed" + 0.128*"executive" + 0.127*"very" + -0.127*"either" + '
#   '-0.127*"fundamental" + -0.125*"citizen"'),
#  (76,
#   '-0.170*"environment" + 0.153*"day" + -0.147*"upside" + -0.145*"help" + '
#   '-0.141*"mr" + 0.137*"every" + -0.132*"domestic" + 0.132*"target" + '
#   '0.128*"together" + -0.127*"example"'),
#  (77,
#   '-0.137*"deficit" + 0.132*"sustainable" + -0.128*"doubt" + '
#   '-0.126*"unanimous" + 0.124*"consensus" + 0.118*"domestic" + '
#   '-0.116*"conference" + -0.116*"regarding" + 0.116*"value" + 0.115*"ensure"'),
#  (78,
#   '-0.166*"remains" + 0.142*"demand" + 0.137*"average" + 0.123*"capacity" + '
#   '-0.119*"eurogroup" + -0.119*"shock" + 0.117*"essential" + -0.116*"explain" '
#   '+ 0.116*"respond" + -0.111*"forecast"'),
#  (79,
#   '-0.212*"agreement" + -0.169*"upside" + 0.165*"goal" + 0.161*"observed" + '
#   '-0.133*"investment" + -0.132*"extremely" + -0.131*"debt" + -0.129*"note" + '
#   '0.128*"front" + 0.116*"example"'),
#  (80,
#   '-0.186*"labour" + -0.159*"remember" + 0.129*"totally" + 0.129*"everybody" + '
#   '0.122*"ask" + -0.119*"observing" + 0.116*"confident" + -0.116*"commitment" '
#   '+ -0.115*"extremely" + 0.110*"unemployment"'),
#  (81,
#   '-0.168*"minister" + 0.165*"keep" + -0.151*"finance" + 0.150*"big" + '
#   '-0.142*"week" + -0.136*"benefit" + -0.133*"understanding" + 0.129*"discus" '
#   '+ 0.123*"day" + 0.123*"movement"'),
#  (82,
#   '-0.143*"mediumterm" + -0.143*"making" + 0.140*"whatever" + '
#   '-0.133*"responsible" + 0.128*"event" + 0.125*"potential" + 0.123*"remember" '
#   '+ -0.123*"down" + -0.122*"ensure" + 0.122*"ongoing"'),
#  (83,
#   '0.187*"assumption" + -0.184*"volatility" + 0.146*"decide" + -0.145*"very" + '
#   '-0.138*"move" + -0.127*"help" + 0.123*"anchor" + -0.120*"communication" + '
#   '-0.120*"concept" + 0.118*"pact"'),
#  (84,
#   '-0.185*"available" + -0.161*"fundamental" + 0.143*"week" + -0.134*"share" + '
#   '-0.124*"cut" + 0.116*"inflationary" + 0.115*"sheet" + -0.111*"don" + '
#   '0.110*"specific" + -0.110*"we"'),
#  (85,
#   '-0.156*"participant" + -0.155*"crisis" + 0.153*"credible" + '
#   '0.148*"maintain" + 0.144*"forecast" + 0.130*"italy" + 0.129*"possibility" + '
#   '-0.121*"credibility" + 0.115*"delivering" + 0.114*"shock"'),
#  (86,
#   '0.155*"germany" + -0.121*"single" + 0.118*"million" + 0.117*"strategy" + '
#   '-0.116*"used" + -0.114*"ask" + -0.112*"assumption" + 0.112*"influence" + '
#   '-0.109*"week" + -0.108*"money"'),
#  (87,
#   '0.158*"pact" + 0.155*"size" + 0.153*"strategy" + 0.138*"extremely" + '
#   '-0.136*"household" + -0.134*"reflect" + -0.131*"down" + 0.126*"depends" + '
#   '-0.125*"here" + 0.122*"inflationary"'),
#  (88,
#   '-0.163*"asset" + -0.136*"financing" + 0.134*"potential" + '
#   '0.130*"parliament" + 0.128*"observed" + 0.126*"basically" + '
#   '0.124*"favourable" + -0.124*"upon" + -0.121*"influence" + '
#   '-0.120*"participant"'),
#  (89,
#   '0.155*"use" + 0.142*"decrease" + 0.140*"outcome" + -0.138*"strategy" + '
#   '-0.137*"following" + -0.133*"response" + -0.127*"whatever" + '
#   '-0.123*"together" + 0.122*"depends" + 0.121*"help"'),
#  (90,
#   '0.137*"deliver" + -0.137*"commitment" + 0.125*"used" + -0.123*"week" + '
#   '-0.123*"reserve" + -0.121*"functioning" + 0.118*"likely" + '
#   '-0.112*"improvement" + -0.112*"trust" + -0.110*"potential"'),
#  (91,
#   '0.181*"don" + -0.156*"keep" + -0.147*"specific" + -0.146*"evolution" + '
#   '0.142*"ongoing" + 0.136*"rather" + 0.126*"towards" + 0.119*"day" + '
#   '0.119*"five" + -0.115*"we"'),
#  (92,
#   '0.190*"day" + -0.169*"framework" + 0.143*"indicator" + -0.135*"matter" + '
#   '0.130*"normal" + 0.116*"sign" + 0.115*"mr" + -0.114*"basically" + '
#   '-0.113*"reserve" + -0.113*"cautious"'),
#  (93,
#   '0.161*"forecast" + -0.152*"day" + -0.150*"december" + -0.144*"earlier" + '
#   '0.144*"concern" + 0.136*"improve" + 0.134*"cope" + -0.134*"activity" + '
#   '-0.131*"environment" + -0.128*"principle"'),
#  (94,
#   '-0.161*"investment" + 0.145*"early" + -0.142*"eurogroup" + '
#   '-0.131*"unemployment" + -0.126*"cautious" + -0.123*"political" + '
#   '-0.117*"able" + 0.115*"component" + -0.115*"upside" + -0.112*"carefully"'),
#  (95,
#   '0.194*"earlier" + 0.170*"perspective" + -0.148*"goal" + -0.142*"specific" + '
#   '0.130*"very" + 0.128*"expected" + 0.122*"action" + -0.122*"discus" + '
#   '-0.120*"contribution" + -0.119*"phenomenon"'),
#  (96,
#   '0.155*"week" + 0.148*"commodity" + 0.144*"purchase" + -0.135*"yield" + '
#   '0.124*"communication" + -0.123*"deposit" + 0.115*"wa" + 0.114*"use" + '
#   '0.114*"carefully" + -0.114*"imf"'),
#  (97,
#   '-0.178*"cost" + 0.155*"executive" + 0.147*"labour" + 0.144*"signal" + '
#   '-0.143*"understanding" + 0.135*"confirm" + -0.127*"inflationary" + '
#   '0.125*"alert" + 0.119*"ensure" + -0.114*"response"'),
#  (98,
#   '-0.178*"rather" + -0.166*"domestic" + 0.159*"observer" + -0.151*"address" + '
#   '-0.150*"sentiment" + -0.136*"probably" + -0.131*"spread" + -0.131*"become" '
#   '+ 0.129*"delivery" + 0.128*"mr"'),
#  (99,
#   '-0.150*"judge" + 0.150*"perspective" + -0.142*"reserve" + 0.134*"following" '
#   '+ -0.127*"shock" + -0.126*"itself" + -0.120*"principle" + '
#   '0.118*"implemented" + 0.112*"although" + -0.108*"probably"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.



coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)


coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='u_mass')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)
# Out:
# Coherence Score:  0.3694741671625609
#
# Coherence Score5:  0.41057361778769463
#
# Coherence Score10:  0.30203698652897476
#
# Coherence Score20:  0.2613019217506215
#
# Coherence Score50:  0.21371762822051177
#
# Coherence Score100:  0.19499868453255395
#
# Coherence Score:  -0.6368778718060781
#
# Coherence Score5:  -0.7189833105908405
#
# Coherence Score10:  -0.8296744307444698
#
# Coherence Score20:  -0.8398944521090221
#
# Coherence Score50:  -0.9145502729148082
#
# Coherence Score100:  -0.9478979102558159
