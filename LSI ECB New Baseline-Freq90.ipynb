# %%
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['Press']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(4394 unique tokens: ['able', 'acceptable', 'accompanied', 'according', 'account']...)

# %%
# filter words that occur in more than 90% of documents
id2word.filter_extremes(no_above = 0.900)
print(id2word)
# Out:
# Dictionary(1940 unique tokens: ['able', 'accompanied', 'according', 'account', 'achievement']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.193*"analysis" + 0.169*"financial" + 0.141*"loan" + 0.133*"recent" + '
#   '0.128*"credit" + 0.124*"support" + 0.123*"pressure" + 0.123*"quarter" + '
#   '0.121*"measure" + 0.120*"activity"')]
# [(0,
#   '0.193*"analysis" + 0.169*"financial" + 0.141*"loan" + 0.133*"recent" + '
#   '0.128*"credit" + 0.124*"support" + 0.123*"pressure" + 0.123*"quarter" + '
#   '0.121*"measure" + 0.120*"activity"'),
#  (1,
#   '0.255*"loan" + 0.192*"measure" + -0.162*"first" + -0.157*"strong" + '
#   '-0.151*"recent" + 0.140*"recovery" + -0.136*"wage" + -0.125*"would" + '
#   '0.122*"nonfinancial" + 0.121*"analysis"'),
#  (2,
#   '0.204*"bank" + -0.195*"upside" + -0.179*"strong" + 0.174*"central" + '
#   '0.150*"national" + 0.147*"operation" + -0.146*"oil" + 0.138*"january" + '
#   '0.130*"first" + 0.127*"decision"'),
#  (3,
#   '0.228*"oil" + -0.217*"financial" + -0.214*"pressure" + 0.184*"projection" + '
#   '0.161*"recovery" + 0.161*"quarter" + 0.144*"purchase" + -0.144*"commodity" '
#   '+ 0.133*"implementation" + 0.124*"staff"'),
#  (4,
#   '-0.272*"financial" + 0.204*"recovery" + -0.190*"credit" + 0.152*"positive" '
#   '+ -0.151*"money" + 0.149*"oil" + -0.133*"upside" + 0.129*"measure" + '
#   '-0.128*"underlying" + 0.123*"low"')]
# [(0,
#   '0.193*"analysis" + 0.169*"financial" + 0.141*"loan" + 0.133*"recent" + '
#   '0.128*"credit" + 0.124*"support" + 0.123*"pressure" + 0.123*"quarter" + '
#   '0.121*"measure" + 0.120*"activity"'),
#  (1,
#   '-0.255*"loan" + -0.192*"measure" + 0.162*"first" + 0.157*"strong" + '
#   '0.151*"recent" + -0.140*"recovery" + 0.136*"wage" + 0.125*"would" + '
#   '-0.122*"nonfinancial" + -0.121*"analysis"'),
#  (2,
#   '0.204*"bank" + -0.195*"upside" + -0.179*"strong" + 0.174*"central" + '
#   '0.150*"national" + 0.147*"operation" + -0.146*"oil" + 0.138*"january" + '
#   '0.130*"first" + 0.127*"decision"'),
#  (3,
#   '-0.228*"oil" + 0.217*"financial" + 0.214*"pressure" + -0.184*"projection" + '
#   '-0.161*"recovery" + -0.161*"quarter" + -0.144*"purchase" + '
#   '0.144*"commodity" + -0.133*"implementation" + -0.124*"staff"'),
#  (4,
#   '-0.272*"financial" + 0.204*"recovery" + -0.190*"credit" + 0.152*"positive" '
#   '+ -0.151*"money" + 0.149*"oil" + -0.133*"upside" + 0.129*"measure" + '
#   '-0.128*"underlying" + 0.123*"low"'),
#  (5,
#   '-0.189*"remains" + 0.158*"financial" + -0.149*"underlying" + 0.143*"effect" '
#   '+ 0.138*"recovery" + -0.123*"operation" + -0.122*"pressure" + '
#   '-0.116*"ample" + -0.114*"liquidity" + 0.114*"negative"'),
#  (6,
#   '0.404*"projection" + 0.288*"staff" + 0.181*"measure" + 0.173*"range" + '
#   '0.171*"macroeconomic" + 0.153*"eurosystem" + 0.141*"operation" + '
#   '-0.131*"subdued" + 0.117*"gdp" + -0.111*"demand"'),
#  (7,
#   '0.242*"projection" + 0.233*"recent" + -0.199*"credit" + 0.182*"pressure" + '
#   '-0.152*"bank" + 0.152*"staff" + 0.126*"inflationary" + -0.122*"money" + '
#   '0.115*"effect" + -0.112*"condition"'),
#  (8,
#   '0.186*"subdued" + -0.184*"measure" + -0.174*"purchase" + 0.156*"activity" + '
#   '0.143*"projection" + -0.126*"contribute" + -0.116*"firm" + '
#   '-0.112*"supported" + -0.110*"recovery" + -0.106*"food"'),
#  (9,
#   '0.282*"financial" + -0.243*"may" + 0.184*"measure" + 0.139*"environment" + '
#   '0.129*"tension" + -0.122*"april" + 0.122*"mediumterm" + 0.117*"october" + '
#   '0.116*"uncertainty" + -0.115*"march"')]
# [(0,
#   '0.193*"analysis" + 0.169*"financial" + 0.141*"loan" + 0.133*"recent" + '
#   '0.128*"credit" + 0.124*"support" + 0.123*"pressure" + 0.123*"quarter" + '
#   '0.121*"measure" + 0.120*"activity"'),
#  (1,
#   '-0.255*"loan" + -0.192*"measure" + 0.162*"first" + 0.157*"strong" + '
#   '0.151*"recent" + -0.140*"recovery" + 0.136*"wage" + 0.125*"would" + '
#   '-0.122*"nonfinancial" + -0.121*"analysis"'),
#  (2,
#   '-0.204*"bank" + 0.195*"upside" + 0.179*"strong" + -0.174*"central" + '
#   '-0.150*"national" + -0.147*"operation" + 0.146*"oil" + -0.138*"january" + '
#   '-0.130*"first" + -0.127*"decision"'),
#  (3,
#   '-0.228*"oil" + 0.217*"financial" + 0.214*"pressure" + -0.184*"projection" + '
#   '-0.161*"recovery" + -0.161*"quarter" + -0.144*"purchase" + '
#   '0.144*"commodity" + -0.133*"implementation" + -0.124*"staff"'),
#  (4,
#   '-0.272*"financial" + 0.204*"recovery" + -0.190*"credit" + 0.152*"positive" '
#   '+ -0.151*"money" + 0.149*"oil" + -0.133*"upside" + 0.129*"measure" + '
#   '-0.128*"underlying" + 0.123*"low"'),
#  (5,
#   '0.189*"remains" + -0.158*"financial" + 0.149*"underlying" + -0.143*"effect" '
#   '+ -0.138*"recovery" + 0.123*"operation" + 0.122*"pressure" + 0.116*"ample" '
#   '+ 0.114*"liquidity" + -0.114*"negative"'),
#  (6,
#   '0.404*"projection" + 0.288*"staff" + 0.181*"measure" + 0.173*"range" + '
#   '0.171*"macroeconomic" + 0.153*"eurosystem" + 0.141*"operation" + '
#   '-0.131*"subdued" + 0.117*"gdp" + -0.111*"demand"'),
#  (7,
#   '-0.242*"projection" + -0.233*"recent" + 0.199*"credit" + -0.182*"pressure" '
#   '+ 0.152*"bank" + -0.152*"staff" + -0.126*"inflationary" + 0.122*"money" + '
#   '-0.115*"effect" + 0.112*"condition"'),
#  (8,
#   '-0.185*"subdued" + 0.184*"measure" + 0.174*"purchase" + -0.156*"activity" + '
#   '-0.143*"projection" + 0.126*"contribute" + 0.116*"firm" + 0.112*"supported" '
#   '+ 0.110*"recovery" + 0.106*"food"'),
#  (9,
#   '0.282*"financial" + -0.243*"may" + 0.184*"measure" + 0.139*"environment" + '
#   '0.128*"tension" + -0.123*"april" + 0.122*"mediumterm" + 0.117*"october" + '
#   '0.115*"uncertainty" + -0.115*"march"'),
#  (10,
#   '-0.226*"projection" + 0.217*"operation" + 0.147*"refinancing" + '
#   '0.145*"period" + -0.141*"staff" + 0.135*"measure" + -0.127*"escb" + '
#   '0.122*"decided" + -0.118*"analysis" + 0.117*"effect"'),
#  (11,
#   '-0.165*"activity" + 0.165*"moderate" + -0.132*"january" + 0.125*"wage" + '
#   '0.123*"gdp" + 0.122*"factor" + -0.121*"commodity" + -0.118*"accommodative" '
#   '+ -0.117*"demand" + -0.115*"looking"'),
#  (12,
#   '0.230*"financial" + -0.186*"effect" + 0.175*"volatility" + 0.158*"credit" + '
#   '-0.139*"bank" + -0.137*"first" + 0.132*"may" + 0.130*"recent" + '
#   '-0.121*"wage" + 0.106*"overall"'),
#  (13,
#   '0.327*"january" + 0.327*"december" + -0.240*"june" + -0.182*"july" + '
#   '0.171*"november" + -0.153*"recent" + -0.145*"may" + -0.124*"august" + '
#   '0.122*"latest" + 0.107*"facility"'),
#  (14,
#   '-0.175*"recent" + 0.150*"period" + 0.137*"since" + 0.136*"still" + '
#   '0.134*"overall" + 0.133*"domestic" + 0.128*"september" + -0.126*"activity" '
#   '+ -0.122*"however" + -0.122*"january"'),
#  (15,
#   '0.242*"quarter" + -0.159*"march" + -0.143*"pillar" + -0.139*"macroeconomic" '
#   '+ -0.138*"key" + 0.127*"operation" + -0.122*"looking" + -0.120*"mediumterm" '
#   '+ 0.119*"july" + 0.114*"august"'),
#  (16,
#   '0.216*"march" + 0.177*"condition" + -0.166*"september" + 0.165*"financial" '
#   '+ 0.161*"pace" + -0.148*"expectation" + -0.146*"october" + 0.137*"recovery" '
#   '+ -0.126*"november" + -0.124*"oil"'),
#  (17,
#   '0.159*"operation" + 0.137*"low" + 0.131*"september" + -0.130*"need" + '
#   '-0.125*"quarter" + -0.120*"first" + -0.118*"higher" + 0.113*"asset" + '
#   '0.112*"remains" + -0.111*"consumer"'),
#  (18,
#   '-0.198*"bank" + -0.175*"may" + 0.158*"strategy" + 0.140*"january" + '
#   '-0.132*"june" + -0.129*"central" + -0.125*"information" + -0.122*"domestic" '
#   '+ -0.120*"national" + -0.119*"european"'),
#  (19,
#   '-0.173*"operation" + -0.151*"domestic" + 0.128*"gradual" + '
#   '0.122*"september" + 0.116*"bank" + -0.115*"march" + -0.110*"weak" + '
#   '0.108*"previous" + -0.108*"oil" + 0.106*"january"')]
# [(0,
#   '-0.193*"analysis" + -0.169*"financial" + -0.141*"loan" + -0.133*"recent" + '
#   '-0.128*"credit" + -0.124*"support" + -0.123*"pressure" + -0.123*"quarter" + '
#   '-0.121*"measure" + -0.120*"activity"'),
#  (1,
#   '0.255*"loan" + 0.192*"measure" + -0.162*"first" + -0.157*"strong" + '
#   '-0.151*"recent" + 0.140*"recovery" + -0.136*"wage" + -0.125*"would" + '
#   '0.122*"nonfinancial" + 0.121*"analysis"'),
#  (2,
#   '-0.204*"bank" + 0.195*"upside" + 0.179*"strong" + -0.174*"central" + '
#   '-0.150*"national" + -0.147*"operation" + 0.146*"oil" + -0.138*"january" + '
#   '-0.130*"first" + -0.127*"decision"'),
#  (3,
#   '-0.228*"oil" + 0.217*"financial" + 0.214*"pressure" + -0.184*"projection" + '
#   '-0.161*"recovery" + -0.161*"quarter" + -0.144*"purchase" + '
#   '0.144*"commodity" + -0.133*"implementation" + -0.124*"staff"'),
#  (4,
#   '0.272*"financial" + -0.204*"recovery" + 0.190*"credit" + -0.152*"positive" '
#   '+ 0.151*"money" + -0.149*"oil" + 0.133*"upside" + -0.129*"measure" + '
#   '0.128*"underlying" + -0.123*"low"'),
#  (5,
#   '-0.189*"remains" + 0.158*"financial" + -0.149*"underlying" + 0.143*"effect" '
#   '+ 0.138*"recovery" + -0.123*"operation" + -0.122*"pressure" + '
#   '-0.116*"ample" + -0.114*"liquidity" + 0.114*"negative"'),
#  (6,
#   '-0.404*"projection" + -0.288*"staff" + -0.181*"measure" + -0.173*"range" + '
#   '-0.171*"macroeconomic" + -0.153*"eurosystem" + -0.141*"operation" + '
#   '0.131*"subdued" + -0.117*"gdp" + 0.111*"demand"'),
#  (7,
#   '0.242*"projection" + 0.233*"recent" + -0.199*"credit" + 0.182*"pressure" + '
#   '-0.152*"bank" + 0.152*"staff" + 0.126*"inflationary" + -0.122*"money" + '
#   '0.115*"effect" + -0.112*"condition"'),
#  (8,
#   '0.186*"subdued" + -0.184*"measure" + -0.174*"purchase" + 0.156*"activity" + '
#   '0.143*"projection" + -0.126*"contribute" + -0.116*"firm" + '
#   '-0.113*"supported" + -0.110*"recovery" + -0.106*"food"'),
#  (9,
#   '-0.282*"financial" + 0.243*"may" + -0.184*"measure" + -0.139*"environment" '
#   '+ -0.128*"tension" + 0.123*"april" + -0.122*"mediumterm" + -0.117*"october" '
#   '+ -0.115*"uncertainty" + 0.115*"march"'),
#  (10,
#   '-0.226*"projection" + 0.217*"operation" + 0.147*"refinancing" + '
#   '0.144*"period" + -0.141*"staff" + 0.135*"measure" + -0.127*"escb" + '
#   '0.122*"decided" + -0.118*"analysis" + 0.117*"effect"'),
#  (11,
#   '0.166*"activity" + -0.165*"moderate" + 0.132*"january" + -0.125*"wage" + '
#   '-0.123*"gdp" + -0.122*"factor" + 0.121*"commodity" + 0.118*"accommodative" '
#   '+ 0.117*"demand" + 0.115*"looking"'),
#  (12,
#   '0.230*"financial" + -0.186*"effect" + 0.175*"volatility" + 0.157*"credit" + '
#   '-0.139*"bank" + -0.137*"first" + 0.132*"may" + 0.129*"recent" + '
#   '-0.121*"wage" + 0.107*"overall"'),
#  (13,
#   '-0.327*"january" + -0.327*"december" + 0.240*"june" + 0.182*"july" + '
#   '-0.171*"november" + 0.153*"recent" + 0.145*"may" + 0.124*"august" + '
#   '-0.122*"latest" + -0.107*"facility"'),
#  (14,
#   '-0.175*"recent" + 0.150*"period" + 0.137*"since" + 0.136*"still" + '
#   '0.134*"overall" + 0.133*"domestic" + 0.129*"september" + -0.126*"activity" '
#   '+ -0.122*"january" + -0.122*"however"'),
#  (15,
#   '-0.241*"quarter" + 0.159*"march" + 0.143*"pillar" + 0.139*"macroeconomic" + '
#   '0.138*"key" + -0.127*"operation" + 0.121*"looking" + 0.120*"mediumterm" + '
#   '-0.119*"july" + -0.114*"august"'),
#  (16,
#   '-0.216*"march" + -0.177*"condition" + 0.165*"september" + '
#   '-0.164*"financial" + -0.161*"pace" + 0.149*"expectation" + 0.146*"october" '
#   '+ -0.137*"recovery" + 0.126*"november" + 0.124*"oil"'),
#  (17,
#   '-0.159*"operation" + -0.137*"low" + -0.131*"september" + 0.130*"need" + '
#   '0.125*"quarter" + 0.120*"first" + 0.118*"higher" + -0.113*"asset" + '
#   '-0.112*"remains" + 0.111*"consumer"'),
#  (18,
#   '0.197*"bank" + 0.175*"may" + -0.158*"strategy" + -0.141*"january" + '
#   '0.132*"june" + 0.129*"central" + 0.125*"information" + 0.122*"domestic" + '
#   '0.120*"european" + 0.120*"national"'),
#  (19,
#   '0.173*"operation" + 0.151*"domestic" + -0.128*"gradual" + '
#   '-0.122*"september" + -0.117*"bank" + 0.116*"march" + 0.110*"weak" + '
#   '-0.109*"previous" + 0.108*"oil" + -0.107*"january"'),
#  (20,
#   '0.168*"june" + -0.141*"activity" + 0.136*"would" + -0.129*"strategy" + '
#   '0.125*"high" + -0.112*"reference" + 0.111*"july" + 0.109*"remains" + '
#   '-0.107*"value" + -0.107*"october"'),
#  (21,
#   '-0.239*"activity" + 0.177*"january" + 0.150*"first" + -0.150*"eurosystem" + '
#   '-0.149*"higher" + 0.132*"quarter" + -0.132*"bank" + 0.125*"basis" + '
#   '-0.120*"would" + 0.115*"money"'),
#  (22,
#   '-0.151*"banknote" + -0.146*"oil" + -0.142*"information" + 0.140*"basis" + '
#   '-0.139*"particular" + -0.138*"money" + 0.131*"quarter" + -0.129*"recent" + '
#   '0.119*"point" + 0.118*"balance"'),
#  (23,
#   '-0.182*"february" + 0.178*"shortterm" + 0.145*"support" + -0.143*"exchange" '
#   '+ 0.126*"impact" + 0.123*"money" + 0.110*"overall" + 0.108*"operation" + '
#   '0.106*"value" + -0.100*"intensification"'),
#  (24,
#   '-0.140*"overall" + -0.131*"upward" + -0.123*"december" + -0.121*"remains" + '
#   '-0.116*"likely" + 0.106*"would" + 0.105*"underlying" + 0.105*"september" + '
#   '-0.104*"activity" + 0.102*"first"'),
#  (25,
#   '-0.172*"regard" + 0.166*"activity" + -0.139*"previous" + 0.139*"recent" + '
#   '-0.137*"underlying" + -0.137*"quarter" + 0.129*"impact" + -0.123*"trend" + '
#   '0.108*"would" + 0.107*"first"'),
#  (26,
#   '0.174*"first" + 0.125*"recovery" + -0.121*"past" + 0.119*"may" + '
#   '0.119*"oil" + -0.114*"ensure" + 0.112*"continues" + 0.111*"mediumterm" + '
#   '0.109*"expansion" + -0.104*"reflecting"'),
#  (27,
#   '0.325*"oil" + -0.160*"regard" + -0.158*"day" + -0.149*"banknote" + '
#   '0.145*"strong" + 0.132*"exchange" + -0.121*"analysis" + -0.120*"new" + '
#   '-0.119*"european" + -0.117*"evidence"'),
#  (28,
#   '-0.154*"ongoing" + 0.138*"factor" + 0.131*"quarter" + 0.130*"recent" + '
#   '-0.125*"pressure" + -0.120*"upward" + 0.114*"well" + -0.112*"eurosystem" + '
#   '-0.111*"european" + 0.109*"may"'),
#  (29,
#   '0.173*"decision" + 0.163*"pressure" + 0.160*"point" + 0.139*"basis" + '
#   '0.134*"may" + -0.132*"recent" + -0.131*"available" + 0.117*"would" + '
#   '-0.117*"period" + -0.114*"become"'),
#  (30,
#   '-0.167*"well" + 0.136*"macroeconomic" + -0.130*"external" + '
#   '-0.124*"forecast" + 0.122*"however" + -0.121*"first" + -0.113*"important" + '
#   '-0.111*"line" + -0.110*"exchange" + -0.109*"measure"'),
#  (31,
#   '0.230*"decision" + 0.141*"february" + -0.139*"remains" + -0.138*"quarter" + '
#   '-0.138*"november" + -0.131*"continued" + 0.120*"particular" + 0.119*"trend" '
#   '+ 0.114*"august" + -0.113*"line"'),
#  (32,
#   '-0.189*"first" + 0.149*"information" + -0.135*"recent" + -0.134*"new" + '
#   '0.128*"oil" + -0.119*"target" + -0.118*"domestic" + 0.108*"account" + '
#   '0.106*"march" + -0.101*"remained"'),
#  (33,
#   '-0.221*"continued" + -0.164*"june" + -0.156*"july" + 0.152*"march" + '
#   '-0.144*"activity" + 0.139*"remains" + -0.127*"expansion" + 0.121*"first" + '
#   '-0.111*"low" + -0.109*"eurosystem"'),
#  (34,
#   '0.256*"recent" + 0.149*"particularly" + -0.146*"activity" + '
#   '-0.137*"support" + -0.127*"basis" + -0.124*"first" + -0.118*"pressure" + '
#   '0.113*"government" + -0.112*"need" + 0.111*"deposit"'),
#  (35,
#   '-0.181*"quarter" + -0.161*"wage" + -0.148*"data" + 0.147*"oil" + '
#   '0.141*"strong" + -0.141*"demand" + -0.124*"activity" + -0.121*"taking" + '
#   '-0.120*"impact" + -0.118*"july"'),
#  (36,
#   '0.175*"remains" + 0.170*"quarter" + 0.142*"recent" + -0.142*"particular" + '
#   '-0.130*"may" + -0.125*"therefore" + 0.118*"shortterm" + 0.117*"past" + '
#   '0.108*"process" + -0.106*"confidence"'),
#  (37,
#   '-0.181*"support" + 0.173*"first" + 0.170*"particular" + 0.167*"would" + '
#   '0.114*"information" + 0.111*"analysis" + -0.110*"february" + 0.108*"latest" '
#   '+ -0.101*"recovery" + -0.099*"regard"'),
#  (38,
#   '-0.209*"support" + 0.136*"demand" + -0.129*"particular" + 0.126*"rise" + '
#   '0.121*"domestic" + -0.119*"eurosystem" + -0.117*"period" + -0.104*"recent" '
#   '+ 0.104*"banknote" + 0.100*"confirm"'),
#  (39,
#   '-0.160*"available" + 0.142*"new" + -0.139*"december" + -0.127*"line" + '
#   '-0.119*"information" + -0.119*"oil" + -0.106*"june" + -0.105*"factor" + '
#   '0.103*"september" + 0.103*"union"'),
#  (40,
#   '0.156*"mainly" + -0.134*"impact" + 0.132*"uncertainty" + -0.122*"firm" + '
#   '-0.118*"strong" + 0.114*"energy" + 0.112*"previous" + 0.107*"important" + '
#   '-0.106*"number" + -0.100*"decline"'),
#  (41,
#   '-0.151*"potential" + 0.133*"may" + 0.130*"effect" + 0.120*"remains" + '
#   '0.118*"strong" + 0.117*"ahead" + -0.114*"overall" + -0.107*"background" + '
#   '-0.107*"well" + 0.107*"subdued"'),
#  (42,
#   '0.163*"ensure" + 0.160*"moderate" + 0.136*"unchanged" + 0.130*"october" + '
#   '-0.111*"lower" + -0.110*"loan" + -0.108*"looking" + -0.102*"therefore" + '
#   '0.099*"credit" + -0.098*"member"'),
#  (43,
#   '-0.209*"would" + -0.150*"july" + -0.146*"consolidation" + 0.144*"april" + '
#   '0.126*"october" + 0.123*"mediumterm" + -0.119*"could" + 0.119*"november" + '
#   '-0.113*"impact" + -0.113*"august"'),
#  (44,
#   '0.200*"march" + -0.157*"available" + 0.149*"overall" + -0.133*"remains" + '
#   '-0.130*"december" + 0.128*"money" + 0.119*"still" + -0.117*"june" + '
#   '-0.113*"regard" + 0.110*"labour"'),
#  (45,
#   '0.257*"continued" + -0.143*"regard" + 0.120*"range" + -0.119*"june" + '
#   '-0.116*"looking" + 0.104*"course" + 0.100*"gradual" + 0.099*"day" + '
#   '0.097*"energy" + 0.097*"thus"'),
#  (46,
#   '0.139*"information" + 0.139*"pressure" + -0.135*"may" + 0.133*"purchase" + '
#   '-0.122*"impact" + -0.115*"condition" + -0.113*"value" + 0.107*"expansion" + '
#   '-0.100*"overall" + -0.098*"higher"'),
#  (47,
#   '0.154*"overall" + -0.152*"continued" + 0.127*"january" + -0.119*"decline" + '
#   '0.115*"factor" + 0.114*"financial" + 0.113*"deficit" + -0.112*"bank" + '
#   '0.112*"finance" + -0.109*"would"'),
#  (48,
#   '0.173*"would" + -0.162*"purchase" + -0.161*"particular" + '
#   '0.155*"implementation" + -0.127*"global" + 0.122*"credit" + '
#   '-0.119*"reflecting" + -0.117*"programme" + 0.110*"cost" + 0.099*"april"'),
#  (49,
#   '-0.219*"quarter" + 0.184*"past" + -0.129*"treaty" + -0.113*"rise" + '
#   '0.110*"stronger" + -0.107*"moderate" + 0.107*"labour" + 0.103*"service" + '
#   '-0.102*"decline" + -0.101*"taking"')]
# [(0,
#   '-0.193*"analysis" + -0.169*"financial" + -0.141*"loan" + -0.133*"recent" + '
#   '-0.128*"credit" + -0.124*"support" + -0.123*"pressure" + -0.123*"quarter" + '
#   '-0.121*"measure" + -0.120*"activity"'),
#  (1,
#   '-0.255*"loan" + -0.192*"measure" + 0.162*"first" + 0.157*"strong" + '
#   '0.151*"recent" + -0.140*"recovery" + 0.136*"wage" + 0.125*"would" + '
#   '-0.122*"nonfinancial" + -0.121*"analysis"'),
#  (2,
#   '0.204*"bank" + -0.195*"upside" + -0.179*"strong" + 0.174*"central" + '
#   '0.150*"national" + 0.147*"operation" + -0.146*"oil" + 0.138*"january" + '
#   '0.130*"first" + 0.127*"decision"'),
#  (3,
#   '0.228*"oil" + -0.217*"financial" + -0.214*"pressure" + 0.184*"projection" + '
#   '0.161*"recovery" + 0.161*"quarter" + 0.144*"purchase" + -0.144*"commodity" '
#   '+ 0.133*"implementation" + 0.124*"staff"'),
#  (4,
#   '0.272*"financial" + -0.204*"recovery" + 0.190*"credit" + -0.152*"positive" '
#   '+ 0.151*"money" + -0.149*"oil" + 0.133*"upside" + -0.129*"measure" + '
#   '0.128*"underlying" + -0.123*"low"'),
#  (5,
#   '0.189*"remains" + -0.158*"financial" + 0.149*"underlying" + -0.143*"effect" '
#   '+ -0.138*"recovery" + 0.123*"operation" + 0.122*"pressure" + 0.116*"ample" '
#   '+ 0.114*"liquidity" + -0.114*"negative"'),
#  (6,
#   '-0.404*"projection" + -0.288*"staff" + -0.181*"measure" + -0.173*"range" + '
#   '-0.171*"macroeconomic" + -0.153*"eurosystem" + -0.141*"operation" + '
#   '0.131*"subdued" + -0.117*"gdp" + 0.111*"demand"'),
#  (7,
#   '0.242*"projection" + 0.233*"recent" + -0.199*"credit" + 0.182*"pressure" + '
#   '-0.152*"bank" + 0.152*"staff" + 0.126*"inflationary" + -0.122*"money" + '
#   '0.115*"effect" + -0.112*"condition"'),
#  (8,
#   '-0.186*"subdued" + 0.184*"measure" + 0.174*"purchase" + -0.156*"activity" + '
#   '-0.143*"projection" + 0.126*"contribute" + 0.116*"firm" + 0.113*"supported" '
#   '+ 0.110*"recovery" + 0.106*"food"'),
#  (9,
#   '-0.282*"financial" + 0.243*"may" + -0.184*"measure" + -0.139*"environment" '
#   '+ -0.129*"tension" + 0.123*"april" + -0.122*"mediumterm" + -0.117*"october" '
#   '+ -0.115*"uncertainty" + 0.115*"march"'),
#  (10,
#   '0.226*"projection" + -0.217*"operation" + -0.147*"refinancing" + '
#   '-0.144*"period" + 0.141*"staff" + -0.135*"measure" + 0.127*"escb" + '
#   '-0.122*"decided" + 0.118*"analysis" + -0.117*"effect"'),
#  (11,
#   '-0.166*"activity" + 0.165*"moderate" + -0.132*"january" + 0.125*"wage" + '
#   '0.123*"gdp" + 0.122*"factor" + -0.121*"commodity" + -0.118*"accommodative" '
#   '+ -0.117*"demand" + -0.115*"looking"'),
#  (12,
#   '0.230*"financial" + -0.186*"effect" + 0.176*"volatility" + 0.157*"credit" + '
#   '-0.139*"bank" + -0.137*"first" + 0.132*"may" + 0.129*"recent" + '
#   '-0.121*"wage" + 0.107*"overall"'),
#  (13,
#   '-0.327*"december" + -0.327*"january" + 0.240*"june" + 0.182*"july" + '
#   '-0.171*"november" + 0.153*"recent" + 0.145*"may" + 0.124*"august" + '
#   '-0.122*"latest" + -0.107*"facility"'),
#  (14,
#   '-0.175*"recent" + 0.150*"period" + 0.137*"since" + 0.136*"still" + '
#   '0.134*"overall" + 0.133*"domestic" + 0.129*"september" + -0.126*"activity" '
#   '+ -0.122*"january" + -0.122*"however"'),
#  (15,
#   '0.242*"quarter" + -0.159*"march" + -0.143*"pillar" + -0.139*"macroeconomic" '
#   '+ -0.138*"key" + 0.127*"operation" + -0.122*"looking" + -0.120*"mediumterm" '
#   '+ 0.119*"july" + 0.114*"august"'),
#  (16,
#   '0.216*"march" + 0.177*"condition" + -0.165*"september" + 0.164*"financial" '
#   '+ 0.161*"pace" + -0.149*"expectation" + -0.146*"october" + 0.137*"recovery" '
#   '+ -0.126*"november" + -0.124*"oil"'),
#  (17,
#   '0.159*"operation" + 0.137*"low" + 0.131*"september" + -0.130*"need" + '
#   '-0.125*"quarter" + -0.120*"first" + -0.117*"higher" + 0.113*"asset" + '
#   '0.112*"remains" + -0.111*"consumer"'),
#  (18,
#   '-0.197*"bank" + -0.175*"may" + 0.158*"strategy" + 0.141*"january" + '
#   '-0.132*"june" + -0.129*"central" + -0.125*"information" + -0.122*"domestic" '
#   '+ -0.120*"european" + -0.120*"national"'),
#  (19,
#   '-0.173*"operation" + -0.151*"domestic" + 0.128*"gradual" + '
#   '0.122*"september" + 0.116*"bank" + -0.116*"march" + -0.110*"weak" + '
#   '0.109*"previous" + -0.108*"oil" + 0.107*"january"'),
#  (20,
#   '-0.168*"june" + 0.140*"activity" + -0.136*"would" + 0.130*"strategy" + '
#   '-0.125*"high" + 0.112*"reference" + -0.111*"july" + -0.109*"remains" + '
#   '0.107*"value" + 0.107*"october"'),
#  (21,
#   '0.240*"activity" + -0.177*"january" + -0.150*"first" + 0.150*"eurosystem" + '
#   '0.148*"higher" + -0.132*"quarter" + 0.132*"bank" + -0.125*"basis" + '
#   '0.120*"would" + -0.115*"money"'),
#  (22,
#   '0.151*"banknote" + 0.146*"oil" + 0.142*"information" + 0.140*"particular" + '
#   '-0.140*"basis" + 0.138*"money" + -0.131*"quarter" + 0.129*"recent" + '
#   '-0.119*"point" + -0.118*"balance"'),
#  (23,
#   '-0.183*"february" + 0.178*"shortterm" + 0.145*"support" + -0.143*"exchange" '
#   '+ 0.126*"impact" + 0.123*"money" + 0.110*"overall" + 0.108*"operation" + '
#   '0.106*"value" + -0.100*"intensification"'),
#  (24,
#   '-0.140*"overall" + -0.131*"upward" + -0.123*"december" + -0.121*"remains" + '
#   '-0.116*"likely" + 0.106*"would" + 0.105*"underlying" + 0.104*"september" + '
#   '-0.104*"activity" + 0.102*"first"'),
#  (25,
#   '-0.172*"regard" + 0.166*"activity" + 0.139*"recent" + -0.138*"previous" + '
#   '-0.138*"underlying" + -0.137*"quarter" + 0.129*"impact" + -0.124*"trend" + '
#   '0.108*"would" + 0.107*"first"'),
#  (26,
#   '0.174*"first" + 0.125*"recovery" + -0.121*"past" + 0.119*"may" + '
#   '0.119*"oil" + -0.114*"ensure" + 0.112*"continues" + 0.111*"mediumterm" + '
#   '0.109*"expansion" + -0.103*"analysis"'),
#  (27,
#   '0.325*"oil" + -0.160*"regard" + -0.158*"day" + -0.149*"banknote" + '
#   '0.145*"strong" + 0.132*"exchange" + -0.121*"analysis" + -0.119*"new" + '
#   '-0.119*"european" + -0.117*"evidence"'),
#  (28,
#   '-0.154*"ongoing" + 0.138*"factor" + 0.131*"quarter" + 0.130*"recent" + '
#   '-0.125*"pressure" + -0.119*"upward" + 0.114*"well" + -0.112*"eurosystem" + '
#   '-0.111*"european" + 0.109*"may"'),
#  (29,
#   '-0.173*"decision" + -0.163*"pressure" + -0.160*"point" + -0.139*"basis" + '
#   '-0.134*"may" + 0.132*"recent" + 0.131*"available" + -0.117*"would" + '
#   '0.117*"period" + 0.114*"become"'),
#  (30,
#   '-0.167*"well" + 0.137*"macroeconomic" + -0.130*"external" + '
#   '-0.123*"forecast" + -0.122*"first" + 0.121*"however" + -0.112*"important" + '
#   '-0.112*"line" + -0.110*"exchange" + -0.109*"measure"'),
#  (31,
#   '0.230*"decision" + 0.142*"february" + -0.140*"remains" + -0.139*"quarter" + '
#   '-0.138*"november" + -0.132*"continued" + 0.119*"particular" + 0.119*"trend" '
#   '+ 0.114*"august" + -0.113*"line"'),
#  (32,
#   '0.189*"first" + -0.148*"information" + 0.135*"recent" + 0.135*"new" + '
#   '-0.128*"oil" + 0.120*"target" + 0.118*"domestic" + -0.109*"account" + '
#   '-0.106*"march" + 0.101*"remained"'),
#  (33,
#   '0.222*"continued" + 0.164*"june" + 0.156*"july" + -0.153*"march" + '
#   '0.144*"activity" + -0.139*"remains" + 0.127*"expansion" + -0.121*"first" + '
#   '0.112*"low" + -0.109*"oil"'),
#  (34,
#   '-0.256*"recent" + -0.149*"particularly" + 0.146*"activity" + '
#   '0.137*"support" + 0.127*"basis" + 0.124*"first" + 0.117*"pressure" + '
#   '-0.114*"government" + 0.112*"need" + -0.111*"deposit"'),
#  (35,
#   '0.180*"quarter" + 0.161*"wage" + 0.148*"data" + -0.147*"oil" + '
#   '0.141*"demand" + -0.140*"strong" + 0.124*"activity" + 0.121*"taking" + '
#   '0.120*"impact" + 0.118*"july"'),
#  (36,
#   '-0.175*"remains" + -0.171*"quarter" + -0.142*"recent" + 0.141*"particular" '
#   '+ 0.130*"may" + 0.126*"therefore" + -0.118*"shortterm" + -0.117*"past" + '
#   '-0.108*"process" + 0.106*"confidence"'),
#  (37,
#   '-0.179*"support" + 0.174*"first" + 0.171*"particular" + 0.167*"would" + '
#   '0.113*"information" + 0.112*"analysis" + -0.109*"february" + 0.109*"latest" '
#   '+ -0.102*"recovery" + -0.099*"regard"'),
#  (38,
#   '-0.210*"support" + 0.136*"demand" + -0.129*"particular" + 0.126*"rise" + '
#   '0.122*"domestic" + -0.119*"eurosystem" + -0.117*"period" + -0.106*"recent" '
#   '+ 0.104*"banknote" + 0.101*"confirm"'),
#  (39,
#   '-0.159*"available" + 0.143*"new" + -0.139*"december" + -0.127*"line" + '
#   '-0.119*"information" + -0.119*"oil" + -0.106*"june" + -0.105*"factor" + '
#   '0.104*"september" + 0.102*"union"'),
#  (40,
#   '0.158*"mainly" + -0.137*"impact" + 0.131*"uncertainty" + -0.122*"strong" + '
#   '-0.121*"firm" + 0.114*"energy" + 0.111*"previous" + 0.108*"important" + '
#   '-0.107*"number" + -0.099*"decline"'),
#  (41,
#   '-0.154*"potential" + 0.134*"may" + 0.133*"effect" + 0.119*"ahead" + '
#   '0.119*"remains" + -0.115*"overall" + 0.113*"strong" + 0.110*"subdued" + '
#   '-0.107*"global" + -0.107*"well"'),
#  (42,
#   '0.164*"ensure" + 0.160*"moderate" + 0.136*"unchanged" + 0.131*"october" + '
#   '-0.111*"lower" + -0.109*"loan" + -0.107*"looking" + -0.101*"therefore" + '
#   '-0.099*"member" + 0.099*"credit"'),
#  (43,
#   '-0.210*"would" + -0.150*"july" + -0.147*"consolidation" + 0.145*"april" + '
#   '0.125*"october" + 0.123*"mediumterm" + -0.119*"could" + 0.118*"november" + '
#   '-0.113*"august" + -0.113*"impact"'),
#  (44,
#   '0.200*"march" + -0.158*"available" + 0.150*"overall" + -0.133*"remains" + '
#   '-0.129*"december" + 0.129*"money" + 0.119*"still" + -0.116*"june" + '
#   '-0.112*"regard" + 0.110*"labour"'),
#  (45,
#   '0.258*"continued" + -0.143*"regard" + -0.121*"june" + 0.119*"range" + '
#   '-0.116*"looking" + 0.103*"course" + 0.102*"gradual" + 0.098*"day" + '
#   '0.098*"energy" + 0.096*"thus"'),
#  (46,
#   '0.139*"information" + 0.137*"pressure" + 0.135*"purchase" + -0.133*"may" + '
#   '-0.122*"impact" + -0.115*"condition" + -0.113*"value" + 0.106*"expansion" + '
#   '-0.098*"overall" + -0.096*"february"'),
#  (47,
#   '0.155*"overall" + -0.154*"continued" + 0.128*"january" + -0.118*"decline" + '
#   '0.114*"financial" + 0.114*"factor" + 0.114*"deficit" + -0.113*"bank" + '
#   '0.110*"finance" + -0.107*"would"'),
#  (48,
#   '-0.174*"would" + 0.161*"purchase" + 0.160*"particular" + '
#   '-0.155*"implementation" + 0.127*"global" + -0.120*"credit" + '
#   '0.118*"programme" + 0.118*"reflecting" + -0.111*"cost" + -0.101*"april"'),
#  (49,
#   '-0.221*"quarter" + 0.184*"past" + -0.130*"treaty" + -0.113*"rise" + '
#   '0.111*"stronger" + -0.110*"moderate" + 0.105*"labour" + -0.103*"decline" + '
#   '0.102*"service" + -0.100*"taking"'),
#  (50,
#   '0.148*"line" + 0.147*"unchanged" + 0.137*"august" + 0.124*"since" + '
#   '0.124*"activity" + -0.123*"november" + -0.121*"recent" + -0.113*"recovery" '
#   '+ 0.108*"value" + -0.105*"future"'),
#  (51,
#   '-0.148*"remains" + 0.146*"strong" + 0.132*"recent" + -0.128*"second" + '
#   '-0.127*"effect" + 0.123*"expansion" + -0.120*"positive" + -0.119*"purchase" '
#   '+ -0.109*"activity" + -0.103*"additional"'),
#  (52,
#   '-0.164*"expectation" + 0.145*"october" + -0.133*"august" + '
#   '-0.127*"december" + 0.122*"february" + -0.110*"first" + 0.107*"factor" + '
#   '-0.100*"activity" + 0.097*"forecast" + -0.096*"decline"'),
#  (53,
#   '0.174*"impact" + 0.128*"available" + -0.117*"wage" + 0.116*"programme" + '
#   '0.108*"would" + -0.102*"money" + 0.102*"high" + -0.100*"line" + '
#   '0.097*"following" + -0.097*"longer"'),
#  (54,
#   '0.207*"particular" + 0.148*"moderate" + 0.147*"activity" + '
#   '-0.137*"available" + -0.121*"looking" + 0.114*"take" + -0.112*"confidence" '
#   '+ -0.111*"credit" + -0.110*"particularly" + 0.108*"quarter"'),
#  (55,
#   '-0.119*"significantly" + -0.116*"second" + 0.106*"december" + '
#   '0.106*"member" + 0.106*"ongoing" + 0.105*"upward" + -0.101*"two" + '
#   '0.100*"earlier" + -0.097*"remains" + 0.096*"state"'),
#  (56,
#   '0.155*"gradual" + 0.128*"purchase" + -0.122*"ahead" + -0.121*"contribute" + '
#   '-0.121*"recovery" + 0.119*"mediumterm" + -0.113*"overall" + -0.109*"global" '
#   '+ 0.108*"pressure" + 0.105*"projected"'),
#  (57,
#   '-0.158*"data" + 0.133*"consistent" + -0.124*"last" + 0.122*"environment" + '
#   '0.120*"financial" + 0.111*"range" + -0.111*"let" + 0.109*"pact" + '
#   '0.104*"trend" + 0.101*"international"'),
#  (58,
#   '0.126*"high" + 0.113*"still" + 0.111*"need" + -0.108*"remains" + '
#   '-0.106*"point" + 0.101*"confidence" + 0.098*"decline" + -0.096*"owing" + '
#   '-0.093*"basis" + 0.091*"movement"'),
#  (59,
#   '0.159*"remains" + -0.136*"particular" + 0.133*"information" + -0.131*"rise" '
#   '+ -0.129*"factor" + -0.112*"looking" + 0.109*"well" + -0.106*"prospect" + '
#   '0.105*"june" + -0.104*"effect"'),
#  (60,
#   '-0.151*"data" + 0.147*"march" + -0.141*"may" + -0.136*"progress" + '
#   '-0.132*"well" + 0.115*"measure" + -0.109*"need" + -0.105*"commodity" + '
#   '-0.103*"september" + 0.101*"consumer"'),
#  (61,
#   '0.174*"september" + -0.134*"november" + -0.118*"ongoing" + -0.117*"may" + '
#   '0.114*"overall" + 0.113*"account" + -0.109*"improvement" + 0.103*"ahead" + '
#   '-0.102*"unemployment" + -0.097*"global"'),
#  (62,
#   '0.157*"measure" + -0.139*"data" + 0.130*"december" + -0.125*"consolidation" '
#   '+ -0.118*"last" + 0.117*"low" + -0.114*"june" + -0.104*"related" + '
#   '-0.103*"remained" + 0.103*"still"'),
#  (63,
#   '-0.154*"slightly" + -0.134*"march" + -0.130*"contribute" + -0.120*"deficit" '
#   '+ 0.120*"necessary" + 0.114*"january" + -0.105*"basis" + 0.101*"confirm" + '
#   '-0.100*"coming" + -0.100*"government"'),
#  (64,
#   '0.138*"consumer" + 0.125*"still" + 0.120*"broadly" + 0.114*"remained" + '
#   '-0.104*"energy" + -0.099*"range" + 0.095*"december" + -0.095*"ensure" + '
#   '0.095*"activity" + 0.093*"imbalance"'),
#  (65,
#   '-0.193*"decline" + 0.161*"range" + 0.118*"quarter" + 0.108*"make" + '
#   '-0.104*"towards" + -0.102*"point" + 0.101*"likely" + -0.098*"labour" + '
#   '-0.096*"past" + 0.095*"slightly"'),
#  (66,
#   '0.141*"reflecting" + -0.137*"government" + -0.133*"broadly" + '
#   '0.130*"effect" + -0.121*"ongoing" + -0.121*"moderate" + -0.120*"activity" + '
#   '0.098*"high" + 0.098*"confidence" + -0.095*"subject"'),
#  (67,
#   '-0.146*"last" + 0.143*"unchanged" + -0.119*"environment" + '
#   '-0.115*"european" + 0.112*"since" + -0.108*"upside" + 0.103*"information" + '
#   '-0.100*"still" + -0.100*"could" + 0.098*"need"'),
#  (68,
#   '-0.137*"adjustment" + 0.126*"european" + 0.126*"treaty" + -0.125*"effect" + '
#   '0.114*"measure" + 0.111*"first" + -0.109*"balance" + 0.108*"taken" + '
#   '-0.108*"demand" + 0.106*"improvement"'),
#  (69,
#   '0.156*"second" + -0.131*"improvement" + -0.122*"line" + 0.121*"energy" + '
#   '-0.112*"thereby" + -0.112*"strong" + 0.109*"contribute" + 0.109*"april" + '
#   '-0.107*"new" + -0.105*"following"'),
#  (70,
#   '0.139*"uncertainty" + 0.118*"support" + -0.115*"range" + -0.115*"following" '
#   '+ -0.108*"macroeconomic" + 0.104*"could" + 0.098*"several" + '
#   '-0.094*"moreover" + -0.094*"expect" + -0.092*"supported"'),
#  (71,
#   '-0.137*"loan" + 0.132*"employment" + 0.121*"currently" + 0.114*"factor" + '
#   '0.110*"adjustment" + -0.100*"stance" + -0.099*"high" + -0.097*"taking" + '
#   '-0.096*"remains" + 0.092*"point"'),
#  (72,
#   '-0.147*"february" + 0.141*"april" + 0.132*"implementation" + '
#   '-0.120*"consumer" + -0.108*"labour" + -0.107*"point" + -0.099*"decline" + '
#   '0.098*"take" + 0.098*"downside" + -0.094*"low"'),
#  (73,
#   '0.137*"owing" + -0.134*"given" + 0.118*"support" + 0.117*"august" + '
#   '-0.115*"unchanged" + -0.115*"low" + 0.107*"condition" + -0.104*"recovery" + '
#   '0.103*"january" + 0.101*"upward"'),
#  (74,
#   '0.135*"demand" + -0.119*"october" + -0.119*"condition" + 0.117*"particular" '
#   '+ 0.110*"continued" + -0.110*"rise" + 0.109*"previous" + 0.103*"confidence" '
#   '+ -0.096*"impact" + -0.091*"analysis"'),
#  (75,
#   '0.131*"inflationary" + -0.125*"upward" + 0.103*"still" + -0.101*"past" + '
#   '0.100*"latest" + -0.099*"strong" + 0.097*"addition" + -0.094*"february" + '
#   '0.093*"support" + -0.092*"average"'),
#  (76,
#   '-0.136*"increased" + -0.127*"energy" + 0.127*"factor" + -0.116*"effect" + '
#   '0.113*"higher" + 0.107*"need" + -0.104*"exchange" + 0.103*"past" + '
#   '-0.102*"demand" + -0.100*"available"'),
#  (77,
#   '-0.165*"expansion" + 0.144*"energy" + -0.102*"available" + 0.097*"higher" + '
#   '-0.096*"new" + 0.090*"coming" + 0.089*"continued" + 0.084*"particular" + '
#   '0.083*"environment" + -0.083*"indicator"'),
#  (78,
#   '0.132*"measure" + -0.130*"somewhat" + -0.121*"range" + -0.120*"and" + '
#   '-0.114*"public" + 0.109*"august" + -0.103*"decision" + -0.102*"unchanged" + '
#   '0.101*"pillar" + 0.100*"thus"'),
#  (79,
#   '-0.125*"overall" + 0.115*"range" + 0.114*"february" + -0.108*"process" + '
#   '-0.107*"impact" + 0.107*"continued" + 0.106*"ensure" + 0.103*"basis" + '
#   '0.101*"situation" + -0.100*"course"'),
#  (80,
#   '-0.146*"decline" + 0.128*"available" + 0.119*"however" + -0.117*"european" '
#   '+ 0.116*"october" + 0.115*"context" + -0.113*"january" + -0.109*"important" '
#   '+ 0.109*"public" + -0.107*"credit"'),
#  (81,
#   '0.161*"overall" + -0.145*"service" + 0.143*"november" + -0.131*"account" + '
#   '-0.127*"new" + 0.106*"however" + 0.104*"compared" + 0.099*"owing" + '
#   '-0.095*"oil" + -0.095*"background"'),
#  (82,
#   '0.136*"and" + -0.124*"labour" + -0.124*"however" + 0.111*"essential" + '
#   '-0.108*"june" + 0.102*"longer" + -0.098*"regard" + 0.095*"service" + '
#   '0.093*"somewhat" + 0.090*"february"'),
#  (83,
#   '-0.123*"october" + 0.110*"indirect" + 0.108*"support" + -0.100*"labour" + '
#   '0.100*"would" + 0.096*"already" + 0.095*"broadly" + 0.089*"including" + '
#   '-0.088*"banknote" + -0.086*"analysis"'),
#  (84,
#   '-0.144*"range" + 0.143*"consistent" + -0.116*"still" + -0.116*"thereby" + '
#   '0.115*"general" + 0.113*"positive" + -0.106*"need" + -0.106*"supporting" + '
#   '-0.100*"july" + 0.098*"energy"'),
#  (85,
#   '-0.133*"public" + 0.129*"october" + 0.125*"ongoing" + -0.113*"particular" + '
#   '0.101*"appropriate" + -0.098*"reflects" + -0.094*"slightly" + '
#   '-0.093*"situation" + -0.092*"therefore" + 0.087*"tender"'),
#  (86,
#   '0.125*"positive" + 0.115*"mainly" + -0.113*"employment" + '
#   '-0.112*"continues" + 0.107*"february" + 0.099*"sustained" + '
#   '-0.094*"available" + -0.093*"average" + -0.092*"somewhat" + '
#   '-0.092*"december"'),
#  (87,
#   '0.112*"due" + -0.110*"short" + 0.108*"likely" + -0.107*"continued" + '
#   '-0.106*"budgetary" + 0.101*"first" + -0.098*"range" + -0.091*"particular" + '
#   '0.088*"investment" + 0.088*"account"'),
#  (88,
#   '0.188*"april" + 0.146*"wage" + 0.131*"longterm" + -0.111*"owing" + '
#   '-0.110*"credit" + 0.109*"uncertainty" + -0.104*"broadly" + '
#   '0.096*"according" + 0.094*"general" + -0.090*"still"'),
#  (89,
#   '0.120*"cost" + -0.110*"may" + -0.107*"shortterm" + 0.106*"half" + '
#   '-0.102*"objective" + 0.100*"treaty" + 0.097*"eu" + -0.096*"press" + '
#   '0.092*"plan" + 0.091*"would"'),
#  (90,
#   '-0.147*"improvement" + 0.123*"need" + 0.116*"available" + '
#   '0.110*"strengthening" + -0.106*"recently" + -0.105*"regard" + '
#   '-0.103*"remained" + 0.103*"essential" + 0.098*"number" + '
#   '-0.097*"employment"'),
#  (91,
#   '0.111*"stronger" + -0.110*"forecast" + -0.108*"september" + '
#   '-0.099*"liquidity" + 0.099*"place" + 0.097*"coming" + 0.093*"following" + '
#   '-0.093*"banknote" + -0.092*"rise" + -0.091*"member"'),
#  (92,
#   '-0.154*"july" + 0.138*"range" + 0.125*"overall" + -0.116*"opportunity" + '
#   '0.116*"treaty" + 0.115*"past" + 0.111*"september" + 0.105*"high" + '
#   '-0.100*"indicator" + 0.098*"well"'),
#  (93,
#   '0.111*"likely" + 0.109*"labour" + 0.108*"compared" + 0.100*"reflecting" + '
#   '0.092*"stance" + -0.090*"lower" + 0.087*"favourable" + -0.087*"february" + '
#   '-0.081*"remains" + 0.081*"base"'),
#  (94,
#   '0.121*"october" + 0.113*"significantly" + 0.112*"ahead" + -0.109*"global" + '
#   '-0.099*"strong" + 0.099*"government" + -0.098*"reflecting" + -0.096*"april" '
#   '+ -0.095*"revised" + 0.094*"currently"'),
#  (95,
#   '0.131*"factor" + 0.118*"welcome" + -0.104*"gradually" + -0.100*"given" + '
#   '-0.098*"low" + 0.096*"use" + 0.095*"strengthening" + 0.093*"evidence" + '
#   '-0.092*"oil" + 0.088*"macroeconomic"'),
#  (96,
#   '-0.151*"increased" + 0.126*"continued" + -0.121*"given" + -0.106*"credit" + '
#   '-0.102*"consumer" + 0.102*"energy" + 0.097*"mediumterm" + '
#   '-0.094*"uncertainty" + 0.089*"pace" + 0.087*"strengthening"'),
#  (97,
#   '-0.107*"survey" + 0.103*"ongoing" + 0.102*"crucial" + -0.099*"trend" + '
#   '-0.099*"even" + 0.097*"energy" + 0.095*"sign" + -0.094*"august" + '
#   '-0.093*"already" + -0.089*"programme"'),
#  (98,
#   '0.119*"like" + -0.118*"deficit" + 0.107*"view" + -0.102*"service" + '
#   '0.088*"ahead" + 0.086*"one" + -0.085*"upward" + -0.084*"future" + '
#   '0.081*"enhance" + 0.080*"range"'),
#  (99,
#   '0.122*"future" + 0.109*"improvement" + 0.105*"government" + 0.105*"may" + '
#   '-0.104*"point" + 0.102*"fully" + 0.098*"framework" + 0.094*"survey" + '
#   '-0.092*"implementation" + -0.089*"condition"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lsi5 = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi5 = coherence_model_lsi5.get_coherence()
print('\nCoherence Score5: ', coherence_lsi5)

# Compute Coherence Score
coherence_model_lsi10 = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi10 = coherence_model_lsi10.get_coherence()
print('\nCoherence Score10: ', coherence_lsi10)

# Compute Coherence Score
coherence_model_lsi20 = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi20 = coherence_model_lsi20.get_coherence()
print('\nCoherence Score20: ', coherence_lsi20)

# Compute Coherence Score
coherence_model_lsi50 = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi50 = coherence_model_lsi50.get_coherence()
print('\nCoherence Score50: ', coherence_lsi50)

# Compute Coherence Score
coherence_model_lsi100 = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi100 = coherence_model_lsi100.get_coherence()
print('\nCoherence Score100: ', coherence_lsi100)


# Compute Coherence Score
coherence_model_lsi5 = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi5 = coherence_model_lsi5.get_coherence()
print('\nCoherence Score5: ', coherence_lsi5)

# Compute Coherence Score
coherence_model_lsi10 = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi10 = coherence_model_lsi10.get_coherence()
print('\nCoherence Score10: ', coherence_lsi10)

# Compute Coherence Score
coherence_model_lsi20 = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi20 = coherence_model_lsi20.get_coherence()
print('\nCoherence Score20: ', coherence_lsi20)

# Compute Coherence Score
coherence_model_lsi50 = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi50 = coherence_model_lsi50.get_coherence()
print('\nCoherence Score50: ', coherence_lsi50)

# Compute Coherence Score
coherence_model_lsi100 = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi100 = coherence_model_lsi100.get_coherence()
print('\nCoherence Score100: ', coherence_lsi100)
# Out:
# Coherence Score5:  0.42682540713313327
#
# Coherence Score10:  0.3808948089504834
#
# Coherence Score20:  0.3056806081216009
#
# Coherence Score50:  0.2649981379103551
#
# Coherence Score100:  0.22734486420751004
#
# Coherence Score5:  -0.4580836133795101
#
# Coherence Score10:  -0.5540768993358647
#
# Coherence Score20:  -0.6162619389403085
#
# Coherence Score50:  -0.982782699586782
#
# Coherence Score100:  -0.8700090458458614
