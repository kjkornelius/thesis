# %%
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['qa']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(8371 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# less than 10 documents,
id2word = corpora.Dictionary(data)
id2word.filter_extremes(no_below = 10)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.163*"programme" + 0.150*"actually" + 0.134*"condition" + 0.123*"bond" + '
#   '0.110*"money" + 0.095*"recovery" + 0.093*"several" + 0.092*"lower" + '
#   '0.092*"don" + 0.092*"action"')]
# [(0,
#   '0.163*"programme" + 0.150*"actually" + 0.134*"condition" + 0.123*"bond" + '
#   '0.110*"money" + 0.095*"recovery" + 0.093*"several" + 0.092*"lower" + '
#   '0.092*"don" + 0.092*"action"'),
#  (1,
#   '-0.243*"actually" + 0.173*"deliver" + -0.163*"programme" + '
#   '-0.151*"condition" + 0.133*"currency" + -0.131*"basically" + -0.130*"thats" '
#   '+ -0.120*"sense" + -0.118*"bond" + 0.114*"observed"'),
#  (2,
#   '-0.336*"programme" + -0.260*"operation" + -0.251*"greece" + -0.214*"bond" + '
#   '-0.212*"greek" + -0.186*"nonstandard" + -0.177*"billion" + '
#   '-0.150*"collateral" + -0.109*"functioning" + 0.103*"data"'),
#  (3,
#   '-0.314*"programme" + 0.267*"money" + -0.257*"thats" + 0.181*"operation" + '
#   '-0.162*"condition" + -0.158*"greece" + -0.152*"weve" + -0.130*"recovery" + '
#   '0.129*"balance" + 0.128*"don"'),
#  (4,
#   '-0.221*"thats" + -0.169*"weve" + -0.160*"negative" + -0.147*"purchase" + '
#   '0.146*"treaty" + -0.136*"lower" + -0.132*"loan" + 0.118*"greece" + '
#   '0.118*"week" + -0.112*"lending"')]
# [(0,
#   '0.163*"programme" + 0.150*"actually" + 0.134*"condition" + 0.123*"bond" + '
#   '0.110*"money" + 0.095*"recovery" + 0.093*"several" + 0.092*"lower" + '
#   '0.092*"don" + 0.092*"action"'),
#  (1,
#   '0.243*"actually" + -0.173*"deliver" + 0.162*"programme" + 0.151*"condition" '
#   '+ -0.133*"currency" + 0.131*"basically" + 0.130*"thats" + 0.120*"sense" + '
#   '0.118*"bond" + -0.114*"observed"'),
#  (2,
#   '-0.336*"programme" + -0.260*"operation" + -0.251*"greece" + -0.214*"bond" + '
#   '-0.212*"greek" + -0.186*"nonstandard" + -0.177*"billion" + '
#   '-0.150*"collateral" + -0.109*"functioning" + 0.103*"data"'),
#  (3,
#   '0.314*"programme" + -0.267*"money" + 0.256*"thats" + -0.181*"operation" + '
#   '0.162*"condition" + 0.159*"greece" + 0.152*"weve" + 0.129*"recovery" + '
#   '-0.129*"don" + -0.129*"balance"'),
#  (4,
#   '-0.221*"thats" + -0.168*"weve" + -0.160*"negative" + -0.147*"purchase" + '
#   '0.145*"treaty" + -0.136*"lower" + -0.132*"loan" + 0.119*"week" + '
#   '0.118*"greece" + -0.112*"lending"'),
#  (5,
#   '0.227*"money" + 0.224*"operation" + -0.164*"deliver" + -0.143*"programme" + '
#   '0.131*"forecast" + 0.118*"week" + 0.118*"billion" + 0.111*"conclusion" + '
#   '0.111*"negative" + -0.105*"crisis"'),
#  (6,
#   '0.265*"greek" + -0.254*"nonstandard" + 0.227*"greece" + 0.223*"bond" + '
#   '0.158*"collateral" + 0.155*"ela" + -0.150*"recovery" + -0.144*"help" + '
#   '0.120*"condition" + 0.115*"capital"'),
#  (7,
#   '0.248*"greece" + -0.216*"balance" + 0.204*"forward" + -0.203*"bond" + '
#   '0.172*"guidance" + -0.163*"condition" + -0.157*"sheet" + 0.124*"recovery" + '
#   '-0.115*"don" + -0.113*"creation"'),
#  (8,
#   '-0.228*"programme" + 0.224*"negative" + -0.223*"ab" + 0.217*"condition" + '
#   '-0.177*"we" + -0.170*"ve" + 0.149*"objective" + 0.138*"funding" + '
#   '0.138*"financing" + -0.131*"qe"'),
#  (9,
#   '-0.213*"guidance" + -0.190*"forward" + 0.169*"quarter" + 0.168*"labour" + '
#   '-0.162*"asset" + -0.148*"currency" + 0.119*"crisis" + 0.117*"unemployment" '
#   '+ -0.111*"environment" + -0.109*"bond"')]
# [(0,
#   '0.163*"programme" + 0.150*"actually" + 0.134*"condition" + 0.123*"bond" + '
#   '0.110*"money" + 0.095*"recovery" + 0.093*"several" + 0.092*"lower" + '
#   '0.092*"don" + 0.092*"action"'),
#  (1,
#   '-0.243*"actually" + 0.173*"deliver" + -0.162*"programme" + '
#   '-0.151*"condition" + 0.133*"currency" + -0.131*"basically" + -0.130*"thats" '
#   '+ -0.120*"sense" + -0.118*"bond" + 0.114*"observed"'),
#  (2,
#   '0.336*"programme" + 0.260*"operation" + 0.251*"greece" + 0.214*"bond" + '
#   '0.212*"greek" + 0.186*"nonstandard" + 0.177*"billion" + 0.150*"collateral" '
#   '+ 0.109*"functioning" + -0.103*"data"'),
#  (3,
#   '-0.314*"programme" + 0.267*"money" + -0.256*"thats" + 0.181*"operation" + '
#   '-0.162*"condition" + -0.158*"greece" + -0.152*"weve" + -0.130*"recovery" + '
#   '0.129*"balance" + 0.128*"don"'),
#  (4,
#   '-0.221*"thats" + -0.169*"weve" + -0.160*"negative" + -0.147*"purchase" + '
#   '0.146*"treaty" + -0.136*"lower" + -0.132*"loan" + 0.118*"week" + '
#   '0.118*"greece" + -0.112*"lending"'),
#  (5,
#   '-0.228*"money" + -0.224*"operation" + 0.163*"deliver" + 0.144*"programme" + '
#   '-0.128*"forecast" + -0.119*"week" + -0.118*"billion" + -0.111*"conclusion" '
#   '+ -0.110*"negative" + 0.105*"crisis"'),
#  (6,
#   '0.265*"greek" + -0.254*"nonstandard" + 0.227*"greece" + 0.223*"bond" + '
#   '0.159*"collateral" + 0.154*"ela" + -0.150*"recovery" + -0.144*"help" + '
#   '0.119*"condition" + 0.114*"capital"'),
#  (7,
#   '-0.248*"greece" + 0.215*"balance" + -0.204*"forward" + 0.203*"bond" + '
#   '-0.173*"guidance" + 0.163*"condition" + 0.156*"sheet" + -0.125*"recovery" + '
#   '0.115*"don" + 0.113*"creation"'),
#  (8,
#   '-0.228*"programme" + 0.225*"negative" + -0.223*"ab" + 0.218*"condition" + '
#   '-0.178*"we" + -0.171*"ve" + 0.149*"objective" + 0.138*"funding" + '
#   '0.134*"financing" + -0.131*"qe"'),
#  (9,
#   '0.213*"guidance" + 0.190*"forward" + -0.170*"quarter" + -0.168*"labour" + '
#   '0.162*"asset" + 0.148*"currency" + -0.120*"crisis" + -0.118*"unemployment" '
#   '+ 0.111*"environment" + 0.109*"favourable"'),
#  (10,
#   '0.209*"deliver" + -0.195*"recovery" + 0.181*"objective" + -0.180*"data" + '
#   '0.148*"secondround" + -0.146*"balance" + -0.134*"pact" + -0.118*"negative" '
#   '+ 0.105*"money" + -0.100*"positive"'),
#  (11,
#   '-0.315*"money" + 0.227*"nonstandard" + -0.199*"recovery" + 0.195*"staff" + '
#   '0.143*"eurosystem" + -0.138*"instrument" + 0.137*"billion" + '
#   '-0.131*"crisis" + -0.122*"currency" + 0.120*"assumption"'),
#  (12,
#   '-0.212*"programme" + 0.188*"balance" + 0.188*"instrument" + '
#   '0.172*"recovery" + -0.137*"loan" + 0.124*"uncertainty" + 0.124*"staff" + '
#   '0.120*"collateral" + 0.120*"nonstandard" + -0.118*"bond"'),
#  (13,
#   '-0.170*"pact" + -0.161*"collateral" + 0.156*"operation" + '
#   '-0.156*"framework" + 0.151*"scenario" + 0.141*"uncertainty" + 0.140*"test" '
#   '+ 0.133*"stress" + -0.128*"ab" + 0.124*"actually"'),
#  (14,
#   '0.172*"recovery" + 0.149*"forward" + 0.146*"condition" + 0.141*"labour" + '
#   '-0.139*"committee" + -0.124*"ab" + -0.122*"within" + -0.116*"loan" + '
#   '-0.115*"sustainable" + -0.112*"concept"'),
#  (15,
#   '0.170*"programme" + -0.165*"capital" + -0.160*"currency" + -0.156*"billion" '
#   '+ -0.149*"ela" + 0.143*"recovery" + 0.139*"conditionality" + 0.135*"staff" '
#   '+ -0.129*"creation" + 0.127*"objective"'),
#  (16,
#   '0.258*"balance" + 0.251*"lending" + -0.189*"banking" + -0.163*"asset" + '
#   '-0.143*"we" + 0.139*"thats" + -0.138*"investment" + 0.121*"every" + '
#   '-0.120*"crisis" + -0.115*"negative"'),
#  (17,
#   '-0.236*"condition" + 0.221*"recovery" + 0.142*"thats" + 0.141*"demand" + '
#   '-0.127*"negative" + -0.116*"financing" + 0.111*"secondround" + '
#   '-0.110*"deliver" + 0.109*"functioning" + -0.105*"guidance"'),
#  (18,
#   '0.228*"actually" + 0.190*"operation" + -0.189*"balance" + -0.139*"bond" + '
#   '-0.125*"sheet" + -0.117*"lending" + -0.112*"scenario" + -0.112*"treaty" + '
#   '0.111*"guidance" + 0.106*"currency"'),
#  (19,
#   '0.194*"quarter" + 0.173*"lending" + -0.160*"balance" + 0.154*"bond" + '
#   '-0.132*"money" + -0.118*"nonstandard" + 0.117*"scenario" + '
#   '-0.105*"consensus" + -0.103*"sustainable" + 0.100*"instrument"')]
# [(0,
#   '-0.163*"programme" + -0.150*"actually" + -0.134*"condition" + -0.123*"bond" '
#   '+ -0.110*"money" + -0.095*"recovery" + -0.093*"several" + -0.092*"lower" + '
#   '-0.092*"don" + -0.092*"action"'),
#  (1,
#   '-0.243*"actually" + 0.173*"deliver" + -0.162*"programme" + '
#   '-0.151*"condition" + 0.133*"currency" + -0.131*"basically" + -0.130*"thats" '
#   '+ -0.120*"sense" + -0.118*"bond" + 0.114*"observed"'),
#  (2,
#   '0.336*"programme" + 0.260*"operation" + 0.251*"greece" + 0.214*"bond" + '
#   '0.212*"greek" + 0.186*"nonstandard" + 0.177*"billion" + 0.150*"collateral" '
#   '+ 0.109*"functioning" + -0.103*"data"'),
#  (3,
#   '-0.314*"programme" + 0.267*"money" + -0.257*"thats" + 0.181*"operation" + '
#   '-0.162*"condition" + -0.158*"greece" + -0.152*"weve" + -0.129*"recovery" + '
#   '0.129*"balance" + 0.128*"don"'),
#  (4,
#   '0.221*"thats" + 0.169*"weve" + 0.160*"negative" + 0.147*"purchase" + '
#   '-0.146*"treaty" + 0.136*"lower" + 0.132*"loan" + -0.118*"greece" + '
#   '-0.118*"week" + 0.111*"lending"'),
#  (5,
#   '-0.227*"money" + -0.224*"operation" + 0.164*"deliver" + 0.143*"programme" + '
#   '-0.130*"forecast" + -0.119*"week" + -0.118*"billion" + -0.111*"conclusion" '
#   '+ -0.110*"negative" + 0.105*"crisis"'),
#  (6,
#   '0.265*"greek" + -0.254*"nonstandard" + 0.227*"greece" + 0.223*"bond" + '
#   '0.159*"collateral" + 0.154*"ela" + -0.150*"recovery" + -0.144*"help" + '
#   '0.119*"condition" + 0.114*"capital"'),
#  (7,
#   '-0.248*"greece" + 0.216*"balance" + -0.204*"forward" + 0.202*"bond" + '
#   '-0.173*"guidance" + 0.163*"condition" + 0.156*"sheet" + -0.125*"recovery" + '
#   '0.115*"don" + 0.114*"creation"'),
#  (8,
#   '0.228*"programme" + -0.225*"negative" + 0.223*"ab" + -0.218*"condition" + '
#   '0.177*"we" + 0.170*"ve" + -0.149*"objective" + -0.138*"funding" + '
#   '-0.135*"financing" + 0.131*"qe"'),
#  (9,
#   '0.212*"guidance" + 0.190*"forward" + -0.169*"quarter" + -0.168*"labour" + '
#   '0.162*"asset" + 0.148*"currency" + -0.120*"crisis" + -0.118*"unemployment" '
#   '+ 0.109*"environment" + 0.108*"communication"'),
#  (10,
#   '0.208*"deliver" + -0.196*"recovery" + 0.180*"objective" + -0.179*"data" + '
#   '0.148*"secondround" + -0.147*"balance" + -0.132*"pact" + -0.117*"negative" '
#   '+ 0.105*"money" + -0.099*"positive"'),
#  (11,
#   '-0.314*"money" + 0.227*"nonstandard" + -0.200*"recovery" + 0.196*"staff" + '
#   '0.143*"eurosystem" + 0.139*"billion" + -0.138*"instrument" + '
#   '-0.133*"crisis" + -0.121*"currency" + 0.120*"assumption"'),
#  (12,
#   '-0.214*"programme" + 0.190*"balance" + 0.189*"instrument" + '
#   '0.170*"recovery" + -0.135*"loan" + 0.126*"staff" + 0.123*"collateral" + '
#   '0.122*"uncertainty" + 0.119*"nonstandard" + -0.116*"bond"'),
#  (13,
#   '0.169*"pact" + 0.160*"collateral" + 0.156*"framework" + -0.154*"operation" '
#   '+ -0.153*"scenario" + -0.143*"uncertainty" + -0.140*"test" + '
#   '-0.134*"stress" + 0.129*"ab" + -0.126*"actually"'),
#  (14,
#   '0.173*"recovery" + 0.151*"forward" + 0.147*"condition" + 0.141*"labour" + '
#   '-0.139*"committee" + -0.125*"ab" + -0.121*"within" + -0.116*"loan" + '
#   '-0.114*"sustainable" + -0.110*"concept"'),
#  (15,
#   '-0.170*"programme" + 0.164*"capital" + 0.160*"currency" + 0.156*"billion" + '
#   '0.150*"ela" + -0.141*"recovery" + -0.139*"conditionality" + -0.133*"staff" '
#   '+ -0.128*"objective" + 0.128*"creation"'),
#  (16,
#   '0.259*"balance" + 0.250*"lending" + -0.190*"banking" + -0.162*"asset" + '
#   '-0.144*"we" + 0.138*"thats" + -0.136*"investment" + 0.122*"every" + '
#   '-0.119*"crisis" + -0.116*"negative"'),
#  (17,
#   '-0.232*"condition" + 0.221*"recovery" + 0.142*"demand" + 0.138*"thats" + '
#   '-0.129*"negative" + 0.115*"functioning" + -0.114*"deliver" + '
#   '0.112*"secondround" + -0.112*"financing" + -0.109*"guidance"'),
#  (18,
#   '-0.227*"actually" + -0.191*"operation" + 0.187*"balance" + 0.138*"bond" + '
#   '0.126*"sheet" + 0.118*"treaty" + 0.115*"scenario" + 0.114*"lending" + '
#   '-0.110*"currency" + -0.107*"guidance"'),
#  (19,
#   '0.198*"quarter" + 0.172*"lending" + -0.160*"balance" + 0.153*"bond" + '
#   '-0.135*"money" + -0.119*"nonstandard" + 0.116*"scenario" + '
#   '-0.105*"consensus" + -0.103*"sustainable" + 0.103*"instrument"'),
#  (20,
#   '-0.258*"quarter" + -0.145*"greece" + -0.134*"negative" + 0.133*"currency" + '
#   '0.131*"single" + 0.130*"functioning" + 0.128*"scenario" + 0.121*"programme" '
#   '+ 0.121*"data" + 0.116*"condition"'),
#  (21,
#   '0.191*"staff" + 0.176*"labour" + 0.164*"operation" + 0.160*"instrument" + '
#   '-0.145*"lower" + 0.128*"competitiveness" + -0.112*"inflationary" + '
#   '0.109*"cost" + 0.109*"progress" + 0.108*"ab"'),
#  (22,
#   '-0.280*"instrument" + -0.162*"bond" + 0.131*"we" + -0.123*"germany" + '
#   '-0.117*"don" + 0.116*"ve" + 0.113*"condition" + -0.112*"framework" + '
#   '-0.111*"target" + -0.111*"labour"'),
#  (23,
#   '-0.152*"move" + 0.147*"currency" + -0.144*"fixed" + -0.133*"tender" + '
#   '-0.131*"bond" + -0.125*"banking" + 0.121*"functioning" + 0.115*"volatility" '
#   '+ -0.100*"observed" + 0.095*"president"'),
#  (24,
#   '0.174*"pact" + 0.153*"observed" + -0.126*"credible" + 0.124*"cost" + '
#   '-0.119*"took" + -0.115*"credibility" + 0.109*"vigilance" + 0.107*"quarter" '
#   '+ 0.106*"observation" + -0.105*"loan"'),
#  (25,
#   '-0.189*"treaty" + 0.132*"action" + -0.132*"labour" + 0.124*"don" + '
#   '-0.121*"eurosystem" + 0.119*"committee" + 0.119*"balance" + '
#   '-0.119*"consolidation" + -0.114*"lower" + 0.113*"capital"'),
#  (26,
#   '-0.253*"currency" + 0.134*"ab" + 0.122*"money" + 0.115*"recovery" + '
#   '0.115*"deliver" + 0.115*"president" + -0.110*"dynamic" + -0.109*"loan" + '
#   '0.109*"eurogroup" + -0.106*"instrument"'),
#  (27,
#   '-0.142*"thats" + -0.129*"actually" + 0.125*"operation" + 0.115*"ready" + '
#   '0.115*"phenomenon" + -0.111*"mediumterm" + -0.108*"trend" + '
#   '-0.107*"potential" + 0.106*"several" + -0.102*"benchmark"'),
#  (28,
#   '-0.117*"tender" + -0.115*"participant" + 0.114*"help" + 0.111*"observed" + '
#   '0.111*"every" + -0.110*"stress" + 0.103*"cost" + -0.101*"staff" + '
#   '-0.101*"remember" + 0.101*"scenario"'),
#  (29,
#   '0.190*"uncertainty" + 0.146*"currency" + -0.115*"move" + -0.109*"data" + '
#   '0.107*"citizen" + 0.106*"purchase" + -0.102*"week" + 0.100*"labour" + '
#   '-0.099*"positive" + 0.098*"greece"'),
#  (30,
#   '0.182*"note" + 0.166*"staff" + -0.160*"nonstandard" + -0.159*"objective" + '
#   '0.134*"plan" + 0.132*"mediumterm" + -0.115*"quarter" + 0.114*"deliver" + '
#   '0.107*"negative" + -0.104*"collateral"'),
#  (31,
#   '0.139*"scenario" + -0.132*"concept" + -0.115*"functioning" + '
#   '-0.114*"capital" + 0.113*"observed" + 0.108*"inflationary" + '
#   '-0.104*"conclusion" + 0.102*"sign" + -0.100*"bond" + -0.099*"channel"'),
#  (32,
#   '0.159*"banking" + -0.153*"vigilance" + -0.137*"lending" + '
#   '-0.136*"favourable" + -0.121*"scenario" + 0.118*"actually" + '
#   '-0.114*"inflationary" + 0.109*"treaty" + -0.108*"programme" + '
#   '0.107*"thats"'),
#  (33,
#   '0.195*"treaty" + 0.142*"programme" + 0.141*"single" + -0.132*"note" + '
#   '0.118*"credible" + -0.116*"security" + -0.113*"transmission" + '
#   '0.112*"decrease" + 0.105*"action" + 0.105*"recovery"'),
#  (34,
#   '0.180*"note" + 0.143*"action" + -0.141*"data" + -0.109*"billion" + '
#   '-0.107*"secondround" + -0.103*"supply" + 0.096*"pillar" + 0.095*"quarter" + '
#   '-0.094*"international" + -0.093*"partner"'),
#  (35,
#   '-0.150*"decide" + 0.137*"framework" + -0.131*"committee" + 0.129*"creation" '
#   '+ 0.113*"treaty" + -0.109*"data" + 0.105*"channel" + 0.102*"pillar" + '
#   '0.099*"lending" + 0.098*"agreement"'),
#  (36,
#   '0.186*"treaty" + -0.148*"volatility" + 0.141*"recovery" + 0.133*"note" + '
#   '-0.115*"balance" + 0.114*"fragmentation" + -0.103*"single" + -0.102*"curve" '
#   '+ 0.098*"nonstandard" + 0.098*"staff"'),
#  (37,
#   '0.168*"quarter" + -0.128*"nonstandard" + 0.127*"ab" + -0.116*"survey" + '
#   '-0.116*"took" + 0.112*"objective" + -0.107*"volatility" + -0.100*"loan" + '
#   '-0.098*"run" + 0.093*"able"'),
#  (38,
#   '-0.167*"move" + 0.124*"observed" + 0.117*"inflationary" + '
#   '0.108*"functioning" + 0.105*"credible" + -0.099*"recovery" + 0.099*"help" + '
#   '-0.097*"several" + -0.096*"dialogue" + 0.094*"deficit"'),
#  (39,
#   '0.153*"quarter" + 0.147*"actually" + 0.142*"staff" + 0.136*"money" + '
#   '-0.136*"unemployment" + 0.109*"currency" + 0.104*"colleague" + '
#   '0.098*"functioning" + 0.094*"explain" + -0.094*"deliver"'),
#  (40,
#   '0.226*"uncertainty" + -0.173*"secondround" + -0.113*"tender" + '
#   '-0.111*"survey" + 0.109*"credibility" + -0.100*"qe" + 0.100*"pact" + '
#   '-0.095*"intervention" + 0.089*"basically" + -0.083*"greece"'),
#  (41,
#   '-0.152*"single" + -0.136*"decide" + -0.133*"data" + -0.130*"instrument" + '
#   '0.126*"average" + 0.115*"committee" + 0.112*"deficit" + 0.106*"scenario" + '
#   '0.103*"ex" + -0.099*"imf"'),
#  (42,
#   '-0.120*"consensus" + 0.112*"banking" + 0.110*"programme" + 0.105*"currency" '
#   '+ -0.104*"however" + 0.104*"recovery" + -0.103*"remember" + '
#   '0.100*"nonstandard" + -0.098*"creation" + -0.096*"decide"'),
#  (43,
#   '-0.140*"deficit" + 0.109*"functioning" + -0.106*"sense" + 0.105*"creation" '
#   '+ 0.103*"essential" + -0.103*"esm" + 0.102*"greece" + -0.101*"extremely" + '
#   '-0.100*"pact" + -0.092*"due"'),
#  (44,
#   '0.127*"uncertainty" + -0.117*"progress" + -0.116*"used" + 0.115*"tender" + '
#   '0.109*"phenomenon" + 0.104*"condition" + -0.098*"concern" + '
#   '0.098*"objective" + 0.097*"staff" + -0.096*"sheet"'),
#  (45,
#   '-0.138*"matter" + -0.130*"tender" + 0.122*"investment" + '
#   '-0.115*"unemployment" + 0.100*"pillar" + -0.099*"president" + '
#   '0.096*"primary" + -0.093*"commitment" + -0.089*"yield" + '
#   '-0.088*"eurogroup"'),
#  (46,
#   '-0.143*"decrease" + 0.138*"upside" + -0.129*"changed" + -0.128*"deflation" '
#   '+ 0.114*"mediumterm" + 0.110*"basically" + -0.099*"run" + 0.097*"survey" + '
#   '0.095*"commitment" + 0.094*"methodology"'),
#  (47,
#   '0.151*"nonstandard" + 0.121*"cost" + -0.112*"achieved" + -0.109*"plan" + '
#   '-0.108*"expenditure" + 0.097*"reserve" + 0.097*"lack" + -0.093*"outlook" + '
#   '0.092*"correction" + 0.091*"actually"'),
#  (48,
#   '-0.203*"banking" + 0.129*"phenomenon" + -0.119*"took" + -0.114*"tightening" '
#   '+ -0.110*"staff" + 0.105*"demand" + 0.097*"sustainable" + 0.095*"creation" '
#   '+ 0.095*"benchmark" + 0.093*"big"'),
#  (49,
#   '0.147*"reserve" + 0.137*"intervention" + 0.127*"credible" + -0.127*"week" + '
#   '0.100*"spread" + -0.098*"crisis" + -0.095*"pillar" + -0.094*"adjustment" + '
#   '-0.093*"imf" + 0.093*"deliver"')]
# [(0,
#   '-0.163*"programme" + -0.150*"actually" + -0.134*"condition" + -0.123*"bond" '
#   '+ -0.110*"money" + -0.095*"recovery" + -0.093*"several" + -0.092*"lower" + '
#   '-0.092*"don" + -0.092*"action"'),
#  (1,
#   '-0.243*"actually" + 0.173*"deliver" + -0.162*"programme" + '
#   '-0.151*"condition" + 0.133*"currency" + -0.131*"basically" + -0.130*"thats" '
#   '+ -0.120*"sense" + -0.118*"bond" + 0.114*"observed"'),
#  (2,
#   '-0.336*"programme" + -0.260*"operation" + -0.251*"greece" + -0.214*"bond" + '
#   '-0.212*"greek" + -0.186*"nonstandard" + -0.177*"billion" + '
#   '-0.150*"collateral" + -0.109*"functioning" + 0.103*"data"'),
#  (3,
#   '-0.314*"programme" + 0.267*"money" + -0.257*"thats" + 0.181*"operation" + '
#   '-0.162*"condition" + -0.158*"greece" + -0.152*"weve" + -0.129*"recovery" + '
#   '0.129*"balance" + 0.128*"don"'),
#  (4,
#   '0.221*"thats" + 0.169*"weve" + 0.160*"negative" + 0.147*"purchase" + '
#   '-0.146*"treaty" + 0.136*"lower" + 0.132*"loan" + -0.118*"week" + '
#   '-0.118*"greece" + 0.111*"lending"'),
#  (5,
#   '0.227*"money" + 0.224*"operation" + -0.164*"deliver" + -0.143*"programme" + '
#   '0.130*"forecast" + 0.119*"week" + 0.118*"billion" + 0.111*"conclusion" + '
#   '0.110*"negative" + -0.105*"crisis"'),
#  (6,
#   '-0.265*"greek" + 0.254*"nonstandard" + -0.227*"greece" + -0.223*"bond" + '
#   '-0.159*"collateral" + -0.154*"ela" + 0.150*"recovery" + 0.144*"help" + '
#   '-0.119*"condition" + -0.114*"capital"'),
#  (7,
#   '-0.248*"greece" + 0.216*"balance" + -0.204*"forward" + 0.202*"bond" + '
#   '-0.173*"guidance" + 0.163*"condition" + 0.156*"sheet" + -0.125*"recovery" + '
#   '0.116*"don" + 0.114*"creation"'),
#  (8,
#   '-0.228*"programme" + 0.225*"negative" + -0.223*"ab" + 0.218*"condition" + '
#   '-0.177*"we" + -0.170*"ve" + 0.149*"objective" + 0.138*"funding" + '
#   '0.135*"financing" + -0.131*"qe"'),
#  (9,
#   '-0.213*"guidance" + -0.190*"forward" + 0.169*"quarter" + 0.168*"labour" + '
#   '-0.162*"asset" + -0.148*"currency" + 0.120*"crisis" + 0.117*"unemployment" '
#   '+ -0.110*"environment" + -0.108*"communication"'),
#  (10,
#   '-0.208*"deliver" + 0.196*"recovery" + -0.181*"objective" + 0.180*"data" + '
#   '-0.148*"secondround" + 0.146*"balance" + 0.132*"pact" + 0.117*"negative" + '
#   '-0.104*"money" + 0.099*"positive"'),
#  (11,
#   '-0.313*"money" + 0.227*"nonstandard" + -0.200*"recovery" + 0.196*"staff" + '
#   '0.142*"eurosystem" + 0.138*"billion" + -0.138*"instrument" + '
#   '-0.134*"crisis" + -0.121*"currency" + 0.120*"assumption"'),
#  (12,
#   '0.214*"programme" + -0.190*"balance" + -0.188*"instrument" + '
#   '-0.171*"recovery" + 0.135*"loan" + -0.126*"staff" + -0.123*"collateral" + '
#   '-0.122*"uncertainty" + -0.119*"nonstandard" + 0.117*"bond"'),
#  (13,
#   '0.170*"pact" + 0.160*"collateral" + 0.156*"framework" + -0.154*"operation" '
#   '+ -0.153*"scenario" + -0.142*"uncertainty" + -0.140*"test" + '
#   '-0.134*"stress" + 0.129*"ab" + -0.125*"actually"'),
#  (14,
#   '-0.173*"recovery" + -0.151*"forward" + -0.147*"condition" + -0.142*"labour" '
#   '+ 0.138*"committee" + 0.125*"ab" + 0.121*"within" + 0.116*"loan" + '
#   '0.114*"sustainable" + -0.110*"deliver"'),
#  (15,
#   '0.170*"programme" + -0.164*"capital" + -0.160*"currency" + -0.156*"billion" '
#   '+ -0.150*"ela" + 0.141*"recovery" + 0.139*"conditionality" + 0.133*"staff" '
#   '+ 0.128*"objective" + -0.128*"creation"'),
#  (16,
#   '-0.259*"balance" + -0.251*"lending" + 0.188*"banking" + 0.162*"asset" + '
#   '0.145*"we" + -0.138*"thats" + 0.136*"investment" + -0.122*"every" + '
#   '0.120*"crisis" + 0.116*"negative"'),
#  (17,
#   '0.233*"condition" + -0.220*"recovery" + -0.143*"demand" + -0.138*"thats" + '
#   '0.129*"negative" + -0.115*"functioning" + 0.115*"deliver" + '
#   '-0.112*"secondround" + 0.111*"financing" + 0.110*"guidance"'),
#  (18,
#   '-0.228*"actually" + -0.190*"operation" + 0.187*"balance" + 0.138*"bond" + '
#   '0.126*"sheet" + 0.118*"treaty" + 0.115*"lending" + 0.114*"scenario" + '
#   '-0.109*"currency" + -0.106*"guidance"'),
#  (19,
#   '-0.197*"quarter" + -0.172*"lending" + 0.160*"balance" + -0.153*"bond" + '
#   '0.134*"money" + 0.119*"nonstandard" + -0.116*"scenario" + 0.105*"consensus" '
#   '+ 0.103*"sustainable" + -0.103*"instrument"'),
#  (20,
#   '-0.258*"quarter" + -0.144*"greece" + 0.134*"currency" + -0.134*"negative" + '
#   '0.131*"single" + 0.130*"functioning" + 0.128*"scenario" + 0.121*"data" + '
#   '0.120*"programme" + 0.116*"condition"'),
#  (21,
#   '-0.191*"staff" + -0.176*"labour" + -0.164*"operation" + -0.161*"instrument" '
#   '+ 0.144*"lower" + -0.128*"competitiveness" + 0.113*"inflationary" + '
#   '-0.110*"cost" + -0.108*"progress" + -0.107*"ab"'),
#  (22,
#   '0.279*"instrument" + 0.162*"bond" + -0.132*"we" + 0.123*"germany" + '
#   '-0.117*"ve" + 0.117*"don" + -0.114*"condition" + 0.113*"framework" + '
#   '0.112*"target" + 0.111*"labour"'),
#  (23,
#   '0.153*"move" + -0.147*"currency" + 0.144*"fixed" + 0.134*"tender" + '
#   '0.130*"bond" + 0.125*"banking" + -0.121*"functioning" + -0.114*"volatility" '
#   '+ 0.102*"observed" + -0.095*"collateral"'),
#  (24,
#   '-0.173*"pact" + -0.153*"observed" + 0.128*"credible" + -0.123*"cost" + '
#   '0.119*"took" + 0.116*"credibility" + -0.109*"vigilance" + -0.107*"quarter" '
#   '+ -0.106*"observation" + 0.105*"loan"'),
#  (25,
#   '0.189*"treaty" + 0.132*"labour" + -0.130*"action" + -0.123*"don" + '
#   '0.121*"eurosystem" + -0.119*"committee" + -0.119*"balance" + '
#   '0.118*"consolidation" + -0.114*"capital" + 0.113*"lower"'),
#  (26,
#   '0.254*"currency" + -0.135*"ab" + -0.123*"money" + -0.117*"recovery" + '
#   '-0.114*"deliver" + -0.113*"president" + 0.111*"dynamic" + 0.109*"loan" + '
#   '-0.109*"eurogroup" + 0.105*"instrument"'),
#  (27,
#   '0.141*"thats" + 0.129*"actually" + -0.123*"operation" + -0.118*"phenomenon" '
#   '+ -0.116*"ready" + 0.112*"mediumterm" + 0.109*"trend" + 0.107*"potential" + '
#   '-0.107*"several" + 0.103*"benchmark"'),
#  (28,
#   '-0.117*"participant" + -0.116*"tender" + 0.113*"help" + 0.113*"observed" + '
#   '-0.109*"stress" + 0.108*"every" + 0.106*"cost" + -0.101*"remember" + '
#   '-0.098*"staff" + 0.098*"scenario"'),
#  (29,
#   '-0.181*"objective" + 0.178*"staff" + -0.150*"move" + -0.141*"quarter" + '
#   '0.129*"asset" + 0.129*"billion" + -0.125*"collateral" + 0.119*"uncertainty" '
#   '+ 0.118*"currency" + 0.113*"note"'),
#  (30,
#   '-0.151*"nonstandard" + 0.149*"mediumterm" + -0.148*"uncertainty" + '
#   '0.145*"note" + -0.122*"deposit" + 0.119*"week" + -0.117*"survey" + '
#   '-0.104*"citizen" + 0.103*"plan" + 0.102*"irish"'),
#  (31,
#   '-0.138*"scenario" + 0.130*"concept" + 0.115*"functioning" + 0.113*"capital" '
#   '+ -0.112*"observed" + -0.108*"inflationary" + 0.103*"conclusion" + '
#   '-0.102*"sign" + 0.099*"bond" + 0.098*"channel"'),
#  (32,
#   '0.157*"banking" + -0.153*"vigilance" + -0.136*"lending" + '
#   '-0.135*"favourable" + -0.122*"scenario" + 0.116*"actually" + '
#   '-0.115*"inflationary" + -0.108*"programme" + 0.107*"thats" + '
#   '0.105*"treaty"'),
#  (33,
#   '-0.195*"treaty" + -0.140*"programme" + -0.140*"single" + 0.125*"note" + '
#   '-0.119*"credible" + 0.116*"security" + -0.115*"decrease" + '
#   '0.114*"transmission" + -0.108*"action" + -0.105*"recovery"'),
#  (34,
#   '0.186*"note" + 0.143*"action" + -0.141*"data" + -0.108*"secondround" + '
#   '-0.106*"billion" + -0.101*"supply" + 0.098*"quarter" + 0.097*"pillar" + '
#   '-0.096*"partner" + -0.094*"international"'),
#  (35,
#   '-0.149*"decide" + 0.137*"framework" + -0.129*"committee" + 0.128*"creation" '
#   '+ 0.121*"treaty" + -0.111*"data" + 0.107*"channel" + 0.103*"pillar" + '
#   '0.101*"lending" + 0.096*"agreement"'),
#  (36,
#   '-0.180*"treaty" + 0.144*"volatility" + -0.139*"recovery" + -0.131*"note" + '
#   '-0.117*"fragmentation" + 0.114*"balance" + 0.106*"curve" + 0.100*"single" + '
#   '-0.100*"staff" + -0.099*"nonstandard"'),
#  (37,
#   '0.168*"quarter" + 0.127*"ab" + -0.127*"nonstandard" + -0.116*"took" + '
#   '-0.113*"survey" + 0.111*"objective" + -0.108*"volatility" + -0.100*"loan" + '
#   '-0.100*"run" + 0.094*"able"'),
#  (38,
#   '0.168*"move" + -0.126*"observed" + -0.120*"inflationary" + '
#   '-0.105*"functioning" + -0.103*"credible" + 0.099*"recovery" + -0.098*"help" '
#   '+ 0.098*"several" + 0.096*"dialogue" + -0.095*"deficit"'),
#  (39,
#   '0.156*"quarter" + 0.152*"actually" + 0.141*"staff" + 0.137*"money" + '
#   '-0.137*"unemployment" + 0.109*"currency" + 0.105*"colleague" + '
#   '0.101*"functioning" + -0.095*"deliver" + 0.092*"explain"'),
#  (40,
#   '-0.224*"uncertainty" + 0.174*"secondround" + 0.118*"tender" + '
#   '0.111*"survey" + -0.110*"credibility" + 0.101*"qe" + -0.097*"pact" + '
#   '0.094*"intervention" + -0.091*"basically" + 0.084*"greece"'),
#  (41,
#   '-0.153*"single" + -0.136*"decide" + -0.130*"data" + -0.129*"instrument" + '
#   '0.124*"average" + 0.114*"committee" + 0.113*"deficit" + 0.105*"scenario" + '
#   '0.103*"ex" + -0.101*"imf"'),
#  (42,
#   '0.117*"consensus" + -0.116*"banking" + -0.109*"programme" + 0.107*"however" '
#   '+ -0.103*"currency" + 0.102*"remember" + -0.100*"recovery" + '
#   '0.099*"creation" + -0.096*"nonstandard" + 0.093*"million"'),
#  (43,
#   '-0.143*"deficit" + 0.111*"functioning" + -0.106*"pact" + -0.104*"extremely" '
#   '+ -0.102*"sense" + 0.102*"greece" + 0.101*"essential" + -0.098*"tender" + '
#   '-0.098*"condition" + 0.098*"creation"'),
#  (44,
#   '0.134*"uncertainty" + -0.124*"progress" + 0.114*"phenomenon" + '
#   '-0.106*"used" + -0.103*"atlantic" + -0.102*"concern" + 0.098*"carefully" + '
#   '0.097*"staff" + 0.095*"tender" + 0.095*"condition"'),
#  (45,
#   '0.141*"tender" + 0.138*"matter" + -0.122*"investment" + '
#   '0.114*"unemployment" + -0.100*"pillar" + -0.099*"primary" + '
#   '0.093*"commitment" + 0.093*"president" + 0.091*"eurogroup" + 0.088*"yield"'),
#  (46,
#   '0.142*"decrease" + -0.135*"upside" + 0.130*"deflation" + 0.129*"changed" + '
#   '-0.115*"mediumterm" + -0.109*"basically" + 0.099*"run" + '
#   '-0.094*"commitment" + -0.094*"survey" + 0.093*"took"'),
#  (47,
#   '-0.153*"nonstandard" + -0.121*"cost" + 0.114*"plan" + 0.111*"achieved" + '
#   '0.110*"expenditure" + -0.098*"reserve" + -0.096*"actually" + -0.095*"lack" '
#   '+ -0.092*"correction" + 0.092*"esm"'),
#  (48,
#   '0.204*"banking" + -0.137*"phenomenon" + 0.118*"took" + 0.116*"staff" + '
#   '0.114*"tightening" + -0.104*"demand" + -0.099*"sustainable" + '
#   '-0.097*"benchmark" + -0.093*"proposal" + -0.092*"banknote"'),
#  (49,
#   '0.154*"reserve" + 0.140*"intervention" + 0.133*"credible" + -0.127*"week" + '
#   '-0.105*"adjustment" + 0.101*"spread" + -0.095*"crisis" + -0.091*"pillar" + '
#   '-0.089*"treaty" + 0.088*"bad"'),
#  (50,
#   '0.120*"functioning" + 0.115*"germany" + 0.114*"tender" + -0.112*"review" + '
#   '0.109*"demand" + -0.097*"secondround" + -0.097*"team" + 0.096*"credibility" '
#   '+ -0.094*"quarter" + 0.092*"collateral"'),
#  (51,
#   '-0.117*"banking" + -0.110*"concept" + 0.105*"imf" + 0.102*"investment" + '
#   '0.098*"functioning" + -0.096*"citizen" + 0.095*"action" + '
#   '0.094*"phenomenon" + -0.094*"supervision" + -0.093*"difference"'),
#  (52,
#   '0.133*"potential" + 0.119*"test" + 0.109*"germany" + -0.098*"upside" + '
#   '0.097*"competition" + 0.095*"draw" + 0.093*"commitment" + '
#   '0.091*"mediumterm" + -0.089*"international" + -0.088*"trust"'),
#  (53,
#   '-0.160*"note" + 0.131*"operation" + -0.129*"volatility" + -0.128*"don" + '
#   '0.102*"plan" + 0.099*"forecast" + 0.097*"sentiment" + -0.093*"capital" + '
#   '0.093*"million" + -0.092*"intervention"'),
#  (54,
#   '0.122*"stress" + 0.119*"conclusion" + -0.115*"trust" + 0.114*"test" + '
#   '0.106*"draw" + 0.106*"fragmentation" + -0.106*"action" + -0.104*"option" + '
#   '-0.099*"observing" + 0.099*"ab"'),
#  (55,
#   '-0.112*"observing" + -0.100*"debt" + 0.098*"ex" + 0.097*"settlement" + '
#   '0.095*"them" + -0.090*"phenomenon" + 0.089*"ante" + -0.089*"upside" + '
#   '-0.085*"opinion" + 0.084*"default"'),
#  (56,
#   '-0.144*"decide" + -0.110*"use" + -0.110*"tender" + -0.107*"investment" + '
#   '0.107*"dynamic" + -0.106*"sign" + -0.105*"fixed" + 0.101*"indicator" + '
#   '-0.099*"plan" + 0.092*"staff"'),
#  (57,
#   '0.118*"banknote" + -0.113*"default" + 0.106*"security" + -0.103*"action" + '
#   '0.099*"president" + -0.097*"uncertainty" + 0.095*"shock" + -0.089*"upside" '
#   '+ 0.087*"forecast" + -0.085*"positive"'),
#  (58,
#   '-0.141*"quarter" + -0.127*"condition" + 0.097*"yield" + 0.092*"opinion" + '
#   '-0.091*"forecast" + -0.091*"supervisor" + -0.091*"money" + 0.087*"able" + '
#   '0.085*"deficit" + 0.084*"review"'),
#  (59,
#   '-0.134*"lower" + 0.120*"intervention" + 0.114*"improvement" + '
#   '0.100*"amount" + 0.097*"assumption" + -0.096*"uncertainty" + '
#   '-0.095*"review" + -0.091*"operation" + 0.087*"fellow" + '
#   '-0.087*"especially"'),
#  (60,
#   '0.125*"functioning" + -0.122*"sense" + -0.109*"upside" + -0.106*"essential" '
#   '+ -0.101*"took" + -0.099*"favourable" + 0.095*"normal" + 0.094*"decide" + '
#   '0.092*"default" + -0.091*"irish"'),
#  (61,
#   '0.115*"mr" + -0.106*"germany" + -0.106*"eurogroup" + -0.105*"review" + '
#   '0.102*"shock" + -0.096*"upside" + 0.094*"supervision" + 0.092*"investment" '
#   '+ 0.091*"day" + 0.090*"supervisory"'),
#  (62,
#   '0.160*"objective" + 0.137*"loan" + -0.129*"remark" + 0.104*"germany" + '
#   '-0.104*"flow" + 0.101*"competitiveness" + 0.101*"capital" + 0.099*"survey" '
#   '+ 0.095*"december" + -0.092*"basically"'),
#  (63,
#   '0.101*"able" + -0.095*"fundamental" + -0.094*"inflationary" + '
#   '-0.092*"creation" + 0.089*"bond" + -0.088*"target" + -0.085*"used" + '
#   '-0.083*"conditionality" + -0.083*"sign" + 0.082*"become"'),
#  (64,
#   '-0.114*"considered" + 0.112*"extremely" + 0.110*"matter" + '
#   '0.109*"financing" + 0.099*"example" + -0.097*"difference" + 0.096*"hard" + '
#   '-0.095*"don" + -0.094*"fragmentation" + -0.089*"occasion"'),
#  (65,
#   '-0.138*"several" + -0.114*"cyprus" + 0.107*"action" + 0.099*"quarter" + '
#   '-0.098*"move" + -0.097*"negative" + -0.095*"occasion" + -0.091*"extremely" '
#   '+ 0.089*"conclusion" + -0.089*"every"'),
#  (66,
#   '-0.123*"uncertainty" + -0.120*"anchoring" + 0.115*"totally" + '
#   '-0.102*"sustainable" + 0.096*"progressively" + 0.096*"convincing" + '
#   '0.092*"deficit" + -0.091*"creation" + 0.090*"percentage" + -0.089*"week"'),
#  (67,
#   '-0.116*"standard" + 0.107*"political" + -0.104*"ab" + 0.103*"ensure" + '
#   '0.102*"able" + 0.101*"tender" + -0.093*"pact" + 0.093*"committee" + '
#   '-0.093*"potential" + -0.088*"favourable"'),
#  (68,
#   '0.150*"move" + -0.126*"assumption" + -0.111*"tax" + -0.111*"reserve" + '
#   '0.105*"facility" + 0.102*"mr" + 0.100*"security" + -0.099*"carefully" + '
#   '0.093*"report" + -0.093*"loan"'),
#  (69,
#   '0.117*"meet" + -0.110*"phenomenon" + 0.108*"march" + 0.107*"potential" + '
#   '-0.103*"bond" + 0.099*"reserve" + -0.096*"whatever" + -0.096*"indicator" + '
#   '-0.096*"spread" + -0.094*"lower"'),
#  (70,
#   '0.136*"purchase" + -0.108*"credible" + -0.093*"uncertainty" + -0.087*"qe" + '
#   '-0.086*"get" + -0.085*"service" + -0.084*"supply" + 0.084*"observing" + '
#   '0.083*"germany" + -0.081*"instrument"'),
#  (71,
#   '-0.129*"observed" + -0.119*"treaty" + 0.118*"option" + 0.112*"data" + '
#   '-0.105*"observing" + 0.098*"ltro" + -0.096*"funding" + -0.093*"flow" + '
#   '-0.091*"proposal" + 0.091*"march"'),
#  (72,
#   '0.148*"environment" + -0.123*"single" + -0.120*"debt" + 0.113*"president" + '
#   '0.108*"banking" + -0.103*"range" + -0.102*"agreement" + '
#   '0.095*"independence" + -0.094*"draw" + 0.094*"mediumterm"'),
#  (73,
#   '0.135*"day" + -0.109*"ltro" + 0.106*"sentiment" + 0.105*"opinion" + '
#   '-0.105*"eurogroup" + -0.103*"week" + 0.097*"parliament" + -0.092*"decide" + '
#   '-0.088*"environment" + -0.086*"sustainable"'),
#  (74,
#   '0.122*"credibility" + -0.118*"conclusion" + 0.116*"within" + '
#   '0.104*"intervention" + 0.095*"single" + 0.093*"finance" + -0.092*"around" + '
#   '0.091*"regarding" + 0.089*"review" + 0.088*"key"'),
#  (75,
#   '0.099*"everybody" + -0.092*"credible" + -0.090*"positive" + 0.088*"upside" '
#   '+ -0.087*"esm" + -0.085*"additional" + 0.083*"standard" + '
#   '-0.083*"improvement" + 0.081*"looking" + 0.078*"yield"'),
#  (76,
#   '-0.144*"imf" + -0.124*"conditionality" + -0.102*"functioning" + '
#   '-0.099*"intervention" + 0.098*"trend" + 0.098*"refinancing" + -0.090*"upon" '
#   '+ 0.089*"unanimous" + 0.086*"single" + -0.085*"emerging"'),
#  (77,
#   '0.114*"operation" + 0.112*"recovery" + -0.104*"uncertainty" + -0.087*"use" '
#   '+ 0.085*"upon" + 0.084*"opinion" + -0.084*"difficulty" + -0.083*"president" '
#   '+ -0.083*"international" + 0.083*"draw"'),
#  (78,
#   '0.110*"agreement" + 0.107*"uncertainty" + -0.098*"considered" + '
#   '0.097*"consensus" + 0.094*"executive" + -0.090*"legislation" + '
#   '0.085*"recovery" + 0.084*"pillar" + 0.082*"challenge" + -0.080*"loan"'),
#  (79,
#   '-0.116*"responsible" + -0.112*"banknote" + 0.094*"commitment" + '
#   '0.092*"deliver" + 0.090*"carefully" + 0.089*"itself" + 0.089*"functioning" '
#   '+ 0.086*"changed" + -0.083*"improvement" + 0.082*"trust"'),
#  (80,
#   '-0.112*"shock" + -0.110*"ongoing" + -0.096*"facility" + 0.096*"control" + '
#   '-0.092*"investment" + 0.091*"forecast" + -0.089*"agreement" + '
#   '0.087*"series" + 0.086*"don" + -0.085*"fixed"'),
#  (81,
#   '-0.134*"normal" + -0.122*"crisis" + 0.095*"conditionality" + '
#   '-0.093*"implemented" + 0.092*"volatility" + 0.087*"week" + '
#   '0.085*"extremely" + -0.085*"concern" + -0.081*"budget" + '
#   '-0.081*"basically"'),
#  (82,
#   '-0.131*"day" + 0.105*"proposal" + -0.094*"diagnosis" + -0.093*"smp" + '
#   '0.086*"con" + -0.084*"necessarily" + -0.083*"closely" + -0.079*"open" + '
#   '0.078*"pro" + 0.078*"president"'),
#  (83,
#   '-0.119*"action" + -0.103*"concept" + -0.101*"independence" + '
#   '-0.094*"greece" + 0.092*"credible" + -0.091*"money" + -0.090*"day" + '
#   '-0.085*"dollar" + 0.083*"ii" + 0.082*"remains"'),
#  (84,
#   '-0.106*"money" + 0.102*"observed" + -0.098*"adjustment" + '
#   '-0.094*"convincing" + -0.093*"banknote" + 0.090*"finance" + '
#   '-0.086*"basically" + -0.083*"payment" + 0.079*"uncertainty" + -0.078*"due"'),
#  (85,
#   '0.141*"president" + 0.135*"credibility" + 0.114*"especially" + '
#   '-0.108*"very" + 0.100*"option" + -0.098*"esm" + -0.097*"objective" + '
#   '0.090*"evidence" + -0.083*"parliament" + -0.080*"irish"'),
#  (86,
#   '-0.139*"day" + -0.109*"proposal" + 0.098*"addressed" + 0.097*"looking" + '
#   '0.097*"essential" + -0.088*"volatility" + 0.087*"potential" + 0.086*"value" '
#   '+ -0.082*"holding" + -0.080*"intervention"'),
#  (87,
#   '0.133*"within" + 0.108*"labour" + -0.108*"vigilant" + -0.107*"volatility" + '
#   '-0.106*"loss" + 0.097*"indicator" + -0.096*"agreement" + '
#   '-0.092*"phenomenon" + 0.087*"together" + 0.086*"credibility"'),
#  (88,
#   '-0.132*"independence" + -0.107*"open" + -0.101*"alert" + -0.093*"pressure" '
#   '+ 0.093*"criterion" + 0.091*"consensus" + -0.090*"speaking" + '
#   '-0.084*"vigilant" + -0.084*"decisive" + 0.084*"agree"'),
#  (89,
#   '0.124*"forecast" + -0.105*"inflationary" + 0.091*"environment" + '
#   '-0.088*"use" + -0.084*"financing" + -0.084*"staff" + 0.083*"headline" + '
#   '-0.083*"meet" + 0.082*"mechanism" + -0.082*"claim"'),
#  (90,
#   '-0.118*"effective" + -0.109*"conference" + -0.099*"here" + '
#   '0.099*"intervention" + -0.098*"welcome" + -0.097*"share" + 0.088*"judge" + '
#   '-0.088*"ahead" + 0.086*"rest" + -0.086*"deliver"'),
#  (91,
#   '0.115*"intervention" + 0.111*"signal" + -0.102*"principle" + 0.099*"upon" + '
#   '-0.089*"financing" + -0.087*"crisis" + -0.085*"ensure" + 0.085*"saver" + '
#   '0.082*"exceptional" + 0.081*"consensus"'),
#  (92,
#   '-0.118*"several" + 0.110*"value" + -0.096*"eurogroup" + -0.095*"reserve" + '
#   '0.093*"don" + -0.092*"dollar" + -0.089*"tender" + -0.086*"extremely" + '
#   '0.083*"methodology" + 0.082*"domestic"'),
#  (93,
#   '0.129*"intervention" + -0.110*"conclusion" + 0.108*"difference" + '
#   '-0.101*"smp" + 0.099*"move" + -0.094*"up" + -0.092*"carefully" + '
#   '0.088*"crisis" + -0.087*"indicator" + 0.086*"target"'),
#  (94,
#   '0.124*"deliver" + -0.100*"phenomenon" + 0.088*"president" + '
#   '-0.084*"convergence" + 0.081*"opinion" + -0.079*"tender" + '
#   '0.078*"competitiveness" + -0.077*"quarter" + 0.077*"eurosystem" + '
#   '-0.076*"enough"'),
#  (95,
#   '-0.132*"extremely" + -0.098*"sustainable" + 0.089*"big" + '
#   '-0.087*"supervision" + 0.084*"reduction" + 0.081*"size" + '
#   '-0.079*"influence" + 0.078*"action" + -0.077*"stand" + -0.075*"mr"'),
#  (96,
#   '-0.103*"crisis" + 0.102*"observation" + 0.100*"deal" + 0.095*"ten" + '
#   '0.083*"matter" + -0.083*"intervention" + -0.082*"fragmentation" + '
#   '-0.082*"esm" + 0.079*"mechanism" + -0.078*"plan"'),
#  (97,
#   '-0.115*"intervention" + 0.099*"week" + 0.098*"however" + 0.095*"move" + '
#   '-0.094*"money" + 0.088*"confirm" + 0.087*"tightening" + -0.086*"goal" + '
#   '0.086*"commodity" + -0.083*"phenomenon"'),
#  (98,
#   '0.106*"functioning" + 0.093*"sentiment" + 0.090*"vigilance" + -0.089*"used" '
#   '+ -0.087*"expected" + 0.085*"homework" + -0.084*"whatever" + '
#   '0.083*"essential" + -0.079*"mr" + -0.077*"response"'),
#  (99,
#   '0.126*"proposal" + -0.096*"crisis" + 0.094*"plan" + 0.090*"mechanism" + '
#   '-0.088*"totally" + 0.088*"support" + 0.088*"use" + 0.085*"opinion" + '
#   '-0.084*"supply" + 0.082*"inflationary"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.



coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)


coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='u_mass')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)
# Out:
# Coherence Score:  0.36947416716256093
#
# Coherence Score5:  0.38689368894906395
#
# Coherence Score10:  0.3397486309013991
#
# Coherence Score20:  0.2946181100712224
#
# Coherence Score50:  0.23935728105026186
#
# Coherence Score100:  0.2159579422727433
#
# Coherence Score:  -0.6375017967841166
#
# Coherence Score5:  -0.7795614532841282
#
# Coherence Score10:  -0.9597490376004874
#
# Coherence Score20:  -1.0554194068070197
#
# Coherence Score50:  -1.3610980137024504
#
# Coherence Score100:  -1.3002173199446867
