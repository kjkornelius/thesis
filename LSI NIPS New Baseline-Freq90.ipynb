# %% [markdown]
# # load packages

# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess, lemmatize
from gensim.models import CoherenceModel
from gensim.models import LdaModel, LdaMulticore
import gensim.downloader as api
from gensim.models import LsiModel

nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools 
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
#import logging
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
#logging.root.setLevel(level=logging.INFO)
#import warnings
#warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_csv('C:/Users/Kornelius/Desktop/Data 2/nips-papers/papers.csv', header = 0, sep = ';', error_bad_lines=False)
# Drop the columns not needed
df = df.drop(columns=['id', 'event_type', 'pdf_name'], axis=1)

# %%
# Drop a row by condition
df = df[df.abstract != 'Abstract Missing']

# %%
data = df.abstract.values.tolist()

# %% [markdown]
# # Pre-processing (Baseline)

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(data):
    stop_free = " ".join([i for i in data.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(data).split() for data in data]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(16129 unique tokens: ['activity', 'also', 'analysis', 'applied', 'assume']...)

# %%
# filter words that occur in more than 90% of documents
id2word.filter_extremes(no_above = 0.900)
print(id2word)
# Out:
# Dictionary(4415 unique tokens: ['activity', 'also', 'analysis', 'applied', 'assume']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# # LSI

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.103*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '0.519*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.328*"network" + '
#   '-0.296*"method" + -0.165*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.123*"neural"'),
#  (3,
#   '-0.574*"method" + 0.440*"learning" + 0.359*"network" + 0.292*"algorithm" + '
#   '-0.254*"data" + -0.121*"matrix" + -0.104*"problem" + 0.099*"neural" + '
#   '0.099*"deep" + 0.087*"task"'),
#  (4,
#   '0.588*"network" + -0.579*"learning" + -0.266*"data" + 0.218*"neural" + '
#   '0.104*"method" + 0.104*"algorithm" + -0.081*"task" + 0.079*"deep" + '
#   '-0.075*"approach" + 0.075*"image"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.103*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '0.519*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.327*"network" + '
#   '-0.296*"method" + -0.165*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.124*"neural"'),
#  (3,
#   '-0.574*"method" + 0.440*"learning" + 0.359*"network" + 0.292*"algorithm" + '
#   '-0.254*"data" + -0.121*"matrix" + -0.104*"problem" + 0.100*"neural" + '
#   '0.098*"deep" + 0.087*"task"'),
#  (4,
#   '0.588*"network" + -0.579*"learning" + -0.267*"data" + 0.219*"neural" + '
#   '0.104*"method" + 0.104*"algorithm" + -0.081*"task" + 0.080*"deep" + '
#   '-0.075*"approach" + 0.075*"image"'),
#  (5,
#   '-0.681*"data" + 0.315*"function" + -0.262*"algorithm" + 0.201*"model" + '
#   '0.196*"problem" + 0.184*"learning" + 0.162*"method" + -0.139*"network" + '
#   '0.115*"optimization" + -0.111*"feature"'),
#  (6,
#   '0.522*"image" + -0.328*"data" + -0.271*"function" + -0.251*"network" + '
#   '0.244*"algorithm" + 0.236*"feature" + 0.234*"object" + 0.219*"method" + '
#   '-0.185*"distribution" + -0.119*"bound"'),
#  (7,
#   '0.483*"method" + -0.424*"problem" + 0.320*"algorithm" + -0.290*"image" + '
#   '0.225*"learning" + -0.125*"object" + 0.124*"inference" + 0.124*"gradient" + '
#   '-0.120*"matrix" + -0.114*"distribution"'),
#  (8,
#   '-0.568*"problem" + 0.530*"function" + 0.211*"image" + 0.192*"feature" + '
#   '-0.183*"matrix" + -0.170*"learning" + 0.167*"distribution" + '
#   '-0.145*"network" + 0.127*"bound" + 0.097*"loss"'),
#  (9,
#   '-0.500*"function" + 0.350*"distribution" + 0.271*"bound" + -0.258*"data" + '
#   '-0.251*"problem" + 0.206*"matrix" + 0.195*"sample" + -0.128*"optimization" '
#   '+ 0.104*"complexity" + 0.104*"show"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '0.728*"model" + -0.434*"algorithm" + -0.240*"problem" + -0.134*"function" + '
#   '-0.114*"learning" + 0.108*"network" + 0.103*"image" + -0.090*"bound" + '
#   '0.086*"neural" + -0.079*"method"'),
#  (2,
#   '0.519*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.327*"network" + '
#   '-0.296*"method" + -0.166*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.124*"neural"'),
#  (3,
#   '-0.574*"method" + 0.440*"learning" + 0.359*"network" + 0.292*"algorithm" + '
#   '-0.254*"data" + -0.121*"matrix" + -0.104*"problem" + 0.100*"neural" + '
#   '0.098*"deep" + 0.087*"task"'),
#  (4,
#   '0.589*"network" + -0.579*"learning" + -0.267*"data" + 0.218*"neural" + '
#   '0.104*"algorithm" + 0.104*"method" + -0.081*"task" + 0.078*"deep" + '
#   '-0.075*"approach" + 0.075*"image"'),
#  (5,
#   '-0.681*"data" + 0.316*"function" + -0.262*"algorithm" + 0.201*"model" + '
#   '0.196*"problem" + 0.184*"learning" + 0.162*"method" + -0.139*"network" + '
#   '0.114*"optimization" + -0.112*"feature"'),
#  (6,
#   '-0.523*"image" + 0.327*"data" + 0.271*"function" + 0.251*"network" + '
#   '-0.244*"algorithm" + -0.236*"feature" + -0.234*"object" + -0.219*"method" + '
#   '0.185*"distribution" + 0.120*"bound"'),
#  (7,
#   '-0.483*"method" + 0.424*"problem" + -0.320*"algorithm" + 0.291*"image" + '
#   '-0.225*"learning" + 0.125*"object" + -0.125*"inference" + -0.123*"gradient" '
#   '+ 0.121*"matrix" + 0.113*"distribution"'),
#  (8,
#   '0.569*"problem" + -0.530*"function" + -0.211*"image" + -0.191*"feature" + '
#   '0.184*"matrix" + 0.170*"learning" + -0.167*"distribution" + 0.144*"network" '
#   '+ -0.127*"bound" + -0.094*"loss"'),
#  (9,
#   '-0.499*"function" + 0.349*"distribution" + 0.270*"bound" + -0.258*"data" + '
#   '-0.251*"problem" + 0.206*"matrix" + 0.195*"sample" + -0.130*"optimization" '
#   '+ 0.106*"show" + 0.106*"complexity"'),
#  (10,
#   '-0.448*"feature" + -0.378*"matrix" + 0.368*"distribution" + '
#   '0.277*"approach" + 0.243*"inference" + 0.202*"image" + -0.185*"kernel" + '
#   '-0.131*"model" + 0.124*"problem" + -0.111*"function"'),
#  (11,
#   '-0.403*"feature" + -0.323*"kernel" + -0.299*"approach" + 0.274*"bound" + '
#   '-0.242*"inference" + 0.222*"image" + -0.196*"distribution" + 0.183*"data" + '
#   '0.164*"loss" + -0.142*"graph"'),
#  (12,
#   '-0.283*"graph" + -0.274*"image" + 0.260*"task" + -0.228*"distribution" + '
#   '-0.221*"matrix" + 0.209*"time" + 0.191*"policy" + 0.174*"feature" + '
#   '0.173*"information" + -0.166*"kernel"'),
#  (13,
#   '0.510*"matrix" + -0.384*"feature" + 0.278*"approach" + -0.246*"graph" + '
#   '-0.175*"bound" + -0.156*"problem" + 0.154*"image" + -0.147*"method" + '
#   '-0.136*"distribution" + 0.120*"neural"'),
#  (14,
#   '0.509*"graph" + -0.368*"distribution" + -0.315*"feature" + 0.233*"approach" '
#   '+ -0.181*"problem" + 0.171*"kernel" + 0.156*"bound" + 0.154*"clustering" + '
#   '-0.147*"gradient" + 0.145*"time"'),
#  (15,
#   '0.398*"bound" + 0.387*"approach" + -0.284*"distribution" + -0.280*"graph" + '
#   '0.214*"inference" + -0.184*"task" + 0.155*"feature" + -0.142*"clustering" + '
#   '0.124*"kernel" + -0.122*"method"'),
#  (16,
#   '-0.457*"kernel" + 0.348*"task" + 0.276*"matrix" + -0.201*"image" + '
#   '-0.190*"gradient" + 0.186*"function" + 0.179*"approach" + -0.174*"rate" + '
#   '-0.143*"stochastic" + -0.121*"convergence"'),
#  (17,
#   '0.340*"task" + 0.276*"gradient" + -0.234*"bound" + -0.226*"inference" + '
#   '0.190*"training" + -0.188*"image" + -0.186*"method" + -0.151*"learning" + '
#   '0.148*"performance" + 0.144*"stochastic"'),
#  (18,
#   '0.504*"kernel" + -0.357*"approach" + 0.313*"task" + -0.217*"graph" + '
#   '-0.196*"feature" + 0.149*"inference" + 0.141*"classification" + '
#   '-0.138*"gradient" + -0.137*"sparse" + 0.112*"loss"'),
#  (19,
#   '-0.278*"gradient" + 0.249*"loss" + -0.233*"matrix" + -0.232*"policy" + '
#   '0.211*"neural" + -0.201*"stochastic" + 0.188*"approach" + -0.173*"time" + '
#   '0.171*"classification" + -0.168*"process"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.103*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '0.519*"algorithm" + 0.391*"model" + -0.334*"learning" + -0.327*"network" + '
#   '-0.296*"method" + -0.165*"image" + -0.155*"task" + -0.143*"feature" + '
#   '-0.125*"deep" + -0.123*"neural"'),
#  (3,
#   '0.574*"method" + -0.440*"learning" + -0.359*"network" + -0.292*"algorithm" '
#   '+ 0.254*"data" + 0.121*"matrix" + 0.104*"problem" + -0.100*"neural" + '
#   '-0.099*"deep" + -0.087*"task"'),
#  (4,
#   '-0.589*"network" + 0.579*"learning" + 0.267*"data" + -0.218*"neural" + '
#   '-0.104*"algorithm" + -0.104*"method" + 0.081*"task" + -0.079*"deep" + '
#   '0.075*"approach" + -0.075*"image"'),
#  (5,
#   '-0.681*"data" + 0.316*"function" + -0.262*"algorithm" + 0.201*"model" + '
#   '0.196*"problem" + 0.184*"learning" + 0.162*"method" + -0.139*"network" + '
#   '0.114*"optimization" + -0.112*"feature"'),
#  (6,
#   '-0.523*"image" + 0.327*"data" + 0.271*"function" + 0.251*"network" + '
#   '-0.243*"algorithm" + -0.236*"feature" + -0.234*"object" + -0.219*"method" + '
#   '0.185*"distribution" + 0.120*"bound"'),
#  (7,
#   '0.483*"method" + -0.424*"problem" + 0.320*"algorithm" + -0.290*"image" + '
#   '0.225*"learning" + -0.125*"object" + 0.124*"inference" + 0.123*"gradient" + '
#   '-0.120*"matrix" + -0.113*"distribution"'),
#  (8,
#   '-0.568*"problem" + 0.529*"function" + 0.211*"image" + 0.191*"feature" + '
#   '-0.184*"matrix" + -0.170*"learning" + 0.167*"distribution" + '
#   '-0.145*"network" + 0.126*"bound" + 0.095*"loss"'),
#  (9,
#   '-0.500*"function" + 0.349*"distribution" + 0.271*"bound" + -0.258*"data" + '
#   '-0.250*"problem" + 0.205*"matrix" + 0.195*"sample" + -0.130*"optimization" '
#   '+ 0.105*"complexity" + 0.104*"show"'),
#  (10,
#   '-0.448*"feature" + -0.380*"matrix" + 0.369*"distribution" + '
#   '0.277*"approach" + 0.244*"inference" + 0.202*"image" + -0.186*"kernel" + '
#   '-0.131*"model" + 0.125*"problem" + -0.111*"function"'),
#  (11,
#   '0.402*"feature" + 0.324*"kernel" + 0.298*"approach" + -0.274*"bound" + '
#   '0.239*"inference" + -0.222*"image" + 0.198*"distribution" + -0.183*"data" + '
#   '-0.162*"loss" + 0.142*"graph"'),
#  (12,
#   '0.282*"graph" + 0.276*"image" + -0.260*"task" + 0.228*"distribution" + '
#   '0.222*"matrix" + -0.210*"time" + -0.190*"policy" + -0.174*"feature" + '
#   '-0.172*"information" + 0.164*"kernel"'),
#  (13,
#   '0.508*"matrix" + -0.387*"feature" + 0.280*"approach" + -0.238*"graph" + '
#   '-0.172*"bound" + 0.158*"image" + -0.157*"problem" + -0.147*"method" + '
#   '-0.141*"distribution" + 0.123*"neural"'),
#  (14,
#   '-0.510*"graph" + 0.368*"distribution" + 0.309*"feature" + -0.234*"approach" '
#   '+ 0.180*"problem" + -0.167*"kernel" + -0.161*"bound" + -0.153*"clustering" '
#   '+ 0.148*"gradient" + -0.143*"time"'),
#  (15,
#   '-0.400*"approach" + -0.397*"bound" + 0.283*"graph" + 0.279*"distribution" + '
#   '-0.214*"inference" + 0.170*"task" + -0.159*"feature" + 0.145*"clustering" + '
#   '0.121*"method" + 0.115*"information"'),
#  (16,
#   '-0.460*"kernel" + 0.355*"task" + 0.278*"matrix" + -0.198*"image" + '
#   '-0.193*"gradient" + 0.189*"function" + -0.178*"rate" + 0.168*"approach" + '
#   '-0.145*"stochastic" + -0.120*"convergence"'),
#  (17,
#   '0.339*"task" + 0.271*"gradient" + -0.237*"bound" + -0.228*"inference" + '
#   '0.192*"training" + -0.189*"image" + -0.187*"method" + -0.149*"learning" + '
#   '0.146*"stochastic" + 0.142*"convergence"'),
#  (18,
#   '0.509*"kernel" + -0.350*"approach" + 0.315*"task" + -0.213*"graph" + '
#   '-0.194*"feature" + -0.153*"sparse" + 0.142*"classification" + '
#   '0.137*"inference" + 0.120*"process" + -0.119*"gradient"'),
#  (19,
#   '-0.289*"gradient" + 0.252*"loss" + -0.232*"matrix" + -0.231*"policy" + '
#   '0.211*"neural" + -0.204*"stochastic" + 0.179*"approach" + '
#   '0.175*"classification" + 0.175*"linear" + -0.165*"process"'),
#  (20,
#   '-0.501*"inference" + 0.276*"approach" + 0.215*"policy" + 0.195*"kernel" + '
#   '-0.179*"graph" + -0.171*"show" + 0.161*"distribution" + -0.147*"task" + '
#   '-0.139*"variational" + -0.139*"loss"'),
#  (21,
#   '-0.401*"task" + -0.346*"bound" + 0.321*"time" + 0.230*"show" + '
#   '0.223*"label" + 0.189*"training" + 0.187*"loss" + -0.146*"structure" + '
#   '0.132*"classification" + 0.128*"class"'),
#  (22,
#   '0.336*"clustering" + -0.254*"time" + 0.239*"information" + -0.227*"sparse" '
#   '+ -0.179*"parameter" + -0.175*"regression" + -0.175*"task" + 0.169*"matrix" '
#   '+ -0.166*"image" + 0.166*"approach"'),
#  (23,
#   '0.455*"clustering" + -0.332*"graph" + 0.234*"show" + -0.177*"gradient" + '
#   '-0.173*"time" + 0.169*"cluster" + -0.159*"information" + 0.159*"result" + '
#   '-0.158*"loss" + 0.141*"inference"'),
#  (24,
#   '-0.353*"result" + -0.292*"policy" + 0.268*"object" + 0.227*"number" + '
#   '0.215*"time" + 0.202*"sample" + -0.200*"show" + 0.176*"task" + '
#   '0.175*"parameter" + -0.158*"new"'),
#  (25,
#   '0.317*"time" + 0.261*"object" + 0.238*"loss" + -0.195*"training" + '
#   '-0.189*"neural" + -0.181*"show" + -0.181*"bound" + -0.178*"using" + '
#   '0.172*"framework" + -0.172*"policy"'),
#  (26,
#   '-0.466*"object" + 0.363*"time" + -0.219*"show" + -0.212*"variable" + '
#   '0.205*"clustering" + 0.201*"result" + -0.181*"structure" + 0.150*"image" + '
#   '-0.148*"latent" + -0.130*"space"'),
#  (27,
#   '-0.335*"latent" + -0.275*"show" + -0.236*"variable" + -0.216*"time" + '
#   '-0.177*"clustering" + -0.167*"structure" + -0.166*"topic" + 0.166*"graph" + '
#   '0.156*"inference" + 0.154*"loss"'),
#  (28,
#   '-0.355*"information" + -0.298*"process" + 0.286*"show" + 0.271*"object" + '
#   '-0.255*"label" + -0.163*"set" + -0.161*"parameter" + -0.139*"bayesian" + '
#   '0.136*"task" + 0.127*"domain"'),
#  (29,
#   '0.467*"information" + -0.302*"loss" + -0.232*"state" + -0.213*"number" + '
#   '-0.197*"clustering" + -0.152*"process" + -0.148*"task" + 0.139*"sample" + '
#   '-0.129*"gradient" + -0.128*"linear"'),
#  (30,
#   '0.443*"show" + 0.278*"loss" + -0.249*"result" + -0.200*"class" + '
#   '-0.179*"latent" + -0.174*"number" + 0.158*"parameter" + -0.155*"analysis" + '
#   '0.143*"regret" + -0.142*"topic"'),
#  (31,
#   '0.361*"sample" + 0.302*"variable" + 0.262*"training" + -0.205*"label" + '
#   '0.202*"latent" + 0.201*"clustering" + -0.195*"number" + -0.191*"sparse" + '
#   '-0.186*"distribution" + 0.171*"loss"'),
#  (32,
#   '-0.396*"set" + 0.370*"using" + -0.204*"class" + -0.198*"label" + '
#   '0.174*"sparse" + 0.172*"loss" + 0.147*"vector" + 0.139*"object" + '
#   '0.132*"representation" + -0.128*"image"'),
#  (33,
#   '-0.233*"number" + 0.223*"process" + 0.215*"error" + 0.210*"label" + '
#   '-0.199*"set" + 0.194*"classification" + -0.185*"regret" + 0.183*"based" + '
#   '0.180*"bound" + -0.173*"information"'),
#  (34,
#   '-0.267*"process" + -0.265*"set" + -0.251*"training" + 0.231*"state" + '
#   '-0.203*"performance" + 0.178*"information" + 0.178*"estimator" + '
#   '0.177*"label" + -0.170*"optimization" + 0.158*"space"'),
#  (35,
#   '-0.307*"using" + -0.262*"set" + -0.262*"result" + 0.241*"variable" + '
#   '0.232*"performance" + 0.216*"policy" + 0.198*"parameter" + -0.178*"space" + '
#   '-0.173*"rate" + 0.147*"framework"'),
#  (36,
#   '0.330*"process" + -0.271*"using" + 0.271*"rate" + 0.226*"number" + '
#   '-0.208*"gradient" + -0.203*"parameter" + -0.197*"set" + -0.180*"structure" '
#   '+ 0.162*"show" + 0.157*"information"'),
#  (37,
#   '0.471*"framework" + -0.225*"state" + 0.224*"using" + 0.224*"domain" + '
#   '-0.187*"performance" + 0.173*"structure" + 0.164*"label" + -0.162*"loss" + '
#   '-0.160*"information" + 0.153*"sample"'),
#  (38,
#   '0.303*"using" + 0.184*"class" + -0.183*"set" + 0.181*"estimator" + '
#   '-0.179*"loss" + 0.170*"rate" + -0.167*"sample" + -0.167*"complexity" + '
#   '0.165*"parameter" + -0.143*"domain"'),
#  (39,
#   '-0.328*"structure" + 0.236*"state" + 0.220*"framework" + -0.220*"tree" + '
#   '-0.207*"result" + 0.206*"parameter" + 0.181*"domain" + 0.173*"set" + '
#   '-0.168*"gradient" + -0.166*"class"'),
#  (40,
#   '-0.320*"parameter" + 0.274*"variable" + 0.247*"linear" + -0.185*"neural" + '
#   '0.179*"policy" + -0.167*"state" + 0.160*"loss" + -0.156*"structure" + '
#   '-0.156*"new" + -0.150*"optimization"'),
#  (41,
#   '-0.277*"result" + -0.261*"using" + 0.258*"space" + -0.256*"number" + '
#   '0.231*"representation" + -0.203*"variable" + 0.176*"estimator" + '
#   '0.176*"sparse" + -0.158*"new" + 0.150*"neural"'),
#  (42,
#   '-0.332*"analysis" + -0.307*"process" + 0.238*"sparse" + '
#   '0.179*"optimization" + 0.168*"clustering" + 0.164*"optimal" + 0.151*"human" '
#   '+ 0.147*"bayesian" + 0.144*"rate" + 0.140*"kernel"'),
#  (43,
#   '0.275*"information" + 0.271*"linear" + -0.271*"rate" + 0.229*"result" + '
#   '0.209*"framework" + 0.175*"state" + 0.168*"object" + -0.149*"topic" + '
#   '-0.148*"word" + 0.148*"gradient"'),
#  (44,
#   '-0.351*"domain" + 0.253*"sample" + -0.207*"time" + 0.194*"number" + '
#   '-0.188*"information" + -0.171*"sparse" + 0.170*"framework" + 0.151*"linear" '
#   '+ -0.145*"bound" + -0.142*"structure"'),
#  (45,
#   '0.292*"optimization" + 0.280*"class" + 0.234*"using" + 0.229*"new" + '
#   '0.215*"policy" + -0.210*"result" + 0.164*"loss" + 0.161*"convex" + '
#   '-0.150*"proposed" + -0.143*"propose"'),
#  (46,
#   '-0.244*"tree" + 0.241*"policy" + -0.227*"state" + 0.219*"result" + '
#   '-0.211*"class" + 0.188*"parameter" + 0.170*"label" + 0.164*"sample" + '
#   '-0.163*"linear" + 0.158*"set"'),
#  (47,
#   '0.214*"class" + 0.200*"state" + -0.190*"structure" + -0.177*"metric" + '
#   '-0.175*"number" + -0.170*"policy" + 0.170*"human" + -0.161*"tree" + '
#   '-0.156*"linear" + 0.142*"representation"'),
#  (48,
#   '-0.459*"new" + 0.354*"optimization" + 0.222*"domain" + -0.182*"sparse" + '
#   '-0.165*"gradient" + -0.159*"rate" + -0.147*"set" + 0.133*"parameter" + '
#   '0.122*"work" + 0.121*"random"'),
#  (49,
#   '0.233*"performance" + -0.233*"parameter" + -0.229*"linear" + -0.205*"class" '
#   '+ -0.200*"representation" + 0.183*"estimator" + -0.177*"human" + '
#   '-0.149*"based" + -0.135*"new" + 0.134*"random"')]
# [(0,
#   '0.380*"model" + 0.312*"algorithm" + 0.260*"learning" + 0.235*"method" + '
#   '0.227*"problem" + 0.222*"data" + 0.160*"show" + 0.136*"approach" + '
#   '0.131*"function" + 0.123*"network"'),
#  (1,
#   '-0.728*"model" + 0.434*"algorithm" + 0.240*"problem" + 0.134*"function" + '
#   '0.114*"learning" + -0.108*"network" + -0.103*"image" + 0.090*"bound" + '
#   '-0.086*"neural" + 0.079*"method"'),
#  (2,
#   '-0.519*"algorithm" + -0.391*"model" + 0.334*"learning" + 0.327*"network" + '
#   '0.296*"method" + 0.165*"image" + 0.155*"task" + 0.143*"feature" + '
#   '0.125*"deep" + 0.123*"neural"'),
#  (3,
#   '-0.574*"method" + 0.440*"learning" + 0.359*"network" + 0.292*"algorithm" + '
#   '-0.254*"data" + -0.121*"matrix" + -0.104*"problem" + 0.100*"neural" + '
#   '0.099*"deep" + 0.087*"task"'),
#  (4,
#   '-0.589*"network" + 0.579*"learning" + 0.267*"data" + -0.218*"neural" + '
#   '-0.104*"method" + -0.104*"algorithm" + 0.081*"task" + -0.079*"deep" + '
#   '0.075*"approach" + -0.075*"image"'),
#  (5,
#   '-0.681*"data" + 0.316*"function" + -0.262*"algorithm" + 0.201*"model" + '
#   '0.196*"problem" + 0.184*"learning" + 0.162*"method" + -0.139*"network" + '
#   '0.114*"optimization" + -0.112*"feature"'),
#  (6,
#   '-0.523*"image" + 0.327*"data" + 0.271*"function" + 0.251*"network" + '
#   '-0.244*"algorithm" + -0.236*"feature" + -0.234*"object" + -0.219*"method" + '
#   '0.185*"distribution" + 0.120*"bound"'),
#  (7,
#   '-0.483*"method" + 0.424*"problem" + -0.320*"algorithm" + 0.290*"image" + '
#   '-0.225*"learning" + 0.126*"object" + -0.124*"inference" + -0.123*"gradient" '
#   '+ 0.121*"matrix" + 0.113*"distribution"'),
#  (8,
#   '-0.568*"problem" + 0.530*"function" + 0.212*"image" + 0.191*"feature" + '
#   '-0.184*"matrix" + -0.170*"learning" + 0.167*"distribution" + '
#   '-0.145*"network" + 0.127*"bound" + 0.095*"loss"'),
#  (9,
#   '0.500*"function" + -0.349*"distribution" + -0.271*"bound" + 0.258*"data" + '
#   '0.250*"problem" + -0.206*"matrix" + -0.195*"sample" + 0.130*"optimization" '
#   '+ -0.105*"show" + -0.104*"complexity"'),
#  (10,
#   '0.448*"feature" + 0.380*"matrix" + -0.369*"distribution" + '
#   '-0.277*"approach" + -0.244*"inference" + -0.202*"image" + 0.186*"kernel" + '
#   '0.131*"model" + -0.125*"problem" + 0.111*"function"'),
#  (11,
#   '0.403*"feature" + 0.324*"kernel" + 0.299*"approach" + -0.274*"bound" + '
#   '0.240*"inference" + -0.223*"image" + 0.197*"distribution" + -0.183*"data" + '
#   '-0.163*"loss" + 0.140*"graph"'),
#  (12,
#   '0.282*"graph" + 0.275*"image" + -0.259*"task" + 0.230*"distribution" + '
#   '0.222*"matrix" + -0.211*"time" + -0.191*"policy" + -0.174*"feature" + '
#   '-0.172*"information" + 0.166*"kernel"'),
#  (13,
#   '-0.508*"matrix" + 0.387*"feature" + -0.281*"approach" + 0.238*"graph" + '
#   '0.172*"bound" + -0.158*"image" + 0.158*"problem" + 0.147*"method" + '
#   '0.142*"distribution" + -0.123*"neural"'),
#  (14,
#   '0.510*"graph" + -0.368*"distribution" + -0.309*"feature" + 0.233*"approach" '
#   '+ -0.180*"problem" + 0.167*"kernel" + 0.162*"bound" + 0.155*"clustering" + '
#   '-0.148*"gradient" + 0.144*"time"'),
#  (15,
#   '-0.399*"approach" + -0.396*"bound" + 0.284*"graph" + 0.280*"distribution" + '
#   '-0.215*"inference" + 0.171*"task" + -0.159*"feature" + 0.145*"clustering" + '
#   '0.121*"method" + 0.117*"information"'),
#  (16,
#   '-0.459*"kernel" + 0.359*"task" + 0.278*"matrix" + -0.201*"image" + '
#   '-0.193*"gradient" + 0.190*"function" + -0.174*"rate" + 0.168*"approach" + '
#   '-0.147*"stochastic" + -0.123*"convergence"'),
#  (17,
#   '-0.340*"task" + -0.272*"gradient" + 0.236*"bound" + 0.229*"inference" + '
#   '-0.192*"training" + 0.188*"image" + 0.187*"method" + 0.149*"learning" + '
#   '-0.146*"stochastic" + -0.140*"convergence"'),
#  (18,
#   '-0.510*"kernel" + 0.355*"approach" + -0.318*"task" + 0.212*"graph" + '
#   '0.193*"feature" + 0.153*"sparse" + -0.139*"classification" + '
#   '-0.139*"inference" + -0.121*"process" + 0.117*"gradient"'),
#  (19,
#   '-0.292*"gradient" + 0.255*"loss" + -0.234*"matrix" + -0.232*"policy" + '
#   '0.211*"neural" + -0.202*"stochastic" + 0.174*"approach" + 0.173*"linear" + '
#   '0.171*"classification" + -0.163*"time"'),
#  (20,
#   '0.501*"inference" + -0.278*"approach" + -0.213*"policy" + -0.197*"kernel" + '
#   '0.180*"graph" + 0.168*"show" + -0.160*"distribution" + 0.142*"task" + '
#   '0.141*"variational" + 0.135*"loss"'),
#  (21,
#   '-0.398*"task" + -0.345*"bound" + 0.324*"time" + 0.229*"show" + '
#   '0.225*"label" + 0.186*"loss" + 0.185*"training" + -0.149*"structure" + '
#   '0.138*"classification" + 0.132*"class"'),
#  (22,
#   '0.343*"clustering" + -0.259*"time" + 0.226*"information" + -0.225*"sparse" '
#   '+ -0.181*"parameter" + -0.179*"task" + -0.176*"regression" + -0.171*"image" '
#   '+ 0.169*"matrix" + 0.163*"approach"'),
#  (23,
#   '0.449*"clustering" + -0.330*"graph" + 0.238*"show" + -0.179*"gradient" + '
#   '-0.171*"time" + -0.170*"information" + 0.165*"cluster" + -0.162*"loss" + '
#   '0.154*"result" + 0.146*"set"'),
#  (24,
#   '-0.365*"result" + -0.284*"policy" + 0.274*"object" + 0.221*"number" + '
#   '0.198*"time" + 0.194*"sample" + -0.193*"show" + 0.179*"task" + '
#   '0.171*"parameter" + -0.162*"new"'),
#  (25,
#   '-0.328*"time" + -0.255*"object" + -0.233*"loss" + 0.200*"show" + '
#   '0.195*"training" + 0.186*"neural" + 0.181*"bound" + 0.179*"policy" + '
#   '0.177*"using" + -0.171*"framework"'),
#  (26,
#   '-0.469*"object" + 0.362*"time" + 0.219*"clustering" + -0.217*"show" + '
#   '-0.210*"variable" + 0.195*"result" + -0.177*"structure" + 0.152*"image" + '
#   '-0.143*"latent" + -0.135*"space"'),
#  (27,
#   '-0.333*"latent" + -0.293*"show" + -0.241*"variable" + -0.222*"time" + '
#   '-0.168*"topic" + -0.168*"clustering" + 0.164*"graph" + 0.162*"loss" + '
#   '-0.161*"structure" + -0.150*"word"'),
#  (28,
#   '-0.382*"information" + -0.290*"process" + 0.281*"object" + -0.249*"label" + '
#   '0.246*"show" + -0.162*"set" + -0.152*"parameter" + 0.145*"task" + '
#   '-0.138*"bayesian" + 0.133*"domain"'),
#  (29,
#   '0.456*"information" + -0.305*"loss" + -0.226*"state" + -0.211*"number" + '
#   '-0.202*"clustering" + -0.160*"process" + -0.143*"task" + 0.139*"sample" + '
#   '-0.130*"gradient" + -0.122*"linear"'),
#  (30,
#   '0.466*"show" + 0.256*"loss" + -0.247*"result" + -0.196*"class" + '
#   '-0.187*"latent" + -0.185*"number" + -0.148*"analysis" + -0.145*"topic" + '
#   '0.143*"parameter" + -0.141*"variable"'),
#  (31,
#   '-0.376*"sample" + -0.276*"variable" + -0.268*"training" + 0.236*"label" + '
#   '-0.208*"clustering" + -0.204*"loss" + -0.193*"latent" + 0.185*"number" + '
#   '0.183*"distribution" + 0.164*"sparse"'),
#  (32,
#   '-0.408*"set" + 0.220*"process" + 0.200*"bound" + -0.189*"kernel" + '
#   '0.184*"using" + -0.174*"parameter" + -0.172*"result" + 0.155*"error" + '
#   '-0.154*"setting" + 0.153*"based"'),
#  (33,
#   '-0.328*"using" + 0.276*"label" + -0.250*"number" + -0.215*"loss" + '
#   '0.175*"set" + 0.173*"rate" + -0.171*"sparse" + 0.165*"show" + 0.147*"class" '
#   '+ 0.145*"error"'),
#  (34,
#   '0.291*"process" + 0.267*"training" + 0.255*"set" + -0.226*"state" + '
#   '0.190*"optimization" + 0.179*"performance" + -0.178*"estimator" + '
#   '-0.177*"information" + -0.161*"label" + 0.149*"object"'),
#  (35,
#   '0.312*"using" + -0.275*"performance" + -0.251*"variable" + 0.250*"result" + '
#   '0.232*"set" + -0.208*"policy" + -0.191*"parameter" + 0.191*"rate" + '
#   '0.174*"space" + -0.150*"loss"'),
#  (36,
#   '-0.307*"process" + 0.276*"using" + -0.253*"rate" + -0.243*"number" + '
#   '0.223*"set" + 0.203*"parameter" + 0.197*"gradient" + 0.177*"structure" + '
#   '-0.169*"latent" + -0.166*"show"'),
#  (37,
#   '0.506*"framework" + 0.241*"domain" + -0.193*"state" + 0.185*"using" + '
#   '-0.171*"result" + -0.170*"performance" + -0.168*"information" + '
#   '-0.167*"loss" + 0.166*"label" + 0.165*"structure"'),
#  (38,
#   '-0.281*"using" + 0.240*"set" + -0.229*"class" + -0.203*"parameter" + '
#   '0.195*"loss" + -0.185*"estimator" + 0.168*"domain" + -0.153*"performance" + '
#   '0.150*"paper" + 0.138*"sparse"'),
#  (39,
#   '0.296*"parameter" + -0.291*"structure" + 0.269*"state" + -0.205*"result" + '
#   '-0.197*"gradient" + -0.175*"tree" + 0.172*"optimization" + 0.168*"based" + '
#   '0.163*"framework" + -0.155*"sample"'),
#  (40,
#   '-0.289*"variable" + 0.253*"structure" + -0.252*"linear" + 0.198*"parameter" '
#   '+ -0.193*"using" + 0.190*"tree" + 0.188*"neural" + -0.168*"policy" + '
#   '0.161*"show" + -0.157*"latent"'),
#  (41,
#   '-0.283*"result" + 0.260*"space" + -0.256*"number" + -0.252*"using" + '
#   '0.209*"representation" + -0.184*"variable" + 0.181*"estimator" + '
#   '-0.161*"parameter" + 0.156*"sparse" + -0.147*"new"'),
#  (42,
#   '0.317*"analysis" + 0.298*"process" + -0.218*"sparse" + -0.188*"rate" + '
#   '-0.177*"optimal" + -0.175*"clustering" + -0.156*"optimization" + '
#   '-0.156*"human" + -0.141*"kernel" + -0.140*"bayesian"'),
#  (43,
#   '-0.267*"rate" + 0.264*"linear" + 0.263*"information" + 0.230*"result" + '
#   '0.202*"framework" + -0.179*"analysis" + 0.172*"state" + 0.163*"object" + '
#   '-0.154*"two" + 0.149*"gradient"'),
#  (44,
#   '0.380*"domain" + -0.259*"sample" + 0.203*"information" + 0.191*"time" + '
#   '0.164*"structure" + -0.159*"number" + -0.158*"system" + 0.152*"sparse" + '
#   '-0.149*"framework" + 0.149*"parameter"'),
#  (45,
#   '-0.313*"optimization" + -0.268*"class" + -0.230*"policy" + -0.224*"using" + '
#   '-0.217*"new" + 0.217*"result" + -0.157*"loss" + -0.154*"convex" + '
#   '0.143*"proposed" + 0.142*"propose"'),
#  (46,
#   '0.261*"tree" + -0.213*"policy" + 0.197*"new" + 0.188*"state" + '
#   '0.187*"linear" + -0.185*"sample" + -0.182*"result" + -0.180*"parameter" + '
#   '0.164*"class" + -0.162*"label"'),
#  (47,
#   '-0.246*"state" + -0.235*"class" + 0.220*"number" + 0.188*"policy" + '
#   '0.182*"metric" + -0.178*"representation" + 0.167*"structure" + '
#   '-0.162*"human" + 0.158*"space" + 0.139*"distance"'),
#  (48,
#   '-0.461*"new" + 0.340*"optimization" + 0.243*"domain" + 0.175*"random" + '
#   '-0.163*"gradient" + -0.154*"sparse" + -0.143*"rate" + -0.138*"policy" + '
#   '-0.125*"set" + -0.121*"error"'),
#  (49,
#   '-0.285*"parameter" + -0.278*"linear" + 0.221*"performance" + '
#   '0.202*"estimator" + -0.178*"human" + -0.171*"class" + '
#   '-0.170*"representation" + 0.167*"set" + -0.151*"decision" + 0.135*"state"'),
#  (50,
#   '0.215*"framework" + -0.192*"metric" + -0.192*"new" + 0.186*"convergence" + '
#   '0.181*"structure" + -0.179*"based" + 0.179*"system" + -0.165*"one" + '
#   '-0.156*"optimization" + 0.154*"rate"'),
#  (51,
#   '-0.425*"estimator" + 0.284*"performance" + 0.234*"state" + -0.202*"policy" '
#   '+ -0.157*"based" + 0.152*"analysis" + 0.145*"regression" + 0.125*"error" + '
#   '-0.122*"estimation" + 0.120*"sample"'),
#  (52,
#   '0.326*"label" + 0.285*"new" + -0.226*"training" + -0.224*"tree" + '
#   '-0.208*"framework" + -0.206*"decision" + 0.193*"linear" + 0.179*"deep" + '
#   '0.179*"performance" + -0.168*"topic"'),
#  (53,
#   '-0.266*"performance" + 0.205*"deep" + 0.185*"representation" + '
#   '0.182*"prediction" + 0.175*"game" + -0.170*"system" + -0.162*"domain" + '
#   '0.159*"new" + -0.154*"linear" + 0.150*"sampling"'),
#  (54,
#   '0.290*"class" + -0.237*"bayesian" + -0.203*"regression" + 0.195*"propose" + '
#   '-0.174*"two" + -0.170*"optimization" + 0.152*"point" + 0.144*"process" + '
#   '-0.142*"state" + -0.139*"estimator"'),
#  (55,
#   '-0.289*"space" + 0.233*"linear" + -0.225*"new" + 0.209*"analysis" + '
#   '-0.193*"representation" + 0.159*"propose" + 0.156*"training" + '
#   '-0.147*"parameter" + -0.144*"regression" + -0.143*"domain"'),
#  (56,
#   '-0.232*"two" + 0.183*"training" + 0.180*"analysis" + 0.166*"prediction" + '
#   '0.157*"system" + 0.154*"sparse" + -0.150*"regression" + -0.150*"set" + '
#   '0.149*"clustering" + -0.144*"propose"'),
#  (57,
#   '-0.272*"two" + -0.260*"approximation" + 0.235*"analysis" + -0.205*"sparse" '
#   '+ 0.202*"set" + 0.173*"performance" + 0.166*"representation" + '
#   '0.166*"estimator" + -0.146*"label" + -0.141*"also"'),
#  (58,
#   '0.227*"tree" + 0.213*"based" + -0.200*"training" + -0.197*"space" + '
#   '0.192*"random" + -0.170*"framework" + -0.156*"human" + -0.150*"prediction" '
#   '+ 0.147*"performance" + -0.146*"metric"'),
#  (59,
#   '0.319*"error" + 0.286*"approximation" + 0.271*"structure" + '
#   '-0.178*"proposed" + 0.153*"based" + -0.143*"label" + 0.142*"sampling" + '
#   '-0.130*"tree" + -0.125*"parameter" + 0.124*"domain"'),
#  (60,
#   '0.241*"error" + 0.221*"prediction" + 0.207*"input" + -0.189*"training" + '
#   '-0.178*"based" + -0.167*"human" + -0.160*"optimal" + 0.156*"sample" + '
#   '0.138*"two" + 0.137*"classifier"'),
#  (61,
#   '-0.397*"sampling" + 0.336*"two" + -0.223*"regression" + -0.205*"propose" + '
#   '0.161*"game" + -0.152*"topic" + -0.139*"new" + 0.137*"framework" + '
#   '-0.113*"visual" + -0.112*"training"'),
#  (62,
#   '0.260*"space" + 0.232*"sampling" + 0.193*"two" + 0.185*"training" + '
#   '-0.174*"online" + -0.163*"domain" + 0.151*"signal" + 0.150*"structure" + '
#   '-0.147*"large" + 0.145*"input"'),
#  (63,
#   '0.235*"random" + 0.226*"test" + -0.211*"metric" + -0.186*"proposed" + '
#   '-0.172*"sampling" + -0.157*"solution" + -0.155*"optimal" + -0.150*"paper" + '
#   '-0.147*"approximation" + -0.144*"bayesian"'),
#  (64,
#   '0.284*"game" + -0.256*"representation" + 0.203*"neural" + -0.196*"two" + '
#   '0.182*"used" + 0.173*"also" + -0.172*"estimator" + 0.165*"bayesian" + '
#   '-0.155*"linear" + -0.142*"approximation"'),
#  (65,
#   '0.404*"based" + 0.281*"regression" + -0.225*"new" + -0.169*"framework" + '
#   '0.167*"space" + 0.166*"propose" + -0.151*"optimal" + 0.150*"prediction" + '
#   '-0.131*"proposed" + -0.127*"paper"'),
#  (66,
#   '0.313*"prediction" + -0.246*"game" + 0.213*"neural" + -0.194*"noise" + '
#   '0.179*"proposed" + 0.163*"point" + 0.156*"class" + 0.146*"sequence" + '
#   '-0.134*"neuron" + -0.134*"user"'),
#  (67,
#   '-0.269*"game" + -0.229*"large" + -0.226*"random" + 0.171*"deep" + '
#   '-0.154*"vector" + 0.150*"propose" + 0.149*"number" + -0.141*"test" + '
#   '0.128*"paper" + 0.123*"decision"'),
#  (68,
#   '0.238*"test" + -0.214*"local" + 0.200*"application" + 0.184*"bayesian" + '
#   '-0.162*"point" + 0.159*"many" + 0.142*"prediction" + -0.138*"metric" + '
#   '-0.135*"error" + -0.133*"query"'),
#  (69,
#   '0.276*"also" + -0.214*"regression" + -0.196*"optimal" + 0.181*"test" + '
#   '-0.178*"paper" + 0.175*"tree" + 0.173*"propose" + 0.156*"dynamic" + '
#   '0.142*"online" + -0.139*"complexity"'),
#  (70,
#   '-0.299*"space" + 0.213*"based" + -0.201*"proposed" + 0.198*"metric" + '
#   '-0.193*"error" + 0.166*"number" + 0.164*"also" + -0.151*"paper" + '
#   '-0.142*"approximation" + 0.138*"representation"'),
#  (71,
#   '0.315*"proposed" + -0.244*"point" + -0.213*"prediction" + '
#   '0.186*"approximation" + 0.167*"memory" + -0.166*"optimal" + -0.140*"sparse" '
#   '+ 0.138*"error" + -0.137*"user" + 0.135*"based"'),
#  (72,
#   '0.284*"test" + 0.227*"regression" + 0.163*"representation" + 0.162*"point" '
#   '+ -0.158*"human" + 0.154*"analysis" + 0.154*"system" + 0.147*"optimal" + '
#   '0.147*"solution" + -0.145*"latent"'),
#  (73,
#   '0.238*"efficient" + -0.216*"one" + -0.193*"memory" + 0.190*"noise" + '
#   '-0.165*"sparse" + 0.163*"case" + 0.155*"prediction" + 0.153*"random" + '
#   '-0.149*"setting" + -0.143*"machine"'),
#  (74,
#   '-0.189*"also" + -0.184*"paper" + -0.175*"present" + -0.158*"representation" '
#   '+ 0.148*"work" + 0.144*"used" + 0.141*"framework" + -0.141*"classifier" + '
#   '-0.133*"point" + 0.132*"sample"'),
#  (75,
#   '-0.218*"neuron" + -0.218*"input" + 0.193*"representation" + -0.182*"topic" '
#   '+ 0.175*"large" + 0.154*"neural" + -0.153*"game" + -0.137*"sequence" + '
#   '-0.127*"action" + 0.125*"brain"'),
#  (76,
#   '0.249*"action" + -0.189*"sparse" + -0.186*"deep" + -0.172*"game" + '
#   '0.160*"norm" + 0.157*"local" + 0.153*"paper" + 0.150*"prior" + '
#   '0.147*"representation" + 0.136*"estimation"'),
#  (77,
#   '-0.273*"also" + 0.242*"neural" + 0.167*"system" + 0.158*"sampling" + '
#   '0.156*"metric" + -0.153*"neuron" + 0.139*"sparse" + -0.138*"one" + '
#   '-0.131*"performance" + -0.123*"visual"'),
#  (78,
#   '-0.315*"dynamic" + 0.231*"test" + 0.211*"user" + -0.187*"study" + '
#   '-0.178*"norm" + 0.162*"also" + -0.161*"vector" + -0.151*"local" + '
#   '-0.129*"case" + -0.126*"tensor"'),
#  (79,
#   '-0.187*"signal" + 0.187*"different" + 0.186*"estimation" + 0.180*"class" + '
#   '-0.175*"classifier" + 0.164*"one" + 0.151*"multiple" + -0.139*"game" + '
#   '-0.138*"point" + 0.136*"bayesian"'),
#  (80,
#   '0.311*"local" + -0.250*"also" + 0.188*"test" + -0.179*"optimal" + '
#   '-0.169*"norm" + -0.167*"propose" + -0.156*"analysis" + -0.148*"stochastic" '
#   '+ -0.141*"estimation" + 0.140*"present"'),
#  (81,
#   '0.213*"also" + 0.199*"present" + -0.198*"metric" + 0.190*"classifier" + '
#   '0.178*"noise" + -0.169*"representation" + 0.156*"random" + -0.155*"error" + '
#   '0.154*"solution" + -0.139*"probability"'),
#  (82,
#   '-0.244*"signal" + -0.213*"prediction" + 0.175*"norm" + 0.174*"online" + '
#   '0.153*"complexity" + 0.151*"sampling" + 0.148*"prior" + -0.146*"one" + '
#   '0.146*"work" + -0.141*"estimation"'),
#  (83,
#   '-0.211*"work" + 0.199*"paper" + -0.191*"norm" + -0.185*"prior" + '
#   '-0.165*"decision" + 0.163*"online" + -0.162*"error" + 0.157*"different" + '
#   '-0.156*"novel" + -0.145*"variable"'),
#  (84,
#   '-0.226*"online" + 0.216*"also" + -0.179*"memory" + 0.177*"decision" + '
#   '0.171*"sampling" + -0.169*"prior" + 0.162*"latent" + 0.161*"estimator" + '
#   '-0.142*"large" + -0.142*"variable"'),
#  (85,
#   '-0.244*"probability" + 0.204*"regret" + -0.166*"point" + 0.163*"error" + '
#   '0.158*"paper" + 0.148*"variable" + -0.141*"proposed" + -0.141*"estimate" + '
#   '0.138*"case" + -0.134*"work"'),
#  (86,
#   '-0.248*"optimal" + 0.204*"human" + -0.157*"tree" + -0.141*"estimate" + '
#   '0.136*"layer" + 0.135*"spike" + 0.134*"analysis" + -0.130*"brain" + '
#   '-0.127*"estimation" + 0.126*"action"'),
#  (87,
#   '-0.239*"efficient" + 0.185*"space" + 0.164*"case" + -0.158*"vector" + '
#   '-0.154*"many" + -0.151*"response" + -0.150*"natural" + 0.149*"variational" '
#   '+ 0.142*"work" + 0.139*"paper"'),
#  (88,
#   '0.230*"also" + -0.190*"noise" + 0.187*"point" + -0.174*"used" + '
#   '-0.173*"experiment" + 0.168*"deep" + -0.145*"work" + 0.144*"case" + '
#   '0.138*"memory" + 0.135*"estimation"'),
#  (89,
#   '0.243*"point" + -0.217*"visual" + 0.187*"technique" + 0.170*"used" + '
#   '-0.153*"convex" + -0.148*"large" + -0.144*"natural" + 0.129*"brain" + '
#   '-0.127*"local" + -0.121*"tensor"'),
#  (90,
#   '-0.254*"present" + 0.199*"memory" + -0.180*"experiment" + -0.178*"estimate" '
#   '+ 0.171*"large" + 0.168*"propose" + -0.165*"classification" + '
#   '-0.158*"visual" + 0.143*"local" + 0.140*"noise"'),
#  (91,
#   '0.211*"sampling" + 0.205*"setting" + 0.200*"deep" + 0.179*"signal" + '
#   '-0.170*"propose" + -0.165*"complexity" + 0.161*"used" + 0.151*"test" + '
#   '-0.139*"component" + -0.136*"random"'),
#  (92,
#   '-0.238*"constraint" + 0.219*"noise" + 0.176*"value" + 0.159*"signal" + '
#   '0.157*"point" + -0.148*"random" + -0.129*"probability" + 0.122*"visual" + '
#   '-0.118*"convex" + -0.116*"estimation"'),
#  (93,
#   '0.227*"probability" + -0.206*"query" + -0.175*"search" + -0.156*"proposed" '
#   '+ 0.138*"first" + 0.138*"also" + -0.138*"one" + 0.130*"decision" + '
#   '0.129*"label" + -0.129*"vector"'),
#  (94,
#   '-0.193*"provide" + 0.188*"selection" + 0.186*"sampling" + 0.159*"large" + '
#   '-0.157*"computational" + 0.149*"online" + 0.147*"classifier" + '
#   '-0.146*"bayesian" + -0.143*"local" + -0.140*"neuron"'),
#  (95,
#   '0.243*"dynamic" + -0.226*"provide" + -0.203*"vector" + 0.183*"work" + '
#   '0.164*"decision" + -0.153*"system" + -0.146*"use" + 0.139*"also" + '
#   '-0.137*"weight" + 0.129*"ranking"'),
#  (96,
#   '-0.276*"component" + -0.194*"local" + 0.192*"point" + 0.162*"input" + '
#   '-0.162*"used" + 0.139*"visual" + 0.138*"efficient" + -0.131*"constraint" + '
#   '0.128*"random" + 0.125*"distance"'),
#  (97,
#   '-0.249*"memory" + 0.197*"signal" + -0.158*"used" + -0.154*"stimulus" + '
#   '0.144*"one" + 0.143*"two" + -0.138*"objective" + -0.130*"convergence" + '
#   '-0.129*"error" + -0.127*"neuron"'),
#  (98,
#   '-0.204*"online" + 0.191*"use" + 0.181*"experiment" + -0.178*"constraint" + '
#   '-0.162*"setting" + 0.150*"memory" + -0.147*"technique" + 0.145*"efficient" '
#   '+ 0.145*"layer" + 0.138*"one"'),
#  (99,
#   '0.214*"different" + -0.188*"optimal" + 0.173*"noise" + 0.160*"point" + '
#   '0.152*"stochastic" + -0.145*"well" + 0.145*"constraint" + '
#   '-0.139*"classifier" + 0.131*"used" + -0.124*"brain"')]

# %% [markdown]
# # Evaluation

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.



coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)


coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='u_mass')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)
# Out:
# Coherence Score:  0.2627923251812317
#
# Coherence Score5:  0.35653020559757864
#
# Coherence Score10:  0.35593953031241315
#
# Coherence Score20:  0.33203982756412365
#
# Coherence Score50:  0.26863829336267986
#
# Coherence Score100:  0.22407987393885836
#
# Coherence Score:  -1.3206663098063114
#
# Coherence Score5:  -2.157627129084235
#
# Coherence Score10:  -2.1645552638616903
#
# Coherence Score20:  -2.1081879086677953
#
# Coherence Score50:  -2.2846532022421058
#
# Coherence Score100:  -2.432806760450514
