# %%
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['qa']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(8371 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# filter words that occur in more than 90% of documents
id2word.filter_extremes(no_above = 0.990)
print(id2word)
# Out:
# Dictionary(3465 unique tokens: ['absence', 'accept', 'achieve', 'activity', 'add']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.208*"price" + 0.195*"market" + 0.163*"bank" + 0.161*"stability" + '
#   '0.155*"policy" + 0.147*"inflation" + 0.146*"see" + 0.141*"decision" + '
#   '0.139*"monetary" + 0.135*"area"')]
# [(0,
#   '0.208*"price" + 0.195*"market" + 0.163*"bank" + 0.161*"stability" + '
#   '0.155*"policy" + 0.147*"inflation" + 0.146*"see" + 0.141*"decision" + '
#   '0.139*"monetary" + 0.135*"area"'),
#  (1,
#   '0.238*"regard" + -0.213*"policy" + 0.182*"stability" + -0.178*"bank" + '
#   '-0.178*"think" + -0.142*"actually" + 0.130*"level" + -0.130*"monetary" + '
#   '-0.128*"answer" + -0.114*"second"'),
#  (2,
#   '-0.322*"price" + 0.295*"government" + -0.273*"inflation" + 0.261*"decision" '
#   '+ 0.209*"country" + 0.183*"bank" + 0.170*"measure" + -0.128*"risk" + '
#   '-0.122*"growth" + -0.111*"oil"'),
#  (3,
#   '0.311*"market" + 0.242*"bank" + -0.222*"policy" + -0.219*"growth" + '
#   '0.187*"risk" + -0.181*"monetary" + -0.154*"year" + 0.142*"money" + '
#   '0.124*"credit" + -0.118*"council"'),
#  (4,
#   '-0.326*"inflation" + -0.292*"policy" + -0.209*"measure" + -0.203*"decision" '
#   '+ -0.183*"programme" + 0.178*"think" + 0.159*"area" + 0.139*"so" + '
#   '-0.134*"monetary" + -0.125*"expectation"')]
# [(0,
#   '0.208*"price" + 0.195*"market" + 0.163*"bank" + 0.161*"stability" + '
#   '0.155*"policy" + 0.147*"inflation" + 0.146*"see" + 0.141*"decision" + '
#   '0.139*"monetary" + 0.135*"area"'),
#  (1,
#   '0.238*"regard" + -0.213*"policy" + 0.182*"stability" + -0.178*"bank" + '
#   '-0.178*"think" + -0.142*"actually" + 0.130*"level" + -0.130*"monetary" + '
#   '-0.128*"answer" + -0.114*"second"'),
#  (2,
#   '0.322*"price" + -0.295*"government" + 0.273*"inflation" + -0.261*"decision" '
#   '+ -0.209*"country" + -0.183*"bank" + -0.170*"measure" + 0.128*"risk" + '
#   '0.122*"growth" + 0.111*"oil"'),
#  (3,
#   '-0.311*"market" + -0.242*"bank" + 0.222*"policy" + 0.219*"growth" + '
#   '-0.187*"risk" + 0.181*"monetary" + 0.154*"year" + -0.142*"money" + '
#   '-0.124*"credit" + 0.118*"council"'),
#  (4,
#   '0.326*"inflation" + 0.293*"policy" + 0.209*"measure" + 0.204*"decision" + '
#   '0.183*"programme" + -0.178*"think" + -0.158*"area" + -0.139*"so" + '
#   '0.134*"monetary" + 0.125*"expectation"'),
#  (5,
#   '0.281*"country" + 0.249*"area" + -0.229*"council" + -0.200*"governing" + '
#   '-0.186*"bank" + -0.180*"central" + 0.162*"stability" + 0.156*"government" + '
#   '0.146*"price" + -0.140*"market"'),
#  (6,
#   '-0.358*"council" + -0.325*"governing" + -0.187*"risk" + -0.172*"ecb" + '
#   '0.153*"year" + 0.144*"bank" + -0.128*"clear" + 0.125*"economy" + '
#   '0.124*"level" + 0.120*"decision"'),
#  (7,
#   '0.377*"market" + 0.268*"price" + 0.228*"stability" + 0.181*"policy" + '
#   '-0.153*"see" + -0.143*"economy" + -0.133*"figure" + -0.126*"point" + '
#   '-0.119*"inflation" + 0.115*"deliver"'),
#  (8,
#   '-0.291*"monetary" + 0.289*"inflation" + -0.244*"policy" + -0.231*"bank" + '
#   '-0.222*"risk" + 0.158*"governing" + 0.151*"council" + -0.128*"analysis" + '
#   '-0.126*"growth" + 0.122*"market"'),
#  (9,
#   '-0.393*"bank" + 0.275*"risk" + 0.214*"area" + 0.183*"monetary" + '
#   '0.170*"decision" + 0.163*"market" + -0.150*"confidence" + -0.139*"economy" '
#   '+ -0.133*"central" + 0.121*"regard"')]
# [(0,
#   '0.208*"price" + 0.195*"market" + 0.163*"bank" + 0.161*"stability" + '
#   '0.155*"policy" + 0.147*"inflation" + 0.146*"see" + 0.141*"decision" + '
#   '0.139*"monetary" + 0.135*"area"'),
#  (1,
#   '0.238*"regard" + -0.213*"policy" + 0.182*"stability" + -0.178*"bank" + '
#   '-0.178*"think" + -0.142*"actually" + 0.130*"level" + -0.130*"monetary" + '
#   '-0.128*"answer" + -0.114*"second"'),
#  (2,
#   '0.322*"price" + -0.295*"government" + 0.273*"inflation" + -0.260*"decision" '
#   '+ -0.209*"country" + -0.183*"bank" + -0.170*"measure" + 0.128*"risk" + '
#   '0.122*"growth" + 0.111*"oil"'),
#  (3,
#   '0.311*"market" + 0.242*"bank" + -0.222*"policy" + -0.219*"growth" + '
#   '0.187*"risk" + -0.181*"monetary" + -0.154*"year" + 0.142*"money" + '
#   '0.124*"credit" + -0.118*"council"'),
#  (4,
#   '0.326*"inflation" + 0.292*"policy" + 0.209*"measure" + 0.204*"decision" + '
#   '0.183*"programme" + -0.178*"think" + -0.158*"area" + -0.139*"so" + '
#   '0.134*"monetary" + 0.124*"expectation"'),
#  (5,
#   '-0.280*"country" + -0.249*"area" + 0.229*"council" + 0.200*"governing" + '
#   '0.186*"bank" + 0.180*"central" + -0.162*"stability" + -0.156*"government" + '
#   '-0.146*"price" + 0.140*"market"'),
#  (6,
#   '-0.359*"council" + -0.325*"governing" + -0.188*"risk" + -0.172*"ecb" + '
#   '0.153*"year" + 0.145*"bank" + -0.127*"clear" + 0.125*"economy" + '
#   '0.124*"level" + 0.120*"decision"'),
#  (7,
#   '-0.377*"market" + -0.268*"price" + -0.228*"stability" + -0.180*"policy" + '
#   '0.152*"see" + 0.143*"economy" + 0.133*"figure" + 0.126*"point" + '
#   '0.119*"inflation" + -0.115*"deliver"'),
#  (8,
#   '0.292*"monetary" + -0.289*"inflation" + 0.244*"policy" + 0.231*"bank" + '
#   '0.221*"risk" + -0.158*"governing" + -0.151*"council" + 0.129*"analysis" + '
#   '0.126*"growth" + -0.122*"price"'),
#  (9,
#   '0.392*"bank" + -0.274*"risk" + -0.214*"area" + -0.182*"monetary" + '
#   '-0.169*"decision" + -0.162*"market" + 0.150*"confidence" + 0.139*"economy" '
#   '+ 0.133*"central" + -0.122*"regard"'),
#  (10,
#   '0.382*"market" + -0.332*"price" + -0.210*"bank" + -0.193*"stability" + '
#   '-0.164*"decision" + 0.144*"reform" + 0.144*"economy" + 0.143*"policy" + '
#   '0.141*"financial" + -0.112*"today"'),
#  (11,
#   '0.260*"growth" + -0.176*"situation" + -0.167*"analysis" + 0.163*"market" + '
#   '-0.161*"so" + -0.159*"confidence" + -0.157*"policy" + -0.146*"stability" + '
#   '-0.142*"monetary" + 0.121*"regard"'),
#  (12,
#   '-0.221*"it" + 0.210*"governing" + 0.205*"council" + 0.189*"country" + '
#   '-0.183*"confidence" + 0.147*"economy" + -0.139*"bond" + -0.134*"greek" + '
#   '-0.133*"market" + -0.130*"know"'),
#  (13,
#   '-0.315*"risk" + -0.226*"inflation" + 0.195*"decision" + -0.162*"area" + '
#   '-0.160*"bank" + 0.153*"think" + 0.130*"level" + 0.124*"certainly" + '
#   '0.118*"financial" + -0.117*"interest"'),
#  (14,
#   '-0.325*"measure" + 0.252*"government" + 0.165*"greece" + -0.159*"regard" + '
#   '-0.159*"ecb" + -0.148*"fiscal" + -0.146*"nonstandard" + 0.143*"greek" + '
#   '0.135*"last" + -0.133*"interest"'),
#  (15,
#   '-0.216*"economy" + -0.172*"measure" + 0.171*"level" + 0.156*"decision" + '
#   '0.155*"inflation" + -0.153*"price" + 0.140*"confidence" + -0.139*"second" + '
#   '0.136*"growth" + 0.131*"today"'),
#  (16,
#   '-0.253*"economy" + 0.186*"month" + -0.175*"point" + -0.171*"interest" + '
#   '0.158*"situation" + -0.154*"european" + 0.152*"it" + -0.144*"measure" + '
#   '0.136*"country" + 0.127*"regard"'),
#  (17,
#   '-0.245*"it" + 0.233*"growth" + -0.232*"country" + 0.159*"think" + '
#   '-0.136*"take" + -0.123*"monetary" + 0.122*"government" + -0.119*"could" + '
#   '0.119*"year" + -0.117*"central"'),
#  (18,
#   '0.236*"country" + -0.214*"risk" + -0.158*"stability" + 0.148*"monetary" + '
#   '0.143*"interest" + -0.142*"year" + -0.131*"government" + 0.127*"greek" + '
#   '-0.126*"measure" + -0.124*"ab"'),
#  (19,
#   '0.292*"economy" + -0.220*"year" + -0.192*"level" + 0.137*"fiscal" + '
#   '-0.132*"last" + 0.131*"effect" + 0.126*"money" + -0.118*"see" + 0.109*"so" '
#   '+ 0.108*"risk"')]
# [(0,
#   '-0.208*"price" + -0.195*"market" + -0.163*"bank" + -0.161*"stability" + '
#   '-0.155*"policy" + -0.147*"inflation" + -0.146*"see" + -0.141*"decision" + '
#   '-0.139*"monetary" + -0.135*"area"'),
#  (1,
#   '0.238*"regard" + -0.213*"policy" + 0.182*"stability" + -0.178*"bank" + '
#   '-0.178*"think" + -0.142*"actually" + 0.130*"level" + -0.130*"monetary" + '
#   '-0.128*"answer" + -0.114*"second"'),
#  (2,
#   '-0.322*"price" + 0.295*"government" + -0.273*"inflation" + 0.261*"decision" '
#   '+ 0.209*"country" + 0.183*"bank" + 0.170*"measure" + -0.128*"risk" + '
#   '-0.122*"growth" + -0.111*"oil"'),
#  (3,
#   '0.311*"market" + 0.242*"bank" + -0.222*"policy" + -0.219*"growth" + '
#   '0.187*"risk" + -0.181*"monetary" + -0.154*"year" + 0.142*"money" + '
#   '0.124*"credit" + -0.118*"council"'),
#  (4,
#   '0.326*"inflation" + 0.293*"policy" + 0.209*"measure" + 0.204*"decision" + '
#   '0.183*"programme" + -0.178*"think" + -0.158*"area" + -0.139*"so" + '
#   '0.134*"monetary" + 0.124*"expectation"'),
#  (5,
#   '-0.281*"country" + -0.249*"area" + 0.229*"council" + 0.200*"governing" + '
#   '0.186*"bank" + 0.180*"central" + -0.162*"stability" + -0.156*"government" + '
#   '-0.146*"price" + 0.140*"market"'),
#  (6,
#   '0.359*"council" + 0.325*"governing" + 0.188*"risk" + 0.172*"ecb" + '
#   '-0.153*"year" + -0.145*"bank" + 0.127*"clear" + -0.125*"economy" + '
#   '-0.124*"level" + -0.120*"decision"'),
#  (7,
#   '-0.377*"market" + -0.268*"price" + -0.228*"stability" + -0.180*"policy" + '
#   '0.152*"see" + 0.143*"economy" + 0.133*"figure" + 0.126*"point" + '
#   '0.119*"inflation" + -0.115*"deliver"'),
#  (8,
#   '-0.291*"monetary" + 0.289*"inflation" + -0.244*"policy" + -0.231*"bank" + '
#   '-0.221*"risk" + 0.158*"governing" + 0.151*"council" + -0.129*"analysis" + '
#   '-0.126*"growth" + 0.121*"price"'),
#  (9,
#   '0.393*"bank" + -0.274*"risk" + -0.214*"area" + -0.182*"monetary" + '
#   '-0.169*"decision" + -0.162*"market" + 0.151*"confidence" + 0.139*"economy" '
#   '+ 0.133*"central" + -0.122*"regard"'),
#  (10,
#   '-0.382*"market" + 0.333*"price" + 0.209*"bank" + 0.193*"stability" + '
#   '0.164*"decision" + -0.145*"economy" + -0.144*"reform" + -0.143*"policy" + '
#   '-0.140*"financial" + 0.113*"today"'),
#  (11,
#   '-0.260*"growth" + 0.176*"situation" + 0.166*"analysis" + -0.163*"market" + '
#   '0.161*"so" + 0.159*"confidence" + 0.157*"policy" + 0.146*"stability" + '
#   '0.141*"monetary" + -0.120*"effect"'),
#  (12,
#   '0.221*"it" + -0.210*"governing" + -0.205*"council" + -0.189*"country" + '
#   '0.184*"confidence" + -0.147*"economy" + 0.139*"bond" + 0.134*"greek" + '
#   '0.133*"market" + 0.130*"know"'),
#  (13,
#   '0.315*"risk" + 0.226*"inflation" + -0.195*"decision" + 0.162*"area" + '
#   '0.159*"bank" + -0.152*"think" + -0.131*"level" + -0.124*"certainly" + '
#   '0.118*"interest" + -0.118*"financial"'),
#  (14,
#   '0.326*"measure" + -0.252*"government" + -0.165*"greece" + 0.159*"regard" + '
#   '0.158*"ecb" + 0.148*"fiscal" + 0.145*"nonstandard" + -0.142*"greek" + '
#   '-0.136*"last" + 0.133*"interest"'),
#  (15,
#   '0.215*"economy" + 0.172*"measure" + -0.171*"level" + -0.156*"decision" + '
#   '-0.155*"inflation" + 0.154*"price" + -0.139*"confidence" + 0.138*"second" + '
#   '-0.135*"growth" + -0.132*"today"'),
#  (16,
#   '0.253*"economy" + -0.184*"month" + 0.176*"point" + 0.171*"interest" + '
#   '-0.157*"situation" + 0.153*"european" + -0.152*"it" + 0.144*"measure" + '
#   '-0.136*"country" + -0.126*"regard"'),
#  (17,
#   '0.244*"it" + -0.233*"growth" + 0.233*"country" + -0.159*"think" + '
#   '0.136*"take" + 0.122*"monetary" + -0.122*"government" + 0.119*"could" + '
#   '-0.119*"year" + 0.116*"central"'),
#  (18,
#   '0.235*"country" + -0.214*"risk" + -0.158*"stability" + 0.147*"monetary" + '
#   '0.143*"interest" + -0.143*"year" + -0.131*"government" + 0.127*"greek" + '
#   '-0.126*"ab" + -0.124*"measure"'),
#  (19,
#   '-0.294*"economy" + 0.221*"year" + 0.192*"level" + -0.139*"fiscal" + '
#   '0.133*"last" + -0.130*"effect" + -0.125*"money" + 0.117*"see" + -0.108*"so" '
#   '+ -0.107*"risk"'),
#  (20,
#   '-0.205*"regard" + 0.175*"point" + 0.163*"market" + 0.162*"today" + '
#   '0.154*"area" + -0.147*"second" + -0.141*"it" + 0.137*"country" + '
#   '0.134*"decision" + 0.132*"think"'),
#  (21,
#   '0.200*"projection" + 0.165*"effect" + 0.158*"central" + -0.147*"programme" '
#   '+ -0.145*"stability" + 0.143*"responsibility" + 0.140*"oil" + '
#   '-0.140*"month" + 0.127*"european" + 0.126*"inflation"'),
#  (22,
#   '0.186*"instrument" + -0.186*"risk" + 0.184*"policy" + 0.150*"point" + '
#   '-0.147*"well" + -0.144*"decision" + -0.140*"think" + -0.136*"interest" + '
#   '0.127*"stability" + -0.123*"term"'),
#  (23,
#   '0.253*"level" + -0.228*"see" + -0.216*"decision" + -0.204*"growth" + '
#   '0.174*"situation" + 0.159*"area" + 0.139*"important" + -0.135*"look" + '
#   '0.132*"think" + -0.131*"market"'),
#  (24,
#   '-0.197*"year" + -0.153*"credit" + 0.152*"second" + -0.151*"change" + '
#   '0.150*"see" + 0.140*"information" + -0.125*"economy" + 0.122*"figure" + '
#   '0.118*"growth" + 0.117*"mandate"'),
#  (25,
#   '-0.175*"point" + -0.169*"figure" + -0.166*"government" + 0.165*"measure" + '
#   '0.160*"think" + -0.154*"price" + 0.149*"important" + 0.137*"good" + '
#   '0.118*"it" + -0.118*"basis"'),
#  (26,
#   '-0.175*"confidence" + -0.172*"figure" + -0.169*"year" + 0.169*"reform" + '
#   '-0.159*"think" + 0.155*"already" + 0.152*"number" + -0.143*"bond" + '
#   '-0.140*"economy" + -0.118*"information"'),
#  (27,
#   '0.221*"country" + -0.205*"area" + -0.185*"economy" + -0.165*"think" + '
#   '-0.143*"figure" + 0.130*"fiscal" + -0.118*"so" + 0.118*"treaty" + '
#   '-0.117*"interest" + 0.110*"meeting"'),
#  (28,
#   '0.168*"increase" + -0.165*"programme" + 0.158*"it" + -0.156*"country" + '
#   '0.140*"term" + -0.132*"certainly" + 0.128*"situation" + 0.125*"condition" + '
#   '-0.115*"lending" + 0.107*"measure"'),
#  (29,
#   '-0.315*"see" + -0.176*"reason" + 0.147*"fiscal" + -0.140*"effect" + '
#   '0.124*"growth" + 0.118*"projection" + -0.111*"european" + 0.104*"past" + '
#   '-0.102*"don" + -0.102*"year"'),
#  (30,
#   '-0.229*"exchange" + -0.183*"last" + 0.170*"interest" + 0.155*"clear" + '
#   '-0.145*"regard" + 0.132*"change" + 0.119*"position" + -0.116*"currency" + '
#   '-0.108*"well" + -0.105*"new"'),
#  (31,
#   '0.175*"financial" + -0.159*"year" + -0.133*"central" + -0.124*"important" + '
#   '0.123*"nonstandard" + 0.120*"expectation" + -0.120*"bond" + '
#   '-0.118*"programme" + -0.118*"exchange" + 0.115*"development"'),
#  (32,
#   '0.268*"situation" + 0.168*"growth" + -0.140*"course" + -0.140*"important" + '
#   '0.136*"area" + -0.120*"go" + 0.116*"exchange" + 0.114*"assessment" + '
#   '-0.112*"reason" + 0.110*"creation"'),
#  (33,
#   '0.152*"area" + -0.140*"level" + 0.126*"so" + -0.122*"government" + '
#   '0.116*"know" + -0.113*"economy" + -0.113*"thats" + 0.111*"case" + '
#   '-0.108*"clear" + -0.107*"reform"'),
#  (34,
#   '0.181*"situation" + -0.159*"regard" + 0.145*"second" + 0.142*"well" + '
#   '-0.134*"financial" + 0.127*"growth" + -0.121*"inflation" + '
#   '0.119*"particular" + 0.119*"quarter" + 0.110*"already"'),
#  (35,
#   '0.162*"government" + -0.145*"decision" + -0.137*"reason" + '
#   '0.132*"information" + 0.121*"different" + -0.114*"european" + '
#   '-0.112*"financial" + 0.111*"part" + 0.108*"exchange" + 0.105*"always"'),
#  (36,
#   '0.239*"certainly" + -0.170*"central" + 0.168*"new" + -0.157*"think" + '
#   '0.157*"meeting" + 0.147*"message" + 0.137*"government" + 0.120*"job" + '
#   '0.112*"past" + -0.109*"projection"'),
#  (37,
#   '0.150*"important" + 0.143*"look" + -0.142*"responsibility" + '
#   '0.128*"country" + 0.123*"it" + 0.119*"mandate" + -0.113*"central" + '
#   '0.112*"give" + -0.104*"second" + -0.101*"today"'),
#  (38,
#   '-0.195*"clear" + -0.193*"information" + 0.145*"global" + 0.134*"way" + '
#   '-0.123*"reform" + 0.122*"issue" + -0.109*"area" + 0.107*"expectation" + '
#   '-0.107*"recovery" + -0.107*"appropriate"'),
#  (39,
#   '-0.151*"think" + -0.148*"government" + -0.139*"loan" + 0.134*"stability" + '
#   '-0.133*"point" + -0.128*"month" + -0.122*"european" + 0.115*"liquidity" + '
#   '0.113*"actually" + -0.104*"greece"'),
#  (40,
#   '-0.149*"global" + -0.145*"ecb" + 0.144*"projection" + 0.137*"again" + '
#   '0.134*"thing" + 0.122*"responsibility" + -0.121*"financial" + 0.117*"two" + '
#   '0.114*"new" + -0.110*"price"'),
#  (41,
#   '-0.182*"ecb" + 0.165*"effect" + 0.158*"course" + 0.142*"point" + '
#   '0.136*"interest" + -0.129*"year" + 0.124*"exchange" + 0.118*"programme" + '
#   '0.112*"recovery" + 0.110*"regard"'),
#  (42,
#   '0.150*"figure" + -0.146*"change" + 0.143*"new" + -0.142*"period" + '
#   '-0.136*"last" + 0.131*"today" + -0.121*"meeting" + 0.112*"bond" + '
#   '-0.109*"thing" + 0.109*"issue"'),
#  (43,
#   '0.152*"appropriate" + 0.139*"two" + -0.137*"change" + -0.137*"liquidity" + '
#   '0.122*"clear" + -0.121*"level" + -0.120*"come" + -0.116*"better" + '
#   '-0.110*"europe" + -0.104*"credit"'),
#  (44,
#   '0.167*"know" + -0.136*"global" + 0.126*"take" + -0.126*"today" + '
#   '0.120*"figure" + 0.115*"reform" + -0.108*"stance" + 0.108*"course" + '
#   '-0.107*"possible" + -0.104*"since"'),
#  (45,
#   '-0.160*"account" + 0.149*"new" + -0.139*"recovery" + -0.137*"european" + '
#   '0.135*"level" + -0.128*"possible" + 0.123*"next" + -0.114*"ecb" + '
#   '0.113*"financial" + 0.109*"month"'),
#  (46,
#   '0.202*"important" + 0.137*"credit" + -0.136*"regard" + 0.134*"move" + '
#   '-0.132*"think" + -0.131*"well" + 0.125*"confidence" + -0.118*"change" + '
#   '-0.118*"negative" + -0.109*"again"'),
#  (47,
#   '-0.146*"look" + -0.130*"regard" + -0.126*"europe" + -0.119*"bond" + '
#   '-0.117*"interest" + 0.108*"today" + 0.106*"message" + -0.102*"inflation" + '
#   '0.100*"liquidity" + -0.095*"good"'),
#  (48,
#   '-0.164*"credit" + -0.157*"mandate" + 0.150*"programme" + -0.121*"taken" + '
#   '-0.114*"interest" + 0.113*"expectation" + 0.108*"year" + -0.103*"state" + '
#   '-0.099*"important" + 0.096*"mentioned"'),
#  (49,
#   '-0.203*"ecb" + 0.161*"again" + -0.123*"figure" + 0.122*"appropriate" + '
#   '0.122*"let" + 0.115*"statement" + -0.108*"course" + 0.108*"see" + '
#   '-0.107*"mentioned" + -0.105*"interest"')]
# [(0,
#   '-0.208*"price" + -0.195*"market" + -0.163*"bank" + -0.161*"stability" + '
#   '-0.155*"policy" + -0.147*"inflation" + -0.146*"see" + -0.141*"decision" + '
#   '-0.139*"monetary" + -0.135*"area"'),
#  (1,
#   '0.238*"regard" + -0.213*"policy" + 0.182*"stability" + -0.178*"bank" + '
#   '-0.178*"think" + -0.142*"actually" + 0.130*"level" + -0.130*"monetary" + '
#   '-0.128*"answer" + -0.114*"second"'),
#  (2,
#   '0.322*"price" + -0.295*"government" + 0.273*"inflation" + -0.261*"decision" '
#   '+ -0.209*"country" + -0.183*"bank" + -0.170*"measure" + 0.128*"risk" + '
#   '0.122*"growth" + 0.111*"oil"'),
#  (3,
#   '0.311*"market" + 0.242*"bank" + -0.222*"policy" + -0.219*"growth" + '
#   '0.187*"risk" + -0.181*"monetary" + -0.154*"year" + 0.142*"money" + '
#   '0.124*"credit" + -0.118*"council"'),
#  (4,
#   '0.326*"inflation" + 0.293*"policy" + 0.209*"measure" + 0.204*"decision" + '
#   '0.183*"programme" + -0.178*"think" + -0.158*"area" + -0.139*"so" + '
#   '0.134*"monetary" + 0.124*"expectation"'),
#  (5,
#   '0.281*"country" + 0.249*"area" + -0.229*"council" + -0.200*"governing" + '
#   '-0.186*"bank" + -0.180*"central" + 0.162*"stability" + 0.156*"government" + '
#   '0.146*"price" + -0.140*"market"'),
#  (6,
#   '0.359*"council" + 0.325*"governing" + 0.188*"risk" + 0.172*"ecb" + '
#   '-0.153*"year" + -0.145*"bank" + 0.127*"clear" + -0.125*"economy" + '
#   '-0.124*"level" + -0.120*"decision"'),
#  (7,
#   '0.377*"market" + 0.268*"price" + 0.228*"stability" + 0.180*"policy" + '
#   '-0.152*"see" + -0.143*"economy" + -0.133*"figure" + -0.126*"point" + '
#   '-0.119*"inflation" + 0.115*"deliver"'),
#  (8,
#   '-0.291*"monetary" + 0.289*"inflation" + -0.244*"policy" + -0.231*"bank" + '
#   '-0.221*"risk" + 0.158*"governing" + 0.151*"council" + -0.129*"analysis" + '
#   '-0.126*"growth" + 0.121*"price"'),
#  (9,
#   '-0.393*"bank" + 0.274*"risk" + 0.214*"area" + 0.182*"monetary" + '
#   '0.169*"decision" + 0.162*"market" + -0.151*"confidence" + -0.139*"economy" '
#   '+ -0.133*"central" + 0.122*"regard"'),
#  (10,
#   '0.382*"market" + -0.332*"price" + -0.209*"bank" + -0.193*"stability" + '
#   '-0.164*"decision" + 0.145*"economy" + 0.144*"reform" + 0.143*"policy" + '
#   '0.141*"financial" + -0.113*"today"'),
#  (11,
#   '-0.260*"growth" + 0.176*"situation" + 0.166*"analysis" + -0.163*"market" + '
#   '0.161*"so" + 0.159*"confidence" + 0.157*"policy" + 0.146*"stability" + '
#   '0.141*"monetary" + -0.120*"effect"'),
#  (12,
#   '0.221*"it" + -0.210*"governing" + -0.205*"council" + -0.189*"country" + '
#   '0.184*"confidence" + -0.147*"economy" + 0.138*"bond" + 0.135*"greek" + '
#   '0.133*"market" + 0.130*"know"'),
#  (13,
#   '-0.315*"risk" + -0.226*"inflation" + 0.195*"decision" + -0.162*"area" + '
#   '-0.159*"bank" + 0.152*"think" + 0.131*"level" + 0.124*"certainly" + '
#   '-0.118*"interest" + 0.117*"financial"'),
#  (14,
#   '0.326*"measure" + -0.252*"government" + -0.165*"greece" + 0.159*"regard" + '
#   '0.158*"ecb" + 0.149*"fiscal" + 0.145*"nonstandard" + -0.142*"greek" + '
#   '-0.135*"last" + 0.132*"interest"'),
#  (15,
#   '0.215*"economy" + 0.171*"measure" + -0.171*"level" + -0.156*"decision" + '
#   '-0.155*"inflation" + 0.154*"price" + -0.140*"confidence" + 0.138*"second" + '
#   '-0.136*"growth" + -0.132*"today"'),
#  (16,
#   '0.254*"economy" + -0.184*"month" + 0.176*"point" + 0.171*"interest" + '
#   '-0.157*"situation" + 0.154*"european" + -0.152*"it" + 0.144*"measure" + '
#   '-0.136*"country" + -0.126*"regard"'),
#  (17,
#   '-0.244*"it" + -0.233*"country" + 0.233*"growth" + 0.159*"think" + '
#   '-0.136*"take" + -0.122*"monetary" + 0.122*"government" + -0.119*"could" + '
#   '0.119*"year" + -0.116*"central"'),
#  (18,
#   '-0.235*"country" + 0.214*"risk" + 0.158*"stability" + -0.147*"monetary" + '
#   '-0.143*"interest" + 0.143*"year" + 0.131*"government" + -0.128*"greek" + '
#   '0.126*"ab" + 0.125*"measure"'),
#  (19,
#   '0.294*"economy" + -0.221*"year" + -0.192*"level" + 0.139*"fiscal" + '
#   '-0.133*"last" + 0.130*"effect" + 0.126*"money" + -0.117*"see" + 0.108*"so" '
#   '+ 0.107*"risk"'),
#  (20,
#   '0.205*"regard" + -0.175*"point" + -0.164*"market" + -0.162*"today" + '
#   '-0.154*"area" + 0.147*"second" + 0.140*"it" + -0.137*"country" + '
#   '-0.134*"decision" + -0.132*"think"'),
#  (21,
#   '-0.200*"projection" + -0.165*"effect" + -0.158*"central" + '
#   '0.147*"programme" + 0.146*"stability" + -0.143*"responsibility" + '
#   '-0.141*"oil" + 0.140*"month" + -0.127*"european" + -0.126*"inflation"'),
#  (22,
#   '-0.187*"instrument" + 0.186*"risk" + -0.184*"policy" + -0.149*"point" + '
#   '0.148*"well" + 0.143*"decision" + 0.140*"think" + 0.136*"interest" + '
#   '-0.127*"stability" + 0.123*"term"'),
#  (23,
#   '0.252*"level" + -0.229*"see" + -0.217*"decision" + -0.204*"growth" + '
#   '0.173*"situation" + 0.160*"area" + 0.139*"important" + -0.135*"look" + '
#   '0.131*"think" + -0.131*"market"'),
#  (24,
#   '0.197*"year" + 0.153*"credit" + -0.152*"second" + 0.151*"change" + '
#   '-0.149*"see" + -0.140*"information" + 0.124*"economy" + -0.122*"figure" + '
#   '-0.118*"growth" + -0.116*"mandate"'),
#  (25,
#   '-0.175*"point" + -0.169*"figure" + -0.166*"government" + 0.165*"measure" + '
#   '0.160*"think" + -0.154*"price" + 0.149*"important" + 0.137*"good" + '
#   '0.118*"it" + -0.118*"basis"'),
#  (26,
#   '-0.174*"confidence" + -0.172*"figure" + -0.170*"year" + 0.169*"reform" + '
#   '-0.158*"think" + 0.155*"already" + 0.151*"number" + -0.143*"bond" + '
#   '-0.140*"economy" + -0.118*"information"'),
#  (27,
#   '-0.221*"country" + 0.205*"area" + 0.185*"economy" + 0.165*"think" + '
#   '0.144*"figure" + -0.131*"fiscal" + 0.119*"so" + -0.118*"treaty" + '
#   '0.117*"interest" + -0.110*"meeting"'),
#  (28,
#   '-0.168*"increase" + 0.165*"programme" + -0.159*"it" + 0.156*"country" + '
#   '-0.140*"term" + 0.132*"certainly" + -0.128*"situation" + -0.126*"condition" '
#   '+ 0.115*"lending" + -0.106*"measure"'),
#  (29,
#   '-0.315*"see" + -0.176*"reason" + 0.147*"fiscal" + -0.140*"effect" + '
#   '0.124*"growth" + 0.119*"projection" + -0.111*"european" + 0.104*"past" + '
#   '-0.103*"year" + -0.102*"don"'),
#  (30,
#   '0.226*"exchange" + 0.182*"last" + -0.170*"interest" + -0.156*"clear" + '
#   '0.145*"regard" + -0.133*"change" + -0.116*"position" + 0.114*"currency" + '
#   '0.109*"well" + 0.107*"new"'),
#  (31,
#   '0.175*"financial" + -0.157*"year" + -0.133*"central" + -0.124*"important" + '
#   '-0.123*"exchange" + 0.123*"nonstandard" + -0.121*"bond" + '
#   '0.121*"expectation" + -0.120*"programme" + 0.116*"development"'),
#  (32,
#   '-0.269*"situation" + -0.168*"growth" + 0.141*"important" + 0.139*"course" + '
#   '-0.137*"area" + 0.120*"go" + -0.119*"exchange" + 0.113*"reason" + '
#   '-0.112*"assessment" + -0.110*"creation"'),
#  (33,
#   '0.152*"area" + -0.140*"level" + 0.126*"so" + -0.121*"government" + '
#   '0.116*"know" + -0.114*"economy" + -0.113*"thats" + 0.111*"case" + '
#   '-0.109*"clear" + -0.108*"reform"'),
#  (34,
#   '0.180*"situation" + -0.159*"regard" + 0.146*"well" + 0.144*"second" + '
#   '-0.134*"financial" + 0.126*"growth" + -0.122*"inflation" + '
#   '0.121*"particular" + 0.117*"quarter" + -0.109*"recovery"'),
#  (35,
#   '0.162*"government" + -0.145*"decision" + -0.137*"reason" + '
#   '0.131*"information" + 0.120*"different" + -0.113*"european" + '
#   '-0.112*"financial" + 0.110*"part" + 0.108*"exchange" + 0.105*"never"'),
#  (36,
#   '-0.238*"certainly" + 0.171*"central" + -0.167*"new" + 0.157*"think" + '
#   '-0.157*"meeting" + -0.148*"message" + -0.136*"government" + -0.121*"job" + '
#   '-0.112*"past" + 0.110*"projection"'),
#  (37,
#   '0.151*"important" + 0.144*"look" + -0.143*"responsibility" + '
#   '0.128*"country" + 0.124*"it" + 0.117*"mandate" + -0.114*"central" + '
#   '0.112*"give" + -0.102*"second" + -0.101*"today"'),
#  (38,
#   '0.195*"clear" + 0.193*"information" + -0.144*"global" + -0.134*"way" + '
#   '-0.123*"issue" + 0.123*"reform" + 0.108*"area" + 0.108*"recovery" + '
#   '0.107*"appropriate" + 0.107*"economy"'),
#  (39,
#   '-0.153*"think" + -0.147*"government" + -0.139*"loan" + 0.133*"stability" + '
#   '-0.133*"point" + -0.127*"month" + -0.122*"european" + 0.116*"liquidity" + '
#   '0.114*"actually" + -0.104*"meeting"'),
#  (40,
#   '0.151*"global" + -0.146*"projection" + 0.145*"ecb" + -0.137*"again" + '
#   '-0.135*"thing" + 0.121*"financial" + -0.119*"responsibility" + -0.117*"two" '
#   '+ -0.114*"new" + 0.109*"price"'),
#  (41,
#   '0.182*"ecb" + -0.167*"effect" + -0.156*"course" + -0.141*"point" + '
#   '-0.136*"interest" + 0.131*"year" + -0.123*"exchange" + -0.118*"programme" + '
#   '-0.113*"recovery" + -0.110*"mentioned"'),
#  (42,
#   '0.154*"figure" + -0.148*"change" + 0.142*"new" + -0.142*"period" + '
#   '-0.141*"last" + 0.128*"today" + -0.123*"meeting" + 0.112*"bond" + '
#   '0.109*"issue" + -0.107*"thing"'),
#  (43,
#   '0.151*"appropriate" + 0.141*"two" + -0.138*"change" + -0.136*"liquidity" + '
#   '0.123*"clear" + -0.121*"level" + -0.121*"come" + -0.117*"better" + '
#   '-0.109*"europe" + -0.104*"credit"'),
#  (44,
#   '0.170*"know" + -0.135*"global" + -0.131*"today" + 0.127*"take" + '
#   '0.119*"figure" + 0.114*"reform" + 0.111*"course" + -0.110*"possible" + '
#   '-0.109*"stance" + -0.104*"since"'),
#  (45,
#   '0.159*"account" + -0.148*"new" + 0.139*"recovery" + 0.136*"european" + '
#   '-0.134*"level" + 0.128*"possible" + -0.125*"next" + -0.114*"financial" + '
#   '0.113*"ecb" + -0.110*"month"'),
#  (46,
#   '-0.203*"important" + 0.141*"regard" + 0.135*"well" + -0.135*"credit" + '
#   '0.132*"think" + -0.130*"move" + -0.129*"confidence" + 0.119*"negative" + '
#   '0.117*"change" + 0.112*"again"'),
#  (47,
#   '-0.143*"look" + -0.128*"regard" + -0.127*"europe" + -0.119*"bond" + '
#   '-0.117*"interest" + 0.107*"today" + 0.105*"message" + -0.100*"inflation" + '
#   '0.098*"liquidity" + 0.097*"responsibility"'),
#  (48,
#   '0.166*"credit" + 0.158*"mandate" + -0.148*"programme" + 0.123*"taken" + '
#   '-0.114*"expectation" + -0.112*"year" + 0.111*"interest" + 0.100*"state" + '
#   '0.095*"important" + 0.095*"different"'),
#  (49,
#   '0.203*"ecb" + -0.159*"again" + 0.127*"figure" + -0.120*"let" + '
#   '-0.118*"appropriate" + -0.112*"statement" + -0.109*"see" + '
#   '0.106*"mentioned" + -0.105*"well" + 0.104*"course"'),
#  (50,
#   '0.163*"global" + 0.123*"development" + 0.117*"level" + -0.114*"decision" + '
#   '-0.112*"banking" + -0.110*"go" + 0.101*"balance" + 0.101*"today" + '
#   '-0.099*"meeting" + 0.099*"no"'),
#  (51,
#   '0.180*"money" + 0.126*"balance" + 0.124*"european" + 0.121*"policy" + '
#   '-0.115*"year" + 0.110*"effect" + 0.106*"liquidity" + 0.106*"last" + '
#   '-0.104*"rule" + -0.103*"monetary"'),
#  (52,
#   '0.153*"projection" + 0.131*"could" + 0.127*"ecb" + 0.126*"message" + '
#   '-0.125*"think" + -0.120*"price" + -0.117*"course" + 0.109*"state" + '
#   '-0.104*"oil" + -0.101*"policy"'),
#  (53,
#   '0.160*"financial" + 0.135*"let" + 0.126*"development" + 0.118*"system" + '
#   '0.114*"banking" + 0.112*"look" + 0.111*"know" + -0.109*"european" + '
#   '0.105*"new" + 0.105*"thats"'),
#  (54,
#   '-0.185*"last" + 0.141*"appropriate" + 0.130*"monetary" + -0.125*"policy" + '
#   '0.110*"stability" + 0.106*"financial" + 0.106*"actually" + 0.100*"term" + '
#   '-0.098*"come" + -0.097*"element"'),
#  (55,
#   '-0.148*"analysis" + -0.128*"figure" + 0.124*"today" + 0.116*"new" + '
#   '0.113*"point" + -0.112*"let" + -0.111*"development" + -0.111*"full" + '
#   '0.106*"like" + -0.104*"measure"'),
#  (56,
#   '-0.136*"continue" + 0.121*"impact" + -0.108*"possible" + 0.098*"condition" '
#   '+ -0.097*"balance" + -0.095*"close" + -0.095*"measure" + 0.094*"nothing" + '
#   '0.094*"public" + -0.092*"job"'),
#  (57,
#   '0.177*"certainly" + 0.177*"condition" + -0.146*"fact" + 0.123*"period" + '
#   '0.111*"factor" + -0.106*"bank" + -0.104*"different" + -0.102*"account" + '
#   '-0.102*"meeting" + 0.100*"central"'),
#  (58,
#   '-0.125*"term" + 0.113*"condition" + 0.104*"go" + -0.104*"mandate" + '
#   '-0.102*"analysis" + -0.100*"done" + 0.098*"statement" + 0.095*"fact" + '
#   '0.094*"mentioned" + -0.092*"public"'),
#  (59,
#   '-0.136*"actually" + -0.135*"basis" + -0.126*"no" + 0.122*"european" + '
#   '-0.118*"sector" + -0.118*"discussion" + -0.117*"going" + -0.113*"account" + '
#   '0.102*"balance" + 0.099*"go"'),
#  (60,
#   '-0.134*"second" + -0.133*"programme" + -0.123*"need" + 0.117*"always" + '
#   '-0.116*"lending" + 0.116*"interest" + -0.100*"institution" + -0.099*"take" '
#   '+ 0.094*"figure" + 0.092*"staff"'),
#  (61,
#   '0.114*"term" + 0.111*"lower" + 0.108*"judgement" + -0.100*"level" + '
#   '0.097*"account" + -0.096*"ab" + -0.096*"liquidity" + -0.096*"greece" + '
#   '0.096*"year" + 0.095*"data"'),
#  (62,
#   '0.135*"regard" + -0.129*"look" + 0.128*"let" + 0.112*"recovery" + '
#   '-0.111*"term" + 0.107*"quarter" + -0.106*"possible" + 0.104*"particular" + '
#   '0.103*"may" + 0.101*"third"'),
#  (63,
#   '0.142*"something" + 0.131*"important" + 0.127*"different" + '
#   '0.114*"stability" + 0.104*"expectation" + -0.104*"economic" + '
#   '-0.101*"committee" + -0.099*"confidence" + -0.099*"national" + '
#   '0.098*"regard"'),
#  (64,
#   '-0.146*"information" + 0.138*"confidence" + -0.137*"year" + 0.135*"lower" + '
#   '0.125*"better" + -0.115*"account" + -0.115*"possible" + -0.113*"situation" '
#   '+ -0.104*"medium" + -0.097*"comment"'),
#  (65,
#   '-0.142*"work" + -0.128*"tender" + -0.127*"know" + -0.109*"recovery" + '
#   '-0.108*"financial" + -0.105*"take" + 0.103*"policy" + -0.102*"even" + '
#   '0.100*"various" + 0.100*"phenomenon"'),
#  (66,
#   '0.143*"treaty" + 0.133*"way" + 0.128*"know" + -0.110*"done" + '
#   '-0.110*"capital" + 0.105*"increase" + 0.104*"programme" + 0.101*"full" + '
#   '-0.100*"come" + 0.097*"certainly"'),
#  (67,
#   '0.150*"credit" + -0.137*"regard" + -0.116*"number" + -0.114*"mandate" + '
#   '-0.100*"figure" + -0.097*"whether" + -0.096*"treaty" + -0.095*"observing" + '
#   '-0.092*"true" + -0.092*"go"'),
#  (68,
#   '0.143*"much" + -0.130*"comment" + 0.129*"work" + 0.123*"call" + '
#   '-0.116*"number" + -0.111*"growth" + -0.105*"could" + 0.103*"statement" + '
#   '0.097*"balance" + 0.094*"second"'),
#  (69,
#   '-0.214*"could" + -0.135*"year" + -0.116*"want" + 0.110*"responsibility" + '
#   '0.110*"know" + 0.109*"we" + 0.098*"ve" + 0.096*"fact" + -0.095*"structural" '
#   '+ -0.094*"and"'),
#  (70,
#   '0.127*"nonstandard" + 0.122*"believe" + -0.117*"could" + -0.099*"country" + '
#   '-0.098*"collateral" + 0.098*"projection" + -0.093*"ab" + 0.093*"survey" + '
#   '-0.090*"security" + -0.089*"again"'),
#  (71,
#   '0.120*"take" + -0.119*"structural" + 0.109*"analysis" + -0.106*"measure" + '
#   '0.102*"second" + 0.099*"thing" + 0.098*"ab" + 0.095*"currency" + '
#   '-0.093*"ecb" + 0.091*"volatility"'),
#  (72,
#   '-0.157*"exchange" + 0.139*"case" + 0.113*"course" + 0.104*"made" + '
#   '-0.101*"again" + -0.100*"nonstandard" + 0.100*"assessment" + '
#   '-0.095*"projection" + -0.095*"government" + 0.093*"call"'),
#  (73,
#   '-0.158*"already" + 0.150*"fully" + 0.126*"period" + -0.112*"take" + '
#   '-0.106*"whether" + 0.103*"much" + -0.099*"make" + -0.091*"element" + '
#   '0.089*"change" + -0.088*"might"'),
#  (74,
#   '0.167*"already" + 0.119*"taken" + 0.115*"account" + -0.105*"rule" + '
#   '0.098*"world" + 0.090*"much" + -0.087*"balance" + 0.083*"money" + '
#   '0.083*"might" + -0.082*"appropriate"'),
#  (75,
#   '0.125*"course" + -0.121*"area" + -0.112*"economic" + 0.108*"last" + '
#   '-0.105*"recovery" + -0.103*"intervention" + 0.100*"regard" + '
#   '-0.094*"factor" + -0.094*"discussion" + 0.093*"long"'),
#  (76,
#   '0.140*"again" + -0.138*"want" + -0.123*"present" + -0.108*"statement" + '
#   '-0.107*"central" + -0.105*"close" + -0.102*"far" + -0.097*"currency" + '
#   '0.084*"line" + -0.083*"important"'),
#  (77,
#   '-0.128*"look" + -0.128*"case" + -0.120*"fiscal" + 0.108*"currency" + '
#   '0.108*"assessment" + 0.105*"figure" + 0.104*"fully" + -0.104*"mentioned" + '
#   '0.103*"work" + 0.102*"second"'),
#  (78,
#   '0.130*"fact" + 0.104*"message" + 0.104*"fiscal" + -0.098*"mentioned" + '
#   '-0.095*"growth" + -0.094*"europe" + -0.091*"episode" + -0.091*"observed" + '
#   '-0.090*"expectation" + 0.089*"way"'),
#  (79,
#   '0.124*"month" + -0.106*"basis" + -0.105*"responsibility" + 0.100*"thing" + '
#   '0.096*"discussion" + 0.094*"authority" + 0.091*"projection" + '
#   '-0.090*"press" + -0.089*"operation" + 0.089*"done"'),
#  (80,
#   '0.131*"still" + 0.129*"therefore" + 0.113*"judgement" + -0.107*"message" + '
#   '-0.100*"public" + -0.100*"balance" + -0.096*"really" + 0.093*"uncertainty" '
#   '+ -0.090*"move" + -0.090*"liquidity"'),
#  (81,
#   '-0.118*"central" + 0.114*"figure" + 0.113*"today" + -0.109*"take" + '
#   '0.092*"problem" + 0.092*"ecb" + -0.088*"answer" + 0.088*"low" + '
#   '-0.088*"another" + 0.086*"currency"'),
#  (82,
#   '-0.135*"well" + -0.133*"could" + -0.116*"currency" + 0.114*"today" + '
#   '-0.112*"statement" + 0.111*"real" + 0.099*"different" + 0.094*"national" + '
#   '-0.094*"low" + -0.093*"responsibility"'),
#  (83,
#   '0.148*"message" + 0.115*"position" + 0.103*"so" + 0.100*"something" + '
#   '0.099*"large" + -0.096*"done" + 0.093*"past" + 0.092*"united" + '
#   '-0.091*"basis" + 0.086*"again"'),
#  (84,
#   '0.137*"month" + -0.131*"member" + -0.123*"uncertainty" + -0.105*"comment" + '
#   '-0.096*"come" + 0.094*"real" + 0.090*"development" + 0.088*"united" + '
#   '0.087*"including" + 0.087*"nonstandard"'),
#  (85,
#   '-0.109*"present" + 0.108*"liquidity" + 0.102*"certainly" + '
#   '-0.100*"statement" + 0.100*"europe" + -0.099*"monetary" + -0.098*"month" + '
#   '0.094*"state" + -0.093*"draw" + 0.091*"long"'),
#  (86,
#   '0.105*"statement" + 0.102*"recovery" + -0.099*"economic" + '
#   '-0.099*"assessment" + 0.098*"basis" + -0.097*"position" + 0.097*"important" '
#   '+ 0.097*"institution" + -0.092*"know" + -0.091*"think"'),
#  (87,
#   '-0.115*"come" + -0.113*"financial" + 0.104*"future" + -0.102*"different" + '
#   '-0.095*"make" + -0.094*"bond" + -0.093*"know" + 0.092*"good" + '
#   '-0.089*"month" + 0.087*"government"'),
#  (88,
#   '0.145*"always" + -0.136*"different" + -0.111*"new" + -0.091*"all" + '
#   '0.089*"sign" + 0.089*"made" + 0.088*"statement" + -0.086*"course" + '
#   '-0.085*"number" + 0.085*"eurogroup"'),
#  (89,
#   '-0.134*"economic" + 0.124*"today" + 0.116*"credit" + -0.115*"much" + '
#   '0.102*"note" + 0.097*"europe" + 0.093*"increase" + 0.091*"again" + '
#   '-0.088*"made" + 0.087*"really"'),
#  (90,
#   '0.162*"expectation" + -0.151*"european" + -0.110*"country" + 0.104*"greece" '
#   '+ -0.104*"different" + -0.103*"risk" + -0.101*"no" + -0.099*"two" + '
#   '-0.095*"economy" + 0.087*"responsibility"'),
#  (91,
#   '0.113*"particular" + -0.105*"regard" + 0.099*"today" + -0.098*"view" + '
#   '-0.094*"now" + 0.092*"measure" + -0.091*"mandate" + 0.089*"made" + '
#   '-0.084*"new" + -0.082*"without"'),
#  (92,
#   '0.138*"period" + -0.110*"mean" + 0.104*"basis" + -0.097*"term" + '
#   '0.097*"exchange" + 0.096*"state" + 0.094*"sign" + -0.089*"possible" + '
#   '-0.080*"consider" + -0.079*"factor"'),
#  (93,
#   '-0.112*"situation" + -0.103*"comment" + -0.100*"global" + 0.097*"clear" + '
#   '0.095*"direction" + 0.093*"operation" + 0.093*"everything" + '
#   '0.092*"exchange" + -0.090*"need" + 0.089*"part"'),
#  (94,
#   '-0.131*"real" + -0.120*"economic" + -0.107*"credible" + 0.105*"data" + '
#   '0.100*"large" + 0.096*"continue" + -0.094*"banking" + -0.091*"course" + '
#   '0.089*"may" + 0.086*"inflation"'),
#  (95,
#   '0.110*"operation" + -0.106*"message" + -0.102*"looking" + -0.091*"exactly" '
#   '+ 0.084*"point" + -0.080*"data" + -0.079*"sector" + -0.078*"ecb" + '
#   '0.078*"certainly" + 0.078*"high"'),
#  (96,
#   '-0.091*"message" + -0.090*"future" + 0.089*"main" + -0.087*"quite" + '
#   '-0.087*"discussed" + 0.086*"assumption" + 0.085*"kind" + -0.084*"see" + '
#   '-0.083*"important" + 0.083*"interest"'),
#  (97,
#   '0.151*"position" + -0.095*"quarter" + -0.095*"reason" + -0.090*"situation" '
#   '+ -0.089*"ab" + 0.088*"whole" + -0.085*"functioning" + 0.083*"ireland" + '
#   '-0.080*"cost" + 0.079*"negative"'),
#  (98,
#   '-0.122*"currency" + -0.107*"recovery" + -0.101*"issue" + 0.098*"authority" '
#   '+ 0.097*"real" + -0.097*"view" + 0.096*"remain" + -0.095*"good" + '
#   '-0.094*"so" + -0.093*"going"'),
#  (99,
#   '-0.117*"mentioned" + -0.110*"purchase" + -0.108*"new" + 0.103*"figure" + '
#   '0.097*"answer" + 0.097*"close" + -0.095*"oil" + -0.092*"environment" + '
#   '-0.087*"principle" + -0.086*"second"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.



coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)


coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='u_mass')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)
# Out:
# Coherence Score:  0.25611330623034756
#
# Coherence Score5:  0.3219423189227545
#
# Coherence Score10:  0.3223122530866651
#
# Coherence Score20:  0.2734173400869614
#
# Coherence Score50:  0.25490750845248256
#
# Coherence Score100:  0.23092173766884735
#
# Coherence Score:  -0.08709861031715181
#
# Coherence Score5:  -0.25007873963317373
#
# Coherence Score10:  -0.33207712861297056
#
# Coherence Score20:  -0.40096841610535866
#
# Coherence Score50:  -0.8211611437484474
#
# Coherence Score100:  -0.683707400909619
