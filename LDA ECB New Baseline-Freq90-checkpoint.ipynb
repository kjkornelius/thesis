# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['Press']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(4394 unique tokens: ['able', 'acceptable', 'accompanied', 'according', 'account']...)

# %%
# filter words that occur in more than 90% of documents
id2word.filter_extremes(no_above = 0.900)
print(id2word)
# Out:
# Dictionary(1940 unique tokens: ['able', 'accompanied', 'according', 'account', 'achievement']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=1, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
lda_model5 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model10 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model20 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model50 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=50, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

lda_model100 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=100, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\models\ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
# Print the Keyword in the 1 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.009*"loan" + 0.009*"analysis" + 0.008*"measure" + 0.008*"quarter" + '
#   '0.008*"recovery" + 0.006*"support" + 0.006*"financial" + 0.006*"credit" + '
#   '0.005*"condition" + 0.005*"necessary"')]

# %%
# Print the Keyword in the 5 topics
pprint(lda_model5.print_topics())
doc_lda = lda_model5[corpus]

# Print the Keyword in the 10 topics
pprint(lda_model10.print_topics())
doc_lda = lda_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lda_model20.print_topics())
doc_lda = lda_model20[corpus]

# Print the Keyword in the 50 topics
pprint(lda_model50.print_topics())
doc_lda = lda_model50[corpus]

# Print the Keyword in the 100 topics
pprint(lda_model100.print_topics())
doc_lda = lda_model100[corpus]
# Out:
# [(0,
#   '0.010*"recent" + 0.009*"oil" + 0.007*"however" + 0.007*"analysis" + '
#   '0.006*"pressure" + 0.006*"effect" + 0.006*"past" + 0.006*"recovery" + '
#   '0.006*"low" + 0.006*"confidence"'),
#  (1,
#   '0.010*"upside" + 0.009*"analysis" + 0.009*"strong" + 0.008*"remains" + '
#   '0.008*"credit" + 0.007*"recent" + 0.006*"wage" + 0.006*"ongoing" + '
#   '0.006*"support" + 0.006*"effect"'),
#  (2,
#   '0.011*"loan" + 0.011*"financial" + 0.010*"analysis" + 0.008*"measure" + '
#   '0.007*"line" + 0.007*"expectation" + 0.006*"credit" + 0.006*"activity" + '
#   '0.006*"pressure" + 0.006*"bank"'),
#  (3,
#   '0.014*"recovery" + 0.014*"measure" + 0.013*"loan" + 0.012*"quarter" + '
#   '0.010*"analysis" + 0.010*"purchase" + 0.009*"implementation" + '
#   '0.008*"necessary" + 0.008*"support" + 0.008*"condition"'),
#  (4,
#   '0.008*"first" + 0.007*"recent" + 0.006*"bank" + 0.006*"financial" + '
#   '0.006*"decision" + 0.006*"january" + 0.005*"central" + 0.005*"regard" + '
#   '0.005*"consumer" + 0.005*"second"')]
# [(0,
#   '0.001*"accumulation" + 0.001*"pressure" + 0.001*"appreciation" + '
#   '0.001*"oil" + 0.001*"low" + 0.001*"liquidity" + 0.001*"recent" + '
#   '0.001*"activity" + 0.001*"strong" + 0.001*"treaty"'),
#  (1,
#   '0.009*"analysis" + 0.008*"upside" + 0.008*"strong" + 0.007*"remains" + '
#   '0.007*"recent" + 0.007*"credit" + 0.007*"activity" + 0.006*"ongoing" + '
#   '0.006*"effect" + 0.006*"labour"'),
#  (2,
#   '0.014*"financial" + 0.013*"measure" + 0.012*"loan" + 0.010*"pressure" + '
#   '0.010*"analysis" + 0.009*"may" + 0.009*"undue" + 0.009*"bank" + '
#   '0.009*"commodity" + 0.008*"support"'),
#  (3,
#   '0.014*"recovery" + 0.014*"measure" + 0.013*"loan" + 0.012*"quarter" + '
#   '0.010*"analysis" + 0.010*"purchase" + 0.009*"implementation" + '
#   '0.008*"necessary" + 0.008*"support" + 0.008*"condition"'),
#  (4,
#   '0.015*"bank" + 0.013*"banknote" + 0.013*"central" + 0.011*"national" + '
#   '0.011*"first" + 0.008*"reference" + 0.008*"decision" + 0.008*"value" + '
#   '0.008*"financial" + 0.007*"european"'),
#  (5,
#   '0.001*"recent" + 0.001*"oil" + 0.001*"regard" + 0.001*"recovery" + '
#   '0.001*"quarter" + 0.001*"financial" + 0.001*"first" + 0.001*"activity" + '
#   '0.001*"support" + 0.001*"low"'),
#  (6,
#   '0.001*"derivation" + 0.001*"reference" + 0.001*"value" + 0.001*"velocity" + '
#   '0.001*"escb" + 0.001*"central" + 0.001*"cash" + 0.001*"banknote" + '
#   '0.001*"legal" + 0.001*"changeover"'),
#  (7,
#   '0.012*"recent" + 0.011*"oil" + 0.008*"however" + 0.006*"regard" + '
#   '0.006*"recovery" + 0.006*"confidence" + 0.006*"effect" + 0.006*"would" + '
#   '0.006*"wage" + 0.006*"pressure"'),
#  (8,
#   '0.019*"operation" + 0.011*"refinancing" + 0.011*"facility" + '
#   '0.011*"january" + 0.011*"main" + 0.009*"tender" + 0.009*"point" + '
#   '0.008*"threemonth" + 0.008*"eurosystem" + 0.008*"first"'),
#  (9,
#   '0.014*"loan" + 0.011*"analysis" + 0.010*"financial" + 0.009*"credit" + '
#   '0.009*"quarter" + 0.009*"subdued" + 0.007*"demand" + 0.007*"downside" + '
#   '0.007*"line" + 0.007*"nonfinancial"')]
# [(0,
#   '0.001*"oil" + 0.001*"pressure" + 0.001*"remains" + 0.001*"recent" + '
#   '0.001*"strong" + 0.001*"wage" + 0.001*"activity" + 0.001*"regard" + '
#   '0.001*"line" + 0.001*"information"'),
#  (1,
#   '0.031*"referred" + 0.012*"fulfilled" + 0.000*"financial" + 0.000*"bank" + '
#   '0.000*"balance" + 0.000*"activity" + 0.000*"analysis" + 0.000*"central" + '
#   '0.000*"agreement" + 0.000*"derived"'),
#  (2,
#   '0.008*"analysis" + 0.007*"recent" + 0.007*"strong" + 0.007*"pressure" + '
#   '0.007*"effect" + 0.007*"support" + 0.006*"remains" + 0.006*"upside" + '
#   '0.006*"expectation" + 0.006*"activity"'),
#  (3,
#   '0.046*"oil" + 0.028*"favourable" + 0.024*"ample" + 0.022*"upside" + '
#   '0.017*"vigilance" + 0.016*"strong" + 0.013*"liquidity" + 0.012*"longer" + '
#   '0.012*"ensure" + 0.012*"efficiency"'),
#  (4,
#   '0.011*"first" + 0.008*"decision" + 0.007*"bank" + 0.007*"january" + '
#   '0.007*"central" + 0.007*"consumer" + 0.007*"recent" + 0.006*"main" + '
#   '0.006*"second" + 0.006*"banknote"'),
#  (5,
#   '0.001*"recent" + 0.001*"oil" + 0.001*"regard" + 0.001*"first" + '
#   '0.001*"activity" + 0.001*"support" + 0.001*"consumer" + 0.001*"past" + '
#   '0.001*"would" + 0.001*"strong"'),
#  (6,
#   '0.001*"however" + 0.001*"oil" + 0.001*"recent" + 0.001*"first" + '
#   '0.001*"banknote" + 0.001*"regard" + 0.001*"decision" + 0.001*"particular" + '
#   '0.001*"available" + 0.001*"activity"'),
#  (7,
#   '0.001*"recent" + 0.001*"oil" + 0.001*"regard" + 0.001*"information" + '
#   '0.001*"remains" + 0.001*"first" + 0.001*"analysis" + 0.001*"high" + '
#   '0.001*"data" + 0.001*"however"'),
#  (8,
#   '0.001*"recent" + 0.001*"allotment" + 0.001*"financial" + 0.001*"oil" + '
#   '0.001*"remains" + 0.001*"analysis" + 0.001*"refinancing" + 0.001*"first" + '
#   '0.001*"data" + 0.001*"fixed"'),
#  (9,
#   '0.013*"recent" + 0.009*"high" + 0.008*"however" + 0.008*"decline" + '
#   '0.008*"financial" + 0.008*"factor" + 0.007*"uncertainty" + 0.007*"activity" '
#   '+ 0.007*"confidence" + 0.007*"potential"'),
#  (10,
#   '0.001*"recent" + 0.001*"oil" + 0.001*"continued" + 0.001*"need" + '
#   '0.001*"analysis" + 0.001*"favourable" + 0.001*"strong" + 0.001*"low" + '
#   '0.001*"context" + 0.001*"would"'),
#  (11,
#   '0.001*"recent" + 0.001*"contraction" + 0.001*"analysis" + 0.001*"first" + '
#   '0.001*"oil" + 0.001*"data" + 0.001*"available" + 0.001*"quarter" + '
#   '0.001*"particular" + 0.001*"labour"'),
#  (12,
#   '0.013*"recovery" + 0.013*"loan" + 0.012*"quarter" + 0.012*"purchase" + '
#   '0.012*"measure" + 0.010*"necessary" + 0.010*"implementation" + '
#   '0.010*"condition" + 0.010*"analysis" + 0.009*"support"'),
#  (13,
#   '0.001*"oil" + 0.001*"analysis" + 0.001*"recent" + 0.001*"remains" + '
#   '0.001*"effect" + 0.001*"wage" + 0.001*"first" + 0.001*"liquidity" + '
#   '0.001*"activity" + 0.001*"quarter"'),
#  (14,
#   '0.001*"recent" + 0.001*"analysis" + 0.001*"quarter" + 0.001*"activity" + '
#   '0.001*"particular" + 0.001*"pressure" + 0.001*"financial" + '
#   '0.001*"recovery" + 0.001*"unchanged" + 0.001*"condition"'),
#  (15,
#   '0.016*"loan" + 0.014*"financial" + 0.013*"analysis" + 0.011*"measure" + '
#   '0.010*"bank" + 0.009*"nonfinancial" + 0.008*"credit" + 0.008*"underlying" + '
#   '0.008*"quarter" + 0.008*"line"'),
#  (16,
#   '0.017*"measure" + 0.016*"recovery" + 0.015*"loan" + 0.015*"june" + '
#   '0.012*"staff" + 0.012*"march" + 0.012*"projection" + 0.012*"quarter" + '
#   '0.010*"analysis" + 0.009*"april"'),
#  (17,
#   '0.001*"recent" + 0.001*"first" + 0.001*"regard" + 0.001*"oil" + '
#   '0.001*"financial" + 0.001*"consumer" + 0.001*"cash" + 0.001*"value" + '
#   '0.001*"upward" + 0.001*"second"'),
#  (18,
#   '0.030*"industrialised" + 0.027*"precondition" + 0.017*"termsoftrade" + '
#   '0.011*"precautionary" + 0.009*"examine" + 0.007*"summary" + '
#   '0.005*"undermining" + 0.004*"accumulation" + 0.002*"appreciation" + '
#   '0.001*"article"'),
#  (19,
#   '0.183*"turmoil" + 0.096*"diminishing" + 0.017*"middle" + 0.016*"recognised" '
#   '+ 0.015*"policymaking" + 0.014*"intensified" + 0.010*"undermining" + '
#   '0.010*"resulted" + 0.009*"drop" + 0.006*"definition"')]
# [(5,
#   '0.001*"recent" + 0.001*"oil" + 0.001*"recovery" + 0.001*"financial" + '
#   '0.001*"data" + 0.001*"support" + 0.001*"regard" + 0.001*"would" + '
#   '0.001*"low" + 0.001*"wage"'),
#  (10,
#   '0.001*"need" + 0.001*"favourable" + 0.001*"low" + 0.001*"continued" + '
#   '0.001*"domestic" + 0.001*"analysis" + 0.001*"context" + 0.001*"line" + '
#   '0.001*"upside" + 0.001*"recent"'),
#  (13,
#   '0.001*"oil" + 0.001*"analysis" + 0.001*"recent" + 0.001*"remains" + '
#   '0.001*"effect" + 0.001*"wage" + 0.001*"quarter" + 0.001*"support" + '
#   '0.001*"liquidity" + 0.001*"labour"'),
#  (35,
#   '0.001*"first" + 0.001*"oil" + 0.001*"quarter" + 0.001*"recent" + '
#   '0.001*"second" + 0.001*"strong" + 0.001*"particular" + 0.001*"regard" + '
#   '0.001*"pressure" + 0.001*"confidence"'),
#  (17,
#   '0.001*"financial" + 0.001*"recent" + 0.001*"first" + 0.001*"regard" + '
#   '0.001*"oil" + 0.001*"condition" + 0.001*"january" + 0.001*"wage" + '
#   '0.001*"second" + 0.001*"decision"'),
#  (6,
#   '0.001*"banknote" + 0.001*"however" + 0.001*"decision" + 0.001*"recent" + '
#   '0.001*"regard" + 0.001*"data" + 0.001*"first" + 0.001*"central" + '
#   '0.001*"bank" + 0.001*"financial"'),
#  (0,
#   '0.001*"oil" + 0.001*"upward" + 0.001*"first" + 0.001*"recent" + '
#   '0.001*"line" + 0.001*"remains" + 0.001*"strong" + 0.001*"pressure" + '
#   '0.001*"quarter" + 0.001*"regard"'),
#  (36,
#   '0.001*"recent" + 0.001*"first" + 0.001*"central" + 0.001*"bank" + '
#   '0.001*"national" + 0.001*"however" + 0.001*"data" + 0.001*"regard" + '
#   '0.001*"oil" + 0.001*"decision"'),
#  (43,
#   '0.001*"oil" + 0.001*"recent" + 0.001*"strong" + 0.001*"financial" + '
#   '0.001*"favourable" + 0.001*"first" + 0.001*"high" + 0.001*"quarter" + '
#   '0.001*"available" + 0.001*"consumer"'),
#  (22,
#   '0.001*"oil" + 0.001*"recent" + 0.001*"would" + 0.001*"financial" + '
#   '0.001*"data" + 0.001*"first" + 0.001*"regard" + 0.001*"condition" + '
#   '0.001*"pressure" + 0.001*"effect"'),
#  (2,
#   '0.207*"scheme" + 0.101*"remuneration" + 0.078*"spill" + 0.053*"assume" + '
#   '0.053*"demanding" + 0.046*"obtain" + 0.030*"complicate" + 0.026*"ever" + '
#   '0.000*"organised" + 0.000*"treaty"'),
#  (16,
#   '0.046*"ample" + 0.036*"liquidity" + 0.028*"elevated" + 0.027*"warranted" + '
#   '0.026*"prerequisite" + 0.024*"job" + 0.021*"environment" + 0.021*"creation" '
#   '+ 0.021*"contribution" + 0.020*"strengthen"'),
#  (38,
#   '0.025*"strong" + 0.024*"consumer" + 0.018*"determination" + 0.016*"second" '
#   '+ 0.015*"first" + 0.013*"tender" + 0.013*"pillar" + 0.013*"expansion" + '
#   '0.013*"main" + 0.012*"noninflationary"'),
#  (30,
#   '0.038*"bank" + 0.029*"central" + 0.027*"national" + 0.020*"system" + '
#   '0.017*"eligible" + 0.017*"target" + 0.015*"reserve" + 0.015*"release" + '
#   '0.014*"escb" + 0.014*"press"'),
#  (25,
#   '0.011*"recent" + 0.008*"first" + 0.007*"regard" + 0.007*"financial" + '
#   '0.006*"however" + 0.006*"decision" + 0.006*"data" + 0.005*"information" + '
#   '0.005*"january" + 0.005*"second"'),
#  (15,
#   '0.016*"operation" + 0.016*"enterprise" + 0.013*"bank" + 0.012*"quarter" + '
#   '0.011*"underpins" + 0.011*"refinancing" + 0.011*"relate" + '
#   '0.011*"essential" + 0.011*"analysis" + 0.010*"loan"'),
#  (39,
#   '0.010*"analysis" + 0.010*"upside" + 0.009*"strong" + 0.009*"recent" + '
#   '0.008*"remains" + 0.007*"effect" + 0.007*"pressure" + 0.007*"oil" + '
#   '0.007*"support" + 0.007*"labour"'),
#  (29,
#   '0.019*"financial" + 0.013*"loan" + 0.013*"analysis" + 0.012*"expectation" + '
#   '0.011*"line" + 0.010*"activity" + 0.009*"subdued" + 0.009*"pressure" + '
#   '0.009*"demand" + 0.009*"nonfinancial"'),
#  (48,
#   '0.018*"loan" + 0.017*"measure" + 0.013*"recovery" + 0.012*"march" + '
#   '0.011*"credit" + 0.011*"quarter" + 0.010*"april" + 0.010*"analysis" + '
#   '0.009*"purchase" + 0.007*"supported"'),
#  (12,
#   '0.014*"recovery" + 0.013*"quarter" + 0.011*"measure" + 0.011*"loan" + '
#   '0.011*"implementation" + 0.010*"necessary" + 0.010*"support" + '
#   '0.010*"analysis" + 0.009*"condition" + 0.009*"purchase"')]
# [(5,
#   '0.001*"recovery" + 0.001*"recent" + 0.001*"course" + 0.001*"past" + '
#   '0.001*"activity" + 0.001*"low" + 0.001*"remains" + 0.001*"first" + '
#   '0.001*"favourable" + 0.001*"moderate"'),
#  (6,
#   '0.001*"available" + 0.001*"first" + 0.001*"second" + 0.001*"central" + '
#   '0.001*"course" + 0.001*"high" + 0.001*"january" + 0.001*"favourable" + '
#   '0.001*"conference" + 0.001*"upward"'),
#  (10,
#   '0.001*"favourable" + 0.001*"expansion" + 0.001*"remains" + '
#   '0.001*"condition" + 0.001*"wage" + 0.001*"moderate" + 0.001*"context" + '
#   '0.001*"credit" + 0.001*"upside" + 0.001*"analysis"'),
#  (13,
#   '0.001*"analysis" + 0.001*"projection" + 0.001*"oil" + 0.001*"remains" + '
#   '0.001*"past" + 0.001*"liquidity" + 0.001*"gdp" + 0.001*"low" + '
#   '0.001*"activity" + 0.001*"broadly"'),
#  (90,
#   '0.001*"analysis" + 0.001*"oil" + 0.001*"energy" + 0.001*"remains" + '
#   '0.001*"mainly" + 0.001*"activity" + 0.001*"strong" + 0.001*"low" + '
#   '0.001*"recent" + 0.001*"pressure"'),
#  (96,
#   '0.001*"projection" + 0.001*"activity" + 0.001*"june" + 0.001*"strong" + '
#   '0.001*"gdp" + 0.001*"eurosystem" + 0.001*"would" + 0.001*"already" + '
#   '0.001*"decided" + 0.001*"ongoing"'),
#  (66,
#   '0.001*"recent" + 0.001*"data" + 0.001*"january" + 0.001*"since" + '
#   '0.001*"three" + 0.001*"previous" + 0.001*"background" + 0.001*"operation" + '
#   '0.001*"unchanged" + 0.001*"may"'),
#  (22,
#   '0.001*"oil" + 0.001*"projection" + 0.001*"gdp" + 0.001*"first" + '
#   '0.001*"recent" + 0.001*"credit" + 0.001*"would" + 0.001*"quarter" + '
#   '0.001*"effect" + 0.001*"recovery"'),
#  (53,
#   '0.001*"financial" + 0.001*"central" + 0.001*"recent" + 0.001*"confidence" + '
#   '0.001*"member" + 0.001*"however" + 0.001*"gdp" + 0.001*"bank" + '
#   '0.001*"national" + 0.001*"wage"'),
#  (81,
#   '0.001*"data" + 0.001*"financial" + 0.001*"consumer" + 0.001*"april" + '
#   '0.001*"addition" + 0.001*"indicator" + 0.001*"activity" + 0.001*"since" + '
#   '0.001*"decision" + 0.001*"january"'),
#  (64,
#   '0.716*"undue" + 0.090*"entrenched" + 0.032*"though" + 0.017*"resulted" + '
#   '0.000*"compliance" + 0.000*"encouraged" + 0.000*"favourable" + '
#   '0.000*"condition" + 0.000*"implementation" + 0.000*"stated"'),
#  (38,
#   '0.064*"preserving" + 0.064*"august" + 0.056*"adverse" + 0.054*"option" + '
#   '0.037*"elsewhere" + 0.034*"steep" + 0.031*"composition" + 0.029*"tender" + '
#   '0.028*"fixed" + 0.024*"absorbed"'),
#  (12,
#   '0.847*"swift" + 0.000*"pick" + 0.000*"favourable" + 0.000*"recovery" + '
#   '0.000*"oil" + 0.000*"compliance" + 0.000*"support" + 0.000*"adjusted" + '
#   '0.000*"path" + 0.000*"effect"'),
#  (48,
#   '0.694*"extension" + 0.043*"waning" + 0.037*"technology" + 0.022*"edge" + '
#   '0.022*"contains" + 0.019*"countries" + 0.017*"interpretation" + '
#   '0.016*"remuneration" + 0.013*"appropriately" + 0.000*"decreasing"'),
#  (56,
#   '0.026*"pressure" + 0.024*"recent" + 0.022*"inflationary" + 0.018*"need" + '
#   '0.017*"confidence" + 0.016*"contained" + 0.016*"domestic" + 0.016*"however" '
#   '+ 0.014*"allotment" + 0.013*"could"'),
#  (94,
#   '0.019*"strong" + 0.016*"oil" + 0.016*"recent" + 0.014*"wage" + '
#   '0.012*"effect" + 0.011*"enhancement" + 0.011*"upside" + 0.010*"would" + '
#   '0.010*"consumer" + 0.010*"high"'),
#  (59,
#   '0.015*"financial" + 0.009*"operation" + 0.009*"period" + 0.008*"bank" + '
#   '0.007*"data" + 0.007*"january" + 0.007*"decline" + 0.007*"decided" + '
#   '0.007*"recent" + 0.007*"may"'),
#  (73,
#   '0.026*"may" + 0.022*"first" + 0.022*"adjusted" + 0.019*"relationship" + '
#   '0.019*"intended" + 0.018*"composition" + 0.017*"repeatedly" + '
#   '0.017*"enterprise" + 0.013*"uncertainty" + 0.013*"achieve"'),
#  (52,
#   '0.015*"analysis" + 0.009*"activity" + 0.008*"support" + 0.008*"line" + '
#   '0.008*"expectation" + 0.008*"financial" + 0.008*"credit" + 0.007*"loan" + '
#   '0.007*"remains" + 0.006*"ongoing"'),
#  (58,
#   '0.017*"recovery" + 0.016*"loan" + 0.016*"measure" + 0.014*"quarter" + '
#   '0.011*"analysis" + 0.011*"implementation" + 0.010*"purchase" + '
#   '0.010*"necessary" + 0.009*"support" + 0.009*"condition"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity5: ', lda_model5.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity10: ', lda_model10.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity20: ', lda_model20.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity50: ', lda_model50.log_perplexity(corpus))  # a measure of how good the model is. lower the better.
print('\nPerplexity100: ', lda_model100.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100: ', coherence_lda)


# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence ScoreUMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score5UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score10UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score20UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score50UMass: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score100UMass: ', coherence_lda)
# Out:
# Perplexity:  -6.978832980602515
#
# Perplexity5:  -6.767819087678118
#
# Perplexity10:  -6.783274147802905
#
# Perplexity20:  -6.831110605354843
#
# Perplexity50:  -6.891769550640171
#
# Perplexity100:  -8.295755903680451
#
# Coherence Score:  0.40655708281536285
#
# Coherence Score5:  0.3443464108254094
#
# Coherence Score10:  0.40300051905035045
#
# Coherence Score20:  0.3204572636799415
#
# Coherence Score50:  0.3140445133771953
#
# Coherence Score100:  0.2983083910261611
#
# Coherence ScoreUMass:  -0.36062027660450846
#
# Coherence Score5UMass:  -0.3581313958133607
#
# Coherence Score10UMass:  -0.4948022066589095
#
# Coherence Score20UMass:  -0.6359567922876141
#
# Coherence Score50UMass:  -0.6392607188507902
#
# Coherence Score100UMass:  -0.7620415949720715
