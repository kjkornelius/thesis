# %%
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['Press']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(4394 unique tokens: ['able', 'acceptable', 'accompanied', 'according', 'account']...)

# %%
# less than 10 documents,
id2word = corpora.Dictionary(data)
id2word.filter_extremes(no_below = 4)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.203*"projection" + 0.157*"staff" + 0.130*"operation" + 0.115*"december" + '
#   '0.110*"commodity" + 0.106*"january" + 0.102*"september" + 0.096*"march" + '
#   '0.093*"to" + 0.093*"june"')]
# [(0,
#   '0.203*"projection" + 0.157*"staff" + 0.130*"operation" + 0.115*"december" + '
#   '0.110*"commodity" + 0.106*"january" + 0.102*"september" + 0.096*"march" + '
#   '0.093*"to" + 0.093*"june"'),
#  (1,
#   '-0.254*"central" + -0.210*"national" + 0.202*"projection" + '
#   '-0.185*"banknote" + -0.174*"escb" + -0.158*"three" + -0.147*"january" + '
#   '-0.144*"reference" + -0.142*"system" + -0.137*"value"'),
#  (2,
#   '-0.230*"operation" + -0.160*"subdued" + -0.153*"refinancing" + '
#   '0.135*"trend" + -0.131*"below" + -0.130*"to" + -0.119*"purchase" + '
#   '0.115*"food" + 0.113*"longer" + 0.109*"robust"'),
#  (3,
#   '-0.401*"projection" + -0.262*"staff" + 0.177*"commodity" + '
#   '-0.162*"purchase" + 0.146*"keeping" + 0.142*"negative" + '
#   '0.137*"policyrelevant" + 0.128*"tension" + 0.123*"aim" + 0.115*"deposit"'),
#  (4,
#   '0.406*"projection" + 0.281*"staff" + 0.234*"range" + -0.177*"subdued" + '
#   '-0.148*"gradual" + 0.132*"operation" + -0.130*"purchase" + '
#   '0.114*"commodity" + -0.112*"pillar" + -0.104*"asset"')]
# [(0,
#   '0.203*"projection" + 0.157*"staff" + 0.130*"operation" + 0.115*"december" + '
#   '0.110*"commodity" + 0.106*"january" + 0.102*"september" + 0.096*"march" + '
#   '0.093*"to" + 0.093*"june"'),
#  (1,
#   '-0.254*"central" + -0.210*"national" + 0.202*"projection" + '
#   '-0.185*"banknote" + -0.174*"escb" + -0.158*"three" + -0.147*"january" + '
#   '-0.144*"reference" + -0.142*"system" + -0.137*"value"'),
#  (2,
#   '-0.230*"operation" + -0.160*"subdued" + -0.153*"refinancing" + '
#   '0.135*"trend" + -0.131*"below" + -0.130*"to" + -0.119*"purchase" + '
#   '0.115*"food" + 0.113*"longer" + 0.109*"robust"'),
#  (3,
#   '-0.401*"projection" + -0.262*"staff" + 0.177*"commodity" + '
#   '-0.162*"purchase" + 0.146*"keeping" + 0.142*"negative" + '
#   '0.137*"policyrelevant" + 0.128*"tension" + 0.123*"aim" + 0.115*"deposit"'),
#  (4,
#   '0.406*"projection" + 0.281*"staff" + 0.234*"range" + -0.177*"subdued" + '
#   '-0.148*"gradual" + 0.132*"operation" + -0.130*"purchase" + '
#   '0.114*"commodity" + -0.112*"pillar" + -0.104*"asset"'),
#  (5,
#   '-0.226*"operation" + 0.215*"projection" + 0.183*"negative" + '
#   '0.175*"subdued" + -0.157*"ample" + -0.153*"tension" + -0.152*"refinancing" '
#   '+ -0.138*"fixed" + 0.121*"staff" + -0.117*"job"'),
#  (6,
#   '0.228*"food" + -0.171*"ample" + 0.164*"commodity" + 0.148*"secondround" + '
#   '0.147*"turmoil" + -0.140*"longer" + 0.130*"operation" + 0.123*"behaviour" + '
#   '0.112*"scheme" + 0.111*"january"'),
#  (7,
#   '-0.233*"purchase" + 0.174*"december" + 0.151*"projection" + -0.148*"escb" + '
#   '-0.145*"june" + -0.139*"asset" + -0.132*"firm" + 0.131*"consumer" + '
#   '0.124*"pillar" + 0.123*"subdued"'),
#  (8,
#   '0.391*"january" + 0.227*"december" + -0.194*"july" + -0.175*"august" + '
#   '-0.152*"tension" + 0.148*"february" + 0.147*"purchase" + 0.139*"march" + '
#   '0.137*"facility" + -0.135*"september"'),
#  (9,
#   '-0.225*"subdued" + -0.180*"december" + 0.175*"consumer" + -0.172*"january" '
#   '+ 0.154*"operation" + 0.144*"june" + 0.143*"purchase" + 0.141*"negative" + '
#   '0.141*"pillar" + -0.110*"escb"')]
# [(0,
#   '0.203*"projection" + 0.157*"staff" + 0.130*"operation" + 0.115*"december" + '
#   '0.110*"commodity" + 0.106*"january" + 0.102*"september" + 0.096*"march" + '
#   '0.093*"to" + 0.093*"june"'),
#  (1,
#   '0.254*"central" + 0.210*"national" + -0.202*"projection" + 0.185*"banknote" '
#   '+ 0.174*"escb" + 0.158*"three" + 0.147*"january" + 0.144*"reference" + '
#   '0.142*"system" + 0.137*"value"'),
#  (2,
#   '0.230*"operation" + 0.160*"subdued" + 0.153*"refinancing" + -0.135*"trend" '
#   '+ 0.131*"below" + 0.130*"to" + 0.119*"purchase" + -0.115*"food" + '
#   '-0.113*"longer" + -0.109*"robust"'),
#  (3,
#   '0.401*"projection" + 0.262*"staff" + -0.177*"commodity" + 0.162*"purchase" '
#   '+ -0.146*"keeping" + -0.142*"negative" + -0.137*"policyrelevant" + '
#   '-0.128*"tension" + -0.123*"aim" + -0.115*"deposit"'),
#  (4,
#   '-0.406*"projection" + -0.281*"staff" + -0.234*"range" + 0.177*"subdued" + '
#   '0.148*"gradual" + -0.132*"operation" + 0.130*"purchase" + '
#   '-0.114*"commodity" + 0.112*"pillar" + 0.104*"asset"'),
#  (5,
#   '0.226*"operation" + -0.215*"projection" + -0.183*"negative" + '
#   '-0.175*"subdued" + 0.157*"ample" + 0.153*"tension" + 0.152*"refinancing" + '
#   '0.138*"fixed" + -0.121*"staff" + 0.117*"job"'),
#  (6,
#   '0.228*"food" + -0.171*"ample" + 0.164*"commodity" + 0.148*"secondround" + '
#   '0.147*"turmoil" + -0.140*"longer" + 0.130*"operation" + 0.123*"behaviour" + '
#   '0.112*"scheme" + 0.111*"january"'),
#  (7,
#   '-0.233*"purchase" + 0.174*"december" + 0.151*"projection" + -0.148*"escb" + '
#   '-0.145*"june" + -0.139*"asset" + -0.132*"firm" + 0.131*"consumer" + '
#   '0.124*"pillar" + 0.123*"subdued"'),
#  (8,
#   '0.391*"january" + 0.227*"december" + -0.194*"july" + -0.175*"august" + '
#   '-0.152*"tension" + 0.148*"february" + 0.148*"purchase" + 0.140*"march" + '
#   '0.137*"facility" + -0.135*"september"'),
#  (9,
#   '-0.225*"subdued" + -0.181*"december" + 0.175*"consumer" + -0.172*"january" '
#   '+ 0.154*"operation" + 0.144*"june" + 0.143*"purchase" + 0.141*"negative" + '
#   '0.141*"pillar" + -0.110*"escb"'),
#  (10,
#   '0.293*"october" + -0.289*"march" + 0.288*"september" + -0.257*"april" + '
#   '0.214*"november" + 0.155*"purchase" + 0.140*"december" + -0.136*"february" '
#   '+ -0.125*"june" + -0.117*"subdued"'),
#  (11,
#   '-0.245*"operation" + 0.172*"contained" + 0.157*"process" + '
#   '-0.148*"refinancing" + -0.142*"volatility" + -0.137*"longer" + '
#   '0.135*"february" + 0.132*"march" + 0.127*"projection" + 0.112*"tension"'),
#  (12,
#   '-0.177*"commodity" + -0.173*"fall" + -0.151*"turmoil" + -0.146*"march" + '
#   '-0.126*"diminishing" + 0.123*"november" + 0.119*"september" + '
#   '0.119*"october" + -0.118*"intensification" + -0.117*"february"'),
#  (13,
#   '0.225*"value" + -0.207*"national" + 0.203*"reference" + -0.203*"july" + '
#   '-0.163*"central" + 0.148*"march" + -0.141*"june" + 0.128*"november" + '
#   '0.127*"trend" + -0.127*"facility"'),
#  (14,
#   '0.233*"banknote" + -0.166*"operation" + 0.158*"july" + -0.156*"procedure" + '
#   '-0.142*"framework" + -0.116*"finance" + 0.114*"day" + -0.109*"ncbs" + '
#   '0.107*"owing" + -0.107*"asset"'),
#  (15,
#   '-0.181*"march" + -0.176*"national" + 0.171*"july" + -0.161*"central" + '
#   '-0.152*"exchange" + 0.134*"facility" + 0.129*"value" + -0.128*"volatility" '
#   '+ -0.113*"foreign" + 0.110*"november"'),
#  (16,
#   '0.203*"gradual" + 0.163*"september" + 0.157*"accommodative" + -0.144*"weak" '
#   '+ -0.134*"tension" + -0.131*"several" + -0.130*"june" + 0.126*"volatility" '
#   '+ 0.124*"commodity" + 0.118*"august"'),
#  (17,
#   '-0.220*"system" + -0.179*"banking" + 0.176*"june" + -0.130*"objective" + '
#   '0.109*"ncbs" + 0.102*"central" + 0.100*"three" + -0.097*"purchase" + '
#   '-0.096*"operation" + 0.095*"reference"'),
#  (18,
#   '0.188*"volatility" + -0.130*"pillar" + -0.129*"cash" + -0.127*"december" + '
#   '-0.122*"moderation" + -0.118*"changeover" + 0.108*"august" + '
#   '-0.106*"november" + 0.101*"firm" + -0.099*"gradual"'),
#  (19,
#   '-0.170*"target" + 0.154*"pillar" + -0.142*"contained" + 0.133*"january" + '
#   '-0.132*"december" + 0.131*"august" + -0.116*"legal" + -0.116*"november" + '
#   '-0.113*"june" + -0.109*"day"')]
# [(0,
#   '-0.203*"projection" + -0.157*"staff" + -0.130*"operation" + '
#   '-0.115*"december" + -0.110*"commodity" + -0.106*"january" + '
#   '-0.102*"september" + -0.096*"march" + -0.093*"to" + -0.093*"june"'),
#  (1,
#   '0.254*"central" + 0.210*"national" + -0.202*"projection" + 0.185*"banknote" '
#   '+ 0.174*"escb" + 0.158*"three" + 0.147*"january" + 0.144*"reference" + '
#   '0.142*"system" + 0.137*"value"'),
#  (2,
#   '-0.230*"operation" + -0.160*"subdued" + -0.153*"refinancing" + '
#   '0.135*"trend" + -0.131*"below" + -0.130*"to" + -0.119*"purchase" + '
#   '0.115*"food" + 0.113*"longer" + 0.109*"robust"'),
#  (3,
#   '0.401*"projection" + 0.262*"staff" + -0.177*"commodity" + 0.162*"purchase" '
#   '+ -0.146*"keeping" + -0.142*"negative" + -0.137*"policyrelevant" + '
#   '-0.128*"tension" + -0.123*"aim" + -0.115*"deposit"'),
#  (4,
#   '-0.406*"projection" + -0.281*"staff" + -0.234*"range" + 0.177*"subdued" + '
#   '0.148*"gradual" + -0.132*"operation" + 0.130*"purchase" + '
#   '-0.114*"commodity" + 0.112*"pillar" + 0.104*"asset"'),
#  (5,
#   '-0.226*"operation" + 0.215*"projection" + 0.183*"negative" + '
#   '0.175*"subdued" + -0.157*"ample" + -0.153*"tension" + -0.152*"refinancing" '
#   '+ -0.138*"fixed" + 0.121*"staff" + -0.117*"job"'),
#  (6,
#   '-0.228*"food" + 0.171*"ample" + -0.164*"commodity" + -0.147*"secondround" + '
#   '-0.147*"turmoil" + 0.140*"longer" + -0.130*"operation" + -0.123*"behaviour" '
#   '+ -0.112*"scheme" + -0.111*"january"'),
#  (7,
#   '0.233*"purchase" + -0.173*"december" + -0.151*"projection" + 0.148*"escb" + '
#   '0.145*"june" + 0.139*"asset" + 0.132*"firm" + -0.131*"consumer" + '
#   '-0.124*"pillar" + -0.123*"subdued"'),
#  (8,
#   '-0.391*"january" + -0.227*"december" + 0.194*"july" + 0.175*"august" + '
#   '0.152*"tension" + -0.148*"february" + -0.148*"purchase" + -0.139*"march" + '
#   '-0.137*"facility" + 0.135*"september"'),
#  (9,
#   '0.225*"subdued" + 0.181*"december" + -0.175*"consumer" + 0.172*"january" + '
#   '-0.154*"operation" + -0.144*"june" + -0.143*"purchase" + -0.141*"negative" '
#   '+ -0.141*"pillar" + 0.110*"escb"'),
#  (10,
#   '0.293*"october" + -0.289*"march" + 0.288*"september" + -0.257*"april" + '
#   '0.214*"november" + 0.155*"purchase" + 0.140*"december" + -0.136*"february" '
#   '+ -0.125*"june" + -0.117*"subdued"'),
#  (11,
#   '0.245*"operation" + -0.172*"contained" + -0.157*"process" + '
#   '0.148*"refinancing" + 0.142*"volatility" + 0.137*"longer" + '
#   '-0.135*"february" + -0.132*"march" + -0.126*"projection" + '
#   '-0.112*"tension"'),
#  (12,
#   '-0.177*"commodity" + -0.173*"fall" + -0.151*"turmoil" + -0.147*"march" + '
#   '-0.126*"diminishing" + 0.123*"november" + 0.119*"september" + '
#   '0.119*"october" + -0.118*"intensification" + -0.117*"february"'),
#  (13,
#   '0.225*"value" + -0.207*"national" + 0.204*"reference" + -0.203*"july" + '
#   '-0.162*"central" + 0.148*"march" + -0.141*"june" + 0.127*"november" + '
#   '-0.127*"facility" + 0.127*"trend"'),
#  (14,
#   '-0.233*"banknote" + 0.166*"operation" + -0.158*"july" + 0.156*"procedure" + '
#   '0.142*"framework" + 0.116*"finance" + -0.114*"day" + 0.109*"ncbs" + '
#   '0.107*"asset" + -0.107*"owing"'),
#  (15,
#   '-0.181*"march" + -0.175*"national" + 0.171*"july" + -0.161*"central" + '
#   '-0.152*"exchange" + 0.135*"facility" + 0.130*"value" + -0.128*"volatility" '
#   '+ -0.113*"foreign" + 0.110*"november"'),
#  (16,
#   '-0.203*"gradual" + -0.163*"september" + -0.157*"accommodative" + '
#   '0.144*"weak" + 0.135*"tension" + 0.132*"several" + 0.130*"june" + '
#   '-0.127*"volatility" + -0.123*"commodity" + -0.117*"august"'),
#  (17,
#   '-0.221*"system" + -0.179*"banking" + 0.176*"june" + -0.130*"objective" + '
#   '0.109*"ncbs" + 0.102*"central" + 0.100*"three" + -0.097*"purchase" + '
#   '-0.096*"operation" + 0.095*"reference"'),
#  (18,
#   '0.189*"volatility" + -0.130*"cash" + -0.130*"pillar" + -0.127*"december" + '
#   '-0.122*"moderation" + -0.118*"changeover" + 0.107*"august" + '
#   '-0.106*"november" + 0.101*"firm" + 0.099*"course"'),
#  (19,
#   '-0.169*"target" + 0.155*"pillar" + -0.142*"contained" + 0.133*"january" + '
#   '-0.132*"december" + 0.130*"august" + -0.116*"november" + -0.116*"legal" + '
#   '-0.113*"june" + -0.109*"day"'),
#  (20,
#   '0.176*"lending" + 0.175*"banknote" + 0.164*"increasing" + 0.158*"momentum" '
#   '+ -0.128*"june" + -0.112*"march" + -0.110*"sustained" + -0.108*"confirmed" '
#   '+ 0.105*"two" + 0.104*"anchoring"'),
#  (21,
#   '-0.152*"volatility" + -0.135*"changeover" + -0.135*"cash" + '
#   '0.133*"exchange" + -0.128*"june" + 0.126*"february" + -0.118*"banknote" + '
#   '-0.116*"weak" + 0.107*"stabilisation" + -0.104*"forward"'),
#  (22,
#   '-0.212*"december" + -0.167*"banknote" + 0.151*"exchange" + -0.147*"day" + '
#   '0.136*"september" + -0.122*"evidence" + 0.121*"cost" + -0.114*"production" '
#   '+ 0.108*"march" + 0.107*"renewed"'),
#  (23,
#   '0.195*"february" + -0.178*"april" + -0.157*"day" + -0.155*"end" + '
#   '0.124*"institution" + -0.119*"september" + 0.118*"additional" + '
#   '-0.114*"reflected" + -0.109*"lead" + 0.109*"january"'),
#  (24,
#   '-0.160*"gradual" + 0.122*"weak" + -0.121*"january" + -0.115*"lower" + '
#   '-0.114*"service" + -0.114*"target" + 0.112*"single" + 0.104*"accommodative" '
#   '+ -0.102*"day" + 0.100*"contained"'),
#  (25,
#   '-0.192*"april" + -0.168*"october" + 0.148*"trend" + -0.135*"march" + '
#   '0.133*"january" + -0.133*"september" + 0.123*"weak" + 0.121*"december" + '
#   '-0.113*"november" + -0.107*"union"'),
#  (26,
#   '-0.152*"january" + 0.148*"april" + -0.135*"july" + -0.134*"range" + '
#   '0.132*"march" + -0.125*"exchange" + -0.118*"treaty" + 0.107*"day" + '
#   '-0.105*"thus" + -0.103*"position"'),
#  (27,
#   '-0.219*"february" + 0.181*"confirmed" + -0.160*"august" + -0.138*"ncbs" + '
#   '0.137*"april" + 0.132*"course" + 0.129*"june" + -0.127*"side" + '
#   '0.118*"december" + -0.111*"july"'),
#  (28,
#   '0.124*"reduction" + 0.119*"contained" + 0.113*"pillar" + -0.110*"framework" '
#   '+ 0.107*"lower" + -0.106*"momentum" + -0.106*"treaty" + -0.104*"value" + '
#   '-0.096*"enhance" + 0.096*"state"'),
#  (29,
#   '0.234*"june" + -0.220*"august" + 0.160*"november" + -0.142*"deficit" + '
#   '-0.133*"march" + 0.122*"december" + -0.122*"value" + -0.119*"course" + '
#   '-0.110*"gradually" + -0.109*"firm"'),
#  (30,
#   '0.142*"take" + 0.136*"productivity" + -0.136*"pillar" + -0.133*"one" + '
#   '0.124*"end" + 0.123*"side" + -0.120*"already" + -0.120*"early" + '
#   '0.118*"robust" + 0.106*"thus"'),
#  (31,
#   '-0.186*"programme" + 0.153*"service" + -0.132*"two" + -0.130*"gradual" + '
#   '-0.123*"day" + -0.122*"respect" + -0.118*"next" + -0.112*"effort" + '
#   '0.112*"vigilance" + 0.108*"sign"'),
#  (32,
#   '-0.155*"july" + -0.154*"programme" + -0.132*"pillar" + 0.121*"half" + '
#   '0.120*"take" + -0.117*"thus" + 0.115*"october" + 0.111*"background" + '
#   '0.105*"next" + 0.104*"increasing"'),
#  (33,
#   '0.232*"volatility" + -0.170*"august" + 0.148*"weak" + -0.129*"december" + '
#   '-0.126*"trend" + 0.118*"significantly" + -0.112*"somewhat" + 0.112*"needed" '
#   '+ -0.109*"treaty" + -0.098*"evidence"'),
#  (34,
#   '0.152*"course" + -0.124*"capacity" + -0.116*"competition" + -0.115*"fact" + '
#   '0.107*"banknote" + -0.105*"like" + 0.104*"observed" + 0.102*"sign" + '
#   '0.101*"production" + 0.101*"process"'),
#  (35,
#   '-0.163*"prospect" + 0.145*"service" + 0.141*"programme" + 0.141*"longterm" '
#   '+ 0.136*"purchase" + 0.131*"treaty" + -0.129*"december" + -0.127*"target" + '
#   '0.108*"april" + 0.105*"prevailing"'),
#  (36,
#   '0.189*"firm" + -0.155*"september" + -0.153*"december" + 0.139*"commodity" + '
#   '-0.134*"volatility" + 0.133*"forecast" + -0.110*"treaty" + 0.109*"november" '
#   '+ 0.102*"indicates" + 0.101*"lower"'),
#  (37,
#   '0.143*"process" + -0.126*"purchase" + 0.117*"tender" + -0.115*"additional" '
#   '+ 0.115*"firm" + 0.115*"significantly" + 0.113*"gradually" + 0.113*"june" + '
#   '-0.112*"take" + 0.101*"lead"'),
#  (38,
#   '-0.194*"range" + -0.137*"gradual" + 0.128*"position" + -0.123*"november" + '
#   '-0.113*"purchase" + -0.109*"confirmed" + -0.099*"cost" + '
#   '0.099*"substantial" + -0.098*"december" + -0.096*"situation"'),
#  (39,
#   '-0.152*"february" + -0.131*"deficit" + -0.127*"firm" + -0.125*"procedure" + '
#   '0.123*"maintain" + -0.118*"exchange" + -0.103*"excessive" + '
#   '0.099*"comprehensive" + 0.095*"relatively" + -0.095*"full"'),
#  (40,
#   '0.154*"october" + 0.144*"deficit" + -0.136*"december" + 0.121*"cost" + '
#   '0.120*"june" + 0.118*"broadbased" + 0.104*"treaty" + 0.102*"observed" + '
#   '-0.099*"august" + -0.097*"major"'),
#  (41,
#   '0.208*"range" + 0.156*"asset" + -0.134*"trend" + -0.132*"provide" + '
#   '-0.120*"reduction" + -0.111*"situation" + 0.110*"prospect" + '
#   '0.109*"slightly" + -0.106*"reflect" + 0.099*"movement"'),
#  (42,
#   '-0.154*"trend" + -0.134*"contribute" + -0.130*"needed" + 0.125*"pillar" + '
#   '-0.124*"significantly" + 0.121*"issue" + -0.115*"discussion" + '
#   '-0.113*"good" + -0.111*"slightly" + 0.110*"system"'),
#  (43,
#   '0.152*"subdued" + -0.139*"february" + 0.121*"purchase" + 0.118*"april" + '
#   '0.115*"firm" + -0.112*"october" + -0.111*"downward" + -0.111*"lower" + '
#   '-0.108*"early" + -0.107*"fourth"'),
#  (44,
#   '-0.145*"february" + -0.133*"trend" + -0.125*"service" + -0.124*"fully" + '
#   '-0.119*"banknote" + 0.118*"april" + 0.113*"several" + 0.105*"treaty" + '
#   '0.100*"november" + -0.097*"including"'),
#  (45,
#   '-0.128*"lower" + 0.127*"base" + 0.122*"objective" + -0.114*"range" + '
#   '0.111*"moderation" + -0.106*"commodity" + -0.105*"materialise" + '
#   '0.105*"several" + 0.100*"accordingly" + 0.099*"slightly"'),
#  (46,
#   '0.177*"contribute" + 0.117*"april" + 0.114*"tension" + -0.112*"state" + '
#   '-0.110*"commodity" + -0.108*"june" + 0.099*"service" + -0.097*"early" + '
#   '-0.094*"nature" + 0.093*"trend"'),
#  (47,
#   '-0.148*"consumer" + -0.126*"fully" + -0.118*"negative" + 0.116*"banknote" + '
#   '0.114*"world" + -0.114*"process" + 0.110*"related" + 0.109*"june" + '
#   '-0.108*"phase" + 0.104*"owing"'),
#  (48,
#   '0.161*"tender" + 0.148*"contribute" + 0.145*"end" + 0.127*"momentum" + '
#   '-0.113*"must" + 0.107*"june" + -0.106*"effective" + 0.106*"robust" + '
#   '-0.102*"september" + -0.102*"somewhat"'),
#  (49,
#   '-0.146*"treaty" + 0.117*"challenge" + 0.109*"deficit" + 0.108*"evidence" + '
#   '-0.107*"must" + -0.107*"maastricht" + -0.106*"december" + '
#   '-0.104*"materialise" + -0.099*"international" + -0.095*"agreed"')]
# [(0,
#   '-0.203*"projection" + -0.157*"staff" + -0.130*"operation" + '
#   '-0.115*"december" + -0.110*"commodity" + -0.106*"january" + '
#   '-0.102*"september" + -0.096*"march" + -0.093*"to" + -0.093*"june"'),
#  (1,
#   '0.254*"central" + 0.210*"national" + -0.202*"projection" + 0.185*"banknote" '
#   '+ 0.174*"escb" + 0.158*"three" + 0.147*"january" + 0.144*"reference" + '
#   '0.142*"system" + 0.137*"value"'),
#  (2,
#   '-0.230*"operation" + -0.160*"subdued" + -0.153*"refinancing" + '
#   '0.135*"trend" + -0.131*"below" + -0.130*"to" + -0.119*"purchase" + '
#   '0.115*"food" + 0.113*"longer" + 0.109*"robust"'),
#  (3,
#   '0.401*"projection" + 0.262*"staff" + -0.177*"commodity" + 0.162*"purchase" '
#   '+ -0.146*"keeping" + -0.142*"negative" + -0.137*"policyrelevant" + '
#   '-0.128*"tension" + -0.123*"aim" + -0.115*"deposit"'),
#  (4,
#   '0.406*"projection" + 0.281*"staff" + 0.234*"range" + -0.177*"subdued" + '
#   '-0.148*"gradual" + 0.132*"operation" + -0.130*"purchase" + '
#   '0.114*"commodity" + -0.112*"pillar" + -0.104*"asset"'),
#  (5,
#   '-0.226*"operation" + 0.215*"projection" + 0.183*"negative" + '
#   '0.175*"subdued" + -0.157*"ample" + -0.153*"tension" + -0.152*"refinancing" '
#   '+ -0.138*"fixed" + 0.121*"staff" + -0.117*"job"'),
#  (6,
#   '0.228*"food" + -0.171*"ample" + 0.164*"commodity" + 0.147*"secondround" + '
#   '0.147*"turmoil" + -0.140*"longer" + 0.130*"operation" + 0.123*"behaviour" + '
#   '0.112*"scheme" + 0.111*"january"'),
#  (7,
#   '0.233*"purchase" + -0.173*"december" + -0.151*"projection" + 0.148*"escb" + '
#   '0.145*"june" + 0.139*"asset" + 0.132*"firm" + -0.131*"consumer" + '
#   '-0.124*"pillar" + -0.123*"subdued"'),
#  (8,
#   '-0.391*"january" + -0.227*"december" + 0.194*"july" + 0.175*"august" + '
#   '0.152*"tension" + -0.148*"february" + -0.148*"purchase" + -0.139*"march" + '
#   '-0.137*"facility" + 0.135*"september"'),
#  (9,
#   '-0.225*"subdued" + -0.181*"december" + 0.175*"consumer" + -0.172*"january" '
#   '+ 0.154*"operation" + 0.144*"june" + 0.143*"purchase" + 0.141*"negative" + '
#   '0.141*"pillar" + -0.110*"escb"'),
#  (10,
#   '-0.293*"october" + 0.289*"march" + -0.288*"september" + 0.257*"april" + '
#   '-0.214*"november" + -0.155*"purchase" + -0.140*"december" + '
#   '0.136*"february" + 0.125*"june" + 0.117*"subdued"'),
#  (11,
#   '-0.245*"operation" + 0.172*"contained" + 0.157*"process" + '
#   '-0.148*"refinancing" + -0.142*"volatility" + -0.137*"longer" + '
#   '0.135*"february" + 0.132*"march" + 0.127*"projection" + 0.112*"tension"'),
#  (12,
#   '-0.177*"commodity" + -0.173*"fall" + -0.151*"turmoil" + -0.147*"march" + '
#   '-0.126*"diminishing" + 0.123*"november" + 0.119*"september" + '
#   '0.119*"october" + -0.118*"intensification" + -0.117*"february"'),
#  (13,
#   '0.225*"value" + -0.207*"national" + 0.204*"reference" + -0.203*"july" + '
#   '-0.163*"central" + 0.148*"march" + -0.141*"june" + 0.127*"november" + '
#   '-0.127*"facility" + 0.127*"trend"'),
#  (14,
#   '0.233*"banknote" + -0.166*"operation" + 0.158*"july" + -0.156*"procedure" + '
#   '-0.142*"framework" + -0.116*"finance" + 0.114*"day" + -0.109*"ncbs" + '
#   '-0.107*"asset" + 0.107*"owing"'),
#  (15,
#   '0.181*"march" + 0.175*"national" + -0.171*"july" + 0.160*"central" + '
#   '0.152*"exchange" + -0.135*"facility" + -0.130*"value" + 0.128*"volatility" '
#   '+ 0.113*"foreign" + -0.110*"november"'),
#  (16,
#   '-0.203*"gradual" + -0.164*"september" + -0.157*"accommodative" + '
#   '0.144*"weak" + 0.134*"tension" + 0.132*"several" + 0.130*"june" + '
#   '-0.127*"volatility" + -0.123*"commodity" + -0.117*"august"'),
#  (17,
#   '0.220*"system" + 0.179*"banking" + -0.176*"june" + 0.130*"objective" + '
#   '-0.109*"ncbs" + -0.102*"central" + -0.100*"three" + 0.097*"purchase" + '
#   '0.096*"operation" + -0.095*"reference"'),
#  (18,
#   '-0.189*"volatility" + 0.130*"cash" + 0.130*"pillar" + 0.127*"december" + '
#   '0.123*"moderation" + 0.118*"changeover" + -0.107*"august" + '
#   '0.106*"november" + -0.101*"firm" + -0.099*"course"'),
#  (19,
#   '0.170*"target" + -0.155*"pillar" + 0.142*"contained" + -0.134*"january" + '
#   '0.132*"december" + -0.130*"august" + 0.116*"november" + 0.116*"legal" + '
#   '0.114*"june" + 0.109*"day"'),
#  (20,
#   '0.177*"lending" + 0.175*"banknote" + 0.165*"increasing" + 0.158*"momentum" '
#   '+ -0.128*"june" + -0.112*"march" + -0.110*"sustained" + -0.109*"confirmed" '
#   '+ 0.105*"two" + 0.104*"anchoring"'),
#  (21,
#   '0.153*"volatility" + 0.135*"changeover" + 0.135*"cash" + -0.133*"exchange" '
#   '+ 0.128*"june" + -0.126*"february" + 0.118*"banknote" + 0.116*"weak" + '
#   '-0.107*"stabilisation" + 0.104*"forward"'),
#  (22,
#   '0.212*"december" + 0.168*"banknote" + -0.151*"exchange" + 0.147*"day" + '
#   '-0.136*"september" + 0.122*"evidence" + -0.120*"cost" + 0.114*"production" '
#   '+ -0.108*"march" + -0.106*"renewed"'),
#  (23,
#   '-0.195*"february" + 0.178*"april" + 0.157*"day" + 0.155*"end" + '
#   '-0.124*"institution" + 0.119*"september" + -0.117*"additional" + '
#   '0.114*"reflected" + 0.109*"lead" + -0.109*"january"'),
#  (24,
#   '0.160*"gradual" + -0.122*"weak" + 0.120*"january" + 0.115*"lower" + '
#   '0.114*"service" + 0.114*"target" + -0.112*"single" + -0.104*"accommodative" '
#   '+ 0.102*"day" + -0.100*"contained"'),
#  (25,
#   '0.193*"april" + 0.168*"october" + -0.148*"trend" + 0.135*"march" + '
#   '0.133*"september" + -0.133*"january" + -0.123*"weak" + -0.121*"december" + '
#   '0.113*"november" + 0.108*"union"'),
#  (26,
#   '-0.151*"january" + 0.148*"april" + -0.135*"july" + -0.134*"range" + '
#   '0.132*"march" + -0.125*"exchange" + -0.118*"treaty" + 0.108*"day" + '
#   '-0.105*"thus" + 0.103*"banknote"'),
#  (27,
#   '0.218*"february" + -0.180*"confirmed" + 0.160*"august" + -0.138*"april" + '
#   '0.138*"ncbs" + -0.132*"course" + -0.129*"june" + 0.127*"side" + '
#   '-0.118*"december" + 0.111*"july"'),
#  (28,
#   '0.123*"reduction" + 0.120*"contained" + 0.113*"pillar" + -0.110*"framework" '
#   '+ 0.106*"lower" + -0.106*"treaty" + -0.106*"momentum" + -0.104*"value" + '
#   '0.096*"state" + -0.096*"enhance"'),
#  (29,
#   '-0.234*"june" + 0.220*"august" + -0.160*"november" + 0.142*"deficit" + '
#   '0.133*"march" + -0.122*"december" + 0.122*"value" + 0.119*"course" + '
#   '0.109*"gradually" + 0.109*"firm"'),
#  (30,
#   '-0.142*"take" + -0.137*"productivity" + 0.135*"pillar" + 0.132*"one" + '
#   '-0.124*"end" + -0.123*"side" + 0.120*"early" + 0.120*"already" + '
#   '-0.118*"robust" + -0.106*"thus"'),
#  (31,
#   '-0.186*"programme" + 0.153*"service" + -0.132*"two" + -0.130*"gradual" + '
#   '-0.123*"day" + -0.122*"respect" + -0.118*"next" + 0.112*"vigilance" + '
#   '-0.111*"effort" + 0.108*"sign"'),
#  (32,
#   '0.155*"july" + 0.154*"programme" + 0.132*"pillar" + -0.121*"half" + '
#   '-0.120*"take" + 0.117*"thus" + -0.116*"october" + -0.111*"background" + '
#   '-0.105*"next" + -0.104*"increasing"'),
#  (33,
#   '-0.232*"volatility" + 0.169*"august" + -0.149*"weak" + 0.129*"december" + '
#   '0.125*"trend" + -0.118*"significantly" + -0.112*"needed" + 0.111*"somewhat" '
#   '+ 0.110*"treaty" + 0.099*"evidence"'),
#  (34,
#   '-0.153*"course" + 0.124*"capacity" + 0.117*"competition" + 0.116*"fact" + '
#   '-0.106*"banknote" + 0.105*"like" + -0.104*"observed" + -0.101*"production" '
#   '+ -0.101*"sign" + 0.100*"utilisation"'),
#  (35,
#   '0.161*"prospect" + -0.145*"service" + -0.142*"programme" + '
#   '-0.140*"longterm" + -0.137*"purchase" + 0.129*"december" + -0.128*"treaty" '
#   '+ 0.126*"target" + -0.111*"april" + -0.106*"food"'),
#  (36,
#   '0.191*"firm" + -0.154*"september" + -0.151*"december" + 0.138*"commodity" + '
#   '0.133*"forecast" + -0.133*"volatility" + -0.113*"treaty" + 0.107*"november" '
#   '+ 0.103*"indicates" + 0.103*"lower"'),
#  (37,
#   '0.145*"process" + -0.124*"purchase" + 0.116*"tender" + 0.114*"firm" + '
#   '0.114*"significantly" + -0.114*"additional" + 0.114*"gradually" + '
#   '0.112*"june" + -0.111*"take" + 0.102*"lead"'),
#  (38,
#   '-0.192*"range" + -0.138*"gradual" + 0.129*"position" + -0.122*"november" + '
#   '-0.111*"purchase" + -0.108*"confirmed" + 0.099*"substantial" + '
#   '-0.099*"december" + -0.098*"cost" + -0.097*"situation"'),
#  (39,
#   '0.151*"february" + 0.133*"deficit" + 0.127*"procedure" + 0.126*"firm" + '
#   '-0.122*"maintain" + 0.118*"exchange" + 0.103*"excessive" + '
#   '-0.099*"comprehensive" + -0.095*"relatively" + 0.094*"full"'),
#  (40,
#   '0.156*"october" + 0.144*"deficit" + -0.138*"december" + 0.119*"june" + '
#   '0.119*"cost" + 0.118*"broadbased" + 0.103*"treaty" + 0.101*"observed" + '
#   '-0.099*"august" + -0.096*"major"'),
#  (41,
#   '0.209*"range" + 0.156*"asset" + -0.135*"provide" + -0.133*"trend" + '
#   '-0.118*"reduction" + 0.111*"prospect" + 0.111*"slightly" + '
#   '-0.108*"situation" + -0.107*"reflect" + 0.098*"movement"'),
#  (42,
#   '-0.156*"trend" + -0.135*"contribute" + -0.132*"needed" + 0.125*"pillar" + '
#   '0.121*"issue" + -0.120*"significantly" + -0.115*"discussion" + '
#   '-0.115*"good" + 0.110*"system" + -0.109*"slightly"'),
#  (43,
#   '-0.151*"subdued" + 0.139*"february" + -0.123*"purchase" + -0.119*"april" + '
#   '-0.115*"firm" + 0.111*"downward" + 0.110*"october" + 0.109*"lower" + '
#   '0.108*"early" + 0.107*"fourth"'),
#  (44,
#   '0.142*"february" + 0.134*"trend" + 0.128*"service" + 0.126*"fully" + '
#   '0.120*"banknote" + -0.118*"several" + -0.114*"april" + -0.108*"treaty" + '
#   '-0.099*"november" + 0.099*"including"'),
#  (45,
#   '-0.129*"lower" + 0.123*"base" + 0.120*"objective" + -0.115*"range" + '
#   '0.111*"moderation" + -0.108*"commodity" + -0.102*"materialise" + '
#   '0.102*"accordingly" + 0.101*"several" + 0.097*"slightly"'),
#  (46,
#   '0.177*"contribute" + 0.119*"april" + 0.114*"tension" + -0.112*"commodity" + '
#   '-0.110*"state" + -0.108*"june" + -0.098*"early" + -0.097*"nature" + '
#   '0.096*"service" + -0.093*"due"'),
#  (47,
#   '-0.150*"consumer" + -0.127*"fully" + 0.117*"banknote" + -0.116*"negative" + '
#   '0.114*"world" + -0.113*"process" + 0.111*"related" + 0.109*"june" + '
#   '-0.108*"phase" + 0.105*"owing"'),
#  (48,
#   '0.161*"tender" + 0.149*"contribute" + 0.147*"end" + 0.128*"momentum" + '
#   '-0.115*"must" + 0.109*"june" + -0.108*"effective" + 0.104*"robust" + '
#   '-0.103*"september" + -0.100*"somewhat"'),
#  (49,
#   '-0.148*"treaty" + 0.123*"challenge" + 0.109*"deficit" + -0.107*"maastricht" '
#   '+ 0.106*"evidence" + -0.106*"december" + -0.105*"materialise" + '
#   '-0.101*"must" + -0.100*"international" + 0.095*"two"'),
#  (50,
#   '0.154*"september" + -0.135*"range" + -0.125*"exchange" + -0.120*"november" '
#   '+ -0.114*"needed" + -0.100*"assumption" + -0.099*"reflect" + '
#   '0.097*"security" + 0.090*"indicates" + 0.087*"additional"'),
#  (51,
#   '-0.154*"average" + 0.128*"member" + -0.126*"process" + -0.123*"commodity" + '
#   '0.118*"background" + 0.116*"firm" + 0.108*"release" + -0.107*"prospect" + '
#   '0.106*"next" + 0.105*"opportunity"'),
#  (52,
#   '0.142*"value" + -0.139*"february" + 0.131*"full" + -0.124*"asset" + '
#   '0.112*"component" + 0.106*"reference" + -0.102*"next" + 0.098*"challenge" + '
#   '-0.098*"significantly" + -0.097*"tender"'),
#  (53,
#   '-0.191*"range" + 0.151*"full" + -0.132*"commodity" + 0.120*"projection" + '
#   '-0.117*"international" + 0.109*"reduce" + -0.102*"contribute" + '
#   '-0.095*"pillar" + 0.093*"stressed" + 0.093*"declined"'),
#  (54,
#   '0.126*"cost" + 0.124*"take" + -0.124*"confirmed" + -0.119*"increasing" + '
#   '-0.117*"around" + -0.110*"seen" + 0.109*"projected" + 0.109*"aggregate" + '
#   '-0.108*"commodity" + 0.100*"owing"'),
#  (55,
#   '0.156*"reflected" + 0.125*"due" + -0.117*"commission" + -0.102*"half" + '
#   '-0.098*"commitment" + 0.096*"banking" + 0.094*"rather" + -0.092*"renewed" + '
#   '-0.090*"confirmed" + -0.089*"significantly"'),
#  (56,
#   '-0.124*"including" + -0.117*"range" + -0.115*"lower" + -0.113*"state" + '
#   '0.110*"reflects" + -0.106*"help" + 0.104*"improve" + -0.101*"much" + '
#   '0.099*"general" + 0.097*"programme"'),
#  (57,
#   '-0.143*"two" + 0.124*"average" + -0.124*"reduce" + 0.122*"programme" + '
#   '0.120*"end" + 0.119*"emerging" + 0.109*"made" + -0.106*"additional" + '
#   '-0.102*"march" + 0.096*"cost"'),
#  (58,
#   '0.133*"momentum" + 0.129*"increasing" + -0.116*"tender" + -0.112*"average" '
#   '+ -0.109*"reflects" + 0.106*"generally" + -0.099*"additional" + '
#   '0.098*"earlier" + 0.094*"july" + -0.091*"treaty"'),
#  (59,
#   '-0.120*"budget" + -0.114*"somewhat" + 0.112*"projected" + 0.107*"situation" '
#   '+ -0.094*"significantly" + -0.092*"special" + -0.092*"exchange" + '
#   '0.090*"august" + -0.089*"longterm" + 0.089*"observed"'),
#  (60,
#   '0.139*"early" + 0.126*"february" + -0.121*"course" + -0.113*"forecast" + '
#   '0.109*"competitiveness" + -0.107*"banking" + -0.102*"effective" + '
#   '0.102*"april" + -0.100*"lower" + 0.100*"remaining"'),
#  (61,
#   '-0.132*"november" + -0.127*"firm" + 0.120*"within" + 0.118*"relating" + '
#   '0.113*"end" + 0.112*"december" + 0.112*"early" + -0.111*"effort" + '
#   '-0.105*"job" + 0.103*"contribute"'),
#  (62,
#   '0.176*"somewhat" + 0.121*"service" + 0.109*"december" + 0.098*"half" + '
#   '0.095*"volatility" + 0.095*"general" + -0.094*"fully" + -0.094*"reflect" + '
#   '-0.094*"slightly" + -0.094*"november"'),
#  (63,
#   '-0.172*"lower" + -0.124*"effective" + 0.116*"consumer" + -0.114*"service" + '
#   '0.113*"full" + 0.107*"range" + -0.104*"plan" + -0.100*"affected" + '
#   '0.100*"suggest" + 0.095*"productivity"'),
#  (64,
#   '0.149*"finance" + 0.134*"april" + 0.131*"range" + -0.124*"temporary" + '
#   '-0.115*"suggest" + -0.113*"subject" + -0.110*"next" + 0.105*"trend" + '
#   '-0.100*"march" + -0.097*"shock"'),
#  (65,
#   '0.140*"improve" + -0.138*"continuing" + 0.130*"reflected" + -0.119*"march" '
#   '+ 0.114*"challenge" + -0.110*"somewhat" + 0.099*"production" + '
#   '-0.096*"sustained" + 0.094*"strengthened" + 0.092*"owing"'),
#  (66,
#   '-0.161*"moderation" + -0.108*"nature" + 0.104*"thus" + 0.102*"recently" + '
#   '-0.098*"negative" + -0.096*"subdued" + -0.093*"course" + 0.092*"signal" + '
#   '-0.092*"ecofin" + -0.092*"opportunity"'),
#  (67,
#   '0.137*"perspective" + 0.120*"lead" + 0.117*"related" + -0.115*"november" + '
#   '0.105*"plan" + 0.102*"improve" + -0.102*"commitment" + -0.097*"process" + '
#   '0.096*"banking" + -0.093*"somewhat"'),
#  (68,
#   '-0.158*"longterm" + -0.145*"september" + 0.135*"improved" + '
#   '-0.109*"programme" + 0.101*"work" + 0.095*"cost" + 0.093*"vigilance" + '
#   '-0.092*"general" + 0.091*"half" + 0.091*"longer"'),
#  (69,
#   '0.127*"forecast" + -0.114*"around" + -0.111*"background" + -0.109*"next" + '
#   '0.105*"budgetary" + -0.105*"needed" + -0.099*"scenario" + 0.099*"prospect" '
#   '+ 0.093*"member" + -0.090*"commodity"'),
#  (70,
#   '0.132*"service" + 0.123*"fact" + 0.111*"bond" + 0.109*"budgetary" + '
#   '0.108*"observed" + -0.107*"stabilisation" + -0.102*"side" + '
#   '0.100*"strongly" + 0.100*"stemming" + 0.098*"range"'),
#  (71,
#   '0.144*"contribute" + 0.119*"resulting" + -0.108*"october" + '
#   '0.104*"confirmed" + -0.101*"gradual" + -0.100*"turn" + 0.100*"july" + '
#   '-0.099*"somewhat" + -0.098*"trend" + -0.097*"plan"'),
#  (72,
#   '-0.149*"commodity" + 0.116*"two" + -0.109*"october" + -0.108*"one" + '
#   '0.105*"service" + 0.101*"temporary" + 0.097*"course" + 0.097*"organisation" '
#   '+ -0.093*"respect" + 0.086*"present"'),
#  (73,
#   '-0.190*"already" + -0.121*"opportunity" + 0.115*"revised" + '
#   '-0.112*"programme" + 0.097*"recently" + -0.097*"confirmed" + '
#   '0.097*"situation" + 0.096*"reduce" + 0.096*"although" + 0.095*"prevailing"'),
#  (74,
#   '0.114*"service" + -0.113*"recover" + 0.103*"lending" + -0.101*"reflects" + '
#   '-0.099*"early" + -0.098*"flow" + 0.097*"april" + 0.096*"help" + '
#   '0.094*"grow" + -0.093*"like"'),
#  (75,
#   '-0.128*"prospect" + -0.128*"signal" + 0.118*"exchange" + -0.116*"half" + '
#   '0.111*"owing" + -0.108*"due" + 0.108*"percentage" + -0.102*"furthermore" + '
#   '-0.098*"further" + -0.097*"range"'),
#  (76,
#   '0.117*"budget" + 0.114*"clearly" + -0.109*"indicate" + 0.108*"opportunity" '
#   '+ -0.107*"service" + 0.099*"start" + -0.097*"heightened" + 0.096*"revised" '
#   '+ -0.094*"asset" + -0.094*"way"'),
#  (77,
#   '0.135*"contribute" + -0.109*"temporary" + -0.105*"august" + '
#   '-0.104*"negative" + -0.103*"surrounding" + 0.097*"release" + '
#   '-0.095*"reflect" + -0.087*"role" + -0.087*"output" + 0.087*"implemented"'),
#  (78,
#   '-0.134*"range" + -0.128*"two" + -0.113*"sustained" + -0.106*"one" + '
#   '0.100*"job" + 0.096*"return" + -0.095*"asset" + -0.093*"july" + '
#   '0.093*"challenge" + -0.090*"effective"'),
#  (79,
#   '-0.178*"july" + -0.124*"cost" + 0.111*"fall" + 0.111*"september" + '
#   '0.110*"case" + 0.104*"slightly" + -0.094*"capital" + -0.093*"negative" + '
#   '0.091*"around" + -0.087*"october"'),
#  (80,
#   '-0.151*"strongly" + 0.142*"service" + -0.120*"especially" + 0.109*"respect" '
#   '+ -0.100*"recently" + 0.100*"further" + -0.097*"subject" + '
#   '-0.094*"including" + -0.090*"firm" + -0.089*"significantly"'),
#  (81,
#   '-0.130*"moderation" + -0.114*"largely" + 0.109*"december" + '
#   '0.107*"position" + 0.104*"reason" + 0.101*"programme" + -0.099*"november" + '
#   '-0.099*"august" + 0.097*"situation" + -0.092*"security"'),
#  (82,
#   '0.146*"hand" + 0.111*"deposit" + -0.109*"significantly" + 0.108*"one" + '
#   '0.106*"even" + -0.100*"evidence" + 0.093*"slightly" + -0.092*"union" + '
#   '-0.090*"followed" + -0.087*"commodity"'),
#  (83,
#   '0.111*"thus" + 0.108*"reflected" + -0.101*"volatility" + 0.099*"position" + '
#   '-0.098*"somewhat" + -0.097*"service" + 0.094*"weak" + -0.094*"pillar" + '
#   '0.091*"commodity" + -0.090*"productivity"'),
#  (84,
#   '0.126*"projected" + 0.121*"help" + -0.118*"fully" + -0.109*"half" + '
#   '-0.109*"purchase" + -0.100*"february" + -0.094*"thus" + 0.086*"treaty" + '
#   '-0.086*"recently" + 0.084*"return"'),
#  (85,
#   '0.134*"ecbs" + -0.111*"must" + -0.108*"budget" + -0.106*"march" + '
#   '0.103*"result" + 0.102*"evidence" + 0.100*"monthly" + -0.095*"remaining" + '
#   '-0.095*"significantly" + 0.088*"fourth"'),
#  (86,
#   '-0.142*"thus" + 0.112*"better" + 0.100*"continuing" + -0.096*"early" + '
#   '0.095*"background" + 0.095*"instrument" + -0.093*"gradually" + '
#   '0.089*"regarding" + 0.088*"week" + 0.087*"maintained"'),
#  (87,
#   '-0.139*"slightly" + 0.120*"including" + -0.117*"case" + 0.104*"process" + '
#   '-0.104*"further" + -0.100*"range" + -0.099*"end" + -0.095*"consequence" + '
#   '0.085*"side" + -0.084*"continuing"'),
#  (88,
#   '0.123*"mr" + 0.113*"commission" + 0.108*"sound" + 0.101*"debt" + '
#   '0.101*"call" + -0.098*"course" + -0.093*"member" + -0.091*"state" + '
#   '0.091*"union" + 0.090*"trend"'),
#  (89,
#   '0.104*"deficit" + -0.104*"like" + 0.098*"beyond" + -0.097*"budgetary" + '
#   '0.095*"better" + 0.095*"earlier" + -0.095*"around" + 0.089*"issue" + '
#   '-0.088*"cost" + 0.088*"reason"'),
#  (90,
#   '-0.111*"lead" + 0.109*"sustained" + 0.108*"recently" + -0.104*"service" + '
#   '-0.104*"prospect" + 0.102*"consumer" + 0.099*"focus" + -0.097*"budget" + '
#   '0.091*"lower" + 0.089*"action"'),
#  (91,
#   '0.116*"reduction" + 0.115*"base" + -0.112*"maintain" + 0.111*"gain" + '
#   '-0.105*"accommodative" + -0.092*"needed" + 0.088*"strengthened" + '
#   '0.087*"side" + 0.085*"banking" + 0.085*"relating"'),
#  (92,
#   '-0.128*"sustained" + 0.126*"course" + -0.104*"take" + -0.102*"shock" + '
#   '0.100*"must" + -0.099*"state" + -0.097*"contributed" + 0.095*"evidence" + '
#   '-0.093*"including" + 0.089*"accordingly"'),
#  (93,
#   '-0.131*"objective" + -0.106*"liquid" + 0.104*"mechanism" + 0.102*"fully" + '
#   '0.100*"budget" + 0.100*"slightly" + 0.099*"deceleration" + 0.098*"november" '
#   '+ -0.098*"beyond" + -0.087*"region"'),
#  (94,
#   '0.138*"sound" + -0.117*"october" + -0.110*"thus" + -0.107*"loss" + '
#   '0.101*"good" + -0.100*"base" + -0.097*"great" + 0.094*"programme" + '
#   '-0.094*"situation" + -0.091*"competitiveness"'),
#  (95,
#   '-0.134*"reflects" + 0.134*"signal" + 0.120*"august" + -0.104*"competition" '
#   '+ -0.102*"sign" + -0.100*"effective" + -0.096*"gradual" + -0.092*"deficit" '
#   '+ 0.089*"keep" + 0.089*"procedure"'),
#  (96,
#   '-0.122*"prospect" + 0.113*"trend" + 0.113*"substantial" + -0.110*"owing" + '
#   '0.105*"eu" + -0.098*"target" + 0.096*"issue" + 0.095*"monthly" + '
#   '-0.093*"reflect" + 0.087*"budget"'),
#  (97,
#   '0.130*"result" + -0.120*"somewhat" + 0.106*"partly" + -0.100*"forecast" + '
#   '-0.092*"allow" + 0.088*"effective" + -0.087*"within" + 0.086*"date" + '
#   '-0.084*"observed" + -0.082*"half"'),
#  (98,
#   '0.114*"august" + 0.106*"remaining" + -0.096*"sustained" + 0.095*"upswing" + '
#   '-0.090*"commission" + 0.090*"robust" + 0.089*"relatively" + '
#   '-0.088*"situation" + -0.087*"leave" + -0.085*"reflects"'),
#  (99,
#   '0.133*"process" + -0.123*"needed" + -0.119*"avoid" + 0.107*"sign" + '
#   '0.107*"strongly" + -0.106*"around" + 0.098*"renewed" + 0.097*"objective" + '
#   '-0.091*"next" + -0.091*"commission"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.



# Compute Coherence Score
coherence_model_lsi5 = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi5 = coherence_model_lsi5.get_coherence()
print('\nCoherence Score5: ', coherence_lsi5)

# Compute Coherence Score
coherence_model_lsi10 = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi10 = coherence_model_lsi10.get_coherence()
print('\nCoherence Score10: ', coherence_lsi10)

# Compute Coherence Score
coherence_model_lsi20 = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi20 = coherence_model_lsi20.get_coherence()
print('\nCoherence Score20: ', coherence_lsi20)

# Compute Coherence Score
coherence_model_lsi50 = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi50 = coherence_model_lsi50.get_coherence()
print('\nCoherence Score50: ', coherence_lsi50)

# Compute Coherence Score
coherence_model_lsi100 = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi100 = coherence_model_lsi100.get_coherence()
print('\nCoherence Score100: ', coherence_lsi100)


# Compute Coherence Score
coherence_model_lsi5 = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi5 = coherence_model_lsi5.get_coherence()
print('\nCoherence Score5: ', coherence_lsi5)

# Compute Coherence Score
coherence_model_lsi10 = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi10 = coherence_model_lsi10.get_coherence()
print('\nCoherence Score10: ', coherence_lsi10)

# Compute Coherence Score
coherence_model_lsi20 = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi20 = coherence_model_lsi20.get_coherence()
print('\nCoherence Score20: ', coherence_lsi20)

# Compute Coherence Score
coherence_model_lsi50 = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi50 = coherence_model_lsi50.get_coherence()
print('\nCoherence Score50: ', coherence_lsi50)

# Compute Coherence Score
coherence_model_lsi100 = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi100 = coherence_model_lsi100.get_coherence()
print('\nCoherence Score100: ', coherence_lsi100)
# Out:
# Coherence Score5:  0.4025285351694075
#
# Coherence Score10:  0.3805070141970469
#
# Coherence Score20:  0.3168577092702009
#
# Coherence Score50:  0.2582536892110195
#
# Coherence Score100:  0.23282134147409667
#
# Coherence Score5:  -0.8581298561623868
#
# Coherence Score10:  -1.058928411414699
#
# Coherence Score20:  -1.1322301143363211
#
# Coherence Score50:  -1.6970001910136936
#
# Coherence Score100:  -1.5451509226897906
