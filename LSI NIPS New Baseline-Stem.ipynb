# %% [markdown]
# # load packages

# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess, lemmatize
from gensim.models import CoherenceModel
from gensim.models import LdaModel, LdaMulticore
import gensim.downloader as api
from gensim.models import LsiModel

nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools 
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
#import logging
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
#logging.root.setLevel(level=logging.INFO)
#import warnings
#warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_csv('C:/Users/Kornelius/Desktop/Data 2/nips-papers/papers.csv', header = 0, sep = ';', error_bad_lines=False)
# Drop the columns not needed
df = df.drop(columns=['id', 'event_type', 'pdf_name'], axis=1)

# %%
# Drop a row by condition
df = df[df.abstract != 'Abstract Missing']

# %%
data = df.abstract.values.tolist()

# %% [markdown]
# # Pre-processing (Baseline)

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
ps = PorterStemmer()
def clean(data):
    stop_free = " ".join([i for i in data.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(ps.stem(word) for word in punc_free.split())
    return normalized

data = [clean(data).split() for data in data]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(12827 unique tokens: ['activ', 'also', 'analysi', 'appli', 'assum']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# # LSI

# %%
# Build the LSI Model
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.352*"model" + 0.290*"learn" + 0.267*"algorithm" + 0.209*"use" + '
#   '0.200*"method" + 0.192*"problem" + 0.190*"data" + 0.149*"propos" + '
#   '0.148*"show" + 0.138*"gener"')]
# [(0,
#   '0.352*"model" + 0.290*"learn" + 0.267*"algorithm" + 0.209*"use" + '
#   '0.200*"method" + 0.192*"problem" + 0.190*"data" + 0.149*"propos" + '
#   '0.148*"show" + 0.138*"gener"'),
#  (1,
#   '0.731*"model" + -0.407*"algorithm" + -0.230*"problem" + -0.164*"optim" + '
#   '-0.130*"function" + -0.099*"bound" + 0.099*"network" + 0.094*"imag" + '
#   '-0.088*"method" + 0.081*"neural"'),
#  (2,
#   '0.692*"learn" + -0.294*"algorithm" + -0.294*"model" + 0.216*"network" + '
#   '-0.172*"estim" + 0.150*"task" + 0.141*"train" + 0.134*"imag" + '
#   '0.110*"featur" + 0.107*"deep"'),
#  (3,
#   '0.506*"algorithm" + -0.490*"method" + 0.390*"learn" + 0.272*"model" + '
#   '-0.232*"estim" + -0.137*"use" + -0.135*"network" + -0.109*"data" + '
#   '-0.104*"imag" + -0.097*"propos"'),
#  (4,
#   '-0.649*"network" + 0.347*"data" + 0.273*"learn" + -0.241*"neural" + '
#   '-0.196*"algorithm" + 0.183*"method" + 0.168*"estim" + -0.122*"imag" + '
#   '-0.120*"deep" + -0.118*"train"')]
# [(0,
#   '0.352*"model" + 0.290*"learn" + 0.267*"algorithm" + 0.209*"use" + '
#   '0.200*"method" + 0.192*"problem" + 0.190*"data" + 0.149*"propos" + '
#   '0.148*"show" + 0.138*"gener"'),
#  (1,
#   '0.731*"model" + -0.407*"algorithm" + -0.230*"problem" + -0.164*"optim" + '
#   '-0.130*"function" + -0.099*"bound" + 0.099*"network" + 0.094*"imag" + '
#   '-0.088*"method" + 0.081*"neural"'),
#  (2,
#   '-0.693*"learn" + 0.294*"algorithm" + 0.294*"model" + -0.216*"network" + '
#   '0.172*"estim" + -0.150*"task" + -0.141*"train" + -0.134*"imag" + '
#   '-0.110*"featur" + -0.107*"deep"'),
#  (3,
#   '0.506*"algorithm" + -0.490*"method" + 0.390*"learn" + 0.272*"model" + '
#   '-0.232*"estim" + -0.137*"use" + -0.135*"network" + -0.109*"data" + '
#   '-0.103*"imag" + -0.097*"propos"'),
#  (4,
#   '-0.649*"network" + 0.347*"data" + 0.273*"learn" + -0.241*"neural" + '
#   '-0.196*"algorithm" + 0.183*"method" + 0.168*"estim" + -0.122*"imag" + '
#   '-0.119*"deep" + -0.118*"train"'),
#  (5,
#   '-0.517*"data" + 0.378*"function" + -0.322*"algorithm" + 0.247*"optim" + '
#   '-0.245*"cluster" + 0.175*"model" + 0.169*"learn" + -0.164*"imag" + '
#   '0.160*"problem" + -0.132*"featur"'),
#  (6,
#   '0.459*"estim" + -0.432*"method" + 0.295*"distribut" + 0.231*"data" + '
#   '0.221*"network" + 0.204*"sampl" + -0.187*"imag" + -0.169*"model" + '
#   '-0.161*"object" + 0.150*"bound"'),
#  (7,
#   '-0.496*"imag" + 0.398*"method" + 0.264*"network" + -0.249*"object" + '
#   '-0.184*"gener" + 0.181*"learn" + -0.179*"problem" + 0.147*"data" + '
#   '-0.142*"use" + 0.138*"algorithm"'),
#  (8,
#   '0.433*"data" + 0.393*"problem" + -0.335*"estim" + -0.255*"algorithm" + '
#   '0.249*"function" + -0.246*"use" + 0.188*"cluster" + 0.183*"network" + '
#   '-0.162*"imag" + -0.161*"method"'),
#  (9,
#   '-0.629*"function" + 0.448*"problem" + -0.270*"use" + -0.176*"data" + '
#   '0.166*"estim" + -0.141*"approxim" + 0.127*"matrix" + 0.117*"network" + '
#   '0.116*"structur" + -0.111*"algorithm"')]
# [(0,
#   '0.352*"model" + 0.290*"learn" + 0.267*"algorithm" + 0.209*"use" + '
#   '0.200*"method" + 0.192*"problem" + 0.190*"data" + 0.149*"propos" + '
#   '0.148*"show" + 0.138*"gener"'),
#  (1,
#   '0.731*"model" + -0.407*"algorithm" + -0.230*"problem" + -0.164*"optim" + '
#   '-0.130*"function" + -0.099*"bound" + 0.099*"network" + 0.094*"imag" + '
#   '-0.088*"method" + 0.081*"neural"'),
#  (2,
#   '-0.693*"learn" + 0.294*"algorithm" + 0.294*"model" + -0.216*"network" + '
#   '0.172*"estim" + -0.150*"task" + -0.141*"train" + -0.134*"imag" + '
#   '-0.110*"featur" + -0.107*"deep"'),
#  (3,
#   '0.506*"algorithm" + -0.490*"method" + 0.390*"learn" + 0.272*"model" + '
#   '-0.232*"estim" + -0.137*"use" + -0.135*"network" + -0.109*"data" + '
#   '-0.104*"imag" + -0.097*"propos"'),
#  (4,
#   '-0.649*"network" + 0.347*"data" + 0.273*"learn" + -0.241*"neural" + '
#   '-0.196*"algorithm" + 0.183*"method" + 0.168*"estim" + -0.122*"imag" + '
#   '-0.120*"deep" + -0.117*"train"'),
#  (5,
#   '-0.517*"data" + 0.378*"function" + -0.321*"algorithm" + 0.247*"optim" + '
#   '-0.244*"cluster" + 0.175*"model" + 0.168*"learn" + -0.164*"imag" + '
#   '0.161*"problem" + -0.131*"featur"'),
#  (6,
#   '-0.458*"estim" + 0.432*"method" + -0.295*"distribut" + -0.231*"data" + '
#   '-0.221*"network" + -0.204*"sampl" + 0.186*"imag" + 0.169*"model" + '
#   '0.162*"object" + -0.151*"bound"'),
#  (7,
#   '-0.495*"imag" + 0.398*"method" + 0.264*"network" + -0.250*"object" + '
#   '-0.184*"gener" + 0.181*"learn" + -0.180*"problem" + 0.147*"data" + '
#   '-0.142*"use" + 0.138*"algorithm"'),
#  (8,
#   '-0.433*"data" + -0.394*"problem" + 0.335*"estim" + 0.255*"algorithm" + '
#   '0.247*"use" + -0.247*"function" + -0.188*"cluster" + -0.184*"network" + '
#   '0.161*"imag" + 0.160*"method"'),
#  (9,
#   '-0.628*"function" + 0.446*"problem" + -0.271*"use" + -0.178*"data" + '
#   '0.165*"estim" + -0.140*"approxim" + 0.127*"matrix" + 0.116*"structur" + '
#   '0.115*"network" + -0.111*"featur"'),
#  (10,
#   '-0.501*"estim" + 0.337*"distribut" + 0.293*"sampl" + 0.228*"bound" + '
#   '0.213*"gener" + -0.181*"function" + -0.161*"algorithm" + 0.160*"infer" + '
#   '-0.134*"network" + -0.130*"structur"'),
#  (11,
#   '-0.430*"use" + -0.279*"problem" + 0.270*"gener" + 0.250*"method" + '
#   '0.207*"bound" + -0.202*"comput" + -0.195*"approach" + -0.195*"infer" + '
#   '0.181*"imag" + 0.136*"train"'),
#  (12,
#   '0.371*"featur" + -0.331*"optim" + 0.239*"bound" + -0.221*"data" + '
#   '0.212*"kernel" + -0.200*"imag" + -0.191*"estim" + 0.186*"graph" + '
#   '0.180*"matrix" + -0.173*"approach"'),
#  (13,
#   '-0.382*"cluster" + -0.311*"distribut" + -0.275*"graph" + -0.207*"function" '
#   '+ 0.196*"optim" + -0.185*"infer" + 0.172*"data" + 0.151*"time" + '
#   '-0.149*"approxim" + -0.146*"imag"'),
#  (14,
#   '-0.481*"cluster" + 0.442*"featur" + -0.290*"use" + 0.246*"kernel" + '
#   '0.202*"distribut" + 0.144*"gener" + -0.143*"set" + -0.141*"bound" + '
#   '-0.132*"method" + 0.120*"problem"'),
#  (15,
#   '-0.408*"use" + -0.387*"gener" + 0.296*"cluster" + 0.274*"distribut" + '
#   '0.245*"optim" + 0.242*"featur" + 0.195*"propos" + -0.192*"problem" + '
#   '0.152*"object" + -0.132*"data"'),
#  (16,
#   '0.316*"cluster" + 0.306*"gener" + -0.300*"label" + -0.295*"approach" + '
#   '0.272*"optim" + -0.229*"bound" + -0.222*"infer" + 0.205*"featur" + '
#   '-0.196*"predict" + 0.167*"use"'),
#  (17,
#   '0.441*"gener" + 0.306*"propos" + 0.303*"approach" + -0.270*"distribut" + '
#   '0.210*"task" + -0.207*"featur" + -0.183*"label" + -0.179*"use" + '
#   '0.168*"cluster" + 0.161*"process"'),
#  (18,
#   '-0.436*"imag" + 0.265*"train" + 0.231*"use" + 0.195*"label" + 0.192*"task" '
#   '+ -0.181*"bound" + 0.176*"featur" + -0.163*"neuron" + 0.149*"predict" + '
#   '-0.143*"learn"'),
#  (19,
#   '0.316*"kernel" + -0.295*"distribut" + 0.290*"optim" + -0.236*"method" + '
#   '0.233*"comput" + 0.186*"bound" + 0.162*"graph" + -0.157*"problem" + '
#   '0.156*"gradient" + 0.152*"approach"')]
# [(0,
#   '0.352*"model" + 0.290*"learn" + 0.267*"algorithm" + 0.209*"use" + '
#   '0.200*"method" + 0.192*"problem" + 0.190*"data" + 0.149*"propos" + '
#   '0.148*"show" + 0.138*"gener"'),
#  (1,
#   '-0.731*"model" + 0.407*"algorithm" + 0.230*"problem" + 0.164*"optim" + '
#   '0.130*"function" + 0.099*"bound" + -0.099*"network" + -0.094*"imag" + '
#   '0.088*"method" + -0.081*"neural"'),
#  (2,
#   '0.693*"learn" + -0.294*"algorithm" + -0.294*"model" + 0.216*"network" + '
#   '-0.172*"estim" + 0.150*"task" + 0.141*"train" + 0.134*"imag" + '
#   '0.110*"featur" + 0.107*"deep"'),
#  (3,
#   '-0.506*"algorithm" + 0.490*"method" + -0.390*"learn" + -0.272*"model" + '
#   '0.232*"estim" + 0.137*"use" + 0.135*"network" + 0.109*"data" + 0.104*"imag" '
#   '+ 0.097*"propos"'),
#  (4,
#   '0.649*"network" + -0.347*"data" + -0.273*"learn" + 0.241*"neural" + '
#   '0.196*"algorithm" + -0.184*"method" + -0.168*"estim" + 0.122*"imag" + '
#   '0.120*"deep" + 0.118*"train"'),
#  (5,
#   '0.517*"data" + -0.379*"function" + 0.321*"algorithm" + -0.247*"optim" + '
#   '0.244*"cluster" + -0.175*"model" + -0.169*"learn" + 0.164*"imag" + '
#   '-0.161*"problem" + 0.132*"featur"'),
#  (6,
#   '-0.458*"estim" + 0.432*"method" + -0.295*"distribut" + -0.231*"data" + '
#   '-0.220*"network" + -0.204*"sampl" + 0.186*"imag" + 0.169*"model" + '
#   '0.161*"object" + -0.150*"bound"'),
#  (7,
#   '0.496*"imag" + -0.398*"method" + -0.264*"network" + 0.250*"object" + '
#   '0.184*"gener" + -0.181*"learn" + 0.180*"problem" + -0.147*"data" + '
#   '0.142*"use" + -0.138*"algorithm"'),
#  (8,
#   '-0.432*"data" + -0.395*"problem" + 0.335*"estim" + 0.255*"algorithm" + '
#   '0.247*"use" + -0.246*"function" + -0.188*"cluster" + -0.183*"network" + '
#   '0.162*"imag" + 0.160*"method"'),
#  (9,
#   '-0.628*"function" + 0.447*"problem" + -0.270*"use" + -0.178*"data" + '
#   '0.165*"estim" + -0.140*"approxim" + 0.127*"matrix" + 0.117*"structur" + '
#   '0.116*"network" + -0.111*"featur"'),
#  (10,
#   '-0.501*"estim" + 0.334*"distribut" + 0.296*"sampl" + 0.230*"bound" + '
#   '0.215*"gener" + -0.180*"function" + -0.161*"algorithm" + 0.158*"infer" + '
#   '-0.134*"network" + -0.131*"structur"'),
#  (11,
#   '0.430*"use" + 0.278*"problem" + -0.268*"gener" + -0.249*"method" + '
#   '-0.205*"bound" + 0.201*"comput" + 0.198*"infer" + 0.195*"approach" + '
#   '-0.182*"imag" + -0.134*"train"'),
#  (12,
#   '-0.373*"featur" + 0.330*"optim" + -0.240*"bound" + 0.221*"data" + '
#   '-0.214*"kernel" + 0.198*"imag" + 0.189*"estim" + -0.186*"graph" + '
#   '-0.180*"matrix" + 0.172*"approach"'),
#  (13,
#   '0.383*"cluster" + 0.312*"distribut" + 0.274*"graph" + 0.207*"function" + '
#   '-0.195*"optim" + 0.187*"infer" + -0.172*"data" + -0.153*"time" + '
#   '0.149*"approxim" + 0.146*"imag"'),
#  (14,
#   '-0.481*"cluster" + 0.441*"featur" + -0.290*"use" + 0.247*"kernel" + '
#   '0.200*"distribut" + -0.143*"set" + -0.143*"bound" + 0.141*"gener" + '
#   '-0.133*"method" + 0.121*"problem"'),
#  (15,
#   '-0.408*"use" + -0.389*"gener" + 0.295*"cluster" + 0.274*"distribut" + '
#   '0.247*"optim" + 0.241*"featur" + -0.193*"problem" + 0.192*"propos" + '
#   '0.152*"object" + -0.131*"data"'),
#  (16,
#   '-0.314*"cluster" + -0.303*"gener" + 0.300*"label" + 0.296*"approach" + '
#   '-0.275*"optim" + 0.231*"bound" + 0.224*"infer" + -0.206*"featur" + '
#   '0.195*"predict" + -0.167*"use"'),
#  (17,
#   '-0.442*"gener" + -0.309*"propos" + -0.300*"approach" + 0.267*"distribut" + '
#   '-0.212*"task" + 0.202*"featur" + 0.178*"label" + 0.176*"use" + '
#   '-0.170*"cluster" + -0.161*"process"'),
#  (18,
#   '-0.436*"imag" + 0.265*"train" + 0.235*"use" + 0.200*"label" + 0.187*"task" '
#   '+ 0.181*"featur" + -0.176*"bound" + -0.160*"neuron" + 0.149*"predict" + '
#   '-0.142*"learn"'),
#  (19,
#   '-0.316*"kernel" + 0.296*"distribut" + -0.289*"optim" + 0.235*"method" + '
#   '-0.232*"comput" + -0.187*"bound" + -0.165*"graph" + 0.158*"problem" + '
#   '-0.157*"gradient" + -0.150*"approach"'),
#  (20,
#   '0.281*"featur" + -0.260*"label" + 0.235*"bound" + 0.210*"sampl" + '
#   '-0.196*"graph" + -0.194*"distribut" + -0.185*"kernel" + -0.185*"comput" + '
#   '-0.171*"predict" + 0.160*"network"'),
#  (21,
#   '-0.494*"structur" + 0.270*"kernel" + -0.235*"graph" + 0.204*"cluster" + '
#   '0.194*"label" + 0.180*"problem" + -0.179*"optim" + 0.174*"train" + '
#   '-0.170*"propos" + -0.157*"use"'),
#  (22,
#   '-0.346*"propos" + 0.318*"graph" + 0.268*"gener" + -0.256*"matrix" + '
#   '0.221*"set" + 0.169*"optim" + 0.161*"estim" + 0.157*"featur" + '
#   '0.157*"method" + 0.143*"kernel"'),
#  (23,
#   '-0.488*"sampl" + 0.246*"bound" + 0.235*"kernel" + -0.222*"function" + '
#   '0.215*"infer" + 0.213*"set" + -0.191*"comput" + -0.190*"time" + '
#   '-0.167*"graph" + -0.155*"matrix"'),
#  (24,
#   '-0.331*"object" + -0.316*"label" + 0.299*"task" + 0.247*"set" + '
#   '-0.239*"infer" + -0.228*"featur" + 0.203*"imag" + 0.198*"comput" + '
#   '0.164*"structur" + -0.150*"gener"'),
#  (25,
#   '0.407*"kernel" + -0.310*"comput" + -0.229*"approxim" + -0.226*"infer" + '
#   '0.208*"use" + 0.201*"propos" + -0.166*"set" + -0.166*"spars" + '
#   '0.165*"bound" + 0.162*"problem"'),
#  (26,
#   '-0.407*"approach" + 0.368*"object" + 0.302*"task" + 0.264*"infer" + '
#   '0.241*"kernel" + 0.218*"matrix" + -0.163*"propos" + 0.154*"approxim" + '
#   '0.141*"predict" + -0.133*"featur"'),
#  (27,
#   '-0.579*"set" + 0.272*"bound" + -0.268*"matrix" + -0.173*"approach" + '
#   '0.169*"comput" + -0.168*"sampl" + -0.167*"label" + 0.143*"estim" + '
#   '0.143*"show" + 0.137*"data"'),
#  (28,
#   '0.308*"optim" + 0.267*"matrix" + -0.266*"comput" + -0.263*"object" + '
#   '-0.233*"set" + 0.212*"label" + 0.191*"result" + 0.177*"polici" + '
#   '0.167*"graph" + 0.161*"task"'),
#  (29,
#   '0.390*"sampl" + -0.295*"object" + 0.238*"task" + -0.218*"distribut" + '
#   '0.193*"train" + 0.190*"structur" + -0.185*"show" + 0.178*"infer" + '
#   '0.166*"optim" + 0.159*"cluster"'),
#  (30,
#   '-0.379*"approach" + 0.348*"comput" + 0.329*"propos" + -0.258*"train" + '
#   '0.247*"label" + -0.200*"show" + -0.180*"graph" + -0.148*"variabl" + '
#   '-0.136*"rate" + -0.132*"perform"'),
#  (31,
#   '-0.405*"task" + 0.268*"show" + 0.264*"result" + 0.259*"time" + '
#   '-0.234*"bound" + -0.177*"object" + 0.170*"infer" + -0.164*"inform" + '
#   '-0.162*"comput" + 0.158*"loss"'),
#  (32,
#   '0.336*"gradient" + -0.296*"optim" + 0.280*"converg" + -0.219*"object" + '
#   '0.215*"stochast" + 0.206*"label" + 0.184*"process" + 0.179*"rate" + '
#   '-0.178*"rank" + 0.175*"graph"'),
#  (33,
#   '-0.439*"predict" + 0.315*"propos" + 0.303*"show" + -0.280*"approach" + '
#   '0.214*"train" + -0.188*"loss" + 0.142*"neuron" + -0.133*"network" + '
#   '0.126*"approxim" + -0.123*"time"'),
#  (34,
#   '0.302*"matrix" + 0.267*"gradient" + 0.249*"train" + 0.239*"time" + '
#   '-0.209*"sampl" + -0.183*"object" + 0.167*"stochast" + 0.155*"latent" + '
#   '-0.153*"result" + 0.152*"structur"'),
#  (35,
#   '-0.342*"inform" + -0.309*"perform" + 0.273*"time" + 0.254*"graph" + '
#   '-0.217*"structur" + 0.212*"task" + 0.193*"result" + 0.187*"loss" + '
#   '-0.179*"gradient" + 0.150*"optim"'),
#  (36,
#   '0.317*"structur" + -0.292*"graph" + -0.287*"show" + -0.270*"inform" + '
#   '0.197*"label" + -0.194*"set" + 0.194*"polici" + 0.165*"result" + '
#   '0.155*"number" + 0.145*"object"'),
#  (37,
#   '-0.296*"time" + 0.294*"result" + -0.281*"show" + 0.221*"inform" + '
#   '0.220*"train" + 0.203*"loss" + -0.200*"task" + 0.177*"comput" + '
#   '0.161*"infer" + -0.157*"approxim"'),
#  (38,
#   '0.463*"show" + -0.330*"perform" + -0.239*"graph" + -0.205*"propos" + '
#   '-0.172*"predict" + 0.170*"kernel" + -0.162*"approxim" + 0.156*"task" + '
#   '-0.143*"train" + 0.141*"inform"'),
#  (39,
#   '0.387*"time" + -0.342*"loss" + -0.329*"process" + 0.220*"result" + '
#   '-0.192*"polici" + -0.162*"show" + -0.143*"gaussian" + -0.133*"state" + '
#   '0.131*"inform" + 0.127*"provid"'),
#  (40,
#   '-0.328*"approxim" + -0.298*"predict" + 0.266*"process" + -0.215*"structur" '
#   '+ 0.210*"perform" + 0.204*"inform" + 0.184*"number" + 0.171*"time" + '
#   '-0.163*"result" + 0.148*"variabl"'),
#  (41,
#   '0.327*"process" + 0.302*"inform" + -0.270*"variabl" + -0.246*"latent" + '
#   '-0.236*"perform" + 0.234*"train" + -0.179*"dynam" + -0.171*"loss" + '
#   '0.170*"structur" + -0.169*"gradient"'),
#  (42,
#   '0.293*"predict" + -0.250*"perform" + -0.230*"structur" + -0.221*"loss" + '
#   '-0.200*"adapt" + 0.200*"latent" + -0.173*"domain" + 0.168*"variabl" + '
#   '0.160*"linear" + 0.159*"base"'),
#  (43,
#   '-0.357*"approxim" + -0.279*"loss" + -0.266*"inform" + 0.211*"complex" + '
#   '-0.175*"state" + -0.167*"paramet" + -0.167*"variabl" + -0.166*"regular" + '
#   '-0.164*"time" + 0.158*"show"'),
#  (44,
#   '-0.386*"variabl" + -0.192*"condit" + 0.185*"embed" + 0.182*"word" + '
#   '0.169*"sampl" + 0.169*"represent" + -0.161*"select" + 0.156*"state" + '
#   '0.149*"neural" + -0.146*"test"'),
#  (45,
#   '-0.404*"result" + 0.264*"domain" + 0.179*"spars" + 0.168*"two" + '
#   '-0.166*"process" + 0.162*"represent" + 0.161*"differ" + 0.148*"adapt" + '
#   '-0.143*"gradient" + -0.141*"classif"'),
#  (46,
#   '-0.275*"spars" + -0.227*"number" + 0.207*"rate" + 0.188*"rank" + '
#   '0.164*"base" + -0.163*"result" + 0.159*"structur" + 0.154*"perform" + '
#   '0.149*"local" + 0.149*"converg"'),
#  (47,
#   '0.286*"measur" + -0.278*"rate" + 0.216*"gradient" + -0.191*"number" + '
#   '-0.176*"result" + 0.174*"differ" + -0.163*"adapt" + 0.160*"loss" + '
#   '-0.151*"dynam" + -0.149*"system"'),
#  (48,
#   '-0.224*"inform" + -0.220*"local" + -0.218*"system" + -0.212*"paramet" + '
#   '-0.208*"regular" + 0.193*"process" + 0.185*"rate" + -0.185*"linear" + '
#   '-0.184*"base" + -0.170*"dynam"'),
#  (49,
#   '-0.310*"number" + -0.261*"adapt" + 0.238*"regular" + -0.202*"domain" + '
#   '0.185*"perform" + -0.178*"result" + -0.174*"paramet" + 0.170*"polici" + '
#   '-0.165*"dataset" + 0.151*"time"')]
# [(0,
#   '0.352*"model" + 0.290*"learn" + 0.267*"algorithm" + 0.209*"use" + '
#   '0.200*"method" + 0.192*"problem" + 0.190*"data" + 0.149*"propos" + '
#   '0.148*"show" + 0.138*"gener"'),
#  (1,
#   '-0.731*"model" + 0.407*"algorithm" + 0.230*"problem" + 0.164*"optim" + '
#   '0.130*"function" + 0.099*"bound" + -0.099*"network" + -0.094*"imag" + '
#   '0.088*"method" + -0.081*"neural"'),
#  (2,
#   '-0.693*"learn" + 0.294*"algorithm" + 0.294*"model" + -0.216*"network" + '
#   '0.172*"estim" + -0.150*"task" + -0.141*"train" + -0.134*"imag" + '
#   '-0.110*"featur" + -0.107*"deep"'),
#  (3,
#   '0.506*"algorithm" + -0.490*"method" + 0.390*"learn" + 0.272*"model" + '
#   '-0.232*"estim" + -0.137*"use" + -0.135*"network" + -0.109*"data" + '
#   '-0.104*"imag" + -0.097*"propos"'),
#  (4,
#   '-0.649*"network" + 0.347*"data" + 0.273*"learn" + -0.241*"neural" + '
#   '-0.196*"algorithm" + 0.184*"method" + 0.168*"estim" + -0.122*"imag" + '
#   '-0.120*"deep" + -0.118*"train"'),
#  (5,
#   '-0.517*"data" + 0.379*"function" + -0.321*"algorithm" + 0.247*"optim" + '
#   '-0.244*"cluster" + 0.175*"model" + 0.169*"learn" + -0.164*"imag" + '
#   '0.161*"problem" + -0.131*"featur"'),
#  (6,
#   '-0.458*"estim" + 0.432*"method" + -0.295*"distribut" + -0.231*"data" + '
#   '-0.221*"network" + -0.204*"sampl" + 0.186*"imag" + 0.169*"model" + '
#   '0.161*"object" + -0.151*"bound"'),
#  (7,
#   '-0.496*"imag" + 0.398*"method" + 0.264*"network" + -0.250*"object" + '
#   '-0.184*"gener" + 0.181*"learn" + -0.181*"problem" + 0.146*"data" + '
#   '-0.142*"use" + 0.138*"algorithm"'),
#  (8,
#   '-0.432*"data" + -0.395*"problem" + 0.335*"estim" + 0.255*"algorithm" + '
#   '0.247*"use" + -0.246*"function" + -0.188*"cluster" + -0.184*"network" + '
#   '0.162*"imag" + 0.160*"method"'),
#  (9,
#   '-0.628*"function" + 0.447*"problem" + -0.270*"use" + -0.178*"data" + '
#   '0.166*"estim" + -0.140*"approxim" + 0.127*"matrix" + 0.117*"structur" + '
#   '0.116*"network" + -0.111*"featur"'),
#  (10,
#   '-0.501*"estim" + 0.335*"distribut" + 0.296*"sampl" + 0.230*"bound" + '
#   '0.215*"gener" + -0.180*"function" + -0.160*"algorithm" + 0.157*"infer" + '
#   '-0.134*"network" + -0.131*"structur"'),
#  (11,
#   '-0.430*"use" + -0.279*"problem" + 0.268*"gener" + 0.250*"method" + '
#   '0.204*"bound" + -0.202*"comput" + -0.197*"infer" + -0.195*"approach" + '
#   '0.181*"imag" + 0.135*"train"'),
#  (12,
#   '-0.373*"featur" + 0.330*"optim" + -0.240*"bound" + 0.221*"data" + '
#   '-0.214*"kernel" + 0.199*"imag" + 0.190*"estim" + -0.186*"graph" + '
#   '-0.180*"matrix" + 0.172*"approach"'),
#  (13,
#   '0.383*"cluster" + 0.312*"distribut" + 0.274*"graph" + 0.207*"function" + '
#   '-0.196*"optim" + 0.187*"infer" + -0.172*"data" + -0.152*"time" + '
#   '0.148*"approxim" + 0.147*"imag"'),
#  (14,
#   '0.481*"cluster" + -0.442*"featur" + 0.290*"use" + -0.246*"kernel" + '
#   '-0.201*"distribut" + 0.143*"set" + 0.142*"bound" + -0.141*"gener" + '
#   '0.132*"method" + -0.120*"problem"'),
#  (15,
#   '-0.407*"use" + -0.389*"gener" + 0.295*"cluster" + 0.275*"distribut" + '
#   '0.248*"optim" + 0.241*"featur" + -0.192*"problem" + 0.192*"propos" + '
#   '0.152*"object" + -0.131*"data"'),
#  (16,
#   '-0.313*"cluster" + -0.303*"gener" + 0.299*"label" + 0.296*"approach" + '
#   '-0.274*"optim" + 0.230*"bound" + 0.225*"infer" + -0.206*"featur" + '
#   '0.198*"predict" + -0.168*"use"'),
#  (17,
#   '0.442*"gener" + 0.310*"propos" + 0.299*"approach" + -0.269*"distribut" + '
#   '0.211*"task" + -0.202*"featur" + -0.179*"label" + -0.177*"use" + '
#   '0.171*"cluster" + 0.161*"process"'),
#  (18,
#   '-0.436*"imag" + 0.265*"train" + 0.234*"use" + 0.199*"label" + 0.187*"task" '
#   '+ 0.182*"featur" + -0.178*"bound" + -0.162*"neuron" + 0.150*"predict" + '
#   '-0.142*"learn"'),
#  (19,
#   '-0.316*"kernel" + 0.294*"distribut" + -0.288*"optim" + 0.236*"method" + '
#   '-0.230*"comput" + -0.188*"bound" + -0.164*"graph" + 0.157*"problem" + '
#   '-0.157*"gradient" + -0.150*"approach"'),
#  (20,
#   '-0.281*"featur" + 0.262*"label" + -0.237*"bound" + -0.210*"sampl" + '
#   '0.195*"graph" + 0.194*"distribut" + 0.189*"kernel" + 0.181*"comput" + '
#   '0.174*"predict" + -0.159*"network"'),
#  (21,
#   '-0.497*"structur" + 0.267*"kernel" + -0.236*"graph" + 0.204*"cluster" + '
#   '0.197*"label" + 0.179*"problem" + -0.178*"optim" + 0.176*"train" + '
#   '-0.171*"propos" + -0.157*"use"'),
#  (22,
#   '-0.346*"propos" + 0.320*"graph" + 0.271*"gener" + -0.253*"matrix" + '
#   '0.217*"set" + 0.168*"optim" + 0.162*"estim" + 0.159*"featur" + '
#   '0.156*"method" + 0.143*"label"'),
#  (23,
#   '0.487*"sampl" + -0.245*"bound" + -0.245*"kernel" + 0.221*"function" + '
#   '-0.216*"set" + -0.214*"infer" + 0.193*"comput" + 0.188*"time" + '
#   '0.164*"matrix" + 0.160*"graph"'),
#  (24,
#   '-0.330*"object" + -0.315*"label" + 0.299*"task" + 0.249*"set" + '
#   '-0.238*"infer" + -0.229*"featur" + 0.204*"imag" + 0.197*"comput" + '
#   '0.162*"structur" + -0.150*"gener"'),
#  (25,
#   '0.404*"kernel" + -0.314*"comput" + -0.230*"infer" + -0.227*"approxim" + '
#   '0.208*"use" + 0.198*"propos" + -0.167*"set" + -0.166*"spars" + '
#   '0.163*"problem" + 0.161*"bound"'),
#  (26,
#   '-0.411*"approach" + 0.379*"object" + 0.299*"task" + 0.261*"infer" + '
#   '0.247*"kernel" + 0.211*"matrix" + 0.156*"approxim" + -0.156*"propos" + '
#   '0.141*"predict" + -0.134*"featur"'),
#  (27,
#   '0.574*"set" + -0.276*"bound" + 0.276*"matrix" + 0.178*"approach" + '
#   '-0.174*"comput" + 0.171*"label" + 0.164*"sampl" + -0.145*"estim" + '
#   '-0.141*"show" + -0.134*"data"'),
#  (28,
#   '0.302*"optim" + -0.264*"comput" + 0.261*"matrix" + -0.257*"object" + '
#   '-0.250*"set" + 0.205*"label" + 0.195*"result" + 0.181*"polici" + '
#   '0.175*"graph" + 0.171*"task"'),
#  (29,
#   '-0.395*"sampl" + 0.291*"object" + -0.240*"task" + 0.218*"distribut" + '
#   '-0.200*"train" + -0.191*"structur" + 0.185*"show" + -0.172*"infer" + '
#   '-0.163*"optim" + -0.160*"cluster"'),
#  (30,
#   '-0.384*"approach" + 0.334*"comput" + 0.330*"propos" + -0.258*"train" + '
#   '0.249*"label" + -0.205*"show" + -0.181*"graph" + -0.142*"variabl" + '
#   '-0.134*"rate" + -0.127*"perform"'),
#  (31,
#   '-0.395*"task" + 0.271*"show" + 0.261*"time" + 0.256*"result" + '
#   '-0.238*"bound" + -0.192*"object" + -0.180*"comput" + 0.173*"infer" + '
#   '-0.169*"inform" + 0.155*"loss"'),
#  (32,
#   '-0.340*"gradient" + 0.296*"optim" + -0.284*"converg" + -0.226*"stochast" + '
#   '0.215*"object" + -0.199*"label" + -0.186*"rate" + -0.181*"process" + '
#   '0.175*"rank" + -0.175*"graph"'),
#  (33,
#   '0.436*"predict" + -0.325*"propos" + -0.308*"show" + 0.284*"approach" + '
#   '-0.204*"train" + 0.196*"loss" + 0.130*"network" + -0.126*"neuron" + '
#   '0.121*"time" + -0.119*"approxim"'),
#  (34,
#   '0.303*"matrix" + 0.257*"gradient" + 0.255*"train" + 0.244*"time" + '
#   '-0.211*"sampl" + -0.172*"object" + 0.161*"stochast" + 0.159*"latent" + '
#   '0.158*"structur" + -0.149*"result"'),
#  (35,
#   '-0.346*"inform" + -0.302*"perform" + 0.274*"time" + 0.259*"graph" + '
#   '-0.216*"structur" + 0.206*"task" + 0.195*"result" + -0.185*"gradient" + '
#   '0.179*"loss" + 0.151*"optim"'),
#  (36,
#   '-0.332*"structur" + 0.319*"graph" + 0.306*"inform" + -0.227*"label" + '
#   '0.225*"show" + 0.188*"set" + -0.169*"polici" + -0.153*"number" + '
#   '-0.144*"object" + -0.137*"complex"'),
#  (37,
#   '-0.318*"show" + 0.312*"result" + -0.277*"time" + 0.228*"train" + '
#   '-0.215*"task" + 0.188*"loss" + 0.186*"comput" + -0.172*"approxim" + '
#   '0.165*"inform" + 0.147*"observ"'),
#  (38,
#   '0.480*"show" + -0.339*"perform" + -0.224*"graph" + -0.202*"propos" + '
#   '0.171*"kernel" + 0.164*"task" + -0.160*"approxim" + -0.151*"predict" + '
#   '-0.145*"train" + -0.131*"process"'),
#  (39,
#   '0.370*"time" + -0.338*"loss" + -0.331*"process" + 0.235*"result" + '
#   '-0.188*"polici" + -0.146*"gaussian" + 0.143*"inform" + -0.138*"show" + '
#   '-0.129*"state" + 0.124*"provid"'),
#  (40,
#   '0.347*"approxim" + 0.301*"predict" + -0.235*"process" + 0.215*"structur" + '
#   '-0.211*"perform" + -0.187*"inform" + -0.186*"number" + -0.178*"time" + '
#   '0.164*"result" + -0.161*"variabl"'),
#  (41,
#   '0.332*"process" + 0.331*"inform" + -0.290*"variabl" + -0.254*"latent" + '
#   '0.213*"train" + -0.187*"perform" + 0.185*"structur" + -0.174*"dynam" + '
#   '-0.171*"gradient" + -0.152*"predict"'),
#  (42,
#   '-0.297*"predict" + 0.265*"perform" + 0.226*"loss" + 0.216*"structur" + '
#   '0.188*"adapt" + -0.166*"base" + 0.165*"time" + 0.163*"domain" + '
#   '-0.162*"latent" + -0.161*"process"'),
#  (43,
#   '0.353*"approxim" + 0.281*"loss" + 0.253*"inform" + 0.214*"variabl" + '
#   '-0.210*"complex" + 0.176*"state" + 0.168*"regular" + 0.160*"time" + '
#   '0.158*"paramet" + -0.156*"infer"'),
#  (44,
#   '-0.379*"variabl" + -0.182*"condit" + 0.180*"word" + 0.177*"sampl" + '
#   '0.171*"embed" + -0.164*"train" + 0.157*"state" + 0.150*"neural" + '
#   '0.148*"represent" + 0.144*"approxim"'),
#  (45,
#   '0.397*"result" + -0.256*"domain" + -0.191*"spars" + -0.189*"represent" + '
#   '0.169*"process" + 0.158*"gradient" + -0.149*"differ" + -0.148*"regular" + '
#   '0.146*"classif" + -0.141*"infer"'),
#  (46,
#   '0.291*"spars" + -0.203*"rate" + -0.196*"base" + -0.178*"local" + '
#   '-0.177*"rank" + 0.168*"result" + 0.166*"number" + 0.159*"represent" + '
#   '-0.153*"structur" + -0.136*"converg"'),
#  (47,
#   '0.255*"measur" + -0.229*"number" + 0.218*"differ" + -0.194*"rate" + '
#   '-0.185*"system" + -0.179*"dynam" + -0.179*"result" + 0.164*"gradient" + '
#   '-0.159*"adapt" + 0.157*"polici"'),
#  (48,
#   '-0.272*"rate" + 0.250*"paramet" + 0.216*"inform" + 0.211*"local" + '
#   '-0.192*"process" + 0.180*"regular" + 0.177*"base" + 0.169*"system" + '
#   '0.169*"linear" + 0.168*"gradient"'),
#  (49,
#   '-0.335*"number" + -0.256*"adapt" + 0.237*"regular" + -0.207*"domain" + '
#   '0.201*"perform" + -0.174*"result" + -0.169*"paramet" + -0.156*"measur" + '
#   '-0.155*"predict" + 0.149*"time"'),
#  (50,
#   '0.288*"class" + 0.265*"new" + -0.209*"infer" + 0.192*"provid" + '
#   '0.183*"base" + -0.179*"local" + -0.177*"space" + -0.175*"perform" + '
#   '-0.169*"result" + 0.147*"latent"'),
#  (51,
#   '-0.344*"number" + 0.180*"differ" + -0.175*"class" + 0.168*"represent" + '
#   '0.166*"adapt" + -0.164*"framework" + 0.162*"domain" + -0.158*"polici" + '
#   '0.157*"latent" + 0.140*"comput"'),
#  (52,
#   '-0.304*"paramet" + 0.266*"effici" + 0.230*"framework" + 0.200*"domain" + '
#   '0.179*"random" + 0.152*"dynam" + 0.150*"linear" + -0.146*"comput" + '
#   '0.145*"applic" + 0.144*"adapt"'),
#  (53,
#   '0.298*"framework" + -0.232*"activ" + 0.231*"linear" + -0.213*"human" + '
#   '0.207*"new" + -0.154*"state" + 0.148*"analysi" + 0.142*"base" + '
#   '-0.136*"rate" + 0.129*"deep"'),
#  (54,
#   '0.289*"base" + 0.234*"regular" + -0.220*"provid" + -0.203*"propos" + '
#   '0.188*"new" + -0.186*"linear" + 0.186*"gradient" + -0.162*"converg" + '
#   '0.152*"select" + 0.148*"spars"'),
#  (55,
#   '0.223*"random" + 0.220*"state" + -0.218*"latent" + -0.217*"dynam" + '
#   '0.183*"local" + -0.176*"label" + 0.165*"tree" + 0.157*"activ" + '
#   '0.154*"class" + -0.149*"result"'),
#  (56,
#   '0.316*"state" + -0.256*"local" + -0.217*"human" + -0.188*"loss" + '
#   '0.187*"predict" + 0.172*"inform" + -0.157*"regret" + -0.157*"game" + '
#   '0.150*"measur" + -0.147*"latent"'),
#  (57,
#   '-0.326*"observ" + -0.268*"test" + 0.257*"provid" + -0.225*"linear" + '
#   '-0.195*"class" + -0.176*"dynam" + 0.154*"random" + -0.149*"approxim" + '
#   '0.145*"local" + 0.139*"regular"'),
#  (58,
#   '0.374*"paramet" + -0.251*"polici" + -0.208*"spars" + 0.182*"embed" + '
#   '-0.177*"error" + -0.173*"rank" + -0.167*"number" + 0.150*"class" + '
#   '0.147*"regular" + 0.145*"effici"'),
#  (59,
#   '-0.265*"new" + 0.239*"tree" + -0.216*"measur" + -0.213*"complex" + '
#   '-0.211*"select" + -0.193*"condit" + 0.184*"observ" + -0.178*"framework" + '
#   '-0.167*"activ" + 0.166*"decis"'),
#  (60,
#   '0.235*"adapt" + -0.205*"new" + -0.202*"state" + -0.173*"condit" + '
#   '0.172*"domain" + 0.154*"word" + 0.153*"polici" + 0.146*"provid" + '
#   '-0.145*"rank" + 0.145*"classif"'),
#  (61,
#   '0.344*"framework" + -0.213*"linear" + 0.212*"paramet" + -0.210*"new" + '
#   '0.183*"statist" + -0.161*"provid" + 0.157*"random" + -0.152*"metric" + '
#   '-0.146*"class" + -0.146*"regular"'),
#  (62,
#   '-0.380*"effici" + -0.220*"provid" + -0.211*"measur" + 0.200*"linear" + '
#   '0.186*"condit" + 0.182*"embed" + 0.174*"process" + -0.172*"metric" + '
#   '-0.143*"local" + -0.124*"spars"'),
#  (63,
#   '-0.430*"test" + 0.254*"base" + 0.234*"measur" + -0.223*"statist" + '
#   '0.180*"complex" + 0.178*"class" + 0.133*"approxim" + -0.129*"dataset" + '
#   '-0.129*"activ" + -0.128*"provid"'),
#  (64,
#   '-0.261*"base" + 0.188*"framework" + 0.186*"analysi" + 0.178*"class" + '
#   '0.178*"train" + -0.177*"deep" + -0.176*"neural" + 0.158*"state" + '
#   '0.157*"differ" + -0.140*"new"'),
#  (65,
#   '-0.358*"class" + -0.266*"effici" + 0.228*"new" + -0.204*"paramet" + '
#   '0.193*"provid" + 0.190*"regress" + -0.181*"represent" + -0.178*"polici" + '
#   '0.156*"state" + 0.153*"bayesian"'),
#  (66,
#   '0.406*"base" + -0.288*"new" + 0.212*"provid" + -0.187*"tree" + '
#   '-0.176*"complex" + -0.176*"regress" + -0.153*"dataset" + -0.139*"rate" + '
#   '-0.127*"embed" + 0.125*"perform"'),
#  (67,
#   '0.286*"rank" + -0.203*"random" + 0.190*"provid" + -0.185*"activ" + '
#   '0.174*"regress" + 0.164*"represent" + -0.156*"measur" + 0.153*"space" + '
#   '-0.147*"convex" + -0.138*"dynam"'),
#  (68,
#   '-0.410*"complex" + -0.234*"test" + -0.226*"two" + 0.197*"paramet" + '
#   '-0.177*"regular" + 0.161*"activ" + -0.139*"framework" + -0.126*"spike" + '
#   '0.125*"system" + 0.125*"deep"'),
#  (69,
#   '0.319*"effici" + 0.242*"error" + -0.200*"space" + 0.192*"activ" + '
#   '0.166*"achiev" + -0.164*"framework" + 0.161*"layer" + 0.149*"deep" + '
#   '0.149*"weight" + 0.142*"linear"'),
#  (70,
#   '0.215*"hash" + 0.211*"similar" + 0.211*"framework" + -0.203*"analysi" + '
#   '0.174*"two" + -0.165*"space" + -0.164*"represent" + 0.161*"code" + '
#   '-0.154*"rank" + 0.138*"work"'),
#  (71,
#   '0.336*"condit" + -0.214*"base" + 0.183*"local" + 0.168*"decis" + '
#   '0.160*"represent" + 0.160*"framework" + 0.158*"tree" + -0.153*"studi" + '
#   '0.147*"minim" + -0.147*"space"'),
#  (72,
#   '-0.222*"two" + 0.197*"random" + 0.189*"dynam" + -0.179*"observ" + '
#   '0.177*"condit" + 0.167*"provid" + 0.160*"class" + 0.153*"embed" + '
#   '-0.144*"activ" + -0.142*"linear"'),
#  (73,
#   '-0.287*"new" + -0.234*"observ" + 0.226*"neural" + 0.194*"dataset" + '
#   '-0.190*"error" + 0.184*"linear" + 0.169*"regress" + 0.154*"differ" + '
#   '-0.154*"provid" + -0.152*"activ"'),
#  (74,
#   '0.210*"class" + 0.183*"rank" + 0.177*"neural" + -0.169*"select" + '
#   '0.168*"prior" + -0.158*"provid" + -0.155*"matrix" + 0.147*"bayesian" + '
#   '0.146*"spars" + 0.146*"two"'),
#  (75,
#   '-0.283*"game" + -0.208*"rank" + -0.202*"activ" + 0.189*"human" + '
#   '0.185*"analysi" + -0.145*"domain" + 0.141*"random" + -0.138*"dynam" + '
#   '-0.136*"larg" + 0.133*"number"'),
#  (76,
#   '0.257*"local" + -0.239*"bayesian" + -0.224*"differ" + 0.192*"topic" + '
#   '0.187*"observ" + -0.158*"tree" + -0.157*"embed" + 0.148*"condit" + '
#   '-0.145*"dynam" + 0.135*"statist"'),
#  (77,
#   '-0.250*"present" + 0.218*"random" + 0.213*"regular" + -0.145*"nois" + '
#   '-0.144*"embed" + 0.138*"rank" + -0.135*"condit" + 0.135*"latent" + '
#   '-0.134*"regress" + -0.132*"analysi"'),
#  (78,
#   '-0.236*"error" + -0.233*"regular" + -0.188*"dataset" + 0.175*"spars" + '
#   '-0.173*"point" + 0.159*"tree" + 0.152*"condit" + -0.146*"select" + '
#   '0.145*"search" + -0.135*"metric"'),
#  (79,
#   '0.302*"dataset" + 0.219*"linear" + -0.217*"differ" + -0.188*"number" + '
#   '0.188*"represent" + 0.165*"rank" + 0.153*"measur" + -0.149*"complex" + '
#   '-0.148*"code" + -0.144*"paper"'),
#  (80,
#   '0.198*"measur" + -0.190*"compon" + 0.184*"regular" + -0.182*"similar" + '
#   '0.169*"represent" + -0.164*"spars" + -0.158*"space" + 0.157*"random" + '
#   '0.147*"deep" + -0.147*"complex"'),
#  (81,
#   '-0.214*"space" + 0.194*"improv" + -0.183*"game" + -0.173*"dataset" + '
#   '0.165*"variabl" + 0.160*"regret" + 0.155*"similar" + 0.154*"decis" + '
#   '0.153*"rank" + 0.134*"regular"'),
#  (82,
#   '0.230*"space" + -0.205*"metric" + -0.165*"select" + -0.157*"similar" + '
#   '-0.156*"observ" + 0.151*"local" + 0.151*"studi" + -0.149*"framework" + '
#   '-0.144*"variat" + 0.143*"input"'),
#  (83,
#   '-0.218*"represent" + -0.198*"dynam" + -0.194*"tree" + 0.183*"demonstr" + '
#   '0.145*"paramet" + -0.134*"base" + -0.132*"improv" + 0.132*"experi" + '
#   '-0.131*"deep" + 0.129*"classifi"'),
#  (84,
#   '-0.262*"improv" + -0.236*"prior" + 0.228*"studi" + 0.206*"two" + '
#   '-0.176*"bayesian" + -0.156*"select" + 0.150*"probabl" + -0.143*"present" + '
#   '0.136*"neural" + 0.133*"decis"'),
#  (85,
#   '-0.242*"improv" + 0.185*"point" + -0.177*"memori" + -0.173*"test" + '
#   '-0.168*"condit" + -0.157*"variat" + -0.153*"game" + -0.148*"regular" + '
#   '0.148*"weight" + -0.140*"metric"'),
#  (86,
#   '0.219*"regress" + 0.192*"topic" + -0.192*"space" + 0.176*"select" + '
#   '0.164*"tree" + -0.155*"dataset" + 0.155*"two" + 0.151*"word" + '
#   '0.150*"local" + -0.125*"activ"'),
#  (87,
#   '0.237*"game" + 0.193*"depend" + 0.159*"statist" + -0.156*"class" + '
#   '-0.155*"weight" + 0.141*"paper" + -0.137*"regress" + -0.133*"robust" + '
#   '0.121*"tree" + -0.121*"space"'),
#  (88,
#   '-0.192*"adapt" + 0.188*"differ" + -0.163*"demonstr" + -0.159*"layer" + '
#   '-0.151*"dataset" + 0.140*"framework" + 0.139*"rank" + 0.137*"human" + '
#   '0.136*"regress" + -0.134*"signal"'),
#  (89,
#   '0.206*"point" + -0.160*"vector" + 0.159*"dynam" + -0.158*"neural" + '
#   '0.156*"random" + 0.143*"solut" + 0.139*"deep" + 0.137*"probabl" + '
#   '0.134*"also" + 0.134*"work"'),
#  (90,
#   '0.225*"larg" + 0.196*"deep" + 0.175*"norm" + 0.174*"convex" + '
#   '-0.169*"signal" + -0.169*"also" + 0.155*"develop" + -0.153*"factor" + '
#   '-0.146*"improv" + -0.137*"random"'),
#  (91,
#   '-0.272*"demonstr" + 0.162*"differ" + -0.162*"measur" + 0.159*"error" + '
#   '-0.158*"paper" + 0.156*"user" + -0.155*"analysi" + 0.150*"state" + '
#   '0.148*"game" + 0.144*"onlin"'),
#  (92,
#   '0.177*"work" + -0.176*"number" + -0.160*"random" + 0.159*"code" + '
#   '-0.158*"classifi" + 0.142*"bayesian" + 0.141*"latent" + 0.140*"user" + '
#   '-0.139*"natur" + 0.130*"nois"'),
#  (93,
#   '-0.260*"also" + 0.233*"human" + 0.212*"weight" + 0.156*"memori" + '
#   '-0.133*"complex" + 0.120*"game" + 0.116*"topic" + -0.114*"converg" + '
#   '0.113*"find" + -0.113*"map"'),
#  (94,
#   '0.266*"also" + -0.256*"metric" + 0.194*"onlin" + 0.173*"larg" + '
#   '-0.151*"prior" + 0.150*"analysi" + 0.144*"user" + 0.117*"design" + '
#   '-0.117*"provid" + -0.115*"case"'),
#  (95,
#   '-0.260*"improv" + 0.193*"represent" + 0.170*"adapt" + -0.156*"system" + '
#   '-0.154*"probabl" + 0.138*"input" + 0.137*"action" + 0.136*"select" + '
#   '-0.128*"point" + 0.125*"demonstr"'),
#  (96,
#   '0.273*"also" + -0.176*"represent" + 0.168*"minim" + 0.166*"demonstr" + '
#   '-0.159*"present" + 0.151*"norm" + -0.149*"nois" + -0.143*"rate" + '
#   '0.132*"one" + -0.131*"onlin"'),
#  (97,
#   '0.260*"visual" + 0.247*"paper" + 0.236*"present" + 0.180*"deep" + '
#   '-0.159*"norm" + -0.150*"match" + 0.140*"experi" + -0.137*"work" + '
#   '0.133*"regress" + 0.129*"minim"'),
#  (98,
#   '0.206*"metric" + -0.195*"select" + -0.158*"two" + -0.157*"experi" + '
#   '0.149*"framework" + -0.147*"present" + -0.145*"point" + 0.143*"empir" + '
#   '-0.135*"norm" + 0.132*"deep"'),
#  (99,
#   '0.247*"demonstr" + 0.204*"weight" + 0.196*"natur" + 0.190*"point" + '
#   '-0.172*"random" + 0.171*"tree" + -0.158*"effici" + -0.154*"metric" + '
#   '0.149*"visual" + 0.148*"space"')]

# %% [markdown]
# # Evaluation

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.




coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)

coherence_model_lsa = CoherenceModel(model=lsi_model, texts=texts, dictionary=id2word, coherence='u_mass')
coherence_lsa = coherence_model_lsa.get_coherence()
print('\nCoherence Score: ', coherence_lsa)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score5: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score10: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score20: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score50: ', coherence_lsi)

# Compute Coherence Score
coherence_model_lsi = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi = coherence_model_lsi.get_coherence()
print('\nCoherence Score100: ', coherence_lsi)
# Out:
# Coherence Score:  0.25545931125308097
#
# Coherence Score5:  0.39581850693804266
#
# Coherence Score10:  0.33438864521992995
#
# Coherence Score20:  0.3129252455390608
#
# Coherence Score50:  0.26852417815632545
#
# Coherence Score100:  0.23019417570332634
#
# Coherence Score:  -1.1490767037588188
#
# Coherence Score5:  -2.1067155489734253
#
# Coherence Score10:  -1.9292452901755552
#
# Coherence Score20:  -1.8362967538194226
#
# Coherence Score50:  -2.010876425762292
#
# Coherence Score100:  -2.2579269381318907
