# %%
import re, string, unicodedata
import numpy as np
import pandas as pd
from pprint import pprint
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary


nltk.download('wordnet')
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
#from bs4 import BeautifulSoup
#from nltk import word_tokenize, sent_tokenize

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inlin

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\Kornelius\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kornelius\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Import data and prepare data

# %%
# Load dataset
df = pd.read_excel('C:/Users/Kornelius/Desktop/Data 2/ecbpr/Warin_Sanger_ECB.xlsx') 
df.head()
# Out:
#    Date                                              Press  \
# 0  1998  Ladies and gentlemen, in line with our stated ...
# 1  1998  Ladies and gentlemen, as in previous months, t...
# 2  1998  Ladies and gentlemen, the Vice-President and I...
# 3  1998  Ladies and gentlemen, the Vice-President and I...
# 4  1999  Ladies and gentlemen, the Vice-President and I...
#
#                                                   qa
# 0  We have no indications based on the most recen...
# 1  The answer to the first question is that it is...
# 2  We simply felt that the announcement of a rang...
# 3  No, that is not a signal that it is supposed t...
# 4  The main problems have not been technical ones...

# %%
#df = df.values.tolist()
# Drop a row by condition
# Print out the first rows of papers
#df = df[df.press]
df = df['Press']

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(df):
    stop_free = " ".join([i for i in df.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

data = [clean(df).split()for df in df]

# %%
# remove characters and numbers
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
data = data_words
# Create Dictionary
id2word = corpora.Dictionary(data)
print((id2word))
# Out:
# Dictionary(4394 unique tokens: ['able', 'acceptable', 'accompanied', 'according', 'account']...)

# %%
id2word.filter_n_most_frequent(10)
print((id2word))
# Out:
# Dictionary(4384 unique tokens: ['able', 'acceptable', 'accompanied', 'according', 'account']...)

# %%
# Create Corpus
texts = data
# Term Document Frequency and creating corpus
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# Gensim creates a unique id for each word in the document. The produced corpus shown above is a mapping of (word_id, word_frequency).
# For example, (0, 1) above implies, word id 0 occurs once in the first document. Likewise, word id 1 occurs twice and so on.
# This is used as the input by the LDA model.

# %% [markdown]
# We have everything required to train the LDA model. In addition to the corpus and dictionary, you need to provide the number of topics as well.
#
# Apart from that, alpha and eta are hyperparameters that affect sparsity of the topics. According to the Gensim docs, both defaults to 1.0/num_topics prior.
#
# chunksize is the number of documents to be used in each training chunk. update_every determines how often the model parameters should be updated and passes is the total number of training passes.

# %%
# Build the LSI Model
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
lsi_model = LsiModel(corpus=corpus, id2word=id2word, num_topics=1, decay=0.5)

lsi_model5 = LsiModel(corpus=corpus, id2word=id2word, num_topics=5, decay=0.5)

lsi_model10 = LsiModel(corpus=corpus, id2word=id2word, num_topics=10, decay=0.5)

lsi_model20 = LsiModel(corpus=corpus, id2word=id2word, num_topics=20, decay=0.5)

lsi_model50 = LsiModel(corpus=corpus, id2word=id2word, num_topics=50, decay=0.5)

lsi_model100 = LsiModel(corpus=corpus, id2word=id2word, num_topics=100, decay=0.5)

# %%
# View Topics
pprint(lsi_model.print_topics(-1))

# Print the Keyword in the 5 topics
pprint(lsi_model5.print_topics(-1))
doc_lsi = lsi_model5[corpus]

# Print the Keyword in the 5 topics
pprint(lsi_model10.print_topics(-1))
doc_lsi = lsi_model10[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model20.print_topics(-1))
doc_lsi = lsi_model20[corpus]

# Print the Keyword in the 20 topics
pprint(lsi_model50.print_topics(-1))
doc_lsi = lsi_model50[corpus]

# Print the Keyword in the 40 topics
pprint(lsi_model100.print_topics(-1))
doc_lsi = lsi_model100[corpus]
# Out:
# [(0,
#   '0.246*"inflation" + 0.187*"risk" + 0.181*"policy" + 0.177*"governing" + '
#   '0.176*"stability" + 0.166*"market" + 0.158*"term" + 0.157*"medium" + '
#   '0.154*"annual" + 0.139*"remain"')]
# [(0,
#   '0.246*"inflation" + 0.187*"risk" + 0.181*"policy" + 0.177*"governing" + '
#   '0.176*"stability" + 0.166*"market" + 0.158*"term" + 0.157*"medium" + '
#   '0.154*"annual" + 0.139*"remain"'),
#  (1,
#   '0.335*"governing" + -0.218*"inflation" + 0.202*"ecb" + -0.164*"loan" + '
#   '0.158*"stability" + 0.153*"first" + 0.148*"interest" + 0.138*"central" + '
#   '0.134*"today" + -0.133*"remain"'),
#  (2,
#   '-0.285*"stability" + -0.254*"risk" + 0.238*"policy" + 0.205*"governing" + '
#   '-0.192*"strong" + -0.182*"upside" + 0.153*"loan" + 0.145*"measure" + '
#   '0.124*"recovery" + -0.122*"oil"'),
#  (3,
#   '0.245*"policy" + 0.196*"oil" + -0.173*"financial" + -0.168*"pressure" + '
#   '-0.163*"governing" + 0.149*"projection" + -0.148*"remain" + -0.145*"medium" '
#   '+ 0.140*"reform" + 0.128*"quarter"'),
#  (4,
#   '0.346*"market" + 0.282*"financial" + 0.246*"risk" + -0.202*"term" + '
#   '-0.177*"recovery" + -0.164*"remain" + 0.138*"underlying" + -0.129*"oil" + '
#   '-0.122*"medium" + 0.119*"credit"')]
# [(0,
#   '0.246*"inflation" + 0.187*"risk" + 0.181*"policy" + 0.177*"governing" + '
#   '0.176*"stability" + 0.166*"market" + 0.158*"term" + 0.157*"medium" + '
#   '0.154*"annual" + 0.139*"remain"'),
#  (1,
#   '-0.335*"governing" + 0.218*"inflation" + -0.202*"ecb" + 0.164*"loan" + '
#   '-0.158*"stability" + -0.153*"first" + -0.148*"interest" + -0.138*"central" '
#   '+ -0.134*"today" + 0.133*"remain"'),
#  (2,
#   '0.285*"stability" + 0.254*"risk" + -0.238*"policy" + -0.205*"governing" + '
#   '0.192*"strong" + 0.182*"upside" + -0.153*"loan" + -0.145*"measure" + '
#   '-0.124*"recovery" + 0.122*"oil"'),
#  (3,
#   '-0.245*"policy" + -0.196*"oil" + 0.173*"financial" + 0.168*"pressure" + '
#   '0.163*"governing" + -0.149*"projection" + 0.148*"remain" + 0.145*"medium" + '
#   '-0.140*"reform" + -0.128*"quarter"'),
#  (4,
#   '-0.346*"market" + -0.282*"financial" + -0.246*"risk" + 0.202*"term" + '
#   '0.177*"recovery" + 0.164*"remain" + -0.138*"underlying" + 0.129*"oil" + '
#   '0.122*"medium" + -0.119*"credit"'),
#  (5,
#   '-0.193*"increase" + 0.175*"financial" + -0.154*"remains" + 0.141*"effect" + '
#   '0.138*"stability" + 0.134*"inflation" + -0.130*"liquidity" + 0.115*"policy" '
#   '+ -0.115*"pressure" + -0.114*"overall"'),
#  (6,
#   '0.331*"projection" + 0.235*"staff" + 0.171*"governing" + -0.165*"financial" '
#   '+ 0.150*"range" + 0.139*"macroeconomic" + -0.135*"reform" + 0.122*"upside" '
#   '+ 0.121*"measure" + -0.119*"demand"'),
#  (7,
#   '0.233*"projection" + 0.224*"inflation" + -0.213*"medium" + 0.203*"pressure" '
#   '+ 0.191*"recent" + -0.186*"credit" + -0.173*"remain" + 0.154*"staff" + '
#   '0.137*"inflationary" + -0.135*"loan"'),
#  (8,
#   '-0.360*"policy" + -0.221*"measure" + 0.219*"projection" + 0.149*"subdued" + '
#   '0.130*"staff" + 0.122*"eurosystem" + 0.105*"expected" + -0.105*"purchase" + '
#   '-0.103*"tension" + 0.099*"annual"'),
#  (9,
#   '0.223*"financial" + 0.184*"market" + -0.148*"energy" + -0.143*"food" + '
#   '-0.138*"may" + 0.116*"fiscal" + -0.112*"recent" + -0.107*"contribute" + '
#   '0.107*"reform" + 0.106*"environment"')]
# [(0,
#   '0.246*"inflation" + 0.187*"risk" + 0.181*"policy" + 0.177*"governing" + '
#   '0.176*"stability" + 0.166*"market" + 0.158*"term" + 0.157*"medium" + '
#   '0.154*"annual" + 0.139*"remain"'),
#  (1,
#   '-0.335*"governing" + 0.218*"inflation" + -0.202*"ecb" + 0.164*"loan" + '
#   '-0.158*"stability" + -0.153*"first" + -0.148*"interest" + -0.138*"central" '
#   '+ -0.134*"today" + 0.133*"remain"'),
#  (2,
#   '0.285*"stability" + 0.254*"risk" + -0.238*"policy" + -0.205*"governing" + '
#   '0.192*"strong" + 0.182*"upside" + -0.153*"loan" + -0.145*"measure" + '
#   '-0.124*"recovery" + 0.122*"oil"'),
#  (3,
#   '-0.245*"policy" + -0.196*"oil" + 0.173*"financial" + 0.168*"pressure" + '
#   '0.163*"governing" + -0.149*"projection" + 0.148*"remain" + 0.145*"medium" + '
#   '-0.140*"reform" + -0.128*"quarter"'),
#  (4,
#   '-0.346*"market" + -0.282*"financial" + -0.246*"risk" + 0.203*"term" + '
#   '0.177*"recovery" + 0.164*"remain" + -0.138*"underlying" + 0.129*"oil" + '
#   '0.122*"medium" + -0.119*"credit"'),
#  (5,
#   '-0.193*"increase" + 0.175*"financial" + -0.154*"remains" + 0.141*"effect" + '
#   '0.138*"stability" + 0.134*"inflation" + -0.130*"liquidity" + 0.115*"policy" '
#   '+ -0.115*"pressure" + -0.114*"overall"'),
#  (6,
#   '0.331*"projection" + 0.235*"staff" + 0.171*"governing" + -0.165*"financial" '
#   '+ 0.150*"range" + 0.139*"macroeconomic" + -0.135*"reform" + 0.122*"upside" '
#   '+ 0.121*"measure" + -0.119*"demand"'),
#  (7,
#   '-0.233*"projection" + -0.224*"inflation" + 0.213*"medium" + '
#   '-0.203*"pressure" + -0.191*"recent" + 0.186*"credit" + 0.173*"remain" + '
#   '-0.154*"staff" + -0.137*"inflationary" + 0.135*"loan"'),
#  (8,
#   '0.360*"policy" + 0.221*"measure" + -0.219*"projection" + -0.149*"subdued" + '
#   '-0.130*"staff" + -0.122*"eurosystem" + -0.105*"expected" + 0.105*"purchase" '
#   '+ 0.103*"tension" + -0.099*"annual"'),
#  (9,
#   '-0.223*"financial" + -0.184*"market" + 0.148*"energy" + 0.143*"food" + '
#   '0.138*"may" + -0.116*"fiscal" + 0.112*"recent" + 0.107*"contribute" + '
#   '-0.107*"reform" + -0.106*"environment"'),
#  (10,
#   '-0.206*"ecb" + 0.198*"operation" + 0.163*"measure" + -0.160*"projection" + '
#   '0.136*"refinancing" + 0.128*"economy" + 0.127*"today" + 0.125*"credit" + '
#   '0.122*"month" + -0.120*"escb"'),
#  (11,
#   '-0.213*"level" + 0.174*"may" + -0.160*"interest" + 0.149*"market" + '
#   '-0.137*"january" + -0.136*"inflation" + -0.134*"activity" + '
#   '0.133*"financial" + 0.119*"also" + 0.118*"month"'),
#  (12,
#   '-0.213*"recent" + -0.191*"may" + 0.180*"moderate" + 0.162*"wage" + '
#   '-0.145*"activity" + -0.142*"policy" + 0.132*"fiscal" + -0.126*"market" + '
#   '-0.115*"data" + 0.112*"high"'),
#  (13,
#   '-0.251*"january" + -0.224*"december" + 0.146*"june" + 0.144*"july" + '
#   '-0.137*"recovery" + -0.134*"continued" + 0.129*"effect" + 0.129*"policy" + '
#   '-0.128*"interest" + 0.128*"second"'),
#  (14,
#   '-0.188*"quarter" + -0.170*"also" + 0.160*"inflation" + 0.140*"ecb" + '
#   '-0.137*"low" + 0.135*"country" + -0.134*"operation" + -0.124*"market" + '
#   '-0.123*"level" + 0.118*"mediumterm"'),
#  (15,
#   '0.192*"stability" + -0.160*"bank" + -0.145*"month" + -0.138*"inflation" + '
#   '-0.127*"key" + 0.123*"continue" + -0.115*"wage" + -0.107*"market" + '
#   '0.105*"financial" + 0.104*"quarter"'),
#  (16,
#   '-0.190*"increase" + -0.165*"oil" + 0.159*"continue" + 0.155*"condition" + '
#   '-0.152*"activity" + -0.151*"risk" + -0.144*"measure" + 0.140*"period" + '
#   '0.121*"market" + 0.120*"money"'),
#  (17,
#   '-0.258*"march" + 0.227*"september" + -0.202*"february" + 0.166*"august" + '
#   '0.162*"market" + 0.150*"july" + 0.139*"inflation" + -0.132*"economy" + '
#   '-0.119*"governing" + 0.118*"october"'),
#  (18,
#   '-0.148*"january" + 0.140*"risk" + -0.137*"staff" + -0.122*"remain" + '
#   '-0.121*"first" + 0.117*"today" + -0.114*"activity" + 0.114*"low" + '
#   '-0.112*"december" + 0.111*"operation"'),
#  (19,
#   '-0.236*"year" + -0.178*"activity" + -0.156*"bank" + -0.151*"recovery" + '
#   '0.143*"market" + 0.136*"stability" + -0.135*"also" + 0.128*"first" + '
#   '-0.116*"remains" + 0.112*"pillar"')]
# [(0,
#   '-0.246*"inflation" + -0.187*"risk" + -0.181*"policy" + -0.177*"governing" + '
#   '-0.176*"stability" + -0.166*"market" + -0.158*"term" + -0.157*"medium" + '
#   '-0.154*"annual" + -0.139*"remain"'),
#  (1,
#   '0.335*"governing" + -0.218*"inflation" + 0.202*"ecb" + -0.164*"loan" + '
#   '0.158*"stability" + 0.153*"first" + 0.148*"interest" + 0.138*"central" + '
#   '0.134*"today" + -0.133*"remain"'),
#  (2,
#   '-0.285*"stability" + -0.254*"risk" + 0.238*"policy" + 0.205*"governing" + '
#   '-0.192*"strong" + -0.182*"upside" + 0.153*"loan" + 0.145*"measure" + '
#   '0.124*"recovery" + -0.122*"oil"'),
#  (3,
#   '-0.245*"policy" + -0.196*"oil" + 0.173*"financial" + 0.168*"pressure" + '
#   '0.163*"governing" + -0.149*"projection" + 0.148*"remain" + 0.145*"medium" + '
#   '-0.140*"reform" + -0.128*"quarter"'),
#  (4,
#   '-0.346*"market" + -0.282*"financial" + -0.246*"risk" + 0.202*"term" + '
#   '0.177*"recovery" + 0.164*"remain" + -0.138*"underlying" + 0.129*"oil" + '
#   '0.122*"medium" + -0.119*"credit"'),
#  (5,
#   '-0.193*"increase" + 0.175*"financial" + -0.154*"remains" + 0.141*"effect" + '
#   '0.138*"stability" + 0.134*"inflation" + -0.130*"liquidity" + 0.115*"policy" '
#   '+ -0.115*"pressure" + -0.114*"overall"'),
#  (6,
#   '-0.331*"projection" + -0.235*"staff" + -0.171*"governing" + '
#   '0.165*"financial" + -0.150*"range" + -0.139*"macroeconomic" + '
#   '0.135*"reform" + -0.122*"upside" + -0.121*"measure" + 0.119*"demand"'),
#  (7,
#   '-0.233*"projection" + -0.224*"inflation" + 0.213*"medium" + '
#   '-0.203*"pressure" + -0.190*"recent" + 0.186*"credit" + 0.173*"remain" + '
#   '-0.154*"staff" + -0.137*"inflationary" + 0.135*"loan"'),
#  (8,
#   '0.360*"policy" + 0.221*"measure" + -0.219*"projection" + -0.149*"subdued" + '
#   '-0.130*"staff" + -0.122*"eurosystem" + -0.105*"expected" + 0.105*"purchase" '
#   '+ 0.103*"tension" + -0.099*"annual"'),
#  (9,
#   '0.223*"financial" + 0.184*"market" + -0.148*"energy" + -0.143*"food" + '
#   '-0.138*"may" + 0.116*"fiscal" + -0.112*"recent" + -0.107*"contribute" + '
#   '0.107*"reform" + 0.106*"environment"'),
#  (10,
#   '0.206*"ecb" + -0.198*"operation" + -0.163*"measure" + 0.160*"projection" + '
#   '-0.136*"refinancing" + -0.128*"economy" + -0.127*"today" + -0.125*"credit" '
#   '+ -0.122*"month" + 0.120*"escb"'),
#  (11,
#   '-0.213*"level" + 0.174*"may" + -0.160*"interest" + 0.149*"market" + '
#   '-0.137*"january" + -0.136*"inflation" + -0.134*"activity" + '
#   '0.133*"financial" + 0.119*"also" + 0.118*"month"'),
#  (12,
#   '-0.213*"recent" + -0.191*"may" + 0.179*"moderate" + 0.163*"wage" + '
#   '-0.145*"activity" + -0.142*"policy" + 0.133*"fiscal" + -0.126*"market" + '
#   '-0.115*"data" + 0.113*"high"'),
#  (13,
#   '-0.251*"january" + -0.224*"december" + 0.146*"june" + 0.144*"july" + '
#   '-0.137*"recovery" + -0.134*"continued" + 0.129*"effect" + 0.129*"policy" + '
#   '0.128*"second" + -0.128*"interest"'),
#  (14,
#   '-0.188*"quarter" + -0.170*"also" + 0.160*"inflation" + 0.140*"ecb" + '
#   '-0.137*"low" + 0.135*"country" + -0.135*"operation" + -0.125*"market" + '
#   '-0.123*"level" + 0.118*"mediumterm"'),
#  (15,
#   '-0.192*"stability" + 0.159*"bank" + 0.146*"month" + 0.138*"inflation" + '
#   '0.126*"key" + -0.123*"continue" + 0.115*"wage" + 0.107*"market" + '
#   '-0.105*"financial" + -0.104*"quarter"'),
#  (16,
#   '-0.190*"increase" + -0.165*"oil" + 0.159*"continue" + 0.156*"condition" + '
#   '-0.152*"activity" + -0.151*"risk" + -0.144*"measure" + 0.140*"period" + '
#   '0.121*"money" + 0.121*"market"'),
#  (17,
#   '0.258*"march" + -0.227*"september" + 0.202*"february" + -0.166*"august" + '
#   '-0.162*"market" + -0.150*"july" + -0.139*"inflation" + 0.132*"economy" + '
#   '0.119*"governing" + -0.118*"october"'),
#  (18,
#   '-0.148*"january" + 0.140*"risk" + -0.137*"staff" + -0.122*"remain" + '
#   '-0.121*"first" + 0.117*"today" + -0.114*"activity" + 0.114*"low" + '
#   '-0.111*"december" + 0.110*"operation"'),
#  (19,
#   '0.235*"year" + 0.177*"activity" + 0.157*"bank" + 0.151*"recovery" + '
#   '-0.143*"market" + -0.136*"stability" + 0.135*"also" + -0.128*"first" + '
#   '0.115*"remains" + -0.112*"pillar"'),
#  (20,
#   '-0.192*"domestic" + 0.179*"january" + -0.170*"bank" + -0.145*"country" + '
#   '-0.138*"eurosystem" + -0.131*"european" + 0.130*"outlook" + '
#   '0.120*"strategy" + 0.117*"interest" + -0.114*"may"'),
#  (21,
#   '-0.212*"governing" + 0.185*"term" + 0.149*"medium" + 0.148*"june" + '
#   '-0.143*"expected" + 0.131*"market" + -0.127*"ongoing" + 0.124*"april" + '
#   '-0.124*"december" + -0.121*"november"'),
#  (22,
#   '-0.196*"policy" + -0.178*"activity" + -0.169*"operation" + -0.146*"medium" '
#   '+ -0.130*"october" + 0.129*"high" + 0.114*"june" + -0.112*"refinancing" + '
#   '0.108*"ahead" + 0.108*"remained"'),
#  (23,
#   '-0.171*"economy" + 0.151*"particular" + 0.143*"money" + 0.142*"year" + '
#   '0.141*"oil" + 0.131*"support" + 0.128*"recent" + -0.128*"march" + '
#   '0.128*"demand" + -0.116*"real"'),
#  (24,
#   '0.250*"oil" + 0.196*"also" + -0.183*"country" + 0.183*"term" + '
#   '0.128*"economy" + 0.122*"medium" + -0.113*"year" + -0.111*"become" + '
#   '-0.109*"fiscal" + -0.104*"reform"'),
#  (25,
#   '0.167*"also" + -0.137*"year" + -0.120*"overall" + 0.116*"current" + '
#   '0.114*"underlying" + 0.111*"september" + -0.109*"impact" + 0.107*"regard" + '
#   '0.107*"previous" + -0.105*"moderate"'),
#  (26,
#   '-0.169*"banknote" + 0.133*"trend" + 0.133*"decision" + -0.128*"level" + '
#   '-0.127*"national" + 0.127*"reference" + 0.125*"value" + -0.112*"important" '
#   '+ 0.111*"quarter" + -0.105*"exchange"'),
#  (27,
#   '-0.168*"ecb" + -0.155*"activity" + 0.151*"governing" + -0.121*"key" + '
#   '-0.116*"may" + -0.115*"first" + 0.113*"structural" + 0.107*"inflation" + '
#   '0.100*"positive" + 0.100*"previous"'),
#  (28,
#   '-0.172*"quarter" + -0.150*"december" + 0.125*"stability" + 0.122*"recovery" '
#   '+ 0.122*"oil" + -0.117*"real" + 0.114*"increase" + 0.107*"financial" + '
#   '-0.107*"lower" + -0.103*"new"'),
#  (29,
#   '0.188*"increase" + 0.167*"country" + -0.141*"first" + -0.133*"available" + '
#   '-0.132*"year" + -0.125*"risk" + 0.117*"current" + -0.110*"information" + '
#   '-0.108*"june" + 0.105*"structural"'),
#  (30,
#   '0.153*"increase" + -0.148*"remain" + 0.145*"stability" + -0.142*"first" + '
#   '-0.136*"recent" + 0.130*"information" + -0.125*"strong" + -0.123*"also" + '
#   '0.117*"projection" + 0.116*"recovery"'),
#  (31,
#   '0.298*"also" + -0.178*"quarter" + -0.145*"oil" + -0.113*"continued" + '
#   '-0.111*"demand" + -0.109*"domestic" + -0.104*"gdp" + -0.102*"policy" + '
#   '-0.101*"wage" + 0.097*"potential"'),
#  (32,
#   '0.231*"first" + -0.211*"remain" + -0.199*"recent" + -0.199*"year" + '
#   '0.158*"continue" + -0.132*"data" + 0.128*"pressure" + -0.119*"particularly" '
#   '+ 0.113*"strong" + 0.112*"quarter"'),
#  (33,
#   '0.185*"fiscal" + 0.139*"economy" + -0.133*"inflation" + -0.131*"year" + '
#   '-0.127*"decision" + 0.116*"july" + -0.109*"april" + 0.107*"macroeconomic" + '
#   '0.106*"need" + -0.104*"programme"'),
#  (34,
#   '0.223*"inflation" + -0.189*"particular" + 0.143*"remains" + '
#   '-0.127*"pressure" + 0.116*"quarter" + -0.110*"policy" + -0.106*"remained" + '
#   '-0.101*"new" + 0.099*"recovery" + 0.097*"operation"'),
#  (35,
#   '0.206*"year" + 0.177*"continued" + -0.145*"august" + -0.140*"data" + '
#   '-0.132*"country" + -0.128*"outlook" + 0.123*"november" + 0.109*"therefore" '
#   '+ 0.102*"take" + -0.098*"operation"'),
#  (36,
#   '0.178*"would" + 0.164*"level" + 0.140*"time" + -0.130*"expansion" + '
#   '0.119*"october" + -0.117*"year" + 0.105*"may" + -0.105*"financial" + '
#   '-0.104*"ecb" + -0.103*"main"'),
#  (37,
#   '0.163*"continued" + -0.158*"oil" + -0.154*"february" + 0.141*"recent" + '
#   '0.127*"remain" + 0.117*"expected" + 0.116*"month" + 0.110*"november" + '
#   '-0.109*"expectation" + 0.103*"june"'),
#  (38,
#   '0.171*"country" + 0.160*"also" + 0.157*"level" + 0.148*"market" + '
#   '0.129*"recent" + -0.114*"june" + -0.109*"banknote" + 0.101*"time" + '
#   '-0.100*"fiscal" + -0.095*"production"'),
#  (39,
#   '0.165*"current" + -0.155*"also" + -0.142*"country" + 0.138*"level" + '
#   '-0.134*"line" + -0.131*"july" + 0.128*"value" + -0.123*"policy" + '
#   '0.110*"reference" + 0.104*"effect"'),
#  (40,
#   '0.171*"increase" + 0.161*"recent" + 0.146*"january" + 0.136*"assessment" + '
#   '-0.132*"demand" + -0.118*"account" + -0.115*"quarter" + 0.113*"support" + '
#   '0.110*"ahead" + 0.106*"period"'),
#  (41,
#   '0.200*"continue" + 0.171*"quarter" + -0.155*"inflation" + 0.133*"current" + '
#   '0.133*"available" + 0.133*"decline" + 0.128*"expected" + -0.116*"outlook" + '
#   '0.115*"sector" + 0.114*"impact"'),
#  (42,
#   '-0.164*"support" + 0.143*"line" + 0.128*"shortterm" + -0.128*"expected" + '
#   '0.128*"outlook" + 0.126*"particularly" + 0.116*"oil" + -0.110*"gradual" + '
#   '-0.108*"point" + -0.107*"activity"'),
#  (43,
#   '-0.181*"governing" + -0.160*"overall" + -0.160*"quarter" + 0.155*"month" + '
#   '0.153*"interest" + 0.148*"march" + -0.144*"factor" + 0.130*"time" + '
#   '0.129*"continued" + -0.128*"level"'),
#  (44,
#   '0.150*"high" + 0.117*"term" + 0.116*"ecb" + 0.112*"december" + '
#   '0.110*"consolidation" + -0.107*"low" + 0.104*"moderate" + -0.104*"higher" + '
#   '-0.103*"interest" + -0.103*"well"'),
#  (45,
#   '0.157*"time" + 0.147*"country" + 0.143*"overall" + -0.130*"month" + '
#   '0.122*"mainly" + -0.117*"october" + 0.117*"oil" + -0.108*"support" + '
#   '0.106*"market" + 0.104*"could"'),
#  (46,
#   '0.155*"overall" + 0.154*"remain" + -0.154*"outlook" + -0.139*"european" + '
#   '-0.121*"july" + 0.120*"high" + -0.119*"remains" + 0.111*"public" + '
#   '-0.109*"would" + 0.108*"view"'),
#  (47,
#   '-0.159*"would" + 0.126*"labour" + -0.120*"time" + 0.112*"governing" + '
#   '-0.110*"liquidity" + -0.109*"early" + -0.100*"february" + '
#   '-0.100*"available" + 0.098*"stability" + 0.096*"line"'),
#  (48,
#   '0.172*"continued" + -0.169*"remains" + 0.123*"also" + 0.118*"impact" + '
#   '0.111*"lower" + -0.105*"projection" + -0.104*"april" + -0.103*"quarter" + '
#   '0.101*"range" + -0.095*"liquidity"'),
#  (49,
#   '-0.159*"available" + 0.118*"condition" + 0.115*"reform" + 0.113*"impact" + '
#   '0.111*"expected" + -0.109*"pressure" + 0.108*"risk" + -0.106*"expansion" + '
#   '-0.103*"purchase" + -0.100*"outlook"')]
# [(0,
#   '-0.246*"inflation" + -0.187*"risk" + -0.181*"policy" + -0.177*"governing" + '
#   '-0.176*"stability" + -0.166*"market" + -0.158*"term" + -0.157*"medium" + '
#   '-0.154*"annual" + -0.139*"remain"'),
#  (1,
#   '0.335*"governing" + -0.218*"inflation" + 0.202*"ecb" + -0.164*"loan" + '
#   '0.158*"stability" + 0.153*"first" + 0.148*"interest" + 0.138*"central" + '
#   '0.134*"today" + -0.133*"remain"'),
#  (2,
#   '-0.285*"stability" + -0.254*"risk" + 0.238*"policy" + 0.205*"governing" + '
#   '-0.192*"strong" + -0.182*"upside" + 0.153*"loan" + 0.145*"measure" + '
#   '0.124*"recovery" + -0.122*"oil"'),
#  (3,
#   '0.245*"policy" + 0.196*"oil" + -0.173*"financial" + -0.168*"pressure" + '
#   '-0.163*"governing" + 0.149*"projection" + -0.148*"remain" + -0.145*"medium" '
#   '+ 0.140*"reform" + 0.128*"quarter"'),
#  (4,
#   '-0.346*"market" + -0.282*"financial" + -0.246*"risk" + 0.202*"term" + '
#   '0.177*"recovery" + 0.164*"remain" + -0.138*"underlying" + 0.129*"oil" + '
#   '0.122*"medium" + -0.119*"credit"'),
#  (5,
#   '-0.193*"increase" + 0.175*"financial" + -0.154*"remains" + 0.141*"effect" + '
#   '0.138*"stability" + 0.134*"inflation" + -0.130*"liquidity" + 0.115*"policy" '
#   '+ -0.115*"pressure" + -0.114*"overall"'),
#  (6,
#   '-0.331*"projection" + -0.235*"staff" + -0.171*"governing" + '
#   '0.165*"financial" + -0.150*"range" + -0.139*"macroeconomic" + '
#   '0.135*"reform" + -0.122*"upside" + -0.121*"measure" + 0.119*"demand"'),
#  (7,
#   '-0.233*"projection" + -0.224*"inflation" + 0.213*"medium" + '
#   '-0.203*"pressure" + -0.191*"recent" + 0.186*"credit" + 0.173*"remain" + '
#   '-0.154*"staff" + -0.137*"inflationary" + 0.135*"loan"'),
#  (8,
#   '0.360*"policy" + 0.221*"measure" + -0.219*"projection" + -0.149*"subdued" + '
#   '-0.130*"staff" + -0.122*"eurosystem" + -0.105*"expected" + 0.105*"purchase" '
#   '+ 0.103*"tension" + -0.099*"annual"'),
#  (9,
#   '-0.223*"financial" + -0.184*"market" + 0.148*"energy" + 0.143*"food" + '
#   '0.138*"may" + -0.116*"fiscal" + 0.112*"recent" + -0.107*"reform" + '
#   '0.107*"contribute" + -0.106*"environment"'),
#  (10,
#   '0.206*"ecb" + -0.198*"operation" + -0.163*"measure" + 0.160*"projection" + '
#   '-0.136*"refinancing" + -0.128*"economy" + -0.127*"today" + -0.125*"credit" '
#   '+ -0.122*"month" + 0.120*"escb"'),
#  (11,
#   '-0.213*"level" + 0.174*"may" + -0.160*"interest" + 0.149*"market" + '
#   '-0.137*"january" + -0.136*"inflation" + -0.134*"activity" + '
#   '0.133*"financial" + 0.119*"also" + 0.118*"month"'),
#  (12,
#   '-0.213*"recent" + -0.191*"may" + 0.179*"moderate" + 0.163*"wage" + '
#   '-0.145*"activity" + -0.142*"policy" + 0.133*"fiscal" + -0.126*"market" + '
#   '-0.115*"data" + 0.113*"high"'),
#  (13,
#   '0.251*"january" + 0.224*"december" + -0.146*"june" + -0.144*"july" + '
#   '0.137*"recovery" + 0.134*"continued" + -0.129*"effect" + -0.129*"policy" + '
#   '-0.128*"second" + 0.128*"interest"'),
#  (14,
#   '0.188*"quarter" + 0.170*"also" + -0.160*"inflation" + -0.140*"ecb" + '
#   '0.137*"low" + -0.135*"country" + 0.135*"operation" + 0.125*"market" + '
#   '0.123*"level" + -0.118*"mediumterm"'),
#  (15,
#   '0.192*"stability" + -0.159*"bank" + -0.146*"month" + -0.139*"inflation" + '
#   '-0.126*"key" + 0.123*"continue" + -0.115*"wage" + -0.107*"market" + '
#   '0.105*"financial" + 0.105*"quarter"'),
#  (16,
#   '-0.190*"increase" + -0.165*"oil" + 0.159*"continue" + 0.156*"condition" + '
#   '-0.152*"activity" + -0.151*"risk" + -0.144*"measure" + 0.140*"period" + '
#   '0.121*"money" + 0.121*"market"'),
#  (17,
#   '-0.258*"march" + 0.227*"september" + -0.202*"february" + 0.166*"august" + '
#   '0.162*"market" + 0.150*"july" + 0.139*"inflation" + -0.132*"economy" + '
#   '-0.119*"governing" + 0.118*"october"'),
#  (18,
#   '-0.148*"january" + 0.141*"risk" + -0.137*"staff" + -0.122*"remain" + '
#   '-0.121*"first" + 0.117*"today" + -0.114*"activity" + 0.114*"low" + '
#   '-0.111*"december" + 0.110*"operation"'),
#  (19,
#   '-0.236*"year" + -0.177*"activity" + -0.156*"bank" + -0.151*"recovery" + '
#   '0.143*"market" + 0.136*"stability" + -0.135*"also" + 0.128*"first" + '
#   '-0.116*"remains" + 0.112*"pillar"'),
#  (20,
#   '-0.192*"domestic" + 0.178*"january" + -0.170*"bank" + -0.145*"country" + '
#   '-0.138*"eurosystem" + -0.130*"european" + 0.130*"outlook" + '
#   '0.120*"strategy" + 0.117*"interest" + -0.114*"may"'),
#  (21,
#   '-0.212*"governing" + 0.185*"term" + 0.149*"medium" + 0.148*"june" + '
#   '-0.143*"expected" + 0.131*"market" + -0.127*"ongoing" + 0.124*"april" + '
#   '-0.124*"december" + -0.122*"november"'),
#  (22,
#   '-0.196*"policy" + -0.178*"activity" + -0.169*"operation" + -0.147*"medium" '
#   '+ -0.131*"october" + 0.129*"high" + 0.114*"june" + -0.112*"refinancing" + '
#   '0.108*"ahead" + 0.108*"remained"'),
#  (23,
#   '0.171*"economy" + -0.151*"particular" + -0.143*"money" + -0.142*"year" + '
#   '-0.141*"oil" + -0.131*"support" + -0.128*"recent" + -0.128*"demand" + '
#   '0.128*"march" + 0.116*"real"'),
#  (24,
#   '-0.251*"oil" + -0.196*"also" + 0.183*"country" + -0.183*"term" + '
#   '-0.128*"economy" + -0.122*"medium" + 0.113*"year" + 0.111*"become" + '
#   '0.109*"fiscal" + 0.104*"reform"'),
#  (25,
#   '0.167*"also" + -0.137*"year" + -0.120*"overall" + 0.116*"current" + '
#   '0.114*"underlying" + 0.111*"september" + -0.109*"impact" + 0.107*"previous" '
#   '+ 0.106*"regard" + -0.105*"moderate"'),
#  (26,
#   '-0.169*"banknote" + 0.134*"trend" + 0.132*"decision" + -0.128*"level" + '
#   '-0.127*"national" + 0.127*"reference" + 0.125*"value" + -0.111*"important" '
#   '+ 0.111*"quarter" + 0.105*"also"'),
#  (27,
#   '-0.168*"ecb" + -0.155*"activity" + 0.151*"governing" + -0.121*"key" + '
#   '-0.116*"may" + -0.114*"first" + 0.113*"structural" + 0.107*"inflation" + '
#   '0.100*"positive" + 0.099*"previous"'),
#  (28,
#   '-0.172*"quarter" + -0.150*"december" + 0.124*"stability" + 0.123*"recovery" '
#   '+ 0.122*"oil" + -0.118*"real" + 0.114*"increase" + 0.107*"financial" + '
#   '-0.107*"lower" + -0.104*"new"'),
#  (29,
#   '-0.188*"increase" + -0.167*"country" + 0.141*"first" + 0.133*"available" + '
#   '0.132*"year" + 0.125*"risk" + -0.117*"current" + 0.110*"information" + '
#   '0.108*"june" + -0.105*"structural"'),
#  (30,
#   '-0.153*"increase" + 0.148*"remain" + -0.146*"stability" + 0.142*"first" + '
#   '0.137*"recent" + -0.129*"information" + 0.126*"strong" + 0.124*"also" + '
#   '-0.117*"projection" + -0.116*"recovery"'),
#  (31,
#   '0.298*"also" + -0.178*"quarter" + -0.145*"oil" + -0.112*"continued" + '
#   '-0.110*"demand" + -0.110*"domestic" + -0.104*"gdp" + -0.102*"policy" + '
#   '-0.101*"wage" + 0.098*"potential"'),
#  (32,
#   '0.231*"first" + -0.211*"remain" + -0.199*"recent" + -0.199*"year" + '
#   '0.157*"continue" + -0.132*"data" + 0.129*"pressure" + -0.119*"particularly" '
#   '+ 0.113*"strong" + 0.112*"quarter"'),
#  (33,
#   '-0.186*"fiscal" + -0.139*"economy" + 0.133*"inflation" + 0.131*"year" + '
#   '0.127*"decision" + -0.115*"july" + 0.108*"april" + -0.107*"macroeconomic" + '
#   '-0.106*"need" + 0.104*"programme"'),
#  (34,
#   '0.222*"inflation" + -0.189*"particular" + 0.143*"remains" + '
#   '-0.127*"pressure" + 0.117*"quarter" + -0.111*"policy" + -0.106*"remained" + '
#   '-0.100*"new" + 0.098*"recovery" + 0.098*"operation"'),
#  (35,
#   '0.207*"year" + 0.177*"continued" + -0.146*"august" + -0.139*"data" + '
#   '-0.132*"country" + -0.129*"outlook" + 0.123*"november" + 0.108*"therefore" '
#   '+ 0.101*"take" + -0.097*"operation"'),
#  (36,
#   '0.177*"would" + 0.163*"level" + 0.139*"time" + -0.130*"expansion" + '
#   '0.119*"october" + -0.117*"year" + 0.105*"may" + -0.105*"financial" + '
#   '-0.104*"ecb" + -0.103*"main"'),
#  (37,
#   '0.164*"continued" + -0.159*"oil" + -0.154*"february" + 0.143*"recent" + '
#   '0.127*"remain" + 0.118*"expected" + 0.117*"month" + 0.110*"november" + '
#   '-0.110*"expectation" + 0.103*"june"'),
#  (38,
#   '0.171*"country" + 0.160*"also" + 0.156*"level" + 0.147*"market" + '
#   '0.129*"recent" + -0.114*"june" + -0.110*"banknote" + 0.102*"time" + '
#   '-0.101*"fiscal" + -0.095*"production"'),
#  (39,
#   '0.165*"current" + -0.155*"also" + -0.142*"country" + 0.138*"level" + '
#   '-0.135*"line" + -0.131*"july" + 0.129*"value" + -0.122*"policy" + '
#   '0.110*"reference" + 0.104*"effect"'),
#  (40,
#   '0.169*"increase" + 0.160*"recent" + 0.145*"january" + 0.134*"assessment" + '
#   '-0.133*"demand" + -0.118*"account" + -0.116*"quarter" + 0.114*"support" + '
#   '0.110*"ahead" + 0.106*"period"'),
#  (41,
#   '0.200*"continue" + 0.171*"quarter" + -0.155*"inflation" + 0.133*"available" '
#   '+ 0.133*"current" + 0.132*"decline" + 0.128*"expected" + -0.116*"outlook" + '
#   '0.115*"sector" + 0.114*"impact"'),
#  (42,
#   '0.163*"support" + -0.142*"line" + 0.128*"expected" + -0.128*"shortterm" + '
#   '-0.127*"outlook" + -0.127*"particularly" + -0.116*"oil" + 0.108*"gradual" + '
#   '0.108*"point" + 0.107*"activity"'),
#  (43,
#   '0.181*"governing" + 0.160*"quarter" + 0.158*"overall" + -0.155*"month" + '
#   '-0.153*"interest" + -0.149*"march" + 0.145*"factor" + -0.130*"continued" + '
#   '-0.129*"time" + -0.129*"april"'),
#  (44,
#   '-0.151*"high" + -0.118*"ecb" + -0.115*"term" + -0.109*"december" + '
#   '0.107*"low" + -0.106*"consolidation" + -0.105*"moderate" + 0.104*"higher" + '
#   '0.104*"eurosystem" + 0.103*"well"'),
#  (45,
#   '-0.154*"time" + -0.146*"country" + -0.140*"overall" + 0.130*"month" + '
#   '-0.120*"mainly" + 0.118*"october" + -0.117*"oil" + 0.108*"support" + '
#   '-0.107*"market" + -0.104*"could"'),
#  (46,
#   '-0.155*"overall" + 0.155*"outlook" + -0.153*"remain" + 0.140*"european" + '
#   '0.120*"july" + 0.119*"remains" + -0.119*"high" + -0.112*"public" + '
#   '-0.110*"view" + 0.109*"would"'),
#  (47,
#   '-0.160*"would" + 0.125*"labour" + -0.123*"time" + 0.112*"governing" + '
#   '-0.108*"liquidity" + -0.108*"early" + -0.101*"february" + '
#   '-0.099*"available" + 0.098*"stability" + 0.096*"december"'),
#  (48,
#   '-0.173*"continued" + 0.168*"remains" + -0.122*"also" + -0.118*"impact" + '
#   '-0.112*"lower" + 0.106*"projection" + 0.105*"april" + 0.103*"quarter" + '
#   '-0.102*"range" + 0.095*"term"'),
#  (49,
#   '0.156*"available" + -0.118*"condition" + -0.116*"reform" + -0.113*"impact" '
#   '+ -0.111*"expected" + -0.109*"risk" + 0.109*"pressure" + 0.106*"expansion" '
#   '+ 0.103*"purchase" + 0.099*"outlook"'),
#  (50,
#   '-0.163*"continue" + -0.141*"economy" + 0.137*"risk" + 0.127*"term" + '
#   '-0.127*"effect" + 0.123*"reform" + -0.114*"low" + -0.113*"deficit" + '
#   '0.112*"basis" + -0.107*"factor"'),
#  (51,
#   '-0.158*"also" + -0.134*"support" + -0.133*"time" + 0.125*"first" + '
#   '-0.119*"april" + 0.113*"however" + 0.112*"rise" + 0.110*"well" + '
#   '-0.104*"data" + 0.103*"january"'),
#  (52,
#   '-0.168*"purchase" + -0.138*"also" + 0.133*"cost" + -0.131*"particular" + '
#   '0.131*"implementation" + 0.129*"would" + 0.125*"assessment" + '
#   '-0.121*"outlook" + -0.115*"global" + -0.111*"still"'),
#  (53,
#   '-0.134*"since" + 0.130*"expected" + -0.123*"employment" + -0.122*"energy" + '
#   '-0.113*"remains" + -0.107*"overall" + -0.099*"year" + 0.098*"expectation" + '
#   '0.096*"december" + 0.095*"risk"'),
#  (54,
#   '-0.167*"level" + -0.148*"particular" + 0.145*"past" + -0.144*"country" + '
#   '0.121*"annual" + -0.120*"medium" + -0.116*"therefore" + -0.113*"strong" + '
#   '0.110*"impact" + -0.105*"tension"'),
#  (55,
#   '-0.158*"continue" + 0.133*"country" + -0.121*"time" + -0.116*"real" + '
#   '0.112*"broadly" + 0.110*"environment" + 0.105*"remained" + -0.102*"policy" '
#   '+ -0.096*"loan" + 0.093*"structural"'),
#  (56,
#   '0.149*"purchase" + 0.141*"activity" + -0.140*"regard" + 0.129*"governing" + '
#   '0.129*"decline" + 0.121*"need" + -0.116*"impact" + 0.116*"average" + '
#   '-0.114*"macroeconomic" + 0.110*"remains"'),
#  (57,
#   '-0.166*"strong" + 0.147*"expected" + 0.119*"uncertainty" + 0.114*"annual" + '
#   '-0.106*"december" + -0.106*"may" + 0.097*"previous" + 0.096*"march" + '
#   '-0.095*"account" + -0.094*"employment"'),
#  (58,
#   '-0.147*"information" + 0.138*"expected" + 0.130*"factor" + 0.127*"line" + '
#   '-0.119*"first" + -0.119*"available" + -0.114*"increase" + -0.109*"market" + '
#   '0.109*"particular" + -0.104*"data"'),
#  (59,
#   '0.200*"would" + 0.139*"recent" + -0.122*"assessment" + 0.120*"quarter" + '
#   '0.115*"commodity" + 0.111*"line" + 0.106*"december" + -0.104*"latest" + '
#   '-0.098*"month" + -0.098*"increase"'),
#  (60,
#   '0.138*"therefore" + -0.121*"country" + 0.108*"continue" + 0.107*"earlier" + '
#   '0.105*"loan" + -0.103*"would" + -0.102*"longterm" + 0.098*"data" + '
#   '-0.097*"inflation" + 0.097*"september"'),
#  (61,
#   '-0.132*"assessment" + 0.126*"wage" + -0.121*"march" + -0.119*"government" + '
#   '-0.118*"data" + 0.117*"trend" + -0.116*"april" + -0.113*"thereby" + '
#   '0.108*"february" + 0.106*"recovery"'),
#  (62,
#   '-0.141*"decline" + 0.140*"assessment" + -0.135*"however" + -0.121*"quarter" '
#   '+ 0.116*"broadly" + -0.109*"expected" + -0.101*"need" + -0.098*"challenge" '
#   '+ 0.098*"oil" + 0.097*"environment"'),
#  (63,
#   '0.183*"risk" + 0.150*"may" + 0.135*"policy" + -0.133*"outlook" + '
#   '-0.124*"regard" + -0.104*"second" + -0.102*"underlying" + 0.101*"fiscal" + '
#   '-0.098*"bank" + 0.098*"high"'),
#  (64,
#   '0.204*"effect" + 0.168*"remain" + -0.125*"term" + -0.116*"line" + '
#   '-0.116*"interest" + -0.113*"treaty" + 0.113*"consumer" + 0.110*"upward" + '
#   '-0.110*"stability" + -0.101*"thereby"'),
#  (65,
#   '0.148*"still" + 0.112*"somewhat" + -0.103*"also" + 0.101*"hicp" + '
#   '0.100*"needed" + -0.094*"future" + 0.093*"financial" + -0.093*"commodity" + '
#   '-0.091*"governing" + -0.090*"credit"'),
#  (66,
#   '0.148*"contribute" + 0.144*"risk" + -0.128*"ongoing" + -0.123*"regard" + '
#   '0.105*"recovery" + -0.099*"improvement" + 0.098*"broadly" + 0.098*"hand" + '
#   '-0.095*"new" + -0.092*"financial"'),
#  (67,
#   '-0.165*"reform" + 0.123*"march" + 0.112*"year" + -0.108*"necessary" + '
#   '0.107*"fiscal" + -0.106*"today" + 0.103*"first" + -0.103*"annual" + '
#   '0.101*"deficit" + 0.100*"stance"'),
#  (68,
#   '-0.130*"banknote" + -0.120*"quarter" + -0.108*"data" + -0.107*"factor" + '
#   '0.107*"credit" + -0.104*"july" + 0.104*"confidence" + -0.099*"loan" + '
#   '-0.097*"hicp" + -0.096*"slightly"'),
#  (69,
#   '0.122*"december" + 0.117*"adjustment" + 0.115*"low" + -0.109*"today" + '
#   '-0.107*"continue" + -0.106*"overall" + -0.103*"environment" + '
#   '-0.099*"remain" + -0.094*"purchase" + -0.094*"strong"'),
#  (70,
#   '0.148*"level" + -0.128*"outlook" + 0.127*"improvement" + 0.126*"november" + '
#   '-0.114*"high" + 0.109*"demand" + -0.106*"last" + 0.102*"ongoing" + '
#   '-0.102*"private" + -0.097*"higher"'),
#  (71,
#   '0.135*"decline" + -0.127*"hicp" + -0.121*"quarter" + -0.117*"well" + '
#   '-0.107*"may" + 0.098*"past" + 0.097*"april" + -0.096*"two" + -0.092*"asset" '
#   '+ 0.089*"taken"'),
#  (72,
#   '-0.189*"still" + 0.156*"country" + 0.110*"need" + -0.108*"uncertainty" + '
#   '0.103*"october" + 0.102*"latest" + 0.100*"inflation" + 0.100*"effect" + '
#   '0.099*"adjustment" + -0.099*"reform"'),
#  (73,
#   '0.160*"continue" + 0.124*"confidence" + 0.122*"reflecting" + '
#   '0.109*"expected" + -0.109*"balance" + 0.106*"economy" + 0.105*"uncertainty" '
#   '+ 0.105*"factor" + 0.101*"global" + -0.099*"ongoing"'),
#  (74,
#   '0.141*"may" + -0.139*"range" + 0.129*"treaty" + 0.127*"sector" + '
#   '-0.111*"regard" + 0.107*"average" + -0.106*"month" + -0.104*"recent" + '
#   '0.096*"organisation" + 0.096*"consumer"'),
#  (75,
#   '0.124*"september" + 0.120*"adjustment" + -0.116*"moderate" + '
#   '0.114*"remained" + -0.101*"financing" + 0.100*"still" + -0.098*"past" + '
#   '0.095*"confidence" + 0.092*"continued" + 0.089*"positive"'),
#  (76,
#   '0.152*"ensure" + 0.138*"continued" + -0.124*"decline" + -0.111*"factor" + '
#   '0.110*"range" + -0.104*"outlook" + -0.103*"asset" + -0.102*"fiscal" + '
#   '-0.101*"early" + -0.089*"strong"'),
#  (77,
#   '0.143*"particular" + 0.123*"oil" + -0.111*"economy" + 0.103*"continue" + '
#   '-0.102*"thereby" + -0.101*"increased" + 0.099*"energy" + 0.098*"demand" + '
#   '0.097*"point" + -0.094*"interest"'),
#  (78,
#   '0.133*"unchanged" + 0.126*"fiscal" + -0.114*"well" + 0.112*"quarter" + '
#   '-0.108*"lower" + -0.106*"environment" + -0.104*"european" + 0.102*"high" + '
#   '0.097*"mediumterm" + -0.095*"domestic"'),
#  (79,
#   '0.139*"increase" + -0.116*"activity" + -0.115*"remained" + '
#   '0.113*"particular" + -0.112*"let" + 0.109*"demand" + -0.103*"state" + '
#   '-0.097*"reduce" + 0.096*"deficit" + 0.095*"credit"'),
#  (80,
#   '-0.126*"decline" + -0.122*"august" + 0.112*"uncertainty" + -0.109*"let" + '
#   '0.104*"could" + 0.098*"bank" + 0.097*"sector" + -0.097*"line" + '
#   '-0.089*"country" + 0.089*"month"'),
#  (81,
#   '-0.137*"high" + 0.126*"expected" + 0.122*"however" + -0.111*"country" + '
#   '-0.110*"appropriate" + -0.103*"and" + 0.098*"current" + '
#   '-0.098*"information" + -0.097*"expectation" + 0.092*"september"'),
#  (82,
#   '0.179*"however" + 0.153*"february" + -0.122*"sector" + -0.116*"expansion" + '
#   '-0.111*"recent" + -0.102*"remains" + 0.101*"progress" + -0.095*"structural" '
#   '+ -0.093*"support" + 0.092*"labour"'),
#  (83,
#   '-0.116*"country" + 0.108*"low" + -0.107*"ahead" + -0.101*"annual" + '
#   '0.101*"broadly" + -0.099*"current" + 0.095*"appropriate" + 0.094*"remains" '
#   '+ -0.094*"compared" + -0.093*"around"'),
#  (84,
#   '-0.115*"credit" + 0.110*"necessary" + -0.104*"essential" + -0.098*"bank" + '
#   '-0.093*"unchanged" + -0.093*"like" + -0.091*"part" + 0.090*"april" + '
#   '-0.088*"overall" + -0.088*"somewhat"'),
#  (85,
#   '-0.163*"employment" + 0.123*"particular" + -0.111*"unchanged" + '
#   '-0.101*"somewhat" + 0.100*"fiscal" + -0.096*"turning" + -0.095*"decision" + '
#   '0.093*"balance" + 0.091*"number" + -0.089*"continued"'),
#  (86,
#   '-0.121*"annual" + 0.110*"increased" + 0.108*"moreover" + 0.107*"ongoing" + '
#   '-0.101*"general" + 0.100*"would" + 0.096*"month" + 0.095*"remain" + '
#   '0.094*"perspective" + -0.091*"public"'),
#  (87,
#   '0.124*"may" + -0.117*"favourable" + -0.113*"broadly" + 0.110*"positive" + '
#   '0.106*"could" + 0.106*"year" + -0.103*"volatility" + -0.102*"measure" + '
#   '0.102*"hicp" + -0.099*"confirm"'),
#  (88,
#   '0.149*"available" + -0.144*"continued" + -0.139*"basis" + -0.109*"sector" + '
#   '-0.108*"situation" + -0.106*"improvement" + 0.100*"energy" + 0.100*"fully" '
#   '+ -0.098*"moreover" + 0.098*"course"'),
#  (89,
#   '0.130*"stability" + -0.106*"energy" + 0.106*"economy" + -0.102*"range" + '
#   '-0.100*"condition" + -0.097*"negative" + -0.093*"treaty" + 0.093*"activity" '
#   '+ -0.091*"measure" + -0.089*"longterm"'),
#  (90,
#   '0.137*"current" + 0.107*"energy" + 0.103*"thus" + -0.103*"recent" + '
#   '-0.102*"following" + 0.101*"april" + -0.101*"continue" + 0.098*"assessment" '
#   '+ 0.093*"latest" + -0.091*"upward"'),
#  (91,
#   '-0.114*"therefore" + -0.103*"labour" + 0.102*"upside" + '
#   '-0.091*"expectation" + -0.090*"base" + 0.089*"addition" + -0.085*"ecb" + '
#   '0.085*"policy" + -0.083*"still" + -0.080*"measure"'),
#  (92,
#   '-0.143*"october" + -0.127*"unchanged" + 0.106*"slightly" + 0.104*"global" + '
#   '0.100*"economy" + 0.095*"indicates" + 0.093*"view" + 0.091*"current" + '
#   '0.091*"ecbs" + -0.091*"tender"'),
#  (93,
#   '-0.156*"confirmed" + -0.112*"service" + -0.105*"objective" + -0.096*"last" '
#   '+ 0.095*"uncertainty" + 0.093*"outlook" + -0.091*"information" + '
#   '0.090*"labour" + 0.089*"public" + 0.087*"month"'),
#  (94,
#   '0.172*"july" + -0.142*"service" + -0.108*"inflationary" + 0.107*"suggest" + '
#   '-0.097*"september" + -0.092*"balance" + 0.090*"number" + -0.089*"reduce" + '
#   '0.088*"stronger" + 0.088*"ensure"'),
#  (95,
#   '-0.120*"regard" + 0.105*"continues" + -0.102*"remains" + -0.099*"june" + '
#   '-0.097*"however" + -0.097*"tender" + 0.097*"order" + 0.091*"significantly" '
#   '+ -0.088*"improvement" + 0.086*"new"'),
#  (96,
#   '-0.117*"ongoing" + 0.111*"due" + 0.106*"wage" + -0.103*"production" + '
#   '0.101*"measure" + -0.099*"improvement" + 0.095*"april" + '
#   '-0.092*"environment" + -0.088*"owing" + -0.087*"opportunity"'),
#  (97,
#   '-0.118*"range" + 0.093*"recovery" + -0.089*"coming" + -0.087*"interest" + '
#   '-0.086*"supporting" + -0.086*"december" + -0.085*"many" + 0.084*"october" + '
#   '-0.084*"january" + -0.084*"press"'),
#  (98,
#   '-0.143*"owing" + 0.115*"implementation" + -0.114*"september" + '
#   '-0.113*"level" + -0.107*"fiscal" + -0.105*"strengthening" + -0.101*"course" '
#   '+ 0.098*"longterm" + -0.096*"framework" + 0.089*"given"'),
#  (99,
#   '0.137*"fiscal" + -0.118*"outlook" + 0.107*"august" + -0.102*"november" + '
#   '0.097*"background" + 0.097*"strengthening" + -0.096*"shortterm" + '
#   '0.094*"firm" + 0.091*"remains" + 0.089*"half"')]

# %% [markdown]
# # Evaluation
# Topic 0 is a represented as _0.016“car” + 0.014“power” + 0.010“light” + 0.009“drive” + 0.007“mount” + 0.007“controller” + 0.007“cool” + 0.007“engine” + 0.007“back” + ‘0.006“turn”.
#
# It means the top 10 keywords that contribute to this topic are: ‘car’, ‘power’, ‘light’.. and so on and the weight of ‘car’ on topic 0 is 0.016.
#
# The weights reflect how important a keyword is to that topic.
#
# Looking at these keywords, can you guess what this topic could be? You may summarise it either are ‘cars’ or ‘automobiles’.

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute Perplexity not working?
#print('\nPerplexity: ', lsi_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.


# Compute Coherence Score
coherence_model_lsi5 = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi5 = coherence_model_lsi5.get_coherence()
print('\nCoherence Score5: ', coherence_lsi5)

# Compute Coherence Score
coherence_model_lsi10 = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi10 = coherence_model_lsi10.get_coherence()
print('\nCoherence Score10: ', coherence_lsi10)

# Compute Coherence Score
coherence_model_lsi20 = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi20 = coherence_model_lsi20.get_coherence()
print('\nCoherence Score20: ', coherence_lsi20)

# Compute Coherence Score
coherence_model_lsi50 = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi50 = coherence_model_lsi50.get_coherence()
print('\nCoherence Score50: ', coherence_lsi50)

# Compute Coherence Score
coherence_model_lsi100 = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='c_v')
coherence_lsi100 = coherence_model_lsi100.get_coherence()
print('\nCoherence Score100: ', coherence_lsi100)


# Compute Coherence Score
coherence_model_lsi5 = CoherenceModel(model=lsi_model5, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi5 = coherence_model_lsi5.get_coherence()
print('\nCoherence Score5: ', coherence_lsi5)

# Compute Coherence Score
coherence_model_lsi10 = CoherenceModel(model=lsi_model10, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi10 = coherence_model_lsi10.get_coherence()
print('\nCoherence Score10: ', coherence_lsi10)

# Compute Coherence Score
coherence_model_lsi20 = CoherenceModel(model=lsi_model20, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi20 = coherence_model_lsi20.get_coherence()
print('\nCoherence Score20: ', coherence_lsi20)

# Compute Coherence Score
coherence_model_lsi50 = CoherenceModel(model=lsi_model50, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi50 = coherence_model_lsi50.get_coherence()
print('\nCoherence Score50: ', coherence_lsi50)

# Compute Coherence Score
coherence_model_lsi100 = CoherenceModel(model=lsi_model100, texts=data, dictionary=id2word, coherence='u_mass')
coherence_lsi100 = coherence_model_lsi100.get_coherence()
print('\nCoherence Score100: ', coherence_lsi100)
# Out:
# Coherence Score5:  0.35895310315514867
#
# Coherence Score10:  0.35981935220504474
#
# Coherence Score20:  0.3177107166753187
#
# Coherence Score50:  0.2661538065697478
#
# Coherence Score100:  0.24111208227019712
#
# Coherence Score5:  -0.4969437369397351
#
# Coherence Score10:  -0.35776576982152414
#
# Coherence Score20:  -0.4122784504979503
#
# Coherence Score50:  -0.8384191081744025
#
# Coherence Score100:  -0.7247330471276321
